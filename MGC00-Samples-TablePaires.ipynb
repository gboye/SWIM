# %%
# -*- coding: utf8 -*-
# %matplotlib inline
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import math

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %% [markdown]
# typeEchantillon :
# - fixe pour utiliser tailleEchantillon
# - variable pour utiliser nombre,increment
# - total pour utiliser tout le lexique

# %%
numEchantillon=5
filePrefix="MGC-150815"
exportName="MGC-151208-TablesPaires-%02d-SWIM.pkl"%numEchantillon
repertoire="/Users/gilles/Copy/Recherche/Boye/CMLF2016/"

# %%
rangsEchantillons=5
nombreEchantillons=20
echantillonPrefix="-extend"

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %% [markdown]
# ###Définition des cases
# - principales pour le paradigme courant
# - secondaires pour les cases rares
# - totales pour le tout

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %%
pdEchantillon=pd.read_csv("2015-Data/"+filePrefix+echantillonPrefix+"-%02d-paradigmes.csv"%numEchantillon,sep=";",encoding="utf8")
pdEchantillon
# Out:
#       Unnamed: 0       lexeme      ai1P     ai1S ai2P     ai2S      ai3P  \
# 0              0     abaisser       NaN    abEsE  NaN      NaN    abEsEr
# 1              1   abandonner  abâdOnam  abâdOnE  NaN  abâdOna  abâdOnEr
# 2              2   abasourdir       NaN      NaN  NaN      NaN       NaN
# 3              3      abattre       NaN    abati  NaN      NaN    abatir
# 4              4     abdiquer       NaN   abdikE  NaN      NaN       NaN
# 5              5      aberrer       NaN      NaN  NaN      NaN       NaN
# 6              6     abhorrer       NaN      NaN  NaN      NaN       NaN
# 7              7      abjurer       NaN      NaN  NaN      NaN       NaN
# 8              8       abolir       NaN      NaN  NaN      NaN       NaN
# 9              9      abonder       NaN    abôdE  NaN      NaN       NaN
# 10            10      abonner       NaN    abOnE  NaN      NaN       NaN
# 11            11      aborder   abOrdam   abOrdE  NaN      NaN   abOrdEr
# 12            12     aboucher       NaN      NaN  NaN      NaN       NaN
# 13            13      abouler       NaN      NaN  NaN      NaN       NaN
# 14            14      abouter       NaN      NaN  NaN      NaN       NaN
# 15            15      aboutir    abutim    abuti  NaN      NaN    abutir
# 16            16       aboyer       NaN      NaN  NaN      NaN   abwajEr
# 17            17      abraser       NaN      NaN  NaN      NaN       NaN
# 18            18     abreuver       NaN      NaN  NaN      NaN       NaN
# 19            19    abricoter       NaN      NaN  NaN      NaN       NaN
# 20            20      abriter   abritam   abritE  NaN      NaN   abritEr
# 21            21      abroger       NaN      NaN  NaN      NaN       NaN
# 22            22      abrutir       NaN      NaN  NaN      NaN       NaN
# 23            23      abréger       NaN   abrEZE  NaN      NaN       NaN
# 24            24     absenter       NaN   absâtE  NaN      NaN   absâtEr
# 25            25     absorber       NaN  absOrbE  NaN      NaN  absOrbEr
# 26            26     absoudre       NaN      NaN  NaN      NaN       NaN
# 27            27     abstenir       NaN    abstê  NaN      NaN    abstêr
# 28            28    abstraire       NaN      NaN  NaN      NaN       NaN
# 29            29       abuser       NaN    abyzE  NaN      NaN    abyzEr
# ...          ...          ...       ...      ...  ...      ...       ...
# 5342        5342     étourdir       NaN      NaN  NaN      NaN   Eturdir
# 5343        5343    étrangler       NaN  EtrâglE  NaN      NaN       NaN
# 5344        5344    étreindre   EtrEJim      NaN  NaN      NaN   EtrEJir
# 5345        5345     étrenner       NaN      NaN  NaN      NaN       NaN
# 5346        5346     étriller       NaN      NaN  NaN      NaN       NaN
# 5347        5347      étriper       NaN      NaN  NaN      NaN   EtripEr
# 5348        5348     étriquer       NaN      NaN  NaN      NaN       NaN
# 5349        5349      étrécir       NaN      NaN  NaN      NaN       NaN
# 5350        5350      étudier       NaN   EtydjE  NaN      NaN   EtydjEr
# 5351        5351       étuver       NaN      NaN  NaN      NaN       NaN
# 5352        5352       étêter       NaN      NaN  NaN      NaN       NaN
# 5353        5353      évacuer       NaN   EvakyE  NaN      NaN   EvakyEr
# 5354        5354       évader       NaN      NaN  NaN      NaN    EvadEr
# 5355        5355      évaluer       NaN      NaN  NaN      NaN   EvalyEr
# 5356        5356  évangéliser       NaN      NaN  NaN      NaN       NaN
# 5357        5357     évanouir       NaN      NaN  NaN      NaN   Evanuir
# 5358        5358     évaporer       NaN      NaN  NaN      NaN       NaN
# 5359        5359       évaser       NaN      NaN  NaN      NaN       NaN
# 5360        5360     éveiller       NaN    EvEjE  NaN      NaN    EvEjEr
# 5361        5361      éventer       NaN    EvâtE  NaN      NaN       NaN
# 5362        5362     éventrer       NaN      NaN  NaN      NaN       NaN
# 5363        5363     évertuer       NaN      NaN  NaN      NaN       NaN
# 5364        5364       évider       NaN      NaN  NaN      NaN       NaN
# 5365        5365      évincer       NaN    EvêsE  NaN      NaN       NaN
# 5366        5366    éviscérer       NaN      NaN  NaN      NaN       NaN
# 5367        5367       éviter    Evitam    EvitE  NaN      NaN    EvitEr
# 5368        5368      évoluer       NaN      NaN  NaN      NaN   EvOlyEr
# 5369        5369      évoquer    EvOkam    EvOkE  NaN      NaN    EvOkEr
# 5370        5370         être       fym       fy  fyt       fy       fyr
# 5371        5371         ôter       NaN      OtE  NaN      NaN      OtEr
#
#          ai3S       fi1P       fi1S   ...        ppFP      ppFS       ppMP  \
# 0       abEsa        NaN    abEs6rE   ...       abEse     abEse      abEse
# 1     abâdOna  abâdOn6rô  abâdOn6rE   ...     abâdOne   abâdOne    abâdOne
# 2         NaN        NaN        NaN   ...         NaN  abazurdi   abazurdi
# 3       abati     abatrô     abatrE   ...       abaty     abaty      abaty
# 4      abdika        NaN        NaN   ...         NaN    abdike        NaN
# 5         NaN        NaN        NaN   ...         NaN       NaN        NaN
# 6         NaN        NaN        NaN   ...         NaN     abOre      abOre
# 7         NaN        NaN        NaN   ...         NaN       NaN        NaN
# 8       abOli        NaN        NaN   ...       abOli     abOli      abOli
# 9       abôda        NaN        NaN   ...         NaN       NaN        NaN
# 10        NaN        NaN        NaN   ...       abOne     abOne      abOne
# 11     abOrda   abOrd6rô   abOrd6rE   ...      abOrde    abOrde     abOrde
# 12        NaN        NaN        NaN   ...         NaN     abuSe      abuSe
# 13        NaN        NaN        NaN   ...         NaN       NaN        NaN
# 14        NaN        NaN        NaN   ...         NaN       NaN        NaN
# 15      abuti    abutirô    abutirE   ...         NaN       NaN        NaN
# 16     abwaja        NaN        NaN   ...         NaN       NaN        NaN
# 17        NaN        NaN        NaN   ...         NaN       NaN        NaN
# 18     abr6va        NaN        NaN   ...         NaN    abr6ve     abr6ve
# 19        NaN        NaN        NaN   ...         NaN       NaN        NaN
# 20     abrita   abrit6rô        NaN   ...      abrite    abrite     abrite
# 21        NaN        NaN        NaN   ...      abrOZe    abrOZe     abrOZe
# 22     abryti        NaN        NaN   ...      abryti    abryti     abryti
# 23     abrEZa        NaN   abrEZ6rE   ...         NaN    abrEZe        NaN
# 24     absâta        NaN   absât6rE   ...         NaN    absâte     absâte
# 25    absOrba        NaN  absOrb6rE   ...     absOrbe   absOrbe    absOrbe
# 26        NaN        NaN    absudrE   ...       absut     absut        NaN
# 27      abstê  abstjêdrô  abstjêdrE   ...     abst6ny   abst6ny    abst6ny
# 28        NaN        NaN        NaN   ...     abstrEt   abstrEt     abstrE
# 29      abyza        NaN    abyz6rE   ...       abyze     abyze      abyze
# ...       ...        ...        ...   ...         ...       ...        ...
# 5342   Eturdi        NaN        NaN   ...         NaN    Eturdi     Eturdi
# 5343  Etrâgla        NaN  Etrâgl6rE   ...     Etrâgle   Etrâgle    Etrâgle
# 5344   EtrEJi    Etrêdrô        NaN   ...       Etrêt     Etrêt       Etrê
# 5345   EtrEna        NaN        NaN   ...         NaN    EtrEne        NaN
# 5346   Etrija        NaN        NaN   ...         NaN    Etrije     Etrije
# 5347      NaN        NaN   Etrip6rE   ...         NaN    Etripe     Etripe
# 5348   Etrika        NaN        NaN   ...      Etrike    Etrike     Etrike
# 5349   EtrEsi        NaN        NaN   ...         NaN    EtrEsi        NaN
# 5350   Etydja    Etydirô    EtydirE   ...      Etydje    Etydje     Etydje
# 5351      NaN        NaN        NaN   ...         NaN       NaN        NaN
# 5352    EtEta        NaN        NaN   ...         NaN       NaN      EtEte
# 5353   Evakya    Evakyrô    EvakyrE   ...      Evakye    Evakye     Evakye
# 5354    Evada        NaN    Evad6rE   ...         NaN     Evade      Evade
# 5355   Evalya        NaN        NaN   ...      Evalye    Evalye     Evalye
# 5356      NaN        NaN        NaN   ...         NaN       NaN  EvâZElize
# 5357   Evanui   Evanuirô   EvanuirE   ...      Evanui    Evanui     Evanui
# 5358  EvapOra        NaN        NaN   ...         NaN       NaN    EvapOre
# 5359      NaN        NaN        NaN   ...       Evaze     Evaze      Evaze
# 5360    EvEja        NaN    EvEj6rE   ...       EvEje     EvEje      EvEje
# 5361    Evâta        NaN    Evât6rE   ...       Evâte     Evâte      Evâte
# 5362   Evâtra        NaN   Evâtr6rE   ...      Evâtre    Evâtre     Evâtre
# 5363  EvErtya        NaN        NaN   ...         NaN       NaN        NaN
# 5364    Evida        NaN        NaN   ...       Evide     Evide      Evide
# 5365      NaN        NaN        NaN   ...         NaN     Evêse      Evêse
# 5366      NaN        NaN        NaN   ...         NaN   EvisEre    EvisEre
# 5367    Evita    Evit6rô    Evit6rE   ...       Evite     Evite      Evite
# 5368   EvOlya        NaN        NaN   ...         NaN       NaN        NaN
# 5369    EvOka    EvOk6rô    EvOk6rE   ...       EvOke     EvOke      EvOke
# 5370       fy       s6rô       s6rE   ...         NaN       NaN        NaN
# 5371      Ota        NaN      Ot6rE   ...         Ote       Ote        Ote
#
#            ppMS   ps1P     ps1S      ps2P     ps2S    ps3P     ps3S
# 0         abEse    NaN      NaN       NaN      NaN     NaN      NaN
# 1       abâdOne    NaN      NaN       NaN   abâdOn  abâdOn   abâdOn
# 2      abazurdi    NaN      NaN       NaN      NaN     NaN      NaN
# 3         abaty    NaN     abat       NaN     abat     NaN     abat
# 4        abdike    NaN      NaN       NaN      NaN     NaN      NaN
# 5           NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 6         abOre    NaN      NaN       NaN      NaN     NaN      NaN
# 7        abZyre    NaN      NaN       NaN      NaN     NaN      NaN
# 8         abOli    NaN      NaN       NaN      NaN     NaN      NaN
# 9           NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 10        abOne    NaN      NaN       NaN      NaN     NaN      NaN
# 11       abOrde    NaN      NaN       NaN      NaN     NaN      NaN
# 12        abuSe    NaN      NaN       NaN      NaN     NaN      NaN
# 13          NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 14          NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 15          NaN    NaN   abutis       NaN      NaN     NaN   abutis
# 16          NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 17       abraze    NaN      NaN       NaN      NaN     NaN      NaN
# 18       abr6ve    NaN      NaN       NaN      NaN     NaN      NaN
# 19          NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 20       abrite    NaN      NaN       NaN      NaN     NaN      NaN
# 21       abrOZe    NaN      NaN       NaN      NaN     NaN      NaN
# 22       abryti    NaN      NaN       NaN      NaN     NaN      NaN
# 23       abrEZe    NaN      NaN       NaN      NaN     NaN      NaN
# 24       absâte    NaN      NaN       NaN      NaN     NaN    absât
# 25      absOrbe    NaN      NaN  absOrbje      NaN     NaN      NaN
# 26          NaN    NaN      NaN       NaN   absOlv     NaN   absOlv
# 27      abst6ny    NaN  abstjEn       NaN  abstjEn     NaN  abstjEn
# 28       abstrE    NaN      NaN       NaN      NaN     NaN      NaN
# 29        abyze    NaN      NaN       NaN      NaN     NaN      NaN
# ...         ...    ...      ...       ...      ...     ...      ...
# 5342     Eturdi    NaN      NaN       NaN      NaN     NaN      NaN
# 5343    Etrâgle    NaN   Etrâgl       NaN      NaN     NaN      NaN
# 5344       Etrê    NaN    EtrEJ       NaN      NaN   EtrEJ    EtrEJ
# 5345     EtrEne    NaN      NaN       NaN    EtrEn     NaN      NaN
# 5346     Etrije    NaN      NaN       NaN      NaN     NaN      NaN
# 5347     Etripe    NaN    Etrip       NaN      NaN     NaN    Etrip
# 5348     Etrike    NaN      NaN       NaN      NaN     NaN      NaN
# 5349     EtrEsi    NaN      NaN       NaN      NaN     NaN      NaN
# 5350     Etydje    NaN      NaN   Etydije      NaN     NaN      NaN
# 5351      Etyve    NaN      NaN       NaN      NaN     NaN      NaN
# 5352      EtEte    NaN      NaN       NaN      NaN     NaN      NaN
# 5353     Evakye    NaN      NaN       NaN    Evaky     NaN      NaN
# 5354      Evade    NaN      NaN       NaN     Evad     NaN     Evad
# 5355     Evalye    NaN      NaN       NaN      NaN     NaN      NaN
# 5356  EvâZElize    NaN      NaN       NaN      NaN     NaN      NaN
# 5357     Evanui    NaN  Evanuis       NaN  Evanuis     NaN  Evanuis
# 5358    EvapOre    NaN      NaN       NaN      NaN     NaN      NaN
# 5359      Evaze    NaN      NaN       NaN      NaN     NaN      NaN
# 5360      EvEje    NaN      NaN       NaN      NaN     NaN      NaN
# 5361      Evâte    NaN      NaN       NaN      NaN     NaN      NaN
# 5362     Evâtre    NaN      NaN       NaN      NaN     NaN      NaN
# 5363    EvErtye    NaN      NaN       NaN      NaN     NaN      NaN
# 5364      Evide    NaN      NaN       NaN      NaN     NaN      NaN
# 5365      Evêse    NaN      NaN       NaN      NaN     NaN      NaN
# 5366        NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 5367      Evite    NaN      NaN       NaN      NaN     NaN     Evit
# 5368        NaN    NaN      NaN       NaN      NaN     NaN      NaN
# 5369      EvOke    NaN      NaN       NaN      NaN     NaN      NaN
# 5370        Ete  swajô      swa     swaje      swa     swa      swa
# 5371        Ote    NaN      NaN       NaN      NaN     NaN      NaN
#
# [5372 rows x 53 columns]

# %%
sampleCases=[]
for element in pdEchantillon.columns:
    if element in casesTotales:
        sampleCases.append(element)
#sampleCases

# %%
refCases=casesTotales

# %%
table=pd.DataFrame(columns=["ligne","colonne","nbPaires"])
for n,paire in enumerate(it.combinations_with_replacement(refCases,2)):
    if paire[0] in pdEchantillon.columns and paire[1] in pdEchantillon.columns:
        nbPaires=len(pdEchantillon[[paire[0],paire[1]]].dropna())
    else:
        nbPaires=0
    table.loc[2*n]=[paire[0],paire[1],nbPaires]
    table.loc[2*n+1]=[paire[1],paire[0],nbPaires]

# %%
table
# Out:
#      ligne colonne  nbPaires
# 0      inf     inf      4704
# 1      inf     inf      4704
# 2      inf    pi1S      2934
# 3     pi1S     inf      2934
# 4      inf    pi2S      1826
# 5     pi2S     inf      1826
# 6      inf    pi3S      3802
# 7     pi3S     inf      3802
# 8      inf    pi1P      1305
# 9     pi1P     inf      1305
# 10     inf    pi2P      1931
# 11    pi2P     inf      1931
# 12     inf    pi3P      2983
# 13    pi3P     inf      2983
# 14     inf    ii1S      1906
# 15    ii1S     inf      1906
# 16     inf    ii2S       977
# 17    ii2S     inf       977
# 18     inf    ii3S      3515
# 19    ii3S     inf      3515
# 20     inf    ii1P       970
# 21    ii1P     inf       970
# 22     inf    ii2P       820
# 23    ii2P     inf       820
# 24     inf    ii3P      2773
# 25    ii3P     inf      2773
# 26     inf    fi1S      1277
# 27    fi1S     inf      1277
# 28     inf    fi2S       802
# 29    fi2S     inf       802
# ...    ...     ...       ...
# 2622  is2S    is2S       134
# 2623  is2S    is2S       134
# 2624  is2S    is3S        99
# 2625  is3S    is2S        99
# 2626  is2S    is1P        47
# 2627  is1P    is2S        47
# 2628  is2S    is2P        46
# 2629  is2P    is2S        46
# 2630  is2S    is3P        58
# 2631  is3P    is2S        58
# 2632  is3S    is3S       949
# 2633  is3S    is3S       949
# 2634  is3S    is1P       109
# 2635  is1P    is3S       109
# 2636  is3S    is2P       107
# 2637  is2P    is3S       107
# 2638  is3S    is3P       182
# 2639  is3P    is3S       182
# 2640  is1P    is1P       138
# 2641  is1P    is1P       138
# 2642  is1P    is2P        45
# 2643  is2P    is1P        45
# 2644  is1P    is3P        56
# 2645  is3P    is1P        56
# 2646  is2P    is2P       130
# 2647  is2P    is2P       130
# 2648  is2P    is3P        66
# 2649  is3P    is2P        66
# 2650  is3P    is3P       240
# 2651  is3P    is3P       240
#
# [2652 rows x 3 columns]

# %%
tableau=table.pivot_table(index="ligne",columns=["colonne"])
tableau
# Out:
#         nbPaires                                                  ...         \
# colonne     ai1P  ai1S ai2P ai2S  ai3P  ai3S fi1P  fi1S fi2P fi2S ...   ppFP
# ligne                                                             ...
# ai1P         427   353   83  116   383   415  287   352  293  276 ...    345
# ai1S         353  1208  112  178   901  1145  529   766  557  552 ...    920
# ai2P          83   112  133   55   121   128   95   117  107  107 ...    114
# ai2S         116   178   55  238   193   225  141   185  146  155 ...    196
# ai3P         383   901  121  193  1602  1488  628   874  633  611 ...   1180
# ai3S         415  1145  128  225  1488  2816  722  1155  767  750 ...   1841
# fi1P         287   529   95  141   628   722  767   631  503  491 ...    632
# fi1S         352   766  117  185   874  1155  631  1279  681  662 ...   1000
# fi2P         293   557  107  146   633   767  503   681  819  542 ...    668
# fi2S         276   552  107  155   611   750  491   662  542  803 ...    643
# fi3P         327   675  113  170   821   996  580   775  593  580 ...    874
# fi3S         373   894  124  195  1113  1515  689  1048  721  705 ...   1295
# ii1P         332   675  110  161   764   905  549   681  531  512 ...    756
# ii1S         392  1019  127  194  1162  1648  666  1023  714  701 ...   1325
# ii2P         295   587  111  153   629   758  487   654  520  524 ...    653
# ii2S         309   647  115  166   714   903  502   720  551  564 ...    754
# ii3P         414  1110  129  214  1486  2223  725  1145  766  753 ...   1840
# ii3S         420  1182  132  220  1556  2585  748  1230  799  790 ...   2168
# inf          426  1206  133  234  1596  2757  767  1277  818  802 ...   2431
# is1P          79   115   47   56   120   134  105   116  102  104 ...    120
# is1S         112   160   57   72   165   182  136   166  146  149 ...    166
# is2P          77   110   49   59   120   128  109   117  113  113 ...    119
# is2S          76   109   40   55   118   131  104   114  102  105 ...    106
# is3P         122   190   50   77   204   232  162   202  170  173 ...    205
# is3S         305   645  107  161   746   903  493   668  511  482 ...    773
# pI1P         353   739  110  170   863  1076  611   836  615  591 ...    954
# pI2P         377   968  124  200  1150  1661  699  1102  734  727 ...   1441
# pI2S         402  1064  129  212  1320  2019  710  1179  762  758 ...   1693
# pP           419  1148  130  219  1513  2430  743  1195  786  775 ...   2028
# pc1P         179   261   73  105   285   307  235   285  250  238 ...    282
# pc1S         316   647  113  173   726   893  524   759  570  571 ...    776
# pc2P         197   322   84  119   349   391  294   359  311  304 ...    339
# pc2S         249   472  106  152   510   612  401   563  444  461 ...    537
# pc3P         317   621  107  161   756   875  514   683  533  524 ...    751
# pc3S         376   887  125  186  1091  1494  672  1017  697  694 ...   1244
# pi1P         366   806  113  178   929  1163  628   869  638  613 ...    996
# pi1S         412  1139  129  218  1422  2248  741  1234  789  784 ...   1866
# pi2P         378   951  125  197  1136  1614  696  1086  740  727 ...   1367
# pi2S         357   870  127  194  1034  1493  640   990  680  691 ...   1222
# pi3P         414  1113  133  211  1498  2313  746  1195  793  774 ...   1953
# pi3S         426  1191  133  225  1567  2643  759  1261  806  797 ...   2282
# ppFP         345   920  114  196  1180  1841  632  1000  668  643 ...   2601
# ppFS         366  1031  123  206  1322  2166  673  1121  724  700 ...   2398
# ppMP         359   987  120  197  1297  2048  656  1084  702  691 ...   2272
# ppMS         382  1091  126  210  1398  2402  692  1173  753  729 ...   2507
# ps1P          82   126   48   64   138   153  113   131  116  116 ...    141
# ps1S         191   322   84  125   376   447  291   380  310  308 ...    393
# ps2P          97   136   56   65   151   158  130   150  130  132 ...    148
# ps2S         192   332   86  121   382   467  295   384  305  320 ...    424
# ps3P          98   146   52   71   159   180  134   151  132  133 ...    157
# ps3S         250   446   98  143   550   674  412   532  424  409 ...    579
#
#
# colonne  ppFS  ppMP  ppMS ps1P ps1S ps2P ps2S ps3P ps3S
# ligne
# ai1P      366   359   382   82  191   97  192   98  250
# ai1S     1031   987  1091  126  322  136  332  146  446
# ai2P      123   120   126   48   84   56   86   52   98
# ai2S      206   197   210   64  125   65  121   71  143
# ai3P     1322  1297  1398  138  376  151  382  159  550
# ai3S     2166  2048  2402  153  447  158  467  180  674
# fi1P      673   656   692  113  291  130  295  134  412
# fi1S     1121  1084  1173  131  380  150  384  151  532
# fi2P      724   702   753  116  310  130  305  132  424
# fi2S      700   691   729  116  308  132  320  133  409
# fi3P      932   919   978  132  356  141  353  143  493
# fi3S     1474  1413  1566  143  416  156  413  161  601
# ii1P      820   810   867  126  313  138  326  146  431
# ii1S     1505  1449  1657  147  429  155  415  172  601
# ii2P      707   688   740  125  299  137  309  134  412
# ii2S      826   804   881  124  331  142  334  149  441
# ii3P     2158  2041  2365  150  442  158  466  182  676
# ii3S     2630  2504  2973  154  461  160  501  186  716
# inf      3072  2855  3642  157  474  164  529  188  743
# is1P      126   124   130   50   78   58   81   50   90
# is1S      170   168   175   61  107   70  115   68  129
# is2P      120   118   122   52   86   52   86   52  107
# is2S      118   111   121   47   75   51   80   52   92
# is3P      214   213   221   58  134   71  125   74  168
# is3S      840   813   869  113  311  136  311  144  434
# pI1P     1048  1013  1096  129  347  145  359  146  478
# pI2P     1683  1611  1818  141  419  155  428  166  589
# pI2S     2000  1909  2209  149  436  160  469  180  647
# pP       2409  2259  2702  151  465  161  480  183  704
# pc1P      292   287   296   77  170   94  178   96  214
# pc1S      856   831   883  128  345  142  347  138  465
# pc2P      362   353   371   93  204   98  224  108  261
# pc2S      581   564   596  115  279  131  300  125  368
# pc3P      824   797   849  121  328  134  319  142  451
# pc3S     1418  1369  1503  140  412  152  398  167  609
# pi1P     1098  1070  1160  138  364  150  367  152  512
# pi1S     2229  2129  2522  151  464  163  483  179  688
# pi2P     1589  1541  1720  144  425  157  426  167  591
# pi2S     1418  1344  1555  142  432  153  475  169  616
# pi3P     2299  2182  2541  149  447  161  486  185  699
# pi3S     2809  2634  3215  156  469  163  533  186  735
# ppFP     2398  2272  2507  141  393  148  424  157  579
# ppFS     3322  2722  3155  146  423  152  471  167  635
# ppMP     2722  3065  2958  143  416  148  455  160  605
# ppMS     3155  2958  3977  149  433  154  492  169  654
# ps1P      146   143   149  157   83   55   86   61  107
# ps1S      423   416   433   83  475  101  241   98  363
# ps2P      152   148   154   55  101  164  107   62  114
# ps2S      471   455   492   86  241  107  537  102  303
# ps3P      167   160   169   61   98   62  102  189  129
# ps3S      635   605   654  107  363  114  303  129  746
#
# [51 rows x 51 columns]

# %% [raw]
# with codecs.open(repertoire+exportName,"wb") as output:
#     pickle.dump(tableau, output, pickle.HIGHEST_PROTOCOL)

# %%
tableau.to_csv(repertoire+exportName.replace(".pkl",".csv"),sep=";",encoding="utf8")

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
import yaml

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
sampleNumber="03-X"
genDigraphe=False
genGraphe=False
samplePrefix="MGC-150815-extend-%s-paradigmes"%sampleNumber
sampleFile=samplePrefix+".csv"
goldFile="MGC-150815-total-1508150555-paradigmes.csv"
analysisPrefix="MGC-150815-extend-%s"%sampleNumber
logfile_name=analysisPrefix+samplePrefix+".log"
logfile = codecs.open("2015-Data/"+logfile_name,mode='w',encoding="utf8")

# %% [markdown]
# ###Préparation des cases du paradigme

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# #Préparation du calcul des analogies

# %% [markdown]
# ###Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ###Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ###Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ###Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmes=pd.read_csv("2015-Data/"+sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
#paradigmes

# %%
phonologicalMap=analysisPrefix[-2:]
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %%
GOLD=pd.read_csv("2015-Data/"+goldFile,sep=";",encoding="utf8")
del GOLD[u"Unnamed: 0"]
goldCases=GOLD.columns.tolist()
goldCases.remove(u"lexeme")
for case in goldCases:
    GOLD[case]=GOLD[case].apply(lambda x: recoder(x))
    
paradigmesGOLD=GOLD[paradigmes.columns.values.tolist()]
#paradigmesGOLD

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 49485

# %%
with open("2015-Data/"+analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ###Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(casesTotales):
    print ("Attention l'analyse ne comprend pas toutes les cases")

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %%
def generate(lexeme,genDigraphe=True):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
len(paradigmes.dropna(thresh=2)["lexeme"])
# Out:
# 4547

# %%
paradigmes.dropna(thresh=2).count().sum()-paradigmes.dropna(thresh=2)["lexeme"].count()
# Out:
# 44938

# %% [markdown]
# ####Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    for (depart,arrivee) in it.combinations_with_replacement(clique,2):
        score+=graph[depart][arrivee]["weight"]
    return score

# %% [markdown]
# ##Génération des formes

# %%
# %%time
debug=False
#listeTest=[u"manger",u"boire",u"dormir",u"aller",u"neiger"]
listeTest=paradigmes.dropna(thresh=2)["lexeme"].values.tolist()
#listeTest=[u"abasourdir",u"évacuer"]
nbVerbes=len(listeTest)
print (nbVerbes)
globDigraphe=nx.DiGraph()
globGraphe=nx.Graph()
cliques=[]
cliquesScores={}
cliquesListes={}
numClique=0
for i,element in enumerate(listeTest):
    if (i%25)==0: print (i, dateheure(), int(100*float(i)/nbVerbes), end=", ")
    result=generate(element,genDigraphe)
    (generation,lexDigraphe,lexGraphe,lexCliques)= result
#    print (generation,lexDigraphe,lexGraphe,lexCliques)
    if genDigraphe:
        globDigraphe=nx.union(globDigraphe,lexDigraphe)
    if genGraphe:
        globGraphe=nx.union(globGraphe,lexGraphe)
    cliques.extend(lexCliques)
    for clique in lexCliques:
        cliquesScores[numClique]=cliqueScore(clique,lexGraphe)
        cliquesListes[numClique]=clique
        numClique+=1
# Out:
# 4547
# 0 1509140307 0, 25 1509140309 0, 50 1509140310 1, 75 1509140312 1, 100 1509140314 2, 125 1509140315 2, 150 1509140317 3, 175 1509140318 3, 200 1509140320 4, 225 1509140321 4, 250 1509140323 5, 275 1509140325 6, 300 1509140326 6, 325 1509140328 7, 350 1509140330 7, 375 1509140331 8, 400 1509140333 8, 425 1509140334 9, 450 1509140335 9, 475 1509140337 10, 500 1509140338 10, 525 1509140339 11, 550 1509140341 12, 575 1509140342 12, 600 1509140343 13, 625 1509140344 13, 650 1509140346 14, 675 1509140347 14, 700 1509140348 15, 725 1509140350 15, 750 1509140351 16, 775 1509140352 17, 800 1509140354 17, 825 1509140355 18, 850 1509140357 18, 875 1509140358 19, 900 1509140400 19, 925 1509140402 20, 950 1509140403 20, 975 1509140405 21, 1000 1509140406 21, 1025 1509140408 22, 1050 1509140409 23, 1075 1509140411 23, 1100 1509140412 24, 1125 1509140414 24, 1150 1509140415 25, 1175 1509140416 25, 1200 1509140418 26, 1225 1509140419 26, 1250 1509140420 27, 1275 1509140422 28, 1300 1509140423 28, 1325 1509140425 29, 1350 1509140426 29, 1375 1509140427 30, 1400 1509140428 30, 1425 1509140430 31, 1450 1509140431 31, 1475 1509140432 32, 1500 1509140434 32, 1525 1509140435 33, 1550 1509140436 34, 1575 1509140437 34, 1600 1509140439 35, 1625 1509140441 35, 1650 1509140442 36, 1675 1509140443 36, 1700 1509140445 37, 1725 1509140446 37, 1750 1509140448 38, 1775 1509140449 39, 1800 1509140451 39, 1825 1509140453 40, 1850 1509140454 40, 1875 1509140456 41, 1900 1509140457 41, 1925 1509140459 42, 1950 1509140500 42, 1975 1509140502 43, 2000 1509140503 43, 2025 1509140505 44, 2050 1509140506 45, 2075 1509140508 45, 2100 1509140509 46, 2125 1509140510 46, 2150 1509140512 47, 2175 1509140513 47, 2200 1509140515 48, 2225 1509140516 48, 2250 1509140518 49, 2275 1509140519 50, 2300 1509140520 50, 2325 1509140522 51, 2350 1509140523 51, 2375 1509140525 52, 2400 1509140526 52, 2425 1509140528 53, 2450 1509140529 53, 2475 1509140531 54, 2500 1509140532 54, 2525 1509140534 55, 2550 1509140535 56, 2575 1509140537 56, 2600 1509140538 57, 2625 1509140539 57, 2650 1509140541 58, 2675 1509140542 58, 2700 1509140544 59, 2725 1509140545 59, 2750 1509140546 60, 2775 1509140548 61, 2800 1509140549 61, 2825 1509140551 62, 2850 1509140552 62, 2875 1509140554 63, 2900 1509140555 63, 2925 1509140557 64, 2950 1509140559 64, 2975 1509140600 65, 3000 1509140601 65, 3025 1509140603 66, 3050 1509140604 67, 3075 1509140606 67, 3100 1509140608 68, 3125 1509140609 68, 3150 1509140611 69, 3175 1509140612 69, 3200 1509140614 70, 3225 1509140616 70, 3250 1509140617 71, 3275 1509140619 72, 3300 1509140620 72, 3325 1509140622 73, 3350 1509140624 73, 3375 1509140625 74, 3400 1509140627 74, 3425 1509140629 75, 3450 1509140631 75, 3475 1509140632 76, 3500 1509140634 76, 3525 1509140636 77, 3550 1509140638 78, 3575 1509140640 78, 3600 1509140641 79, 3625 1509140643 79, 3650 1509140644 80, 3675 1509140646 80, 3700 1509140647 81, 3725 1509140648 81, 3750 1509140650 82, 3775 1509140652 83, 3800 1509140653 83, 3825 1509140655 84, 3850 1509140656 84, 3875 1509140658 85, 3900 1509140659 85, 3925 1509140701 86, 3950 1509140702 86, 3975 1509140704 87, 4000 1509140705 87, 4025 1509140707 88, 4050 1509140708 89, 4075 1509140710 89, 4100 1509140711 90, 4125 1509140713 90, 4150 1509140715 91, 4175 1509140716 91, 4200 1509140718 92, 4225 1509140719 92, 4250 1509140720 93, 4275 1509140721 94, 4300 1509140723 94, 4325 1509140724 95, 4350 1509140726 95, 4375 1509140727 96, 4400 1509140729 96, 4425 1509140730 97, 4450 1509140731 97, 4475 1509140733 98, 4500 1509140734 98, 4525 1509140736 99, CPU times: user 4h 28min 30s, sys: 37.4 s, total: 4h 29min 8s
# Wall time: 4h 30min 29s

# %%
# %%time
versionStamp=dateheure()
if genDigraphe: 
    nx.write_dot(globDigraphe,u"2015-Data/digraphe-%s.dot"%versionStamp)
if genGraphe:
    nx.write_dot(globGraphe,u"2015-Data/graphe-%s.dot"%versionStamp)
# Out:
# CPU times: user 26 µs, sys: 4 µs, total: 30 µs
# Wall time: 29.1 µs

# %%
print (len(cliques))
# Out:
# 589271

# %%
longueurCliques={}
for clique in cliques:
    longueur=len(clique)
    if not longueur in longueurCliques:
        longueurCliques[longueur]=1
    else:
        longueurCliques[longueur]+=1
longueurCliques
# Out:
# {1: 4,
#  2: 3531,
#  3: 2760,
#  4: 7668,
#  5: 7250,
#  6: 9637,
#  7: 15055,
#  8: 23345,
#  9: 27118,
#  10: 30091,
#  11: 27344,
#  12: 26186,
#  13: 25603,
#  14: 25743,
#  15: 22804,
#  16: 23162,
#  17: 25095,
#  18: 27769,
#  19: 28488,
#  20: 28613,
#  21: 29287,
#  22: 25056,
#  23: 21711,
#  24: 17446,
#  25: 14035,
#  26: 11407,
#  27: 9547,
#  28: 9042,
#  29: 8177,
#  30: 8606,
#  31: 7194,
#  32: 5844,
#  33: 4843,
#  34: 4844,
#  35: 3914,
#  36: 3208,
#  37: 2428,
#  38: 2772,
#  39: 2014,
#  40: 3749,
#  41: 2283,
#  42: 1960,
#  43: 1591,
#  44: 1007,
#  45: 15,
#  46: 5,
#  47: 3,
#  48: 10,
#  49: 4,
#  53: 3}

# %% [markdown]
# ###Faire la liste des cases lexicalisées de l'échantillon

# %%
nbFormesLexicales={}
casesLexicales={element:paradigmes[paradigmes["lexeme"]==element].columns[paradigmes[paradigmes["lexeme"]==element].notnull().iloc[0]].tolist() for element in listeTest}
for element in casesLexicales:
    casesLexicales[element].remove("lexeme")
    nbFormesLexicales[element]=len(casesLexicales[element])

# %% [markdown]
# ##Comparer la sortie des cliques avec le paradigme de départ

# %%
# %%time
seuilClique=1
#paradigmesCLIQUES=pd.DataFrame(columns=paradigmes.columns.values.tolist())
paradigmesListe=[]
for n,clique in enumerate(sorted(cliques,key=lambda x: len(x),reverse=True)):
#    if seuilClique==0:
#        seuilClique=len(clique)-15
    if len(clique)>seuilClique:
        paradigmeClique={}
        sampleOK=True
#        print (n, len(clique))
        point=clique[0].split("-")
        lPoint=len(point)
#        print (point,"-".join(point[0:len(point)-2]))
        if lPoint==3:
            lexeme=point[0]
        else:
            lexeme="-".join(point[0:len(point)-2])
        paradigmeClique["lexeme"]=lexeme
        if n%250==0: print (n,end=", ")
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].notnull().columns.tolist()
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
#        casesLexeme.remove("lexeme")
        casesLexeme=casesLexicales[lexeme]
        nbInitial=len(casesLexeme)
        if casesLexeme and len(casesLexeme)<=len(clique):
            for element in casesLexeme:
#                print (lexeme,element, paradigmes[paradigmes["lexeme"]==lexeme][element])
                champForme=paradigmes[paradigmes["lexeme"]==lexeme][element].iloc[0]
                if ","  in champForme:
                    formes=champForme.split(",")
                    nbInitial+=len(formes)-1
                    okFormes=False
                    for forme in formes:
                        pointCase=u"%s-%s-%s"% (lexeme,forme,element)
#                        if debug: print (pointCase, clique)
                        if pointCase in clique:
                            okFormes=True
                            print ("point",pointCase)
#                            print ("clique",clique)
                            print ("gold",GOLD[GOLD["lexeme"]==lexeme][element])
                    if okFormes:
                        sampleOK=True
                    else:
                        sampleOK=False
                        break
                else:
                    forme=champForme
                    pointCase=u"%s-%s-%s"% (lexeme,forme,element)
                    if debug: print (pointCase, clique)
                    if not pointCase in clique:
                        sampleOK=False
#                        print ("point",pointCase)
#                        print ("clique",clique)
#                        print ("gold",GOLD[GOLD["lexeme"]==lexeme][element])
                        break
        else:
            sampleOK=False
        if sampleOK:
            for element in clique:
                elements=element.split("-")
                forme=elements[-2]
                taminfo=elements[-1]
#                try:
#                 (lexeme,forme,taminfo)=element.split("-")
#                except ValueError:
#                    print (element)
                paradigmeClique[taminfo]=forme
#                if taminfo in paradigmes.columns:
#                    if not paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].isnull().item():
#                        if paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item()!=forme:
#                            sampleOK=False
#                            print (paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item(),forme,taminfo,end=", ")
            paradigmeClique["score"]=cliquesScores[n]
            paradigmeClique["ajouts"]=len(clique)-nbInitial
#            print (cliqueScore(clique),clique)
            paradigmesListe.append(paradigmeClique)
        else:
            if debug:
                print ()
                print (lexeme,clique)
                print ()
    else:
        break

paradigmesCLIQUES=pd.DataFrame(paradigmesListe,columns=GOLD.columns.values.tolist()+[u"score",u"ajouts"])
print (seuilClique)
# Out:
# 0, point essayer-EsErô-fi1P
# gold 2749    EsErô,EsEj6rô
# Name: fi1P, dtype: object
# point essayer-EsEj6rô-fi1P
# gold 2749    EsErô,EsEj6rô
# Name: fi1P, dtype: object
# point essayer-EsErE-fi1S
# gold 2749    EsErE,EsEj6rE
# Name: fi1S, dtype: object
# point essayer-EsEj6rE-fi1S
# gold 2749    EsErE,EsEj6rE
# Name: fi1S, dtype: object
# point essayer-EsEre-fi2P
# gold 2749    EsEre,EsEj6re
# Name: fi2P, dtype: object
# point essayer-EsEj6re-fi2P
# gold 2749    EsEre,EsEj6re
# Name: fi2P, dtype: object
# point essayer-EsErô-fi3P
# gold 2749    EsErô,EsEj6rô
# Name: fi3P, dtype: object
# point essayer-EsEj6rô-fi3P
# gold 2749    EsErô,EsEj6rô
# Name: fi3P, dtype: object
# point essayer-EsEra-fi3S
# gold 2749    EsEra,EsEj6ra
# Name: fi3S, dtype: object
# point essayer-EsEj6ra-fi3S
# gold 2749    EsEra,EsEj6ra
# Name: fi3S, dtype: object
# point essayer-EsE-pI2S
# gold 2749    EsE,EsEj
# Name: pI2S, dtype: object
# point essayer-EsEj-pI2S
# gold 2749    EsE,EsEj
# Name: pI2S, dtype: object
# point essayer-EsErE-pc1S
# gold 2749    EsErE,EsEj6rE
# Name: pc1S, dtype: object
# point essayer-EsEj6rE-pc1S
# gold 2749    EsErE,EsEj6rE
# Name: pc1S, dtype: object
# point essayer-EsErE-pc2S
# gold 2749    EsErE,EsEj6rE
# Name: pc2S, dtype: object
# point essayer-EsEj6rE-pc2S
# gold 2749    EsErE,EsEj6rE
# Name: pc2S, dtype: object
# point essayer-EsErE-pc3P
# gold 2749    EsErE,EsEj6rE
# Name: pc3P, dtype: object
# point essayer-EsEj6rE-pc3P
# gold 2749    EsErE,EsEj6rE
# Name: pc3P, dtype: object
# point essayer-EsErE-pc3S
# gold 2749    EsErE,EsEj6rE
# Name: pc3S, dtype: object
# point essayer-EsEj6rE-pc3S
# gold 2749    EsErE,EsEj6rE
# Name: pc3S, dtype: object
# point essayer-EsE-pi1S
# gold 2749    EsE,EsEj
# Name: pi1S, dtype: object
# point essayer-EsEj-pi1S
# gold 2749    EsE,EsEj
# Name: pi1S, dtype: object
# point essayer-EsE-pi2S
# gold 2749    EsE,EsEj
# Name: pi2S, dtype: object
# point essayer-EsEj-pi2S
# gold 2749    EsE,EsEj
# Name: pi2S, dtype: object
# point essayer-EsE-pi3P
# gold 2749    EsE,EsEj
# Name: pi3P, dtype: object
# point essayer-EsEj-pi3P
# gold 2749    EsE,EsEj
# Name: pi3P, dtype: object
# point essayer-EsE-pi3S
# gold 2749    EsE,EsEj
# Name: pi3S, dtype: object
# point essayer-EsEj-pi3S
# gold 2749    EsE,EsEj
# Name: pi3S, dtype: object
# point essayer-EsE-ps2S
# gold 2749    EsE,EsEj
# Name: ps2S, dtype: object
# point essayer-EsEj-ps2S
# gold 2749    EsE,EsEj
# Name: ps2S, dtype: object
# point payer-pErô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pErE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEre-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pEj6ra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pErô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEj6rô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pEj6ra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pE-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pEj-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pErE-pc1S
# gold 4229    pErE,pEj6rE
# Name: pc1S, dtype: object
# point payer-pEj6rE-pc1S
# gold 4229    pErE,pEj6rE
# Name: pc1S, dtype: object
# point payer-pErE-pc2S
# gold 4229    pErE,pEj6rE
# Name: pc2S, dtype: object
# point payer-pEj6rE-pc2S
# gold 4229    pErE,pEj6rE
# Name: pc2S, dtype: object
# point payer-pErE-pc3P
# gold 4229    pErE,pEj6rE
# Name: pc3P, dtype: object
# point payer-pEj6rE-pc3P
# gold 4229    pErE,pEj6rE
# Name: pc3P, dtype: object
# point payer-pErE-pc3S
# gold 4229    pErE,pEj6rE
# Name: pc3S, dtype: object
# point payer-pEj6rE-pc3S
# gold 4229    pErE,pEj6rE
# Name: pc3S, dtype: object
# point payer-pE-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pEj-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pE-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pEj-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pE-pi3P
# gold 4229    pE,pEj
# Name: pi3P, dtype: object
# point payer-pEj-pi3P
# gold 4229    pE,pEj
# Name: pi3P, dtype: object
# point payer-pE-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pEj-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pE-ps1S
# gold 4229    pE,pEj
# Name: ps1S, dtype: object
# point payer-pEj-ps1S
# gold 4229    pE,pEj
# Name: ps1S, dtype: object
# point payer-pE-ps3S
# gold 4229    pE,pEj
# Name: ps3S, dtype: object
# point payer-pEj-ps3S
# gold 4229    pE,pEj
# Name: ps3S, dtype: object
# point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pErE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEre-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pErô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEj6rô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pEj6ra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pEj-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pErE-pc1S
# gold 4229    pErE,pEj6rE
# Name: pc1S, dtype: object
# point payer-pEj6rE-pc1S
# gold 4229    pErE,pEj6rE
# Name: pc1S, dtype: object
# point payer-pErE-pc2S
# gold 4229    pErE,pEj6rE
# Name: pc2S, dtype: object
# point payer-pEj6rE-pc2S
# gold 4229    pErE,pEj6rE
# Name: pc2S, dtype: object
# point payer-pErE-pc3P
# gold 4229    pErE,pEj6rE
# Name: pc3P, dtype: object
# point payer-pEj6rE-pc3P
# gold 4229    pErE,pEj6rE
# Name: pc3P, dtype: object
# point payer-pErE-pc3S
# gold 4229    pErE,pEj6rE
# Name: pc3S, dtype: object
# point payer-pEj6rE-pc3S
# gold 4229    pErE,pEj6rE
# Name: pc3S, dtype: object
# point payer-pE-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pEj-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pE-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pEj-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pE-pi3P
# gold 4229    pE,pEj
# Name: pi3P, dtype: object
# point payer-pEj-pi3P
# gold 4229    pE,pEj
# Name: pi3P, dtype: object
# point payer-pE-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pEj-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsEj-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsEj-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsEj-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsEj-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point vouloir-v6je-pI2P
# gold 6227    v6je,vule
# Name: pI2P, dtype: object
# point vouloir-vule-pI2P
# gold 6227    v6je,vule
# Name: pI2P, dtype: object
# 250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, point asseoir-asjErE-fi1S
# gold 398    asjErE,aswarE
# Name: fi1S, dtype: object
# point asseoir-aswarE-fi1S
# gold 398    asjErE,aswarE
# Name: fi1S, dtype: object
# point asseoir-asjErô-fi3P
# gold 398    asjErô,aswarô
# Name: fi3P, dtype: object
# point asseoir-aswarô-fi3P
# gold 398    asjErô,aswarô
# Name: fi3P, dtype: object
# point asseoir-asEje-pI2P
# gold 398    asEje,aswaje
# Name: pI2P, dtype: object
# point asseoir-aswaje-pI2P
# gold 398    asEje,aswaje
# Name: pI2P, dtype: object
# point asseoir-asje-pI2S
# gold 398    asje,aswa
# Name: pI2S, dtype: object
# point asseoir-aswa-pI2S
# gold 398    asje,aswa
# Name: pI2S, dtype: object
# point asseoir-asje-pi1S
# gold 398    asje,aswa
# Name: pi1S, dtype: object
# point asseoir-aswa-pi1S
# gold 398    asje,aswa
# Name: pi1S, dtype: object
# point asseoir-asEje-pi2P
# gold 398    asEje,aswaje
# Name: pi2P, dtype: object
# point asseoir-aswaje-pi2P
# gold 398    asEje,aswaje
# Name: pi2P, dtype: object
# point asseoir-asje-pi2S
# gold 398    asje,aswa
# Name: pi2S, dtype: object
# point asseoir-aswa-pi2S
# gold 398    asje,aswa
# Name: pi2S, dtype: object
# point asseoir-asEj-pi3P
# gold 398    asEj,aswa
# Name: pi3P, dtype: object
# point asseoir-aswa-pi3P
# gold 398    asEj,aswa
# Name: pi3P, dtype: object
# point asseoir-asje-pi3S
# gold 398    asje,aswa
# Name: pi3S, dtype: object
# point asseoir-aswa-pi3S
# gold 398    asje,aswa
# Name: pi3S, dtype: object
# point asseoir-asEj-ps1S
# gold 398    asEj,aswa
# Name: ps1S, dtype: object
# point asseoir-aswa-ps1S
# gold 398    asEj,aswa
# Name: ps1S, dtype: object
# point asseoir-asEj-ps3S
# gold 398    asEj,aswa
# Name: ps3S, dtype: object
# point asseoir-aswa-ps3S
# gold 398    asEj,aswa
# Name: ps3S, dtype: object
# 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000, 10250, 10500, 10750, 11000, 11250, 11500, 11750, 12000, 12250, 12500, 12750, 13000, 13250, 13500, 13750, 14000, 14250, 14500, 14750, 15000, 15250, 15500, 15750, 16000, 16250, 16500, 16750, 17000, 17250, 17500, 17750, 18000, 18250, point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 18500, 18750, 19000, 19250, 19500, 19750, point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6ra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pEj6rô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEj6ra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6ra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pEj6rô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEj6ra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# 20000, point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 20250, 20500, 20750, 21000, 21250, 21500, point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 21750, 22000, 22250, 22500, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 22750, 23000, 23250, 23500, 23750, 24000, point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# 24250, 24500, 24750, 25000, 25250, 25500, 25750, 26000, 26250, 26500, 26750, 27000, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 27250, 27500, 27750, 28000, 28250, 28500, 28750, 29000, 29250, 29500, 29750, 30000, 30250, 30500, 30750, 31000, 31250, 31500, 31750, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 32000, 32250, 32500, 32750, 33000, point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 33250, 33500, 33750, 34000, 34250, 34500, 34750, 35000, 35250, 35500, 35750, 36000, 36250, 36500, 36750, 37000, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 37250, 37500, 37750, 38000, 38250, 38500, 38750, 39000, point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# 39250, 39500, 39750, 40000, 40250, 40500, 40750, 41000, 41250, 41500, 41750, 42000, 42250, 42500, 42750, 43000, 43250, 43500, 43750, 44000, 44250, 44500, 44750, 45000, 45250, 45500, 45750, 46000, 46250, 46500, 46750, 47000, 47250, 47500, 47750, 48000, 48250, 48500, 48750, 49000, 49250, 49500, 49750, 50000, 50250, 50500, 50750, 51000, 51250, 51500, 51750, 52000, 52250, 52500, 52750, 53000, 53250, 53500, 53750, 54000, 54250, 54500, 54750, 55000, 55250, 55500, 55750, 56000, 56250, 56500, 56750, 57000, 57250, point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 57500, 57750, 58000, 58250, 58500, 58750, 59000, 59250, 59500, 59750, 60000, 60250, 60500, 60750, 61000, 61250, 61500, 61750, 62000, 62250, 62500, 62750, 63000, 63250, 63500, 63750, 64000, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 64250, 64500, 64750, 65000, 65250, 65500, 65750, 66000, 66250, 66500, 66750, 67000, 67250, 67500, 67750, 68000, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 68250, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 68500, 68750, 69000, 69250, 69500, 69750, 70000, 70250, 70500, 70750, 71000, 71250, 71500, 71750, 72000, 72250, 72500, 72750, 73000, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 73250, 73500, 73750, 74000, 74250, point balayer-balE-pI2S
# gold 515    balE,balEj
# Name: pI2S, dtype: object
# point balayer-balEj-pI2S
# gold 515    balE,balEj
# Name: pI2S, dtype: object
# point balayer-balErE-pc3S
# gold 515    balErE,balEj6rE
# Name: pc3S, dtype: object
# point balayer-balEj6rE-pc3S
# gold 515    balErE,balEj6rE
# Name: pc3S, dtype: object
# point balayer-balE-pi1S
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# point balayer-balEj-pi1S
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# point balayer-balE-pi3S
# gold 515    balE,balEj
# Name: pi3S, dtype: object
# point balayer-balEj-pi3S
# gold 515    balE,balEj
# Name: pi3S, dtype: object
# 74500, 74750, 75000, 75250, 75500, 75750, 76000, 76250, 76500, 76750, 77000, 77250, 77500, 77750, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 78000, 78250, 78500, 78750, 79000, 79250, 79500, 79750, 80000, 80250, 80500, 80750, 81000, 81250, 81500, 81750, 82000, 82250, 82500, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 82750, 83000, 83250, 83500, 83750, 84000, 84250, 84500, point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 84750, 85000, 85250, 85500, 85750, 86000, 86250, 86500, point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrEj-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEj-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrEj-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrEj-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEj-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# 86750, 87000, 87250, 87500, 87750, point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 88000, 88250, 88500, 88750, 89000, 89250, 89500, 89750, 90000, 90250, 90500, 90750, 91000, point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 91250, 91500, 91750, 92000, 92250, 92500, 92750, 93000, 93250, 93500, 93750, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 94000, 94250, 94500, 94750, 95000, 95250, 95500, 95750, 96000, 96250, 96500, 96750, point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 97000, 97250, 97500, 97750, 98000, 98250, 98500, 98750, 99000, 99250, 99500, 99750, 100000, 100250, 100500, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 100750, 101000, 101250, 101500, 101750, 102000, 102250, 102500, 102750, 103000, 103250, 103500, 103750, 104000, 104250, 104500, point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 104750, 105000, 105250, 105500, 105750, 106000, 106250, 106500, 106750, 107000, 107250, 107500, 107750, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 108000, 108250, 108500, 108750, 109000, 109250, 109500, 109750, 110000, 110250, 110500, 110750, 111000, 111250, point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 111500, 111750, 112000, 112250, 112500, 112750, 113000, 113250, 113500, 113750, 114000, 114250, point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# 114500, 114750, 115000, 115250, 115500, 115750, 116000, 116250, point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# 116500, 116750, 117000, 117250, 117500, 117750, 118000, 118250, 118500, 118750, 119000, 119250, 119500, 119750, 120000, 120250, 120500, 120750, 121000, point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 121250, 121500, 121750, 122000, 122250, 122500, 122750, 123000, 123250, 123500, 123750, 124000, 124250, 124500, 124750, 125000, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 125250, 125500, 125750, 126000, 126250, 126500, 126750, 127000, 127250, 127500, 127750, 128000, 128250, 128500, 128750, 129000, 129250, 129500, 129750, point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# 130000, 130250, 130500, 130750, 131000, 131250, 131500, 131750, 132000, 132250, 132500, 132750, 133000, 133250, 133500, point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# 133750, 134000, 134250, 134500, 134750, 135000, 135250, 135500, 135750, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 136000, 136250, 136500, 136750, 137000, 137250, 137500, 137750, 138000, 138250, 138500, 138750, 139000, 139250, 139500, 139750, 140000, 140250, 140500, 140750, 141000, 141250, 141500, 141750, 142000, 142250, 142500, 142750, 143000, 143250, 143500, 143750, 144000, 144250, 144500, 144750, 145000, 145250, 145500, 145750, 146000, 146250, 146500, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 146750, 147000, 147250, 147500, 147750, 148000, 148250, 148500, 148750, 149000, 149250, 149500, 149750, 150000, 150250, 150500, 150750, 151000, 151250, 151500, 151750, 152000, 152250, 152500, 152750, point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 153000, 153250, 153500, 153750, 154000, 154250, 154500, 154750, 155000, 155250, 155500, 155750, 156000, 156250, 156500, 156750, 157000, 157250, 157500, 157750, 158000, 158250, 158500, 158750, 159000, 159250, 159500, 159750, 160000, 160250, 160500, 160750, 161000, 161250, 161500, 161750, 162000, 162250, 162500, 162750, 163000, 163250, 163500, 163750, 164000, 164250, 164500, 164750, 165000, 165250, 165500, 165750, 166000, point rayer-rE-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 166250, 166500, 166750, 167000, 167250, 167500, 167750, 168000, 168250, 168500, 168750, 169000, 169250, 169500, 169750, 170000, 170250, 170500, 170750, 171000, 171250, 171500, point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 171750, 172000, 172250, 172500, 172750, 173000, 173250, 173500, 173750, 174000, 174250, 174500, 174750, 175000, 175250, 175500, 175750, 176000, 176250, 176500, 176750, 177000, 177250, 177500, 177750, 178000, 178250, 178500, 178750, 179000, 179250, 179500, 179750, 180000, 180250, 180500, 180750, 181000, 181250, 181500, 181750, 182000, 182250, 182500, 182750, 183000, 183250, point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# 183500, 183750, 184000, 184250, 184500, 184750, 185000, 185250, 185500, 185750, 186000, 186250, 186500, 186750, 187000, 187250, 187500, 187750, 188000, 188250, 188500, 188750, 189000, 189250, 189500, 189750, 190000, 190250, 190500, 190750, 191000, 191250, 191500, 191750, 192000, 192250, 192500, 192750, 193000, 193250, 193500, 193750, point rayer-rE-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# 194000, 194250, 194500, 194750, 195000, 195250, 195500, 195750, 196000, 196250, 196500, 196750, 197000, 197250, 197500, 197750, 198000, 198250, 198500, 198750, 199000, 199250, 199500, 199750, 200000, 200250, 200500, 200750, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 201000, 201250, 201500, 201750, 202000, 202250, 202500, 202750, 203000, 203250, 203500, 203750, 204000, 204250, 204500, 204750, 205000, 205250, 205500, 205750, 206000, 206250, 206500, 206750, 207000, 207250, 207500, 207750, 208000, 208250, point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 208500, 208750, 209000, 209250, 209500, 209750, 210000, 210250, 210500, 210750, 211000, 211250, 211500, 211750, 212000, 212250, 212500, 212750, 213000, 213250, 213500, 213750, 214000, 214250, 214500, 214750, 215000, 215250, 215500, 215750, 216000, 216250, 216500, 216750, 217000, 217250, 217500, 217750, 218000, 218250, 218500, 218750, 219000, 219250, 219500, 219750, 220000, 220250, 220500, 220750, 221000, 221250, 221500, 221750, 222000, 222250, 222500, 222750, 223000, 223250, 223500, 223750, 224000, 224250, 224500, 224750, 225000, 225250, 225500, 225750, 226000, 226250, 226500, 226750, 227000, 227250, 227500, 227750, 228000, 228250, 228500, 228750, 229000, 229250, 229500, 229750, 230000, 230250, 230500, 230750, 231000, 231250, 231500, 231750, 232000, 232250, 232500, 232750, 233000, 233250, 233500, 233750, 234000, 234250, 234500, 234750, 235000, 235250, 235500, 235750, 236000, 236250, 236500, point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# 236750, 237000, 237250, 237500, 237750, 238000, 238250, 238500, 238750, 239000, 239250, 239500, 239750, 240000, 240250, 240500, 240750, 241000, 241250, 241500, 241750, 242000, 242250, 242500, 242750, 243000, 243250, 243500, 243750, 244000, 244250, 244500, 244750, 245000, 245250, 245500, 245750, 246000, 246250, 246500, 246750, 247000, 247250, 247500, 247750, 248000, 248250, 248500, 248750, 249000, 249250, 249500, 249750, 250000, 250250, 250500, 250750, 251000, 251250, 251500, 251750, 252000, 252250, 252500, 252750, 253000, 253250, 253500, 253750, 254000, 254250, 254500, 254750, 255000, 255250, 255500, 255750, 256000, 256250, 256500, 256750, 257000, 257250, 257500, 257750, 258000, 258250, 258500, 258750, 259000, 259250, 259500, 259750, 260000, 260250, 260500, 260750, 261000, 261250, 261500, 261750, 262000, 262250, 262500, 262750, 263000, 263250, 263500, 263750, 264000, 264250, 264500, 264750, 265000, 265250, 265500, 265750, 266000, 266250, 266500, 266750, 267000, 267250, 267500, 267750, 268000, 268250, 268500, 268750, 269000, 269250, 269500, 269750, 270000, 270250, 270500, 270750, 271000, 271250, 271500, 271750, 272000, 272250, 272500, 272750, 273000, 273250, 273500, 273750, 274000, 274250, 274500, 274750, 275000, 275250, 275500, 275750, 276000, 276250, 276500, 276750, 277000, 277250, 277500, 277750, 278000, 278250, 278500, 278750, 279000, 279250, 279500, 279750, 280000, 280250, 280500, 280750, 281000, 281250, 281500, 281750, 282000, 282250, 282500, 282750, 283000, 283250, 283500, 283750, 284000, 284250, 284500, 284750, 285000, 285250, 285500, 285750, 286000, 286250, 286500, 286750, 287000, 287250, 287500, 287750, 288000, 288250, 288500, 288750, 289000, 289250, 289500, 289750, 290000, 290250, 290500, 290750, 291000, 291250, 291500, 291750, 292000, 292250, 292500, 292750, 293000, 293250, 293500, 293750, 294000, 294250, 294500, 294750, 295000, 295250, 295500, 295750, 296000, 296250, 296500, 296750, 297000, 297250, 297500, 297750, 298000, 298250, 298500, 298750, 299000, 299250, 299500, 299750, 300000, 300250, 300500, 300750, 301000, 301250, 301500, 301750, 302000, 302250, 302500, 302750, 303000, 303250, 303500, 303750, 304000, 304250, 304500, 304750, 305000, 305250, 305500, 305750, 306000, 306250, 306500, 306750, 307000, 307250, 307500, 307750, 308000, 308250, 308500, 308750, 309000, 309250, 309500, 309750, 310000, 310250, 310500, 310750, 311000, 311250, 311500, 311750, 312000, 312250, 312500, 312750, 313000, 313250, 313500, 313750, 314000, 314250, 314500, 314750, 315000, 315250, 315500, 315750, 316000, 316250, 316500, 316750, 317000, 317250, 317500, 317750, 318000, 318250, 318500, 318750, 319000, 319250, 319500, 319750, 320000, 320250, 320500, 320750, 321000, 321250, 321500, 321750, 322000, 322250, 322500, 322750, 323000, 323250, 323500, 323750, 324000, 324250, 324500, 324750, 325000, 325250, 325500, 325750, 326000, 326250, 326500, 326750, 327000, 327250, 327500, 327750, 328000, 328250, 328500, 328750, 329000, 329250, 329500, 329750, 330000, 330250, 330500, 330750, 331000, 331250, 331500, 331750, 332000, 332250, 332500, 332750, 333000, 333250, 333500, 333750, 334000, 334250, 334500, 334750, 335000, 335250, 335500, 335750, 336000, 336250, 336500, 336750, 337000, 337250, 337500, 337750, 338000, 338250, 338500, 338750, 339000, 339250, 339500, 339750, 340000, 340250, 340500, 340750, 341000, 341250, 341500, 341750, 342000, 342250, 342500, 342750, 343000, 343250, 343500, 343750, 344000, 344250, 344500, 344750, 345000, 345250, 345500, 345750, 346000, 346250, 346500, 346750, 347000, 347250, 347500, 347750, 348000, 348250, 348500, 348750, 349000, 349250, 349500, 349750, 350000, 350250, 350500, 350750, 351000, 351250, 351500, 351750, 352000, 352250, 352500, 352750, 353000, 353250, 353500, 353750, 354000, 354250, 354500, 354750, 355000, 355250, 355500, 355750, 356000, 356250, 356500, 356750, 357000, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 357250, 357500, 357750, 358000, 358250, 358500, 358750, 359000, 359250, 359500, 359750, 360000, 360250, 360500, 360750, 361000, 361250, 361500, 361750, 362000, 362250, 362500, 362750, 363000, 363250, 363500, 363750, 364000, 364250, 364500, 364750, 365000, 365250, 365500, 365750, 366000, 366250, 366500, 366750, 367000, 367250, 367500, 367750, 368000, 368250, 368500, 368750, 369000, 369250, 369500, 369750, 370000, 370250, 370500, 370750, 371000, 371250, 371500, 371750, 372000, 372250, 372500, 372750, 373000, 373250, 373500, 373750, 374000, 374250, 374500, 374750, 375000, 375250, 375500, 375750, 376000, 376250, 376500, 376750, 377000, 377250, 377500, 377750, 378000, 378250, 378500, 378750, 379000, 379250, 379500, 379750, 380000, 380250, 380500, 380750, 381000, 381250, 381500, 381750, 382000, 382250, 382500, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 382750, 383000, 383250, 383500, 383750, 384000, 384250, 384500, 384750, 385000, 385250, 385500, 385750, 386000, 386250, 386500, 386750, 387000, 387250, 387500, 387750, 388000, 388250, 388500, 388750, 389000, 389250, 389500, 389750, 390000, 390250, 390500, 390750, 391000, 391250, 391500, 391750, 392000, 392250, 392500, 392750, 393000, 393250, 393500, 393750, 394000, 394250, 394500, 394750, 395000, 395250, 395500, 395750, 396000, 396250, 396500, 396750, 397000, 397250, 397500, 397750, 398000, 398250, 398500, 398750, 399000, 399250, 399500, 399750, 400000, 400250, 400500, 400750, 401000, 401250, 401500, 401750, 402000, 402250, 402500, 402750, 403000, 403250, 403500, 403750, 404000, 404250, 404500, 404750, 405000, 405250, 405500, 405750, 406000, 406250, 406500, 406750, 407000, 407250, 407500, 407750, 408000, 408250, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 408500, 408750, 409000, 409250, 409500, 409750, 410000, 410250, 410500, 410750, 411000, 411250, 411500, 411750, 412000, 412250, 412500, 412750, 413000, 413250, 413500, 413750, 414000, 414250, 414500, 414750, 415000, 415250, 415500, 415750, 416000, 416250, 416500, 416750, 417000, 417250, 417500, 417750, 418000, 418250, 418500, 418750, 419000, 419250, 419500, 419750, 420000, 420250, 420500, 420750, 421000, 421250, 421500, 421750, 422000, 422250, 422500, 422750, 423000, 423250, 423500, 423750, 424000, 424250, 424500, 424750, 425000, 425250, 425500, 425750, 426000, 426250, 426500, 426750, 427000, 427250, 427500, 427750, 428000, 428250, 428500, 428750, 429000, 429250, 429500, 429750, 430000, 430250, 430500, 430750, 431000, 431250, 431500, 431750, 432000, 432250, 432500, 432750, 433000, 433250, 433500, 433750, 434000, 434250, 434500, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 434750, 435000, 435250, 435500, 435750, 436000, 436250, 436500, 436750, 437000, 437250, 437500, 437750, 438000, 438250, 438500, 438750, 439000, 439250, 439500, 439750, 440000, 440250, 440500, 440750, 441000, 441250, 441500, 441750, 442000, 442250, 442500, 442750, 443000, 443250, 443500, 443750, 444000, 444250, 444500, 444750, 445000, 445250, 445500, 445750, 446000, 446250, 446500, 446750, 447000, 447250, 447500, 447750, 448000, 448250, 448500, 448750, 449000, 449250, 449500, 449750, 450000, 450250, 450500, 450750, 451000, 451250, 451500, 451750, 452000, 452250, 452500, 452750, 453000, 453250, 453500, 453750, 454000, 454250, 454500, 454750, 455000, 455250, 455500, 455750, 456000, 456250, 456500, 456750, 457000, 457250, 457500, 457750, 458000, 458250, 458500, 458750, 459000, 459250, 459500, 459750, 460000, 460250, 460500, 460750, 461000, 461250, 461500, 461750, 462000, 462250, 462500, 462750, 463000, 463250, 463500, 463750, 464000, 464250, 464500, 464750, 465000, 465250, 465500, 465750, 466000, 466250, 466500, 466750, 467000, 467250, 467500, 467750, 468000, 468250, 468500, 468750, 469000, 469250, 469500, 469750, 470000, 470250, 470500, 470750, 471000, 471250, 471500, 471750, 472000, 472250, 472500, 472750, 473000, 473250, 473500, 473750, 474000, 474250, 474500, 474750, 475000, 475250, 475500, 475750, 476000, 476250, 476500, 476750, 477000, 477250, 477500, 477750, 478000, 478250, 478500, 478750, 479000, 479250, 479500, 479750, 480000, 480250, 480500, 480750, 481000, 481250, 481500, 481750, 482000, 482250, 482500, 482750, 483000, 483250, point rasseoir-rasje-pi3S
# gold 4717    rasje,raswa
# Name: pi3S, dtype: object
# point rasseoir-raswa-pi3S
# gold 4717    rasje,raswa
# Name: pi3S, dtype: object
# 483500, 483750, 484000, 484250, 484500, 484750, 485000, 485250, 485500, 485750, 486000, 486250, 486500, 486750, 487000, 487250, 487500, 487750, 488000, 488250, 488500, 488750, 489000, 489250, 489500, 489750, 490000, 490250, 490500, 490750, 491000, 491250, 491500, 491750, 492000, 492250, 492500, 492750, 493000, 493250, 493500, 493750, 494000, 494250, 494500, 494750, 495000, 495250, 495500, 495750, 496000, 496250, 496500, 496750, 497000, 497250, 497500, 497750, 498000, 498250, 498500, 498750, 499000, 499250, 499500, 499750, 500000, 500250, 500500, 500750, 501000, 501250, 501500, 501750, 502000, 502250, 502500, 502750, 503000, 503250, 503500, 503750, 504000, 504250, 504500, 504750, 505000, 505250, 505500, 505750, 506000, 506250, 506500, 506750, 507000, 507250, 507500, 507750, 508000, 508250, 508500, 508750, 509000, 509250, 509500, 509750, 510000, 510250, 510500, 510750, 511000, 511250, 511500, 511750, 512000, 512250, 512500, 512750, 513000, 513250, 513500, 513750, 514000, 514250, 514500, 514750, 515000, 515250, 515500, 515750, 516000, 516250, 516500, 516750, 517000, 517250, 517500, 517750, 518000, 518250, 518500, 518750, 519000, 519250, 519500, 519750, 520000, 520250, 520500, 520750, 521000, 521250, 521500, 521750, 522000, 522250, 522500, 522750, 523000, 523250, 523500, 523750, 524000, 524250, 524500, 524750, 525000, 525250, 525500, 525750, 526000, 526250, 526500, 526750, 527000, 527250, 527500, 527750, 528000, 528250, 528500, 528750, 529000, 529250, 529500, 529750, 530000, 530250, 530500, 530750, 531000, 531250, 531500, 531750, 532000, 532250, 532500, 532750, 533000, 533250, 533500, 533750, 534000, 534250, 534500, 534750, 535000, 535250, 535500, 535750, 536000, 536250, 536500, 536750, 537000, 537250, 537500, 537750, 538000, 538250, 538500, 538750, 539000, 539250, 539500, 539750, 540000, 540250, 540500, 540750, 541000, 541250, 541500, 541750, 542000, 542250, 542500, 542750, 543000, 543250, 543500, 543750, 544000, 544250, 544500, 544750, 545000, 545250, 545500, 545750, 546000, 546250, 546500, 546750, 547000, 547250, 547500, 547750, 548000, 548250, 548500, 548750, 549000, 549250, 549500, 549750, 550000, 550250, 550500, 550750, 551000, 551250, 551500, 551750, 552000, 552250, 552500, 552750, 553000, 553250, 553500, 553750, 554000, 554250, 554500, 554750, 555000, 555250, 555500, 555750, 556000, 556250, 556500, 556750, 557000, 557250, 557500, 557750, 558000, 558250, 558500, 558750, 559000, 559250, 559500, 559750, 560000, 560250, 560500, 560750, 561000, 561250, 561500, 561750, 562000, 562250, 562500, 562750, 563000, 563250, 563500, 563750, 564000, 564250, 564500, 564750, 565000, 565250, 565500, 565750, 566000, 566250, 566500, 566750, 567000, 567250, 567500, 567750, 568000, 568250, 568500, 568750, 569000, 569250, 569500, 569750, 570000, 570250, 570500, 570750, 571000, 571250, 571500, 571750, 572000, 572250, 572500, 572750, 573000, 573250, 573500, 573750, 574000, 574250, 574500, 574750, 575000, 575250, 575500, 575750, 576000, 576250, 576500, 576750, 577000, 577250, 577500, 577750, 578000, 578250, 578500, 578750, 579000, 579250, 579500, 579750, 580000, 580250, 580500, 580750, 581000, 581250, 581500, 581750, 582000, 582250, 582500, 582750, 583000, 583250, 583500, 583750, 584000, 584250, 584500, 584750, 585000, 585250, 585500, 585750, 586000, 586250, 586500, 586750, 587000, 587250, 587500, 587750, 588000, 588250, 588500, 588750, 589000, 589250, 1
# CPU times: user 8min 30s, sys: 1.46 s, total: 8min 32s
# Wall time: 8min 34s

# %%
paradigmeSILVER=paradigmesCLIQUES[paradigmesCLIQUES["score"]==paradigmesCLIQUES.groupby(["lexeme"])["score"].transform(max)]

# %%
paradigmeSILVER
# Out:
#              lexeme        ai1P       ai1S ai2P    ai2S        ai3P  \
# 0           essayer      EsEjam      EsEjE  NaN     NaN      EsEjEr
# 1             payer         NaN       pEjE  NaN     NaN       pEjEr
# 2             faire         fim         fi  fit      fi         fir
# 3         réessayer         NaN    rEEsEjE  NaN     NaN    rEEsEjEr
# 10            avoir          ym          y  NaN     NaN          yr
# 11           devoir         dym         dy  NaN     NaN         dyr
# 13          trouver      truvam      truvE  NaN   truva      truvEr
# 14             être         fym         fy  fyt      fy         fyr
# 21            ruser       ryzam       ryzE  NaN    ryza       ryzEr
# 25          vouloir         NaN       vuly  NaN     NaN       vulyr
# 33          abriter     abritam     abritE  NaN     NaN     abritEr
# 49         adresser     adrEsam     adrEsE  NaN     NaN     adrEsEr
# 52     affectionner  afEksjOnam  afEksjOnE  NaN     NaN  afEksjOnEr
# 54          affiner      afinam      afinE  NaN     NaN      afinEr
# 56         affréter     afrEtam     afrEtE  NaN  afrEta     afrEtEr
# 58       agglutiner   aglytinam   aglytinE  NaN     NaN   aglytinEr
# 61         agresser     agrEsam     agrEsE  NaN     NaN     agrEsEr
# 64         agripper     agripam     agripE  NaN  agripa     agripEr
# 66     aiguillonner   EgHijOnam   EgHijOnE  NaN     NaN   EgHijOnEr
# 67            aimer        Emam        EmE  NaN     NaN        EmEr
# 70          aliéner     aljEnam     aljEnE  NaN     NaN     aljEnEr
# 71      ambitionner   âbisjOnam   âbisjOnE  NaN     NaN   âbisjOnEr
# 73        amidonner    amidOnam    amidOnE  NaN     NaN    amidOnEr
# 75          amputer      âpytam      âpytE  NaN     NaN      âpytEr
# 77        approuver     apruvam     apruvE  NaN     NaN     apruvEr
# 81         apprêter     aprEtam     aprEtE  NaN     NaN     aprEtEr
# 84      arraisonner    arEzOnam    arEzOnE  NaN     NaN    arEzOnEr
# 85          arrimer      arimam      arimE  NaN     NaN      arimEr
# 86          arriver      arivam      arivE  NaN   ariva      arivEr
# 87          arrêter      arEtam      arEtE  NaN   arEta      arEtEr
# ...             ...         ...        ...  ...     ...         ...
# 53655        courre         NaN        NaN  NaN     NaN         NaN
# 53656       cranter         NaN        NaN  NaN     NaN         NaN
# 53679       désaxer         NaN        NaN  NaN     NaN         NaN
# 53704        herser         NaN        NaN  NaN     NaN         NaN
# 53713       lisérer         NaN        NaN  NaN     NaN         NaN
# 53716       meugler         NaN        NaN  NaN     NaN         NaN
# 53720      monnayer         NaN        NaN  NaN     NaN         NaN
# 53721     moquetter         NaN        NaN  NaN     NaN         NaN
# 53725       méjuger         NaN        NaN  NaN     NaN         NaN
# 53735      parapher         NaN        NaN  NaN     NaN         NaN
# 53738     politiser         NaN        NaN  NaN     NaN         NaN
# 53741      pommeler         NaN        NaN  NaN     NaN         NaN
# 53742     postdater         NaN        NaN  NaN     NaN         NaN
# 53745    rabibocher         NaN        NaN  NaN     NaN         NaN
# 53754   reconquérir         NaN        NaN  NaN     NaN         NaN
# 53756    rediffuser         NaN        NaN  NaN     NaN         NaN
# 53783      vidanger         NaN        NaN  NaN     NaN         NaN
# 53786       écloper         NaN        NaN  NaN     NaN         NaN
# 53792        étuver         NaN        NaN  NaN     NaN         NaN
# 53793  brinquebaler         NaN        NaN  NaN     NaN         NaN
# 53796      emperler         NaN        NaN  NaN     NaN         NaN
# 53797         hâler         NaN        NaN  NaN     NaN         NaN
# 53799        jeûner         NaN        NaN  NaN     NaN         NaN
# 53803         paner         NaN        NaN  NaN     NaN         NaN
# 53818         seoir         NaN        NaN  NaN     NaN         NaN
# 53828       enclore         NaN        NaN  NaN     NaN         NaN
# 53836        meuler         NaN        NaN  NaN     NaN         NaN
# 53840        moudre         NaN        NaN  NaN     NaN         NaN
# 53853       sourdre         NaN        NaN  NaN     NaN         NaN
# 53855        éclore         NaN        NaN  NaN     NaN         NaN
#
#             ai3S        fi1P         fi1S         fi2P  ...         ppMP  \
# 0          EsEja     EsEj6rô      EsEj6rE      EsEj6re  ...        EsEje
# 1           pEja      pEj6rô       pEj6rE       pEj6re  ...         pEje
# 2             fi        f6rô         f6rE         f6re  ...           fE
# 3        rEEsEja   rEEsEj6rô    rEEsEj6rE    rEEsEj6re  ...      rEEsEje
# 10             y         Orô          OrE          Ore  ...            y
# 11            dy       d6vrô        d6vrE        d6vre  ...           dy
# 13         truva     truv6rô      truv6rE      truv6re  ...        truve
# 14            fy        s6rô         s6rE         s6re  ...          NaN
# 21          ryza      ryz6rô       ryz6rE       ryz6re  ...         ryze
# 25          vuly       vudrô        vudrE        vudre  ...         vuly
# 33        abrita    abrit6rô     abrit6rE     abrit6re  ...       abrite
# 49        adrEsa    adrEs6rô     adrEs6rE     adrEs6re  ...       adrEse
# 52     afEksjOna         NaN  afEksjOn6rE  afEksjOn6re  ...    afEksjOne
# 54         afina     afin6rô      afin6rE      afin6re  ...        afine
# 56        afrEta    afrEt6rô     afrEt6rE     afrEt6re  ...       afrEte
# 58      aglytina  aglytin6rô   aglytin6rE   aglytin6re  ...     aglytine
# 61        agrEsa    agrEs6rô     agrEs6rE     agrEs6re  ...       agrEse
# 64        agripa    agrip6rô     agrip6rE     agrip6re  ...       agripe
# 66      EgHijOna  EgHijOn6rô   EgHijOn6rE   EgHijOn6re  ...     EgHijOne
# 67           Ema         NaN        Em6rE        Em6re  ...          Eme
# 70        aljEna         NaN     aljEn6rE     aljEn6re  ...       aljEne
# 71      âbisjOna  âbisjOn6rô   âbisjOn6rE   âbisjOn6re  ...     âbisjOne
# 73       amidOna         NaN    amidOn6rE    amidOn6re  ...      amidOne
# 75         âpyta     âpyt6rô      âpyt6rE      âpyt6re  ...        âpyte
# 77        apruva    apruv6rô     apruv6rE     apruv6re  ...       apruve
# 81        aprEta    aprEt6rô     aprEt6rE     aprEt6re  ...       aprEte
# 84       arEzOna   arEzOn6rô    arEzOn6rE    arEzOn6re  ...      arEzOne
# 85         arima     arim6rô      arim6rE      arim6re  ...        arime
# 86         ariva     ariv6rô      ariv6rE      ariv6re  ...        arive
# 87         arEta     arEt6rô      arEt6rE      arEt6re  ...        arEte
# ...          ...         ...          ...          ...  ...          ...
# 53655        NaN        kurô         kurE          NaN  ...          NaN
# 53656        NaN         NaN          NaN          NaN  ...        krâte
# 53679        NaN         NaN          NaN          NaN  ...      dEzakse
# 53704        NaN         NaN          NaN          NaN  ...         Erse
# 53713        NaN         NaN          NaN          NaN  ...       lizEre
# 53716      m6gla         NaN          NaN          NaN  ...          NaN
# 53720     mOnEja         NaN          NaN          NaN  ...          NaN
# 53721        NaN         NaN          NaN          NaN  ...       mOkEte
# 53725        NaN         NaN          NaN          NaN  ...       mEZyZe
# 53735        NaN         NaN          NaN          NaN  ...       parafe
# 53738        NaN         NaN          NaN          NaN  ...     pOlitize
# 53741        NaN         NaN          NaN          NaN  ...       pOm6le
# 53742        NaN         NaN          NaN          NaN  ...     pOstdate
# 53745        NaN         NaN          NaN          NaN  ...     rabibOSe
# 53754        NaN         NaN          NaN          NaN  ...          NaN
# 53756        NaN         NaN          NaN          NaN  ...     r6difyze
# 53783        NaN         NaN          NaN          NaN  ...       vidâZe
# 53786        NaN         NaN          NaN          NaN  ...       EklOpe
# 53792        NaN         NaN          NaN          NaN  ...        Etyve
# 53793        NaN         NaN          NaN          NaN  ...    brêk6bale
# 53796        NaN         NaN          NaN          NaN  ...       âpErle
# 53797        NaN         NaN          NaN          NaN  ...          ale
# 53799        NaN         NaN          NaN          NaN  ...          NaN
# 53803        NaN         NaN          NaN          NaN  ...          NaN
# 53818        NaN         NaN          NaN          NaN  ...          NaN
# 53828        NaN         NaN          NaN          NaN  ...          NaN
# 53836        NaN         NaN          NaN          NaN  ...          NaN
# 53840        NaN         NaN          NaN          NaN  ...          NaN
# 53853        NaN         NaN          NaN          NaN  ...          NaN
# 53855        NaN         NaN          NaN          NaN  ...          NaN
#
#             ppMS        ps1P      ps1S        ps2P      ps2S      ps3P  \
# 0          EsEje         NaN       NaN         NaN       EsE       NaN
# 1           pEje         NaN       pEj         NaN       pEj       NaN
# 2             fE       fasjô       fas       fasje       fas       fas
# 3        rEEsEje         NaN       NaN         NaN    rEEsEj       NaN
# 10             y         Ejô         E         Eje         E         E
# 11            dy         NaN      dwav       d6vje      dwav      dwav
# 13         truve      truvjô      truv         NaN      truv      truv
# 14           NaN       swajô       swa       swaje       swa       swa
# 21          ryze       ryzjô       ryz         NaN       ryz       ryz
# 25          vuly       vuljô       v9j       vulje       v9j       v9j
# 33        abrite     abritjô     abrit     abritje     abrit     abrit
# 49        adrEse     adrEsjô     adrEs     adrEsje     adrEs     adrEs
# 52     afEksjOne  afEksjOnjô  afEksjOn  afEksjOnje  afEksjOn  afEksjOn
# 54         afine      afinjô      afin      afinje      afin      afin
# 56        afrEte     afrEtjô     afrEt         NaN     afrEt     afrEt
# 58      aglytine   aglytinjô   aglytin   aglytinje   aglytin   aglytin
# 61        agrEse     agrEsjô     agrEs     agrEsje     agrEs     agrEs
# 64        agripe     agripjô     agrip         NaN     agrip     agrip
# 66      EgHijOne   EgHijOnjô   EgHijOn   EgHijOnje   EgHijOn   EgHijOn
# 67           Eme        Emjô        Em        Emje        Em        Em
# 70        aljEne     aljEnjô     aljEn     aljEnje     aljEn     aljEn
# 71      âbisjOne   âbisjOnjô   âbisjOn   âbisjOnje   âbisjOn   âbisjOn
# 73       amidOne    amidOnjô    amidOn    amidOnje    amidOn    amidOn
# 75         âpyte      âpytjô      âpyt      âpytje      âpyt      âpyt
# 77        apruve     apruvjô     apruv     apruvje     apruv     apruv
# 81        aprEte     aprEtjô     aprEt     aprEtje     aprEt     aprEt
# 84       arEzOne    arEzOnjô    arEzOn    arEzOnje    arEzOn    arEzOn
# 85         arime      arimjô      arim      arimje      arim      arim
# 86         arive      arivjô      ariv         NaN      ariv      ariv
# 87         arEte      arEtjô      arEt         NaN      arEt      arEt
# ...          ...         ...       ...         ...       ...       ...
# 53655        NaN         NaN       NaN         NaN       NaN       NaN
# 53656      krâte         NaN       NaN         NaN       NaN       NaN
# 53679    dEzakse         NaN       NaN         NaN       NaN       NaN
# 53704        NaN         NaN       NaN         NaN       NaN       NaN
# 53713     lizEre         NaN       NaN         NaN       NaN       NaN
# 53716        NaN         NaN       NaN         NaN       NaN       NaN
# 53720        NaN         NaN       NaN         NaN       NaN       NaN
# 53721     mOkEte         NaN       NaN         NaN       NaN       NaN
# 53725     mEZyZe         NaN       NaN         NaN       NaN       NaN
# 53735     parafe         NaN       NaN         NaN       NaN       NaN
# 53738   pOlitize         NaN       NaN         NaN       NaN       NaN
# 53741     pOm6le         NaN       NaN         NaN       NaN       NaN
# 53742   pOstdate         NaN       NaN         NaN       NaN       NaN
# 53745   rabibOSe         NaN       NaN         NaN       NaN       NaN
# 53754        NaN         NaN       NaN         NaN       NaN       NaN
# 53756        NaN         NaN       NaN         NaN       NaN       NaN
# 53783     vidâZe         NaN       NaN         NaN       NaN       NaN
# 53786     EklOpe         NaN       NaN         NaN       NaN       NaN
# 53792      Etyve         NaN       NaN         NaN       NaN       NaN
# 53793  brêk6bale         NaN       NaN         NaN       NaN       NaN
# 53796     âpErle         NaN       NaN         NaN       NaN       NaN
# 53797        ale         NaN       NaN         NaN       NaN       NaN
# 53799        NaN         NaN       NaN         NaN       NaN       NaN
# 53803       pane         NaN       NaN         NaN       NaN       NaN
# 53818        NaN         NaN       NaN         NaN       NaN       NaN
# 53828        NaN         NaN       NaN         NaN       NaN       NaN
# 53836        NaN         NaN       NaN         NaN       NaN       NaN
# 53840       muly         NaN       NaN         NaN       NaN       NaN
# 53853        NaN         NaN       NaN         NaN       NaN       NaN
# 53855        NaN         NaN       NaN         NaN       NaN       NaN
#
#            ps3S       score ajouts
# 0           EsE   24.202445      0
# 1           pEj   37.528186      0
# 2           fas   45.065101      0
# 3         rEEsE   27.611996     39
# 10            E    4.903443      0
# 11         dwav    2.237239      0
# 13         truv    7.904566      0
# 14          swa   17.419402      0
# 21          ryz   51.087294     41
# 25          v9j   47.256412      0
# 33        abrit    8.966221     24
# 49        adrEs    4.469587     12
# 52     afEksjOn   55.741954     38
# 54         afin   60.547743     37
# 56        afrEt   71.316388     39
# 58      aglytin   76.457156     36
# 61        agrEs   38.993736     34
# 64        agrip   63.883999     30
# 66      EgHijOn   68.748015     40
# 67           Em   53.694037      0
# 70        aljEn   86.259914     38
# 71      âbisjOn   68.595334     41
# 73       amidOn   36.128037     40
# 75         âpyt   63.271613     37
# 77        apruv   69.663771     19
# 81        aprEt   34.779447     28
# 84       arEzOn   65.147948     43
# 85         arim   73.015295     36
# 86         ariv   43.912860      4
# 87         arEt   81.261085      1
# ...         ...         ...    ...
# 53655       NaN  163.824618      3
# 53656       NaN  123.218144      3
# 53679       NaN   49.912887      3
# 53704       NaN  257.900204      3
# 53713       NaN  198.935340      3
# 53716       NaN   29.409855      0
# 53720       NaN  338.726739      0
# 53721       NaN  370.768427      3
# 53725       NaN  146.735798      3
# 53735       NaN  261.919873      2
# 53738       NaN  271.398093      2
# 53741       NaN  285.709978      3
# 53742       NaN  264.778886      3
# 53745       NaN  337.048051      2
# 53754  r6kôkjEr   12.763392      0
# 53756       NaN   73.812750      3
# 53783       NaN  369.272336      3
# 53786       NaN  302.429509      3
# 53792       NaN   91.000000      3
# 53793       NaN  483.903417      2
# 53796       NaN  139.869137      2
# 53797       NaN  507.497184      1
# 53799       NaN  345.147413      0
# 53803       NaN  498.009416      1
# 53818       NaN   46.906240      0
# 53828       NaN   89.750986      0
# 53836       NaN  130.525773      0
# 53840       NaN   12.253097      0
# 53853       NaN   16.285355      0
# 53855       NaN   61.865183      1
#
# [4570 rows x 54 columns]

# %%
def compareGOLD(row):
    global n
#    if row["lexeme"]=="dodo": 
#        debug=True
#    else:
#        debug=False
    if n%250==0: print (n,end=", ")
    n+=1
    ligne={k:row[k] for k in row.keys() if not k in ["lexeme","score","ajouts"]}
    lexeme=row["lexeme"]
    score=row["score"]
    ajouts=row["ajouts"]
    if not lexeme in conjugaisons:
        conjugaisons[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    if not lexeme in cliquesTypes:
        cliquesTypes[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    identiques=[]
    differents=[]
    missing=[]
    over=[]
    for case in analyseCases:
        if debug:    
            print (lexeme,case)
            print (GOLD[GOLD["lexeme"]==lexeme][case].item())
            print ((GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]))
        if not case in row:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("absence",case)
        elif case in row[row.isnull()] and not GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("CLIQUES +NaN",case)
        elif not case in row[row.isnull()] and GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            over.append(u"%s : %s ≠ Ø" % (case,row[case]))
            lexical=False
            if debug: print ("GOLD -NaN",case)            
        elif (row[case]==GOLD[GOLD["lexeme"]==lexeme][case].item()):
            if debug: print ("egal")
            identiques.append(u"%s : %s" % (case,row[case]))
            if debug: print ("valeurs id")
        elif (case in row[row.isnull()]) and (GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]):
            if debug: print ("NaNs")
            identiques.append(u"%s : %s" % (case,u"ØØØ"))
            if debug: print ("deux NaN")
        else:
            if debug: print ("else")
            differents.append(u"%s : %s ≠ %s" % (case, row[case],GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print (u"différence",case)
    if differents:
        conjugaisons[lexeme]["diff"].append(differents)
        cliquesTypes[lexeme]["diff"].append((ligne,score,ajouts))
        if debug: print ("DIFF",len(differents),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: print (", ".join(differents))
    if missing and over:
        conjugaisons[lexeme]["overmiss"].append(over+missing)
        cliquesTypes[lexeme]["overmiss"].append((ligne,score,ajouts))
        if debug: print ("OVERMISS", len(over), len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
            print (", ".join(over))
    elif missing:
        conjugaisons[lexeme]["miss"].append(missing)
        cliquesTypes[lexeme]["miss"].append((ligne,score,ajouts))
        if debug: print ("MISS", len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
    elif over:
        conjugaisons[lexeme]["over"].append(over)
        cliquesTypes[lexeme]["over"].append((ligne,score,ajouts))
        if debug: print ("OVER", len(over),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(over))
    if identiques:
        conjugaisons[lexeme]["ok"].append(identiques)
        cliquesTypes[lexeme]["ok"].append((ligne,score,ajouts))
        if debug: print ("OK", len(identiques), len(identiques)-nombreElements[lexeme],end=saut)
        if debug1: print (", ".join(identiques))
#    print ()
    return lexical

# %%
# %%time
debug=False
debug1=False
saut="\n"
n=0
conjugaisons={}
cliquesTypes={}
print (", ".join(sampleCases))
#paradigmesCLIQUES.apply(compareGOLD,axis=1)
paradigmeSILVER.apply(compareGOLD,axis=1)
# Out:
# ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P, fi2S, fi3P, fi3S, ii1P, ii1S, ii2P, ii2S, ii3P, ii3S, inf, is1P, is1S, is2P, is2S, is3P, is3S, pI1P, pI2P, pI2S, pP, pc1P, pc1S, pc2P, pc2S, pc3P, pc3S, pi1P, pi1S, pi2P, pi2S, pi3P, pi3S, ppFP, ppFS, ppMP, ppMS, ps1P, ps1S, ps2P, ps2S, ps3P, ps3S
# 0, 250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, CPU times: user 7min 31s, sys: 710 ms, total: 7min 32s
# Wall time: 7min 35s

# %% [markdown]
# with codecs.open("2015-Data/"+samplePrefix+".yaml", 'w', encoding='utf8') as outfile:
#     outfile.write(yaml.dump(conjugaisons, default_flow_style=True, encoding='utf8'))

# %%
yaml.safe_dump(conjugaisons, file("2015-Data/"+samplePrefix+dateheure()+".yaml",'w'), encoding='utf-8', allow_unicode=True)
yaml.safe_dump(cliquesTypes, file("2015-Data/"+samplePrefix+"cliques-"+dateheure()+".yaml",'w'), encoding='utf-8', allow_unicode=True)

# %% [markdown]
# pb=[i for i in conjugaisons if conjugaisons[i]["diff"]]
# print (len(pb))
# for element in pb:
#     print (element)
#     print ("DIFF",conjugaisons[element]["diff"])
#     print ("MISS",conjugaisons[element]["miss"],end="\n\n")

# %% [markdown]
# good=[i for i in conjugaisons if not conjugaisons[i]["diff"]]
# for lexeme in good:
#     print (lexeme)
#     for ident in conjugaisons[lexeme]:
#         for element in conjugaisons[lexeme][ident]:
#             print (ident)
#             print (", ".join(element))
#     print ()

# %%
precisions={"bon":0,"mauvais":0}
for verbe in cliquesTypes:
    if debug: print (verbe)
    for cle in cliquesTypes[verbe]:
        if debug: print (cle)
        for element in cliquesTypes[verbe][cle]:
            if debug: print (element[1],element[2])
            if cle in ["ok"]:
                precisions["bon"]+=element[2]
            elif cle in ["diff"]:
                precisions["mauvais"]+=element[2]
precisions
# Out:
# {'bon': 105545, 'mauvais': 6028}

# %%
float(precisions["bon"])/(precisions["bon"]+precisions["mauvais"])
# Out:
# 0.9459725919353249

# %%
basesMesures={"total":0,"bon":0,"mauvais":0}
for verbe in conjugaisons:
    for cat in conjugaisons[verbe]:
        if conjugaisons[verbe][cat]:
#            print (verbe,cat,len(conjugaisons[verbe][cat][0]))
            if cat=="miss":
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
            elif cat=="ok":
                basesMesures["bon"]+=len(conjugaisons[verbe][cat][0])
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
            elif cat=="diff":
                basesMesures["mauvais"]+=len(conjugaisons[verbe][cat][0])
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
            elif cat=="overmiss":
                basesMesures["mauvais"]+=len(conjugaisons[verbe][cat][0])
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
basesMesures
# Out:
# {'bon': 148012, 'mauvais': 11539, 'total': 231627}

# %%
precisionManip=float(basesMesures["bon"])/(basesMesures["bon"]+basesMesures["mauvais"])
precisionManip
# Out:
# 0.927678297221578

# %%
rappelManip=float(basesMesures["bon"])/(basesMesures["total"])
rappelManip
# Out:
# 0.6390101326701982

# %%
paradigmeSILVER.to_csv(path_or_buf="2015-Data/"+analysisPrefix+'-Silver.csv',encoding="utf8",sep=";")
GOLD.to_csv(path_or_buf="2015-Data/"+analysisPrefix+'-Gold.csv',encoding="utf8",sep=";")

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
import yaml

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
sampleNumber="05-X"
genDigraphe=False
genGraphe=False
samplePrefix="MGC-150815-extend-%s-paradigmes"%sampleNumber
sampleFile=samplePrefix+".csv"
goldFile="MGC-150815-total-1508150555-paradigmes.csv"
analysisPrefix="MGC-150815-extend-%s"%sampleNumber
logfile_name=analysisPrefix+samplePrefix+".log"
logfile = codecs.open("2015-Data/"+logfile_name,mode='w',encoding="utf8")

# %% [markdown]
# ###Préparation des cases du paradigme

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# #Préparation du calcul des analogies

# %% [markdown]
# ###Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ###Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ###Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ###Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmes=pd.read_csv("2015-Data/"+sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
#paradigmes

# %%
phonologicalMap=analysisPrefix[-2:]
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %%
GOLD=pd.read_csv("2015-Data/"+goldFile,sep=";",encoding="utf8")
del GOLD[u"Unnamed: 0"]
goldCases=GOLD.columns.tolist()
goldCases.remove(u"lexeme")
for case in goldCases:
    GOLD[case]=GOLD[case].apply(lambda x: recoder(x))
    
paradigmesGOLD=GOLD[paradigmes.columns.values.tolist()]
#paradigmesGOLD

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 80263

# %%
with open("2015-Data/"+analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ###Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(casesTotales):
    print ("Attention l'analyse ne comprend pas toutes les cases")

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %%
def generate(lexeme,genDigraphe=True):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
len(paradigmes.dropna(thresh=2)["lexeme"])
# Out:
# 5372

# %%
paradigmes.dropna(thresh=2).count().sum()-paradigmes.dropna(thresh=2)["lexeme"].count()
# Out:
# 74891

# %% [markdown]
# ####Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    for (depart,arrivee) in it.combinations_with_replacement(clique,2):
        score+=graph[depart][arrivee]["weight"]
    return score

# %% [markdown]
# ##Génération des formes

# %%
# %%time
debug=False
#listeTest=[u"manger",u"boire",u"dormir",u"aller",u"neiger"]
listeTest=paradigmes.dropna(thresh=2)["lexeme"].values.tolist()
#listeTest=[u"abasourdir",u"évacuer"]
nbVerbes=len(listeTest)
print (nbVerbes)
globDigraphe=nx.DiGraph()
globGraphe=nx.Graph()
cliques=[]
cliquesScores={}
cliquesListes={}
numClique=0
for i,element in enumerate(listeTest):
    if (i%25)==0: print (i, dateheure(), int(100*float(i)/nbVerbes), end=", ")
    result=generate(element,genDigraphe)
    (generation,lexDigraphe,lexGraphe,lexCliques)= result
#    print (generation,lexDigraphe,lexGraphe,lexCliques)
    if genDigraphe:
        globDigraphe=nx.union(globDigraphe,lexDigraphe)
    if genGraphe:
        globGraphe=nx.union(globGraphe,lexGraphe)
    cliques.extend(lexCliques)
    for clique in lexCliques:
        cliquesScores[numClique]=cliqueScore(clique,lexGraphe)
        cliquesListes[numClique]=clique
        numClique+=1
# Out:
# 5372
# 0 1509151040 0, 25 1509151043 0, 50 1509151047 0, 75 1509151051 1, 100 1509151055 1, 125 1509151058 2, 150 1509151102 2, 175 1509151105 3, 200 1509151108 3, 225 1509151113 4, 250 1509151117 4, 275 1509151122 5, 300 1509151125 5, 325 1509151129 6, 350 1509151134 6, 375 1509151138 6, 400 1509151142 7, 425 1509151145 7, 450 1509151149 8, 475 1509151152 8, 500 1509151154 9, 525 1509151158 9, 550 1509151201 10, 575 1509151204 10, 600 1509151207 11, 625 1509151210 11, 650 1509151213 12, 675 1509151216 12, 700 1509151219 13, 725 1509151221 13, 750 1509151224 13, 775 1509151227 14, 800 1509151230 14, 825 1509151233 15, 850 1509151236 15, 875 1509151239 16, 900 1509151242 16, 925 1509151246 17, 950 1509151249 17, 975 1509151253 18, 1000 1509151257 18, 1025 1509151301 19, 1050 1509151304 19, 1075 1509151308 20, 1100 1509151311 20, 1125 1509151315 20, 1150 1509151318 21, 1175 1509151321 21, 1200 1509151324 22, 1225 1509151328 22, 1250 1509151331 23, 1275 1509151334 23, 1300 1509151338 24, 1325 1509151342 24, 1350 1509151345 25, 1375 1509151348 25, 1400 1509151351 26, 1425 1509151354 26, 1450 1509151357 26, 1475 1509151400 27, 1500 1509151403 27, 1525 1509151407 28, 1550 1509151410 28, 1575 1509151413 29, 1600 1509151416 29, 1625 1509151419 30, 1650 1509151422 30, 1675 1509151425 31, 1700 1509151428 31, 1725 1509151431 32, 1750 1509151434 32, 1775 1509151437 33, 1800 1509151440 33, 1825 1509151442 33, 1850 1509151445 34, 1875 1509151449 34, 1900 1509151453 35, 1925 1509151455 35, 1950 1509151458 36, 1975 1509151501 36, 2000 1509151504 37, 2025 1509151507 37, 2050 1509151511 38, 2075 1509151514 38, 2100 1509151518 39, 2125 1509151521 39, 2150 1509151525 40, 2175 1509151529 40, 2200 1509151532 40, 2225 1509151536 41, 2250 1509151539 41, 2275 1509151542 42, 2300 1509151546 42, 2325 1509151549 43, 2350 1509151552 43, 2375 1509151556 44, 2400 1509151559 44, 2425 1509151603 45, 2450 1509151606 45, 2475 1509151609 46, 2500 1509151612 46, 2525 1509151616 47, 2550 1509151619 47, 2575 1509151622 47, 2600 1509151626 48, 2625 1509151629 48, 2650 1509151632 49, 2675 1509151635 49, 2700 1509151638 50, 2725 1509151642 50, 2750 1509151645 51, 2775 1509151648 51, 2800 1509151651 52, 2825 1509151655 52, 2850 1509151658 53, 2875 1509151702 53, 2900 1509151705 53, 2925 1509151709 54, 2950 1509151712 54, 2975 1509151715 55, 3000 1509151719 55, 3025 1509151722 56, 3050 1509151725 56, 3075 1509151728 57, 3100 1509151732 57, 3125 1509151735 58, 3150 1509151738 58, 3175 1509151742 59, 3200 1509151745 59, 3225 1509151748 60, 3250 1509151751 60, 3275 1509151755 60, 3300 1509151758 61, 3325 1509151802 61, 3350 1509151805 62, 3375 1509151809 62, 3400 1509151812 63, 3425 1509151815 63, 3450 1509151819 64, 3475 1509151822 64, 3500 1509151826 65, 3525 1509151830 65, 3550 1509151833 66, 3575 1509151836 66, 3600 1509151839 67, 3625 1509151844 67, 3650 1509151848 67, 3675 1509151852 68, 3700 1509151855 68, 3725 1509151900 69, 3750 1509151903 69, 3775 1509151907 70, 3800 1509151910 70, 3825 1509151914 71, 3850 1509151918 71, 3875 1509151922 72, 3900 1509151925 72, 3925 1509151928 73, 3950 1509151932 73, 3975 1509151937 73, 4000 1509151941 74, 4025 1509151944 74, 4050 1509151948 75, 4075 1509151951 75, 4100 1509151955 76, 4125 1509152000 76, 4150 1509152004 77, 4175 1509152008 77, 4200 1509152012 78, 4225 1509152016 78, 4250 1509152019 79, 4275 1509152023 79, 4300 1509152026 80, 4325 1509152029 80, 4350 1509152033 80, 4375 1509152037 81, 4400 1509152039 81, 4425 1509152043 82, 4450 1509152047 82, 4475 1509152051 83, 4500 1509152054 83, 4525 1509152058 84, 4550 1509152102 84, 4575 1509152106 85, 4600 1509152109 85, 4625 1509152113 86, 4650 1509152116 86, 4675 1509152120 87, 4700 1509152123 87, 4725 1509152126 87, 4750 1509152130 88, 4775 1509152133 88, 4800 1509152136 89, 4825 1509152139 89, 4850 1509152143 90, 4875 1509152147 90, 4900 1509152150 91, 4925 1509152154 91, 4950 1509152158 92, 4975 1509152201 92, 5000 1509152204 93, 5025 1509152206 93, 5050 1509152209 94, 5075 15 ...
# Wall time: 12h 11min 9s

# %%
# %%time
versionStamp=dateheure()
if genDigraphe: 
    nx.write_dot(globDigraphe,u"2015-Data/digraphe-%s.dot"%versionStamp)
if genGraphe:
    nx.write_dot(globGraphe,u"2015-Data/graphe-%s.dot"%versionStamp)
# Out:
# CPU times: user 40 µs, sys: 9 µs, total: 49 µs
# Wall time: 43.2 µs

# %%
print (len(cliques))
# Out:
# 939562

# %%
longueurCliques={}
for clique in cliques:
    longueur=len(clique)
    if not longueur in longueurCliques:
        longueurCliques[longueur]=1
    else:
        longueurCliques[longueur]+=1
longueurCliques
# Out:
# {1: 1,
#  2: 643,
#  3: 3078,
#  4: 7198,
#  5: 6502,
#  6: 8642,
#  7: 13623,
#  8: 14357,
#  9: 20812,
#  10: 31519,
#  11: 42568,
#  12: 54307,
#  13: 69783,
#  14: 74391,
#  15: 74888,
#  16: 70692,
#  17: 64680,
#  18: 57621,
#  19: 43515,
#  20: 36638,
#  21: 31221,
#  22: 27275,
#  23: 20902,
#  24: 18223,
#  25: 17050,
#  26: 15417,
#  27: 16725,
#  28: 12522,
#  29: 11008,
#  30: 11137,
#  31: 8478,
#  32: 6215,
#  33: 6211,
#  34: 4787,
#  35: 4644,
#  36: 4454,
#  37: 3544,
#  38: 3355,
#  39: 2520,
#  40: 2207,
#  41: 2255,
#  42: 1923,
#  43: 1258,
#  44: 1669,
#  45: 2205,
#  46: 839,
#  47: 811,
#  48: 781,
#  49: 933,
#  50: 1137,
#  51: 2334,
#  52: 25,
#  53: 1,
#  54: 12,
#  58: 4,
#  59: 16,
#  63: 3,
#  65: 1,
#  67: 2}

# %% [markdown]
# ###Faire la liste des cases lexicalisées de l'échantillon

# %%
nbFormesLexicales={}
casesLexicales={element:paradigmes[paradigmes["lexeme"]==element].columns[paradigmes[paradigmes["lexeme"]==element].notnull().iloc[0]].tolist() for element in listeTest}
for element in casesLexicales:
    casesLexicales[element].remove("lexeme")
    nbFormesLexicales[element]=len(casesLexicales[element])

# %% [markdown]
# ##Comparer la sortie des cliques avec le paradigme de départ

# %%
# %%time
seuilClique=1
#paradigmesCLIQUES=pd.DataFrame(columns=paradigmes.columns.values.tolist())
paradigmesListe=[]
#for n,clique in enumerate(sorted(cliques,key=lambda x: len(x),reverse=True)):
for n,clique in enumerate(cliques):
#    if seuilClique==0:
#        seuilClique=len(clique)-15
    if len(clique)>seuilClique:
        paradigmeClique={}
        sampleOK=True
#        print (n, len(clique))
        point=clique[0].split("-")
        lPoint=len(point)
#        print (point,"-".join(point[0:len(point)-2]))
        if lPoint==3:
            lexeme=point[0]
        else:
            lexeme="-".join(point[0:len(point)-2])
        paradigmeClique["lexeme"]=lexeme
        if n%1000==0: print (n,end=", ")
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].notnull().columns.tolist()
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
#        casesLexeme.remove("lexeme")
        casesLexeme=casesLexicales[lexeme]
        nbInitial=len(casesLexeme)
        if casesLexeme and len(casesLexeme)<=len(clique):
            for element in casesLexeme:
#                print (lexeme,element, paradigmes[paradigmes["lexeme"]==lexeme][element])
                champForme=paradigmes[paradigmes["lexeme"]==lexeme][element].iloc[0]
                if ","  in champForme:
                    formes=champForme.split(",")
                    nbInitial+=len(formes)-1
                    okFormes=False
                    for forme in formes:
                        pointCase=u"%s-%s-%s"% (lexeme,forme,element)
#                        if debug: print (pointCase, clique)
                        if pointCase in clique:
                            okFormes=True
                            print ("point",pointCase)
#                            print ("clique",clique)
                            print ("gold",GOLD[GOLD["lexeme"]==lexeme][element])
                    if okFormes:
                        sampleOK=True
                    else:
                        sampleOK=False
                        break
                else:
                    forme=champForme
                    pointCase=u"%s-%s-%s"% (lexeme,forme,element)
                    if debug: print (pointCase, clique)
                    if not pointCase in clique:
                        sampleOK=False
#                        print ("point",pointCase)
#                        print ("clique",clique)
#                        print ("gold",GOLD[GOLD["lexeme"]==lexeme][element])
                        break
        else:
            sampleOK=False
        if sampleOK:
            for element in clique:
                elements=element.split("-")
                forme=elements[-2]
                taminfo=elements[-1]
#                try:
#                 (lexeme,forme,taminfo)=element.split("-")
#                except ValueError:
#                    print (element)
                paradigmeClique[taminfo]=forme
#                if taminfo in paradigmes.columns:
#                    if not paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].isnull().item():
#                        if paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item()!=forme:
#                            sampleOK=False
#                            print (paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item(),forme,taminfo,end=", ")
#            if n<100: print (clique==cliquesListes[n])
            paradigmeClique["score"]=cliquesScores[n]
            paradigmeClique["ajouts"]=len(clique)-nbInitial
#            print (cliqueScore(clique),clique)
            paradigmesListe.append(paradigmeClique)
        else:
            if debug:
                print ()
                print (lexeme,clique)
                print ()

paradigmesCLIQUES=pd.DataFrame(paradigmesListe,columns=GOLD.columns.values.tolist()+[u"score",u"ajouts"])
print (seuilClique)
# Out:
# 0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000, 67000, 68000, 69000, 70000, 71000, 72000, 73000, 74000, 75000, 76000, 77000, point asseoir-asjErE-fi1S
# gold 398    asjErE,aswarE
# Name: fi1S, dtype: object
# point asseoir-aswarE-fi1S
# gold 398    asjErE,aswarE
# Name: fi1S, dtype: object
# point asseoir-asjEra-fi2S
# gold 398    asjEra,aswara
# Name: fi2S, dtype: object
# point asseoir-aswara-fi2S
# gold 398    asjEra,aswara
# Name: fi2S, dtype: object
# point asseoir-asjErô-fi3P
# gold 398    asjErô,aswarô
# Name: fi3P, dtype: object
# point asseoir-aswarô-fi3P
# gold 398    asjErô,aswarô
# Name: fi3P, dtype: object
# point asseoir-asjEra-fi3S
# gold 398    asjEra,aswara
# Name: fi3S, dtype: object
# point asseoir-aswara-fi3S
# gold 398    asjEra,aswara
# Name: fi3S, dtype: object
# point asseoir-asEjE-ii3S
# gold 398    asEjE,aswajE
# Name: ii3S, dtype: object
# point asseoir-aswajE-ii3S
# gold 398    asEjE,aswajE
# Name: ii3S, dtype: object
# point asseoir-asEje-pI2P
# gold 398    asEje,aswaje
# Name: pI2P, dtype: object
# point asseoir-aswaje-pI2P
# gold 398    asEje,aswaje
# Name: pI2P, dtype: object
# point asseoir-asje-pI2S
# gold 398    asje,aswa
# Name: pI2S, dtype: object
# point asseoir-aswa-pI2S
# gold 398    asje,aswa
# Name: pI2S, dtype: object
# point asseoir-asjErE-pc1S
# gold 398    asjErE,aswarE
# Name: pc1S, dtype: object
# point asseoir-aswarE-pc1S
# gold 398    asjErE,aswarE
# Name: pc1S, dtype: object
# point asseoir-asjErE-pc3P
# gold 398    asjErE,aswarE
# Name: pc3P, dtype: object
# point asseoir-aswarE-pc3P
# gold 398    asjErE,aswarE
# Name: pc3P, dtype: object
# point asseoir-asjErE-pc3S
# gold 398    asjErE,aswarE
# Name: pc3S, dtype: object
# point asseoir-aswarE-pc3S
# gold 398    asjErE,aswarE
# Name: pc3S, dtype: object
# point asseoir-asEjô-pi1P
# gold 398    asEjô,aswajô
# Name: pi1P, dtype: object
# point asseoir-aswajô-pi1P
# gold 398    asEjô,aswajô
# Name: pi1P, dtype: object
# point asseoir-asje-pi1S
# gold 398    asje,aswa
# Name: pi1S, dtype: object
# point asseoir-aswa-pi1S
# gold 398    asje,aswa
# Name: pi1S, dtype: object
# point asseoir-asEje-pi2P
# gold 398    asEje,aswaje
# Name: pi2P, dtype: object
# point asseoir-aswaje-pi2P
# gold 398    asEje,aswaje
# Name: pi2P, dtype: object
# point asseoir-asje-pi2S
# gold 398    asje,aswa
# Name: pi2S, dtype: object
# point asseoir-aswa-pi2S
# gold 398    asje,aswa
# Name: pi2S, dtype: object
# point asseoir-asEj-pi3P
# gold 398    asEj,aswa
# Name: pi3P, dtype: object
# point asseoir-aswa-pi3P
# gold 398    asEj,aswa
# Name: pi3P, dtype: object
# point asseoir-asje-pi3S
# gold 398    asje,aswa
# Name: pi3S, dtype: object
# point asseoir-aswa-pi3S
# gold 398    asje,aswa
# Name: pi3S, dtype: object
# point asseoir-asEj-ps1S
# gold 398    asEj,aswa
# Name: ps1S, dtype: object
# point asseoir-aswa-ps1S
# gold 398    asEj,aswa
# Name: ps1S, dtype: object
# point asseoir-asEj-ps2S
# gold 398    asEj,aswa
# Name: ps2S, dtype: object
# point asseoir-aswa-ps2S
# gold 398    asEj,aswa
# Name: ps2S, dtype: object
# point asseoir-asEj-ps3S
# gold 398    asEj,aswa
# Name: ps3S, dtype: object
# point asseoir-aswa-ps3S
# gold 398    asEj,aswa
# Name: ps3S, dtype: object
# 78000, 79000, 80000, 81000, 82000, 83000, 84000, 85000, 86000, 87000, 88000, 89000, 90000, 91000, 92000, 93000, 94000, 95000, 96000, 97000, 98000, 99000, 100000, 101000, 102000, 103000, 104000, 105000, 106000, 107000, 108000, 109000, 110000, point balayer-balEj6rE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEj6re-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balEj6rE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEj6re-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balEj6rE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEj6re-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balEj6rE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEj6re-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balEj6rE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEj6re-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balErE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEj6rE-fi1S
# gold 515    balErE,balEj6rE
# Name: fi1S, dtype: object
# point balayer-balEre-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balEj6re-fi2P
# gold 515    balEre,balEj6re
# Name: fi2P, dtype: object
# point balayer-balEra-fi3S
# gold 515    balEra,balEj6ra
# Name: fi3S, dtype: object
# point balayer-balEj6ra-fi3S
# gold 515    balEra,balEj6ra
# Name: fi3S, dtype: object
# point balayer-balE-pI2S
# gold 515    balE,balEj
# Name: pI2S, dtype: object
# point balayer-balEj-pI2S
# gold 515    balE,balEj
# Name: pI2S, dtype: object
# point balayer-balErE-pc3P
# gold 515    balErE,balEj6rE
# Name: pc3P, dtype: object
# point balayer-balEj6rE-pc3P
# gold 515    balErE,balEj6rE
# Name: pc3P, dtype: object
# point balayer-balErE-pc3S
# gold 515    balErE,balEj6rE
# Name: pc3S, dtype: object
# point balayer-balEj6rE-pc3S
# gold 515    balErE,balEj6rE
# Name: pc3S, dtype: object
# point balayer-balE-pi1S
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# point balayer-balEj-pi1S
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# point balayer-balE-pi3P
# gold 515    balE,balEj
# Name: pi3P, dtype: object
# point balayer-balEj-pi3P
# gold 515    balE,balEj
# Name: pi3P, dtype: object
# point balayer-balE-pi3S
# gold 515    balE,balEj
# Name: pi3S, dtype: object
# point balayer-balEj-pi3S
# gold 515    balE,balEj
# Name: pi3S, dtype: object
# 111000, 112000, 113000, 114000, 115000, 116000, 117000, 118000, 119000, 120000, 121000, 122000, 123000, 124000, 125000, 126000, 127000, 128000, 129000, 130000, 131000, 132000, 133000, 134000, 135000, 136000, 137000, 138000, 139000, 140000, point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgE-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgE-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pI2S
# gold 771    bEgE,bEgEj
# Name: pI2S, dtype: object
# point bégayer-bEgEj-pi1S
# gold 771    bEgE,bEgEj
# Name: pi1S, dtype: object
# point bégayer-bEgE-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgEj-pi2S
# gold 771    bEgE,bEgEj
# Name: pi2S, dtype: object
# point bégayer-bEgE-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# point bégayer-bEgEj-pi3S
# gold 771    bEgE,bEgEj
# Name: pi3S, dtype: object
# 141000, 142000, 143000, 144000, 145000, 146000, 147000, 148000, 149000, 150000, 151000, 152000, 153000, 154000, 155000, 156000, 157000, 158000, 159000, 160000, 161000, 162000, 163000, 164000, 165000, 166000, 167000, 168000, 169000, 170000, 171000, 172000, 173000, 174000, 175000, 176000, 177000, 178000, 179000, 180000, 181000, 182000, 183000, 184000, 185000, 186000, 187000, 188000, 189000, 190000, 191000, 192000, 193000, 194000, 195000, 196000, 197000, 198000, 199000, 200000, 201000, 202000, 203000, 204000, 205000, 206000, 207000, 208000, 209000, 210000, 211000, 212000, 213000, 214000, 215000, 216000, 217000, 218000, 219000, 220000, 221000, 222000, 223000, 224000, 225000, 226000, 227000, 228000, 229000, 230000, 231000, 232000, 233000, 234000, 235000, 236000, 237000, 238000, 239000, 240000, 241000, 242000, 243000, 244000, 245000, 246000, 247000, 248000, 249000, 250000, 251000, 252000, 253000, 254000, 255000, 256000, 257000, 258000, 259000, 260000, 261000, 262000, 263000, 264000, 265000, 266000, 267000, 268000, 269000, 270000, 271000, 272000, 273000, 274000, 275000, 276000, 277000, 278000, 279000, 280000, 281000, 282000, 283000, 284000, 285000, 286000, point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElE-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# point délayer-dElEj-pi3S
# gold 1914    dElE,dElEj
# Name: pi3S, dtype: object
# 287000, 288000, 289000, 290000, 291000, 292000, 293000, 294000, 295000, 296000, 297000, 298000, 299000, 300000, 301000, 302000, 303000, 304000, 305000, 306000, 307000, 308000, 309000, 310000, 311000, 312000, 313000, point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrErE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrEj6rE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrEj-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrEj-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEj-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrErE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrEj6rE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrEj-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrEj-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEj-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrErE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrEj6rE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrEj-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrEj-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEj-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrE-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrEj-pI2S
# gold 2348    EfrE,EfrEj
# Name: pI2S, dtype: object
# point effrayer-EfrErE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrEj6rE-pc3S
# gold 2348    EfrErE,EfrEj6rE
# Name: pc3S, dtype: object
# point effrayer-EfrE-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrEj-pi1S
# gold 2348    EfrE,EfrEj
# Name: pi1S, dtype: object
# point effrayer-EfrE-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrEj-pi3P
# gold 2348    EfrE,EfrEj
# Name: pi3P, dtype: object
# point effrayer-EfrE-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEj-pi3S
# gold 2348    EfrE,EfrEj
# Name: pi3S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEj6ra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# point effrayer-EfrEra-fi2S
# gold 2348    EfrEra,EfrEj6ra
# Name: fi2S, dtype: object
# 314000, 315000, 316000, 317000, 318000, 319000, 320000, 321000, 322000, 323000, 324000, 325000, 326000, 327000, 328000, 329000, 330000, 331000, 332000, 333000, 334000, 335000, 336000, 337000, 338000, 339000, point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârE-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârE-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârE-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârE-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârE-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# point enrayer-ârEj-pi3S
# gold 2615    ârE,ârEj
# Name: pi3S, dtype: object
# 340000, 341000, 342000, 343000, 344000, 345000, 346000, 347000, 348000, 349000, 350000, 351000, point essayer-EsErô-fi1P
# gold 2749    EsErô,EsEj6rô
# Name: fi1P, dtype: object
# point essayer-EsEj6rô-fi1P
# gold 2749    EsErô,EsEj6rô
# Name: fi1P, dtype: object
# point essayer-EsErE-fi1S
# gold 2749    EsErE,EsEj6rE
# Name: fi1S, dtype: object
# point essayer-EsEj6rE-fi1S
# gold 2749    EsErE,EsEj6rE
# Name: fi1S, dtype: object
# point essayer-EsEre-fi2P
# gold 2749    EsEre,EsEj6re
# Name: fi2P, dtype: object
# point essayer-EsEj6re-fi2P
# gold 2749    EsEre,EsEj6re
# Name: fi2P, dtype: object
# point essayer-EsEra-fi2S
# gold 2749    EsEra,EsEj6ra
# Name: fi2S, dtype: object
# point essayer-EsEj6ra-fi2S
# gold 2749    EsEra,EsEj6ra
# Name: fi2S, dtype: object
# point essayer-EsErô-fi3P
# gold 2749    EsErô,EsEj6rô
# Name: fi3P, dtype: object
# point essayer-EsEj6rô-fi3P
# gold 2749    EsErô,EsEj6rô
# Name: fi3P, dtype: object
# point essayer-EsEra-fi3S
# gold 2749    EsEra,EsEj6ra
# Name: fi3S, dtype: object
# point essayer-EsEj6ra-fi3S
# gold 2749    EsEra,EsEj6ra
# Name: fi3S, dtype: object
# point essayer-EsE-pI2S
# gold 2749    EsE,EsEj
# Name: pI2S, dtype: object
# point essayer-EsEj-pI2S
# gold 2749    EsE,EsEj
# Name: pI2S, dtype: object
# point essayer-EsErE-pc1S
# gold 2749    EsErE,EsEj6rE
# Name: pc1S, dtype: object
# point essayer-EsEj6rE-pc1S
# gold 2749    EsErE,EsEj6rE
# Name: pc1S, dtype: object
# point essayer-EsErje-pc2P
# gold 2749    EsErje,EsEj6rje
# Name: pc2P, dtype: object
# point essayer-EsEj6rje-pc2P
# gold 2749    EsErje,EsEj6rje
# Name: pc2P, dtype: object
# point essayer-EsErE-pc2S
# gold 2749    EsErE,EsEj6rE
# Name: pc2S, dtype: object
# point essayer-EsEj6rE-pc2S
# gold 2749    EsErE,EsEj6rE
# Name: pc2S, dtype: object
# point essayer-EsErE-pc3P
# gold 2749    EsErE,EsEj6rE
# Name: pc3P, dtype: object
# point essayer-EsEj6rE-pc3P
# gold 2749    EsErE,EsEj6rE
# Name: pc3P, dtype: object
# point essayer-EsErE-pc3S
# gold 2749    EsErE,EsEj6rE
# Name: pc3S, dtype: object
# point essayer-EsEj6rE-pc3S
# gold 2749    EsErE,EsEj6rE
# Name: pc3S, dtype: object
# point essayer-EsE-pi1S
# gold 2749    EsE,EsEj
# Name: pi1S, dtype: object
# point essayer-EsEj-pi1S
# gold 2749    EsE,EsEj
# Name: pi1S, dtype: object
# point essayer-EsE-pi2S
# gold 2749    EsE,EsEj
# Name: pi2S, dtype: object
# point essayer-EsEj-pi2S
# gold 2749    EsE,EsEj
# Name: pi2S, dtype: object
# point essayer-EsE-pi3P
# gold 2749    EsE,EsEj
# Name: pi3P, dtype: object
# point essayer-EsEj-pi3P
# gold 2749    EsE,EsEj
# Name: pi3P, dtype: object
# point essayer-EsE-pi3S
# gold 2749    EsE,EsEj
# Name: pi3S, dtype: object
# point essayer-EsEj-pi3S
# gold 2749    EsE,EsEj
# Name: pi3S, dtype: object
# point essayer-EsE-ps2S
# gold 2749    EsE,EsEj
# Name: ps2S, dtype: object
# point essayer-EsEj-ps2S
# gold 2749    EsE,EsEj
# Name: ps2S, dtype: object
# 352000, 353000, 354000, 355000, 356000, 357000, 358000, 359000, 360000, 361000, 362000, 363000, 364000, 365000, 366000, 367000, 368000, 369000, 370000, 371000, 372000, 373000, 374000, 375000, 376000, 377000, 378000, 379000, 380000, point ficher-fiSe-ppMP
# gold 2904    fiSy,fiSe
# Name: ppMP, dtype: object
# point ficher-fiSy-ppMP
# gold 2904    fiSy,fiSe
# Name: ppMP, dtype: object
# point ficher-fiSe-ppMP
# gold 2904    fiSy,fiSe
# Name: ppMP, dtype: object
# 381000, 382000, 383000, 384000, 385000, 386000, 387000, 388000, 389000, 390000, 391000, 392000, 393000, 394000, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frE-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 395000, point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi1S
# gold 3019    frE,frEj
# Name: pi1S, dtype: object
# point frayer-frE-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frEj-pi2S
# gold 3019    frE,frEj
# Name: pi2S, dtype: object
# point frayer-frE-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frEj-pi3P
# gold 3019    frE,frEj
# Name: pi3P, dtype: object
# point frayer-frE-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# point frayer-frEj-pi3S
# gold 3019    frE,frEj
# Name: pi3S, dtype: object
# 396000, 397000, 398000, 399000, 400000, 401000, 402000, 403000, 404000, 405000, 406000, 407000, 408000, 409000, 410000, 411000, 412000, 413000, 414000, 415000, 416000, 417000, 418000, 419000, 420000, 421000, 422000, 423000, 424000, 425000, 426000, 427000, 428000, 429000, 430000, 431000, 432000, 433000, 434000, 435000, 436000, 437000, 438000, 439000, 440000, 441000, 442000, 443000, 444000, 445000, 446000, 447000, 448000, 449000, 450000, 451000, 452000, 453000, 454000, 455000, 456000, 457000, 458000, 459000, 460000, 461000, 462000, 463000, 464000, 465000, 466000, 467000, 468000, 469000, 470000, 471000, 472000, 473000, 474000, 475000, 476000, 477000, 478000, 479000, 480000, 481000, 482000, 483000, 484000, 485000, 486000, 487000, 488000, 489000, 490000, 491000, 492000, 493000, 494000, 495000, 496000, 497000, 498000, 499000, 500000, 501000, 502000, 503000, 504000, 505000, 506000, 507000, point monnayer-mOnE-pi3S
# gold 3871    mOnE,mOnEj
# Name: pi3S, dtype: object
# point monnayer-mOnEj-pi3S
# gold 3871    mOnE,mOnEj
# Name: pi3S, dtype: object
# 508000, 509000, 510000, 511000, 512000, 513000, 514000, 515000, 516000, 517000, 518000, 519000, 520000, 521000, 522000, 523000, 524000, 525000, 526000, 527000, 528000, 529000, 530000, 531000, 532000, 533000, 534000, 535000, 536000, 537000, 538000, 539000, 540000, 541000, 542000, 543000, 544000, 545000, point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagEj-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagEj-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagEj-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagEj-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# point pagayer-pagE-pi3S
# gold 4126    pagE,pagEj
# Name: pi3S, dtype: object
# 546000, 547000, 548000, 549000, 550000, 551000, 552000, 553000, 554000, point payer-pErô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pEj6rô-fi1P
# gold 4229    pErô,pEj6rô
# Name: fi1P, dtype: object
# point payer-pErE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEre-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEj6re-fi2P
# gold 4229    pEre,pEj6re
# Name: fi2P, dtype: object
# point payer-pEra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pEj6ra-fi2S
# gold 4229    pEra,pEj6ra
# Name: fi2S, dtype: object
# point payer-pErô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEj6rô-fi3P
# gold 4229    pErô,pEj6rô
# Name: fi3P, dtype: object
# point payer-pEra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pEj6ra-fi3S
# gold 4229    pEra,pEj6ra
# Name: fi3S, dtype: object
# point payer-pE-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pEj-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pErjô-pc1P
# gold 4229    pErjô,pEj6rjô
# Name: pc1P, dtype: object
# point payer-pEj6rjô-pc1P
# gold 4229    pErjô,pEj6rjô
# Name: pc1P, dtype: object
# point payer-pErE-pc1S
# gold 4229    pErE,pEj6rE
# Name: pc1S, dtype: object
# point payer-pEj6rE-pc1S
# gold 4229    pErE,pEj6rE
# Name: pc1S, dtype: object
# point payer-pErje-pc2P
# gold 4229    pErje,pEj6rje
# Name: pc2P, dtype: object
# point payer-pEj6rje-pc2P
# gold 4229    pErje,pEj6rje
# Name: pc2P, dtype: object
# point payer-pErE-pc2S
# gold 4229    pErE,pEj6rE
# Name: pc2S, dtype: object
# point payer-pEj6rE-pc2S
# gold 4229    pErE,pEj6rE
# Name: pc2S, dtype: object
# point payer-pErE-pc3P
# gold 4229    pErE,pEj6rE
# Name: pc3P, dtype: object
# point payer-pEj6rE-pc3P
# gold 4229    pErE,pEj6rE
# Name: pc3P, dtype: object
# point payer-pErE-pc3S
# gold 4229    pErE,pEj6rE
# Name: pc3S, dtype: object
# point payer-pEj6rE-pc3S
# gold 4229    pErE,pEj6rE
# Name: pc3S, dtype: object
# point payer-pE-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pEj-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pE-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pEj-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pE-pi3P
# gold 4229    pE,pEj
# Name: pi3P, dtype: object
# point payer-pEj-pi3P
# gold 4229    pE,pEj
# Name: pi3P, dtype: object
# point payer-pE-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pEj-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pE-ps1S
# gold 4229    pE,pEj
# Name: ps1S, dtype: object
# point payer-pEj-ps1S
# gold 4229    pE,pEj
# Name: ps1S, dtype: object
# point payer-pE-ps3P
# gold 4229    pE,pEj
# Name: ps3P, dtype: object
# point payer-pEj-ps3P
# gold 4229    pE,pEj
# Name: ps3P, dtype: object
# point payer-pE-ps3S
# gold 4229    pE,pEj
# Name: ps3S, dtype: object
# point payer-pEj-ps3S
# gold 4229    pE,pEj
# Name: ps3S, dtype: object
# 555000, 556000, 557000, 558000, 559000, 560000, 561000, 562000, 563000, 564000, 565000, 566000, 567000, 568000, 569000, 570000, 571000, 572000, 573000, 574000, 575000, 576000, 577000, 578000, 579000, 580000, 581000, 582000, 583000, 584000, 585000, 586000, 587000, 588000, 589000, 590000, 591000, 592000, 593000, 594000, 595000, 596000, 597000, 598000, 599000, 600000, 601000, 602000, 603000, 604000, 605000, 606000, 607000, 608000, 609000, 610000, 611000, 612000, 613000, 614000, 615000, 616000, 617000, 618000, 619000, 620000, 621000, 622000, 623000, 624000, 625000, 626000, 627000, 628000, 629000, 630000, 631000, 632000, 633000, 634000, 635000, 636000, 637000, 638000, 639000, 640000, 641000, 642000, 643000, 644000, 645000, 646000, 647000, point rasseoir-rasEjE-ii3S
# gold 4717    rasEjE,raswajE
# Name: ii3S, dtype: object
# point rasseoir-raswajE-ii3S
# gold 4717    rasEjE,raswajE
# Name: ii3S, dtype: object
# point rasseoir-rasje-pi1S
# gold 4717    rasje,raswa
# Name: pi1S, dtype: object
# point rasseoir-raswa-pi1S
# gold 4717    rasje,raswa
# Name: pi1S, dtype: object
# point rasseoir-rasEj-pi3P
# gold 4717    rasEj,raswa
# Name: pi3P, dtype: object
# point rasseoir-raswa-pi3P
# gold 4717    rasEj,raswa
# Name: pi3P, dtype: object
# point rasseoir-rasje-pi3S
# gold 4717    rasje,raswa
# Name: pi3S, dtype: object
# point rasseoir-raswa-pi3S
# gold 4717    rasje,raswa
# Name: pi3S, dtype: object
# 648000, 649000, 650000, 651000, 652000, 653000, 654000, 655000, point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rE-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rEj-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rE-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rEj-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rE-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rEj-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rE-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rEj-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rE-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rE-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rEj-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rE-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rEj-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rE-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rEj-pI2S
# gold 4747    rE,rEj
# Name: pI2S, dtype: object
# point rayer-rE-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rEj-pi3P
# gold 4747    rE,rEj
# Name: pi3P, dtype: object
# point rayer-rE-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# point rayer-rEj-pi3S
# gold 4747    rE,rEj
# Name: pi3S, dtype: object
# 656000, 657000, 658000, 659000, 660000, 661000, 662000, 663000, 664000, 665000, 666000, 667000, 668000, 669000, 670000, 671000, 672000, 673000, 674000, 675000, 676000, 677000, 678000, 679000, 680000, 681000, 682000, 683000, 684000, 685000, 686000, 687000, 688000, 689000, 690000, 691000, 692000, 693000, point relayer-r6lEra-fi3S
# gold 4914    r6lEra,r6lEj6ra
# Name: fi3S, dtype: object
# point relayer-r6lEj6ra-fi3S
# gold 4914    r6lEra,r6lEj6ra
# Name: fi3S, dtype: object
# point relayer-r6lE-pi1S
# gold 4914    r6lE,r6lEj
# Name: pi1S, dtype: object
# point relayer-r6lEj-pi1S
# gold 4914    r6lE,r6lEj
# Name: pi1S, dtype: object
# point relayer-r6lE-pi3P
# gold 4914    r6lE,r6lEj
# Name: pi3P, dtype: object
# point relayer-r6lEj-pi3P
# gold 4914    r6lE,r6lEj
# Name: pi3P, dtype: object
# point relayer-r6lE-pi3S
# gold 4914    r6lE,r6lEj
# Name: pi3S, dtype: object
# point relayer-r6lEj-pi3S
# gold 4914    r6lE,r6lEj
# Name: pi3S, dtype: object
# 694000, 695000, 696000, 697000, 698000, 699000, 700000, 701000, 702000, 703000, 704000, 705000, 706000, 707000, 708000, 709000, 710000, 711000, 712000, 713000, 714000, 715000, 716000, 717000, 718000, 719000, 720000, 721000, point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOrtisE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOr-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# point ressortir-r6sOrti-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOrtisE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOr-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOr-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOr-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# point ressortir-r6sOrti-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# 722000, point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOrtE-ii2S
# gold 5105    r6sOrtE,r6sOrtisE
# Name: ii2S, dtype: object
# point ressortir-r6sOrti-pI2S
# gold 5105    r6sOr,r6sOrti
# Name: pI2S, dtype: object
# 723000, 724000, 725000, 726000, 727000, 728000, 729000, 730000, 731000, 732000, 733000, 734000, 735000, 736000, 737000, 738000, 739000, 740000, 741000, 742000, 743000, 744000, 745000, 746000, 747000, 748000, 749000, 750000, 751000, 752000, 753000, 754000, 755000, 756000, 757000, point réessayer-rEEsE-pI2S
# gold 5319    rEEsE,rEEsEj
# Name: pI2S, dtype: object
# point réessayer-rEEsEj-pI2S
# gold 5319    rEEsE,rEEsEj
# Name: pI2S, dtype: object
# point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsEj-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsEj-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsE-pI2S
# gold 5319    rEEsE,rEEsEj
# Name: pI2S, dtype: object
# point réessayer-rEEsEj-pI2S
# gold 5319    rEEsE,rEEsEj
# Name: pI2S, dtype: object
# point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsEj-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsEj-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsE-pI2S
# gold 5319    rEEsE,rEEsEj
# Name: pI2S, dtype: object
# point réessayer-rEEsEj-pI2S
# gold 5319    rEEsE,rEEsEj
# Name: pI2S, dtype: object
# point réessayer-rEEsE-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsEj-pi1S
# gold 5319    rEEsE,rEEsEj
# Name: pi1S, dtype: object
# point réessayer-rEEsE-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# point réessayer-rEEsEj-pi3S
# gold 5319    rEEsE,rEEsEj
# Name: pi3S, dtype: object
# 758000, 759000, 760000, 761000, 762000, 763000, 764000, 765000, 766000, 767000, 768000, 769000, 770000, 771000, 772000, 773000, 774000, 775000, 776000, 777000, 778000, 779000, 780000, 781000, 782000, 783000, 784000, 785000, 786000, 787000, 788000, 789000, 790000, 791000, 792000, 793000, 794000, 795000, 796000, 797000, 798000, 799000, 800000, 801000, 802000, 803000, 804000, 805000, 806000, 807000, 808000, 809000, 810000, point sortir-sOrtE-ii3P
# gold 5600    sOrtE,sOrtisE
# Name: ii3P, dtype: object
# point sortir-sOrtisE-ii3P
# gold 5600    sOrtE,sOrtisE
# Name: ii3P, dtype: object
# point sortir-sOrtE-ii3S
# gold 5600    sOrtE,sOrtisE
# Name: ii3S, dtype: object
# point sortir-sOrtisE-ii3S
# gold 5600    sOrtE,sOrtisE
# Name: ii3S, dtype: object
# point sortir-sOrt-pi3P
# gold 5600    sOrt,sOrtis
# Name: pi3P, dtype: object
# point sortir-sOrtis-pi3P
# gold 5600    sOrt,sOrtis
# Name: pi3P, dtype: object
# point sortir-sOrt-ps3P
# gold 5600    sOrt,sOrtis
# Name: ps3P, dtype: object
# point sortir-sOrtis-ps3P
# gold 5600    sOrt,sOrtis
# Name: ps3P, dtype: object
# 811000, 812000, 813000, 814000, 815000, 816000, 817000, 818000, 819000, 820000, 821000, 822000, 823000, 824000, 825000, 826000, 827000, 828000, 829000, 830000, 831000, 832000, 833000, 834000, 835000, 836000, 837000, 838000, 839000, 840000, 841000, 842000, 843000, 844000, 845000, 846000, 847000, 848000, 849000, 850000, 851000, 852000, 853000, 854000, 855000, 856000, 857000, 858000, 859000, 860000, 861000, 862000, 863000, 864000, 865000, 866000, 867000, 868000, 869000, 870000, 871000, 872000, 873000, 874000, 875000, 876000, 877000, 878000, 879000, 880000, 881000, 882000, 883000, 884000, 885000, 886000, 887000, 888000, 889000, 890000, 891000, 892000, 893000, 894000, 895000, 896000, 897000, 898000, point vouloir-v6je-pI2P
# gold 6227    v6je,vule
# Name: pI2P, dtype: object
# point vouloir-vule-pI2P
# gold 6227    v6je,vule
# Name: pI2P, dtype: object
# point vouloir-v9j-pI2S
# gold 6227    v9j,v2
# Name: pI2S, dtype: object
# point vouloir-v2-pI2S
# gold 6227    v9j,v2
# Name: pI2S, dtype: object
# 899000, 900000, 901000, 902000, 903000, 904000, 905000, point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzE-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# point zézayer-zEzEj-pi3S
# gold 6258    zEzE,zEzEj
# Name: pi3S, dtype: object
# 906000, 907000, 908000, 909000, 910000, 911000, 912000, 913000, 914000, 915000, 916000, 917000, point égayer-EgE-pi3S
# gold 6371    EgE,EgEj
# Name: pi3S, dtype: object
# point égayer-EgEj-pi3S
# gold 6371    EgE,EgEj
# Name: pi3S, dtype: object
# point égayer-EgE-pi3S
# gold 6371    EgE,EgEj
# Name: pi3S, dtype: object
# point égayer-EgEj-pi3S
# gold 6371    EgE,EgEj
# Name: pi3S, dtype: object
# 918000, 919000, 920000, 921000, 922000, 923000, 924000, 925000, 926000, 927000, 928000, 929000, 930000, 931000, point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtE-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# point étayer-EtEj-pi3S
# gold 6513    EtE,EtEj
# Name: pi3S, dtype: object
# 932000, 933000, 934000, 935000, 936000, 937000, 938000, 939000, 1
# CPU times: user 13min 39s, sys: 2.2 s, total: 13min 41s
# Wall time: 13min 45s

# %%
paradigmeSILVER=paradigmesCLIQUES[paradigmesCLIQUES["score"]==paradigmesCLIQUES.groupby(["lexeme"])["score"].transform(max)].reset_index()
del paradigmeSILVER["index"]

# %%
#paradigmeSILVER[paradigmeSILVER["lexeme"]=="aboutir"]

# %%
paradigmeSILVER.to_csv(path_or_buf="2015-Data/"+analysisPrefix+'-Silver.csv',encoding="utf8",sep=";")
GOLD.to_csv(path_or_buf="2015-Data/"+analysisPrefix+'-Gold.csv',encoding="utf8",sep=";")

# %%
sys.exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-bb4a55c6a962> in <module>()
# ----> 1 sys.exit()
#
# NameError: name 'sys' is not defined

# %%
def compareGOLD(row):
    global n
#    if row["lexeme"]=="dodo": 
#        debug=True
#    else:
#        debug=False
    if n%250==0: print (n,end=", ")
    n+=1
    ligne={k:row[k] for k in row.keys() if not k in ["lexeme","score","ajouts"]}
    lexeme=row["lexeme"]
    score=row["score"]
    ajouts=row["ajouts"]
    if not lexeme in conjugaisons:
        conjugaisons[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    if not lexeme in cliquesTypes:
        cliquesTypes[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    identiques=[]
    differents=[]
    missing=[]
    over=[]
    for case in analyseCases:
        if debug:    
            print (lexeme,case)
            print (GOLD[GOLD["lexeme"]==lexeme][case].item())
            print ((GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]))
        if not case in row:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("absence",case)
        elif case in row[row.isnull()] and not GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("CLIQUES +NaN",case)
        elif not case in row[row.isnull()] and GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            over.append(u"%s : %s ≠ Ø" % (case,row[case]))
            lexical=False
            if debug: print ("GOLD -NaN",case)            
        elif (row[case]==GOLD[GOLD["lexeme"]==lexeme][case].item()):
            if debug: print ("egal")
            identiques.append(u"%s : %s" % (case,row[case]))
            if debug: print ("valeurs id")
        elif (case in row[row.isnull()]) and (GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]):
            if debug: print ("NaNs")
            identiques.append(u"%s : %s" % (case,u"ØØØ"))
            if debug: print ("deux NaN")
        else:
            if debug: print ("else")
            differents.append(u"%s : %s ≠ %s" % (case, row[case],GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print (u"différence",case)
    if differents:
        conjugaisons[lexeme]["diff"].append(differents)
        cliquesTypes[lexeme]["diff"].append((ligne,score,ajouts))
        if debug: print ("DIFF",len(differents),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: print (", ".join(differents))
    if missing and over:
        conjugaisons[lexeme]["overmiss"].append(over+missing)
        cliquesTypes[lexeme]["overmiss"].append((ligne,score,ajouts))
        if debug: print ("OVERMISS", len(over), len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
            print (", ".join(over))
    elif missing:
        conjugaisons[lexeme]["miss"].append(missing)
        cliquesTypes[lexeme]["miss"].append((ligne,score,ajouts))
        if debug: print ("MISS", len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
    elif over:
        conjugaisons[lexeme]["over"].append(over)
        cliquesTypes[lexeme]["over"].append((ligne,score,ajouts))
        if debug: print ("OVER", len(over),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(over))
    if identiques:
        conjugaisons[lexeme]["ok"].append(identiques)
        cliquesTypes[lexeme]["ok"].append((ligne,score,ajouts))
        if debug: print ("OK", len(identiques), len(identiques)-nombreElements[lexeme],end=saut)
        if debug1: print (", ".join(identiques))
#    print ()
    return lexical

# %%
# %%time
debug=False
debug1=False
saut="\n"
n=0
conjugaisons={}
cliquesTypes={}
print (", ".join(sampleCases))
#paradigmesCLIQUES.apply(compareGOLD,axis=1)
paradigmeSILVER.apply(compareGOLD,axis=1)

# %% [markdown]
# with codecs.open("2015-Data/"+samplePrefix+".yaml", 'w', encoding='utf8') as outfile:
#     outfile.write(yaml.dump(conjugaisons, default_flow_style=True, encoding='utf8'))

# %%
yaml.safe_dump(conjugaisons, file("2015-Data/"+samplePrefix+dateheure()+".yaml",'w'), encoding='utf-8', allow_unicode=True)
yaml.safe_dump(cliquesTypes, file("2015-Data/"+samplePrefix+"cliques-"+dateheure()+".yaml",'w'), encoding='utf-8', allow_unicode=True)

# %% [markdown]
# pb=[i for i in conjugaisons if conjugaisons[i]["diff"]]
# print (len(pb))
# for element in pb:
#     print (element)
#     print ("DIFF",conjugaisons[element]["diff"])
#     print ("MISS",conjugaisons[element]["miss"],end="\n\n")

# %% [markdown]
# good=[i for i in conjugaisons if not conjugaisons[i]["diff"]]
# for lexeme in good:
#     print (lexeme)
#     for ident in conjugaisons[lexeme]:
#         for element in conjugaisons[lexeme][ident]:
#             print (ident)
#             print (", ".join(element))
#     print ()

# %%
precisions={"bon":0,"mauvais":0}
for verbe in cliquesTypes:
    if debug: print (verbe)
    for cle in cliquesTypes[verbe]:
        if debug: print (cle)
        for element in cliquesTypes[verbe][cle]:
            if debug: print (element[1],element[2])
            if cle in ["ok"]:
                precisions["bon"]+=element[2]
            elif cle in ["diff"]:
                precisions["mauvais"]+=element[2]
precisions

# %%
float(precisions["bon"])/(precisions["bon"]+precisions["mauvais"])

# %%
basesMesures={"total":0,"bon":0,"mauvais":0}
for verbe in conjugaisons:
    for cat in conjugaisons[verbe]:
        if conjugaisons[verbe][cat]:
#            print (verbe,cat,len(conjugaisons[verbe][cat][0]))
            if cat=="miss":
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
            elif cat=="ok":
                basesMesures["bon"]+=len(conjugaisons[verbe][cat][0])
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
            elif cat=="diff":
                basesMesures["mauvais"]+=len(conjugaisons[verbe][cat][0])
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
            elif cat=="overmiss":
                basesMesures["mauvais"]+=len(conjugaisons[verbe][cat][0])
                basesMesures["total"]+=len(conjugaisons[verbe][cat][0])
basesMesures

# %%
precisionManip=float(basesMesures["bon"])/(basesMesures["bon"]+basesMesures["mauvais"])
precisionManip

# %%
rappelManip=float(basesMesures["bon"])/(basesMesures["total"])
rappelManip

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
import yaml

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
samplePrefix="MGC-150815-extend-01-X-paradigmes"
sampleFile=samplePrefix+".csv"
goldFile="MGC-150815-total-1508150555-paradigmes.csv"
analysisPrefix="MGC-150815-extend-01-X"
logfile_name=analysisPrefix+samplePrefix+".log"
logfile = codecs.open("2015-Data/"+logfile_name,mode='w',encoding="utf8")

# %% [markdown]
# ###Préparation des cases du paradigme

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# #Préparation du calcul des analogies

# %% [markdown]
# ###Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ###Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ###Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ###Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmes=pd.read_csv("2015-Data/"+sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]

# %%
phonologicalMap=analysisPrefix[-2:]
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %%
GOLD=pd.read_csv("2015-Data/"+goldFile,sep=";",encoding="utf8")
del GOLD[u"Unnamed: 0"]
goldCases=GOLD.columns.tolist()
goldCases.remove(u"lexeme")
for case in goldCases:
    GOLD[case]=GOLD[case].apply(lambda x: recoder(x))
    
paradigmesGOLD=GOLD[paradigmes.columns.values.tolist()]
paradigmesGOLD
# Out:
#              lexeme         ai1P        ai1S         ai2P        ai2S  \
# 0          abaisser       abEsam       abEsE       abEsat       abEsa
# 1        abandonner     abâdOnam     abâdOnE     abâdOnat     abâdOna
# 2        abasourdir    abazurdim    abazurdi    abazurdit    abazurdi
# 3           abattre       abatim       abati       abatit       abati
# 4           abcéder      absEdam      absEdE      absEdat      absEda
# 5          abdiquer      abdikam      abdikE      abdikat      abdika
# 6          abecquer       abEkam       abEkE       abEkat       abEka
# 7           aberrer       abEram       abErE       abErat       abEra
# 8          abhorrer       abOram       abOrE       abOrat       abOra
# 9           abjurer      abZyram      abZyrE      abZyrat      abZyra
# 10          ablater      ablatam      ablatE      ablatat      ablata
# 11          ablatir      ablatim      ablati      ablatit      ablati
# 12         abloquer      ablOkam      ablOkE      ablOkat      ablOka
# 13           abolir       abOlim       abOli       abOlit       abOli
# 14          abonder       abôdam       abôdE       abôdat       abôda
# 15          abonner       abOnam       abOnE       abOnat       abOna
# 16          abonnir       abOnim       abOni       abOnit       abOni
# 17          aborder      abOrdam      abOrdE      abOrdat      abOrda
# 18          aborner      abOrnam      abOrnE      abOrnat      abOrna
# 19         aboucher       abuSam       abuSE       abuSat       abuSa
# 20          abouler       abulam       abulE       abulat       abula
# 21          abouter       abutam       abutE       abutat       abuta
# 22          aboutir       abutim       abuti       abutit       abuti
# 23           aboyer      abwajam      abwajE      abwajat      abwaja
# 24          abraser      abrazam      abrazE      abrazat      abraza
# 25         abreuver      abr6vam      abr6vE      abr6vat      abr6va
# 26        abricoter    abrikOtam    abrikOtE    abrikOtat    abrikOta
# 27          abriter      abritam      abritE      abritat      abrita
# 28          abroger      abrOZam      abrOZE      abrOZat      abrOZa
# 29          abrutir      abrytim      abryti      abrytit      abryti
# ...             ...          ...         ...          ...         ...
# 6531      étreindre      EtrEJim      EtrEJi      EtrEJit      EtrEJi
# 6532       étrenner      EtrEnam      EtrEnE      EtrEnat      EtrEna
# 6533       étriller      Etrijam      EtrijE      Etrijat      Etrija
# 6534        étriper      Etripam      EtripE      Etripat      Etripa
# 6535       étriquer      Etrikam      EtrikE      Etrikat      Etrika
# 6536        étrécir      EtrEsim      EtrEsi      EtrEsit      EtrEsi
# 6537  étrésillonner  EtrEzijOnam  EtrEzijOnE  EtrEzijOnat  EtrEzijOna
# 6538        étudier      Etydjam      EtydjE      Etydjat      Etydja
# 6539         étuver       Etyvam       EtyvE       Etyvat       Etyva
# 6540         étêter       EtEtam       EtEtE       EtEtat       EtEta
# 6541        évacuer      Evakyam      EvakyE      Evakyat      Evakya
# 6542         évader       Evadam       EvadE       Evadat       Evada
# 6543        évaluer      Evalyam      EvalyE      Evalyat      Evalya
# 6544    évangéliser   EvâZElizam   EvâZElizE   EvâZElizat   EvâZEliza
# 6545       évanouir      Evanuim      Evanui      Evanuit      Evanui
# 6546       évaporer     EvapOram     EvapOrE     EvapOrat     EvapOra
# 6547         évaser       Evazam       EvazE       Evazat       Evaza
# 6548       éveiller       EvEjam       EvEjE       EvEjat       EvEja
# 6549        éventer       Evâtam       EvâtE       Evâtat       Evâta
# 6550     éventiller     Evâtijam     EvâtijE     Evâtijat     Evâtija
# 6551       éventrer      Evâtram      EvâtrE      Evâtrat      Evâtra
# 6552       évertuer     EvErtyam     EvErtyE     EvErtyat     EvErtya
# 6553         évider       Evidam       EvidE       Evidat       Evida
# 6554        évincer       Evêsam       EvêsE       Evêsat       Evêsa
# 6555      éviscérer     EvisEram     EvisErE     EvisErat     EvisEra
# 6556         éviter       Evitam       EvitE       Evitat       Evita
# 6557        évoluer      EvOlyam      EvOlyE      EvOlyat      EvOlya
# 6558        évoquer       EvOkam       EvOkE       EvOkat       EvOka
# 6559           être          fym          fy          fyt          fy
# 6560           ôter         Otam         OtE         Otat         Ota
#
#              ai3P        ai3S          fi1P          fi1S          fi2P  \
# 0          abEsEr       abEsa       abEs6rô       abEs6rE       abEs6re
# 1        abâdOnEr     abâdOna     abâdOn6rô     abâdOn6rE     abâdOn6re
# 2       abazurdir    abazurdi    abazurdirô    abazurdirE    abazurdire
# 3          abatir       abati        abatrô        abatrE        abatre
# 4         absEdEr      absEda      absEd6rô      absEd6rE      absEd6re
# 5         abdikEr      abdika      abdik6rô      abdik6rE      abdik6re
# 6          abEkEr       abEka       abEk6rô       abEk6rE       abEk6re
# 7          abErEr       abEra       abEr6rô       abEr6rE       abEr6re
# 8          abOrEr       abOra       abOr6rô       abOr6rE       abOr6re
# 9         abZyrEr      abZyra      abZyr6rô      abZyr6rE      abZyr6re
# 10        ablatEr      ablata      ablat6rô      ablat6rE      ablat6re
# 11        ablatir      ablati      ablatirô      ablatirE      ablatire
# 12        ablOkEr      ablOka      ablOk6rô      ablOk6rE      ablOk6re
# 13         abOlir       abOli       abOlirô       abOlirE       abOlire
# 14         abôdEr       abôda       abôd6rô       abôd6rE       abôd6re
# 15         abOnEr       abOna       abOn6rô       abOn6rE       abOn6re
# 16         abOnir       abOni       abOnirô       abOnirE       abOnire
# 17        abOrdEr      abOrda      abOrd6rô      abOrd6rE      abOrd6re
# 18        abOrnEr      abOrna      abOrn6rô      abOrn6rE      abOrn6re
# 19         abuSEr       abuSa       abuS6rô       abuS6rE       abuS6re
# 20         abulEr       abula       abul6rô       abul6rE       abul6re
# 21         abutEr       abuta       abut6rô       abut6rE       abut6re
# 22         abutir       abuti       abutirô       abutirE       abutire
# 23        abwajEr      abwaja        abwarô        abwarE        abware
# 24        abrazEr      abraza      abraz6rô      abraz6rE      abraz6re
# 25        abr6vEr      abr6va      abr6v6rô      abr6v6rE      abr6v6re
# 26      abrikOtEr    abrikOta    abrikOt6rô    abrikOt6rE    abrikOt6re
# 27        abritEr      abrita      abrit6rô      abrit6rE      abrit6re
# 28        abrOZEr      abrOZa      abrOZ6rô      abrOZ6rE      abrOZ6re
# 29        abrytir      abryti      abrytirô      abrytirE      abrytire
# ...           ...         ...           ...           ...           ...
# 6531      EtrEJir      EtrEJi       Etrêdrô       EtrêdrE       Etrêdre
# 6532      EtrEnEr      EtrEna      EtrEn6rô      EtrEn6rE      EtrEn6re
# 6533      EtrijEr      Etrija      Etrij6rô      Etrij6rE      Etrij6re
# 6534      EtripEr      Etripa      Etrip6rô      Etrip6rE      Etrip6re
# 6535      EtrikEr      Etrika      Etrik6rô      Etrik6rE      Etrik6re
# 6536      EtrEsir      EtrEsi      EtrEsirô      EtrEsirE      EtrEsire
# 6537  EtrEzijOnEr  EtrEzijOna  EtrEzijOn6rô  EtrEzijOn6rE  EtrEzijOn6re
# 6538      EtydjEr      Etydja       Etydirô       EtydirE       Etydire
# 6539       EtyvEr       Etyva       Etyv6rô       Etyv6rE       Etyv6re
# 6540       EtEtEr       EtEta       EtEt6rô       EtEt6rE       EtEt6re
# 6541      EvakyEr      Evakya       Evakyrô       EvakyrE       Evakyre
# 6542       EvadEr       Evada       Evad6rô       Evad6rE       Evad6re
# 6543      EvalyEr      Evalya       Evalyrô       EvalyrE       Evalyre
# 6544   EvâZElizEr   EvâZEliza   EvâZEliz6rô   EvâZEliz6rE   EvâZEliz6re
# 6545      Evanuir      Evanui      Evanuirô      EvanuirE      Evanuire
# 6546     EvapOrEr     EvapOra     EvapOr6rô     EvapOr6rE     EvapOr6re
# 6547       EvazEr       Evaza       Evaz6rô       Evaz6rE       Evaz6re
# 6548       EvEjEr       EvEja       EvEj6rô       EvEj6rE       EvEj6re
# 6549       EvâtEr       Evâta       Evât6rô       Evât6rE       Evât6re
# 6550     EvâtijEr     Evâtija     Evâtij6rô     Evâtij6rE     Evâtij6re
# 6551      EvâtrEr      Evâtra      Evâtr6rô      Evâtr6rE      Evâtr6re
# 6552     EvErtyEr     EvErtya      EvErtyrô      EvErtyrE      EvErtyre
# 6553       EvidEr       Evida       Evid6rô       Evid6rE       Evid6re
# 6554       EvêsEr       Evêsa       Evês6rô       Evês6rE       Evês6re
# 6555     EvisErEr     EvisEra     EvisEr6rô     EvisEr6rE     EvisEr6re
# 6556       EvitEr       Evita       Evit6rô       Evit6rE       Evit6re
# 6557      EvOlyEr      EvOlya       EvOlyrô       EvOlyrE       EvOlyre
# 6558       EvOkEr       EvOka       EvOk6rô       EvOk6rE       EvOk6re
# 6559          fyr          fy          s6rô          s6rE          s6re
# 6560         OtEr         Ota         Ot6rô         Ot6rE         Ot6re
#
#         ...            ppFP        ppFS        ppMP        ppMS         ps1P  \
# 0       ...           abEse       abEse       abEse       abEse       abEsjô
# 1       ...         abâdOne     abâdOne     abâdOne     abâdOne     abâdOnjô
# 2       ...        abazurdi    abazurdi    abazurdi    abazurdi  abazurdisjô
# 3       ...           abaty       abaty       abaty       abaty       abatjô
# 4       ...             NaN         NaN         NaN      absEde      absEdjô
# 5       ...          abdike      abdike      abdike      abdike      abdikjô
# 6       ...           abEke       abEke       abEke       abEke       abEkjô
# 7       ...             NaN         NaN         NaN       abEre       abErjô
# 8       ...           abOre       abOre       abOre       abOre       abOrjô
# 9       ...          abZyre      abZyre      abZyre      abZyre      abZyrjô
# 10      ...          ablate      ablate      ablate      ablate      ablatjô
# 11      ...          ablati      ablati      ablati      ablati    ablatisjô
# 12      ...          ablOke      ablOke      ablOke      ablOke      ablOkjô
# 13      ...           abOli       abOli       abOli       abOli     abOlisjô
# 14      ...             NaN         NaN         NaN       abôde       abôdjô
# 15      ...           abOne       abOne       abOne       abOne       abOnjô
# 16      ...           abOni       abOni       abOni       abOni     abOnisjô
# 17      ...          abOrde      abOrde      abOrde      abOrde      abOrdjô
# 18      ...          abOrne      abOrne      abOrne      abOrne      abOrnjô
# 19      ...           abuSe       abuSe       abuSe       abuSe       abuSjô
# 20      ...           abule       abule       abule       abule       abuljô
# 21      ...           abute       abute       abute       abute       abutjô
# 22      ...             NaN         NaN         NaN       abuti     abutisjô
# 23      ...             NaN         NaN         NaN      abwaje       abwajô
# 24      ...          abraze      abraze      abraze      abraze      abrazjô
# 25      ...          abr6ve      abr6ve      abr6ve      abr6ve      abr6vjô
# 26      ...        abrikOte    abrikOte    abrikOte    abrikOte    abrikOtjô
# 27      ...          abrite      abrite      abrite      abrite      abritjô
# 28      ...          abrOZe      abrOZe      abrOZe      abrOZe      abrOZjô
# 29      ...          abryti      abryti      abryti      abryti    abrytisjô
# ...     ...             ...         ...         ...         ...          ...
# 6531    ...           Etrêt       Etrêt        Etrê        Etrê       EtrEJô
# 6532    ...          EtrEne      EtrEne      EtrEne      EtrEne      EtrEnjô
# 6533    ...          Etrije      Etrije      Etrije      Etrije       Etrijô
# 6534    ...          Etripe      Etripe      Etripe      Etripe      Etripjô
# 6535    ...          Etrike      Etrike      Etrike      Etrike      Etrikjô
# 6536    ...          EtrEsi      EtrEsi      EtrEsi      EtrEsi    EtrEsisjô
# 6537    ...      EtrEzijOne  EtrEzijOne  EtrEzijOne  EtrEzijOne  EtrEzijOnjô
# 6538    ...          Etydje      Etydje      Etydje      Etydje      Etydijô
# 6539    ...           Etyve       Etyve       Etyve       Etyve       Etyvjô
# 6540    ...           EtEte       EtEte       EtEte       EtEte       EtEtjô
# 6541    ...          Evakye      Evakye      Evakye      Evakye      Evakyjô
# 6542    ...           Evade       Evade       Evade       Evade       Evadjô
# 6543    ...          Evalye      Evalye      Evalye      Evalye      Evalyjô
# 6544    ...       EvâZElize   EvâZElize   EvâZElize   EvâZElize   EvâZElizjô
# 6545    ...          Evanui      Evanui      Evanui      Evanui    Evanuisjô
# 6546    ...         EvapOre     EvapOre     EvapOre     EvapOre     EvapOrjô
# 6547    ...           Evaze       Evaze       Evaze       Evaze       Evazjô
# 6548    ...           EvEje       EvEje       EvEje       EvEje        EvEjô
# 6549    ...           Evâte       Evâte       Evâte       Evâte       Evâtjô
# 6550    ...             NaN         NaN         NaN     Evâtije      Evâtijô
# 6551    ...          Evâtre      Evâtre      Evâtre      Evâtre      Evâtrjô
# 6552    ...         EvErtye     EvErtye     EvErtye     EvErtye     EvErtyjô
# 6553    ...           Evide       Evide       Evide       Evide       Evidjô
# 6554    ...           Evêse       Evêse       Evêse       Evêse       Evêsjô
# 6555    ...         EvisEre     EvisEre     EvisEre     EvisEre     EvisErjô
# 6556    ...           Evite       Evite       Evite       Evite       Evitjô
# 6557    ...             NaN         NaN         NaN      EvOlye      EvOlyjô
# 6558    ...           EvOke       EvOke       EvOke       EvOke       EvOkjô
# 6559    ...             NaN         NaN         NaN         Ete        swajô
# 6560    ...             Ote         Ote         Ote         Ote         Otjô
#
#            ps1S         ps2P       ps2S       ps3P       ps3S
# 0          abEs       abEsje       abEs       abEs       abEs
# 1        abâdOn     abâdOnje     abâdOn     abâdOn     abâdOn
# 2     abazurdis  abazurdisje  abazurdis  abazurdis  abazurdis
# 3          abat       abatje       abat       abat       abat
# 4         absEd      absEdje      absEd      absEd      absEd
# 5         abdik      abdikje      abdik      abdik      abdik
# 6          abEk       abEkje       abEk       abEk       abEk
# 7          abEr       abErje       abEr       abEr       abEr
# 8          abOr       abOrje       abOr       abOr       abOr
# 9         abZyr      abZyrje      abZyr      abZyr      abZyr
# 10        ablat      ablatje      ablat      ablat      ablat
# 11      ablatis    ablatisje    ablatis    ablatis    ablatis
# 12        ablOk      ablOkje      ablOk      ablOk      ablOk
# 13       abOlis     abOlisje     abOlis     abOlis     abOlis
# 14         abôd       abôdje       abôd       abôd       abôd
# 15         abOn       abOnje       abOn       abOn       abOn
# 16       abOnis     abOnisje     abOnis     abOnis     abOnis
# 17        abOrd      abOrdje      abOrd      abOrd      abOrd
# 18        abOrn      abOrnje      abOrn      abOrn      abOrn
# 19         abuS       abuSje       abuS       abuS       abuS
# 20         abul       abulje       abul       abul       abul
# 21         abut       abutje       abut       abut       abut
# 22       abutis     abutisje     abutis     abutis     abutis
# 23         abwa       abwaje       abwa       abwa       abwa
# 24        abraz      abrazje      abraz      abraz      abraz
# 25        abr9v      abr6vje      abr9v      abr9v      abr9v
# 26      abrikOt    abrikOtje    abrikOt    abrikOt    abrikOt
# 27        abrit      abritje      abrit      abrit      abrit
# 28        abrOZ      abrOZje      abrOZ      abrOZ      abrOZ
# 29      abrytis    abrytisje    abrytis    abrytis    abrytis
# ...         ...          ...        ...        ...        ...
# 6531      EtrEJ       EtrEJe      EtrEJ      EtrEJ      EtrEJ
# 6532      EtrEn      EtrEnje      EtrEn      EtrEn      EtrEn
# 6533      Etrij       Etrije      Etrij      Etrij      Etrij
# 6534      Etrip      Etripje      Etrip      Etrip      Etrip
# 6535      Etrik      Etrikje      Etrik      Etrik      Etrik
# 6536    EtrEsis    EtrEsisje    EtrEsis    EtrEsis    EtrEsis
# 6537  EtrEzijOn  EtrEzijOnje  EtrEzijOn  EtrEzijOn  EtrEzijOn
# 6538      Etydi      Etydije      Etydi      Etydi      Etydi
# 6539       Etyv       Etyvje       Etyv       Etyv       Etyv
# 6540       EtEt       EtEtje       EtEt       EtEt       EtEt
# 6541      Evaky      Evakyje      Evaky      Evaky      Evaky
# 6542       Evad       Evadje       Evad       Evad       Evad
# 6543      Evaly      Evalyje      Evaly      Evaly      Evaly
# 6544   EvâZEliz   EvâZElizje   EvâZEliz   EvâZEliz   EvâZEliz
# 6545    Evanuis    Evanuisje    Evanuis    Evanuis    Evanuis
# 6546     EvapOr     EvapOrje     EvapOr     EvapOr     EvapOr
# 6547       Evaz       Evazje       Evaz       Evaz       Evaz
# 6548       EvEj        EvEje       EvEj       EvEj       EvEj
# 6549       Evât       Evâtje       Evât       Evât       Evât
# 6550     Evâtij      Evâtije     Evâtij     Evâtij     Evâtij
# 6551      Evâtr      Evâtrje      Evâtr      Evâtr      Evâtr
# 6552     EvErty     EvErtyje     EvErty     EvErty     EvErty
# 6553       Evid       Evidje       Evid       Evid       Evid
# 6554       Evês       Evêsje       Evês       Evês       Evês
# 6555     EvisEr     EvisErje     EvisEr     EvisEr     EvisEr
# 6556       Evit       Evitje       Evit       Evit       Evit
# 6557      EvOly      EvOlyje      EvOly      EvOly      EvOly
# 6558       EvOk       EvOkje       EvOk       EvOk       EvOk
# 6559        swa        swaje        swa        swa        swa
# 6560         ot         Otje         ot         ot         ot
#
# [6561 rows x 49 columns]

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 17784

# %%
with open("2015-Data/"+analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ###Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(casesTotales):
    print ("Attention l'analyse ne comprend pas toutes les cases")
# Out:
# Attention l'analyse ne comprend pas toutes les cases

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %%
def generate(lexeme,genDigraphe=True):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
len(paradigmes.dropna(thresh=3)["lexeme"])
# Out:
# 1950

# %%
# %%time
debug=False
genDigraphe=False
genGraphe=False
listeTest=[u"manger",u"boire",u"dormir",u"aller",u"neiger"]
listeTest=paradigmes.dropna(thresh=3)["lexeme"].values.tolist()
nbVerbes=len(listeTest)
print (nbVerbes)
globDigraphe=nx.DiGraph()
globGraphe=nx.Graph()
cliques=[]
for i,element in enumerate(listeTest):
    if (i%25)==0: print (i, dateheure(), int(100*float(i)/nbVerbes), end=", ")
    result=generate(element,genDigraphe)
    (generation,lexDigraphe,lexGraphe,lexCliques)= result
#    print (generation,lexDigraphe,lexGraphe,lexCliques)
    if genDigraphe:
        globDigraphe=nx.union(digraphe,lexDigraphe)
    if genGraphe:
        globGraphe=nx.union(graphe,lexGraphe)
    cliques.extend(lexCliques)
# Out:
# 1950
# 0 1508241103 0, 25 1508241104 1, 50 1508241105 2, 75 1508241106 3, 100 1508241107 5, 125 1508241117 6, 150 1508241118 7, 175 1508241119 8, 200 1508241121 10, 225 1508241133 11, 250 1508241134 12, 275 1508241135 14, 300 1508241136 15, 325 1508250234 16, 350 1508250235 17, 375 1508250237 19, 400 1508250238 20, 425 1508250240 21, 450 1508250241 23, 475 1508250243 24, 500 1508250244 25, 525 1508250245 26, 550 1508250246 28, 575 1508250247 29, 600 1508250248 30, 625 1508250249 32, 650 1508250251 33, 675 1508250252 34, 700 1508250253 35, 725 1508250255 37, 750 1508250257 38, 775 1508250258 39, 800 1508250259 41, 825 1508250301 42, 850 1508250302 43, 875 1508250303 44, 900 1508250304 46, 925 1508250306 47, 950 1508250307 48, 975 1508250309 50, 1000 1508250310 51, 1025 1508250311 52, 1050 1508250313 53, 1075 1508250314 55, 1100 1508250316 56, 1125 1508250317 57, 1150 1508250318 58, 1175 1508250320 60, 1200 1508250737 61, 1225 1508250738 62, 1250 1508250740 64, 1275 1508250741 65, 1300 1508250743 66, 1325 1508250744 67, 1350 1508250746 69, 1375 1508250747 70, 1400 1508250748 71, 1425 1508250750 73, 1450 1508250751 74, 1475 1508250752 75, 1500 1508250754 76, 1525 1508250755 78, 1550 1508250756 79, 1575 1508250757 80, 1600 1508250759 82, 1625 1508250800 83, 1650 1508250802 84, 1675 1508250803 85, 1700 1508250804 87, 1725 1508250805 88, 1750 1508250807 89, 1775 1508250808 91, 1800 1508250809 92, 1825 1508250810 93, 1850 1508250811 94, 1875 1508250813 96, 1900 1508250814 97, 1925 1508250815 98, CPU times: user 1h 38min 14s, sys: 1min, total: 1h 39min 15s
# Wall time: 21h 12min 51s

# %%
# %%time
versionStamp=dateheure()
if genDigraphe: 
    nx.write_dot(digraphe,u"2015-Data/digraphe-%s.dot"%versionStamp)
if genGraphe:
    nx.write_dot(graphe,u"2015-Data/graphe-%s.dot"%versionStamp)
# Out:
# CPU times: user 38 µs, sys: 1e+03 ns, total: 39 µs
# Wall time: 46 µs

# %%
#graphe=nx.Graph()
#graphe=nx.read_dot(u"graphe-1508180522.dot")

# %%
#%%time
#cliques=list(nx.algorithms.clique.find_cliques(graphe))

# %%
print (len(cliques))
# Out:
# 242442

# %%
longueurCliques={}
for clique in cliques:
    longueur=len(clique)
    if not longueur in longueurCliques:
        longueurCliques[longueur]=1
    else:
        longueurCliques[longueur]+=1
longueurCliques
# Out:
# {1: 5,
#  2: 1151,
#  3: 1558,
#  4: 3607,
#  5: 4171,
#  6: 5725,
#  7: 7742,
#  8: 9145,
#  9: 11626,
#  10: 13720,
#  11: 13233,
#  12: 11699,
#  13: 10779,
#  14: 10316,
#  15: 9237,
#  16: 9137,
#  17: 8436,
#  18: 8835,
#  19: 9714,
#  20: 10360,
#  21: 10633,
#  22: 9713,
#  23: 8873,
#  24: 8156,
#  25: 8162,
#  26: 7841,
#  27: 6712,
#  28: 7178,
#  29: 5865,
#  30: 4961,
#  31: 1965,
#  32: 1182,
#  33: 351,
#  34: 311,
#  35: 240,
#  36: 56,
#  37: 36,
#  39: 2,
#  40: 1,
#  41: 5,
#  44: 2,
#  45: 1}

# %% [markdown]
# ###Faire la liste des cases lexicalisées de l'échantillon

# %%
nbFormesLexicales={}
casesLexicales={element:paradigmes[paradigmes["lexeme"]==element].columns[paradigmes[paradigmes["lexeme"]==element].notnull().iloc[0]].tolist() for element in listeTest}
for element in casesLexicales:
    casesLexicales[element].remove("lexeme")
    nbFormesLexicales[element]=len(casesLexicales[element])

# %% [markdown]
# ##Comparer la sortie des cliques avec le paradigme de départ

# %%
# %%time
seuilClique=1
#paradigmesCLIQUES=pd.DataFrame(columns=paradigmes.columns.values.tolist())
paradigmesListe=[]
for n,clique in enumerate(sorted(cliques,key=lambda x: len(x),reverse=True)):
#    if seuilClique==0:
#        seuilClique=len(clique)-15
    if len(clique)>seuilClique:
        paradigmeClique={}
        sampleOK=True
#        print (n, len(clique))
        point=clique[0].split("-")
        lPoint=len(point)
#        print (point,"-".join(point[0:len(point)-2]))
        if lPoint==3:
            lexeme=point[0]
        else:
            lexeme="-".join(point[0:len(point)-2])
        paradigmeClique["lexeme"]=lexeme
        if n%250==0: print (n,end=", ")
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].notnull().columns.tolist()
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
#        casesLexeme.remove("lexeme")
        casesLexeme=casesLexicales[lexeme]
        if casesLexeme and len(casesLexeme)<=len(clique):
            for element in casesLexeme:
#                print (lexeme,element, paradigmes[paradigmes["lexeme"]==lexeme][element])
                champForme=paradigmes[paradigmes["lexeme"]==lexeme][element].iloc[0]
                if ","  in champForme:
                    formes=champForme.split(",")
                    okFormes=False
                    for forme in formes:
                        pointCase=u"%s-%s-%s"% (lexeme,forme,element)
#                        if debug: print (pointCase, clique)
                        if pointCase in clique:
                            okFormes=True
                            print ("point",pointCase)
#                            print ("clique",clique)
                            print ("gold",GOLD[GOLD["lexeme"]==lexeme][element])
                    if okFormes:
                        sampleOK=True
                    else:
                        sampleOK=False
                        break
                else:
                    forme=champForme
                    pointCase=u"%s-%s-%s"% (lexeme,forme,element)
                    if debug: print (pointCase, clique)
                    if not pointCase in clique:
                        sampleOK=False
#                        print ("point",pointCase)
#                        print ("clique",clique)
#                        print ("gold",GOLD[GOLD["lexeme"]==lexeme][element])
                        break
        else:
            sampleOK=False
        if sampleOK:
            for element in clique:
                elements=element.split("-")
                forme=elements[-2]
                taminfo=elements[-1]
#                try:
#                 (lexeme,forme,taminfo)=element.split("-")
#                except ValueError:
#                    print (element)
                paradigmeClique[taminfo]=forme
#                if taminfo in paradigmes.columns:
#                    if not paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].isnull().item():
#                        if paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item()!=forme:
#                            sampleOK=False
#                            print (paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item(),forme,taminfo,end=", ")
            paradigmesListe.append(paradigmeClique)
        else:
            if debug:
                print ()
                print (lexeme,clique)
                print ()
    else:
        break

paradigmesCLIQUES=pd.DataFrame(paradigmesListe,columns=GOLD.columns.values.tolist())
print (seuilClique)
# Out:
# 0, point vouloir-v6je-pI2P
# gold 6227    v6je,vule
# Name: pI2P, dtype: object
# point vouloir-vule-pI2P
# gold 6227    v6je,vule
# Name: pI2P, dtype: object
# point essayer-EsErô-fi1P
# gold 2749    EsErô,EsEj6rô
# Name: fi1P, dtype: object
# point essayer-EsEj6rô-fi1P
# gold 2749    EsErô,EsEj6rô
# Name: fi1P, dtype: object
# point essayer-EsEra-fi3S
# gold 2749    EsEra,EsEj6ra
# Name: fi3S, dtype: object
# point essayer-EsEj6ra-fi3S
# gold 2749    EsEra,EsEj6ra
# Name: fi3S, dtype: object
# point essayer-EsE-pI2S
# gold 2749    EsE,EsEj
# Name: pI2S, dtype: object
# point essayer-EsEj-pI2S
# gold 2749    EsE,EsEj
# Name: pI2S, dtype: object
# point essayer-EsE-pi1S
# gold 2749    EsE,EsEj
# Name: pi1S, dtype: object
# point essayer-EsEj-pi1S
# gold 2749    EsE,EsEj
# Name: pi1S, dtype: object
# point essayer-EsE-pi2S
# gold 2749    EsE,EsEj
# Name: pi2S, dtype: object
# point essayer-EsEj-pi2S
# gold 2749    EsE,EsEj
# Name: pi2S, dtype: object
# point essayer-EsE-pi3S
# gold 2749    EsE,EsEj
# Name: pi3S, dtype: object
# point essayer-EsEj-pi3S
# gold 2749    EsE,EsEj
# Name: pi3S, dtype: object
# point essayer-EsE-ps2S
# gold 2749    EsE,EsEj
# Name: ps2S, dtype: object
# point essayer-EsEj-ps2S
# gold 2749    EsE,EsEj
# Name: ps2S, dtype: object
# 250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000, 10250, 10500, 10750, 11000, 11250, 11500, 11750, 12000, 12250, 12500, 12750, 13000, 13250, 13500, 13750, 14000, 14250, 14500, 14750, 15000, 15250, 15500, 15750, 16000, 16250, 16500, 16750, 17000, 17250, 17500, 17750, 18000, 18250, 18500, 18750, 19000, 19250, 19500, point payer-pErE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pEj6rE-fi1S
# gold 4229    pErE,pEj6rE
# Name: fi1S, dtype: object
# point payer-pE-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pEj-pI2S
# gold 4229    pE,pEj
# Name: pI2S, dtype: object
# point payer-pE-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pEj-pi1S
# gold 4229    pE,pEj
# Name: pi1S, dtype: object
# point payer-pE-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pEj-pi2S
# gold 4229    pE,pEj
# Name: pi2S, dtype: object
# point payer-pE-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pEj-pi3S
# gold 4229    pE,pEj
# Name: pi3S, dtype: object
# point payer-pE-ps1S
# gold 4229    pE,pEj
# Name: ps1S, dtype: object
# point payer-pEj-ps1S
# gold 4229    pE,pEj
# Name: ps1S, dtype: object
# point payer-pE-ps3S
# gold 4229    pE,pEj
# Name: ps3S, dtype: object
# point payer-pEj-ps3S
# gold 4229    pE,pEj
# Name: ps3S, dtype: object
# 19750, 20000, 20250, 20500, 20750, 21000, 21250, 21500, 21750, 22000, 22250, 22500, 22750, 23000, 23250, 23500, 23750, 24000, 24250, 24500, 24750, 25000, 25250, 25500, 25750, 26000, 26250, 26500, 26750, 27000, 27250, 27500, 27750, 28000, 28250, 28500, 28750, 29000, 29250, 29500, point asseoir-asje-pI2S
# gold 398    asje,aswa
# Name: pI2S, dtype: object
# point asseoir-aswa-pI2S
# gold 398    asje,aswa
# Name: pI2S, dtype: object
# point asseoir-asje-pi1S
# gold 398    asje,aswa
# Name: pi1S, dtype: object
# point asseoir-aswa-pi1S
# gold 398    asje,aswa
# Name: pi1S, dtype: object
# point asseoir-asje-pi2S
# gold 398    asje,aswa
# Name: pi2S, dtype: object
# point asseoir-aswa-pi2S
# gold 398    asje,aswa
# Name: pi2S, dtype: object
# point asseoir-asje-pi3S
# gold 398    asje,aswa
# Name: pi3S, dtype: object
# point asseoir-aswa-pi3S
# gold 398    asje,aswa
# Name: pi3S, dtype: object
# 29750, 30000, 30250, 30500, 30750, 31000, 31250, 31500, 31750, 32000, 32250, 32500, 32750, 33000, 33250, 33500, 33750, 34000, 34250, 34500, 34750, 35000, 35250, 35500, 35750, 36000, 36250, 36500, 36750, 37000, 37250, 37500, 37750, 38000, 38250, 38500, 38750, 39000, 39250, 39500, 39750, 40000, 40250, 40500, 40750, 41000, 41250, 41500, 41750, 42000, 42250, 42500, 42750, 43000, 43250, 43500, 43750, 44000, 44250, 44500, 44750, 45000, 45250, 45500, 45750, 46000, 46250, 46500, 46750, 47000, 47250, 47500, 47750, 48000, 48250, 48500, 48750, 49000, 49250, 49500, 49750, 50000, 50250, 50500, 50750, 51000, 51250, 51500, 51750, 52000, 52250, 52500, 52750, 53000, 53250, 53500, 53750, 54000, 54250, 54500, 54750, 55000, 55250, 55500, 55750, 56000, 56250, 56500, 56750, 57000, 57250, 57500, 57750, 58000, 58250, 58500, 58750, 59000, 59250, 59500, 59750, 60000, 60250, 60500, 60750, 61000, 61250, 61500, 61750, 62000, 62250, 62500, 62750, 63000, 63250, 63500, 63750, 64000, 64250, 64500, 64750, 65000, 65250, 65500, 65750, 66000, 66250, 66500, 66750, 67000, 67250, 67500, 67750, 68000, 68250, 68500, 68750, 69000, 69250, 69500, 69750, 70000, 70250, 70500, 70750, 71000, 71250, 71500, 71750, 72000, 72250, 72500, 72750, 73000, 73250, 73500, 73750, 74000, 74250, 74500, 74750, 75000, 75250, 75500, 75750, 76000, 76250, 76500, 76750, 77000, 77250, 77500, 77750, 78000, 78250, 78500, 78750, 79000, 79250, 79500, 79750, 80000, 80250, 80500, 80750, 81000, 81250, 81500, 81750, 82000, 82250, 82500, 82750, 83000, 83250, 83500, 83750, 84000, 84250, 84500, 84750, 85000, 85250, 85500, 85750, 86000, 86250, 86500, 86750, 87000, 87250, 87500, 87750, 88000, 88250, 88500, 88750, 89000, 89250, 89500, 89750, 90000, 90250, 90500, 90750, 91000, 91250, 91500, 91750, 92000, 92250, 92500, 92750, 93000, 93250, 93500, 93750, 94000, 94250, 94500, 94750, 95000, 95250, 95500, 95750, 96000, 96250, 96500, 96750, 97000, 97250, 97500, 97750, 98000, 98250, 98500, 98750, 99000, 99250, 99500, 99750, 100000, 100250, 100500, 100750, 101000, 101250, 101500, 101750, 102000, 102250, 102500, 102750, 103000, 103250, 103500, 103750, 104000, 104250, 104500, 104750, 105000, 105250, 105500, 105750, 106000, 106250, 106500, 106750, 107000, 107250, 107500, 107750, 108000, 108250, 108500, 108750, 109000, 109250, 109500, 109750, 110000, 110250, 110500, 110750, 111000, 111250, 111500, 111750, 112000, 112250, 112500, 112750, 113000, 113250, 113500, 113750, 114000, 114250, 114500, 114750, 115000, 115250, 115500, 115750, 116000, 116250, 116500, 116750, 117000, 117250, 117500, 117750, 118000, 118250, 118500, 118750, 119000, 119250, 119500, 119750, 120000, 120250, 120500, 120750, 121000, 121250, 121500, 121750, 122000, 122250, 122500, 122750, 123000, 123250, 123500, 123750, 124000, 124250, 124500, 124750, 125000, 125250, 125500, 125750, 126000, 126250, 126500, 126750, 127000, 127250, 127500, 127750, 128000, 128250, 128500, 128750, 129000, 129250, 129500, 129750, 130000, 130250, 130500, 130750, 131000, 131250, 131500, 131750, 132000, 132250, 132500, 132750, 133000, 133250, 133500, 133750, 134000, 134250, 134500, 134750, 135000, 135250, 135500, 135750, 136000, 136250, 136500, 136750, 137000, 137250, 137500, 137750, 138000, 138250, 138500, 138750, 139000, 139250, 139500, 139750, 140000, 140250, 140500, 140750, 141000, 141250, 141500, 141750, 142000, 142250, 142500, 142750, 143000, 143250, 143500, 143750, 144000, 144250, 144500, 144750, 145000, 145250, 145500, 145750, 146000, 146250, 146500, 146750, 147000, 147250, 147500, 147750, 148000, 148250, 148500, 148750, 149000, 149250, 149500, 149750, 150000, 150250, 150500, 150750, 151000, 151250, 151500, 151750, 152000, 152250, 152500, 152750, 153000, 153250, 153500, 153750, 154000, 154250, 154500, 154750, 155000, 155250, 155500, 155750, 156000, 156250, 156500, 156750, 157000, 157250, 157500, 157750, 158000, 158250, 158500, 158750, 159000, 159250, 159500, 159750, 160000, 160250, 160500, 160750, 161000, 161250, 161500, 161750, 162000, 162250, 162500, 162750, 163000, 163250, 1 ...
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# point balayer-balEj-pi1S
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# 199000, 199250, 199500, 199750, 200000, 200250, 200500, 200750, 201000, 201250, 201500, 201750, 202000, 202250, 202500, 202750, 203000, 203250, 203500, 203750, 204000, 204250, 204500, 204750, 205000, 205250, 205500, 205750, 206000, 206250, 206500, 206750, 207000, 207250, 207500, 207750, 208000, 208250, 208500, 208750, 209000, 209250, 209500, 209750, 210000, 210250, point balayer-balEj-pi1S
# gold 515    balE,balEj
# Name: pi1S, dtype: object
# 210500, 210750, 211000, 211250, 211500, 211750, 212000, 212250, 212500, 212750, 213000, 213250, 213500, 213750, 214000, 214250, 214500, 214750, 215000, 215250, 215500, 215750, 216000, 216250, 216500, 216750, 217000, 217250, 217500, 217750, 218000, 218250, 218500, 218750, 219000, 219250, 219500, 219750, 220000, 220250, 220500, 220750, 221000, 221250, 221500, 221750, 222000, 222250, 222500, 222750, 223000, 223250, 223500, 223750, 224000, 224250, 224500, 224750, 225000, 225250, 225500, 225750, 226000, 226250, 226500, 226750, 227000, 227250, 227500, 227750, 228000, 228250, 228500, 228750, 229000, 229250, 229500, 229750, 230000, 230250, 230500, 230750, 231000, 231250, 231500, 231750, 232000, 232250, 232500, 232750, 233000, 233250, 233500, 233750, 234000, 234250, 234500, 234750, 235000, 235250, 235500, 235750, 236000, 236250, 236500, 236750, 237000, 237250, 237500, 237750, 238000, 238250, 238500, 238750, 239000, 239250, 239500, 239750, 240000, 240250, 240500, 240750, 241000, 241250, 241500, 241750, 242000, 242250, 1
# CPU times: user 5min 56s, sys: 1.36 s, total: 5min 58s
# Wall time: 5min 59s

# %%
paradigmesCLIQUES
# Out:
#             lexeme    ai1P      ai1S ai2P ai2S       ai3P      ai3S  \
# 0            faire     fim        fi  NaN   fi        fir        fi
# 1            avoir      ym         y  NaN  NaN        NaN         y
# 2           devoir     NaN        dy  NaN  NaN        dyr        dy
# 3             dire     dim        di  dit  NaN        dir        di
# 4             être     NaN        fy  NaN   fy        fyr        fy
# 5            aller    alam       alE  NaN  NaN       alEr       ala
# 6          trouver  truvam     truvE  NaN  NaN     truvEr     truva
# 7            venir     NaN       NaN  NaN   vê        vêr        vê
# 8          abriter     NaN    abritE  NaN  NaN    abritEr    abrita
# 9           abuser     NaN     abyzE  NaN  NaN     abyzEr     abyza
# 10        agripper     NaN    agripE  NaN  NaN    agripEr    agripa
# 11       autoriser     NaN   OtOrizE  NaN  NaN   OtOrizEr   OtOriza
# 12          bouder     NaN      budE  NaN  NaN      budEr      buda
# 13          brider     NaN     bridE  NaN  NaN     bridEr     brida
# 14          briser     NaN     brizE  NaN  NaN     brizEr     briza
# 15         brouter     NaN     brutE  NaN  NaN     brutEr     bruta
# 16           buter     NaN      bytE  NaN  NaN      bytEr      byta
# 17         débuter     NaN    dEbytE  NaN  NaN    dEbytEr    dEbyta
# 18        effriter     NaN    EfritE  NaN  NaN    EfritEr    Efrita
# 19       favoriser     NaN  favOrizE  NaN  NaN  favOrizEr  favOriza
# 20          friser     NaN     frizE  NaN  NaN     frizEr     friza
# 21         gripper     NaN     gripE  NaN  NaN     gripEr     gripa
# 22          griser     NaN     grizE  NaN  NaN     grizEr     griza
# 23         grouper     NaN     grupE  NaN  NaN     grupEr     grupa
# 24         hériter     NaN     EritE  NaN  NaN     EritEr     Erita
# 25         irriter     NaN     iritE  NaN  NaN     iritEr     irita
# 26       maîtriser     NaN   mEtrizE  NaN  NaN   mEtrizEr   mEtriza
# 27        mépriser     NaN   mEprizE  NaN  NaN   mEprizEr   mEpriza
# 28         mériter     NaN    mEritE  NaN  NaN    mEritEr    mErita
# 29          priser     NaN     prizE  NaN  NaN     prizEr     priza
# ...            ...     ...       ...  ...  ...        ...       ...
# 35210      meubler     NaN       NaN  NaN  NaN        NaN       NaN
# 35211     patauger     NaN       NaN  NaN  NaN        NaN       NaN
# 35212       paumer     NaN       NaN  NaN  NaN        NaN       NaN
# 35213     pleuvoir     NaN       NaN  NaN  NaN        NaN       NaN
# 35214    propulser     NaN  prOpylsE  NaN  NaN  prOpylsEr       NaN
# 35215     raréfier     NaN       NaN  NaN  NaN        NaN       NaN
# 35216     raréfier     NaN       NaN  NaN  NaN        NaN       NaN
# 35217     rasseoir     NaN       NaN  NaN  NaN        NaN      rasi
# 35218      tutoyer     NaN       NaN  NaN  NaN        NaN       NaN
# 35219      usurper     NaN       NaN  NaN  NaN        NaN       NaN
# 35220      vaincre     NaN       NaN  NaN  NaN        NaN       NaN
# 35221     étriller     NaN       NaN  NaN  NaN        NaN       NaN
# 35222      évoluer     NaN    EvOlyE  NaN  NaN    EvOlyEr       NaN
# 35223    assaillir     NaN       NaN  NaN  NaN     asajir       NaN
# 35224     aveugler     NaN       NaN  NaN  NaN        NaN       NaN
# 35225      beugler     NaN       NaN  NaN  NaN        NaN     b6gla
# 35226    conquérir     NaN       NaN  NaN  NaN        NaN       NaN
# 35227    dissoudre     NaN       NaN  NaN  NaN        NaN       NaN
# 35228    décroître     NaN       NaN  NaN  NaN        NaN     dEkry
# 35229    embaucher     NaN       NaN  NaN  NaN        NaN       NaN
# 35230     embaumer     NaN       NaN  NaN  NaN        NaN       NaN
# 35231     enquérir     NaN       âki  NaN  NaN        NaN       âki
# 35232       jauger     NaN       NaN  NaN  NaN        NaN       NaN
# 35233      mouvoir     NaN       NaN  NaN  NaN        NaN       NaN
# 35234      peupler     NaN       NaN  NaN  NaN        NaN       NaN
# 35235  reconquérir     NaN       NaN  NaN  NaN        NaN       NaN
# 35236        choir     NaN       NaN  NaN  NaN        NaN       NaN
# 35237    corrompre     NaN       NaN  NaN  NaN        NaN       NaN
# 35238      relayer     NaN       NaN  NaN  NaN        NaN       NaN
# 35239      sourdre     NaN       NaN  NaN  NaN        NaN       NaN
#
#              fi1P        fi1S        fi2P   ...         ppFP      ppFS  \
# 0            f6rô        f6rE        f6re   ...          fEt       fEt
# 1             Orô         OrE         Ore   ...            y         y
# 2           d6vrô       d6vrE       d6vre   ...           dy        dy
# 3            dirô        dirE        dire   ...          dit       dit
# 4            s6rô        s6rE        s6re   ...          NaN       NaN
# 5             irô         irE         ire   ...          ale       ale
# 6         truv6rô     truv6rE     truv6re   ...        truve     truve
# 7          vjêdrô      vjêdrE      vjêdre   ...         v6ny      v6ny
# 8        abrit6rô    abrit6rE    abrit6re   ...       abrite    abrite
# 9         abyz6rô     abyz6rE     abyz6re   ...        abyze     abyze
# 10       agrip6rô    agrip6rE    agrip6re   ...       agripe    agripe
# 11      OtOriz6rô   OtOriz6rE   OtOriz6re   ...      OtOrize   OtOrize
# 12         bud6rô      bud6rE      bud6re   ...         bude      bude
# 13        brid6rô     brid6rE     brid6re   ...        bride     bride
# 14        briz6rô     briz6rE     briz6re   ...        brize     brize
# 15        brut6rô     brut6rE     brut6re   ...        brute     brute
# 16         byt6rô      byt6rE      byt6re   ...         byte      byte
# 17       dEbyt6rô    dEbyt6rE    dEbyt6re   ...       dEbyte    dEbyte
# 18       Efrit6rô    Efrit6rE    Efrit6re   ...       Efrite    Efrite
# 19     favOriz6rô  favOriz6rE  favOriz6re   ...     favOrize  favOrize
# 20        friz6rô     friz6rE     friz6re   ...        frize     frize
# 21        grip6rô     grip6rE     grip6re   ...        gripe     gripe
# 22        griz6rô     griz6rE     griz6re   ...        grize     grize
# 23        grup6rô     grup6rE     grup6re   ...        grupe     grupe
# 24        Erit6rô     Erit6rE     Erit6re   ...        Erite     Erite
# 25        irit6rô     irit6rE     irit6re   ...        irite     irite
# 26      mEtriz6rô   mEtriz6rE   mEtriz6re   ...      mEtrize   mEtrize
# 27      mEpriz6rô   mEpriz6rE   mEpriz6re   ...      mEprize   mEprize
# 28       mErit6rô    mErit6rE    mErit6re   ...       mErite    mErite
# 29        priz6rô     priz6rE     priz6re   ...        prize     prize
# ...           ...         ...         ...   ...          ...       ...
# 35210         NaN         NaN         NaN   ...          NaN       NaN
# 35211         NaN         NaN         NaN   ...          NaN    patOZe
# 35212         NaN         NaN         NaN   ...          NaN      pOme
# 35213         NaN         NaN         NaN   ...          NaN       NaN
# 35214         NaN         NaN         NaN   ...          NaN       NaN
# 35215         NaN         NaN         NaN   ...          NaN       NaN
# 35216         NaN         NaN         NaN   ...          NaN       NaN
# 35217         NaN         NaN         NaN   ...          NaN       NaN
# 35218         NaN         NaN         NaN   ...          NaN       NaN
# 35219         NaN         NaN         NaN   ...      yzyrpet   yzyrpet
# 35220       vêkrô         NaN         NaN   ...          NaN      vêky
# 35221         NaN         NaN         NaN   ...      Etrijet   Etrijet
# 35222         NaN         NaN         NaN   ...          NaN       NaN
# 35223         NaN         NaN         NaN   ...          NaN       NaN
# 35224         NaN         NaN         NaN   ...          NaN       NaN
# 35225         NaN         NaN         NaN   ...          NaN       NaN
# 35226         NaN         NaN         NaN   ...          NaN       NaN
# 35227         NaN         NaN         NaN   ...          NaN       NaN
# 35228         NaN         NaN         NaN   ...          NaN       NaN
# 35229         NaN         NaN         NaN   ...          NaN       NaN
# 35230         NaN         NaN         NaN   ...          NaN       NaN
# 35231         NaN         NaN         NaN   ...          NaN       NaN
# 35232         NaN         NaN         NaN   ...          NaN       NaN
# 35233         NaN         NaN         NaN   ...          NaN       NaN
# 35234         NaN         NaN         NaN   ...        p6ple       NaN
# 35235         NaN         NaN         NaN   ...          NaN       NaN
# 35236         NaN         NaN         NaN   ...          NaN       NaN
# 35237         NaN         NaN         NaN   ...          NaN       NaN
# 35238         NaN         NaN         NaN   ...          NaN       NaN
# 35239         NaN         NaN         NaN   ...          NaN       NaN
#
#            ppMP      ppMS   ps1P     ps1S   ps2P     ps2S     ps3P     ps3S
# 0            fE        fE  fasjô      fas  fasje      fas      fas      fas
# 1             y         y    Ejô        E    Eje        E        E        E
# 2            dy        dy    NaN     dwav  d6vje      NaN     dwav     dwav
# 3            di        di    NaN      diz  dizje      diz      diz      diz
# 4           NaN       NaN  swajô      swa  swaje      swa      swa      swa
# 5           ale       ale    NaN       aj    NaN       aj       aj       aj
# 6         truve     truve    NaN     truv    NaN     truv     truv     truv
# 7          v6ny      v6ny    NaN     vjEn    NaN     vjEn     vjEn     vjEn
# 8        abrite    abrite    NaN    abrit    NaN    abrit    abrit    abrit
# 9         abyze     abyze    NaN     abyz    NaN     abyz     abyz     abyz
# 10       agripe    agripe    NaN    agrip    NaN    agrip    agrip    agrip
# 11      OtOrize   OtOrize    NaN   OtOriz    NaN   OtOriz   OtOriz   OtOriz
# 12         bude      bude    NaN      bud    NaN      bud      bud      bud
# 13        bride     bride    NaN     brid    NaN     brid     brid     brid
# 14        brize     brize    NaN     briz    NaN     briz     briz     briz
# 15        brute     brute    NaN     brut    NaN     brut     brut     brut
# 16         byte      byte    NaN      byt    NaN      byt      byt      byt
# 17       dEbyte    dEbyte    NaN    dEbyt    NaN    dEbyt    dEbyt    dEbyt
# 18       Efrite    Efrite    NaN    Efrit    NaN    Efrit    Efrit    Efrit
# 19     favOrize  favOrize    NaN  favOriz    NaN  favOriz  favOriz  favOriz
# 20        frize     frize    NaN     friz    NaN     friz     friz     friz
# 21        gripe     gripe    NaN     grip    NaN     grip     grip     grip
# 22        grize     grize    NaN     griz    NaN     griz     griz     griz
# 23        grupe     grupe    NaN     grup    NaN     grup     grup     grup
# 24        Erite     Erite    NaN     Erit    NaN     Erit     Erit     Erit
# 25        irite     irite    NaN     irit    NaN     irit     irit     irit
# 26      mEtrize   mEtrize    NaN   mEtriz    NaN   mEtriz   mEtriz   mEtriz
# 27      mEprize   mEprize    NaN   mEpriz    NaN   mEpriz   mEpriz   mEpriz
# 28       mErite    mErite    NaN    mErit    NaN    mErit    mErit    mErit
# 29        prize     prize    NaN     priz    NaN     priz     priz     priz
# ...         ...       ...    ...      ...    ...      ...      ...      ...
# 35210     m6ble       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35211       NaN    patOZe    NaN      NaN    NaN      NaN      NaN      NaN
# 35212       NaN      pOme    NaN      NaN    NaN      NaN      NaN      NaN
# 35213       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35214       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35215   rarEfje       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35216   rarEfje       NaN    NaN      NaN    NaN   rarEfj      NaN      NaN
# 35217       NaN      rasy    NaN      NaN    NaN      NaN      NaN      NaN
# 35218       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35219    yzyrpe    yzyrpe    NaN      NaN    NaN      NaN      NaN      NaN
# 35220       NaN      vêky    NaN      NaN    NaN      NaN      NaN      NaN
# 35221    Etrije    Etrije    NaN      NaN    NaN      NaN      NaN      NaN
# 35222       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35223       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35224       NaN    av6gle    NaN      NaN    NaN      NaN      NaN      NaN
# 35225       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35226       NaN       NaN    NaN   kôkjEr    NaN      NaN      NaN      NaN
# 35227       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35228       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35229       NaN     âbOSe    NaN      NaN    NaN      NaN      NaN      NaN
# 35230       NaN     âbOme    NaN      NaN    NaN      NaN      NaN      NaN
# 35231       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35232       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35233       NaN        my    NaN      NaN    NaN      NaN      NaN      NaN
# 35234       NaN     p6ple    NaN      NaN    NaN      NaN      NaN      NaN
# 35235       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35236       NaN        Sy    NaN      NaN    NaN      NaN      NaN      NaN
# 35237       NaN    kOrôpy    NaN      NaN    NaN      NaN      NaN      NaN
# 35238       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
# 35239       NaN       NaN    NaN      NaN    NaN      NaN      NaN      NaN
#
# [35240 rows x 52 columns]

# %%
def compareGOLD(row):
    global n
#    if row["lexeme"]=="dodo": 
#        debug=True
#    else:
#        debug=False
    if n%250==0: print (n,end=", ")
    n+=1
    ligne={k:row[k] for k in row.keys() if k!="lexeme"}
    lexeme=row["lexeme"]
    if not lexeme in conjugaisons:
        conjugaisons[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    if not lexeme in cliquesTypes:
        cliquesTypes[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    identiques=[]
    differents=[]
    missing=[]
    over=[]
    for case in analyseCases:
        if debug:    
            print (lexeme,case)
            print (GOLD[GOLD["lexeme"]==lexeme][case].item())
            print ((GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]))
        if not case in row:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("absence",case)
        elif case in row[row.isnull()] and not GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("CLIQUES +NaN",case)
        elif not case in row[row.isnull()] and GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            over.append(u"%s : %s ≠ Ø" % (case,row[case]))
            lexical=False
            if debug: print ("GOLD -NaN",case)            
        elif (row[case]==GOLD[GOLD["lexeme"]==lexeme][case].item()):
            if debug: print ("egal")
            identiques.append(u"%s : %s" % (case,row[case]))
            if debug: print ("valeurs id")
        elif (case in row[row.isnull()]) and (GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]):
            if debug: print ("NaNs")
            identiques.append(u"%s : %s" % (case,u"ØØØ"))
            if debug: print ("deux NaN")
        else:
            if debug: print ("else")
            differents.append(u"%s : %s ≠ %s" % (case, row[case],GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print (u"différence",case)
    if differents:
        conjugaisons[lexeme]["diff"].append(differents)
        cliquesTypes[lexeme]["diff"].append(ligne)
        if debug: print ("DIFF",len(differents),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: print (", ".join(differents))
    if missing and over:
        conjugaisons[lexeme]["overmiss"].append(over+missing)
        cliquesTypes[lexeme]["overmiss"].append(ligne)
        if debug: print ("OVERMISS", len(over), len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
            print (", ".join(over))
    elif missing:
        conjugaisons[lexeme]["miss"].append(missing)
        cliquesTypes[lexeme]["miss"].append(ligne)
        if debug: print ("MISS", len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
    elif over:
        conjugaisons[lexeme]["over"].append(over)
        cliquesTypes[lexeme]["over"].append(ligne)
        if debug: print ("OVER", len(over),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(over))
    if identiques:
        conjugaisons[lexeme]["ok"].append(identiques)
        cliquesTypes[lexeme]["ok"].append(ligne)
        if debug: print ("OK", len(identiques), len(identiques)-nombreElements[lexeme],end=saut)
        if debug1: print (", ".join(identiques))
#    print ()
    return lexical

# %%
# %%time
debug=False
debug1=False
saut="\n"
n=0
conjugaisons={}
cliquesTypes={}
print (", ".join(sampleCases))
paradigmesCLIQUES.apply(compareGOLD,axis=1)
# Out:
# ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P, fi2S, fi3P, fi3S, ii1P, ii1S, ii2P, ii2S, ii3P, ii3S, inf, is1S, is3P, is3S, pI1P, pI2P, pI2S, pP, pc1P, pc1S, pc2P, pc2S, pc3P, pc3S, pi1P, pi1S, pi2P, pi2S, pi3P, pi3S, ppFP, ppFS, ppMP, ppMS, ps1P, ps1S, ps2P, ps2S, ps3P, ps3S
# 0, 250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000, 6250, 6500, 6750, 7000, 7250, 7500, 7750, 8000, 8250, 8500, 8750, 9000, 9250, 9500, 9750, 10000, 10250, 10500, 10750, 11000, 11250, 11500, 11750, 12000, 12250, 12500, 12750, 13000, 13250, 13500, 13750, 14000, 14250, 14500, 14750, 15000, 15250, 15500, 15750, 16000, 16250, 16500, 16750, 17000, 17250, 17500, 17750, 18000, 18250, 18500, 18750, 19000, 19250, 19500, 19750, 20000, 20250, 20500, 20750, 21000, 21250, 21500, 21750, 22000, 22250, 22500, 22750, 23000, 23250, 23500, 23750, 24000, 24250, 24500, 24750, 25000, 25250, 25500, 25750, 26000, 26250, 26500, 26750, 27000, 27250, 27500, 27750, 28000, 28250, 28500, 28750, 29000, 29250, 29500, 29750, 30000, 30250, 30500, 30750, 31000, 31250, 31500, 31750, 32000, 32250, 32500, 32750, 33000, 33250, 33500, 33750, 34000, 34250, 34500, 34750, 35000, CPU times: user 1h 18min 27s, sys: 18.1 s, total: 1h 18min 46s
# Wall time: 2d 16h 42min

# %% [markdown]
# with codecs.open("2015-Data/"+samplePrefix+".yaml", 'w', encoding='utf8') as outfile:
#     outfile.write(yaml.dump(conjugaisons, default_flow_style=True, encoding='utf8'))

# %%
yaml.safe_dump(conjugaisons, file("2015-Data/"+samplePrefix+dateheure()+".yaml",'w'), encoding='utf-8', allow_unicode=True)
yaml.safe_dump(cliquesTypes, file("2015-Data/"+samplePrefix+"cliques-"+dateheure()+".yaml",'w'), encoding='utf-8', allow_unicode=True)

# %% [markdown]
# pb=[i for i in conjugaisons if conjugaisons[i]["diff"]]
# print (len(pb))
# for element in pb:
#     print (element)
#     print ("DIFF",conjugaisons[element]["diff"])
#     print ("MISS",conjugaisons[element]["miss"],end="\n\n")

# %% [markdown]
# good=[i for i in conjugaisons if not conjugaisons[i]["diff"]]
# for lexeme in good:
#     print (lexeme)
#     for ident in conjugaisons[lexeme]:
#         for element in conjugaisons[lexeme][ident]:
#             print (ident)
#             print (", ".join(element))
#     print ()

# %% [markdown]
# cliquesTypes

# %% [markdown]
# #Génération de paradigme
# À partir d'un remplissage de paradigme, calculer la génération suivante du remplissage

# %%
import copy

# %% [markdown]
# ##Données
#
# - paradigme : dict
#  - le premier niveau défini les cases avec la liste des formes qui les occupent
#  - le deuxième niveau donne les formes et leur proportion à l'intérieur de la case
# - règles

# %%
# inParadigme={'imparf3': [], 'inf': [('kree',1)], 'partpst': [], 'prs3': []}
# inParadigme={'imparf3': [('alE',1)], 'inf': [('ale',1)], 'partpst': [('ale',1)], 'prs3': [('vô',1)]}
inParadigme={'imparf3': [], 'inf': [('finir',1)], 'partpst': [], 'prs3': []}
emptyParadigme={"inf":[], "prs3":[], "partpst":[], "imparf3":[]}
regles={"inf":{
                "prs3":[("e",""),("ir","i")],
                "partpst":[("e","e"),("ir","i")],
                "imparf3":[("e","E"),("ir","isE")]
            }, 
        "prs3":{
                "inf":[("","e"),("i","ir")], 
                "partpst":[("","e"),("i","i")], 
                "imparf3":[("","E"),("i","isE")]
            },
        "partpst":{
                "inf":[("e","e"),("i","ir")],
                "prs3":[("e",""),("i","i")],
                "imparf3":[("e","E"),("i","isE")]
            }, 
        "imparf3":{
                "inf":[("E","e"),("isE","ir")],
                "prs3":[("E",""),("isE","i")],
                "partpst":[("E","e"),("isE","i")]}, 
        }
distributions={}

casePoids={"inf":1.0, "prs3":1.0, "partpst":1.0, "imparf3":1.0}

# %% [markdown]
# Essai d'interprétation d'une règle au format de sortie de PredSPE

# %%
def appliquerRegle(inForme,regle):
    if len(regle[0])!=0 and inForme.endswith(regle[0]):
        result=inForme[:-len(regle[0])]+regle[1]
    elif inForme.endswith(regle[0]):
        result=inForme+regle[1]
    return result

# %% [markdown]
# ###genererParadigme
# calcul la génération suivante du paradigme à partir de l'état actuel et des règles de transformation
#
# chaque case renseignée contribue à sa propre conservation et à la modification de toutes les autres
#
# - le poids de la case *casePoids* pondère ses contributions
# - la distribution des formes dans les cases du nouveau paradigme est normalisée à partir de toutes les contributions pondérées.

# %%
def genererParadigme(inParadigme):
    distributions={}
    resParadigme={"inf":[], "prs3":[], "partpst":[], "imparf3":[]}
    
    def distribuerForme(inForme):
        outListe=[]
        result=[]
        nbRegles=0
        for regle in regles[inCase][outCase]:
            if inForme.endswith(regle[0]):
                nbRegles+=1
                outForme=appliquerRegle(inForme,regle)
                outListe.append(outForme)
        for element in outListe:
            result.append((element,poids/nbRegles))
        return result
    
    
    for inCase in inParadigme:
        if inParadigme[inCase]:
#            print (inCase)
            autresCases=[i for i in inParadigme.keys() if i!=inCase]
            for outCase in autresCases:
                if not outCase in distributions:
                    distributions[outCase]={}
                if not inCase in distributions[outCase]:
                    distributions[outCase][inCase]={}
                for forme,poids in inParadigme[inCase]:
                    distributions[outCase][inCase][forme]=distribuerForme(forme)
            if not inCase in distributions:
                distributions[inCase]={}
            if not inCase in distributions[inCase]:
                distributions[inCase][inCase]={}
            for forme,poids in inParadigme[inCase]:
                distributions[inCase][inCase][forme]=[(forme,poids)]
#    print ("d",distributions)
    for distribution in distributions:
#        print (distribution)
        outDistribution={}
        nbOutFormes=0
        for inCase in distributions[distribution]:
#            print ("\t",inCase,end="\n")
            for inForme in distributions[distribution][inCase]:
#                print ("\t\t",inForme,end="\t")
                for outForme in distributions[distribution][inCase][inForme]:
#                    print (outForme,end="\n")
                    if not outForme[0] in outDistribution:
                        outDistribution[outForme[0]]=0
#                    print (outForme[1],casePoids[inCase])
                    outDistribution[outForme[0]]+=outForme[1]*casePoids[inCase]
                    nbOutFormes+=outForme[1]*casePoids[inCase]
#            print ("\t\t\t","outDistribution",outDistribution,end="\n")
        vecteurDistribution=[]
        for forme in outDistribution:
            vecteurDistribution.append((forme,outDistribution[forme]/nbOutFormes))
#        print ("vecteur",distribution,vecteurDistribution)
        resParadigme[distribution]=vecteurDistribution
    return resParadigme

# %%
print ("#", inParadigme)
# Out:
# # {'imparf3': [], 'partpst': [], 'prs3': [], 'inf': [('finir', 1)]}

# %%
oldParadigme=inParadigme
for i in range(15):
    newParadigme=genererParadigme(oldParadigme)
    print (i)
    for element in newParadigme:
            print (element,newParadigme[element])
    print ()
    oldParadigme=copy.deepcopy(newParadigme)
#    oldParadigme=newParadigme
# Out:
# 0
# imparf3 [('finisE', 1.0)]
# partpst [('fini', 1.0)]
# prs3 [('fini', 1.0)]
# inf [('finir', 1.0)]
#
# 1
# imparf3 [('finiE', 0.125), ('finisE', 0.875)]
# partpst [('fini', 0.75), ('finie', 0.125), ('finise', 0.125)]
# prs3 [('fini', 0.875), ('finis', 0.125)]
# inf [('finie', 0.125), ('finise', 0.125), ('finir', 0.75)]
#
# 2
# imparf3 [('finiE', 0.203125), ('finisE', 0.796875)]
# partpst [('finie', 0.203125), ('fini', 0.59375), ('finise', 0.203125)]
# prs3 [('fini', 0.796875), ('finis', 0.203125)]
# inf [('finie', 0.203125), ('finise', 0.203125), ('finir', 0.59375)]
#
# 3
# imparf3 [('finiE', 0.251953125), ('finisE', 0.748046875)]
# partpst [('finie', 0.251953125), ('fini', 0.49609375), ('finise', 0.251953125)]
# prs3 [('fini', 0.748046875), ('finis', 0.251953125)]
# inf [('finie', 0.251953125), ('finise', 0.251953125), ('finir', 0.49609375)]
#
# 4
# imparf3 [('finiE', 0.282470703125), ('finisE', 0.717529296875)]
# partpst [('finie', 0.282470703125), ('fini', 0.43505859375), ('finise', 0.282470703125)]
# prs3 [('fini', 0.717529296875), ('finis', 0.282470703125)]
# inf [('finie', 0.282470703125), ('finise', 0.282470703125), ('finir', 0.43505859375)]
#
# 5
# imparf3 [('finiE', 0.301544189453125), ('finisE', 0.698455810546875)]
# partpst [('finie', 0.301544189453125), ('fini', 0.39691162109375), ('finise', 0.301544189453125)]
# prs3 [('fini', 0.698455810546875), ('finis', 0.301544189453125)]
# inf [('finie', 0.301544189453125), ('finise', 0.301544189453125), ('finir', 0.39691162109375)]
#
# 6
# imparf3 [('finiE', 0.3134651184082031), ('finisE', 0.6865348815917969)]
# partpst [('finie', 0.3134651184082031), ('fini', 0.37306976318359375), ('finise', 0.3134651184082031)]
# prs3 [('fini', 0.6865348815917969), ('finis', 0.3134651184082031)]
# inf [('finie', 0.3134651184082031), ('finise', 0.3134651184082031), ('finir', 0.37306976318359375)]
#
# 7
# imparf3 [('finiE', 0.32091569900512695), ('finisE', 0.679084300994873)]
# partpst [('finie', 0.32091569900512695), ('fini', 0.3581686019897461), ('finise', 0.32091569900512695)]
# prs3 [('fini', 0.679084300994873), ('finis', 0.32091569900512695)]
# inf [('finie', 0.32091569900512695), ('finise', 0.32091569900512695), ('finir', 0.3581686019897461)]
#
# 8
# imparf3 [('finiE', 0.32557231187820435), ('finisE', 0.6744276881217957)]
# partpst [('finie', 0.32557231187820435), ('fini', 0.3488553762435913), ('finise', 0.32557231187820435)]
# prs3 [('fini', 0.6744276881217957), ('finis', 0.32557231187820435)]
# inf [('finie', 0.32557231187820435), ('finise', 0.32557231187820435), ('finir', 0.3488553762435913)]
#
# 9
# imparf3 [('finiE', 0.3284826949238777), ('finisE', 0.6715173050761223)]
# partpst [('finie', 0.3284826949238777), ('fini', 0.34303461015224457), ('finise', 0.3284826949238777)]
# prs3 [('fini', 0.6715173050761223), ('finis', 0.3284826949238777)]
# inf [('finie', 0.3284826949238777), ('finise', 0.3284826949238777), ('finir', 0.34303461015224457)]
#
# 10
# imparf3 [('finiE', 0.3303016843274236), ('finisE', 0.6696983156725764)]
# partpst [('finie', 0.3303016843274236), ('fini', 0.33939663134515285), ('finise', 0.3303016843274236)]
# prs3 [('fini', 0.6696983156725764), ('finis', 0.3303016843274236)]
# inf [('finie', 0.3303016843274236), ('finise', 0.3303016843274236), ('finir', 0.33939663134515285)]
#
# 11
# imparf3 [('finiE', 0.33143855270463973), ('finisE', 0.6685614472953603)]
# partpst [('finie', 0.33143855270463973), ('fini', 0.33712289459072053), ('finise', 0.33143855270463973)]
# prs3 [('fini', 0.6685614472953603), ('finis', 0.33143855270463973)]
# inf [('finie', 0.33143855270463973), ('finise', 0.33143855270463973), ('finir', 0.33712289459072053)]
#
# 12
# imparf3 [('finiE', 0.33214909544039983), ('finisE', 0.6678509045596002)]
# partpst [('finie', 0.33214909544039983), ('fini', 0.33570180911920033), ('finise', 0.33214909544039983)]
# prs3 [('fini', 0.6678509045596002), ('finis', 0.33214909544039983)]
# inf [('finie', 0.33214909544039983), ('finise', 0.33214909544039983), ('finir', 0.33570180911920033)]
#
# 13
# imparf3 [('finiE', 0.3325931846502499), ('finisE', 0.6674068153497501)]
# partpst [('finie', 0.3325931846502499), ('fini', 0.3348136306995002), ('finise', 0.3325931846502499)]
# prs3 [('fini', 0.6674068153497501), ('finis', 0.3325931846502499)]
# inf [('finie', 0.3325931846502499), ('finise', 0.3325931846502499), ('finir', 0.3348136306995002)]
#
# 14
# imparf3 [('finiE', 0.3328707404064062), ('finisE', 0.6671292595935938)]
# partpst [('finie', 0.3328707404064062), ('fini', 0.33425851918718763), ('finise', 0.3328707404064062)]
# prs3 [('fini', 0.6671292595935938), ('finis', 0.3328707404064062)]
# inf [('finie', 0.3328707404064062), ('finise', 0.3328707404064062), ('finir', 0.33425851918718763)]

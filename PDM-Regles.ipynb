# %%
import re
import sys
import copy

# %%
sepPaire="=>"
paireCase=""
pairesCases=[]
pairesCasesRegles={}
sortiesCases={}
Classes={}
classeDict={}
classeListe=[]
reglesSPE={}
reglesPDM=[]

# %%
def paireEntree(paire):
    return paire.split("=>")[0]
def paireSortie(paire):
    return paire.split("=>")[1]
def fairePaire(entree,sortie):
    return entree+sepPaire+sortie

# %%
def formaterRegle(line):
    m=re.search("^(\S+)\s+-->\s+(\S+)\s+/\s+(\S+)\s+___\s+(\S+)\s+(.*)$",line)
    if m:
        a=m.group(1)
        if a=="[]":
            a=""
        b=m.group(2)
        if b=="[]":
            b=""
        c="".join(m.group(3).split(","))
        if c[0]=="X":
            c="^(.*"+c[1:]+")"
        if c[0]=="#":
            c="^("+c[1:]+")"
        d=m.group(4)
        if d[-1]=="X":
            d="("+d[:-1]+".*)$"
        if d[-1]=="#":
            d="("+d[:-1]+")$"
        reste=m.group(5)
        return (c+a+d,b,reste)
    else:
        print ("NOT A RULE")
        return

# %% [markdown]
# ###Ajouter une règle à la liste et renvoyer le numéro de la règle
#
# si la règle existe déjà, on renvoie simplement le numéro existant

# %%
def ajouterRegle(regle):
    (regex,subst)=regle
    if not regle in reglesPDM:
        reglesPDM.append(regle)
    return reglesPDM.index(regle)

# %% [markdown]
# ###Interface avec la sortie de PredSPE

# %%
def lirePredSPE(nomFichier):
    try:
        fichierPredSPE=open(nomFichier,"r")
    except IOError:
        print ('I could not open the file', nomFichier)
        sys.exit()
    zoneRegles=False
    zoneClasses=False
    zoneClasse=False
    for line in fichierPredSPE:
        line=line.strip()
        m=re.search("^\s*(\S+)\s+==>\s+(\S+)\s*$",line)
        if m:
            paireCase=m.group(1)+sepPaire+m.group(2)
#            print (paireCase)
            reglesSPE[paireCase]=[]
            pairesCases.append(paireCase)
            case=paireSortie(paireCase)
            if not case in sortiesCases:
                sortiesCases[case]=[]
            sortiesCases[case].append(paireEntree(paireCase))
        if "*****" in line:
            zoneRegles=False
            zoneClasses=False
        if "done." in line:
            zoneRegles=False
        if "conditional entropy for" in line:
            zoneClasses=False        
            paireCase=""
        if zoneRegles:
#            print ("Règle",line)
#            reglesSPE[paireCase].append(line)
            (inPatron,mod,reste)=formaterRegle(line)
            if not paireCase in pairesCasesRegles:
                pairesCasesRegles[paireCase]=[]
            pairesCasesRegles[paireCase].append((ajouterRegle((inPatron,mod))))
        if zoneClasses:
            if "local conditional entropy" in line:
                zoneClasse=False
                nomClasse="-".join(sorted(classeListe,key=int))
                if not paireCase in Classes:
                    Classes[paireCase]={}
                Classes[paireCase][nomClasse]=classeDict
            if zoneClasse:
                (inPatron, mod, reste)=formaterRegle(line)
                n=re.search("^.*—(.+)%.*$",reste)
                if n:
                    classeDict[reglesPDM.index((inPatron,mod))]=float(n.group(1))
                    classeListe.append(str(reglesPDM.index((inPatron,mod))))
#                    print (reglesPDM.index((inPatron,mod)),float(n.group(1)))
                else:
                    print ("NO DISTRIBUTION")
            if "class" in line:
                zoneClasse=True
                classeDict={}
                classeListe=[]
        if "Inferring rules" in line:
            zoneRegles=True
        if "done." in line:
            zoneClasses=True

# %%
lirePredSPE("./PDM-Rules.txt")

# %% [markdown]
# ###Lecture des règles
#
# - Les règles sont transformées en expression régulières.
# - *reglesPDM* contient la liste des règles
# - *pairesCasesRegles* contient les numéros des règles utilisées pour chaque paire de cases

# %%
# reglesPDM=[]
# pairesCasesRegles={}
for paireCase in pairesCases:
#    pairesCasesRegles[paireCase]=[]
#    for regleSPE in reglesSPE[paireCase]:
#        (inPatron,mod,reste)=formaterRegle(regleSPE)
#        pairesCasesRegles[paireCase].append(ajouterRegle((inPatron,mod)))
    pairesCasesRegles[paireCase]=sorted(pairesCasesRegles[paireCase])

# %%
formes={
    "ipf.3":[("finisE",1)],
    "prs.3":[("fini",1)],
    "inf":[("finir",1)]
}
formes={
    "ipf.3":[("sortE",1)],
    "prs.3":[("sor",1)],
    "inf":[("sortir",1)]
}
formes={
    "ipf.3":[("lavE",1)],
    "prs.3":[],
    "inf":[]
}
formes={
    "ipf.3":[("finisE",1)],
    "prs.3":[("fini",1)],
    "inf":[("finir",1)]
}

# %% [markdown]
# ##Génération de distributions à partir d'une forme
#
# - Eventuellement éliminer le tri des numéros de règle pour gagner du temps

# %% [raw]
# for outCase in sortiesCases:
#     print (outCase)
#     for inCase in sortiesCases[outCase]:
#         paireCase=fairePaire(inCase,outCase)
#         print (paireCase)
#         for (forme,part) in formes[paireEntree(paireCase)]:
#             numsClasse={}
#             for numero in pairesCasesRegles[paireCase]:
#                 (inPatron,mod)=reglesPDM[numero]
#                 extrait=re.search(inPatron,forme)
#                 if extrait:
#                     sortie=extrait.group(1)+mod+extrait.group(2)
#                     numsClasse[numero]=sortie
#             alphaKeys=[]
#             for num in sorted(numsClasse.keys()):
#                 alphaKeys.append(str(num))
#             classe="-".join(alphaKeys)
#             print (forme,classe)
#             for numero in numsClasse:
#                 if Classes[paireCase][classe][numero]>=0:
#                     print (forme,numsClasse[numero],"\t",Classes[paireCase][classe][numero]*part,"\t",numero)
#             print()
#     print()

# %%
def distributionVecteurs(matrice):
    formes={}
    total=0
    for vecteur in matrice:
        for (forme,coef) in vecteur:
            if not forme in formes:
                formes[forme]=0
            formes[forme]+=coef
            total+=coef
    distribution=[]
    for forme in formes:
        distribution.append((forme,float("{0:.2f}".format(formes[forme]/total))))
    return distribution

# %%
class DistributionFormes:
    def __init__(self,inCase,outCase):
        self.paireCase=fairePaire(inCase,outCase)
        self.entrees=[]
        self.vecteurDistribution=[]
        if inCase==outCase:
            self.reflexif=True
        else:
            self.reflexif=False
    def ajouterFormeCoef(self, FormeCoef):
        self.entrees.append(FormeCoef)
    def ajouterFormesCoefs(self, FormesCoefs):
        for FormeCoef in FormesCoefs:
            self.entrees.append(FormeCoef)
    def distribution(self):
        if self.reflexif:
            return distributionVecteurs([self.entrees])
        else:
            lines=[]
            for (forme,part) in self.entrees:
                numsClasse={}
                for numero in pairesCasesRegles[self.paireCase]:
                    (inPatron,mod)=reglesPDM[numero]
                    extrait=re.search(inPatron,forme)
                    if extrait:
                        sortie=extrait.group(1)+mod+extrait.group(2)
                        numsClasse[numero]=sortie
#                        print (numero,inPatron,forme,mod)
                alphaKeys=[]
                for num in sorted(numsClasse.keys()):
                    alphaKeys.append(str(num))
                classe="-".join(alphaKeys)
                if not classe in Classes[self.paireCase]:
                    print ("FORME SANS SORTIE",forme)
                else:
                    for numero in numsClasse:
                        if Classes[self.paireCase][classe][numero]>0:
                            lines.append((numsClasse[numero],Classes[self.paireCase][classe][numero]*part))
            formeNB={}
            total=0
            return distributionVecteurs([lines])

# %%
ancienParadigme=formes
for i in range(25):
    print (i)
    nouveauParadigme={}
    for outCase in sortiesCases:
#        print (outCase)
        distribution=[]
#        for inCase in sortiesCases[outCase]: #Sans réflexivité
        for inCase in sortiesCases:           #Avec réflexivité
            distributionInOut=DistributionFormes(inCase,outCase)
            distributionInOut.ajouterFormesCoefs(ancienParadigme[inCase])
            distribution.append(distributionInOut.distribution())
        nouveauParadigme[outCase]=distributionVecteurs(distribution)
    for case in nouveauParadigme:
        print (case,nouveauParadigme[case])
    ancienParadigme=copy.deepcopy(nouveauParadigme)
# Out:
# 0
# ipf.3 [('finjE', 0.07), ('finisE', 0.78), ('finE', 0.16)]
# prs.3 [('finis', 0.11), ('fini', 0.89)]
# inf [('finjE', 0.17), ('finir', 0.8), ('finisE', 0.03)]
# 1
# ipf.3 [('finjE', 0.14), ('finisE', 0.68), ('finE', 0.18)]
# prs.3 [('fini', 0.81), ('fin', 0.05), ('finis', 0.13)]
# inf [('finjE', 0.24), ('finir', 0.64), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.05)]
# 2
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.18), ('finisE', 0.62), ('finE', 0.19)]
# prs.3 [('fini', 0.76), ('fin', 0.09), ('finis', 0.14)]
# inf [('finjE', 0.27), ('finir', 0.55), ('finisE', 0.09), ('finjr', 0.0), ('finE', 0.09)]
# 3
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.2), ('finisE', 0.59), ('finE', 0.21)]
# prs.3 [('fini', 0.73), ('fin', 0.12), ('finis', 0.15)]
# inf [('finjE', 0.28), ('finir', 0.5), ('finisE', 0.1), ('finjr', 0.0), ('finE', 0.12)]
# 4
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.21), ('finisE', 0.56), ('finE', 0.23)]
# prs.3 [('fini', 0.7), ('fin', 0.15), ('finis', 0.15)]
# inf [('finjE', 0.29), ('finir', 0.47), ('finisE', 0.1), ('finjr', 0.0), ('finE', 0.15)]
# 5
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.21), ('finisE', 0.54), ('finE', 0.25)]
# prs.3 [('fini', 0.68), ('fin', 0.18), ('finis', 0.15)]
# inf [('finjE', 0.29), ('finir', 0.44), ('finisE', 0.1), ('finjr', 0.0), ('finE', 0.17)]
# 6
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.21), ('finisE', 0.52), ('finE', 0.27)]
# prs.3 [('fini', 0.66), ('fin', 0.2), ('finis', 0.14)]
# inf [('finjE', 0.28), ('finir', 0.42), ('finisE', 0.1), ('finjr', 0.0), ('finE', 0.2)]
# 7
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.21), ('finisE', 0.5), ('finE', 0.29)]
# prs.3 [('fini', 0.64), ('fin', 0.22), ('finis', 0.14)]
# inf [('finjE', 0.28), ('finir', 0.4), ('finisE', 0.1), ('finjr', 0.0), ('finE', 0.22)]
# 8
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.21), ('finisE', 0.49), ('finE', 0.31)]
# prs.3 [('fini', 0.62), ('fin', 0.24), ('finis', 0.14)]
# inf [('finjE', 0.27), ('finir', 0.39), ('finisE', 0.09), ('finjr', 0.0), ('finE', 0.24)]
# 9
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.2), ('finisE', 0.47), ('finE', 0.33)]
# prs.3 [('fini', 0.6), ('fin', 0.26), ('finis', 0.13)]
# inf [('finjE', 0.27), ('finir', 0.38), ('finisE', 0.09), ('finjr', 0.0), ('finE', 0.26)]
# 10
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.2), ('finisE', 0.46), ('finE', 0.34)]
# prs.3 [('fini', 0.59), ('fin', 0.28), ('finis', 0.13)]
# inf [('finjE', 0.26), ('finir', 0.37), ('finisE', 0.09), ('finjr', 0.0), ('finE', 0.28)]
# 11
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.19), ('finisE', 0.45), ('finE', 0.36)]
# prs.3 [('fini', 0.57), ('fin', 0.3), ('finis', 0.13)]
# inf [('finjE', 0.26), ('finir', 0.36), ('finisE', 0.09), ('finjr', 0.0), ('finE', 0.3)]
# 12
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.19), ('finisE', 0.44), ('finE', 0.37)]
# prs.3 [('fini', 0.56), ('fin', 0.32), ('finis', 0.12)]
# inf [('finjE', 0.25), ('finir', 0.35), ('finisE', 0.09), ('finjr', 0.0), ('finE', 0.31)]
# 13
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.18), ('finisE', 0.43), ('finE', 0.39)]
# prs.3 [('fini', 0.55), ('fin', 0.33), ('finis', 0.12)]
# inf [('finjE', 0.24), ('finir', 0.35), ('finisE', 0.08), ('finjr', 0.0), ('finE', 0.33)]
# 14
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.18), ('finisE', 0.42), ('finE', 0.4)]
# prs.3 [('fini', 0.53), ('fin', 0.35), ('finis', 0.12)]
# inf [('finjE', 0.24), ('finir', 0.34), ('finisE', 0.08), ('finjr', 0.0), ('finE', 0.34)]
# 15
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.18), ('finisE', 0.41), ('finE', 0.42)]
# prs.3 [('fini', 0.52), ('fin', 0.36), ('finis', 0.11)]
# inf [('finjE', 0.23), ('finir', 0.33), ('finisE', 0.08), ('finjr', 0.0), ('finE', 0.36)]
# 16
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.17), ('finisE', 0.4), ('finE', 0.43)]
# prs.3 [('fini', 0.51), ('fin', 0.38), ('finis', 0.11)]
# inf [('finjE', 0.23), ('finir', 0.32), ('finisE', 0.08), ('finjr', 0.0), ('finE', 0.37)]
# 17
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.17), ('finisE', 0.39), ('finE', 0.44)]
# prs.3 [('fini', 0.5), ('fin', 0.39), ('finis', 0.11)]
# inf [('finjE', 0.22), ('finir', 0.31), ('finisE', 0.08), ('finjr', 0.0), ('finE', 0.39)]
# 18
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.16), ('finisE', 0.38), ('finE', 0.46)]
# prs.3 [('fini', 0.49), ('fin', 0.41), ('finis', 0.11)]
# inf [('finjE', 0.22), ('finir', 0.31), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.4)]
# 19
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.16), ('finisE', 0.37), ('finE', 0.47)]
# prs.3 [('fini', 0.48), ('fin', 0.42), ('finis', 0.1)]
# inf [('finjE', 0.21), ('finir', 0.3), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.42)]
# 20
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.16), ('finisE', 0.36), ('finE', 0.48)]
# prs.3 [('fini', 0.46), ('fin', 0.44), ('finis', 0.1)]
# inf [('finjE', 0.21), ('finir', 0.3), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.43)]
# 21
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.15), ('finisE', 0.35), ('finE', 0.5)]
# prs.3 [('fini', 0.45), ('fin', 0.45), ('finis', 0.1)]
# inf [('finjE', 0.2), ('finir', 0.29), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.44)]
# 22
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.15), ('finisE', 0.34), ('finE', 0.51)]
# prs.3 [('fini', 0.44), ('fin', 0.46), ('finis', 0.1)]
# inf [('finjE', 0.2), ('finir', 0.28), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.46)]
# 23
# FORME SANS SORTIE finjr
# ipf.3 [('finjE', 0.15), ('finisE', 0.34), ('finE', 0.52)]
# prs.3 [('fini', 0.43), ('fin', 0.48), ('finis', 0.1)]
# inf [('finjE', 0.19), ('finir', 0.27), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.47)]
# 24
# FORME SANS SORTIE finjr
# ipf.3
#  [('finjE', 0.14), ('finisE', 0.33), ('finE', 0.53)]
# prs.3 [('fini', 0.42), ('fin', 0.49), ('finis', 0.09)]
# inf [('finjE', 0.19), ('finir', 0.27), ('finisE', 0.07), ('finjr', 0.0), ('finE', 0.48)]

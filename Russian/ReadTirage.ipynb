# %%
import pandas as pd

# %%
    sample=pd.read_pickle("/Users/gilles/pCloud Drive/FOD/GB/Divers/RussianData/MGC-160804-0-1Mo-0-Tirage.pkl")

# %%
sample.sort_values("tir1",ascending=False)
# Out:
#                       Gloss    Sg    Pl    case  rawFreq     adjFreq  \
# 65972                  time  1796   149   NomSg     1303  1303660024
# 49773                  year  1545  1437   GenPl      870   870567783
# 66492                  life  1476    16   NomSg      678   678542425
# 66273                 thing  1128   343   NomSg      656   656414537
# 55220                  year  1545  1437   GenSg      618   618567783
# 70568                person  1388  1383   NomSg      552   552510086
# 66283                   day   873   336   NomSg      546   546320825
# 55598                  life  1476    16   GenSg      461   461542425
# 33432                  year  1545  1437  Loc2Sg      438   438567783
# 59674                person  1388  1383   GenSg      448   448510086
# 32439                person  1388  1383   NomPl      435   435510086
# 54227                person  1388  1383   GenPl      421   421510086
# 27968                   eye    96   855   NomPl      423   423035280
# ...

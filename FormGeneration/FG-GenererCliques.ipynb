# %% [markdown]
# # Génération des cliques à partir d'un échantillon et des classes

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs,glob,re,pickle,features
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import networkx as nx
debug=False
from __future__ import print_function

# %%
import yaml

# %% [markdown]
# from ipywidgets import FloatProgress
# from IPython.display import display

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ### Préparation des matrices de traits

# %%
#features.add_config('../bdlexique.ini')
features.add_config('../german.ini')
fs=features.FeatureSystem('phonemes')

# %%
genDigraphe=False
genGraphe=False

# %%
phonologicalMap="-X"

repSample="/Users/gilles/Box Sync/2015-Data/FlexionAdjectifs/"
repClasses="/Users/gilles/Box Sync/2015-Data/FlexionAdjectifs/"
repSample="/Users/gilles/Box Sync/2015-Data/German/"
repClasses="/Users/gilles/Box Sync/2015-Data/German/"
serie="MSP"
numEchantillon=0
nomGold="/Users/gilles/Box Sync/2015-Data/MGC-170716-Adjectifs.pkl"
nomGold=""

listeSamples=glob.glob(repSample+"Longitudinal*%s.pkl"%serie)
listeSamples=glob.glob(repSample+"German*%s.pkl"%serie)
nomSample=listeSamples[numEchantillon]
print (nomSample)
listeClasses=glob.glob(repSample+"Longitudinal*%s-Regles.pkl"%serie)
listeClasses=glob.glob(repSample+"German*%s-Regles.pkl"%serie)
nomClasse=listeClasses[numEchantillon]
print (nomClasse)
analyseCases=[]
# Out:
# /Users/gilles/Box Sync/2015-Data/German/German-V-X-MSP.pkl
# /Users/gilles/Box Sync/2015-Data/German/German-V-X-MSP-Regles.pkl

# %%
dierese={"j":"ij", "w":"uw","H":"yH","i":"ij","u":"uw","y":"yH"}
def checkFrench(prononciation):
    result=recoder(prononciation)
    m=re.match(ur"^.*([^ieèEaOouy926êôâ])[jwH]$",result)
    if m:
        print ("pb avec un glide final", prononciation)
    m=re.match(ur"(.*[ptkbdgfsSvzZ][rl])([jwH])(.*)",result)
    if m:
        n=re.search(ur"[ptkbdgfsSvzZ][rl](wa|Hi|wê)",result)
        if not n:
            glide=m.group(2)
            result=m.group(1)+dierese[glide]+m.group(3)
    m=re.match(ur"(.*)([iuy])([ieEaOouy].*)",result)
    if m:
        glide=m.group(2)
        result=m.group(1)+dierese[glide]+m.group(3)
    return result

# %%
def lireLexique(nomLexique):
    with open(nomLexique, 'rb') as input:
        lexique=pickle.load(input)
    return lexique

# %%
def lexique2Paradigmes(lexique):
    return pd.pivot_table(lexique, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

# %%
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# ### Préparation du paradigme de référence (Gold)

# %%
if nomGold:
    lexiqueGold=lireLexique(nomGold)
    lexiqueGold["phono"]=lexiqueGold["phono"].apply(checkFrench)
    paradigmesGold=lexique2Paradigmes(lexiqueGold)

# %% [markdown]
# ### Préparation du paradigme de référence (Base)

# %%
def preparerLexiqueBase(nomSample):
    nomBase=nomSample
    if serie=="OMP":
        nomBase=nomSample.replace("OMP","MSP")
    print (nomBase)
    lexiqueBase=lireLexique(nomBase)
    lexiqueBase["phono"]=lexiqueBase["phono"].apply(checkFrench)
    paradigmesBase=lexique2Paradigmes(lexiqueBase)
    return paradigmesBase

# %% [raw]
# paradigmesGold

# %% [markdown]
# ### Préparation des cases du paradigme

# %% [raw]
# casesTotales=lireLexique(nomSample)["case"].unique().tolist()

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            if debug: print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            if debug:
                print (forme, file=logfile) 
                print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
def preparerSample(nomSample):
    lexique=lireLexique(nomSample)
    lexique["phono"]=lexique["phono"].apply(checkFrench)
    morphomes={}
    if "morphome" in lexique.columns:
        for morphome in lexique.morphome.unique():
            if "/" in morphome:
                morphomeCases=morphome.split("/")
                morphomeCase=lexique[lexique["morphome"]==morphome]["case"].unique().tolist()
                if len(morphomeCase)>1:
                    print("pb",morphomeCase)
                else:
                    morphomeCase=morphomeCase[0]
                morphomes[morphomeCase]=morphomeCases
        print (morphomes)
    paradigmes=lexique2Paradigmes(lexique)
    paradigmes=paradigmes.dropna(axis=1,how='all')
    return morphomes,paradigmes

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %% [raw]
# sampleCases=paradigmes.columns.values.tolist()
# sampleCases.remove(u"lexeme")

# %% [raw]
# paradigmes.stack().value_counts(dropna=True).sum()

# %%
def preparerClasses(numSample):
    nomClasse=listeClasses[numSample]
    print(nomClasse)
    with open(nomClasse, 'rb') as input:
        resultatsLecture = pickle.load(input)
    return resultatsLecture
#resultatsLecture=preparerClasses(numSample)

# %% [markdown]
# ### Comparer les cases analysées avec l'ensemble de toutes les cases

# %% [raw]
# analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
# if sorted(analyseCases)!=sorted(casesTotales):
#     print ("Attention l'analyse ne comprend pas toutes les cases")

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self):
        caseListe=analyseCases
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True):
#    print (generation1.formes)
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()
    for caseDepart in analyseCases:
#        print (distributionInitiale)
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %%
def generate(lexeme,genDigraphe=True):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %% [raw]
# len(paradigmes.dropna(thresh=1)["lexeme"])

# %% [raw]
# paradigmes.dropna(thresh=1);

# %% [raw]
# paradigmes.dropna(thresh=1).count().sum()-paradigmes.dropna(thresh=1)["lexeme"].count()

# %% [markdown]
# #### Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    for (depart,arrivee) in it.combinations_with_replacement(clique,2):
        score+=graph[depart][arrivee]["weight"]
    return score

# %% [markdown]
# ## Génération des formes

# %%
def genererFormes(paradigmes):
    debug=False
    listeTest=paradigmes.dropna(thresh=1)["lexeme"].values.tolist()
    nbLexemes=len(listeTest)
    print (nbLexemes)
    globDigraphe=nx.DiGraph()
    globGraphe=nx.Graph()
    cliques=[]
    cliquesScores={}
    cliquesListes={}
    numClique=0
    #progressBar = FloatProgress(min=0, max=nbLexemes)
    #display(progressBar)
    for i,element in enumerate(listeTest):
    #    if (i%100)==0: print (i, dateheure()[-4:], int(100*float(i)/nbVerbes), end=", ")
    #    progressBar.value=i
        result=generate(element,genDigraphe)
        (generation,lexDigraphe,lexGraphe,lexCliques)= result
    #    print (generation,lexDigraphe,lexGraphe,lexCliques)
        if genDigraphe:
            globDigraphe=nx.union(globDigraphe,lexDigraphe)
        if genGraphe:
            globGraphe=nx.union(globGraphe,lexGraphe)
        cliques.extend(lexCliques)
        for clique in lexCliques:
            cliquesScores[numClique]=cliqueScore(clique,lexGraphe)
            cliquesListes[numClique]=clique
            numClique+=1
    versionStamp=dateheure()
    if genDigraphe: 
        nx.write_dot(globDigraphe,u"2015-Data/digraphe-%s.dot"%versionStamp)
    if genGraphe:
        nx.write_dot(globGraphe,u"2015-Data/graphe-%s.dot"%versionStamp)    
    return listeTest,cliques,cliquesScores

# %% [raw]
# print (len(cliques))

# %% [raw]
# longueurCliques={}
# for clique in cliques:
#     longueur=len(clique)
#     if not longueur in longueurCliques:
#         longueurCliques[longueur]=1
#     else:
#         longueurCliques[longueur]+=1
# longueurCliques

# %% [markdown]
# ### Faire la liste des cases lexicalisées de l'échantillon

# %%
def preparerCasesLexicales(paradigmes):
    nbFormesLexicales={}
    casesLexicales={element:paradigmes[paradigmes["lexeme"]==element].columns[paradigmes[paradigmes["lexeme"]==element].notnull().iloc[0]].tolist() for element in listeTest}
    for element in casesLexicales:
        casesLexicales[element].remove("lexeme")
        nbFormesLexicales[element]=len(casesLexicales[element])
    return casesLexicales
#casesLexicales=preparerCasesLexicales(paradigmes)

# %% [markdown]
# ## Comparer la sortie des cliques avec le paradigme de départ

# %%
def filtrerFidelite(clique,casesLexicales):
    seuilClique=1
    paradigmesListe=[]
    #progressBar = FloatProgress(min=0, max=len(cliques))
    #display(progressBar)
    for n,clique in enumerate(cliques):
    #    progressBar.value=n
        if len(clique)>seuilClique:
            paradigmeClique={}
            sampleOK=True
            point=clique[0].split("-")
            lPoint=len(point)
            if lPoint==3:
                lexeme=point[0]
            else:
                lexeme="-".join(point[0:len(point)-2])
            paradigmeClique["lexeme"]=lexeme
            casesLexeme=casesLexicales[lexeme]
            nbInitial=len(casesLexeme)
            if casesLexeme and len(casesLexeme)<=len(clique):
                for element in casesLexeme:
                    champForme=paradigmes[paradigmes["lexeme"]==lexeme][element].iloc[0]
                    if ","  in champForme:
                        formes=champForme.split(",")
                        nbInitial+=len(formes)-1
                        okFormes=False
                        for forme in formes:
                            pointCase=u"%s-%s-%s"% (lexeme,forme,element)
                            if pointCase in clique:
                                okFormes=True
                                if debug: print ("point",pointCase)
                        if okFormes:
                            sampleOK=True
                        else:
                            sampleOK=False
                            break
                    else:
                        forme=champForme
                        pointCase=u"%s-%s-%s"% (lexeme,forme,element)
                        if debug: print (pointCase, clique)
                        if not pointCase in clique:
                            sampleOK=False
                            break
            else:
                sampleOK=False
            if sampleOK:
                for element in clique:
                    elements=element.split("-")
                    forme=elements[-2]
                    taminfo=elements[-1]
                    paradigmeClique[taminfo]=forme
                paradigmeClique["score"]=cliquesScores[n]
                paradigmeClique["ajouts"]=len(clique)-nbInitial
                paradigmeClique["lexicales"]=", ".join(casesLexeme)
                paradigmesListe.append(paradigmeClique)
            else:
                if debug:
                    print ()
                    print (lexeme,clique)
                    print ()
    paradigmesCLIQUES=pd.DataFrame(paradigmesListe,columns=[u"lexeme"]+sampleCases+[u"score",u"ajouts","lexicales"])
    return paradigmesCLIQUES
#paradigmesCLIQUES=filtrerFidelite(clique,casesLexicales)

# %% [raw]
# paradigmesCLIQUES

# %%
def mesurerSimilarite(x):
    def calculSimilariteCase(x,caseMorphome):
        if (paradigmesBase[paradigmesBase["lexeme"]==lexeme][caseMorphome]!=x[case]).all():
            if (paradigmesGold[paradigmesGold["lexeme"]==lexeme][caseMorphome]!=x[case]).all():
                if x[case]:
                    result["wrong"]+=1
                else:
                    result["missing"]+=1
            else:
                result["right"]+=1
        else:
            result["known"]+=1
    
    result={"known":0,"right":0,"wrong":0,"missing":0}
    lexeme=x["lexeme"]
#    print (lexeme,sampleCases)
    for case in sampleCases:
#        print (case)
        if case in morphomes:
#            print ("morphome",case,morphomes[case])
            for caseMorphome in morphomes[case]:
#                print ("caseMorphome",caseMorphome)
                calculSimilariteCase(x,caseMorphome)
#                print (result,case)
        else:
#            print ("normal",case)
            calculSimilariteCase(x,case)
#    print (lexeme,result["known"],result["right"],result["wrong"],result["missing"])
    return (result["known"],result["right"],result["wrong"],result["missing"])

# %%
def filtrerMax(paradigmesCLIQUES):
    paradigmesMAX=paradigmesCLIQUES[paradigmesCLIQUES["score"]==paradigmesCLIQUES.groupby(["lexeme"])["score"].transform(max)].reset_index()
    del paradigmesMAX["index"]
    paradigmesMAX["score"]=paradigmesMAX["score"].apply(str)
    paradigmesMAX["ajouts"]=paradigmesMAX["ajouts"].apply(str)

    paradigmesSILVER=paradigmesMAX.groupby("lexeme").agg(lambda x: ",".join(list(set(x.dropna().values)))).reset_index()
    if nomGold:
        paradigmesSILVER["eval"]=paradigmesSILVER.apply(lambda x: mesurerSimilarite(x), axis=1)
        paradigmesSILVER["known"],paradigmesSILVER["right"],paradigmesSILVER["wrong"],paradigmesSILVER["missing"]=zip(*paradigmesSILVER["eval"])
        paradigmesSILVER.drop("eval",axis=1,inplace=True)

    return paradigmesSILVER

#paradigmesSILVER=filtrerMax(paradigmesCLIQUES)

# %% [raw]
# paradigmesSILVER.to_csv(path_or_buf=nomSample.replace(".pkl","-Silver.csv"),encoding="utf8",sep=";")
# #GOLD.to_csv(path_or_buf="2015-Data/"+analysisPrefix+'-Gold.csv',encoding="utf8",sep=";")

# %% [raw]
# paradigmesSILVER[["known","right","wrong","missing"]].sum(),numEchantillon,serie

# %% [markdown]
# # Boucle sur les échantillons

# %%
for numSample,nomSample in enumerate(listeSamples):
    print (numSample,nomSample)
    paradigmesBase=preparerLexiqueBase(nomSample)
    morphomes,paradigmes=preparerSample(nomSample)
    sampleCases=paradigmes.columns.values.tolist()
    sampleCases.remove(u"lexeme")
    casesTotales=paradigmesGold.columns.values.tolist()
    casesTotales.remove(u"lexeme")
    resultatsLecture=preparerClasses(numSample)
    analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
    if sorted(analyseCases)!=sorted(casesTotales):
        print ("Attention l'analyse ne comprend pas toutes les cases")
    listeTest,cliques,cliquesScores=genererFormes(paradigmes)
    casesLexicales=preparerCasesLexicales(paradigmes)
    paradigmesCLIQUES=filtrerFidelite(cliques,casesLexicales)
    paradigmesSILVER=filtrerMax(paradigmesCLIQUES)
    paradigmesSILVER.to_csv(path_or_buf=nomSample.replace(".pkl","-Silver.csv"),encoding="utf8",sep=";")
    if nomGold:
        print (paradigmesSILVER[["known","right","wrong","missing"]].sum(),numSample,serie)
# Out:
# 0 /Users/gilles/Box Sync/2015-Data/German/German-V-X-MSP.pkl
# /Users/gilles/Box Sync/2015-Data/German/German-V-X-MSP.pkl
# /Users/gilles/Box Sync/2015-Data/German/German-V-X-MSP-Regles.pkl
# Attention l'analyse ne comprend pas toutes les cases
# 3282

# %% [markdown]
# # TESTS

# %%
paradigmesSILVER[paradigmesSILVER["wrong"]>0]

# %%
paradigmesBase[paradigmesBase["fs"].notnull() & paradigmesBase["fs"].str.contains(",")]

# %%
lexique=lireLexique(nomSample.replace("OMP","MSP"))
lexique[lexique["lexeme"]=="lapon"]

# %%
resultatsLecture[("fp","ms")].patrons

# %%
pd.read_csv(path_or_buf=nomSample.replace(".pkl","-Silver.csv"),encoding="utf8",sep=";")

# %%
paradigmesSILVER[paradigmesSILVER["ajouts"]!="0"].groupby("NFIN").agg(' '.join)
# Out:
#                                                               lexeme  \
# NFIN
#                    antwortetest atmeten ballastete ballten beabsi...
# Etzen                                                    ätze ätzten
# Eçten                                                        ächtest
# S2pfen                                          schöpfest schöpftest
# SEmen                                                       schämtet
# SEnden                                                     schändest
# SErfen                                                       schärft
# SEumen                                                     schäumtet
# Saben                                                         schabt
# Salten                                                     schaltend
# Sassen                                  schassend schasste schasstet
# Seinen                                                      scheinen
# Senken                                            schenkend schenkst
# Serzen                                                      scherzen
# Seuksen                                          scheuche scheuchest
# Sijeben                                                      schiebe
# Sijelen                                schielend schielten schieltet
# Sikanijeren                                             schikanieret
# Siken                                       schicke schickt schickte
# Simpfen                                                   schimpfend
# Sleifen                                         schleifest schleifst
# Sleimen                                                   schleimtet
# Slemmen                                schlemme schlemmet schlemmtet
# Sleppen                                                    schleppen
# Slurfen                                           schlurfet schlurft
# Slypfen                                                     schlüpfe
# Slyrfen                                         schlürfen schlürftet
# Smauksen                                                 schmauchest
# Smeissen                                                  schmeißest
# Smeken                                  schmecke schmeckt schmeckten
# ...                                                              ...
# ztreiçen                                                  streichest
# ztriken                                    stricke stricken strickst
# ztrukturijeren                           strukturierest strukturiert
# ztudijeren                                                studierest
# ztutzen                                                     stutzend
# ztyrzen                                    stürzst stürzte stürztest
# ztytzen                                     stützend stützest stützt
# zubstituwijeren                                       substituiertet
# zubtrahijeren                                           subtrahieren
# zubventijonijeren                                   subventionierest
# zuksen                               suchend suchet suchtest suchtet
# zummen                                        summest summte summten
# zummijeren                            summierest summieret summierst
# zupfen                                                        zupfet
# zuppen                                                         zuppt
# zurfen                                                surfest surfet
# zurren                                                        surrte
# zuspendijenijeren    suspendieniere suspendienierst suspendieniertet
# zvEngen                                                      zwängst
# zvangsernEhren                      zwangsernährest zwangsernährtest
# zvingen                                                     zwingest
# zymbolisijeren                          symbolisierest symbolisierst
# zynden                                                        zünden
# zynthetisijeren                        synthetisierest synthetisiert
# çangijeren                                    changiere changiertest
# çargijeren                                               chargierten
# çeken                                     checkte checkten checktest
# çiffrijeren                    chiffrierend chiffrierte chiffrierten
# çloroformijeren                     chloroformiere chloroformiertest
# çristijanisijeren                                    christianisiert
#
#                                                         PLxPRSxINDx2  \
# NFIN
#                      ballastet       bearbeitet      beiçtt  beke...
# Etzen                                                          Etzt
# Eçten                                                          Eçtet
# S2pfen                                                         S2pft
# SEmen                                                           SEmt
# SEnden
# SErfen                                                         SErft
# SEumen                                                         SEumt
# Saben                                                           Sabt
# Salten                                                         Saltt
# Sassen                                                        Sasst
# Seinen                                                         Seint
# Senken                                                        Senkt
# Serzen
# Seuksen                                                      Seukst
# Sijeben                                                       Sijebt
# Sijelen
# Sikanijeren                                               Sikanijert
# Siken                                                      Sikt Sikt
# Simpfen
# Sleifen                                                       Sleift
# Sleimen
# Slemmen
# Sleppen                                                       Sleppt
# Slurfen                                                Slurft Slurft
# Slypfen                                                       Slypft
# Slyrfen                                                       Slyrft
# Smauksen
# Smeissen
# Smeken
# ...                                                              ...
# ztreiçen
# ztriken                                         ztrikt ztrikt ztrikt
# ztrukturijeren                           ztrukturijert ztrukturijert
# ztudijeren                                                 ztudijert
# ztutzen                                                       ztutzt
# ztyrzen                                                       ztyrzt
# ztytzen                                               ztytzt  ztytzt
# zubstituwijeren                                       zubstituwijert
# zubtrahijeren                                           zubtrahijert
# zubventijonijeren
# zuksen                                       zukst zukst zukst zukst
# zummen
# zummijeren                                      zummijert  zummijert
# zupfen                                                         zupft
# zuppen                                                         zuppt
# zurfen                                                         zurft
# zurren                                                         zurrt
# zuspendijenijeren  zuspendijenijert zuspendijenijert zuspendijeni...
# zvEngen
# zvangsernEhren                                         zvangsernEhrt
# zvingen
# zymbolisijeren                           zymbolisijert zymbolisijert
# zynden
# zynthetisijeren                        zynthetisijert zynthetisijert
# çangijeren                                                çangijert
# çargijeren                                                 çargijert
# çeken                                                 çekt çekt çekt
# çiffrijeren                         çiffrijert çiffrijert çiffrijert
# çloroformijeren                        çloroformijert çloroformijert
# çristijanisijeren                                   çristijanisijert
#
#                                                         PLxPRSxOPTx2  \
# NFIN
#                       ballet  beakstet   bearbeitet       beiçtet...
# Etzen
# Eçten
# S2pfen                                                 S2pfet S2pfet
# SEmen
# SEnden                                                        SEndet
# SErfen                                                        SErfet
# SEumen                                                        SEumet
# Saben
# Salten
# Sassen
# Seinen                                                        Seinet
# Senken                                                 Senket Senket
# Serzen                                                        Serzet
# Seuksen                                              Seukset Seukset
# Sijeben                                                      Sijebet
# Sijelen                                                     Sijelet
# Sikanijeren                                              Sikanijeret
# Siken
# Simpfen
# Sleifen                                              Sleifet Sleifet
# Sleimen
# Slemmen                                             Slemmet Slemmet
# Sleppen                                                      Sleppet
# Slurfen                                              Slurfet Slurfet
# Slypfen                                                      Slypfet
# Slyrfen                                                      Slyrfet
# Smauksen
# Smeissen                                                    Smeisset
# Smeken                                                      Smeket
# ...                                                              ...
# ztreiçen                                                    ztreiçet
# ztriken                                      ztriket ztriket ztriket
# ztrukturijeren                         ztrukturijeret ztrukturijeret
# ztudijeren                                                ztudijeret
# ztutzen                                                      ztutzet
# ztyrzen                                             ztyrzet  ztyrzet
# ztytzen                                      ztytzet ztytzet ztytzet
# zubstituwijeren                                      zubstituwijeret
# zubtrahijeren                                          zubtrahijeret
# zubventijonijeren                                  zubventijonijeret
# zuksen                                               zukset zukset
# zummen                                                      zummet
# zummijeren                          zummijeret zummijeret zummijeret
# zupfen                                                        zupfet
# zuppen                                                        zuppet
# zurfen                                                 zurfet zurfet
# zurren                                                        zurret
# zuspendijenijeren  zuspendijenijeret zuspendijenijeret zuspendije...
# zvEngen                                                      zvEnget
# zvangsernEhren                         zvangsernEhret zvangsernEhret
# zvingen                                                      zvinget
# zymbolisijeren                         zymbolisijeret zymbolisijeret
# zynden
# zynthetisijeren                      zynthetisijeret zynthetisijeret
# çangijeren                                     çangijeret çangijeret
# çargijeren                                                çargijeret
# çeken
# çiffrijeren                      çiffrijeret çiffrijeret çiffrijeret
# çloroformijeren                      çloroformijeret çloroformijeret
# çristijanisijeren                                  çristijanisijeret
#
#                                                    PLxPSTxCONDxPFVx1  \
# NFIN
#                       ballten beabsiçtigten beakstten beaksteten ...
# Etzen                                                  Etzten Etzten
# Eçten
# S2pfen                                               S2pften S2pften
# SEmen
# SEnden
# SErfen                                                       SErften
# SEumen                                                       SEumten
# Saben                                                         Sabten
# Salten
# Sassen                                       Sassten Sassten Sassten
# Seinen
# Senken                                               Senkten Senkten
# Serzen                                                       Serzten
# Seuksen                                            Seuksten Seuksten
# Sijeben                                                     Sijebten
# Sijelen                                           Sijelten Sijelten
# Sikanijeren                                             Sikanijerten
# Siken                                                  Sikten Sikten
# Simpfen                                                     Simpften
# Sleifen                                            Sleiften Sleiften
# Sleimen
# Slemmen                                   Slemmten Slemmten Slemmten
# Sleppen                                                     Sleppten
# Slurfen                                                     Slurften
# Slypfen
# Slyrfen                                            Slyrften Slyrften
# Smauksen
# Smeissen                                                   Smeissten
# Smeken                                              Smekten  Smekten
# ...                                                              ...
# ztreiçen                                                   ztreiçten
# ztriken                                   ztrikten ztrikten ztrikten
# ztrukturijeren                       ztrukturijerten ztrukturijerten
# ztudijeren                                               ztudijerten
# ztutzen                                                     ztutzten
# ztyrzen                                                    ztyrzten
# ztytzen                                   ztytzten ztytzten ztytzten
# zubstituwijeren                                     zubstituwijerten
# zubtrahijeren                                         zubtrahijerten
# zubventijonijeren                                 zubventijonijerten
# zuksen                                      zuksten  zuksten zuksten
# zummen                                              zummten zummten
# zummijeren                       zummijerten zummijerten zummijerten
# zupfen                                                       zupften
# zuppen                                                       zuppten
# zurfen                                               zurften zurften
# zurren                                                       zurrten
# zuspendijenijeren  zuspendijenijerten zuspendijenijerten zuspendi...
# zvEngen                                                     zvEngten
# zvangsernEhren
# zvingen                                                     zvingten
# zymbolisijeren                       zymbolisijerten zymbolisijerten
# zynden
# zynthetisijeren                    zynthetisijerten zynthetisijerten
# çangijeren                                   çangijerten çangijerten
# çargijeren                                               çargijerten
# çeken                                                         çekten
# çiffrijeren                   çiffrijerten çiffrijerten çiffrijerten
# çloroformijeren                    çloroformijerten çloroformijerten
# çristijanisijeren                                 çristijanisijerten
#
#                                                    PLxPSTxCONDxPFVx2  \
# NFIN
#                    antvortetet atmetet      beakstetet     befrei...
# Etzen                                                         Etztet
# Eçten
# S2pfen
# SEmen                                                         SEmtet
# SEnden
# SErfen                                                       SErftet
# SEumen                                                       SEumtet
# Saben
# Salten
# Sassen
# Seinen
# Senken                                               Senktet Senktet
# Serzen
# Seuksen
# Sijeben                                                     Sijebtet
# Sijelen                                                     Sijeltet
# Sikanijeren                                             Sikanijertet
# Siken
# Simpfen
# Sleifen                                                    Sleiftet
# Sleimen                                                     Sleimtet
# Slemmen                                                     Slemmtet
# Sleppen
# Slurfen                                                     Slurftet
# Slypfen
# Slyrfen                                            Slyrftet Slyrftet
# Smauksen
# Smeissen
# Smeken
# ...                                                              ...
# ztreiçen                                                   ztreiçtet
# ztriken                                                    ztriktet
# ztrukturijeren                       ztrukturijertet ztrukturijertet
# ztudijeren                                               ztudijertet
# ztutzen
# ztyrzen                                                    ztyrztet
# ztytzen
# zubstituwijeren
# zubtrahijeren
# zubventijonijeren                                 zubventijonijertet
# zuksen
# zummen                                                      zummtet
# zummijeren                       zummijertet zummijertet zummijertet
# zupfen
# zuppen
# zurfen                                               zurftet zurftet
# zurren                                                       zurrtet
# zuspendijenijeren  zuspendijenijertet zuspendijenijertet zuspendi...
# zvEngen                                                     zvEngtet
# zvangsernEhren
# zvingen
# zymbolisijeren                       zymbolisijertet zymbolisijertet
# zynden                                                       zyndtet
# zynthetisijeren                    zynthetisijertet zynthetisijertet
# çangijeren                                              çangijertet
# çargijeren                                               çargijertet
# çeken
# çiffrijeren                               çiffrijertet  çiffrijertet
# çloroformijeren                    çloroformijertet çloroformijertet
# çristijanisijeren                                 çristijanisijertet
#
#                                                     PLxPSTxINDxPFVx1  \
# NFIN
#                    antvorteten atmeten ballasteten     beaksteten...
# Etzen                                                  Etzten Etzten
# Eçten                                                        Eçteten
# S2pfen                                               S2pften S2pften
# SEmen
# SEnden                                                       SEndten
# SErfen                                                       SErften
# SEumen
# Saben                                                         Sabten
# Salten
# Sassen                                       Sassten Sassten Sassten
# Seinen
# Senken                                               Senkten Senkten
# Serzen                                                       Serzten
# Seuksen                                                     Seuksten
# Sijeben
# Sijelen                                            Sijelten Sijelten
# Sikanijeren                                             Sikanijerten
# Siken                                           Sikten Sikten Sikten
# Simpfen
# Sleifen                                            Sleiften Sleiften
# Sleimen
# Slemmen                                           Slemmten Slemmten
# Sleppen                                                     Sleppten
# Slurfen                                            Slurften Slurften
# Slypfen                                                     Slypften
# Slyrfen                                            Slyrften Slyrften
# Smauksen                                                   Smauksten
# Smeissen                                                   Smeissten
# Smeken
# ...                                                              ...
# ztreiçen                                                   ztreiçten
# ztriken                                   ztrikten ztrikten ztrikten
# ztrukturijeren                       ztrukturijerten ztrukturijerten
# ztudijeren                                               ztudijerten
# ztutzen                                                     ztutzten
# ztyrzen                                           ztyrzten  ztyrzten
# ztytzen                                           ztytzten  ztytzten
# zubstituwijeren                                     zubstituwijerten
# zubtrahijeren                                         zubtrahijerten
# zubventijonijeren                                 zubventijonijerten
# zuksen                               zuksten zuksten zuksten zuksten
# zummen                                              zummten  zummten
# zummijeren                       zummijerten zummijerten zummijerten
# zupfen                                                       zupften
# zuppen
# zurfen
# zurren
# zuspendijenijeren  zuspendijenijerten zuspendijenijerten zuspendi...
# zvEngen                                                     zvEngten
# zvangsernEhren
# zvingen                                                     zvingten
# zymbolisijeren                       zymbolisijerten zymbolisijerten
# zynden                                                       zyndten
# zynthetisijeren                    zynthetisijerten zynthetisijerten
# çangijeren                                   çangijerten çangijerten
# çargijeren                                               çargijerten
# çeken                                                  çekten çekten
# çiffrijeren                   çiffrijerten çiffrijerten çiffrijerten
# çloroformijeren                    çloroformijerten çloroformijerten
# çristijanisijeren                                 çristijanisijerten
#
#                                                     PLxPSTxINDxPFVx2  \
# NFIN
#                     atmetet ballastetet   beaksttet  beakstetet b...
# Etzen
# Eçten
# S2pfen                                                       S2pftet
# SEmen
# SEnden
# SErfen
# SEumen
# Saben
# Salten
# Sassen                                                       Sasstet
# Seinen
# Senken
# Serzen                                                       Serztet
# Seuksen                                                    Seukstet
# Sijeben                                                     Sijebtet
# Sijelen                                           Sijeltet Sijeltet
# Sikanijeren                                             Sikanijertet
# Siken
# Simpfen
# Sleifen
# Sleimen                                                     Sleimtet
# Slemmen
# Sleppen                                                     Slepptet
# Slurfen
# Slypfen
# Slyrfen                                                    Slyrftet
# Smauksen
# Smeissen                                                   Smeisstet
# Smeken
# ...                                                              ...
# ztreiçen                                                   ztreiçtet
# ztriken                                                   ztriktet
# ztrukturijeren                       ztrukturijertet ztrukturijertet
# ztudijeren                                               ztudijertet
# ztutzen
# ztyrzen                                   ztyrztet ztyrztet ztyrztet
# ztytzen                                                     ztytztet
# zubstituwijeren                                     zubstituwijertet
# zubtrahijeren                                         zubtrahijertet
# zubventijonijeren                                 zubventijonijertet
# zuksen                                               zukstet zukstet
# zummen
# zummijeren                       zummijertet zummijertet zummijertet
# zupfen
# zuppen                                                       zupptet
# zurfen
# zurren
# zuspendijenijeren  zuspendijenijertet zuspendijenijertet zuspendi...
# zvEngen
# zvangsernEhren
# zvingen
# zymbolisijeren                       zymbolisijertet zymbolisijertet
# zynden
# zynthetisijeren                    zynthetisijertet zynthetisijertet
# çangijeren                                   çangijertet çangijertet
# çargijeren                                               çargijertet
# çeken                                                       çektet
# çiffrijeren                   çiffrijertet çiffrijertet çiffrijertet
# çloroformijeren                    çloroformijertet çloroformijertet
# çristijanisijeren                                 çristijanisijertet
#
#                                                                  PRS  \
# NFIN
#                        beabsiçtigend           beiçtend  bekehren...
# Etzen                                                        Etzend
# Eçten
# S2pfen                                                      S2pfend
# SEmen                                                         SEmend
# SEnden                                                       SEndend
# SErfen                                                       SErfend
# SEumen                                                       SEumend
# Saben
# Salten                                                       Saltend
# Sassen                                              Sassend Sassend
# Seinen
# Senken                                               Senkend Senkend
# Serzen                                                       Serzend
# Seuksen                                            Seuksend Seuksend
# Sijeben                                                     Sijebend
# Sijelen                                                   Sijelend
# Sikanijeren                                             Sikanijerend
# Siken                                                         Sikend
# Simpfen                                                     Simpfend
# Sleifen                                            Sleifend Sleifend
# Sleimen
# Slemmen                                           Slemmend Slemmend
# Sleppen                                                     Sleppend
# Slurfen                                            Slurfend Slurfend
# Slypfen                                                     Slypfend
# Slyrfen                                                     Slyrfend
# Smauksen                                                   Smauksend
# Smeissen                                                   Smeissend
# Smeken                                                       Smekend
# ...                                                              ...
# ztreiçen                                                   ztreiçend
# ztriken                                            ztrikend ztrikend
# ztrukturijeren                       ztrukturijerend ztrukturijerend
# ztudijeren                                               ztudijerend
# ztutzen                                                     ztutzend
# ztyrzen                                           ztyrzend  ztyrzend
# ztytzen                                   ztytzend ztytzend ztytzend
# zubstituwijeren                                     zubstituwijerend
# zubtrahijeren                                         zubtrahijerend
# zubventijonijeren                                 zubventijonijerend
# zuksen                                             zuksend zuksend
# zummen                                                     zummend
# zummijeren                                  zummijerend  zummijerend
# zupfen                                                       zupfend
# zuppen                                                       zuppend
# zurfen                                               zurfend zurfend
# zurren                                                       zurrend
# zuspendijenijeren  zuspendijenijerend zuspendijenijerend zuspendi...
# zvEngen                                                     zvEngend
# zvangsernEhren                       zvangsernEhrend zvangsernEhrend
# zvingen                                                     zvingend
# zymbolisijeren                       zymbolisijerend zymbolisijerend
# zynden
# zynthetisijeren                    zynthetisijerend zynthetisijerend
# çangijeren                                              çangijerend
# çargijeren                                               çargijerend
# çeken                                                         çekend
# çiffrijeren                   çiffrijerend çiffrijerend çiffrijerend
# çloroformijeren                    çloroformijerend çloroformijerend
# çristijanisijeren                                 çristijanisijerend
#
#                                                                  PST  \
# NFIN
#                    antvortet    beabsiçtigt          begnadigt   ...
# Etzen
# Eçten
# S2pfen
# SEmen
# SEnden
# SErfen
# SEumen
# Saben
# Salten
# Sassen
# Seinen
# Senken
# Serzen
# Seuksen
# Sijeben
# Sijelen
# Sikanijeren
# Siken
# Simpfen
# Sleifen
# Sleimen
# Slemmen
# Sleppen
# Slurfen
# Slypfen
# Slyrfen
# Smauksen
# Smeissen
# Smeken
# ...                                                              ...
# ztreiçen
# ztriken
# ztrukturijeren
# ztudijeren
# ztutzen
# ztyrzen
# ztytzen
# zubstituwijeren
# zubtrahijeren
# zubventijonijeren                                   zubventijonijert
# zuksen
# zummen
# zummijeren                                                zummijert
# zupfen
# zuppen
# zurfen
# zurren
# zuspendijenijeren
# zvEngen
# zvangsernEhren
# zvingen
# zymbolisijeren
# zynden
# zynthetisijeren
# çangijeren                                                 çangijert
# çargijeren
# çeken
# çiffrijeren
# çloroformijeren
# çristijanisijeren
#
#                                                         SGxPRSxINDx1  \
# NFIN
#                       ball6  beakst6 beakst6  bearbeit6  befolg6 ...
# Etzen                                                          Etz6
# Eçten
# S2pfen                                                   S2pf6 S2pf6
# SEmen
# SEnden                                                         SEnd6
# SErfen                                                         SErf6
# SEumen                                                         SEum6
# Saben                                                           Sab6
# Salten                                                         Salt6
# Sassen                                             Sass6 Sass6 Sass6
# Seinen                                                         Sein6
# Senken                                                   Senk6 Senk6
# Serzen                                                         Serz6
# Seuksen                                                Seuks6 Seuks6
# Sijeben                                                       Sijeb6
# Sijelen                                               Sijel6 Sijel6
# Sikanijeren                                               Sikanijer6
# Siken                                                 Sik6 Sik6 Sik6
# Simpfen
# Sleifen                                                Sleif6 Sleif6
# Sleimen                                                       Sleim6
# Slemmen                                         Slemm6 Slemm6 Slemm6
# Sleppen                                                       Slepp6
# Slurfen                                                Slurf6 Slurf6
# Slypfen                                                       Slypf6
# Slyrfen                                                Slyrf6 Slyrf6
# Smauksen                                                     Smauks6
# Smeissen                                                     Smeiss6
# Smeken                                                       Smek6
# ...                                                              ...
# ztreiçen                                                     ztreiç6
# ztriken                                         ztrik6 ztrik6 ztrik6
# ztrukturijeren                           ztrukturijer6 ztrukturijer6
# ztudijeren                                                 ztudijer6
# ztutzen                                                       ztutz6
# ztyrzen                                         ztyrz6 ztyrz6 ztyrz6
# ztytzen                                         ztytz6 ztytz6 ztytz6
# zubstituwijeren                                       zubstituwijer6
# zubtrahijeren                                           zubtrahijer6
# zubventijonijeren                                   zubventijonijer6
# zuksen                                       zuks6 zuks6 zuks6 zuks6
# zummen                                                  zumm6 zumm6
# zummijeren                             zummijer6 zummijer6 zummijer6
# zupfen                                                         zupf6
# zuppen                                                         zupp6
# zurfen                                                   zurf6 zurf6
# zurren                                                         zurr6
# zuspendijenijeren  zuspendijenijer6 zuspendijenijer6 zuspendijeni...
# zvEngen                                                       zvEng6
# zvangsernEhren                           zvangsernEhr6 zvangsernEhr6
# zvingen                                                       zving6
# zymbolisijeren                           zymbolisijer6 zymbolisijer6
# zynden
# zynthetisijeren                        zynthetisijer6 zynthetisijer6
# çangijeren                                                çangijer6
# çargijeren                                                 çargijer6
# çeken
# çiffrijeren                         çiffrijer6 çiffrijer6 çiffrijer6
# çloroformijeren                        çloroformijer6 çloroformijer6
# çristijanisijeren                                   çristijanisijer6
#
#                                                         SGxPRSxINDx2  \
# NFIN
#                     atmest ballastest   beakstst    bearbeitest  ...
# Etzen                                                         Etzst
# Eçten                                                         Eçtest
# S2pfen
# SEmen
# SEnden                                                        SEndst
# SErfen                                                        SErfst
# SEumen
# Saben
# Salten
# Sassen                                                Sassst Sassst
# Seinen                                                        Seinst
# Senken                                                 Senkst Senkst
# Serzen                                                        Serzst
# Seuksen
# Sijeben                                                      Sijebst
# Sijelen                                                     Sijelst
# Sikanijeren                                              Sikanijerst
# Siken                                                          Sikst
# Simpfen
# Sleifen                                              Sleifst Sleifst
# Sleimen                                                      Sleimst
# Slemmen                                             Slemmst Slemmst
# Sleppen                                                      Sleppst
# Slurfen                                                     Slurfst
# Slypfen                                                      Slypfst
# Slyrfen                                                     Slyrfst
# Smauksen
# Smeissen                                                    Smeissst
# Smeken
# ...                                                              ...
# ztreiçen                                                    ztreiçst
# ztriken                                      ztrikst ztrikst ztrikst
# ztrukturijeren                         ztrukturijerst ztrukturijerst
# ...
# Smeissen                                                  Smeisstest
# Smeken
# ...                                                              ...
# ztreiçen                                                  ztreiçtest
# ztriken                                ztriktest ztriktest ztriktest
# ztrukturijeren                     ztrukturijertest ztrukturijertest
# ztudijeren                                              ztudijertest
# ztutzen                                                    ztutztest
# ztyrzen                                         ztyrztest  ztyrztest
# ztytzen                                ztytztest ztytztest ztytztest
# zubstituwijeren                                    zubstituwijertest
# zubtrahijeren                                        zubtrahijertest
# zubventijonijeren
# zuksen                           zukstest zukstest zukstest zukstest
# zummen
# zummijeren                                zummijertest  zummijertest
# zupfen                                                      zupftest
# zuppen                                                      zupptest
# zurfen                                                     zurftest
# zurren                                                      zurrtest
# zuspendijenijeren  zuspendijenijertest zuspendijenijertest zuspen...
# zvEngen
# zvangsernEhren                     zvangsernEhrtest zvangsernEhrtest
# zvingen
# zymbolisijeren                     zymbolisijertest zymbolisijertest
# zynden
# zynthetisijeren                  zynthetisijertest zynthetisijertest
# çangijeren                                 çangijertest çangijertest
# çargijeren                                              çargijertest
# çeken                                                        çektest
# çiffrijeren                çiffrijertest çiffrijertest çiffrijertest
# çloroformijeren                  çloroformijertest çloroformijertest
# çristijanisijeren                                çristijanisijertest
#
#                                                                score  \
# NFIN
#                    10.0 6.0 15.0 10.0 6.0 25.8125 5.8125 15.0 14....
# Etzen                                                      36.0 15.0
# Eçten                                                           15.0
# S2pfen                                                     45.0 45.0
# SEmen                                                           10.0
# SEnden                                                         27.75
# SErfen                                                 77.9722222222
# SEumen                                                          21.0
# Saben                                                           15.0
# Salten                                                          15.0
# Sassen                                                45.0 55.0 45.0
# Seinen                                                          21.0
# Senken                                                     36.0 36.0
# Serzen                                                 77.9722222222
# Seuksen                                                    45.0 45.0
# Sijeben                                                87.6166666667
# Sijelen                                               21.0 21.0 15.0
# Sikanijeren                                            119.922222222
# Siken                                                 15.0 21.0 36.0
# Simpfen                                                         10.0
# Sleifen                                                    45.0 45.0
# Sleimen                                                         15.0
# Slemmen                                               28.0 28.0 15.0
# Sleppen                                                         45.0
# Slurfen                                                    36.0 36.0
# Slypfen                                                         36.0
# Slyrfen                                                    21.0 36.0
# Smauksen                                                        28.0
# Smeissen                                                        45.0
# Smeken                                                15.0 10.0 10.0
# ...                                                              ...
# ztreiçen                                                        66.0
# ztriken                                      54.9722222222 55.0 55.0
# ztrukturijeren                           119.922222222 119.522222222
# ztudijeren                                             135.922222222
# ztutzen                                                         36.0
# ztyrzen                             44.8333333333 36.0 44.8333333333
# ztytzen                                               36.0 28.0 36.0
# zubstituwijeren                                        119.522222222
# zubtrahijeren                                          119.922222222
# zubventijonijeren                                      65.9722222222
# zuksen                                           36.0 36.0 45.0 45.0
# zummen                                                27.6 21.0 15.0
# zummijeren                 119.922222222 44.8796296296 119.522222222
# zupfen                                                          45.0
# zuppen                                                 44.5833333333
# zurfen                                                     45.0 45.0
# zurren                                                          45.0
# zuspendijenijeren          119.922222222 119.522222222 119.922222222
# zvEngen                                                         36.0
# zvangsernEhren                                             28.0 28.0
# zvingen                                                         36.0
# zymbolisijeren                           135.922222222 135.497222222
# zynden                                                          21.0
# zynthetisijeren                          135.922222222 135.922222222
# çangijeren                               119.922222222 35.9722222222
# çargijeren                                                     119.7
# çeken                                               21.0 20.875 28.0
# çiffrijeren                119.922222222 119.922222222 119.922222222
# çloroformijeren                                  119.922222222 119.7
# çristijanisijeren                                      135.922222222
#
#                                                               ajouts  \
# NFIN
#                    2 1 3 2 1 5 1 3 3 3 1 2 4 3 1 6 2 5 2 1 3 1 1 ...
# Etzen                                                            7 3
# Eçten                                                              3
# S2pfen                                                           7 7
# SEmen                                                              1
# SEnden                                                             5
# SErfen                                                            10
# SEumen                                                             3
# Saben                                                              3
# Salten                                                             3
# Sassen                                                         7 8 6
# Seinen                                                             4
# Senken                                                           5 6
# Serzen                                                            11
# Seuksen                                                          7 7
# Sijeben                                                           11
# Sijelen                                                        4 4 3
# Sikanijeren                                                       13
# Siken                                                          3 4 6
# Simpfen                                                            2
# Sleifen                                                          7 7
# Sleimen                                                            3
# Slemmen                                                        5 5 3
# Sleppen                                                            8
# Slurfen                                                          6 6
# Slypfen                                                            6
# Slyrfen                                                          4 6
# Smauksen                                                           5
# Smeissen                                                           7
# Smeken                                                         3 2 2
# ...                                                              ...
# ztreiçen                                                           9
# ztriken                                                        8 8 8
# ztrukturijeren                                                 13 13
# ztudijeren                                                        14
# ztutzen                                                            6
# ztyrzen                                                        7 6 7
# ztytzen                                                        6 5 6
# zubstituwijeren                                                   13
# zubtrahijeren                                                     13
# zubventijonijeren                                                  9
# zuksen                                                       6 6 7 7
# zummen                                                         5 4 3
# zummijeren                                                   13 6 13
# zupfen                                                             7
# zuppen                                                             7
# zurfen                                                           7 7
# zurren                                                             7
# zuspendijenijeren                                           13 13 13
# zvEngen                                                            6
# zvangsernEhren                                                   5 5
# zvingen                                                            6
# zymbolisijeren                                                 14 14
# zynden                                                             5
# zynthetisijeren                                                14 14
# çangijeren                                                      13 6
# çargijeren                                                        13
# çeken                                                          5 4 5
# çiffrijeren                                                 13 13 13
# çloroformijeren                                                14 13
# çristijanisijeren                                                 14
#
#                                                            lexicales
# NFIN
#                    PLxPSTxCONDxPFVx2, SGxPSTxINDxPFVx2 PLxPSTxIND...
# Etzen               SGxPRSxINDx1 PLxPSTxCONDxPFVx2, PLxPSTxINDxPFVx1
# Eçten                                             NFIN, SGxPRSxINDx2
# S2pfen             SGxPRSxOPTx2, SGxPSTxINDxPFVx1 NFIN, SGxPSTxCO...
# SEmen                           PLxPRSxINDx2, PLxPSTxCONDxPFVx2, PRS
# SEnden                                            NFIN, SGxPRSxOPTx2
# SErfen                               PLxPRSxINDx2, PLxPSTxCONDxPFVx1
# SEumen                 PLxPRSxOPTx2, PLxPSTxCONDxPFVx2, SGxPRSxINDx1
# Saben                                PLxPRSxINDx2, PLxPSTxCONDxPFVx1
# Salten                                             PRS, SGxPRSxINDx1
# Sassen             PRS, SGxPRSxOPTx2 PLxPSTxINDxPFVx1, SGxPSTxCON...
# Seinen                                            NFIN, SGxPRSxINDx2
# Senken             PLxPSTxINDxPFVx1, PRS, SGxPRSxINDx1 PLxPSTxIND...
# Serzen                                                          NFIN
# Seuksen            PLxPSTxCONDxPFVx1, SGxPRSxINDx1 SGxPRSxOPTx2, ...
# Sijeben                                   PLxPRSxOPTx2, SGxPRSxINDx1
# Sijelen            PRS, SGxPSTxINDxPFVx2 PLxPSTxINDxPFVx1, SGxPRS...
# Sikanijeren                               PLxPRSxOPTx2, SGxPRSxINDx1
# Siken              SGxPRSxINDx1, SGxPSTxCONDxPFVx2 PLxPRSxINDx2, ...
# Simpfen                                       PLxPSTxCONDxPFVx1, PRS
# Sleifen                        NFIN, SGxPRSxOPTx2 NFIN, SGxPRSxINDx2
# Sleimen                          PLxPSTxINDxPFVx2, SGxPSTxCONDxPFVx1
# Slemmen            PLxPSTxCONDxPFVx1, SGxPRSxINDx1 PLxPRSxOPTx2, ...
# Sleppen                                                         NFIN
# Slurfen            PLxPRSxOPTx2, SGxPRSxINDx3 PLxPRSxINDx2, SGxPR...
# Slypfen                               PLxPSTxINDxPFVx1, SGxPRSxINDx1
# Slyrfen                NFIN, PLxPSTxINDxPFVx2 PLxPSTxCONDxPFVx2, PRS
# Smauksen                              PLxPSTxINDxPFVx1, SGxPRSxOPTx2
# Smeissen                                          NFIN, SGxPRSxOPTx2
# Smeken             PLxPSTxCONDxPFVx1, SGxPRSxINDx1 SGxPRSxINDx3, ...
# ...                                                              ...
# ztreiçen                                  SGxPRSxINDx1, SGxPRSxOPTx2
# ztriken            SGxPRSxINDx1, SGxPSTxINDxPFVx1 NFIN, PLxPRSxIN...
# ztrukturijeren     SGxPRSxOPTx2, SGxPSTxCONDxPFVx1 PLxPRSxINDx2, ...
# ztudijeren                            SGxPRSxOPTx2, SGxPSTxINDxPFVx2
# ztutzen                                                    NFIN, PRS
# ztyrzen            PLxPSTxINDxPFVx1, SGxPRSxINDx2 PLxPSTxCONDxPFV...
# ztytzen            NFIN, PRS PLxPSTxCONDxPFVx1, SGxPRSxOPTx2 NFIN...
# zubstituwijeren                       PLxPSTxINDxPFVx2, SGxPRSxINDx2
# zubtrahijeren                                     NFIN, SGxPRSxINDx1
# zubventijonijeren                                  PST, SGxPRSxOPTx2
# zuksen             PLxPRSxOPTx2, PRS PLxPRSxOPTx2, PLxPSTxINDxPFV...
# zummen             SGxPRSxINDx3, SGxPRSxOPTx2 SGxPSTxCONDxPFVx1, ...
# zummijeren         SGxPRSxINDx1, SGxPRSxOPTx2 PLxPRSxOPTx2, PLxPS...
# zupfen                               PLxPRSxOPTx2, SGxPSTxCONDxPFVx1
# zuppen                               PLxPRSxINDx2, PLxPSTxCONDxPFVx1
# zurfen             NFIN, SGxPRSxOPTx2 PLxPRSxOPTx2, PLxPSTxCONDxP...
# zurren                           PLxPSTxCONDxPFVx1, SGxPSTxINDxPFVx1
# zuspendijenijeren  PRS, SGxPRSxINDx1 NFIN, SGxPRSxINDx2 PLxPSTxCO...
# zvEngen                                            PRS, SGxPRSxINDx2
# zvangsernEhren     SGxPRSxOPTx2, SGxPSTxINDxPFVx2 SGxPRSxINDx2, S...
# zvingen                                           NFIN, SGxPRSxOPTx2
# zymbolisijeren         SGxPRSxINDx3, SGxPRSxOPTx2 NFIN, SGxPRSxINDx2
# zynden                                                          NFIN
# zynthetisijeren    SGxPRSxINDx1, SGxPRSxOPTx2 PLxPSTxCONDxPFVx2, ...
# çangijeren          SGxPRSxINDx1, SGxPRSxOPTx2 PST, SGxPSTxINDxPFVx2
# çargijeren                       PLxPSTxCONDxPFVx1, PLxPSTxINDxPFVx1
# çeken              SGxPSTxINDxPFVx1 PLxPSTxINDxPFVx1, SGxPSTxINDx...
# çiffrijeren        PRS, SGxPRSxOPTx2 SGxPRSxINDx3, SGxPSTxINDxPFV...
# çloroformijeren     SGxPRSxINDx1 PLxPSTxINDxPFVx1, SGxPSTxCONDxPFVx2
# çristijanisijeren                         PLxPRSxINDx2, PLxPRSxOPTx2
#
# [1436 rows x 20 columns]

# %%
import codecs
import pandas as pd
import matplotlib.pyplot as plt

# %%
nomLexiqueOrg="/Users/gilles/ownCloud/Python/phonemisation/Lexique380-UTF8.txt"
#nomFlexiqueVerbes="/Users/gilles/Github/flexique/data/vlexique.csv"
Lexique3=pd.read_csv(nomLexiqueOrg,sep="\t")
#vlexique=pd.read_csv(nomFlexiqueVerbes,sep=",",header=None)

# %%
Lexique3.columns#, vlexique.columns
# Out:
# Index([u'1_ortho', u'2_phon', u'3_lemme', u'4_cgram', u'5_genre', u'6_nombre',
#        u'7_freqlemfilms2', u'8_freqlemlivres', u'9_freqfilms2',
#        u'10_freqlivres', u'11_infover', u'12_nbhomogr', u'13_nbhomoph',
#        u'14_islem', u'15_nblettres', u'16_nbphons', u'17_cvcv', u'18_p_cvcv',
#        u'19_voisorth', u'20_voisphon', u'21_puorth', u'22_puphon', u'23_syll',
#        u'24_nbsyll', u'25_cv-cv', u'26_orthrenv', u'27_phonrenv',
#        u'28_orthosyll', u'29_cgramortho', u'30_deflem', u'31_defobs',
#        u'32_old20', u'33_pld20', u'34_morphoder', u'35_nbmorph'],
#       dtype='object')

# %%
lex3=Lexique3[["1_ortho","2_phon","3_lemme","4_cgram","5_genre","6_nombre","7_freqlemfilms2","8_freqlemlivres","9_freqfilms2","10_freqlivres","11_infover"]]

# %% [markdown]
# - extraction des verbes de Lexique3 => *verb3*

# %%
lex3.loc[:,"7_freqlemfilms2"]=lex3["7_freqlemfilms2"].astype(float)
lex3.loc[:,"8_freqlemlivres"]=lex3["8_freqlemlivres"].astype(float)
lex3.loc[:,"9_freqfilms2"]=lex3["9_freqfilms2"].astype(float)
lex3.loc[:,"10_freqlivres"]=lex3["10_freqlivres"].astype(float)

# %%
lex3.rename(columns={'11_infover':'lex3_11_infover'}, inplace=True)

# %%
verb3=lex3[lex3["4_cgram"]=="VER"]

# %% [markdown]
# - élimination des infover mal formés
#  - liste des 412 problèmes
#  - remplacement des infover problématiques par un tag cohérent

# %%
verb3[(verb3["lex3_11_infover"].str.split(";").apply(set).str.len()!=verb3["lex3_11_infover"].str.split(";").str.len())]
# Out:
#             1_ortho   2_phon      3_lemme 4_cgram 5_genre 6_nombre  \
# 481         abriter   abRite      abriter     VER     NaN      NaN
# 659          absous     apsu     absoudre     VER       m      NaN
# 1094    accompagner  ak§paNe  accompagner     VER     NaN      NaN
# 1729         acheté    aS°te      acheter     VER       m        s
# 1864         acquis      aki     acquérir     VER       m      NaN
# 2328        admirer   admiRe      admirer     VER     NaN      NaN
# 2346          admis     admi     admettre     VER       m      NaN
# 2871       afficher    afiSe     afficher     VER     NaN      NaN
# 2970        affirmé   afiRme     affirmer     VER       m        s
# 3040        affoler    afole      affoler     VER     NaN      NaN
# 3116      affronter   afR§te    affronter     VER     NaN      NaN
# 3624       agripper   agRipe     agripper     VER     NaN      NaN
# 3798          aider      ede        aider     VER     NaN      NaN
# 3994           aime       Em        aimer     VER     NaN      NaN
# 3996          aimer      eme        aimer     VER     NaN      NaN
# 4108        ajouter    aZute      ajouter     VER     NaN      NaN
# 4127         ajouté    aZute      ajouter     VER       m        s
# 4534          aller      ale        aller     VER     NaN      NaN
# 4611       allonger    al§Ze     allonger     VER     NaN      NaN
# 5166         amener    am°ne       amener     VER     NaN      NaN
# 5559         amuser    amyze       amuser     VER     NaN      NaN
# 7438        appeler    ap°le      appeler     VER     NaN      NaN
# 7589       apporter   apORte     apporter     VER     NaN      NaN
# 7662         appris     apRi    apprendre     VER       m      NaN
# 7706      approcher   apRoSe    approcher     VER     NaN      NaN
# 8624       arracher    aRaSe     arracher     VER     NaN      NaN
# 8675       arranger    aR@Ze     arranger     VER     NaN      NaN
# 8729        arriver    aRive      arriver     VER     NaN      NaN
# 8755         arrivé    aRive      arriver     VER       m        s
# 8923        arrêter    aRete      arrêter     VER     NaN      NaN
# ...             ...      ...          ...     ...     ...      ...
# 133270    témoigner  temwaNe    témoigner     VER     NaN      NaN
# 133854     utiliser  ytilize     utiliser     VER     NaN      NaN
# 134709       vendre     v@dR       vendre     VER     NaN      NaN
# 135084       verser    vERse       verser     VER     NaN      NaN
# 135252        vexer    vEkse        vexer     VER     NaN      NaN
# 135510     vieillis    vjeji     vieillir     VER       m        p
# 135762       violer    vjole       violer     VER     NaN      NaN
# 135915         viré     viRe        virer     VER       m        s
# 136347         voir     vwaR         voir     VER     NaN      NaN
# 136673        vouer      vwe        vouer     VER     NaN      NaN
# 138102      écarter   ekaRte      écarter     VER     NaN      NaN
# 138487     éclairer   ekleRe     éclairer     VER     NaN      NaN
# 138530      éclater   eklate      éclater     VER     NaN      NaN
# 138852      écouter    ekute      écouter     VER     NaN      NaN
# 139387      égorger   egORZe      égorger     VER     NaN      NaN
# 139739       élever    El°ve       élever     VER     NaN      NaN
# 139854     éloigner   elwaNe     éloigner     VER     NaN      NaN
# 140209         émis      emi      émettre     VER       m      NaN
# 140544     épargner   epaRNe     épargner     VER     NaN      NaN
# 140806       épiler    epile       épiler     VER     NaN      NaN
# 141013      épouser    epuze      épouser     VER     NaN      NaN
# 141104        épris     epRi     éprendre     VER       m      NaN
# 141687      étendre    et@dR      étendre     VER     NaN      NaN
# 141942     étouffer    etufe     étouffer     VER     NaN      NaN
# 142026    étrangler  etR@gle    étrangler     VER     NaN      NaN
# 142070    étreindre   etR5dR    étreindre     VER     NaN      NaN
# 142532    éviscérer  eviseRe    éviscérer     VER     NaN      NaN
# 142546       éviter    evite       éviter     VER     NaN      NaN
# 142654         être      EtR         être     VER     NaN      NaN
# 142672         ôter      ote         ôter     VER     NaN      NaN
#
#         7_freqlemfilms2  8_freqlemlivres  9_freqfilms2  10_freqlivres  \
# 481                7.92            26.22          2.37           6.96
# 659                2.66             3.72          1.15           1.08
# 1094              90.56           124.46         24.87          22.23
# 1729             290.70           148.38         72.38          28.72
# 1864               8.30            29.66          3.52          13.65
# 2328              32.39            68.18          6.50          17.64
# 2346              50.05            59.46          6.74          11.35
# 2871               8.35            19.26          2.06           3.78
# 2970              15.61            63.51          1.66           4.59
# 3040               5.92            20.54          1.00           2.50
# 3116              30.72            22.43         19.57          13.38
# 3624               2.81            17.57          0.44           1.28
# 3798             688.71           158.65        362.77          60.41
# 3994            1655.07           795.61        751.29         257.57
# 3996            1655.07           795.61         90.44          84.46
# 4108              38.88           224.66         15.45          33.85
# 4127              38.88           224.66          4.42          18.99
# 4534            9992.77          2854.93        816.76         368.04
# 4611              41.05            89.66          9.96          12.16
# 5166             190.32            93.92         35.60          18.18
# 5559             141.41           120.95         43.77          25.34
# 7438            1165.48           465.34        192.69          63.92
# 7589             209.91           159.32         34.43          29.53
# 7662             348.47           286.69        120.98          97.70
# 7706             117.65           196.15         19.62          35.27
# 8624              54.19           113.38         17.20          34.32
# 8675             116.14            75.81         48.51          18.45
# 8729            1252.42           723.04        182.88          95.00
# 8755            1252.42           723.04        203.06          97.91
# 8923             993.79           462.50        178.62          80.61
# ...                 ...              ...           ...            ...
# 133270            24.29            25.68         13.36           7.64
# 133854           182.44            43.51         61.97          15.61
# 134709           206.95            92.64         73.62          30.81
# 135084            31.20            53.99          4.62           9.86
# 135252            15.56            11.76          4.30           2.57
# 135510            20.47            32.23          2.74           1.89
# 135762            39.43            19.19          8.36           4.93
# 135915            86.30            37.84         25.59           6.28
# 136347          4119.43          2401.76       1401.10         716.55
# 136673             6.88            18.92          0.42           2.43
# 138102            24.83            92.36          4.77          16.89
# 138487            18.03            85.95          5.91          12.97
# 138530            41.33           100.47         15.52          19.59
# 138852           470.93           314.05         73.13          56.15
# 139387             9.04             9.66          2.96           2.84
# 139739            52.03           103.85         15.57          20.20
# 139854            41.15           133.11         14.51          28.45
# 140209             9.45            17.23          1.57           2.30
# 140544            26.39            25.95          6.90           7.64
# 140806             2.04             2.77          1.13           1.22
# 141013           118.78            59.26         57.87          20.20
# 141104             2.95             5.95          1.56           3.04
# 141687            21.90           111.89          5.87          19.59
# 141942            28.50            59.46          7.45          12.30
# 142026            18.53            22.09          6.87           6.49
# 142070             3.05            16.96          0.69           2.97
# 142532             0.50             0.14          0.26           0.00
# 142546            87.47           110.47         53.71          60.07
# 142654         32236.50         15085.47       1111.69         505.61
# 142672            16.81            42.03          5.57          10.00
#
#                                           lex3_11_infover
# 481                                       inf;;inf;;inf;;
# 659        imp:pre:2s;ind:pre:1s;par:pas;par:pas;par:pas;
# 1094                                                inf;;
# 1729                             par:pas;par:pas;par:pas;
# 1864                          ind:pas:1s;par:pas;par:pas;
# 2328                                                inf;;
# 2346                          ind:pas:1s;par:pas;par:pas;
# 2871                                                inf;;
# 2970                          imp:pre:2s;par:pas;par:pas;
# 3040                                                inf;;
# 3116                                                inf;;
# 3624                                                inf;;
# 3798                                 inf;;inf;;inf;;inf;;
# 3994    imp:pre:2s;ind:pre:1s;ind:pre:1s;ind:pre:3s;su...
# 3996                  inf;;inf;;inf;;inf;;inf;;inf;;inf;;
# 4108                                                inf;;
# 4127                          imp:pre:2s;par:pas;par:pas;
# 4534                                      inf;;inf;;inf;;
# 4611                                                inf;;
# 5166                                                inf;;
# 5559                                      inf;;inf;;inf;;
# 7438                                 inf;;inf;;inf;;inf;;
# 7589                                 inf;;inf;;inf;;inf;;
# 7662               ind:pas:1s;ind:pas:2s;par:pas;par:pas;
# 7706                                                inf;;
# 8624                                                inf;;
# 8675                                                inf;;
# 8729                                      inf;;inf;;inf;;
# 8755                             par:pas;par:pas;par:pas;
# 8923                                 inf;;inf;;inf;;inf;;
# ...                                                   ...
# 133270                                              inf;;
# 133854                                              inf;;
# 134709                                              inf;;
# 135084                                              inf;;
# 135252                                              inf;;
# 135510  imp:pre:2s;ind:pre:1s;ind:pre:2s;par:pas;par:pas;
# 135762                                              inf;;
# 135915                           par:pas;par:pas;par:pas;
# 136347                                              inf;;
# 136673                                    inf;;inf;;inf;;
# 138102                                              inf;;
# 138487                                    inf;;inf;;inf;;
# 138530                                              inf;;
# 138852                                              inf;;
# 139387                                              inf;;
# 139739                                              inf;;
# 139854                                              inf;;
# 140209             ind:pas:1s;ind:pas:2s;par:pas;par:pas;
# 140544                                              inf;;
# 140806                                              inf;;
# 141013                                              inf;;
# 141104             ind:pas:1s;ind:pas:2s;par:pas;par:pas;
# 141687                                              inf;;
# 141942                                              inf;;
# 142026                                              inf;;
# 142070                                              inf;;
# 142532                                              inf;;
# 142546                                              inf;;
# 142654                                    inf;;inf;;inf;;
# 142672                                              inf;;
#
# [412 rows x 11 columns]

# %% [markdown]
# ### Supprimer les tags incorrects
# - imp:pre:3s n'existe pas en français

# %%
verb3["lex3_11_infover"]=verb3["lex3_11_infover"].str.replace("imp:pre:3s;","")
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
verb3[verb3["lex3_11_infover"].str.contains("imp:pre:3s")]
# Out:
# Empty DataFrame
# Columns: [1_ortho, 2_phon, 3_lemme, 4_cgram, 5_genre, 6_nombre, 7_freqlemfilms2, 8_freqlemlivres, 9_freqfilms2, 10_freqlivres, lex3_11_infover]
# Index: []

# %% [markdown]
# ### réparer les infover
# 1. effacer les ; finaux
# 1. couper sur les ;
# 1. éliminer les doublons
# 1. trier la liste
# 1. assembler la liste et ajouter un ; final
# 1. créer la colonne 11_infover corrigée

# %%
verb3.loc[:,"11_infover"]=verb3["lex3_11_infover"].str.strip(";").str.split(";").apply(set).apply(list).apply(sorted).str.join(";").str.strip(";")+";"

# %%
verb3
# Out:
#               1_ortho   2_phon     3_lemme 4_cgram 5_genre 6_nombre  \
# 2                   a        a       avoir     VER     NaN      NaN
# 18            abaissa    abEsa    abaisser     VER     NaN      NaN
# 19           abaissai    abEsE    abaisser     VER     NaN      NaN
# 20        abaissaient    abEsE    abaisser     VER     NaN      NaN
# 21          abaissait    abEsE    abaisser     VER     NaN      NaN
# 23          abaissant    abEs@    abaisser     VER     NaN      NaN
# 26            abaisse     abEs    abaisser     VER     NaN      NaN
# 29          abaissent     abEs    abaisser     VER     NaN      NaN
# 30           abaisser    abese    abaisser     VER     NaN      NaN
# 31          abaissera  abEs°Ra    abaisser     VER     NaN      NaN
# 32         abaisserai  abEs°RE    abaisser     VER     NaN      NaN
# 33      abaisseraient  abEs°RE    abaisser     VER     NaN      NaN
# 34        abaisserais  abEs°RE    abaisser     VER     NaN      NaN
# 35        abaisserait  abEs°RE    abaisser     VER     NaN      NaN
# 36           abaisses     abEs    abaisser     VER     NaN      NaN
# 37           abaissez    abEse    abaisser     VER     NaN      NaN
# 38          abaissons    abEs§    abaisser     VER     NaN      NaN
# 39        abaissèrent   abEsER    abaisser     VER     NaN      NaN
# 40            abaissé    abese    abaisser     VER       m        s
# 42           abaissée    abese    abaisser     VER       f        s
# 44          abaissées    abese    abaisser     VER       f        p
# 46           abaissés    abese    abaisser     VER       m        p
# 51          abandonna  ab@dona  abandonner     VER     NaN      NaN
# 52         abandonnai  ab@donE  abandonner     VER     NaN      NaN
# 53      abandonnaient  ab@donE  abandonner     VER     NaN      NaN
# 54        abandonnais  ab@donE  abandonner     VER     NaN      NaN
# 55        abandonnait  ab@donE  abandonner     VER     NaN      NaN
# 56        abandonnant  ab@don@  abandonner     VER     NaN      NaN
# 57         abandonnas  ab@dona  abandonner     VER     NaN      NaN
# 58          abandonne   ab@dOn  abandonner     VER     NaN      NaN
# ...               ...      ...         ...     ...     ...      ...
# 142635       évoquées    evoke     évoquer     VER       f        p
# 142636        évoqués    evoke     évoquer     VER       m        p
# 142651           êtes       Et        être     VER     NaN      NaN
# 142654           être      EtR        être     VER     NaN      NaN
# 142664            ôta      ota        ôter     VER     NaN      NaN
# 142665           ôtai      otE        ôter     VER     NaN      NaN
# 142666        ôtaient      otE        ôter     VER     NaN      NaN
# 142667          ôtais      otE        ôter     VER     NaN      NaN
# 142668          ôtait      otE        ôter     VER     NaN      NaN
# 142669          ôtant      ot@        ôter     VER     NaN      NaN
# 142670            ôte       ot        ôter     VER     NaN      NaN
# 142671          ôtent       ot        ôter     VER     NaN      NaN
# 142672           ôter      ote        ôter     VER     NaN      NaN
# 142673          ôtera    ot°Ra        ôter     VER     NaN      NaN
# 142674         ôterai    ot°RE        ôter     VER     NaN      NaN
# 142675        ôterais    ot°RE        ôter     VER     NaN      NaN
# 142676        ôterait    ot°RE        ôter     VER     NaN      NaN
# 142677         ôteras    ot°Ra        ôter     VER     NaN      NaN
# 142678         ôterez    ot°Re        ôter     VER     NaN      NaN
# 142679       ôterions   ot°Rj§        ôter     VER     NaN      NaN
# 142680           ôtes       ot        ôter     VER     NaN      NaN
# 142681           ôtez      ote        ôter     VER     NaN      NaN
# 142682          ôtiez     otje        ôter     VER     NaN      NaN
# 142683          ôtons      ot§        ôter     VER     NaN      NaN
# 142684           ôtât      ota        ôter     VER     NaN      NaN
# 142685        ôtèrent     otER        ôter     VER     NaN      NaN
# 142686            ôté      ote        ôter     VER       m        s
# 142688           ôtée      ote        ôter     VER       f        s
# 142690          ôtées      ote        ôter     VER       f        p
# 142692           ôtés      ote        ôter     VER       m        p
#
#         7_freqlemfilms2  8_freqlemlivres  9_freqfilms2  10_freqlivres  \
# 2              13572.40          6426.49       5498.34        1669.39
# 18                 4.93            18.04          0.00           2.64
# 19                 4.93            18.04          0.10           0.07
# 20                 4.93            18.04          0.00           0.41
# 21                 4.93            18.04          0.02           2.50
# 23                 4.93            18.04          0.01           2.50
# 26                 4.93            18.04          1.28           3.45
# 29                 4.93            18.04          0.05           0.95
# 30                 4.93            18.04          1.09           2.91
# 31                 4.93            18.04          0.19           0.07
# 32                 4.93            18.04          0.10           0.07
# 33                 4.93            18.04          0.01           0.07
# 34                 4.93            18.04          0.13           0.00
# 35                 4.93            18.04          0.02           0.20
# 36                 4.93            18.04          0.16           0.07
# 37                 4.93            18.04          0.53           0.07
# 38                 4.93            18.04          0.02           0.00
# 39                 4.93            18.04          0.00           0.41
# 40                 4.93            18.04          0.74           1.35
# 42                 4.93            18.04          0.17           0.27
# 44                 4.93            18.04          0.01           0.00
# 46                 4.93            18.04          0.30           0.07
# 51               110.87           128.45          0.59           8.92
# 52               110.87           128.45          0.27           2.16
# 53               110.87           128.45          0.07           1.55
# 54               110.87           128.45          0.35           1.49
# 55               110.87           128.45          1.04           9.46
# 56               110.87           128.45          1.15           9.93
# 57               110.87           128.45          0.00           0.14
# 58               110.87           128.45         24.04          15.54
# ...                 ...              ...           ...            ...
# 142635            11.57            73.51          0.03           0.41
# 142636            11.57            73.51          0.06           1.28
# 142651         32236.50         15085.47       1002.88         195.54
# 142654         32236.50         15085.47       1111.69         505.61
# 142664            16.81            42.03          0.46           8.04
# 142665            16.81            42.03          0.00           0.68
# 142666            16.81            42.03          0.01           1.08
# 142667            16.81            42.03          0.03           0.68
# 142668            16.81            42.03          0.16           4.53
# 142669            16.81            42.03          0.43           2.50
# 142670            16.81            42.03          3.05           5.27
# 142671            16.81            42.03          0.29           0.41
# 142672            16.81            42.03          5.57          10.00
# 142673            16.81            42.03          0.26           0.34
# 142674            16.81            42.03          0.09           0.07
# 142675            16.81            42.03          0.14           0.00
# 142676            16.81            42.03          0.03           0.54
# 142677            16.81            42.03          0.17           0.14
# 142678            16.81            42.03          0.17           0.20
# 142679            16.81            42.03          0.00           0.07
# 142680            16.81            42.03          0.65           0.00
# 142681            16.81            42.03          1.30           0.81
# 142682            16.81            42.03          0.17           0.00
# 142683            16.81            42.03          0.02           0.07
# 142684            16.81            42.03          0.00           0.14
# 142685            16.81            42.03          0.00           0.27
# 142686            16.81            42.03          3.18           5.47
# 142688            16.81            42.03          0.42           0.54
# 142690            16.81            42.03          0.16           0.07
# 142692            16.81            42.03          0.04           0.14
#
#                                      lex3_11_infover  \
# 2                                        ind:pre:3s;
# 18                                       ind:pas:3s;
# 19                                       ind:pas:1s;
# 20                                       ind:imp:3p;
# 21                                       ind:imp:3s;
# 23                                          par:pre;
# 26                 imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 29                                       ind:pre:3p;
# 30                                              inf;
# 31                                       ind:fut:3s;
# 32                                       ind:fut:1s;
# 33                                       cnd:pre:3p;
# 34                            cnd:pre:1s;cnd:pre:2s;
# 35                                       cnd:pre:3s;
# 36                                       ind:pre:2s;
# 37                            imp:pre:2p;ind:pre:2p;
# 38                                       imp:pre:1p;
# 39                                       ind:pas:3p;
# 40                                          par:pas;
# 42                                          par:pas;
# 44                                          par:pas;
# 46                                          par:pas;
# 51                                       ind:pas:3s;
# 52                                       ind:pas:1s;
# 53                                       ind:imp:3p;
# 54                            ind:imp:1s;ind:imp:2s;
# 55                                       ind:imp:3s;
# 56                                          par:pre;
# 57                                       ind:pas:2s;
# 58      imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;
# ...                                              ...
# 142635                                      par:pas;
# 142636                                      par:pas;
# 142651                        imp:pre:2p;ind:pre:2p;
# 142654                               inf;;inf;;inf;;
# 142664                                   ind:pas:3s;
# 142665                                   ind:pas:1s;
# 142666                                   ind:imp:3p;
# 142667                        ind:imp:1s;ind:imp:2s;
# 142668                                   ind:imp:3s;
# 142669                                      par:pre;
# 142670             imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 142671                                   ind:pre:3p;
# 142672                                         inf;;
# 142673                                   ind:fut:3s;
# 142674                                   ind:fut:1s;
# 142675                        cnd:pre:1s;cnd:pre:2s;
# 142676                                   cnd:pre:3s;
# 142677                                   ind:fut:2s;
# 142678                                   ind:fut:2p;
# 142679                                   cnd:pre:1p;
# 142680                                   ind:pre:2s;
# 142681                        imp:pre:2p;ind:pre:2p;
# 142682                                   ind:imp:2p;
# 142683                                   ind:pre:1p;
# 142684                                   sub:imp:3s;
# 142685                                   ind:pas:3p;
# 142686                                      par:pas;
# 142688                                      par:pas;
# 142690                                      par:pas;
# 142692                                      par:pas;
#
#                                           11_infover
# 2                                        ind:pre:3s;
# 18                                       ind:pas:3s;
# 19                                       ind:pas:1s;
# 20                                       ind:imp:3p;
# 21                                       ind:imp:3s;
# 23                                          par:pre;
# 26                 imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 29                                       ind:pre:3p;
# 30                                              inf;
# 31                                       ind:fut:3s;
# 32                                       ind:fut:1s;
# 33                                       cnd:pre:3p;
# 34                            cnd:pre:1s;cnd:pre:2s;
# 35                                       cnd:pre:3s;
# 36                                       ind:pre:2s;
# 37                            imp:pre:2p;ind:pre:2p;
# 38                                       imp:pre:1p;
# 39                                       ind:pas:3p;
# 40                                          par:pas;
# 42                                          par:pas;
# 44                                          par:pas;
# 46                                          par:pas;
# 51                                       ind:pas:3s;
# 52                                       ind:pas:1s;
# 53                                       ind:imp:3p;
# 54                            ind:imp:1s;ind:imp:2s;
# 55                                       ind:imp:3s;
# 56                                          par:pre;
# 57                                       ind:pas:2s;
# 58      imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;
# ...                                              ...
# 142635                                      par:pas;
# 142636                                      par:pas;
# 142651                        imp:pre:2p;ind:pre:2p;
# 142654                                          inf;
# 142664                                   ind:pas:3s;
# 142665                                   ind:pas:1s;
# 142666                                   ind:imp:3p;
# 142667                        ind:imp:1s;ind:imp:2s;
# 142668                                   ind:imp:3s;
# 142669                                      par:pre;
# 142670             imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 142671                                   ind:pre:3p;
# 142672                                          inf;
# 142673                                   ind:fut:3s;
# 142674                                   ind:fut:1s;
# 142675                        cnd:pre:1s;cnd:pre:2s;
# 142676                                   cnd:pre:3s;
# 142677                                   ind:fut:2s;
# 142678                                   ind:fut:2p;
# 142679                                   cnd:pre:1p;
# 142680                                   ind:pre:2s;
# 142681                        imp:pre:2p;ind:pre:2p;
# 142682                                   ind:imp:2p;
# 142683                                   ind:pre:1p;
# 142684                                   sub:imp:3s;
# 142685                                   ind:pas:3p;
# 142686                                      par:pas;
# 142688                                      par:pas;
# 142690                                      par:pas;
# 142692                                      par:pas;
#
# [64929 rows x 12 columns]

# %%
verb3[verb3["3_lemme"]=="aimer"]
# Out:
#          1_ortho  2_phon 3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 3967        aima     Ema   aimer     VER     NaN      NaN          1655.07
# 3971       aimai     EmE   aimer     VER     NaN      NaN          1655.07
# 3972    aimaient     EmE   aimer     VER     NaN      NaN          1655.07
# 3973      aimais     EmE   aimer     VER     NaN      NaN          1655.07
# 3974      aimait     EmE   aimer     VER     NaN      NaN          1655.07
# 3977      aimant     Em@   aimer     VER     NaN      NaN          1655.07
# 3991     aimasse    Emas   aimer     VER     NaN      NaN          1655.07
# 3992   aimassent    Emas   aimer     VER     NaN      NaN          1655.07
# 3993  aimassions  Emasj§   aimer     VER     NaN      NaN          1655.07
# 3994        aime      Em   aimer     VER     NaN      NaN          1655.07
# 3995      aiment      Em   aimer     VER     NaN      NaN          1655.07
# 3996       aimer     eme   aimer     VER     NaN      NaN          1655.07
# 3997      aimera   Em°Ra   aimer     VER     NaN      NaN          1655.07
# 3998     aimerai   Em°RE   aimer     VER     NaN      NaN          1655.07
# 3999  aimeraient   Em°RE   aimer     VER     NaN      NaN          1655.07
# 4000    aimerais   Em°RE   aimer     VER     NaN      NaN          1655.07
# 4001    aimerait   Em°RE   aimer     VER     NaN      NaN          1655.07
# 4002     aimeras   Em°Ra   aimer     VER     NaN      NaN          1655.07
# 4003     aimerez   Em°Re   aimer     VER     NaN      NaN          1655.07
# 4004    aimeriez  Em°Rje   aimer     VER     NaN      NaN          1655.07
# 4005   aimerions  Em°Rj§   aimer     VER     NaN      NaN          1655.07
# 4006    aimerons   Em°R§   aimer     VER     NaN      NaN          1655.07
# 4007    aimeront   Em°R§   aimer     VER     NaN      NaN          1655.07
# 4008       aimes      Em   aimer     VER     NaN      NaN          1655.07
# 4010       aimez     Eme   aimer     VER     NaN      NaN          1655.07
# 4011      aimiez    Emje   aimer     VER     NaN      NaN          1655.07
# 4012     aimions    Emj§   aimer     VER     NaN      NaN          1655.07
# 4013      aimons     Em§   aimer     VER     NaN      NaN          1655.07
# 4014     aimâmes    Emam   aimer     VER     NaN      NaN          1655.07
# 4015       aimât     Ema   aimer     VER     NaN      NaN          1655.07
# 4016     aimâtes    Emat   aimer     VER     NaN      NaN          1655.07
# 4017    aimèrent    EmER   aimer     VER     NaN      NaN          1655.07
# 4018        aimé     eme   aimer     VER       m        s          1655.07
# 4020       aimée     eme   aimer     VER       f        s          1655.07
# 4022      aimées     eme   aimer     VER       f        p          1655.07
# 4024       aimés     eme   aimer     VER       m        p          1655.07
#
#       8_freqlemlivres  9_freqfilms2  10_freqlivres  \
# 3967           795.61          0.41           1.69
# 3971           795.61          0.20           0.81
# 3972           795.61          6.20          16.42
# 3973           795.61         58.07          57.16
# 3974           795.61         49.57         128.72
# 3977           795.61          2.60           3.92
# 3991           795.61          0.02           0.00
# 3992           795.61          0.00           0.20
# 3993           795.61          0.00           0.07
# 3994           795.61        751.29         257.57
# 3995           795.61         48.46          26.96
# 3996           795.61         90.44          84.46
# 3997           795.61          8.10           2.57
# 3998           795.61         13.99           2.97
# 3999           795.61          5.08           2.03
# 4000           795.61        227.66          36.01
# 4001           795.61         21.70          12.43
# 4002           795.61          4.30           1.28
# 4003           795.61          2.71           1.01
# 4004           795.61          8.88           0.88
# 4005           795.61          7.21           1.01
# 4006           795.61          0.46           0.27
# 4007           795.61          1.32           0.34
# 4008           795.61        170.38          25.61
# 4010           795.61         62.25          18.38
# 4011           795.61          6.92           2.64
# 4012           795.61          2.03           6.55
# 4013           795.61         11.58           6.22
# 4014           795.61          0.00           0.14
# 4015           795.61          0.10           2.03
# 4016           795.61          0.03           0.00
# 4017           795.61          0.16           0.47
# 4018           795.61         75.92          71.96
# 4020           795.61         12.66          14.80
# 4022           795.61          0.43           1.62
# 4024           795.61          3.94           6.42
#
#                                         lex3_11_infover  \
# 3967                                        ind:pas:3s;
# 3971                                        ind:pas:1s;
# 3972                                        ind:imp:3p;
# 3973                             ind:imp:1s;ind:imp:2s;
# 3974                                        ind:imp:3s;
# 3977                                           par:pre;
# 3991                                        sub:imp:1s;
# 3992                                        sub:imp:3p;
# 3993                                        sub:imp:1p;
# 3994  imp:pre:2s;ind:pre:1s;ind:pre:1s;ind:pre:3s;su...
# 3995                             ind:pre:3p;sub:pre:3p;
# 3996                inf;;inf;;inf;;inf;;inf;;inf;;inf;;
# 3997                                        ind:fut:3s;
# 3998                                        ind:fut:1s;
# 3999                                        cnd:pre:3p;
# 4000                             cnd:pre:1s;cnd:pre:2s;
# 4001                                        cnd:pre:3s;
# 4002                                        ind:fut:2s;
# 4003                                        ind:fut:2p;
# 4004                                        cnd:pre:2p;
# 4005                                        cnd:pre:1p;
# 4006                                        ind:fut:1p;
# 4007                                        ind:fut:3p;
# 4008                             ind:pre:2s;sub:pre:2s;
# 4010                             imp:pre:2p;ind:pre:2p;
# 4011                             ind:imp:2p;sub:pre:2p;
# 4012                             ind:imp:1p;sub:pre:1p;
# 4013                             imp:pre:1p;ind:pre:1p;
# 4014                                        ind:pas:1p;
# 4015                                        sub:imp:3s;
# 4016                                        ind:pas:2p;
# 4017                                        ind:pas:3p;
# 4018                                           par:pas;
# 4020                                           par:pas;
# 4022                                           par:pas;
# 4024                                           par:pas;
#
#                                              11_infover
# 3967                                        ind:pas:3s;
# 3971                                        ind:pas:1s;
# 3972                                        ind:imp:3p;
# 3973                             ind:imp:1s;ind:imp:2s;
# 3974                                        ind:imp:3s;
# 3977                                           par:pre;
# 3991                                        sub:imp:1s;
# 3992                                        sub:imp:3p;
# 3993                                        sub:imp:1p;
# 3994  imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:1s;su...
# 3995                             ind:pre:3p;sub:pre:3p;
# 3996                                               inf;
# 3997                                        ind:fut:3s;
# 3998                                        ind:fut:1s;
# 3999                                        cnd:pre:3p;
# 4000                             cnd:pre:1s;cnd:pre:2s;
# 4001                                        cnd:pre:3s;
# 4002                                        ind:fut:2s;
# 4003                                        ind:fut:2p;
# 4004                                        cnd:pre:2p;
# 4005                                        cnd:pre:1p;
# 4006                                        ind:fut:1p;
# 4007                                        ind:fut:3p;
# 4008                             ind:pre:2s;sub:pre:2s;
# 4010                             imp:pre:2p;ind:pre:2p;
# 4011                             ind:imp:2p;sub:pre:2p;
# 4012                             ind:imp:1p;sub:pre:1p;
# 4013                             imp:pre:1p;ind:pre:1p;
# 4014                                        ind:pas:1p;
# 4015                                        sub:imp:3s;
# 4016                                        ind:pas:2p;
# 4017                                        ind:pas:3p;
# 4018                                           par:pas;
# 4020                                           par:pas;
# 4022                                           par:pas;
# 4024                                           par:pas;

# %%
verb3.groupby("11_infover")[["11_infover"]].count()
# Out:
#                                                     11_infover
# 11_infover
# cnd:pre:1p;                                                242
# cnd:pre:1s;                                                388
# cnd:pre:1s;cnd:pre:2s;                                     567
# cnd:pre:2p;                                                351
# cnd:pre:2s;                                                 54
# cnd:pre:3p;                                                931
# cnd:pre:3s;                                               1683
# imp:pre:1p;                                                233
# imp:pre:1p;ind:imp:1p;ind:pre:1p;                            1
# imp:pre:1p;ind:pre:1p;                                     954
# imp:pre:1p;ind:pre:1p;inf;                                   1
# imp:pre:1p;ind:pre:1p;sub:pre:2s;                            1
# imp:pre:1p;sub:pre:1p;                                       2
# imp:pre:2p;                                                356
# imp:pre:2p;ind:imp:3s;inf;                                   1
# imp:pre:2p;ind:pre:2p;                                    1680
# imp:pre:2p;ind:pre:2p;inf;                                   3
# imp:pre:2p;ind:pre:2p;par:pas;                               4
# imp:pre:2p;inf;                                             10
# imp:pre:2p;sub:pre:2p;                                       2
# imp:pre:2s;                                                 45
# imp:pre:2s;ind:imp:1s;ind:imp:2s;                            1
# imp:pre:2s;ind:pas:1s;ind:pre:1s;ind:pre:2s;                 1
# imp:pre:2s;ind:pas:1s;ind:pre:1s;ind:pre:2s;par...           2
# imp:pre:2s;ind:pas:2s;ind:pre:1s;ind:pre:2s;par...           1
# imp:pre:2s;ind:pas:2s;ind:pre:2s;par:pas;                    1
# imp:pre:2s;ind:pre:1s;                                      40
# imp:pre:2s;ind:pre:1s;ind:pre:2s;                          181
# imp:pre:2s;ind:pre:1s;ind:pre:2s;inf;                        2
# imp:pre:2s;ind:pre:1s;ind:pre:2s;par:pas;                   91
# ...                                                        ...
# ind:pre:2s;sub:pre:1p;sub:pre:2s;                            2
# ind:pre:2s;sub:pre:2s;                                     279
# ind:pre:3p;                                               3066
# ind:pre:3p;sub:imp:3p;                                       2
# ind:pre:3p;sub:pre:3p;                                      97
# ind:pre:3s;                                               1088
# ind:pre:3s;par:pas;                                         82
# ind:pre:3s;sub:pre:1s;                                       1
# ind:pre:3s;sub:pre:3s;                                      10
# inf;                                                      5219
# inf;par:pas;                                                 1
# par:pas;                                                 13949
# par:pas;sub:pre:1s;sub:pre:3s;                               4
# par:pas;sub:pre:2s;                                          3
# par:pas;sub:pre:3s;                                          1
# par:pre;                                                  3370
# sub:imp:1p;                                                 12
# sub:imp:1s;                                                 84
# sub:imp:1s;sub:pre:3s;                                       2
# sub:imp:2p;                                                  7
# sub:imp:2s;                                                 14
# sub:imp:3p;                                                148
# sub:imp:3s;                                                925
# sub:pre:1p;                                                 12
# sub:pre:1s;                                                 15
# sub:pre:1s;sub:pre:3s;                                     241
# sub:pre:2p;                                                  7
# sub:pre:2s;                                                207
# sub:pre:3p;                                                 13
# sub:pre:3s;                                                 93
#
# [130 rows x 1 columns]

# %% [markdown]
# # Calculs pour Caveats with Entropy

# %% [markdown]
# ## Préparations des données
# - flemme regroupe toutes les cases d'un même lemme

# %%
flemme=verb3.groupby(by="3_lemme")[["11_infover"]].sum()

# %% [markdown]
# - calcul du nombre de cases par lemme

# %%
flemme["11_infover"].str.split(";").apply(set).str.len().sort_values()[-20:]
# Out:
# 3_lemme
# sentir       43
# partir       43
# mettre       43
# dire         43
# chercher     43
# prendre      43
# connaître    44
# trouver      44
# croire       44
# vouloir      44
# donner       44
# pouvoir      44
# passer       44
# parler       44
# savoir       45
# devoir       46
# aimer        46
# faire        48
# avoir        48
# être         49
# Name: 11_infover, dtype: int64

# %%
print len(flemme[flemme.index=="essayer"]["11_infover"].str.split(";").apply(set).values[0])
# Out:
# 38

# %% [markdown]
# - ajout du genre et du nombre sur les cases du participe passé

# %%
def infoVer(row):
    genreNombre=""
    if isinstance(row["11_infover"],str):
        if isinstance(row["5_genre"],str):
            genreNombre+=row["5_genre"]
        if isinstance(row["6_nombre"],str):
            genreNombre+=row["6_nombre"]        
        return row["11_infover"].replace("par:pas","par:pas:"+genreNombre)
    else:
        return row["11_infover"]

# %%
verb3.loc[:,"infover"]=verb3.apply(lambda x: infoVer(x),axis=1)

# %%
verb3[(verb3["11_infover"].str.contains("par:pas")) & (verb3["3_lemme"]=="mettre")]
# Out:
#       1_ortho 2_phon 3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 82937     mis     mi  mettre     VER       m      NaN          1004.83
# 82953    mise    miz  mettre     VER       f        s          1004.83
# 82965   mises    miz  mettre     VER       f        p          1004.83
#
#        8_freqlemlivres  9_freqfilms2  10_freqlivres  \
# 82937          1083.72        228.57         245.68
# 82953          1083.72         35.33          46.69
# 82965          1083.72          5.36           9.05
#
#                                          lex3_11_infover  \
# 82937  ind:pas:1s;ind:pas:2s;par:pas;par:pas;par:pas;...
# 82953                                           par:pas;
# 82965                                           par:pas;
#
#                            11_infover                           infover
# 82937  ind:pas:1s;ind:pas:2s;par:pas;  ind:pas:1s;ind:pas:2s;par:pas:m;
# 82953                        par:pas;                       par:pas:fs;
# 82965                        par:pas;                       par:pas:fp;

# %% [markdown]
# - ajout d'une colonne pour le nombre de cases de chaque lemme

# %%
flemme=verb3.groupby(by="3_lemme")[["infover"]].sum()
flemme["nbSet"]=flemme["infover"].str.split(";").apply(set).str.len()-1

# %%
flemme.sort_values("nbSet")
# Out:
#                                                          infover  nbSet
# 3_lemme
# rebrûler                                             par:pas:ms;      1
# catéchiser                                           par:pas:fs;      1
# friseler                                                    inf;      1
# varapper                                                    inf;      1
# subvertir                                                   inf;      1
# désheurer                                            ind:imp:3p;      1
# déceindre                                            ind:pre:3s;      1
# fretter                                              ind:pas:3s;      1
# fuiter                                                      inf;      1
# plus                                                 par:pas:mp;      1
# redisposer                                                  inf;      1
# désertifier                                          ind:pre:3s;      1
# pleuvioter                                                  inf;      1
# violeter                                             ind:pas:3s;      1
# férir                                                       inf;      1
# fumeronner                                           ind:pre:3s;      1
# sténographier                                        ind:pas:1s;      1
# poirer                                                      inf;      1
# poitriner                                               par:pre;      1
# décalaminer                                          par:pas:ms;      1
# challenger                                                  inf;      1
# retuber                                                     inf;      1
# retuer                                                  inf;inf;      1
# chabler                                                     inf;      1
# retâter                                              par:pas:ms;      1
# désinhiber                                           ind:pre:3s;      1
# revalider                                                   inf;      1
# désincruster                                                inf;      1
# tremblocher                                             par:pre;      1
# décambuter                                                  inf;      1
# ...                                                          ...    ...
# venir          ind:imp:3p;ind:imp:1s;ind:imp:2s;ind:imp:3s;pa...     44
# rendre         ind:pre:3s;ind:imp:3p;ind:imp:1s;ind:imp:2s;in...     44
# arrêter        ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     44
# prendre        imp:pre:2p;ind:imp:3p;ind:imp:1s;ind:imp:2s;in...     44
# voir           ind:fut:3s;ind:fut:1s;cnd:pre:3p;cnd:pre:1s;cn...     44
# mettre         ind:pre:3s;imp:pre:2s;ind:pre:1s;ind:pre:2s;in...     44
# aller          sub:pre:1s;sub:pre:3s;sub:pre:3p;sub:pre:2s;in...     44
# devenir        ind:imp:3p;ind:imp:1s;ind:imp:2s;ind:imp:3s;pa...     44
# revenir        ind:imp:3p;ind:imp:1s;ind:imp:2s;ind:imp:3s;pa...     44
# courir         ind:imp:3p;ind:imp:1s;ind:imp:2s;ind:imp:3s;pa...     44
# sentir         imp:pre:2s;ind:pre:1s;ind:pre:2s;ind:pre:3s;in...     45
# laisser        ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     45
# entendre       ind:pre:3s;ind:imp:3p;ind:imp:1s;ind:imp:2s;in...     45
# dire           ind:fut:3s;ind:fut:1s;cnd:pre:3p;cnd:pre:1s;cn...     45
# quitter        ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     45
# chercher       ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     45
# partir         imp:pre:2s;ind:pre:1s;ind:pre:2s;ind:pre:3s;in...     45
# vouloir        imp:pre:2s;sub:pre:1s;sub:pre:3s;sub:pre:3p;su...     46
# connaître      imp:pre:2s;ind:pre:1s;ind:pre:2s;ind:imp:3p;in...     46
# donner         ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     46
# croire         sub:pre:1s;sub:pre:3s;ind:pre:3p;sub:pre:2s;in...     46
# parler         ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     46
# passer         ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     46
# trouver        ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     46
# savoir         par:pre;imp:pre:2s;sub:pre:1s;sub:pre:3s;sub:p...     47
# devoir         ind:imp:3p;ind:imp:1s;ind:imp:2s;ind:imp:3s;pa...     48
# aimer          ind:pas:3s;ind:pas:1s;ind:imp:3p;ind:imp:1s;in...     48
# être           ind:pre:2s;ind:pre:3s;ind:pas:3p;ind:pas:1s;in...     48
# avoir          ind:pre:3s;ind:pre:1s;imp:pre:2s;sub:pre:1s;su...     50
# faire          inf;imp:pre:2s;ind:pre:1s;ind:pre:2s;ind:imp:3...     50
#
# [6399 rows x 2 columns]

# %% [markdown]
# - calcul du nombre de lemmes avec exactement une seule forme réparti par nom de case

# %%
flemme[(flemme["nbSet"]==1)].groupby(by="infover").count().sort_values("nbSet")
# Out:
#              nbSet
# infover
# sub:pre:3s;      1
# sub:imp:3s;      1
# sub:imp:1s;      1
# sub:pre:2s;      1
# ind:pre:1p;      1
# inf;inf;         2
# ind:imp:1p;      2
# ind:pas:2s;      2
# imp:pre:1p;      3
# ind:pre:2p;      3
# ind:pas:1s;      3
# ind:pas:3p;      4
# ind:imp:1s;      4
# imp:pre:2p;      5
# ind:fut:3s;      6
# imp:pre:2s;      8
# ind:imp:3p;     12
# ind:pre:1s;     12
# ind:pre:2s;     12
# ind:pre:3p;     20
# par:pas:fp;     22
# ind:pas:3s;     25
# ind:imp:3s;     36
# par:pre;        42
# par:pas:mp;     46
# par:pas:fs;     48
# ind:pre:3s;     84
# par:pas:ms;    143
# inf;           421

# %% [markdown]
# ## Quelle influence pour le imparfait 4/5 et le subjonctif 4/5
# - combien des lexèmes ont exactement une seule forme dans Lex3 qui appartient à cette zone
#  - 2 : sélecter et impulser
#  - tous les deux des confusions probables avec les noms pluriels : sélections et impulsions
#   - leur fréquence est 0 pour livres et le minimum 0.01 pour films

# %%
flemme[(flemme["infover"].str.contains("(ind:imp|sub:pre):(1|2)p")) & (flemme["nbSet"]==1)]
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#               infover  nbSet
# 3_lemme
# impulser  ind:imp:1p;      1
# sélecter  ind:imp:1p;      1

# %%
lex3[lex3["1_ortho"].isin(["sélections","impulsions"])]
# Out:
#            1_ortho    2_phon    3_lemme 4_cgram 5_genre 6_nombre  \
# 69193   impulsions   5pylsj§   impulser     VER     NaN      NaN
# 69194   impulsions   5pylsj§  impulsion     NOM       f        p
# 126414  sélections  selEksj§  sélection     NOM       f        p
# 126415  sélections  selEktj§   sélecter     VER     NaN      NaN
#
#         7_freqlemfilms2  8_freqlemlivres  9_freqfilms2  10_freqlivres  \
# 69193              0.01             0.00          0.01           0.00
# 69194              4.58             8.38          1.58           2.36
# 126414             4.69             2.64          0.24           0.27
# 126415             0.01             0.00          0.01           0.00
#
#        lex3_11_infover
# 69193      ind:imp:1p;
# 69194              NaN
# 126414             NaN
# 126415     ind:imp:1p;

# %% [markdown]
# ## Verbes sans formes fondamentales
# - Combien de verbes n'ont aucune des formes fondamentales (infinitif, participe passé/présent, indicatif présent) ?
#  - 135
# - Combien de formes ont-ils ?
#  - 1 forme : 114
#  - 2 formes : 20
#  - 3 formes :1

# %%
flemme[~(flemme["infover"].str.contains("(inf|par:pas|ind:pre|par:pre)"))]
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#                                              infover  nbSet
# 3_lemme
# abouter                       ind:imp:3s;imp:pre:1p;      2
# aboutonner                               ind:pas:1s;      1
# abricoter                                imp:pre:2p;      1
# accalmir                                 ind:pas:3s;      1
# acter              ind:pas:3s;ind:imp:1p;sub:pre:1p;      3
# adire                                    ind:fut:3s;      1
# agneler                                  ind:pas:3s;      1
# aguiller                                 ind:fut:3s;      1
# alper                                    ind:pas:3s;      1
# amurer                                   ind:pas:3s;      1
# anter                                    imp:pre:2s;      1
# aquareller                               ind:imp:3s;      1
# arquebuser                               sub:imp:3s;      1
# arquepincer                              imp:pre:2s;      1
# autosuggestionner                        ind:pas:3s;      1
# bignoler                                 ind:imp:3s;      1
# bouillotter                              ind:imp:3s;      1
# boulocher                                ind:imp:3s;      1
# bourriquer                               ind:imp:3s;      1
# brifer                                   imp:pre:2p;      1
# brouillasser                             ind:imp:3s;      1
# brousser                                 ind:imp:3s;      1
# brumasser                                ind:imp:3s;      1
# buer                                     ind:pas:3s;      1
# cabaner                                  ind:pas:3s;      1
# calandrer                                imp:pre:2s;      1
# chauvir                                  ind:pas:3s;      1
# chever                                   ind:pas:1s;      1
# chienner                                 sub:imp:1s;      1
# choler                                   ind:fut:3s;      1
# ...                                              ...    ...
# recalibrer                               ind:imp:1s;      1
# reconvaincre                             ind:fut:3s;      1
# refourrer                                ind:imp:3s;      1
# rekidnapper                              ind:imp:1s;      1
# remoucher                                ind:pas:3s;      1
# renfourner                               ind:imp:3s;      1
# reployer                                 ind:imp:3s;      1
# reposter                                 ind:imp:3s;      1
# reressortir                              ind:imp:3s;      1
# rerécurer                                ind:imp:3s;      1
# revider                       ind:pas:3s;ind:pas:3p;      2
# rognonner                                ind:imp:3s;      1
# rupiner                       sub:imp:1s;ind:imp:2p;      2
# rédimer                                  ind:imp:3p;      1
# réer                          ind:pas:3s;ind:imp:3s;      2
# sais                                     imp:pre:2s;      1
# sardiner                                 ind:imp:3p;      1
# satiriser                                ind:imp:3p;      1
# siller                                   imp:pre:1p;      1
# soubresauter                  ind:imp:3p;ind:imp:3s;      2
# sténographier                            ind:pas:1s;      1
# swinguer                                 ind:imp:3p;      1
# sélecter                                 ind:imp:1p;      1
# tabuler                                  ind:pas:3s;      1
# tapager                                  ind:imp:3s;      1
# tomer                                    ind:pas:3s;      1
# trouiller                                ind:imp:3s;      1
# violeter                                 ind:pas:3s;      1
# égrapper                                 ind:imp:3s;      1
# épastrouiller                            ind:fut:3s;      1
#
# [135 rows x 2 columns]

# %%
flemme[~(flemme["infover"].str.contains("(inf|par:pas|ind:pre|par:pre)"))].groupby(by="nbSet").count()
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#        infover
# nbSet
# 1          114
# 2           20
# 3            1

# %%
# %matplotlib inline

# %%
flemme.groupby(by="nbSet")["nbSet"].count().plot(kind="bar",figsize=(12,3))

# %%
print len(flemme[flemme.index=="distraire"]["infover"].str.split(";").apply(set).values[0])
# Out:
# 27

# %%
lex3[(lex3["4_cgram"]=="VER") & (lex3["3_lemme"]=="distraire")]
# Out:
#              1_ortho    2_phon    3_lemme 4_cgram 5_genre 6_nombre  \
# 37707       distraie    distRE  distraire     VER     NaN      NaN
# 37708     distraient    distRE  distraire     VER     NaN      NaN
# 37709      distraies    distRE  distraire     VER     NaN      NaN
# 37710      distraira  distRERa  distraire     VER     NaN      NaN
# 37711  distrairaient  distRERE  distraire     VER     NaN      NaN
# 37712    distrairait  distRERE  distraire     VER     NaN      NaN
# 37713      distraire   distRER  distraire     VER     NaN      NaN
# 37714    distrairont  distRER§  distraire     VER     NaN      NaN
# 37715       distrais    distRE  distraire     VER     NaN      NaN
# 37716       distrait    distRE  distraire     VER       m        s
# 37719      distraite   distREt  distraire     VER       f        s
# 37722     distraites   distREt  distraire     VER       f        p
# 37724      distraits    distRE  distraire     VER       m        p
# 37727   distrayaient  distREjE  distraire     VER     NaN      NaN
# 37728     distrayais  distREjE  distraire     VER     NaN      NaN
# 37729     distrayait  distREjE  distraire     VER     NaN      NaN
# 37730     distrayant  distREj@  distraire     VER     NaN      NaN
# 37735      distrayez  distREje  distraire     VER     NaN      NaN
# 37736     distrayons  distREj§  distraire     VER     NaN      NaN
#
#        7_freqlemfilms2  8_freqlemlivres  9_freqfilms2  10_freqlivres  \
# 37707             16.0            27.77          0.02           0.20
# 37708             16.0            27.77          0.37           0.27
# 37709             16.0            27.77          0.01           0.07
# 37710             16.0            27.77          0.41           0.34
# 37711             16.0            27.77          0.00           0.07
# 37712             16.0            27.77          0.05           0.41
# 37713             16.0            27.77          7.56          13.38
# 37714             16.0            27.77          0.01           0.07
# 37715             16.0            27.77          0.76           0.20
# 37716             16.0            27.77          4.45           6.76
# 37719             16.0            27.77          1.20           2.50
# 37722             16.0            27.77          0.05           0.20
# 37724             16.0            27.77          0.29           0.74
# 37727             16.0            27.77          0.00           0.54
# 37728             16.0            27.77          0.04           0.27
# 37729             16.0            27.77          0.15           1.42
# 37730             16.0            27.77          0.19           0.27
# 37735             16.0            27.77          0.34           0.00
# 37736             16.0            27.77          0.11           0.07
#
#                          lex3_11_infover
# 37707             sub:pre:1s;sub:pre:3s;
# 37708             ind:pre:3p;sub:pre:3p;
# 37709                        sub:pre:2s;
# 37710                        ind:fut:3s;
# 37711                        cnd:pre:3p;
# 37712                        cnd:pre:3s;
# 37713                    inf;;inf;;inf;;
# 37714                        ind:fut:3p;
# 37715  imp:pre:2s;ind:pre:1s;ind:pre:2s;
# 37716                ind:pre:3s;par:pas;
# 37719                           par:pas;
# 37722                           par:pas;
# 37724                           par:pas;
# 37727                        ind:imp:3p;
# 37728                        ind:imp:1s;
# 37729                        ind:imp:3s;
# 37730                           par:pre;
# 37735             imp:pre:2p;ind:pre:2p;
# 37736             imp:pre:1p;ind:pre:1p;

# %%
Lexique3[(Lexique3["4_cgram"]=="VER") & (Lexique3["3_lemme"]=="manger")]
# Out:
#            1_ortho   2_phon 3_lemme 4_cgram 5_genre 6_nombre  7_freqlemfilms2  \
# 79702        mange      m@Z  manger     VER     NaN      NaN           467.82
# 79707       mangea     m@Za  manger     VER     NaN      NaN           467.82
# 79710      mangeai     m@ZE  manger     VER     NaN      NaN           467.82
# 79711   mangeaient     m@ZE  manger     VER     NaN      NaN           467.82
# 79714     mangeais     m@ZE  manger     VER     NaN      NaN           467.82
# 79715     mangeait     m@ZE  manger     VER     NaN      NaN           467.82
# 79716     mangeant     m@Z@  manger     VER     NaN      NaN           467.82
# 79717      mangeas     m@Za  manger     VER     NaN      NaN           467.82
# 79718    mangeasse    m@Zas  manger     VER     NaN      NaN           467.82
# 79719      mangent      m@Z  manger     VER     NaN      NaN           467.82
# 79722     mangeons     m@Z§  manger     VER     NaN      NaN           467.82
# 79724       manger     m@Ze  manger     VER     NaN      NaN           467.82
# 79725      mangera   m@Z°Ra  manger     VER     NaN      NaN           467.82
# 79726     mangerai   m@Z°RE  manger     VER     NaN      NaN           467.82
# 79727  mangeraient   m@Z°RE  manger     VER     NaN      NaN           467.82
# 79728    mangerais   m@Z°RE  manger     VER     NaN      NaN           467.82
# 79729    mangerait   m@Z°RE  manger     VER     NaN      NaN           467.82
# 79730     mangeras   m@Z°Ra  manger     VER     NaN      NaN           467.82
# 79731     mangerez   m@Z°Re  manger     VER     NaN      NaN           467.82
# 79733    mangeriez  m@Z°Rje  manger     VER     NaN      NaN           467.82
# 79734   mangerions  m@Z°Rj§  manger     VER     NaN      NaN           467.82
# 79735    mangerons   m@Z°R§  manger     VER     NaN      NaN           467.82
# 79736    mangeront   m@Z°R§  manger     VER     NaN      NaN           467.82
# 79737       manges      m@Z  manger     VER     NaN      NaN           467.82
# 79743       mangez     m@Ze  manger     VER     NaN      NaN           467.82
# 79744    mangeâmes    m@Zam  manger     VER     NaN      NaN           467.82
# 79745      mangeât     m@Za  manger     VER     NaN      NaN           467.82
# 79746      mangiez    m@Zje  manger     VER     NaN      NaN           467.82
# 79747     mangions    m@Zj§  manger     VER     NaN      NaN           467.82
# 79757    mangèrent    m@ZER  manger     VER     NaN      NaN           467.82
# 79758        mangé     m@Ze  manger     VER       m        s           467.82
# 79759       mangée     m@Ze  manger     VER       f        s           467.82
# 79760      mangées     m@Ze  manger     VER       f        p           467.82
# 79761       mangés     m@Ze  manger     VER       m        p           467.82
#
#        8_freqlemlivres  9_freqfilms2  10_freqlivres     ...      26_orthrenv  \
# 79702           280.61        103.81          31.96     ...            egnam
# 79707           280.61          0.66           5.54     ...           aegnam
# 79710           280.61          0.02           1.55     ...          iaegnam
# 79711           280.61          0.99           7.91     ...       tneiaegnam
# 79714           280.61          2.31           2.91     ...         siaegnam
# 79715           280.61          4.93          20.14     ...         tiaegnam
# 79716           280.61          3.13           7.57     ...         tnaegnam
# 79717           280.61          0.10           0.07     ...          saegnam
# 79718           280.61          0.00           0.07     ...        essaegnam
# 79719           280.61         13.77           8.18     ...          tnegnam
# 79722           280.61          4.05           1.82     ...         snoegnam
# 79724           280.61        207.63         134.26     ...           regnam
# 79725           280.61          4.91           1.35     ...          aregnam
# 79726           280.61          5.01           1.42     ...         iaregnam
# 79727           280.61          0.13           0.54     ...      tneiaregnam
# 79728           280.61          2.84           1.08     ...        siaregnam
# 79729           280.61          1.88           1.96     ...        tiaregnam
# 79730           280.61          2.54           1.49     ...         saregnam
# 79731           280.61          1.43           0.54     ...         zeregnam
# 79733           280.61          0.32           0.07     ...        zeiregnam
# 79734           280.61          0.03           0.27     ...       snoiregnam
# 79735           280.61          1.49           0.74     ...        snoregnam
# 79736           280.61          1.43           0.81     ...        tnoregnam
# 79737           280.61         20.56           4.46     ...           segnam
# 79743           280.61         17.85           3.31     ...           zegnam
# 79744           280.61          0.01           0.47     ...        semâegnam
# 79745           280.61          0.00           0.34     ...          tâegnam
# 79746           280.61          0.91           0.20     ...          zeignam
# 79747           280.61          0.34           1.89     ...         snoignam
# 79757           280.61          0.33           3.72     ...        tnerègnam
# 79758           280.61         60.43          27.50     ...            égnam
# 79759           280.61          1.98           3.04     ...           eégnam
# 79760           280.61          0.38           1.01     ...          seégnam
# 79761           280.61          1.66           2.43     ...           ségnam
#
#        27_phonrenv   28_orthosyll  29_cgramortho  30_deflem  31_defobs  \
# 79702          Z@m         man-ge            VER      100.0       20.0
# 79707         aZ@m        man-gea            VER      100.0       20.0
# 79710         EZ@m       man-geai            VER      100.0       20.0
# 79711         EZ@m    man-geaient            VER      100.0       20.0
# 79714         EZ@m      man-geais            VER      100.0       20.0
# 79715         EZ@m      man-geait            VER      100.0       20.0
# 79716         @Z@m      man-geant            VER      100.0       20.0
# 79717         aZ@m       man-geas            VER      100.0       20.0
# 79718        saZ@m    man-geas-se            VER      100.0       20.0
# 79719          Z@m       man-gent            VER      100.0       20.0
# 79722         §Z@m      man-geons            VER      100.0       20.0
# 79724         eZ@m        man-ger        NOM,VER      100.0       20.0
# 79725       aR°Z@m      man-ge-ra            VER      100.0       20.0
# 79726       ER°Z@m     man-ge-rai            VER      100.0       20.0
# 79727       ER°Z@m  man-ge-raient            VER      100.0       20.0
# 79728       ER°Z@m    man-ge-rais            VER      100.0       20.0
# 79729       ER°Z@m    man-ge-rait            VER      100.0       20.0
# 79730       aR°Z@m     man-ge-ras            VER      100.0       20.0
# 79731       eR°Z@m     man-ge-rez            VER      100.0       20.0
# 79733      ejR°Z@m    man-ge-riez            VER      100.0       20.0
# 79734      §jR°Z@m   man-ge-rions            VER      100.0       20.0
# 79735       §R°Z@m    man-ge-rons            VER      100.0       20.0
# 79736       §R°Z@m    man-ge-ront            VER      100.0       20.0
# 79737          Z@m        man-ges            VER      100.0       20.0
# 79743         eZ@m        man-gez            VER      100.0       20.0
# 79744        maZ@m    man-geâ-mes            VER      100.0       20.0
# 79745         aZ@m       man-geât            VER      100.0       20.0
# 79746        ejZ@m       man-giez            VER      100.0       20.0
# 79747        §jZ@m      man-gions            VER      100.0       20.0
# 79757        REZ@m    man-gè-rent            VER      100.0       20.0
# 79758         eZ@m         man-gé            VER      100.0       20.0
# 79759         eZ@m        man-gée            VER      100.0       20.0
# 79760         eZ@m       man-gées            VER      100.0       20.0
# 79761         eZ@m        man-gés            VER      100.0       20.0
#
#       32_old20 33_pld20  34_morphoder  35_nbmorph
# 79702     1.00     1.00        manger         1.0
# 79707     1.55     1.05        manger         1.0
# 79710     1.70     1.30        manger         1.0
# 79711     1.90     1.30        manger         1.0
# 79714     1.75     1.30        manger         1.0
# 79715     1.60     1.30        manger         1.0
# 79716     1.80     1.35        manger         1.0
# 79717     1.70     1.05        manger         1.0
# 79718     2.75     1.80        manger         1.0
# 79719     1.75     1.00        manger         1.0
# 79722     1.85     1.35        manger         1.0
# 79724     1.35     1.25        manger         1.0
# 79725     1.70      NaN        manger         1.0
# 79726     1.65      NaN        manger         1.0
# 79727     1.90      NaN        manger         1.0
# 79728     1.60      NaN        manger         1.0
# 79729     1.80      NaN        manger         1.0
# 79730     1.75      NaN        manger         1.0
# 79731     1.95      NaN        manger         1.0
# 79733     2.40     1.95        manger         1.0
# 79734     2.45     2.30        manger         1.0
# 79735     1.80      NaN        manger         1.0
# 79736     1.85      NaN        manger         1.0
# 79737     1.00     1.00        manger         1.0
# 79743     1.60     1.25        manger         1.0
# 79744     2.70     1.70        manger         1.0
# 79745     1.90     1.05        manger         1.0
# 79746     1.90     1.55        manger         1.0
# 79747     1.85     1.55        manger         1.0
# 79757     1.85     1.60        manger         1.0
# 79758     1.55     1.25        manger         1.0
# 79759     1.55     1.25        manger         1.0
# 79760     1.70     1.25        manger         1.0
# 79761     1.60     1.25        manger         1.0
#
# [34 rows x 35 columns]

# %% [markdown]
# # Comparer les fréquences de Lexique3 avec Zipf
# - découper les syncrétismes en cases
# - converger vers la distribution de fréquences pour les syncrétismes
#  - calculer la distribution moyenne
#  - diviser la fréquence des syncrétismes en fonction de la moyenne
# - tracer la courbe de fréquence pour les verbes

# %%
lemmeFilm3=verb3[(verb3["7_freqlemfilms2"]!=0)][["3_lemme","1_ortho","7_freqlemfilms2"]]
lemmeFilm3.columns=["lemme","ortho","freq"]

# %%
lemmeFilm3.groupby("lemme").first()["freq"].sort_values(ascending=False).reset_index()[:250].plot()

# %%
film3=verb3[(verb3["9_freqfilms2"]!=0)][["3_lemme","1_ortho","9_freqfilms2","infover"]]
film3.columns=["lemme","ortho","freq","cases"]

# %%
freqTable=pd.pivot_table(film3, values='freq', index=['lemme'], columns=['cases'], aggfunc=lambda x: sum(x)).reset_index().reindex()

# %%
freqTable.set_index("lemme")
# Out:
# cases         cnd:pre:1p;  cnd:pre:1s;  cnd:pre:1s;cnd:pre:2s;  cnd:pre:2p;  \
# lemme
# abaisser              NaN          NaN                    0.13          NaN
# abandonner           0.01          NaN                    0.93         0.23
# abasourdir            NaN          NaN                     NaN          NaN
# abattre               NaN          NaN                    0.10         0.02
# abdiquer              NaN          NaN                     NaN          NaN
# abhorrer              NaN          NaN                     NaN          NaN
# abjurer               NaN          NaN                     NaN          NaN
# abolir                NaN          NaN                     NaN          NaN
# abonder               NaN          NaN                     NaN          NaN
# abonner               NaN          NaN                     NaN          NaN
# aborder               NaN         0.02                     NaN         0.01
# abouler               NaN          NaN                     NaN          NaN
# aboutir               NaN          NaN                     NaN          NaN
# aboyer                NaN          NaN                     NaN          NaN
# abracadabrer          NaN          NaN                     NaN          NaN
# abreuver              NaN          NaN                     NaN          NaN
# abricoter             NaN          NaN                     NaN          NaN
# abriter               NaN          NaN                     NaN          NaN
# abroger               NaN          NaN                     NaN          NaN
# abrutir               NaN          NaN                     NaN          NaN
# abréger               NaN          NaN                     NaN          NaN
# absenter              NaN          NaN                     NaN          NaN
# absorber              NaN          NaN                     NaN          NaN
# absoudre              NaN          NaN                     NaN         0.01
# abstenir              NaN         0.03                     NaN          NaN
# abstraire             NaN          NaN                     NaN          NaN
# abuser                NaN          NaN                    0.09         0.02
# abâtardir             NaN          NaN                     NaN          NaN
# abêtir                NaN          NaN                     NaN          NaN
# abîmer                NaN          NaN                    0.02          NaN
# ...                   ...          ...                     ...          ...
# étonner               NaN         0.02                     NaN          NaN
# étouffer              NaN          NaN                    0.06         0.01
# étourdir              NaN          NaN                     NaN          NaN
# étrangler             NaN          NaN                    0.46          NaN
# étreindre             NaN          NaN                     NaN          NaN
# étrenner              NaN          NaN                     NaN          NaN
# étriller              NaN          NaN                     NaN          NaN
# étriper               NaN         0.01                     NaN          NaN
# étriquer              NaN          NaN                     NaN          NaN
# étudier               NaN          NaN                    0.14          NaN
# étuver                NaN          NaN                     NaN          NaN
# évacuer               NaN          NaN                    0.02          NaN
# évader                NaN          NaN                    0.03          NaN
# évaluer               NaN          NaN                     NaN          NaN
# évangéliser           NaN          NaN                     NaN          NaN
# évanouir              NaN          NaN                     NaN          NaN
# évaporer              NaN          NaN                     NaN          NaN
# évaser                NaN          NaN                     NaN          NaN
# éveiller              NaN          NaN                     NaN          NaN
# éventer               NaN          NaN                     NaN          NaN
# éventrer              NaN          NaN                     NaN          NaN
# évertuer              NaN          NaN                     NaN          NaN
# évider                NaN          NaN                     NaN          NaN
# évincer               NaN          NaN                     NaN          NaN
# éviscérer             NaN          NaN                     NaN          NaN
# éviter                NaN          NaN                    0.97         0.07
# évoluer               NaN          NaN                     NaN          NaN
# évoquer               NaN          NaN                     NaN          NaN
# être                 7.14          NaN                   86.94        17.64
# ôter                  NaN          NaN                    0.14          NaN
#
# cases         cnd:pre:2s;  cnd:pre:3p;  cnd:pre:3s;  imp:pre:1p;  \
# lemme
# abaisser              NaN         0.01         0.02         0.02
# abandonner            NaN         0.02         0.23          NaN
# abasourdir            NaN          NaN          NaN          NaN
# abattre               NaN         0.03         0.63          NaN
# abdiquer              NaN          NaN          NaN          NaN
# abhorrer              NaN          NaN          NaN          NaN
# abjurer               NaN          NaN          NaN          NaN
# abolir                NaN          NaN          NaN          NaN
# abonder               NaN          NaN          NaN          NaN
# abonner               NaN          NaN          NaN          NaN
# aborder               NaN          NaN         0.02          NaN
# abouler               NaN          NaN          NaN          NaN
# aboutir               NaN         0.01         0.05          NaN
# aboyer                NaN          NaN         0.01          NaN
# abracadabrer          NaN          NaN          NaN          NaN
# abreuver              NaN          NaN          NaN         0.01
# abricoter             NaN          NaN          NaN          NaN
# abriter               NaN          NaN         0.04          NaN
# abroger               NaN          NaN          NaN          NaN
# abrutir               NaN          NaN          NaN          NaN
# abréger               NaN          NaN          NaN         0.12
# absenter              NaN          NaN          NaN          NaN
# absorber              NaN         0.11         0.04          NaN
# absoudre              NaN          NaN         0.14          NaN
# abstenir              NaN          NaN         0.02          NaN
# abstraire             NaN          NaN          NaN          NaN
# abuser                NaN          NaN         0.02          NaN
# abâtardir             NaN          NaN          NaN          NaN
# abêtir                NaN          NaN          NaN          NaN
# abîmer                NaN          NaN         0.08          NaN
# ...                   ...          ...          ...          ...
# étonner               NaN         0.03        10.62          NaN
# étouffer              NaN         0.10         0.29          NaN
# étourdir              NaN          NaN          NaN          NaN
# étrangler             NaN         0.01         0.15          NaN
# étreindre             NaN          NaN          NaN          NaN
# étrenner              NaN          NaN          NaN          NaN
# étriller              NaN          NaN          NaN          NaN
# étriper               NaN         0.01          NaN          NaN
# étriquer              NaN          NaN          NaN          NaN
# étudier               NaN          NaN         0.02          NaN
# étuver                NaN          NaN          NaN          NaN
# évacuer               NaN          NaN         0.01          NaN
# évader                NaN          NaN         0.03          NaN
# évaluer               NaN          NaN          NaN          NaN
# évangéliser           NaN          NaN          NaN          NaN
# évanouir              NaN          NaN         0.05          NaN
# évaporer              NaN          NaN          NaN          NaN
# évaser                NaN          NaN          NaN          NaN
# éveiller              NaN          NaN         0.24          NaN
# éventer               NaN          NaN          NaN         0.01
# éventrer              NaN          NaN          NaN          NaN
# évertuer              NaN          NaN          NaN          NaN
# évider                NaN          NaN          NaN          NaN
# évincer               NaN          NaN          NaN          NaN
# éviscérer             NaN          NaN          NaN          NaN
# éviter                NaN          NaN         0.77          NaN
# évoluer               NaN          NaN         0.04          NaN
# évoquer               NaN          NaN         0.04          NaN
# être                  NaN        15.68       311.37          NaN
# ôter                  NaN          NaN         0.03          NaN
#
# cases         imp:pre:1p;ind:imp:1p;ind:pre:1p;  imp:pre:1p;ind:pre:1p;  \
# lemme
# abaisser                                    NaN                     NaN
# abandonner                                  NaN                    1.06
# abasourdir                                  NaN                     NaN
# abattre                                     NaN                    0.33
# abdiquer                                    NaN                     NaN
# abhorrer                                    NaN                     NaN
# abjurer                                     NaN                     NaN
# abolir                                      NaN                    0.02
# abonder                                     NaN                     NaN
# abonner                                     NaN                     NaN
# aborder                                     NaN                    0.72
# abouler                                     NaN                     NaN
# aboutir                                     NaN                     NaN
# aboyer                                      NaN                     NaN
# abracadabrer                                NaN                     NaN
# abreuver                                    NaN                     NaN
# abricoter                                   NaN                     NaN
# abriter                                     NaN                    0.40
# abroger                                     NaN                     NaN
# abrutir                                     NaN                     NaN
# abréger                                     NaN                     NaN
# absenter                                    NaN                     NaN
# absorber                                    NaN                     NaN
# absoudre                                    NaN                     NaN
# abstenir                                    NaN                    0.02
# abstraire                                   NaN                     NaN
# abuser                                      NaN                    0.37
# abâtardir                                   NaN                     NaN
# abêtir                                      NaN                     NaN
# abîmer                                      NaN                     NaN
# ...                                         ...                     ...
# étonner                                     NaN                    0.01
# étouffer                                    NaN                    0.02
# étourdir                                    NaN                     NaN
# étrangler                                   NaN                     NaN
# étreindre                                   NaN                    0.01
# étrenner                                    NaN                     NaN
# étriller                                    NaN                     NaN
# étriper                                     NaN                     NaN
# étriquer                                    NaN                     NaN
# étudier                                     NaN                    0.77
# étuver                                      NaN                     NaN
# évacuer                                     NaN                    0.39
# évader                                      NaN                     NaN
# évaluer                                     NaN                    0.23
# évangéliser                                 NaN                     NaN
# évanouir                                    NaN                     NaN
# évaporer                                    NaN                     NaN
# évaser                                      NaN                     NaN
# éveiller                                    NaN                    0.02
# éventer                                     NaN                     NaN
# éventrer                                    NaN                     NaN
# évertuer                                    NaN                     NaN
# évider                                      NaN                     NaN
# évincer                                     NaN                     NaN
# éviscérer                                   NaN                     NaN
# éviter                                      NaN                    1.30
# évoluer                                     NaN                    0.21
# évoquer                                     NaN                    0.08
# être                                        NaN                     NaN
# ôter                                        NaN                     NaN
#
# cases            ...       sub:imp:2s;  sub:imp:3p;  sub:imp:3s;  sub:pre:1p;  \
# lemme            ...
# abaisser         ...               NaN          NaN          NaN          NaN
# abandonner       ...               NaN          NaN          NaN          NaN
# abasourdir       ...               NaN          NaN          NaN          NaN
# abattre          ...               NaN          NaN          NaN          NaN
# abdiquer         ...               NaN          NaN          NaN          NaN
# abhorrer         ...               NaN          NaN          NaN          NaN
# abjurer          ...               NaN          NaN          NaN          NaN
# abolir           ...               NaN          NaN          NaN          NaN
# abonder          ...               NaN          NaN          NaN          NaN
# abonner          ...               NaN          NaN          NaN          NaN
# aborder          ...               NaN          NaN          NaN          NaN
# abouler          ...               NaN          NaN          NaN          NaN
# aboutir          ...               NaN          NaN          NaN          NaN
# aboyer           ...               NaN          NaN          NaN          NaN
# abracadabrer     ...               NaN          NaN          NaN          NaN
# abreuver         ...               NaN          NaN          NaN          NaN
# abricoter        ...               NaN          NaN          NaN          NaN
# abriter          ...               NaN          NaN          NaN          NaN
# abroger          ...               NaN          NaN          NaN          NaN
# abrutir          ...               NaN          NaN          NaN          NaN
# abréger          ...               NaN          NaN          NaN          NaN
# absenter         ...               NaN          NaN          NaN          NaN
# absorber         ...               NaN          NaN          NaN          NaN
# absoudre         ...               NaN          NaN          NaN          NaN
# abstenir         ...               NaN          NaN          NaN          NaN
# abstraire        ...               NaN          NaN          NaN          NaN
# abuser           ...               NaN          NaN          NaN          NaN
# abâtardir        ...               NaN          NaN          NaN          NaN
# abêtir           ...               NaN          NaN          NaN          NaN
# abîmer           ...               NaN          NaN          NaN          NaN
# ...              ...               ...          ...          ...          ...
# étonner          ...               NaN          NaN          NaN          NaN
# étouffer         ...               NaN          NaN          NaN          NaN
# étourdir         ...               NaN          NaN          NaN          NaN
# étrangler        ...               NaN          NaN          NaN          NaN
# étreindre        ...               NaN          NaN          NaN          NaN
# étrenner         ...               NaN          NaN          NaN          NaN
# étriller         ...               NaN          NaN          NaN          NaN
# étriper          ...               NaN          NaN          NaN          NaN
# étriquer         ...               NaN          NaN          NaN          NaN
# étudier          ...               NaN          NaN          NaN          NaN
# étuver           ...               NaN          NaN          NaN          NaN
# évacuer          ...               NaN          NaN          NaN          NaN
# évader           ...               NaN          NaN          NaN          NaN
# évaluer          ...               NaN          NaN          NaN          NaN
# évangéliser      ...               NaN          NaN          NaN          NaN
# évanouir         ...               NaN          NaN          NaN          NaN
# évaporer         ...               NaN          NaN          NaN          NaN
# évaser           ...               NaN          NaN          NaN          NaN
# éveiller         ...               NaN          NaN          NaN          NaN
# éventer          ...               NaN          NaN          NaN          NaN
# éventrer         ...               NaN          NaN         0.14          NaN
# évertuer         ...               NaN          NaN          NaN          NaN
# évider           ...               NaN          NaN          NaN          NaN
# évincer          ...               NaN          NaN          NaN          NaN
# éviscérer        ...               NaN          NaN          NaN          NaN
# éviter           ...               NaN          NaN          NaN          NaN
# évoluer          ...               NaN          NaN          NaN          NaN
# évoquer          ...               NaN          NaN          NaN          NaN
# être             ...               NaN         0.33         5.57          NaN
# ôter             ...               NaN          NaN          NaN          NaN
#
# cases         sub:pre:1s;  sub:pre:1s;sub:pre:3s;  sub:pre:2p;  sub:pre:2s;  \
# lemme
# abaisser              NaN                     NaN          NaN          NaN
# abandonner            NaN                     NaN          NaN          NaN
# abasourdir            NaN                     NaN          NaN          NaN
# abattre               NaN                    0.58          NaN         0.11
# abdiquer              NaN                     NaN          NaN          NaN
# abhorrer              NaN                     NaN          NaN          NaN
# abjurer               NaN                     NaN          NaN          NaN
# abolir                NaN                     NaN          NaN          NaN
# abonder               NaN                     NaN          NaN          NaN
# abonner               NaN                     NaN          NaN          NaN
# aborder               NaN                     NaN          NaN          NaN
# abouler               NaN                     NaN          NaN          NaN
# aboutir               NaN                    0.08          NaN          NaN
# aboyer                NaN                     NaN          NaN          NaN
# abracadabrer          NaN                     NaN          NaN          NaN
# abreuver              NaN                     NaN          NaN          NaN
# abricoter             NaN                     NaN          NaN          NaN
# abriter               NaN                     NaN          NaN          NaN
# abroger               NaN                     NaN          NaN          NaN
# abrutir               NaN                     NaN          NaN          NaN
# abréger               NaN                     NaN          NaN          NaN
# absenter              NaN                     NaN          NaN          NaN
# absorber              NaN                     NaN          NaN          NaN
# absoudre              NaN                     NaN          NaN         0.01
# abstenir              NaN                    0.02          NaN         0.02
# abstraire             NaN                     NaN          NaN          NaN
# abuser                NaN                     NaN          NaN          NaN
# abâtardir             NaN                     NaN          NaN          NaN
# abêtir                NaN                     NaN          NaN          NaN
# abîmer                NaN                     NaN          NaN          NaN
# ...                   ...                     ...          ...          ...
# étonner               NaN                     NaN          NaN          NaN
# étouffer              NaN                     NaN          NaN          NaN
# étourdir              NaN                     NaN          NaN          NaN
# étrangler             NaN                     NaN          NaN          NaN
# étreindre             NaN                    0.14          NaN          NaN
# étrenner              NaN                     NaN          NaN          NaN
# étriller              NaN                     NaN          NaN          NaN
# étriper               NaN                     NaN          NaN          NaN
# étriquer              NaN                     NaN          NaN          NaN
# étudier               NaN                     NaN          NaN          NaN
# étuver                NaN                     NaN          NaN          NaN
# évacuer               NaN                     NaN          NaN          NaN
# évader                NaN                     NaN          NaN          NaN
# évaluer               NaN                     NaN          NaN          NaN
# évangéliser           NaN                     NaN          NaN          NaN
# évanouir              NaN                    0.18          NaN         0.07
# évaporer              NaN                     NaN          NaN          NaN
# évaser                NaN                     NaN          NaN          NaN
# éveiller              NaN                     NaN          NaN          NaN
# éventer               NaN                     NaN          NaN          NaN
# éventrer              NaN                     NaN          NaN          NaN
# évertuer              NaN                     NaN          NaN          NaN
# évider                NaN                     NaN          NaN          NaN
# évincer               NaN                     NaN          NaN          NaN
# éviscérer             NaN                     NaN          NaN          NaN
# éviter                NaN                     NaN          NaN          NaN
# évoluer               NaN                     NaN          NaN          NaN
# évoquer               NaN                     NaN          NaN          NaN
# être                  NaN                     NaN          NaN          NaN
# ôter                  NaN                     NaN          NaN          NaN
#
# cases         sub:pre:3p;  sub:pre:3s;
# lemme
# abaisser              NaN          NaN
# abandonner            NaN          NaN
# abasourdir            NaN          NaN
# abattre               NaN          NaN
# abdiquer              NaN          NaN
# abhorrer              NaN          NaN
# abjurer               NaN          NaN
# abolir                NaN          NaN
# abonder               NaN          NaN
# abonner               NaN          NaN
# aborder               NaN          NaN
# abouler               NaN          NaN
# aboutir               NaN          NaN
# aboyer                NaN          NaN
# abracadabrer          NaN          NaN
# abreuver              NaN          NaN
# abricoter             NaN          NaN
# abriter               NaN          NaN
# abroger               NaN          NaN
# abrutir               NaN          NaN
# abréger               NaN          NaN
# absenter              NaN          NaN
# absorber              NaN          NaN
# absoudre              NaN         0.16
# abstenir              NaN          NaN
# abstraire             NaN          NaN
# abuser                NaN          NaN
# abâtardir             NaN          NaN
# abêtir                NaN          NaN
# abîmer                NaN          NaN
# ...                   ...          ...
# étonner               NaN          NaN
# étouffer              NaN          NaN
# étourdir              NaN          NaN
# étrangler             NaN          NaN
# étreindre             NaN          NaN
# étrenner              NaN          NaN
# étriller              NaN          NaN
# étriper               NaN          NaN
# étriquer              NaN          NaN
# étudier               NaN          NaN
# étuver                NaN          NaN
# évacuer               NaN          NaN
# évader                NaN          NaN
# évaluer               NaN          NaN
# évangéliser           NaN          NaN
# évanouir              NaN          NaN
# évaporer              NaN          NaN
# évaser                NaN          NaN
# éveiller              NaN          NaN
# éventer               NaN          NaN
# éventrer              NaN          NaN
# évertuer              NaN          NaN
# évider                NaN          NaN
# évincer               NaN          NaN
# éviscérer             NaN          NaN
# éviter                NaN          NaN
# évoluer               NaN          NaN
# évoquer               NaN          NaN
# être                 34.3       319.65
# ôter                  NaN          NaN
#
# [5356 rows x 142 columns]

# %%
cellOrder=[c for c in freqTable.columns[1:] if not ";" in c[:-1]]+[c for c in freqTable.columns[1:] if ";" in c[:-1]]
cellOrder
# Out:
# ['cnd:pre:1p;',
#  'cnd:pre:1s;',
#  'cnd:pre:2p;',
#  'cnd:pre:2s;',
#  'cnd:pre:3p;',
#  'cnd:pre:3s;',
#  'imp:pre:1p;',
#  'imp:pre:2p;',
#  'imp:pre:2s;',
#  'ind:fut:1p;',
#  'ind:fut:1s;',
#  'ind:fut:2p;',
#  'ind:fut:2s;',
#  'ind:fut:3p;',
#  'ind:fut:3s;',
#  'ind:imp:1p;',
#  'ind:imp:1s;',
#  'ind:imp:2p;',
#  'ind:imp:2s;',
#  'ind:imp:3p;',
#  'ind:imp:3s;',
#  'ind:pas:1p;',
#  'ind:pas:1s;',
#  'ind:pas:2p;',
#  'ind:pas:2s;',
#  'ind:pas:3p;',
#  'ind:pas:3s;',
#  'ind:pre:1p;',
#  'ind:pre:1s;',
#  'ind:pre:2p;',
#  'ind:pre:2s;',
#  'ind:pre:3p;',
#  'ind:pre:3s;',
#  'inf;',
#  'par:pas:fp;',
#  'par:pas:fs;',
#  'par:pas:m;',
#  'par:pas:mp;',
#  'par:pas:ms;',
#  'par:pas:p;',
#  'par:pre;',
#  'sub:imp:1p;',
#  'sub:imp:1s;',
#  'sub:imp:2p;',
#  'sub:imp:2s;',
#  'sub:imp:3p;',
#  'sub:imp:3s;',
#  'sub:pre:1p;',
#  'sub:pre:1s;',
#  'sub:pre:2p;',
#  'sub:pre:2s;',
#  'sub:pre:3p;',
#  'sub:pre:3s;',
#  'cnd:pre:1s;cnd:pre:2s;',
#  'imp:pre:1p;ind:imp:1p;ind:pre:1p;',
#  'imp:pre:1p;ind:pre:1p;',
#  'imp:pre:1p;ind:pre:1p;inf;',
#  'imp:pre:1p;ind:pre:1p;sub:pre:2s;',
#  'imp:pre:1p;sub:pre:1p;',
#  'imp:pre:2p;ind:imp:3s;inf;',
#  'imp:pre:2p;ind:pre:2p;',
#  'imp:pre:2p;ind:pre:2p;inf;',
#  'imp:pre:2p;ind:pre:2p;par:pas:fp;',
#  'imp:pre:2p;inf;',
#  'imp:pre:2p;sub:pre:2p;',
#  'imp:pre:2s;ind:imp:1s;ind:imp:2s;',
#  'imp:pre:2s;ind:pas:1s;ind:pre:1s;ind:pre:2s;',
#  'imp:pre:2s;ind:pas:1s;ind:pre:1s;ind:pre:2s;par:pas:mp;',
#  'imp:pre:2s;ind:pas:2s;ind:pre:1s;ind:pre:2s;par:pas:mp;',
#  'imp:pre:2s;ind:pas:2s;ind:pre:2s;par:pas:mp;',
#  'imp:pre:2s;ind:pre:1s;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:2s;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:2s;inf;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:2s;par:pas:m;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:2s;par:pas:mp;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:3s;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:1s;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:1s;sub:pre:3s;',
#  'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;',
#  'imp:pre:2s;ind:pre:1s;par:pas:m;',
#  'imp:pre:2s;ind:pre:1s;par:pas:mp;',
#  'imp:pre:2s;ind:pre:2s;',
#  'imp:pre:2s;ind:pre:3s;',
#  'imp:pre:2s;ind:pre:3s;sub:pre:3s;',
#  'imp:pre:2s;par:pas:mp;',
#  'imp:pre:2s;par:pas:ms;',
#  'imp:pre:2s;sub:pre:1s;',
#  'imp:pre:2s;sub:pre:1s;sub:pre:2s;',
#  'imp:pre:2s;sub:pre:1s;sub:pre:3s;',
#  'ind:fut:2s;ind:pas:2s;',
#  'ind:fut:3p;ind:pas:3s;ind:pre:3s;par:pas:ms;',
#  'ind:fut:3s;ind:pas:3s;',
#  'ind:fut:3s;inf;',
#  'ind:imp:1p;sub:pre:1p;',
#  'ind:imp:1s;ind:imp:2s;',
#  'ind:imp:1s;ind:imp:2s;ind:pre:2s;',
#  'ind:imp:2p;sub:pre:2p;',
#  'ind:imp:3p;ind:pre:3p;',
#  'ind:imp:3p;ind:pre:3p;sub:pre:3p;',
#  'ind:imp:3p;par:pas:fs;',
#  'ind:imp:3s;ind:pre:3s;',
#  'ind:imp:3s;inf;',
#  'ind:imp:3s;par:pas:fp;',
#  'ind:imp:3s;par:pas:fs;',
#  'ind:pas:1s;ind:pas:2s;',
#  'ind:pas:1s;ind:pas:2s;par:pas:m;',
#  'ind:pas:1s;ind:pas:2s;par:pas:mp;',
#  'ind:pas:1s;par:pas:m;',
#  'ind:pas:1s;par:pas:mp;',
#  'ind:pas:2s;par:pas:m;',
#  'ind:pas:2s;par:pas:mp;',
#  'ind:pas:2s;sub:imp:1s;',
#  'ind:pas:3p;ind:pas:3s;',
#  'ind:pas:3s;ind:pre:3s;',
#  'ind:pre:1p;ind:pre:1s;ind:pre:2s;',
#  'ind:pre:1p;ind:pre:2s;',
#  'ind:pre:1p;ind:pre:2s;sub:pre:2s;',
#  'ind:pre:1p;ind:pre:3p;',
#  'ind:pre:1s;ind:pre:2s;',
#  'ind:pre:1s;ind:pre:2s;par:pas:mp;',
#  'ind:pre:1s;ind:pre:3s;',
#  'ind:pre:1s;ind:pre:3s;sub:pre:1s;',
#  'ind:pre:1s;ind:pre:3s;sub:pre:3s;',
#  'ind:pre:1s;par:pas:m;',
#  'ind:pre:1s;par:pas:mp;',
#  'ind:pre:2p;ind:pre:2s;',
#  'ind:pre:2p;inf;',
#  'ind:pre:2p;par:pas:fp;',
#  'ind:pre:2s;par:pas:mp;',
#  'ind:pre:2s;par:pas:ms;',
#  'ind:pre:2s;sub:pre:1p;sub:pre:2s;',
#  'ind:pre:2s;sub:pre:2s;',
#  'ind:pre:3p;sub:imp:3p;',
#  'ind:pre:3p;sub:pre:3p;',
#  'ind:pre:3s;par:pas:ms;',
#  'ind:pre:3s;sub:pre:3s;',
#  'inf;par:pas:mp;',
#  'par:pas:fp;sub:pre:2s;',
#  'par:pas:fs;sub:pre:1s;sub:pre:3s;',
#  'par:pas:fs;sub:pre:3s;',
#  'sub:imp:1s;sub:pre:3s;',
#  'sub:pre:1s;sub:pre:3s;']

# %%
freqTable=freqTable.reindex_axis(["lemme"]+cellOrder, axis=1)

# %%
freqTable.columns=[c.strip(";") for c in freqTable.columns]

# %%
simplesCases=freqTable.sum()[1:54]
multiplesCases=freqTable.sum()[54:]
refFreq=simplesCases.copy()

# %%
convergence=0.0000000001
boolConvergence=False
while not boolConvergence:
    curFreq=simplesCases.copy()
    for m in multiplesCases.keys():
        mCases=[c for c in m.strip(";").split(";")]
        mTotal=0
        for case in mCases:
            mTotal+=refFreq[case]
        for case in mCases:
            partCase=refFreq[case]/mTotal*multiplesCases[m]
    #        print partCase,
            curFreq[case]+=partCase
    #    print
    boolFin=True
    for case in refFreq.keys():
        if (refFreq[case]-curFreq[case])/refFreq[case]>convergence:
            print case, refFreq[case],curFreq[case]
            boolFin=False
    #        break
    refFreq=curFreq.copy()
    if boolFin:
        boolConvergence=True
refFreq
# Out:
# cnd:pre:1p       90.64
# cnd:pre:1s     1505.82
# cnd:pre:2p      314.95
# cnd:pre:2s     139.695
# cnd:pre:3p      162.75
# cnd:pre:3s     1809.05
# imp:pre:1p     69.4849
# imp:pre:2p     812.971
# imp:pre:2s     59.5317
# ind:fut:1p      332.84
# ind:fut:1s     1680.56
# ind:fut:2p         548
# ind:fut:2s     792.872
# ind:fut:3p     457.735
# ind:fut:3s      2777.6
# ind:imp:1p     205.747
# ind:imp:1s     3524.87
# ind:imp:2p     567.765
# ind:imp:2s     98.3754
# ind:imp:3p     534.116
# ind:imp:3s     5842.83
# ind:pas:1p        7.44
# ind:pas:1s     847.651
# ind:pas:2p       11.05
# ind:pas:2s     206.448
# ind:pas:3p     81.3279
# ind:pas:3s     587.316
# ind:pre:1p     2499.05
# ind:pre:1s     17170.7
# ind:pre:2p     12281.5
# ind:pre:2s       14625
# ind:pre:3p     5437.96
# ind:pre:3s     58420.6
# inf            34970.7
# par:pas:fp     598.689
# par:pas:fs     3094.63
# par:pas:m      289.898
# par:pas:mp     1522.54
# par:pas:ms     20114.5
# par:pas:p         3.16
# par:pre        1054.32
# sub:imp:1p        0.27
# sub:imp:1s     1.86457
# sub:imp:2p        0.36
# sub:imp:2s        0.03
# sub:imp:3p    0.860574
# sub:imp:3s       13.65
# sub:pre:1p     24.6785
# sub:pre:1s     10.0892
# sub:pre:2p     70.4132
# sub:pre:2s     594.362
# sub:pre:3p     93.5292
# sub:pre:3s     1427.86
# dtype: object

# %%
refFreq.sort_values(ascending=False).plot(kind="bar",figsize=(12,8))

# %%
"""https://github.com/cognoma/genes/blob/721204091a96e55de6dcad165d6d8265e67e2a48/2.process.py#L61-L95"""

def tidy_split(df, column, sep='|', keep=False):
    """
    Split the values of a column and expand so the new DataFrame has one split
    value per row. Filters rows where the column is missing.
    
    Params
    ------
    df : pandas.DataFrame
        dataframe with the column to split and expand
    column : str
        the column to split and expand
    sep : str
        the string used to split the column's values
    keep : bool
        whether to retain the presplit value as it's own row
    
    Returns
    -------
    pandas.DataFrame
        Returns a dataframe with the same columns as `df`.
    """
    indexes = list()
    new_values = list()
    df = df.dropna(subset=[column])
    for i, presplit in enumerate(df[column].astype(str)):
        values = presplit.split(sep)
        if keep and len(values) > 1:
            indexes.append(i)
            new_values.append(presplit)
        for value in values:
            indexes.append(i)
            new_values.append(value)
    new_df = df.iloc[indexes, :].copy()
    new_df[column] = new_values
    return new_df

# %%
film3["case"]=film3["cases"].str[:-1]

# %%
splitFilm3=tidy_split(film3, "case", sep=';', keep=False)
splitFilm3
# Out:
#              lemme          ortho     freq                              cases  \
# 2            avoir              a  5498.34                        ind:pre:3s;
# 19        abaisser       abaissai     0.10                        ind:pas:1s;
# 21        abaisser      abaissait     0.02                        ind:imp:3s;
# 23        abaisser      abaissant     0.01                           par:pre;
# 26        abaisser        abaisse     1.28  imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 26        abaisser        abaisse     1.28  imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 26        abaisser        abaisse     1.28  imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 29        abaisser      abaissent     0.05                        ind:pre:3p;
# 30        abaisser       abaisser     1.09                               inf;
# 31        abaisser      abaissera     0.19                        ind:fut:3s;
# 32        abaisser     abaisserai     0.10                        ind:fut:1s;
# 33        abaisser  abaisseraient     0.01                        cnd:pre:3p;
# 34        abaisser    abaisserais     0.13             cnd:pre:1s;cnd:pre:2s;
# 34        abaisser    abaisserais     0.13             cnd:pre:1s;cnd:pre:2s;
# 35        abaisser    abaisserait     0.02                        cnd:pre:3s;
# 36        abaisser       abaisses     0.16                        ind:pre:2s;
# 37        abaisser       abaissez     0.53             imp:pre:2p;ind:pre:2p;
# 37        abaisser       abaissez     0.53             imp:pre:2p;ind:pre:2p;
# 38        abaisser      abaissons     0.02                        imp:pre:1p;
# 40        abaisser        abaissé     0.74                        par:pas:ms;
# 42        abaisser       abaissée     0.17                        par:pas:fs;
# 44        abaisser      abaissées     0.01                        par:pas:fp;
# 46        abaisser       abaissés     0.30                        par:pas:mp;
# 51      abandonner      abandonna     0.59                        ind:pas:3s;
# 52      abandonner     abandonnai     0.27                        ind:pas:1s;
# 53      abandonner  abandonnaient     0.07                        ind:imp:3p;
# 54      abandonner    abandonnais     0.35             ind:imp:1s;ind:imp:2s;
# 54      abandonner    abandonnais     0.35             ind:imp:1s;ind:imp:2s;
# 55      abandonner    abandonnait     1.04                        ind:imp:3s;
# 56      abandonner    abandonnant     1.15                           par:pre;
# ...            ...            ...      ...                                ...
# 142651        être           êtes  1002.88             imp:pre:2p;ind:pre:2p;
# 142651        être           êtes  1002.88             imp:pre:2p;ind:pre:2p;
# 142654        être           être  1111.69                               inf;
# 142664        ôter            ôta     0.46                        ind:pas:3s;
# 142666        ôter        ôtaient     0.01                        ind:imp:3p;
# 142667        ôter          ôtais     0.03             ind:imp:1s;ind:imp:2s;
# 142667        ôter          ôtais     0.03             ind:imp:1s;ind:imp:2s;
# 142668        ôter          ôtait     0.16                        ind:imp:3s;
# 142669        ôter          ôtant     0.43                           par:pre;
# 142670        ôter            ôte     3.05  imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 142670        ôter            ôte     3.05  imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 142670        ôter            ôte     3.05  imp:pre:2s;ind:pre:1s;ind:pre:3s;
# 142671        ôter          ôtent     0.29                        ind:pre:3p;
# 142672        ôter           ôter     5.57                               inf;
# 142673        ôter          ôtera     0.26                        ind:fut:3s;
# 142674        ôter         ôterai     0.09                        ind:fut:1s;
# 142675        ôter        ôterais     0.14             cnd:pre:1s;cnd:pre:2s;
# 142675        ôter        ôterais     0.14             cnd:pre:1s;cnd:pre:2s;
# 142676        ôter        ôterait     0.03                        cnd:pre:3s;
# 142677        ôter         ôteras     0.17                        ind:fut:2s;
# 142678        ôter         ôterez     0.17                        ind:fut:2p;
# 142680        ôter           ôtes     0.65                        ind:pre:2s;
# 142681        ôter           ôtez     1.30             imp:pre:2p;ind:pre:2p;
# 142681        ôter           ôtez     1.30             imp:pre:2p;ind:pre:2p;
# 142682        ôter          ôtiez     0.17                        ind:imp:2p;
# 142683        ôter          ôtons     0.02                        ind:pre:1p;
# 142686        ôter            ôté     3.18                        par:pas:ms;
# 142688        ôter           ôtée     0.42                        par:pas:fs;
# 142690        ôter          ôtées     0.16                        par:pas:fp;
# 142692        ôter           ôtés     0.04                        par:pas:mp;
#
#               case
# 2       ind:pre:3s
# 19      ind:pas:1s
# 21      ind:imp:3s
# 23         par:pre
# 26      imp:pre:2s
# 26      ind:pre:1s
# 26      ind:pre:3s
# 29      ind:pre:3p
# 30             inf
# 31      ind:fut:3s
# 32      ind:fut:1s
# 33      cnd:pre:3p
# 34      cnd:pre:1s
# 34      cnd:pre:2s
# 35      cnd:pre:3s
# 36      ind:pre:2s
# 37      imp:pre:2p
# 37      ind:pre:2p
# 38      imp:pre:1p
# 40      par:pas:ms
# 42      par:pas:fs
# 44      par:pas:fp
# 46      par:pas:mp
# 51      ind:pas:3s
# 52      ind:pas:1s
# 53      ind:imp:3p
# 54      ind:imp:1s
# 54      ind:imp:2s
# 55      ind:imp:3s
# 56         par:pre
# ...            ...
# 142651  imp:pre:2p
# 142651  ind:pre:2p
# 142654         inf
# 142664  ind:pas:3s
# 142666  ind:imp:3p
# 142667  ind:imp:1s
# 142667  ind:imp:2s
# 142668  ind:imp:3s
# 142669     par:pre
# 142670  imp:pre:2s
# 142670  ind:pre:1s
# 142670  ind:pre:3s
# 142671  ind:pre:3p
# 142672         inf
# 142673  ind:fut:3s
# 142674  ind:fut:1s
# 142675  cnd:pre:1s
# 142675  cnd:pre:2s
# 142676  cnd:pre:3s
# 142677  ind:fut:2s
# 142678  ind:fut:2p
# 142680  ind:pre:2s
# 142681  imp:pre:2p
# 142681  ind:pre:2p
# 142682  ind:imp:2p
# 142683  ind:pre:1p
# 142686  par:pas:ms
# 142688  par:pas:fs
# 142690  par:pas:fp
# 142692  par:pas:mp
#
# [59843 rows x 5 columns]

# %%
def relativeFreqs(case,cases):
    totalFreq=sum([refFreq[c] for c in cases])
    result={}
    for c in cases:
        result[c]=float(refFreq[c])/totalFreq
#    print result,result[case]
    return result[case]

def repartitionFreqCases(row):
    cases=row["cases"][:-1].split(";")
    case=row["case"]
#    print case
    if len(cases)>1:
        relFreqCase=relativeFreqs(case,cases)
        return relFreqCase*row["freq"]
    else:
        return row["freq"]

# %%
splitFilm3["relFreq"]=splitFilm3.apply(repartitionFreqCases,axis=1)

# %%
splitFilm3["relFreq"].sort_values(ascending=False).reset_index()["relFreq"]
# Out:
# 0        19417.690000
# 1         5498.340000
# 2         3379.106623
# 3         2735.960000
# 4         2475.780000
# 5         2356.650000
# 6         2047.145987
# 7         1849.070000
# 8         1813.153712
# 9         1644.990000
# 10        1575.406922
# 11        1564.520000
# 12        1449.030000
# 13        1401.100000
# 14        1346.258411
# 15        1343.023615
# 16        1327.009220
# 17        1318.110000
# 18        1274.310000
# 19        1209.640000
# 20        1146.661589
# 21        1143.906385
# 22        1111.690000
# 23        1041.220000
# 24        1005.128577
# 25         941.698286
# 26         940.616324
# 27         905.210000
# 28         816.760000
# 29         802.081714
#              ...
# 59813        0.000010
# 59814        0.000010
# 59815        0.000010
# 59816        0.000010
# 59817        0.000010
# 59818        0.000010
# 59819        0.000010
# 59820        0.000010
# 59821        0.000010
# 59822        0.000010
# 59823        0.000010
# 59824        0.000010
# 59825        0.000010
# 59826        0.000010
# 59827        0.000010
# 59828        0.000010
# 59829        0.000010
# 59830        0.000010
# 59831        0.000008
# 59832        0.000008
# 59833        0.000008
# 59834        0.000008
# 59835        0.000008
# 59836        0.000008
# 59837        0.000008
# 59838        0.000008
# 59839        0.000008
# 59840        0.000008
# 59841        0.000008
# 59842        0.000008
# Name: relFreq, dtype: float64

# %%
splitFilm3["relFreq"].sort_values(ascending=False).reset_index()["relFreq"][:100].plot(figsize=(20,5))

# %%
Lexique3[Lexique3["9_freqfilms2"]!=0]["9_freqfilms2"].sort_values(ascending=False).reset_index()["9_freqfilms2"].plot()

# %%
import Levenshtein as lv

# %%
paires=[("kataba","yaktubu"),
        ("Daraba","yaDribu"),
        ("kaburu","yakburu"),
        ("labisa","yalbasu"),
       ("benyam","ephrem")]

# %%
for a,b in paires:
    print(a,b,lv.distance(a,b))
    e=lv.editops(a,b)
    # print(e)
    ie=lv.editops(b,a)
    print(ie)
    o=lv.opcodes(a,b)
    # print(o)
    io=lv.opcodes(b,a)
    # mb=lv.matching_blocks(e,a,b)
    # print(''.join([a[x[0]:x[0]+x[2]] for x in mb]))
    # print(''.join([b[x[1]:x[1]+x[2]] for x in mb]))
    imb=lv.matching_blocks(ie,b,a)
    print(''.join([b[x[0]:x[0]+x[2]] for x in imb]))
    print(''.join([a[x[1]:x[1]+x[2]] for x in imb]))
# Out:
# kataba yaktubu 4
# [('replace', 0, 0), ('delete', 2, 2), ('replace', 4, 3), ('replace', 6, 5)]
# atb
# atb
# Daraba yaDribu 4
# [('replace', 0, 0), ('delete', 2, 2), ('replace', 4, 3), ('replace', 6, 5)]
# arb
# arb
# kaburu yakburu 2
# [('replace', 0, 0), ('delete', 2, 2)]
# aburu
# aburu
# labisa yalbasu 4
# [('replace', 0, 0), ('delete', 2, 2), ('replace', 4, 3), ('replace', 6, 5)]
# abs
# abs
# benyam ephrem 5
# [('insert', 0, 0), ('replace', 1, 2), ('replace', 2, 3), ('replace', 3, 4), ('delete', 4, 5)]
# em
# em

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
from IPython.html.widgets import FloatProgress
from IPython.display import display
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
phonologicalMap="-N"

# %%
import math
def rAn(r,n):
    f = math.factorial
    return f(n) / f(n-r)
def rCn(r,n):
    f = math.factorial
    return f(n) / f(r) / f(n-r)

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
validPhonemes=list(fs.supremum.concept.extent)
#for phoneme in validPhonemes:
#    print (phoneme, [phoneme], ";")

# %%
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# # Lecture du tableau de VERBES

# %% [markdown]
# ### Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
filePrefix="2015-Data/MGC-160104"

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print (forme, file=logfile)
                print ("pas de classe",idClasseForme, file=logfile)
                print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ## Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for n,paire in enumerate(it.combinations_with_replacement(sampleCases,2)):
        progressBar.value=n
        if debug: print (paire, file=logfile)
        if debug: print ("-".join(paire),end=", ")
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ### Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
debug1=True

for echantillon in range(0,1):
    echantillonPrefix="-%02d"%(echantillon+1)
    
    nomLexique=filePrefix+echantillonPrefix+"-paradigmes.csv"
    paradigmes=pd.read_csv(nomLexique,sep=";",encoding="utf8")    

    del paradigmes[u"Unnamed: 0"]
    sampleCases=paradigmes.columns.tolist()
    sampleCases.remove(u"lexeme")    

    #Neutralize all the forms
    for case in sampleCases:
        paradigmes[case]=paradigmes[case].apply(lambda x: recoder(x))

    #Save neutralized paradigms
    paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+phonologicalMap+"-paradigmes.csv",encoding="utf8",sep=";")    
    
    logfile_name=filePrefix+echantillonPrefix+phonologicalMap+".log"
    logfile = codecs.open(logfile_name,mode='w',encoding="utf8")
    
    progressBar = FloatProgress(min=0, max=rCn(2,len(sampleCases)))
    display(progressBar)
    
    resultats=evaluerEchantillon(paradigmes)
    classesFinales={}
    for resultat in resultats:
        classesFinales[resultat]=resultats[resultat][0]
        classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]
#    with open(filePrefix+echantillonPrefix+phonologicalMap+'-Regles.pkl', 'wb') as output:
    with open("2015-Data/MGC-160104-%02d"%(echantillon+1)+phonologicalMap+'-Regles.pkl', 'wb') as output:
       pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 3min 5s, sys: 726 ms, total: 3min 6s
# Wall time: 3min 5s

# %%
for element in  (classesFinales[("pi3S","inf")].sortirForme(u"mâZ")):
    print (element)
# Out:
# mâZe

# %%
classesFinales
# Out:
# {(u'ps2P', u'is1S'): <__main__.classesPaire instance at 0x10e594368>,
#  (u'ii3S', u'ps3P'): <__main__.classesPaire instance at 0x10d613908>,
#  (u'ii3S', u'pI1P'): <__main__.classesPaire instance at 0x10eb04128>,
#  (u'is2S', u'pc3P'): <__main__.classesPaire instance at 0x10d8da908>,
#  (u'ps2S', u'ii2P'): <__main__.classesPaire instance at 0x10e5b0998>,
#  (u'pc2P', u'ai2P'): <__main__.classesPaire instance at 0x1074d4bd8>,
#  (u'ai1S', u'ai2P'): <__main__.classesPaire instance at 0x10cda8a28>,
#  (u'fi3P', u'pi2P'): <__main__.classesPaire instance at 0x10f7f6d40>,
#  (u'pi1P', u'ai2P'): <__main__.classesPaire instance at 0x10d642518>,
#  (u'pc1P', u'pi2S'): <__main__.classesPaire instance at 0x10cdc4050>,
#  (u'is2P', u'pP'): <__main__.classesPaire instance at 0x10d8902d8>,
#  (u'is2S', u'ai1S'): <__main__.classesPaire instance at 0x10d521a70>,
#  (u'fi1P', u'pI1P'): <__main__.classesPaire instance at 0x10cfa8518>,
#  (u'ps2P', u'ai3S'): <__main__.classesPaire instance at 0x10d6434d0>,
#  (u'ppFP', u'pi2S'): <__main__.classesPaire instance at 0x10d6aa878>,
#  (u'ii3S', u'ii3P'): <__main__.classesPaire instance at 0x10d5b7638>,
#  (u'ps2S', u'fi1S'): <__main__.classesPaire instance at 0x10d5dc710>,
#  (u'pi2P', u'fi1S'): <__main__.classesPaire instance at 0x10cf22b90>,
#  (u'ps3S', u'is2P'): <__main__.classesPaire instance at 0x10b7ac638>,
#  (u'pi1S', u'fi3S'): <__main__.classesPaire instance at 0x10d8edd88>,
#  (u'is1P', u'pP'): <__main__.classesPaire instance at 0x10d5caf38>,
#  (u'ppFP', u'ppFP'): <__main__.classesPaire instance at 0x10d571248>,
#  (u'ppFS', u'fi3S'): <__main__.classesPaire instance at 0x10e8e8ea8>,
#  (u'ii2P', u'ps3P'): <__main__.classesPaire instance at 0x10e38e7e8>,
#  (u'inf', u'pi2S'): <__main__.classesPaire instance at 0x10e0d5200>,
#  (u'pc1P', u'fi3P'): <__main__.classesPaire instance at 0x10e2e5fc8>,
#  (u'is3P', u'pI2P'): <__main__.classesPaire instance at 0x10e6ff7e8>,
#  (u'ppMP', u'pc1P'): <__main__.classesPaire instance at 0x10f7c8fc8>,
#  (u'is3P', u'ppFS'): <__main__.classesPaire instance at 0x10d84a3b0>,
#  (u'ii3P', u'fi2S'): <__main__.classesPaire instance at 0x10d826a28>,
#  (u'inf', u'is2P'): <__main__.classesPaire instance at 0x10d5377e8>,
#  (u'fi1S', u'ps1S'): <__main__.classesPaire instance at 0x10d572c68>,
#  (u'is1P', u'pc1P'): <__main__.classesPaire instance at 0x10d3629e0>,
#  (u'pi3S', u'pc3S'): <__main__.classesPaire instance at 0x10d57c128>,
#  (u'pi1P', u'ppMP'): <__main__.classesPaire instance at 0x10e8feef0>,
#  (u'ppMP', u'ii3P'): <__main__.classesPaire instance at 0x10e65db00>,
#  (u'fi3P', u'ppMP'): <__main__.classesPaire instance at 0x10e614908>,
#  (u'ppFS', u'is3P'): <__main__.classesPaire instance at 0x10e67a050>,
#  (u'ps2P', u'is3S'): <__main__.classesPaire instance at 0x10e5b0320>,
#  (u'ai3S', u'fi3S'): <__main__.classesPaire instance at 0x10e35b488>,
#  (u'fi3P', u'pi1P'): <__main__.classesPaire instance at 0x10d8ed2d8>,
#  (u'fi1P', u'ii3P'): <__main__.classesPaire instance at 0x10e57a998>,
#  (u'fi3S', u'fi2P'): <__main__.classesPaire instance at 0x10f7cdb00>,
#  (u'ppMP', u'ps3P'): <__main__.classesPaire instance at 0x10d03bab8>,
#  (u'pI2P', u'ps2P'): <__main__.classesPaire instance at 0x10e65d050>,
#  (u'pi2P', u'ps3P'): <__main__.classesPaire instance at 0x10e0e96c8>,
#  (u'pi2S', u'ps3P'): <__main__.classesPaire instance at 0x10e8e4cf8>,
#  (u'pI1P', u'ai2S'): <__main__.classesPaire instance at 0x10eb04368>,
#  (u'pI2P', u'ps1S'): <__main__.classesPaire instance at 0x10e8504d0>,
#  (u'pi2P', u'pi3P'): <__main__.classesPaire instance at 0x10d5a1758>,
#  (u'ii1P', u'pc2S'): <__main__.classesPaire instance at 0x10e21eb00>,
#  (u'pI2P', u'is1S'): <__main__.classesPaire instance at 0x10e0e9fc8>,
#  (u'pc3S', u'is1P'): <__main__.classesPaire instance at 0x10e21e290>,
#  (u'ppFP', u'pI2P'): <__main__.classesPaire instance at 0x10cdc4bd8>,
#  (u'is3S', u'ppMS'): <__main__.classesPaire instance at 0x10cf74e18>,
#  (u'fi1P', u'ppFP'): <__main__.classesPaire instance at 0x10e8fad88>,
#  (u'ps3S', u'fi1S'): <__main__.classesPaire instance at 0x10f7cd908>,
#  (u'inf', u'is3P'): <__main__.classesPaire instance at 0x10c25b0e0>,
#  (u'pI1P', u'ii1P'): <__main__.classesPaire instance at 0x10d8ec290>,
#  (u'fi1S', u'ps1P'): <__main__.classesPaire instance at 0x10d874e60>,
#  (u'fi3S', u'fi1S'): <__main__.classesPaire instance at 0x107579290>,
#  (u'ii3P', u'ppMP'): <__main__.classesPaire instance at 0x10752cfc8>,
#  (u'is2S', u'ps1P'): <__main__.classesPaire instance at 0x10cd9b9e0>,
#  (u'is1P', u'fi2P'): <__main__.classesPaire instance at 0x10e38e908>,
#  (u'pi3P', u'ii1P'): <__main__.classesPaire instance at 0x10d6e8830>,
#  (u'ppMS', u'is1P'): <__main__.classesPaire instance at 0x10eb987a0>,
#  (u'ps3S', u'is1P'): <__main__.classesPaire instance at 0x10eb86710>,
#  (u'fi1S', u'ps2S'): <__main__.classesPaire instance at 0x10e5d11b8>,
#  (u'inf', u'ps2S'): <__main__.classesPaire instance at 0x10e67a440>,
#  (u'fi1P', u'ii2S'): <__main__.classesPaire instance at 0x10eb04a28>,
#  (u'ps1S', u'ai3P'): <__main__.classesPaire instance at 0x1074d9758>,
#  (u'fi1P', u'fi1S'): <__main__.classesPaire instance at 0x10a1b4320>,
#  (u'ai1S', u'ii1P'): <__main__.classesPaire instance at 0x10cda88c0>,
#  (u'pI1P', u'ai1S'): <__main__.classesPaire instance at 0x109fb9830>,
#  (u'pi2P', u'pc1S'): <__main__.classesPaire instance at 0x10e6f5f38>,
#  (u'pc3S', u'fi1S'): <__main__.classesPaire instance at 0x10f8a5ef0>,
#  (u'pi1S', u'inf'): <__main__.classesPaire instance at 0x10e5bf5f0>,
#  (u'pP', u'pI2P'): <__main__.classesPaire instance at 0x10d8904d0>,
#  (u'ai3S', u'ii3P'): <__main__.classesPaire instance at 0x10e6ffb90>,
#  (u'is1P', u'ppMP'): <__main__.classesPaire instance at 0x10d826ab8>,
#  (u'fi1P', u'is1P'): <__main__.classesPaire instance at 0x10745e7a0>,
#  (u'pi3S', u'pi3S'): <__main__.classesPaire instance at 0x10d6aae18>,
#  (u'pI2S', u'ii3S'): <__main__.classesPaire instance at 0x10d6e8cb0>,
#  (u'ai3S', u'is1P'): <__main__.classesPaire instance at 0x10d826b90>,
#  (u'ai1P', u'ps1S'): <__main__.classesPaire instance at 0x10752f758>,
#  (u'ps3P', u'pi2S'): <__main__.classesPaire instance at 0x10d03bbd8>,
#  (u'ppMP', u'fi1S'): <__main__.classesPaire instance at 0x10ca07998>,
#  (u'ps1S', u'ii2P'): <__main__.classesPaire instance at 0x10e886a28>,
#  (u'ai2S', u'is2P'): <__main__.classesPaire instance at 0x10e3b1d40>,
#  (u'fi2P', u'ps1P'): <__main__.classesPaire instance at 0x10e8fa200>,
#  (u'ps2P', u'ps2P'): <__main__.classesPaire instance at 0x10e304b90>,
#  (u'pP', u'fi3P'): <__main__.classesPaire instance at 0x10eb98a28>,
#  (u'is1S', u'ps3S'): <__main__.classesPaire instance at 0x10e8fe290>,
#  (u'ai2P', u'ii3P'): <__main__.classesPaire instance at 0x10d643bd8>,
#  (u'fi3P', u'ps1P'): <__main__.classesPaire instance at 0x10e614bd8>,
#  (u'fi3P', u'is3P'): <__main__.classesPaire instance at 0x10da8e5f0>,
#  (u'pc3P', u'pi2S'): <__main__.classesPaire instance at 0x10e850170>,
#  (u'is2S', u'pc1P'): <__main__.classesPaire instance at 0x10d8da3f8>,
#  (u'fi2P', u'pI2P'): <__main__.classesPaire instance at 0x10f8a5c20>,
#  (u'ai2S', u'fi3P'): <__main__.classesPaire instance at 0x10d521050>,
#  (u'pI2P', u'is2S'): <__main__.classesPaire instance at 0x10b7ac9e0>,
#  (u'pc1S', u'ppFP'): <__main__.classesPaire instance at 0x10e207ea8>,
#  (u'inf', u'pi3P'): <__main__.classesPaire instance at 0x10e21e248>,
#  (u'pc3S', u'pc3P'): <__main__.classesPaire instance at 0x10e8e7998>,
#  (u'ps2S', u'pP'): <__main__.classesPaire instance at 0x10eb550e0>,
#  (u'ai2P', u'pi1P'): <__main__.classesPaire instance at 0x10d642830>,
#  (u'is1P', u'ai2S'): <__main__.classesPaire instance at 0x10e5d1440>,
#  (u'fi3P', u'pi3S'): <__main__.classesPaire instance at 0x10d5ca1b8>,
#  (u'pi3P', u'inf'): <__main__.classesPaire instance at 0x10e21e908>,
#  (u'pI2P', u'fi2S'): <__main__.classesPaire instance at 0x10e21fab8>,
#  (u'fi2P', u'pc1S'): <__main__.classesPaire instance at 0x10d01b680>,
#  (u'pI1P', u'ppMP'): <__main__.classesPaire instance at 0x10e248128>,
#  (u'inf', u'pc1P'): <__main__.classesPaire instance at 0x10e594128>,
#  (u'ii3S', u'pi3S'): <__main__.classesPaire instance at 0x10d6954d0>,
#  (u'is2P', u'ppFS'): <__main__.classesPaire instance at 0x10e594908>,
#  (u'ppFP', u'pi3P'): <__main__.classesPaire instance at 0x10e88db90>,
#  (u'pc2S', u'ai3S'): <__main__.classesPaire instance at 0x10e3b1758>,
#  (u'ii3S', u'pc1S'): <__main__.classesPaire instance at 0x10d5b7488>,
#  (u'is2S', u'fi2S'): <__main__.classesPaire instance at 0x10e8fa908>,
#  (u'fi1S', u'ai1S'): <__main__.classesPaire instance at 0x10d572488>,
#  (u'pc3P', u'ps3P'): <__main__.classesPaire instance at 0x10d6aadd0>,
#  (u'is2P', u'fi2P'): <__main__.classesPaire instance at 0x10f85eb00>,
#  (u'ppFP', u'ps3P'): <__main__.classesPaire instance at 0x10fa99cb0>,
#  (u'ai1S', u'ppMP'): <__main__.classesPaire instance at 0x10d521b00>,
#  (u'pi2S', u'ps2S'): <__main__.classesPaire instance at 0x10da62950>,
#  (u'ps3S', u'pc3P'): <__main__.classesPaire instance at 0x10d6aab48>,
#  (u'ai3P', u'fi3P'): <__main__.classesPaire instance at 0x107518680>,
#  (u'pi1P', u'fi1P'): <__main__.classesPaire instance at 0x10e0d5170>,
#  (u'pP', u'ppMS'): <__main__.classesPaire instance at 0x10f7c85a8>,
#  (u'pc2S', u'is1S'): <__main__.classesPaire instance at 0x10e0e9440>,
#  (u'ppMP', u'inf'): <__main__.classesPaire instance at 0x10d847b90>,
#  (u'ai1S', u'pi2S'): <__main__.classesPaire instance at 0x10a1b72d8>,
#  (u'ppMS', u'ps1P'): <__main__.classesPaire instance at 0x10cfa4488>,
#  (u'ppFP', u'fi3P'): <__main__.classesPaire instance at 0x10e614f38>,
#  (u'pi1S', u'pc1P'): <__main__.classesPaire instance at 0x10d554f38>,
#  (u'pi3P', u'pi1P'): <__main__.classesPaire instance at 0x10d6e6c20>,
#  (u'is1S', u'pc3S'): <__main__.classesPaire instance at 0x10e594ab8>,
#  (u'ii1P', u'ii1S'): <__main__.classesPaire instance at 0x10e80e6c8>,
#  (u'fi2P', u'pi2S'): <__main__.classesPaire instance at 0x10fad39e0>,
#  (u'pi1S', u'pI2P'): <__main__.classesPaire instance at 0x10f8b9098>,
#  (u'ppMP', u'ii2S'): <__main__.classesPaire instance at 0x10f8b9248>,
#  (u'ai2S', u'is1P'): <__main__.classesPaire instance at 0x10e5d1e18>,
#  (u'ai1S', u'ps3S'): <__main__.classesPaire instance at 0x10c5107a0>,
#  (u'ii1S', u'pi1S'): <__main__.classesPaire instance at 0x10e6ffef0>,
#  (u'fi3P', u'fi3P'): <__main__.classesPaire instance at 0x10e20cb90>,
#  (u'pI2P', u'pc2P'): <__main__.classesPaire instance at 0x10cdc46c8>,
#  (u'ps1S', u'ps2P'): <__main__.classesPaire instance at 0x10cfa5bd8>,
#  (u'ai2S', u'pi3P'): <__main__.classesPaire instance at 0x10e3b1c68>,
#  (u'pc2P', u'fi2P'): <__main__.classesPaire instance at 0x10e80e9e0>,
#  (u'ai3P', u'ii1S'): <__main__.classesPaire instance at 0x10e5077a0>,
#  (u'pP', u'ai3P'): <__main__.classesPaire instance at 0x10e507248>,
#  (u'is3S', u'is2P'): <__main__.classesPaire instance at 0x10e67a758>,
#  (u'pc1P', u'is2S'): <__main__.classesPaire instance at 0x10d8da5f0>,
#  (u'ii3P', u'is3S'): <__main__.classesPaire instance at 0x10da45170>,
#  (u'pi2P', u'pi2S'): <__main__.classesPaire instance at 0x10e3b9488>,
#  (u'ii3S', u'fi2S'): <__main__.classesPaire instance at 0x10e35b4d0>,
#  (u'pc3P', u'pc3P'): <__main__.classesPaire instance at 0x10d8b9e18>,
#  (u'ii3S', u'ai3S'): <__main__.classesPaire instance at 0x10d521c68>,
#  (u'is2S', u'pc2S'): <__main__.classesPaire instance at 0x10b7ac758>,
#  (u'is3P', u'pc3S'): <__main__.classesPaire instance at 0x10cfa5e18>,
#  (u'ps1P', u'fi1P'): <__main__.classesPaire instance at 0x10cf22368>,
#  (u'fi2S', u'pi3S'): <__main__.classesPaire instance at 0x10f85e0e0>,
#  (u'ii1S', u'ai1P'): <__main__.classesPaire instance at 0x10d0322d8>,
#  (u'pc2S', u'pi2S'): <__main__.classesPaire instance at 0x10d6aa998>,
#  (u'ii2P', u'ppMP'): <__main__.classesPaire instance at 0x10e80ee60>,
#  (u'is3P', u'pi1P'): <__main__.classesPaire instance at 0x10cf87b48>,
#  (u'ii2S', u'pc2P'): <__main__.classesPaire instance at 0x10cfa8b00>,
#  (u'ai3S', u'pP'): <__main__.classesPaire instance at 0x10cda8998>,
#  (u'pc3P', u'pi1S'): <__main__.classesPaire instance at 0x10e8fe638>,
#  (u'fi3S', u'ai1S'): <__main__.classesPaire instance at 0x10d032560>,
#  (u'ii1S', u'is3S'): <__main__.classesPaire instance at 0x10e240b00>,
#  (u'pc2P', u'ppFS'): <__main__.classesPaire instance at 0x10d52a320>,
#  (u'ai1P', u'fi1P'): <__main__.classesPaire instance at 0x10d572d88>,
#  (u'pi3P', u'ps3P'): <__main__.classesPaire instance at 0x10ebaa830>,
#  (u'pc2P', u'fi3S'): <__main__.classesPaire instance at 0x10cda8320>,
#  (u'ai2P', u'ppFP'): <__main__.classesPaire instance at 0x10e527dd0>,
#  (u'pI1P', u'is3P'): <__main__.classesPaire instance at 0x10d8dac20>,
#  (u'pc1P', u'fi1P'): <__main__.classesPaire instance at 0x10e3b1b00>,
#  (u'ps1P', u'ii1S'): <__main__.classesPaire instance at 0x10eb86ea8>,
#  (u'ai1S', u'fi1S'): <__main__.classesPaire instance at 0x10e5d1098>,
#  (u'ii2P', u'ai3S'): <__main__.classesPaire instance at 0x10f8a5368>,
#  (u'is2S', u'pI2S'): <__main__.classesPaire instance at 0x10b7acb00>,
#  (u'pi3P', u'is3P'): <__main__.classesPaire instance at 0x10e248c20>,
#  (u'ai3S', u'ii2S'): <__main__.classesPaire instance at 0x10cf22290>,
#  (u'pi2P', u'is2P'): <__main__.classesPaire instance at 0x10e5b0050>,
#  (u'is1S', u'pc2P'): <__main__.classesPaire instance at 0x10e81be18>,
#  (u'ai1S', u'is3P'): <__main__.classesPaire instance at 0x10c704950>,
#  (u'ps1S', u'fi3P'): <__main__.classesPaire instance at 0x10c4bb368>,
#  (u'pi1P', u'pi1P'): <__main__.classesPaire instance at 0x10d571200>,
#  (u'pc1S', u'is3P'): <__main__.classesPaire instance at 0x10d8b9dd0>,
#  (u'pi2S', u'pc3S'): <__main__.classesPaire instance at 0x10d03be60>,
#  (u'pi1S', u'pi1S'): <__main__.classesPaire instance at 0x10cdd03b0>,
#  (u'pP', u'ii1P'): <__main__.classesPaire instance at 0x10f7f61b8>,
#  (u'ai2S', u'pc3P'): <__main__.classesPaire instance at 0x10d643c68>,
#  (u'is2S', u'ai3P'): <__main__.classesPaire instance at 0x10d539b48>,
#  (u'ai3P', u'ppMS'): <__main__.classesPaire instance at 0x10e57ab00>,
#  (u'ii2P', u'ppFP'): <__main__.classesPaire instance at 0x10d56c7a0>,
#  (u'pi2P', u'ai3S'): <__main__.classesPaire instance at 0x10751a098>,
#  (u'ps1S', u'pc1S'): <__main__.classesPaire instance at 0x10e594200>,
#  (u'ppMS', u'pI1P'): <__main__.classesPaire instance at 0x10daac518>,
#  (u'pc1S', u'fi3P'): <__main__.classesPaire instance at 0x10d56c2d8>,
#  (u'pc3P', u'inf'): <__main__.classesPaire instance at 0x10d362170>,
#  (u'fi2S', u'ai1P'): <__main__.classesPaire instance at 0x1075adc20>,
#  (u'ps2P', u'fi1S'): <__main__.classesPaire instance at 0x10eb98950>,
#  (u'fi2S', u'fi1P'): <__main__.classesPaire instance at 0x10d6411b8>,
#  (u'pc3P', u'pi3P'): <__main__.classesPaire instance at 0x10d8ec368>,
#  (u'pi3P', u'pi3P'): <__main__.classesPaire instance at 0x10e850638>,
#  (u'ai3S', u'is2P'): <__main__.classesPaire instance at 0x10d01bc68>,
#  (u'ii1P', u'pc1P'): <__main__.classesPaire instance at 0x10e507dd0>,
#  (u'ai3P', u'ps3P'): <__main__.classesPaire instance at 0x10cbf6638>,
#  (u'ai1P', u'pi1S'): <__main__.classesPaire instance at 0x1074ffd88>,
#  (u'ii1S', u'ii1P'): <__main__.classesPaire instance at 0x10f85e638>,
#  (u'pc3P', u'is1P'): <__main__.classesPaire instance at 0x10d8b9b90>,
#  (u'ppFS', u'pI1P'): <__main__.classesPaire instance at 0x10d362f38>,
#  (u'pi3S', u'is3P'): <__main__.classesPaire instance at 0x10f8b97a0>,
#  (u'pI1P', u'fi3P'): <__main__.classesPaire instance at 0x10f85e5a8>,
#  (u'ppFS', u'ps1S'): <__main__.classesPaire instance at 0x10eb55440>,
#  (u'is1P', u'ps3S'): <__main__.classesPaire instance at 0x10d5ca3f8>,
#  (u'pI2S', u'fi1S'): <__main__.classesPaire instance at 0x10e6ff878>,
#  (u'ai2S', u'ii3P'): <__main__.classesPaire instance at 0x10a1b73b0>,
#  (u'is1S', u'fi2S'): <__main__.classesPaire instance at 0x10d01bb48>,
#  (u'pi3S', u'ii1S'): <__main__.classesPaire instance at 0x10e6f5440>,
#  (u'pP', u'pP'): <__main__.classesPaire instance at 0x10d8daab8>,
#  (u'pi1S', u'pP'): <__main__.classesPaire instance at 0x10e8e7a70>,
#  (u'ppFS', u'pi1P'): <__main__.classesPaire instance at 0x10d03b950>,
#  (u'ii2S', u'pc3S'): <__main__.classesPaire instance at 0x10e65d638>,
#  (u'ps3S', u'pI2S'): <__main__.classesPaire instance at 0x10d84a9e0>,
#  (u'ps2P', u'fi2S'): <__main__.classesPaire instance at 0x10e507c20>,
#  (u'ii2P', u'ai2S'): <__main__.classesPaire instance at 0x10e3b1cf8>,
#  (u'ai2P', u'is2P'): <__main__.classesPaire instance at 0x10d642c20>,
#  (u'pc1S', u'ii1S'): <__main__.classesPaire instance at 0x10e6ff098>,
#  (u'pc3S', u'pc2P'): <__main__.classesPaire instance at 0x10e8e7878>,
#  (u'ai2S', u'ps3P'): <__main__.classesPaire instance at 0x10cda8098>,
#  (u'pi3P', u'is2S'): <__main__.classesPaire instance at 0x10cd9b488>,
#  (u'ai1S', u'pi3P'): <__main__.classesPaire instance at 0x107511560>,
#  (u'pI2S', u'ii1S'): <__main__.classesPaire instance at 0x10e6f5e60>,
#  (u'is2P', u'pI1P'): <__main__.classesPaire instance at 0x10e67acf8>,
#  (u'fi2S', u'ppMP'): <__main__.classesPaire instance at 0x10d8747e8>,
#  (u'fi2P', u'inf'): <__main__.classesPaire instance at 0x10e0d5680>,
#  (u'fi1S', u'fi1P'): <__main__.classesPaire instance at 0x10d01b320>,
#  (u'fi2P', u'pi3P'): <__main__.classesPaire instance at 0x10f7cd710>,
#  (u'ii1S', u'fi1P'): <__main__.classesPaire instance at 0x10f7cd368>,
#  (u'pc3S', u'pI2S'): <__main__.classesPaire instance at 0x10e8fe200>,
#  (u'ai2S', u'ps2P'): <__main__.classesPaire instance at 0x10cda8dd0>,
#  (u'fi3P', u'ps2S'): <__main__.classesPaire instance at 0x10d54ef38>,
#  (u'pi2P', u'pi1S'): <__main__.classesPaire instance at 0x10cdfb050>,
#  (u'ai3S', u'pi1S'): <__main__.classesPaire instance at 0x10c61b908>,
#  (u'fi2S', u'ps3S'): <__main__.classesPaire instance at 0x10d3883b0>,
#  (u'ai2P', u'ppFS'): <__main__.classesPaire instance at 0x1075ade18>,
#  (u'ppMP', u'ps2S'): <__main__.classesPaire instance at 0x10e8e4ea8>,
#  (u'fi1S', u'fi2P'): <__main__.classesPaire instance at 0x10c55df80>,
#  (u'ps3P', u'pP'): <__main__.classesPaire instance at 0x10e8e7b00>,
#  (u'fi3S', u'pP'): <__main__.classesPaire instance at 0x10f85ec20>,
#  (u'fi3P', u'ai3S'): <__main__.classesPaire instance at 0x10d826bd8>,
#  (u'ps1P', u'pc1S'): <__main__.classesPaire instance at 0x10cfa5ef0>,
#  (u'ai3S', u'fi1P'): <__main__.classesPaire instance at 0x10d826830>,
#  (u'ppFS', u'pc2S'): <__main__.classesPaire instance at 0x10f7c80e0>,
#  (u'ii1S', u'ppMP'): <__main__.classesPaire instance at 0x10d56cc68>,
#  (u'pi1P', u'pI1P'): <__main__.classesPaire instance at 0x10cfe4518>,
#  (u'ppFP', u'pc3P'): <__main__.classesPaire instance at 0x10d8900e0>,
#  (u'pc2P', u'pc3S'): <__main__.classesPaire instance at 0x10e20c908>,
#  (u'ps2P', u'pc1S'): <__main__.classesPaire instance at 0x10e67a098>,
#  (u'fi2S', u'pi2P'): <__main__.classesPaire instance at 0x10eb98ea8>,
#  (u'fi1P', u'ai3P'): <__main__.classesPaire instance at 0x10f8a5440>,
#  (u'pi2P', u'ai1P'): <__main__.classesPaire instance at 0x10cda8ef0>,
#  (u'pc2S', u'pi3P'): <__main__.classesPaire instance at 0x10f7c8f38>,
#  (u'fi2P', u'fi3S'): <__main__.classesPaire instance at 0x10f7cdd88>,
#  (u'ii2S', u'ii2P'): <__main__.classesPaire instance at 0x10e6f5a70>,
#  (u'fi1P', u'pP'): <__main__.classesPaire instance at 0x10d01b998>,
#  (u'pc2S', u'ps3P'): <__main__.classesPaire instance at 0x10d5217a0>,
#  (u'is1S', u'pc1S'): <__main__.classesPaire instance at 0x10d69c098>,
#  (u'fi3S', u'fi1P'): <__main__.classesPaire instance at 0x10e800cb0>,
#  (u'ii2S', u'pP'): <__main__.classesPaire instance at 0x10d613ea8>,
#  (u'is2P', u'is3S'): <__main__.classesPaire instance at 0x10cdc98c0>,
#  (u'pc1S', u'ppMS'): <__main__.classesPaire instance at 0x10eb551b8>,
#  (u'fi3S', u'is2S'): <__main__.classesPaire instance at 0x10e3b1a28>,
#  (u'pI2S', u'ppMS'): <__main__.classesPaire instance at 0x10d554e60>,
#  (u'ppFP', u'pc2P'): <__main__.classesPaire instance at 0x10d554ea8>,
#  (u'ii3P', u'pi3P'): <__main__.classesPaire instance at 0x10d613f38>,
#  (u'pc1S', u'ps3P'): <__main__.classesPaire instance at 0x10f897638>,
#  (u'pc3P', u'ps2P'): <__main__.classesPaire instance at 0x10e886560>,
#  (u'ai3S', u'ai3S'): <__main__.classesPaire instance at 0x10d826050>,
#  (u'ps1P', u'fi3S'): <__main__.classesPaire instance at 0x10e8e8d88>,
#  (u'ps1S', u'ppMP'): <__main__.classesPaire instance at 0x10e6e22d8>,
#  (u'is3P', u'ps1P'): <__main__.classesPaire instance at 0x10b7ac560>,
#  (u'pi3S', u'pi1P'): <__main__.classesPaire instance at 0x10cdc4ef0>,
#  (u'ai2P', u'pc1S'): <__main__.classesPaire instance at 0x1075929e0>,
#  (u'fi2S', u'ai2S'): <__main__.classesPaire instance at 0x10d572cb0>,
#  (u'pi1S', u'ps3P'): <__main__.classesPaire instance at 0x10cdfbea8>,
#  (u'pc2S', u'ai1P'): <__main__.classesPaire instance at 0x10d032e60>,
#  (u'ps2S', u'fi3P'): <__main__.classesPaire instance at 0x10cb019e0>,
#  (u'fi3S', u'ppFP'): <__main__.classesPaire instance at 0x10e21e128>,
#  (u'inf', u'fi1S'): <__main__.classesPaire instance at 0x10e35bfc8>,
#  (u'pI2P', u'ai3P'): <__main__.classesPaire instance at 0x10dabe0e0>,
#  (u'pi1S', u'ii3S'): <__main__.classesPaire instance at 0x10e507fc8>,
#  (u'ai3P', u'ii2S'): <__main__.classesPaire instance at 0x10f7cddd0>,
#  (u'pi3S', u'fi3S'): <__main__.classesPaire instance at 0x10e614cf8>,
#  (u'pI2P', u'pc1P'): <__main__.classesPaire instance at 0x10e207290>,
#  (u'is3S', u'ppFP'): <__main__.classesPaire instance at 0x10d890e18>,
#  (u'fi3P', u'pi3P'): <__main__.classesPaire instance at 0x10d01b5a8>,
#  (u'is2P', u'pI2P'): <__main__.classesPaire instance at 0x10e67a908>,
#  (u'is2S', u'inf'): <__main__.classesPaire instance at 0x10e207f80>,
#  (u'fi2P', u'pI2S'): <__main__.classesPaire instance at 0x10fad35f0>,
#  (u'is3P', u'pc1S'): <__main__.classesPaire instance at 0x10d8b97e8>,
#  (u'pI1P', u'ii3P'): <__main__.classesPaire instance at 0x10d613c68>,
#  (u'ai1P', u'ppFP'): <__main__.classesPaire instance at 0x10757c680>,
#  (u'is1S', u'ps2S'): <__main__.classesPaire instance at 0x10cf74f38>,
#  (u'ai2P', u'ps1P'): <__main__.classesPaire instance at 0x10d643cf8>,
#  (u'is1S', u'ppFS'): <__main__.classesPaire instance at 0x10d362d88>,
#  (u'ppMP', u'ii1S'): <__main__.classesPaire instance at 0x10d56cd40>,
#  (u'ii1P', u'ps2S'): <__main__.classesPaire instance at 0x10cd938c0>,
#  (u'ai3S', u'pc1S'): <__main__.classesPaire instance at 0x10e3b10e0>,
#  (u'ppMS', u'pi3P'): <__main__.classesPaire instance at 0x10f88dfc8>,
#  (u'pc2S', u'pi1S'): <__main__.classesPaire instance at 0x10e0e9b00>,
#  (u'ii1S', u'ai2S'): <__main__.classesPaire instance at 0x10d642440>,
#  (u'ppFS', u'ppFS'): <__main__.classesPaire instance at 0x10e3b9d88>,
#  (u'ii2S', u'pc1S'): <__main__.classesPaire instance at 0x10e3b1488>,
#  (u'pi2P', u'fi3S'): <__main__.classesPaire instance at 0x10e8fa7a0>,
#  (u'ii3S', u'ai1P'): <__main__.classesPaire instance at 0x10d5729e0>,
#  (u'pc2S', u'ii2S'): <__main__.classesPaire instance at 0x10d695830>,
#  (u'pi1P', u'fi2S'): <__main__.classesPaire instance at 0x10f85ed88>,
#  (u'is1P', u'is2S'): <__main__.classesPaire instance at 0x10eb866c8>,
#  (u'fi2P', u'ai1P'): <__main__.classesPaire instance at 0x107595f80>,
#  (u'ppFP', u'ai1S'): <__main__.classesPaire instance at 0x10d539488>,
#  (u'inf', u'fi3P'): <__main__.classesPaire instance at 0x10cfa8320>,
#  (u'pI2S', u'is2P'): <__main__.classesPaire instance at 0x10d890680>,
#  (u'ps3P', u'is2P'): <__main__.classesPaire instance at 0x10b7ac710>,
#  (u'is1S', u'ii3S'): <__main__.classesPaire instance at 0x10d84ab00>,
#  (u'pi3S', u'is1S'): <__main__.classesPaire instance at 0x10e6e34d0>,
#  (u'ii2P', u'pc2S'): <__main__.classesPaire instance at 0x10eb86488>,
#  (u'pI1P', u'ppFP'): <__main__.classesPaire instance at 0x10cf15830>,
#  (u'ps1P', u'ii2P'): <__main__.classesPaire instance at 0x10cda8680>,
#  (u'fi1P', u'pc1P'): <__main__.classesPaire instance at 0x10d032170>,
#  (u'ii3S', u'pI2S'): <__main__.classesPaire instance at 0x10e38e3f8>,
#  (u'pi3P', u'ps1S'): <__main__.classesPaire instance at 0x10da62560>,
#  (u'pi3P', u'ppMS'): <__main__.classesPaire instance at 0x10d554c68>,
#  (u'ii2P', u'is1P'): <__main__.classesPaire instance at 0x10daac6c8>,
#  (u'ps3S', u'inf'): <__main__.classesPaire instance at 0x10e5bf560>,
#  (u'is2P', u'fi1P'): <__main__.classesPaire instance at 0x10758b2d8>,
#  (u'fi2P', u'pi1S'): <__main__.classesPaire instance at 0x10c613200>,
#  (u'ps1P', u'is1S'): <__main__.classesPaire instance at 0x10e296440>,
#  (u'is2S', u'ps3S'): <__main__.classesPaire instance at 0x10cfa5a28>,
#  (u'ppFS', u'fi2S'): <__main__.classesPaire instance at 0x10f7f69e0>,
#  (u'ii2S', u'ai1S'): <__main__.classesPaire instance at 0x10d539950>,
#  (u'fi3P', u'pc1S'): <__main__.classesPaire instance at 0x10d56c248>,
#  (u'ps1S', u'ai2S'): <__main__.classesPaire instance at 0x10c6eaef0>,
#  (u'pi2S', u'pc2S'): <__main__.classesPaire instance at 0x10d6aa170>,
#  (u'ps1S', u'pi1P'): <__main__.classesPaire instance at 0x10e6e2fc8>,
#  (u'fi3P', u'ai2P'): <__main__.classesPaire instance at 0x10d5398c0>,
#  (u'is3S', u'pI2S'): <__main__.classesPaire instance at 0x10e296638>,
#  (u'ai2P', u'ai2S'): <__main__.classesPaire instance at 0x10dabecf8>,
#  (u'pi2P', u'pI2P'): <__main__.classesPaire instance at 0x10d6951b8>,
#  (u'inf', u'pc1S'): <__main__.classesPaire instance at 0x10f8b9290>,
#  (u'pc3S', u'inf'): <__main__.classesPaire instance at 0x10e8e8998>,
#  (u'ppMP', u'ppMS'): <__main__.classesPaire instance at 0x10e8fe518>,
#  (u'ii3P', u'pi2S'): <__main__.classesPaire instance at 0x10e21e5a8>,
#  (u'ai3P', u'pI1P'): <__main__.classesPaire instance at 0x107544518>,
#  (u'is2P', u'ppMP'): <__main__.classesPaire instance at 0x10d362e18>,
#  (u'fi1S', u'pc3S'): <__main__.classesPaire instance at 0x10d642200>,
#  (u'pc2P', u'ps1S'): <__main__.classesPaire instance at 0x10e88dd40>,
#  (u'fi1P', u'ai2S'): <__main__.classesPaire instance at 0x10e6e3908>,
#  (u'pc1P', u'ai3S'): <__main__.classesPaire instance at 0x10d5215a8>,
#  (u'ps3S', u'ii1S'): <__main__.classesPaire instance at 0x10d53d680>,
#  (u'is2P', u'ps3S'): <__main__.classesPaire instance at 0x10b7ac1b8>,
#  (u'ps3P', u'ii1S'): <__main__.classesPaire instance at 0x10e614200>,
#  (u'ppMS', u'is3P'): <__main__.classesPaire instance at 0x10cd3fbd8>,
#  (u'ii3S', u'is1S'): <__main__.classesPaire instance at 0x10d84ab48>,
#  (u'inf', u'ppMS'): <__main__.classesPaire instance at 0x10e81b878>,
#  (u'ppMS', u'ai2S'): <__main__.classesPaire instance at 0x10d6413f8>,
#  (u'pc2S', u'is2P'): <__main__.classesPaire instance at 0x10d84a3f8>,
#  (u'pi3P', u'ps2P'): <__main__.classesPaire instance at 0x10e3b9f38>,
#  (u'inf', u'pi2P'): <__main__.classesPaire instance at 0x10e886bd8>,
#  (u'ai2P', u'ii2P'): <__main__.classesPaire instance at 0x10d6423b0>,
#  (u'pi2P', u'pc3S'): <__main__.classesPaire instance at 0x10d57ccf8>,
#  (u'is3P', u'pc2S'): <__main__.classesPaire instance at 0x10d84a5a8>,
#  (u'fi3P', u'ppFS'): <__main__.classesPaire instance at 0x10daacd88>,
#  (u'ii2S', u'pi1S'): <__main__.classesPaire instance at 0x10e6f5758>,
#  (u'is2S', u'pc3S'): <__main__.classesPaire instance at 0x10d8da710>,
#  (u'ii2S', u'ai2P'): <__main__.classesPaire instance at 0x10d643638>,
#  (u'pP', u'ps1S'): <__main__.classesPaire instance at 0x10e8feb00>,
#  (u'pc3P', u'pc2P'): <__main__.classesPaire instance at 0x10e8e7b90>,
#  (u'fi3P', u'pi2S'): <__main__.classesPaire instance at 0x10e0d58c0>,
#  (u'ps1P', u'ii3P'): <__main__.classesPaire instance at 0x10cdc9290>,
#  (u'ps1S', u'ai1P'): <__main__.classesPaire instance at 0x10e3566c8>,
#  (u'is2S', u'ai1P'): <__main__.classesPaire instance at 0x10d54e518>,
#  (u'pc1S', u'pi2S'): <__main__.classesPaire instance at 0x10d8b9f38>,
#  (u'ps2S', u'fi1P'): <__main__.classesPaire instance at 0x10cad7cf8>,
#  (u'ii1P', u'ai3P'): <__main__.classesPaire instance at 0x10c4f8e60>,
#  (u'pI2P', u'ai1P'): <__main__.classesPaire instance at 0x1075924d0>,
#  (u'fi2S', u'ai3P'): <__main__.classesPaire instance at 0x10e800f38>,
#  (u'ii2S', u'ii1S'): <__main__.classesPaire instance at 0x10e21e2d8>,
#  (u'ps3S', u'is2S'): <__main__.classesPaire instance at 0x10cfa5878>,
#  (u'pI2P', u'pc3P'): <__main__.classesPaire instance at 0x10cf74908>,
#  (u'pc3S', u'ai1S'): <__main__.classesPaire instance at 0x1074eecb0>,
#  (u'ai2P', u'ps2P'): <__main__.classesPaire instance at 0x10cda82d8>,
#  (u'pc1P', u'ii2S'): <__main__.classesPaire instance at 0x10da8ef38>,
#  (u'pc1P', u'ii3P'): <__main__.classesPaire instance at 0x10e8e87e8>,
#  (u'pi1P', u'ai2S'): <__main__.classesPaire instance at 0x10d54ef80>,
#  (u'pi1S', u'ii2P'): <__main__.classesPaire instance at 0x10d6137a0>,
#  (u'ppFS', u'ii3S'): <__main__.classesPaire instance at 0x10d6953f8>,
#  (u'fi3P', u'ps3P'): <__main__.classesPaire instance at 0x10e6e3560>,
#  (u'ps3P', u'ps1S'): <__main__.classesPaire instance at 0x10fa99050>,
#  (u'ppMP', u'pc1S'): <__main__.classesPaire instance at 0x10e248a28>,
#  (u'ppFS', u'fi1P'): <__main__.classesPaire instance at 0x10cfa8908>,
#  (u'is1P', u'inf'): <__main__.classesPaire instance at 0x10d3886c8>,
#  (u'is1S', u'pc2S'): <__main__.classesPaire instance at 0x10e0e9b48>,
#  (u'ppFP', u'ppMP'): <__main__.classesPaire instance at 0x10e2f2638>,
#  (u'ps3S', u'fi2S'): <__main__.classesPaire instance at 0x10e80e560>,
#  (u'pP', u'is2S'): <__main__.classesPaire instance at 0x10d8da440>,
#  (u'ii3S', u'inf'): <__main__.classesPaire instance at 0x10e8e8e18>,
#  (u'ppFS', u'pi1S'): <__main__.classesPaire instance at 0x10f897e60>,
#  (u'ps2P', u'is3P'): <__main__.classesPaire instance at 0x10f8973f8>,
#  (u'ps2P', u'ps1P'): <__main__.classesPaire instance at 0x10cfa5cb0>,
#  (u'pc2P', u'is1S'): <__main__.classesPaire instance at 0x10e81b0e0>,
#  (u'ii1S', u'ai3P'): <__main__.classesPaire instance at 0x10e507b90>,
#  (u'ppFS', u'ai3S'): <__main__.classesPaire instance at 0x10fad3560>,
#  (u'is1P', u'ai1P'): <__main__.classesPaire instance at 0x10d5dca28>,
#  (u'is2P', u'ai2S'): <__main__.classesPaire instance at 0x1074d4b90>,
#  (u'pc3P', u'fi3P'): <__main__.classesPaire instance at 0x10daace18>,
#  (u'fi1P', u'ppMP'): <__main__.classesPaire instance at 0x10d826440>,
#  (u'ps1S', u'ps3S'): <__main__.classesPaire instance at 0x10fa99c20>,
#  (u'fi3P', u'pI2P'): <__main__.classesPaire instance at 0x10da8ed88>,
#  (u'pI1P', u'ai2P'): <__main__.classesPaire instance at 0x10e527680>,
#  (u'pi1S', u'pc2S'): <__main__.classesPaire instance at 0x10e8e8830>,
#  (u'pi2P', u'pi3S'): <__main__.classesPaire instance at 0x10cf15b48>,
#  (u'ii1P', u'pc2P'): <__main__.classesPaire instance at 0x10e364dd0>,
#  (u'ii1P', u'ii3S'): <__main__.classesPaire instance at 0x10e507f80>,
#  (u'ppMP', u'ps1S'): <__main__.classesPaire instance at 0x10e6e2cb0>,
#  (u'ppFP', u'pI2S'): <__main__.classesPaire instance at 0x10e5bf098>,
#  (u'pP', u'fi2P'): <__main__.classesPaire instance at 0x10d01be18>,
#  (u'ai3S', u'pi3P'): <__main__.classesPaire instance at 0x10e5d10e0>,
#  (u'pc1S', u'ps1P'): <__main__.classesPaire instance at 0x10cfa5ab8>,
#  (u'fi2S', u'pI2P'): <__main__.classesPaire instance at 0x10e6e3320>,
#  (u'pc1P', u'ai2S'): <__main__.classesPaire instance at 0x10d874cb0>,
#  (u'pi1P', u'pc3P'): <__main__.classesPaire instance at 0x10e850e18>,
#  (u'fi2S', u'is1P'): <__main__.classesPaire instance at 0x10e5d1290>,
#  (u'ppMS', u'ppMP'): <__main__.classesPaire instance at 0x10cf87830>,
#  (u'pc1S', u'ai3S'): <__main__.classesPaire instance at 0x10e3b1638>,
#  (u'pc1S', u'pI1P'): <__main__.classesPaire instance at 0x10e8e87a0>,
#  (u'pi2P', u'ppFP'): <__main__.classesPaire instance at 0x10d6e6098>,
#  (u'pP', u'ps1P'): <__main__.classesPaire instance at 0x10cf74e60>,
#  (u'is1P', u'pi1S'): <__main__.classesPaire instance at 0x10d8ec440>,
#  (u'ai2P', u'pc3S'): <__main__.classesPaire instance at 0x10d032050>,
#  (u'fi3P', u'ai1S'): <__main__.classesPaire instance at 0x10c53f638>,
#  (u'ii2S', u'ppMS'): <__main__.classesPaire instance at 0x10757cb48>,
#  (u'pi3P', u'ii1S'): <__main__.classesPaire instance at 0x10cd93248>,
#  (u'is2P', u'is2S'): <__main__.classesPaire instance at 0x10d537ab8>,
#  (u'ai1P', u'pP'): <__main__.classesPaire instance at 0x10cb014d0>,
#  (u'ai3P', u'is3P'): <__main__.classesPaire instance at 0x10d5725f0>,
#  (u'pI1P', u'ps3S'): <__main__.classesPaire instance at 0x10d6e6950>,
#  (u'ai1S', u'fi3P'): <__main__.classesPaire instance at 0x10bcb9128>,
#  (u'pi1P', u'pc2S'): <__main__.classesPaire instance at 0x10d5711b8>,
#  (u'ps1P', u'ai2P'): <__main__.classesPaire instance at 0x10d6433f8>,
#  (u'pc2S', u'pI1P'): <__main__.classesPaire instance at 0x10e67a9e0>,
#  (u'ii3P', u'fi3P'): <__main__.classesPaire instance at 0x10e6e3ea8>,
#  (u'pi2P', u'inf'): <__main__.classesPaire instance at 0x10d5b77a0>,
#  (u'ii2S', u'fi2S'): <__main__.classesPaire instance at 0x10eb98f80>,
#  (u'fi1S', u'ai3S'): <__main__.classesPaire instance at 0x10e5d1dd0>,
#  (u'fi3P', u'ii1S'): <__main__.classesPaire instance at 0x10e2071b8>,
#  (u'is1P', u'ai2P'): <__main__.classesPaire instance at 0x10d643ef0>,
#  (u'ppMP', u'fi3S'): <__main__.classesPaire instance at 0x10e296170>,
#  (u'is1S', u'pi2P'): <__main__.classesPaire instance at 0x10e0e97e8>,
#  (u'ps1S', u'ii2S'): <__main__.classesPaire instance at 0x10d6e8710>,
#  (u'is3P', u'ii2S'): <__main__.classesPaire instance at 0x10cf225a8>,
#  (u'ps3P', u'ai1P'): <__main__.classesPaire instance at 0x107516758>,
#  (u'pi3P', u'ii3S'): <__main__.classesPaire instance at 0x10cd937e8>,
#  (u'ii3S', u'pc2P'): <__main__.classesPaire instance at 0x10e594e18>,
#  (u'ai2P', u'ppMS'): <__main__.classesPaire instance at 0x10d6439e0>,
#  (u'is1S', u'ps3P'): <__main__.classesPaire instance at 0x10e8fecb0>,
#  (u'fi1P', u'fi2P'): <__main__.classesPaire instance at 0x10fad3dd0>,
#  (u'ii2S', u'ppFS'): <__main__.classesPaire instance at 0x10f8b9ab8>,
#  (u'fi1S', u'ppMS'): <__main__.classesPaire instance at 0x10d5391b8>,
#  (u'ai2S', u'fi2S'): <__main__.classesPaire instance at 0x10d572200>,
#  (u'is2P', u'pi2P'): <__main__.classesPaire instance at 0x10d890290>,
#  (u'pc2S', u'pc1S'): <__main__.classesPaire instance at 0x10e5bf758>,
#  (u'pc3S', u'pc3S'): <__main__.classesPaire instance at 0x10d537f38>,
#  (u'pi1P', u'is2S'): <__main__.classesPaire instance at 0x10d8daea8>,
#  (u'fi3P', u'inf'): <__main__.classesPaire instance at 0x10d53d638>,
#  (u'ppMS', u'ii1P'): <__main__.classesPaire instance at 0x10f8067e8>,
#  (u'pI2S', u'pc1S'): <__main__.classesPaire instance at 0x10d388b48>,
#  (u'ii1P', u'pc3S'): <__main__.classesPaire instance at 0x10e20c5a8>,
#  (u'pi3S', u'ps3S'): <__main__.classesPaire instance at 0x10d84a1b8>,
#  (u'pI1P', u'ppMS'): <__main__.classesPaire instance at 0x10daacb90>,
#  (u'fi2P', u'ai3S'): <__main__.classesPaire instance at 0x10f8a5d40>,
#  (u'ps3P', u'ai3S'): <__main__.classesPaire instance at 0x10e5d1998>,
#  (u'pc1P', u'pP'): <__main__.classesPaire instance at 0x10cdc4cb0>,
#  (u'pP', u'ai2P'): <__main__.classesPaire instance at 0x10e3b1f38>,
#  (u'fi2P', u'fi2S'): <__main__.classesPaire instance at 0x10c510320>,
#  (u'ii2P', u'ai3P'): <__main__.classesPaire instance at 0x10c55d878>,
#  (u'fi2S', u'fi2P'): <__main__.classesPaire instance at 0x1074f1d40>,
#  (u'is3S', u'ai3P'): <__main__.classesPaire instance at 0x10f8a5758>,
#  (u'is2S', u'fi2P'): <__main__.classesPaire instance at 0x10d53d7e8>,
#  (u'pI1P', u'ps2P'): <__main__.classesPaire instance at 0x10b7ac8c0>,
#  (u'ii1P', u'ai2S'): <__main__.classesPaire instance at 0x10e356098>,
#  (u'ai1S', u'ppMS'): <__main__.classesPaire instance at 0x10cad7dd0>,
#  (u'pc1S', u'ppFS'): <__main__.classesPaire instance at 0x10eb98c68>,
#  (u'ps3S', u'pc3S'): <__main__.classesPaire instance at 0x10cf87320>,
#  (u'fi2P', u'ppFP'): <__main__.classesPaire instance at 0x10e2e54d0>,
#  (u'is3S', u'pP'): <__main__.classesPaire instance at 0x10b7acea8>,
#  (u'ps2P', u'ppMS'): <__main__.classesPaire instance at 0x10cd3f200>,
#  (u'fi2P', u'is2P'): <__main__.classesPaire instance at 0x10f85e200>,
#  (u'ii2P', u'ai1P'): <__main__.classesPaire instance at 0x10d032758>,
#  (u'pi3S', u'pc2S'): <__main__.classesPaire instance at 0x10f8b9f38>,
#  (u'is1S', u'pc3P'): <__main__.classesPaire instance at 0x10eb86b48>,
#  (u'pi1P', u'ppFP'): <__main__.classesPaire instance at 0x10cdfb9e0>,
#  (u'ii1P', u'ii1P'): <__main__.classesPaire instance at 0x10e80e050>,
#  (u'ai1P', u'pI2S'): <__main__.classesPaire instance at 0x10e527b90>,
#  (u'ii2P', u'fi1P'): <__main__.classesPaire instance at 0x10d01b050>,
#  (u'ai3P', u'ps1P'): <__main__.classesPaire instance at 0x10e356c68>,
#  (u'ps1P', u'ppMS'): <__main__.classesPaire instance at 0x10e55ffc8>,
#  (u'pi3P', u'pI2P'): <__main__.classesPaire instance at 0x10d8ec3b0>,
#  (u'pc2S', u'fi2S'): <__main__.classesPaire instance at 0x10e21fd40>,
#  (u'is2P', u'ps1S'): <__main__.classesPaire instance at 0x10cdc9e18>,
#  (u'is3P', u'ai1P'): <__main__.classesPaire instance at 0x10e5277a0>,
#  (u'pI2S', u'ps1S'): <__main__.classesPaire instance at 0x10eb869e0>,
#  (u'ii1S', u'ii3P'): <__main__.classesPaire instance at 0x10e6149e0>,
#  (u'is2P', u'ai3P'): <__main__.classesPaire instance at 0x10f7cdb48>,
#  (u'pi2S', u'fi1P'): <__main__.classesPaire instance at 0x10e8002d8>,
#  (u'pc1P', u'is2P'): <__main__.classesPaire instance at 0x10e5bf7a0>,
#  (u'pi2P', u'pi2P'): <__main__.classesPaire instance at 0x10e850fc8>,
#  (u'ii1P', u'ii2P'): <__main__.classesPaire instance at 0x10e2e56c8>,
#  (u'ppFP', u'is2P'): <__main__.classesPaire instance at 0x10d5376c8>,
#  (u'pc2P', u'ai1S'): <__main__.classesPaire instance at 0x10e800cf8>,
#  (u'is2S', u'pc2P'): <__main__.classesPaire instance at 0x10d8dacb0>,
#  (u'fi1P', u'pI2P'): <__main__.classesPaire instance at 0x10d521710>,
#  (u'pc2S', u'ppFS'): <__main__.classesPaire instance at 0x10cf87440>,
#  (u'fi2S', u'pi3P'): <__main__.classesPaire instance at 0x10e3b1c20>,
#  (u'is3P', u'pi1S'): <__main__.classesPaire instance at 0x10d8ed680>,
#  (u'ps2P', u'pI2P'): <__main__.classesPaire instance at 0x10eb55290>,
#  (u'pc2S', u'fi1S'): <__main__.classesPaire instance at 0x10c4d7320>,
#  (u'fi2S', u'pc2P'): <__main__.classesPaire instance at 0x10daaccf8>,
#  (u'pc1P', u'ai1P'): <__main__.classesPaire instance at 0x10cbf67a0>,
#  (u'fi2S', u'is3S'): <__main__.classesPaire instance at 0x10da8e9e0>,
#  (u'ps2S', u'pi1S'): <__main__.classesPaire instance at 0x10eb55368>,
#  (u'fi2S', u'ps1S'): <__main__.classesPaire instance at 0x10e57a7a0>,
#  (u'ps2P', u'ii1S'): <__main__.classesPaire instance at 0x10c510878>,
#  (u'pc2P', u'ii3S'): <__main__.classesPaire instance at 0x10e594830>,
#  (u'pc1S', u'ps3S'): <__main__.classesPaire instance at 0x10e8e74d0>,
#  (u'ppMP', u'pc3S'): <__main__.classesPaire instance at 0x10d554710>,
#  (u'ai1S', u'fi1P'): <__main__.classesPaire instance at 0x107558c20>,
#  (u'ppMS', u'pI2P'): <__main__.classesPaire instance at 0x10e886f38>,
#  (u'pi3P', u'ai2P'): <__main__.classesPaire instance at 0x10e3b1e60>,
#  (u'is1S', u'inf'): <__main__.classesPaire instance at 0x10f8063f8>,
#  (u'is2S', u'pi2P'): <__main__.classesPaire instance at 0x10cd9be18>,
#  (u'ps1P', u'pc3S'): <__main__.classesPaire instance at 0x10d57cd88>,
#  (u'pi3P', u'is3S'): <__main__.classesPaire instance at 0x10cdc9c20>,
#  (u'pI1P', u'is2S'): <__main__.classesPaire instance at 0x10b7acc68>,
#  (u'ii1P', u'ppMP'): <__main__.classesPaire instance at 0x10c69d7a0>,
#  (u'ai2P', u'is3P'): <__main__.classesPaire instance at 0x10e5270e0>,
#  (u'ppMP', u'ii3S'): <__main__.classesPaire instance at 0x10d5caab8>,
#  (u'is1S', u'is1P'): <__main__.classesPaire instance at 0x10eb984d0>,
#  (u'ps2P', u'ai2P'): <__main__.classesPaire instance at 0x10cda8e60>,
#  (u'pi2S', u'pc3P'): <__main__.classesPaire instance at 0x10e886cf8>,
#  (u'fi1S', u'fi3S'): <__main__.classesPaire instance at 0x10cbf6f38>,
#  (u'pc1P', u'pi1S'): <__main__.classesPaire instance at 0x10e296710>,
#  (u'ps1S', u'pc2S'): <__main__.classesPaire instance at 0x10d847560>,
#  (u'ps3S', u'ii2S'): <__main__.classesPaire instance at 0x10e2e5758>,
#  (u'pI2P', u'fi1P'): <__main__.classesPaire instance at 0x10d521488>,
#  (u'ai3P', u'is2S'): <__main__.classesPaire instance at 0x10d539638>,
#  (u'ai3P', u'ppMP'): <__main__.classesPaire instance at 0x10f7cd320>,
#  (u'fi2S', u'fi1S'): <__main__.classesPaire instance at 0x10cbf66c8>,
#  (u'is3S', u'ai1S'): <__main__.classesPaire instance at 0x10e2e5560>,
#  (u'ii2S', u'ps2S'): <__main__.classesPaire instance at 0x10d8ed200>,
#  (u'ai2P', u'ai2P'): <__main__.classesPaire instance at 0x10a1b75f0>,
#  (u'pc2P', u'ps2S'): <__main__.classesPaire instance at 0x10cf15cb0>,
#  (u'pi2S', u'ai2S'): <__main__.classesPaire instance at 0x10f8a5b90>,
#  (u'pI2S', u'pI1P'): <__main__.classesPaire instance at 0x10cd93200>,
#  (u'pI2S', u'is1S'): <__main__.classesPaire instance at 0x10e0e98c0>,
#  (u'pc3S', u'ppFP'): <__main__.classesPaire instance at 0x10e6f55f0>,
#  (u'ai1P', u'pi3P'): <__main__.classesPaire instance at 0x1075523b0>,
#  (u'pP', u'ppFP'): <__main__.classesPaire instance at 0x10d6959e0>,
#  (u'ppMS', u'ps2P'): <__main__.classesPaire instance at 0x10e88df38>,
#  (u'ii1P', u'pI1P'): <__main__.classesPaire instance at 0x10d8ec908>,
#  (u'pc3P', u'is1S'): <__main__.classesPaire instance at 0x10e0e93b0>,
#  (u'ai1P', u'pc1P'): <__main__.classesPaire instance at 0x10cbf6518>,
#  (u'ps1P', u'pc2P'): <__main__.classesPaire instance at 0x10d5710e0>,
#  (u'pP', u'pi1S'): <__main__.classesPaire instance at 0x10e8e7050>,
#  (u'ai1P', u'is3S'): <__main__.classesPaire instance at 0x10e527488>,
#  (u'fi2P', u'ai2P'): <__main__.classesPaire instance at 0x10dabe710>,
#  (u'ai1S', u'ai1S'): <__main__.classesPaire instance at 0x10d539e18>,
#  (u'is1P', u'fi1P'): <__main__.classesPaire instance at 0x109fb9248>,
#  (u'pI1P', u'ps1S'): <__main__.classesPaire instance at 0x10e8fef80>,
#  (u'ai3S', u'ai1S'): <__main__.classesPaire instance at 0x10c3a6440>,
#  (u'ii2P', u'pc1P'): <__main__.classesPaire instance at 0x10e6f5908>,
#  (u'pi2P', u'is3P'): <__main__.classesPaire instance at 0x10d890710>,
#  (u'pI1P', u'ai3P'): <__main__.classesPaire instance at 0x1075047e8>,
#  (u'ps2P', u'fi2P'): <__main__.classesPaire instance at 0x10d8ed368>,
#  (u'pc2S', u'pc2S'): <__main__.classesPaire instance at 0x10f88d5a8>,
#  (u'pi3P', u'is2P'): <__main__.classesPaire instance at 0x10e594b00>,
#  (u'pi2S', u'pi2S'): <__main__.classesPaire instance at 0x10e67ad88>,
#  (u'fi3S', u'pi2P'): <__main__.classesPaire instance at 0x10d826dd0>,
#  (u'ii1S', u'is2S'): <__main__.classesPaire instance at 0x10e2075f0>,
#  (u'ai1S', u'pi1P'): <__main__.classesPaire instance at 0x10e6e3710>,
#  (u'ai3P', u'inf'): <__main__.classesPaire instance at 0x10d641560>,
#  (u'pP', u'pc3P'): <__main__.classesPaire instance at 0x10cdc4c68>,
#  (u'ai3S', u'pi1P'): <__main__.classesPaire instance at 0x1074f8710>,
#  (u'ai2S', u'pi3S'): <__main__.classesPaire instance at 0x10eb04638>,
#  (u'is1S', u'ps1P'): <__main__.classesPaire instance at 0x10d362050>,
#  (u'is1P', u'fi3S'): <__main__.classesPaire instance at 0x10d521e60>,
#  (u'ps2S', u'ai3P'): <__main__.classesPaire instance at 0x10c4f8320>,
#  (u'pc1S', u'ii2S'): <__main__.classesPaire instance at 0x10d847a70>,
#  (u'pc2P', u'is2S'): <__main__.classesPaire instance at 0x10d8da7a0>,
#  (u'pc1S', u'fi2S'): <__main__.classesPaire instance at 0x10da8eea8>,
#  (u'ppFS', u'pc2P'): <__main__.classesPaire instance at 0x10d52a1b8>,
#  (u'fi3P', u'is2S'): <__main__.classesPaire instance at 0x10da8e4d0>,
#  (u'ii2P', u'ps2S'): <__main__.classesPaire instance at 0x10e20c950>,
#  (u'pi1P', u'inf'): <__main__.classesPaire instance at 0x10e81b1b8>,
#  (u'ii3P', u'is2S'): <__main__.classesPaire instance at 0x10f806200>,
#  (u'fi2P', u'ii3P'): <__main__.classesPaire instance at 0x10e0d5320>,
#  (u'ii1S', u'ppMS'): <__main__.classesPaire instance at 0x10eb86170>,
#  (u'ai1S', u'ps3P'): <__main__.classesPaire instance at 0x103e243f8>,
#  (u'pc3P', u'ai1P'): <__main__.classesPaire instance at 0x10d5dc7a0>,
#  (u'fi2S', u'pi2S'): <__main__.classesPaire instance at 0x10e6ffab8>,
#  (u'fi3S', u'inf'): <__main__.classesPaire instance at 0x10da45998>,
#  (u'ii2S', u'pI2S'): <__main__.classesPaire instance at 0x10e2403b0>,
#  (u'ps3S', u'pi2S'): <__main__.classesPaire instance at 0x10e6e23f8>,
#  (u'ii1P', u'ps1S'): <__main__.classesPaire instance at 0x10d8ecab8>,
#  (u'ii1P', u'is3S'): <__main__.classesPaire instance at 0x10d8ed638>,
#  (u'ii2S', u'ii2S'): <__main__.classesPaire instance at 0x10e207ab8>,
#  (u'fi2P', u'fi1P'): <__main__.classesPaire instance at 0x10d643128>,
#  (u'ps3P', u'pc3S'): <__main__.classesPaire instance at 0x10cf15f38>,
#  (u'pc1S', u'ppMP'): <__main__.classesPaire instance at 0x10743af80>,
#  (u'ppMS', u'pc1P'): <__main__.classesPaire instance at 0x10e850908>,
#  (u'pP', u'ii2S'): <__main__.classesPaire instance at 0x10e5b0fc8>,
#  (u'fi2P', u'ppMS'): <__main__.classesPaire instance at 0x10e800710>,
#  (u'ai1P', u'ppMS'): <__main__.classesPaire instance at 0x10cad7a70>,
#  (u'pc3S', u'ii2S'): <__main__.classesPaire instance at 0x10e65d098>,
#  (u'pi1S', u'pi3S'): <__main__.classesPaire instance at 0x10b7acd40>,
#  (u'ai3P', u'ai1S'): <__main__.classesPaire instance at 0x10d5725a8>,
#  (u'fi2S', u'ii1S'): <__main__.classesPaire instance at 0x10e20c1b8>,
#  (u'ppMS', u'pP'): <__main__.classesPaire instance at 0x10f7c8bd8>,
#  (u'pc3S', u'pi2S'): <__main__.classesPaire instance at 0x10e88d8c0>,
#  (u'ii1P', u'pc3P'): <__main__.classesPaire instance at 0x10e21eb90>,
#  (u'fi1S', u'pI1P'): <__main__.classesPaire instance at 0x10d8263f8>,
#  (u'pi1P', u'ai3S'): <__main__.classesPaire instance at 0x10e527cb0>,
#  (u'fi1S', u'is1S'): <__main__.classesPaire instance at 0x10d8ed908>,
#  (u'ii3P', u'pi3S'): <__main__.classesPaire instance at 0x10d847ea8>,
#  (u'is2S', u'ppMP'): <__main__.classesPaire instance at 0x10cd9b098>,
#  (u'ps1P', u'fi3P'): <__main__.classesPaire instance at 0x10e6142d8>,
#  (u'pc3P', u'ppFS'): <__main__.classesPaire instance at 0x10cd3ff38>,
#  (u'pc1P', u'pi3P'): <__main__.classesPaire instance at 0x10743a128>,
#  (u'pI2P', u'fi3P'): <__main__.classesPaire instance at 0x10f7f6248>,
#  (u'pi3P', u'ai3S'): <__main__.classesPaire instance at 0x10e364cf8>,
#  (u'ii3S', u'ps1S'): <__main__.classesPaire instance at 0x10f806ef0>,
#  (u'pi1S', u'pc3S'): <__main__.classesPaire instance at 0x10e850cb0>,
#  (u'ppMS', u'ii2S'): <__main__.classesPaire instance at 0x10e57a098>,
#  (u'fi2S', u'ai2P'): <__main__.classesPaire instance at 0x10d539e60>,
#  (u'fi2S', u'pi1S'): <__main__.classesPaire instance at 0x10e6ffb00>,
#  (u'ai2S', u'ii1P'): <__main__.classesPaire instance at 0x10e356e18>,
#  (u'ii3S', u'pc3S'): <__main__.classesPaire instance at 0x10d8ec098>,
#  (u'fi3S', u'ppFS'): <__main__.classesPaire instance at 0x10e8e8518>,
#  (u'ps3S', u'ai2P'): <__main__.classesPaire instance at 0x10cda8ab8>,
#  (u'ppMP', u'ai2S'): <__main__.classesPaire instance at 0x10d641cb0>,
#  (u'ii2S', u'is1S'): <__main__.classesPaire instance at 0x10d01b170>,
#  (u'ai2P', u'pP'): <__main__.classesPaire instance at 0x10e3b1368>,
#  (u'pI2S', u'pP'): <__main__.classesPaire instance at 0x10f8b93f8>,
#  (u'fi2S', u'pc3P'): <__main__.classesPaire instance at 0x10d8ed950>,
#  (u'ai1P', u'is2S'): <__main__.classesPaire instance at 0x10d572e60>,
#  (u'ai1P', u'pi2S'): <__main__.classesPaire instance at 0x10e3b1560>,
#  (u'pI1P', u'ii3S'): <__main__.classesPaire instance at 0x10d032878>,
#  (u'pc2S', u'ii1S'): <__main__.classesPaire instance at 0x10d032d40>,
#  (u'ai1P', u'ppFS'): <__main__.classesPaire instance at 0x10c55d638>,
#  (u'pi2P', u'ppMS'): <__main__.classesPaire instance at 0x10d57c7e8>,
#  (u'is1S', u'ppFP'): <__main__.classesPaire instance at 0x10d8e6758>,
#  (u'ii1P', u'ps2P'): <__main__.classesPaire instance at 0x10fad37a0>,
#  (u'pc1P', u'ps1S'): <__main__.classesPaire instance at 0x10d5caa28>,
#  (u'ai3P', u'pi1S'): <__main__.classesPaire instance at 0x10eb04710>,
#  (u'pc1S', u'inf'): <__main__.classesPaire instance at 0x10d695d88>,
#  (u'ii1S', u'ai2P'): <__main__.classesPaire instance at 0x10d6425a8>,
#  (u'is3P', u'fi1P'): <__main__.classesPaire instance at 0x1075029e0>,
#  (u'pi2S', u'pI2P'): <__main__.classesPaire instance at 0x10e886908>,
#  (u'ii1S', u'fi2S'): <__main__.classesPaire instance at 0x10e20cd40>,
#  (u'ii3P', u'pc1P'): <__main__.classesPaire instance at 0x10e886950>,
#  (u'ii3S', u'ai1S'): <__main__.classesPaire instance at 0x10d539908>,
#  (u'pi2S', u'ii1P'): <__main__.classesPaire instance at 0x10da45b48>,
#  (u'ii3P', u'ai2S'): <__main__.classesPaire instance at 0x10a1b7c68>,
#  (u'is3P', u'is1S'): <__main__.classesPaire instance at 0x10d8b94d0>,
#  (u'is2P', u'pc3P'): <__main__.classesPaire instance at 0x10e8fe1b8>,
#  (u'pi3P', u'fi2P'): <__main__.classesPaire instance at 0x10d521638>,
#  (u'fi1P', u'pi2P'): <__main__.classesPaire instance at 0x10eb04488>,
#  (u'pi2S', u'pi3P'): <__main__.classesPaire instance at 0x10e5bfea8>,
#  (u'is3S', u'pc1S'): <__main__.classesPaire instance at 0x10cf87518>,
#  (u'pi3S', u'is1P'): <__main__.classesPaire instance at 0x10d69c6c8>,
#  (u'ai2P', u'fi1S'): <__main__.classesPaire instance at 0x10e2e5c20>,
#  (u'ppMS', u'ai1P'): <__main__.classesPaire instance at 0x10c62e950>,
#  (u'fi1S', u'ps3S'): <__main__.classesPaire instance at 0x10f7cd758>,
#  (u'pI1P', u'is2P'): <__main__.classesPaire instance at 0x10e67a560>,
# ...
#  (u'ppFS', u'ii2S'): <__main__.classesPaire instance at 0x10f8b9128>,
#  (u'is3P', u'ps2S'): <__main__.classesPaire instance at 0x10cd9b638>,
#  (u'pi1S', u'pc2P'): <__main__.classesPaire instance at 0x10e8e7560>,
#  (u'pc3S', u'ppMP'): <__main__.classesPaire instance at 0x10d6e6560>,
#  (u'ppFS', u'pi2S'): <__main__.classesPaire instance at 0x10cf72830>,
#  (u'ps3P', u'pi1S'): <__main__.classesPaire instance at 0x10cdfbc20>,
#  (u'ii2P', u'pi1S'): <__main__.classesPaire instance at 0x10d6138c0>,
#  (u'fi1P', u'pi3S'): <__main__.classesPaire instance at 0x10e507ea8>,
#  (u'ii3P', u'pi1S'): <__main__.classesPaire instance at 0x10f8b9bd8>,
#  (u'pi2P', u'is1P'): <__main__.classesPaire instance at 0x10d8b9908>,
#  (u'pi1S', u'is1S'): <__main__.classesPaire instance at 0x10cdc9488>,
#  (u'ii1S', u'pc3P'): <__main__.classesPaire instance at 0x10d826710>,
#  (u'pi2S', u'is3P'): <__main__.classesPaire instance at 0x10cd9bab8>,
#  (u'fi2S', u'pI2S'): <__main__.classesPaire instance at 0x10d641c68>,
#  (u'pi2P', u'pP'): <__main__.classesPaire instance at 0x10e850c68>,
#  (u'is2S', u'ppFS'): <__main__.classesPaire instance at 0x10d8da0e0>,
#  (u'ps1S', u'fi2S'): <__main__.classesPaire instance at 0x10d874440>,
#  (u'ii2S', u'pi2S'): <__main__.classesPaire instance at 0x10d8ed4d0>,
#  (u'ai1P', u'ai3S'): <__main__.classesPaire instance at 0x10d572908>,
#  (u'pc2P', u'pc1S'): <__main__.classesPaire instance at 0x10cd93050>,
#  (u'pc2P', u'inf'): <__main__.classesPaire instance at 0x10e5b0830>,
#  (u'ai2P', u'pc3P'): <__main__.classesPaire instance at 0x10754c710>,
#  (u'pi3P', u'pc3S'): <__main__.classesPaire instance at 0x10e2f2518>,
#  (u'ii2S', u'ppMP'): <__main__.classesPaire instance at 0x10f8b9a70>,
#  (u'ai3P', u'ppFS'): <__main__.classesPaire instance at 0x10d874248>,
#  (u'ii1P', u'fi3P'): <__main__.classesPaire instance at 0x10e240998>,
#  (u'ppMP', u'is3S'): <__main__.classesPaire instance at 0x10e2487a0>,
#  (u'is1S', u'ii1S'): <__main__.classesPaire instance at 0x10e6f53f8>,
#  (u'pi1P', u'ps2S'): <__main__.classesPaire instance at 0x10cd3fef0>,
#  (u'ppMP', u'ai3P'): <__main__.classesPaire instance at 0x10e800dd0>,
#  (u'pi1P', u'ii3P'): <__main__.classesPaire instance at 0x10e3b1098>,
#  (u'pi1P', u'ii1P'): <__main__.classesPaire instance at 0x10e2966c8>,
#  (u'is3S', u'pc2S'): <__main__.classesPaire instance at 0x10e8e8248>,
#  (u'pi1S', u'ps1P'): <__main__.classesPaire instance at 0x10e2f26c8>,
#  (u'ai1S', u'pc2S'): <__main__.classesPaire instance at 0x10e527050>,
#  (u'ii3P', u'ai3S'): <__main__.classesPaire instance at 0x10e35b098>,
#  (u'ps3P', u'fi2S'): <__main__.classesPaire instance at 0x109fe3e18>,
#  (u'fi3S', u'pc1P'): <__main__.classesPaire instance at 0x10d5ca950>,
#  (u'ps2S', u'pc2S'): <__main__.classesPaire instance at 0x10d84aa70>,
#  (u'pc1S', u'ps2P'): <__main__.classesPaire instance at 0x10e3b19e0>,
#  (u'ii3P', u'ps1P'): <__main__.classesPaire instance at 0x10cdc9368>,
#  (u'is2S', u'is1S'): <__main__.classesPaire instance at 0x10d8b91b8>,
#  (u'fi1S', u'ai3P'): <__main__.classesPaire instance at 0x10a1b7638>,
#  (u'pi1S', u'ai3S'): <__main__.classesPaire instance at 0x10cad7cb0>,
#  (u'is3P', u'inf'): <__main__.classesPaire instance at 0x10e65d3b0>,
#  (u'fi3S', u'pi3P'): <__main__.classesPaire instance at 0x10d53d7a0>,
#  (u'ai2S', u'ai1S'): <__main__.classesPaire instance at 0x10d572440>,
#  (u'ai2P', u'pi2S'): <__main__.classesPaire instance at 0x10d54e1b8>,
#  (u'ii3S', u'pc2S'): <__main__.classesPaire instance at 0x10d537b48>,
#  (u'pi1P', u'ai1P'): <__main__.classesPaire instance at 0x10d5dc878>,
#  (u'pi2P', u'ps1P'): <__main__.classesPaire instance at 0x10743ac20>,
#  (u'ii2P', u'pI2S'): <__main__.classesPaire instance at 0x10c69d170>,
#  (u'ai1S', u'pI1P'): <__main__.classesPaire instance at 0x10b8c0c20>,
#  (u'pc3P', u'ai2S'): <__main__.classesPaire instance at 0x10d572560>,
#  (u'fi1P', u'fi2S'): <__main__.classesPaire instance at 0x10e6e3998>,
#  (u'ii3P', u'ppFP'): <__main__.classesPaire instance at 0x10c69d128>,
#  (u'ps3S', u'pi1P'): <__main__.classesPaire instance at 0x10e6e2cf8>,
#  (u'ppMP', u'pi1S'): <__main__.classesPaire instance at 0x10ebaa2d8>,
#  (u'pi2S', u'ii2S'): <__main__.classesPaire instance at 0x10e240098>,
#  (u'ii1S', u'ii2S'): <__main__.classesPaire instance at 0x10daacb48>,
#  (u'is2P', u'pi2S'): <__main__.classesPaire instance at 0x10e5b0440>,
#  (u'pI2P', u'pi2S'): <__main__.classesPaire instance at 0x10d8b9440>,
#  (u'ps2P', u'pi3S'): <__main__.classesPaire instance at 0x10d538998>,
#  (u'ps2P', u'is2P'): <__main__.classesPaire instance at 0x10e5bf1b8>,
#  (u'ii1P', u'pI2S'): <__main__.classesPaire instance at 0x10e0d5878>,
#  (u'pc2S', u'pc1P'): <__main__.classesPaire instance at 0x10d554560>,
#  (u'is3P', u'ii1S'): <__main__.classesPaire instance at 0x10e21f128>,
#  (u'ppMS', u'ii1S'): <__main__.classesPaire instance at 0x10eb86d40>,
#  (u'ai1S', u'pI2S'): <__main__.classesPaire instance at 0x10c6e9ea8>,
#  (u'pi2S', u'is1P'): <__main__.classesPaire instance at 0x10d8b93f8>,
#  (u'fi1S', u'is3P'): <__main__.classesPaire instance at 0x10e8fac20>,
#  (u'pc2S', u'pI2S'): <__main__.classesPaire instance at 0x10c69db00>,
#  (u'ii1S', u'is1P'): <__main__.classesPaire instance at 0x10e296b00>,
#  (u'is3P', u'ai1S'): <__main__.classesPaire instance at 0x10c704d40>,
#  (u'ai3S', u'ai2S'): <__main__.classesPaire instance at 0x10e356170>,
#  (u'pc3S', u'pi1P'): <__main__.classesPaire instance at 0x10cdd0518>,
#  (u'ppFS', u'fi1S'): <__main__.classesPaire instance at 0x10dabecb0>,
#  (u'fi2P', u'fi2P'): <__main__.classesPaire instance at 0x10d8edab8>,
#  (u'ps3P', u'pc2S'): <__main__.classesPaire instance at 0x10d5f7638>,
#  (u'ps2S', u'ps1S'): <__main__.classesPaire instance at 0x10e0e90e0>,
#  (u'is3S', u'ai3S'): <__main__.classesPaire instance at 0x10e364e18>,
#  (u'ppFP', u'is3P'): <__main__.classesPaire instance at 0x10d8da830>,
#  (u'is3P', u'pi3S'): <__main__.classesPaire instance at 0x10eb86290>,
#  (u'is1S', u'ai2P'): <__main__.classesPaire instance at 0x10e8003f8>,
#  (u'pi3S', u'fi2S'): <__main__.classesPaire instance at 0x10e20c200>,
#  (u'ps3S', u'is3S'): <__main__.classesPaire instance at 0x10d8e6b00>,
#  (u'fi2P', u'ppFS'): <__main__.classesPaire instance at 0x10e0d59e0>,
#  (u'fi2S', u'ps2S'): <__main__.classesPaire instance at 0x10d642c68>,
#  (u'pi3P', u'ppFS'): <__main__.classesPaire instance at 0x10d6aab00>,
#  (u'pi3P', u'fi3S'): <__main__.classesPaire instance at 0x10e507758>,
#  (u'fi2P', u'is2S'): <__main__.classesPaire instance at 0x10eb98b00>,
#  (u'ii2P', u'ai1S'): <__main__.classesPaire instance at 0x10e527a70>,
#  (u'ai1S', u'ppFS'): <__main__.classesPaire instance at 0x10d539758>,
#  (u'fi1S', u'ppFS'): <__main__.classesPaire instance at 0x10d874758>,
#  (u'ps2P', u'inf'): <__main__.classesPaire instance at 0x10d362f80>,
#  (u'pc2S', u'ps1P'): <__main__.classesPaire instance at 0x10e88d998>,
#  (u'pc3P', u'pP'): <__main__.classesPaire instance at 0x10cdc4f80>,
#  (u'ai3P', u'ps1S'): <__main__.classesPaire instance at 0x10c466b90>,
#  (u'ai3P', u'pI2S'): <__main__.classesPaire instance at 0x10d642ab8>,
#  (u'ai2P', u'pi3S'): <__main__.classesPaire instance at 0x10e3b1cb0>,
#  (u'ii2S', u'is2P'): <__main__.classesPaire instance at 0x10e2400e0>,
#  (u'ppMS', u'fi1S'): <__main__.classesPaire instance at 0x10d54ec20>,
#  (u'fi1S', u'pc2S'): <__main__.classesPaire instance at 0x10a1b7170>,
#  (u'pc2P', u'pi2P'): <__main__.classesPaire instance at 0x10e5bf878>,
#  (u'pc1S', u'is2S'): <__main__.classesPaire instance at 0x10d8dad40>,
#  (u'pc3S', u'ps2S'): <__main__.classesPaire instance at 0x10e8509e0>,
#  (u'is2P', u'ps1P'): <__main__.classesPaire instance at 0x10d890998>,
#  (u'ps1P', u'ppFS'): <__main__.classesPaire instance at 0x10da72638>,
#  (u'pi2S', u'fi3S'): <__main__.classesPaire instance at 0x10d5cad88>,
#  (u'is2P', u'ai3S'): <__main__.classesPaire instance at 0x10d01be60>,
#  (u'inf', u'fi2P'): <__main__.classesPaire instance at 0x1074cfbd8>,
#  (u'fi1S', u'ii1S'): <__main__.classesPaire instance at 0x10dabee60>,
#  (u'is1P', u'ps2S'): <__main__.classesPaire instance at 0x10f806f80>,
#  (u'pc1P', u'fi2P'): <__main__.classesPaire instance at 0x10d56c4d0>,
#  (u'fi1S', u'is2S'): <__main__.classesPaire instance at 0x10d8ed488>,
#  (u'ps2S', u'pc1S'): <__main__.classesPaire instance at 0x10d8b9d88>,
#  (u'pP', u'inf'): <__main__.classesPaire instance at 0x10d84a998>,
#  (u'pc2P', u'ai1P'): <__main__.classesPaire instance at 0x10d032ea8>,
#  (u'ps3P', u'ps2S'): <__main__.classesPaire instance at 0x10da62ea8>,
#  (u'fi1P', u'ps1S'): <__main__.classesPaire instance at 0x10dabeef0>,
#  (u'pc3P', u'ppMP'): <__main__.classesPaire instance at 0x10d52ad88>,
#  (u'ai3P', u'ps2P'): <__main__.classesPaire instance at 0x107394cf8>,
#  (u'ii1S', u'pP'): <__main__.classesPaire instance at 0x1074fb368>,
#  (u'pI2S', u'ai3P'): <__main__.classesPaire instance at 0x10d6419e0>,
#  (u'pc2S', u'fi1P'): <__main__.classesPaire instance at 0x10e35b758>,
#  (u'ppFS', u'pI2P'): <__main__.classesPaire instance at 0x10cf15488>,
#  (u'fi1S', u'pi1P'): <__main__.classesPaire instance at 0x10d642878>,
#  (u'pI2S', u'fi2P'): <__main__.classesPaire instance at 0x10fad35a8>,
#  (u'pc1P', u'ai1S'): <__main__.classesPaire instance at 0x10e2e5b48>,
#  (u'ii2P', u'inf'): <__main__.classesPaire instance at 0x10d5b7ab8>,
#  (u'ii2P', u'pi1P'): <__main__.classesPaire instance at 0x10e5b0cb0>,
#  (u'fi2S', u'ps1P'): <__main__.classesPaire instance at 0x10d6e8638>,
#  (u'ai1P', u'ii2S'): <__main__.classesPaire instance at 0x10cbf6e18>,
#  (u'ai3P', u'is1S'): <__main__.classesPaire instance at 0x10e356b48>,
#  (u'is2S', u'fi3P'): <__main__.classesPaire instance at 0x10da8e368>,
#  (u'ps2P', u'ii1P'): <__main__.classesPaire instance at 0x10d6e8e60>,
#  (u'ai3S', u'ppMP'): <__main__.classesPaire instance at 0x10fad3128>,
#  (u'fi3S', u'is1P'): <__main__.classesPaire instance at 0x10d56c830>,
#  (u'ai3S', u'pi2P'): <__main__.classesPaire instance at 0x10e800d88>,
#  (u'is3S', u'ii2S'): <__main__.classesPaire instance at 0x10e614170>,
#  (u'ps1P', u'pc3P'): <__main__.classesPaire instance at 0x10d571518>,
#  (u'ai2P', u'is3S'): <__main__.classesPaire instance at 0x10e527758>,
#  (u'is1S', u'ppMS'): <__main__.classesPaire instance at 0x10e8fecf8>,
#  (u'fi3S', u'ii2S'): <__main__.classesPaire instance at 0x10d8740e0>,
#  (u'pc3S', u'pI1P'): <__main__.classesPaire instance at 0x10cdc4878>,
#  (u'pi3P', u'pi2P'): <__main__.classesPaire instance at 0x10d5a1b48>,
#  (u'ps3P', u'is3S'): <__main__.classesPaire instance at 0x10cfa8d40>,
#  (u'fi3S', u'pi2S'): <__main__.classesPaire instance at 0x10d5ca998>,
#  (u'pc1P', u'pi1P'): <__main__.classesPaire instance at 0x10d5f7998>,
#  (u'pc2P', u'pi3P'): <__main__.classesPaire instance at 0x10e88db48>,
#  (u'pc3S', u'ps1P'): <__main__.classesPaire instance at 0x10d57c5f0>,
#  (u'pI2S', u'is3P'): <__main__.classesPaire instance at 0x10d8daef0>,
#  (u'pI2P', u'fi1S'): <__main__.classesPaire instance at 0x10d874cf8>,
#  (u'fi1S', u'ii2S'): <__main__.classesPaire instance at 0x10e800638>,
#  (u'ii3P', u'pI2S'): <__main__.classesPaire instance at 0x10daaca70>,
#  (u'ai3P', u'fi2S'): <__main__.classesPaire instance at 0x10e800950>,
#  (u'ii1S', u'ps3P'): <__main__.classesPaire instance at 0x10e614b48>,
#  (u'ps1P', u'pI2P'): <__main__.classesPaire instance at 0x10f897878>,
#  (u'pP', u'ppMP'): <__main__.classesPaire instance at 0x10f7c8ab8>,
#  (u'pc2P', u'ii2S'): <__main__.classesPaire instance at 0x10d8edcb0>,
#  (u'inf', u'pc2S'): <__main__.classesPaire instance at 0x10cd3ff80>,
#  (u'pI1P', u'pc3P'): <__main__.classesPaire instance at 0x10d8e6d40>,
#  (u'pc3S', u'ppFS'): <__main__.classesPaire instance at 0x10e5945a8>,
#  (u'fi3P', u'pc3P'): <__main__.classesPaire instance at 0x10daac710>,
#  (u'pi3P', u'ps3S'): <__main__.classesPaire instance at 0x10e3b9950>,
#  (u'pI2P', u'pi3P'): <__main__.classesPaire instance at 0x10eb86c20>,
#  (u'ppMS', u'ps2S'): <__main__.classesPaire instance at 0x10cfa5290>,
#  (u'ps2P', u'pi2P'): <__main__.classesPaire instance at 0x10e3b9e60>,
#  (u'ps1P', u'ii2S'): <__main__.classesPaire instance at 0x10d3625f0>,
#  (u'pi2S', u'ai3S'): <__main__.classesPaire instance at 0x10e6ff908>,
#  (u'pI2S', u'pi3P'): <__main__.classesPaire instance at 0x10d6e88c0>,
#  (u'pc2P', u'pP'): <__main__.classesPaire instance at 0x10e81b5a8>,
#  (u'ps1P', u'pc2S'): <__main__.classesPaire instance at 0x10e88dbd8>,
#  (u'pc1P', u'pI2P'): <__main__.classesPaire instance at 0x10eb86440>,
#  (u'ps2P', u'ps3P'): <__main__.classesPaire instance at 0x10e3048c0>,
#  (u'ai1P', u'is3P'): <__main__.classesPaire instance at 0x10e527290>,
#  (u'is1P', u'fi1S'): <__main__.classesPaire instance at 0x10d5dc170>,
#  (u'ppMS', u'pi2P'): <__main__.classesPaire instance at 0x10d57c950>,
#  (u'is3P', u'is3S'): <__main__.classesPaire instance at 0x10cd9b8c0>,
#  (u'pI1P', u'ps1P'): <__main__.classesPaire instance at 0x10d6e6518>,
#  (u'ai3S', u'ii1P'): <__main__.classesPaire instance at 0x10fad3908>,
#  (u'pc3P', u'is3P'): <__main__.classesPaire instance at 0x10cfa5128>,
#  (u'ii3S', u'pI2P'): <__main__.classesPaire instance at 0x10d84a098>,
#  (u'fi2S', u'ppFS'): <__main__.classesPaire instance at 0x10d642368>,
#  (u'pI1P', u'ai3S'): <__main__.classesPaire instance at 0x10e3643f8>,
#  (u'pI2P', u'is3P'): <__main__.classesPaire instance at 0x10eb865a8>,
#  (u'ai2S', u'is3S'): <__main__.classesPaire instance at 0x10eb04050>,
#  (u'pc1S', u'ai1S'): <__main__.classesPaire instance at 0x10cda8bd8>,
#  (u'pi1S', u'fi1S'): <__main__.classesPaire instance at 0x10fad3050>,
#  (u'is3P', u'ii2P'): <__main__.classesPaire instance at 0x10d847368>,
#  (u'ii3P', u'ai1S'): <__main__.classesPaire instance at 0x10e5d1b00>,
#  (u'ii2S', u'fi1P'): <__main__.classesPaire instance at 0x10cfa85a8>,
#  (u'fi3S', u'pc3P'): <__main__.classesPaire instance at 0x10da8ebd8>,
#  (u'ii2P', u'ps2P'): <__main__.classesPaire instance at 0x10eb865f0>,
#  (u'pi3P', u'fi1S'): <__main__.classesPaire instance at 0x10e6fff38>,
#  (u'pc1P', u'is1S'): <__main__.classesPaire instance at 0x10cdc90e0>,
#  (u'ps2S', u'pI2P'): <__main__.classesPaire instance at 0x10e850320>,
#  (u'ppMP', u'ppFS'): <__main__.classesPaire instance at 0x10e304908>,
#  (u'fi2P', u'pc2S'): <__main__.classesPaire instance at 0x10e80e320>,
#  (u'pI2P', u'ii1S'): <__main__.classesPaire instance at 0x10d6e8290>,
#  (u'pc3P', u'pI1P'): <__main__.classesPaire instance at 0x10d84a878>,
#  (u'is3S', u'pc3P'): <__main__.classesPaire instance at 0x10cdc42d8>,
#  (u'pP', u'ps3P'): <__main__.classesPaire instance at 0x10cfa5dd0>,
#  (u'is2S', u'ai2S'): <__main__.classesPaire instance at 0x10eb04248>,
#  (u'ai2S', u'ppFP'): <__main__.classesPaire instance at 0x10e507170>,
#  (u'pc1P', u'ps2P'): <__main__.classesPaire instance at 0x10d5f7128>,
#  (u'is1P', u'pc2S'): <__main__.classesPaire instance at 0x10e8863f8>,
#  (u'fi3S', u'is3S'): <__main__.classesPaire instance at 0x10d53d4d0>,
#  (u'pi3P', u'ii2S'): <__main__.classesPaire instance at 0x10eb98248>,
#  (u'pc3P', u'fi2P'): <__main__.classesPaire instance at 0x10e21f3f8>,
#  (u'ps2P', u'pP'): <__main__.classesPaire instance at 0x10f7c8908>,
#  (u'ps2S', u'ai3S'): <__main__.classesPaire instance at 0x10c613170>,
#  (u'ppFP', u'ps2P'): <__main__.classesPaire instance at 0x10d554170>,
#  (u'fi1S', u'is1P'): <__main__.classesPaire instance at 0x10d5dc4d0>,
#  (u'ppMP', u'ps1P'): <__main__.classesPaire instance at 0x10d57c830>,
#  (u'fi1P', u'pc2P'): <__main__.classesPaire instance at 0x10e8fabd8>,
#  (u'pc2P', u'ii1S'): <__main__.classesPaire instance at 0x10d8ec200>,
#  (u'ps2P', u'ii2P'): <__main__.classesPaire instance at 0x10eb86b00>,
#  (u'pi1S', u'ai1P'): <__main__.classesPaire instance at 0x10d5723b0>,
#  (u'pI2S', u'pI2S'): <__main__.classesPaire instance at 0x10cf87638>,
#  (u'pi3P', u'is1P'): <__main__.classesPaire instance at 0x10e207098>,
#  (u'ii1S', u'pc2S'): <__main__.classesPaire instance at 0x10e8fa5a8>,
#  (u'ps2P', u'pc2P'): <__main__.classesPaire instance at 0x10d52a170>,
#  (u'is1P', u'pI1P'): <__main__.classesPaire instance at 0x10cd93518>,
#  (u'pI1P', u'is1P'): <__main__.classesPaire instance at 0x10d613ab8>,
#  (u'fi1S', u'ai2P'): <__main__.classesPaire instance at 0x10ca07758>,
#  (u'pc1S', u'pi1S'): <__main__.classesPaire instance at 0x10f7c84d0>,
#  (u'ii2P', u'ii3P'): <__main__.classesPaire instance at 0x10daac4d0>,
#  ...}

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
from IPython.html.widgets import FloatProgress
from IPython.display import display
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
phonologicalMap="-N"

# %%
import math
def rAn(r,n):
    f = math.factorial
    return f(n) / f(n-r)
def rCn(r,n):
    f = math.factorial
    return f(n) / f(r) / f(n-r)

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
validPhonemes=list(fs.supremum.concept.extent)
#for phoneme in validPhonemes:
#    print (phoneme, [phoneme], ";")

# %%
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# # Lecture du tableau de VERBES

# %% [markdown]
# ### Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
filePrefix="2015-Data/MGC-160104"

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print (forme, file=logfile)
                print ("pas de classe",idClasseForme, file=logfile)
                print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ## Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for n,paire in enumerate(it.combinations_with_replacement(sampleCases,2)):
        progressBar.value=n
        if debug: print (paire, file=logfile)
        if debug: print ("-".join(paire),end=", ")
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ### Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
debug1=True

for echantillon in range(0,1):
    echantillonPrefix="-%02d"%(echantillon+1)
    
    nomLexique=filePrefix+echantillonPrefix+"-paradigmes.csv"
    paradigmes=pd.read_csv(nomLexique,sep=";",encoding="utf8")    

    del paradigmes[u"Unnamed: 0"]
    sampleCases=paradigmes.columns.tolist()
    sampleCases.remove(u"lexeme")    

    #Neutralize all the forms
    for case in sampleCases:
        paradigmes[case]=paradigmes[case].apply(lambda x: recoder(x))

    #Save neutralized paradigms
    paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+phonologicalMap+"-paradigmes.csv",encoding="utf8",sep=";")    
    
    logfile_name=filePrefix+echantillonPrefix+phonologicalMap+".log"
    logfile = codecs.open(logfile_name,mode='w',encoding="utf8")
    
    progressBar = FloatProgress(min=0, max=rCn(2,len(sampleCases)))
    display(progressBar)
    
    resultats=evaluerEchantillon(paradigmes)
    classesFinales={}
    for resultat in resultats:
        classesFinales[resultat]=resultats[resultat][0]
        classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]
#    with open(filePrefix+echantillonPrefix+phonologicalMap+'-Regles.pkl', 'wb') as output:
    with open("2015-Data/MGC-160104-01"+phonologicalMap+'-Regles.pkl', 'wb') as output:
       pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 36.6 s, sys: 355 ms, total: 36.9 s
# Wall time: 37.1 s

# %%
for element in  (classesFinales[("pi3S","inf")].sortirForme(u"mâZ")):
    print (element)
# Out:
# mâZe

# %%
classesFinales
# Out:
# {(u'ps2P', u'is1S'): <__main__.classesPaire instance at 0x10cd05b90>,
#  (u'ii3S', u'ps3P'): <__main__.classesPaire instance at 0x10c961ab8>,
#  (u'ii3S', u'pI1P'): <__main__.classesPaire instance at 0x10c3d1cf8>,
#  (u'ps2S', u'ii2P'): <__main__.classesPaire instance at 0x10c671b48>,
#  (u'pc2P', u'ai2P'): <__main__.classesPaire instance at 0x10bd3a050>,
#  (u'ai1S', u'ai2P'): <__main__.classesPaire instance at 0x10bcf33b0>,
#  (u'fi3P', u'pi2P'): <__main__.classesPaire instance at 0x10c671128>,
#  (u'pi1P', u'ai2P'): <__main__.classesPaire instance at 0x10bfe4830>,
#  (u'pc1P', u'pi2S'): <__main__.classesPaire instance at 0x10ccbdcf8>,
#  (u'fi1P', u'pI1P'): <__main__.classesPaire instance at 0x109809ea8>,
#  (u'ps2P', u'ai3S'): <__main__.classesPaire instance at 0x10bda7200>,
#  (u'ppFP', u'pi2S'): <__main__.classesPaire instance at 0x10ccd6950>,
#  (u'ii3S', u'ii3P'): <__main__.classesPaire instance at 0x10c9533b0>,
#  (u'ps2S', u'fi1S'): <__main__.classesPaire instance at 0x10b4db710>,
#  (u'pi2P', u'fi1S'): <__main__.classesPaire instance at 0x10bcce3f8>,
#  (u'pi1S', u'fi3S'): <__main__.classesPaire instance at 0x1098bc638>,
#  (u'is1P', u'pP'): <__main__.classesPaire instance at 0x10cb10098>,
#  (u'ppFP', u'ppFP'): <__main__.classesPaire instance at 0x10d4a3710>,
#  (u'ppFS', u'fi3S'): <__main__.classesPaire instance at 0x10c351098>,
#  (u'ii2P', u'ps3P'): <__main__.classesPaire instance at 0x10c1b5dd0>,
#  (u'inf', u'pi2S'): <__main__.classesPaire instance at 0x1098deab8>,
#  (u'pc1P', u'fi3P'): <__main__.classesPaire instance at 0x10c499290>,
#  (u'is3P', u'pI2P'): <__main__.classesPaire instance at 0x10cd16170>,
#  (u'ppMP', u'pc1P'): <__main__.classesPaire instance at 0x10d06db90>,
#  (u'is3P', u'ppFS'): <__main__.classesPaire instance at 0x10cd16638>,
#  (u'ii3P', u'fi2S'): <__main__.classesPaire instance at 0x10c3d1908>,
#  (u'fi1S', u'ps1S'): <__main__.classesPaire instance at 0x10c074a70>,
#  (u'is1P', u'pc1P'): <__main__.classesPaire instance at 0x10ccc0098>,
#  (u'fi1S', u'pi1S'): <__main__.classesPaire instance at 0x10c188ef0>,
#  (u'pi3S', u'pc3S'): <__main__.classesPaire instance at 0x10c1b5170>,
#  (u'pi1P', u'ppMP'): <__main__.classesPaire instance at 0x10c964290>,
#  (u'ppMP', u'ii3P'): <__main__.classesPaire instance at 0x10cb108c0>,
#  (u'fi3P', u'ppMP'): <__main__.classesPaire instance at 0x10c373cb0>,
#  (u'ppFS', u'is3P'): <__main__.classesPaire instance at 0x10cd383b0>,
#  (u'ps2P', u'is3S'): <__main__.classesPaire instance at 0x10c31e320>,
#  (u'ai3S', u'fi3S'): <__main__.classesPaire instance at 0x109846680>,
#  (u'fi3P', u'pi1P'): <__main__.classesPaire instance at 0x10c3516c8>,
#  (u'fi3S', u'fi2P'): <__main__.classesPaire instance at 0x10c054ef0>,
#  (u'ppMP', u'ps3P'): <__main__.classesPaire instance at 0x10c961830>,
#  (u'pI2P', u'ps2P'): <__main__.classesPaire instance at 0x10ccd67e8>,
#  (u'pi2P', u'ps3P'): <__main__.classesPaire instance at 0x10d4d0128>,
#  (u'pi2S', u'ps3P'): <__main__.classesPaire instance at 0x10d277a70>,
#  (u'pI1P', u'ai2S'): <__main__.classesPaire instance at 0x10c054368>,
#  (u'pI2P', u'ps1S'): <__main__.classesPaire instance at 0x109806a28>,
#  (u'pi2P', u'pi3P'): <__main__.classesPaire instance at 0x10cb27050>,
#  (u'ii1P', u'pc2S'): <__main__.classesPaire instance at 0x10bd7f998>,
#  (u'pI2P', u'is1S'): <__main__.classesPaire instance at 0x10ca557e8>,
#  (u'pc3S', u'is1P'): <__main__.classesPaire instance at 0x10ccbd638>,
#  (u'ppFP', u'pI2P'): <__main__.classesPaire instance at 0x10985d5a8>,
#  (u'is3S', u'ppMS'): <__main__.classesPaire instance at 0x10c47db00>,
#  (u'fi1P', u'ppFP'): <__main__.classesPaire instance at 0x109814830>,
#  (u'ps3S', u'fi1S'): <__main__.classesPaire instance at 0x10c335200>,
#  (u'inf', u'is3P'): <__main__.classesPaire instance at 0x10c499b90>,
#  (u'pI1P', u'ii1P'): <__main__.classesPaire instance at 0x10c8269e0>,
#  (u'fi1S', u'ps1P'): <__main__.classesPaire instance at 0x10c331cb0>,
#  (u'fi3S', u'fi1S'): <__main__.classesPaire instance at 0x10bd7bea8>,
#  (u'ii3P', u'ppMP'): <__main__.classesPaire instance at 0x10cb10050>,
#  (u'is1P', u'fi2P'): <__main__.classesPaire instance at 0x1099234d0>,
#  (u'pi3P', u'ii1P'): <__main__.classesPaire instance at 0x10c845c20>,
#  (u'ppMS', u'is1P'): <__main__.classesPaire instance at 0x10ccd6680>,
#  (u'ps3S', u'is1P'): <__main__.classesPaire instance at 0x10ccd6a70>,
#  (u'fi1S', u'ps2S'): <__main__.classesPaire instance at 0x10bd7fb48>,
#  (u'inf', u'ps2S'): <__main__.classesPaire instance at 0x10c39fbd8>,
#  (u'fi1P', u'ii2S'): <__main__.classesPaire instance at 0x1099fb518>,
#  (u'ps1S', u'ai3P'): <__main__.classesPaire instance at 0x10c1141b8>,
#  (u'fi1P', u'fi1S'): <__main__.classesPaire instance at 0x10980de60>,
#  (u'ai1S', u'ii1P'): <__main__.classesPaire instance at 0x10bcf3dd0>,
#  (u'pi2P', u'pc1S'): <__main__.classesPaire instance at 0x10ce801b8>,
#  (u'pc3S', u'fi1S'): <__main__.classesPaire instance at 0x10c331908>,
#  (u'pi1S', u'inf'): <__main__.classesPaire instance at 0x10c494758>,
#  (u'pP', u'pI2P'): <__main__.classesPaire instance at 0x10cd38710>,
#  (u'ai3S', u'ii3P'): <__main__.classesPaire instance at 0x10bc87e18>,
#  (u'is1P', u'ppMP'): <__main__.classesPaire instance at 0x10ccc0680>,
#  (u'fi1P', u'is1P'): <__main__.classesPaire instance at 0x1099f9368>,
#  (u'pi3S', u'pi3S'): <__main__.classesPaire instance at 0x10d088fc8>,
#  (u'pI2S', u'ii3S'): <__main__.classesPaire instance at 0x10ca51098>,
#  (u'ai3S', u'is1P'): <__main__.classesPaire instance at 0x10bc44908>,
#  (u'ai1P', u'ps1S'): <__main__.classesPaire instance at 0x10bc51ea8>,
#  (u'ps3P', u'pi2S'): <__main__.classesPaire instance at 0x10d277b48>,
#  (u'ppMP', u'fi1S'): <__main__.classesPaire instance at 0x10c361b48>,
#  (u'ps1S', u'ii2P'): <__main__.classesPaire instance at 0x10c6715a8>,
#  (u'fi2P', u'ps1P'): <__main__.classesPaire instance at 0x10c0a2f38>,
#  (u'ps2P', u'ps2P'): <__main__.classesPaire instance at 0x10d05dd88>,
#  (u'fi1S', u'fi3S'): <__main__.classesPaire instance at 0x10bd7b0e0>,
#  (u'is1S', u'ps3S'): <__main__.classesPaire instance at 0x10cd05ea8>,
#  (u'ai2P', u'ii3P'): <__main__.classesPaire instance at 0x10bfcb4d0>,
#  (u'fi3P', u'ps1P'): <__main__.classesPaire instance at 0x1098164d0>,
#  (u'fi3P', u'is3P'): <__main__.classesPaire instance at 0x10c499b48>,
#  (u'pc3P', u'pi2S'): <__main__.classesPaire instance at 0x10d05d8c0>,
#  (u'is3P', u'ii2P'): <__main__.classesPaire instance at 0x10c3a7128>,
#  (u'fi2P', u'pI2P'): <__main__.classesPaire instance at 0x1098da1b8>,
#  (u'ai2S', u'fi3P'): <__main__.classesPaire instance at 0x10c01ecf8>,
#  (u'inf', u'pi3P'): <__main__.classesPaire instance at 0x10cbe5b00>,
#  (u'pc3S', u'pc3P'): <__main__.classesPaire instance at 0x10d1dfc68>,
#  (u'ps2S', u'pP'): <__main__.classesPaire instance at 0x10cbcd0e0>,
#  (u'ai2P', u'pi1P'): <__main__.classesPaire instance at 0x10bfe4440>,
#  (u'is1P', u'ai2S'): <__main__.classesPaire instance at 0x10c04fab8>,
#  (u'fi3P', u'pi3S'): <__main__.classesPaire instance at 0x109906368>,
#  (u'pi3P', u'inf'): <__main__.classesPaire instance at 0x10cb0c4d0>,
#  (u'pI2P', u'fi2S'): <__main__.classesPaire instance at 0x10b88d0e0>,
#  (u'fi2P', u'pc1S'): <__main__.classesPaire instance at 0x10bd54128>,
#  (u'pI1P', u'ppMP'): <__main__.classesPaire instance at 0x10c95add0>,
#  (u'inf', u'pc1P'): <__main__.classesPaire instance at 0x10ca51e60>,
#  (u'ii3S', u'pi3S'): <__main__.classesPaire instance at 0x10c671488>,
#  (u'ppFP', u'pi3P'): <__main__.classesPaire instance at 0x10d1dfbd8>,
#  (u'pc2S', u'ai3S'): <__main__.classesPaire instance at 0x109832998>,
#  (u'ii3S', u'pc1S'): <__main__.classesPaire instance at 0x10ca51440>,
#  (u'fi1S', u'ai1S'): <__main__.classesPaire instance at 0x10985ab00>,
#  (u'pc3P', u'ps3P'): <__main__.classesPaire instance at 0x10cd68710>,
#  (u'ppFP', u'ps3P'): <__main__.classesPaire instance at 0x10ce6b5f0>,
#  (u'ai1S', u'ppMP'): <__main__.classesPaire instance at 0x10bd9fc68>,
#  (u'pi2S', u'ps2S'): <__main__.classesPaire instance at 0x10cbe5680>,
#  (u'ps3S', u'pc3P'): <__main__.classesPaire instance at 0x10ce4cab8>,
#  (u'ai3P', u'fi3P'): <__main__.classesPaire instance at 0x10bd2e950>,
#  (u'pi1P', u'fi1P'): <__main__.classesPaire instance at 0x1098107a0>,
#  (u'pP', u'ppMS'): <__main__.classesPaire instance at 0x10bc5bd88>,
#  (u'pc2S', u'is1S'): <__main__.classesPaire instance at 0x10ccab638>,
#  (u'ppMP', u'inf'): <__main__.classesPaire instance at 0x10cb0c6c8>,
#  (u'ai1S', u'pi2S'): <__main__.classesPaire instance at 0x10bcaab00>,
#  (u'ppMS', u'ps1P'): <__main__.classesPaire instance at 0x10d4a3170>,
#  (u'ppFP', u'fi3P'): <__main__.classesPaire instance at 0x10c054248>,
#  (u'pi1S', u'pc1P'): <__main__.classesPaire instance at 0x10cb27440>,
#  (u'pi3P', u'pi1P'): <__main__.classesPaire instance at 0x10d088a70>,
#  (u'is1S', u'pc3S'): <__main__.classesPaire instance at 0x10cbf0518>,
#  (u'ii1P', u'ii1S'): <__main__.classesPaire instance at 0x10c865b00>,
#  (u'fi2P', u'pi2S'): <__main__.classesPaire instance at 0x1098068c0>,
#  (u'pi1S', u'pI2P'): <__main__.classesPaire instance at 0x10cd38e18>,
#  (u'ppMP', u'ii2S'): <__main__.classesPaire instance at 0x10ca54518>,
#  (u'ai2S', u'is1P'): <__main__.classesPaire instance at 0x10c04fa70>,
#  (u'ai1S', u'ps3S'): <__main__.classesPaire instance at 0x10bcce8c0>,
#  (u'ii1S', u'pi1S'): <__main__.classesPaire instance at 0x10c826f80>,
#  (u'fi3P', u'fi3P'): <__main__.classesPaire instance at 0x10c373e60>,
#  (u'pI2P', u'pc2P'): <__main__.classesPaire instance at 0x10c3794d0>,
#  (u'ps1S', u'ps2P'): <__main__.classesPaire instance at 0x10d4be830>,
#  (u'ai2S', u'pi3P'): <__main__.classesPaire instance at 0x10c054fc8>,
#  (u'pc2P', u'fi2P'): <__main__.classesPaire instance at 0x10c331710>,
#  (u'ai3P', u'ii1S'): <__main__.classesPaire instance at 0x10bd7f8c0>,
#  (u'pP', u'ai3P'): <__main__.classesPaire instance at 0x10c04f830>,
#  (u'ps3P', u'ps2S'): <__main__.classesPaire instance at 0x10d05d830>,
#  (u'ii3P', u'is3S'): <__main__.classesPaire instance at 0x10ca54758>,
#  (u'pi2P', u'pi2S'): <__main__.classesPaire instance at 0x10d1b3638>,
#  (u'ii3S', u'fi2S'): <__main__.classesPaire instance at 0x10c1b5d40>,
#  (u'pc3P', u'pc3P'): <__main__.classesPaire instance at 0x10d1ceab8>,
#  (u'ii3S', u'ai3S'): <__main__.classesPaire instance at 0x10c04f098>,
#  (u'is3P', u'pc3S'): <__main__.classesPaire instance at 0x10cc15638>,
#  (u'ps1P', u'fi1P'): <__main__.classesPaire instance at 0x106c3e998>,
#  (u'fi2S', u'pi3S'): <__main__.classesPaire instance at 0x10c39f440>,
#  (u'ii1S', u'ai1P'): <__main__.classesPaire instance at 0x10afcf7a0>,
#  (u'pc2S', u'pi2S'): <__main__.classesPaire instance at 0x1098deea8>,
#  (u'ii2P', u'ppMP'): <__main__.classesPaire instance at 0x10c3515f0>,
#  (u'is3P', u'pi1P'): <__main__.classesPaire instance at 0x10cd05d88>,
#  (u'ii2S', u'pc2P'): <__main__.classesPaire instance at 0x10c9536c8>,
#  (u'ai3S', u'pP'): <__main__.classesPaire instance at 0x10bd2e050>,
#  (u'pc3P', u'pi1S'): <__main__.classesPaire instance at 0x10d21f440>,
#  (u'fi3S', u'ai1S'): <__main__.classesPaire instance at 0x10bc51cf8>,
#  (u'ii1S', u'is3S'): <__main__.classesPaire instance at 0x10c3d1b00>,
#  (u'pc2P', u'ppFS'): <__main__.classesPaire instance at 0x10d086368>,
#  (u'ai1P', u'fi1P'): <__main__.classesPaire instance at 0x10bc44a28>,
#  (u'pi3P', u'ps3P'): <__main__.classesPaire instance at 0x10d1b94d0>,
#  (u'pc2P', u'fi3S'): <__main__.classesPaire instance at 0x10c671b00>,
#  (u'ai2P', u'ppFP'): <__main__.classesPaire instance at 0x10c00b440>,
#  (u'pI1P', u'is3P'): <__main__.classesPaire instance at 0x10cd16248>,
#  (u'pc1P', u'fi1P'): <__main__.classesPaire instance at 0x1098d35f0>,
#  (u'ps1P', u'ii1S'): <__main__.classesPaire instance at 0x10c662248>,
#  (u'ai1S', u'fi1S'): <__main__.classesPaire instance at 0x10bc6ab48>,
#  (u'ii2P', u'ai3S'): <__main__.classesPaire instance at 0x10b2e2098>,
#  (u'pi3P', u'is3P'): <__main__.classesPaire instance at 0x10cd16d40>,
#  (u'ai3S', u'ii2S'): <__main__.classesPaire instance at 0x109846b48>,
#  (u'is1S', u'pc2P'): <__main__.classesPaire instance at 0x10ccab560>,
#  (u'ai1S', u'is3P'): <__main__.classesPaire instance at 0x10bc87c68>,
#  (u'ps1S', u'fi3P'): <__main__.classesPaire instance at 0x10c662cb0>,
#  (u'pi1P', u'pi1P'): <__main__.classesPaire instance at 0x10ce4c998>,
#  (u'pc1S', u'is3P'): <__main__.classesPaire instance at 0x10ccbd680>,
#  (u'pi2S', u'pc3S'): <__main__.classesPaire instance at 0x109949bd8>,
#  (u'pi1S', u'pi1S'): <__main__.classesPaire instance at 0x10c95a6c8>,
#  (u'pP', u'ii1P'): <__main__.classesPaire instance at 0x10c8658c0>,
#  (u'ai2S', u'pc3P'): <__main__.classesPaire instance at 0x10c054320>,
#  (u'ai3P', u'ppMS'): <__main__.classesPaire instance at 0x10b88d1b8>,
#  (u'ii2P', u'ppFP'): <__main__.classesPaire instance at 0x10c3d2128>,
#  (u'pi2P', u'ai3S'): <__main__.classesPaire instance at 0x10c01e9e0>,
#  (u'ps1S', u'pc1S'): <__main__.classesPaire instance at 0x10cd16518>,
#  (u'ppMS', u'pI1P'): <__main__.classesPaire instance at 0x10c499680>,
#  (u'pc1S', u'fi3P'): <__main__.classesPaire instance at 0x10c335e60>,
#  (u'pc3P', u'inf'): <__main__.classesPaire instance at 0x10c948830>,
#  (u'fi2S', u'ai1P'): <__main__.classesPaire instance at 0x10b850050>,
#  (u'ps2P', u'fi1S'): <__main__.classesPaire instance at 0x10c373b90>,
#  (u'fi2S', u'fi1P'): <__main__.classesPaire instance at 0x10993e290>,
#  (u'pc3P', u'pi3P'): <__main__.classesPaire instance at 0x10d06d998>,
#  (u'fi2S', u'pI1P'): <__main__.classesPaire instance at 0x10c3d1950>,
#  (u'ii1P', u'pc1P'): <__main__.classesPaire instance at 0x10c852d88>,
#  (u'ai3P', u'ps3P'): <__main__.classesPaire instance at 0x10bd7bb90>,
#  (u'ai1P', u'pi1S'): <__main__.classesPaire instance at 0x10bcaac68>,
#  (u'ii1S', u'ii1P'): <__main__.classesPaire instance at 0x109929950>,
#  (u'pc3P', u'is1P'): <__main__.classesPaire instance at 0x10ccc0b48>,
#  (u'ppFS', u'pI1P'): <__main__.classesPaire instance at 0x10ca54878>,
#  (u'pi3S', u'is3P'): <__main__.classesPaire instance at 0x10cd381b8>,
#  (u'pI1P', u'fi3P'): <__main__.classesPaire instance at 0x109814b90>,
#  (u'ppFS', u'ps1S'): <__main__.classesPaire instance at 0x10d6e6170>,
#  (u'is1P', u'ps3S'): <__main__.classesPaire instance at 0x10ccd6ab8>,
#  (u'pI2S', u'fi1S'): <__main__.classesPaire instance at 0x10c1a7248>,
#  (u'ai2S', u'ii3P'): <__main__.classesPaire instance at 0x10c01e5f0>,
#  (u'is1S', u'fi2S'): <__main__.classesPaire instance at 0x10c47dd40>,
#  (u'pi3S', u'ii1S'): <__main__.classesPaire instance at 0x10bc87ef0>,
#  (u'pP', u'pP'): <__main__.classesPaire instance at 0x10ce4c128>,
#  (u'pi1S', u'pP'): <__main__.classesPaire instance at 0x10c928f38>,
#  (u'ppFS', u'pi1P'): <__main__.classesPaire instance at 0x10cd169e0>,
#  (u'ii2S', u'pc3S'): <__main__.classesPaire instance at 0x10ca515f0>,
#  (u'ps3S', u'pI2S'): <__main__.classesPaire instance at 0x10cc15e60>,
#  (u'ps2P', u'fi2S'): <__main__.classesPaire instance at 0x10c494f80>,
#  (u'ii2P', u'ai2S'): <__main__.classesPaire instance at 0x10bfe4908>,
#  (u'pc1S', u'ii1S'): <__main__.classesPaire instance at 0x10c6537e8>,
#  (u'pc3S', u'pc2P'): <__main__.classesPaire instance at 0x10cd68ef0>,
#  (u'ai2S', u'ps3P'): <__main__.classesPaire instance at 0x10bd008c0>,
#  (u'ai1S', u'pi3P'): <__main__.classesPaire instance at 0x10bd3a200>,
#  (u'pI2S', u'ii1S'): <__main__.classesPaire instance at 0x10c331a28>,
#  (u'fi2S', u'ppMP'): <__main__.classesPaire instance at 0x10c39fc20>,
#  (u'fi2P', u'inf'): <__main__.classesPaire instance at 0x10c3d1248>,
#  (u'fi1S', u'fi1P'): <__main__.classesPaire instance at 0x109930638>,
#  (u'fi2P', u'pi3P'): <__main__.classesPaire instance at 0x1098586c8>,
#  (u'ii1S', u'fi1P'): <__main__.classesPaire instance at 0x10b43ee60>,
#  (u'pc3S', u'pI2S'): <__main__.classesPaire instance at 0x10cd38248>,
#  (u'ai2S', u'ps2P'): <__main__.classesPaire instance at 0x10c074ab8>,
#  (u'fi3P', u'ps2S'): <__main__.classesPaire instance at 0x10c6533f8>,
#  (u'pi2P', u'pi1S'): <__main__.classesPaire instance at 0x10ca55710>,
#  (u'ai3S', u'pi1S'): <__main__.classesPaire instance at 0x10c074830>,
#  (u'fi2S', u'ps3S'): <__main__.classesPaire instance at 0x10c361638>,
#  (u'ai2P', u'ppFS'): <__main__.classesPaire instance at 0x10c00b290>,
#  (u'ppMP', u'ps2S'): <__main__.classesPaire instance at 0x10ce70cf8>,
#  (u'fi1S', u'fi2P'): <__main__.classesPaire instance at 0x10991dab8>,
#  (u'ps3P', u'pP'): <__main__.classesPaire instance at 0x10d086d88>,
#  (u'fi3S', u'pP'): <__main__.classesPaire instance at 0x10c662c68>,
#  (u'fi3P', u'ai3S'): <__main__.classesPaire instance at 0x10c01e488>,
#  (u'ps1P', u'pc1S'): <__main__.classesPaire instance at 0x1098f2680>,
#  (u'ai3S', u'fi1P'): <__main__.classesPaire instance at 0x10c188680>,
#  (u'ppFS', u'pc2S'): <__main__.classesPaire instance at 0x10cd05a70>,
#  (u'ii1S', u'ppMP'): <__main__.classesPaire instance at 0x10c852ea8>,
#  (u'pi1P', u'pI1P'): <__main__.classesPaire instance at 0x10cb27ea8>,
#  (u'ppFP', u'pc3P'): <__main__.classesPaire instance at 0x10d1df710>,
#  (u'ai3S', u'is3S'): <__main__.classesPaire instance at 0x10c0a2dd0>,
#  (u'ps2P', u'pc1S'): <__main__.classesPaire instance at 0x10ce6b9e0>,
#  (u'fi2S', u'pi2P'): <__main__.classesPaire instance at 0x10b0db518>,
#  (u'fi1P', u'ai3P'): <__main__.classesPaire instance at 0x10c074170>,
#  (u'pi2P', u'ai1P'): <__main__.classesPaire instance at 0x10bfa2ab8>,
#  (u'pc2S', u'pi3P'): <__main__.classesPaire instance at 0x10d1a1c20>,
#  (u'fi2P', u'fi3S'): <__main__.classesPaire instance at 0x10c39fd88>,
#  (u'ii2S', u'ii2P'): <__main__.classesPaire instance at 0x10c379fc8>,
#  (u'fi1P', u'pP'): <__main__.classesPaire instance at 0x1098fe5f0>,
#  (u'pc2S', u'ps3P'): <__main__.classesPaire instance at 0x10d1df878>,
#  (u'is1S', u'pc1S'): <__main__.classesPaire instance at 0x10ca54bd8>,
#  (u'fi3S', u'fi1P'): <__main__.classesPaire instance at 0x10984c6c8>,
#  (u'ii2S', u'pP'): <__main__.classesPaire instance at 0x10c1b5320>,
#  (u'pc1S', u'ppMS'): <__main__.classesPaire instance at 0x10cc152d8>,
#  (u'pI2S', u'ppMS'): <__main__.classesPaire instance at 0x10c95acb0>,
#  (u'ppFP', u'pc2P'): <__main__.classesPaire instance at 0x10cc15170>,
#  (u'ii3P', u'pi3P'): <__main__.classesPaire instance at 0x10c865fc8>,
#  (u'pc1S', u'ps3P'): <__main__.classesPaire instance at 0x10ce4c9e0>,
#  (u'pc3P', u'ps2P'): <__main__.classesPaire instance at 0x10d249638>,
#  (u'ai3S', u'ai3S'): <__main__.classesPaire instance at 0x10c1880e0>,
#  (u'ps1P', u'fi3S'): <__main__.classesPaire instance at 0x10c6719e0>,
#  (u'ps1S', u'ppMP'): <__main__.classesPaire instance at 0x10d21f170>,
#  (u'is3P', u'ps1P'): <__main__.classesPaire instance at 0x10cb0cb48>,
#  (u'pi3S', u'pi1P'): <__main__.classesPaire instance at 0x10c47d170>,
#  (u'ai2P', u'pc1S'): <__main__.classesPaire instance at 0x10bd9fab8>,
#  (u'fi2S', u'ai2S'): <__main__.classesPaire instance at 0x10bfcbc68>,
#  (u'pi1S', u'ps3P'): <__main__.classesPaire instance at 0x10d088758>,
#  (u'pc2S', u'ai1P'): <__main__.classesPaire instance at 0x10bfa2440>,
#  (u'ps2S', u'fi3P'): <__main__.classesPaire instance at 0x10c653a70>,
#  (u'fi3S', u'ppFP'): <__main__.classesPaire instance at 0x10c335830>,
#  (u'ppMP', u'ai2P'): <__main__.classesPaire instance at 0x10c00b248>,
#  (u'pI2P', u'ai3P'): <__main__.classesPaire instance at 0x10c00be18>,
#  (u'pi1S', u'ii3S'): <__main__.classesPaire instance at 0x10cb102d8>,
#  (u'ai3P', u'ii2S'): <__main__.classesPaire instance at 0x10bd002d8>,
#  (u'pi3S', u'fi3S'): <__main__.classesPaire instance at 0x10c3d1998>,
#  (u'pI2P', u'pc1P'): <__main__.classesPaire instance at 0x10cce4878>,
#  (u'is3S', u'ppFP'): <__main__.classesPaire instance at 0x10ccabfc8>,
#  (u'fi3P', u'pi3P'): <__main__.classesPaire instance at 0x10c114fc8>,
#  (u'fi2P', u'pI2S'): <__main__.classesPaire instance at 0x10c3d2cb0>,
#  (u'is3P', u'pc1S'): <__main__.classesPaire instance at 0x10ccbdd88>,
#  (u'pI1P', u'ii3P'): <__main__.classesPaire instance at 0x10bcce050>,
#  (u'ai1P', u'ppFP'): <__main__.classesPaire instance at 0x10bcceb90>,
#  (u'is1S', u'ps2S'): <__main__.classesPaire instance at 0x10cd05908>,
#  (u'ai2P', u'ps1P'): <__main__.classesPaire instance at 0x10c00bab8>,
#  (u'is1S', u'ppFS'): <__main__.classesPaire instance at 0x10cce4908>,
#  (u'ppMP', u'ii1S'): <__main__.classesPaire instance at 0x10c852f38>,
#  (u'ii1P', u'ps2S'): <__main__.classesPaire instance at 0x10c331e18>,
#  (u'ai3S', u'pc1S'): <__main__.classesPaire instance at 0x10b4e6b00>,
#  (u'ppMS', u'pi3P'): <__main__.classesPaire instance at 0x10c6711b8>,
#  (u'pc2S', u'pi1S'): <__main__.classesPaire instance at 0x10ce6bc68>,
#  (u'ii1S', u'ai2S'): <__main__.classesPaire instance at 0x10bc5bf80>,
#  (u'ppFS', u'ppFS'): <__main__.classesPaire instance at 0x10d1a1878>,
#  (u'ii2S', u'pc1S'): <__main__.classesPaire instance at 0x10c961128>,
#  (u'pi2P', u'fi3S'): <__main__.classesPaire instance at 0x10c39f7e8>,
#  (u'ii3S', u'ai1P'): <__main__.classesPaire instance at 0x10bc6a950>,
#  (u'pc2S', u'ii2S'): <__main__.classesPaire instance at 0x10c499908>,
#  (u'pi1P', u'fi2S'): <__main__.classesPaire instance at 0x10b0db2d8>,
#  (u'fi2P', u'ai1P'): <__main__.classesPaire instance at 0x10bc5b5f0>,
#  (u'ppFP', u'ai1S'): <__main__.classesPaire instance at 0x10bda78c0>,
#  (u'inf', u'fi3P'): <__main__.classesPaire instance at 0x10c3d2878>,
#  (u'is1S', u'ii3S'): <__main__.classesPaire instance at 0x10c3d1758>,
#  (u'pi3S', u'is1S'): <__main__.classesPaire instance at 0x10cd05128>,
#  (u'ii2P', u'pc2S'): <__main__.classesPaire instance at 0x10c8653b0>,
#  (u'pI1P', u'ppFP'): <__main__.classesPaire instance at 0x10cb0c440>,
#  (u'ps1P', u'ii2P'): <__main__.classesPaire instance at 0x10c379ea8>,
#  (u'fi1P', u'pc1P'): <__main__.classesPaire instance at 0x1098d3b90>,
#  (u'ii3S', u'pI2S'): <__main__.classesPaire instance at 0x10ca51b00>,
#  (u'pi3P', u'ps1S'): <__main__.classesPaire instance at 0x10ce80758>,
#  (u'pi3P', u'ppMS'): <__main__.classesPaire instance at 0x10c671098>,
#  (u'ii2P', u'is1P'): <__main__.classesPaire instance at 0x10c662560>,
#  (u'ps3S', u'inf'): <__main__.classesPaire instance at 0x10ca76cb0>,
#  (u'fi2P', u'pi1S'): <__main__.classesPaire instance at 0x10afcffc8>,
#  (u'ps1P', u'is1S'): <__main__.classesPaire instance at 0x10cd05830>,
#  (u'ppFS', u'fi2S'): <__main__.classesPaire instance at 0x10c361ab8>,
#  (u'ii2S', u'ai1S'): <__main__.classesPaire instance at 0x10bd00ea8>,
#  (u'fi3P', u'pc1S'): <__main__.classesPaire instance at 0x10c351e18>,
#  (u'ps1S', u'ai2S'): <__main__.classesPaire instance at 0x10c074908>,
#  (u'pi2S', u'pc2S'): <__main__.classesPaire instance at 0x10cd68170>,
#  (u'ps1S', u'pi1P'): <__main__.classesPaire instance at 0x10c9287a0>,
#  (u'fi3P', u'ai2P'): <__main__.classesPaire instance at 0x109911b00>,
#  (u'is3S', u'pI2S'): <__main__.classesPaire instance at 0x10cd05170>,
#  (u'ai2P', u'ai2S'): <__main__.classesPaire instance at 0x10bfd1e18>,
#  (u'pi2P', u'pI2P'): <__main__.classesPaire instance at 0x10cd38518>,
#  (u'inf', u'pc1S'): <__main__.classesPaire instance at 0x1099f8488>,
#  (u'pc3S', u'inf'): <__main__.classesPaire instance at 0x10cbf05a8>,
#  (u'ai3P', u'ai3S'): <__main__.classesPaire instance at 0x10bd7b7a0>,
#  (u'ii3P', u'pi2S'): <__main__.classesPaire instance at 0x10c961dd0>,
#  (u'ai3P', u'pI1P'): <__main__.classesPaire instance at 0x10bd543f8>,
#  (u'fi1S', u'pc3S'): <__main__.classesPaire instance at 0x10c331ea8>,
#  (u'pc2P', u'ps1S'): <__main__.classesPaire instance at 0x10ce6ba70>,
#  (u'fi1P', u'ai2S'): <__main__.classesPaire instance at 0x10c01e680>,
#  (u'pc1P', u'ai3S'): <__main__.classesPaire instance at 0x10c054680>,
#  (u'ps3S', u'ii1S'): <__main__.classesPaire instance at 0x10c379680>,
#  (u'ps3P', u'ii1S'): <__main__.classesPaire instance at 0x10c671d88>,
#  (u'ppMS', u'is3P'): <__main__.classesPaire instance at 0x10c961200>,
#  (u'ii3S', u'is1S'): <__main__.classesPaire instance at 0x10bcce248>,
#  (u'inf', u'ppMS'): <__main__.classesPaire instance at 0x10cbcd2d8>,
#  (u'ppMS', u'ai2S'): <__main__.classesPaire instance at 0x10c074290>,
#  (u'pi3P', u'ps2P'): <__main__.classesPaire instance at 0x10cbe52d8>,
#  (u'inf', u'pi2P'): <__main__.classesPaire instance at 0x10c3d26c8>,
#  (u'ai2P', u'ii2P'): <__main__.classesPaire instance at 0x10bcaacf8>,
#  (u'pi2P', u'pc3S'): <__main__.classesPaire instance at 0x10d1a1d40>,
#  (u'is3P', u'pc2S'): <__main__.classesPaire instance at 0x10cb10b00>,
#  (u'fi3P', u'ppFS'): <__main__.classesPaire instance at 0x10c00b638>,
#  (u'ii2S', u'pi1S'): <__main__.classesPaire instance at 0x10c961e60>,
#  (u'ii2S', u'ai2P'): <__main__.classesPaire instance at 0x10bfcbb00>,
#  (u'pP', u'ps1S'): <__main__.classesPaire instance at 0x10cbe5dd0>,
#  (u'pc3P', u'pc2P'): <__main__.classesPaire instance at 0x10cd680e0>,
#  (u'fi3P', u'pi2S'): <__main__.classesPaire instance at 0x10c3a7e18>,
#  (u'ps1P', u'ii3P'): <__main__.classesPaire instance at 0x10c852710>,
#  (u'ps1S', u'ai1P'): <__main__.classesPaire instance at 0x10bc51368>,
#  (u'pc1S', u'pi2S'): <__main__.classesPaire instance at 0x10ce5b5a8>,
#  (u'ps2S', u'fi1P'): <__main__.classesPaire instance at 0x109869638>,
#  (u'ii1P', u'ai3P'): <__main__.classesPaire instance at 0x10bc442d8>,
#  (u'pI2P', u'ai1P'): <__main__.classesPaire instance at 0x10b093518>,
#  (u'fi2S', u'ai3P'): <__main__.classesPaire instance at 0x10bcaab48>,
#  (u'ii2S', u'ii1S'): <__main__.classesPaire instance at 0x10c653cf8>,
#  (u'pI2P', u'pc3P'): <__main__.classesPaire instance at 0x10c928d40>,
#  (u'pc3S', u'ai1S'): <__main__.classesPaire instance at 0x10bd54e18>,
#  (u'ai2P', u'ps2P'): <__main__.classesPaire instance at 0x10c00b998>,
#  (u'pc1P', u'ii2S'): <__main__.classesPaire instance at 0x10c961290>,
#  (u'pc1P', u'ii3P'): <__main__.classesPaire instance at 0x10c928cb0>,
#  (u'pi1P', u'ai2S'): <__main__.classesPaire instance at 0x10c054cf8>,
#  (u'pi1S', u'ii2P'): <__main__.classesPaire instance at 0x10c1b5638>,
#  (u'ppFS', u'ii3S'): <__main__.classesPaire instance at 0x10c95a7e8>,
#  (u'fi3P', u'ps3P'): <__main__.classesPaire instance at 0x109949170>,
#  (u'ps3P', u'ps1S'): <__main__.classesPaire instance at 0x10d2773b0>,
#  (u'ppMP', u'pc1S'): <__main__.classesPaire instance at 0x10ca55098>,
#  (u'ppFS', u'fi1P'): <__main__.classesPaire instance at 0x109855050>,
#  (u'ps2S', u'ppFS'): <__main__.classesPaire instance at 0x10d1ce440>,
#  (u'is1S', u'pc2S'): <__main__.classesPaire instance at 0x10ca54c68>,
#  (u'ppFP', u'ppMP'): <__main__.classesPaire instance at 0x10cbcd440>,
#  (u'ps3S', u'fi2S'): <__main__.classesPaire instance at 0x10c361170>,
#  (u'ii3S', u'inf'): <__main__.classesPaire instance at 0x10c31ecb0>,
#  (u'ppFS', u'pi1S'): <__main__.classesPaire instance at 0x10c9619e0>,
#  (u'ps2P', u'is3P'): <__main__.classesPaire instance at 0x10c8655a8>,
#  (u'ps2P', u'ps1P'): <__main__.classesPaire instance at 0x10d1dfdd0>,
#  (u'pc2P', u'is1S'): <__main__.classesPaire instance at 0x10ccab3f8>,
#  (u'ii1S', u'ai3P'): <__main__.classesPaire instance at 0x109844cb0>,
#  (u'ppFS', u'ai3S'): <__main__.classesPaire instance at 0x10aece638>,
#  (u'is1P', u'ai1P'): <__main__.classesPaire instance at 0x10bc51248>,
#  (u'pc3P', u'fi3P'): <__main__.classesPaire instance at 0x10c653680>,
#  (u'fi1P', u'ppMP'): <__main__.classesPaire instance at 0x109923998>,
#  (u'ps1S', u'ps3S'): <__main__.classesPaire instance at 0x10d4a3f38>,
#  (u'fi3P', u'pI2P'): <__main__.classesPaire instance at 0x10c499cf8>,
#  (u'pI1P', u'ai2P'): <__main__.classesPaire instance at 0x10bfd1830>,
#  (u'pi1S', u'pc2S'): <__main__.classesPaire instance at 0x10ca542d8>,
#  (u'pi2P', u'pi3S'): <__main__.classesPaire instance at 0x10cb10710>,
#  (u'ii1P', u'pc2P'): <__main__.classesPaire instance at 0x10c826758>,
#  (u'ii1P', u'ii3S'): <__main__.classesPaire instance at 0x10988c710>,
#  (u'ppMP', u'ps1S'): <__main__.classesPaire instance at 0x10d21f4d0>,
#  (u'ppFP', u'pI2S'): <__main__.classesPaire instance at 0x10cd68f38>,
#  (u'pP', u'fi2P'): <__main__.classesPaire instance at 0x1098fe320>,
#  (u'ai3S', u'pi3P'): <__main__.classesPaire instance at 0x10bd7b5a8>,
#  (u'pc1S', u'ps1P'): <__main__.classesPaire instance at 0x10ce6b1b8>,
#  (u'fi2S', u'pI2P'): <__main__.classesPaire instance at 0x10c361908>,
#  (u'pc1P', u'ai2S'): <__main__.classesPaire instance at 0x10bfcb560>,
#  (u'pi1P', u'pc3P'): <__main__.classesPaire instance at 0x10d1df098>,
#  (u'fi2S', u'is1P'): <__main__.classesPaire instance at 0x10c47d3b0>,
#  (u'ppMS', u'ppMP'): <__main__.classesPaire instance at 0x10ce4c1b8>,
#  (u'ai3S', u'ps1P'): <__main__.classesPaire instance at 0x10bcaa290>,
#  (u'pc1S', u'ai3S'): <__main__.classesPaire instance at 0x10bc44dd0>,
#  (u'pc1S', u'pI1P'): <__main__.classesPaire instance at 0x10ca54098>,
#  (u'pi2P', u'ppFP'): <__main__.classesPaire instance at 0x10cd383f8>,
#  (u'pP', u'ps1P'): <__main__.classesPaire instance at 0x10cbf0a70>,
#  (u'is1P', u'pi1S'): <__main__.classesPaire instance at 0x10ccbd878>,
#  (u'ai2P', u'pc3S'): <__main__.classesPaire instance at 0x10bfe4290>,
#  (u'fi3P', u'ai1S'): <__main__.classesPaire instance at 0x10bc51518>,
#  (u'ii2S', u'ppMS'): <__main__.classesPaire instance at 0x10ca54998>,
#  (u'pi3P', u'ii1S'): <__main__.classesPaire instance at 0x10c948ef0>,
#  (u'ai1P', u'pP'): <__main__.classesPaire instance at 0x10bfa2758>,
#  (u'ai3P', u'is3P'): <__main__.classesPaire instance at 0x10b88d320>,
#  (u'pI1P', u'ps3S'): <__main__.classesPaire instance at 0x10ccab320>,
#  (u'ai1S', u'fi3P'): <__main__.classesPaire instance at 0x10bc51d88>,
#  (u'pi1P', u'pc2S'): <__main__.classesPaire instance at 0x10d1b9908>,
#  (u'ps1P', u'ai2P'): <__main__.classesPaire instance at 0x10c00b368>,
#  (u'pc2S', u'pI1P'): <__main__.classesPaire instance at 0x10cb0c998>,
#  (u'ii3P', u'fi3P'): <__main__.classesPaire instance at 0x10c499b00>,
#  (u'pi2P', u'inf'): <__main__.classesPaire instance at 0x10c3d2050>,
#  (u'ii2S', u'fi2S'): <__main__.classesPaire instance at 0x10981b170>,
#  (u'fi1S', u'ai3S'): <__main__.classesPaire instance at 0x10c188ea8>,
#  (u'fi3P', u'ii1S'): <__main__.classesPaire instance at 0x10bccea28>,
#  (u'is1P', u'ai2P'): <__main__.classesPaire instance at 0x10bd7b5f0>,
#  (u'ppMP', u'fi3S'): <__main__.classesPaire instance at 0x10c8523f8>,
#  (u'is1S', u'pi2P'): <__main__.classesPaire instance at 0x10cce4098>,
#  (u'ps1S', u'ii2S'): <__main__.classesPaire instance at 0x10bcaaa28>,
#  (u'ps3P', u'ai1P'): <__main__.classesPaire instance at 0x10bc6aa70>,
#  (u'pi3P', u'ii3S'): <__main__.classesPaire instance at 0x10ca60830>,
#  (u'ii3S', u'pc2P'): <__main__.classesPaire instance at 0x10ca76ef0>,
#  (u'ai2P', u'ppMS'): <__main__.classesPaire instance at 0x10c00b908>,
#  (u'is1S', u'ps3P'): <__main__.classesPaire instance at 0x10cd05fc8>,
#  (u'fi1P', u'fi2P'): <__main__.classesPaire instance at 0x109b02200>,
#  (u'ii2S', u'ppFS'): <__main__.classesPaire instance at 0x10988f8c0>,
#  (u'pP', u'ppMP'): <__main__.classesPaire instance at 0x10ca547a0>,
#  (u'ai2S', u'fi2S'): <__main__.classesPaire instance at 0x10bfcb3f8>,
#  (u'pc2S', u'pc1S'): <__main__.classesPaire instance at 0x10ce6b4d0>,
#  (u'pc3S', u'pc3S'): <__main__.classesPaire instance at 0x10d1cea28>,
#  (u'pi1P', u'ppMS'): <__main__.classesPaire instance at 0x10ca55128>,
#  (u'fi3P', u'inf'): <__main__.classesPaire instance at 0x10c3d2d40>,
#  (u'ppMS', u'ii1P'): <__main__.classesPaire instance at 0x10c3d19e0>,
#  (u'pI2S', u'pc1S'): <__main__.classesPaire instance at 0x10bd7f488>,
#  (u'ii1P', u'pc3S'): <__main__.classesPaire instance at 0x1099fd3f8>,
#  (u'pi3S', u'ps3S'): <__main__.classesPaire instance at 0x10ccbdc68>,
#  (u'pI1P', u'ppMS'): <__main__.classesPaire instance at 0x10c499ef0>,
#  (u'fi2P', u'ai3S'): <__main__.classesPaire instance at 0x10bc6a878>,
#  (u'ps3P', u'ai3S'): <__main__.classesPaire instance at 0x10b431440>,
#  (u'pc1P', u'pP'): <__main__.classesPaire instance at 0x10ce5b440>,
#  (u'pP', u'ai2P'): <__main__.classesPaire instance at 0x10bd7b998>,
#  (u'fi2P', u'fi2S'): <__main__.classesPaire instance at 0x10c31ebd8>,
#  (u'ii2P', u'ai3P'): <__main__.classesPaire instance at 0x10bd007a0>,
#  (u'fi2S', u'fi2P'): <__main__.classesPaire instance at 0x10c361950>,
#  (u'is3S', u'ai3P'): <__main__.classesPaire instance at 0x10bd54a70>,
#  (u'pI1P', u'ps2P'): <__main__.classesPaire instance at 0x10bd7b488>,
#  (u'ii1P', u'ai2S'): <__main__.classesPaire instance at 0x10bc44560>,
#  (u'ai1S', u'ppMS'): <__main__.classesPaire instance at 0x10bcf3c20>,
#  (u'pc1S', u'ppFS'): <__main__.classesPaire instance at 0x10cbf0d88>,
#  (u'ps3S', u'pc3S'): <__main__.classesPaire instance at 0x10cd684d0>,
#  (u'fi2P', u'ppFP'): <__main__.classesPaire instance at 0x10c3a71b8>,
#  (u'is3S', u'pP'): <__main__.classesPaire instance at 0x10ca51ab8>,
#  (u'ps2P', u'ppMS'): <__main__.classesPaire instance at 0x10ce5b200>,
#  (u'ii2P', u'ai1P'): <__main__.classesPaire instance at 0x10b88dcf8>,
#  (u'pi3S', u'pc2S'): <__main__.classesPaire instance at 0x10d1b9950>,
#  (u'is1S', u'pc3P'): <__main__.classesPaire instance at 0x10c852560>,
#  (u'pi1P', u'ppFP'): <__main__.classesPaire instance at 0x10ca76248>,
#  (u'ii1P', u'ii1P'): <__main__.classesPaire instance at 0x10c6718c0>,
#  (u'ai1P', u'pI2S'): <__main__.classesPaire instance at 0x10bc878c0>,
#  (u'ii2P', u'fi1P'): <__main__.classesPaire instance at 0x109b00908>,
#  (u'ai3P', u'ps1P'): <__main__.classesPaire instance at 0x10bd3aef0>,
#  (u'ps1P', u'ppMS'): <__main__.classesPaire instance at 0x10d4a3560>,
#  (u'pi3P', u'pI2P'): <__main__.classesPaire instance at 0x10cb0c560>,
#  (u'ai2S', u'pc1S'): <__main__.classesPaire instance at 0x10bd2e638>,
#  (u'pc2S', u'fi2S'): <__main__.classesPaire instance at 0x10bda77a0>,
#  (u'is3P', u'ai1P'): <__main__.classesPaire instance at 0x10bc5bef0>,
#  (u'pI2S', u'ps1S'): <__main__.classesPaire instance at 0x10c961fc8>,
#  (u'ii1S', u'ii3P'): <__main__.classesPaire instance at 0x10c4946c8>,
#  (u'pi2S', u'fi1P'): <__main__.classesPaire instance at 0x10985df38>,
#  (u'ps1P', u'ii1P'): <__main__.classesPaire instance at 0x10c331680>,
#  (u'pi2P', u'pi2P'): <__main__.classesPaire instance at 0x10d277fc8>,
#  (u'ii1P', u'ii2P'): <__main__.classesPaire instance at 0x10c671998>,
#  (u'pc2P', u'ai1S'): <__main__.classesPaire instance at 0x10bcf3638>,
#  (u'fi1P', u'pI2P'): <__main__.classesPaire instance at 0x1098f2050>,
#  (u'pc2S', u'ppFS'): <__main__.classesPaire instance at 0x10cd05440>,
#  (u'fi2S', u'pi3P'): <__main__.classesPaire instance at 0x10c31eb48>,
#  (u'is3P', u'pi1S'): <__main__.classesPaire instance at 0x10cce4dd0>,
#  (u'ps2P', u'pI2P'): <__main__.classesPaire instance at 0x10c865a70>,
#  (u'pc2S', u'fi1S'): <__main__.classesPaire instance at 0x10c331440>,
#  (u'fi2S', u'pc2P'): <__main__.classesPaire instance at 0x109872d88>,
#  (u'pc1P', u'ai1P'): <__main__.classesPaire instance at 0x10b4e6d88>,
#  (u'fi2S', u'is3S'): <__main__.classesPaire instance at 0x10c351248>,
#  (u'ps2S', u'pi1S'): <__main__.classesPaire instance at 0x10d05d3b0>,
#  (u'fi2S', u'ps1S'): <__main__.classesPaire instance at 0x10bfa2b48>,
#  (u'ps2P', u'ii1S'): <__main__.classesPaire instance at 0x10bd9f3b0>,
#  (u'pc2P', u'ii3S'): <__main__.classesPaire instance at 0x10ca76b00>,
#  (u'pc1S', u'ps3S'): <__main__.classesPaire instance at 0x109949950>,
#  (u'ppMP', u'pc3S'): <__main__.classesPaire instance at 0x10ce6b098>,
#  (u'ai1S', u'fi1P'): <__main__.classesPaire instance at 0x10bcf3440>,
#  (u'ppMS', u'pI2P'): <__main__.classesPaire instance at 0x10ca548c0>,
#  (u'pi3P', u'ai2P'): <__main__.classesPaire instance at 0x10bfe4050>,
#  (u'is1S', u'inf'): <__main__.classesPaire instance at 0x10cbf0830>,
#  (u'ps1P', u'pc3S'): <__main__.classesPaire instance at 0x10cbf0098>,
#  (u'pi3P', u'is3S'): <__main__.classesPaire instance at 0x10cb275f0>,
#  (u'pc3S', u'pi3P'): <__main__.classesPaire instance at 0x109802cb0>,
#  (u'ii1P', u'ppMP'): <__main__.classesPaire instance at 0x10c826518>,
#  (u'ai2P', u'is3P'): <__main__.classesPaire instance at 0x10bda7050>,
#  (u'ppMP', u'ii3S'): <__main__.classesPaire instance at 0x10cb27998>,
#  (u'is1S', u'is1P'): <__main__.classesPaire instance at 0x10cb0ccb0>,
#  (u'ps2P', u'ai2P'): <__main__.classesPaire instance at 0x10c00b6c8>,
#  (u'pi2S', u'pc3P'): <__main__.classesPaire instance at 0x10d05d440>,
#  (u'pP', u'fi3P'): <__main__.classesPaire instance at 0x10c653248>,
#  (u'pc1P', u'pi1S'): <__main__.classesPaire instance at 0x10c948d40>,
#  (u'ps1S', u'pc2S'): <__main__.classesPaire instance at 0x10cb107a0>,
#  (u'ps3S', u'ii2S'): <__main__.classesPaire instance at 0x10c361cf8>,
#  (u'pI2P', u'fi1P'): <__main__.classesPaire instance at 0x1098f24d0>,
#  (u'ai3P', u'ppMP'): <__main__.classesPaire instance at 0x10c074b90>,
#  (u'fi2S', u'fi1S'): <__main__.classesPaire instance at 0x109832b00>,
#  (u'is3S', u'ai1S'): <__main__.classesPaire instance at 0x10bd3aa28>,
#  (u'ii2S', u'ps2S'): <__main__.classesPaire instance at 0x10c3d1dd0>,
#  (u'ai2P', u'ai2P'): <__main__.classesPaire instance at 0x10bfd1b00>,
#  (u'pc2P', u'ps2S'): <__main__.classesPaire instance at 0x10cb10950>,
#  (u'pi2S', u'ai2S'): <__main__.classesPaire instance at 0x10bfcbe18>,
#  (u'pI2S', u'pI1P'): <__main__.classesPaire instance at 0x1098e6a70>,
#  (u'pI2S', u'is1S'): <__main__.classesPaire instance at 0x10ccbdfc8>,
#  (u'pc3S', u'ppFP'): <__main__.classesPaire instance at 0x10d086fc8>,
#  (u'ai1P', u'pi3P'): <__main__.classesPaire instance at 0x10bc44170>,
#  (u'pP', u'ppFP'): <__main__.classesPaire instance at 0x10c8459e0>,
#  (u'ppMS', u'ps2P'): <__main__.classesPaire instance at 0x10ce70a28>,
#  (u'ii1P', u'pI1P'): <__main__.classesPaire instance at 0x10c826878>,
#  (u'pc3P', u'is1S'): <__main__.classesPaire instance at 0x10cb10e60>,
#  (u'ai1P', u'pc1P'): <__main__.classesPaire instance at 0x10b4e6f80>,
#  (u'ps1P', u'pc2P'): <__main__.classesPaire instance at 0x10d088170>,
#  (u'pP', u'pi1S'): <__main__.classesPaire instance at 0x10cd68998>,
#  (u'ai1P', u'is3S'): <__main__.classesPaire instance at 0x10bc5b9e0>,
#  (u'fi2P', u'ai2P'): <__main__.classesPaire instance at 0x10bfcb758>,
#  (u'ai1S', u'ai1S'): <__main__.classesPaire instance at 0x10bcf3128>,
#  (u'is1P', u'fi1P'): <__main__.classesPaire instance at 0x1099f9488>,
#  (u'pI1P', u'ps1S'): <__main__.classesPaire instance at 0x10cb27950>,
#  (u'ai3S', u'ai1S'): <__main__.classesPaire instance at 0x10bcf3c68>,
#  (u'ii2P', u'pc1P'): <__main__.classesPaire instance at 0x109949a28>,
#  (u'pi2P', u'is3P'): <__main__.classesPaire instance at 0x10cd16050>,
#  (u'pI1P', u'ai3P'): <__main__.classesPaire instance at 0x10c0a2368>,
#  (u'ps2P', u'fi2P'): <__main__.classesPaire instance at 0x10c3a7b00>,
#  (u'pc2S', u'pc2S'): <__main__.classesPaire instance at 0x10d1b3cf8>,
#  (u'pi2S', u'pi2S'): <__main__.classesPaire instance at 0x10d4d0b00>,
#  (u'fi3S', u'pi2P'): <__main__.classesPaire instance at 0x10c8263f8>,
#  (u'ai1S', u'pi1P'): <__main__.classesPaire instance at 0x10bcaa878>,
#  (u'ai3P', u'inf'): <__main__.classesPaire instance at 0x10b88d4d0>,
#  (u'pP', u'pc3P'): <__main__.classesPaire instance at 0x10ccc00e0>,
#  (u'ai3S', u'pi1P'): <__main__.classesPaire instance at 0x10bcf3200>,
#  (u'ai2S', u'pi3S'): <__main__.classesPaire instance at 0x10bfe4950>,
#  (u'is1S', u'ps1P'): <__main__.classesPaire instance at 0x10cd05878>,
#  (u'is1P', u'fi3S'): <__main__.classesPaire instance at 0x1098dea70>,
#  (u'ps2S', u'ai3P'): <__main__.classesPaire instance at 0x10c1145a8>,
#  (u'pc1S', u'ii2S'): <__main__.classesPaire instance at 0x10c961e18>,
#  (u'pc1S', u'fi2S'): <__main__.classesPaire instance at 0x10986e518>,
#  (u'ppFS', u'pc2P'): <__main__.classesPaire instance at 0x10ce4cb90>,
#  (u'pI2S', u'pc3P'): <__main__.classesPaire instance at 0x10cd38ef0>,
#  (u'pi1P', u'inf'): <__main__.classesPaire instance at 0x10c331e60>,
#  (u'fi2P', u'ii3P'): <__main__.classesPaire instance at 0x10c3a7b90>,
#  (u'ii1S', u'ppMS'): <__main__.classesPaire instance at 0x10c653368>,
#  (u'ai1S', u'ps3P'): <__main__.classesPaire instance at 0x10bd3a6c8>,
#  (u'pc3P', u'ai1P'): <__main__.classesPaire instance at 0x10bc51d40>,
#  (u'fi2S', u'pi2S'): <__main__.classesPaire instance at 0x10afcfb90>,
#  (u'fi3S', u'inf'): <__main__.classesPaire instance at 0x10c1b5c20>,
#  (u'ii2S', u'pI2S'): <__main__.classesPaire instance at 0x10c852248>,
#  (u'ps3S', u'pi2S'): <__main__.classesPaire instance at 0x10d2771b8>,
#  (u'ii1P', u'ps1S'): <__main__.classesPaire instance at 0x10c3519e0>,
#  (u'ii1P', u'is3S'): <__main__.classesPaire instance at 0x10c3617e8>,
#  (u'ii2S', u'ii2S'): <__main__.classesPaire instance at 0x10c9534d0>,
#  (u'fi2P', u'fi1P'): <__main__.classesPaire instance at 0x109b02e18>,
#  (u'ps3P', u'pc3S'): <__main__.classesPaire instance at 0x10ca55ab8>,
#  (u'pc1S', u'ppMP'): <__main__.classesPaire instance at 0x10ca551b8>,
#  (u'ppMS', u'pc1P'): <__main__.classesPaire instance at 0x10ce705a8>,
#  (u'pP', u'ii2S'): <__main__.classesPaire instance at 0x10c1b5bd8>,
#  (u'fi2P', u'ppMS'): <__main__.classesPaire instance at 0x109949b90>,
#  (u'ai1P', u'ppMS'): <__main__.classesPaire instance at 0x10b3d4488>,
#  (u'pc3S', u'ii2S'): <__main__.classesPaire instance at 0x10ca51710>,
#  (u'pi1S', u'pi3S'): <__main__.classesPaire instance at 0x10ce70518>,
#  (u'ai3P', u'ai1S'): <__main__.classesPaire instance at 0x10bcf35a8>,
#  (u'fi2S', u'ii1S'): <__main__.classesPaire instance at 0x10c351bd8>,
#  (u'ppMS', u'pP'): <__main__.classesPaire instance at 0x10bfa2c68>,
#  (u'pc3S', u'pi2S'): <__main__.classesPaire instance at 0x10ccd6638>,
#  (u'ii1P', u'pc3P'): <__main__.classesPaire instance at 0x1099493f8>,
#  (u'fi1S', u'pI1P'): <__main__.classesPaire instance at 0x10c0543f8>,
#  (u'pi1P', u'ai3S'): <__main__.classesPaire instance at 0x10983df38>,
#  (u'fi1S', u'is1S'): <__main__.classesPaire instance at 0x109802908>,
#  (u'ii3P', u'pi3S'): <__main__.classesPaire instance at 0x10c948680>,
#  (u'ps1P', u'fi3P'): <__main__.classesPaire instance at 0x109816e18>,
#  (u'pc3P', u'ppFS'): <__main__.classesPaire instance at 0x10d21fb48>,
#  (u'pc1P', u'pi3P'): <__main__.classesPaire instance at 0x10ccabf38>,
#  (u'pI2P', u'fi3P'): <__main__.classesPaire instance at 0x10c499830>,
#  (u'pi3P', u'ai3S'): <__main__.classesPaire instance at 0x10bd7bd88>,
#  (u'ii3S', u'ps1S'): <__main__.classesPaire instance at 0x10cbcd8c0>,
#  (u'pi1S', u'pc3S'): <__main__.classesPaire instance at 0x10cd68cb0>,
#  (u'ppMS', u'ii2S'): <__main__.classesPaire instance at 0x10ca54950>,
#  (u'fi2S', u'ai2P'): <__main__.classesPaire instance at 0x10bfcbcf8>,
#  (u'fi2S', u'pi1S'): <__main__.classesPaire instance at 0x109855dd0>,
#  (u'ai2S', u'ii1P'): <__main__.classesPaire instance at 0x10bd7f5a8>,
#  (u'ii3S', u'pc3S'): <__main__.classesPaire instance at 0x10c3d1ea8>,
#  (u'fi3S', u'ppFS'): <__main__.classesPaire instance at 0x10c671e60>,
#  (u'ps3S', u'ai2P'): <__main__.classesPaire instance at 0x10c00bd88>,
#  (u'ppMP', u'ai2S'): <__main__.classesPaire instance at 0x10c054908>,
#  (u'ii2S', u'is1S'): <__main__.classesPaire instance at 0x10c39f998>,
#  (u'ai2P', u'pP'): <__main__.classesPaire instance at 0x10bd7b830>,
#  (u'pI2S', u'pP'): <__main__.classesPaire instance at 0x10ca51638>,
#  (u'fi2S', u'pc3P'): <__main__.classesPaire instance at 0x10bc5b320>,
#  (u'ai1P', u'pi2S'): <__main__.classesPaire instance at 0x10b88d680>,
#  (u'pI1P', u'ii3S'): <__main__.classesPaire instance at 0x10c3d15f0>,
#  (u'pc2S', u'ii1S'): <__main__.classesPaire instance at 0x109929050>,
#  (u'ai1P', u'ppFS'): <__main__.classesPaire instance at 0x10bcda368>,
#  (u'pi2P', u'ppMS'): <__main__.classesPaire instance at 0x10d4a3998>,
#  (u'is1S', u'ppFP'): <__main__.classesPaire instance at 0x10cb10f38>,
#  (u'ii1P', u'ps2P'): <__main__.classesPaire instance at 0x10983ff38>,
#  (u'pc1P', u'ps1S'): <__main__.classesPaire instance at 0x10c04f5a8>,
#  (u'ai3P', u'pi1S'): <__main__.classesPaire instance at 0x10bcda440>,
#  (u'pc1S', u'inf'): <__main__.classesPaire instance at 0x10c379cb0>,
#  (u'ii1S', u'ai2P'): <__main__.classesPaire instance at 0x10bd54248>,
#  (u'is3P', u'fi1P'): <__main__.classesPaire instance at 0x1098a2998>,
#  (u'pi2S', u'pI2P'): <__main__.classesPaire instance at 0x10ce4c950>,
#  (u'ii1S', u'fi2S'): <__main__.classesPaire instance at 0x10c351b48>,
#  (u'ii3P', u'pc1P'): <__main__.classesPaire instance at 0x10c953b90>,
#  (u'ii3S', u'ai1S'): <__main__.classesPaire instance at 0x10bd3a1b8>,
#  (u'pi2S', u'ii1P'): <__main__.classesPaire instance at 0x10c499560>,
#  (u'ii3P', u'ai2S'): <__main__.classesPaire instance at 0x10c01e248>,
#  (u'is3P', u'is1S'): <__main__.classesPaire instance at 0x10cce41b8>,
#  (u'pi3P', u'fi2P'): <__main__.classesPaire instance at 0x10afcf098>,
#  (u'fi1P', u'pi2P'): <__main__.classesPaire instance at 0x10b43ea70>,
#  (u'pi2S', u'pi3P'): <__main__.classesPaire instance at 0x10ca55f38>,
#  (u'is3S', u'pc1S'): <__main__.classesPaire instance at 0x10cce4ea8>,
#  (u'pi3S', u'is1P'): <__main__.classesPaire instance at 0x10ccc0908>,
#  (u'ai2P', u'fi1S'): <__main__.classesPaire instance at 0x10bfcb8c0>,
#  (u'ppMS', u'ai1P'): <__main__.classesPaire instance at 0x10bcdaf38>,
#  (u'pP', u'ps3P'): <__main__.classesPaire instance at 0x10cbf0fc8>,
#  (u'ai1P', u'ai2P'): <__main__.classesPaire instance at 0x10b88d200>,
#  (u'ai3P', u'pc3S'): <__main__.classesPaire instance at 0x10c0a2f80>,
#  (u'ai3P', u'pi2S'): <__main__.classesPaire instance at 0x10bc51b90>,
#  (u'pP', u'ai1P'): <__main__.classesPaire instance at 0x10bfa2f38>,
#  (u'inf', u'ai1S'): <__main__.classesPaire instance at 0x10bcce3b0>,
#  (u'is1S', u'ai3S'): <__main__.classesPaire instance at 0x10bc51440>,
#  (u'is3S', u'fi3P'): <__main__.classesPaire instance at 0x10c3a72d8>,
#  (u'ps2S', u'ai2S'): <__main__.classesPaire instance at 0x10c054ea8>,
#  (u'pc1P', u'ppFS'): <__main__.classesPaire instance at 0x10d06da70>,
#  (u'pc1S', u'pc2S'): <__main__.classesPaire instance at 0x10ce6b908>,
#  (u'pi1P', u'ii2S'): <__main__.classesPaire instance at 0x10c928170>,
#  (u'fi3P', u'pc1P'): <__main__.classesPaire instance at 0x10afcfe18>,
#  (u'pc2P', u'fi1S'): <__main__.classesPaire instance at 0x10c3313f8>,
#  (u'fi2P', u'ii2S'): <__main__.classesPaire instance at 0x1098524d0>,
#  (u'pi1P', u'is1P'): <__main__.classesPaire instance at 0x10cc15710>,
#  (u'ai3P', u'ai3P'): <__main__.classesPaire instance at 0x10bfe4ab8>,
#  (u'inf', u'pi1P'): <__main__.classesPaire instance at 0x10c331ef0>,
#  (u'is3P', u'pi2S'): <__main__.classesPaire instance at 0x10cd164d0>,
#  (u'ps3S', u'ii3P'): <__main__.classesPaire instance at 0x10c9283b0>,
#  (u'ps3S', u'ii1P'): <__main__.classesPaire instance at 0x10c662830>,
#  (u'fi3P', u'fi2S'): <__main__.classesPaire instance at 0x10c373290>,
#  (u'is3S', u'ps1S'): <__main__.classesPaire instance at 0x10cb10248>,
#  (u'ii3P', u'pc2S'): <__main__.classesPaire instance at 0x10ca517e8>,
#  (u'fi3S', u'ai3P'): <__main__.classesPaire instance at 0x10bc6a098>,
#  (u'pi2P', u'ai2P'): <__main__.classesPaire instance at 0x10bfe45a8>,
#  (u'is3S', u'ps2P'): <__main__.classesPaire instance at 0x10c31e3b0>,
#  (u'ai1S', u'is1S'): <__main__.classesPaire instance at 0x10bcaad40>,
#  (u'ps3S', u'ps3P'): <__main__.classesPaire instance at 0x10d490b48>,
#  (u'ppMS', u'is3S'): <__main__.classesPaire instance at 0x10c1a7878>,
#  (u'pi2S', u'ii3P'): <__main__.classesPaire instance at 0x10c845320>,
#  (u'pi1S', u'ii1S'): <__main__.classesPaire instance at 0x10c95a7a0>,
#  (u'fi1S', u'ii3S'): <__main__.classesPaire instance at 0x1098e95f0>,
#  (u'pi3P', u'ps2S'): <__main__.classesPaire instance at 0x10d1a13f8>,
#  (u'ii1P', u'pI2P'): <__main__.classesPaire instance at 0x10c826998>,
#  (u'fi2P', u'ps2S'): <__main__.classesPaire instance at 0x10c3350e0>,
#  (u'pc3S', u'ii3P'): <__main__.classesPaire instance at 0x10ca55488>,
#  (u'ai2S', u'ai3P'): <__main__.classesPaire instance at 0x10c00bea8>,
#  (u'ii2S', u'is3P'): <__main__.classesPaire instance at 0x10c948050>,
#  (u'ii2S', u'ai2S'): <__main__.classesPaire instance at 0x10bcaa7a0>,
#  (u'is1P', u'pI2P'): <__main__.classesPaire instance at 0x10ccbd950>,
#  (u'inf', u'ppFS'): <__main__.classesPaire instance at 0x10c0a2830>,
#  (u'ppMP', u'is1S'): <__main__.classesPaire instance at 0x10cd05320>,
#  (u'ii1S', u'ps2P'): <__main__.classesPaire instance at 0x10bd9fe60>,
#  (u'fi3P', u'fi1S'): <__main__.classesPaire instance at 0x10bfe4ea8>,
#  (u'fi1P', u'ai1P'): <__main__.classesPaire instance at 0x10bc44b00>,
#  (u'ai3S', u'ps1S'): <__main__.classesPaire instance at 0x10bd9f9e0>,
#  (u'pc1S', u'pi2P'): <__main__.classesPaire instance at 0x10d06dbd8>,
#  (u'ps2S', u'ai3S'): <__main__.classesPaire instance at 0x10b43ef38>,
#  (u'pi3P', u'pc2P'): <__main__.classesPaire instance at 0x10d088368>,
#  (u'fi2S', u'ai3S'): <__main__.classesPaire instance at 0x10981b3b0>,
#  (u'fi1P', u'ps2P'): <__main__.classesPaire instance at 0x1098da488>,
#  (u'pc3S', u'ai1P'): <__main__.classesPaire instance at 0x10bc6a560>,
#  (u'ppMS', u'pi1P'): <__main__.classesPaire instance at 0x10cbe59e0>,
#  (u'ii3P', u'pi1P'): <__main__.classesPaire instance at 0x10c499dd0>,
#  (u'ai2P', u'ps2S'): <__main__.classesPaire instance at 0x10c00b7a0>,
#  (u'ppMS', u'ai3S'): <__main__.classesPaire instance at 0x10bd7f098>,
#  (u'pI1P', u'pI1P'): <__main__.classesPaire instance at 0x10cbe53b0>,
# ...
#  (u'pc2S', u'pI2S'): <__main__.classesPaire instance at 0x10c852a70>,
#  (u'ii1S', u'is1P'): <__main__.classesPaire instance at 0x10c653e18>,
#  (u'is3P', u'ai1S'): <__main__.classesPaire instance at 0x10bd3a8c0>,
#  (u'ai3S', u'ai2S'): <__main__.classesPaire instance at 0x10c01e3f8>,
#  (u'pc3S', u'pi1P'): <__main__.classesPaire instance at 0x10c379a28>,
#  (u'ppFS', u'fi1S'): <__main__.classesPaire instance at 0x10bfa2998>,
#  (u'fi2P', u'fi2P'): <__main__.classesPaire instance at 0x10c1b5440>,
#  (u'ps3P', u'pc2S'): <__main__.classesPaire instance at 0x10d1df758>,
#  (u'ps2S', u'ps1S'): <__main__.classesPaire instance at 0x10d277998>,
#  (u'is3S', u'ai3S'): <__main__.classesPaire instance at 0x10bd2efc8>,
#  (u'ppFP', u'is3P'): <__main__.classesPaire instance at 0x10cb0c488>,
#  (u'is3P', u'pi3S'): <__main__.classesPaire instance at 0x10cd16e18>,
#  (u'is1S', u'ai2P'): <__main__.classesPaire instance at 0x10bda7440>,
#  (u'pi3S', u'fi2S'): <__main__.classesPaire instance at 0x10c39fc68>,
#  (u'ps3S', u'is3S'): <__main__.classesPaire instance at 0x10c335e18>,
#  (u'fi2P', u'ppFS'): <__main__.classesPaire instance at 0x10c188ab8>,
#  (u'fi2S', u'ps2S'): <__main__.classesPaire instance at 0x10c379128>,
#  (u'pi3P', u'ppFS'): <__main__.classesPaire instance at 0x10ce70a70>,
#  (u'pi3P', u'fi3S'): <__main__.classesPaire instance at 0x10c335950>,
#  (u'ii2P', u'ai1S'): <__main__.classesPaire instance at 0x10bd00488>,
#  (u'ai1S', u'ppFS'): <__main__.classesPaire instance at 0x10bd7bf38>,
#  (u'fi1S', u'ppFS'): <__main__.classesPaire instance at 0x10c335ab8>,
#  (u'ps2P', u'inf'): <__main__.classesPaire instance at 0x10cb10368>,
#  (u'pc2S', u'ps1P'): <__main__.classesPaire instance at 0x10d1df9e0>,
#  (u'pc3P', u'pP'): <__main__.classesPaire instance at 0x10ccc0e18>,
#  (u'ai3P', u'ps1S'): <__main__.classesPaire instance at 0x10c114488>,
#  (u'ai3P', u'pI2S'): <__main__.classesPaire instance at 0x10c0a2878>,
#  (u'ai2P', u'pi3S'): <__main__.classesPaire instance at 0x10bfe4dd0>,
#  (u'ppMS', u'fi1S'): <__main__.classesPaire instance at 0x10c3614d0>,
#  (u'fi1S', u'pc2S'): <__main__.classesPaire instance at 0x10c331878>,
#  (u'pc2P', u'pi2P'): <__main__.classesPaire instance at 0x10ce80f38>,
#  (u'ii3S', u'is3P'): <__main__.classesPaire instance at 0x10c953290>,
#  (u'pc3S', u'ps2S'): <__main__.classesPaire instance at 0x10d06ddd0>,
#  (u'ps1P', u'ppFS'): <__main__.classesPaire instance at 0x10d6c9e60>,
#  (u'pi2S', u'fi3S'): <__main__.classesPaire instance at 0x10c653320>,
#  (u'inf', u'fi2P'): <__main__.classesPaire instance at 0x10c3d1ab8>,
#  (u'fi1S', u'ii1S'): <__main__.classesPaire instance at 0x1099f6ab8>,
#  (u'is1P', u'ps2S'): <__main__.classesPaire instance at 0x10ccd6440>,
#  (u'pc1P', u'fi2P'): <__main__.classesPaire instance at 0x10c3d2ab8>,
#  (u'ps2S', u'pc1S'): <__main__.classesPaire instance at 0x10cbcdb00>,
#  (u'pP', u'inf'): <__main__.classesPaire instance at 0x10cbe5e60>,
#  (u'pc2P', u'ai1P'): <__main__.classesPaire instance at 0x10bcaa758>,
#  (u'fi1P', u'ps1S'): <__main__.classesPaire instance at 0x1099fe950>,
#  (u'pc3P', u'ppMP'): <__main__.classesPaire instance at 0x10d1df5a8>,
#  (u'ai3P', u'ps2P'): <__main__.classesPaire instance at 0x10bda7b90>,
#  (u'ii1S', u'pP'): <__main__.classesPaire instance at 0x10c379320>,
#  (u'pI2S', u'ai3P'): <__main__.classesPaire instance at 0x10c0a2560>,
#  (u'pc2S', u'fi1P'): <__main__.classesPaire instance at 0x1097ff2d8>,
#  (u'ppFS', u'pI2P'): <__main__.classesPaire instance at 0x10cb27758>,
#  (u'fi1S', u'pi1P'): <__main__.classesPaire instance at 0x10c331098>,
#  (u'pI2S', u'fi2P'): <__main__.classesPaire instance at 0x10c3d2b00>,
#  (u'pc1P', u'ai1S'): <__main__.classesPaire instance at 0x10bd2e2d8>,
#  (u'ii2P', u'inf'): <__main__.classesPaire instance at 0x1098feb00>,
#  (u'ii2P', u'pi1P'): <__main__.classesPaire instance at 0x10c95ad88>,
#  (u'fi2S', u'ps1P'): <__main__.classesPaire instance at 0x10c494bd8>,
#  (u'ai1P', u'ii2S'): <__main__.classesPaire instance at 0x10bc44cf8>,
#  (u'ai3P', u'is1S'): <__main__.classesPaire instance at 0x10bfcb9e0>,
#  (u'ps2P', u'ii1P'): <__main__.classesPaire instance at 0x10c31e0e0>,
#  (u'ai3S', u'ppMP'): <__main__.classesPaire instance at 0x10bcf3ab8>,
#  (u'fi3S', u'is1P'): <__main__.classesPaire instance at 0x10c114878>,
#  (u'ai3S', u'pi2P'): <__main__.classesPaire instance at 0x1098e6b48>,
#  (u'is3S', u'ii2S'): <__main__.classesPaire instance at 0x10c953638>,
#  (u'ps1P', u'pc3P'): <__main__.classesPaire instance at 0x10cbf0cb0>,
#  (u'ai2P', u'is3S'): <__main__.classesPaire instance at 0x10bfd1998>,
#  (u'is1S', u'ppMS'): <__main__.classesPaire instance at 0x10cd056c8>,
#  (u'fi3S', u'ii2S'): <__main__.classesPaire instance at 0x10c335c20>,
#  (u'pc3S', u'pI1P'): <__main__.classesPaire instance at 0x10c852ab8>,
#  (u'pi3P', u'pi2P'): <__main__.classesPaire instance at 0x10ce5bd40>,
#  (u'ps3P', u'is3S'): <__main__.classesPaire instance at 0x10ca764d0>,
#  (u'fi3S', u'pi2S'): <__main__.classesPaire instance at 0x10c39f908>,
#  (u'pc1P', u'pi1P'): <__main__.classesPaire instance at 0x10ce5b908>,
#  (u'pc2P', u'pi3P'): <__main__.classesPaire instance at 0x10d088440>,
#  (u'pc3S', u'ps1P'): <__main__.classesPaire instance at 0x109885f38>,
#  (u'pI2S', u'is3P'): <__main__.classesPaire instance at 0x10cbcd6c8>,
#  (u'pI2P', u'fi1S'): <__main__.classesPaire instance at 0x10c0a2d40>,
#  (u'fi1S', u'ii2S'): <__main__.classesPaire instance at 0x1099fe1b8>,
#  (u'ii3P', u'pI2S'): <__main__.classesPaire instance at 0x10ca60098>,
#  (u'ai3P', u'fi2S'): <__main__.classesPaire instance at 0x10bcaa200>,
#  (u'ii1S', u'ps3P'): <__main__.classesPaire instance at 0x10c865638>,
#  (u'ps1P', u'pI2P'): <__main__.classesPaire instance at 0x10c671c20>,
#  (u'fi1S', u'ppMS'): <__main__.classesPaire instance at 0x1099fdb48>,
#  (u'pc2P', u'ii2S'): <__main__.classesPaire instance at 0x10c953248>,
#  (u'inf', u'pc2S'): <__main__.classesPaire instance at 0x10c662200>,
#  (u'pI1P', u'pc3P'): <__main__.classesPaire instance at 0x10c95a638>,
#  (u'pc3S', u'ppFS'): <__main__.classesPaire instance at 0x10d086ea8>,
#  (u'fi3P', u'pc3P'): <__main__.classesPaire instance at 0x10c6538c0>,
#  (u'pi3P', u'ps3S'): <__main__.classesPaire instance at 0x10d4d0e60>,
#  (u'pI2P', u'pi3P'): <__main__.classesPaire instance at 0x10c95aab8>,
#  (u'ppMS', u'ps2S'): <__main__.classesPaire instance at 0x10cbcd200>,
#  (u'ps2P', u'pi2P'): <__main__.classesPaire instance at 0x10d1b3bd8>,
#  (u'ps1P', u'ii2S'): <__main__.classesPaire instance at 0x10ca55200>,
#  (u'pi2S', u'ai3S'): <__main__.classesPaire instance at 0x10bc6a5f0>,
#  (u'pI2S', u'pi3P'): <__main__.classesPaire instance at 0x10ce5b830>,
#  (u'pc2P', u'pP'): <__main__.classesPaire instance at 0x10c964248>,
#  (u'ps1P', u'pc2S'): <__main__.classesPaire instance at 0x10d1dfa28>,
#  (u'pc1P', u'pI2P'): <__main__.classesPaire instance at 0x10cce4cf8>,
#  (u'ps2P', u'ps3P'): <__main__.classesPaire instance at 0x10d4be488>,
#  (u'ai1P', u'is3P'): <__main__.classesPaire instance at 0x10b4e6c68>,
#  (u'is1P', u'fi1S'): <__main__.classesPaire instance at 0x10b42ef80>,
#  (u'ppMS', u'pi2P'): <__main__.classesPaire instance at 0x10d4a39e0>,
#  (u'is3P', u'is3S'): <__main__.classesPaire instance at 0x10cd05f80>,
#  (u'pI1P', u'ps1P'): <__main__.classesPaire instance at 0x10cc15830>,
#  (u'ai3S', u'ii1P'): <__main__.classesPaire instance at 0x10c01e908>,
#  (u'pc3P', u'is3P'): <__main__.classesPaire instance at 0x10cce4a28>,
#  (u'ii3S', u'pI2P'): <__main__.classesPaire instance at 0x1098162d8>,
#  (u'fi2S', u'ppFS'): <__main__.classesPaire instance at 0x10c361440>,
#  (u'pI1P', u'ai3S'): <__main__.classesPaire instance at 0x10c054200>,
#  (u'pI2P', u'is3P'): <__main__.classesPaire instance at 0x10cd16098>,
#  (u'pc1S', u'ai1S'): <__main__.classesPaire instance at 0x10bd005a8>,
#  (u'pi1S', u'fi1S'): <__main__.classesPaire instance at 0x109869680>,
#  (u'ii3P', u'ai1S'): <__main__.classesPaire instance at 0x10bd2e998>,
#  (u'ii2S', u'fi1P'): <__main__.classesPaire instance at 0x1099fb638>,
#  (u'fi3S', u'pc3P'): <__main__.classesPaire instance at 0x10c671f80>,
#  (u'ii2P', u'ps2P'): <__main__.classesPaire instance at 0x10c39f5a8>,
#  (u'pi3P', u'fi1S'): <__main__.classesPaire instance at 0x10c335170>,
#  (u'pc1P', u'is1S'): <__main__.classesPaire instance at 0x10c964a70>,
#  (u'ps2S', u'pI2P'): <__main__.classesPaire instance at 0x10ca76f80>,
#  (u'ppMP', u'ppFS'): <__main__.classesPaire instance at 0x10d6c9560>,
#  (u'fi2P', u'pc2S'): <__main__.classesPaire instance at 0x10c0a2c20>,
#  (u'pI2P', u'ii1S'): <__main__.classesPaire instance at 0x10c3d2440>,
#  (u'pc3P', u'pI1P'): <__main__.classesPaire instance at 0x10c95a0e0>,
#  (u'is3S', u'pc3P'): <__main__.classesPaire instance at 0x10cb0c098>,
#  (u'fi1S', u'ps3S'): <__main__.classesPaire instance at 0x10c379b90>,
#  (u'fi3P', u'pc2S'): <__main__.classesPaire instance at 0x10c653908>,
#  (u'ai2S', u'ppFP'): <__main__.classesPaire instance at 0x10bfd1638>,
#  (u'pc1P', u'ps2P'): <__main__.classesPaire instance at 0x10ccab908>,
#  (u'is1P', u'pc2S'): <__main__.classesPaire instance at 0x10ccc0710>,
#  (u'fi3S', u'is3S'): <__main__.classesPaire instance at 0x10c1b5200>,
#  (u'pi3P', u'ii2S'): <__main__.classesPaire instance at 0x10c928cf8>,
#  (u'pc3P', u'fi2P'): <__main__.classesPaire instance at 0x10c3d2b48>,
#  (u'ps2P', u'pP'): <__main__.classesPaire instance at 0x10ccd6368>,
#  (u'is1S', u'is3S'): <__main__.classesPaire instance at 0x10ccd6200>,
#  (u'ppFP', u'ps2P'): <__main__.classesPaire instance at 0x10d4d0d88>,
#  (u'fi1S', u'is1P'): <__main__.classesPaire instance at 0x109836830>,
#  (u'ppMP', u'ps1P'): <__main__.classesPaire instance at 0x10ce4c758>,
#  (u'fi1P', u'pc2P'): <__main__.classesPaire instance at 0x109872c68>,
#  (u'pc2P', u'ii1S'): <__main__.classesPaire instance at 0x10c47d638>,
#  (u'ps2P', u'ii2P'): <__main__.classesPaire instance at 0x10c39fa70>,
#  (u'pi1S', u'ai1P'): <__main__.classesPaire instance at 0x10bcaac20>,
#  (u'pI2S', u'pI2S'): <__main__.classesPaire instance at 0x10ca51c20>,
#  (u'pi3P', u'is1P'): <__main__.classesPaire instance at 0x10ccc0cb0>,
#  (u'ii1S', u'pc2S'): <__main__.classesPaire instance at 0x10c361cb0>,
#  (u'ps2P', u'pc2P'): <__main__.classesPaire instance at 0x10cd687a0>,
#  (u'is1P', u'pI1P'): <__main__.classesPaire instance at 0x10ccbd518>,
#  (u'pI1P', u'is1P'): <__main__.classesPaire instance at 0x10ccbd368>,
#  (u'fi1S', u'ai2P'): <__main__.classesPaire instance at 0x10bfcbc20>,
#  (u'pc1S', u'pi1S'): <__main__.classesPaire instance at 0x10cb104d0>,
#  (u'ii2P', u'ii3P'): <__main__.classesPaire instance at 0x10c3795f0>,
#  (u'pi2P', u'ps2P'): <__main__.classesPaire instance at 0x10d1b3908>,
#  (u'ps1P', u'is1P'): <__main__.classesPaire instance at 0x10ccd62d8>,
#  (u'ps2S', u'ai1P'): <__main__.classesPaire instance at 0x10bcaaa70>,
#  (u'fi2P', u'ps3S'): <__main__.classesPaire instance at 0x10c351830>,
#  (u'ii1S', u'ppFS'): <__main__.classesPaire instance at 0x10c826e60>,
#  (u'ppFP', u'inf'): <__main__.classesPaire instance at 0x10ca76488>,
#  (u'ii1S', u'fi3S'): <__main__.classesPaire instance at 0x10c3793b0>,
#  (u'ii1P', u'is3P'): <__main__.classesPaire instance at 0x10c852cb0>,
#  (u'ps3S', u'pc1S'): <__main__.classesPaire instance at 0x10c3739e0>,
#  (u'ii2P', u'pi2S'): <__main__.classesPaire instance at 0x10c845bd8>,
#  (u'ii3P', u'ii2P'): <__main__.classesPaire instance at 0x109818758>,
#  (u'ai1S', u'fi2P'): <__main__.classesPaire instance at 0x106c43a70>,
#  (u'is3S', u'ps3P'): <__main__.classesPaire instance at 0x10ca76b48>,
#  (u'pI1P', u'pi2S'): <__main__.classesPaire instance at 0x1098daab8>,
#  (u'ai1P', u'ii3P'): <__main__.classesPaire instance at 0x10bc6a050>,
#  (u'ii1P', u'pi2P'): <__main__.classesPaire instance at 0x10c3d27e8>,
#  (u'ai2P', u'is1P'): <__main__.classesPaire instance at 0x10bd7b248>,
#  (u'pc2S', u'ps2S'): <__main__.classesPaire instance at 0x10d1b3d88>,
#  (u'pP', u'ii2P'): <__main__.classesPaire instance at 0x109814cf8>,
#  (u'ii1P', u'pi3S'): <__main__.classesPaire instance at 0x10c0a2488>,
#  (u'pI2P', u'pI2S'): <__main__.classesPaire instance at 0x10cb0c5f0>,
#  (u'pi3S', u'ppFP'): <__main__.classesPaire instance at 0x10d1b9e60>,
#  (u'is3S', u'ii3P'): <__main__.classesPaire instance at 0x10ca55fc8>,
#  (u'ps2S', u'ii1P'): <__main__.classesPaire instance at 0x10c331758>,
#  (u'pI2S', u'pc3S'): <__main__.classesPaire instance at 0x10c3d2560>,
#  (u'pP', u'is1S'): <__main__.classesPaire instance at 0x10c3d2368>,
#  (u'pi2S', u'pI1P'): <__main__.classesPaire instance at 0x109814cb0>,
#  (u'fi3S', u'ii3P'): <__main__.classesPaire instance at 0x10c1884d0>,
#  (u'fi2S', u'ppMS'): <__main__.classesPaire instance at 0x10c3d15a8>,
#  (u'ai3S', u'pI2P'): <__main__.classesPaire instance at 0x105553248>,
#  (u'ps3S', u'pi3S'): <__main__.classesPaire instance at 0x10ccd6320>,
#  (u'is3S', u'pi1P'): <__main__.classesPaire instance at 0x10bcce908>,
#  (u'is3S', u'ai2S'): <__main__.classesPaire instance at 0x10c054290>,
#  (u'ppMS', u'inf'): <__main__.classesPaire instance at 0x10cbcda70>,
#  (u'ii3S', u'pc3P'): <__main__.classesPaire instance at 0x10c3a76c8>,
#  (u'pc1P', u'ii1P'): <__main__.classesPaire instance at 0x10c852998>,
#  (u'ii2S', u'is1P'): <__main__.classesPaire instance at 0x10c361878>,
#  (u'pI2P', u'pi1P'): <__main__.classesPaire instance at 0x10cce47a0>,
#  (u'pi3P', u'pP'): <__main__.classesPaire instance at 0x10ce4cfc8>,
#  (u'is1P', u'ppFP'): <__main__.classesPaire instance at 0x10ccc0ab8>,
#  (u'fi3S', u'ppMS'): <__main__.classesPaire instance at 0x10c361bd8>,
#  (u'ai2S', u'fi1P'): <__main__.classesPaire instance at 0x10c01e200>,
#  (u'ps3P', u'fi3P'): <__main__.classesPaire instance at 0x109949830>,
#  (u'pi2S', u'ai2P'): <__main__.classesPaire instance at 0x10bfe4758>,
#  (u'pi2P', u'ppMP'): <__main__.classesPaire instance at 0x10d1a14d0>,
#  (u'pI1P', u'pc2S'): <__main__.classesPaire instance at 0x10cb0c2d8>,
#  (u'ps3S', u'ppMS'): <__main__.classesPaire instance at 0x10cd386c8>,
#  (u'pi3S', u'pc1P'): <__main__.classesPaire instance at 0x10cb27098>,
#  (u'pc2P', u'pI2P'): <__main__.classesPaire instance at 0x10c3312d8>,
#  (u'pi1S', u'pc1S'): <__main__.classesPaire instance at 0x10ca76d40>,
#  (u'ppMS', u'ii3S'): <__main__.classesPaire instance at 0x10c964368>,
#  (u'pI2S', u'ps3S'): <__main__.classesPaire instance at 0x10c928f80>,
#  (u'ii2P', u'pi3S'): <__main__.classesPaire instance at 0x10c948488>,
#  (u'ps1S', u'pi3P'): <__main__.classesPaire instance at 0x10c928c68>,
#  (u'ai3S', u'ps2P'): <__main__.classesPaire instance at 0x10bda7638>,
#  (u'ii1S', u'pI1P'): <__main__.classesPaire instance at 0x10c47da28>,
#  (u'ii3P', u'pc1S'): <__main__.classesPaire instance at 0x10c9289e0>,
#  (u'ps1P', u'pi3P'): <__main__.classesPaire instance at 0x10d21f560>,
#  (u'is1S', u'pi3S'): <__main__.classesPaire instance at 0x10cce4d88>,
#  (u'pi2S', u'ii1S'): <__main__.classesPaire instance at 0x10c9617e8>,
#  (u'ai1S', u'ps2P'): <__main__.classesPaire instance at 0x10983de18>,
#  (u'pi3P', u'fi2S'): <__main__.classesPaire instance at 0x10c31e5f0>,
#  (u'ps3P', u'ps3P'): <__main__.classesPaire instance at 0x10d490ef0>,
#  (u'fi3P', u'is1P'): <__main__.classesPaire instance at 0x10983f830>,
#  (u'is3S', u'pc1P'): <__main__.classesPaire instance at 0x10ca556c8>,
#  (u'ii2S', u'fi3P'): <__main__.classesPaire instance at 0x10c351758>,
#  (u'pc2S', u'pP'): <__main__.classesPaire instance at 0x10ce700e0>,
#  (u'ppMS', u'ai1S'): <__main__.classesPaire instance at 0x10bcf3bd8>,
#  (u'pc2P', u'ai3S'): <__main__.classesPaire instance at 0x10bd00248>,
#  (u'ai3P', u'pi2P'): <__main__.classesPaire instance at 0x10987c050>,
#  (u'ps3P', u'ii3P'): <__main__.classesPaire instance at 0x10c948d88>,
#  (u'pI2P', u'ai3S'): <__main__.classesPaire instance at 0x10bd3a2d8>,
#  (u'ii1P', u'fi1S'): <__main__.classesPaire instance at 0x10bda7128>,
#  (u'ii3S', u'ii2S'): <__main__.classesPaire instance at 0x10c6714d0>,
#  (u'pI1P', u'pP'): <__main__.classesPaire instance at 0x10cb27680>,
#  (u'is3P', u'fi2S'): <__main__.classesPaire instance at 0x10c47dcf8>,
#  (u'fi2S', u'fi3S'): <__main__.classesPaire instance at 0x10c373320>,
#  (u'pi3P', u'pc1P'): <__main__.classesPaire instance at 0x10ccabcb0>,
#  (u'ps2S', u'ai2P'): <__main__.classesPaire instance at 0x10c00b1b8>,
#  (u'fi2S', u'ii3P'): <__main__.classesPaire instance at 0x10c3d17e8>,
#  ...}

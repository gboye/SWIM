# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
from IPython.html.widgets import FloatProgress
from IPython.display import display

# %%
phonologicalMap="-N"

# %%
import math
def rAn(r,n):
    f = math.factorial
    return f(n) / f(n-r)
def rCn(r,n):
    f = math.factorial
    return f(n) / f(r) / f(n-r)

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
validPhonemes=list(fs.supremum.concept.extent)
#for phoneme in validPhonemes:
#    print (phoneme, [phoneme], ";")

# %%
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# # Lecture du tableau de VERBES

# %% [markdown]
# ### Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
filePrefix="2015-Data/MGC-160104"

# %% [raw]
# casesPrincipales= [
#         'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
#         'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P',
#         'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
#         'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
#         'ps2P', 'ps3P',
#         'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
#         'ppMS', 'ppMP', 'ppFS', 'ppFP'
#             ]
# casesSecondaires= [
#        'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
#             ]
# casesTotales=casesPrincipales+casesSecondaires
# listeCases=casesTotales

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print (forme, file=logfile)
                print ("pas de classe",idClasseForme, file=logfile)
                print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %% [raw]
# def OLDrapports(paradigme):
#     (case1,case2,lexeme)= paradigme.columns.values.tolist()
#     patrons=pairePatrons(case1,case2)
#     if len(paradigme)>0:
# #        for index, row in paradigme.iterrows():
# #            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
#         paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
#         (regles1,regles2)=patrons.calculerGM()
#     return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ## Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for n,paire in enumerate(it.combinations_with_replacement(sampleCases,2)):
        progressBar.value=n
        if debug: print (paire, file=logfile)
        if debug: print ("-".join(paire),end=", ")
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ### Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
debug1=True

for echantillon in range(0,3):
    echantillonPrefix="-%02d"%(echantillon+1)
    
    nomLexique=filePrefix+echantillonPrefix+"-N-ext3-derivations-SILVER.csv"
    paradigmes=pd.read_csv(nomLexique,sep=";",encoding="utf8")    

    del paradigmes[u"Unnamed: 0"]
    sampleCases=paradigmes.columns.tolist()
    sampleCases.remove(u"lexeme")    

    #Neutralize all the forms
#    for case in sampleCases:
#        paradigmes[case]=paradigmes[case].apply(lambda x: recoder(x))

    #Save neutralized paradigms
#    paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+phonologicalMap+"-paradigmes.csv",encoding="utf8",sep=";")    
    
#    logfile_name=filePrefix+echantillonPrefix+phonologicalMap+".log"
#    logfile = codecs.open(logfile_name,mode='w',encoding="utf8")
    
    progressBar = FloatProgress(min=0, max=rCn(2,len(sampleCases)))
    display(progressBar)
    
    resultats=evaluerEchantillon(paradigmes)
    classesFinales={}
    for resultat in resultats:
        classesFinales[resultat]=resultats[resultat][0]
        classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]
#    with open(filePrefix+echantillonPrefix+phonologicalMap+'-Regles.pkl', 'wb') as output:
    with open(nomLexique.replace(".csv",'-Regles.pkl'), 'wb') as output:
       pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 25min 46s, sys: 6.89 s, total: 25min 53s
# Wall time: 26min 1s

# %%
for element in  (classesFinales[("pi3S","inf")].sortirForme(u"mâZ")):
    print (element)
# Out:
# mâZe

# %%
classesFinales
# Out:
# {(u'ps2P', u'is1S'): <__main__.classesPaire instance at 0x114612758>,
#  (u'inf', u'pi2S'): <__main__.classesPaire instance at 0x102ba00e0>,
#  (u'ii3S', u'pI1P'): <__main__.classesPaire instance at 0x10a216950>,
#  (u'is2S', u'pc3P'): <__main__.classesPaire instance at 0x1098aff38>,
#  (u'ps2S', u'ii2P'): <__main__.classesPaire instance at 0x114887d88>,
#  (u'pc2P', u'ai2P'): <__main__.classesPaire instance at 0x10b725680>,
#  (u'ii3P', u'pi2P'): <__main__.classesPaire instance at 0x10c41b998>,
#  (u'fi3P', u'pi2P'): <__main__.classesPaire instance at 0x110c0f440>,
#  (u'pi2S', u'ps3P'): <__main__.classesPaire instance at 0x10b867b48>,
#  (u'pc1P', u'pi2S'): <__main__.classesPaire instance at 0x113b6bc20>,
#  (u'FP', u'ps1P'): <__main__.classesPaire instance at 0x11422ff80>,
#  (u'is2S', u'ai1S'): <__main__.classesPaire instance at 0x110c0f830>,
#  (u'fi1P', u'pI1P'): <__main__.classesPaire instance at 0x114304128>,
#  (u'ps2P', u'ai3S'): <__main__.classesPaire instance at 0x110c0ff80>,
#  (u'pc1S', u'ai3S'): <__main__.classesPaire instance at 0x114c16128>,
#  (u'ii3S', u'ii3P'): <__main__.classesPaire instance at 0x10cd9c170>,
#  (u'FP', u'ps2S'): <__main__.classesPaire instance at 0x11377a050>,
#  (u'ps2S', u'fi1S'): <__main__.classesPaire instance at 0x10b1cd3b0>,
#  (u'pi2P', u'fi1S'): <__main__.classesPaire instance at 0x113fc5cf8>,
#  (u'ps3S', u'is2P'): <__main__.classesPaire instance at 0x10a8e92d8>,
#  (u'pi1S', u'fi3S'): <__main__.classesPaire instance at 0x113e7ca70>,
#  (u'is1P', u'pP'): <__main__.classesPaire instance at 0x10f022200>,
#  (u'ppFP', u'ppFP'): <__main__.classesPaire instance at 0x10be99758>,
#  (u'ppFS', u'fi3S'): <__main__.classesPaire instance at 0x113763e18>,
#  (u'ii2P', u'ps3P'): <__main__.classesPaire instance at 0x1098af998>,
#  (u'ii3S', u'ps3P'): <__main__.classesPaire instance at 0x113ee4878>,
#  (u'pc1P', u'fi3P'): <__main__.classesPaire instance at 0x10de1e8c0>,
#  (u'is3P', u'pI2P'): <__main__.classesPaire instance at 0x10be9d8c0>,
#  (u'ppMP', u'pc1P'): <__main__.classesPaire instance at 0x113ee4e60>,
#  (u'is3P', u'ppFS'): <__main__.classesPaire instance at 0x10da4b4d0>,
#  (u'ii3P', u'fi2S'): <__main__.classesPaire instance at 0x113fc5e60>,
#  (u'inf', u'is2P'): <__main__.classesPaire instance at 0x110307d40>,
#  (u'fi1S', u'ps1S'): <__main__.classesPaire instance at 0x10bacf2d8>,
#  (u'is1S', u'pc2P'): <__main__.classesPaire instance at 0x10c74e440>,
#  (u'pi3S', u'pc3S'): <__main__.classesPaire instance at 0x10a8d53f8>,
#  (u'ps3S', u'is3S'): <__main__.classesPaire instance at 0x10ad98290>,
#  (u'is2S', u'FS'): <__main__.classesPaire instance at 0x10b8a5b00>,
#  (u'ppMP', u'ii3P'): <__main__.classesPaire instance at 0x10b443758>,
#  (u'ppFS', u'pi1P'): <__main__.classesPaire instance at 0x1137632d8>,
#  (u'ppFS', u'is3P'): <__main__.classesPaire instance at 0x110c6ab48>,
#  (u'ps2P', u'is3S'): <__main__.classesPaire instance at 0x114078cb0>,
#  (u'ps3P', u'is1P'): <__main__.classesPaire instance at 0x10bbec0e0>,
#  (u'fi3S', u'fi2P'): <__main__.classesPaire instance at 0x109cd2320>,
#  (u'ppMP', u'ps3P'): <__main__.classesPaire instance at 0x110c1e5f0>,
#  (u'pI2P', u'ps2P'): <__main__.classesPaire instance at 0x113e7a248>,
#  (u'pi1S', u'pi2P'): <__main__.classesPaire instance at 0x10d617200>,
#  (u'is1P', u'pc2P'): <__main__.classesPaire instance at 0x11422f7e8>,
#  (u'FS', u'fi3P'): <__main__.classesPaire instance at 0x113e7a170>,
#  (u'pi1P', u'ai2P'): <__main__.classesPaire instance at 0x11422fd40>,
#  (u'pI1P', u'ai2S'): <__main__.classesPaire instance at 0x10c402680>,
#  (u'pI2P', u'ps1S'): <__main__.classesPaire instance at 0x10e693950>,
#  (u'pi2P', u'pi3P'): <__main__.classesPaire instance at 0x110301908>,
#  (u'fi1S', u'fi3S'): <__main__.classesPaire instance at 0x10e693a70>,
#  (u'ii1P', u'pc2S'): <__main__.classesPaire instance at 0x10f022170>,
#  (u'pI2P', u'is1S'): <__main__.classesPaire instance at 0x110d14f80>,
#  (u'pc3S', u'is1P'): <__main__.classesPaire instance at 0x10f2b7758>,
#  (u'ppMS', u'FS'): <__main__.classesPaire instance at 0x10a62bd88>,
#  (u'ppFP', u'pI2P'): <__main__.classesPaire instance at 0x110c44290>,
#  (u'is3S', u'ppMS'): <__main__.classesPaire instance at 0x113f2db00>,
#  (u'ii2P', u'FS'): <__main__.classesPaire instance at 0x113f817e8>,
#  (u'fi1P', u'ppFP'): <__main__.classesPaire instance at 0x113f2d440>,
#  (u'is2P', u'pP'): <__main__.classesPaire instance at 0x10b532248>,
#  (u'ps3S', u'fi1S'): <__main__.classesPaire instance at 0x11106e290>,
#  (u'inf', u'is3P'): <__main__.classesPaire instance at 0x10bacec20>,
#  (u'pI1P', u'ii1P'): <__main__.classesPaire instance at 0x1140d35a8>,
#  (u'pP', u'ps1S'): <__main__.classesPaire instance at 0x10f2a2200>,
#  (u'pi3S', u'ai1P'): <__main__.classesPaire instance at 0x10f24ab48>,
#  (u'pi2S', u'pI2P'): <__main__.classesPaire instance at 0x10aa39050>,
#  (u'is2S', u'ps1P'): <__main__.classesPaire instance at 0x113fb9518>,
#  (u'is1P', u'fi2P'): <__main__.classesPaire instance at 0x113f44320>,
#  (u'pi3P', u'ii1P'): <__main__.classesPaire instance at 0x110c1ee18>,
#  (u'ppMS', u'is1P'): <__main__.classesPaire instance at 0x10a559248>,
#  (u'ps3S', u'is1P'): <__main__.classesPaire instance at 0x113fb9b90>,
#  (u'pP', u'ps2P'): <__main__.classesPaire instance at 0x10d617ea8>,
#  (u'inf', u'ps2S'): <__main__.classesPaire instance at 0x114625a70>,
#  (u'fi1P', u'ii2S'): <__main__.classesPaire instance at 0x10a8d5050>,
#  (u'fi1P', u'fi1S'): <__main__.classesPaire instance at 0x10b5cb908>,
#  (u'ai1S', u'ii1P'): <__main__.classesPaire instance at 0x1103b4830>,
#  (u'pI1P', u'ai1S'): <__main__.classesPaire instance at 0x113e7cdd0>,
#  (u'pi2P', u'pc1S'): <__main__.classesPaire instance at 0x11459dd88>,
#  (u'pc3S', u'fi1S'): <__main__.classesPaire instance at 0x114c16c68>,
#  (u'pi1S', u'inf'): <__main__.classesPaire instance at 0x109d13d40>,
#  (u'pP', u'pI2P'): <__main__.classesPaire instance at 0x1103b4e60>,
#  (u'is1S', u'pi2P'): <__main__.classesPaire instance at 0x10f0227e8>,
#  (u'ppFP', u'pi2S'): <__main__.classesPaire instance at 0x113e647e8>,
#  (u'is1P', u'ppMP'): <__main__.classesPaire instance at 0x11451b488>,
#  (u'fi1P', u'is1P'): <__main__.classesPaire instance at 0x10b771d40>,
#  (u'pi3S', u'pi3S'): <__main__.classesPaire instance at 0x10ba80488>,
#  (u'pI2S', u'ii3S'): <__main__.classesPaire instance at 0x113ee4d88>,
#  (u'ai3S', u'is1P'): <__main__.classesPaire instance at 0x10c402758>,
#  (u'pc2P', u'FP'): <__main__.classesPaire instance at 0x10b1eadd0>,
#  (u'ai1P', u'ps1S'): <__main__.classesPaire instance at 0x10f24af38>,
#  (u'ps3P', u'pi2S'): <__main__.classesPaire instance at 0x10b867dd0>,
#  (u'ps1S', u'ii2P'): <__main__.classesPaire instance at 0x10e6935a8>,
#  (u'ai2S', u'is2P'): <__main__.classesPaire instance at 0x10e693998>,
#  (u'fi2P', u'ps1P'): <__main__.classesPaire instance at 0x10ca04320>,
#  (u'ps2P', u'ps2P'): <__main__.classesPaire instance at 0x113fcf488>,
#  (u'pP', u'fi3P'): <__main__.classesPaire instance at 0x10f70d8c0>,
#  (u'is1S', u'ps3S'): <__main__.classesPaire instance at 0x1103b41b8>,
#  (u'ai2P', u'ii3P'): <__main__.classesPaire instance at 0x1142397a0>,
#  (u'fi3P', u'ps1P'): <__main__.classesPaire instance at 0x1142a6b00>,
#  (u'fi3P', u'is3P'): <__main__.classesPaire instance at 0x113ec9680>,
#  (u'pc3P', u'pi2S'): <__main__.classesPaire instance at 0x10f163290>,
#  (u'is3P', u'ii2P'): <__main__.classesPaire instance at 0x10f022680>,
#  (u'ppFS', u'pc1P'): <__main__.classesPaire instance at 0x10ca94d40>,
#  (u'ai2S', u'fi3P'): <__main__.classesPaire instance at 0x114774bd8>,
#  (u'pI2P', u'is2S'): <__main__.classesPaire instance at 0x109ccba70>,
#  (u'inf', u'pi3P'): <__main__.classesPaire instance at 0x110349bd8>,
#  (u'pc3S', u'pc3P'): <__main__.classesPaire instance at 0x11457b560>,
#  (u'ps2S', u'pP'): <__main__.classesPaire instance at 0x10d617488>,
#  (u'ai2P', u'pi1P'): <__main__.classesPaire instance at 0x11422fcb0>,
#  (u'ii3P', u'pI2P'): <__main__.classesPaire instance at 0x1140f4c68>,
#  (u'ii1P', u'pc3P'): <__main__.classesPaire instance at 0x109825ef0>,
#  (u'pi1P', u'ai3S'): <__main__.classesPaire instance at 0x10ad55128>,
#  (u'pI2P', u'fi2S'): <__main__.classesPaire instance at 0x113e9f638>,
#  (u'pc1P', u'pi3P'): <__main__.classesPaire instance at 0x10f2b71b8>,
#  (u'pI1P', u'ppMP'): <__main__.classesPaire instance at 0x10b594710>,
#  (u'pi1S', u'pc3S'): <__main__.classesPaire instance at 0x10b725bd8>,
#  (u'ii3S', u'pi3S'): <__main__.classesPaire instance at 0x1146000e0>,
#  (u'is2P', u'ppFS'): <__main__.classesPaire instance at 0x110307200>,
#  (u'ppFP', u'pi3P'): <__main__.classesPaire instance at 0x10cbb43f8>,
#  (u'pc2S', u'ai3S'): <__main__.classesPaire instance at 0x10e391ab8>,
#  (u'ii3S', u'pc1S'): <__main__.classesPaire instance at 0x10f24ad88>,
#  (u'is2S', u'fi2S'): <__main__.classesPaire instance at 0x11032a200>,
#  (u'pP', u'ai1P'): <__main__.classesPaire instance at 0x10f022bd8>,
#  (u'pc3P', u'ps3P'): <__main__.classesPaire instance at 0x10bbecc20>,
#  (u'is2P', u'fi2P'): <__main__.classesPaire instance at 0x11489a4d0>,
#  (u'ppFP', u'ps3P'): <__main__.classesPaire instance at 0x114261320>,
#  (u'ai1S', u'ppMP'): <__main__.classesPaire instance at 0x113ee4c68>,
#  (u'pi2S', u'ps2S'): <__main__.classesPaire instance at 0x10be9d3b0>,
#  (u'ps3S', u'pc3P'): <__main__.classesPaire instance at 0x109d13368>,
#  (u'ai3P', u'fi3P'): <__main__.classesPaire instance at 0x10ca04050>,
#  (u'pi1P', u'fi1P'): <__main__.classesPaire instance at 0x10b1ea4d0>,
#  (u'fi1S', u'ppMP'): <__main__.classesPaire instance at 0x11451b710>,
#  (u'pc2S', u'is1S'): <__main__.classesPaire instance at 0x10b594c68>,
#  (u'ppMP', u'inf'): <__main__.classesPaire instance at 0x10dca2e60>,
#  (u'ii3P', u'ai2S'): <__main__.classesPaire instance at 0x10da5e710>,
#  (u'pi3P', u'ai2P'): <__main__.classesPaire instance at 0x114291908>,
#  (u'ppMS', u'ps1P'): <__main__.classesPaire instance at 0x10cb2f0e0>,
#  (u'ppFP', u'fi3P'): <__main__.classesPaire instance at 0x113fb2f38>,
#  (u'ppMS', u'pi1P'): <__main__.classesPaire instance at 0x10f618a70>,
#  (u'pi1S', u'is1P'): <__main__.classesPaire instance at 0x110397a28>,
#  (u'ps3P', u'ai3S'): <__main__.classesPaire instance at 0x10f856248>,
#  (u'is1S', u'pc3S'): <__main__.classesPaire instance at 0x10bbffef0>,
#  (u'ii1P', u'ii1S'): <__main__.classesPaire instance at 0x109d6c488>,
#  (u'fi2P', u'pi2S'): <__main__.classesPaire instance at 0x10c3e7998>,
#  (u'FP', u'pi1P'): <__main__.classesPaire instance at 0x1098a49e0>,
#  (u'pi1S', u'pI2P'): <__main__.classesPaire instance at 0x1149e43f8>,
#  (u'ppMP', u'ii2S'): <__main__.classesPaire instance at 0x110301cf8>,
#  (u'ai2S', u'is1P'): <__main__.classesPaire instance at 0x10cdfee18>,
#  (u'FS', u'ii2S'): <__main__.classesPaire instance at 0x113ea3830>,
#  (u'ii1S', u'pi1S'): <__main__.classesPaire instance at 0x10bae83f8>,
#  (u'fi3P', u'fi3P'): <__main__.classesPaire instance at 0x10b771d88>,
#  (u'pI2P', u'pc2P'): <__main__.classesPaire instance at 0x116fecd88>,
#  (u'FS', u'pi1S'): <__main__.classesPaire instance at 0x113f81b00>,
#  (u'ai2S', u'pi3P'): <__main__.classesPaire instance at 0x11422f5f0>,
#  (u'ai1S', u'FP'): <__main__.classesPaire instance at 0x113e9f2d8>,
#  (u'pc2P', u'fi2P'): <__main__.classesPaire instance at 0x10bacf998>,
#  (u'FP', u'fi3S'): <__main__.classesPaire instance at 0x10d418998>,
#  (u'ai3P', u'ii1S'): <__main__.classesPaire instance at 0x10bace170>,
#  (u'fi1S', u'ai3S'): <__main__.classesPaire instance at 0x114228518>,
#  (u'ps3P', u'ps2S'): <__main__.classesPaire instance at 0x10ca94f38>,
#  (u'pc1P', u'is2S'): <__main__.classesPaire instance at 0x10be99170>,
#  (u'ii3P', u'is3S'): <__main__.classesPaire instance at 0x10a176290>,
#  (u'pi2P', u'pi2S'): <__main__.classesPaire instance at 0x113fb2878>,
#  (u'ii3S', u'fi2S'): <__main__.classesPaire instance at 0x113f2d098>,
#  (u'pc3P', u'pc3P'): <__main__.classesPaire instance at 0x10af8e6c8>,
#  (u'ps1S', u'ps2P'): <__main__.classesPaire instance at 0x113e7c440>,
#  (u'is2S', u'pc2S'): <__main__.classesPaire instance at 0x10a0c0290>,
#  (u'FP', u'pP'): <__main__.classesPaire instance at 0x110cf6bd8>,
#  (u'is3P', u'pc3S'): <__main__.classesPaire instance at 0x10f282b48>,
#  (u'ps1P', u'fi1P'): <__main__.classesPaire instance at 0x11420a170>,
#  (u'fi2S', u'pi3S'): <__main__.classesPaire instance at 0x111007320>,
#  (u'ii1S', u'ai1P'): <__main__.classesPaire instance at 0x10bae8050>,
#  (u'pc2S', u'pi2S'): <__main__.classesPaire instance at 0x10b2c6ef0>,
#  (u'ii2P', u'ppMP'): <__main__.classesPaire instance at 0x10b8102d8>,
#  (u'is3P', u'pi1P'): <__main__.classesPaire instance at 0x10c41b710>,
#  (u'ii2S', u'pc2P'): <__main__.classesPaire instance at 0x111007a70>,
#  (u'pi1S', u'ai1P'): <__main__.classesPaire instance at 0x1140787e8>,
#  (u'pc3P', u'pi1S'): <__main__.classesPaire instance at 0x11422fab8>,
#  (u'fi3S', u'ai1S'): <__main__.classesPaire instance at 0x10baafa70>,
#  (u'ii1S', u'is3S'): <__main__.classesPaire instance at 0x10a13f5f0>,
#  (u'pc2P', u'ppFS'): <__main__.classesPaire instance at 0x10bbecb48>,
#  (u'ai1P', u'fi1P'): <__main__.classesPaire instance at 0x10a8145f0>,
#  (u'pi3P', u'ps3P'): <__main__.classesPaire instance at 0x113e646c8>,
#  (u'pc2P', u'fi3S'): <__main__.classesPaire instance at 0x10b7a3200>,
#  (u'ai2P', u'ppFP'): <__main__.classesPaire instance at 0x10aa39950>,
#  (u'pI1P', u'is3P'): <__main__.classesPaire instance at 0x10a93c248>,
#  (u'pc1P', u'fi1P'): <__main__.classesPaire instance at 0x10de1e5a8>,
#  (u'ps1P', u'ii1S'): <__main__.classesPaire instance at 0x10a7c65f0>,
#  (u'ai1S', u'fi1S'): <__main__.classesPaire instance at 0x113e9ffc8>,
#  (u'ii2P', u'ai3S'): <__main__.classesPaire instance at 0x10ad554d0>,
#  (u'is2S', u'pI2S'): <__main__.classesPaire instance at 0x10a176680>,
#  (u'pi3P', u'is3P'): <__main__.classesPaire instance at 0x10c74e5a8>,
#  (u'is1S', u'pi3S'): <__main__.classesPaire instance at 0x10f0212d8>,
#  (u'FP', u'pi3P'): <__main__.classesPaire instance at 0x10ba80290>,
#  (u'pi2P', u'is2P'): <__main__.classesPaire instance at 0x1137630e0>,
#  (u'is1P', u'pc1P'): <__main__.classesPaire instance at 0x11457bfc8>,
#  (u'ai1S', u'is3P'): <__main__.classesPaire instance at 0x11451b290>,
#  (u'ps1S', u'fi3P'): <__main__.classesPaire instance at 0x1176ad9e0>,
#  (u'pi1P', u'pi1P'): <__main__.classesPaire instance at 0x113fced40>,
#  (u'pi2S', u'pI2S'): <__main__.classesPaire instance at 0x10aa39680>,
#  (u'pi2S', u'pc3S'): <__main__.classesPaire instance at 0x11377acb0>,
#  (u'pi1S', u'pi1S'): <__main__.classesPaire instance at 0x1149e4170>,
#  (u'fi1S', u'ii1S'): <__main__.classesPaire instance at 0x10bae8cb0>,
#  (u'pi2P', u'ps3P'): <__main__.classesPaire instance at 0x114239e60>,
#  (u'ai2S', u'pc3P'): <__main__.classesPaire instance at 0x113ea3290>,
#  (u'is2S', u'ai3P'): <__main__.classesPaire instance at 0x10f4b79e0>,
#  (u'ppMP', u'ai3S'): <__main__.classesPaire instance at 0x10bae89e0>,
#  (u'ii2P', u'ppFP'): <__main__.classesPaire instance at 0x10f24acf8>,
#  (u'FP', u'ii2P'): <__main__.classesPaire instance at 0x109cd2b00>,
#  (u'pi2P', u'ai3S'): <__main__.classesPaire instance at 0x10bbec128>,
#  (u'ps1S', u'pc1S'): <__main__.classesPaire instance at 0x10bacf518>,
#  (u'ai2P', u'FP'): <__main__.classesPaire instance at 0x1140018c0>,
#  (u'ppMS', u'pI1P'): <__main__.classesPaire instance at 0x10f282f80>,
#  (u'pc1S', u'fi3P'): <__main__.classesPaire instance at 0x10a001ab8>,
#  (u'pc3P', u'inf'): <__main__.classesPaire instance at 0x103cb2638>,
#  (u'fi2S', u'ai1P'): <__main__.classesPaire instance at 0x10f2823f8>,
#  (u'ps2P', u'fi1S'): <__main__.classesPaire instance at 0x10b1cdc68>,
#  (u'pc2S', u'pI2P'): <__main__.classesPaire instance at 0x116fec488>,
#  (u'ii3P', u'FS'): <__main__.classesPaire instance at 0x109d130e0>,
#  (u'fi2S', u'pI1P'): <__main__.classesPaire instance at 0x10cbb4368>,
#  (u'ai3S', u'is2P'): <__main__.classesPaire instance at 0x1110079e0>,
#  (u'ii1P', u'pc1P'): <__main__.classesPaire instance at 0x114840878>,
#  (u'ii3S', u'pi2S'): <__main__.classesPaire instance at 0x10b8c3b90>,
#  (u'ai1P', u'pi1S'): <__main__.classesPaire instance at 0x113ee4368>,
#  (u'ii1S', u'ii1P'): <__main__.classesPaire instance at 0x10f31d440>,
#  (u'pc3P', u'is1P'): <__main__.classesPaire instance at 0x10e36fef0>,
#  (u'ppFS', u'pI1P'): <__main__.classesPaire instance at 0x10be993f8>,
#  (u'pi3S', u'is3P'): <__main__.classesPaire instance at 0x10b4eb290>,
#  (u'pI1P', u'fi3P'): <__main__.classesPaire instance at 0x11457ba70>,
#  (u'ppFS', u'ps1S'): <__main__.classesPaire instance at 0x10aa39908>,
#  (u'is1P', u'ps3S'): <__main__.classesPaire instance at 0x113fb9200>,
#  (u'pI2S', u'fi1S'): <__main__.classesPaire instance at 0x10be995a8>,
#  (u'ai2S', u'ii3P'): <__main__.classesPaire instance at 0x10da5e200>,
#  (u'is1S', u'fi2S'): <__main__.classesPaire instance at 0x10f2827a0>,
#  (u'pi3S', u'ii1S'): <__main__.classesPaire instance at 0x10be5ff80>,
#  (u'pP', u'pP'): <__main__.classesPaire instance at 0x1148f18c0>,
#  (u'ai3S', u'ai1P'): <__main__.classesPaire instance at 0x10b2c6200>,
#  (u'fi3P', u'ppMP'): <__main__.classesPaire instance at 0x11451b368>,
#  (u'ii2S', u'pc3S'): <__main__.classesPaire instance at 0x10ba807e8>,
#  (u'ps3S', u'pI2S'): <__main__.classesPaire instance at 0x114239a70>,
#  (u'ps2P', u'fi2S'): <__main__.classesPaire instance at 0x110307ea8>,
#  (u'FS', u'ii3S'): <__main__.classesPaire instance at 0x10cd9c998>,
#  (u'ii2P', u'ai2S'): <__main__.classesPaire instance at 0x1149d4cf8>,
#  (u'ai2P', u'is2P'): <__main__.classesPaire instance at 0x10b8677a0>,
#  (u'pc1S', u'ii1S'): <__main__.classesPaire instance at 0x10d617128>,
#  (u'pc3S', u'pc2P'): <__main__.classesPaire instance at 0x113fcfdd0>,
#  (u'ai2S', u'ps3P'): <__main__.classesPaire instance at 0x10aa39c68>,
#  (u'pi3P', u'is2S'): <__main__.classesPaire instance at 0x1142308c0>,
#  (u'ai1S', u'pi3P'): <__main__.classesPaire instance at 0x113ff6e18>,
#  (u'pI2S', u'ii1S'): <__main__.classesPaire instance at 0x110d12638>,
#  (u'ppFS', u'FP'): <__main__.classesPaire instance at 0x113763b90>,
#  (u'is2P', u'pI1P'): <__main__.classesPaire instance at 0x10bacf878>,
#  (u'fi2S', u'ppMP'): <__main__.classesPaire instance at 0x114239680>,
#  (u'fi2P', u'inf'): <__main__.classesPaire instance at 0x10a609170>,
#  (u'pP', u'fi1S'): <__main__.classesPaire instance at 0x102ba4f38>,
#  (u'fi2P', u'pi3P'): <__main__.classesPaire instance at 0x116fec830>,
#  (u'ii1S', u'fi1P'): <__main__.classesPaire instance at 0x10ad98878>,
#  (u'pc3S', u'pI2S'): <__main__.classesPaire instance at 0x10baaf998>,
#  (u'ai2S', u'ps2P'): <__main__.classesPaire instance at 0x10b1ea2d8>,
#  (u'fi3P', u'ps2S'): <__main__.classesPaire instance at 0x113f2d128>,
#  (u'pi2P', u'pi1S'): <__main__.classesPaire instance at 0x113ff6368>,
#  (u'ai3S', u'pi1S'): <__main__.classesPaire instance at 0x10b1cd950>,
#  (u'fi2S', u'ps3S'): <__main__.classesPaire instance at 0x114261878>,
#  (u'FP', u'fi1S'): <__main__.classesPaire instance at 0x114304440>,
#  (u'pc1S', u'ii2P'): <__main__.classesPaire instance at 0x113e64710>,
#  (u'ppMP', u'ps2S'): <__main__.classesPaire instance at 0x10be9d5a8>,
#  (u'pP', u'fi2S'): <__main__.classesPaire instance at 0x110368b48>,
#  (u'ps3P', u'pP'): <__main__.classesPaire instance at 0x10a93cd40>,
#  (u'fi3S', u'pP'): <__main__.classesPaire instance at 0x114830b00>,
#  (u'fi3P', u'ai3S'): <__main__.classesPaire instance at 0x1097f55f0>,
#  (u'ps1P', u'pc1S'): <__main__.classesPaire instance at 0x114001128>,
#  (u'FP', u'ppMS'): <__main__.classesPaire instance at 0x110d14638>,
#  (u'ai3S', u'fi1P'): <__main__.classesPaire instance at 0x10f2b7098>,
#  (u'ppFS', u'pc2S'): <__main__.classesPaire instance at 0x1176ad8c0>,
#  (u'ii1S', u'ppMP'): <__main__.classesPaire instance at 0x10ad98518>,
#  (u'pi1P', u'pI1P'): <__main__.classesPaire instance at 0x10af8eea8>,
#  (u'ppFP', u'pc3P'): <__main__.classesPaire instance at 0x1103b4b90>,
#  (u'pc2P', u'pc3S'): <__main__.classesPaire instance at 0x113fcf638>,
#  (u'ps2P', u'pc1S'): <__main__.classesPaire instance at 0x116fecef0>,
#  (u'fi2S', u'pi2P'): <__main__.classesPaire instance at 0x10aa3c170>,
#  (u'fi1P', u'ai3P'): <__main__.classesPaire instance at 0x10b5cbe18>,
#  (u'pi2P', u'ai1P'): <__main__.classesPaire instance at 0x113ff6a28>,
#  (u'pc2S', u'pi3P'): <__main__.classesPaire instance at 0x1097e2cf8>,
#  (u'fi2P', u'fi3S'): <__main__.classesPaire instance at 0x10bbec488>,
#  (u'ii2S', u'ii2P'): <__main__.classesPaire instance at 0x1142911b8>,
#  (u'inf', u'FP'): <__main__.classesPaire instance at 0x10c3e7170>,
#  (u'pc2S', u'ps3P'): <__main__.classesPaire instance at 0x10ca94908>,
#  (u'fi2S', u'ii1P'): <__main__.classesPaire instance at 0x1098bc830>,
#  (u'fi3S', u'fi1P'): <__main__.classesPaire instance at 0x10b725758>,
#  (u'FS', u'ai3P'): <__main__.classesPaire instance at 0x10de1e320>,
#  (u'pI2S', u'pi2P'): <__main__.classesPaire instance at 0x113763c68>,
#  (u'ii2S', u'pP'): <__main__.classesPaire instance at 0x109ccbb90>,
#  (u'is2P', u'is3S'): <__main__.classesPaire instance at 0x114078488>,
#  (u'pc1S', u'ppMS'): <__main__.classesPaire instance at 0x110c44518>,
#  (u'fi3S', u'is2S'): <__main__.classesPaire instance at 0x10be99fc8>,
#  (u'pI2S', u'ppMS'): <__main__.classesPaire instance at 0x10a676830>,
#  (u'ppFP', u'pc2P'): <__main__.classesPaire instance at 0x10bace290>,
#  (u'pc3P', u'FS'): <__main__.classesPaire instance at 0x10b771518>,
#  (u'pc1S', u'ps3P'): <__main__.classesPaire instance at 0x10b8a52d8>,
#  (u'pc3P', u'ps2P'): <__main__.classesPaire instance at 0x1147748c0>,
#  (u'ai3S', u'ai3S'): <__main__.classesPaire instance at 0x10b771c20>,
#  (u'ps1P', u'fi3S'): <__main__.classesPaire instance at 0x10d0e8e18>,
#  (u'ps1S', u'ppMP'): <__main__.classesPaire instance at 0x110c1ec20>,
#  (u'is3P', u'ps1P'): <__main__.classesPaire instance at 0x10e391dd0>,
#  (u'pi3S', u'pi1P'): <__main__.classesPaire instance at 0x1142a6cb0>,
#  (u'FS', u'ps1P'): <__main__.classesPaire instance at 0x11422f4d0>,
#  (u'pI2P', u'pP'): <__main__.classesPaire instance at 0x1103b4dd0>,
#  (u'fi2S', u'ai2S'): <__main__.classesPaire instance at 0x1103077e8>,
#  (u'pi3S', u'FS'): <__main__.classesPaire instance at 0x114001dd0>,
#  (u'ps3S', u'ii2S'): <__main__.classesPaire instance at 0x10b2c65a8>,
#  (u'inf', u'ps1S'): <__main__.classesPaire instance at 0x10c3e7cb0>,
#  (u'pc2S', u'ai1P'): <__main__.classesPaire instance at 0x10bc69518>,
#  (u'ps2S', u'fi3P'): <__main__.classesPaire instance at 0x110c44878>,
#  (u'fi3S', u'ppFP'): <__main__.classesPaire instance at 0x113fc54d0>,
#  (u'ppMP', u'ai2P'): <__main__.classesPaire instance at 0x10d13fb00>,
#  (u'pI2P', u'ai3P'): <__main__.classesPaire instance at 0x109cd2e60>,
#  (u'pi1S', u'ii3S'): <__main__.classesPaire instance at 0x110c44d88>,
#  (u'FP', u'ii3S'): <__main__.classesPaire instance at 0x113fd4ef0>,
#  (u'ps3P', u'FS'): <__main__.classesPaire instance at 0x10f4b7a28>,
#  (u'ai3P', u'ii2S'): <__main__.classesPaire instance at 0x10c25d7a0>,
#  (u'fi2P', u'FP'): <__main__.classesPaire instance at 0x10baaf3f8>,
#  (u'pi3S', u'fi3S'): <__main__.classesPaire instance at 0x11420aa28>,
#  (u'pI2P', u'pc1P'): <__main__.classesPaire instance at 0x116fec5f0>,
#  (u'is3S', u'ppFP'): <__main__.classesPaire instance at 0x114078248>,
#  (u'ii1S', u'inf'): <__main__.classesPaire instance at 0x10f282d40>,
#  (u'ii1P', u'pc3S'): <__main__.classesPaire instance at 0x10c842d40>,
#  (u'is2P', u'pI2P'): <__main__.classesPaire instance at 0x11489a9e0>,
#  (u'is2S', u'inf'): <__main__.classesPaire instance at 0x114261ef0>,
#  (u'fi2P', u'pI2S'): <__main__.classesPaire instance at 0x109cd2a28>,
#  (u'ai2P', u'ai3S'): <__main__.classesPaire instance at 0x10c41b560>,
#  (u'pI1P', u'ii3P'): <__main__.classesPaire instance at 0x113fb2d40>,
#  (u'is1S', u'FP'): <__main__.classesPaire instance at 0x10a9a0680>,
#  (u'ai1P', u'ppFP'): <__main__.classesPaire instance at 0x10c4e6d40>,
#  (u'is1S', u'ps2S'): <__main__.classesPaire instance at 0x10ad98f38>,
#  (u'ai2P', u'ps1P'): <__main__.classesPaire instance at 0x1098a4e18>,
#  (u'is1S', u'ppFS'): <__main__.classesPaire instance at 0x10b594a28>,
#  (u'ppMP', u'ii1S'): <__main__.classesPaire instance at 0x10ad983b0>,
#  (u'FP', u'ai2P'): <__main__.classesPaire instance at 0x10b1ea7e8>,
#  (u'ii1P', u'ps2S'): <__main__.classesPaire instance at 0x110cf6b48>,
#  (u'ai3S', u'pc1S'): <__main__.classesPaire instance at 0x10b1ea9e0>,
#  (u'pc2S', u'pi1S'): <__main__.classesPaire instance at 0x10b725e18>,
#  (u'ii1S', u'ai2S'): <__main__.classesPaire instance at 0x10d801fc8>,
#  (u'ppFS', u'ppFS'): <__main__.classesPaire instance at 0x110307488>,
#  (u'fi1P', u'FS'): <__main__.classesPaire instance at 0x114304b48>,
#  (u'ii2S', u'pc1S'): <__main__.classesPaire instance at 0x114291f80>,
#  (u'pi2P', u'fi3S'): <__main__.classesPaire instance at 0x113b6b488>,
#  (u'ii3S', u'ai1P'): <__main__.classesPaire instance at 0x10c4e65f0>,
#  (u'pc2S', u'ii2S'): <__main__.classesPaire instance at 0x10d5b87e8>,
#  (u'pi1P', u'fi2S'): <__main__.classesPaire instance at 0x10ca94c68>,
#  (u'is1P', u'is2S'): <__main__.classesPaire instance at 0x113fc50e0>,
#  (u'fi2P', u'ai1P'): <__main__.classesPaire instance at 0x114078dd0>,
#  (u'ppFP', u'ai1S'): <__main__.classesPaire instance at 0x10b2c6ea8>,
#  (u'inf', u'fi3P'): <__main__.classesPaire instance at 0x110349d88>,
#  (u'FS', u'pc1P'): <__main__.classesPaire instance at 0x114774830>,
#  (u'pI2S', u'is2P'): <__main__.classesPaire instance at 0x11489a7a0>,
#  (u'is3S', u'ps2S'): <__main__.classesPaire instance at 0x113fd4680>,
#  (u'ai3S', u'pi2S'): <__main__.classesPaire instance at 0x10f4b7ef0>,
#  (u'pi3S', u'is1S'): <__main__.classesPaire instance at 0x10b8c3e60>,
#  (u'ii2P', u'pc2S'): <__main__.classesPaire instance at 0x10d5b8fc8>,
#  (u'pI1P', u'ppFP'): <__main__.classesPaire instance at 0x10aa39ef0>,
#  (u'ps1P', u'ii2P'): <__main__.classesPaire instance at 0x116fecc20>,
#  (u'fi1P', u'pc1P'): <__main__.classesPaire instance at 0x10de1edd0>,
#  (u'pI2S', u'ai2P'): <__main__.classesPaire instance at 0x113f81710>,
#  (u'ii2P', u'is1P'): <__main__.classesPaire instance at 0x113e7cc68>,
#  (u'ps3S', u'inf'): <__main__.classesPaire instance at 0x10b2c6f38>,
#  (u'is2P', u'fi1P'): <__main__.classesPaire instance at 0x113e7c248>,
#  (u'fi2P', u'pi1S'): <__main__.classesPaire instance at 0x10baacf38>,
#  (u'ps1P', u'is1S'): <__main__.classesPaire instance at 0x10b8e9bd8>,
#  (u'is2S', u'ps3S'): <__main__.classesPaire instance at 0x10f1638c0>,
#  (u'ppFS', u'fi2S'): <__main__.classesPaire instance at 0x102ba4098>,
#  (u'ppFP', u'is2S'): <__main__.classesPaire instance at 0x10f2821b8>,
#  (u'fi3P', u'pc1S'): <__main__.classesPaire instance at 0x10d418e18>,
#  (u'ps1S', u'ai2S'): <__main__.classesPaire instance at 0x10a5a4a70>,
#  (u'pi2S', u'pc2S'): <__main__.classesPaire instance at 0x10b2c69e0>,
#  (u'ps1S', u'pi1P'): <__main__.classesPaire instance at 0x110349518>,
#  (u'fi3P', u'ai2P'): <__main__.classesPaire instance at 0x10b7255a8>,
#  (u'is3S', u'pI2S'): <__main__.classesPaire instance at 0x10a63a3b0>,
#  (u'ai2P', u'ai2S'): <__main__.classesPaire instance at 0x114001c68>,
#  (u'fi1P', u'FP'): <__main__.classesPaire instance at 0x114304b90>,
#  (u'pi2P', u'pI2P'): <__main__.classesPaire instance at 0x110c0f098>,
#  (u'inf', u'pc1S'): <__main__.classesPaire instance at 0x10c3ff878>,
#  (u'pc3S', u'inf'): <__main__.classesPaire instance at 0x10a176560>,
#  (u'ppMP', u'ppMS'): <__main__.classesPaire instance at 0x10bae8878>,
#  (u'ii3P', u'pi2S'): <__main__.classesPaire instance at 0x10b2c65f0>,
#  (u'ai3P', u'pI1P'): <__main__.classesPaire instance at 0x10de1eab8>,
#  (u'is2P', u'ppMP'): <__main__.classesPaire instance at 0x113ee4908>,
#  (u'fi1S', u'pc3S'): <__main__.classesPaire instance at 0x114c16e60>,
#  (u'pc2P', u'ps1S'): <__main__.classesPaire instance at 0x11489a368>,
#  (u'fi1P', u'ai2S'): <__main__.classesPaire instance at 0x113fcf878>,
#  (u'pc1P', u'ai3S'): <__main__.classesPaire instance at 0x10d5b8cb0>,
#  (u'ps3S', u'ii1S'): <__main__.classesPaire instance at 0x10bae8830>,
#  (u'is2P', u'ps3S'): <__main__.classesPaire instance at 0x109815290>,
#  (u'ppFP', u'fi2S'): <__main__.classesPaire instance at 0x10c402710>,
#  (u'ppMS', u'is3P'): <__main__.classesPaire instance at 0x110c445f0>,
#  (u'ii3S', u'is1S'): <__main__.classesPaire instance at 0x109b30710>,
#  (u'inf', u'ppMS'): <__main__.classesPaire instance at 0x10e095098>,
#  (u'ppMS', u'ai2S'): <__main__.classesPaire instance at 0x10b530908>,
#  (u'pc2S', u'is2P'): <__main__.classesPaire instance at 0x1097e2cb0>,
#  (u'is2P', u'pi3S'): <__main__.classesPaire instance at 0x111007d40>,
#  (u'ii3S', u'ps3S'): <__main__.classesPaire instance at 0x10e391a28>,
#  (u'ai2P', u'ii2P'): <__main__.classesPaire instance at 0x10a8d55f0>,
#  (u'pi2P', u'pc3S'): <__main__.classesPaire instance at 0x113ff6878>,
#  (u'is3P', u'pc2S'): <__main__.classesPaire instance at 0x10c41b908>,
#  (u'fi3P', u'ppFS'): <__main__.classesPaire instance at 0x10b867830>,
#  (u'ii2S', u'pi1S'): <__main__.classesPaire instance at 0x113e7c3f8>,
#  (u'is2S', u'pc3S'): <__main__.classesPaire instance at 0x10aa39200>,
#  (u'ii2S', u'ai2P'): <__main__.classesPaire instance at 0x114001290>,
#  (u'fi1S', u'ps1P'): <__main__.classesPaire instance at 0x1098a46c8>,
#  (u'pc3P', u'pc2P'): <__main__.classesPaire instance at 0x10b24f518>,
#  (u'fi3P', u'pi2S'): <__main__.classesPaire instance at 0x110307710>,
#  (u'ps1P', u'ii3P'): <__main__.classesPaire instance at 0x10bc69f38>,
#  (u'ps1S', u'ai1P'): <__main__.classesPaire instance at 0x10f24a710>,
#  (u'is2S', u'ai1P'): <__main__.classesPaire instance at 0x113fd4908>,
#  (u'FP', u'ii1S'): <__main__.classesPaire instance at 0x10b8e95a8>,
#  (u'ii3P', u'ppMP'): <__main__.classesPaire instance at 0x110c44440>,
#  (u'pc1S', u'pi2S'): <__main__.classesPaire instance at 0x10bc69050>,
#  (u'ps2S', u'fi1P'): <__main__.classesPaire instance at 0x10baaf7e8>,
#  (u'ii1P', u'ai3P'): <__main__.classesPaire instance at 0x110c44368>,
#  (u'pI2P', u'ai1P'): <__main__.classesPaire instance at 0x10983b128>,
#  (u'fi2S', u'ai3P'): <__main__.classesPaire instance at 0x1098183b0>,
#  (u'ii2S', u'ii1S'): <__main__.classesPaire instance at 0x10bae86c8>,
#  (u'ai1P', u'FS'): <__main__.classesPaire instance at 0x10c530128>,
#  (u'ps3S', u'is2S'): <__main__.classesPaire instance at 0x10f163b00>,
#  (u'pI2P', u'pc3P'): <__main__.classesPaire instance at 0x113b6b248>,
#  (u'pc3S', u'ai1S'): <__main__.classesPaire instance at 0x10d5806c8>,
#  (u'ai2P', u'ps2P'): <__main__.classesPaire instance at 0x113e7a488>,
#  (u'pc1P', u'ii2S'): <__main__.classesPaire instance at 0x10a216290>,
#  (u'pc1P', u'ii3P'): <__main__.classesPaire instance at 0x10f4b7c20>,
#  (u'pi1P', u'ai2S'): <__main__.classesPaire instance at 0x114291710>,
#  (u'pi1S', u'ii2P'): <__main__.classesPaire instance at 0x10d0e8290>,
#  (u'ppFS', u'ii3S'): <__main__.classesPaire instance at 0x114078098>,
#  (u'fi3P', u'ps3P'): <__main__.classesPaire instance at 0x113fb2128>,
#  (u'ps3P', u'ps1S'): <__main__.classesPaire instance at 0x10f856830>,
#  (u'ppMP', u'pc1S'): <__main__.classesPaire instance at 0x102ba4b90>,
#  (u'ppFS', u'fi1P'): <__main__.classesPaire instance at 0x113763f38>,
#  (u'ps2S', u'ppFS'): <__main__.classesPaire instance at 0x10da5e680>,
#  (u'is1S', u'pc2S'): <__main__.classesPaire instance at 0x11451dc20>,
#  (u'ppFP', u'ppMP'): <__main__.classesPaire instance at 0x113ec9fc8>,
#  (u'ps3S', u'fi2S'): <__main__.classesPaire instance at 0x114261b48>,
#  (u'pP', u'is2S'): <__main__.classesPaire instance at 0x10f021bd8>,
#  (u'ii3S', u'inf'): <__main__.classesPaire instance at 0x10f022e60>,
#  (u'ppFS', u'pi1S'): <__main__.classesPaire instance at 0x1098bf1b8>,
#  (u'ii1P', u'FS'): <__main__.classesPaire instance at 0x10b49f2d8>,
#  (u'ps2P', u'is3P'): <__main__.classesPaire instance at 0x10a93c3f8>,
#  (u'FP', u'pc3S'): <__main__.classesPaire instance at 0x10f2b76c8>,
#  (u'ps2P', u'ps1P'): <__main__.classesPaire instance at 0x113e7a710>,
#  (u'pc2P', u'is1S'): <__main__.classesPaire instance at 0x10c74ea28>,
#  (u'ii1S', u'ai3P'): <__main__.classesPaire instance at 0x10bacedd0>,
#  (u'fi3S', u'pi2S'): <__main__.classesPaire instance at 0x10ca94cb0>,
#  (u'is1P', u'ai1P'): <__main__.classesPaire instance at 0x10a216440>,
#  (u'is1P', u'ppFS'): <__main__.classesPaire instance at 0x113fc5878>,
#  (u'pc3S', u'FS'): <__main__.classesPaire instance at 0x1149cab90>,
#  (u'is2P', u'ai2S'): <__main__.classesPaire instance at 0x10e693908>,
#  (u'ai2P', u'pI2S'): <__main__.classesPaire instance at 0x113f81cb0>,
#  (u'fi1P', u'ppMP'): <__main__.classesPaire instance at 0x114625ab8>,
#  (u'ps1S', u'ps3S'): <__main__.classesPaire instance at 0x114239b48>,
#  (u'fi3P', u'pI2P'): <__main__.classesPaire instance at 0x10be9d0e0>,
#  (u'pI1P', u'ai2P'): <__main__.classesPaire instance at 0x10b725710>,
#  (u'pi1S', u'pc2S'): <__main__.classesPaire instance at 0x10be9dbd8>,
#  (u'pi2P', u'pi3S'): <__main__.classesPaire instance at 0x113763830>,
#  (u'ii1P', u'pc2P'): <__main__.classesPaire instance at 0x11492dc68>,
#  (u'ii1P', u'ii3S'): <__main__.classesPaire instance at 0x10f6d6560>,
#  (u'ppFP', u'pI2S'): <__main__.classesPaire instance at 0x11489a908>,
#  (u'fi1S', u'fi2S'): <__main__.classesPaire instance at 0x10e3b71b8>,
#  (u'is1S', u'ii2P'): <__main__.classesPaire instance at 0x10f282758>,
#  (u'pi2P', u'is1S'): <__main__.classesPaire instance at 0x10b2641b8>,
#  (u'fi2S', u'pI2P'): <__main__.classesPaire instance at 0x109815ea8>,
#  (u'pc1P', u'ai2S'): <__main__.classesPaire instance at 0x113ea35f0>,
#  (u'pi1P', u'pc3P'): <__main__.classesPaire instance at 0x10c07cfc8>,
#  (u'fi2S', u'is1P'): <__main__.classesPaire instance at 0x1176adbd8>,
#  (u'ppMS', u'ppMP'): <__main__.classesPaire instance at 0x1098256c8>,
#  (u'ps3S', u'FS'): <__main__.classesPaire instance at 0x113fb9c20>,
#  (u'is2S', u'ppFP'): <__main__.classesPaire instance at 0x10be99488>,
#  (u'pc1S', u'pI1P'): <__main__.classesPaire instance at 0x10aa25128>,
#  (u'pi2P', u'ppFP'): <__main__.classesPaire instance at 0x10f4b7b00>,
#  (u'pP', u'ps1P'): <__main__.classesPaire instance at 0x109825cf8>,
#  (u'is1P', u'pi1S'): <__main__.classesPaire instance at 0x110397758>,
#  (u'ai2P', u'pc3S'): <__main__.classesPaire instance at 0x11422f368>,
#  (u'fi3P', u'ai1S'): <__main__.classesPaire instance at 0x10cbb4b00>,
#  (u'ii2S', u'ppMS'): <__main__.classesPaire instance at 0x10bace5a8>,
#  (u'pi3P', u'ii1S'): <__main__.classesPaire instance at 0x10e391c20>,
#  (u'is2P', u'is2S'): <__main__.classesPaire instance at 0x110c0f758>,
#  (u'ai1P', u'pP'): <__main__.classesPaire instance at 0x10f719680>,
#  (u'ai3P', u'is3P'): <__main__.classesPaire instance at 0x110c44248>,
#  (u'pI1P', u'ps3S'): <__main__.classesPaire instance at 0x113f444d0>,
#  (u'ai1S', u'fi3P'): <__main__.classesPaire instance at 0x10cbb44d0>,
#  (u'ps1P', u'ai2P'): <__main__.classesPaire instance at 0x10b1cd440>,
#  (u'ii3P', u'fi3P'): <__main__.classesPaire instance at 0x10be9d6c8>,
#  (u'pi2P', u'inf'): <__main__.classesPaire instance at 0x10e6b84d0>,
#  (u'pi2P', u'fi1P'): <__main__.classesPaire instance at 0x10a216c68>,
#  (u'ii2S', u'fi2S'): <__main__.classesPaire instance at 0x10bbecfc8>,
#  (u'FP', u'FS'): <__main__.classesPaire instance at 0x1097d1d40>,
#  (u'pP', u'ai3P'): <__main__.classesPaire instance at 0x11451ddd0>,
#  (u'fi3P', u'ii1S'): <__main__.classesPaire instance at 0x10f022d88>,
#  (u'is1P', u'ai2P'): <__main__.classesPaire instance at 0x1142a6c20>,
#  (u'ppMP', u'fi3S'): <__main__.classesPaire instance at 0x10b4ebea8>,
#  (u'ai3S', u'ii3P'): <__main__.classesPaire instance at 0x11377a9e0>,
#  (u'ps1S', u'ii2S'): <__main__.classesPaire instance at 0x110349050>,
#  (u'ps3P', u'ai1P'): <__main__.classesPaire instance at 0x10a63acf8>,
#  (u'pi3P', u'ii3S'): <__main__.classesPaire instance at 0x10be9d518>,
#  (u'ii3S', u'pc2P'): <__main__.classesPaire instance at 0x10b2c6b48>,
#  (u'ai2P', u'ppMS'): <__main__.classesPaire instance at 0x114840e18>,
#  (u'fi2S', u'fi1P'): <__main__.classesPaire instance at 0x10af40ab8>,
#  (u'fi1P', u'fi2P'): <__main__.classesPaire instance at 0x1098a47e8>,
#  (u'ii2S', u'ppFS'): <__main__.classesPaire instance at 0x113e644d0>,
#  (u'pP', u'ppMP'): <__main__.classesPaire instance at 0x10b5da758>,
#  (u'ai2S', u'fi2S'): <__main__.classesPaire instance at 0x113e9f9e0>,
#  (u'is2P', u'pi2P'): <__main__.classesPaire instance at 0x1140f4638>,
#  (u'fi1S', u'is2P'): <__main__.classesPaire instance at 0x113e7c0e0>,
#  (u'pc2S', u'pc1S'): <__main__.classesPaire instance at 0x1103973f8>,
#  (u'pc3S', u'pc3S'): <__main__.classesPaire instance at 0x11457bf80>,
#  (u'pi1P', u'is2S'): <__main__.classesPaire instance at 0x110c0fb90>,
#  (u'fi3P', u'inf'): <__main__.classesPaire instance at 0x10f1636c8>,
#  (u'ppMS', u'ii1P'): <__main__.classesPaire instance at 0x10d86b638>,
#  (u'ai2S', u'ai3S'): <__main__.classesPaire instance at 0x114544248>,
#  (u'pI2S', u'pc1S'): <__main__.classesPaire instance at 0x10be99dd0>,
#  (u'fi3P', u'pi3P'): <__main__.classesPaire instance at 0x1149cacb0>,
#  (u'pi3S', u'ps3S'): <__main__.classesPaire instance at 0x110349200>,
#  (u'pI1P', u'ppMS'): <__main__.classesPaire instance at 0x110c6aa70>,
#  (u'fi2P', u'ai3S'): <__main__.classesPaire instance at 0x10b4ebcb0>,
#  (u'pc1P', u'pP'): <__main__.classesPaire instance at 0x1103b43b0>,
#  (u'pi3P', u'ppMS'): <__main__.classesPaire instance at 0x110c6a9e0>,
#  (u'fi2P', u'fi2S'): <__main__.classesPaire instance at 0x10b867f38>,
#  (u'pI1P', u'FS'): <__main__.classesPaire instance at 0x10c24d290>,
#  (u'fi2S', u'fi2P'): <__main__.classesPaire instance at 0x10af5d3b0>,
#  (u'is3S', u'ai3P'): <__main__.classesPaire instance at 0x10b3fa050>,
#  (u'is2S', u'fi2P'): <__main__.classesPaire instance at 0x10da4b680>,
#  (u'pI1P', u'ps2P'): <__main__.classesPaire instance at 0x10b1cde60>,
#  (u'ii1P', u'ai2S'): <__main__.classesPaire instance at 0x113f3f758>,
#  (u'ppMP', u'FP'): <__main__.classesPaire instance at 0x10bae8680>,
#  (u'ai1S', u'ppMS'): <__main__.classesPaire instance at 0x10f618ea8>,
#  (u'pc1S', u'ppFS'): <__main__.classesPaire instance at 0x10be99050>,
#  (u'ps3S', u'pc3S'): <__main__.classesPaire instance at 0x10da5e7a0>,
#  (u'fi2P', u'ppFP'): <__main__.classesPaire instance at 0x10cbb4830>,
#  (u'is3S', u'pP'): <__main__.classesPaire instance at 0x10b532b90>,
#  (u'ps2P', u'ppMS'): <__main__.classesPaire instance at 0x10b737a28>,
#  (u'fi2P', u'is2P'): <__main__.classesPaire instance at 0x11489a098>,
#  (u'ii2P', u'ai1P'): <__main__.classesPaire instance at 0x10c4ce758>,
#  (u'pi3S', u'pc2S'): <__main__.classesPaire instance at 0x1097e28c0>,
#  (u'is1S', u'pc3P'): <__main__.classesPaire instance at 0x10bace368>,
#  (u'pi1P', u'ppFP'): <__main__.classesPaire instance at 0x113b6b4d0>,
#  (u'ii1P', u'ii1P'): <__main__.classesPaire instance at 0x10f765c20>,
#  (u'ai1P', u'pI2S'): <__main__.classesPaire instance at 0x114078ef0>,
#  (u'ii2P', u'fi1P'): <__main__.classesPaire instance at 0x11489e7a0>,
#  (u'FS', u'pP'): <__main__.classesPaire instance at 0x10c3ff320>,
#  (u'ai3P', u'ps1P'): <__main__.classesPaire instance at 0x1140019e0>,
#  (u'FP', u'pc1S'): <__main__.classesPaire instance at 0x1143047a0>,
#  (u'inf', u'ps3P'): <__main__.classesPaire instance at 0x10a216a28>,
#  (u'pI2S', u'ps1S'): <__main__.classesPaire instance at 0x10d5801b8>,
#  (u'pc2S', u'fi2S'): <__main__.classesPaire instance at 0x10a5a4200>,
#  (u'is2P', u'ps1S'): <__main__.classesPaire instance at 0x10d580638>,
#  (u'is3P', u'ai1P'): <__main__.classesPaire instance at 0x10b594368>,
#  (u'pi3P', u'pI2P'): <__main__.classesPaire instance at 0x1149e41b8>,
#  (u'pi3P', u'ps3S'): <__main__.classesPaire instance at 0x113f447e8>,
#  (u'is2P', u'ai3P'): <__main__.classesPaire instance at 0x1110071b8>,
#  (u'FP', u'fi3P'): <__main__.classesPaire instance at 0x11422f128>,
#  (u'pi2S', u'fi1P'): <__main__.classesPaire instance at 0x113e643b0>,
#  (u'ps1P', u'ii1P'): <__main__.classesPaire instance at 0x114840c68>,
#  (u'pi2P', u'pi2P'): <__main__.classesPaire instance at 0x11451d3b0>,
#  (u'ii1P', u'ii2P'): <__main__.classesPaire instance at 0x110d12e60>,
#  (u'ppFP', u'is2P'): <__main__.classesPaire instance at 0x10b2c6cf8>,
#  (u'pc2P', u'ai1S'): <__main__.classesPaire instance at 0x10e693440>,
#  (u'is2S', u'pc2P'): <__main__.classesPaire instance at 0x10e391f80>,
#  (u'fi1P', u'pI2P'): <__main__.classesPaire instance at 0x11489a8c0>,
#  (u'fi2S', u'pi3P'): <__main__.classesPaire instance at 0x10d580e18>,
#  (u'is3P', u'pi1S'): <__main__.classesPaire instance at 0x10c4e6b90>,
#  (u'ps2P', u'pI2P'): <__main__.classesPaire instance at 0x113e7a098>,
#  (u'pc2S', u'fi1S'): <__main__.classesPaire instance at 0x113f811b8>,
#  (u'fi2S', u'pc2P'): <__main__.classesPaire instance at 0x113e7c170>,
#  (u'pc1P', u'ai1P'): <__main__.classesPaire instance at 0x10a216f38>,
#  (u'fi2S', u'is3S'): <__main__.classesPaire instance at 0x10f3e1170>,
#  (u'ps2S', u'pi1S'): <__main__.classesPaire instance at 0x113ea3e18>,
#  (u'fi2S', u'ps1S'): <__main__.classesPaire instance at 0x10cbb4b48>,
#  (u'ps2P', u'ii1S'): <__main__.classesPaire instance at 0x109b309e0>,
#  (u'pc2P', u'ii3S'): <__main__.classesPaire instance at 0x11451be18>,
#  (u'is3S', u'FS'): <__main__.classesPaire instance at 0x10a0c05a8>,
#  (u'ppMP', u'pc3S'): <__main__.classesPaire instance at 0x11106e950>,
#  (u'ai1S', u'fi1P'): <__main__.classesPaire instance at 0x1110078c0>,
#  (u'ppMS', u'pI2P'): <__main__.classesPaire instance at 0x10cb88878>,
#  (u'ii3S', u'ps1P'): <__main__.classesPaire instance at 0x10f3e1cb0>,
#  (u'is1S', u'inf'): <__main__.classesPaire instance at 0x10a13f908>,
#  (u'ps1S', u'pi1S'): <__main__.classesPaire instance at 0x10bab5ea8>,
#  (u'ps1P', u'pc3S'): <__main__.classesPaire instance at 0x114291128>,
#  (u'pi3P', u'is3S'): <__main__.classesPaire instance at 0x113ec9ef0>,
#  (u'pc3S', u'pi3P'): <__main__.classesPaire instance at 0x1142a6638>,
#  (u'ii1P', u'ppMP'): <__main__.classesPaire instance at 0x1097c9cf8>,
#  (u'ai2P', u'is3P'): <__main__.classesPaire instance at 0x113ee4ab8>,
#  (u'pc1P', u'is2P'): <__main__.classesPaire instance at 0x111007c20>,
#  (u'ai1P', u'pI1P'): <__main__.classesPaire instance at 0x10a216908>,
#  (u'is1S', u'is1P'): <__main__.classesPaire instance at 0x10c8dac68>,
#  (u'ps2P', u'ai2P'): <__main__.classesPaire instance at 0x113e7a440>,
#  (u'pi2S', u'pc3P'): <__main__.classesPaire instance at 0x10f1635a8>,
#  (u'pi2S', u'ps1P'): <__main__.classesPaire instance at 0x10a0c0e60>,
#  (u'ps1P', u'ppMS'): <__main__.classesPaire instance at 0x110c1e2d8>,
#  (u'ps1S', u'pc2S'): <__main__.classesPaire instance at 0x113fb2560>,
#  (u'pI1P', u'fi2S'): <__main__.classesPaire instance at 0x10bacf050>,
#  (u'pI2P', u'fi1P'): <__main__.classesPaire instance at 0x113e7c998>,
#  (u'ai3P', u'is2S'): <__main__.classesPaire instance at 0x1176ad320>,
#  (u'ai3P', u'ppMP'): <__main__.classesPaire instance at 0x113ec90e0>,
#  (u'pi2P', u'ai3P'): <__main__.classesPaire instance at 0x113b6b290>,
#  (u'is3S', u'ai1S'): <__main__.classesPaire instance at 0x10e3914d0>,
#  (u'ii2S', u'ps2S'): <__main__.classesPaire instance at 0x10be99a28>,
#  (u'ai2P', u'ai2P'): <__main__.classesPaire instance at 0x10cdfe170>,
#  (u'pc2P', u'ps2S'): <__main__.classesPaire instance at 0x113fcf1b8>,
#  (u'pI2S', u'pI1P'): <__main__.classesPaire instance at 0x102ba0638>,
#  (u'pI2S', u'is1S'): <__main__.classesPaire instance at 0x10f2825a8>,
#  (u'pc3S', u'ppFP'): <__main__.classesPaire instance at 0x113b6b2d8>,
#  (u'ai1P', u'pi3P'): <__main__.classesPaire instance at 0x10b2c6d40>,
#  (u'pP', u'ppFP'): <__main__.classesPaire instance at 0x10b594b00>,
#  (u'ppMS', u'ps2P'): <__main__.classesPaire instance at 0x10acd33b0>,
#  (u'ii1P', u'pI1P'): <__main__.classesPaire instance at 0x10b5327e8>,
#  (u'pI2S', u'pI2P'): <__main__.classesPaire instance at 0x10baaf710>,
#  (u'pc3P', u'is1S'): <__main__.classesPaire instance at 0x10bace3b0>,
#  (u'ai1P', u'pc1P'): <__main__.classesPaire instance at 0x10a2165a8>,
#  (u'ps1P', u'pc2P'): <__main__.classesPaire instance at 0x113763248>,
#  (u'pP', u'pi1S'): <__main__.classesPaire instance at 0x10ad98098>,
#  (u'ai1P', u'is3S'): <__main__.classesPaire instance at 0x109d13dd0>,
#  (u'fi2P', u'ai2P'): <__main__.classesPaire instance at 0x10baafef0>,
#  (u'pP', u'ai1S'): <__main__.classesPaire instance at 0x114573638>,
#  (u'ai1S', u'ai1S'): <__main__.classesPaire instance at 0x10bacf1b8>,
#  (u'is1P', u'fi1P'): <__main__.classesPaire instance at 0x116fec518>,
#  (u'FS', u'fi1P'): <__main__.classesPaire instance at 0x10c3e7320>,
#  (u'pI1P', u'ps1S'): <__main__.classesPaire instance at 0x11489a0e0>,
#  (u'ai3S', u'ai1S'): <__main__.classesPaire instance at 0x1098af320>,
#  (u'ii2P', u'pc1P'): <__main__.classesPaire instance at 0x1142a6f38>,
#  (u'is2S', u'ai2S'): <__main__.classesPaire instance at 0x10c4ce908>,
#  (u'pI1P', u'ai3P'): <__main__.classesPaire instance at 0x10de1ee18>,
#  (u'ps2P', u'fi2P'): <__main__.classesPaire instance at 0x10c402ea8>,
#  (u'pc2S', u'pc2S'): <__main__.classesPaire instance at 0x10d5b8488>,
#  (u'pi3P', u'is2P'): <__main__.classesPaire instance at 0x11489a878>,
#  (u'pi2S', u'pi2S'): <__main__.classesPaire instance at 0x113fb96c8>,
#  (u'FP', u'is1S'): <__main__.classesPaire instance at 0x10c3ff290>,
#  (u'is2S', u'pc1P'): <__main__.classesPaire instance at 0x1142301b8>,
#  (u'FS', u'pI1P'): <__main__.classesPaire instance at 0x10c24db00>,
#  (u'FS', u'ai1P'): <__main__.classesPaire instance at 0x10a283b00>,
#  (u'ii1S', u'is2S'): <__main__.classesPaire instance at 0x113ff64d0>,
#  (u'ai1S', u'pi1P'): <__main__.classesPaire instance at 0x113e7a200>,
#  (u'ai3P', u'inf'): <__main__.classesPaire instance at 0x110c44998>,
#  (u'ai3S', u'pi1P'): <__main__.classesPaire instance at 0x10ad55e18>,
#  (u'ai2S', u'pi3S'): <__main__.classesPaire instance at 0x10aa3ce60>,
#  (u'is1S', u'ps1P'): <__main__.classesPaire instance at 0x10b8e9c20>,
#  (u'is1P', u'fi3S'): <__main__.classesPaire instance at 0x113f53e60>,
#  (u'ps2S', u'ai3P'): <__main__.classesPaire instance at 0x10b1cd320>,
#  (u'pc1S', u'ii2S'): <__main__.classesPaire instance at 0x114291248>,
#  (u'fi2S', u'FS'): <__main__.classesPaire instance at 0x10c0b9c20>,
#  (u'pc1S', u'fi2S'): <__main__.classesPaire instance at 0x10b8a5878>,
#  (u'ppFS', u'pc2P'): <__main__.classesPaire instance at 0x10bbec248>,
#  (u'fi3P', u'is2S'): <__main__.classesPaire instance at 0x11459d170>,
#  (u'pi3P', u'FP'): <__main__.classesPaire instance at 0x10ba80fc8>,
#  (u'ps2P', u'pc2S'): <__main__.classesPaire instance at 0x1149d4098>,
#  (u'ii3P', u'is2S'): <__main__.classesPaire instance at 0x10c41bab8>,
#  (u'fi2P', u'ii3P'): <__main__.classesPaire instance at 0x10f618638>,
#  (u'ii1S', u'ppMS'): <__main__.classesPaire instance at 0x10c58f248>,
#  (u'ai1S', u'ps3P'): <__main__.classesPaire instance at 0x10ca94a28>,
#  (u'pc3P', u'ai1P'): <__main__.classesPaire instance at 0x103cb2560>,
#  (u'fi2S', u'pi2S'): <__main__.classesPaire instance at 0x10c3e73b0>,
#  (u'fi3S', u'inf'): <__main__.classesPaire instance at 0x110307b48>,
#  (u'ii2S', u'pI2S'): <__main__.classesPaire instance at 0x113fb9b00>,
#  (u'ps3S', u'pi2S'): <__main__.classesPaire instance at 0x102ba0ef0>,
#  (u'ii1P', u'ps1S'): <__main__.classesPaire instance at 0x1103b4878>,
#  (u'ii2S', u'ps3P'): <__main__.classesPaire instance at 0x10c3e7e60>,
#  (u'ii1P', u'is3S'): <__main__.classesPaire instance at 0x10b84b680>,
#  (u'ii2S', u'ii2S'): <__main__.classesPaire instance at 0x10af8e998>,
#  (u'fi2P', u'fi1P'): <__main__.classesPaire instance at 0x110d14170>,
#  (u'ps3P', u'pc3S'): <__main__.classesPaire instance at 0x10ca87d40>,
#  (u'pc1S', u'ai1S'): <__main__.classesPaire instance at 0x1097e27a0>,
#  (u'pc1S', u'ppMP'): <__main__.classesPaire instance at 0x102ba4ef0>,
#  (u'ai3P', u'pc2P'): <__main__.classesPaire instance at 0x1103978c0>,
#  (u'pP', u'ii2S'): <__main__.classesPaire instance at 0x109ccbdd0>,
#  (u'fi2P', u'ppMS'): <__main__.classesPaire instance at 0x10bace4d0>,
#  (u'pI2P', u'ps1P'): <__main__.classesPaire instance at 0x1176ad368>,
#  (u'ai1P', u'ppMS'): <__main__.classesPaire instance at 0x110c6aab8>,
#  (u'pc3S', u'ii2S'): <__main__.classesPaire instance at 0x10ba80560>,
#  (u'pi1S', u'pi3S'): <__main__.classesPaire instance at 0x11489e440>,
#  (u'ai3P', u'ai1S'): <__main__.classesPaire instance at 0x113e9f758>,
#  (u'is1S', u'pc1P'): <__main__.classesPaire instance at 0x10bace950>,
#  (u'ppMS', u'pP'): <__main__.classesPaire instance at 0x113f3ff38>,
#  (u'pc3S', u'pi2S'): <__main__.classesPaire instance at 0x113fc5098>,
#  (u'ai3P', u'ps3P'): <__main__.classesPaire instance at 0x10f3e1248>,
#  (u'fi3P', u'pi3S'): <__main__.classesPaire instance at 0x114c16a28>,
#  (u'fi1S', u'pI1P'): <__main__.classesPaire instance at 0x114001a70>,
#  (u'pi3P', u'inf'): <__main__.classesPaire instance at 0x110349830>,
#  (u'fi1S', u'is1S'): <__main__.classesPaire instance at 0x1103b4128>,
#  (u'ii3P', u'pi3S'): <__main__.classesPaire instance at 0x10c41b8c0>,
#  (u'is2S', u'ppMP'): <__main__.classesPaire instance at 0x113ee4b90>,
#  (u'FS', u'ps2P'): <__main__.classesPaire instance at 0x11420a200>,
# ...
#  (u'ppFS', u'is2P'): <__main__.classesPaire instance at 0x110307050>,
#  (u'pi2P', u'ai2P'): <__main__.classesPaire instance at 0x1176adc68>,
#  (u'is3S', u'ps2P'): <__main__.classesPaire instance at 0x114078680>,
#  (u'fi3S', u'ps1S'): <__main__.classesPaire instance at 0x10cbb4128>,
#  (u'ps3S', u'ps3P'): <__main__.classesPaire instance at 0x10a216680>,
#  (u'ppMS', u'is3S'): <__main__.classesPaire instance at 0x113f2de60>,
#  (u'pi2S', u'ii3P'): <__main__.classesPaire instance at 0x113f445a8>,
#  (u'pi1S', u'ii1S'): <__main__.classesPaire instance at 0x10bae8200>,
#  (u'pP', u'ii3P'): <__main__.classesPaire instance at 0x1146253f8>,
#  (u'is2P', u'pi3P'): <__main__.classesPaire instance at 0x1140f4098>,
#  (u'ii1P', u'pI2P'): <__main__.classesPaire instance at 0x10a559d88>,
#  (u'fi2P', u'ps2S'): <__main__.classesPaire instance at 0x10ca04b90>,
#  (u'pc3S', u'ii3P'): <__main__.classesPaire instance at 0x10f4b7908>,
#  (u'is3P', u'pc2P'): <__main__.classesPaire instance at 0x10f022878>,
#  (u'ii2S', u'is3P'): <__main__.classesPaire instance at 0x113ee4b48>,
#  (u'ii2S', u'ai2S'): <__main__.classesPaire instance at 0x10ad55ef0>,
#  (u'FS', u'pc2P'): <__main__.classesPaire instance at 0x11422f9e0>,
#  (u'is2P', u'is1P'): <__main__.classesPaire instance at 0x113e7c2d8>,
#  (u'inf', u'ppFS'): <__main__.classesPaire instance at 0x10f282c20>,
#  (u'ppMP', u'is1S'): <__main__.classesPaire instance at 0x1098f22d8>,
#  (u'ii1S', u'ps2P'): <__main__.classesPaire instance at 0x109b30368>,
#  (u'fi3P', u'fi1S'): <__main__.classesPaire instance at 0x10de1e3b0>,
#  (u'pI2S', u'fi3S'): <__main__.classesPaire instance at 0x10baaffc8>,
#  (u'ai3S', u'ps1S'): <__main__.classesPaire instance at 0x113e7a878>,
#  (u'pc1S', u'pi2P'): <__main__.classesPaire instance at 0x11459db48>,
#  (u'ps2S', u'ai3S'): <__main__.classesPaire instance at 0x110397a70>,
#  (u'pi3P', u'pc2P'): <__main__.classesPaire instance at 0x114887128>,
#  (u'fi2S', u'ai3S'): <__main__.classesPaire instance at 0x113f81098>,
#  (u'pi2S', u'FP'): <__main__.classesPaire instance at 0x113fb2368>,
#  (u'fi1P', u'ps2P'): <__main__.classesPaire instance at 0x10b1cd290>,
#  (u'ppMP', u'is3P'): <__main__.classesPaire instance at 0x10a814b48>,
#  (u'pc3S', u'ai1P'): <__main__.classesPaire instance at 0x103cb2248>,
#  (u'ii3S', u'is2S'): <__main__.classesPaire instance at 0x10c07cb00>,
#  (u'ai2P', u'ps2S'): <__main__.classesPaire instance at 0x110397d88>,
#  (u'ppMS', u'ai3S'): <__main__.classesPaire instance at 0x11106e3b0>,
#  (u'pI1P', u'pI1P'): <__main__.classesPaire instance at 0x10c24d710>,
#  (u'pc1P', u'pi1S'): <__main__.classesPaire instance at 0x11422f680>,
#  (u'ii3S', u'ppFS'): <__main__.classesPaire instance at 0x114078950>,
#  (u'ps3P', u'ps1P'): <__main__.classesPaire instance at 0x10f1639e0>,
#  (u'ai2S', u'fi1S'): <__main__.classesPaire instance at 0x113fcf680>,
#  (u'is2S', u'ii2P'): <__main__.classesPaire instance at 0x113fc51b8>,
#  (u'ppMP', u'fi2S'): <__main__.classesPaire instance at 0x1142395f0>,
#  (u'is2P', u'ii1S'): <__main__.classesPaire instance at 0x113ff6680>,
#  (u'pI1P', u'ii2P'): <__main__.classesPaire instance at 0x109cd2290>,
#  (u'ps2S', u'is2S'): <__main__.classesPaire instance at 0x110307638>,
#  (u'fi1P', u'pi1S'): <__main__.classesPaire instance at 0x114887248>,
#  (u'pc3S', u'pc1S'): <__main__.classesPaire instance at 0x11489e680>,
#  (u'ps3S', u'ii2P'): <__main__.classesPaire instance at 0x10f4b7200>,
#  (u'pi1P', u'is3S'): <__main__.classesPaire instance at 0x1098de758>,
#  (u'ps3P', u'pi3S'): <__main__.classesPaire instance at 0x10ca94098>,
#  (u'pc3S', u'ai3S'): <__main__.classesPaire instance at 0x10f2b7560>,
#  (u'FP', u'pc3P'): <__main__.classesPaire instance at 0x10ad55488>,
#  (u'pc1S', u'pc3S'): <__main__.classesPaire instance at 0x113ea3560>,
#  (u'ppFS', u'pi3P'): <__main__.classesPaire instance at 0x10d580e60>,
#  (u'ii1S', u'ai3S'): <__main__.classesPaire instance at 0x10bace830>,
#  (u'pi2S', u'ppMS'): <__main__.classesPaire instance at 0x109d6c368>,
#  (u'is2P', u'ai2P'): <__main__.classesPaire instance at 0x113e9ff38>,
#  (u'ps2P', u'ii2P'): <__main__.classesPaire instance at 0x10f38fea8>,
#  (u'ppMS', u'pc1S'): <__main__.classesPaire instance at 0x10e6e1ef0>,
#  (u'ps3S', u'pc1S'): <__main__.classesPaire instance at 0x113fd4dd0>,
#  (u'is3P', u'ps2S'): <__main__.classesPaire instance at 0x10c5d1320>,
#  (u'pi1S', u'pc2P'): <__main__.classesPaire instance at 0x109cd27e8>,
#  (u'pc3S', u'ppMP'): <__main__.classesPaire instance at 0x11106ec68>,
#  (u'ppFS', u'pi2S'): <__main__.classesPaire instance at 0x10b867c20>,
#  (u'ps3P', u'pi1S'): <__main__.classesPaire instance at 0x10b867d40>,
#  (u'ii2P', u'pi1S'): <__main__.classesPaire instance at 0x1103975a8>,
#  (u'fi1P', u'pi3S'): <__main__.classesPaire instance at 0x1149ca488>,
#  (u'ii3P', u'pi1S'): <__main__.classesPaire instance at 0x10b867a28>,
#  (u'pc1S', u'ps1S'): <__main__.classesPaire instance at 0x10cbb4998>,
#  (u'pi1S', u'is1S'): <__main__.classesPaire instance at 0x10b532170>,
#  (u'ii1S', u'pc3P'): <__main__.classesPaire instance at 0x10ca70dd0>,
#  (u'pc1S', u'pI2S'): <__main__.classesPaire instance at 0x10be997e8>,
#  (u'fi2S', u'pI2S'): <__main__.classesPaire instance at 0x110c0f200>,
#  (u'pi2P', u'pP'): <__main__.classesPaire instance at 0x10c8da3b0>,
#  (u'is2S', u'ppFS'): <__main__.classesPaire instance at 0x10aa3c488>,
#  (u'ps1S', u'fi2S'): <__main__.classesPaire instance at 0x10cbb4878>,
#  (u'ii2S', u'pi2S'): <__main__.classesPaire instance at 0x10f4b7098>,
#  (u'ai1P', u'ai3S'): <__main__.classesPaire instance at 0x10b2c6a70>,
#  (u'pc2P', u'pc1S'): <__main__.classesPaire instance at 0x10ad553f8>,
#  (u'pc2P', u'inf'): <__main__.classesPaire instance at 0x103cb2518>,
#  (u'ai2P', u'pc3P'): <__main__.classesPaire instance at 0x10d0e87e8>,
#  (u'pi3P', u'pc3S'): <__main__.classesPaire instance at 0x1142a6950>,
#  (u'ii2S', u'ppMP'): <__main__.classesPaire instance at 0x10ad06638>,
#  (u'ai3P', u'ppFS'): <__main__.classesPaire instance at 0x10aa3c560>,
#  (u'ii1P', u'fi3P'): <__main__.classesPaire instance at 0x110d14710>,
#  (u'pI2S', u'ps1P'): <__main__.classesPaire instance at 0x1145443b0>,
#  (u'ppMP', u'is3S'): <__main__.classesPaire instance at 0x10b3fa830>,
#  (u'is1S', u'ii1S'): <__main__.classesPaire instance at 0x10bea5d88>,
#  (u'pi1S', u'FS'): <__main__.classesPaire instance at 0x113f81c20>,
#  (u'ppMP', u'ai3P'): <__main__.classesPaire instance at 0x113ec96c8>,
#  (u'pi1P', u'ii3P'): <__main__.classesPaire instance at 0x113f44518>,
#  (u'pi1P', u'ii1P'): <__main__.classesPaire instance at 0x102ba49e0>,
#  (u'is3S', u'pc2S'): <__main__.classesPaire instance at 0x10c4ce950>,
#  (u'ai1S', u'pc2S'): <__main__.classesPaire instance at 0x10e6937e8>,
#  (u'ii3P', u'ai3S'): <__main__.classesPaire instance at 0x11377a518>,
#  (u'ps3P', u'fi2S'): <__main__.classesPaire instance at 0x114239fc8>,
#  (u'fi3S', u'pc1P'): <__main__.classesPaire instance at 0x1097f5758>,
#  (u'ps2S', u'pc2S'): <__main__.classesPaire instance at 0x113ea3248>,
#  (u'pc1S', u'ps2P'): <__main__.classesPaire instance at 0x116fec368>,
#  (u'ii3P', u'ps1P'): <__main__.classesPaire instance at 0x10bc696c8>,
#  (u'is2S', u'is1S'): <__main__.classesPaire instance at 0x10b8e9638>,
#  (u'pP', u'ai3S'): <__main__.classesPaire instance at 0x110d14128>,
#  (u'pi1S', u'ai3S'): <__main__.classesPaire instance at 0x10baaf248>,
#  (u'is3P', u'inf'): <__main__.classesPaire instance at 0x10e3b7320>,
#  (u'fi3S', u'pi3P'): <__main__.classesPaire instance at 0x10f0e5dd0>,
#  (u'ai2S', u'ai1S'): <__main__.classesPaire instance at 0x10b2c6098>,
#  (u'ai2P', u'pi2S'): <__main__.classesPaire instance at 0x10f2a2b90>,
#  (u'ii3S', u'pc2S'): <__main__.classesPaire instance at 0x10b2c6290>,
#  (u'pi1P', u'ai1P'): <__main__.classesPaire instance at 0x10ad981b8>,
#  (u'pi2P', u'ps1P'): <__main__.classesPaire instance at 0x1176ade18>,
#  (u'pP', u'ii1S'): <__main__.classesPaire instance at 0x114840b90>,
#  (u'pI1P', u'pi1P'): <__main__.classesPaire instance at 0x10af8ec68>,
#  (u'ai1S', u'pI1P'): <__main__.classesPaire instance at 0x113e7cbd8>,
#  (u'pc3P', u'ai2S'): <__main__.classesPaire instance at 0x113ea33b0>,
#  (u'fi1P', u'fi2S'): <__main__.classesPaire instance at 0x113b6b5f0>,
#  (u'ii3P', u'ppFP'): <__main__.classesPaire instance at 0x10d617830>,
#  (u'ps3S', u'pi1P'): <__main__.classesPaire instance at 0x10c41b0e0>,
#  (u'ppMP', u'pi1S'): <__main__.classesPaire instance at 0x10b5da290>,
#  (u'pi2S', u'ii2S'): <__main__.classesPaire instance at 0x10c07c9e0>,
#  (u'ii1S', u'ii2S'): <__main__.classesPaire instance at 0x11106e998>,
#  (u'is2P', u'pi2S'): <__main__.classesPaire instance at 0x10aa39bd8>,
#  (u'pI2P', u'pi2S'): <__main__.classesPaire instance at 0x10aa39998>,
#  (u'ps2P', u'pi3S'): <__main__.classesPaire instance at 0x10ca04248>,
#  (u'ps2P', u'is2P'): <__main__.classesPaire instance at 0x113e9fdd0>,
#  (u'pc2S', u'pc1P'): <__main__.classesPaire instance at 0x113ea3638>,
#  (u'FS', u'is2P'): <__main__.classesPaire instance at 0x10bacfc68>,
#  (u'ppFS', u'ii3P'): <__main__.classesPaire instance at 0x110349c68>,
#  (u'is3P', u'ii1S'): <__main__.classesPaire instance at 0x10b5324d0>,
#  (u'ppMS', u'ii1S'): <__main__.classesPaire instance at 0x10c58f830>,
#  (u'ai1S', u'pI2S'): <__main__.classesPaire instance at 0x10c402e60>,
#  (u'pi2S', u'is1P'): <__main__.classesPaire instance at 0x113e64878>,
#  (u'pP', u'is3S'): <__main__.classesPaire instance at 0x10ca4a8c0>,
#  (u'pc2S', u'pI2S'): <__main__.classesPaire instance at 0x109cd25a8>,
#  (u'ii1S', u'is1P'): <__main__.classesPaire instance at 0x10c528680>,
#  (u'is3P', u'ai1S'): <__main__.classesPaire instance at 0x11451bb90>,
#  (u'ai3S', u'ai2S'): <__main__.classesPaire instance at 0x114544440>,
#  (u'pc3S', u'pi1P'): <__main__.classesPaire instance at 0x110c0f998>,
#  (u'ppFS', u'fi1S'): <__main__.classesPaire instance at 0x11459d1b8>,
#  (u'fi2P', u'fi2P'): <__main__.classesPaire instance at 0x113f81638>,
#  (u'pI1P', u'FP'): <__main__.classesPaire instance at 0x10c24da28>,
#  (u'ps3P', u'pc2S'): <__main__.classesPaire instance at 0x10ca94830>,
#  (u'ps2S', u'ps1S'): <__main__.classesPaire instance at 0x10bacf5f0>,
#  (u'is3S', u'ai3S'): <__main__.classesPaire instance at 0x109d13680>,
#  (u'ppFP', u'is3P'): <__main__.classesPaire instance at 0x10c5d18c0>,
#  (u'is3P', u'pi3S'): <__main__.classesPaire instance at 0x10b4eb2d8>,
#  (u'ppMP', u'FS'): <__main__.classesPaire instance at 0x10981cd88>,
#  (u'is1S', u'ai2P'): <__main__.classesPaire instance at 0x10b8101b8>,
#  (u'pi3S', u'fi2S'): <__main__.classesPaire instance at 0x1110076c8>,
#  (u'pi1P', u'ppMP'): <__main__.classesPaire instance at 0x113f2d050>,
#  (u'fi2P', u'ppFS'): <__main__.classesPaire instance at 0x10d5807a0>,
#  (u'fi2S', u'ps2S'): <__main__.classesPaire instance at 0x113e7c8c0>,
#  (u'pi3P', u'ppFS'): <__main__.classesPaire instance at 0x10d580200>,
#  (u'pi1S', u'pc1P'): <__main__.classesPaire instance at 0x11422fdd0>,
#  (u'pi3P', u'fi3S'): <__main__.classesPaire instance at 0x10f0e5e18>,
#  (u'fi2P', u'is2S'): <__main__.classesPaire instance at 0x114261dd0>,
#  (u'ii2P', u'ai1S'): <__main__.classesPaire instance at 0x113e7c368>,
#  (u'ai1S', u'ppFS'): <__main__.classesPaire instance at 0x10aa3c878>,
#  (u'fi1S', u'ppFS'): <__main__.classesPaire instance at 0x10c402d40>,
#  (u'ps2P', u'inf'): <__main__.classesPaire instance at 0x109825d88>,
#  (u'pi3P', u'pI1P'): <__main__.classesPaire instance at 0x1149cad40>,
#  (u'pc3P', u'pP'): <__main__.classesPaire instance at 0x1103b4d40>,
#  (u'ai3P', u'ps1S'): <__main__.classesPaire instance at 0x10baaf758>,
#  (u'ai3P', u'pI2S'): <__main__.classesPaire instance at 0x114544998>,
#  (u'ai2P', u'pi3S'): <__main__.classesPaire instance at 0x114291a28>,
#  (u'FP', u'ai3P'): <__main__.classesPaire instance at 0x10f2ffef0>,
#  (u'ii2S', u'is2P'): <__main__.classesPaire instance at 0x1140f4320>,
#  (u'ppMS', u'fi1S'): <__main__.classesPaire instance at 0x10af405a8>,
#  (u'pP', u'pc2P'): <__main__.classesPaire instance at 0x103c73b90>,
#  (u'ps1S', u'is3P'): <__main__.classesPaire instance at 0x11451b2d8>,
#  (u'pc2P', u'pi2P'): <__main__.classesPaire instance at 0x1176adef0>,
#  (u'ii3S', u'is3P'): <__main__.classesPaire instance at 0x113f2d998>,
#  (u'pc1S', u'is2S'): <__main__.classesPaire instance at 0x1149d4b48>,
#  (u'pc3S', u'ps2S'): <__main__.classesPaire instance at 0x10b1cd5a8>,
#  (u'is2P', u'ps1P'): <__main__.classesPaire instance at 0x113e9fcb0>,
#  (u'ps1P', u'ppFS'): <__main__.classesPaire instance at 0x10bbeccb0>,
#  (u'pi2S', u'fi3S'): <__main__.classesPaire instance at 0x10ca945f0>,
#  (u'is2P', u'ai3S'): <__main__.classesPaire instance at 0x111007518>,
#  (u'inf', u'fi2P'): <__main__.classesPaire instance at 0x10c4e6c68>,
#  (u'pP', u'ii1P'): <__main__.classesPaire instance at 0x10c3fffc8>,
#  (u'is1P', u'ps2S'): <__main__.classesPaire instance at 0x10f2a2e18>,
#  (u'pI2S', u'FP'): <__main__.classesPaire instance at 0x110c6a4d0>,
#  (u'pc1P', u'fi2P'): <__main__.classesPaire instance at 0x1098a44d0>,
#  (u'pc1S', u'is3P'): <__main__.classesPaire instance at 0x114239d40>,
#  (u'ps2S', u'pc1S'): <__main__.classesPaire instance at 0x113fcf320>,
#  (u'pP', u'inf'): <__main__.classesPaire instance at 0x10c3e1560>,
#  (u'pc2P', u'ai1P'): <__main__.classesPaire instance at 0x10af40488>,
#  (u'is3S', u'is2P'): <__main__.classesPaire instance at 0x10c41b200>,
#  (u'fi1P', u'ps1S'): <__main__.classesPaire instance at 0x10a5a4ab8>,
#  (u'pc3P', u'ppMP'): <__main__.classesPaire instance at 0x10b3fa758>,
#  (u'ai3P', u'ps2P'): <__main__.classesPaire instance at 0x10cbb4f80>,
#  (u'ii1S', u'pP'): <__main__.classesPaire instance at 0x114840cb0>,
#  (u'pI2S', u'ai3P'): <__main__.classesPaire instance at 0x1145447a0>,
#  (u'pc2S', u'fi1P'): <__main__.classesPaire instance at 0x113ea3878>,
#  (u'ppFS', u'pI2P'): <__main__.classesPaire instance at 0x10be9df80>,
#  (u'fi1S', u'pi1P'): <__main__.classesPaire instance at 0x10e36f758>,
#  (u'pI2S', u'fi2P'): <__main__.classesPaire instance at 0x109cd2440>,
#  (u'pc1P', u'ai1S'): <__main__.classesPaire instance at 0x10f163e18>,
#  (u'ii2P', u'inf'): <__main__.classesPaire instance at 0x113fb9ab8>,
#  (u'ppMS', u'pi3P'): <__main__.classesPaire instance at 0x110c6ae60>,
#  (u'fi2S', u'ps1P'): <__main__.classesPaire instance at 0x116feca70>,
#  (u'ai1P', u'ii2S'): <__main__.classesPaire instance at 0x11377ab00>,
#  (u'ai3P', u'is1S'): <__main__.classesPaire instance at 0x10c8da368>,
#  (u'is2S', u'fi3P'): <__main__.classesPaire instance at 0x10aa3cf80>,
#  (u'ps2P', u'ii1P'): <__main__.classesPaire instance at 0x10c8da950>,
#  (u'ai3S', u'ppMP'): <__main__.classesPaire instance at 0x10be9d998>,
#  (u'is3S', u'FP'): <__main__.classesPaire instance at 0x10f3e17e8>,
#  (u'fi3S', u'is1P'): <__main__.classesPaire instance at 0x113f53bd8>,
#  (u'is1S', u'ii3P'): <__main__.classesPaire instance at 0x10981cb90>,
#  (u'is3S', u'ii2S'): <__main__.classesPaire instance at 0x10bea57e8>,
#  (u'ps1P', u'pc3P'): <__main__.classesPaire instance at 0x1149e4cf8>,
#  (u'ai2P', u'is3S'): <__main__.classesPaire instance at 0x10b3fae18>,
#  (u'is1S', u'ppMS'): <__main__.classesPaire instance at 0x10a13f560>,
#  (u'fi3S', u'ii2S'): <__main__.classesPaire instance at 0x113ea37a0>,
#  (u'pc3S', u'pI1P'): <__main__.classesPaire instance at 0x10ba80638>,
#  (u'pi3P', u'pi2P'): <__main__.classesPaire instance at 0x1176add88>,
#  (u'ii3S', u'ai3S'): <__main__.classesPaire instance at 0x10b594e18>,
#  (u'ppFS', u'ai3S'): <__main__.classesPaire instance at 0x10d580950>,
#  (u'pc1P', u'pi1P'): <__main__.classesPaire instance at 0x10f2ff368>,
#  (u'pc2P', u'pi3P'): <__main__.classesPaire instance at 0x114887200>,
#  (u'pc3S', u'ps1P'): <__main__.classesPaire instance at 0x1142917a0>,
#  (u'pI2S', u'is3P'): <__main__.classesPaire instance at 0x10c4e6998>,
#  (u'pI2P', u'fi1S'): <__main__.classesPaire instance at 0x10aa3c518>,
#  (u'fi1S', u'ii2S'): <__main__.classesPaire instance at 0x1140781b8>,
#  (u'ii3P', u'pI2S'): <__main__.classesPaire instance at 0x110349908>,
#  (u'ai3P', u'fi2S'): <__main__.classesPaire instance at 0x109818ef0>,
#  (u'ii1S', u'ps3P'): <__main__.classesPaire instance at 0x1099b0440>,
#  (u'ps1P', u'pI2P'): <__main__.classesPaire instance at 0x1176ad3b0>,
#  (u'fi1S', u'ppMS'): <__main__.classesPaire instance at 0x102ba4a28>,
#  (u'pc2P', u'ii2S'): <__main__.classesPaire instance at 0x11459df80>,
#  ...}

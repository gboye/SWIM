# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
from IPython.html.widgets import FloatProgress
from IPython.display import display
# Out:
# /Users/gilles/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
phonologicalMap="-N"

# %%
import math
def rAn(r,n):
    f = math.factorial
    return f(n) / f(n-r)
def rCn(r,n):
    f = math.factorial
    return f(n) / f(r) / f(n-r)

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
validPhonemes=list(fs.supremum.concept.extent)
#for phoneme in validPhonemes:
#    print (phoneme, [phoneme], ";")

# %%
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# # Lecture du tableau de VERBES

# %% [markdown]
# ### Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
filePrefix="2015-Data/MGC-160104"

# %% [raw]
# casesPrincipales= [
#         'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
#         'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P',
#         'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
#         'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
#         'ps2P', 'ps3P',
#         'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
#         'ppMS', 'ppMP', 'ppFS', 'ppFP'
#             ]
# casesSecondaires= [
#        'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
#             ]
# casesTotales=casesPrincipales+casesSecondaires
# listeCases=casesTotales

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print (forme, file=logfile)
                print ("pas de classe",idClasseForme, file=logfile)
                print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %% [raw]
# def OLDrapports(paradigme):
#     (case1,case2,lexeme)= paradigme.columns.values.tolist()
#     patrons=pairePatrons(case1,case2)
#     if len(paradigme)>0:
# #        for index, row in paradigme.iterrows():
# #            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
#         paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
#         (regles1,regles2)=patrons.calculerGM()
#     return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ## Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for n,paire in enumerate(it.combinations_with_replacement(sampleCases,2)):
        progressBar.value=n
        if debug: print (paire, file=logfile)
        if debug: print ("-".join(paire),end=", ")
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ### Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
debug1=True

for echantillon in range(0,3):
    echantillonPrefix="-%02d"%(echantillon+1)
    
    nomLexique=filePrefix+echantillonPrefix+"-N-ext3-derivations-BRASS.csv"
    paradigmes=pd.read_csv(nomLexique,sep=";",encoding="utf8")    

    del paradigmes[u"Unnamed: 0"]
    sampleCases=paradigmes.columns.tolist()
    sampleCases.remove(u"lexeme")    

    #Neutralize all the forms
#    for case in sampleCases:
#        paradigmes[case]=paradigmes[case].apply(lambda x: recoder(x))

    #Save neutralized paradigms
#    paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+phonologicalMap+"-paradigmes.csv",encoding="utf8",sep=";")    
    
#    logfile_name=filePrefix+echantillonPrefix+phonologicalMap+".log"
#    logfile = codecs.open(logfile_name,mode='w',encoding="utf8")
    
    progressBar = FloatProgress(min=0, max=rCn(2,len(sampleCases)))
    display(progressBar)
    
    resultats=evaluerEchantillon(paradigmes)
    classesFinales={}
    for resultat in resultats:
        classesFinales[resultat]=resultats[resultat][0]
        classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]
#    with open(filePrefix+echantillonPrefix+phonologicalMap+'-Regles.pkl', 'wb') as output:
    with open(nomLexique.replace(".csv",'-Regles.pkl'), 'wb') as output:
       pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)
# Out:
# CPU times: user 6min 6s, sys: 4.72 s, total: 6min 11s
# Wall time: 6min 14s

# %%
for element in  (classesFinales[("pi3S","FS")].sortirForme(u"ariv")):
    print (element)
# Out:
# arive

# %%
classesFinales
# Out:
# {(u'ps2P', u'is1S'): <__main__.classesPaire instance at 0x10dcbd320>,
#  (u'inf', u'pi2S'): <__main__.classesPaire instance at 0x10dbd37e8>,
#  (u'ii3S', u'pI1P'): <__main__.classesPaire instance at 0x10dfccdd0>,
#  (u'is2S', u'pc3P'): <__main__.classesPaire instance at 0x10ccfd998>,
#  (u'ps2S', u'ii2P'): <__main__.classesPaire instance at 0x10df127e8>,
#  (u'pc2P', u'ai2P'): <__main__.classesPaire instance at 0x10add3dd0>,
#  (u'ii3P', u'pi2P'): <__main__.classesPaire instance at 0x1096c7b00>,
#  (u'fi3P', u'pi2P'): <__main__.classesPaire instance at 0x10d175cf8>,
#  (u'pi2S', u'ps3P'): <__main__.classesPaire instance at 0x10dc5b248>,
#  (u'pc1P', u'pi2S'): <__main__.classesPaire instance at 0x10e108710>,
#  (u'is2P', u'pP'): <__main__.classesPaire instance at 0x10df15b48>,
#  (u'is2S', u'ai1S'): <__main__.classesPaire instance at 0x10add3680>,
#  (u'fi1P', u'pI1P'): <__main__.classesPaire instance at 0x10b0700e0>,
#  (u'ps2P', u'ai3S'): <__main__.classesPaire instance at 0x10db2dfc8>,
#  (u'pc1S', u'ai3S'): <__main__.classesPaire instance at 0x105b6abd8>,
#  (u'ii3S', u'ii3P'): <__main__.classesPaire instance at 0x10ce18368>,
#  (u'FP', u'ps2S'): <__main__.classesPaire instance at 0x10de97440>,
#  (u'pP', u'pi1P'): <__main__.classesPaire instance at 0x10de823b0>,
#  (u'ps2S', u'fi1S'): <__main__.classesPaire instance at 0x10d12d248>,
#  (u'pi2P', u'fi1S'): <__main__.classesPaire instance at 0x1063bad40>,
#  (u'ps3S', u'is2P'): <__main__.classesPaire instance at 0x10dfaf0e0>,
#  (u'pi1S', u'fi3S'): <__main__.classesPaire instance at 0x10b5e4d40>,
#  (u'is1P', u'pP'): <__main__.classesPaire instance at 0x10dc63098>,
#  (u'ppFP', u'ppFP'): <__main__.classesPaire instance at 0x10d31a170>,
#  (u'ppFS', u'fi3S'): <__main__.classesPaire instance at 0x10b5e47a0>,
#  (u'ii2P', u'ps3P'): <__main__.classesPaire instance at 0x106d7ea28>,
#  (u'ii3S', u'ps3P'): <__main__.classesPaire instance at 0x10dea33f8>,
#  (u'pc1P', u'fi3P'): <__main__.classesPaire instance at 0x10cab6b00>,
#  (u'is3P', u'pI2P'): <__main__.classesPaire instance at 0x10643ef80>,
#  (u'ppMP', u'pc1P'): <__main__.classesPaire instance at 0x10ce18a70>,
#  (u'is3P', u'ppFS'): <__main__.classesPaire instance at 0x10dc4e9e0>,
#  (u'ii3P', u'fi2S'): <__main__.classesPaire instance at 0x10dfbf0e0>,
#  (u'inf', u'is2P'): <__main__.classesPaire instance at 0x10e150758>,
#  (u'fi1S', u'ps1S'): <__main__.classesPaire instance at 0x10de6c998>,
#  (u'is1P', u'pc1P'): <__main__.classesPaire instance at 0x109a280e0>,
#  (u'pi3S', u'pc3S'): <__main__.classesPaire instance at 0x10ba7c290>,
#  (u'ps3S', u'is3S'): <__main__.classesPaire instance at 0x109a28bd8>,
#  (u'is2S', u'FS'): <__main__.classesPaire instance at 0x10ca3d5a8>,
#  (u'ppMP', u'ii3P'): <__main__.classesPaire instance at 0x10d9c5bd8>,
#  (u'fi3P', u'ppMP'): <__main__.classesPaire instance at 0x10dfc5248>,
#  (u'ppFS', u'is3P'): <__main__.classesPaire instance at 0x109a27a28>,
#  (u'ps2P', u'is3S'): <__main__.classesPaire instance at 0x106d91a70>,
#  (u'ai3S', u'fi3S'): <__main__.classesPaire instance at 0x10becc098>,
#  (u'fi3P', u'pi1P'): <__main__.classesPaire instance at 0x10d9f2710>,
#  (u'fi1P', u'ii3P'): <__main__.classesPaire instance at 0x10becc8c0>,
#  (u'fi3S', u'fi2P'): <__main__.classesPaire instance at 0x10de607a0>,
#  (u'ppMP', u'ps3P'): <__main__.classesPaire instance at 0x10bfb9710>,
#  (u'pI2P', u'ps2P'): <__main__.classesPaire instance at 0x10db85dd0>,
#  (u'pi2P', u'ps3P'): <__main__.classesPaire instance at 0x10641abd8>,
#  (u'FS', u'fi3P'): <__main__.classesPaire instance at 0x10df15710>,
#  (u'pi1P', u'ai2P'): <__main__.classesPaire instance at 0x10cfd4b00>,
#  (u'pI1P', u'ai2S'): <__main__.classesPaire instance at 0x10d9aacb0>,
#  (u'pI2P', u'ps1S'): <__main__.classesPaire instance at 0x10e150050>,
#  (u'pi2P', u'pi3P'): <__main__.classesPaire instance at 0x106d89680>,
#  (u'pP', u'fi3P'): <__main__.classesPaire instance at 0x10ce181b8>,
#  (u'ii1P', u'pc2S'): <__main__.classesPaire instance at 0x10ded7758>,
#  (u'pI2P', u'is1S'): <__main__.classesPaire instance at 0x10dbf7a70>,
#  (u'pc3S', u'is1P'): <__main__.classesPaire instance at 0x10defe200>,
#  (u'ppMS', u'FS'): <__main__.classesPaire instance at 0x10bfb9e60>,
#  (u'ppFP', u'pI2P'): <__main__.classesPaire instance at 0x10ca3dbd8>,
#  (u'is3S', u'ppMS'): <__main__.classesPaire instance at 0x10dcbd878>,
#  (u'pc2P', u'is3P'): <__main__.classesPaire instance at 0x10df18e18>,
#  (u'ii2P', u'FS'): <__main__.classesPaire instance at 0x10d9edd88>,
#  (u'fi1P', u'ppFP'): <__main__.classesPaire instance at 0x10def6ea8>,
#  (u'FP', u'ps1P'): <__main__.classesPaire instance at 0x10d9f9998>,
#  (u'ps3S', u'fi1S'): <__main__.classesPaire instance at 0x10ceac908>,
#  (u'inf', u'is3P'): <__main__.classesPaire instance at 0x10dfcc710>,
#  (u'pI1P', u'ii1P'): <__main__.classesPaire instance at 0x10bea3ab8>,
#  (u'fi1S', u'ps1P'): <__main__.classesPaire instance at 0x10c8c94d0>,
#  (u'pi3S', u'ai1P'): <__main__.classesPaire instance at 0x10ccdf9e0>,
#  (u'fi1S', u'pi3S'): <__main__.classesPaire instance at 0x106daf830>,
#  (u'ii3P', u'ppMP'): <__main__.classesPaire instance at 0x10dc4e830>,
#  (u'is2S', u'ps1P'): <__main__.classesPaire instance at 0x10b773cf8>,
#  (u'is1P', u'fi2P'): <__main__.classesPaire instance at 0x10e1447a0>,
#  (u'pi3P', u'ii1P'): <__main__.classesPaire instance at 0x10b070200>,
#  (u'ppMS', u'is1P'): <__main__.classesPaire instance at 0x10df0a3b0>,
#  (u'ps3S', u'is1P'): <__main__.classesPaire instance at 0x10cfc2dd0>,
#  (u'pc2P', u'is1S'): <__main__.classesPaire instance at 0x10df152d8>,
#  (u'inf', u'ps2S'): <__main__.classesPaire instance at 0x10df123b0>,
#  (u'fi1P', u'ii2S'): <__main__.classesPaire instance at 0x1096f0a70>,
#  (u'fi1P', u'fi1S'): <__main__.classesPaire instance at 0x10d14c098>,
#  (u'ai1S', u'ii1P'): <__main__.classesPaire instance at 0x1096f0170>,
#  (u'pI1P', u'ai1S'): <__main__.classesPaire instance at 0x10ce26440>,
#  (u'pi2P', u'pc1S'): <__main__.classesPaire instance at 0x106d84680>,
#  (u'pc3S', u'fi1S'): <__main__.classesPaire instance at 0x106dc23f8>,
#  (u'pi1S', u'inf'): <__main__.classesPaire instance at 0x10dc63a28>,
#  (u'pP', u'pI2P'): <__main__.classesPaire instance at 0x10df183b0>,
#  (u'ai3S', u'ii3P'): <__main__.classesPaire instance at 0x10df5f128>,
#  (u'ppFP', u'pi2S'): <__main__.classesPaire instance at 0x10de974d0>,
#  (u'is1P', u'ppMP'): <__main__.classesPaire instance at 0x10df15098>,
#  (u'fi1P', u'is1P'): <__main__.classesPaire instance at 0x10ce268c0>,
#  (u'pi3S', u'pP'): <__main__.classesPaire instance at 0x10ba7cd88>,
#  (u'pi3S', u'pi3S'): <__main__.classesPaire instance at 0x109a27518>,
#  (u'pI2S', u'ii3S'): <__main__.classesPaire instance at 0x10cfcd5f0>,
#  (u'ai3S', u'is1P'): <__main__.classesPaire instance at 0x10b518c20>,
#  (u'pc2P', u'FP'): <__main__.classesPaire instance at 0x10cee6fc8>,
#  (u'ai1P', u'ps1S'): <__main__.classesPaire instance at 0x10e1276c8>,
#  (u'ps3P', u'pi2S'): <__main__.classesPaire instance at 0x10e15c680>,
#  (u'ps1P', u'ii1P'): <__main__.classesPaire instance at 0x10cfc2e18>,
#  (u'ai2S', u'is2P'): <__main__.classesPaire instance at 0x10ad6e098>,
#  (u'fi2P', u'ps1P'): <__main__.classesPaire instance at 0x10d9f1b48>,
#  (u'ps2P', u'ps2P'): <__main__.classesPaire instance at 0x109698d40>,
#  (u'fi1S', u'fi3S'): <__main__.classesPaire instance at 0x106409fc8>,
#  (u'is1S', u'ps3S'): <__main__.classesPaire instance at 0x10dc5b9e0>,
#  (u'ai2P', u'ii3P'): <__main__.classesPaire instance at 0x10d11b7a0>,
#  (u'fi3P', u'ps1P'): <__main__.classesPaire instance at 0x109699098>,
#  (u'fi3P', u'is3P'): <__main__.classesPaire instance at 0x10dc4e638>,
#  (u'pc3P', u'pi2S'): <__main__.classesPaire instance at 0x10dbd6878>,
#  (u'is2S', u'pc1P'): <__main__.classesPaire instance at 0x10d17cb00>,
#  (u'ai2S', u'fi3P'): <__main__.classesPaire instance at 0x1096c4368>,
#  (u'pI2P', u'is2S'): <__main__.classesPaire instance at 0x10dfcc8c0>,
#  (u'inf', u'pi3P'): <__main__.classesPaire instance at 0x10de344d0>,
#  (u'pc3S', u'pc3P'): <__main__.classesPaire instance at 0x10cf7dcb0>,
#  (u'ps2S', u'pP'): <__main__.classesPaire instance at 0x10de935a8>,
#  (u'ai2P', u'pi1P'): <__main__.classesPaire instance at 0x10cfd4f80>,
#  (u'ii3P', u'pI2P'): <__main__.classesPaire instance at 0x10e110e18>,
#  (u'ii1P', u'pc3P'): <__main__.classesPaire instance at 0x10def6cb0>,
#  (u'pi1P', u'ai3S'): <__main__.classesPaire instance at 0x10d35ecf8>,
#  (u'pI2P', u'fi2S'): <__main__.classesPaire instance at 0x10d9a6488>,
#  (u'pc1P', u'pi3P'): <__main__.classesPaire instance at 0x10b6acfc8>,
#  (u'pI1P', u'ppMP'): <__main__.classesPaire instance at 0x10ca3d878>,
#  (u'inf', u'pc1P'): <__main__.classesPaire instance at 0x106d7dea8>,
#  (u'ii3S', u'pi3S'): <__main__.classesPaire instance at 0x10dec0050>,
#  (u'is2P', u'ppFS'): <__main__.classesPaire instance at 0x10ccfd440>,
#  (u'ppFP', u'pi3P'): <__main__.classesPaire instance at 0x10e119c68>,
#  (u'pc2S', u'ai3S'): <__main__.classesPaire instance at 0x10e1560e0>,
#  (u'ii3S', u'pc1S'): <__main__.classesPaire instance at 0x10de34f80>,
#  (u'is2S', u'fi2S'): <__main__.classesPaire instance at 0x10cab6f80>,
#  (u'fi1S', u'ai1S'): <__main__.classesPaire instance at 0x10b864cf8>,
#  (u'pc3P', u'ps3P'): <__main__.classesPaire instance at 0x10db5eea8>,
#  (u'is2P', u'fi2P'): <__main__.classesPaire instance at 0x10ce186c8>,
#  (u'ppFP', u'ps3P'): <__main__.classesPaire instance at 0x109698950>,
#  (u'ai1S', u'ppMP'): <__main__.classesPaire instance at 0x10df4c950>,
#  (u'pi2S', u'ps2S'): <__main__.classesPaire instance at 0x106d84e60>,
#  (u'ps3S', u'pc3P'): <__main__.classesPaire instance at 0x10d31ab90>,
#  (u'ai3P', u'fi3P'): <__main__.classesPaire instance at 0x10bc4df38>,
#  (u'pi1P', u'fi1P'): <__main__.classesPaire instance at 0x10ce18b90>,
#  (u'fi1S', u'ppMP'): <__main__.classesPaire instance at 0x10de62050>,
#  (u'pc2S', u'is1S'): <__main__.classesPaire instance at 0x1096deb48>,
#  (u'ppMP', u'inf'): <__main__.classesPaire instance at 0x10dc5b7e8>,
#  (u'is1P', u'pI2P'): <__main__.classesPaire instance at 0x10b5e43b0>,
#  (u'pi3P', u'ai2P'): <__main__.classesPaire instance at 0x10cfd4bd8>,
#  (u'ppMS', u'ps1P'): <__main__.classesPaire instance at 0x105b7bb90>,
#  (u'ppFP', u'fi3P'): <__main__.classesPaire instance at 0x10cffc488>,
#  (u'ppMS', u'pi1P'): <__main__.classesPaire instance at 0x106d95248>,
#  (u'ps3P', u'ai3S'): <__main__.classesPaire instance at 0x10d123ea8>,
#  (u'is1S', u'pc3S'): <__main__.classesPaire instance at 0x10c8f48c0>,
#  (u'ii1P', u'ii1S'): <__main__.classesPaire instance at 0x10e144b48>,
#  (u'fi2P', u'pi2S'): <__main__.classesPaire instance at 0x10de60bd8>,
#  (u'FP', u'pi1P'): <__main__.classesPaire instance at 0x10e119c20>,
#  (u'pi1S', u'pI2P'): <__main__.classesPaire instance at 0x10dff0c20>,
#  (u'ppMP', u'ii2S'): <__main__.classesPaire instance at 0x10d1219e0>,
#  (u'ai2S', u'is1P'): <__main__.classesPaire instance at 0x10bbfd1b8>,
#  (u'FS', u'ii2S'): <__main__.classesPaire instance at 0x10de163b0>,
#  (u'ii1S', u'pi1S'): <__main__.classesPaire instance at 0x10df98200>,
#  (u'fi3P', u'fi3P'): <__main__.classesPaire instance at 0x1096c7368>,
#  (u'pI2P', u'pc2P'): <__main__.classesPaire instance at 0x10969fdd0>,
#  (u'FS', u'pi1S'): <__main__.classesPaire instance at 0x10e15c7e8>,
#  (u'ai2S', u'pi3P'): <__main__.classesPaire instance at 0x10add3ef0>,
#  (u'ai1S', u'FP'): <__main__.classesPaire instance at 0x10db370e0>,
#  (u'pi1P', u'FP'): <__main__.classesPaire instance at 0x10e1198c0>,
#  (u'pc2P', u'fi2P'): <__main__.classesPaire instance at 0x10def6560>,
#  (u'FP', u'fi3S'): <__main__.classesPaire instance at 0x10bea30e0>,
#  (u'fi3S', u'ps1S'): <__main__.classesPaire instance at 0x1034465f0>,
#  (u'ai3P', u'ii1S'): <__main__.classesPaire instance at 0x10af50f38>,
#  (u'pP', u'ai3P'): <__main__.classesPaire instance at 0x10bbcbbd8>,
#  (u'ps3P', u'ps2S'): <__main__.classesPaire instance at 0x10af0d638>,
#  (u'pc1P', u'is2S'): <__main__.classesPaire instance at 0x10d17c680>,
#  (u'ii3P', u'is3S'): <__main__.classesPaire instance at 0x106d9d440>,
#  (u'pi2P', u'pi2S'): <__main__.classesPaire instance at 0x10dbd08c0>,
#  (u'ii3S', u'fi2S'): <__main__.classesPaire instance at 0x10b070950>,
#  (u'pI1P', u'pI2P'): <__main__.classesPaire instance at 0x10e1105f0>,
#  (u'pc3P', u'pc3P'): <__main__.classesPaire instance at 0x10ba7c098>,
#  (u'ps1S', u'ps2P'): <__main__.classesPaire instance at 0x10de97a70>,
#  (u'is2S', u'pc2S'): <__main__.classesPaire instance at 0x10d17c200>,
#  (u'FP', u'pP'): <__main__.classesPaire instance at 0x10ba7cbd8>,
#  (u'is3P', u'pc3S'): <__main__.classesPaire instance at 0x10b773f80>,
#  (u'ps1P', u'fi1P'): <__main__.classesPaire instance at 0x10de60710>,
#  (u'fi2S', u'pi3S'): <__main__.classesPaire instance at 0x10d30d518>,
#  (u'ii1S', u'ai1P'): <__main__.classesPaire instance at 0x10b68ca28>,
#  (u'pc2S', u'pi2S'): <__main__.classesPaire instance at 0x10dfccfc8>,
#  (u'ii2P', u'ppMP'): <__main__.classesPaire instance at 0x10d1513b0>,
#  (u'ppMP', u'fi3S'): <__main__.classesPaire instance at 0x10d9f1248>,
#  (u'is3P', u'pi1P'): <__main__.classesPaire instance at 0x10e1714d0>,
#  (u'ii2S', u'pc2P'): <__main__.classesPaire instance at 0x10db85ef0>,
#  (u'ii2S', u'pI2S'): <__main__.classesPaire instance at 0x10d9edab8>,
#  (u'pi1S', u'ai1P'): <__main__.classesPaire instance at 0x1063e32d8>,
#  (u'pc3P', u'pi1S'): <__main__.classesPaire instance at 0x10cf7d710>,
#  (u'fi3S', u'ai1S'): <__main__.classesPaire instance at 0x10c822bd8>,
#  (u'ii1S', u'is3S'): <__main__.classesPaire instance at 0x10de16dd0>,
#  (u'pc2P', u'ppFS'): <__main__.classesPaire instance at 0x10b5db9e0>,
#  (u'ai1P', u'fi1P'): <__main__.classesPaire instance at 0x10dbf05a8>,
#  (u'ii1S', u'ii3S'): <__main__.classesPaire instance at 0x1063ba368>,
#  (u'pc2P', u'fi3S'): <__main__.classesPaire instance at 0x10bea3dd0>,
#  (u'pI1P', u'is3P'): <__main__.classesPaire instance at 0x10ca3d050>,
#  (u'pc1P', u'fi1P'): <__main__.classesPaire instance at 0x10d12d758>,
#  (u'ps1P', u'ii1S'): <__main__.classesPaire instance at 0x10cfcdd40>,
#  (u'ai1S', u'fi1S'): <__main__.classesPaire instance at 0x10b864cb0>,
#  (u'ii2P', u'ai3S'): <__main__.classesPaire instance at 0x10dfbf6c8>,
#  (u'is2S', u'pI2S'): <__main__.classesPaire instance at 0x10dfcc518>,
#  (u'pi3P', u'is3P'): <__main__.classesPaire instance at 0x10df18dd0>,
#  (u'ai3S', u'ii2S'): <__main__.classesPaire instance at 0x10cfd45a8>,
#  (u'pc3P', u'ii1S'): <__main__.classesPaire instance at 0x10d9eb2d8>,
#  (u'pi2P', u'is2P'): <__main__.classesPaire instance at 0x10df50b90>,
#  (u'is1S', u'pc2P'): <__main__.classesPaire instance at 0x10d9ed8c0>,
#  (u'ai1S', u'is3P'): <__main__.classesPaire instance at 0x10d325c68>,
#  (u'ppFP', u'is2P'): <__main__.classesPaire instance at 0x10ccfd710>,
#  (u'ps1S', u'fi3P'): <__main__.classesPaire instance at 0x10c88c638>,
#  (u'pi1P', u'pi1P'): <__main__.classesPaire instance at 0x106d95e60>,
#  (u'pc1S', u'is3P'): <__main__.classesPaire instance at 0x10643ecf8>,
#  (u'pi2S', u'pc3S'): <__main__.classesPaire instance at 0x10d1e5c20>,
#  (u'pi1S', u'pi1S'): <__main__.classesPaire instance at 0x10b5dbab8>,
#  (u'pP', u'ii1P'): <__main__.classesPaire instance at 0x10d9a6b90>,
#  (u'ai2S', u'pc3P'): <__main__.classesPaire instance at 0x106db2950>,
#  (u'ppMP', u'ai3S'): <__main__.classesPaire instance at 0x10d325ea8>,
#  (u'ii2P', u'ppFP'): <__main__.classesPaire instance at 0x10df12908>,
#  (u'FP', u'ii2P'): <__main__.classesPaire instance at 0x10de87440>,
#  (u'pi2P', u'ai3S'): <__main__.classesPaire instance at 0x10d1157e8>,
#  (u'ps1S', u'pc1S'): <__main__.classesPaire instance at 0x10cee6c68>,
#  (u'fi2S', u'is2P'): <__main__.classesPaire instance at 0x10d175c20>,
#  (u'ppMS', u'pI1P'): <__main__.classesPaire instance at 0x10de87830>,
#  (u'pc1S', u'fi3P'): <__main__.classesPaire instance at 0x106d91e18>,
#  (u'pc3P', u'inf'): <__main__.classesPaire instance at 0x10dcbe518>,
#  (u'fi2S', u'ai1P'): <__main__.classesPaire instance at 0x10b8643f8>,
#  (u'ai2S', u'pc2P'): <__main__.classesPaire instance at 0x10d1003f8>,
#  (u'pc2S', u'pI2P'): <__main__.classesPaire instance at 0x10de20cf8>,
#  (u'pc3P', u'pi3P'): <__main__.classesPaire instance at 0x106d88b00>,
#  (u'fi2S', u'pI1P'): <__main__.classesPaire instance at 0x10d9a6d40>,
#  (u'ai3S', u'is2P'): <__main__.classesPaire instance at 0x10b5c1290>,
#  (u'ii1P', u'pc1P'): <__main__.classesPaire instance at 0x10b070758>,
#  (u'ai3P', u'ps3P'): <__main__.classesPaire instance at 0x10db2d050>,
#  (u'ai1P', u'pi1S'): <__main__.classesPaire instance at 0x1096ec710>,
#  (u'ii1S', u'ii1P'): <__main__.classesPaire instance at 0x10cfcd908>,
#  (u'pc3P', u'is1P'): <__main__.classesPaire instance at 0x10defe638>,
#  (u'ppFS', u'pI1P'): <__main__.classesPaire instance at 0x10ca3d4d0>,
#  (u'pi3S', u'is3P'): <__main__.classesPaire instance at 0x1096a3878>,
#  (u'pI1P', u'fi3P'): <__main__.classesPaire instance at 0x10de60b90>,
#  (u'ppFS', u'ps1S'): <__main__.classesPaire instance at 0x10cc2d518>,
#  (u'is1P', u'ps3S'): <__main__.classesPaire instance at 0x10d368488>,
#  (u'pI2S', u'fi1S'): <__main__.classesPaire instance at 0x10ceac998>,
#  (u'ai2S', u'ii3P'): <__main__.classesPaire instance at 0x10ceed7a0>,
#  (u'is1S', u'fi2S'): <__main__.classesPaire instance at 0x10de16368>,
#  (u'pi3S', u'ii1S'): <__main__.classesPaire instance at 0x10d151950>,
#  (u'pP', u'pP'): <__main__.classesPaire instance at 0x10b6acd88>,
#  (u'pi1S', u'pP'): <__main__.classesPaire instance at 0x10dff0830>,
#  (u'ppFS', u'pi1P'): <__main__.classesPaire instance at 0x10dbd6758>,
#  (u'ii2S', u'pc3S'): <__main__.classesPaire instance at 0x10d151a70>,
#  (u'ps3S', u'pI2S'): <__main__.classesPaire instance at 0x10c88c908>,
#  (u'ps2P', u'fi2S'): <__main__.classesPaire instance at 0x106dafd40>,
#  (u'FS', u'ii3S'): <__main__.classesPaire instance at 0x10df0a7a0>,
#  (u'ii2P', u'ai2S'): <__main__.classesPaire instance at 0x10cfd4098>,
#  (u'fi2S', u'FP'): <__main__.classesPaire instance at 0x106d7d290>,
#  (u'pc1S', u'ii1S'): <__main__.classesPaire instance at 0x10dec0950>,
#  (u'pc3S', u'pc2P'): <__main__.classesPaire instance at 0x106d884d0>,
#  (u'ai2S', u'ps3P'): <__main__.classesPaire instance at 0x10cf52908>,
#  (u'pi3P', u'is2S'): <__main__.classesPaire instance at 0x10b773440>,
#  (u'ai1S', u'pi3P'): <__main__.classesPaire instance at 0x10dbf0ab8>,
#  (u'pI2S', u'ii1S'): <__main__.classesPaire instance at 0x10d9f2638>,
#  (u'ppFS', u'FP'): <__main__.classesPaire instance at 0x106d95d40>,
#  (u'is2P', u'pI1P'): <__main__.classesPaire instance at 0x10dea3170>,
#  (u'fi2S', u'ppMP'): <__main__.classesPaire instance at 0x10df98680>,
#  (u'fi2P', u'inf'): <__main__.classesPaire instance at 0x10c88c758>,
#  (u'pP', u'fi1S'): <__main__.classesPaire instance at 0x10c88c518>,
#  (u'pc1P', u'pc1S'): <__main__.classesPaire instance at 0x10de47098>,
#  (u'ii1S', u'fi1P'): <__main__.classesPaire instance at 0x10df5ff38>,
#  (u'pc3S', u'pI2S'): <__main__.classesPaire instance at 0x10dcbe7a0>,
#  (u'ai2S', u'ps2P'): <__main__.classesPaire instance at 0x10e127a70>,
#  (u'fi3P', u'ps2S'): <__main__.classesPaire instance at 0x10d123b90>,
#  (u'pi2P', u'pi1S'): <__main__.classesPaire instance at 0x10e171710>,
#  (u'ai3S', u'pi1S'): <__main__.classesPaire instance at 0x10bc4d290>,
#  (u'fi2S', u'ps3S'): <__main__.classesPaire instance at 0x10dbf71b8>,
#  (u'FP', u'fi1S'): <__main__.classesPaire instance at 0x10c8c9050>,
#  (u'ai2P', u'ppFS'): <__main__.classesPaire instance at 0x10b88c950>,
#  (u'ppMP', u'ps2S'): <__main__.classesPaire instance at 0x106d88b90>,
#  (u'fi1S', u'fi2P'): <__main__.classesPaire instance at 0x10d35af38>,
#  (u'ps3P', u'pP'): <__main__.classesPaire instance at 0x10dc634d0>,
#  (u'fi3S', u'pP'): <__main__.classesPaire instance at 0x10de82638>,
#  (u'fi3P', u'ai3S'): <__main__.classesPaire instance at 0x10bc66098>,
#  (u'ps1P', u'pc1S'): <__main__.classesPaire instance at 0x10dbd6638>,
#  (u'FP', u'ppMS'): <__main__.classesPaire instance at 0x10ca93320>,
#  (u'ppFS', u'ai3S'): <__main__.classesPaire instance at 0x10de3e320>,
#  (u'ai3S', u'fi1P'): <__main__.classesPaire instance at 0x10cfcad40>,
#  (u'ppFS', u'pc2S'): <__main__.classesPaire instance at 0x10ca28128>,
#  (u'ii1S', u'ppMP'): <__main__.classesPaire instance at 0x10df12758>,
#  (u'pi1P', u'pI1P'): <__main__.classesPaire instance at 0x10de20b00>,
#  (u'ppFP', u'pc3P'): <__main__.classesPaire instance at 0x10cf76680>,
#  (u'pc2P', u'pc3S'): <__main__.classesPaire instance at 0x106d88488>,
#  (u'ps2P', u'pc1S'): <__main__.classesPaire instance at 0x10de93f38>,
#  (u'fi2S', u'pi2P'): <__main__.classesPaire instance at 0x10c88c3b0>,
#  (u'fi1P', u'ai3P'): <__main__.classesPaire instance at 0x10d3068c0>,
#  (u'pi2P', u'ai1P'): <__main__.classesPaire instance at 0x10c8ee5f0>,
#  (u'pc2S', u'pi3P'): <__main__.classesPaire instance at 0x10cee6050>,
#  (u'fi2P', u'fi3S'): <__main__.classesPaire instance at 0x10dcbdc20>,
#  (u'ii2S', u'ii2P'): <__main__.classesPaire instance at 0x10de87a28>,
#  (u'fi1P', u'pP'): <__main__.classesPaire instance at 0x10dcbd4d0>,
#  (u'pc2S', u'ps3P'): <__main__.classesPaire instance at 0x10df556c8>,
#  (u'is1S', u'pc1S'): <__main__.classesPaire instance at 0x10e150a28>,
#  (u'fi3S', u'fi1P'): <__main__.classesPaire instance at 0x106db2b00>,
#  (u'FS', u'ai3P'): <__main__.classesPaire instance at 0x10dfbf7a0>,
#  (u'pI2S', u'pi2P'): <__main__.classesPaire instance at 0x10cee6950>,
#  (u'ii2S', u'pP'): <__main__.classesPaire instance at 0x10d9a6518>,
#  (u'is2P', u'is3S'): <__main__.classesPaire instance at 0x10dea3ab8>,
#  (u'pc1S', u'ppMS'): <__main__.classesPaire instance at 0x10cee61b8>,
#  (u'fi3S', u'is2S'): <__main__.classesPaire instance at 0x10b74a098>,
#  (u'pI2S', u'ppMS'): <__main__.classesPaire instance at 0x10c8ecc68>,
#  (u'ppFP', u'pc2P'): <__main__.classesPaire instance at 0x10ca3d170>,
#  (u'ii3P', u'pi3P'): <__main__.classesPaire instance at 0x10db853f8>,
#  (u'pc1S', u'ps3P'): <__main__.classesPaire instance at 0x10dff0758>,
#  (u'pc3P', u'ps2P'): <__main__.classesPaire instance at 0x10e171998>,
#  (u'ai3S', u'ai3S'): <__main__.classesPaire instance at 0x10ded85f0>,
#  (u'ps1P', u'fi3S'): <__main__.classesPaire instance at 0x10cfcdcb0>,
#  (u'ps1S', u'ppMP'): <__main__.classesPaire instance at 0x10af0def0>,
#  (u'is3P', u'ps1P'): <__main__.classesPaire instance at 0x10df50830>,
#  (u'pi3S', u'pi1P'): <__main__.classesPaire instance at 0x10b6acb90>,
#  (u'FS', u'ps1P'): <__main__.classesPaire instance at 0x10d9f9248>,
#  (u'ai2P', u'pc1S'): <__main__.classesPaire instance at 0x10c8ee9e0>,
#  (u'fi2S', u'ai2S'): <__main__.classesPaire instance at 0x10cf52a70>,
#  (u'pi3S', u'FS'): <__main__.classesPaire instance at 0x10cffcdd0>,
#  (u'ps3S', u'ii2S'): <__main__.classesPaire instance at 0x10db85170>,
#  (u'inf', u'ps1S'): <__main__.classesPaire instance at 0x10db6f5a8>,
#  (u'pc2S', u'ai1P'): <__main__.classesPaire instance at 0x10c822dd0>,
#  (u'ps2S', u'fi3P'): <__main__.classesPaire instance at 0x10cfd57e8>,
#  (u'fi3S', u'ppFP'): <__main__.classesPaire instance at 0x109a31b48>,
#  (u'ppMP', u'ai2P'): <__main__.classesPaire instance at 0x10c8eec20>,
#  (u'pI2P', u'ai3P'): <__main__.classesPaire instance at 0x10d988488>,
#  (u'pi1S', u'ii3S'): <__main__.classesPaire instance at 0x10e1500e0>,
#  (u'FP', u'ii3S'): <__main__.classesPaire instance at 0x10df0a0e0>,
#  (u'ps3P', u'FS'): <__main__.classesPaire instance at 0x10dcba098>,
#  (u'ai3P', u'ii2S'): <__main__.classesPaire instance at 0x10bc4dea8>,
#  (u'fi2P', u'FP'): <__main__.classesPaire instance at 0x10cfd53b0>,
#  (u'pi3S', u'fi3S'): <__main__.classesPaire instance at 0x10cfd5998>,
#  (u'pI2P', u'pc1P'): <__main__.classesPaire instance at 0x106d7dd40>,
#  (u'is3S', u'ppFP'): <__main__.classesPaire instance at 0x109a27bd8>,
#  (u'fi3P', u'pi3P'): <__main__.classesPaire instance at 0x10d9f1b00>,
#  (u'is2P', u'pI2P'): <__main__.classesPaire instance at 0x106d918c0>,
#  (u'is2S', u'inf'): <__main__.classesPaire instance at 0x10ccfda28>,
#  (u'fi2P', u'pI2S'): <__main__.classesPaire instance at 0x10b88c758>,
#  (u'is3P', u'pc1S'): <__main__.classesPaire instance at 0x10d121c68>,
#  (u'pI1P', u'ii3P'): <__main__.classesPaire instance at 0x10db7cb90>,
#  (u'is1S', u'FP'): <__main__.classesPaire instance at 0x10df50c20>,
#  (u'ai1P', u'ppFP'): <__main__.classesPaire instance at 0x10cf52a28>,
#  (u'is1S', u'ps2S'): <__main__.classesPaire instance at 0x106d91c68>,
#  (u'ai2P', u'ps1P'): <__main__.classesPaire instance at 0x10c8ee998>,
#  (u'is1S', u'ppFS'): <__main__.classesPaire instance at 0x10bea3b48>,
#  (u'ppMP', u'ii1S'): <__main__.classesPaire instance at 0x10df12638>,
#  (u'FP', u'ai2P'): <__main__.classesPaire instance at 0x10cfca7a0>,
#  (u'ii1P', u'ps2S'): <__main__.classesPaire instance at 0x10969f680>,
#  (u'ai3S', u'pc1S'): <__main__.classesPaire instance at 0x105b6acf8>,
#  (u'pc2S', u'pi1S'): <__main__.classesPaire instance at 0x10e150908>,
#  (u'ii1S', u'ai2S'): <__main__.classesPaire instance at 0x10db4b638>,
#  (u'ppFS', u'ppFS'): <__main__.classesPaire instance at 0x10c8ca950>,
#  (u'fi1P', u'FS'): <__main__.classesPaire instance at 0x10cfd41b8>,
#  (u'ii2S', u'pc1S'): <__main__.classesPaire instance at 0x10d368d40>,
#  (u'pi2P', u'fi3S'): <__main__.classesPaire instance at 0x10d9d16c8>,
#  (u'ii3S', u'ai1P'): <__main__.classesPaire instance at 0x10b68c9e0>,
#  (u'pc2S', u'ii2S'): <__main__.classesPaire instance at 0x10defe560>,
#  (u'pi1P', u'fi2S'): <__main__.classesPaire instance at 0x10969f1b8>,
#  (u'is1P', u'is2S'): <__main__.classesPaire instance at 0x10d37eb90>,
#  (u'fi2P', u'ai1P'): <__main__.classesPaire instance at 0x10b864710>,
#  (u'ii2S', u'is2S'): <__main__.classesPaire instance at 0x10e1102d8>,
#  (u'inf', u'fi3P'): <__main__.classesPaire instance at 0x10df15908>,
#  (u'FS', u'pc1P'): <__main__.classesPaire instance at 0x106d895f0>,
#  (u'pI2S', u'is2P'): <__main__.classesPaire instance at 0x10dea3d88>,
#  (u'is3S', u'ps2S'): <__main__.classesPaire instance at 0x109a27488>,
#  (u'is1S', u'ii3S'): <__main__.classesPaire instance at 0x10defefc8>,
#  (u'pi3S', u'is1S'): <__main__.classesPaire instance at 0x10de87ea8>,
#  (u'ii2P', u'pc2S'): <__main__.classesPaire instance at 0x10dbf7cf8>,
#  (u'pI1P', u'ppFP'): <__main__.classesPaire instance at 0x10db851b8>,
#  (u'ps1S', u'ii1P'): <__main__.classesPaire instance at 0x10de82cf8>,
#  (u'fi1P', u'pc1P'): <__main__.classesPaire instance at 0x103446170>,
#  (u'pI2S', u'ai2P'): <__main__.classesPaire instance at 0x10becc7a0>,
#  (u'pi3P', u'ps1S'): <__main__.classesPaire instance at 0x106d67200>,
#  (u'pi3P', u'ppMS'): <__main__.classesPaire instance at 0x10c8ec5a8>,
#  (u'ii2P', u'is1P'): <__main__.classesPaire instance at 0x10b5e42d8>,
#  (u'ps3S', u'inf'): <__main__.classesPaire instance at 0x10c8f45a8>,
#  (u'is2P', u'fi1P'): <__main__.classesPaire instance at 0x10dca30e0>,
#  (u'fi2P', u'pi1S'): <__main__.classesPaire instance at 0x10de3e3f8>,
#  (u'ps1P', u'is1S'): <__main__.classesPaire instance at 0x10dc5b170>,
#  (u'is2S', u'ps3S'): <__main__.classesPaire instance at 0x10ca3d3f8>,
#  (u'pI1P', u'pc1S'): <__main__.classesPaire instance at 0x10dc5bab8>,
#  (u'ppFP', u'is2S'): <__main__.classesPaire instance at 0x10b773878>,
#  (u'fi3P', u'pc1S'): <__main__.classesPaire instance at 0x10de06248>,
#  (u'ps1S', u'ai2S'): <__main__.classesPaire instance at 0x10ceed9e0>,
#  (u'pi2S', u'pc2S'): <__main__.classesPaire instance at 0x10dfccef0>,
#  (u'is2S', u'pi2S'): <__main__.classesPaire instance at 0x10b773c20>,
#  (u'fi3P', u'ai2P'): <__main__.classesPaire instance at 0x10becc0e0>,
#  (u'is3S', u'pI2S'): <__main__.classesPaire instance at 0x10de60950>,
#  (u'ai2P', u'ai2S'): <__main__.classesPaire instance at 0x10d325248>,
#  (u'fi1P', u'FP'): <__main__.classesPaire instance at 0x10ba6b170>,
#  (u'pi2P', u'pI2P'): <__main__.classesPaire instance at 0x10de20248>,
#  (u'inf', u'pc1S'): <__main__.classesPaire instance at 0x10d9ede18>,
#  (u'pc3S', u'inf'): <__main__.classesPaire instance at 0x10d9f27a0>,
#  (u'ai3P', u'ai3S'): <__main__.classesPaire instance at 0x10ded7878>,
#  (u'ai1S', u'ai2S'): <__main__.classesPaire instance at 0x10ad6ee60>,
#  (u'ai3P', u'pI1P'): <__main__.classesPaire instance at 0x10add3d40>,
#  (u'is2P', u'ppMP'): <__main__.classesPaire instance at 0x10ccfd098>,
#  (u'pP', u'pc3P'): <__main__.classesPaire instance at 0x10de20440>,
#  (u'pc2P', u'ps1S'): <__main__.classesPaire instance at 0x10e110908>,
#  (u'fi1P', u'ai2S'): <__main__.classesPaire instance at 0x10beccb48>,
#  (u'pc1P', u'ai3S'): <__main__.classesPaire instance at 0x10e156560>,
#  (u'ps3S', u'ii1S'): <__main__.classesPaire instance at 0x10dbf7050>,
#  (u'is2P', u'ps3S'): <__main__.classesPaire instance at 0x10dfaf9e0>,
#  (u'ps3P', u'ii1S'): <__main__.classesPaire instance at 0x10db817e8>,
#  (u'ppMS', u'is3P'): <__main__.classesPaire instance at 0x10e171050>,
#  (u'ii3S', u'is1S'): <__main__.classesPaire instance at 0x10defe830>,
#  (u'inf', u'ppMS'): <__main__.classesPaire instance at 0x106d915f0>,
#  (u'ppMS', u'ai2S'): <__main__.classesPaire instance at 0x10dfbf290>,
#  (u'pc2S', u'is2P'): <__main__.classesPaire instance at 0x10dc63c68>,
#  (u'ai2P', u'ai3P'): <__main__.classesPaire instance at 0x106da5d88>,
#  (u'pi3P', u'ps2P'): <__main__.classesPaire instance at 0x10bc8f3f8>,
#  (u'ii3S', u'ps3S'): <__main__.classesPaire instance at 0x10e1109e0>,
#  (u'pc1S', u'ppFS'): <__main__.classesPaire instance at 0x10dea3290>,
#  (u'pi2P', u'pc3S'): <__main__.classesPaire instance at 0x10de34290>,
#  (u'is3P', u'pc2S'): <__main__.classesPaire instance at 0x10b6cd440>,
#  (u'fi3P', u'ppFS'): <__main__.classesPaire instance at 0x10c8d2ef0>,
#  (u'ii2S', u'pi1S'): <__main__.classesPaire instance at 0x10d151128>,
#  (u'is2S', u'pc3S'): <__main__.classesPaire instance at 0x10d17c2d8>,
#  (u'ii2S', u'ai2P'): <__main__.classesPaire instance at 0x10d325170>,
#  (u'pP', u'ps1S'): <__main__.classesPaire instance at 0x10ceac950>,
#  (u'pc3P', u'pc2P'): <__main__.classesPaire instance at 0x106d881b8>,
#  (u'fi3P', u'pi2S'): <__main__.classesPaire instance at 0x10d175290>,
#  (u'ps1P', u'ii3P'): <__main__.classesPaire instance at 0x10d151ef0>,
#  (u'ps1S', u'ai1P'): <__main__.classesPaire instance at 0x10e127f38>,
#  (u'is2S', u'ai1P'): <__main__.classesPaire instance at 0x10cfca638>,
#  (u'FP', u'ii1S'): <__main__.classesPaire instance at 0x10de16cb0>,
#  (u'ai1P', u'fi2P'): <__main__.classesPaire instance at 0x10b864f80>,
#  (u'pc1S', u'pi2S'): <__main__.classesPaire instance at 0x10df55128>,
#  (u'ps2S', u'fi1P'): <__main__.classesPaire instance at 0x10c8c9680>,
#  (u'ii1P', u'ai3P'): <__main__.classesPaire instance at 0x10af50440>,
#  (u'pI2P', u'ai1P'): <__main__.classesPaire instance at 0x10b864368>,
#  (u'fi2S', u'ai3P'): <__main__.classesPaire instance at 0x10ded8cf8>,
#  (u'ii2S', u'ii1S'): <__main__.classesPaire instance at 0x10db81878>,
#  (u'ai1P', u'FS'): <__main__.classesPaire instance at 0x10db4b2d8>,
#  (u'ps3S', u'is2S'): <__main__.classesPaire instance at 0x10ca3d710>,
#  (u'pI2P', u'pc3P'): <__main__.classesPaire instance at 0x10de93dd0>,
#  (u'pc3S', u'ai1S'): <__main__.classesPaire instance at 0x10d1649e0>,
#  (u'ai2P', u'ps2P'): <__main__.classesPaire instance at 0x10ce661b8>,
#  (u'pc1P', u'ii2S'): <__main__.classesPaire instance at 0x106d7ee60>,
#  (u'pc1P', u'ii3P'): <__main__.classesPaire instance at 0x10de875a8>,
#  (u'pi1P', u'ai2S'): <__main__.classesPaire instance at 0x10dc2d2d8>,
#  (u'pi1S', u'ii2P'): <__main__.classesPaire instance at 0x10cab6fc8>,
#  (u'ppFS', u'ii3S'): <__main__.classesPaire instance at 0x10df0a680>,
#  (u'fi3P', u'ps3P'): <__main__.classesPaire instance at 0x10df98a28>,
#  (u'ps3P', u'ps1S'): <__main__.classesPaire instance at 0x10def3ef0>,
#  (u'ppMP', u'pc1S'): <__main__.classesPaire instance at 0x10de20fc8>,
#  (u'ppFS', u'fi1P'): <__main__.classesPaire instance at 0x10dcbdf80>,
#  (u'ps2S', u'ppFS'): <__main__.classesPaire instance at 0x10cf76b90>,
#  (u'is1S', u'pc2S'): <__main__.classesPaire instance at 0x10ded8830>,
#  (u'ppFP', u'ppMP'): <__main__.classesPaire instance at 0x10dbd6950>,
#  (u'ps3S', u'fi2S'): <__main__.classesPaire instance at 0x10df98758>,
#  (u'fi1S', u'is2P'): <__main__.classesPaire instance at 0x10c88c950>,
#  (u'ii3S', u'inf'): <__main__.classesPaire instance at 0x10d121248>,
#  (u'fi3P', u'ppMS'): <__main__.classesPaire instance at 0x10de162d8>,
#  (u'ps2P', u'is3P'): <__main__.classesPaire instance at 0x10de201b8>,
#  (u'FP', u'pc3S'): <__main__.classesPaire instance at 0x106d893b0>,
#  (u'ps2P', u'ps1P'): <__main__.classesPaire instance at 0x10cee9f80>,
#  (u'pP', u'ps2P'): <__main__.classesPaire instance at 0x106d84c68>,
#  (u'ii1S', u'ai3P'): <__main__.classesPaire instance at 0x10af50878>,
#  (u'fi3S', u'pi2S'): <__main__.classesPaire instance at 0x10dfc5a70>,
#  (u'is1P', u'ai1P'): <__main__.classesPaire instance at 0x10b88c290>,
#  (u'is1P', u'ppFS'): <__main__.classesPaire instance at 0x10b6cd170>,
#  (u'pc3S', u'FS'): <__main__.classesPaire instance at 0x10cf7d908>,
#  (u'is2P', u'ai2S'): <__main__.classesPaire instance at 0x10d9aad88>,
#  (u'pc3P', u'fi3P'): <__main__.classesPaire instance at 0x10d9f2950>,
#  (u'fi1P', u'ppMP'): <__main__.classesPaire instance at 0x10def6f80>,
#  (u'ps1S', u'ps3S'): <__main__.classesPaire instance at 0x10e119a28>,
#  (u'fi3P', u'pI2P'): <__main__.classesPaire instance at 0x10d30d830>,
#  (u'pI1P', u'ai2P'): <__main__.classesPaire instance at 0x10caeefc8>,
#  (u'pi1S', u'pc2S'): <__main__.classesPaire instance at 0x10e1507e8>,
#  (u'pi2P', u'pi3S'): <__main__.classesPaire instance at 0x10de206c8>,
#  (u'ii1P', u'pc2P'): <__main__.classesPaire instance at 0x10cfc29e0>,
#  (u'ii1P', u'ii3S'): <__main__.classesPaire instance at 0x10cfc2098>,
#  (u'ppFP', u'pI2S'): <__main__.classesPaire instance at 0x10dc63a70>,
#  (u'pP', u'fi2P'): <__main__.classesPaire instance at 0x10dbba878>,
#  (u'ai3S', u'pi3P'): <__main__.classesPaire instance at 0x10becc560>,
#  (u'pi2P', u'is1S'): <__main__.classesPaire instance at 0x10b6cdf38>,
#  (u'fi2S', u'pI2P'): <__main__.classesPaire instance at 0x10d9a6098>,
#  (u'pc1P', u'ai2S'): <__main__.classesPaire instance at 0x10d35e5a8>,
#  (u'pi1P', u'pc3P'): <__main__.classesPaire instance at 0x1096a36c8>,
#  (u'ai1S', u'ii3P'): <__main__.classesPaire instance at 0x10cfcabd8>,
#  (u'ppMS', u'ppMP'): <__main__.classesPaire instance at 0x10bc8fa28>,
#  (u'ps3S', u'FS'): <__main__.classesPaire instance at 0x10de97e18>,
#  (u'is2S', u'ppFP'): <__main__.classesPaire instance at 0x10b7733f8>,
#  (u'pc1S', u'pI1P'): <__main__.classesPaire instance at 0x10c8f4cb0>,
#  (u'pi2P', u'ppFP'): <__main__.classesPaire instance at 0x10ca28200>,
#  (u'pP', u'ps1P'): <__main__.classesPaire instance at 0x10dfccbd8>,
#  (u'is1P', u'pi1S'): <__main__.classesPaire instance at 0x10d9c50e0>,
#  (u'ai2P', u'pc3S'): <__main__.classesPaire instance at 0x10add32d8>,
#  (u'fi3P', u'ai1S'): <__main__.classesPaire instance at 0x10cfca248>,
#  (u'ii2S', u'ppMS'): <__main__.classesPaire instance at 0x10ce18ab8>,
#  (u'pi3P', u'ii1S'): <__main__.classesPaire instance at 0x10dc63f80>,
#  (u'is2P', u'is2S'): <__main__.classesPaire instance at 0x10df12dd0>,
#  (u'ai1P', u'pP'): <__main__.classesPaire instance at 0x10b68c0e0>,
#  (u'ii2P', u'fi1P'): <__main__.classesPaire instance at 0x106da5488>,
#  (u'pI1P', u'ps3S'): <__main__.classesPaire instance at 0x10643ed88>,
#  (u'ai1S', u'fi3P'): <__main__.classesPaire instance at 0x10cfcae18>,
#  (u'ps1P', u'ai2P'): <__main__.classesPaire instance at 0x10c8eeb00>,
#  (u'ii3P', u'fi3P'): <__main__.classesPaire instance at 0x10def6a28>,
#  (u'pi2P', u'inf'): <__main__.classesPaire instance at 0x10dfaf5f0>,
#  (u'ii2S', u'fi2S'): <__main__.classesPaire instance at 0x10cfd4c68>,
#  (u'FP', u'FS'): <__main__.classesPaire instance at 0x10cad6830>,
#  (u'fi1S', u'ai3S'): <__main__.classesPaire instance at 0x10af501b8>,
#  (u'fi3P', u'ii1S'): <__main__.classesPaire instance at 0x10dbf7ef0>,
#  (u'is1P', u'ai2P'): <__main__.classesPaire instance at 0x10b88ccb0>,
#  (u'inf', u'ps3P'): <__main__.classesPaire instance at 0x1096dea70>,
#  (u'is1S', u'pi2P'): <__main__.classesPaire instance at 0x10b6cdd88>,
#  (u'ps1S', u'ii2S'): <__main__.classesPaire instance at 0x10dc4ed88>,
#  (u'pi2S', u'ppMP'): <__main__.classesPaire instance at 0x10ba7c7a0>,
#  (u'pi3P', u'ii3S'): <__main__.classesPaire instance at 0x10defeb48>,
#  (u'ii3S', u'pc2P'): <__main__.classesPaire instance at 0x10b5e4098>,
#  (u'ai2P', u'ppMS'): <__main__.classesPaire instance at 0x10c8ee1b8>,
#  (u'fi2S', u'fi1P'): <__main__.classesPaire instance at 0x10dbba3f8>,
#  (u'fi1P', u'fi2P'): <__main__.classesPaire instance at 0x106dbe4d0>,
#  (u'ii2S', u'ppFS'): <__main__.classesPaire instance at 0x10d9f2c68>,
#  (u'fi1S', u'ppMS'): <__main__.classesPaire instance at 0x10de60f38>,
#  (u'ai2S', u'fi2S'): <__main__.classesPaire instance at 0x10bc662d8>,
#  (u'is2P', u'pi2P'): <__main__.classesPaire instance at 0x10df50680>,
#  (u'pc2S', u'pc1S'): <__main__.classesPaire instance at 0x10ba7c950>,
#  (u'pc3S', u'pc3S'): <__main__.classesPaire instance at 0x10b6ac560>,
#  (u'pi1P', u'is2S'): <__main__.classesPaire instance at 0x10d17c518>,
#  (u'fi3P', u'inf'): <__main__.classesPaire instance at 0x10d3681b8>,
#  (u'ppMS', u'ii1P'): <__main__.classesPaire instance at 0x10cfcdf80>,
#  (u'ai2S', u'ai3S'): <__main__.classesPaire instance at 0x10becc440>,
#  (u'pI2S', u'pc1S'): <__main__.classesPaire instance at 0x10dec0518>,
#  (u'ii1P', u'pc3S'): <__main__.classesPaire instance at 0x10dbd3710>,
#  (u'pi3S', u'ps3S'): <__main__.classesPaire instance at 0x1097574d0>,
#  (u'pI1P', u'ppMS'): <__main__.classesPaire instance at 0x10cffc878>,
#  (u'fi2P', u'ai3S'): <__main__.classesPaire instance at 0x10d123e18>,
#  (u'pc1P', u'pP'): <__main__.classesPaire instance at 0x10dbd0f80>,
#  (u'fi1S', u'ai2S'): <__main__.classesPaire instance at 0x10cfd4e60>,
#  (u'fi2P', u'fi2S'): <__main__.classesPaire instance at 0x10c8c9098>,
#  (u'pI1P', u'FS'): <__main__.classesPaire instance at 0x10d1b04d0>,
#  (u'fi2S', u'fi2P'): <__main__.classesPaire instance at 0x10c8c9560>,
#  (u'is3S', u'ai3P'): <__main__.classesPaire instance at 0x10add3d88>,
#  (u'is2S', u'fi2P'): <__main__.classesPaire instance at 0x10c88cdd0>,
#  (u'pI1P', u'ps2P'): <__main__.classesPaire instance at 0x10dfaf560>,
#  (u'ii1P', u'ai2S'): <__main__.classesPaire instance at 0x10623b0e0>,
#  (u'ppMP', u'FP'): <__main__.classesPaire instance at 0x10ca28cf8>,
#  (u'ai1S', u'ppMS'): <__main__.classesPaire instance at 0x10ce26518>,
#  (u'is2S', u'ai3P'): <__main__.classesPaire instance at 0x10e156dd0>,
#  (u'ps3S', u'pc3S'): <__main__.classesPaire instance at 0x10dbd04d0>,
#  (u'fi2P', u'ppFP'): <__main__.classesPaire instance at 0x10ce18290>,
#  (u'is3S', u'pP'): <__main__.classesPaire instance at 0x10df553f8>,
#  (u'ps2P', u'ppMS'): <__main__.classesPaire instance at 0x106d67b90>,
#  (u'ps2S', u'ps2S'): <__main__.classesPaire instance at 0x10af0d878>,
#  (u'fi2P', u'is2P'): <__main__.classesPaire instance at 0x10ce18998>,
#  (u'ii2P', u'ai1P'): <__main__.classesPaire instance at 0x10d325440>,
#  (u'pi3S', u'pc2S'): <__main__.classesPaire instance at 0x10e119758>,
#  (u'is1S', u'pc3P'): <__main__.classesPaire instance at 0x10e150440>,
#  (u'pi1P', u'ppFP'): <__main__.classesPaire instance at 0x1096a3710>,
#  (u'ii1P', u'ii1P'): <__main__.classesPaire instance at 0x10db81440>,
#  (u'ai1P', u'pI2S'): <__main__.classesPaire instance at 0x10db4b5a8>,
#  (u'ai3P', u'is3P'): <__main__.classesPaire instance at 0x10e156cb0>,
#  (u'FS', u'pP'): <__main__.classesPaire instance at 0x10c8ec170>,
#  (u'ai3P', u'ps1P'): <__main__.classesPaire instance at 0x10bbcb560>,
#  (u'FP', u'pc1S'): <__main__.classesPaire instance at 0x10e119680>,
#  (u'ii3S', u'pi2S'): <__main__.classesPaire instance at 0x106dafa28>,
#  (u'pI2S', u'ps1S'): <__main__.classesPaire instance at 0x10d1b0a28>,
#  (u'pc2S', u'fi2S'): <__main__.classesPaire instance at 0x10d9a6e60>,
#  (u'is2P', u'ps1S'): <__main__.classesPaire instance at 0x10ccfd5f0>,
#  (u'is3P', u'ai1P'): <__main__.classesPaire instance at 0x10cfca1b8>,
#  (u'pi3P', u'pI2P'): <__main__.classesPaire instance at 0x10dbd6bd8>,
#  (u'pi3P', u'ps3S'): <__main__.classesPaire instance at 0x106d7a128>,
#  (u'is2P', u'ai3P'): <__main__.classesPaire instance at 0x10cfd4f38>,
#  (u'FP', u'fi3P'): <__main__.classesPaire instance at 0x10ce18cf8>,
#  (u'pi2S', u'fi1P'): <__main__.classesPaire instance at 0x10b5c1518>,
#  (u'ps1S', u'ii2P'): <__main__.classesPaire instance at 0x10cfd58c0>,
#  (u'pi2P', u'pi2P'): <__main__.classesPaire instance at 0x10df50320>,
#  (u'ii1P', u'ii2P'): <__main__.classesPaire instance at 0x10cfc2ea8>,
#  (u'pc1S', u'is3S'): <__main__.classesPaire instance at 0x10d37e758>,
#  (u'pc2P', u'ai1S'): <__main__.classesPaire instance at 0x10add3e60>,
#  (u'is2S', u'pc2P'): <__main__.classesPaire instance at 0x10d17c320>,
#  (u'fi1P', u'pI2P'): <__main__.classesPaire instance at 0x10dfc5cb0>,
#  (u'fi2S', u'pi3P'): <__main__.classesPaire instance at 0x10969f170>,
#  (u'is3P', u'pi1S'): <__main__.classesPaire instance at 0x10dfaf8c0>,
#  (u'ps2P', u'pI2P'): <__main__.classesPaire instance at 0x10df15488>,
#  (u'pc2S', u'fi1S'): <__main__.classesPaire instance at 0x10b88cb48>,
#  (u'fi2S', u'pc2P'): <__main__.classesPaire instance at 0x10d30db00>,
#  (u'pc1P', u'ai1P'): <__main__.classesPaire instance at 0x10b864488>,
#  (u'fi2S', u'is3S'): <__main__.classesPaire instance at 0x10def6fc8>,
#  (u'is2S', u'ai3S'): <__main__.classesPaire instance at 0x10de06b00>,
#  (u'ps2S', u'pi1S'): <__main__.classesPaire instance at 0x106d843f8>,
#  (u'fi2S', u'ps1S'): <__main__.classesPaire instance at 0x10e144d40>,
#  (u'ps2P', u'ii1S'): <__main__.classesPaire instance at 0x10dc4e098>,
#  (u'pc2P', u'ii3S'): <__main__.classesPaire instance at 0x10cfcdc20>,
#  (u'is3S', u'FS'): <__main__.classesPaire instance at 0x10de34128>,
#  (u'ppMP', u'pc3S'): <__main__.classesPaire instance at 0x10ca93440>,
#  (u'ai1S', u'fi1P'): <__main__.classesPaire instance at 0x10ccdf170>,
#  (u'ppMS', u'pI2P'): <__main__.classesPaire instance at 0x10c8f4d88>,
#  (u'ii3S', u'ps1P'): <__main__.classesPaire instance at 0x10d1215a8>,
#  (u'is1S', u'inf'): <__main__.classesPaire instance at 0x10dcbef38>,
#  (u'is2S', u'pi2P'): <__main__.classesPaire instance at 0x10b773758>,
#  (u'ps1P', u'pc3S'): <__main__.classesPaire instance at 0x10ca93050>,
#  (u'pi3P', u'is3S'): <__main__.classesPaire instance at 0x10d1b0cb0>,
#  (u'pI1P', u'is2S'): <__main__.classesPaire instance at 0x10d121d88>,
#  (u'ii1P', u'ppMP'): <__main__.classesPaire instance at 0x10c88c4d0>,
#  (u'ai2P', u'is3P'): <__main__.classesPaire instance at 0x10caee050>,
#  (u'pc1P', u'is2P'): <__main__.classesPaire instance at 0x10ca47440>,
#  (u'ii3P', u'ii2S'): <__main__.classesPaire instance at 0x10defe5a8>,
#  (u'ai1P', u'pI1P'): <__main__.classesPaire instance at 0x10cfcae60>,
#  (u'is1S', u'is1P'): <__main__.classesPaire instance at 0x10d9c5908>,
#  (u'ps2P', u'ai2P'): <__main__.classesPaire instance at 0x10ce664d0>,
#  (u'pi2S', u'pc3P'): <__main__.classesPaire instance at 0x10e171b00>,
#  (u'pi2S', u'ps1P'): <__main__.classesPaire instance at 0x10af0d9e0>,
#  (u'ps1P', u'ppMS'): <__main__.classesPaire instance at 0x10bc8fe18>,
#  (u'ps1S', u'pc2S'): <__main__.classesPaire instance at 0x106d7e4d0>,
#  (u'ppFS', u'pc1S'): <__main__.classesPaire instance at 0x10de34050>,
#  (u'pI2P', u'fi1P'): <__main__.classesPaire instance at 0x10dfc5f38>,
#  (u'ai3P', u'is2S'): <__main__.classesPaire instance at 0x10e1566c8>,
#  (u'ppMP', u'ai3P'): <__main__.classesPaire instance at 0x10ceed050>,
#  (u'pi2P', u'ai3P'): <__main__.classesPaire instance at 0x10dbba440>,
#  (u'is3S', u'ai1S'): <__main__.classesPaire instance at 0x10add3320>,
#  (u'ii2S', u'ps2S'): <__main__.classesPaire instance at 0x10d121440>,
#  (u'pc2P', u'ps2S'): <__main__.classesPaire instance at 0x10cf7d5a8>,
#  (u'pc2S', u'pI2S'): <__main__.classesPaire instance at 0x10c8eccb0>,
#  (u'pI2S', u'is1S'): <__main__.classesPaire instance at 0x10d37ec68>,
#  (u'pc3S', u'ppFP'): <__main__.classesPaire instance at 0x10ca93f38>,
#  (u'ai1P', u'pi3P'): <__main__.classesPaire instance at 0x1053906c8>,
#  (u'fi1S', u'ppFS'): <__main__.classesPaire instance at 0x10d1c77e8>,
#  (u'ppMS', u'ps2P'): <__main__.classesPaire instance at 0x10dbd0488>,
#  (u'ii1P', u'pI1P'): <__main__.classesPaire instance at 0x10cfd59e0>,
#  (u'pc3P', u'is1S'): <__main__.classesPaire instance at 0x10b6cd5a8>,
#  (u'ai1P', u'pc1P'): <__main__.classesPaire instance at 0x10b864ef0>,
#  (u'ps1P', u'pc2P'): <__main__.classesPaire instance at 0x10cf7d248>,
#  (u'fi1S', u'pi1P'): <__main__.classesPaire instance at 0x106d7d4d0>,
#  (u'ai1P', u'is3S'): <__main__.classesPaire instance at 0x10b88c5f0>,
#  (u'fi2P', u'ai2P'): <__main__.classesPaire instance at 0x10b88cd40>,
#  (u'pP', u'ai1S'): <__main__.classesPaire instance at 0x1063b8908>,
#  (u'ai1S', u'ai1S'): <__main__.classesPaire instance at 0x10db4b488>,
#  (u'is1P', u'fi1P'): <__main__.classesPaire instance at 0x10cfd4878>,
#  (u'FS', u'fi1P'): <__main__.classesPaire instance at 0x1097132d8>,
#  (u'pI1P', u'ps1S'): <__main__.classesPaire instance at 0x10d9a6d88>,
#  (u'ai3S', u'ai1S'): <__main__.classesPaire instance at 0x10b88c3f8>,
#  (u'ii2P', u'pc1P'): <__main__.classesPaire instance at 0x10db6f6c8>,
#  (u'is2S', u'ai2S'): <__main__.classesPaire instance at 0x10d9aa680>,
#  (u'pI1P', u'ai3P'): <__main__.classesPaire instance at 0x10c822908>,
#  (u'ps2P', u'fi2P'): <__main__.classesPaire instance at 0x10e144998>,
#  (u'ai2P', u'ii2P'): <__main__.classesPaire instance at 0x10cf52170>,
#  (u'pc2S', u'pc2S'): <__main__.classesPaire instance at 0x10dbd0560>,
#  (u'pi3P', u'is2P'): <__main__.classesPaire instance at 0x10e110440>,
#  (u'pi2S', u'pi2S'): <__main__.classesPaire instance at 0x10ccfd3b0>,
#  (u'FP', u'is1S'): <__main__.classesPaire instance at 0x10df50638>,
#  (u'fi2S', u'ppMS'): <__main__.classesPaire instance at 0x10b5e4f80>,
#  (u'FS', u'pI1P'): <__main__.classesPaire instance at 0x10d1b0950>,
#  (u'FS', u'ai1P'): <__main__.classesPaire instance at 0x10db4b878>,
#  (u'ii1S', u'is2S'): <__main__.classesPaire instance at 0x10c8f4200>,
#  (u'ai1S', u'pi1P'): <__main__.classesPaire instance at 0x10db37e60>,
#  (u'ai3P', u'inf'): <__main__.classesPaire instance at 0x10d9aaea8>,
#  (u'ai3S', u'pi1P'): <__main__.classesPaire instance at 0x10b68cb00>,
#  (u'ai2S', u'pi3S'): <__main__.classesPaire instance at 0x10d35e1b8>,
#  (u'is1S', u'ps1P'): <__main__.classesPaire instance at 0x10dc5bc68>,
#  (u'is1P', u'fi3S'): <__main__.classesPaire instance at 0x10cab6d88>,
#  (u'is1S', u'is3P'): <__main__.classesPaire instance at 0x109a282d8>,
#  (u'ai2P', u'ppFP'): <__main__.classesPaire instance at 0x10bc665f0>,
#  (u'fi2S', u'FS'): <__main__.classesPaire instance at 0x106dc2cb0>,
#  (u'pc1S', u'fi2S'): <__main__.classesPaire instance at 0x10d30d680>,
#  (u'ppFS', u'pc2P'): <__main__.classesPaire instance at 0x10b5db488>,
#  (u'fi3P', u'is2S'): <__main__.classesPaire instance at 0x10de169e0>,
#  (u'pi3P', u'FP'): <__main__.classesPaire instance at 0x10d37e830>,
#  (u'pi1P', u'inf'): <__main__.classesPaire instance at 0x10ca47830>,
#  (u'ii3P', u'is2S'): <__main__.classesPaire instance at 0x10b85c8c0>,
#  (u'fi2P', u'ii3P'): <__main__.classesPaire instance at 0x10de3eb90>,
#  (u'ii1S', u'ppMS'): <__main__.classesPaire instance at 0x10cfcdef0>,
#  (u'ai1S', u'ps3P'): <__main__.classesPaire instance at 0x1096c4830>,
#  (u'pc3P', u'ai1P'): <__main__.classesPaire instance at 0x10c822098>,
#  (u'fi2S', u'pi2S'): <__main__.classesPaire instance at 0x10b5e4710>,
#  (u'fi3S', u'inf'): <__main__.classesPaire instance at 0x10d9f2bd8>,
#  (u'fi2P', u'ps3P'): <__main__.classesPaire instance at 0x10d1759e0>,
#  (u'ps3S', u'pi2S'): <__main__.classesPaire instance at 0x10cf7db00>,
#  (u'ii1P', u'ps1S'): <__main__.classesPaire instance at 0x10de82f80>,
#  (u'ii2S', u'ps3P'): <__main__.classesPaire instance at 0x10df0a050>,
#  (u'ii1P', u'is3S'): <__main__.classesPaire instance at 0x10db85ab8>,
#  (u'ii2S', u'ii2S'): <__main__.classesPaire instance at 0x106d7e950>,
#  (u'fi2P', u'fi1P'): <__main__.classesPaire instance at 0x10dbba368>,
#  (u'ps3P', u'pc3S'): <__main__.classesPaire instance at 0x10ca93ef0>,
#  (u'pc1S', u'ai1S'): <__main__.classesPaire instance at 0x10db37248>,
#  (u'pc1S', u'ppMP'): <__main__.classesPaire instance at 0x10e119200>,
#  (u'ai3P', u'pc2P'): <__main__.classesPaire instance at 0x10bbfd6c8>,
#  (u'fi1S', u'ii2P'): <__main__.classesPaire instance at 0x10d368098>,
#  (u'fi2P', u'ppMS'): <__main__.classesPaire instance at 0x10d9a6368>,
#  (u'pI2P', u'ps1P'): <__main__.classesPaire instance at 0x10dff0290>,
#  (u'ai1P', u'ppMS'): <__main__.classesPaire instance at 0x10b864248>,
#  (u'pc3S', u'ii2S'): <__main__.classesPaire instance at 0x10d151b48>,
#  (u'pi1S', u'pi3S'): <__main__.classesPaire instance at 0x10cee62d8>,
#  (u'ai3P', u'ai1S'): <__main__.classesPaire instance at 0x10db2d290>,
#  (u'fi2S', u'ii1S'): <__main__.classesPaire instance at 0x1096c4cf8>,
#  (u'ppMS', u'pP'): <__main__.classesPaire instance at 0x109a33bd8>,
#  (u'pc3S', u'pi2S'): <__main__.classesPaire instance at 0x10dbd6d88>,
# ...
#  (u'is2P', u'ppMS'): <__main__.classesPaire instance at 0x10e110290>,
#  (u'is3P', u'pi2S'): <__main__.classesPaire instance at 0x10d9f2518>,
#  (u'ps3S', u'ii3P'): <__main__.classesPaire instance at 0x10b74abd8>,
#  (u'ps3S', u'ii1P'): <__main__.classesPaire instance at 0x10de60830>,
#  (u'fi3P', u'fi2S'): <__main__.classesPaire instance at 0x10cffc6c8>,
#  (u'is3S', u'ps1S'): <__main__.classesPaire instance at 0x1096ded88>,
#  (u'ii3P', u'pc2S'): <__main__.classesPaire instance at 0x10dec0998>,
#  (u'fi3S', u'ai3P'): <__main__.classesPaire instance at 0x10db188c0>,
#  (u'ppFS', u'is2P'): <__main__.classesPaire instance at 0x10ccfd680>,
#  (u'is2S', u'is3S'): <__main__.classesPaire instance at 0x10dfafa70>,
#  (u'is3S', u'ps2P'): <__main__.classesPaire instance at 0x10dec0320>,
#  (u'fi2S', u'ii3S'): <__main__.classesPaire instance at 0x10c8d2f80>,
#  (u'ps3S', u'ps3P'): <__main__.classesPaire instance at 0x10dcbab48>,
#  (u'ppMS', u'is3S'): <__main__.classesPaire instance at 0x10dcbd200>,
#  (u'pi2S', u'ii3P'): <__main__.classesPaire instance at 0x10df15128>,
#  (u'pi1S', u'ii1S'): <__main__.classesPaire instance at 0x10df982d8>,
#  (u'fi1S', u'ii3S'): <__main__.classesPaire instance at 0x10d9a6248>,
#  (u'is2P', u'pi3P'): <__main__.classesPaire instance at 0x10e110f80>,
#  (u'ii1P', u'pI2P'): <__main__.classesPaire instance at 0x10969ff80>,
#  (u'fi2P', u'ps2S'): <__main__.classesPaire instance at 0x10d368200>,
#  (u'pc3S', u'ii3P'): <__main__.classesPaire instance at 0x10dc632d8>,
#  (u'ai2S', u'ai3P'): <__main__.classesPaire instance at 0x10ad6e7a0>,
#  (u'ii2S', u'is3P'): <__main__.classesPaire instance at 0x106d9d098>,
#  (u'ii2S', u'ai2S'): <__main__.classesPaire instance at 0x10ceed368>,
#  (u'ii3P', u'ai2S'): <__main__.classesPaire instance at 0x10ceed518>,
#  (u'is2P', u'is1P'): <__main__.classesPaire instance at 0x10d37ec20>,
#  (u'inf', u'ppFS'): <__main__.classesPaire instance at 0x10dc5be60>,
#  (u'ppMP', u'is1S'): <__main__.classesPaire instance at 0x10defe1b8>,
#  (u'ii1S', u'ps2P'): <__main__.classesPaire instance at 0x10cfc2998>,
#  (u'ps1P', u'ps1P'): <__main__.classesPaire instance at 0x10c8afd88>,
#  (u'fi3P', u'fi1S'): <__main__.classesPaire instance at 0x10dc14908>,
#  (u'pI2S', u'fi3S'): <__main__.classesPaire instance at 0x10d9f1cf8>,
#  (u'ai3S', u'ps1S'): <__main__.classesPaire instance at 0x10e127b48>,
#  (u'pc1S', u'pi2P'): <__main__.classesPaire instance at 0x106d840e0>,
#  (u'ps2S', u'ai3S'): <__main__.classesPaire instance at 0x10db2d440>,
#  (u'pi3P', u'pc2P'): <__main__.classesPaire instance at 0x10e144a28>,
#  (u'fi2S', u'ai3S'): <__main__.classesPaire instance at 0x10dc2d488>,
#  (u'pi2S', u'FP'): <__main__.classesPaire instance at 0x10d31a320>,
#  (u'fi1P', u'ps2P'): <__main__.classesPaire instance at 0x10d368560>,
#  (u'pc3S', u'ai1P'): <__main__.classesPaire instance at 0x10db37998>,
#  (u'ii3S', u'is2S'): <__main__.classesPaire instance at 0x10e150368>,
#  (u'ai2P', u'ps2S'): <__main__.classesPaire instance at 0x106409830>,
#  (u'ppMS', u'ai3S'): <__main__.classesPaire instance at 0x10db37ab8>,
#  (u'pI1P', u'pI1P'): <__main__.classesPaire instance at 0x109a273f8>,
#  (u'pc1P', u'pi1S'): <__main__.classesPaire instance at 0x10cfcd518>,
#  (u'ii3S', u'ppFS'): <__main__.classesPaire instance at 0x10df0a998>,
#  (u'ps3P', u'ps1P'): <__main__.classesPaire instance at 0x10cee95f0>,
#  (u'ii3S', u'is3S'): <__main__.classesPaire instance at 0x10dc63cb0>,
#  (u'ppFP', u'ppMS'): <__main__.classesPaire instance at 0x10ca471b8>,
#  (u'ppMP', u'fi2S'): <__main__.classesPaire instance at 0x10db6fbd8>,
#  (u'is2P', u'ii1S'): <__main__.classesPaire instance at 0x10de60998>,
#  (u'ps3S', u'fi2P'): <__main__.classesPaire instance at 0x10cab6bd8>,
#  (u'ps2S', u'is2S'): <__main__.classesPaire instance at 0x10ca3d128>,
#  (u'fi1P', u'pi1S'): <__main__.classesPaire instance at 0x10b85c9e0>,
#  (u'pc3S', u'pc1S'): <__main__.classesPaire instance at 0x10ca28098>,
#  (u'ppFS', u'pc1P'): <__main__.classesPaire instance at 0x10de93d40>,
#  (u'pi1P', u'is3S'): <__main__.classesPaire instance at 0x10dbd6908>,
#  (u'ps3P', u'pi3S'): <__main__.classesPaire instance at 0x10641a368>,
#  (u'pc3S', u'ai3S'): <__main__.classesPaire instance at 0x106dbe8c0>,
#  (u'FP', u'pc3P'): <__main__.classesPaire instance at 0x105b7bef0>,
#  (u'pc1S', u'pc3S'): <__main__.classesPaire instance at 0x10dbd6290>,
#  (u'ppFS', u'pi3P'): <__main__.classesPaire instance at 0x10c8caf80>,
#  (u'ii1S', u'ai3S'): <__main__.classesPaire instance at 0x10df5f170>,
#  (u'is2P', u'ai2P'): <__main__.classesPaire instance at 0x10e156518>,
#  (u'fi3P', u'pI2S'): <__main__.classesPaire instance at 0x10c8c9a28>,
#  (u'ai3P', u'pc2S'): <__main__.classesPaire instance at 0x10de51a70>,
#  (u'ppFS', u'ii2S'): <__main__.classesPaire instance at 0x10d9f2dd0>,
#  (u'is3P', u'ps2S'): <__main__.classesPaire instance at 0x10ca3d680>,
#  (u'pi1S', u'pc2P'): <__main__.classesPaire instance at 0x10ca3d248>,
#  (u'pc3S', u'ppMP'): <__main__.classesPaire instance at 0x10e15c200>,
#  (u'fi3S', u'ai3S'): <__main__.classesPaire instance at 0x10becc998>,
#  (u'ps3P', u'pi1S'): <__main__.classesPaire instance at 0x10d138ea8>,
#  (u'fi1P', u'pi3S'): <__main__.classesPaire instance at 0x106db2b48>,
#  (u'ii3P', u'pi1S'): <__main__.classesPaire instance at 0x10de34b90>,
#  (u'pc1S', u'ps1S'): <__main__.classesPaire instance at 0x10c8c9ef0>,
#  (u'pi1S', u'is1S'): <__main__.classesPaire instance at 0x10cab6248>,
#  (u'ii1S', u'pc3P'): <__main__.classesPaire instance at 0x10c88cfc8>,
#  (u'pc1S', u'pI2S'): <__main__.classesPaire instance at 0x109a28f38>,
#  (u'fi2S', u'pI2S'): <__main__.classesPaire instance at 0x1096c7f38>,
#  (u'pi2P', u'pP'): <__main__.classesPaire instance at 0x10c8ec320>,
#  (u'is2S', u'ppFS'): <__main__.classesPaire instance at 0x10b773d88>,
#  (u'ps1S', u'fi2S'): <__main__.classesPaire instance at 0x1096c0dd0>,
#  (u'ii2S', u'pi2S'): <__main__.classesPaire instance at 0x10df150e0>,
#  (u'ai1P', u'ai3S'): <__main__.classesPaire instance at 0x109709b90>,
#  (u'ps2S', u'ai3P'): <__main__.classesPaire instance at 0x10ceeda28>,
#  (u'pc2P', u'inf'): <__main__.classesPaire instance at 0x10643e518>,
#  (u'ai2P', u'pc3P'): <__main__.classesPaire instance at 0x10add3f80>,
#  (u'pi3P', u'pc3S'): <__main__.classesPaire instance at 0x10df183f8>,
#  (u'ii2S', u'ppMP'): <__main__.classesPaire instance at 0x10cfd5fc8>,
#  (u'ai3P', u'ppFS'): <__main__.classesPaire instance at 0x10ca52200>,
#  (u'ii1P', u'fi3P'): <__main__.classesPaire instance at 0x10def65a8>,
#  (u'pI2S', u'ps1P'): <__main__.classesPaire instance at 0x10b6ac878>,
#  (u'ppMP', u'is3S'): <__main__.classesPaire instance at 0x10b6cd7a0>,
#  (u'fi2S', u'pc1P'): <__main__.classesPaire instance at 0x10d175560>,
#  (u'pi1S', u'FS'): <__main__.classesPaire instance at 0x10e15cef0>,
#  (u'ai3P', u'ppMP'): <__main__.classesPaire instance at 0x10ded8a28>,
#  (u'pi1P', u'ii3P'): <__main__.classesPaire instance at 0x10dc63440>,
#  (u'pi1P', u'ii1P'): <__main__.classesPaire instance at 0x10e144ab8>,
#  (u'is3S', u'pc2S'): <__main__.classesPaire instance at 0x10e1715f0>,
#  (u'ai1S', u'pc2S'): <__main__.classesPaire instance at 0x10ca40e18>,
#  (u'ii3P', u'ai3S'): <__main__.classesPaire instance at 0x10ded8b48>,
#  (u'ps3P', u'fi2S'): <__main__.classesPaire instance at 0x10db6f7e8>,
#  (u'fi3S', u'pc1P'): <__main__.classesPaire instance at 0x10dc4e2d8>,
#  (u'ps2S', u'pc2S'): <__main__.classesPaire instance at 0x10dfd9518>,
#  (u'pc1S', u'ps2P'): <__main__.classesPaire instance at 0x10b6cdc68>,
#  (u'ii3P', u'ps1P'): <__main__.classesPaire instance at 0x10defe710>,
#  (u'is2S', u'is1S'): <__main__.classesPaire instance at 0x10defe368>,
#  (u'pP', u'ai3S'): <__main__.classesPaire instance at 0x10ccdf560>,
#  (u'pi1S', u'ai3S'): <__main__.classesPaire instance at 0x10d3257e8>,
#  (u'is3P', u'inf'): <__main__.classesPaire instance at 0x106d7e6c8>,
#  (u'fi3S', u'pi3P'): <__main__.classesPaire instance at 0x10df98ef0>,
#  (u'is3P', u'pi3P'): <__main__.classesPaire instance at 0x10dcbe2d8>,
#  (u'ai2P', u'pi2S'): <__main__.classesPaire instance at 0x10cfd4908>,
#  (u'ii3S', u'pc2S'): <__main__.classesPaire instance at 0x10dfcc488>,
#  (u'pi1P', u'ai1P'): <__main__.classesPaire instance at 0x10db37128>,
#  (u'pc1S', u'is1S'): <__main__.classesPaire instance at 0x10e150560>,
#  (u'fi1S', u'ii1P'): <__main__.classesPaire instance at 0x10de62440>,
#  (u'ii2P', u'pI2S'): <__main__.classesPaire instance at 0x10db856c8>,
#  (u'ai1S', u'pI1P'): <__main__.classesPaire instance at 0x10ce26710>,
#  (u'pc3P', u'ai2S'): <__main__.classesPaire instance at 0x10db378c0>,
#  (u'fi1P', u'fi2S'): <__main__.classesPaire instance at 0x10dbba638>,
#  (u'ii3P', u'ppFP'): <__main__.classesPaire instance at 0x10d121098>,
#  (u'ps3S', u'pi1P'): <__main__.classesPaire instance at 0x10dff0ab8>,
#  (u'ppMP', u'pi1S'): <__main__.classesPaire instance at 0x106d89ef0>,
#  (u'pi2S', u'ii2S'): <__main__.classesPaire instance at 0x10df15fc8>,
#  (u'ii1S', u'ii2S'): <__main__.classesPaire instance at 0x10db81560>,
#  (u'is2P', u'pi2S'): <__main__.classesPaire instance at 0x10d9f1638>,
#  (u'pI2P', u'pi2S'): <__main__.classesPaire instance at 0x109a31878>,
#  (u'ps2P', u'pi3S'): <__main__.classesPaire instance at 0x109757320>,
#  (u'ps2P', u'is2P'): <__main__.classesPaire instance at 0x10ccfdd88>,
#  (u'pc2S', u'pc1P'): <__main__.classesPaire instance at 0x1096a3c68>,
#  (u'FS', u'is2P'): <__main__.classesPaire instance at 0x10d121680>,
#  (u'ppFS', u'ii3P'): <__main__.classesPaire instance at 0x10e1502d8>,
#  (u'is3P', u'ii1S'): <__main__.classesPaire instance at 0x10db85050>,
#  (u'ppMS', u'ii1S'): <__main__.classesPaire instance at 0x10cfcd998>,
#  (u'is1P', u'pi2P'): <__main__.classesPaire instance at 0x10d9ed9e0>,
#  (u'pi2S', u'is1P'): <__main__.classesPaire instance at 0x10dbf7b90>,
#  (u'fi1S', u'is3P'): <__main__.classesPaire instance at 0x10ce185f0>,
#  (u'pI2S', u'pI1P'): <__main__.classesPaire instance at 0x10ca3db48>,
#  (u'ii1S', u'is1P'): <__main__.classesPaire instance at 0x10cfc2c20>,
#  (u'is3P', u'ai1S'): <__main__.classesPaire instance at 0x10add3ab8>,
#  (u'ai3S', u'ai2S'): <__main__.classesPaire instance at 0x10becc758>,
#  (u'pc3S', u'pi1P'): <__main__.classesPaire instance at 0x10de20290>,
#  (u'fi2P', u'fi2P'): <__main__.classesPaire instance at 0x10d9f15a8>,
#  (u'pI1P', u'FP'): <__main__.classesPaire instance at 0x10643e560>,
#  (u'ps3P', u'pc2S'): <__main__.classesPaire instance at 0x10cf7d7e8>,
#  (u'ps2S', u'ps1S'): <__main__.classesPaire instance at 0x10de97710>,
#  (u'is3S', u'ai3S'): <__main__.classesPaire instance at 0x10bedd0e0>,
#  (u'ppFP', u'is3P'): <__main__.classesPaire instance at 0x109a271b8>,
#  (u'is3P', u'pi3S'): <__main__.classesPaire instance at 0x1096a3d88>,
#  (u'ppMP', u'FS'): <__main__.classesPaire instance at 0x1096f4c68>,
#  (u'is1S', u'ai2P'): <__main__.classesPaire instance at 0x10ce260e0>,
#  (u'pi3S', u'fi2S'): <__main__.classesPaire instance at 0x10d30df80>,
#  (u'pi1P', u'ppMP'): <__main__.classesPaire instance at 0x10db5e440>,
#  (u'fi2P', u'ppFS'): <__main__.classesPaire instance at 0x10dba2908>,
#  (u'fi2S', u'ps2S'): <__main__.classesPaire instance at 0x106daf098>,
#  (u'pi3P', u'ppFS'): <__main__.classesPaire instance at 0x10c8aff80>,
#  (u'pi3P', u'fi3S'): <__main__.classesPaire instance at 0x10df98fc8>,
#  (u'fi2P', u'is2S'): <__main__.classesPaire instance at 0x10d9a60e0>,
#  (u'ii2P', u'ai1S'): <__main__.classesPaire instance at 0x10ce26b90>,
#  (u'ai1S', u'ppFS'): <__main__.classesPaire instance at 0x10ad6eab8>,
#  (u'pP', u'ppFP'): <__main__.classesPaire instance at 0x10df18b00>,
#  (u'ps2P', u'inf'): <__main__.classesPaire instance at 0x106d7ecf8>,
#  (u'ii2S', u'pI2P'): <__main__.classesPaire instance at 0x10d175248>,
#  (u'pc3P', u'pP'): <__main__.classesPaire instance at 0x10de20b48>,
#  (u'pi1P', u'ps3S'): <__main__.classesPaire instance at 0x10b6cdb00>,
#  (u'ai3P', u'ps1S'): <__main__.classesPaire instance at 0x10dc4d5f0>,
#  (u'ai3P', u'pI2S'): <__main__.classesPaire instance at 0x10c8eeab8>,
#  (u'ai2P', u'pi3S'): <__main__.classesPaire instance at 0x10add3f38>,
#  (u'FP', u'ai3P'): <__main__.classesPaire instance at 0x10dfbfcb0>,
#  (u'ii2S', u'is2P'): <__main__.classesPaire instance at 0x10e110dd0>,
#  (u'ppMS', u'fi1S'): <__main__.classesPaire instance at 0x10db7cf80>,
#  (u'pP', u'pc2P'): <__main__.classesPaire instance at 0x10ca3d290>,
#  (u'pc2P', u'pi2P'): <__main__.classesPaire instance at 0x10b6ac710>,
#  (u'pc1S', u'is2S'): <__main__.classesPaire instance at 0x10d17cd40>,
#  (u'pc3S', u'ps2S'): <__main__.classesPaire instance at 0x10cc2dc20>,
#  (u'is2P', u'ps1P'): <__main__.classesPaire instance at 0x10e110d40>,
#  (u'ps1P', u'ppFS'): <__main__.classesPaire instance at 0x106d89518>,
#  (u'pi2S', u'fi3S'): <__main__.classesPaire instance at 0x10dfc5c20>,
#  (u'is2P', u'ai3S'): <__main__.classesPaire instance at 0x10bc66908>,
#  (u'inf', u'fi2P'): <__main__.classesPaire instance at 0x10d9a6e18>,
#  (u'fi1S', u'ii1S'): <__main__.classesPaire instance at 0x105b26248>,
#  (u'is1P', u'ps2S'): <__main__.classesPaire instance at 0x10de82908>,
#  (u'pI2S', u'FP'): <__main__.classesPaire instance at 0x1096f47a0>,
#  (u'pc1P', u'fi2P'): <__main__.classesPaire instance at 0x10d368f80>,
#  (u'fi1S', u'is2S'): <__main__.classesPaire instance at 0x10c8d2e18>,
#  (u'ps2S', u'pc1S'): <__main__.classesPaire instance at 0x10d17c710>,
#  (u'pP', u'inf'): <__main__.classesPaire instance at 0x106daf1b8>,
#  (u'pc2P', u'ai1P'): <__main__.classesPaire instance at 0x10db4bf80>,
#  (u'is3S', u'is2P'): <__main__.classesPaire instance at 0x10dea34d0>,
#  (u'fi1P', u'ps1S'): <__main__.classesPaire instance at 0x1096c0680>,
#  (u'pc3P', u'ppMP'): <__main__.classesPaire instance at 0x106d95680>,
#  (u'ai3P', u'ps2P'): <__main__.classesPaire instance at 0x10db37dd0>,
#  (u'ii1S', u'pP'): <__main__.classesPaire instance at 0x10e108cb0>,
#  (u'pI2S', u'ai3P'): <__main__.classesPaire instance at 0x10db37638>,
#  (u'pc2S', u'fi1P'): <__main__.classesPaire instance at 0x10cffcfc8>,
#  (u'ppFS', u'pI2P'): <__main__.classesPaire instance at 0x10ca28830>,
#  (u'pP', u'pi1S'): <__main__.classesPaire instance at 0x1096f4440>,
#  (u'pI2S', u'fi2P'): <__main__.classesPaire instance at 0x10d12d440>,
#  (u'pc1P', u'ai1S'): <__main__.classesPaire instance at 0x10c8eeea8>,
#  (u'ii2P', u'inf'): <__main__.classesPaire instance at 0x10dfcc248>,
#  (u'ppMS', u'pi3P'): <__main__.classesPaire instance at 0x10c8ca638>,
#  (u'ai2P', u'pc1P'): <__main__.classesPaire instance at 0x10c8ee758>,
#  (u'fi2S', u'ps1P'): <__main__.classesPaire instance at 0x106d913f8>,
#  (u'ai1P', u'ii2S'): <__main__.classesPaire instance at 0x10db4bcb0>,
#  (u'ai3P', u'is1S'): <__main__.classesPaire instance at 0x106db2830>,
#  (u'is2S', u'fi3P'): <__main__.classesPaire instance at 0x10dc4e8c0>,
#  (u'ps2P', u'ii1P'): <__main__.classesPaire instance at 0x109a31cf8>,
#  (u'ai3S', u'ppMP'): <__main__.classesPaire instance at 0x10b5186c8>,
#  (u'is3S', u'FP'): <__main__.classesPaire instance at 0x10df18b90>,
#  (u'fi3S', u'is1P'): <__main__.classesPaire instance at 0x10df15680>,
#  (u'ai3S', u'pi2P'): <__main__.classesPaire instance at 0x10af509e0>,
#  (u'is3S', u'ii2S'): <__main__.classesPaire instance at 0x10b74af38>,
#  (u'ps1P', u'pc3P'): <__main__.classesPaire instance at 0x10b5db8c0>,
#  (u'ai2P', u'is3S'): <__main__.classesPaire instance at 0x10c822a70>,
#  (u'is1S', u'ppMS'): <__main__.classesPaire instance at 0x10dc5b290>,
#  (u'fi3S', u'ii2S'): <__main__.classesPaire instance at 0x10db85d40>,
#  (u'pc3S', u'pI1P'): <__main__.classesPaire instance at 0x10de93368>,
#  (u'pi3P', u'pi2P'): <__main__.classesPaire instance at 0x106d897a0>,
#  (u'ii1P', u'FS'): <__main__.classesPaire instance at 0x10e108830>,
#  (u'ii1P', u'is1S'): <__main__.classesPaire instance at 0x10df98488>,
#  (u'pc1P', u'pi1P'): <__main__.classesPaire instance at 0x10df500e0>,
#  (u'pc2P', u'pi3P'): <__main__.classesPaire instance at 0x1096f43b0>,
#  (u'pc3S', u'ps1P'): <__main__.classesPaire instance at 0x10ca93170>,
#  (u'pI2S', u'is3P'): <__main__.classesPaire instance at 0x10d17c050>,
#  (u'pI2P', u'fi1S'): <__main__.classesPaire instance at 0x10d3688c0>,
#  (u'pP', u'ii2P'): <__main__.classesPaire instance at 0x10dfcc050>,
#  (u'ii3P', u'pI2S'): <__main__.classesPaire instance at 0x10def6e18>,
#  (u'ai3P', u'fi2S'): <__main__.classesPaire instance at 0x10ded88c0>,
#  ...}

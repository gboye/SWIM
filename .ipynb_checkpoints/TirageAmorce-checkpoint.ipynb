# %%
import codecs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
# %pylab inline
pd.options.display.mpl_style = 'default'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nomLexique="/Users/gilles/Copy/Python/phonemisation/bdlexique.txt"
bdlexique=pd.read_csv(nomLexique,sep=";",names=["ortho","phono","ext","cs","ms","vs","lexeme","L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"])

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
# Out:
# ['inf',
#  'pi1S',
#  'pi2S',
#  'pi3S',
#  'pi1P',
#  'pi2P',
#  'pi3P',
#  'ii1S',
#  'ii2S',
#  'ii3S',
#  'ii1P',
#  'ii2P',
#  'ii3P',
#  'fi1S',
#  'fi2S',
#  'fi3S',
#  'fi1P',
#  'fi2P',
#  'fi3P',
#  'pI2S',
#  'pI1P',
#  'pI2P',
#  'ps1S',
#  'ps2S',
#  'ps3S',
#  'ps1P',
#  'ps2P',
#  'ps3P',
#  'pc1S',
#  'pc2S',
#  'pc3S',
#  'pc1P',
#  'pc2P',
#  'pc3P',
#  'pP',
#  'ai1S',
#  'ai2S',
#  'ai3S',
#  'ai1P',
#  'ai2P',
#  'ai3P',
#  'is1S',
#  'is2S',
#  'is3S',
#  'is1P',
#  'is2P',
#  'is3P']

# %%
produitPrincipal=[(x,y) for (x,y) in it.product(casesPrincipales,casesPrincipales) if x!=y]

# %%
bdlexique["freq"]=bdlexique[bdlexique["formeFrantext"]!="***"]["formeFrantext"].astype(float)*10
bdlexique.loc[bdlexique["formeFrantext"]=="0","freq"]=5
bdlexique.loc[bdlexique["formeFrantext"]=="***","freq"]=1

# %%
inutilesColonnes=["L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"]
for colonne in inutilesColonnes:
    del bdlexique[colonne]

# %%
verbes=bdlexique[bdlexique["cs"]=="V"].copy()

# %%
verbes._is_view
# Out:
# False

# %%
verbes["prob"]=verbes["freq"]/verbes["freq"].sum()

# %%
verbes["ms"]=verbes["ms"].fillna("")
verbes["case"]=verbes["vs"]+verbes["ms"]

# %%
manquantesMoyenne={}
annexesMoyenne={}

# %% [markdown]
# %%time
# nbTirages=250
# echantillonTailles=[250*x for x in range(2,10)]
#
# for echantillonTaille in echantillonTailles:
#     nbManquantes=0
#     nbAnnexes=0
#     for n in range(nbTirages):
#         tirage=np.random.choice(verbes.index,size=echantillonTaille,p=verbes["prob"],replace=False)
#         extrait=verbes.ix[np.sort(tirage)]
#         formes=extrait.groupby(["lexeme"])["case"].count()
#         liste=formes[formes>1].index
#         manquantes=[case for case in casesPrincipales if not case in extrait[extrait["lexeme"].isin(liste)]["case"].unique()]
#         annexes=[case for case in casesSecondaires if not case in extrait[extrait["lexeme"].isin(liste)]["case"].unique()]
#         if manquantes :
#             nbManquantes+=1
#         if annexes:
#             nbAnnexes+=1
#     manquantesMoyenne[echantillonTaille]=100*float(nbManquantes)/nbTirages
#     annexesMoyenne[echantillonTaille]=100*float(nbAnnexes)/nbTirages

# %%
# %%time
nbTirages=250
echantillonTailles=[250*x for x in range(2,10)]

for echantillonTaille in echantillonTailles:
    nbManquantes=0
    nbAnnexes=0
    for n in range(nbTirages):
        tirage=np.random.choice(verbes.index,size=echantillonTaille,p=verbes["prob"],replace=False)
        extrait=verbes.ix[np.sort(tirage)]
        paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: x)
        paradigmes.count()
        manquantes=[case for case in casesPrincipales if not case in extrait[extrait["lexeme"].isin(liste)]["case"].unique()]
        annexes=[case for case in casesSecondaires if not case in extrait[extrait["lexeme"].isin(liste)]["case"].unique()]
        if manquantes :
            nbManquantes+=1
        if annexes:
            nbAnnexes+=1
    manquantesMoyenne[echantillonTaille]=100*float(nbManquantes)/nbTirages
    annexesMoyenne[echantillonTaille]=100*float(nbAnnexes)/nbTirages
# Out:
# CPU times: user 1min 12s, sys: 1.04 s, total: 1min 13s
# Wall time: 1min 13s

# %%
courbeSecondaires=pd.Series(annexesMoyenne)
courbePrincipales=pd.Series(manquantesMoyenne)

# %%
courbePrincipales.plot()
courbeSecondaires.plot()

# %%
formes[formes>1]
# Out:
# lexeme
# abandonner      5
# accepter        6
# accompagner     2
# accuser         2
# accélérer       4
# acheter         6
# admettre        4
# adorer          7
# affecter        2
# affirmer        2
# agacer          2
# agir            3
# aider           9
# aimer          16
# aller          19
# ...
# voir        15
# voler        4
# vouloir     19
# vérifier     3
# échapper     4
# échouer      4
# écouter      8
# écrire       3
# éliminer     2
# énerver      3
# épater       2
# établir      2
# éviter       2
# être        29
# ôter         2
# Name: case, Length: 384, dtype: int64

# %%
tirageCases=extrait[extrait["lexeme"].isin(liste)].groupby(["lexeme"])["case"].apply(lambda x: list(x)).copy()
#tirageCases["paires"]=tirageCases["cases"].apply(lambda x: [(y,z) for (y,z) in it.product(x,x) if y!=z])

# %%
nbPaires={}
for paire in produitPrincipal:
#    print paire
    for index,row in tirageCases.iteritems():
#        print row
        if paire[0] in row and paire[1] in row:
            if not paire in nbPaires:
                nbPaires[paire]=0
            nbPaires[paire]+=1

# %%
nbPairesSuffisantes=pd.Series()
for seuil in range(10):
    pairesManquantes=produitPrincipal[:]
    for paire in nbPaires:
        if nbPaires[paire]>seuil:
            pairesManquantes.remove(paire)
    nbPairesSuffisantes.loc[seuil]=len(produitPrincipal)-len(pairesManquantes)

# %%
for paire in produitPrincipal:
    extrait

# %%
extrait[extrait["lexeme"]=="asseoir"]
# Out:
#          ortho  phono  ext cs  ms   vs   lexeme   freq      prob  case
# 27087  asseoir  aswar  NaN  V      inf  asseoir  65100  0.000198   inf
# 27097   assoit   aswa   t"  V  3S   pi  asseoir   3310  0.000010  pi3S
# 27113    assis    asi   z"  V  1S   ai  asseoir  52340  0.000159  ai1S
# 27114    assis    asi   z"  V  2S   ai  asseoir  52340  0.000159  ai2S

# %%
paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ";".join(x))

# %%
paradigmes.dropna(thresh=2, axis=0).fillna("")
# Out:
# case           ai1S ai2P   ai2S   ai3S  fi1P      fi1S  fi2P     fi2S   fi3P  \
# lexeme
# abandonner
# accepter
# accompagner
# accuser
# accélérer
# acheter                                                       aSèt6ra
# admettre
# adorer
# affecter
# affirmer
# agacer
# agir                               aZi
# aider                                                                  èd6rô
# aimer
# aller                                              irè
# allumer
# amener
# amuser
# annoncer
# apparaître                       apary        aparètrè
# appartenir
# appeler                                        apèl6rè
# apporter
# apprendre                         apri
# approcher
# apprécier
# armer
# arracher
# arranger
# arriver
# ...             ...  ...    ...    ...   ...       ...   ...      ...    ...
# travailler
# traverser
# tromper
# trouver                                                       truv6ra
# tuer
# téléphoner
# utiliser
# valoir
# veiller
# vendre
# venir                                           vjêdrè
# verser
# vexer
# vieillir                  vjèji
# vivre
# voir             vi          vi         vèrô                     vèra
# voler
# vouloir                                                         vudra
# vérifier
# échapper
# échouer                           èSua
# écouter
# écrire                                          èkrirè
# éliminer
# énerver
# épater
# établir      ètabli
# éviter
# être                                fy  s6rô      s6rè  s6re     s6ra
# ôter
#
# case            fi3S   ...        pi2P    pi2S  pi3P     pi3S   ps1P     ps1S  \
# lexeme                 ...
# abandonner             ...                                             abâdòn
# accepter               ...              aksEpt                         aksEpt
# accompagner            ...                                             akôpaJ
# accuser                ...                               akyz            akyz
# accélérer              ...                            aksèlEr         aksèlEr
# acheter                ...                      aSEt     aSEt            aSEt
# admettre               ...      admète
# adorer                 ...                      adOr     adOr            adOr
# affecter               ...                              afEkt           afEkt
# affirmer               ...
# agacer                 ...                               agas
# agir                   ...                                aZi
# aider                  ...         ède                     Ed              Ed
# aimer                  ...         ème      Em    Em       Em              Em
# aller            ira   ...         ale      va    vô       va              aj
# allumer                ...                               alym
# amener                 ...                               amEn            amEn
# amuser                 ...       amyze                                   amyz
# annoncer               ...                               anôs
# apparaître             ...
# appartenir             ...                            apartjê
# appeler                ...       ap6le                   apEl            apEl
# apporter               ...      apOrte                                  apOrt
# apprendre    aprâdra   ...                               aprâ
# approcher              ...                              aprOS           aprOS
# apprécier              ...                             aprèsi
# armer                  ...                                arm
# arracher               ...                               araS
# arranger               ...       arâZe                   arâZ
# arriver      ariv6ra   ...                ariv  ariv     ariv            ariv
# ...              ...   ...         ...     ...   ...      ...    ...      ...
# travailler             ...                             travaj
# traverser              ...                            travErs         travErs
# tromper                ...                trôp
# trouver      truv6ra   ...                      truv     truv            truv
# tuer                   ...         tye      ty    ty       ty              ty
# téléphoner             ...                            tèlèfòn         tèlèfòn
# utiliser               ...     ytilize
# valoir         vòdra   ...                                 vo
# veiller                ...                                vEj
# vendre                 ...                       vâd       vâ
# venir                  ...        v6ne     vjê            vjê            vjEn
# verser                 ...                vErs
# vexer                  ...                                               vEks
# vieillir               ...
# vivre                  ...                       viv       vi
# voir            vèra   ...       vwaje     vwa            vwa
# voler                  ...                                                vOl
# vouloir                ...        vule      v2   v9l       v2
# vérifier               ...                                             vèrifi
# échapper               ...                               èSap
# échouer                ...                                èSu             èSu
# écouter                ...       èkute    èkut           èkut            èkut
# écrire                 ...                               èkri
# éliminer               ...                                             èlimin
# énerver                ...                              ènErv
# épater                 ...                                               èpat
# établir                ...
# éviter                 ...                               èvit
# être            s6ra   ...          Et       è    sô        è  swajô      swa
# ôter                   ...                                 ot
#
# case          ps2P    ps2S    ps3P     ps3S
# lexeme
# abandonner          abâdòn
# accepter                             aksEpt
# accompagner
# accuser
# accélérer                           aksèlEr
# acheter
# admettre
# adorer                adOr             adOr
# affecter
# affirmer                              afirm
# agacer                                 agas
# agir
# aider                                    Ed
# aimer                   Em               Em
# aller                                    aj
# allumer
# amener                                 amEn
# amuser                                 amyz
# annoncer                               anôs
# apparaître
# appartenir
# appeler               apEl             apEl
# apporter
# apprendre
# approcher            aprOS   aprOS
# apprécier
# armer
# arracher
# arranger
# arriver               ariv    ariv     ariv
# ...            ...     ...     ...      ...
# travailler                  travaj   travaj
# traverser
# tromper
# trouver                                truv
# tuer                            ty       ty
# téléphoner
# utiliser                             ytiliz
# valoir
# veiller
# vendre
# venir        v6nje            vjEn     vjEn
# verser                                 vErs
# vexer                                  vEks
# vieillir
# vivre                                   viv
# voir
# voler                                   vOl
# vouloir
# vérifier
# échapper                               èSap
# échouer                                 èSu
# écouter                                èkut
# écrire
# éliminer
# énerver                               ènErv
# épater                èpat
# établir
# éviter
# être         swaje     swa              swa
# ôter
#
# [384 rows x 42 columns]

# %%
len(casesTotales)
# Out:
# 47

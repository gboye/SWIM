# %%
import csv,pickle,codecs
import pandas as pd

# %%
lexiquePrefix="2015-Data/MGC-160104-basesDerives"
with open('2015-Data/MGC-160104-Derives2.pkl', 'rb') as input:
    derives = pickle.load(input)

# %%
baseDerives=derives.set_index("lexeme")["base"].to_dict()
baseDerives
# Out:
# {u'absoute': u'absoudre',
#  u'accalmie': u'accalmir',
#  u'accrue': u'accro\xeetre',
#  u'agonie': u'agonir',
#  u'all\xe9e': u'aller',
#  u'amen\xe9e': u'amener',
#  u'arriv\xe9e': u'arriver',
#  u'assise': u'asseoir',
#  u'astreinte': u'astreindre',
#  u'atteinte': u'atteindre',
#  u'attente': u'attendre',
#  u'battue': u'battre',
#  u'but\xe9e': u'buter',
#  u'bu\xe9e': u'buer',
#  u'charpie': u'charpir',
#  u'chevauch\xe9e': u'chevaucher',
#  u'chute': u'choir',
#  u'complainte': u'complaindre',
#  u'conduite': u'conduire',
#  u'conqu\xeate': u'conqu\xe9rir',
#  u'contrainte': u'contraindre',
#  u'course': u'courir',
#  u'couverte': u'couvrir',
#  u'couv\xe9e': u'couver',
#  u'crainte': u'craindre',
#  u'crois\xe9e': u'croiser',
#  u'crue': u'cro\xeetre',
#  u'cueillette': u'cueillir',
#  u'cuite': u'cuire',
#  u'descente': u'descendre',
#  u'desserte': u'desservir ',
#  u'dette': u'devoir',
#  u'dict\xe9e': u'dicter',
#  u'dur\xe9e': u'durer',
#  u'd\xe9couverte': u'd\xe9couvrir',
#  u'd\xe9crue': u'd\xe9cro\xeetre',
#  u'd\xe9culott\xe9e': u'd\xe9culotter',
#  u'd\xe9faite': u'd\xe9faire',
#  u'd\xe9fense': u'd\xe9fendre',
#  u'd\xe9prise': u'd\xe9prendre',
#  u'd\xe9rouill\xe9e': u'd\xe9rouiller',
#  u'd\xe9tente': u'd\xe9tendre',
#  u'embard\xe9e': u'embarder',
#  u'embellie': u'embellir',
#  u'empreinte': u'empreindre',
#  u'enqu\xeate': u'enqu\xe9rir',
#  u'entente': u'entendre',
#  u'entremise': u'entremettre',
#  u'entreprise': u'entreprendre',
#  u'entr\xe9e': u'entrer',
#  u'envol\xe9e': u'envoler',
#  u'feinte': u'feindre',
#  u'fente': u'fendre',
#  u'flamb\xe9e': u'flamber',
#  u'fondue': u'fondre',
#  u'fonte': u'fondre',
#  u'foul\xe9e': u'fouler',
#  u'fricass\xe9e': u'fricasser',
#  u'fuite': u'fuir',
#  u'fum\xe9e': u'fumer',
#  u'fus\xe9e': u'fuser',
#  u'garantie': u'garantir',
#  u'gel\xe9e': u'geler',
#  u'gicl\xe9e': u'gicler',
#  u'grimp\xe9e': u'grimper',
#  u'hu\xe9e': u'huer',
#  u'jet\xe9e': u'jeter',
#  u'lamp\xe9e': u'lamper',
#  u'lanc\xe9e': u'lancer',
#  u'lev\xe9e': u'lever',
#  u'meute': u'mouvoir',
#  u'mise': u'mettre',
#  u'mort': u'mourir',
#  u'm\xe9prise': u'm\xe9prendre',
#  u'm\xe9vente': u'm\xe9vendre',
#  u'm\xeal\xe9e': u'm\xealer',
#  u'ou\xefe': u'ou\xefr',
#  u'partie': u'partir',
#  u'pass\xe9e': u'passer',
#  u'pav\xe9e': u'paver',
#  u'pens\xe9e': u'penser',
#  u'pente': u'pendre',
#  u'perc\xe9e': u'percer',
#  u'perte': u'perdre',
#  u'pes\xe9e': u'peser',
#  u'pip\xe9e': u'piper',
#  u'plainte': u'plaindre',
#  u'plong\xe9e': u'plonger',
#  u'pointe': u'poindre',
#  u'ponte': u'pondre',
#  u'port\xe9e': u'porter',
#  u'poursuite': u'poursuivre',
#  u'pouss\xe9e': u'pousser',
#  u'prise': u'prendre',
#  u'promesse': u'promettre',
#  u'qu\xeate': u'qu\xe9rir',
#  u'randonn\xe9e': u'randonner',
#  u'recette': u'recevoir',
#  u'reconduite': u'reconduire',
#  u'redite': u'redire',
#  u'refonte': u'refondre',
#  u'remise': u'remettre',
#  u'remont\xe9e': u'remonter',
#  u'renomm\xe9e': u'renommer',
#  u'rente': u'rendre',
#  u'rentr\xe9e': u'rentrer',
#  u'repartie': u'repartir',
#  u'repos\xe9e': u'reposer',
#  u'reprise': u'reprendre',
#  u'requ\xeate': u'requ\xe9rir',
#  u'retomb\xe9e': u'retomber',
#  u'retraite': u'retraire',
#  u'revente': u'revendre',
#  u'revue': u'revoir',
#  u'rinc\xe9e': u'rincer',
#  u'ross\xe9e': u'rosser',
#  u'ru\xe9e': u'ruer',
#  u'r\xe9gie': u'r\xe9gir',
#  u'r\xe9ponse': u'r\xe9pondre',
#  u'r\xe9ussite': u'r\xe9ussir',
#  u'saign\xe9e': u'saigner',
#  u'saillie': u'saillir',
#  u'saisie': u'saisir',
#  u'sauc\xe9e': u'saucer',
#  u'sortie': u'sortir',
#  u'suite': u'suivre',
#  u'surprise': u'surprendre',
#  u'surtonte': u'surtondre',
#  u'survenue': u'survenir',
#  u'survie': u'survie',
#  u'su\xe9e': u'suer',
#  u'tabass\xe9e': u'tabasser',
#  u'teinte': u'teindre',
#  u'tente': u'tendre',
#  u'tenue': u'tenir',
#  u'tomb\xe9e': u'tomber',
#  u'tonte': u'tondre',
#  u'torch\xe9e': u'torcher',
#  u'tourn\xe9e': u'tourner',
#  u'tou\xe9e': u'touer',
#  u'traite': u'traire',
#  u'tranch\xe9e': u'trancher',
#  u'travers\xe9e': u'traverser',
#  u'tra\xeen\xe9e': u'tra\xeener',
#  u'trou\xe9e': u'trouer',
#  u't\xe9t\xe9e': u't\xe9ter',
#  u'veill\xe9e': u'veiller',
#  u'vente': u'vendre',
#  u'venue': u'venir',
#  u'vie': u'vivre',
#  u'vir\xe9e': u'virer',
#  u'vis\xe9e': u'viser',
#  u'vol\xe9e': u'voler',
#  u'vue': u'voir',
#  u'\xe9chapp\xe9e': u'\xe9chapper',
#  u'\xe9claircie': u'\xe9claircir',
#  u'\xe9meute': u'\xe9mouvoir',
#  u'\xe9tendue': u'\xe9tendre',
#  u'\xe9treinte': u'\xe9treindre',
#  u'\xe9tuv\xe9e': u'\xe9tuver'}

# %%
verbesBRASS=pd.read_csv(lexiquePrefix+"-01-N-paradigmes.csv",sep=";",encoding="utf8")
del verbesBRASS[u"Unnamed: 0"]
verbesBRASS
# Out:
# 139        virer     NaN      virE  NaN  NaN      virEr      vira         NaN
# 140        viser     NaN      vizE  NaN  NaN      vizEr      viza      viz9rô
# 141        vivre     NaN       NaN  NaN  NaN      vEkyr       NaN       vivrô
# 142         voir     vim        vi  NaN   vi        NaN        vi        vErô
# 143        voler     NaN      vOlE  NaN  NaN      vOlEr      vOla         NaN
# 144     échapper     NaN     ESapE  NaN  NaN     ESapEr     ESapa         NaN
# 145    éclaircir     NaN   EklErsi  NaN  NaN   EklErsir   EklErsi         NaN
# 146     émouvoir     NaN       NaN  NaN  NaN       Emyr       Emy       EmOrô
# 147      étendre     NaN     Etâdi  NaN  NaN     Etâdir     Etâdi         NaN
# 148    étreindre     NaN       NaN  NaN  NaN        NaN       NaN         NaN
# 149       étuver     NaN     EtyvE  NaN  NaN     EtyvEr     Etyva         NaN
#
#            fi1S       fi2P   ...         ppFP      ppFS      ppMP      ppMS  \
# 0           NaN    absudre   ...          NaN       NaN       NaN       NaN
# 1      akrwatrE   akrwatre   ...          NaN       NaN       NaN       NaN
# 2       agOnirE    agOnire   ...          NaN       NaN     agOni     agOni
# 3           irE        ire   ...          ale       ale       ale       ale
# 4       amEn9rE        NaN   ...        am9ne     am9ne     am9ne     am9ne
# 5       ariv9rE    ariv9re   ...        arive     arive     arive     arive
# 6           NaN        NaN   ...         asiz      asiz       NaN       NaN
# 7     astrEJ9rE  astrEJ9re   ...      astrEJe   astrEJe   astrEJe   astrEJe
# 8        atêdrE        NaN   ...         atêt      atêt       atê       atê
# 9        atâdrE        NaN   ...          NaN     atâdy     atâdy     atâdy
# 10          NaN        NaN   ...         baty      baty      baty      baty
# 11       byt9rE     byt9re   ...         byte      byte      byte      byte
# 12     S9vOS9rE   S9vOS9re   ...       S9vOSe    S9vOSe    S9vOSe    S9vOSe
# 13          NaN      Sware   ...          NaN       NaN       NaN       NaN
# 14      kôdHirE        NaN   ...          NaN    kôdHit     kôdHi     kôdHi
# 15          NaN        NaN   ...          NaN       NaN       NaN       NaN
# 16          NaN        NaN   ...          NaN    kôtrêt       NaN     kôtrê
# 17          NaN        NaN   ...          NaN       NaN       NaN      kury
# 18       kuv9rE     kuv9re   ...          NaN      kuve      kuve      kuve
# 19      kuvrirE        NaN   ...          NaN       NaN     kuvEr     kuvEr
# 20          NaN        NaN   ...          NaN      krêt       NaN       krê
# 21     krwaz9rE        NaN   ...          NaN    krwaze    krwaze    krwaze
# 22      krwatrE    krwatre   ...          NaN       NaN       NaN       NaN
# 23       k9jirE     k9jire   ...          NaN       NaN       NaN       NaN
# 24        kHirE        NaN   ...          NaN      kHit       kHi       kHi
# 25      dEsâdrE        NaN   ...       dEsâdy    dEsâdy    dEsâdy    dEsâdy
# 26        d9vrE      d9vre   ...           dy       NaN        dy        dy
# 27      dikt9rE        NaN   ...          NaN     dikte     dikte     dikte
# 28       dyr9rE     dyr9re   ...          NaN      dyre      dyre      dyre
# 29          NaN        NaN   ...          NaN       NaN       NaN       NaN
# ..          ...        ...   ...          ...       ...       ...       ...
# 120   syrvjêdrE  syrvjêdre   ...          NaN   syrv9ny   syrv9ny   syrv9ny
# 121    tabas9rE   tabas9re   ...       tabase    tabase    tabase    tabase
# 122       têdrE        NaN   ...          NaN       NaN       NaN       NaN
# 123       tâdrE        NaN   ...         tâdy      tâdy      tâdy      tâdy
# 124      tjêdrE     tjêdre   ...          NaN      t9ny      t9ny      t9ny
# 125      tôb9rE        NaN   ...         tôbe      tôbe      tôbe      tôbe
# 126         NaN        NaN   ...          NaN       NaN       NaN      tôdy
# 127     tOrS9rE        NaN   ...          NaN     tOrSe     tOrSe     tOrSe
# 128         NaN        NaN   ...          NaN       NaN        tu        tu
# 129         NaN        NaN   ...          NaN     turne     turne     turne
# 130       trErE      trEre   ...          NaN       NaN       NaN       NaN
# 131     trâS9rE        NaN   ...        trâSe     trâSe     trâSe     trâSe
# 132  travErs9rE        NaN   ...     travErse  travErse  travErse  travErse
# 133     trEn9rE        NaN   ...          NaN     trEne       NaN     trEne
# 134         NaN        NaN   ...          NaN      true      true      true
# 135      tEt9rE     tEt9re   ...          NaN      tEte      tEte      tEte
# 136         NaN        NaN   ...          NaN      vEje      vEje      vEje
# 137       vâdrE        NaN   ...         vâdy      vâdy      vâdy      vâdy
# 138      vjêdrE     vjêdre   ...         v9ny      v9ny      v9ny      v9ny
# 139      vir9rE     vir9re   ...          NaN      vire      vire      vire
# 140      viz9rE     viz9re   ...         vize      vize      vize      vize
# 141       vivrE      vivre   ...         vEky      vEky      vEky      vEky
# 142        vErE       vEre   ...           vy        vy        vy        vy
# 143      vOl9rE     vOl9re   ...          NaN       NaN       NaN      vOle
# 144     ESap9rE        NaN   ...        ESape     ESape     ESape     ESape
# 145         NaN        NaN   ...          NaN   EklErsi       NaN   EklErsi
# 146       EmOrE        NaN   ...          NaN       NaN       NaN       Emy
# 147      EtâdrE        NaN   ...          NaN     Etâdy     Etâdy     Etâdy
# 148     EtrêdrE    Etrêdre   ...          NaN       NaN       NaN       NaN
# 149     Etyv9rE    Etyv9re   ...          NaN     Etyve     Etyve     Etyve
#
#       ps1P     ps1S   ps2P     ps2S     ps3P     ps3S
# 0      NaN    absud    NaN      NaN      NaN    absud
# 1      NaN      NaN    NaN      NaN      NaN      NaN
# 2      NaN      NaN    NaN      NaN      NaN      NaN
# 3      NaN       aj    NaN       aj       aj       aj
# 4      NaN      NaN    NaN      NaN      NaN     amEn
# 5      NaN     ariv    NaN     ariv     ariv     ariv
# 6      NaN      NaN    NaN     asEj      NaN      NaN
# 7      NaN   astrEJ    NaN   astrEJ   astrEJ   astrEJ
# 8      NaN     atEJ    NaN      NaN      NaN      NaN
# 9      NaN     atâd    NaN      NaN      NaN     atâd
# 10     NaN      bat    NaN      NaN      NaN      NaN
# 11     NaN      byt    NaN      byt      NaN      byt
# 12     NaN    S9vOS    NaN    S9vOS    S9vOS    S9vOS
# 13     NaN      NaN    NaN      NaN      NaN      NaN
# 14     NaN   kôdHiz    NaN      NaN      NaN   kôdHiz
# 15     NaN      NaN    NaN      NaN      NaN      NaN
# 16     NaN      NaN    NaN      NaN      NaN      NaN
# 17     NaN      NaN    NaN      NaN      NaN      NaN
# 18     NaN      kuv    NaN      kuv      kuv      kuv
# 19     NaN      NaN    NaN     kuvr     kuvr     kuvr
# 20     NaN      NaN    NaN      NaN      NaN      NaN
# 21     NaN    krwaz    NaN    krwaz    krwaz    krwaz
# 22     NaN      NaN    NaN      NaN      NaN      NaN
# 23     NaN      NaN    NaN      NaN      NaN      NaN
# 24     NaN     kHiz    NaN      NaN      NaN     kHiz
# 25     NaN    dEsâd    NaN      NaN      NaN    dEsâd
# 26     NaN      NaN  d9vje      NaN     dwav     dwav
# 27     NaN     dikt    NaN     dikt      NaN     dikt
# 28     NaN      dyr    NaN      dyr      dyr      dyr
# 29     NaN      NaN    NaN   dEkuvr   dEkuvr   dEkuvr
# ..     ...      ...    ...      ...      ...      ...
# 120    NaN  syrvjEn    NaN  syrvjEn  syrvjEn  syrvjEn
# 121    NaN    tabas    NaN    tabas    tabas    tabas
# 122    NaN      têd    NaN      NaN      NaN      têd
# 123    NaN      tâd    NaN      NaN      NaN      tâd
# 124  t9njô     tjEn    NaN      NaN      NaN     tjEn
# 125    NaN      tôb    NaN      tôb      tôb      tôb
# 126    NaN      tôd    NaN      NaN      NaN      tôd
# 127    NaN     tOrS    NaN     tOrS     tOrS     tOrS
# 128    NaN      NaN    NaN      NaN      NaN      NaN
# 129    NaN     turn    NaN     turn      NaN     turn
# 130    NaN      trE    NaN      NaN      NaN      trE
# 131    NaN     trâS    NaN     trâS     trâS     trâS
# 132    NaN  travErs    NaN  travErs  travErs  travErs
# 133    NaN     trEn    NaN      NaN      NaN     trEn
# 134    NaN      NaN    NaN      tru      NaN      tru
# 135    NaN      tEt    NaN      NaN      NaN      tEt
# 136    NaN      vEj    NaN      vEj      NaN      NaN
# 137    NaN      vâd    NaN      NaN      NaN      vâd
# 138    NaN     vjEn    NaN     vjEn     vjEn     vjEn
# 139    NaN      vir    NaN      vir      vir      vir
# 140    NaN      NaN    NaN      viz      NaN      NaN
# 141    NaN      viv    NaN      NaN      viv      viv
# 142    NaN      vwa    NaN      vwa      vwa      vwa
# 143    NaN      vOl    NaN      vOl      vOl      NaN
# 144    NaN     ESap    NaN     ESap      NaN     ESap
# 145    NaN   EklErs    NaN      NaN      NaN   EklErs
# 146    NaN      NaN    NaN      NaN      NaN      NaN
# 147    NaN     Etâd    NaN      NaN      NaN     Etâd
# 148    NaN      NaN    NaN      NaN      NaN      NaN
# 149    NaN     Etyv    NaN     Etyv     Etyv     Etyv
#
# [150 rows x 52 columns]

# %%
verbesGOLD=pd.read_csv(lexiquePrefix+"-01-N-GOLD.csv",sep=";",encoding="utf8")
del verbesGOLD[u"Unnamed: 0"]
verbesGOLD
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-136-239d15f489a4> in <module>()
# ----> 1 verbesGOLD=pd.read_csv(lexiquePrefix+"-01-N-GOLD.csv",sep=";",encoding="utf8")
#       2 del verbesGOLD[u"Unnamed: 0"]
#       3 verbesGOLD
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     496                     skip_blank_lines=skip_blank_lines)
#     497
# --> 498         return _read(filepath_or_buffer, kwds)
#     499
#     500     parser_f.__name__ = name
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     273
#     274     # Create the parser.
# --> 275     parser = TextFileReader(filepath_or_buffer, **kwds)
#     276
#     277     if (nrows is not None) and (chunksize is not None):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     588             self.options['has_index_names'] = kwds['has_index_names']
#     589
# --> 590         self._make_engine(self.engine)
#     591
#     592     def _get_options_with_defaults(self, engine):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     729     def _make_engine(self, engine='c'):
#     730         if engine == 'c':
# --> 731             self._engine = CParserWrapper(self.f, **self.options)
#     732         else:
#     733             if engine == 'python':
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1101         kwds['allow_leading_cols'] = self.index_col is not False
#    1102
# -> 1103         self._reader = _parser.TextReader(src, **kwds)
#    1104
#    1105         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3246)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6111)()
#
# IOError: File 2015-Data/MGC-160104-basesDerives-01-N-GOLD.csv does not exist

# %%
derivesBRASS=pd.read_csv(lexiquePrefix+"-derives-01-N-paradigmes.csv",sep=";",encoding="utf8")
del derivesBRASS[u"Unnamed: 0"]
derivesBRASS
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-137-89c4bdb7bb46> in <module>()
# ----> 1 derivesBRASS=pd.read_csv(lexiquePrefix+"-derives-01-N-paradigmes.csv",sep=";",encoding="utf8")
#       2 del derivesBRASS[u"Unnamed: 0"]
#       3 derivesBRASS
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     496                     skip_blank_lines=skip_blank_lines)
#     497
# --> 498         return _read(filepath_or_buffer, kwds)
#     499
#     500     parser_f.__name__ = name
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     273
#     274     # Create the parser.
# --> 275     parser = TextFileReader(filepath_or_buffer, **kwds)
#     276
#     277     if (nrows is not None) and (chunksize is not None):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     588             self.options['has_index_names'] = kwds['has_index_names']
#     589
# --> 590         self._make_engine(self.engine)
#     591
#     592     def _get_options_with_defaults(self, engine):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     729     def _make_engine(self, engine='c'):
#     730         if engine == 'c':
# --> 731             self._engine = CParserWrapper(self.f, **self.options)
#     732         else:
#     733             if engine == 'python':
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1101         kwds['allow_leading_cols'] = self.index_col is not False
#    1102
# -> 1103         self._reader = _parser.TextReader(src, **kwds)
#    1104
#    1105         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3246)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6111)()
#
# IOError: File 2015-Data/MGC-160104-basesDerives-derives-01-N-paradigmes.csv does not exist

# %%
derivesSILVER=pd.read_csv(lexiquePrefix+"-derives-01-N-Silver.csv",sep=";",encoding="utf8")
del derivesSILVER[u"Unnamed: 0"]
del derivesSILVER[u"score"]
del derivesSILVER[u"ajouts"]
derivesSILVER
# Out:
#         lexeme        FP        FS
# 0       agonie     agOni     agOni
# 1        allée       ale       ale
# 2      arrivée     arive     arive
# 3       assise      asiz      asiz
# 4      attente      atât      atât
# 5         buée       bye       bye
# 6     conduite    kôdHit    kôdHit
# 7   contrainte    kôtrêt    kôtrêt
# 8      crainte      krêt      krêt
# 9     descente     dEsât     dEsât
# 10       durée      dyre      dyre
# 11  découverte  dEkuvErt  dEkuvErt
# 12     défaite     dEfEt     dEfEt
# 13     détente     dEtât     dEtât
# 14    embellie     âbEli     âbEli
# 15   empreinte     âprêt     âprêt
# 16     enquête      âkEt      âkEt
# 17  entreprise  âtr9priz  âtr9priz
# 18      entrée      âtre      âtre
# 19      fondue      fôdy      fôdy
# 20       fonte       fôt       fôt
# 21       fuite      fHit      fHit
# 22       fumée      fyme      fyme
# 23       fusée      fyze      fyze
# 24       gelée      Z9le      Z9le
# 25       jetée      Z9te      Z9te
# 26      lampée      lâpe      lâpe
# 27      lancée      lâse      lâse
# 28       levée      l9ve      l9ve
# 29       meute       m2t       m2t
# ..         ...       ...       ...
# 40      portée     pOrte     pOrte
# 41   poursuite   pursHit   pursHit
# 42       prise      priz      priz
# 43    renommée    r9nOme    r9nOme
# 44     reprise    r9priz    r9priz
# 45     requête     r9kEt     r9kEt
# 46    retraite    r9trEt    r9trEt
# 47       revue      r9vy      r9vy
# 48     réponse     rEpôs     rEpôs
# 49      sortie     sOrti     sOrti
# 50       suite      sHit      sHit
# 51    surprise   syrpriz   syrpriz
# 52        suée       sye       sye
# 53      teinte       têt       têt
# 54       tenue      t9ny      t9ny
# 55      tombée      tôbe      tôbe
# 56       tonte       tôt       tôt
# 57     tournée     turne     turne
# 58    tranchée     trâSe     trâSe
# 59   traversée  travErse  travErse
# 60     traînée     trEne     trEne
# 61       vente       vât       vât
# 62       venue      v9ny      v9ny
# 63       visée      vize      vize
# 64       volée      vOle      vOle
# 65         vue        vy        vy
# 66    échappée     ESape     ESape
# 67      émeute      Em2t      Em2t
# 68     étendue     Etâdy     Etâdy
# 69    étreinte     Etrêt     Etrêt
#
# [70 rows x 3 columns]

# %%
derivesGOLD=pd.read_csv(lexiquePrefix+"-derives-01-N-Gold.csv",sep=";",encoding="utf8")
del derivesGOLD[u"Unnamed: 0"]
derivesGOLD
# Out:
#          lexeme        FP        FS
# 0       absoute     absut     absut
# 1      accalmie    akalmi    akalmi
# 2        accrue      akry      akry
# 3        agonie     agOni     agOni
# 4         allée       ale       ale
# 5        amenée     am9ne     am9ne
# 6       arrivée     arive     arive
# 7        assise      asiz      asiz
# 8     astreinte    astrêt    astrêt
# 9      atteinte      atêt      atêt
# 10      attente      atât      atât
# 11       battue      baty      baty
# 12        butée      byte      byte
# 13         buée       bye       bye
# 14      charpie     Sarpi     Sarpi
# 15   chevauchée    S9vOSe    S9vOSe
# 16   complainte    kôplêt    kôplêt
# 17     conduite    kôdHit    kôdHit
# 18     conquête     kôkEt     kôkEt
# 19   contrainte    kôtrêt    kôtrêt
# 20     couverte    kuvErt    kuvErt
# 21       couvée      kuve      kuve
# 22      crainte      krêt      krêt
# 23      croisée    krwaze    krwaze
# 24         crue       kry       kry
# 25        cuite      kHit      kHit
# 26     descente     dEsât     dEsât
# 27     desserte    dEsErt    dEsErt
# 28       dictée     dikte     dikte
# 29        durée      dyre      dyre
# ..          ...       ...       ...
# 120    survenue   syrv9ny   syrv9ny
# 121        suée       sye       sye
# 122    tabassée    tabase    tabase
# 123      teinte       têt       têt
# 124       tente       tât       tât
# 125       tenue      t9ny      t9ny
# 126      tombée      tôbe      tôbe
# 127       tonte       tôt       tôt
# 128     torchée     tOrSe     tOrSe
# 129     tournée     turne     turne
# 130       touée       tue       tue
# 131      traite      trEt      trEt
# 132    tranchée     trâSe     trâSe
# 133   traversée  travErse  travErse
# 134     traînée     trEne     trEne
# 135      trouée      true      true
# 136       tétée      tEte      tEte
# 137     veillée      vEje      vEje
# 138       vente       vât       vât
# 139       venue      v9ny      v9ny
# 140       virée      vire      vire
# 141       visée      vize      vize
# 142       volée      vOle      vOle
# 143         vue        vy        vy
# 144    échappée     ESape     ESape
# 145   éclaircie   EklErsi   EklErsi
# 146      émeute      Em2t      Em2t
# 147     étendue     Etâdy     Etâdy
# 148    étreinte     Etrêt     Etrêt
# 149      étuvée     Etyve     Etyve
#
# [150 rows x 3 columns]

# %%
listVerbesBRASS=verbesBRASS["lexeme"].tolist()
listVerbesSILVER=verbesSILVER["lexeme"].tolist()
listVerbesGOLD=verbesGOLD["lexeme"].tolist()
for derive in baseDerives:
    if baseDerives[derive] in listVerbesBRASS:
        if derivesBRASS[derivesBRASS["lexeme"]==derive]["FS"].values:
            verbesBRASS.loc[verbesBRASS["lexeme"]==baseDerives[derive],"FS"]=derivesBRASS[derivesBRASS["lexeme"]==derive]["FS"].values[0]
        if derivesBRASS[derivesBRASS["lexeme"]==derive]["FP"].values:
            verbesBRASS.loc[verbesBRASS["lexeme"]==baseDerives[derive],"FP"]=derivesBRASS[derivesBRASS["lexeme"]==derive]["FP"].values[0]
    if baseDerives[derive] in listVerbesSILVER:
        if derivesSILVER[derivesSILVER["lexeme"]==derive]["FS"].values:
            verbesSILVER.loc[verbesSILVER["lexeme"]==baseDerives[derive],"FS"]=derivesSILVER[derivesSILVER["lexeme"]==derive]["FS"].values[0]
        if derivesSILVER[derivesSILVER["lexeme"]==derive]["FP"].values:
            verbesSILVER.loc[verbesSILVER["lexeme"]==baseDerives[derive],"FP"]=derivesSILVER[derivesSILVER["lexeme"]==derive]["FP"].values[0]
    if baseDerives[derive] in listVerbesGOLD:
        if derivesGOLD[derivesGOLD["lexeme"]==derive]["FS"].values:
            verbesGOLD.loc[verbesGOLD["lexeme"]==baseDerives[derive],"FS"]=derivesGOLD[derivesGOLD["lexeme"]==derive]["FS"].values[0]
        if derivesGOLD[derivesGOLD["lexeme"]==derive]["FP"].values:
            verbesGOLD.loc[verbesGOLD["lexeme"]==baseDerives[derive],"FP"]=derivesGOLD[derivesGOLD["lexeme"]==derive]["FP"].values[0]

# %%
#derivesSILVER[derivesSILVER["lexeme"]==derive]["FS"].values[0]
verbesSILVER
# Out:
#           lexeme ai1P      ai1S ai2P ai2S       ai3P      ai3S        fi1P  \
# 0       abaisser  NaN     abEsE  NaN  NaN     abEsEr     abEsa         NaN
# 1     abandonner  NaN       NaN  NaN  NaN        NaN   abâdOna   abâdOn9rô
# 2     abasourdir  NaN       NaN  NaN  NaN  abazurdir  abazurdi  abazurdirô
# 3        abattre  NaN       NaN  NaN  NaN     abatir     abati         NaN
# 4        abjurer  NaN    abZyrE  NaN  NaN    abZyrEr    abZyra         NaN
# 5         abolir  NaN       NaN  NaN  NaN        NaN     abOli         NaN
# 6        abonder  NaN     abôdE  NaN  NaN     abôdEr     abôda     abôd9rô
# 7        abonner  NaN     abOnE  NaN  NaN     abOnEr     abOna         NaN
# 8        aborder  NaN    abOrdE  NaN  NaN    abOrdEr    abOrda    abOrd9rô
# 9        abouler  NaN     abulE  NaN  NaN     abulEr     abula         NaN
# 10       aboutir  NaN       NaN  NaN  NaN     abutir       NaN         NaN
# 11        aboyer  NaN       NaN  NaN  NaN        NaN    abwaja         NaN
# 12      abreuver  NaN    abr9vE  NaN  NaN    abr9vEr    abr9va         NaN
# 13       abriter  NaN    abritE  NaN  NaN    abritEr    abrita    abrit9rô
# 14       abroger  NaN    abrOZE  NaN  NaN    abrOZEr    abrOZa         NaN
# 15       abrutir  NaN       NaN  NaN  NaN    abrytir    abryti         NaN
# 16      absenter  NaN    absâtE  NaN  NaN    absâtEr    absâta         NaN
# 17      absorber  NaN       NaN  NaN  NaN        NaN       NaN   absOrb9rô
# 18      absoudre  NaN       NaN  NaN  NaN   absOlvEr   absOlva         NaN
# 19      abstenir  NaN       NaN  NaN  NaN        NaN     abstê         NaN
# 20     abstraire  NaN       NaN  NaN  NaN        NaN       NaN         NaN
# 21        abuser  NaN     abyzE  NaN  NaN     abyzEr     abyza         NaN
# 22     abâtardir  NaN       NaN  NaN  NaN  abatardir  abatardi  abatardirô
# 23        abîmer  NaN       NaN  NaN  NaN        NaN       NaN     abim9rô
# 24    acagnarder  NaN  akaJardE  NaN  NaN  akaJardEr  akaJarda         NaN
# 25      accabler  NaN       NaN  NaN  NaN    akablEr    akabla         NaN
# 26      accabler  NaN       NaN  NaN  NaN        NaN    akabla         NaN
# 27     accaparer  NaN   akaparE  NaN  NaN   akaparEr   akapara         NaN
# 28     accentuer  NaN       NaN  NaN  NaN        NaN   aksâtya         NaN
# 29      accepter  NaN       NaN  NaN  NaN        NaN   aksEpta         NaN
# ...          ...  ...       ...  ...  ...        ...       ...         ...
# 3155   étinceler  NaN   Etês9lE  NaN  NaN   Etês9lEr   Etês9la         NaN
# 3156     étioler  NaN    EtjOlE  NaN  NaN    EtjOlEr    EtjOla         NaN
# 3157   étiqueter  NaN   Etik9tE  NaN  NaN   Etik9tEr   Etik9ta         NaN
# 3158      étirer  NaN     EtirE  NaN  NaN     EtirEr     Etira         NaN
# 3159     étoiler  NaN    EtwalE  NaN  NaN    EtwalEr    Etwala         NaN
# 3160     étonner  NaN       NaN  NaN  NaN        NaN     EtOna         NaN
# 3161    étouffer  NaN     EtufE  NaN  NaN     EtufEr     Etufa         NaN
# 3162    étourdir  NaN       NaN  NaN  NaN        NaN    Eturdi         NaN
# 3163   étrangler  NaN       NaN  NaN  NaN   EtrâglEr   Etrâgla         NaN
# 3164   étrangler  NaN       NaN  NaN  NaN        NaN   Etrâgla         NaN
# 3165   étreindre  NaN       NaN  NaN  NaN        NaN       NaN         NaN
# 3166    étrenner  NaN       NaN  NaN  NaN        NaN       NaN    EtrEn9rô
# 3167     étudier  NaN       NaN  NaN  NaN        NaN       NaN         NaN
# 3168     évacuer  NaN       NaN  NaN  NaN    EvakyEr    Evakya         NaN
# 3169     évacuer  NaN       NaN  NaN  NaN        NaN    Evakya         NaN
# 3170     évacuer  NaN       NaN  NaN  NaN    EvakyEr    Evakya         NaN
# 3171     évacuer  NaN       NaN  NaN  NaN        NaN    Evakya         NaN
# 3172     évacuer  NaN       NaN  NaN  NaN    EvakyEr    Evakya         NaN
# 3173      évader  NaN     EvadE  NaN  NaN     EvadEr     Evada         NaN
# 3174    évanouir  NaN       NaN  NaN  NaN        NaN    Evanui         NaN
# 3175    évaporer  NaN   EvapOrE  NaN  NaN   EvapOrEr   EvapOra         NaN
# 3176    éveiller  NaN     EvEjE  NaN  NaN     EvEjEr     EvEja         NaN
# 3177     éventer  NaN     EvâtE  NaN  NaN     EvâtEr     Evâta         NaN
# 3178    éventrer  NaN       NaN  NaN  NaN    EvâtrEr    Evâtra         NaN
# 3179    évertuer  NaN       NaN  NaN  NaN        NaN   EvErtya    EvErtyrô
# 3180      éviter  NaN     EvitE  NaN  NaN     EvitEr     Evita         NaN
# 3181     évoluer  NaN       NaN  NaN  NaN    EvOlyEr    EvOlya     EvOlyrô
# 3182     évoquer  NaN     EvOkE  NaN  NaN     EvOkEr     EvOka         NaN
# 3183        être  fym        fy  fyt   fy        fyr        fy        s9rô
# 3184        ôter  NaN       NaN  NaN  NaN       OtEr       Ota         NaN
#
#             fi1S        fi2P  ...        ppMP      ppMS   ps1P     ps1S  \
# 0        abEs9rE     abEs9re  ...       abEse     abEse    NaN     abEs
# 1      abâdOn9rE   abâdOn9re  ...     abâdOne   abâdOne    NaN   abâdOn
# 2     abazurdirE  abazurdire  ...    abazurdi  abazurdi    NaN      NaN
# 3            NaN         NaN  ...       abaty     abaty    NaN     abat
# 4       abZyr9rE    abZyr9re  ...      abZyre    abZyre    NaN    abZyr
# 5            NaN         NaN  ...         NaN     abOli    NaN      NaN
# 6        abôd9rE     abôd9re  ...       abôde     abôde    NaN      NaN
# 7            NaN         NaN  ...       abOne     abOne    NaN      NaN
# 8       abOrd9rE         NaN  ...      abOrde    abOrde    NaN    abOrd
# 9        abul9rE     abul9re  ...         NaN     abule    NaN     abul
# 10           NaN         NaN  ...         NaN     abuti    NaN   abutis
# 11           NaN         NaN  ...      abwaje    abwaje    NaN      NaN
# 12           NaN    abr9v9re  ...      abr9ve    abr9ve    NaN      NaN
# 13      abrit9rE    abrit9re  ...      abrite    abrite    NaN    abrit
# 14      abrOZ9rE    abrOZ9re  ...      abrOZe    abrOZe    NaN    abrOZ
# 15      abrytirE         NaN  ...      abryti    abryti    NaN      NaN
# 16           NaN         NaN  ...      absâte    absâte    NaN      NaN
# 17     absOrb9rE         NaN  ...     absOrbe   absOrbe    NaN      NaN
# 18           NaN         NaN  ...     absOlve   absOlve    NaN   absOlv
# 19     abstjêdrE   abstjêdre  ...     abst9ny   abst9ny    NaN  abstjEn
# 20           NaN         NaN  ...      abstrE    abstrE    NaN      NaN
# 21       abyz9rE     abyz9re  ...       abyze     abyze    NaN     abyz
# 22    abatardirE  abatardire  ...    abatardi  abatardi    NaN      NaN
# 23       abim9rE     abim9re  ...       abime     abime    NaN     abim
# 24    akaJard9rE         NaN  ...    akaJarde  akaJarde    NaN  akaJard
# 25      akabl9rE         NaN  ...      akable    akable    NaN      NaN
# 26      akabl9rE         NaN  ...      akable    akable    NaN      NaN
# 27     akapar9rE         NaN  ...     akapare   akapare    NaN   akapar
# 28           NaN         NaN  ...     aksâtye   aksâtye    NaN      NaN
# 29     aksEpt9rE         NaN  ...         NaN   aksEpte    NaN   aksEpt
# ...          ...         ...  ...         ...       ...    ...      ...
# 3155         NaN   Etês9l9re  ...     Etês9le   Etês9le    NaN      NaN
# 3156    EtjOl9rE    EtjOl9re  ...         NaN    EtjOle    NaN    EtjOl
# 3157         NaN   Etik9t9re  ...     Etik9te   Etik9te    NaN      NaN
# 3158     Etir9rE     Etir9re  ...       Etire     Etire    NaN     Etir
# 3159    Etwal9rE         NaN  ...      Etwale    Etwale    NaN      NaN
# 3160     EtOn9rE     EtOn9re  ...       EtOne     EtOne    NaN     EtOn
# 3161     Etuf9rE     Etuf9re  ...       Etufe     Etufe    NaN     Etuf
# 3162         NaN         NaN  ...         NaN    Eturdi    NaN      NaN
# 3163   Etrâgl9rE         NaN  ...         NaN   Etrâgle    NaN   Etrâgl
# 3164   Etrâgl9rE         NaN  ...         NaN   Etrâgle    NaN   Etrâgl
# 3165         NaN         NaN  ...         NaN      Etrê    NaN      NaN
# 3166    EtrEn9rE         NaN  ...         NaN    EtrEne    NaN    EtrEn
# 3167     EtydirE         NaN  ...         NaN    Etydje    NaN      NaN
# 3168         NaN         NaN  ...      Evakye    Evakye    NaN      NaN
# 3169         NaN         NaN  ...      Evakye    Evakye    NaN      NaN
# 3170         NaN         NaN  ...         NaN    Evakye    NaN      NaN
# 3171         NaN         NaN  ...         NaN    Evakye    NaN      NaN
# 3172         NaN         NaN  ...      Evakye    Evakye    NaN      NaN
# 3173     Evad9rE         NaN  ...         NaN     Evade    NaN     Evad
# 3174         NaN         NaN  ...         NaN    Evanui    NaN      NaN
# 3175   EvapOr9rE   EvapOr9re  ...     EvapOre   EvapOre    NaN   EvapOr
# 3176         NaN         NaN  ...       EvEje     EvEje    NaN     EvEj
# 3177     Evât9rE         NaN  ...       Evâte     Evâte    NaN      NaN
# 3178    Evâtr9rE         NaN  ...      Evâtre    Evâtre    NaN    Evâtr
# 3179    EvErtyrE         NaN  ...     EvErtye   EvErtye    NaN   EvErty
# 3180     Evit9rE     Evit9re  ...       Evite     Evite    NaN     Evit
# 3181     EvOlyrE         NaN  ...      EvOlye    EvOlye    NaN    EvOly
# 3182     EvOk9rE     EvOk9re  ...       EvOke     EvOke    NaN     EvOk
# 3183        s9rE        s9re  ...         NaN       NaN  swajô      swa
# 3184         NaN         NaN  ...         NaN       Ote    NaN      NaN
#
#        ps2P     ps2S     ps3P     ps3S     FS     FP
# 0       NaN     abEs     abEs     abEs    NaN    NaN
# 1       NaN   abâdOn   abâdOn   abâdOn    NaN    NaN
# 2       NaN      NaN      NaN      NaN    NaN    NaN
# 3       NaN      NaN      NaN      NaN    NaN    NaN
# 4       NaN    abZyr    abZyr    abZyr    NaN    NaN
# 5       NaN      NaN      NaN   abOlis    NaN    NaN
# 6       NaN      NaN     abôd      NaN    NaN    NaN
# 7       NaN      NaN      NaN     abOn    NaN    NaN
# 8       NaN      NaN      NaN    abOrd    NaN    NaN
# 9       NaN     abul     abul     abul    NaN    NaN
# 10      NaN      NaN      NaN      NaN    NaN    NaN
# 11      NaN      NaN      NaN      NaN    NaN    NaN
# 12      NaN    abr9v      NaN      NaN    NaN    NaN
# 13      NaN    abrit      NaN    abrit    NaN    NaN
# 14      NaN    abrOZ    abrOZ    abrOZ    NaN    NaN
# 15      NaN      NaN      NaN      NaN    NaN    NaN
# 16      NaN    absât      NaN    absât    NaN    NaN
# 17      NaN      NaN      NaN      NaN    NaN    NaN
# 18      NaN   absOlv      NaN   absOlv    NaN    NaN
# 19      NaN      NaN      NaN  abstjEn    NaN    NaN
# 20      NaN      NaN      NaN      NaN    NaN    NaN
# 21      NaN     abyz     abyz     abyz    NaN    NaN
# 22      NaN      NaN      NaN      NaN    NaN    NaN
# 23      NaN     abim     abim     abim    NaN    NaN
# 24      NaN  akaJard  akaJard  akaJard    NaN    NaN
# 25      NaN    akabl      NaN    akabl    NaN    NaN
# 26      NaN    akabl      NaN    akabl    NaN    NaN
# 27      NaN   akapar   akapar   akapar    NaN    NaN
# 28      NaN      NaN      NaN   aksâty    NaN    NaN
# 29      NaN      NaN      NaN   aksEpt    NaN    NaN
# ...     ...      ...      ...      ...    ...    ...
# 3155    NaN      NaN      NaN      NaN    NaN    NaN
# 3156    NaN    EtjOl    EtjOl      NaN    NaN    NaN
# 3157    NaN      NaN      NaN      NaN    NaN    NaN
# 3158    NaN     Etir     Etir     Etir    NaN    NaN
# 3159    NaN      NaN      NaN    Etwal    NaN    NaN
# 3160    NaN     EtOn     EtOn     EtOn    NaN    NaN
# 3161    NaN     Etuf     Etuf     Etuf    NaN    NaN
# 3162    NaN      NaN      NaN      NaN    NaN    NaN
# 3163    NaN   Etrâgl      NaN   Etrâgl    NaN    NaN
# 3164    NaN   Etrâgl      NaN   Etrâgl    NaN    NaN
# 3165    NaN      NaN      NaN    EtrEJ  Etrêt  Etrêt
# 3166    NaN    EtrEn      NaN    EtrEn    NaN    NaN
# 3167    NaN      NaN      NaN      NaN    NaN    NaN
# 3168    NaN    Evaky      NaN    Evaky    NaN    NaN
# 3169    NaN    Evaky      NaN    Evaky    NaN    NaN
# 3170    NaN    Evaky      NaN    Evaky    NaN    NaN
# 3171    NaN    Evaky      NaN    Evaky    NaN    NaN
# 3172    NaN    Evaky      NaN    Evaky    NaN    NaN
# 3173    NaN     Evad      NaN     Evad    NaN    NaN
# 3174    NaN      NaN      NaN      NaN    NaN    NaN
# 3175    NaN   EvapOr   EvapOr   EvapOr    NaN    NaN
# 3176    NaN     EvEj      NaN      NaN    NaN    NaN
# 3177    NaN     Evât      NaN     Evât    NaN    NaN
# 3178    NaN      NaN      NaN    Evâtr    NaN    NaN
# 3179    NaN   EvErty      NaN   EvErty    NaN    NaN
# 3180    NaN     Evit      NaN     Evit    NaN    NaN
# 3181    NaN    EvOly      NaN    EvOly    NaN    NaN
# 3182    NaN     EvOk     EvOk     EvOk    NaN    NaN
# 3183  swaje      swa      swa      swa    NaN    NaN
# 3184    NaN      NaN      NaN      NaN    NaN    NaN
#
# [3185 rows x 54 columns]

# %%
#verbesBRASS.to_csv(path_or_buf=lexiquePrefix+"-01-N"+'-VerbesActions-BRASS.csv',encoding="utf8",sep=";")
verbesSILVER.to_csv(path_or_buf=lexiquePrefix+"-01-N"+'-VerbesActions-SILVER.csv',encoding="utf8",sep=";")
#verbesGOLD.to_csv(path_or_buf=lexiquePrefix+"-01-N"+'-VerbesActions-GOLD.csv',encoding="utf8",sep=";")

# %%
derivesABS=derivesGOLD[~derivesGOLD["lexeme"].isin(derivesSILVER["lexeme"].tolist())]["lexeme"].tolist()
basesABS=[baseDerives[derive] for derive in derivesABS]
basesABS
# Out:
# [u'absoudre',
#  u'accalmir',
#  u'accro\xeetre',
#  u'amener',
#  u'astreindre',
#  u'atteindre',
#  u'battre',
#  u'buter',
#  u'charpir',
#  u'chevaucher',
#  u'complaindre',
#  u'conqu\xe9rir',
#  u'couvrir',
#  u'couver',
#  u'croiser',
#  u'cro\xeetre',
#  u'cuire',
#  u'desservir ',
#  u'dicter',
#  u'd\xe9cro\xeetre',
#  u'd\xe9culotter',
#  u'd\xe9prendre',
#  u'd\xe9rouiller',
#  u'embarder',
#  u'entendre',
#  u'entremettre',
#  u'envoler',
#  u'feindre',
#  u'fendre',
#  u'flamber',
#  u'fouler',
#  u'fricasser',
#  u'garantir',
#  u'gicler',
#  u'grimper',
#  u'huer',
#  u'm\xe9prendre',
#  u'm\xe9vendre',
#  u'm\xealer',
#  u'ou\xefr',
#  u'passer',
#  u'paver',
#  u'percer',
#  u'peser',
#  u'piper',
#  u'pousser',
#  u'randonner',
#  u'reconduire',
#  u'redire',
#  u'refondre',
#  u'remettre',
#  u'remonter',
#  u'rendre',
#  u'rentrer',
#  u'repartir',
#  u'reposer',
#  u'retomber',
#  u'revendre',
#  u'rincer',
#  u'rosser',
#  u'ruer',
#  u'r\xe9gir',
#  u'r\xe9ussir',
#  u'saigner',
#  u'saillir',
#  u'saisir',
#  u'saucer',
#  u'surtondre',
#  u'survenir',
#  u'tabasser',
#  u'tendre',
#  u'torcher',
#  u'touer',
#  u'traire',
#  u'trouer',
#  u't\xe9ter',
#  u'veiller',
#  u'virer',
#  u'\xe9claircir',
#  u'\xe9tuver']

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import datetime

# %%
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %% [markdown]
# typeEchantillon :
# - fixe pour utiliser tailleEchantillon
# - variable pour utiliser nombre,increment,nombreInitial
# - total pour utiliser tout le lexique

# %%
typeEchantillon="total"
tailleEchantillon=50000
nombre=1000
increment=250
nombreInitial=20
freqForme=1000000
if typeEchantillon=="total":
    echantillonPrefix="-total"
elif typeEchantillon=="fixe":
    echantillonPrefix="-%d-%s" % (tailleEchantillon,dateheure())
else:
    echantillonPrefix="XXX"

# %%
filePrefix="MGC-150812"

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False

# %% [markdown]
# ###Préparation des matrices de traits

# %% [markdown]
# features.add_config('bdlexique.ini')
# fs=features.FeatureSystem('phonemes')
# #fs.supremum.concept.extent

# %% [markdown]
# bdlexiqueIn = unicode(u"èò")
# bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
# neutreOut = unicode(u"EO")
# neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %% [markdown]
# def recoder(chaine,table=neutralise):
#     if type(chaine)==str:
#         temp=unicode(chaine.decode('utf8')).translate(table)
#         result=temp.encode('utf8')
#     elif type(chaine)==unicode:
#         result=chaine.translate(table)
#     return result

# %% [markdown]
# ###Définition des cases
# - principales pour le paradigme courant
# - secondaires pour les cases rares
# - totales pour le tout

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %%
with open('MGC-150812-Verbes.pkl', 'rb') as input:
    verbes = pickle.load(input)

# %% [markdown]
# verbes["phono"]=verbes["phono"].apply(lambda x: recoder(x))

# %% [markdown]
# #Echantillonage

# %% [markdown]
# ##Assembler les échantillons correspondant à une étape n

# %%
def assemblerExtrait(nombre):
    return verbes.ix[np.sort(np.concatenate(tirages[0:nombre]))]

# %% [markdown]
# ###Tirage incrémental des formes disponibles
# - increment : taille de chaque tirage
# - nombre : nombre de tirages
#
# np.random.choice donne une liste d'index de formes tirées dans l'ordre du tirage
#
# on découpe la liste en morceaux de la taille de l'incrément

# %%
if typeEchantillon=="variable":
    tirage=np.random.choice(verbes.index,size=nombre*increment,p=verbes["prob"],replace=False)
    tirages=[tirage[increment*x:increment*(x+1)] for x in range(len(tirage)/increment+(len(tirage)%increment!=0))]
    extrait=assemblerExtrait(nombreInitial)
elif typeEchantillon=="fixe":
    tirage=np.random.choice(verbes.index,size=tailleEchantillon,p=verbes["prob"],replace=False)
    extrait=verbes.ix[np.sort(tirage)]
elif typeEchantillon=="total":
    extrait=verbes

# %%
paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

# %%
paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+"-paradigmes.csv",encoding="utf8",sep=";")

# %%
#with open(filePrefix+echantillonPrefix+'-Paradigmes.pkl', 'wb') as output:
#   pickle.dump(paradigmes, output, pickle.HIGHEST_PROTOCOL)

# %%
extrait
# Out:
#                 ortho     phono  ext cs  ms   vs    lexeme          freq  \
# 40                  a         a  NaN  V  3S   pi     avoir  7.167730e+11
# 45            abaissa     abèsa  NaN  V  3S   ai  abaisser  2.640000e+08
# 46           abaissai     abèsè  NaN  V  1S   ai  abaisser  1.700000e+07
# 47        abaissaient     abèsè   t"  V  3P   ii  abaisser  4.100000e+07
# 48          abaissais     abèsè   z"  V  1S   ii  abaisser  2.297000e+03
# 49          abaissais     abèsè   z"  V  2S   ii  abaisser  2.297000e+03
# 50          abaissait     abèsè   t"  V  3S   ii  abaisser  2.520000e+08
# 52          abaissant     abèsâ   t"  V       pP  abaisser  2.510000e+08
# 56           abaissas     abèsa   z"  V  2S   ai  abaisser  2.297000e+03
# 57         abaissasse    abèsas    @  V  1S   is  abaisser  2.297000e+03
# 58       abaissassent    abèsas  @t"  V  3P   is  abaisser  2.297000e+03
# 59        abaissasses    abèsas    @  V  2S   is  abaisser  2.297000e+03
# 60       abaissassiez  abèsasje   z"  V  2P   is  abaisser  2.297000e+03
# 61      abaissassions  abèsasjô   z"  V  1P   is  abaisser  2.297000e+03
# 64            abaisse      abEs    @  V  1S   pi  abaisser  4.730000e+08
# 65            abaisse      abEs    @  V  1S   ps  abaisser  2.297000e+03
# 66            abaisse      abEs    @  V  2S   pI  abaisser  4.730000e+08
# 67            abaisse      abEs    @  V  3S   pi  abaisser  4.730000e+08
# 68            abaisse      abEs    @  V  3S   ps  abaisser  2.297000e+03
# 71          abaissent      abEs  @t"  V  3P   pi  abaisser  1.000000e+08
# 72          abaissent      abEs  @t"  V  3P   ps  abaisser  2.297000e+03
# 73           abaisser     abèse   R"  V      inf  abaisser  4.000000e+08
# 74          abaissera   abès6ra  NaN  V  3S   fi  abaisser  2.600000e+07
# 75         abaisserai   abès6rè  NaN  V  1S   fi  abaisser  1.700000e+07
# 49      4.261360e-11  ii2S
# 50      4.675067e-06  ii3S
# 52      4.656515e-06    pP
# 56      4.261360e-11  ai2S
# 57      4.261360e-11  is1S
# 58      4.261360e-11  is3P
# 59      4.261360e-11  is2S
# 60      4.261360e-11  is2P
# 61      4.261360e-11  is1P
# 64      8.775026e-06  pi1S
# 65      4.261360e-11  ps1S
# 66      8.775026e-06  pI2S
# 67      8.775026e-06  pi3S
# 68      4.261360e-11  ps3S
# 71      1.855185e-06  pi3P
# 72      4.261360e-11  ps3P
# 73      7.420741e-06   inf
# 74      4.823481e-07  fi3S
# 75      3.153815e-07  fi1S
# 76      1.484148e-07  pc3P
# 77      2.411741e-07  pc1S
# 78      2.411741e-07  pc2S
# 79      4.081407e-07  pc3S
# 80      4.261360e-11  fi2S
# 81      4.261360e-11  fi2P
# ...              ...   ...
# 437518  1.113111e-06  fi3S
# 437519  2.968296e-07  fi1S
# 437520  1.091405e-10  pc3P
# 437521  2.597259e-07  pc1S
# 437522  2.597259e-07  pc2S
# 437523  1.057456e-06  pc3S
# 437524  5.751074e-07  fi2S
# 437525  6.864185e-07  fi2P
# 437526  1.091405e-10  pc2P
# 437527  1.298630e-07  pc1P
# 437528  1.091405e-10  fi1P
# 437529  1.091405e-10  fi3P
# 437530  1.205870e-06  pi2S
# 437531  1.091405e-10  ps2S
# 437532  3.914441e-06  pI2P
# 437533  3.914441e-06  pi2P
# 437534  3.153815e-07  ii2P
# 437535  1.091405e-10  ps2P
# 437536  1.091405e-10  ii1P
# 437537  1.091405e-10  ps1P
# 437538  1.091405e-10  pI1P
# 437539  1.669667e-07  pi1P
# 437540  1.091405e-10  ai1P
# 437541  2.597259e-07  is3S
# 437542  1.091405e-10  ai2P
# 437543  5.009000e-07  ai3P
# 437544  1.604735e-05  ppMS
# 437545  1.780978e-06  ppFS
# 437546  4.266926e-07  ppFP
# 437547  3.339333e-07  ppMP
#
# [328103 rows x 10 columns]

# %%
extrait[extrait["vs"]=="pp"]
# Out:
#               ortho     phono  ext cs  ms  vs      lexeme          freq  \
# 101         abaissé     abèse  NaN  K  MS  pp    abaisser  2.090000e+08
# 102        abaissée     abèse  NaN  K  FS  pp    abaisser  4.400000e+07
# 103       abaissées     abèse   z"  K  FP  pp    abaisser  1.000000e+06
# 104        abaissés     abèse   z"  K  MP  pp    abaisser  3.700000e+07
# 164       abandonné   abâdòne  NaN  K  MS  pp  abandonner  4.648000e+09
# 166      abandonnée   abâdòne  NaN  K  FS  pp  abandonner  1.700000e+09
# 168     abandonnées   abâdòne   z"  K  FP  pp  abandonner  3.970000e+08
# 170      abandonnés   abâdòne   z"  K  MP  pp  abandonner  8.480000e+08
# 177       abasourdi  abazurdi  NaN  K  MS  pp  abasourdir  2.440000e+08
# 179      abasourdie  abazurdi  NaN  K  FS  pp  abasourdir  6.600000e+07
# 181     abasourdies  abazurdi   z"  K  FP  pp  abasourdir  3.520000e+02
# 437335      évitées     èvite   z"  K  FP  pp      éviter  3.100000e+07
# 437336       évités     èvite   z"  K  MP  pp      éviter  7.200000e+07
# 437412       évolué    èvòlye  NaN  K  MS  pp     évoluer  2.229000e+03
# 437463       évoqué     èvòke  NaN  K  MS  pp     évoquer  7.000000e+08
# 437464      évoquée     èvòke  NaN  K  FS  pp     évoquer  1.060000e+08
# 437465     évoquées     èvòke   z"  K  FP  pp     évoquer  4.400000e+07
# 437466      évoqués     èvòke   z"  K  MP  pp     évoquer  1.340000e+08
# 437544          ôté       òte  NaN  K  MS  pp        ôter  8.650000e+08
# 437545         ôtée       òte  NaN  K  FS  pp        ôter  9.600000e+07
# 437546        ôtées       òte   z"  K  FP  pp        ôter  2.300000e+07
# 437547         ôtés       òte   z"  K  MP  pp        ôter  1.800000e+07
#
#                 prob  case
# 101     3.877337e-06  ppMS
# 102     8.162815e-07  ppFS
# 103     1.855185e-08  ppFP
# 104     6.864185e-07  ppMP
# 164     8.622901e-05  ppMS
# 166     3.153815e-05  ppFS
# 168     7.365085e-06  ppFP
# 170     1.573197e-05  ppMP
# 177     4.526652e-06  ppMS
# 179     1.224422e-06  ppFS
# 181     6.530252e-12  ppFP
# 197     5.009000e-07  ppMP
# 305     3.508155e-05  ppMS
# 307     8.570955e-06  ppFS
# 310     1.317181e-06  ppFP
# 313     8.997648e-06  ppMP
# 386     1.855185e-16  ppMS
# 443     1.966496e-06  ppMS
# 444     1.298630e-07  ppFS
# 445     6.010800e-12  ppFP
# 446     6.010800e-12  ppMP
# 505     1.855185e-16  ppMS
# 506     1.855185e-16  ppFS
# 507     1.855185e-16  ppFP
# 508     1.855185e-16  ppMP
# 567     3.710370e-13  ppMS
# 616     5.194518e-07  ppMS
# 617     1.298630e-07  ppFS
# 618     3.005400e-12  ppFP
# 619     1.298630e-07  ppMP
# ...              ...   ...
# 437048  1.298630e-07  ppMP
# 437096  7.049704e-07  ppMS
# 437097  5.918041e-12  ppFS
# 437098  5.918041e-12  ppFP
# 437099  5.918041e-12  ppMP
# 437166  1.484148e-07  ppMS
# 437167  3.895889e-07  ppFS
# 437168  1.484148e-07  ppFP
# 437169  1.298630e-07  ppMP
# 437203  1.094559e-06  ppMS
# 437204  7.420741e-08  ppFS
# 437205  3.506300e-12  ppFP
# 437206  2.411741e-07  ppMP
# 437274  1.187319e-12  ppMS
# 437275  2.040704e-07  ppFS
# 437276  1.187319e-12  ppFP
# 437277  2.411741e-07  ppMP
# 437333  1.981338e-05  ppMS
# 437334  2.541604e-06  ppFS
# 437335  5.751074e-07  ppFP
# 437336  1.335733e-06  ppMP
# 437412  4.135208e-11  ppMS
# 437463  1.298630e-05  ppMS
# 437464  1.966496e-06  ppFS
# 437465  8.162815e-07  ppFP
# 437466  2.485948e-06  ppMP
# 437544  1.604735e-05  ppMS
# 437545  1.780978e-06  ppFS
# 437546  4.266926e-07  ppFP
# 437547  3.339333e-07  ppMP
#
# [23543 rows x 10 columns]

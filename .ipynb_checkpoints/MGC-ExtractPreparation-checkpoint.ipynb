# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import datetime

# %%
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %% [markdown]
# typeEchantillon :
# - fixe pour utiliser tailleEchantillon
# - variable pour utiliser nombre,increment,nombreInitial
# - total pour utiliser tout le lexique

# %%
typeEchantillon="fixe"
tailleEchantillon=30000
nombre=1000
increment=250
nombreInitial=20
freqForme=1000000
if typeEchantillon=="total":
    echantillonPrefix="-total"
elif typeEchantillon=="fixe":
    echantillonPrefix="-%d-%s" % (tailleEchantillon,dateheure())
else:
    echantillonPrefix="XXX"

# %%
filePrefix="MGC-150812"

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False

# %% [markdown]
# ###Préparation des matrices de traits

# %% [markdown]
# features.add_config('bdlexique.ini')
# fs=features.FeatureSystem('phonemes')
# #fs.supremum.concept.extent

# %% [markdown]
# bdlexiqueIn = unicode(u"èò")
# bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
# neutreOut = unicode(u"EO")
# neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %% [markdown]
# def recoder(chaine,table=neutralise):
#     if type(chaine)==str:
#         temp=unicode(chaine.decode('utf8')).translate(table)
#         result=temp.encode('utf8')
#     elif type(chaine)==unicode:
#         result=chaine.translate(table)
#     return result

# %% [markdown]
# ###Définition des cases
# - principales pour le paradigme courant
# - secondaires pour les cases rares
# - totales pour le tout

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %%
with open('MGC-150812-Verbes.pkl', 'rb') as input:
    verbes = pickle.load(input)

# %% [markdown]
# verbes["phono"]=verbes["phono"].apply(lambda x: recoder(x))

# %% [markdown]
# #Echantillonage

# %% [markdown]
# ##Assembler les échantillons correspondant à une étape n

# %%
def assemblerExtrait(nombre):
    return verbes.ix[np.sort(np.concatenate(tirages[0:nombre]))]

# %% [markdown]
# ###Tirage incrémental des formes disponibles
# - increment : taille de chaque tirage
# - nombre : nombre de tirages
#
# np.random.choice donne une liste d'index de formes tirées dans l'ordre du tirage
#
# on découpe la liste en morceaux de la taille de l'incrément

# %%
if typeEchantillon=="variable":
    tirage=np.random.choice(verbes.index,size=nombre*increment,p=verbes["prob"],replace=False)
    tirages=[tirage[increment*x:increment*(x+1)] for x in range(len(tirage)/increment+(len(tirage)%increment!=0))]
    extrait=assemblerExtrait(nombreInitial)
elif typeEchantillon=="fixe":
    tirage=np.random.choice(verbes.index,size=tailleEchantillon,p=verbes["prob"],replace=False)
    extrait=verbes.ix[np.sort(tirage)]
elif typeEchantillon=="total":
    extrait=verbes

# %%
paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

# %%
paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+"-paradigmes.csv",encoding="utf8",sep=";")

# %%
#with open(filePrefix+echantillonPrefix+'-Paradigmes.pkl', 'wb') as output:
#   pickle.dump(paradigmes, output, pickle.HIGHEST_PROTOCOL)

# %%
paradigmes
# Out:
# case      lexeme ai1P     ai1S ai2P ai2S     ai3P     ai3S       fi1P  \
# 0       abaisser  NaN      NaN  NaN  NaN   abèsEr    abèsa        NaN
# 1     abandonner  NaN  abâdònè  NaN  NaN      NaN  abâdòna  abâdòn6rô
# 2     abasourdir  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3        abattre  NaN    abati  NaN  NaN   abatir    abati        NaN
# 4       abdiquer  NaN   abdikè  NaN  NaN      NaN      NaN        NaN
# 5       abhorrer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 6        abjurer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 7         abolir  NaN      NaN  NaN  NaN      NaN    abòli        NaN
# 8        abonder  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 9        abonner  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 10       aborder  NaN      NaN  NaN  NaN  abOrdEr   abOrda        NaN
# 11      aboucher  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 12       abouler  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 13       aboutir  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 14        aboyer  NaN      NaN  NaN  NaN      NaN   abwaja        NaN
# 15      abreuver  NaN      NaN  NaN  NaN      NaN   abr6va        NaN
# 16       abriter  NaN      NaN  NaN  NaN      NaN      NaN   abrit6rô
# 17       abroger  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 18       abrutir  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 19       abréger  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 20      absenter  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 21      absorber  NaN      NaN  NaN  NaN      NaN  absOrba        NaN
# 22      absoudre  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 23      abstenir  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 24     abstraire  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 25        abuser  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 26        abîmer  NaN    abimè  NaN  NaN      NaN      NaN        NaN
# 27    acagnarder  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 28      accabler  NaN      NaN  NaN  NaN  akablEr      NaN        NaN
# 29     accaparer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# ...          ...  ...      ...  ...  ...      ...      ...        ...
# 3891     étioler  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3892   étiqueter  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3893      étirer  NaN    ètirè  NaN  NaN   ètirEr    ètira        NaN
# 3894     étoffer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3895     étoiler  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3896     étonner  NaN    ètònè  NaN  NaN   ètònEr    ètòna        NaN
# 3897    étouffer  NaN      NaN  NaN  NaN      NaN    ètufa        NaN
# 3898    étourdir  NaN      NaN  NaN  NaN      NaN   èturdi        NaN
# 3899   étrangler  NaN      NaN  NaN  NaN      NaN  ètrâgla        NaN
# 3900   étreindre  NaN      NaN  NaN  NaN      NaN   ètrèJi        NaN
# 3901    étriller  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3902     étriper  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3903     étudier  NaN   ètydjè  NaN  NaN      NaN   ètydja    ètydirô
# 3904     évacuer  NaN      NaN  NaN  NaN      NaN   èvakya        NaN
# 3905      évader  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3906     évaluer  NaN      NaN  NaN  NaN  èvalyEr   èvalya        NaN
# 3907    évanouir  NaN      NaN  NaN  NaN      NaN   èvanui        NaN
# 3908    évaporer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3909    éveiller  NaN    èvèjè  NaN  NaN      NaN    èvèja        NaN
# 3910     éventer  NaN      NaN  NaN  NaN      NaN    èvâta        NaN
# 3911    éventrer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3912    évertuer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3913      évider  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3914     évincer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3915   éviscérer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3916      éviter  NaN      NaN  NaN  NaN      NaN    èvita        NaN
# 3917     évoluer  NaN      NaN  NaN  NaN      NaN      NaN        NaN
# 3918     évoquer  NaN    èvòkè  NaN  NaN      NaN    èvòka        NaN
# 3919        être  fym       fy  NaN   fy      fyr       fy       s6rô
# 3920        ôter  NaN      òtè  NaN  NaN      NaN      òta        NaN
#
# case       fi1S  fi2P   ...        ppFP     ppFS     ppMP      ppMS   ps1P  \
# 0       abès6rè   NaN   ...         NaN    abèse      NaN     abèse    NaN
# 1     abâdòn6rè   NaN   ...     abâdòne  abâdòne  abâdòne   abâdòne    NaN
# 2           NaN   NaN   ...         NaN      NaN      NaN  abazurdi    NaN
# 3        abatrè   NaN   ...         NaN    abaty    abaty     abaty    NaN
# 4           NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 5           NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 6           NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 7           NaN   NaN   ...         NaN    abòli    abòli     abòli    NaN
# 8           NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 9           NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 10          NaN   NaN   ...      abOrde      NaN   abOrde    abOrde    NaN
# 11          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 12          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 13          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 14          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 15          NaN   NaN   ...         NaN      NaN      NaN    abr6ve    NaN
# 16          NaN   NaN   ...      abrite   abrite      NaN    abrite    NaN
# 17          NaN   NaN   ...         NaN      NaN   abròZe       NaN    NaN
# 18          NaN   NaN   ...         NaN   abryti   abryti    abryti    NaN
# 19          NaN   NaN   ...         NaN      NaN      NaN    abrèZe    NaN
# 20          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 21          NaN   NaN   ...         NaN  absOrbe  absOrbe   absOrbe    NaN
# 22          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 23          NaN   NaN   ...         NaN  abst6ny      NaN       NaN    NaN
# 24          NaN   NaN   ...         NaN      NaN   abstrè    abstrè    NaN
# 25          NaN   NaN   ...         NaN      NaN      NaN     abyze    NaN
# 26          NaN   NaN   ...         NaN    abime    abime     abime    NaN
# 27          NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 28          NaN   NaN   ...         NaN      NaN   akable    akable    NaN
# 29          NaN   NaN   ...         NaN      NaN      NaN   akapare    NaN
# ...         ...   ...   ...         ...      ...      ...       ...    ...
# 3891        NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 3892        NaN   NaN   ...         NaN      NaN      NaN   ètik6te    NaN
# 3893        NaN   NaN   ...       ètire    ètire    ètire     ètire    NaN
# 3894        NaN   NaN   ...         NaN      NaN      NaN     ètòfe    NaN
# 3895        NaN   NaN   ...      ètwale      NaN   ètwale       NaN    NaN
# 3896        NaN   NaN   ...       ètòne    ètòne    ètòne     ètòne    NaN
# 3897        NaN   NaN   ...         NaN    ètufe    ètufe     ètufe    NaN
# 3898        NaN   NaN   ...         NaN      NaN   èturdi    èturdi    NaN
# 3899  ètrâgl6rè   NaN   ...         NaN  ètrâgle      NaN   ètrâgle    NaN
# 3900        NaN   NaN   ...         NaN      NaN     ètrê      ètrê    NaN
# 3901        NaN   NaN   ...         NaN      NaN   ètrije       NaN    NaN
# 3902        NaN   NaN   ...         NaN      NaN      NaN    ètripe    NaN
# 3903        NaN   NaN   ...         NaN   ètydje      NaN    ètydje    NaN
# 3904        NaN   NaN   ...         NaN   èvakye   èvakye    èvakye    NaN
# 3905        NaN   NaN   ...         NaN    èvade      NaN     èvade    NaN
# 3906        NaN   NaN   ...         NaN      NaN      NaN    èvalye    NaN
# 3907        NaN   NaN   ...         NaN   èvanui   èvanui    èvanui    NaN
# 3908        NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 3909    èvèj6rè   NaN   ...       èvèje    èvèje    èvèje     èvèje    NaN
# 3910        NaN   NaN   ...         NaN    èvâte      NaN     èvâte    NaN
# 3911        NaN   NaN   ...         NaN      NaN      NaN    èvâtre    NaN
# 3912        NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 3913        NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 3914        NaN   NaN   ...         NaN      NaN      NaN     èvêse    NaN
# 3915        NaN   NaN   ...         NaN  èvisère      NaN       NaN    NaN
# 3916        NaN   NaN   ...         NaN    èvite    èvite     èvite    NaN
# 3917        NaN   NaN   ...         NaN      NaN      NaN       NaN    NaN
# 3918        NaN   NaN   ...         NaN    èvòke    èvòke     èvòke    NaN
# 3919       s6rè  s6re   ...         NaN      NaN      NaN       NaN  swajô
# 3920        NaN   NaN   ...         NaN      òte      NaN       òte    NaN
#
# case    ps1S   ps2P    ps2S    ps3P     ps3S
# 0        NaN    NaN     NaN     NaN      NaN
# 1        NaN    NaN  abâdòn  abâdòn   abâdòn
# 2        NaN    NaN     NaN     NaN      NaN
# 3       abat    NaN     NaN     NaN      NaN
# 4        NaN    NaN     NaN     NaN      NaN
# 5        NaN    NaN     NaN     NaN      NaN
# 6        NaN    NaN     NaN     NaN      NaN
# 7        NaN    NaN     NaN     NaN      NaN
# 8        NaN    NaN     NaN     NaN      NaN

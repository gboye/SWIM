# %% [markdown]
# #Génération de paradigme
# À partir d'un remplissage de paradigme, calculer la génération suivante du remplissage

# %% [markdown]
# ##Données
#
# - paradigme : dict
#  - le premier niveau défini les cases avec la liste des formes qui les occupent
#  - le deuxième niveau donne les formes et leur proportion à l'intérieur de la case
# - règles

# %%
# inParadigme={"inf":["lave"], "prs3":[], "partpst":[], "imparf3":[]}
# inParadigme={'imparf3': ['lavE'], 'inf': [], 'partpst': ['lave'], 'prs3': ['lav']}
inParadigme={'imparf3': [], 'inf': [('finir',1)], 'partpst': [], 'prs3': []}
outParadigme={"inf":[], "prs3":[], "partpst":[], "imparf3":[]}
regles={"inf":{"prs3":[("e",""),("ir","i")],"partpst":[("e","e"),("ir","i")],"imparf3":[("e","E"),("ir","isE")]}, 
        "prs3":{"inf":[("","e"),("i","ir")], "partpst":[("","e"),("i","i")], "imparf3":[("","E"),("i","isE")]},
        "partpst":{"inf":[("e","e")],"prs3":[("e","")],"imparf3":[("e","E")]}, 
        "imparf3":{"inf":[("E","e")],"prs3":[("E","")],"partpst":[("E","e")]}, 
        }
distributions={}

# %%
def appliquerRegle(inForme,regle):
    if len(regle[0])!=0 and inForme.endswith(regle[0]):
        result=inForme[:-len(regle[0])]+regle[1]
    elif inForme.endswith(regle[0]):
        result=inForme+regle[1]
    return result

# %%
def genererParadigme(inParadigme):
    
    
    def distribuerForme(inForme):
        result=[]
        for regle in regles[inCase][outCase]:
            if inForme.endswith(regle[0]):
                outForme=appliquerRegle(inForme,regle)
                result.append((outForme,poids))
        return result
    
    
    for inCase in inParadigme:
        if inParadigme[inCase]:
            autresCases=[i for i in inParadigme.keys() if i!=inCase]
#            print autresCases
            for outCase in autresCases:
                if not outCase in distributions:
                    distributions[outCase]={}
                if not inCase in distributions[outCase]:
                    distributions[outCase][inCase]={}
                for forme,poids in inParadigme[inCase]:
                    distributions[outCase][inCase][forme]=distribuerForme(forme)
#                print
#        else:
#            print "no inForme"
#            print
#    print distributions
    for distribution in distributions:
        print (distribution)
        outFormes=set()
        for inCase in distributions[distribution]:
            print ("\t",inCase,end="\n")
            for inForme in distributions[distribution][inCase]:
                print ("\t\t",inForme,end="\t")
                for outForme in distributions[distribution][inCase][inForme]:
                    print (outForme,end="\n")
                    outFormes.add(outForme)
                    print ("\t\t\t","outFormes",outFormes,end="\n")
        outParadigme[distribution]=list(outFormes)
    return outParadigme

# %%
print ("#", inParadigme)
# Out:
# # {'partpst': [], 'imparf3': [], 'inf': [('finir', 1)], 'prs3': []}

# %%
outParadigme=inParadigme
for i in range(5):
    genererParadigme(outParadigme)
    print (i, outParadigme)
# Out:
# partpst
# 	 inf
# 		 finir	('fini', 1)
# 			 outFormes {('fini', 1)}
# imparf3
# 	 inf
# 		 finir	('finisE', 1)
# 			 outFormes {('finisE', 1)}
# prs3
# 	 inf
# 		 finir	('fini', 1)
# 			 outFormes {('fini', 1)}
# 0 {'partpst': [('fini', 1)], 'imparf3': [('finisE', 1)], 'inf': [('finir', 1)], 'prs3': [('fini', 1)]}
# partpst
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finise', 1)}
# 	 inf
# 		 finir	('fini', 1)
# 			 outFormes {('fini', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('finie', 1), ('fini', 1), ('finise', 1)}
# ('fini', 1)
# 			 outFormes {('finie', 1), ('fini', 1), ('finise', 1)}
# imparf3
# 	 partpst
# 		 fini		 inf
# 		 finir	('finisE', 1)
# 			 outFormes {('finisE', 1)}
# 	 prs3
# 		 fini	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# ('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# inf
# 	 partpst
# 		 fini		 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# ('finir', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# prs3
# 	 partpst
# 		 fini		 imparf3
# 		 finisE	('finis', 1)
# 			 outFormes {('finis', 1)}
# 	 inf
# 		 finir	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 1 {'partpst': [('finie', 1), ('fini', 1), ('finise', 1)], 'imparf3': [('finiE', 1), ('finisE', 1)], 'inf': [('finie', 1), ('finir', 1), ('finise', 1)], 'prs3': [('finis', 1), ('fini', 1)]}
# partpst
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finise', 1)}
# 		 finiE	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 inf
# 		 finise	('finise', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finie	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finir	('fini', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# ('fini', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# 		 finis	('finise', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# imparf3
# 	 partpst
# 		 finise	('finisE', 1)
# 			 outFormes {('finisE', 1)}
# 		 fini			 finie	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 	 inf
# 		 finise	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finie	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finir	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 	 prs3
# 		 fini	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# ('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finis	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# inf
# 	 partpst
# 		 finise	('finise', 1)
# 			 outFormes {('finise', 1)}
# 		 fini			 finie	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finiE	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# ('finir', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# 		 finis	('finise', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# prs3
# 	 partpst
# 		 finise	('finis', 1)
# 			 outFormes {('finis', 1)}
# 		 fini			 finie	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 	 imparf3
# 		 finisE	('finis', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finiE	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 	 inf
# 		 finise	('finis', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finie	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finir	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 2 {'partpst': [('fini', 1), ('finie', 1), ('finise', 1)], 'imparf3': [('finiE', 1), ('finisE', 1)], 'inf': [('finie', 1), ('finir', 1), ('finise', 1)], 'prs3': [('finis', 1), ('fini', 1)]}
# partpst
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finise', 1)}
# 		 finiE	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 inf
# 		 finise	('finise', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finie	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finir	('fini', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# ('fini', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# 		 finis	('finise', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# imparf3
# 	 partpst
# 		 finise	('finisE', 1)
# 			 outFormes {('finisE', 1)}
# 		 fini			 finie	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 	 inf
# 		 finise	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finie	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finir	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 	 prs3
# 		 fini	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# ('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finis	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# inf
# 	 partpst
# 		 finise	('finise', 1)
# 			 outFormes {('finise', 1)}
# 		 fini			 finie	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finiE	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# ('finir', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# 		 finis	('finise', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# prs3
# 	 partpst
# 		 finise	('finis', 1)
# 			 outFormes {('finis', 1)}
# 		 fini			 finie	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 	 imparf3
# 		 finisE	('finis', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finiE	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 	 inf
# 		 finise	('finis', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finie	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finir	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 3 {'partpst': [('fini', 1), ('finie', 1), ('finise', 1)], 'imparf3': [('finiE', 1), ('finisE', 1)], 'inf': [('finie', 1), ('finir', 1), ('finise', 1)], 'prs3': [('finis', 1), ('fini', 1)]}
# partpst
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finise', 1)}
# 		 finiE	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 inf
# 		 finise	('finise', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finie	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finir	('fini', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# ('fini', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# 		 finis	('finise', 1)
# 			 outFormes {('fini', 1), ('finie', 1), ('finise', 1)}
# imparf3
# 	 partpst
# 		 finise	('finisE', 1)
# 			 outFormes {('finisE', 1)}
# 		 fini			 finie	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 	 inf
# 		 finise	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finie	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finir	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 	 prs3
# 		 fini	('finiE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# ('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# 		 finis	('finisE', 1)
# 			 outFormes {('finiE', 1), ('finisE', 1)}
# inf
# 	 partpst
# 		 finise	('finise', 1)
# 			 outFormes {('finise', 1)}
# 		 fini			 finie	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 imparf3
# 		 finisE	('finise', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 		 finiE	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# 	 prs3
# 		 fini	('finie', 1)
# 			 outFormes {('finie', 1), ('finise', 1)}
# ('finir', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# 		 finis	('finise', 1)
# 			 outFormes {('finie', 1), ('finir', 1), ('finise', 1)}
# prs3
# 	 partpst
# 		 finise	('finis', 1)
# 			 outFormes {('finis', 1)}
# 		 fini			 finie	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 	 imparf3
# 		 finisE	('finis', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finiE	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 	 inf
# 		 finise	('finis', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finie	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 		 finir	('fini', 1)
# 			 outFormes {('finis', 1), ('fini', 1)}
# 4 {'partpst': [('fini', 1), ('finie', 1), ('finise', 1)], 'imparf3': [('finiE', 1), ('finisE', 1)], 'inf': [('finie', 1), ('finir', 1), ('finise', 1)], 'prs3': [('finis', 1), ('fini', 1)]}

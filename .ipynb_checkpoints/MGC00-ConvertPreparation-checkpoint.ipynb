# %%
# -*- coding: utf8 -*-

# %%
debug=False

filePrefix="MGC-160104"
nomLexique="/Users/gilles/Copy/Python/phonemisation/bdlexique-PDM-Resync2.txt"
nomConverts="/Users/gilles/Github/SWIM/2015-Data/VerbesAction-ConvertsPP.txt"
nomAutres="/Users/gilles/Github/SWIM/2015-Data/VerbesAction-Autres2.txt"
nomInconnus="/Users/gilles/Github/SWIM/2015-Data/VerbesAction-DerivesInconnus.csv"
nomManquants="/Users/gilles/Github/SWIM/2015-Data/VerbesAction-BasesManquantes.csv"

freqForme=1000000

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
import pandas as pd
import pickle
import numpy as np

# %% [markdown]
# # Préparation du tableau de VERBES

# %% [markdown]
# ### Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
bdlexique=pd.read_csv(nomLexique,sep=";",names=["ortho","phono","ext","cs","ms","vs","lexeme","L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"],encoding="utf8")
bdlexique.loc[(bdlexique["ms"]=="ij")&(bdlexique["cs"].isin(["V","K"])),"ms"]="MS"
bdlexique.drop_duplicates(inplace=True,subset=["phono","ext","cs","ms","vs","lexeme","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"])

# %% [markdown]
# ### Création de la colonne de fréquence *freq*
#
# - fréquence forme : 1000000x(formeFrantext+formeFilms)
# - fréquence lexeme : lemmeFrantext+lemmeFilms
# - fréquence inexistante : .01

# %%
bdlexique["freq"]=1.0/100
filtreLFrantext=(bdlexique["lemmeFrantext"]!="***") 
filtreLFilms=(bdlexique["lemmeFilms"]!="***")
filtreFFrantext=(bdlexique["formeFrantext"]!="***") 
filtreFFilms=(bdlexique["formeFilms"]!="***")
bdlexique.loc[filtreLFrantext|filtreLFilms,"freq"]=bdlexique[filtreLFrantext]["lemmeFrantext"].astype(float)+bdlexique[filtreLFilms]["lemmeFilms"].astype(float)
bdlexique.loc[filtreFFrantext | filtreFFrantext,"freq"]=bdlexique[filtreFFrantext]["formeFrantext"].astype(float)*freqForme+bdlexique[filtreFFilms]["formeFilms"].astype(float)*freqForme

# %% [markdown]
# ### Elimination des colonnes inutiles
# - indicateur L23
# - fréquences brutes

# %%
inutilesColonnes=["L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"]
for colonne in inutilesColonnes:
    del bdlexique[colonne]

# %%
convertsPP=pd.read_csv(nomConverts,sep=";",names=["lexeme","base"],encoding="utf8")
autresDerives=pd.read_csv(nomAutres,sep=";",names=["lexeme","base"],encoding="utf8")

# %%
derivesLexicaux=pd.concat([convertsPP,autresDerives]).reset_index()
del derivesLexicaux["index"]
derivesLexicaux=derivesLexicaux.drop_duplicates()
listDerives=derivesLexicaux["lexeme"].tolist()

# %% [markdown]
# ### Extraction des converts dans une structure *derives*

# %%
derives=bdlexique[(bdlexique["cs"]=="N") & (bdlexique["ms"].str.startswith("F")) & (bdlexique["lexeme"].isin(listDerives))]

# %%
setDerivesBdlexique=set(derives["lexeme"].tolist())
setDerivesLexicaux=set(listDerives)
setDerivesManquants=setDerivesLexicaux-setDerivesBdlexique

# %%
derives=derives.merge(derivesLexicaux,on="lexeme",how="left")
#derives

# %%
#derivesLexicaux

# %%
derivesInconnus=pd.read_csv(nomInconnus,sep=";",encoding="utf8")
#derivesInconnus

# %%
basesManquantes=pd.read_csv(nomManquants,sep=";",encoding="utf8")
basesManquantes
# Out:
#          ortho     phono  ext cs  ms   vs       lexeme  freq
# 0     accalmir   akalmir  NaN  V NaN  inf     accalmir  0.01
# 1         buer       bHe  NaN  V NaN  inf         buer  0.01
# 2      charpir    Sarpir  NaN  V NaN  inf      charpir  0.01
# 3  complaindre   kôplêdr  NaN  V NaN  inf  complaindre  0.01
# 4    desservir  desErvir  NaN  V NaN  inf    desservir  0.01

# %%
derives=derives.append(derivesInconnus, ignore_index=True)

# %%
derives
# Out:
#             ortho       phono  ext cs  ms   vs        lexeme          freq  \
# 0         absoute       absut    @  N  FS  NaN       absoute  1.400000e+07
# 1        absoutes       absut  @z"  N  FP  NaN       absoute  1.400000e+01
# 2        accalmie      akalmi  NaN  N  FS  NaN      accalmie  3.430000e+08
# 3       accalmies      akalmi   z"  N  FP  NaN      accalmie  7.800000e+07
# 4          accrue        akry  NaN  N  FS  NaN        accrue  7.000000e+06
# 5         accrues        akry   z"  N  FP  NaN        accrue  7.000000e+00
# 6          agonie       agòni  NaN  N  FS  NaN        agonie  1.782000e+09
# 7         agonies       agòni   z"  N  FP  NaN        agonie  1.470000e+08
# 8           allée         ale  NaN  N  FS  NaN         allée  4.597000e+09
# 9          allées         ale   z"  N  FP  NaN         allée  2.855000e+09
# 10         amenée       am6ne  NaN  N  FS  NaN        amenée  9.000000e+06
# 11        amenées       am6ne   z"  N  FP  NaN        amenée  9.000000e+00
# 12        arrivée       arive  NaN  N  FS  NaN       arrivée  1.197400e+10
# 13       arrivées       arive   z"  N  FP  NaN       arrivée  2.920000e+08
# 14         assise        asiz    @  N  FS  NaN        assise  5.110000e+08
# 15        assises        asiz  @z"  N  FP  NaN        assise  8.430000e+08
# 16      astreinte      astrêt    @  N  FS  NaN     astreinte  9.000000e+06
# 17     astreintes      astrêt  @z"  N  FP  NaN     astreinte  1.000000e+06
# 18       atteinte        atêt    @  N  FS  NaN      atteinte  7.780000e+08
# 19      atteintes        atêt  @z"  N  FP  NaN      atteinte  2.220000e+08
# 20        attente        atât    @  N  FS  NaN       attente  8.412000e+09
# 21       attentes        atât  @z"  N  FP  NaN       attente  4.790000e+08
# 22         battue        baty  NaN  N  FS  NaN        battue  3.610000e+08
# 23        battues        baty   z"  N  FP  NaN        battue  1.720000e+08
# 24          butée        byte  NaN  N  FS  NaN         butée  9.400000e+07
# 25         butées        byte   z"  N  FP  NaN         butée  9.400000e+01
# 26           buée         bye  NaN  N  FS  NaN          buée  1.343000e+09
# 27          buées         bye   z"  N  FP  NaN          buée  4.100000e+07
# 28        charpie       Sarpi  NaN  N  FS  NaN       charpie  2.950000e+08
# 29       charpies       Sarpi   z"  N  FP  NaN       charpie  7.000000e+06
# ..            ...         ...  ... ..  ..  ...           ...           ...
# 328       empilée       âpile  NaN  N  FS  NaN       empilée  1.000000e-02
# 329      enceinte        âsêt  NaN  N  FS  NaN      enceinte  1.000000e-02
# 330       fauchée        foSe  NaN  N  FS  NaN       fauchée  1.000000e-02
# 331        fessée        fEse  NaN  N  FS  NaN        fessée  1.000000e-02
# 332        frayée       frEje  NaN  N  FS  NaN        frayée  1.000000e-02
# 333       freinée       frEne  NaN  N  FS  NaN       freinée  1.000000e-02
# 334       galopée      galope  NaN  N  FS  NaN       galopée  1.000000e-02
# 335       gueulée        g2le  NaN  N  FS  NaN       gueulée  1.000000e-02
# 336        happée         ape  NaN  N  FS  NaN        happée  1.000000e-02
# 337        juchée        ZySe  NaN  N  FS  NaN        juchée  1.000000e-02
# 338         lapée        lape  NaN  N  FS  NaN         lapée  1.000000e-02
# 339    méconduite    mekôdHit  NaN  N  FS  NaN    méconduite  1.000000e-02
# 340        montée        môte  NaN  N  FS  NaN        montée  1.000000e-02
# 341       nivelée      niv6le  NaN  N  FS  NaN       nivelée  1.000000e-02
# 342        piégée       pjeZe  NaN  N  FS  NaN        piégée  1.000000e-02
# 343        plumée       plyme  NaN  N  FS  NaN        plumée  1.000000e-02
# 344        prisée       prize  NaN  N  FS  NaN        prisée  1.000000e-02
# 345  redécouverte  r6dekuvErt  NaN  N  FS  NaN  redécouverte  1.000000e-02
# 346      répartie     reparti  NaN  N  FS  NaN      répartie  1.000000e-02
# 347     replongée     r6plôZe  NaN  N  FS  NaN     replongée  1.000000e-02
# 348       retenue      r6t6ny  NaN  N  FS  NaN       retenue  1.000000e-02
# 349     rétreinte      retrêt  NaN  N  FS  NaN     rétreinte  1.000000e-02
# 350       revenue     r6v6nue  NaN  N  FS  NaN       revenue  1.000000e-02
# 351      saboulée      sabule  NaN  N  FS  NaN      saboulée  1.000000e-02
# 352       secouée       s6kue  NaN  N  FS  NaN       secouée  1.000000e-02
# 353     seringuée      s6rêge  NaN  N  FS  NaN     seringuée  1.000000e-02
# 354       souquée        suke  NaN  N  FS  NaN       souquée  1.000000e-02
# 355       offerte       OfErt  NaN  N  FS  NaN       offerte  1.000000e-02
# 356       refente       r6fât  NaN  N  FS  NaN       refente  1.000000e-02
# 357       retonte       r6tôt  NaN  N  FS  NaN       retonte  1.000000e-02
#
#             base
# 0       absoudre
# 1       absoudre
# 2       accalmir
# 3       accalmir
# 4      accroître
# 5      accroître
# 6         agonir
# 7         agonir
# 8          aller
# 9          aller
# 10        amener
# 11        amener
# 12       arriver
# 13       arriver
# 14       asseoir
# 15       asseoir
# 16    astreindre
# 17    astreindre
# 18     atteindre
# 19     atteindre
# 20      attendre
# 21      attendre
# 22        battre
# 23        battre
# 24         buter
# 25         buter
# 26          buer
# 27          buer
# 28       charpir
# 29       charpir
# ..           ...
# 328      empiler
# 329    enceindre
# 330      faucher
# 331       fesser
# 332       frayer
# 333      freiner
# 334      galoper
# 335      gueuler
# 336       happer
# 337       jucher
# 338        laper
# 339   méconduire
# 340       monter
# 341      niveler
# 342       piéger
# 343       plumer
# 344       priser
# 345  redécouvrir
# 346     repartir
# 347    replonger
# 348      retenir
# 349   rétreindre
# 350      revenir
# 351     sabouler
# 352      secouer
# 353    seringuer
# 354      souquer
# 355       offrir
# 356     refendre
# 357     retondre
#
# [358 rows x 9 columns]

# %% [markdown]
# ### Ajout d'une colonne *prob* pour la fréquence relative

# %%
derives["prob"]=derives["freq"]/derives["freq"].sum()

# %% [markdown]
# ### Ajout d'une colonne *case*
# - remplir les *ms* vides pour permettre la concaténation sans erreur
# - remplir les *vs* vides des participes passés par "pp" pour permettre l'identification de la case
# - *case* est la concaténation de *vs* et *ms*

# %%
bdlexiqueIn = unicode(u"èò")
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO")
neutralise = dict(zip(bdlexiqueNum, neutreOut))

def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

derives["phono"]=derives["phono"].apply(recoder)

# %%
with open("2015-Data/"+filePrefix+'-Derives2.pkl', 'wb') as output:
   pickle.dump(derives, output, pickle.HIGHEST_PROTOCOL)

# %%
derives.sort_values(by="prob")
# Out:
#            ortho     phono  ext cs  ms   vs      lexeme          freq  \
# 357      retonte     r6tôt  NaN  N  FS  NaN     retonte  1.000000e-02
# 331       fessée      fEse  NaN  N  FS  NaN      fessée  1.000000e-02
# 330      fauchée      foSe  NaN  N  FS  NaN     fauchée  1.000000e-02
# 329     enceinte      âsêt  NaN  N  FS  NaN    enceinte  1.000000e-02
# 328      empilée     âpile  NaN  N  FS  NaN     empilée  1.000000e-02
# 327     départie   departi  NaN  N  FS  NaN    départie  1.000000e-02
# 326     cueillie      k9ji  NaN  N  FS  NaN    cueillie  1.000000e-02
# 325        criée     krije  NaN  N  FS  NaN       criée  1.000000e-02
# 324       coulée      kule  NaN  N  FS  NaN      coulée  1.000000e-02
# 323       brisée     brize  NaN  N  FS  NaN      brisée  1.000000e-02
# 44      couverte    kuvErt    @  N  FS  NaN    couverte  1.000000e-02
# 45     couvertes    kuvErt  @z"  N  FP  NaN    couverte  1.000000e-02
# 321       bramée     brame  NaN  N  FS  NaN      bramée  1.000000e-02
# 320      avancée     avâse  NaN  N  FS  NaN     avancée  1.000000e-02
# 332       frayée     frEje  NaN  N  FS  NaN      frayée  1.000000e-02
# 279       touées       tue   z"  N  FP  NaN       touée  1.000000e-02
# 255    surtontes    syrtôt  @z"  N  FP  NaN    surtonte  1.000000e-02
# 254     surtonte    syrtôt    @  N  FS  NaN    surtonte  1.000000e-02
# 215     reposées    r6pOze   z"  N  FP  NaN     reposée  1.000000e-02
# 214      reposée    r6pOze  NaN  N  FS  NaN     reposée  1.000000e-02
# 197  reconduites  r6kôdHit  @z"  N  FP  NaN  reconduite  1.000000e-02
# 78       déprise    dEpriz    @  N  FS  NaN     déprise  1.000000e-02
# 79      déprises    dEpriz  @z"  N  FP  NaN     déprise  1.000000e-02
# 196   reconduite  r6kôdHit    @  N  FS  NaN  reconduite  1.000000e-02
# 356      refente     r6fât  NaN  N  FS  NaN     refente  1.000000e-02
# 159       pavées      pave   z"  N  FP  NaN       pavée  1.000000e-02
# 158        pavée      pave  NaN  N  FS  NaN       pavée  1.000000e-02
# 157      passées      pase   z"  N  FP  NaN      passée  1.000000e-02
# 156       passée      pase  NaN  N  FS  NaN      passée  1.000000e-02
# 278        touée       tue  NaN  N  FS  NaN       touée  1.000000e-02
# ..           ...       ...  ... ..  ..  ...         ...           ...
# 268        tenue      t6ny  NaN  N  FS  NaN       tenue  4.761000e+09
# 186        prise      priz    @  N  FS  NaN       prise  5.062000e+09
# 96    entreprise  âtr6priz    @  N  FS  NaN  entreprise  5.184000e+09
# 299         vies        vi   z"  N  FP  NaN         vie  5.247000e+09
# 32         chute       Syt    @  N  FS  NaN       chute  5.628000e+09
# 166        perte      pErt    @  N  FS  NaN       perte  5.682000e+09
# 48       crainte      krêt    @  N  FS  NaN     crainte  5.700000e+09
# 116        fuite      fHit    @  N  FS  NaN       fuite  5.784000e+09
# 43       courses      kurs  @z"  N  FP  NaN      course  6.204000e+09
# 142         mise       miz    @  N  FS  NaN        mise  6.586000e+09
# 90       enquête      âkEt    @  N  FS  NaN     enquête  7.234000e+09
# 118        fumée      fyme  NaN  N  FS  NaN       fumée  7.579000e+09
# 222     retraite    r6trEt    @  N  FS  NaN    retraite  7.707000e+09
# 176       pointe      pwêt    @  N  FS  NaN      pointe  8.042000e+09
# 20       attente      atât    @  N  FS  NaN     attente  8.412000e+09
# 161      pensées      pâse   z"  N  FP  NaN      pensée  8.425000e+09
# 42        course      kurs    @  N  FS  NaN      course  9.167000e+09
# 76       défense     dEfâs    @  N  FS  NaN     défense  9.633000e+09
# 248       sortie     sOrti  NaN  N  FS  NaN      sortie  1.085900e+10
# 12       arrivée     arive  NaN  N  FS  NaN     arrivée  1.197400e+10
# 160       pensée      pâse  NaN  N  FS  NaN      pensée  1.251700e+10
# 252     surprise   syrpriz    @  N  FS  NaN    surprise  1.441300e+10
# 145        morts       mOr   z"  N  FP  NaN        mort  1.442400e+10
# 98        entrée      âtre  NaN  N  FS  NaN      entrée  1.574700e+10
# 236      réponse     rEpôs    @  N  FS  NaN     réponse  1.629100e+10
# 306          vue        vy  NaN  N  FS  NaN         vue  2.204300e+10
# 154       partie     parti  NaN  N  FS  NaN      partie  3.657800e+10
# 250        suite      sHit    @  N  FS  NaN       suite  5.450600e+10
# 144         mort       mOr  NaN  N  FS  NaN        mort  7.460600e+10
# 298          vie        vi  NaN  N  FS  NaN         vie  1.822060e+11
#
#              base          prob
# 357      retondre  1.281217e-14
# 331        fesser  1.281217e-14
# 330       faucher  1.281217e-14
# 329     enceindre  1.281217e-14
# 328       empiler  1.281217e-14
# 327      départir  1.281217e-14
# 326      cueillir  1.281217e-14
# 325         crier  1.281217e-14
# 324        couler  1.281217e-14
# 323        briser  1.281217e-14
# 44        couvrir  1.281217e-14
# 45        couvrir  1.281217e-14
# 321        bramer  1.281217e-14
# 320       avancer  1.281217e-14
# 332        frayer  1.281217e-14
# 279         touer  1.281217e-14
# 255     surtondre  1.281217e-14
# 254     surtondre  1.281217e-14
# 215       reposer  1.281217e-14
# 214       reposer  1.281217e-14
# 197    reconduire  1.281217e-14
# 78      déprendre  1.281217e-14
# 79      déprendre  1.281217e-14
# 196    reconduire  1.281217e-14
# 356      refendre  1.281217e-14
# 159         paver  1.281217e-14
# 158         paver  1.281217e-14
# 157        passer  1.281217e-14
# 156        passer  1.281217e-14
# 278         touer  1.281217e-14
# ..            ...           ...
# 268         tenir  6.099873e-03
# 186       prendre  6.485520e-03
# 96   entreprendre  6.641828e-03
# 299         vivre  6.722545e-03
# 32          choir  7.210688e-03
# 166        perdre  7.279874e-03
# 48       craindre  7.302936e-03
# 116          fuir  7.410558e-03
# 43         courir  7.948669e-03
# 142        mettre  8.438094e-03
# 90       enquérir  9.268323e-03
# 118         fumer  9.710342e-03
# 222      retraire  9.874338e-03
# 176       poindre  1.030355e-02
# 20       attendre  1.077760e-02
# 161        penser  1.079425e-02
# 42         courir  1.174491e-02
# 76       défendre  1.234196e-02
# 248        sortir  1.391273e-02
# 12        arriver  1.534129e-02
# 160        penser  1.603699e-02
# 252    surprendre  1.846618e-02
# 145        mourir  1.848027e-02
# 98         entrer  2.017532e-02
# 236      répondre  2.087230e-02
# 306          voir  2.824186e-02
# 154        partir  4.686435e-02
# 250        suivre  6.983401e-02
# 144        mourir  9.558646e-02
# 298         vivre  2.334454e-01
#
# [358 rows x 10 columns]

# %%
tirage=np.random.choice(derives.index,size=75,p=derives["prob"],replace=False)

# %%
extrait=derives.ix[np.sort(tirage)]

# %%
extrait
# Out:
#            ortho     phono  ext cs  ms   vs      lexeme          freq  \
# 3      accalmies    akalmi   z"  N  FP  NaN    accalmie  7.800000e+07
# 8          allée       ale  NaN  N  FS  NaN       allée  4.597000e+09
# 9         allées       ale   z"  N  FP  NaN       allée  2.855000e+09
# 12       arrivée     arive  NaN  N  FS  NaN     arrivée  1.197400e+10
# 14        assise      asiz    @  N  FS  NaN      assise  5.110000e+08
# 20       attente      atât    @  N  FS  NaN     attente  8.412000e+09
# 26          buée       bye  NaN  N  FS  NaN        buée  1.343000e+09
# 30    chevauchée    S6vOSe  NaN  N  FS  NaN  chevauchée  2.920000e+08
# 32         chute       Syt    @  N  FS  NaN       chute  5.628000e+09
# 38      conquête     kôkEt    @  N  FS  NaN    conquête  1.473000e+09
# 39     conquêtes     kôkEt  @z"  N  FP  NaN    conquête  7.640000e+08
# 42        course      kurs    @  N  FS  NaN      course  9.167000e+09
# 43       courses      kurs  @z"  N  FP  NaN      course  6.204000e+09
# 48       crainte      krêt    @  N  FS  NaN     crainte  5.700000e+09
# 56         cuite      kHit    @  N  FS  NaN       cuite  4.320000e+08
# 58      descente     dEsât    @  N  FS  NaN    descente  3.129000e+09
# 62         dette       dEt    @  N  FS  NaN       dette  1.791000e+09
# 64        dictée     dikte  NaN  N  FS  NaN      dictée  5.100000e+08
# 76       défense     dEfâs    @  N  FS  NaN     défense  9.633000e+09
# 82       détente     dEtât    @  N  FS  NaN     détente  1.589000e+09
# 90       enquête      âkEt    @  N  FS  NaN     enquête  7.234000e+09
# 96    entreprise  âtr6priz    @  N  FS  NaN  entreprise  5.184000e+09
# 97   entreprises  âtr6priz  @z"  N  FP  NaN  entreprise  1.483000e+09
# 98        entrée      âtre  NaN  N  FS  NaN      entrée  1.574700e+10
# 99       entrées      âtre   z"  N  FP  NaN      entrée  9.400000e+08
# 102       feinte       fêt    @  N  FS  NaN      feinte  2.000000e+08
# 104        fente       fât    @  N  FS  NaN       fente  1.415000e+09
# 110        fonte       fôt    @  N  FS  NaN       fonte  9.050000e+08
# 116        fuite      fHit    @  N  FS  NaN       fuite  5.784000e+09
# 118        fumée      fyme  NaN  N  FS  NaN       fumée  7.579000e+09
# ..           ...       ...  ... ..  ..  ...         ...           ...
# 184      poussée      puse  NaN  N  FS  NaN     poussée  1.240000e+09
# 187       prises      priz  @z"  N  FP  NaN       prise  1.567000e+09
# 188     promesse    prOmEs    @  N  FS  NaN    promesse  4.221000e+09
# 189    promesses    prOmEs  @z"  N  FP  NaN    promesse  3.020000e+09
# 190        quête       kEt    @  N  FS  NaN       quête  2.389000e+09
# 194      recette     r6sEt    @  N  FS  NaN     recette  1.645000e+09
# 202       remise     r6miz    @  N  FS  NaN      remise  1.976000e+09
# 216      reprise    r6priz    @  N  FS  NaN     reprise  1.065000e+09
# 222     retraite    r6trEt    @  N  FS  NaN    retraite  7.707000e+09
# 226        revue      r6vy  NaN  N  FS  NaN       revue  3.293000e+09
# 236      réponse     rEpôs    @  N  FS  NaN     réponse  1.629100e+10
# 238     réussite    rEysit    @  N  FS  NaN    réussite  2.698000e+09
# 243     saillies      saji   z"  N  FP  NaN     saillie  2.350000e+08
# 248       sortie     sOrti  NaN  N  FS  NaN      sortie  1.085900e+10
# 250        suite      sHit    @  N  FS  NaN       suite  5.450600e+10
# 252     surprise   syrpriz    @  N  FS  NaN    surprise  1.441300e+10
# 253    surprises   syrpriz  @z"  N  FP  NaN    surprise  1.597000e+09
# 266        tente       tât    @  N  FS  NaN       tente  3.352000e+09
# 268        tenue      t6ny  NaN  N  FS  NaN       tenue  4.761000e+09
# 270       tombée      tôbe  NaN  N  FS  NaN      tombée  1.245000e+09
# 276      tournée     turne  NaN  N  FS  NaN     tournée  3.736000e+09
# 283    tranchées     trâSe   z"  N  FP  NaN    tranchée  1.468000e+09
# 293     veillées      vEje   z"  N  FP  NaN     veillée  3.800000e+08
# 294        vente       vât    @  N  FS  NaN       vente  3.390000e+09
# 296        venue      v6ny  NaN  N  FS  NaN       venue  1.983000e+09
# 298          vie        vi  NaN  N  FS  NaN         vie  1.822060e+11
# 306          vue        vy  NaN  N  FS  NaN         vue  2.204300e+10
# 307         vues        vy   z"  N  FP  NaN         vue  1.180000e+09
# 313      émeutes      Em2t  @z"  N  FP  NaN      émeute  4.870000e+08
# 316     étreinte     Etrêt    @  N  FS  NaN    étreinte  1.442000e+09
#
#              base      prob
# 3        accalmir  0.000100
# 8           aller  0.005890
# 9           aller  0.003658
# 12        arriver  0.015341
# 14        asseoir  0.000655
# 20       attendre  0.010778
# 26           buer  0.001721
# 30     chevaucher  0.000374
# 32          choir  0.007211
# 38      conquérir  0.001887
# 39      conquérir  0.000979
# 42         courir  0.011745
# 43         courir  0.007949
# 48       craindre  0.007303
# 56          cuire  0.000553
# 58      descendre  0.004009
# 62         devoir  0.002295
# 64         dicter  0.000653
# 76       défendre  0.012342
# 82       détendre  0.002036
# 90       enquérir  0.009268
# 96   entreprendre  0.006642
# 97   entreprendre  0.001900
# 98         entrer  0.020175
# 99         entrer  0.001204
# 102       feindre  0.000256
# 104        fendre  0.001813
# 110        fondre  0.001160
# 116          fuir  0.007411
# 118         fumer  0.009710
# ..            ...       ...
# 184       pousser  0.001589
# 187       prendre  0.002008
# 188     promettre  0.005408
# 189     promettre  0.003869
# 190        quérir  0.003061
# 194      recevoir  0.002108
# 202      remettre  0.002532
# 216     reprendre  0.001364
# 222      retraire  0.009874
# 226        revoir  0.004219
# 236      répondre  0.020872
# 238       réussir  0.003457
# 243       saillir  0.000301
# 248        sortir  0.013913
# 250        suivre  0.069834
# 252    surprendre  0.018466
# 253    surprendre  0.002046
# 266        tendre  0.004295
# 268         tenir  0.006100
# 270        tomber  0.001595
# 276       tourner  0.004787
# 283      trancher  0.001881
# 293       veiller  0.000487
# 294        vendre  0.004343
# 296         venir  0.002541
# 298         vivre  0.233445
# 306          voir  0.028242
# 307          voir  0.001512
# 313      émouvoir  0.000624
# 316     étreindre  0.001848
#
# [75 rows x 10 columns]

# %%
paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['ms'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
paradigmes
# Out:
# ms      lexeme      FP        FS
# 0        allée     NaN       ale
# 1      arrivée     NaN     arive
# 2      attente     NaN      atât
# 3   chevauchée     NaN    S6vOSe
# 4        chute     NaN       Syt
# 5   contrainte     NaN    kôtrêt
# 6       course    kurs      kurs
# 7      crainte     NaN      krêt
# 8     descente     NaN     dEsât
# 9       dictée   dikte       NaN
# 10  découverte     NaN  dEkuvErt
# 11     défaite     NaN     dEfEt
# 12     défense     NaN     dEfâs
# 13     détente     NaN     dEtât
# 14   empreinte     NaN     âprêt
# 15     enquête    âkEt      âkEt
# 16  entreprise     NaN  âtr6priz
# 17      entrée     NaN      âtre
# 18     envolée     NaN     âvOle
# 19       fuite     NaN      fHit
# 20       fumée     NaN      fyme
# 21      giclée     NaN     Zikle
# 22       jetée     NaN      Z6te
# 23       meute     NaN       m2t
# 24        mise     NaN       miz
# 25        mort     mOr       mOr
# 26      partie     NaN     parti
# 27      pensée    pâse      pâse
# 28       pente     pât       pât
# 29       perte    pErt      pErt
# ..         ...     ...       ...
# 35    promesse     NaN    prOmEs
# 36       quête     NaN       kEt
# 37      remise     NaN     r6miz
# 38    renommée     NaN    r6nOme
# 39       rente     rât       NaN
# 40     rentrée     NaN     râtre
# 41     reprise  r6priz       NaN
# 42     requête   r6kEt       NaN
# 43    retraite     NaN    r6trEt
# 44       revue     NaN      r6vy
# 45     réponse     NaN     rEpôs
# 46    réussite     NaN    rEysit
# 47      sortie     NaN     sOrti
# 48       suite     NaN      sHit
# 49    surprise     NaN   syrpriz
# 50      teinte     NaN       têt
# 51       tente     NaN       tât
# 52       tenue     NaN      t6ny
# 53      traite     NaN      trEt
# 54    tranchée   trâSe       NaN
# 55     traînée   trEne       NaN
# 56     veillée    vEje      vEje
# 57       venue     NaN      v6ny
# 58         vie     NaN        vi
# 59       virée     NaN      vire
# 60       volée     NaN      vOle
# 61         vue     NaN        vy
# 62      émeute     NaN      Em2t
# 63     étendue   Etâdy       NaN
# 64    étreinte   Etrêt       NaN
#
# [65 rows x 3 columns]

# %%
paradigmes.to_csv(path_or_buf="2015-Data/"+filePrefix+"-derives2.csv",encoding="utf8",sep=";")

# %%
GOLD=pd.pivot_table(derives, values='phono', index=['lexeme'], columns=['ms'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
GOLD.to_csv(path_or_buf="2015-Data/"+filePrefix+"-derives2-GOLD.csv",encoding="utf8",sep=";")

# %%
bdlexique[bdlexique["lexeme"]=="surtondre"]
# Out:
#                  ortho       phono  ext cs   ms   vs     lexeme  freq
# 384213         surtond       syrtô   t"  V   3S   pi  surtondre  0.01
# 384214    surtondaient     syrtôdè   t"  V   3P   ii  surtondre  0.01
# 384215      surtondais     syrtôdè   z"  V   1S   ii  surtondre  0.01
# 384216      surtondais     syrtôdè   z"  V   2S   ii  surtondre  0.01
# 384217      surtondait     syrtôdè   t"  V   3S   ii  surtondre  0.01
# 384218      surtondant     syrtôdâ   t"  V  NaN   pP  surtondre  0.01
# 384219        surtonde      syrtôd    @  V   1S   ps  surtondre  0.01
# 384220        surtonde      syrtôd    @  V   3S   ps  surtondre  0.01
# 384221      surtondent      syrtôd  @t"  V   3P   pi  surtondre  0.01
# 384222      surtondent      syrtôd  @t"  V   3P   ps  surtondre  0.01
# 384223       surtondes      syrtôd    @  V   2S   ps  surtondre  0.01
# 384224       surtondez     syrtôde   z"  V   2P   pI  surtondre  0.01
# 384225       surtondez     syrtôde   z"  V   2P   pi  surtondre  0.01
# 384226      surtondiez    syrtôdje   z"  V   2P   ii  surtondre  0.01
# 384227      surtondiez    syrtôdje   z"  V   2P   ps  surtondre  0.01
# 384228     surtondions    syrtôdjô   z"  V   1P   ii  surtondre  0.01
# 384229     surtondions    syrtôdjô   z"  V   1P   ps  surtondre  0.01
# 384230    surtondirent    syrtôdir  @t"  V   3P   ai  surtondre  0.01
# 384231       surtondis     syrtôdi   z"  V   1S   ai  surtondre  0.01
# 384232       surtondis     syrtôdi   z"  V   2S   ai  surtondre  0.01
# 384233     surtondisse    syrtôdis    @  V   1S   is  surtondre  0.01
# 384234   surtondissent    syrtôdis  @t"  V   3P   is  surtondre  0.01
# 384235    surtondisses    syrtôdis    @  V   2S   is  surtondre  0.01
# 384236   surtondissiez  syrtôdisje   z"  V   2P   is  surtondre  0.01
# 384237  surtondissions  syrtôdisjô   z"  V   1P   is  surtondre  0.01
# 384238       surtondit     syrtôdi   t"  V   3S   ai  surtondre  0.01
# 384239      surtondons     syrtôdô   z"  V   1P   pI  surtondre  0.01
# 384240      surtondons     syrtôdô   z"  V   1P   pi  surtondre  0.01
# 384241       surtondra    syrtôdra  NaN  V   3S   fi  surtondre  0.01
# 384242      surtondrai    syrtôdrè  NaN  V   1S   fi  surtondre  0.01
# 384243   surtondraient    syrtôdrè   t"  V   3P   pc  surtondre  0.01
# 384244     surtondrais    syrtôdrè   z"  V   1S   pc  surtondre  0.01
# 384245     surtondrais    syrtôdrè   z"  V   2S   pc  surtondre  0.01
# 384246     surtondrait    syrtôdrè   t"  V   3S   pc  surtondre  0.01
# 384247      surtondras    syrtôdra   z"  V   2S   fi  surtondre  0.01
# 384248       surtondre     syrtôdr    @  V  NaN  inf  surtondre  0.01
# 384249      surtondrez    syrtôdre   z"  V   2P   fi  surtondre  0.01
# 384250     surtondriez   syrtôdrie   z"  V   2P   pc  surtondre  0.01
# 384251    surtondrions   syrtôdriô   z"  V   1P   pc  surtondre  0.01
# 384252     surtondrons    syrtôdrô   z"  V   1P   fi  surtondre  0.01
# 384253     surtondront    syrtôdrô   t"  V   3P   fi  surtondre  0.01
# 384254        surtonds       syrtô   z"  V   1S   pi  surtondre  0.01
# 384255        surtonds       syrtô   z"  V   2S   pI  surtondre  0.01
# 384256        surtonds       syrtô   z"  V   2S   pi  surtondre  0.01
# 384257        surtondu     syrtôdy  NaN  K   MS   pp  surtondre  0.01
# 384258       surtondue     syrtôdy  NaN  K   FS   pp  surtondre  0.01
# 384259      surtondues     syrtôdy   z"  K   FP   pp  surtondre  0.01
# 384260       surtondus     syrtôdy   z"  K   MP   pp  surtondre  0.01
# 384261     surtondîmes    syrtôdim  @z"  V   1P   ai  surtondre  0.01
# 384262       surtondît     syrtôdi   t"  V   3S   is  surtondre  0.01
# 384263     surtondîtes    syrtôdit  @z"  V   2P   ai  surtondre  0.01

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
from IPython.html.widgets import FloatProgress
from IPython.display import display

# %%
phonologicalMap="-N"

# %%
import math
def rAn(r,n):
    f = math.factorial
    return f(n) / f(n-r)
def rCn(r,n):
    f = math.factorial
    return f(n) / f(r) / f(n-r)

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
validPhonemes=list(fs.supremum.concept.extent)
#for phoneme in validPhonemes:
#    print (phoneme, [phoneme], ";")

# %%
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# # Lecture du tableau de VERBES

# %% [markdown]
# ### Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
filePrefix="2015-Data/MGC-160104"

# %% [raw]
# casesPrincipales= [
#         'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
#         'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P',
#         'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
#         'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
#         'ps2P', 'ps3P',
#         'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
#         'ppMS', 'ppMP', 'ppFS', 'ppFP'
#             ]
# casesSecondaires= [
#        'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
#             ]
# casesTotales=casesPrincipales+casesSecondaires
# listeCases=casesTotales

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print (forme, file=logfile)
                print ("pas de classe",idClasseForme, file=logfile)
                print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %% [raw]
# def OLDrapports(paradigme):
#     (case1,case2,lexeme)= paradigme.columns.values.tolist()
#     patrons=pairePatrons(case1,case2)
#     if len(paradigme)>0:
# #        for index, row in paradigme.iterrows():
# #            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
#         paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
#         (regles1,regles2)=patrons.calculerGM()
#     return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ## Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for n,paire in enumerate(it.combinations_with_replacement(sampleCases,2)):
        progressBar.value=n
        if debug: print (paire, file=logfile)
        if debug: print ("-".join(paire),end=", ")
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ### Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
debug1=True

for echantillon in range(0,3):
    echantillonPrefix="-%02d"%(echantillon+1)
    for assemblage in ["BRASS","SILVER"]:
        print (echantillon, assemblage)
        nomLexique=filePrefix+echantillonPrefix+"-N-ext3-160215-derivations-%s.csv"%assemblage
        paradigmes=pd.read_csv(nomLexique,sep=";",encoding="utf8")    

        del paradigmes[u"Unnamed: 0"]
        sampleCases=paradigmes.columns.tolist()
        sampleCases.remove(u"lexeme")    

        #Neutralize all the forms
    #    for case in sampleCases:
    #        paradigmes[case]=paradigmes[case].apply(lambda x: recoder(x))

        #Save neutralized paradigms
    #    paradigmes.to_csv(path_or_buf=filePrefix+echantillonPrefix+phonologicalMap+"-paradigmes.csv",encoding="utf8",sep=";")    

    #    logfile_name=filePrefix+echantillonPrefix+phonologicalMap+".log"
    #    logfile = codecs.open(logfile_name,mode='w',encoding="utf8")

        progressBar = FloatProgress(min=0, max=rCn(2,len(sampleCases)))
        display(progressBar)

        resultats=evaluerEchantillon(paradigmes)
        classesFinales={}
        for resultat in resultats:
            classesFinales[resultat]=resultats[resultat][0]
            classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]
    #    with open(filePrefix+echantillonPrefix+phonologicalMap+'-Regles.pkl', 'wb') as output:
        with open(nomLexique.replace(".csv",'-Regles.pkl'), 'wb') as output:
           pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)
# Out:
# 0 BRASS
# 0 SILVER
# 1 BRASS
# 1 SILVER
# 2 BRASS
# 2 SILVER
# CPU times: user 30min 59s, sys: 9.52 s, total: 31min 9s
# Wall time: 31min 8s

# %%
for element in  (classesFinales[("pi3S","FS")].sortirForme(u"ariv")):
    print (element)
# Out:
# arive

# %%
classesFinales
# Out:
# {(u'ps2P', u'is1S'): <__main__.classesPaire instance at 0x10d1c0290>,
#  (u'inf', u'pi2S'): <__main__.classesPaire instance at 0x10cd7c098>,
#  (u'ii3S', u'pI1P'): <__main__.classesPaire instance at 0x10d020098>,
#  (u'is2S', u'pc3P'): <__main__.classesPaire instance at 0x10c09c368>,
#  (u'ps2S', u'ii2P'): <__main__.classesPaire instance at 0x10bf2aa70>,
#  (u'pc2P', u'ai2P'): <__main__.classesPaire instance at 0x110bd45f0>,
#  (u'ii3P', u'pi2P'): <__main__.classesPaire instance at 0x10d020320>,
#  (u'fi3P', u'pi2P'): <__main__.classesPaire instance at 0x1112ea560>,
#  (u'pi2S', u'ps3P'): <__main__.classesPaire instance at 0x10bf5e7a0>,
#  (u'pc1P', u'pi2S'): <__main__.classesPaire instance at 0x10f2a8ea8>,
#  (u'FP', u'ps1P'): <__main__.classesPaire instance at 0x10d22c4d0>,
#  (u'is2S', u'ai1S'): <__main__.classesPaire instance at 0x10c033cf8>,
#  (u'fi1P', u'pI1P'): <__main__.classesPaire instance at 0x10c0db200>,
#  (u'ps2P', u'ai3S'): <__main__.classesPaire instance at 0x10e13c488>,
#  (u'pc1S', u'ai3S'): <__main__.classesPaire instance at 0x10c658320>,
#  (u'ii3S', u'ii3P'): <__main__.classesPaire instance at 0x10bbcb908>,
#  (u'FP', u'ps2S'): <__main__.classesPaire instance at 0x10c465560>,
#  (u'ps2S', u'fi1S'): <__main__.classesPaire instance at 0x10e3c7a28>,
#  (u'pi2P', u'fi1S'): <__main__.classesPaire instance at 0x109a5cf38>,
#  (u'ps3S', u'is2P'): <__main__.classesPaire instance at 0x10ed1b5f0>,
#  (u'pi1S', u'fi3S'): <__main__.classesPaire instance at 0x10bb90518>,
#  (u'is1P', u'pP'): <__main__.classesPaire instance at 0x10d202dd0>,
#  (u'ppFP', u'ppFP'): <__main__.classesPaire instance at 0x10c8f22d8>,
#  (u'ppFS', u'fi3S'): <__main__.classesPaire instance at 0x10b897170>,
#  (u'ii2P', u'ps3P'): <__main__.classesPaire instance at 0x10c142e18>,
#  (u'ii3S', u'ps3P'): <__main__.classesPaire instance at 0x10d370d88>,
#  (u'pc1P', u'fi3P'): <__main__.classesPaire instance at 0x10bb8fea8>,
#  (u'is3P', u'pI2P'): <__main__.classesPaire instance at 0x111204128>,
#  (u'ppMP', u'pc1P'): <__main__.classesPaire instance at 0x10c005e60>,
#  (u'is3P', u'ppFS'): <__main__.classesPaire instance at 0x10bbeb098>,
#  (u'ii3P', u'fi2S'): <__main__.classesPaire instance at 0x10c898b90>,
#  (u'inf', u'is2P'): <__main__.classesPaire instance at 0x10cd0c2d8>,
#  (u'fi1S', u'ps1S'): <__main__.classesPaire instance at 0x10bb3e170>,
#  (u'is1S', u'pc2P'): <__main__.classesPaire instance at 0x1096ca8c0>,
#  (u'pi3S', u'pc3S'): <__main__.classesPaire instance at 0x111315128>,
#  (u'ps3S', u'is3S'): <__main__.classesPaire instance at 0x10f22c680>,
#  (u'is2S', u'FS'): <__main__.classesPaire instance at 0x10e1b7098>,
#  (u'ppMP', u'ii3P'): <__main__.classesPaire instance at 0x10c3b57a0>,
#  (u'ppFS', u'pi1P'): <__main__.classesPaire instance at 0x110b39440>,
#  (u'ppFS', u'is3P'): <__main__.classesPaire instance at 0x10cfd2170>,
#  (u'ps2P', u'is3S'): <__main__.classesPaire instance at 0x10d064b48>,
#  (u'ps3P', u'is1P'): <__main__.classesPaire instance at 0x10b8a4998>,
#  (u'fi3S', u'fi2P'): <__main__.classesPaire instance at 0x10cfd2b48>,
#  (u'ppMP', u'ps3P'): <__main__.classesPaire instance at 0x1097b71b8>,
#  (u'pI2P', u'ps2P'): <__main__.classesPaire instance at 0x10c09cb48>,
#  (u'pi1S', u'pi2P'): <__main__.classesPaire instance at 0x1139a95f0>,
#  (u'is1P', u'pc2P'): <__main__.classesPaire instance at 0x10d105d88>,
#  (u'FS', u'fi3P'): <__main__.classesPaire instance at 0x10b8a0908>,
#  (u'pi1P', u'ai2P'): <__main__.classesPaire instance at 0x10d1c3680>,
#  (u'pI1P', u'ai2S'): <__main__.classesPaire instance at 0x110eea3b0>,
#  (u'pI2P', u'ps1S'): <__main__.classesPaire instance at 0x111315f38>,
#  (u'pi2P', u'pi3P'): <__main__.classesPaire instance at 0x1139a98c0>,
#  (u'fi1S', u'fi3S'): <__main__.classesPaire instance at 0x10d017cf8>,
#  (u'ii1P', u'pc2S'): <__main__.classesPaire instance at 0x10c4c7cf8>,
#  (u'pI2P', u'is1S'): <__main__.classesPaire instance at 0x10ef5cc68>,
#  (u'pc3S', u'is1P'): <__main__.classesPaire instance at 0x110bd6998>,
#  (u'ppMS', u'FS'): <__main__.classesPaire instance at 0x10c0dfc68>,
#  (u'ppFP', u'pI2P'): <__main__.classesPaire instance at 0x1113153f8>,
#  (u'is3S', u'ppMS'): <__main__.classesPaire instance at 0x10d055440>,
#  (u'ii2P', u'FS'): <__main__.classesPaire instance at 0x10cdd8128>,
#  (u'fi1P', u'ppFP'): <__main__.classesPaire instance at 0x1112ea680>,
#  (u'is2P', u'pP'): <__main__.classesPaire instance at 0x10c8564d0>,
#  (u'ps3S', u'fi1S'): <__main__.classesPaire instance at 0x10c1f8d88>,
#  (u'inf', u'is3P'): <__main__.classesPaire instance at 0x1115e3f38>,
#  (u'pI1P', u'ii1P'): <__main__.classesPaire instance at 0x10ee02758>,
#  (u'pP', u'ps1S'): <__main__.classesPaire instance at 0x1116f83f8>,
#  (u'pi3S', u'ai1P'): <__main__.classesPaire instance at 0x110f7f518>,
#  (u'pi2S', u'pI2P'): <__main__.classesPaire instance at 0x10d370518>,
#  (u'is2S', u'ps1P'): <__main__.classesPaire instance at 0x10cb3fef0>,
#  (u'is1P', u'fi2P'): <__main__.classesPaire instance at 0x11155e7a0>,
#  (u'pi3P', u'ii1P'): <__main__.classesPaire instance at 0x11124e950>,
#  (u'ppMS', u'is1P'): <__main__.classesPaire instance at 0x10c0d28c0>,
#  (u'ps3S', u'is1P'): <__main__.classesPaire instance at 0x1115fe6c8>,
#  (u'pP', u'ps2P'): <__main__.classesPaire instance at 0x10961c638>,
#  (u'inf', u'ps2S'): <__main__.classesPaire instance at 0x10d0205f0>,
#  (u'fi1P', u'ii2S'): <__main__.classesPaire instance at 0x111273ab8>,
#  (u'fi1P', u'fi1S'): <__main__.classesPaire instance at 0x10cb9e050>,
#  (u'ai1S', u'ii1P'): <__main__.classesPaire instance at 0x1096b6830>,
#  (u'pI1P', u'ai1S'): <__main__.classesPaire instance at 0x111315c68>,
#  (u'pi2P', u'pc1S'): <__main__.classesPaire instance at 0x10bbf6638>,
#  (u'pc3S', u'fi1S'): <__main__.classesPaire instance at 0x111315878>,
#  (u'pi1S', u'inf'): <__main__.classesPaire instance at 0x10c0d2440>,
#  (u'pP', u'pI2P'): <__main__.classesPaire instance at 0x10c60f050>,
#  (u'is1S', u'pi2P'): <__main__.classesPaire instance at 0x10c470cb0>,
#  (u'ppFP', u'pi2S'): <__main__.classesPaire instance at 0x10bbcbfc8>,
#  (u'is1P', u'ppMP'): <__main__.classesPaire instance at 0x10d6a4f80>,
#  (u'fi1P', u'is1P'): <__main__.classesPaire instance at 0x10d156638>,
#  (u'pi3S', u'pi3S'): <__main__.classesPaire instance at 0x10d02f518>,
#  (u'pI2S', u'ii3S'): <__main__.classesPaire instance at 0x1115e3998>,
#  (u'ai3S', u'is1P'): <__main__.classesPaire instance at 0x10c0bc908>,
#  (u'pc2P', u'FP'): <__main__.classesPaire instance at 0x10b273d88>,
#  (u'ai1P', u'ps1S'): <__main__.classesPaire instance at 0x10d1a4488>,
#  (u'ps3P', u'pi2S'): <__main__.classesPaire instance at 0x10bf5e3f8>,
#  (u'ps1S', u'ii2P'): <__main__.classesPaire instance at 0x1115fed40>,
#  (u'ai2S', u'is2P'): <__main__.classesPaire instance at 0x110bd4248>,
#  (u'fi2P', u'ps1P'): <__main__.classesPaire instance at 0x109611bd8>,
#  (u'ps2P', u'ps2P'): <__main__.classesPaire instance at 0x10c66e5f0>,
#  (u'pP', u'fi3P'): <__main__.classesPaire instance at 0x1105898c0>,
#  (u'is1S', u'ps3S'): <__main__.classesPaire instance at 0x10c8453f8>,
#  (u'ai2P', u'ii3P'): <__main__.classesPaire instance at 0x10c8e7fc8>,
#  (u'fi3P', u'ps1P'): <__main__.classesPaire instance at 0x111201cb0>,
#  (u'fi3P', u'is3P'): <__main__.classesPaire instance at 0x1139a9dd0>,
#  (u'pc3P', u'pi2S'): <__main__.classesPaire instance at 0x10f2a8368>,
#  (u'is3P', u'ii2P'): <__main__.classesPaire instance at 0x110bc1f80>,
#  (u'ppFS', u'pc1P'): <__main__.classesPaire instance at 0x10b8a4050>,
#  (u'ai2S', u'fi3P'): <__main__.classesPaire instance at 0x10ee35830>,
#  (u'pI2P', u'is2S'): <__main__.classesPaire instance at 0x10bd16830>,
#  (u'inf', u'pi3P'): <__main__.classesPaire instance at 0x10bbf6878>,
#  (u'pc3S', u'pc3P'): <__main__.classesPaire instance at 0x10962ebd8>,
#  (u'ps2S', u'pP'): <__main__.classesPaire instance at 0x109679fc8>,
#  (u'ai2P', u'pi1P'): <__main__.classesPaire instance at 0x10d00ef80>,
#  (u'ii3P', u'pI2P'): <__main__.classesPaire instance at 0x10d1c3fc8>,
#  (u'ii1P', u'pc3P'): <__main__.classesPaire instance at 0x11124e3f8>,
#  (u'pi1P', u'ai3S'): <__main__.classesPaire instance at 0x10d156488>,
#  (u'pI2P', u'fi2S'): <__main__.classesPaire instance at 0x10b282950>,
#  (u'pc1P', u'pi3P'): <__main__.classesPaire instance at 0x10d029bd8>,
#  (u'pI1P', u'ppMP'): <__main__.classesPaire instance at 0x10c1c47e8>,
#  (u'pi1S', u'pc3S'): <__main__.classesPaire instance at 0x10bf49170>,
#  (u'ii3S', u'pi3S'): <__main__.classesPaire instance at 0x111672320>,
#  (u'is2P', u'ppFS'): <__main__.classesPaire instance at 0x10bd16c20>,
#  (u'ppFP', u'pi3P'): <__main__.classesPaire instance at 0x10c4650e0>,
#  (u'pc2S', u'ai3S'): <__main__.classesPaire instance at 0x10c66eb48>,
#  (u'ii3S', u'pc1S'): <__main__.classesPaire instance at 0x10cfe00e0>,
#  (u'is2S', u'fi2S'): <__main__.classesPaire instance at 0x110b8de18>,
#  (u'pP', u'ai1P'): <__main__.classesPaire instance at 0x10ee02950>,
#  (u'pc3P', u'ps3P'): <__main__.classesPaire instance at 0x10b8a46c8>,
#  (u'is2P', u'fi2P'): <__main__.classesPaire instance at 0x10e1b77a0>,
#  (u'ppFP', u'ps3P'): <__main__.classesPaire instance at 0x10cd0c7a0>,
#  (u'ai1S', u'ppMP'): <__main__.classesPaire instance at 0x10ee026c8>,
#  (u'pi2S', u'ps2S'): <__main__.classesPaire instance at 0x10c643f38>,
#  (u'ps3S', u'pc3P'): <__main__.classesPaire instance at 0x10d370ea8>,
#  (u'ai3P', u'fi3P'): <__main__.classesPaire instance at 0x10bfc8c20>,
#  (u'pi1P', u'fi1P'): <__main__.classesPaire instance at 0x10bf491b8>,
#  (u'fi1S', u'ppMP'): <__main__.classesPaire instance at 0x1139a9878>,
#  (u'pc2S', u'is1S'): <__main__.classesPaire instance at 0x10c3b55a8>,
#  (u'ppMP', u'inf'): <__main__.classesPaire instance at 0x109625cb0>,
#  (u'ii3P', u'ai2S'): <__main__.classesPaire instance at 0x10c8e73b0>,
#  (u'pi3P', u'ai2P'): <__main__.classesPaire instance at 0x10e1b74d0>,
#  (u'ppMS', u'ps1P'): <__main__.classesPaire instance at 0x10b2355a8>,
#  (u'ppFP', u'fi3P'): <__main__.classesPaire instance at 0x10d1c39e0>,
#  (u'ppMS', u'pi1P'): <__main__.classesPaire instance at 0x1116f8050>,
#  (u'pi1S', u'is1P'): <__main__.classesPaire instance at 0x10bf2ac20>,
#  (u'ps3P', u'ai3S'): <__main__.classesPaire instance at 0x10bfd82d8>,
#  (u'is1S', u'pc3S'): <__main__.classesPaire instance at 0x10b8977e8>,
#  (u'ii1P', u'ii1S'): <__main__.classesPaire instance at 0x1095cd878>,
#  (u'fi2P', u'pi2S'): <__main__.classesPaire instance at 0x10d1c3cf8>,
#  (u'FP', u'pi1P'): <__main__.classesPaire instance at 0x10bd90830>,
#  (u'pi1S', u'pI2P'): <__main__.classesPaire instance at 0x10bd90cb0>,
#  (u'ppMP', u'ii2S'): <__main__.classesPaire instance at 0x10c0dffc8>,
#  (u'ai2S', u'is1P'): <__main__.classesPaire instance at 0x10d12c320>,
#  (u'FS', u'ii2S'): <__main__.classesPaire instance at 0x10d12cc20>,
#  (u'ii1S', u'pi1S'): <__main__.classesPaire instance at 0x110bc1098>,
#  (u'fi3P', u'fi3P'): <__main__.classesPaire instance at 0x10c0dbe18>,
#  (u'pI2P', u'pc2P'): <__main__.classesPaire instance at 0x1104c0b00>,
#  (u'FS', u'pi1S'): <__main__.classesPaire instance at 0x10d0177a0>,
#  (u'ai2S', u'pi3P'): <__main__.classesPaire instance at 0x11136ca70>,
#  (u'ai1S', u'FP'): <__main__.classesPaire instance at 0x111201dd0>,
#  (u'pc2P', u'fi2P'): <__main__.classesPaire instance at 0x10d3703b0>,
#  (u'FP', u'fi3S'): <__main__.classesPaire instance at 0x10ef2a0e0>,
#  (u'ai3P', u'ii1S'): <__main__.classesPaire instance at 0x10c1f8e60>,
#  (u'fi1S', u'ai3S'): <__main__.classesPaire instance at 0x10ef2a710>,
#  (u'ps3P', u'ps2S'): <__main__.classesPaire instance at 0x1116722d8>,
#  (u'pc1P', u'is2S'): <__main__.classesPaire instance at 0x110b8d368>,
#  (u'ii3P', u'is3S'): <__main__.classesPaire instance at 0x10cfe0560>,
#  (u'pi2P', u'pi2S'): <__main__.classesPaire instance at 0x10f2a1290>,
#  (u'ii3S', u'fi2S'): <__main__.classesPaire instance at 0x10d3704d0>,
#  (u'pc3P', u'pc3P'): <__main__.classesPaire instance at 0x10d022950>,
#  (u'ps1S', u'ps2P'): <__main__.classesPaire instance at 0x10c6435f0>,
#  (u'is2S', u'pc2S'): <__main__.classesPaire instance at 0x10c465fc8>,
#  (u'FP', u'pP'): <__main__.classesPaire instance at 0x10ee02170>,
#  (u'is3P', u'pc3S'): <__main__.classesPaire instance at 0x111067200>,
#  (u'ps1P', u'fi1P'): <__main__.classesPaire instance at 0x110bd4e60>,
#  (u'fi2S', u'pi3S'): <__main__.classesPaire instance at 0x10bf7d7e8>,
#  (u'ii1S', u'ai1P'): <__main__.classesPaire instance at 0x10c0df518>,
#  (u'pc2S', u'pi2S'): <__main__.classesPaire instance at 0x10c8e7bd8>,
#  (u'ii2P', u'ppMP'): <__main__.classesPaire instance at 0x10cd7c830>,
#  (u'is3P', u'pi1P'): <__main__.classesPaire instance at 0x1097b73b0>,
#  (u'ii2S', u'pc2P'): <__main__.classesPaire instance at 0x10bb90098>,
#  (u'pi1S', u'ai1P'): <__main__.classesPaire instance at 0x10cfd27e8>,
#  (u'pc3P', u'pi1S'): <__main__.classesPaire instance at 0x10bf49440>,
#  (u'fi3S', u'ai1S'): <__main__.classesPaire instance at 0x10e1b7c20>,
#  (u'ii1S', u'is3S'): <__main__.classesPaire instance at 0x11125fc68>,
#  (u'pc2P', u'ppFS'): <__main__.classesPaire instance at 0x111672b48>,
#  (u'ai1P', u'fi1P'): <__main__.classesPaire instance at 0x10bbcb8c0>,
#  (u'pi3P', u'ps3P'): <__main__.classesPaire instance at 0x10c1427e8>,
#  (u'pc2P', u'fi3S'): <__main__.classesPaire instance at 0x10c8f2c20>,
#  (u'ai2P', u'ppFP'): <__main__.classesPaire instance at 0x109a5c998>,
#  (u'pI1P', u'is3P'): <__main__.classesPaire instance at 0x1116f8bd8>,
#  (u'pc1P', u'fi1P'): <__main__.classesPaire instance at 0x10d017200>,
#  (u'ps1P', u'ii1S'): <__main__.classesPaire instance at 0x10b235128>,
#  (u'ai1S', u'fi1S'): <__main__.classesPaire instance at 0x10d102dd0>,
#  (u'ii2P', u'ai3S'): <__main__.classesPaire instance at 0x10c184830>,
#  (u'is2S', u'pI2S'): <__main__.classesPaire instance at 0x10c0335f0>,
#  (u'pi3P', u'is3P'): <__main__.classesPaire instance at 0x1112045f0>,
#  (u'is1S', u'pi3S'): <__main__.classesPaire instance at 0x10d0557e8>,
#  (u'FP', u'pi3P'): <__main__.classesPaire instance at 0x110bd6f80>,
#  (u'pi2P', u'is2P'): <__main__.classesPaire instance at 0x11166b560>,
#  (u'is1P', u'pc1P'): <__main__.classesPaire instance at 0x10d00ecb0>,
#  (u'ai1S', u'is3P'): <__main__.classesPaire instance at 0x111204560>,
#  (u'ps1S', u'fi3P'): <__main__.classesPaire instance at 0x10bf0b710>,
#  (u'pi1P', u'pi1P'): <__main__.classesPaire instance at 0x10c0bcf80>,
#  (u'pi2S', u'pI2S'): <__main__.classesPaire instance at 0x111201050>,
#  (u'pi2S', u'pc3S'): <__main__.classesPaire instance at 0x10bf5edd0>,
#  (u'pi1S', u'pi1S'): <__main__.classesPaire instance at 0x10c623518>,
#  (u'fi1S', u'ii1S'): <__main__.classesPaire instance at 0x10c1f8638>,
#  (u'pi2P', u'ps3P'): <__main__.classesPaire instance at 0x10b9b8440>,
#  (u'ai2S', u'pc3P'): <__main__.classesPaire instance at 0x10d12c680>,
#  (u'is2S', u'ai3P'): <__main__.classesPaire instance at 0x10bd90b48>,
#  (u'ppMP', u'ai3S'): <__main__.classesPaire instance at 0x10c1c4098>,
#  (u'ii2P', u'ppFP'): <__main__.classesPaire instance at 0x10c465dd0>,
#  (u'FP', u'ii2P'): <__main__.classesPaire instance at 0x10d156b48>,
#  (u'pi2P', u'ai3S'): <__main__.classesPaire instance at 0x10b2abf80>,
#  (u'ps1S', u'pc1S'): <__main__.classesPaire instance at 0x10bf5e050>,
#  (u'ai2P', u'FP'): <__main__.classesPaire instance at 0x10d0340e0>,
#  (u'ppMS', u'pI1P'): <__main__.classesPaire instance at 0x10cfc3320>,
#  (u'pc1S', u'fi3P'): <__main__.classesPaire instance at 0x110862050>,
#  (u'pc3P', u'inf'): <__main__.classesPaire instance at 0x111672a28>,
#  (u'fi2S', u'ai1P'): <__main__.classesPaire instance at 0x1096df6c8>,
#  (u'ps2P', u'fi1S'): <__main__.classesPaire instance at 0x10bf7ab48>,
#  (u'pc2S', u'pI2P'): <__main__.classesPaire instance at 0x1104c0bd8>,
#  (u'ii3P', u'FS'): <__main__.classesPaire instance at 0x110eea830>,
#  (u'fi2S', u'pI1P'): <__main__.classesPaire instance at 0x10c8e7f80>,
#  (u'ai3S', u'is2P'): <__main__.classesPaire instance at 0x10e1b7e60>,
#  (u'ii1P', u'pc1P'): <__main__.classesPaire instance at 0x10c4c7cb0>,
#  (u'ii3S', u'pi2S'): <__main__.classesPaire instance at 0x1115e3fc8>,
#  (u'ai1P', u'pi1S'): <__main__.classesPaire instance at 0x10c3a4dd0>,
#  (u'ii1S', u'ii1P'): <__main__.classesPaire instance at 0x109653368>,
#  (u'pc3P', u'is1P'): <__main__.classesPaire instance at 0x10c0dbea8>,
#  (u'ppFS', u'pI1P'): <__main__.classesPaire instance at 0x10e3c7878>,
#  (u'pi3S', u'is3P'): <__main__.classesPaire instance at 0x10cfe0ab8>,
#  (u'pI1P', u'fi3P'): <__main__.classesPaire instance at 0x10eb255a8>,
#  (u'ppFS', u'ps1S'): <__main__.classesPaire instance at 0x10d156d88>,
#  (u'is1P', u'ps3S'): <__main__.classesPaire instance at 0x10bbf6050>,
#  (u'pI2S', u'fi1S'): <__main__.classesPaire instance at 0x10bf0bd88>,
#  (u'ai2S', u'ii3P'): <__main__.classesPaire instance at 0x10c8e7758>,
#  (u'is1S', u'fi2S'): <__main__.classesPaire instance at 0x10c3b5ab8>,
#  (u'pi3S', u'ii1S'): <__main__.classesPaire instance at 0x10d6a4d40>,
#  (u'pP', u'pP'): <__main__.classesPaire instance at 0x111067a28>,
#  (u'ai3S', u'ai1P'): <__main__.classesPaire instance at 0x1115fe998>,
#  (u'fi3P', u'ppMP'): <__main__.classesPaire instance at 0x109632d88>,
#  (u'ii2S', u'pc3S'): <__main__.classesPaire instance at 0x10c081ab8>,
#  (u'ps3S', u'pI2S'): <__main__.classesPaire instance at 0x10b9b83f8>,
#  (u'ps2P', u'fi2S'): <__main__.classesPaire instance at 0x11114a320>,
#  (u'FS', u'ii3S'): <__main__.classesPaire instance at 0x10b992638>,
#  (u'ii2P', u'ai2S'): <__main__.classesPaire instance at 0x10c184758>,
#  (u'ai2P', u'is2P'): <__main__.classesPaire instance at 0x110bd4098>,
#  (u'pc1S', u'ii1S'): <__main__.classesPaire instance at 0x10c8563f8>,
#  (u'pc3S', u'pc2P'): <__main__.classesPaire instance at 0x10bfc8200>,
#  (u'ai2S', u'ps3P'): <__main__.classesPaire instance at 0x10c0a3cb0>,
#  (u'pi3P', u'is2S'): <__main__.classesPaire instance at 0x10c09c680>,
#  (u'ai1S', u'pi3P'): <__main__.classesPaire instance at 0x10bb3e128>,
#  (u'pI2S', u'ii1S'): <__main__.classesPaire instance at 0x10cd7c128>,
#  (u'ppFS', u'FP'): <__main__.classesPaire instance at 0x1112019e0>,
#  (u'is2P', u'pI1P'): <__main__.classesPaire instance at 0x111318d88>,
#  (u'fi2S', u'ppMP'): <__main__.classesPaire instance at 0x10b9b80e0>,
#  (u'fi2P', u'inf'): <__main__.classesPaire instance at 0x10d1a4560>,
#  (u'pP', u'fi1S'): <__main__.classesPaire instance at 0x10ef25320>,
#  (u'fi2P', u'pi3P'): <__main__.classesPaire instance at 0x10bb23b90>,
#  (u'ii1S', u'fi1P'): <__main__.classesPaire instance at 0x10c8b0f38>,
#  (u'pc3S', u'pI2S'): <__main__.classesPaire instance at 0x10d102fc8>,
#  (u'ai2S', u'ps2P'): <__main__.classesPaire instance at 0x111273b00>,
#  (u'fi3P', u'ps2S'): <__main__.classesPaire instance at 0x10bf7a5f0>,
#  (u'pi2P', u'pi1S'): <__main__.classesPaire instance at 0x1115fe0e0>,
#  (u'ai3S', u'pi1S'): <__main__.classesPaire instance at 0x10bf49128>,
#  (u'fi2S', u'ps3S'): <__main__.classesPaire instance at 0x10d1249e0>,
#  (u'FP', u'fi1S'): <__main__.classesPaire instance at 0x10bb8fcb0>,
#  (u'pc1S', u'ii2P'): <__main__.classesPaire instance at 0x10c623908>,
#  (u'ppMP', u'ps2S'): <__main__.classesPaire instance at 0x10c1f81b8>,
#  (u'pP', u'fi2S'): <__main__.classesPaire instance at 0x111366ea8>,
#  (u'ps3P', u'pP'): <__main__.classesPaire instance at 0x10c856320>,
#  (u'fi3S', u'pP'): <__main__.classesPaire instance at 0x1116f8878>,
#  (u'fi3P', u'ai3S'): <__main__.classesPaire instance at 0x10bdab908>,
#  (u'ps1P', u'pc1S'): <__main__.classesPaire instance at 0x10bd3f518>,
#  (u'FP', u'ppMS'): <__main__.classesPaire instance at 0x10cb816c8>,
#  (u'ai3S', u'fi1P'): <__main__.classesPaire instance at 0x10bf7a488>,
#  (u'ppFS', u'pc2S'): <__main__.classesPaire instance at 0x10b8a4f80>,
#  (u'ii1S', u'ppMP'): <__main__.classesPaire instance at 0x10b988f38>,
#  (u'pi1P', u'pI1P'): <__main__.classesPaire instance at 0x10ef20638>,
#  (u'ppFP', u'pc3P'): <__main__.classesPaire instance at 0x10c3a45f0>,
#  (u'pc2P', u'pc3S'): <__main__.classesPaire instance at 0x11155e128>,
#  (u'ps2P', u'pc1S'): <__main__.classesPaire instance at 0x10bf5e6c8>,
#  (u'fi2S', u'pi2P'): <__main__.classesPaire instance at 0x1112ea320>,
#  (u'fi1P', u'ai3P'): <__main__.classesPaire instance at 0x111239878>,
#  (u'pi2P', u'ai1P'): <__main__.classesPaire instance at 0x11125f4d0>,
#  (u'pc2S', u'pi3P'): <__main__.classesPaire instance at 0x10b2823b0>,
#  (u'fi2P', u'fi3S'): <__main__.classesPaire instance at 0x10bf0b2d8>,
#  (u'ii2S', u'ii2P'): <__main__.classesPaire instance at 0x10bb90a28>,
#  (u'inf', u'FP'): <__main__.classesPaire instance at 0x10c643cf8>,
#  (u'pc2S', u'ps3P'): <__main__.classesPaire instance at 0x109a5cb00>,
#  (u'fi2S', u'ii1P'): <__main__.classesPaire instance at 0x10b992f80>,
#  (u'fi3S', u'fi1P'): <__main__.classesPaire instance at 0x10c85c5f0>,
#  (u'FS', u'ai3P'): <__main__.classesPaire instance at 0x110862d88>,
#  (u'pI2S', u'pi2P'): <__main__.classesPaire instance at 0x1115fe8c0>,
#  (u'ii2S', u'pP'): <__main__.classesPaire instance at 0x10bf247e8>,
#  (u'is2P', u'is3S'): <__main__.classesPaire instance at 0x10c3a4368>,
#  (u'pc1S', u'ppMS'): <__main__.classesPaire instance at 0x10d13e1b8>,
#  (u'fi3S', u'is2S'): <__main__.classesPaire instance at 0x10cb3fa28>,
#  (u'pI2S', u'ppMS'): <__main__.classesPaire instance at 0x10c1f8c20>,
#  (u'ppFP', u'pc2P'): <__main__.classesPaire instance at 0x10c09c098>,
#  (u'pc3P', u'FS'): <__main__.classesPaire instance at 0x10ef2a3b0>,
#  (u'pc1S', u'ps3P'): <__main__.classesPaire instance at 0x10c0a3f80>,
#  (u'pc3P', u'ps2P'): <__main__.classesPaire instance at 0x110f7fea8>,
#  (u'ai3S', u'ai3S'): <__main__.classesPaire instance at 0x10d017170>,
#  (u'ps1P', u'fi3S'): <__main__.classesPaire instance at 0x10c66e4d0>,
#  (u'ps1S', u'ppMP'): <__main__.classesPaire instance at 0x1115e35f0>,
#  (u'is3P', u'ps1P'): <__main__.classesPaire instance at 0x1112042d8>,
#  (u'pi3S', u'pi1P'): <__main__.classesPaire instance at 0x10bbda050>,
#  (u'FS', u'ps1P'): <__main__.classesPaire instance at 0x10d22c830>,
#  (u'pI2P', u'pP'): <__main__.classesPaire instance at 0x10c60f7e8>,
#  (u'fi2S', u'ai2S'): <__main__.classesPaire instance at 0x10d105998>,
#  (u'pi3S', u'FS'): <__main__.classesPaire instance at 0x10eb255f0>,
#  (u'ps3S', u'ii2S'): <__main__.classesPaire instance at 0x1095cfef0>,
#  (u'inf', u'ps1S'): <__main__.classesPaire instance at 0x10b235dd0>,
#  (u'pc2S', u'ai1P'): <__main__.classesPaire instance at 0x1095cf710>,
#  (u'ps2S', u'fi3P'): <__main__.classesPaire instance at 0x10bf7a638>,
#  (u'fi3S', u'ppFP'): <__main__.classesPaire instance at 0x10cfc39e0>,
#  (u'ppMP', u'ai2P'): <__main__.classesPaire instance at 0x10c665680>,
#  (u'pI2P', u'ai3P'): <__main__.classesPaire instance at 0x10b294f38>,
#  (u'pi1S', u'ii3S'): <__main__.classesPaire instance at 0x10d124050>,
#  (u'FP', u'ii3S'): <__main__.classesPaire instance at 0x10d1a4098>,
#  (u'ps3P', u'FS'): <__main__.classesPaire instance at 0x110eea128>,
#  (u'ai3P', u'ii2S'): <__main__.classesPaire instance at 0x110b39cb0>,
#  (u'fi2P', u'FP'): <__main__.classesPaire instance at 0x10b294098>,
#  (u'pi3S', u'fi3S'): <__main__.classesPaire instance at 0x10f2a8638>,
#  (u'pI2P', u'pc1P'): <__main__.classesPaire instance at 0x10ee35d40>,
#  (u'is3S', u'ppFP'): <__main__.classesPaire instance at 0x10c0d2ea8>,
#  (u'ii1S', u'inf'): <__main__.classesPaire instance at 0x10c4705f0>,
#  (u'ii1P', u'pc3S'): <__main__.classesPaire instance at 0x10b8b0f80>,
#  (u'is2P', u'pI2P'): <__main__.classesPaire instance at 0x10d01e488>,
#  (u'is2S', u'inf'): <__main__.classesPaire instance at 0x10c8b0b90>,
#  (u'fi2P', u'pI2S'): <__main__.classesPaire instance at 0x10c1f8ef0>,
#  (u'ai2P', u'ai3S'): <__main__.classesPaire instance at 0x109a5cd88>,
#  (u'pI1P', u'ii3P'): <__main__.classesPaire instance at 0x11136c3f8>,
#  (u'is1S', u'FP'): <__main__.classesPaire instance at 0x10cdb53b0>,
#  (u'ai1P', u'ppFP'): <__main__.classesPaire instance at 0x10d0615a8>,
#  (u'is1S', u'ps2S'): <__main__.classesPaire instance at 0x10c533710>,
#  (u'ai2P', u'ps1P'): <__main__.classesPaire instance at 0x10e13c050>,
#  (u'is1S', u'ppFS'): <__main__.classesPaire instance at 0x10c533098>,
#  (u'ppMP', u'ii1S'): <__main__.classesPaire instance at 0x11125f5a8>,
#  (u'FP', u'ai2P'): <__main__.classesPaire instance at 0x10d034950>,
#  (u'ii1P', u'ps2S'): <__main__.classesPaire instance at 0x10bb12638>,
#  (u'ai3S', u'pc1S'): <__main__.classesPaire instance at 0x10b2735a8>,
#  (u'pc2S', u'pi1S'): <__main__.classesPaire instance at 0x10d12c290>,
#  (u'ii1S', u'ai2S'): <__main__.classesPaire instance at 0x10b9b86c8>,
#  (u'ppFS', u'ppFS'): <__main__.classesPaire instance at 0x110b39ab8>,
#  (u'fi1P', u'FS'): <__main__.classesPaire instance at 0x10c0dbcb0>,
#  (u'ii2S', u'pc1S'): <__main__.classesPaire instance at 0x10d02f200>,
#  (u'pi2P', u'fi3S'): <__main__.classesPaire instance at 0x1112ea9e0>,
#  (u'ii3S', u'ai1P'): <__main__.classesPaire instance at 0x10f2a88c0>,
#  (u'pc2S', u'ii2S'): <__main__.classesPaire instance at 0x10bfc8cf8>,
#  (u'pi1P', u'fi2S'): <__main__.classesPaire instance at 0x1112737e8>,
#  (u'is1P', u'is2S'): <__main__.classesPaire instance at 0x10c09c200>,
#  (u'fi2P', u'ai1P'): <__main__.classesPaire instance at 0x10b992440>,
#  (u'ppFP', u'ai1S'): <__main__.classesPaire instance at 0x10d105758>,
#  (u'inf', u'fi3P'): <__main__.classesPaire instance at 0x10bbda998>,
#  (u'FS', u'pc1P'): <__main__.classesPaire instance at 0x10c623128>,
#  (u'pI2S', u'is2P'): <__main__.classesPaire instance at 0x10e1b7488>,
#  (u'is3S', u'ps2S'): <__main__.classesPaire instance at 0x10ed1bfc8>,
#  (u'ai3S', u'pi2S'): <__main__.classesPaire instance at 0x10b2abc20>,
#  (u'pi3S', u'is1S'): <__main__.classesPaire instance at 0x11125a758>,
#  (u'ii2P', u'pc2S'): <__main__.classesPaire instance at 0x10d102248>,
#  (u'pI1P', u'ppFP'): <__main__.classesPaire instance at 0x10d105bd8>,
#  (u'ps1P', u'ii2P'): <__main__.classesPaire instance at 0x10c142f80>,
#  (u'fi1P', u'pc1P'): <__main__.classesPaire instance at 0x10bf7a1b8>,
#  (u'pI2S', u'ai2P'): <__main__.classesPaire instance at 0x10b9b8878>,
#  (u'ii2P', u'is1P'): <__main__.classesPaire instance at 0x10b8a0c20>,
#  (u'ps3S', u'inf'): <__main__.classesPaire instance at 0x1116724d0>,
#  (u'is2P', u'fi1P'): <__main__.classesPaire instance at 0x111318200>,
#  (u'fi2P', u'pi1S'): <__main__.classesPaire instance at 0x110eeab00>,
#  (u'ps1P', u'is1S'): <__main__.classesPaire instance at 0x110f7f908>,
#  (u'is2S', u'ps3S'): <__main__.classesPaire instance at 0x10d370950>,
#  (u'ppFS', u'fi2S'): <__main__.classesPaire instance at 0x10c1b0ab8>,
#  (u'ppFP', u'is2S'): <__main__.classesPaire instance at 0x10d1058c0>,
#  (u'fi3P', u'pc1S'): <__main__.classesPaire instance at 0x10ef2ae60>,
#  (u'ps1S', u'ai2S'): <__main__.classesPaire instance at 0x109706680>,
#  (u'pi2S', u'pc2S'): <__main__.classesPaire instance at 0x10c8e7878>,
#  (u'ps1S', u'pi1P'): <__main__.classesPaire instance at 0x10c06b950>,
#  (u'fi3P', u'ai2P'): <__main__.classesPaire instance at 0x10c85cb00>,
#  (u'is3S', u'pI2S'): <__main__.classesPaire instance at 0x10c0dfb48>,
#  (u'ai2P', u'ai2S'): <__main__.classesPaire instance at 0x10c85c248>,
#  (u'fi1P', u'FP'): <__main__.classesPaire instance at 0x10bdab320>,
#  (u'pi2P', u'pI2P'): <__main__.classesPaire instance at 0x10bd16170>,
#  (u'inf', u'pc1S'): <__main__.classesPaire instance at 0x1139a97a0>,
#  (u'pc3S', u'inf'): <__main__.classesPaire instance at 0x10b2ab1b8>,
#  (u'ppMP', u'ppMS'): <__main__.classesPaire instance at 0x110bc1ef0>,
#  (u'ii3P', u'pi2S'): <__main__.classesPaire instance at 0x10d3703f8>,
#  (u'ai3P', u'pI1P'): <__main__.classesPaire instance at 0x10969e3f8>,
#  (u'is2P', u'ppMP'): <__main__.classesPaire instance at 0x10c0d2cf8>,
#  (u'fi1S', u'pc3S'): <__main__.classesPaire instance at 0x10d01eea8>,
#  (u'pc2P', u'ps1S'): <__main__.classesPaire instance at 0x10c8b0200>,
#  (u'fi1P', u'ai2S'): <__main__.classesPaire instance at 0x10d02f3f8>,
#  (u'pc1P', u'ai3S'): <__main__.classesPaire instance at 0x10bf49a70>,
#  (u'ps3S', u'ii1S'): <__main__.classesPaire instance at 0x10c665170>,
#  (u'is2P', u'ps3S'): <__main__.classesPaire instance at 0x10b897050>,
#  (u'ppFP', u'fi2S'): <__main__.classesPaire instance at 0x10f2a1dd0>,
#  (u'ppMS', u'is3P'): <__main__.classesPaire instance at 0x10f2a1f80>,
#  (u'ii3S', u'is1S'): <__main__.classesPaire instance at 0x10c845050>,
#  (u'inf', u'ppMS'): <__main__.classesPaire instance at 0x10c665d88>,
#  (u'ppMS', u'ai2S'): <__main__.classesPaire instance at 0x10b897a28>,
#  (u'pc2S', u'is2P'): <__main__.classesPaire instance at 0x10cd0c6c8>,
#  (u'is2P', u'pi3S'): <__main__.classesPaire instance at 0x10e1b7200>,
#  (u'ii3S', u'ps3S'): <__main__.classesPaire instance at 0x1116727a0>,
#  (u'ai2P', u'ii2P'): <__main__.classesPaire instance at 0x10c033998>,
#  (u'pi2P', u'pc3S'): <__main__.classesPaire instance at 0x10d1c3170>,
#  (u'is3P', u'pc2S'): <__main__.classesPaire instance at 0x10f2a8518>,
#  (u'fi3P', u'ppFS'): <__main__.classesPaire instance at 0x110b8d710>,
#  (u'ii2S', u'pi1S'): <__main__.classesPaire instance at 0x10cdd8758>,
#  (u'is2S', u'pc3S'): <__main__.classesPaire instance at 0x10c09ccb0>,
#  (u'ii2S', u'ai2P'): <__main__.classesPaire instance at 0x10d22cb90>,
#  (u'fi1S', u'ps1P'): <__main__.classesPaire instance at 0x110bd6128>,
#  (u'pc3P', u'pc2P'): <__main__.classesPaire instance at 0x11136c638>,
#  (u'fi3P', u'pi2S'): <__main__.classesPaire instance at 0x10cb92680>,
#  (u'ps1P', u'ii3P'): <__main__.classesPaire instance at 0x10bb23518>,
#  (u'ps1S', u'ai1P'): <__main__.classesPaire instance at 0x10d1a4ea8>,
#  (u'is2S', u'ai1P'): <__main__.classesPaire instance at 0x10c1f8758>,
#  (u'FP', u'ii1S'): <__main__.classesPaire instance at 0x10cb810e0>,
#  (u'ii3P', u'ppMP'): <__main__.classesPaire instance at 0x10d6a4ea8>,
#  (u'pc1S', u'pi2S'): <__main__.classesPaire instance at 0x111210908>,
#  (u'ps2S', u'fi1P'): <__main__.classesPaire instance at 0x1112ea2d8>,
#  (u'ii1P', u'ai3P'): <__main__.classesPaire instance at 0x105e52f38>,
#  (u'pI2P', u'ai1P'): <__main__.classesPaire instance at 0x10cfe0cb0>,
#  (u'fi2S', u'ai3P'): <__main__.classesPaire instance at 0x10d01e320>,
#  (u'ii2S', u'ii1S'): <__main__.classesPaire instance at 0x10c0df8c0>,
#  (u'ai1P', u'FS'): <__main__.classesPaire instance at 0x10bfd8b48>,
#  (u'ps3S', u'is2S'): <__main__.classesPaire instance at 0x10d370170>,
#  (u'pI2P', u'pc3P'): <__main__.classesPaire instance at 0x1096a2f80>,
#  (u'pc3S', u'ai1S'): <__main__.classesPaire instance at 0x111318830>,
#  (u'ai2P', u'ps2P'): <__main__.classesPaire instance at 0x10d0348c0>,
#  (u'pc1P', u'ii2S'): <__main__.classesPaire instance at 0x10c85c290>,
#  (u'pc1P', u'ii3P'): <__main__.classesPaire instance at 0x10cfc3128>,
#  (u'pi1P', u'ai2S'): <__main__.classesPaire instance at 0x10bbdaf80>,
#  (u'pi1S', u'ii2P'): <__main__.classesPaire instance at 0x10c465f38>,
#  (u'ppFS', u'ii3S'): <__main__.classesPaire instance at 0x1097b74d0>,
#  (u'fi3P', u'ps3P'): <__main__.classesPaire instance at 0x1139a9ab8>,
#  (u'ps3P', u'ps1S'): <__main__.classesPaire instance at 0x10f2a1f38>,
#  (u'ppMP', u'pc1S'): <__main__.classesPaire instance at 0x10c8b0b00>,
#  (u'ppFS', u'fi1P'): <__main__.classesPaire instance at 0x10c3a4098>,
#  (u'ps2S', u'ppFS'): <__main__.classesPaire instance at 0x109a5c5a8>,
#  (u'is1S', u'pc2S'): <__main__.classesPaire instance at 0x10c3b5fc8>,
#  (u'ppFP', u'ppMP'): <__main__.classesPaire instance at 0x10b235cf8>,
#  (u'ps3S', u'fi2S'): <__main__.classesPaire instance at 0x10ed1b950>,
#  (u'pP', u'is2S'): <__main__.classesPaire instance at 0x10d202200>,
#  (u'ii3S', u'inf'): <__main__.classesPaire instance at 0x10c8f20e0>,
#  (u'ppFS', u'pi1S'): <__main__.classesPaire instance at 0x10c033f38>,
#  (u'ii1P', u'FS'): <__main__.classesPaire instance at 0x10d061dd0>,
#  (u'ps2P', u'is3P'): <__main__.classesPaire instance at 0x10c1b0098>,
#  (u'FP', u'pc3S'): <__main__.classesPaire instance at 0x10c0339e0>,
#  (u'ps2P', u'ps1P'): <__main__.classesPaire instance at 0x10d034cf8>,
#  (u'pc2P', u'is1S'): <__main__.classesPaire instance at 0x1096ca950>,
#  (u'ii1S', u'ai3P'): <__main__.classesPaire instance at 0x1113c8098>,
#  (u'fi3S', u'pi2S'): <__main__.classesPaire instance at 0x10cb92440>,
#  (u'is1P', u'ai1P'): <__main__.classesPaire instance at 0x109706a28>,
#  (u'is1P', u'ppFS'): <__main__.classesPaire instance at 0x10cfd2128>,
#  (u'pc3S', u'FS'): <__main__.classesPaire instance at 0x10bdabf80>,
#  (u'is2P', u'ai2S'): <__main__.classesPaire instance at 0x110bd4200>,
#  (u'ai2P', u'pI2S'): <__main__.classesPaire instance at 0x110bd4a28>,
#  (u'fi1P', u'ppMP'): <__main__.classesPaire instance at 0x10d124170>,
#  (u'ps1S', u'ps3S'): <__main__.classesPaire instance at 0x10c0df638>,
#  (u'fi3P', u'pI2P'): <__main__.classesPaire instance at 0x10bb3e710>,
#  (u'pI1P', u'ai2P'): <__main__.classesPaire instance at 0x10d034a28>,
#  (u'pi1S', u'pc2S'): <__main__.classesPaire instance at 0x10bbdabd8>,
#  (u'pi2P', u'pi3S'): <__main__.classesPaire instance at 0x10c033a28>,
#  (u'ii1P', u'pc2P'): <__main__.classesPaire instance at 0x109653b90>,
#  (u'ii1P', u'ii3S'): <__main__.classesPaire instance at 0x10ee02f38>,
#  (u'ppFP', u'pI2S'): <__main__.classesPaire instance at 0x10c09cab8>,
#  (u'fi1S', u'fi2S'): <__main__.classesPaire instance at 0x110bd6710>,
#  (u'is1S', u'ii2P'): <__main__.classesPaire instance at 0x11125a998>,
#  (u'pi2P', u'is1S'): <__main__.classesPaire instance at 0x10c470a28>,
#  (u'fi2S', u'pI2P'): <__main__.classesPaire instance at 0x10b282a70>,
#  (u'pc1P', u'ai2S'): <__main__.classesPaire instance at 0x10d12ccb0>,
#  (u'pi1P', u'pc3P'): <__main__.classesPaire instance at 0x10d00ee18>,
#  (u'fi2S', u'is1P'): <__main__.classesPaire instance at 0x10bd167e8>,
#  (u'ppMS', u'ppMP'): <__main__.classesPaire instance at 0x10f22c758>,
#  (u'ps3S', u'FS'): <__main__.classesPaire instance at 0x10d370998>,
#  (u'is2S', u'ppFP'): <__main__.classesPaire instance at 0x10d105560>,
#  (u'pc1S', u'pI1P'): <__main__.classesPaire instance at 0x11155d290>,
#  (u'pi2P', u'ppFP'): <__main__.classesPaire instance at 0x10c142b00>,
#  (u'pP', u'ps1P'): <__main__.classesPaire instance at 0x10ee477e8>,
#  (u'is1P', u'pi1S'): <__main__.classesPaire instance at 0x10bf2af38>,
#  (u'ai2P', u'pc3S'): <__main__.classesPaire instance at 0x10d01eb48>,
#  (u'fi3P', u'ai1S'): <__main__.classesPaire instance at 0x110bd46c8>,
#  (u'ii2S', u'ppMS'): <__main__.classesPaire instance at 0x10f22cc20>,
#  (u'pi3P', u'ii1S'): <__main__.classesPaire instance at 0x10c898950>,
#  (u'is2P', u'is2S'): <__main__.classesPaire instance at 0x10c033c20>,
#  (u'ai1P', u'pP'): <__main__.classesPaire instance at 0x1095cfb00>,
#  (u'ai3P', u'is3P'): <__main__.classesPaire instance at 0x10ebf9fc8>,
#  (u'pI1P', u'ps3S'): <__main__.classesPaire instance at 0x10f2a13f8>,
#  (u'ai1S', u'fi3P'): <__main__.classesPaire instance at 0x110bd4fc8>,
#  (u'ps1P', u'ai2P'): <__main__.classesPaire instance at 0x111315710>,
#  (u'ii3P', u'fi3P'): <__main__.classesPaire instance at 0x10c8e7c20>,
#  (u'pi2P', u'inf'): <__main__.classesPaire instance at 0x1116725a8>,
#  (u'pi2P', u'fi1P'): <__main__.classesPaire instance at 0x110bc1170>,
#  (u'ii2S', u'fi2S'): <__main__.classesPaire instance at 0x1113183b0>,
#  (u'FP', u'FS'): <__main__.classesPaire instance at 0x10c85c758>,
#  (u'pP', u'ai3P'): <__main__.classesPaire instance at 0x1116f8758>,
#  (u'fi3P', u'ii1S'): <__main__.classesPaire instance at 0x10c643a28>,
#  (u'is1P', u'ai2P'): <__main__.classesPaire instance at 0x10c85c2d8>,
#  (u'ppMP', u'fi3S'): <__main__.classesPaire instance at 0x10c005dd0>,
#  (u'ai3S', u'ii3P'): <__main__.classesPaire instance at 0x11136c6c8>,
#  (u'ps1S', u'ii2S'): <__main__.classesPaire instance at 0x1115e3dd0>,
#  (u'ps3P', u'ai1P'): <__main__.classesPaire instance at 0x10b2356c8>,
#  (u'pi3P', u'ii3S'): <__main__.classesPaire instance at 0x1139a97e8>,
#  (u'ii3S', u'pc2P'): <__main__.classesPaire instance at 0x1115fe560>,
#  (u'ai2P', u'ppMS'): <__main__.classesPaire instance at 0x10c1b0128>,
#  (u'fi2S', u'fi1P'): <__main__.classesPaire instance at 0x10c184638>,
#  (u'fi1P', u'fi2P'): <__main__.classesPaire instance at 0x1096a2b00>,
#  (u'ii2S', u'ppFS'): <__main__.classesPaire instance at 0x10bd16560>,
#  (u'pP', u'ppMP'): <__main__.classesPaire instance at 0x11124e320>,
#  (u'ai2S', u'fi2S'): <__main__.classesPaire instance at 0x10d105d40>,
#  (u'is2P', u'pi2P'): <__main__.classesPaire instance at 0x10d1564d0>,
#  (u'fi1S', u'is2P'): <__main__.classesPaire instance at 0x111318908>,
#  (u'pc2S', u'pc1S'): <__main__.classesPaire instance at 0x10b2ab878>,
#  (u'pc3S', u'pc3S'): <__main__.classesPaire instance at 0x10bd16518>,
#  (u'pi1P', u'is2S'): <__main__.classesPaire instance at 0x10cb3fb90>,
#  (u'fi3P', u'inf'): <__main__.classesPaire instance at 0x10bbf65f0>,
#  (u'ppMS', u'ii1P'): <__main__.classesPaire instance at 0x10b9927e8>,
#  (u'ai2S', u'ai3S'): <__main__.classesPaire instance at 0x1113155a8>,
#  (u'pI2S', u'pc1S'): <__main__.classesPaire instance at 0x10c06b4d0>,
#  (u'fi3P', u'pi3P'): <__main__.classesPaire instance at 0x10cb9e2d8>,
#  (u'pi3S', u'ps3S'): <__main__.classesPaire instance at 0x11166bc20>,
#  (u'pI1P', u'ppMS'): <__main__.classesPaire instance at 0x10cfc3c20>,
#  (u'fi2P', u'ai3S'): <__main__.classesPaire instance at 0x1139a9cf8>,
#  (u'pc1P', u'pP'): <__main__.classesPaire instance at 0x11123cd40>,
#  (u'pi3P', u'ppMS'): <__main__.classesPaire instance at 0x10ee225f0>,
#  (u'fi2P', u'fi2S'): <__main__.classesPaire instance at 0x10c67a200>,
#  (u'pI1P', u'FS'): <__main__.classesPaire instance at 0x10bf7a9e0>,
#  (u'fi2S', u'fi2P'): <__main__.classesPaire instance at 0x10cd237a0>,
#  (u'is3S', u'ai3P'): <__main__.classesPaire instance at 0x10cd0c8c0>,
#  (u'is2S', u'fi2P'): <__main__.classesPaire instance at 0x10c0a3e60>,
#  (u'pI1P', u'ps2P'): <__main__.classesPaire instance at 0x10d064758>,
#  (u'ii1P', u'ai2S'): <__main__.classesPaire instance at 0x10c4c7f80>,
#  (u'ppMP', u'FP'): <__main__.classesPaire instance at 0x1095ffa70>,
#  (u'ai1S', u'ppMS'): <__main__.classesPaire instance at 0x10cfc3b48>,
#  (u'pc1S', u'ppFS'): <__main__.classesPaire instance at 0x1112ea098>,
#  (u'ps3S', u'pc3S'): <__main__.classesPaire instance at 0x10c8f23b0>,
#  (u'fi2P', u'ppFP'): <__main__.classesPaire instance at 0x10b2abe18>,
#  (u'is3S', u'pP'): <__main__.classesPaire instance at 0x10b8b0b90>,
#  (u'ps2P', u'ppMS'): <__main__.classesPaire instance at 0x1115e3a70>,
#  (u'fi2P', u'is2P'): <__main__.classesPaire instance at 0x10d01ed40>,
#  (u'ii2P', u'ai1P'): <__main__.classesPaire instance at 0x10cd0c7e8>,
#  (u'pi3S', u'pc2S'): <__main__.classesPaire instance at 0x10d02fb00>,
#  (u'is1S', u'pc3P'): <__main__.classesPaire instance at 0x10f22ca28>,
#  (u'pi1P', u'ppFP'): <__main__.classesPaire instance at 0x10c8f2ab8>,
#  (u'ii1P', u'ii1P'): <__main__.classesPaire instance at 0x10b243fc8>,
#  (u'ai1P', u'pI2S'): <__main__.classesPaire instance at 0x10d1a4908>,
#  (u'ii2P', u'fi1P'): <__main__.classesPaire instance at 0x10b273098>,
#  (u'FS', u'pP'): <__main__.classesPaire instance at 0x10d0610e0>,
#  (u'ai3P', u'ps1P'): <__main__.classesPaire instance at 0x10bd3f098>,
#  (u'FP', u'pc1S'): <__main__.classesPaire instance at 0x10bb3e950>,
#  (u'inf', u'ps3P'): <__main__.classesPaire instance at 0x1116f8ab8>,
#  (u'pI2S', u'ps1S'): <__main__.classesPaire instance at 0x10d01e248>,
#  (u'pc2S', u'fi2S'): <__main__.classesPaire instance at 0x10c1842d8>,
#  (u'is2P', u'ps1S'): <__main__.classesPaire instance at 0x10e1b7ab8>,
#  (u'is3P', u'ai1P'): <__main__.classesPaire instance at 0x10c6657a0>,
#  (u'pi3P', u'pI2P'): <__main__.classesPaire instance at 0x10bf7ab90>,
#  (u'pi3P', u'ps3S'): <__main__.classesPaire instance at 0x10c67af38>,
#  (u'is2P', u'ai3P'): <__main__.classesPaire instance at 0x111318bd8>,
#  (u'FP', u'fi3P'): <__main__.classesPaire instance at 0x10c658e18>,
#  (u'pi2S', u'fi1P'): <__main__.classesPaire instance at 0x10c8f2878>,
#  (u'ps1P', u'ii1P'): <__main__.classesPaire instance at 0x10cdb5908>,
#  (u'pi2P', u'pi2P'): <__main__.classesPaire instance at 0x10b8a45a8>,
#  (u'ii1P', u'ii2P'): <__main__.classesPaire instance at 0x10d0613f8>,
#  (u'ppFP', u'is2P'): <__main__.classesPaire instance at 0x10d105e60>,
#  (u'pc2P', u'ai1S'): <__main__.classesPaire instance at 0x111210ab8>,
#  (u'is2S', u'pc2P'): <__main__.classesPaire instance at 0x10cb3f1b8>,
#  (u'fi1P', u'pI2P'): <__main__.classesPaire instance at 0x10cd239e0>,
#  (u'fi2S', u'pi3P'): <__main__.classesPaire instance at 0x1116f87a0>,
#  (u'is3P', u'pi1S'): <__main__.classesPaire instance at 0x10cfd23b0>,
#  (u'ps2P', u'pI2P'): <__main__.classesPaire instance at 0x10b294680>,
#  (u'pc2S', u'fi1S'): <__main__.classesPaire instance at 0x10b8a0cb0>,
#  (u'fi2S', u'pc2P'): <__main__.classesPaire instance at 0x10bf2a950>,
#  (u'pc1P', u'ai1P'): <__main__.classesPaire instance at 0x10cd0ce18>,
#  (u'fi2S', u'is3S'): <__main__.classesPaire instance at 0x10bf7d830>,
#  (u'ps2S', u'pi1S'): <__main__.classesPaire instance at 0x10c09c4d0>,
#  (u'fi2S', u'ps1S'): <__main__.classesPaire instance at 0x10d1057a0>,
#  (u'ps2P', u'ii1S'): <__main__.classesPaire instance at 0x10b235560>,
#  (u'pc2P', u'ii3S'): <__main__.classesPaire instance at 0x10f2a19e0>,
#  (u'is3S', u'FS'): <__main__.classesPaire instance at 0x10c1f85a8>,
#  (u'ppMP', u'pc3S'): <__main__.classesPaire instance at 0x10c1c49e0>,
#  (u'ai1S', u'fi1P'): <__main__.classesPaire instance at 0x10ee35a70>,
#  (u'ppMS', u'pI2P'): <__main__.classesPaire instance at 0x10c0da128>,
#  (u'ii3S', u'ps1P'): <__main__.classesPaire instance at 0x111204ea8>,
#  (u'is1S', u'inf'): <__main__.classesPaire instance at 0x10cd3f128>,
#  (u'ps1S', u'pi1S'): <__main__.classesPaire instance at 0x10bb3ed40>,
#  (u'ps1P', u'pc3S'): <__main__.classesPaire instance at 0x10cd23440>,
#  (u'pi3P', u'is3S'): <__main__.classesPaire instance at 0x10c1c4518>,
#  (u'pc3S', u'pi3P'): <__main__.classesPaire instance at 0x10ef20b48>,
#  (u'ii1P', u'ppMP'): <__main__.classesPaire instance at 0x106ab3dd0>,
#  (u'ai2P', u'is3P'): <__main__.classesPaire instance at 0x109675b00>,
#  (u'pc1P', u'is2P'): <__main__.classesPaire instance at 0x10cb3fab8>,
#  (u'ai1P', u'pI1P'): <__main__.classesPaire instance at 0x10d1241b8>,
#  (u'is1S', u'is1P'): <__main__.classesPaire instance at 0x10f22c5f0>,
#  (u'ps2P', u'ai2P'): <__main__.classesPaire instance at 0x10d034cb0>,
#  (u'pi2S', u'pc3P'): <__main__.classesPaire instance at 0x10f2a8710>,
#  (u'pi2S', u'ps1P'): <__main__.classesPaire instance at 0x10b8a44d0>,
#  (u'ps1P', u'ppMS'): <__main__.classesPaire instance at 0x10d124710>,
#  (u'ps1S', u'pc2S'): <__main__.classesPaire instance at 0x110b39758>,
#  (u'pI1P', u'fi2S'): <__main__.classesPaire instance at 0x11114a3b0>,
#  (u'pI2P', u'fi1P'): <__main__.classesPaire instance at 0x10cd23878>,
#  (u'ai3P', u'is2S'): <__main__.classesPaire instance at 0x10bd90560>,
#  (u'ai3P', u'ppMP'): <__main__.classesPaire instance at 0x10c1c4f80>,
#  (u'pi2P', u'ai3P'): <__main__.classesPaire instance at 0x10e3c7098>,
#  (u'is3S', u'ai1S'): <__main__.classesPaire instance at 0x1139a9ef0>,
#  (u'ii2S', u'ps2S'): <__main__.classesPaire instance at 0x10cb926c8>,
#  (u'ai2P', u'ai2P'): <__main__.classesPaire instance at 0x10c85cb48>,
#  (u'pc2P', u'ps2S'): <__main__.classesPaire instance at 0x10b2946c8>,
#  (u'pI2S', u'pI1P'): <__main__.classesPaire instance at 0x10bf5eef0>,
#  (u'pI2S', u'is1S'): <__main__.classesPaire instance at 0x10ebf98c0>,
#  (u'pc3S', u'ppFP'): <__main__.classesPaire instance at 0x10bbdaf38>,
#  (u'ai1P', u'pi3P'): <__main__.classesPaire instance at 0x10d0013f8>,
#  (u'pP', u'ppFP'): <__main__.classesPaire instance at 0x10c8548c0>,
#  (u'ppMS', u'ps2P'): <__main__.classesPaire instance at 0x1115e3878>,
#  (u'ii1P', u'pI1P'): <__main__.classesPaire instance at 0x10d202320>,
#  (u'pI2S', u'pI2P'): <__main__.classesPaire instance at 0x110bd43f8>,
#  (u'pc3P', u'is1S'): <__main__.classesPaire instance at 0x10f22c4d0>,
#  (u'ai1P', u'pc1P'): <__main__.classesPaire instance at 0x10c8b0050>,
#  (u'ps1P', u'pc2P'): <__main__.classesPaire instance at 0x106b55488>,
#  (u'pP', u'pi1S'): <__main__.classesPaire instance at 0x10b243f80>,
#  (u'ai1P', u'is3S'): <__main__.classesPaire instance at 0x11155eea8>,
#  (u'fi2P', u'ai2P'): <__main__.classesPaire instance at 0x10bbcb170>,
#  (u'pP', u'ai1S'): <__main__.classesPaire instance at 0x11123cbd8>,
#  (u'ai1S', u'ai1S'): <__main__.classesPaire instance at 0x10bf0b0e0>,
#  (u'is1P', u'fi1P'): <__main__.classesPaire instance at 0x10bb904d0>,
#  (u'FS', u'fi1P'): <__main__.classesPaire instance at 0x10c0dfab8>,
#  (u'pI1P', u'ps1S'): <__main__.classesPaire instance at 0x10b294b90>,
#  (u'ai3S', u'ai1S'): <__main__.classesPaire instance at 0x10c8e7cf8>,
#  (u'ii2P', u'pc1P'): <__main__.classesPaire instance at 0x110bd4cf8>,
#  (u'is2S', u'ai2S'): <__main__.classesPaire instance at 0x10cb3ffc8>,
#  (u'pI1P', u'ai3P'): <__main__.classesPaire instance at 0x110b397a0>,
#  (u'ps2P', u'fi2P'): <__main__.classesPaire instance at 0x1104c06c8>,
#  (u'pc2S', u'pc2S'): <__main__.classesPaire instance at 0x10d12c998>,
#  (u'pi3P', u'is2P'): <__main__.classesPaire instance at 0x110b8db90>,
#  (u'pi2S', u'pi2S'): <__main__.classesPaire instance at 0x10bf5ef38>,
#  (u'FP', u'is1S'): <__main__.classesPaire instance at 0x10d6a4a70>,
#  (u'is2S', u'pc1P'): <__main__.classesPaire instance at 0x10cb3f710>,
#  (u'FS', u'pI1P'): <__main__.classesPaire instance at 0x10c0dbfc8>,
#  (u'FS', u'ai1P'): <__main__.classesPaire instance at 0x10bfd8f80>,
#  (u'ii1S', u'is2S'): <__main__.classesPaire instance at 0x10bbeb2d8>,
#  (u'ai1S', u'pi1P'): <__main__.classesPaire instance at 0x10bbbaa70>,
#  (u'ai3P', u'inf'): <__main__.classesPaire instance at 0x10bbdae18>,
#  (u'ai3S', u'pi1P'): <__main__.classesPaire instance at 0x10f2a8f80>,
#  (u'ai2S', u'pi3S'): <__main__.classesPaire instance at 0x1104c0d88>,
#  (u'is1S', u'ps1P'): <__main__.classesPaire instance at 0x110f7f4d0>,
#  (u'is1P', u'fi3S'): <__main__.classesPaire instance at 0x10c5c4368>,
#  (u'ps2S', u'ai3P'): <__main__.classesPaire instance at 0x11114a7e8>,
#  (u'pc1S', u'ii2S'): <__main__.classesPaire instance at 0x111273320>,
#  (u'fi2S', u'FS'): <__main__.classesPaire instance at 0x110bd6878>,
#  (u'pc1S', u'fi2S'): <__main__.classesPaire instance at 0x10c8e77e8>,
#  (u'ppFS', u'pc2P'): <__main__.classesPaire instance at 0x111315248>,
#  (u'fi3P', u'is2S'): <__main__.classesPaire instance at 0x10bd90c68>,
#  (u'pi3P', u'FP'): <__main__.classesPaire instance at 0x110bd6950>,
#  (u'ps2P', u'pc2S'): <__main__.classesPaire instance at 0x10bf2aab8>,
#  (u'ii3P', u'is2S'): <__main__.classesPaire instance at 0x1115e3f80>,
#  (u'fi2P', u'ii3P'): <__main__.classesPaire instance at 0x10c142680>,
#  (u'ii1S', u'ppMS'): <__main__.classesPaire instance at 0x10f2a1b90>,
#  (u'ai1S', u'ps3P'): <__main__.classesPaire instance at 0x10bf7d5a8>,
#  (u'pc3P', u'ai1P'): <__main__.classesPaire instance at 0x10bfd8cf8>,
#  (u'fi2S', u'pi2S'): <__main__.classesPaire instance at 0x10bbdafc8>,
#  (u'fi3S', u'inf'): <__main__.classesPaire instance at 0x1115fe098>,
#  (u'ii2S', u'pI2S'): <__main__.classesPaire instance at 0x10bf0bcb0>,
#  (u'ps3S', u'pi2S'): <__main__.classesPaire instance at 0x10c0d2758>,
#  (u'ii1P', u'ps1S'): <__main__.classesPaire instance at 0x110ee2ab8>,
#  (u'ii2S', u'ps3P'): <__main__.classesPaire instance at 0x10c67af80>,
#  (u'ii1P', u'is3S'): <__main__.classesPaire instance at 0x10bf05200>,
#  (u'ii2S', u'ii2S'): <__main__.classesPaire instance at 0x10eb250e0>,
#  (u'fi2P', u'fi1P'): <__main__.classesPaire instance at 0x1096a28c0>,
#  (u'ps3P', u'pc3S'): <__main__.classesPaire instance at 0x10bbcb950>,
#  (u'pc1S', u'ai1S'): <__main__.classesPaire instance at 0x10cfc3518>,
#  (u'pc1S', u'ppMP'): <__main__.classesPaire instance at 0x1115e37a0>,
#  (u'ai3P', u'pc2P'): <__main__.classesPaire instance at 0x10ef207e8>,
#  (u'pP', u'ii2S'): <__main__.classesPaire instance at 0x10b8b0a70>,
#  (u'fi2P', u'ppMS'): <__main__.classesPaire instance at 0x10d124680>,
#  (u'pI2P', u'ps1P'): <__main__.classesPaire instance at 0x106b55b00>,
#  (u'ai1P', u'ppMS'): <__main__.classesPaire instance at 0x109706cf8>,
#  (u'pc3S', u'ii2S'): <__main__.classesPaire instance at 0x10c081368>,
#  (u'pi1S', u'pi3S'): <__main__.classesPaire instance at 0x10d22c128>,
#  (u'ai3P', u'ai1S'): <__main__.classesPaire instance at 0x10e1b7440>,
#  (u'is1S', u'pc1P'): <__main__.classesPaire instance at 0x10b8974d0>,
#  (u'ppMS', u'pP'): <__main__.classesPaire instance at 0x10bf05c68>,
#  (u'pc3S', u'pi2S'): <__main__.classesPaire instance at 0x10bf5e8c0>,
#  (u'ai3P', u'ps3P'): <__main__.classesPaire instance at 0x10b8a4128>,
#  (u'fi3P', u'pi3S'): <__main__.classesPaire instance at 0x10c623098>,
#  (u'fi1S', u'pI1P'): <__main__.classesPaire instance at 0x10bb8f200>,
#  (u'pi3P', u'inf'): <__main__.classesPaire instance at 0x10bbf6ab8>,
#  (u'fi1S', u'is1S'): <__main__.classesPaire instance at 0x10b988d40>,
#  (u'ii3P', u'pi3S'): <__main__.classesPaire instance at 0x10bbf6e18>,
#  (u'is2S', u'ppMP'): <__main__.classesPaire instance at 0x10bbeb518>,
#  (u'FS', u'ps2P'): <__main__.classesPaire instance at 0x110bd67a0>,
# ...
#  (u'ppFS', u'is2P'): <__main__.classesPaire instance at 0x10bd165f0>,
#  (u'pi2P', u'ai2P'): <__main__.classesPaire instance at 0x10bbba200>,
#  (u'is3S', u'ps2P'): <__main__.classesPaire instance at 0x10d064ea8>,
#  (u'fi3S', u'ps1S'): <__main__.classesPaire instance at 0x10d020950>,
#  (u'ps3S', u'ps3P'): <__main__.classesPaire instance at 0x10bfd8d88>,
#  (u'ppMS', u'is3S'): <__main__.classesPaire instance at 0x10d0553b0>,
#  (u'pi2S', u'ii3P'): <__main__.classesPaire instance at 0x10d3707a0>,
#  (u'pi1S', u'ii1S'): <__main__.classesPaire instance at 0x110bc11b8>,
#  (u'pP', u'ii3P'): <__main__.classesPaire instance at 0x10d202248>,
#  (u'is2P', u'pi3P'): <__main__.classesPaire instance at 0x110b8d050>,
#  (u'ii1P', u'pI2P'): <__main__.classesPaire instance at 0x10ee021b8>,
#  (u'fi2P', u'ps2S'): <__main__.classesPaire instance at 0x10c8e7ef0>,
#  (u'pc3S', u'ii3P'): <__main__.classesPaire instance at 0x10ed1b128>,
#  (u'is3P', u'pc2P'): <__main__.classesPaire instance at 0x110bc1f38>,
#  (u'ii2S', u'is3P'): <__main__.classesPaire instance at 0x10c3a4ab8>,
#  (u'ii2S', u'ai2S'): <__main__.classesPaire instance at 0x1096a2cf8>,
#  (u'FS', u'pc2P'): <__main__.classesPaire instance at 0x111273368>,
#  (u'is2P', u'is1P'): <__main__.classesPaire instance at 0x110bd4f38>,
#  (u'inf', u'ppFS'): <__main__.classesPaire instance at 0x10d370fc8>,
#  (u'ppMP', u'is1S'): <__main__.classesPaire instance at 0x10ee22758>,
#  (u'ii1S', u'ps2P'): <__main__.classesPaire instance at 0x10b235518>,
#  (u'fi3P', u'fi1S'): <__main__.classesPaire instance at 0x10d029f38>,
#  (u'pI2S', u'fi3S'): <__main__.classesPaire instance at 0x10d1c3440>,
#  (u'ai3S', u'ps1S'): <__main__.classesPaire instance at 0x10bbbad88>,
#  (u'pc1S', u'pi2P'): <__main__.classesPaire instance at 0x109a5c710>,
#  (u'ps2S', u'ai3S'): <__main__.classesPaire instance at 0x10d00ebd8>,
#  (u'pi3P', u'pc2P'): <__main__.classesPaire instance at 0x10bfc8c68>,
#  (u'fi2S', u'ai3S'): <__main__.classesPaire instance at 0x10c8e78c0>,
#  (u'pi2S', u'FP'): <__main__.classesPaire instance at 0x109706950>,
#  (u'fi1P', u'ps2P'): <__main__.classesPaire instance at 0x10b282e18>,
#  (u'ppMP', u'is3P'): <__main__.classesPaire instance at 0x10c1b0638>,
#  (u'pc3S', u'ai1P'): <__main__.classesPaire instance at 0x10cd0c758>,
#  (u'ii3S', u'is2S'): <__main__.classesPaire instance at 0x10c1b0560>,
#  (u'ai2P', u'ps2S'): <__main__.classesPaire instance at 0x10d156ef0>,
#  (u'ppMS', u'ai3S'): <__main__.classesPaire instance at 0x10ef5cd40>,
#  (u'pI1P', u'pI1P'): <__main__.classesPaire instance at 0x110862638>,
#  (u'pc1P', u'pi1S'): <__main__.classesPaire instance at 0x10bf49cb0>,
#  (u'ii3S', u'ppFS'): <__main__.classesPaire instance at 0x1097b7a28>,
#  (u'ps3P', u'ps1P'): <__main__.classesPaire instance at 0x10b2abb00>,
#  (u'ai2S', u'fi1S'): <__main__.classesPaire instance at 0x10d02fd88>,
#  (u'is2S', u'ii2P'): <__main__.classesPaire instance at 0x10bd16ab8>,
#  (u'ppMP', u'fi2S'): <__main__.classesPaire instance at 0x10b9b8758>,
#  (u'is2P', u'ii1S'): <__main__.classesPaire instance at 0x10bbeb6c8>,
#  (u'pI1P', u'ii2P'): <__main__.classesPaire instance at 0x10d017998>,
#  (u'ps2S', u'is2S'): <__main__.classesPaire instance at 0x10cb3f638>,
#  (u'fi1P', u'pi1S'): <__main__.classesPaire instance at 0x10bb90440>,
#  (u'pc3S', u'pc1S'): <__main__.classesPaire instance at 0x10c184680>,
#  (u'ps3S', u'ii2P'): <__main__.classesPaire instance at 0x10b235f80>,
#  (u'pi1P', u'is3S'): <__main__.classesPaire instance at 0x1139a9488>,
#  (u'ps3P', u'pi3S'): <__main__.classesPaire instance at 0x10c0a38c0>,
#  (u'pc3S', u'ai3S'): <__main__.classesPaire instance at 0x10bfc8a70>,
#  (u'FP', u'pc3P'): <__main__.classesPaire instance at 0x110bd6e60>,
#  (u'pc1S', u'pc3S'): <__main__.classesPaire instance at 0x110bd4680>,
#  (u'ppFS', u'pi3P'): <__main__.classesPaire instance at 0x10d156878>,
#  (u'ii1S', u'ai3S'): <__main__.classesPaire instance at 0x10cd7c680>,
#  (u'pi2S', u'ppMS'): <__main__.classesPaire instance at 0x1115e3bd8>,
#  (u'is2P', u'ai2P'): <__main__.classesPaire instance at 0x110bd47a0>,
#  (u'ps2P', u'ii2P'): <__main__.classesPaire instance at 0x10c1845a8>,
#  (u'ppMS', u'pc1S'): <__main__.classesPaire instance at 0x110bc1d88>,
#  (u'ps3S', u'pc1S'): <__main__.classesPaire instance at 0x10bf7d4d0>,
#  (u'is3P', u'ps2S'): <__main__.classesPaire instance at 0x10c0d2098>,
#  (u'pi1S', u'pc2P'): <__main__.classesPaire instance at 0x110bd45a8>,
#  (u'pc3S', u'ppMP'): <__main__.classesPaire instance at 0x10c1c44d0>,
#  (u'ppFS', u'pi2S'): <__main__.classesPaire instance at 0x10bf5e830>,
#  (u'ps3P', u'pi1S'): <__main__.classesPaire instance at 0x10c1b0830>,
#  (u'ii2P', u'pi1S'): <__main__.classesPaire instance at 0x10c005a70>,
#  (u'fi1P', u'pi3S'): <__main__.classesPaire instance at 0x10c0813f8>,
#  (u'ii3P', u'pi1S'): <__main__.classesPaire instance at 0x11125f6c8>,
#  (u'pc1S', u'ps1S'): <__main__.classesPaire instance at 0x110bd4b90>,
#  (u'pi1S', u'is1S'): <__main__.classesPaire instance at 0x10d055e60>,
#  (u'ii1S', u'pc3P'): <__main__.classesPaire instance at 0x10f2a1ef0>,
#  (u'pc1S', u'pI2S'): <__main__.classesPaire instance at 0x10c06b3f8>,
#  (u'fi2S', u'pI2S'): <__main__.classesPaire instance at 0x111318b48>,
#  (u'pi2P', u'pP'): <__main__.classesPaire instance at 0x10960a4d0>,
#  (u'is2S', u'ppFS'): <__main__.classesPaire instance at 0x10bbdaa70>,
#  (u'ps1S', u'fi2S'): <__main__.classesPaire instance at 0x10d105680>,
#  (u'ii2S', u'pi2S'): <__main__.classesPaire instance at 0x10d1a43b0>,
#  (u'ai1P', u'ai3S'): <__main__.classesPaire instance at 0x1115fea28>,
#  (u'pc2P', u'pc1S'): <__main__.classesPaire instance at 0x10c85c0e0>,
#  (u'pc2P', u'inf'): <__main__.classesPaire instance at 0x10c0df908>,
#  (u'ai2P', u'pc3P'): <__main__.classesPaire instance at 0x10d00e050>,
#  (u'pi3P', u'pc3S'): <__main__.classesPaire instance at 0x10c06b368>,
#  (u'ii2S', u'ppMP'): <__main__.classesPaire instance at 0x10c005c20>,
#  (u'ai3P', u'ppFS'): <__main__.classesPaire instance at 0x10c8e7b00>,
#  (u'ii1P', u'fi3P'): <__main__.classesPaire instance at 0x10c4cdd40>,
#  (u'pI2S', u'ps1P'): <__main__.classesPaire instance at 0x10c465200>,
#  (u'ppMP', u'is3S'): <__main__.classesPaire instance at 0x10c1b0170>,
#  (u'is1S', u'ii1S'): <__main__.classesPaire instance at 0x111207ef0>,
#  (u'pi1S', u'FS'): <__main__.classesPaire instance at 0x10b8a0a28>,
#  (u'ppMP', u'ai3P'): <__main__.classesPaire instance at 0x10c005cf8>,
#  (u'pi1P', u'ii3P'): <__main__.classesPaire instance at 0x109632fc8>,
#  (u'pi1P', u'ii1P'): <__main__.classesPaire instance at 0x10b8b0518>,
#  (u'is3S', u'pc2S'): <__main__.classesPaire instance at 0x10c1c4b90>,
#  (u'ai1S', u'pc2S'): <__main__.classesPaire instance at 0x11125a9e0>,
#  (u'ii3P', u'ai3S'): <__main__.classesPaire instance at 0x10c1c46c8>,
#  (u'ps3P', u'fi2S'): <__main__.classesPaire instance at 0x10c1c45a8>,
#  (u'fi3S', u'pc1P'): <__main__.classesPaire instance at 0x111210128>,
#  (u'ps2S', u'pc2S'): <__main__.classesPaire instance at 0x10d034e60>,
#  (u'pc1S', u'ps2P'): <__main__.classesPaire instance at 0x10bf5ebd8>,
#  (u'ii3P', u'ps1P'): <__main__.classesPaire instance at 0x10bb23560>,
#  (u'is2S', u'is1S'): <__main__.classesPaire instance at 0x10d1c00e0>,
#  (u'pP', u'ai3S'): <__main__.classesPaire instance at 0x10bb12d88>,
#  (u'pi1S', u'ai3S'): <__main__.classesPaire instance at 0x10cdd8098>,
#  (u'is3P', u'inf'): <__main__.classesPaire instance at 0x1115e3b48>,
#  (u'fi3S', u'pi3P'): <__main__.classesPaire instance at 0x10cb9efc8>,
#  (u'ai2S', u'ai1S'): <__main__.classesPaire instance at 0x10c06b878>,
#  (u'ai2P', u'pi2S'): <__main__.classesPaire instance at 0x111204cf8>,
#  (u'ii3S', u'pc2S'): <__main__.classesPaire instance at 0x10bf7d200>,
#  (u'pi1P', u'ai1P'): <__main__.classesPaire instance at 0x10c8f23f8>,
#  (u'pi2P', u'ps1P'): <__main__.classesPaire instance at 0x10bbbaa28>,
#  (u'pP', u'ii1S'): <__main__.classesPaire instance at 0x10b8b0908>,
#  (u'pI1P', u'pi1P'): <__main__.classesPaire instance at 0x10ef203f8>,
#  (u'ai1S', u'pI1P'): <__main__.classesPaire instance at 0x111315d88>,
#  (u'pc3P', u'ai2S'): <__main__.classesPaire instance at 0x10d12c758>,
#  (u'fi1P', u'fi2S'): <__main__.classesPaire instance at 0x110bd64d0>,
#  (u'ii3P', u'ppFP'): <__main__.classesPaire instance at 0x10c3a44d0>,
#  (u'ps3S', u'pi1P'): <__main__.classesPaire instance at 0x10c1f8320>,
#  (u'ppMP', u'pi1S'): <__main__.classesPaire instance at 0x1139a9098>,
#  (u'pi2S', u'ii2S'): <__main__.classesPaire instance at 0x10d1a4830>,
#  (u'ii1S', u'ii2S'): <__main__.classesPaire instance at 0x10ef5cbd8>,
#  (u'is2P', u'pi2S'): <__main__.classesPaire instance at 0x10d1c3d40>,
#  (u'pI2P', u'pi2S'): <__main__.classesPaire instance at 0x10bb23b48>,
#  (u'ps2P', u'pi3S'): <__main__.classesPaire instance at 0x10e13c830>,
#  (u'ps2P', u'is2P'): <__main__.classesPaire instance at 0x10d01ea70>,
#  (u'pc2S', u'pc1P'): <__main__.classesPaire instance at 0x10b8a06c8>,
#  (u'FS', u'is2P'): <__main__.classesPaire instance at 0x10bf0bd40>,
#  (u'ppFS', u'ii3P'): <__main__.classesPaire instance at 0x10d064a28>,
#  (u'is3P', u'ii1S'): <__main__.classesPaire instance at 0x11125f098>,
#  (u'ppMS', u'ii1S'): <__main__.classesPaire instance at 0x10f2a1b00>,
#  (u'ai1S', u'pI2S'): <__main__.classesPaire instance at 0x10c06b200>,
#  (u'pi2S', u'is1P'): <__main__.classesPaire instance at 0x10c8e74d0>,
#  (u'pP', u'is3S'): <__main__.classesPaire instance at 0x111374518>,
#  (u'pc2S', u'pI2S'): <__main__.classesPaire instance at 0x10ee35170>,
#  (u'ii1S', u'is1P'): <__main__.classesPaire instance at 0x10b2359e0>,
#  (u'is3P', u'ai1S'): <__main__.classesPaire instance at 0x111204440>,
#  (u'ai3S', u'ai2S'): <__main__.classesPaire instance at 0x111315b90>,
#  (u'pc3S', u'pi1P'): <__main__.classesPaire instance at 0x10e13c7a0>,
#  (u'ppFS', u'fi1S'): <__main__.classesPaire instance at 0x110b8dbd8>,
#  (u'fi2P', u'fi2P'): <__main__.classesPaire instance at 0x10cd23dd0>,
#  (u'pI1P', u'FP'): <__main__.classesPaire instance at 0x1112398c0>,
#  (u'ps3P', u'pc2S'): <__main__.classesPaire instance at 0x109a5c638>,
#  (u'ps2S', u'ps1S'): <__main__.classesPaire instance at 0x110b8d488>,
#  (u'is3S', u'ai3S'): <__main__.classesPaire instance at 0x10c1c4998>,
#  (u'ppFP', u'is3P'): <__main__.classesPaire instance at 0x10d064cf8>,
#  (u'is3P', u'pi3S'): <__main__.classesPaire instance at 0x10cfe0518>,
#  (u'ppMP', u'FS'): <__main__.classesPaire instance at 0x10b9b8d40>,
#  (u'is1S', u'ai2P'): <__main__.classesPaire instance at 0x111221518>,
#  (u'pi3S', u'fi2S'): <__main__.classesPaire instance at 0x10bf7d6c8>,
#  (u'pi1P', u'ppMP'): <__main__.classesPaire instance at 0x10cfc3878>,
#  (u'fi2P', u'ppFS'): <__main__.classesPaire instance at 0x110eea950>,
#  (u'fi2S', u'ps2S'): <__main__.classesPaire instance at 0x10d102200>,
#  (u'pi3P', u'ppFS'): <__main__.classesPaire instance at 0x10d1563f8>,
#  (u'pi1S', u'pc1P'): <__main__.classesPaire instance at 0x10bf49bd8>,
#  (u'pi3P', u'fi3S'): <__main__.classesPaire instance at 0x10d0294d0>,
#  (u'fi2P', u'is2S'): <__main__.classesPaire instance at 0x110b8d1b8>,
#  (u'ii2P', u'ai1S'): <__main__.classesPaire instance at 0x11166b320>,
#  (u'ai1S', u'ppFS'): <__main__.classesPaire instance at 0x10bd166c8>,
#  (u'fi1S', u'ppFS'): <__main__.classesPaire instance at 0x110b8dd40>,
#  (u'ps2P', u'inf'): <__main__.classesPaire instance at 0x10c1420e0>,
#  (u'pi3P', u'pI1P'): <__main__.classesPaire instance at 0x10bb90cb0>,
#  (u'pc3P', u'pP'): <__main__.classesPaire instance at 0x10b992998>,
#  (u'ai3P', u'ps1S'): <__main__.classesPaire instance at 0x1112017e8>,
#  (u'ai3P', u'pI2S'): <__main__.classesPaire instance at 0x10d102ea8>,
#  (u'ai2P', u'pi3S'): <__main__.classesPaire instance at 0x10b282dd0>,
#  (u'FP', u'ai3P'): <__main__.classesPaire instance at 0x1112396c8>,
#  (u'ii2S', u'is2P'): <__main__.classesPaire instance at 0x110b8d518>,
#  (u'ppMS', u'fi1S'): <__main__.classesPaire instance at 0x10c6434d0>,
#  (u'pP', u'pc2P'): <__main__.classesPaire instance at 0x10bbc5ef0>,
#  (u'ps1S', u'is3P'): <__main__.classesPaire instance at 0x111204cb0>,
#  (u'pc2P', u'pi2P'): <__main__.classesPaire instance at 0x10bbba248>,
#  (u'ii3S', u'is3P'): <__main__.classesPaire instance at 0x10c665dd0>,
#  (u'pc1S', u'is2S'): <__main__.classesPaire instance at 0x10bd90f80>,
#  (u'pc3S', u'ps2S'): <__main__.classesPaire instance at 0x10b9eb2d8>,
#  (u'is2P', u'ps1P'): <__main__.classesPaire instance at 0x10e1b7ea8>,
#  (u'ps1P', u'ppFS'): <__main__.classesPaire instance at 0x111210518>,
#  (u'pi2S', u'fi3S'): <__main__.classesPaire instance at 0x10cb92e18>,
#  (u'is2P', u'ai3S'): <__main__.classesPaire instance at 0x10e1b7290>,
#  (u'inf', u'fi2P'): <__main__.classesPaire instance at 0x10d1a4128>,
#  (u'pP', u'ii1P'): <__main__.classesPaire instance at 0x10b243bd8>,
#  (u'is1P', u'ps2S'): <__main__.classesPaire instance at 0x110bd6200>,
#  (u'pI2S', u'FP'): <__main__.classesPaire instance at 0x10ee35638>,
#  (u'pc1P', u'fi2P'): <__main__.classesPaire instance at 0x10cd23c20>,
#  (u'pc1S', u'is3P'): <__main__.classesPaire instance at 0x10d1248c0>,
#  (u'ps2S', u'pc1S'): <__main__.classesPaire instance at 0x111273488>,
#  (u'pP', u'inf'): <__main__.classesPaire instance at 0x10cdb5dd0>,
#  (u'pc2P', u'ai1P'): <__main__.classesPaire instance at 0x1113c8cb0>,
#  (u'is3S', u'is2P'): <__main__.classesPaire instance at 0x10bbeb368>,
#  (u'fi1P', u'ps1S'): <__main__.classesPaire instance at 0x10d102908>,
#  (u'pc3P', u'ppMP'): <__main__.classesPaire instance at 0x10c854a70>,
#  (u'ai3P', u'ps2P'): <__main__.classesPaire instance at 0x110eeaf38>,
#  (u'ii1S', u'pP'): <__main__.classesPaire instance at 0x10b8b0e60>,
#  (u'pI2S', u'ai3P'): <__main__.classesPaire instance at 0x10d102950>,
#  (u'pc2S', u'fi1P'): <__main__.classesPaire instance at 0x10d102680>,
#  (u'ppFS', u'pI2P'): <__main__.classesPaire instance at 0x10b9b8b90>,
#  (u'fi1S', u'pi1P'): <__main__.classesPaire instance at 0x10d017830>,
#  (u'pI2S', u'fi2P'): <__main__.classesPaire instance at 0x10c09c7e8>,
#  (u'pc1P', u'ai1S'): <__main__.classesPaire instance at 0x110eeac20>,
#  (u'ii2P', u'inf'): <__main__.classesPaire instance at 0x11125fea8>,
#  (u'ppMS', u'pi3P'): <__main__.classesPaire instance at 0x10cd7c9e0>,
#  (u'fi2S', u'ps1P'): <__main__.classesPaire instance at 0x1104c0128>,
#  (u'ai1P', u'ii2S'): <__main__.classesPaire instance at 0x11125f950>,
#  (u'ai3P', u'is1S'): <__main__.classesPaire instance at 0x110f7f710>,
#  (u'is2S', u'fi3P'): <__main__.classesPaire instance at 0x10c09c518>,
#  (u'ps2P', u'ii1P'): <__main__.classesPaire instance at 0x10bb125f0>,
#  (u'ai3S', u'ppMP'): <__main__.classesPaire instance at 0x10c1c4dd0>,
#  (u'is3S', u'FP'): <__main__.classesPaire instance at 0x11125a368>,
#  (u'fi3S', u'is1P'): <__main__.classesPaire instance at 0x10c5c4a28>,
#  (u'is1S', u'ii3P'): <__main__.classesPaire instance at 0x11123c5a8>,
#  (u'is3S', u'ii2S'): <__main__.classesPaire instance at 0x10c1c4ef0>,
#  (u'ps1P', u'pc3P'): <__main__.classesPaire instance at 0x10cd23638>,
#  (u'ai2P', u'is3S'): <__main__.classesPaire instance at 0x10d001a70>,
#  (u'is1S', u'ppMS'): <__main__.classesPaire instance at 0x1113c6d88>,
#  (u'fi3S', u'ii2S'): <__main__.classesPaire instance at 0x10bf2a560>,
#  (u'pc3S', u'pI1P'): <__main__.classesPaire instance at 0x10cb9e5f0>,
#  (u'pi3P', u'pi2P'): <__main__.classesPaire instance at 0x111210248>,
#  (u'ii3S', u'ai3S'): <__main__.classesPaire instance at 0x10ee47bd8>,
#  (u'ppFS', u'ai3S'): <__main__.classesPaire instance at 0x10ed1b3b0>,
#  (u'pc1P', u'pi1P'): <__main__.classesPaire instance at 0x10bd3f878>,
#  (u'pc2P', u'pi3P'): <__main__.classesPaire instance at 0x10bfc8878>,
#  (u'pc3S', u'ps1P'): <__main__.classesPaire instance at 0x10cd23a70>,
#  (u'pI2S', u'is3P'): <__main__.classesPaire instance at 0x10c1b0cb0>,
#  (u'pI2P', u'fi1S'): <__main__.classesPaire instance at 0x10d1029e0>,
#  (u'fi1S', u'ii2S'): <__main__.classesPaire instance at 0x111273518>,
#  (u'ii3P', u'pI2S'): <__main__.classesPaire instance at 0x10c3a4b00>,
#  (u'ai3P', u'fi2S'): <__main__.classesPaire instance at 0x10d1c3128>,
#  (u'ii1S', u'ps3P'): <__main__.classesPaire instance at 0x10c643248>,
#  (u'ps1P', u'pI2P'): <__main__.classesPaire instance at 0x106b55368>,
#  (u'fi1S', u'ppMS'): <__main__.classesPaire instance at 0x10c643cb0>,
#  (u'pc2P', u'ii2S'): <__main__.classesPaire instance at 0x10bb90cf8>,
#  ...}

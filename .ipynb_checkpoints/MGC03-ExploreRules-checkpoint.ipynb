# %%
import pandas as pd
import pickle
from __future__ import print_function

# %%
regles="MGC-160104-01-N-paradigmes-ext-Regles"

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print (forme, file=logfile)
                print ("pas de classe",idClasseForme, file=logfile)
                print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %%
with open("2015-Data/"+regles+'.pkl', 'rb') as input:
    classesFinales = pickle.load(input)

# %%
longueur=0
nbPaires=0
print ("longueur=%d"%longueur)
for paire,valeur in sorted(classesFinales.items(),key=lambda x: len(x[1].entree.keys())):
    transformations=valeur.entree.keys()
    if len(transformations)!=longueur:
        print ("%d paires pour %d transformation(s)"%(nbPaires,longueur))
        longueur=len(transformations)
        nbPaires=0
        print ()
        print ("longueur=%d"%longueur)
    else:
        nbPaires+=1
    print ("%s => %s :"%paire, valeur.entree.keys(), len(valeur.classe))
print ("%d paires pour %d transformation(s)"%(nbPaires,longueur))
# Out:
# longueur=0
# ps3P => is1P : [] 0
# is1P => pc2P : [] 0
# is1P => fi2P : [] 0
# is1P => ppMP : [] 0
# fi1P => is1P : [] 0
# ai2S => is1P : [] 0
# pc3P => is1P : [] 0
# ii2P => is1P : [] 0
# is1P => ai1P : [] 0
# is1S => is1P : [] 0
# is1P => fi1P : [] 0
# is1P => ai2P : [] 0
# ps1P => is1P : [] 0
# ai2P => is1P : [] 0
# is1P => ppFP : [] 0
# is1P => ii1P : [] 0
# ppMP => is1P : [] 0
# is1P => fi2S : [] 0
# ppFP => is1P : [] 0
# is1P => is3P : [] 0
# ai3P => is1P : [] 0
# is1P => ii2P : [] 0
# is1P => ai2S : [] 0
# ai1P => is1P : [] 0
# fi2P => is1P : [] 0
# is1P => ps3P : [] 0
# fi2S => is1P : [] 0
# ps2P => is1P : [] 0
# is1P => ps1P : [] 0
# pc2P => is1P : [] 0
# is1P => pc2S : [] 0
# is1P => ps1S : [] 0
# is1P => ai3P : [] 0
# is1P => is1S : [] 0
# is3S => is1P : [] 0
# ps1S => is1P : [] 0
# is1P => ppFS : [] 0
# is3P => is1P : [] 0
# ii1P => is1P : [] 0
# pc2S => is1P : [] 0
# ppFS => is1P : [] 0
# is1P => is3S : [] 0
# is1P => ps2P : [] 0
# is1P => pc3P : [] 0
# 44 paires pour 0 transformation(s)
#
# longueur=1
# ii3S => ii3P : ['-'] 1
# is1P => pP : [u'asj\xf4-\xe2'] 1
# ppFP => ppFP : ['-'] 1
# is1P => pc1P : [u'jasj\xf4-rj\xf4'] 1
# ppMS => is1P : [u'e-asj\xf4'] 1
# ps3S => is1P : [u'-jasj\xf4'] 1
# fi1P => fi1S : [u'\xf4-E'] 1
# ps2P => ps2P : ['-'] 1
# pc3S => pc3P : ['-'] 1
# fi3P => fi3P : ['-'] 1
# ps3P => ps2S : ['-'] 1
# pc3P => pc3P : ['-'] 1
# ii1S => ii3S : ['-'] 1
# ai1S => is3P : [u'-s'] 1
# pi1P => pi1P : ['-'] 1
# pc1S => fi3P : [u'E-\xf4'] 1
# is1P => ps3S : [u'jasj\xf4-'] 1
# pP => pP : ['-'] 1
# ai2P => ppFS : ['-'] 1
# ai3S => is3S : ['-'] 1
# fi3S => fi1P : [u'a-\xf4'] 1
# ai3S => ai3S : ['-'] 1
# ppMP => ai2P : [u'-t'] 1
# ai2P => ps1P : [u'fyt-swaj\xf4'] 1
# ppFS => ppFS : ['-'] 1
# fi3P => pc1S : [u'\xf4-E'] 1
# ai2P => ai2S : [u't-'] 1
# ai1S => ai2S : ['-'] 1
# ii2S => ii1S : ['-'] 1
# ps3P => ps1S : ['-'] 1
# is1P => inf : [u'asj\xf4-e'] 1
# ps2P => ps1P : [u'e-\xf4'] 1
# ppMS => ppMP : ['-'] 1
# ps1P => ai2P : [u'swaj\xf4-fyt'] 1
# ai2P => ppMS : [u't-'] 1
# fi2S => fi1P : [u'a-\xf4'] 1
# fi1P => fi2P : [u'\xf4-e'] 1
# fi2P => fi2S : [u'e-a'] 1
# fi2S => fi2P : [u'a-e'] 1
# ii1P => ii1P : ['-'] 1
# pc2S => fi2S : [u'E-a'] 1
# is3P => ai1P : [u's-m'] 1
# pi2P => pi2P : ['-'] 1
# ii1P => ii2P : [u'\xf4-e'] 1
# is1P => ii1S : [u'asj\xf4-E'] 1
# ai2P => is3P : [u't-s'] 1
# ii3P => ii2S : ['-'] 1
# ai1P => is3S : [u'm-'] 1
# ai1S => ai1S : ['-'] 1
# pc2S => pc2S : ['-'] 1
# is1P => fi3S : [u'j.sj\xf4-r.'] 1
# is1S => is3P : ['-'] 1
# pc1S => fi2S : [u'E-a'] 1
# ii2S => ii2S : ['-'] 1
# fi2P => fi1P : [u'e-\xf4'] 1
# ai3P => ai1S : [u'r-'] 1
# fi2S => pc3P : [u'a-E'] 1
# is3P => is1S : ['-'] 1
# ai1P => ai2P : [u'm-t'] 1
# pi1P => is1P : [u'\xf4-asj\xf4'] 1
# ai3P => ai3P : ['-'] 1
# fi3P => fi2S : [u'\xf4-a'] 1
# ps3S => ps3P : ['-'] 1
# ai2S => ai3P : [u'-r'] 1
# fi3P => fi1S : [u'\xf4-E'] 1
# pI1P => pI1P : ['-'] 1
# ps3P => ps1P : [u'-j\xf4'] 1
# ai2P => ai3P : [u't-r'] 1
# ai1P => ai3S : [u'm-'] 1
# ai2P => pc3P : [u'fyt-s9rE'] 1
# ai2S => ai1S : ['-'] 1
# fi1P => fi2S : [u'\xf4-a'] 1
# ii1S => ii2S : ['-'] 1
# is1P => pi2P : [u'asj\xf4-e'] 1
# pi2S => is1P : [u'-jasj\xf4'] 1
# ii1S => is1P : [u'E-asj\xf4'] 1
# is3P => ai1S : [u's-'] 1
# ai3S => ai2S : ['-'] 1
# is3S => ai3S : ['-'] 1
# ai2S => ai1P : [u'-m'] 1
# is1S => ai2P : [u's-t'] 1
# pc2S => fi1P : [u'E-\xf4'] 1
# ai3P => is1S : [u'r-s'] 1
# fi3S => is1P : [u'r.-j.sj\xf4'] 1
# ai2P => is3S : [u't-'] 1
# ii1S => ii3P : ['-'] 1
# ai1P => is3P : [u'm-s'] 1
# is1P => fi1S : [u'jasj\xf4-rE'] 1
# is3P => is3S : [u's-'] 1
# ai2S => is3S : ['-'] 1
# fi3S => pc3P : [u'a-E'] 1
# fi3P => pc2S : [u'\xf4-E'] 1
# pc3P => fi2P : [u'E-e'] 1
# is1S => is3S : [u's-'] 1
# fi1S => is1P : [u'rE-jasj\xf4'] 1
# is1P => pI1P : [u'asj\xf4-\xf4'] 1
# pI1P => is1P : [u'\xf4-asj\xf4'] 1
# fi3P => pc3P : [u'\xf4-E'] 1
# is3S => ai2S : ['-'] 1
# ii2S => is1P : [u'E-asj\xf4'] 1
# ps3P => ps3P : ['-'] 1
# fi3P => is1P : [u'r\xf4-jasj\xf4'] 1
# ii3S => ii2S : ['-'] 1
# fi2S => fi3S : ['-'] 1
# ai1S => is1P : [u'E-asj\xf4'] 1
# is3S => is3P : [u'-s'] 1
# ai2P => ppFP : ['-'] 1
# ai3S => is1S : [u'-s'] 1
# fi3P => fi1P : ['-'] 1
# ps2S => ps3P : ['-'] 1
# is1P => ii3S : [u'asj\xf4-E'] 1
# pc3S => fi1P : [u'E-\xf4'] 1
# is1P => pi2S : [u'jasj\xf4-'] 1
# ii2P => ii1P : [u'e-\xf4'] 1
# pc1S => is1P : [u'rE-jasj\xf4'] 1
# is3P => ai2S : [u's-'] 1
# pc3P => ai2P : [u's9rE-fyt'] 1
# ps2S => ps1P : [u'-j\xf4'] 1
# fi3P => fi3S : [u'\xf4-a'] 1
# pc3P => pc3S : ['-'] 1
# ai3S => ai1P : [u'-m'] 1
# is3P => is3P : ['-'] 1
# pP => is1P : [u'\xe2-asj\xf4'] 1
# fi1S => fi2S : [u'E-a'] 1
# fi1P => pc2S : [u'\xf4-E'] 1
# pi2P => is1P : [u'e-asj\xf4'] 1
# ai2P => ai1P : [u't-m'] 1
# pc3S => fi2S : [u'E-a'] 1
# inf => inf : ['-'] 1
# ii2P => ii2P : ['-'] 1
# pc2S => pc3P : ['-'] 1
# is3S => ai2P : [u'-t'] 1
# is1S => ai3S : [u's-'] 1
# pc3P => pc1S : ['-'] 1
# ai3P => ai2P : [u'r-t'] 1
# fi1P => pc1S : [u'\xf4-E'] 1
# pc2S => fi3P : [u'E-\xf4'] 1
# pc3P => fi3S : [u'E-a'] 1
# fi1S => pc3P : ['-'] 1
# ii3S => ii3S : ['-'] 1
# is1P => ai3S : [u'sj\xf4-'] 1
# ii3S => is1P : [u'E-asj\xf4'] 1
# is1P => ai1S : [u'asj\xf4-E'] 1
# fi1P => fi1P : ['-'] 1
# ps1S => ps3P : ['-'] 1
# is1P => pi1P : [u'asj\xf4-\xf4'] 1
# pc1P => pc2P : [u'\xf4-e'] 1
# is1P => ii3P : [u'asj\xf4-E'] 1
# ai2P => ppMP : [u't-'] 1
# fi2S => pc2S : [u'a-E'] 1
# inf => is1P : [u'e-asj\xf4'] 1
# pc1S => fi1P : [u'E-\xf4'] 1
# is1P => ii2S : [u'asj\xf4-E'] 1
# ii1S => ii1S : ['-'] 1
# pc3P => fi1S : ['-'] 1
# is3S => ai1P : [u'-m'] 1
# ai1P => is1S : [u'm-s'] 1
# fi3S => fi3P : [u'a-\xf4'] 1
# fi2S => fi1S : [u'a-E'] 1
# ai1S => ai2P : [u'-t'] 1
# is1P => fi3P : [u'jasj\xf4-r\xf4'] 1
# ai2P => ai1S : [u't-'] 1
# fi1P => pc3S : [u'\xf4-E'] 1
# fi1S => fi1P : [u'E-\xf4'] 1
# fi2P => pc3P : [u'e-E'] 1
# ii2S => ii3S : ['-'] 1
# ppMP => ppMP : ['-'] 1
# ii3P => is1P : [u'E-asj\xf4'] 1
# fi2S => pc3S : [u'a-E'] 1
# ai3P => ai2S : [u'r-'] 1
# ai2P => ai2P : ['-'] 1
# ai2P => ai3S : [u't-'] 1
# is1P => pI2P : [u'asj\xf4-e'] 1
# ppMS => ai2P : [u'-t'] 1
# pc3P => pc2S : ['-'] 1
# ai1S => is1S : [u'-s'] 1
# fi3P => fi2P : [u'\xf4-e'] 1
# ai2S => is3P : [u'-s'] 1
# fi1P => fi3P : ['-'] 1
# ai2S => ai2P : [u'-t'] 1
# ai3S => is3P : [u'-s'] 1
# ai1S => ai3P : [u'-r'] 1
# ppMS => ppMS : ['-'] 1
# pc1S => pc3P : ['-'] 1
# pc2P => pc1P : [u'e-\xf4'] 1
# fi2S => fi2S : ['-'] 1
# ps1P => ps2P : [u'\xf4-e'] 1
# is1S => ai2S : [u's-'] 1
# ppFP => ai2P : ['-'] 1
# is1S => is1S : ['-'] 1
# pI2P => is1P : [u'e-asj\xf4'] 1
# pc3P => fi1P : [u'E-\xf4'] 1
# pc2P => pc2P : ['-'] 1
# is1S => ai1P : [u's-m'] 1
# ii3P => ii3S : ['-'] 1
# pc1P => is1P : [u'rj\xf4-jasj\xf4'] 1
# fi2S => pc1S : [u'a-E'] 1
# fi1S => fi3P : [u'E-\xf4'] 1
# ps1P => ps1P : ['-'] 1
# fi1P => pc3P : [u'\xf4-E'] 1
# ppMP => ppMS : ['-'] 1
# ii2S => ii3P : ['-'] 1
# ai3S => is1P : [u'-sj\xf4'] 1
# ai1P => ai2S : [u'm-'] 1
# ps3P => ps3S : ['-'] 1
# ps1P => ps3P : [u'j\xf4-'] 1
# ii3P => ii1S : ['-'] 1
# fi1P => fi3S : [u'\xf4-a'] 1
# fi3S => fi2S : ['-'] 1
# ai2S => ai3S : ['-'] 1
# is1P => is1P : ['-'] 1
# ai2S => ai2S : ['-'] 1
# is3S => is1S : [u'-s'] 1
# is1P => ppMS : [u'asj\xf4-e'] 1
# ai3S => ai2P : [u'-t'] 1
# ai1P => ai1P : ['-'] 1
# is3P => ai2P : [u's-t'] 1
# ps1P => ps2S : [u'j\xf4-'] 1
# ai2S => is1S : [u'-s'] 1
# is1P => pc1S : [u'jasj\xf4-rE'] 1
# pc1S => pc1S : ['-'] 1
# pc1P => pc1P : ['-'] 1
# ppFS => ai2P : ['-'] 1
# is1S => ai1S : [u's-'] 1
# pc3P => fi2S : [u'E-a'] 1
# ii3P => ii3P : ['-'] 1
# fi2P => fi3P : [u'e-\xf4'] 1
# ai2P => is1S : [u't-s'] 1
# pc3P => fi3P : [u'E-\xf4'] 1
# is1S => ai3P : [u's-r'] 1
# ii3S => ii1S : ['-'] 1
# fi2S => fi3P : [u'a-\xf4'] 1
# is3P => ai3S : [u's-'] 1
# is3S => is3S : ['-'] 1
# 233 paires pour 1 transformation(s)
#
# longueur=2
# pc2S => ai2P : [u's9rE-fyt', u'rE-t'] 2
# pc2P => ai2P : [u's9rje-fyt', u'rje-t'] 2
# pc1P => fi3P : [u'i\xf4-\xf4', u'j\xf4-\xf4'] 2
# pi1P => ai2P : [u'z\xf4-t', u'sOm-fyt'] 2
# pc3S => is1P : [u'rE-jasj\xf4', u'9rE-asj\xf4'] 2
# ai2P => ii3P : [u't-zE', u'fyt-EtE'] 2
# is3P => ii2P : [u'ys-avje', u'fys-Etje'] 2
# ai2P => pi1P : [u'fyt-sOm', u't-z\xf4'] 2
# pi1S => is1P : [u'-jasj\xf4', u'-asj\xf4'] 2
# pc2P => fi2P : [u'ie-e', u'je-e'] 2
# pc2P => fi3S : [u'ie-a', u'je-a'] 2
# pc1P => fi1P : [u'i\xf4-\xf4', u'j\xf4-\xf4'] 2
# pc1S => pc2P : [u'E-ie', u'E-je'] 2
# pc3S => pc2P : [u'E-ie', u'E-je'] 2
# pc1P => pc1S : [u'j\xf4-E', u'i\xf4-E'] 2
# ii2S => ii2P : [u'E-e', u'E-je'] 2
# ai2P => pc1S : [u't-rE', u'fyt-s9rE'] 2
# is1S => ps2S : [u'fys-swa', u'ys-E'] 2
# fi1P => pc1P : [u'\xf4-j\xf4', u'\xf4-i\xf4'] 2
# ps1P => is1S : [u'swaj\xf4-fys', u'Ej\xf4-ys'] 2
# fi3P => ai2P : [u's9r\xf4-fyt', u'r\xf4-t'] 2
# ai3P => ai3S : [u'r-', u'Er-a'] 2
# ai2P => ii2P : [u'fyt-Etje', u't-zje'] 2
# is3P => pc2S : [u'fys-s9rE', u'ys-OrE'] 2
# ii2S => ai2P : [u'EtE-fyt', u'zE-t'] 2
# pc3P => pc2P : [u'E-ie', u'E-je'] 2
# ai2P => ps2P : [u't-zje', u'fyt-swaje'] 2
# ppFP => ppMP : [u't-', '-'] 2
# ps2P => is3P : [u'swaje-fys', u'Eje-ys'] 2
# ai2P => pI2S : [u't-', u'fyt-swa'] 2
# pI1P => ai2P : [u'z\xf4-t', u'swaj\xf4-fyt'] 2
# is1P => pi1S : [u'asj\xf4-', u'jasj\xf4-'] 1
# ai2P => pc3S : [u't-rE', u'fyt-s9rE'] 2
# ai3P => is3P : [u'r-s', u'Er-as'] 2
# pc2S => pc1S : ['-', u'j9rE-rE'] 2
# is3S => ai3P : [u'a-Er', u'-r'] 2
# ai2P => pc2S : [u't-rE', u'fyt-s9rE'] 2
# pc2S => fi1S : ['-', u'j9rE-rE'] 2
# pi3P => ai2P : [u's\xf4-fyt', u'z-t'] 2
# ps2P => ai2P : [u'zje-t', u'swaje-fyt'] 2
# is3S => ai1S : [u'a-E', '-'] 2
# fi2P => ai2P : [u's9re-fyt', u're-t'] 2
# ai3S => ai1S : [u'a-E', '-'] 2
# is1S => ps1P : [u'fys-swaj\xf4', u'ys-Ej\xf4'] 2
# fi2P => pc1S : [u'e-E', u'j9re-rE'] 2
# fi2S => ai2P : [u'ra-t', u's9ra-fyt'] 2
# ps3S => ai2P : [u'z-t', u'swa-fyt'] 2
# ai2P => pP : [u'fyt-Et\xe2', u't-z\xe2'] 2
# ii1S => ai2P : [u'EtE-fyt', u'zE-t'] 2
# pi3S => is1P : [u'-jasj\xf4', u'-asj\xf4'] 2
# ai2P => fi1S : [u't-rE', u'fyt-s9rE'] 2
# pc1S => pc2S : [u'rE-j9rE', '-'] 2
# pi1P => ii2S : [u'sOm-EtE', u'\xf4-E'] 2
# fi3P => pc1P : [u'\xf4-j\xf4', u'\xf4-i\xf4'] 2
# pc2P => fi1S : [u'ie-E', u'je-E'] 2
# pi2P => ai2P : ['-', u'Et-fyt'] 2
# ai2P => ps2S : [u't-z', u'fyt-swa'] 2
# pc3S => pc1S : ['-', u'j9rE-rE'] 2
# pc1S => pc3S : [u'rE-j9rE', '-'] 2
# is3P => ps2S : [u'fys-swa', u'ys-E'] 2
# pc2P => pc1S : [u'ie-E', u'je-E'] 2
# fi2S => pc1P : [u'a-j\xf4', u'a-i\xf4'] 2
# pi1P => ii3P : [u'sOm-EtE', u'\xf4-E'] 2
# fi3S => pc1P : [u'a-j\xf4', u'a-i\xf4'] 2
# ai2P => pi2S : [u't-', u'fyt-E'] 2
# pc2S => pc1P : [u'E-j\xf4', u'E-i\xf4'] 2
# ps2S => ps1S : [u'j-', '-'] 2
# ai2P => pi3S : [u't-', u'fyt-E'] 2
# is1P => ps2S : [u'asj\xf4-', u'jasj\xf4-'] 1
# pc1P => fi2P : [u'j\xf4-e', u'i\xf4-e'] 2
# ai2P => pc1P : [u't-rj\xf4', u'fyt-s9rj\xf4'] 2
# ppMP => ppFS : [u'-t', '-'] 3
# fi2P => pc2S : [u'e-E', u're-j9rE'] 2
# fi1P => pc2P : [u'\xf4-je', u'\xf4-ie'] 2
# pi3P => is1P : [u'-jasj\xf4', u'-asj\xf4'] 2
# fi1S => ai2P : [u's9rE-fyt', u'rE-t'] 2
# ii2P => ii3P : [u'e-E', u'je-E'] 2
# ii3P => ii2P : [u'E-e', u'E-je'] 2
# pi2S => ai2P : [u'-t', u'E-fyt'] 2
# pI1P => pP : [u'\xf4-\xe2', u'swaj\xf4-Et\xe2'] 2
# ps2S => ai2P : [u'z-t', u'swa-fyt'] 2
# is1P => pI2S : [u'asj\xf4-', u'jasj\xf4-'] 1
# ppFP => ppFS : ['-', u'i.-j.'] 2
# is3P => ps2P : [u'fys-swaje', u'ys-Eje'] 2
# ppFS => ppMP : [u't-', '-'] 2
# pi1P => ii3S : [u'sOm-EtE', u'\xf4-E'] 2
# pi3S => ai2P : [u'-t', u'E-fyt'] 2
# ii1S => ii2P : [u'E-e', u'E-je'] 2
# ii3S => ai2P : [u'EtE-fyt', u'zE-t'] 2
# pc1P => fi2S : [u'j\xf4-a', u'i\xf4-a'] 2
# pc1P => fi1S : [u'j\xf4-E', u'i\xf4-E'] 2
# fi2P => pc2P : [u'e-ie', u'e-je'] 2
# is1P => pc3S : [u'asj\xf4-9rE', u'jasj\xf4-rE'] 1
# pP => ai2P : [u'z\xe2-t', u'Et\xe2-fyt'] 2
# ppFS => ppMS : [u't-', '-'] 2
# ai3S => ai3P : [u'a-Er', u'-r'] 2
# ai2P => ps1S : [u't-z', u'fyt-swa'] 2
# fi1S => pc2P : [u'E-ie', u'E-je'] 2
# ps1S => ps1P : [u'-j\xf4', u'jEn-9nj\xf4'] 2
# pc1P => ai2P : [u's9rj\xf4-fyt', u'rj\xf4-t'] 2
# ii2S => pi1P : [u'E-\xf4', u'EtE-sOm'] 2
# pc1S => ai2P : [u's9rE-fyt', u'rE-t'] 2
# pc3S => ai2P : [u's9rE-fyt', u'rE-t'] 2
# ai2P => pI2P : ['-', u'fyt-swaje'] 2
# pc2P => pc3S : [u'ie-E', u'je-E'] 2
# pc1P => pc3P : [u'j\xf4-E', u'i\xf4-E'] 2
# ai2P => ii3S : [u't-zE', u'fyt-EtE'] 2
# fi3S => pc2S : [u'a-E', u'ra-j9rE'] 2
# ai2P => ps3S : [u't-z', u'fyt-swa'] 2
# ii2P => ii1S : [u'e-E', u'je-E'] 2
# ii1S => pi1P : [u'E-\xf4', u'EtE-sOm'] 2
# ii1P => ai2P : [u'zj\xf4-t', u'Etj\xf4-fyt'] 2
# ai2P => ii2S : [u't-zE', u'fyt-EtE'] 2
# ai3P => is3S : [u'r-', u'Er-a'] 2
# ps2S => is1P : [u'-jasj\xf4', u'-asj\xf4'] 2
# ai2P => ii1P : [u't-zj\xf4', u'fyt-Etj\xf4'] 2
# ai1S => is3S : [u'E-a', '-'] 2
# ai2P => pc2P : [u'fyt-s9rje', u't-rje'] 2
# pc1S => fi3S : [u'E-a', u'rE-j9ra'] 2
# ppMS => ppFS : [u'-t', '-'] 3
# pc2P => pc2S : [u'ie-E', u'je-E'] 2
# ii2P => ai2P : [u'zje-t', u'Etje-fyt'] 2
# pI2S => is1P : [u'-jasj\xf4', u'-asj\xf4'] 2
# ai1S => ai1P : [u'-m', u'E-am'] 2
# pc2S => pc2P : [u'E-ie', u'E-je'] 2
# ai2P => fi2P : [u't-re', u'fyt-s9re'] 2
# is3P => ai3P : [u'as-Er', u's-r'] 2
# pc3S => fi2P : [u'E-e', u'rE-j9re'] 2
# pc3P => pc1P : [u'E-j\xf4', u'E-i\xf4'] 2
# ii2P => is1S : [u'Etje-fys', u'avje-ys'] 2
# fi1P => ai2P : [u's9r\xf4-fyt', u'r\xf4-t'] 2
# pc2P => fi1P : [u'je-\xf4', u'ie-\xf4'] 2
# ii3S => pi1P : [u'E-\xf4', u'EtE-sOm'] 2
# ps3P => ai2P : [u'z-t', u'swa-fyt'] 2
# ii2S => ii1P : [u'E-\xf4', u'E-j\xf4'] 2
# inf => ai2P : [u'r-t', u'Etr-fyt'] 2
# ps3S => ps2S : ['-', u'-j'] 2
# ii3P => pi1P : [u'E-\xf4', u'EtE-sOm'] 2
# pc1P => pc2S : [u'j\xf4-E', u'i\xf4-E'] 2
# fi3S => pc2P : [u'a-ie', u'a-je'] 2
# ai2P => ps3P : [u't-z', u'fyt-swa'] 2
# ai2P => pi2P : [u'fyt-Et', '-'] 2
# ai1P => ai1S : [u'm-', u'am-E'] 2
# pI2P => ai2P : ['-', u'swaje-fyt'] 2
# pc3S => fi3P : [u'E-\xf4', u'j9rE-r\xf4'] 2
# ii1P => ii2S : [u'j\xf4-E', u'\xf4-E'] 2
# ps2S => is1S : [u'swa-fys', u'E-ys'] 2
# ai2P => ii1S : [u't-zE', u'fyt-EtE'] 2
# pc1S => fi1S : [u'rE-j9rE', '-'] 2
# pI2S => ai2P : [u'-t', u'swa-fyt'] 2
# is1P => pi3P : [u'asj\xf4-', u'jasj\xf4-'] 1
# ai2P => inf : [u't-r', u'fyt-Etr'] 2
# fi1S => pc1P : [u'E-j\xf4', u'E-i\xf4'] 2
# pc2S => fi2P : [u'E-e', u'j9rE-re'] 2
# pc1S => pc1P : [u'E-j\xf4', u'E-i\xf4'] 2
# pc1S => fi2P : [u'E-e', u'rE-j9re'] 2
# ai2P => fi2S : [u'fyt-s9ra', u't-ra'] 2
# fi3P => pc2P : [u'\xf4-je', u'\xf4-ie'] 2
# ai3P => ai1P : [u'Er-am', u'r-m'] 2
# pP => pI1P : [u'Et\xe2-swaj\xf4', u'\xe2-\xf4'] 2
# fi3P => pc3S : [u'r\xf4-j9rE', u'\xf4-E'] 2
# ai2P => fi3S : [u'fyt-s9ra', u't-ra'] 2
# fi2P => pc3S : [u'e-E', u'j9re-rE'] 2
# ai2P => fi3P : [u't-r\xf4', u'fyt-s9r\xf4'] 2
# ai2P => fi1P : [u't-r\xf4', u'fyt-s9r\xf4'] 2
# fi2P => pc1P : [u'e-j\xf4', u'e-i\xf4'] 2
# ppMP => ppFP : [u'-t', '-'] 3
# pc1P => fi3S : [u'j\xf4-a', u'i\xf4-a'] 2
# fi2S => pc2P : [u'a-ie', u'a-je'] 2
# ps2S => is3P : [u'swa-fys', u'E-ys'] 2
# ps2S => ps3S : [u'j-', '-'] 2
# ai1S => ai3S : [u'E-a', '-'] 2
# ai1P => ai3P : [u'm-r', u'am-Er'] 2
# ai2P => pI1P : [u't-z\xf4', u'fyt-swaj\xf4'] 2
# ps1P => ps1S : [u'j\xf4-', u'9nj\xf4-jEn'] 2
# pi1P => ii1S : [u'sOm-EtE', u'\xf4-E'] 2
# fi3S => pc1S : [u'j9ra-rE', u'a-E'] 2
# pc2S => is3P : [u's9rE-fys', u'OrE-ys'] 2
# ai2P => pi1S : [u't-', u'fyt-sHi'] 2
# ii3P => ai2P : [u'EtE-fyt', u'zE-t'] 2
# ai2P => pi3P : [u't-z', u'fyt-s\xf4'] 2
# pc2P => fi2S : [u'ie-a', u'je-a'] 2
# pc2P => fi3P : [u'je-\xf4', u'ie-\xf4'] 2
# is1P => pi3S : [u'asj\xf4-', u'jasj\xf4-'] 1
# fi1S => pc1S : ['-', u'j9rE-rE'] 2
# fi3S => ai2P : [u'ra-t', u's9ra-fyt'] 2
# pc3S => pc2S : [u'rE-j9rE', '-'] 2
# ps1S => ps2S : ['-', u'-j'] 2
# ii2P => ii3S : [u'e-E', u'je-E'] 2
# pc2P => pc3P : [u'ie-E', u'je-E'] 2
# pi1S => ai2P : [u'-t', u'sHi-fyt'] 2
# ii2P => ii2S : [u'e-E', u'je-E'] 2
# pc2S => pc3S : ['-', u'j9rE-rE'] 2
# ppFS => ppFP : [u'j.-i.', '-'] 2
# ps3S => ps1P : [u'-j\xf4', u'jEn-9nj\xf4'] 2
# ii2P => is3P : [u'Etje-fys', u'avje-ys'] 2
# ii3S => ii2P : [u'E-e', u'E-je'] 2
# fi1S => pc2S : [u'rE-j9rE', '-'] 2
# ps1S => ai2P : [u'z-t', u'swa-fyt'] 2
# is1S => ii2P : [u'ys-avje', u'fys-Etje'] 2
# ps1P => ps3S : [u'j\xf4-', u'9nj\xf4-jEn'] 2
# pc2S => fi3S : [u'j9rE-ra', u'E-a'] 2
# 201 paires pour 2 transformation(s)
#
# longueur=3
# ps2P => is1S : [u'swaje-fys', u'9vje-ys', u'Eje-ys'] 3
# is3P => ppFS : [u'as-e', u's-', u'\xeas-9ny'] 3
# ppFS => is3P : [u'9ny-\xeas', u'e-as', u'-s'] 3
# fi3S => fi2P : [u'j9ra-re', u'a-e', u'ra-j9re'] 3
# pc3S => fi1S : [u'rE-j9rE', '-', u'j9rE-rE'] 3
# fi1S => fi3S : [u'j9rE-ra', u'E-a', u'rE-j9ra'] 3
# fi3P => is3P : [u'Or\xf4-ys', u'r\xf4-s', u's9r\xf4-fys'] 3
# pc2S => is1S : [u'9vrE-ys', u's9rE-fys', u'OrE-ys'] 3
# is1S => pc3S : [u'ys-9vrE', u'fys-s9rE', u'ys-OrE'] 3
# ii1P => ii1S : [u'j\xf4-E', u'i\xf4-E', u'\xf4-E'] 3
# is1S => pc2P : [u'fys-s9rje', u'ys-9vrie', u'ys-Orje'] 3
# pc1S => is3P : [u'rE-s', u's9rE-fys', u'OrE-ys'] 3
# ii1S => ii1P : [u'E-\xf4', u'E-j\xf4', u'E-i\xf4'] 3
# is1S => fi1S : [u'ys-9vrE', u'fys-s9rE', u'ys-OrE'] 3
# pi1P => pI1P : [u'Om-waj\xf4', '-', u'av.-Ej.'] 3
# fi2P => fi3S : [u'j9re-ra', u'e-a', u're-j9ra'] 3
# ii2S => pP : [u'E-\xe2', u'vE-S\xe2', u'avE-Ej\xe2'] 3
# is3P => ps1P : [u'fys-swaj\xf4', u'ys-Ej\xf4', u'is-j\xf4'] 3
# is3P => pc1S : [u'fys-s9rE', u's-rE', u'ys-OrE'] 3
# pI1P => ii3P : [u'Ej\xf4-avE', u'swaj\xf4-EtE', u'\xf4-E'] 3
# is1S => ppFS : [u'is-y', u's-', u'as-e'] 3
# fi1S => is1S : [u'9vrE-ys', u's9rE-fys', u'OrE-ys'] 3
# fi1S => pc3S : [u'rE-j9rE', '-', u'j9rE-rE'] 3
# ppMS => is3P : [u'9ny-\xeas', u'e-as', u'-s'] 3
# is1S => pc2S : [u'ys-9vrE', u'fys-s9rE', u'ys-OrE'] 3
# pc2P => is1S : [u'9vrie-ys', u's9rje-fys', u'Orje-ys'] 3
# ps1S => ps3S : [u'j-', '-', u'-j'] 3
# pc3S => pc3S : [u'rE-j9rE', '-', u'j9rE-rE'] 3
# pI1P => ps2P : [u'\xf4-je', u'9z\xf4-asje', u'\xf4-e'] 3
# is1S => pc3P : [u'ys-9vrE', u'fys-s9rE', u'ys-OrE'] 3
# pc3P => is1S : [u'9vrE-ys', u's9rE-fys', u'OrE-ys'] 3
# pI1P => ii3S : [u'Ej\xf4-avE', u'swaj\xf4-EtE', u'\xf4-E'] 3
# is1S => ppFP : [u'is-y', u's-', u'as-e'] 3
# is3P => fi1P : [u'ys-Or\xf4', u'\xeas-j\xeadr\xf4', u'fys-s9r\xf4'] 3
# ii2S => is3P : [u'E-is', u'avE-ys', u'EtE-fys'] 3
# ppMP => is1S : [u'e-as', u'-s', u'y-is'] 3
# ppMP => is3P : [u'9ny-\xeas', u'e-as', u'-s'] 3
# pP => ii1S : [u'Ej\xe2-avE', u'S\xe2-vE', u'\xe2-E'] 3
# fi2P => fi2P : [u're-j9re', '-', u'j9re-re'] 3
# ppFP => is3P : [u'9ny-\xeas', u'e-as', u'-s'] 3
# ii1S => pP : [u'E-\xe2', u'vE-S\xe2', u'avE-Ej\xe2'] 3
# is1S => ppMS : [u'is-y', u's-', u'as-e'] 3
# ps1S => ps2P : [u'-je', u'jEn-9nje', u'E.-9.je'] 3
# ps1P => pI2P : [u'j\xf4-e', u'\xf4-e', u'asj\xf4-Et'] 3
# ps2P => ps3P : [u'9nje-jEn', u'je-', u'9vje-wav'] 3
# pI1P => ps1P : [u'9z\xf4-asj\xf4', u'\xf4-j\xf4', '-'] 3
# pc3P => is3P : [u'irE-jas', u's9rE-fys', u'OrE-ys'] 3
# ii1P => is3P : [u'Etj\xf4-fys', u'avj\xf4-ys', u'9nj\xf4-\xeas'] 3
# ps3S => ps3S : [u'j-', '-', u'-j'] 3
# pP => ii3S : [u'Ej\xe2-avE', u'S\xe2-vE', u'\xe2-E'] 3
# ps1P => is3P : [u'swaj\xf4-fys', u'Ej\xf4-ys', u'j\xf4-is'] 3
# pc3S => is1S : [u'9vrE-ys', u's9rE-fys', u'OrE-ys'] 3
# ai2S => ps1P : [u'fy-swaj\xf4', u'y-Hisj\xf4', u'i-asj\xf4'] 3
# pc1P => pc3S : [u'j\xf4-E', u'i\xf4-E', u'rj\xf4-j9rE'] 3
# is3P => ii1P : [u'ys-avj\xf4', u'\xeas-9nj\xf4', u'fys-Etj\xf4'] 3
# is3P => ps3P : [u'ys-E', u'is-', u'fys-swa'] 3
# ps1P => ppFP : [u'j\xf4-e', u'Ej\xf4-y', u'asj\xf4-Et'] 3
# ps3P => ps2P : [u'-je', u'jEn-9nje', u'wav-9vje'] 3
# is3P => ppMP : [u'\xeas-9ny', u'as-e', u's-'] 3
# pP => ii2S : [u'Ej\xe2-avE', u'S\xe2-vE', u'\xe2-E'] 3
# pi3P => pi3P : [u'j-', '-', u'-j'] 3
# fi3S => pc3S : [u'j9ra-rE', u'a-E', u'ra-j9rE'] 3
# ps2S => ps2S : [u'j-', '-', u'-j'] 3
# ps1P => pI1P : [u'j\xf4-\xf4', u'asj\xf4-9z\xf4', '-'] 3
# pI2P => pI2P : [u'ul.-9j.', '-', u'9j.-ul.'] 3
# ps3S => ps1S : [u'j-', '-', u'-j'] 3
# is3P => pc1P : [u'fys-s9rj\xf4', u'\xeas-j\xeadri\xf4', u'ys-Orj\xf4'] 3
# fi1S => fi2P : [u'E-e', u'rE-j9re', u'j9rE-re'] 3
# pc2P => is3P : [u'9rje-as', u's9rje-fys', u'Orje-ys'] 3
# ii3P => pI1P : [u'E-\xf4', u'avE-Ej\xf4', u'EtE-swaj\xf4'] 3
# ppFS => is1S : [u'e-as', u'-s', u'y-is'] 3
# pI1P => ii1S : [u'Ej\xf4-avE', u'swaj\xf4-EtE', u'\xf4-E'] 3
# ppMS => is1S : [u'e-as', u'-s', u'y-is'] 3
# fi1P => is1S : [u'9vr\xf4-ys', u'Or\xf4-ys', u's9r\xf4-fys'] 3
# ppFP => is1S : [u'e-as', u'-s', u'y-is'] 3
# ps1P => ai2S : [u'swaj\xf4-fy', u'asj\xf4-i', u'Hisj\xf4-y'] 3
# is3P => ii2S : [u'fys-EtE', u'is-E', u'ys-avE'] 3
# fi1P => is3P : [u'j\xeadr\xf4-\xeas', u'Or\xf4-ys', u's9r\xf4-fys'] 3
# is3P => fi3P : [u'fys-s9r\xf4', u's-r\xf4', u'ys-Or\xf4'] 3
# ps1S => is1S : [u'swa-fys', u'E-ys', u'-is'] 3
# is1S => fi1P : [u'ys-9vr\xf4', u'ys-Or\xf4', u'fys-s9r\xf4'] 3
# is1S => ps1S : [u'ys-E', u'is-', u'fys-swa'] 3
# fi3S => fi1S : [u'j9ra-rE', u'a-E', u'ra-j9rE'] 3
# ii3S => pP : [u'E-\xe2', u'vE-S\xe2', u'avE-Ej\xe2'] 3
# ii2S => pI1P : [u'E-\xf4', u'avE-Ej\xf4', u'EtE-swaj\xf4'] 3
# ps1S => ps1S : [u'j-', '-', u'-j'] 3
# ps2P => ps1S : [u'9nje-jEn', u'9.je-E.', u'je-'] 3
# pP => ii3P : [u'Ej\xe2-avE', u'S\xe2-vE', u'\xe2-E'] 3
# pc3S => pc1P : [u'j9rE-rj\xf4', u'E-j\xf4', u'E-i\xf4'] 3
# is3P => pc2P : [u'fys-s9rje', u'as-9rje', u'ys-Orje'] 3
# ii1S => pI1P : [u'E-\xf4', u'avE-Ej\xf4', u'EtE-swaj\xf4'] 3
# is1S => ppMP : [u'is-y', u's-', u'as-e'] 3
# ppMS => ppFP : [u'-t', '-', u'j.-i.'] 4
# pi1P => ii2P : [u'\xf4-je', u'sOm-Etje', u'\xf4-e'] 3
# ppFP => ppMS : [u't-', '-', u'i.-j.'] 3
# fi3S => fi3S : [u'ra-j9ra', '-', u'j9ra-ra'] 3
# ps2P => pI1P : [u'e-\xf4', u'asje-9z\xf4', u'je-\xf4'] 3
# fi2P => fi1S : [u'e-E', u're-j9rE', u'j9re-rE'] 3
# pc1P => is3P : [u'j\xeadri\xf4-\xeas', u's9rj\xf4-fys', u'Orj\xf4-ys'] 3
# ppFP => ps1P : [u'e-j\xf4', u'y-Ej\xf4', u'Et-asj\xf4'] 3
# ii3S => pI1P : [u'E-\xf4', u'avE-Ej\xf4', u'EtE-swaj\xf4'] 3
# pI2S => pI2S : [u'j-', '-', u'-j'] 3
# ii3P => pP : [u'E-\xe2', u'vE-S\xe2', u'avE-Ej\xe2'] 3
# is1S => ii1P : [u'ys-avj\xf4', u'fys-Etj\xf4', u'ys-9vj\xf4'] 3
# is3P => ppFP : [u'\xeas-9ny', u'as-e', u's-'] 3
# pI2P => ps1P : [u'e-\xf4', u'e-j\xf4', u'Et-asj\xf4'] 3
# ps3P => is1S : [u'swa-fys', u'E-ys', u'wav-ys'] 3
# ii2P => pi1P : [u'Etje-sOm', u'e-\xf4', u'je-\xf4'] 3
# pc3S => fi3S : [u'j9rE-ra', u'E-a', u'rE-j9ra'] 3
# is3P => pc3P : [u'jas-irE', u'fys-s9rE', u'ys-OrE'] 3
# is3P => ppMS : [u'as-e', u's-', u'\xeas-9ny'] 3
# pI1P => ii2S : [u'Ej\xf4-avE', u'swaj\xf4-EtE', u'\xf4-E'] 3
# pI1P => pi1P : ['-', u'Ej.-av.', u'waj\xf4-Om'] 3
# fi1S => fi1S : [u'rE-j9rE', '-', u'j9rE-rE'] 3
# is1S => ps3P : [u'ys-wav', u'fys-swa', u'ys-E'] 3
# ii1P => is1S : [u'Etj\xf4-fys', u'9vj\xf4-ys', u'avj\xf4-ys'] 3
# is1S => ps2P : [u'ys-9vje', u'fys-swaje', u'ys-Eje'] 3
# ps3P => is3P : [u'swa-fys', u'E-ys', u'-is'] 3
# 117 paires pour 3 transformation(s)
#
# longueur=4
# ii3P => pi2P : [u'E-e', u'E-', u'9zE-Et', u'zE-t'] 4
# pP => pi1P : [u'Ej\xe2-av\xf4', u'Et\xe2-sOm', u'\xe2-\xf4', u'S\xe2-v\xf4'] 4
# is3P => pI2P : [u'fys-swaje', u'as-e', u'is-e', u'ys-Eje'] 4
# pI1P => ii1P : [u'swaj\xf4-Etj\xf4', u'\xf4-j\xf4', '-', u'Ej\xf4-avj\xf4'] 4
# pI1P => pI2P : [u'z\xf4-t', u'\xf4-e', u'9z\xf4-Et', u'ul\xf4-9je'] 4
# is3P => pc3S : [u'fys-s9rE', u's-rE', u'ys-OrE', u'\xeas-j\xeadrE'] 4
# pI1P => is3P : [u'\xf4-is', u'Ej\xf4-ys', u'\xf4-as', u'swaj\xf4-fys'] 4
# is1S => fi2S : [u'ys-Ora', u'is-ra', u'ys-9vra', u'fys-s9ra'] 4
# is1S => pc1S : [u'ys-9vrE', u'fys-s9rE', u'ys-OrE', u'is-rE'] 4
# ii1P => ii3S : [u'j\xf4-E', u'i\xf4-E', u'ij\xf4-jE', u'\xf4-E'] 4
# pc1P => ai2S : [u'rj\xf4-', u's9rj\xf4-fy', u'urj\xf4-y', u'9rj\xf4-i'] 4
# ii1P => pI1P : [u'j\xf4-\xf4', '-', u'Etj\xf4-swaj\xf4', u'avj\xf4-Ej\xf4'] 4
# ps1P => pc2P : [u'as.\xf4-9r.e', u'Ej\xf4-Orje', u'wa.\xf4-9r.e', u'Hisj\xf4-urje'] 4
# pi2P => is3P : [u'Et-fys', u'e-as', u'ave-ys', u'e-is'] 4
# ii2S => is1S : [u'E-is', u'avE-ys', u'EtE-fys', u'9vE-ys'] 4
# pi1P => ii1P : [u'\xf4-j\xf4', '-', u'sOm-Etj\xf4', u'\xf4-i\xf4'] 4
# fi1S => is3P : [u'9rE-as', u'rE-s', u's9rE-fys', u'OrE-ys'] 4
# pP => ii2P : [u'\xe2-je', u'\xe2-e', u'Ej\xe2-avje', u'S\xe2-vje'] 4
# ps1P => pc2S : [u'Ej\xf4-OrE', u'asj\xf4-9rE', u'Hisj\xf4-urE', u'waj\xf4-9rE'] 4
# pI2P => is3P : [u'swaje-fys', u'e-as', u'Eje-ys', u'e-is'] 4
# pc1P => is1S : [u'ri\xf4-is', u's9rj\xf4-fys', u'Orj\xf4-ys', u'9vri\xf4-ys'] 4
# pc1P => ps1P : [u'Orj\xf4-Ej\xf4', u'9r..-wa..', u'urj\xf4-Hisj\xf4', u'9r..-as..'] 4
# is3P => fi2S : [u'ys-Ora', u'fys-s9ra', u'\xeas-j\xeadra', u's-ra'] 4
# ii3P => ii1P : [u'E-\xf4', u'E-j\xf4', u'E-i\xf4', u'jE-ij\xf4'] 4
# ai2S => pc1P : [u'i-9rj\xf4', u'fy-s9rj\xf4', u'-rj\xf4', u'y-urj\xf4'] 4
# ii2P => pI1P : [u'e-\xf4', u'je-\xf4', u'Etje-swaj\xf4', u'avje-Ej\xf4'] 4
# ii2S => pi2P : [u'E-e', u'E-', u'9zE-Et', u'zE-t'] 4
# is1S => fi3S : [u'ys-Ora', u'is-ra', u'ys-9vra', u'fys-s9ra'] 4
# ai1P => ps1P : [u'ym-Hisj\xf4', u'ym-Ej\xf4', u'im-asj\xf4', u'fym-swaj\xf4'] 4
# pI2P => pI1P : [u'e-\xf4', u't-z\xf4', u'Et-9z\xf4', u'9je-ul\xf4'] 4
# ii1P => pi1P : [u'i\xf4-\xf4', u'j\xf4-\xf4', '-', u'Etj\xf4-sOm'] 4
# ii2P => pP : [u'avje-Ej\xe2', u'je-\xe2', u'vje-S\xe2', u'e-\xe2'] 4
# is1S => pI1P : [u'fys-swaj\xf4', u'ys-Ej\xf4', u'ys-9v\xf4', u'is-\xf4'] 4
# ps2P => ps3S : [u'9nje-jEn', u'je-', u'9.je-E.', u'9vje-wav'] 4
# pi2P => pi1P : [u'e-\xf4', u't-z\xf4', u'Et-9z\xf4', u'Et-sOm'] 4
# pI1P => is1S : [u'\xf4-is', u'Ej\xf4-ys', u'9v\xf4-ys', u'swaj\xf4-fys'] 4
# fi3P => is1S : [u'9vr\xf4-ys', u'Or\xf4-ys', u'9r\xf4-as', u's9r\xf4-fys'] 4
# is3P => fi2P : [u'fys-s9re', u's-re', u'ys-Ore', u'\xeas-j\xeadre'] 4
# is3P => ii3P : [u'\xeas-9nE', u'fys-EtE', u'is-E', u'ys-avE'] 4
# pc2P => ps1P : [u'Orje-Ej\xf4', u'9r.e-as.\xf4', u'9r.e-wa.\xf4', u'urje-Hisj\xf4'] 4
# is1S => pi2S : [u'fys-E', u'ys-a', u'ys-wa', u'dis-'] 4
# pi2P => ii3S : [u'e-E', u'-E', u't-zE', u'Et-9zE'] 4
# is1S => ii2S : [u'fys-EtE', u'ys-avE', u'is-E', u'ys-9vE'] 4
# pI2S => ps1P : [u'-j\xf4', u'-tj\xf4', u'E-asj\xf4', u'j\xea-9nj\xf4'] 4
# is1S => fi3P : [u'ys-9vr\xf4', u'as-9r\xf4', u'ys-Or\xf4', u'fys-s9r\xf4'] 4
# ii3S => pi2P : [u'E-e', u'E-', u'9zE-Et', u'zE-t'] 4
# fi2S => is3P : [u's9ra-fys', u'Ora-ys', u'j\xeadra-\xeas', u'ra-s'] 4
# is1S => pc1P : [u'is-ri\xf4', u'fys-s9rj\xf4', u'ys-9vri\xf4', u'ys-Orj\xf4'] 4
# ps1P => pc1P : [u'as..-9r..', u'Ej\xf4-Orj\xf4', u'Hisj\xf4-urj\xf4', u'wa..-9r..'] 4
# fi2S => is1S : [u'9vra-ys', u's9ra-fys', u'Ora-ys', u'ra-is'] 4
# pi1P => pi2P : [u'z\xf4-t', u'\xf4-e', u'9z\xf4-Et', u'sOm-Et'] 4
# pi2P => ii2S : [u'e-E', u'-E', u't-zE', u'Et-9zE'] 4
# is3P => pP : [u'ys-Ej\xe2', u'as-\xe2', u'fys-Et\xe2', u'is-\xe2'] 4
# fi3S => is1S : [u'9vra-ys', u's9ra-fys', u'Ora-ys', u'ra-is'] 4
# ii1P => ii3P : [u'j\xf4-E', u'i\xf4-E', u'ij\xf4-jE', u'\xf4-E'] 4
# pi2P => ii3P : [u'e-E', u'-E', u't-zE', u'Et-9zE'] 4
# ii3P => is3P : [u'E-is', u'9nE-\xeas', u'avE-ys', u'EtE-fys'] 4
# pP => is3P : [u'Ej\xe2-ys', u'Et\xe2-fys', u'\xe2-as', u'\xe2-is'] 4
# pI1P => ii2P : [u'swaj\xf4-Etje', u'\xf4-je', u'\xf4-e', u'Ej\xf4-avje'] 4
# pi1P => pP : [u'\xf4-\xe2', u'sOm-Et\xe2', u'v\xf4-S\xe2', u'av\xf4-Ej\xe2'] 4
# ps1P => ai1P : [u'asj\xf4-im', u'Ej\xf4-ym', u'Hisj\xf4-ym', u'swaj\xf4-fym'] 4
# is3P => fi1S : [u'fys-s9rE', u'as-9rE', u's-rE', u'ys-OrE'] 4
# ii3S => ii1P : [u'E-\xf4', u'E-j\xf4', u'E-i\xf4', u'jE-ij\xf4'] 4
# ii1S => pi2P : [u'E-e', u'E-', u'9zE-Et', u'zE-t'] 4
# fi2P => is3P : [u'j\xeadre-\xeas', u're-s', u's9re-fys', u'Ore-ys'] 4
# is3P => pI1P : [u'fys-swaj\xf4', u'as-\xf4', u'ys-Ej\xf4', u'is-\xf4'] 4
# is3P => pi2P : [u'as-e', u'is-e', u'fys-Et', u'ys-ave'] 4
# pi2P => ii1S : [u'e-E', u'-E', u't-zE', u'Et-9zE'] 4
# pc3S => is3P : [u'j\xeadrE-\xeas', u'rE-s', u's9rE-fys', u'OrE-ys'] 4
# ps3S => ps2P : [u'-je', u'jEn-9nje', u'wav-9vje', u'E.-9.je'] 4
# pc2S => ps1P : [u'9rE-asj\xf4', u'urE-Hisj\xf4', u'OrE-Ej\xf4', u'9rE-waj\xf4'] 4
# ps2P => ps2S : [u'9nje-jEn', u'ulje-9j', u'9.je-E.', u'je-'] 4
# pi2S => is1S : [u'wa-ys', u'E-fys', u'a-ys', u'-dis'] 4
# ps1P => pI2S : [u'j\xf4-', u'asj\xf4-E', u'tj\xf4-', u'9nj\xf4-j\xea'] 4
# is1S => fi2P : [u'ys-9vre', u'fys-s9re', u'ys-Ore', u'is-re'] 4
# fi2P => is1S : [u're-is', u'9vre-ys', u's9re-fys', u'Ore-ys'] 4
# pc1S => is1S : [u'rE-is', u'9vrE-ys', u's9rE-fys', u'OrE-ys'] 4
# ps2S => ps2P : [u'9j-ulje', u'jEn-9nje', u'E.-9.je', u'-je'] 4
# 77 paires pour 4 transformation(s)
#
# longueur=5
# pI2P => ps2P : [u'Et-asje', u't-zje', '-', u'e-je', u'9je-ulje'] 5
# inf => is3P : [u'r-s', u'e-as', u'9nir-\xeas', u'avwar-ys', u'Etr-fys'] 5
# pi3S => pi3S : [u'j-', u'wa-je', '-', u'je-wa', u'-j'] 5
# is1S => ps3S : [u'ys-E', u'ys-wav', u'fys-swa', u'as-', u'is-'] 5
# ppMS => ps1P : [u'i-j\xf4', u'e-j\xf4', u'E-asj\xf4', u'y-Ej\xf4', u'y-j\xf4'] 5
# ps1P => fi1P : [u'asj\xf4-9r\xf4', u'j\xf4-9r\xf4', u'Ej.-Or.', u'waj\xf4-9r\xf4', u'Hisj\xf4-ur\xf4'] 5
# is3P => pi1P : [u'fys-sOm', u'as-\xf4', u'\xeas-9n\xf4', u'ys-av\xf4', u'is-\xf4'] 5
# ps1P => ii1S : [u'j\xf4-E', u'Ej\xf4-avE', u'Hisj\xf4-uvE', u'asj\xf4-9zE', u'swaj\xf4-EtE'] 5
# pi1S => pi1S : [u'j-', u'wa-je', '-', u'je-wa', u'-j'] 5
# ppFP => pc2P : [u't-rje', u'y-Orje', u'e-9rje', u'y-9vrie', u'Et-9rje'] 5
# is1S => ii3S : [u'fys-EtE', u'ys-avE', u'as-E', u'is-E', u'ys-9vE'] 5
# pi3S => is1S : [u'wa-ys', u'-as', u'E-fys', u'a-ys', u'-dis'] 5
# ps1P => ii2P : [u'as.\xf4-9z.e', u'swaj\xf4-Etje', u'Hisj\xf4-uvje', u'\xf4-e', u'Ej\xf4-avje'] 5
# pi2P => pI2P : [u'Et-swaje', '-', u'ul.-9j.', u'v.-S.', u'av.-Ej.'] 5
# ii3S => is1S : [u'E-as', u'avE-ys', u'E-is', u'EtE-fys', u'9vE-ys'] 5
# ppMS => ai2S : [u'Er-ri', '-', u'9ny-\xea', u'E-i', u'y-i'] 5
# ps1P => ii3P : [u'j\xf4-E', u'Ej\xf4-avE', u'Hisj\xf4-uvE', u'asj\xf4-9zE', u'swaj\xf4-EtE'] 5
# pP => ps1P : [u'9z\xe2-asj\xf4', u'\xe2-j\xf4', u'Et\xe2-swaj\xf4', u'uv\xe2-Hisj\xf4', u'\xe2-\xf4'] 5
# is1S => pi2P : [u'as-e', u'ys-ave', u'is-e', u'fys-Et', u'ys-9ve'] 5
# ps1P => ii1P : [u'as..-9z..', u'Hisj\xf4-uvj\xf4', u'Ej\xf4-avj\xf4', '-', u'swaj\xf4-Etj\xf4'] 5
# ps2P => pI2P : [u'asje-Et', u'ulje-9je', u'zje-t', '-', u'je-e'] 5
# is1S => inf : [u'is-r', u'ys-avwar', u'ys-9vwar', u'as-e', u'fys-Etr'] 5
# ps1P => ppMS : [u'j\xf4-e', u'Ej\xf4-y', u'asj\xf4-E', u'j\xf4-i', u'j\xf4-y'] 5
# pI2S => is1S : [u'wa-ys', u'swa-fys', u'E-ys', u'-as', u'-dis'] 5
# pi2S => pi2S : [u'j-', u'wa-je', '-', u'je-wa', u'-j'] 5
# ppMP => ai2S : [u'Er-ri', '-', u'9ny-\xea', u'E-i', u'y-i'] 5
# is3P => pi2S : [u'fys-E', u'ys-a', u'\xeas-j\xea', u'tis-', u'as-'] 5
# pi1S => is1S : [u'wa-ys', u'sHi-fys', u'E-ys', u'-as', u'-dis'] 5
# pi2S => is3P : [u'-as', u'-tis', u'j\xea-\xeas', u'a-ys', u'E-fys'] 5
# ii3P => ps1P : [u'avE-Ej\xf4', u'9zE-asj\xf4', u'E-j\xf4', u'uvE-Hisj\xf4', u'EtE-swaj\xf4'] 5
# is3P => inf : [u'ys-avwar', u'fys-Etr', u's-r', u'as-e', u'\xeas-9nir'] 5
# pi2P => ps1P : [u'ave-Ej\xf4', u'e-j\xf4', u'Et-asj\xf4', u'uve-Hisj\xf4', u'Et-swaj\xf4'] 5
# is3P => ii1S : [u'\xeas-9nE', u'as-E', u'fys-EtE', u'is-E', u'ys-avE'] 5
# ps1P => ppFS : [u'j\xf4-e', u'Ej\xf4-y', u'asj\xf4-Et', u'j\xf4-i', u'j\xf4-y'] 5
# is1S => ii3P : [u'fys-EtE', u'ys-avE', u'as-E', u'is-E', u'ys-9vE'] 5
# ps1P => pc3P : [u'Ej\xf4-OrE', u'asj\xf4-9rE', u'j\xf4-9rE', u'Hisj\xf4-urE', u'waj\xf4-9rE'] 5
# ai2S => ppFP : [u'i-y', u'-z', '-', u'i-Et', u'ri-Ert'] 6
# ps2P => pP : [u'swaje-Et\xe2', u'je-\xe2', u'Hisje-uv\xe2', u'asje-9z\xe2', u'e-\xe2'] 5
# ppMP => ps1P : [u'i-j\xf4', u'e-j\xf4', u'E-asj\xf4', u'y-Ej\xf4', u'y-j\xf4'] 5
# pP => is1S : [u'Ej\xe2-ys', u'9v\xe2-ys', u'\xe2-as', u'Et\xe2-fys', u'\xe2-is'] 5
# ii3S => is3P : [u'E-as', u'9nE-\xeas', u'avE-ys', u'E-is', u'EtE-fys'] 5
# pi1P => is3P : [u'\xf4-is', u'av\xf4-ys', u'9n\xf4-\xeas', u'sOm-fys', u'\xf4-as'] 5
# is1S => pi3S : [u'fys-E', u'ys-a', u'ys-wa', u'dis-', u'as-'] 5
# pi1P => is1S : [u'\xf4-is', u'av\xf4-ys', u'\xf4-as', u'sOm-fys', u'9v\xf4-ys'] 5
# is3S => ps1P : [u'fy-swaj\xf4', u'\xea-9nj\xf4', u'y-Hisj\xf4', u'y-Ej\xf4', u'i-asj\xf4'] 5
# ps1P => pi2P : [u'j\xf4-e', u'Ej\xf4-ave', u'Hisj\xf4-uve', u'swaj\xf4-Et', u'asj\xf4-Et'] 5
# ps3S => is1S : [u'swa-fys', u'-is', u'E-ys', u'-as', u'wav-ys'] 5
# ii2P => ps1P : [u'9z.e-as.\xf4', u'e-\xf4', u'Etje-swaj\xf4', u'uvje-Hisj\xf4', u'avje-Ej\xf4'] 5
# pI2P => pi2P : ['-', u'Ej.-av.', u'swaje-Et', u'9j.-ul.', u'S.-v.'] 5
# ii1S => is1S : [u'E-as', u'avE-ys', u'E-is', u'EtE-fys', u'9vE-ys'] 5
# ii1S => is3P : [u'E-as', u'9nE-\xeas', u'avE-ys', u'E-is', u'EtE-fys'] 5
# pP => pI2P : [u'Et\xe2-swaje', u'z\xe2-t', u'\xe2-e', u'ul\xe2-9je', u'9z\xe2-Et'] 5
# ppFS => ps1P : [u'i-j\xf4', u'e-j\xf4', u'y-Ej\xf4', u'y-j\xf4', u'Et-asj\xf4'] 5
# is1S => pI2S : [u'ys-E', u'ys-wa', u'fys-swa', u'as-', u'dis-'] 5
# ii3P => is1S : [u'E-as', u'avE-ys', u'E-is', u'EtE-fys', u'9vE-ys'] 5
# pi2P => ii2P : [u'-je', u't-zje', '-', u'e-je', u'Et-9zje'] 5
# ps1S => is3P : [u'swa-fys', u'-is', u'jEn-\xeas', u'-as', u'E-ys'] 5
# ps1P => ii2S : [u'j\xf4-E', u'Ej\xf4-avE', u'Hisj\xf4-uvE', u'asj\xf4-9zE', u'swaj\xf4-EtE'] 5
# ii2S => ps1P : [u'avE-Ej\xf4', u'9zE-asj\xf4', u'E-j\xf4', u'uvE-Hisj\xf4', u'EtE-swaj\xf4'] 5
# ps1P => is3S : [u'Ej\xf4-y', u'9nj\xf4-\xea', u'Hisj\xf4-y', u'asj\xf4-i', u'swaj\xf4-fy'] 5
# is1S => pi1S : [u'ys-wa', u'fys-sHi', u'ys-E', u'as-', u'dis-'] 5
# ps1P => pi1P : [u'j\xf4-\xf4', u'asj\xf4-9z\xf4', u'Hisj\xf4-uv\xf4', u'Ej.-av.', u'waj\xf4-Om'] 5
# ppFP => ai2S : [u'y-i', u'z-', '-', u'Ert-ri', u'Et-i'] 5
# pi2P => pI1P : [u'e-\xf4', u'ave-Ej\xf4', u't-z\xf4', u'Et-9z\xf4', u'Et-swaj\xf4'] 5
# pI2P => is1S : [u'swaje-fys', u'e-as', u'e-is', u'Eje-ys', u'9ve-ys'] 5
# is3P => ps1S : [u'as-', u'\xeas-jEn', u'fys-swa', u'ys-E', u'is-'] 5
# ii1P => ps1P : [u'uvj\xf4-Hisj\xf4', u'avj\xf4-Ej\xf4', '-', u'Etj\xf4-swaj\xf4', u'9z..-as..'] 5
# pc3P => ps1P : [u'9rE-asj\xf4', u'urE-Hisj\xf4', u'OrE-Ej\xf4', u'9rE-waj\xf4', u'9rE-j\xf4'] 5
# pi2S => pi3S : [u'j-', u'wa-je', '-', u'je-wa', u'-j'] 5
# ai2S => ppMS : [u'ri-Er', u'i-y', '-', u'i-E', u'\xea-9ny'] 5
# ps1P => ii3S : [u'j\xf4-E', u'Ej\xf4-avE', u'Hisj\xf4-uvE', u'asj\xf4-9zE', u'swaj\xf4-EtE'] 5
# inf => is1S : [u'Etr-fys', u'e-as', u'r-is', u'avwar-ys', u'9vwar-ys'] 5
# is1S => pi1P : [u'fys-sOm', u'as-\xf4', u'ys-av\xf4', u'ys-9v\xf4', u'is-\xf4'] 5
# ps1P => ppMP : [u'j\xf4-e', u'Ej\xf4-y', u'asj\xf4-E', u'j\xf4-i', u'j\xf4-y'] 5
# pI1P => pi2P : [u'Ej\xf4-ave', u'z\xf4-t', u'\xf4-e', u'9z\xf4-Et', u'swaj\xf4-Et'] 5
# is1S => pP : [u'ys-Ej\xe2', u'as-\xe2', u'ys-9v\xe2', u'fys-Et\xe2', u'is-\xe2'] 5
# is1S => pi3P : [u'ys-wav', u'fys-s\xf4', u'as-', u'is-', u'ys-\xf4'] 5
# ii2P => pi2P : ['-', u'zje-t', u'9zje-Et', u'je-e', u'je-'] 5
# pi3S => pi2S : [u'j-', u'wa-je', '-', u'je-wa', u'-j'] 5
# ai2S => ppMP : [u'ri-Er', u'i-y', '-', u'i-E', u'\xea-9ny'] 5
# pP => ps2P : [u'\xe2-je', u'9z\xe2-asje', u'\xe2-e', u'uv\xe2-Hisje', u'Et\xe2-swaje'] 5
# ii3S => ps1P : [u'avE-Ej\xf4', u'9zE-asj\xf4', u'E-j\xf4', u'uvE-Hisj\xf4', u'EtE-swaj\xf4'] 5
# pI2P => pP : [u'swaje-Et\xe2', u'Et-9z\xe2', u'e-\xe2', u't-z\xe2', u'9je-ul\xe2'] 5
# fi1P => ps1P : [u'Or.-Ej.', u'9r\xf4-j\xf4', u'9r\xf4-asj\xf4', u'9r\xf4-waj\xf4', u'ur\xf4-Hisj\xf4'] 5
# pc2P => ppFP : [u'Orje-y', u'9rje-e', u'9rje-Et', u'rje-t', u'9vrie-y'] 5
# ps1P => pP : [u'asj\xf4-9z\xe2', u'\xf4-\xe2', u'swaj\xf4-Et\xe2', u'Hisj\xf4-uv\xe2', u'j\xf4-\xe2'] 5
# pi1P => ps1P : [u'Om-waj\xf4', u'9z\xf4-asj\xf4', u'\xf4-j\xf4', u'av.-Ej.', u'uv\xf4-Hisj\xf4'] 5
# pi3P => is1S : [u'\xf4-ys', u'-is', u'-as', u's\xf4-fys', u'wav-ys'] 5
# is1S => ii1S : [u'fys-EtE', u'ys-avE', u'as-E', u'is-E', u'ys-9vE'] 5
# is1S => pI2P : [u'fys-swaje', u'ys-Eje', u'as-e', u'is-e', u'ys-9ve'] 5
# pi2P => is1S : [u'Et-fys', u'e-as', u'e-is', u'9ve-ys', u'ave-ys'] 5
# ii1S => ps1P : [u'avE-Ej\xf4', u'9zE-asj\xf4', u'E-j\xf4', u'uvE-Hisj\xf4', u'EtE-swaj\xf4'] 5
# is3P => ii3S : [u'\xeas-9nE', u'as-E', u'fys-EtE', u'is-E', u'ys-avE'] 5
# 92 paires pour 5 transformation(s)
#
# longueur=6
# fi1S => ps1P : [u'9rE-waj\xf4', u'9rE-asj\xf4', u'OrE-Ej\xf4', u'urE-Hisj\xf4', u'9rE-j\xf4', u'j\xeadrE-9nj\xf4'] 6
# pi3P => is3P : [u'-as', u's\xf4-fys', u'\xf4-ys', u'-is', u'jEn-\xeas', u'i-jas'] 6
# pP => ii1P : [u'j\xe2-ij\xf4', u'\xe2-i\xf4', u'\xe2-j\xf4', u'S\xe2-vj\xf4', u'\xe2-\xf4', u'Ej\xe2-avj\xf4'] 6
# ai2S => pc3P : [u'i-EtrE', u'i-9rE', u'y-OrE', u'fy-s9rE', u'y-urE', u'i-ErE'] 6
# pi3S => is3P : [u'-as', u'-tis', u'a-ys', u'i-jas', u'E-fys', u'j\xea-\xeas'] 6
# ai1P => ppFP : [u'm-z', u'm-', u'im-Et', u'im-y', u'am-e', u'EJim-\xeat'] 6
# ai3P => ps1P : [u'fyr-swaj\xf4', u'ir-j\xf4', u'yr-Hisj\xf4', u'yr-Ej\xf4', u'Er-j\xf4', u'ir-asj\xf4'] 6
# ps2P => ii1S : [u'asje-9zE', u'Hisje-uvE', u'Sje-vE', u'je-E', u'Eje-avE', u'swaje-EtE'] 6
# ai1P => ppMS : [u'rim-Er', u'm-', u'im-E', u'im-y', u'am-e', u'EJim-\xea'] 6
# ai1P => ppFS : [u'm-z', u'm-', u'im-Et', u'im-y', u'am-e', u'EJim-\xeat'] 6
# ii1P => ps2P : [u'v.\xf4-S.e', u'Etj\xf4-swaje', u'\xf4-e', u'avj\xf4-Eje', u'uvj\xf4-Hisje', u'9z.\xf4-as.e'] 6
# ppMS => ai1P : [u'E-im', u'-m', u'e-am', u'\xea-EJim', u'y-im', u'Er-rim'] 6
# ii1S => ps2P : [u'9zE-asje', u'E-je', u'avE-Eje', u'uvE-Hisje', u'vE-Sje', u'EtE-swaje'] 6
# pi2P => pP : [u'e-\xe2', u'-\xe2', u'ave-Ej\xe2', u'Et-9z\xe2', u've-S\xe2', u't-z\xe2'] 6
# pc3P => ai2S : [u'urE-y', u's9rE-fy', u'OrE-y', u'EtrE-i', u'9rE-i', u'ErE-i'] 6
# pc2P => ai1P : [u'urje-ym', u's9rje-fym', u'9vrie-ym', u'Orje-ym', u'9rje-im', u'9rje-am'] 6
# ps2P => ii1P : [u'Hisje-uvj\xf4', u'S.e-v.\xf4', u'Eje-avj\xf4', u'e-\xf4', u'swaje-Etj\xf4', u'as.e-9z.\xf4'] 6
# pI2S => is3P : [u'-as', u'-tis', u'swa-fys', u'E-ys', u'i-jas', u'j\xea-\xeas'] 6
# ii2P => ps2P : [u'avje-Eje', '-', u'uvje-Hisje', u'9z..-as..', u'v..-S..', u'Etje-swaje'] 6
# ps1P => pi3P : [u'asj\xf4-\xf4', u'Ej\xf4-\xf4', u'waj\xf4-\xf4', u'j\xf4-', u'9nj\xf4-jEn', u'Hisj\xf4-9v'] 6
# is3P => fi3S : [u'fys-s9ra', u'\xeas-j\xeadra', u'as-9ra', u'ys-Ora', u'jas-ira', u's-ra'] 6
# ai1S => ps1P : [u'i-j\xf4', u'fy-swaj\xf4', u'\xea-9nj\xf4', u'E-j\xf4', u'y-Ej\xf4', u'i-asj\xf4'] 6
# ps2P => pi1P : [u'Hisje-uv\xf4', u'je-\xf4', u'Sje-v\xf4', u'Eje-av\xf4', u'waje-Om', u'asje-9z\xf4'] 6
# ii2S => ps2P : [u'9zE-asje', u'E-je', u'avE-Eje', u'uvE-Hisje', u'vE-Sje', u'EtE-swaje'] 6
# ppFS => ai1P : [u'z-m', u'-m', u'\xeat-EJim', u'y-im', u'e-am', u'Et-im'] 6
# ai1P => ppMP : [u'rim-Er', u'm-', u'im-E', u'im-y', u'am-e', u'EJim-\xea'] 6
# ps2P => ii2P : [u'S..-v..', u'as..-9z..', u'swaje-Etje', '-', u'Hisje-uvje', u'Eje-avje'] 6
# is3P => pi3S : [u'ys-a', u'tis-', u'fys-E', u'\xeas-j\xea', u'jas-i', u'as-'] 6
# ii3S => ps2P : [u'9zE-asje', u'E-je', u'avE-Eje', u'uvE-Hisje', u'vE-Sje', u'EtE-swaje'] 6
# is3P => pi3P : [u'\xeas-jEn', u'fys-s\xf4', u'is-', u'jas-i', u'as-', u'ys-\xf4'] 6
# ps1P => ai3P : [u'swaj\xf4-fyr', u'j\xf4-Er', u'j\xf4-ir', u'Ej\xf4-yr', u'asj\xf4-ir', u'Hisj\xf4-yr'] 6
# ai2S => ppFS : [u'i-Et', '-', u'ri-Ert', u'\xea-9ny', u'i-y', u'-z'] 7
# ps1P => ai1S : [u'swaj\xf4-fy', u'asj\xf4-i', u'Ej\xf4-y', u'j\xf4-E', u'j\xf4-i', u'9nj\xf4-\xea'] 6
# inf => ps1P : [u'Er-asj\xf4', u'ir-j\xf4', u'avwar-Ej\xf4', u'e-j\xf4', u'Etr-swaj\xf4', u'uvwar-Hisj\xf4'] 6
# ps2P => ii3P : [u'asje-9zE', u'Hisje-uvE', u'Sje-vE', u'je-E', u'Eje-avE', u'swaje-EtE'] 6
# 55 paires pour 6 transformation(s)
#
# longueur=7
# fi2P => ps1P : [u'9re-waj\xf4', u'9re-asj\xf4', u'Ore-Ej\xf4', u'ure-Hisj\xf4', u'9re-j\xf4', u'j\xeadre-9nj\xf4', u'ire-j\xf4'] 7
# fi3P => ps1P : [u'9r\xf4-asj\xf4', u'Or.-Ej.', u'ir\xf4-j\xf4', u'j\xeadr\xf4-9nj\xf4', u'ur\xf4-Hisj\xf4', u'9r\xf4-j\xf4', u'9r\xf4-waj\xf4'] 7
# ii3P => pI2P : [u'E-e', u'avE-Eje', u'9zE-Et', u'vE-Se', u'zE-t', u'ulE-9je', u'EtE-swaje'] 7
# ai1S => ppMP : [u'E-e', u'i-E', u'ri-Er', '-', u'EJi-\xea', u'\xea-9ny', u'i-y'] 7
# ii2S => pI2P : [u'E-e', u'avE-Eje', u'9zE-Et', u'vE-Se', u'zE-t', u'ulE-9je', u'EtE-swaje'] 7
# fi2S => ps1P : [u'9ra-j\xf4', u'9ra-asj\xf4', u'j\xeadra-9nj\xf4', u'Ora-Ej\xf4', u'ura-Hisj\xf4', u'ira-j\xf4', u'9ra-waj\xf4'] 7
# pc3S => ps1P : [u'9rE-waj\xf4', u'9rE-asj\xf4', u'9rE-j\xf4', u'urE-Hisj\xf4', u'OrE-Ej\xf4', u'j\xeadrE-9nj\xf4', u'irE-j\xf4'] 7
# ps2P => pi2P : [u'zje-t', u'Ej.-av.', u'swaje-Et', u'asje-Et', u'Hisje-uve', u'Sje-ve', u'je-e'] 7
# ii3S => pI2P : [u'E-e', u'avE-Eje', u'9zE-Et', u'vE-Se', u'zE-t', u'ulE-9je', u'EtE-swaje'] 7
# pI2P => ii1S : [u'e-E', u'Et-9zE', u'swaje-EtE', u'Se-vE', u'Eje-avE', u't-zE', u'9je-ulE'] 7
# ppFP => ps2P : [u'e-je', u'Et-asje', u'y-Eje', u'y-9vje', u't-zje', u'i-je', u'y-Esje'] 7
# pi2P => ps2P : [u'e-je', u'Et-asje', u'av.-Ej.', u'uve-Hisje', u'Et-swaje', u've-Sje', u't-zje'] 7
# pI2P => pi1P : [u'Et-9z\xf4', u'Se-v\xf4', u'Eje-av\xf4', u't-z\xf4', u'waje-Om', u'e-\xf4', u'9je-ul\xf4'] 7
# ai1S => ps2P : [u'fy-swaje', u'E-je', u'y-Eje', u'y-9vje', u'i-asje', u'-zje', u'i-je'] 7
# is3S => pc1P : [u'y-urj\xf4', u'a-9rj\xf4', u'fy-s9rj\xf4', u'y-9vri\xf4', u'ly-dri\xf4', u'i-9rj\xf4', u'y-Orj\xf4'] 7
# pc2P => is3S : [u's9rje-fy', u'9vrie-y', u'drie-ly', u'9rje-i', u'Orje-y', u'9rje-a', u'urje-y'] 7
# ai1P => pc3P : [u'am-9rE', u'im-9rE', u'ym-OrE', u'ym-urE', u'ym-9vrE', u'im-ErE', u'fym-s9rE'] 7
# ps3P => pi3P : [u'as-\xf4', u'S-v', u'His-9v', '-', u'aj-v\xf4', u'E-\xf4', u'wa-\xf4'] 7
# ps1P => ai3S : [u'swaj\xf4-fy', u'asj\xf4-i', u'Hisj\xf4-y', u'Ej\xf4-y', u'j\xf4-i', u'9nj\xf4-\xea', u'j\xf4-a'] 7
# pi3P => ps3P : [u'\xf4-as', u'9v-His', u'\xf4-wa', u'v\xf4-aj', '-', u'\xf4-E', u'v-S'] 7
# pc2P => ii1P : [u's9rje-Etj\xf4', u'\xe2drie-9nj\xf4', u'r.e-v.\xf4', u'r.e-z.\xf4', u'9rje-j\xf4', u'rie-j\xf4', u'Or.e-av.\xf4'] 7
# pi1P => pI2P : [u'Om-waje', u'\xf4-e', u'9z\xf4-Et', u'z\xf4-t', u'av\xf4-Eje', u'v\xf4-Se', u'ul\xf4-9je'] 7
# pi3S => ps1P : [u'-j\xf4', u'a-Ej\xf4', u'-tj\xf4', u'2-Hisj\xf4', u'E-swaj\xf4', u'E-asj\xf4', u'j\xea-9nj\xf4'] 7
# pi2S => pi1S : [u'E-sHi', '-', u'a-E', u'je-wa', u'-j', u'j-', u'wa-je'] 7
# ps2P => ai1S : [u'Eje-y', u'asje-i', u'9vje-y', u'zje-', u'je-E', u'je-i', u'swaje-fy'] 7
# pc2P => ai2S : [u's9rje-fy', u'\xe2drie-i', u'warje-y', u'9rje-i', u'Orje-y', u'rje-', u'urje-y'] 7
# pi2S => ps1P : [u'-j\xf4', u'a-Ej\xf4', u'-tj\xf4', u'2-Hisj\xf4', u'E-swaj\xf4', u'E-asj\xf4', u'j\xea-9nj\xf4'] 7
# pi1S => is3P : [u'-as', u'-tis', u'sHi-fys', u'E-ys', u'i-jas', u'-s', u'j\xea-\xeas'] 7
# ai2S => pc2P : [u'y-warje', u'fy-s9rje', u'i-9rje', u'y-Orje', u'y-urje', u'i-\xe2drie', u'-rje'] 7
# pi3S => pi1S : [u'E-sHi', '-', u'a-E', u'je-wa', u'-j', u'j-', u'wa-je'] 7
# ps1P => fi2P : [u'Ej\xf4-Ore', u'9nj\xf4-j\xeadre', u'asj\xf4-9re', u'Hisj\xf4-ure', u'j\xf4-9re', u'waj\xf4-9re', u'j\xf4-ire'] 7
# fi3S => ps1P : [u'9ra-j\xf4', u'9ra-asj\xf4', u'j\xeadra-9nj\xf4', u'Ora-Ej\xf4', u'ura-Hisj\xf4', u'ira-j\xf4', u'9ra-waj\xf4'] 7
# pI1P => ps3P : [u'9v\xf4-wav', u'9z\xf4-as', u'j\xf4-', u'\xf4-', u'9n\xf4-jEn', u'l\xf4-j', u'9.\xf4-E.'] 7
# ps2P => ai1P : [u'Hisje-ym', u'swaje-fym', u'Eje-ym', u'asje-im', u'9vje-ym', u'je-am', u'je-im'] 7
# is3S => pc2P : [u'a-9rje', u'ly-drie', u'y-9vrie', u'i-9rje', u'y-Orje', u'y-urje', u'fy-s9rje'] 7
# pI2P => ii3S : [u'e-E', u'Et-9zE', u'swaje-EtE', u'Se-vE', u'Eje-avE', u't-zE', u'9je-ulE'] 7
# ii1S => pI2P : [u'E-e', u'avE-Eje', u'9zE-Et', u'vE-Se', u'zE-t', u'ulE-9je', u'EtE-swaje'] 7
# ps2P => ai2S : [u'Hisje-y', u'asje-i', u'Esje-y', u'9nje-\xea', u'je-i', u'aSje-y', u'swaje-fy'] 7
# pc2P => ii2P : [u'r..-v..', u'9rje-je', u'Or..-av..', u'drie-lje', u'rje-je', u'r..-z..', u's9rje-Etje'] 7
# ps1P => pi3S : [u'j\xf4-', u'asj\xf4-E', u'tj\xf4-', u'Hisj\xf4-2', u'Ej\xf4-a', u'swaj\xf4-E', u'9nj\xf4-j\xea'] 7
# ps1P => fi2S : [u'j\xf4-ira', u'9nj\xf4-j\xeadra', u'Hisj\xf4-ura', u'asj\xf4-9ra', u'j\xf4-9ra', u'waj\xf4-9ra', u'Ej\xf4-Ora'] 7
# ai3S => ps1P : [u'i-j\xf4', u'a-j\xf4', u'fy-swaj\xf4', u'\xea-9nj\xf4', u'y-Hisj\xf4', u'y-Ej\xf4', u'i-asj\xf4'] 7
# pi1S => pi2S : [u'E-a', u'sHi-E', '-', u'je-wa', u'-j', u'j-', u'wa-je'] 7
# is3S => ppMP : [u'i-E', '-', u'a-e', u'EJi-\xea', u'\xea-9ny', u'i-y', u'zi-'] 7
# ppFP => is3S : [u'z-', u'9ny-\xea', u'e-a', '-', u'\xeat-EJi', u'y-i', u'Et-i'] 7
# pI2P => ii3P : [u'e-E', u'Et-9zE', u'swaje-EtE', u'Se-vE', u'Eje-avE', u't-zE', u'9je-ulE'] 7
# ppMP => ai1S : [u'e-E', u'9ny-\xea', u'E-i', '-', u'y-i', u'\xea-EJi', u'Er-ri'] 7
# pI2P => ii2S : [u'e-E', u'Et-9zE', u'swaje-EtE', u'Se-vE', u'Eje-avE', u't-zE', u'9je-ulE'] 7
# ppFS => ps2P : [u'e-je', u'Et-asje', u'y-je', u'y-Eje', u't-zje', u'i-je', u'y-Esje'] 7
# pc1P => is3S : [u'9vri\xf4-y', u'Orj\xf4-y', u'dri\xf4-ly', u's9rj\xf4-fy', u'urj\xf4-y', u'9rj\xf4-i', u'9rj\xf4-a'] 7
# ai1P => ps2P : [u'ym-Eje', u'fym-swaje', u'ym-Hisje', u'ym-9vje', u'im-asje', u'im-je', u'am-je'] 7
# ps3P => pI1P : [u'wav-9v\xf4', u'as-9z\xf4', u'jEn-9n\xf4', u'j-l\xf4', u'-j\xf4', u'-\xf4', u'E.-9.\xf4'] 7
# ii2P => pc2P : [u'v..-r..', u'je-rje', u'Etje-s9rje', u'av..-Or..', u'lje-drie', u'z..-r..', u'je-9rje'] 8
# ps1P => pi2S : [u'j\xf4-', u'asj\xf4-E', u'tj\xf4-', u'Hisj\xf4-2', u'Ej\xf4-a', u'swaj\xf4-E', u'9nj\xf4-j\xea'] 7
# ps2P => ppFS : [u'Eje-y', u'je-y', u'Esje-y', u'asje-Et', u'zje-t', u'je-e', u'je-i'] 7
# 71 paires pour 7 transformation(s)
#
# longueur=8
# ii2P => ps3P : [u'9zje-as', u'uvje-His', u'avje-E', u'Etje-swa', u'lje-j', u'9nje-jEn', u'vje-S', u'je-'] 8
# is3S => ppMS : [u'i-E', u'ri-Er', '-', u'a-e', u'EJi-\xea', u'\xea-9ny', u'i-y', u'zi-'] 8
# pc3P => ps2P : [u'rE-je', u'urE-Hisje', u'OrE-aSje', u'9rE-waje', u'9rE-asje', u'OrE-Eje', u'drE-lje', u'9rE-je'] 8
# ii2P => ai1P : [u'Etje-fym', u'uvje-ym', u'je-am', u'waje-im', u'9nje-im', u'avje-ym', u'9zje-im', u'je-im'] 8
# ppMP => ai3P : [u'9ny-\xear', u'y-ir', u'O.-u.yr', u'-zir', u'\xea-EJir', u'-r', u'E-ir', u'e-Er'] 8
# pI1P => ps1S : [u'9.\xf4-E.', u'9z\xf4-as', u'j\xf4-', u'\xf4-', u'j\xf4-i', u'l\xf4-j', u'9n\xf4-jEn', u'u.\xf4-9.'] 8
# pi3S => ppFS : [u'E-e', u'i-Eky', u'2.-9.e', u'-i', u'2-y', u'-zy', u'a-y', u'E-iz', u'E-y', u'wa-y', u'-py', u'-e', u'-je', u'-ty', u'E.-9.e', u'e-Ee', '-', u'j\xea-9ny', u'-t', u'-ti', u'-vi', u'-y', u'va-ale', u'9.-O.t', u'-dy', u'o.-O.e', u'i-je', u'wa-iz', u'\xe2-iz', u'je-iz', u'i-y', u'r-Ert', u'-ky'] 45
# 1 paires pour 33 transformation(s)

# %%
classesFinales[paire].classe
# Out:
# {u'-dy': {u'-dy': 6},
#  u'-e': {u'-e': 208},
#  u'-e, -': {'-': 6},
#  u'-e, -, -t': {u'-e': 1, u'-t': 6},
#  u'-e, -, -t, -vi': {u'-vi': 2},
#  u'-e, -, -t, i-je': {'-': 7, u'-e': 1, u'-t': 3, u'i-je': 4},
#  u'-e, -dy': {u'-dy': 1, u'-e': 7},
#  u'-e, -je, -ty, -t': {u'-je': 1},
#  u'-e, -t': {u'-t': 6},
#  u'-e, -t, -ky': {u'-ky': 1},
#  u'-e, -t, -vi, je-iz': {u'je-iz': 1},
#  u'-e, -t, i-je': {u'-t': 1},
#  u'-e, -t, i-je, i-y': {u'i-je': 1, u'i-y': 1},
#  u'-e, -ti': {u'-e': 4, u'-ti': 1},
#  u'-e, -ti, -dy': {u'-dy': 2, u'-e': 9, u'-ti': 1},
#  u'-e, -ti, -dy, r-Ert': {u'r-Ert': 2},
#  u'-e, -ti, -vi, -dy': {u'-e': 1, u'-vi': 1},
#  u'-e, -ti, 9.-O.t, -dy': {u'9.-O.t': 1},
#  u'-e, -ty': {u'-ty': 1},
#  u'-e, -ty, -, -t, i-je': {u'i-je': 2},
#  u'-e, -ty, -t': {u'-t': 3},
#  u'-e, -y': {u'-y': 1},
#  u'-e, E.-9.e': {u'-e': 18, u'E.-9.e': 14},
#  u'-e, e-Ee, -t': {u'e-Ee': 1},
#  u'-e, j\xea-9ny, -t': {u'j\xea-9ny': 11},
#  u'-e, o.-O.e': {u'o.-O.e': 11},
#  u'-i, -e': {u'-i': 3},
#  u'-je': {u'-je': 2},
#  u'-je, -ty': {u'-ty': 2},
#  u'-py, -e, -dy': {u'-py': 1},
#  u'-ti, -dy': {u'-dy': 4, u'-ti': 1},
#  u'-ti, -dy, \xe2-iz': {u'\xe2-iz': 5},
#  u'-ty, va-ale': {u'va-ale': 1},
#  u'-zy, -e': {u'-zy': 1},
#  u'2-y, -e': {u'2-y': 1},
#  u'2.-9.e, -e': {u'2.-9.e': 1},
#  u'E-e, -e': {u'E-e': 1},
#  u'E-iz, -e': {u'E-iz': 4},
#  u'E-iz, E-y, -e': {u'E-iz': 1},
#  u'E-y, -e': {u'E-y': 2},
#  u'E-y, -e, -t': {u'E-y': 2},
#  u'a-y': {u'a-y': 1},
#  u'i-Eky, -e, -ty, -t, i-je': {u'i-Eky': 1},
#  u'wa-y, -je': {u'-je': 1, u'wa-y': 7},
#  u'wa-y, -je, wa-iz': {u'wa-iz': 1}}

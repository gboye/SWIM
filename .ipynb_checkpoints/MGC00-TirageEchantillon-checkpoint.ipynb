# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import itertools as it
import pickle

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %% [markdown]
# typeEchantillon :
# - fixe pour utiliser tailleEchantillon
# - variable pour utiliser nombre,increment
# - total pour utiliser tout le lexique

# %%
filePrefix="MGC-160104"
lexiquePrefix="MGC-160104"
nbEchantillons=6
tailleEchantillon=15000

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
debug=False

# %%
bdlexiqueIn = unicode(u"èò")
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO")
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    return result

# %% [raw]
# with open("2015-Data/"+lexiquePrefix+'-Verbes2.pkl', 'rb') as input:
#     verbes = pickle.load(input)
#
# verbes["phono"]=verbes["phono"].apply(lambda x: recoder(x))
#
# verbes["tirage"]=0
# tirages={}
# minEchantillon=1

# %%
with open("/Users/gilles/ownCloud/Recherche/Boye/2015-Data/"+lexiquePrefix+'-Tirages2.pkl', 'rb') as input:
    verbes = pickle.load(input)
minEchantillon=5
tirages={}

# %%
print dateheure(),
print "nb tirages %d/%d"%(len(verbes[verbes["tirage"]>0]),verbes[verbes["tirage"]>0]["tirage"].sum()),
print "%4.2f"%(float(verbes[verbes["tirage"]>0]["tirage"].sum())/len(verbes[verbes["tirage"]>0]))
# Out:
# 1603140723 nb tirages 74936/225583061 3010.34

# %%
def tirerFormes(limite):
    taille=len(verbes[verbes["tirage"]>0])
    while taille < limite:
        tirage=np.random.choice(verbes.index,p=verbes["prob"])
        verbes.loc[tirage,"tirage"]+=1
        taille=len(verbes[verbes["tirage"]>0])
        if taille%100==0:
            if not taille in tirages:
                tirages[taille]=verbes[verbes["tirage"]>0]["tirage"].sum()
                print dateheure(),
                print "nb tirages %d/%d"%(len(verbes[verbes["tirage"]>0]),verbes[verbes["tirage"]>0]["tirage"].sum()),
                print "%4.2f"%(float(verbes[verbes["tirage"]>0]["tirage"].sum())/len(verbes[verbes["tirage"]>0]))

# %%
# %%time
for echantillon in range(minEchantillon,nbEchantillons+1):
    tirerFormes(echantillon*tailleEchantillon)
    extrait=verbes[verbes["tirage"]>0]
    echantillonPrefix="-%02d"%echantillon
    paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
    paradigmes.to_csv(path_or_buf="2015-Data/"+filePrefix+echantillonPrefix+"-paradigmesSuite.csv",encoding="utf8",sep=";")
    extrait.to_csv(path_or_buf="2015-Data/"+filePrefix+echantillonPrefix+"-tirageSuite.csv",encoding="utf8",sep=";")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-f4033ad18b9f> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'for echantillon in range(minEchantillon,nbEchantillons+1):\n    tirerFormes(echantillon*tailleEchantillon)\n    extrait=verbes[verbes["tirage"]>0]\n    echantillonPrefix="-%02d"%echantillon\n    paradigmes=pd.pivot_table(extrait, values=\'phono\', index=[\'lexeme\'], columns=[\'case\'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()\n    paradigmes.to_csv(path_or_buf="2015-Data/"+filePrefix+echantillonPrefix+"-paradigmesSuite.csv",encoding="utf8",sep=";")\n    extrait.to_csv(path_or_buf="2015-Data/"+filePrefix+echantillonPrefix+"-tirageSuite.csv",encoding="utf8",sep=";")')
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1165         else:
#    1166             st = clock2()
# -> 1167             exec(code, glob, local_ns)
#    1168             end = clock2()
#    1169             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-21-5d9c2d4383c4> in tirerFormes(limite)
#       2     taille=len(verbes[verbes["tirage"]>0])
#       3     while taille < limite:
# ----> 4         tirage=np.random.choice(verbes.index,p=verbes["prob"])
#       5         verbes.loc[tirage,"tirage"]+=1
#       6         taille=len(verbes[verbes["tirage"]>0])
#
# KeyboardInterrupt:

# %%
verbes.sort_values(by="tirage",ascending=False)
# Out:
#                   ortho        phono  ext cs  ms   vs      lexeme  \
# 173659              est            E   t"  V  3S   pi        être
# 40                    a            a  NaN  V  3S   pi       avoir
# 434075            était          EtE   t"  V  3S   ii        être
# 11553                ai            E  NaN  V  1S   pi       avoir
# 371437             sont           sô   t"  V  3P   pi        être
# 415488             voir         vwar  NaN  V      inf        voir
# 171685               es            E   z"  V  2S   pi        être
# 31699             avait          avE   t"  V  3S   ii       avoir
# 408810               va           va  NaN  V  3S   pi       aller
# 408809               va           va  NaN  V  2S   pI       aller
# 181709             faut           fo   t"  V  3S   pi     falloir
# 409393             vais           vE   z"  V  1S   pi       aller
# 286941             peut           p2   t"  V  3S   pi     pouvoir
# 360822             sais           sE   z"  V  1S   pi      savoir
# 360823             sais           sE   z"  V  2S   pi      savoir
# 25728                as            a   z"  V  2S   pi       avoir
# 412479             veux           v2   z"  V  1S   pi     vouloir
# 412481             veux           v2   z"  V  2S   pi     vouloir
# 180043             fait           fE   t"  K  MS   pp       faire
# 180044             fait           fE   t"  V  3S   pi       faire
# 416827               vu           vy  NaN  K  MS   pp        voir
# 380044             suis          sHi   z"  V  1S   pi      suivre
# 380046             suis          sHi   z"  V  2S   pI      suivre
# 103814              dit           di   t"  V  3S   pi        dire
# 103813              dit           di   t"  V  3S   ai        dire
# 103811              dit           di   t"  K  MS   pp        dire
# 174517               eu            y  NaN  K  MS   pp       avoir
# 286944             peux           p2   z"  V  2S   pi     pouvoir
# 286943             peux           p2   z"  V  1S   pi     pouvoir
# 412474             veut           v2   t"  V  3S   pi     vouloir
# ...                 ...          ...  ... ..  ..  ...         ...
# 180611      farandolait     farâdOlE   t"  V  3S   ii  farandoler
# 180548       fantasmées      fâtasme   z"  K  FP   pp   fantasmer
# 180577          fanâmes        fanam  @z"  V  1P   ai       faner
# 180578            fanât         fana   t"  V  3S   is       faner
# 180579          fanâtes        fanat  @z"  V  2P   ai       faner
# 180580         fanèrent        fanEr  @t"  V  3P   ai       faner
# 42283           blousai        bluzE  NaN  V  1S   ai     blouser
# 42282            blousa        bluza  NaN  V  3S   ai     blouser
# 42281         blottîtes       blOtit  @z"  V  2P   ai     blottir
# 42280           blottît        blOti   t"  V  3S   is     blottir
# 180606        farandola     farâdOla  NaN  V  3S   ai  farandoler
# 180607       farandolai     farâdOlE  NaN  V  1S   ai  farandoler
# 180609      farandolais     farâdOlE   z"  V  1S   ii  farandoler
# 180610      farandolais     farâdOlE   z"  V  2S   ii  farandoler
# 180612      farandolant     farâdOlâ   t"  V       pP  farandoler
# 180627       farandoler     farâdOle   R"  V      inf  farandoler
# 180613       farandolas     farâdOla   z"  V  2S   ai  farandoler
# 180614     farandolasse    farâdOlas    @  V  1S   is  farandoler
# 180615   farandolassent    farâdOlas  @t"  V  3P   is  farandoler
# 180616    farandolasses    farâdOlas    @  V  2S   is  farandoler
# 180617   farandolassiez  farâdOlasje   z"  V  2P   is  farandoler
# 180618  farandolassions  farâdOlasjô   z"  V  1P   is  farandoler
# 180620        farandole      farâdOl    @  V  1S   pi  farandoler
# 180621        farandole      farâdOl    @  V  1S   ps  farandoler
# 180622        farandole      farâdOl    @  V  2S   pI  farandoler
# 180623        farandole      farâdOl    @  V  3S   pi  farandoler
# 180624        farandole      farâdOl    @  V  3S   ps  farandoler
# 180625      farandolent      farâdOl  @t"  V  3P   pi  farandoler
# 180626      farandolent      farâdOl  @t"  V  3P   ps  farandoler
# 209267         haussera        Os6ra  NaN  V  3S   fi     hausser
#
#                 freq          prob  case    tirage
# 173659  2.574944e+12  8.253758e-02  pi3S  11615871
# 40      7.167730e+11  2.297553e-02  pi3S   3230283
# 434075  6.045640e+11  1.937877e-02  ii3S   2728340
# 11553   3.094820e+11  9.920176e-03  pi1S   1397319
# 371437  2.162210e+11  6.930776e-03  pi3P    974140
# 415488  2.117650e+11  6.787942e-03   inf    955588
# 171685  2.105690e+11  6.749606e-03  pi2S    949660
# 31699   2.092790e+11  6.708256e-03  ii3S    944926
# 408810  2.038560e+11  6.534426e-03  pi3S    918755
# 408809  2.038560e+11  6.534426e-03  pI2S    918448
# 181709  1.972020e+11  6.321138e-03  pi3S    889691
# 409393  1.924990e+11  6.170388e-03  pi1S    867677
# 286941  1.718630e+11  5.508919e-03  pi3S    775422
# 360822  1.554090e+11  4.981500e-03  pi1S    701214
# 360823  1.554090e+11  4.981500e-03  pi2S    699229
# 25728   1.483030e+11  4.753723e-03  pi2S    669817
# 412479  1.432440e+11  4.591561e-03  pi1S    647033
# 412481  1.432440e+11  4.591561e-03  pi2S    646233
# 180043  1.403750e+11  4.499598e-03  ppMS    633984
# 180044  1.403750e+11  4.499598e-03  pi3S    633360
# 416827  1.298660e+11  4.162741e-03  ppMS    586017
# 380044  1.201670e+11  3.851848e-03  pi1S    543438
# 380046  1.201670e+11  3.851848e-03  pI2S    541926
# 103814  1.186900e+11  3.804504e-03  pi3S    536983
# 103813  1.186900e+11  3.804504e-03  ai3S    536751
# 103811  1.186900e+11  3.804504e-03  ppMS    535419
# 174517  1.105150e+11  3.542462e-03  ppMS    498714
# 286944  9.945900e+10  3.188071e-03  pi2S    449241
# 286943  9.945900e+10  3.188071e-03  pi1S    447733
# 412474  9.118000e+10  2.922695e-03  pi3S    411156
# ...              ...           ...   ...       ...
# 180611  7.000000e+00  2.243789e-13  ii3S         0
# 180548  3.120000e+02  1.000089e-11  ppFP         0
# 180577  9.270000e+02  2.971418e-11  ai1P         0
# 180578  9.270000e+02  2.971418e-11  is3S         0
# 180579  9.270000e+02  2.971418e-11  ai2P         0
# 180580  9.270000e+02  2.971418e-11  ai3P         0
# 42283   1.070000e+02  3.429792e-12  ai1S         0
# 42282   1.070000e+02  3.429792e-12  ai3S         0
# 42281   1.454000e+03  4.660670e-11  ai2P         0
# 42280   1.454000e+03  4.660670e-11  is3S         0
# 180606  7.000000e+00  2.243789e-13  ai3S         0
# 180607  7.000000e+00  2.243789e-13  ai1S         0
# 180609  7.000000e+00  2.243789e-13  ii1S         0
# 180610  7.000000e+00  2.243789e-13  ii2S         0
# 180612  7.000000e+00  2.243789e-13    pP         0
# 180627  7.000000e+00  2.243789e-13   inf         0
# 180613  7.000000e+00  2.243789e-13  ai2S         0
# 180614  7.000000e+00  2.243789e-13  is1S         0
# 180615  7.000000e+00  2.243789e-13  is3P         0
# 180616  7.000000e+00  2.243789e-13  is2S         0
# 180617  7.000000e+00  2.243789e-13  is2P         0
# 180618  7.000000e+00  2.243789e-13  is1P         0
# 180620  7.000000e+00  2.243789e-13  pi1S         0
# 180621  7.000000e+00  2.243789e-13  ps1S         0
# 180622  7.000000e+00  2.243789e-13  pI2S         0
# 180623  7.000000e+00  2.243789e-13  pi3S         0
# 180624  7.000000e+00  2.243789e-13  ps3S         0
# 180625  7.000000e+00  2.243789e-13  pi3P         0
# 180626  7.000000e+00  2.243789e-13  ps3P         0
# 209267  7.371000e+03  2.362710e-10  fi3S         0
#
# [328103 rows x 11 columns]

# %%
print dateheure()
rep="/Users/gilles/ownCloud/Recherche/Boye/2015-Data/"
# Out:
# 1602290742

# %%
with open("/Users/gilles/ownCloud/Recherche/Boye/2015-Data/"+filePrefix+'-Tirages2.pkl', 'wb') as output:
   pickle.dump(verbes, output, pickle.HIGHEST_PROTOCOL)

# %%
verbes
# Out:
#                 ortho     phono  ext cs  ms   vs    lexeme          freq  \
# 40                  a         a  NaN  V  3S   pi     avoir  7.167730e+11
# 45            abaissa     abEsa  NaN  V  3S   ai  abaisser  2.640000e+08
# 46           abaissai     abEsE  NaN  V  1S   ai  abaisser  1.700000e+07
# 47        abaissaient     abEsE   t"  V  3P   ii  abaisser  4.100000e+07
# 48          abaissais     abEsE   z"  V  1S   ii  abaisser  2.297000e+03
# 49          abaissais     abEsE   z"  V  2S   ii  abaisser  2.297000e+03
# 50          abaissait     abEsE   t"  V  3S   ii  abaisser  2.520000e+08
# 52          abaissant     abEsâ   t"  V       pP  abaisser  2.510000e+08
# 56           abaissas     abEsa   z"  V  2S   ai  abaisser  2.297000e+03
# 57         abaissasse    abEsas    @  V  1S   is  abaisser  2.297000e+03
# 58       abaissassent    abEsas  @t"  V  3P   is  abaisser  2.297000e+03
# 59        abaissasses    abEsas    @  V  2S   is  abaisser  2.297000e+03
# 60       abaissassiez  abEsasje   z"  V  2P   is  abaisser  2.297000e+03
# 61      abaissassions  abEsasjô   z"  V  1P   is  abaisser  2.297000e+03
# 64            abaisse      abEs    @  V  1S   pi  abaisser  1.570000e+08
# 65            abaisse      abEs    @  V  1S   ps  abaisser  2.297000e+03
# 66            abaisse      abEs    @  V  2S   pI  abaisser  1.570000e+08
# 67            abaisse      abEs    @  V  3S   pi  abaisser  1.570000e+08
# 68            abaisse      abEs    @  V  3S   ps  abaisser  2.297000e+03
# 71          abaissent      abEs  @t"  V  3P   pi  abaisser  1.000000e+08
# 72          abaissent      abEs  @t"  V  3P   ps  abaisser  2.297000e+03
# 73           abaisser     abEse   R"  V      inf  abaisser  4.000000e+08
# 74          abaissera   abEs6ra  NaN  V  3S   fi  abaisser  2.600000e+07
# 75         abaisserai   abEs6rE  NaN  V  1S   fi  abaisser  1.700000e+07
# 76      abaisseraient   abEs6rE   t"  V  3P   pc  abaisser  8.000000e+06
# 77        abaisserais   abEs6rE   z"  V  1S   pc  abaisser  6.000000e+06
# 78        abaisserais   abEs6rE   z"  V  2S   pc  abaisser  6.000000e+06
# 79        abaisserait   abEs6rE   t"  V  3S   pc  abaisser  2.200000e+07
# 80         abaisseras   abEs6ra   z"  V  2S   fi  abaisser  2.297000e+03
# 81         abaisserez   abEs6re   z"  V  2P   fi  abaisser  2.297000e+03
# ...               ...       ...  ... ..  ..  ...       ...           ...
# 437518          ôtera     Ot6ra  NaN  V  3S   fi      ôter  6.000000e+07
# 437519         ôterai     Ot6rE  NaN  V  1S   fi      ôter  1.600000e+07
# 437520      ôteraient     Ot6rE   t"  V  3P   pc      ôter  5.883000e+03
# 437521        ôterais     Ot6rE   z"  V  1S   pc      ôter  7.000000e+06
# 437522        ôterais     Ot6rE   z"  V  2S   pc      ôter  7.000000e+06
# 437523        ôterait     Ot6rE   t"  V  3S   pc      ôter  5.700000e+07
# 437524         ôteras     Ot6ra   z"  V  2S   fi      ôter  3.100000e+07
# 437525         ôterez     Ot6re   z"  V  2P   fi      ôter  3.700000e+07
# 437526        ôteriez    Ot6rje   z"  V  2P   pc      ôter  5.883000e+03
# 437527       ôterions    Ot6rjô   z"  V  1P   pc      ôter  7.000000e+06
# 437528        ôterons     Ot6rô   z"  V  1P   fi      ôter  5.883000e+03
# 437529        ôteront     Ot6rô   t"  V  3P   fi      ôter  5.883000e+03
# 437530           ôtes        ot    @  V  2S   pi      ôter  6.500000e+07
# 437531           ôtes        ot    @  V  2S   ps      ôter  5.883000e+03
# 437532           ôtez       Ote   z"  V  2P   pI      ôter  1.050000e+08
# 437533           ôtez       Ote   z"  V  2P   pi      ôter  1.050000e+08
# 437534          ôtiez      Otje   z"  V  2P   ii      ôter  1.700000e+07
# 437535          ôtiez      Otje   z"  V  2P   ps      ôter  5.883000e+03
# 437536         ôtions      Otjô   z"  V  1P   ii      ôter  5.883000e+03
# 437537         ôtions      Otjô   z"  V  1P   ps      ôter  5.883000e+03
# 437538          ôtons       Otô   z"  V  1P   pI      ôter  5.883000e+03
# 437539          ôtons       Otô   z"  V  1P   pi      ôter  9.000000e+06
# 437540         ôtâmes      Otam  @z"  V  1P   ai      ôter  5.883000e+03
# 437541           ôtât       Ota   t"  V  3S   is      ôter  1.400000e+07
# 437542         ôtâtes      Otat  @z"  V  2P   ai      ôter  5.883000e+03
# 437543        ôtèrent      OtEr  @t"  V  3P   ai      ôter  2.700000e+07
# 437544            ôté       Ote  NaN  K  MS   pp      ôter  8.650000e+08
# 437545           ôtée       Ote  NaN  K  FS   pp      ôter  9.600000e+07
# 437546          ôtées       Ote   z"  K  FP   pp      ôter  2.300000e+07
# 437547           ôtés       Ote   z"  K  MP   pp      ôter  1.800000e+07
#
#                 prob  case   tirage
# 40      2.297553e-02  pi3S  3230781
# 45      8.462290e-06  ai3S     1249
# 46      5.449202e-07  ai1S       93
# 47      1.314219e-06  ii3P      189
# 48      7.362833e-11  ii1S        0
# 49      7.362833e-11  ii2S        0
# 50      8.077640e-06  ii3S     1154
# 52      8.045586e-06    pP     1116
# 56      7.362833e-11  ai2S        0
# 57      7.362833e-11  is1S        0
# 58      7.362833e-11  is3P        0
# 59      7.362833e-11  is2S        0
# 60      7.362833e-11  is2P        0
# 61      7.362833e-11  is1P        0
# 64      5.032498e-06  pi1S      680
# 65      7.362833e-11  ps1S        0
# 66      5.032498e-06  pI2S      713
# 67      5.032498e-06  pi3S      685
# 68      7.362833e-11  ps3S        0
# 71      3.205413e-06  pi3P      466
# 72      7.362833e-11  ps3P        0
# 73      1.282165e-05   inf     1811
# 74      8.334073e-07  fi3S      116
# 75      5.449202e-07  fi1S       94
# 76      2.564330e-07  pc3P       28
# 77      1.923248e-07  pc1S       30
# 78      1.923248e-07  pc2S       39
# 79      7.051908e-07  pc3S       86
# 80      7.362833e-11  fi2S        0
# 81      7.362833e-11  fi2P        1
# ...              ...   ...      ...
# 437518  1.923248e-06  fi3S      286
# 437519  5.128660e-07  fi1S       78
# 437520  1.885744e-10  pc3P        0
# 437521  2.243789e-07  pc1S       37
# 437522  2.243789e-07  pc2S       29
# 437523  1.827085e-06  pc3S      252
# 437524  9.936780e-07  fi2S      143
# 437525  1.186003e-06  fi2P      159
# 437526  1.885744e-10  pc2P        0
# 437527  2.243789e-07  pc1P       29
# 437528  1.885744e-10  fi1P        0
# 437529  1.885744e-10  fi3P        0
# 437530  2.083518e-06  pi2S      264
# 437531  1.885744e-10  ps2S        0
# 437532  3.365683e-06  pI2P      477
# 437533  3.365683e-06  pi2P      512
# 437534  5.449202e-07  ii2P       71
# 437535  1.885744e-10  ps2P        0
# 437536  1.885744e-10  ii1P        0
# 437537  1.885744e-10  ps1P        0
# 437538  1.885744e-10  pI1P        0
# 437539  2.884871e-07  pi1P       34
# 437540  1.885744e-10  ai1P        0
# 437541  4.487578e-07  is3S       73
# 437542  1.885744e-10  ai2P        0
# 437543  8.654614e-07  ai3P      113
# 437544  2.772682e-05  ppMS     3869
# 437545  3.077196e-06  ppFS      426
# 437546  7.372449e-07  ppFP      111
# 437547  5.769743e-07  ppMP       83
#
# [328103 rows x 11 columns]

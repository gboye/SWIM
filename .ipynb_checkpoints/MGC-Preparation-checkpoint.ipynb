# %% [markdown]
# typeEchantillon :
# - fixe pour utiliser tailleEchantillon
# - variable pour utiliser nombre,increment,nombreInitial
# - total pour utiliser tout le lexique

# %%
typeEchantillon="total"
tailleEchantillon=30000
nombre=1000
increment=250
nombreInitial=20
freqForme=1000000

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')
#fs.supremum.concept.extent

# %%
bdlexiqueIn = unicode(u"èò")
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO")
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    return result

# %%
filePrefix="MGC-150805"

# %% [markdown]
# #Préparation du tableau de VERBES

# %% [markdown]
# ###Lecture du lexique
# - nomLexique pour le fichier
# - names pour les noms de colonnes
# - élimination des lignes dupliquées éventuelles (p.e. dépendre)

# %%
nomLexique="/Users/gilles/Copy/Python/phonemisation/bdlexique-PDM-Resync.txt"
bdlexique=pd.read_csv(nomLexique,sep=";",names=["ortho","phono","ext","cs","ms","vs","lexeme","L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"],encoding="utf8")
bdlexique.loc[(bdlexique["ms"]=="ij")&(bdlexique["cs"].isin(["V","K"])),"ms"]="MS"
bdlexique.drop_duplicates(inplace=True,subset=["phono","ext","cs","ms","vs","lexeme","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"])

# %% [markdown]
# ###Définition des cases
# - principales pour le paradigme courant
# - secondaires pour les cases rares
# - totales pour le tout

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %% [markdown]
# ###Création de la colonne de fréquence *freq*
# - fréquence forme : 1000000x(formeFrantext+formeFilms)
# - fréquence lexeme : lemmeFrantext+lemmeFilms
# - fréquence inexistante : .01

# %%
bdlexique["freq"]=1.0/100
filtreLFrantext=(bdlexique["lemmeFrantext"]!="***") 
filtreLFilms=(bdlexique["lemmeFilms"]!="***")
filtreFFrantext=(bdlexique["formeFrantext"]!="***") 
filtreFFilms=(bdlexique["formeFilms"]!="***")
bdlexique.loc[filtreLFrantext|filtreLFilms,"freq"]=bdlexique[filtreLFrantext]["lemmeFrantext"].astype(float)+bdlexique[filtreLFilms]["lemmeFilms"].astype(float)
bdlexique.loc[filtreFFrantext | filtreFFrantext,"freq"]=bdlexique[filtreFFrantext]["formeFrantext"].astype(float)*freqForme+bdlexique[filtreFFilms]["formeFilms"].astype(float)*freqForme

# %% [markdown]
# ###Elimination des colonnes inutiles
# - indicateur L23
# - fréquences brutes

# %%
inutilesColonnes=["L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"]
for colonne in inutilesColonnes:
    del bdlexique[colonne]

# %% [markdown]
# ###Extraction des formes verbales dans une structure *verbes*

# %%
verbes=bdlexique[bdlexique["cs"].isin(["V","K"])].copy()

# %%
verbes["phono"]=verbes["phono"].apply(lambda x: recoder(x))
verbes[(verbes["cs"]=="K") & (verbes["lexeme"]==u"dépendre")]
# Out:
#             ortho   phono  ext cs  ms   vs    lexeme  freq
# 133628    dépendu  dEpâdy  NaN  K  MS  NaN  dépendre  9682
# 133630   dépendue  dEpâdy  NaN  K  FS  NaN  dépendre  9682
# 133631  dépendues  dEpâdy   z"  K  FP  NaN  dépendre  9682
# 133632   dépendus  dEpâdy   z"  K  MP  NaN  dépendre  9682

# %%
verbes.loc[verbes["ms"]=="ij","ms"]="MS"

# %%
verbes[(verbes["cs"]=="K") & (verbes["lexeme"]==u"dépendre")]
# Out:
#             ortho   phono  ext cs  ms   vs    lexeme  freq
# 133628    dépendu  dEpâdy  NaN  K  MS  NaN  dépendre  9682
# 133630   dépendue  dEpâdy  NaN  K  FS  NaN  dépendre  9682
# 133631  dépendues  dEpâdy   z"  K  FP  NaN  dépendre  9682
# 133632   dépendus  dEpâdy   z"  K  MP  NaN  dépendre  9682

# %% [markdown]
# ###Ajout d'une colonne *prob* pour la fréquence relative

# %%
verbes["prob"]=verbes["freq"]/verbes["freq"].sum()

# %% [markdown]
# ###Ajout d'une colonne *case*
# - remplir les *ms* vides pour permettre la concaténation sans erreur
# - remplir les *vs* vides des participes passés par "pp" pour permettre l'identification de la case
# - *case* est la concaténation de *vs* et *ms*

# %%
verbes["ms"]=verbes["ms"].fillna("")
verbes["vs"]=verbes["vs"].fillna("pp")
verbes["case"]=verbes["vs"]+verbes["ms"]

# %% [markdown]
# #Echantillonage

# %% [markdown]
# ##Assembler les échantillons correspondant à une étape n

# %%
def assemblerExtrait(nombre):
    return verbes.ix[np.sort(np.concatenate(tirages[0:nombre]))]

# %% [markdown]
# ###Tirage incrémental des formes disponibles
# - increment : taille de chaque tirage
# - nombre : nombre de tirages
#
# np.random.choice donne une liste d'index de formes tirées dans l'ordre du tirage
#
# on découpe la liste en morceaux de la taille de l'incrément

# %%
if typeEchantillon=="variable":
    tirage=np.random.choice(verbes.index,size=nombre*increment,p=verbes["prob"],replace=False)
    tirages=[tirage[increment*x:increment*(x+1)] for x in range(len(tirage)/increment+(len(tirage)%increment!=0))]
    extrait=assemblerExtrait(nombreInitial)
elif typeEchantillon=="fixe":
    tirage=np.random.choice(verbes.index,size=tailleEchantillon,p=verbes["prob"],replace=False)
    extrait=verbes.ix[np.sort(tirage)]
elif typeEchantillon=="total":
    extrait=verbes

# %%
#extrait=assemblerExtrait(nEchantillons)

# %%
paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

# %%
verbes[verbes["lexeme"]=="rouler"]
# Out:
#               ortho    phono  ext cs  ms   vs  lexeme        freq  \
# 347237        roula     rula  NaN  V  3S   ai  rouler  1259000000
# 347242       roulai     rulE  NaN  V  1S   ai  rouler    43000000
# 347243    roulaient     rulE   t"  V  3P   ii  rouler  1075000000
# 347244      roulais     rulE   z"  V  1S   ii  rouler   364000000
# 347245      roulais     rulE   z"  V  2S   ii  rouler   364000000
# 347246      roulait     rulE   t"  V  3S   ii  rouler  2534000000
# 347248      roulant     rulâ   t"  V       pP  rouler  1353000000
# 347254       roulas     rula   z"  V  2S   ai  rouler       22526
# 347255     roulasse    rulas    @  V  1S   is  rouler       22526
# 347256   roulassent    rulas  @t"  V  3P   is  rouler       22526
# 347257    roulasses    rulas    @  V  2S   is  rouler       22526
# 347258   roulassiez  rulasje   z"  V  2P   is  rouler       22526
# 347259  roulassions  rulasjô   z"  V  1P   is  rouler       22526
# 347260        roule      rul    @  V  1S   pi  rouler  4718000000
# 347261        roule      rul    @  V  1S   ps  rouler       22526
# 347262        roule      rul    @  V  2S   pI  rouler  4718000000
# 347263        roule      rul    @  V  3S   pi  rouler  4718000000
# 347264        roule      rul    @  V  3S   ps  rouler  4718000000
# 347273      roulent      rul  @t"  V  3P   pi  rouler   830000000
# 347274      roulent      rul  @t"  V  3P   ps  rouler       22526
# 347275       rouler     rule   R"  V      inf  rouler  4819000000
# 347276      roulera   rul6ra  NaN  V  3S   fi  rouler    96000000
# 347277     roulerai   rul6rE  NaN  V  1S   fi  rouler    23000000
# 347278  rouleraient   rul6rE   t"  V  3P   pc  rouler    35000000
# 347279    roulerais   rul6rE   z"  V  1S   pc  rouler    24000000
# 347280    roulerais   rul6rE   z"  V  2S   pc  rouler    24000000
# 347281    roulerait   rul6rE   t"  V  3S   pc  rouler   108000000
# 347282     rouleras   rul6ra   z"  V  2S   fi  rouler     7000000
# 347283     roulerez   rul6re   z"  V  2P   fi  rouler    28000000
# 347284    rouleriez  rul6rje   z"  V  2P   pc  rouler     2000000
# 347285   roulerions  rul6rjô   z"  V  1P   pc  rouler       22526
# 347286    roulerons   rul6rô   z"  V  1P   fi  rouler    15000000
# 347287    rouleront   rul6rô   t"  V  3P   fi  rouler    44000000
paradigmes.to_csv(path_or_buf=filePrefix+"-paradigmes.csv",encoding="utf8",sep=";")

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print minLongueur, maxLongueur
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print phonemes
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print forme1,forme2,patron
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print patron12,patron21
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print "patron1", patron
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print "patron2", patron
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print "le numéro de forme n'est pas dans [1,2]",n

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print forme,
                print "pas de classe",idClasseForme,
                print "%.2f par forme de sortie" % (float(1)/len(classeForme))
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print forme, 
            print "pas de patron"
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ##Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for paire in it.combinations_with_replacement(listeCases,2):
        if debug: print paire
#        if paire[0]==paire[1]:
#            paireListe=[paire[0]]
#        else:
#            paireListe=list(paire)
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ###Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
resultats=evaluerEchantillon(paradigmes)
# Out:
# CPU times: user 3h 17min 12s, sys: 55.6 s, total: 3h 18min 8s
# Wall time: 3h 35min 33s

# %%
classesFinales={}
for resultat in resultats:
    classesFinales[resultat]=resultats[resultat][0]
    classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]

# %%
with open(filePrefix+typeEchantillon+'-Regles.pkl', 'wb') as output:
   pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)

# %%
classesFinales[('pi2S', 'pi3P')].sortirForme("aswa")
# Out:
# {u'asEj': 0.5, 'aswa': 0.5}

# %%
with open(filePrefix+typeEchantillon+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %%
resultatsLecture[('fi1P', 'fi2S')].sortirForme(u"kurrô")
# Out:
# {u'kurra': 1.0}

# %%
lexemeTest="asseoir"
paradigmes[paradigmes["lexeme"]==lexemeTest].stack()
# Out:
#      case
# 398  lexeme            asseoir
#      ai1P                 asim
#      ai1S                  asi
#      ai2P                 asit
#      ai2S                  asi
#      ai3P                 asir
#      ai3S                  asi
#      fi1P        asjErô,aswarô
#      fi1S        asjErE,aswarE
#      fi2P        asjEre,asware
#      fi2S        asjEra,aswara
#      fi3P        asjErô,aswarô
#      fi3S        asjEra,aswara
#      ii1P         asEjô,aswajô
#      ii1S         asEjE,aswajE
#      ii2P         asEje,aswaje
#      ii2S         asEjE,aswajE
#      ii3P         asEjE,aswajE
#      ii3S         asEjE,aswajE
#      inf                 aswar
#      is1P               asisjô
#      is1S                 asis
#      is2P               asisje
#      is2S                 asis
#      is3P                 asis
#      is3S                  asi
#      pI1P         asEjô,aswajô
#      pI2P         asEje,aswaje
#      pI2S            asje,aswa
#      pP           asEjâ,aswajâ
#      pc1P      asjErjô,aswarjô
#      pc1S        asjErE,aswarE
#      pc2P      asjErje,aswarje
#      pc2S        asjErE,aswarE
#      pc3P        asjErE,aswarE
#      pc3S        asjErE,aswarE
#      pi1P         asEjô,aswajô
#      pi1S            asje,aswa
#      pi2P         asEje,aswaje
#      pi2S            asje,aswa
#      pi3P            asEj,aswa
#      pi3S            asje,aswa
#      ppFP                 asiz
#      ppFS                 asiz
#      ppMP                  asi
#      ppMS                  asi
#      ps1P         asEjô,aswajô
#      ps1S            asEj,aswa
#      ps2P         asEje,aswaje
#      ps2S            asEj,aswa
#      ps3P            asEj,aswa
#      ps3S            asEj,aswa
# dtype: object

# %%
# %%time
for forme in listeCases:
    if not pd.isnull(paradigmes[paradigmes["lexeme"]==lexemeTest][forme].iloc[0]):
        depart=paradigmes[paradigmes["lexeme"]==lexemeTest][forme].iloc[0]
        print forme,depart
        if depart!="nan":
            for case in listeCases:
                print case,
                if not isinstance(resultatsLecture[(forme, case)],str):
                    print resultatsLecture[(forme, case)].sortirForme(depart),
            print
            print
# Out:
# inf aswar
# inf {u'aswar': 1.0} pi1S {u'aswa': 0.5, u'asje': 0.5} pi2S {u'aswa': 0.5, u'asje': 0.5} pi3S {u'aswa': 0.42857142857142855, u'asje': 0.5714285714285714} pi1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} pi2P {u'aswaje': 0.5, u'asEje': 0.5} pi3P aswar pas de classe war-Ej, war-je, r- 0.33 par forme de sortie
# {u'aswa': 0.3333333333333333, u'asEj': 0.3333333333333333, u'asje': 0.3333333333333333} ii1S {u'aswajE': 0.5, u'asEjE': 0.5} ii2S {u'aswajE': 0.5, u'asEjE': 0.5} ii3S {u'aswajE': 0.42857142857142855, u'asEjE': 0.5714285714285714} ii1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ii2P {u'aswaje': 0.5, u'asEje': 0.5} ii3P {u'aswajE': 0.42857142857142855, u'asEjE': 0.5714285714285714} fi1S {u'aswarE': 0.5, u'asjErE': 0.5} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.42857142857142855, u'asjEra': 0.5714285714285714} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P {u'asware': 0.5, u'asjEre': 0.5} fi3P {u'aswar\xf4': 0.42857142857142855, u'asjEr\xf4': 0.5714285714285714} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} pI2P {u'aswaje': 0.5, u'asEje': 0.5} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S aswar pas de classe war-Ej, war-je, r- 0.33 par forme de sortie
# {u'aswa': 0.3333333333333333, u'asEj': 0.3333333333333333, u'asje': 0.3333333333333333} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P {u'aswaje': 0.5, u'asEje': 0.5} ps3P aswar pas de classe war-Ej, war-je, r- 0.33 par forme de sortie
# {u'aswa': 0.3333333333333333, u'asEj': 0.3333333333333333, u'asje': 0.3333333333333333} pc1S {u'aswarE': 0.5, u'asjErE': 0.5} pc2S {u'aswarE': 0.5, u'asjErE': 0.5} pc3S {u'aswarE': 0.42857142857142855, u'asjErE': 0.5714285714285714} pc1P {u'asjErj\xf4': 0.5, u'aswarj\xf4': 0.5} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P {u'aswarE': 0.42857142857142855, u'asjErE': 0.5714285714285714} pP {u'asEj\xe2': 0.375, u'asE\xe2': 0.25, u'aswaj\xe2': 0.375} ppMS {u'asi': 1.0} ppMP aswar pas de classe war-y, war-i 0.50 par forme de sortie
# inf {u'asEje,aswaje': 0.8865979381443299, u'asEje,aswar': 0.1134020618556701} pi1S asEje,aswaje pas de classe e-, waje-je, je- 0.33 par forme de sortie
# {u'asEje,aswaj': 0.3333333333333333, u'asEje,aswa': 0.3333333333333333, u'asEje,asje': 0.3333333333333333} pi2S asEje,aswaje pas de classe e-, waje-je, je- 0.33 par forme de sortie
# {u'asEje,aswaj': 0.3333333333333333, u'asEje,aswa': 0.3333333333333333, u'asEje,asje': 0.3333333333333333} pi3S asEje,aswaje pas de classe e-, waje-je, je- 0.33 par forme de sortie
# ...
# {u'aswaj\xf4': 0.25, u'asizj\xf4': 0.25, u'asisj\xf4': 0.25, u'asEj\xf4': 0.25} ii2P {u'aswaje': 0.5, u'asEje': 0.5} ii3P {u'aswajE': 0.5, u'asEjE': 0.5} fi1S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.5, u'asjEra': 0.5} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P asis pas de classe s-re, is-ware, is-jEre 0.33 par forme de sortie
# {u'asware': 0.3333333333333333, u'asjEre': 0.3333333333333333, u'asire': 0.3333333333333333} fi3P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P asis pas de classe is-Ejô, -ô, s-zô, is-wajô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pI2P {u'aswaje': 0.5, u'asEje': 0.5} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S {u'aswa': 0.5, u'asEj': 0.5} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P {u'aswaje': 0.5, u'asEje': 0.5} ps3P {u'aswa': 0.5, u'asEj': 0.5} pc1S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc2S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc3S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc1P {u'asjErj\xf4': 0.5, u'aswarj\xf4': 0.5} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pP {u'asEj\xe2': 0.5, u'aswaj\xe2': 0.5} ppMS {u'asy': 0.2459546925566343, u'asi': 0.7540453074433657} ppMP {u'asy': 0.2647058823529412, u'asi': 0.7352941176470589} ppFS asis pas de classe is-y, s-t, s-z, s- 0.25 par forme de sortie
# {u'asi': 0.25, u'asy': 0.25, u'asit': 0.25, u'asiz': 0.25} ppFP asis pas de classe is-y, s-t, s-z, s- 0.25 par forme de sortie
# {u'asi': 0.25, u'asy': 0.25, u'asit': 0.25, u'asiz': 0.25} ai1S {u'asi': 1.0} ai2S {u'asi': 1.0} ai3S {u'asi': 1.0} ai1P {u'asim': 1.0} ai2P {u'asit': 1.0} ai3P {u'asir': 1.0} is1S {u'asis': 1.0} is2S {u'asis': 1.0} is3S {u'asi': 1.0} is1P {u'asisj\xf4': 1.0} is2P {u'asisje': 1.0} is3P {u'asis': 1.0}
#
# is2S asis
# inf {u'aswar': 0.2, u'asir': 0.8} pi1S {u'aswa': 0.5, u'asje': 0.5} pi2S {u'aswa': 0.5, u'asje': 0.5} pi3S {u'aswa': 0.5, u'asje': 0.5} pi1P asis pas de classe is-wajô, is-Ejô, -ô, s-zô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pi2P {u'aswaje': 0.5, u'asEje': 0.5} pi3P {u'aswa': 0.5, u'asEj': 0.5} ii1S {u'aswajE': 0.5, u'asEjE': 0.5} ii2S {u'aswajE': 0.5, u'asEjE': 0.5} ii3S {u'aswajE': 0.5, u'asEjE': 0.5} ii1P asis pas de classe is-wajô, is-Ejô, -jô, s-zjô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asizj\xf4': 0.25, u'asisj\xf4': 0.25, u'asEj\xf4': 0.25} ii2P {u'aswaje': 0.5, u'asEje': 0.5} ii3P {u'aswajE': 0.5, u'asEjE': 0.5} fi1S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.5, u'asjEra': 0.5} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P asis pas de classe s-re, is-ware, is-jEre 0.33 par forme de sortie
# {u'asware': 0.3333333333333333, u'asjEre': 0.3333333333333333, u'asire': 0.3333333333333333} fi3P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P asis pas de classe is-Ejô, -ô, s-zô, is-wajô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pI2P {u'aswaje': 0.5, u'asEje': 0.5} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S {u'aswa': 0.5, u'asEj': 0.5} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P {u'aswaje': 0.5, u'asEje': 0.5} ps3P {u'aswa': 0.5, u'asEj': 0.5} pc1S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc2S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc3S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc1P {u'asjErj\xf4': 0.5, u'aswarj\xf4': 0.5} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pP {u'asEj\xe2': 0.5, u'aswaj\xe2': 0.5} ppMS {u'asy': 0.2459546925566343, u'asi': 0.7540453074433657} ppMP {u'asy': 0.2647058823529412, u'asi': 0.7352941176470589} ppFS asis pas de classe is-y, s-t, s-z, s- 0.25 par forme de sortie
# {u'asi': 0.25, u'asy': 0.25, u'asit': 0.25, u'asiz': 0.25} ppFP asis pas de classe is-y, s-t, s-z, s- 0.25 par forme de sortie
# {u'asi': 0.25, u'asy': 0.25, u'asit': 0.25, u'asiz': 0.25} ai1S {u'asi': 1.0} ai2S {u'asi': 1.0} ai3S {u'asi': 1.0} ai1P {u'asim': 1.0} ai2P {u'asit': 1.0} ai3P {u'asir': 1.0} is1S {u'asis': 1.0} is2S {u'asis': 1.0} is3S {u'asi': 1.0} is1P {u'asisj\xf4': 1.0} is2P {u'asisje': 1.0} is3P {u'asis': 1.0}
#
# is3S asi
# inf {u'aswar': 0.2, u'asir': 0.8} pi1S asi pas de classe -, i-je, i-wa 0.33 par forme de sortie
# {u'aswa': 0.3333333333333333, u'asi': 0.3333333333333333, u'asje': 0.3333333333333333} pi2S asi pas de classe -, i-je, i-wa 0.33 par forme de sortie
# {u'aswa': 0.3333333333333333, u'asi': 0.3333333333333333, u'asje': 0.3333333333333333} pi3S asi pas de classe -, i-je, i-wa 0.33 par forme de sortie
# {u'aswa': 0.3333333333333333, u'asi': 0.3333333333333333, u'asje': 0.3333333333333333} pi1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} pi2P {u'aswaje': 0.5, u'asEje': 0.5} pi3P {u'aswa': 0.5, u'asEj': 0.5} ii1S {u'aswajE': 0.5, u'asEjE': 0.5} ii2S {u'aswajE': 0.5, u'asEjE': 0.5} ii3S {u'aswajE': 0.5, u'asEjE': 0.5} ii1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ii2P {u'aswaje': 0.5, u'asEje': 0.5} ii3P {u'aswajE': 0.5, u'asEjE': 0.5} fi1S {u'aswarE': 0.5, u'asjErE': 0.5} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.5, u'asjEra': 0.5} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P {u'asware': 0.5, u'asjEre': 0.5} fi3P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} pI2P {u'aswaje': 0.5, u'asEje': 0.5} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S {u'aswa': 0.5, u'asEj': 0.5} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P {u'aswaje': 0.5, u'asEje': 0.5} ps3P {u'aswa': 0.5, u'asEj': 0.5} pc1S {u'aswarE': 0.5, u'asjErE': 0.5} pc2S {u'aswarE': 0.5, u'asjErE': 0.5} pc3S {u'aswarE': 0.5, u'asjErE': 0.5} pc1P asi pas de classe i-jErjô, i-warjô, -rjô 0.33 par forme de sortie
# {u'asirj\xf4': 0.3333333333333333, u'asjErj\xf4': 0.3333333333333333, u'aswarj\xf4': 0.3333333333333333} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P {u'aswarE': 0.5, u'asjErE': 0.5} pP {u'asEj\xe2': 0.5, u'aswaj\xe2': 0.5} ppMS {u'asy': 0.24516129032258063, u'asi': 0.7548387096774194} ppMP {u'asy': 0.26373626373626374, u'asi': 0.7362637362637363} ppFS {u'asy': 0.2916666666666667, u'asit': 0.029166666666666667, u'asi': 0.6625, u'asiz': 0.016666666666666666} ppFP {u'asy': 0.2916666666666667, u'asit': 0.029166666666666667, u'asi': 0.6625, u'asiz': 0.016666666666666666} ai1S {u'asi': 1.0} ai2S {u'asi': 1.0} ai3S {u'asi': 1.0} ai1P {u'asim': 1.0} ai2P {u'asit': 1.0} ai3P {u'asir': 1.0} is1S {u'asis': 1.0} is2S {u'asis': 1.0} is3S {u'asi': 1.0} is1P {u'asisj\xf4': 1.0} is2P {u'asisje': 1.0} is3P {u'asis': 1.0}
#
# is1P asisjô
# inf {u'aswar': 0.2, u'asir': 0.8} pi1S {u'aswa': 0.5, u'asje': 0.5} pi2S {u'aswa': 0.5, u'asje': 0.5} pi3S {u'aswa': 0.5, u'asje': 0.5} pi1P asisjô pas de classe is..-wa.., isjô-Ejô, jô-ô, sjô-zô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pi2P {u'aswaje': 0.5, u'asEje': 0.5} pi3P {u'aswa': 0.5, u'asEj': 0.5} ii1S {u'aswajE': 0.5, u'asEjE': 0.5} ii2S {u'aswajE': 0.5, u'asEjE': 0.5} ii3S {u'aswajE': 0.5, u'asEjE': 0.5} ii1P asisjô pas de classe is..-wa.., -, isjô-Ejô, s..-z.. 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asizj\xf4': 0.25, u'asisj\xf4': 0.25, u'asEj\xf4': 0.25} ii2P asisjô pas de classe is.ô-wa.e, ô-e, s.ô-z.e, isjô-Eje 0.25 par forme de sortie
# {u'asizje': 0.25, u'aswaje': 0.25, u'asisje': 0.25, u'asEje': 0.25} ii3P {u'aswajE': 0.5, u'asEjE': 0.5} fi1S {u'aswarE': 0.5, u'asjErE': 0.5} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.5, u'asjEra': 0.5} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P {u'asware': 0.5, u'asjEre': 0.5} fi3P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P asisjô pas de classe is..-wa.., isjô-Ejô, sjô-zô, jô-ô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pI2P asisjô pas de classe is.ô-wa.e, jô-e, isjô-Eje 0.33 par forme de sortie
# {u'asise': 0.3333333333333333, u'aswaje': 0.3333333333333333, u'asEje': 0.3333333333333333} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S {u'aswa': 0.5, u'asEj': 0.5} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P asisjô pas de classe ô-e, is.ô-wa.e, s.ô-z.e, isjô-Eje 0.25 par forme de sortie
# {u'asizje': 0.25, u'aswaje': 0.25, u'asisje': 0.25, u'asEje': 0.25} ps3P {u'aswa': 0.5, u'asEj': 0.5} pc1S {u'aswarE': 0.5, u'asjErE': 0.5} pc2S {u'aswarE': 0.5, u'asjErE': 0.5} pc3S {u'aswarE': 0.5, u'asjErE': 0.5} pc1P asisjô pas de classe s..-r.., isjô-jErjô, isjô-warjô 0.33 par forme de sortie
# {u'asirj\xf4': 0.3333333333333333, u'asjErj\xf4': 0.3333333333333333, u'aswarj\xf4': 0.3333333333333333} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P {u'aswarE': 0.5, u'asjErE': 0.5} pP {u'asEj\xe2': 0.5, u'aswaj\xe2': 0.5} ppMS {u'asi': 0.7540453074433657, u'asy': 0.2459546925566343} ppMP {u'asi': 0.7352941176470589, u'asy': 0.2647058823529412} ppFS {u'asy': 0.2928870292887029, u'asi': 0.6610878661087866, u'asit': 0.029288702928870293, u'asiz': 0.016736401673640166} ppFP asisjô pas de classe sjô-, sjô-t, sjô-z, isjô-y 0.25 par forme de sortie
# {u'asy': 0.25, u'asi': 0.25, u'asit': 0.25, u'asiz': 0.25} ai1S {u'asi': 1.0} ai2S {u'asi': 1.0} ai3S {u'asi': 1.0} ai1P {u'asim': 1.0} ai2P {u'asit': 1.0} ai3P {u'asir': 1.0} is1S {u'asis': 1.0} is2S {u'asis': 1.0} is3S {u'asi': 1.0} is1P {u'asisj\xf4': 1.0} is2P {u'asisje': 1.0} is3P {u'asis': 1.0}
#
# is2P asisje
# inf {u'aswar': 0.2, u'asir': 0.8} pi1S {u'aswa': 0.5, u'asje': 0.5} pi2S {u'aswa': 0.5, u'asje': 0.5} pi3S {u'aswa': 0.5, u'asje': 0.5} pi1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} pi2P {u'aswaje': 0.5, u'asEje': 0.5} pi3P {u'aswa': 0.5, u'asEj': 0.5} ii1S {u'aswajE': 0.5, u'asEjE': 0.5} ii2S {u'aswajE': 0.5, u'asEjE': 0.5} ii3S {u'aswajE': 0.5, u'asEjE': 0.5} ii1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ii2P {u'aswaje': 0.5, u'asEje': 0.5} ii3P {u'aswajE': 0.5, u'asEjE': 0.5} fi1S {u'aswarE': 0.5, u'asjErE': 0.5} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.5, u'asjEra': 0.5} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P {u'asware': 0.5, u'asjEre': 0.5} fi3P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} pI2P {u'aswaje': 0.5, u'asEje': 0.5} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S {u'aswa': 0.5, u'asEj': 0.5} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P {u'aswaje': 0.5, u'asEje': 0.5} ps3P {u'aswa': 0.5, u'asEj': 0.5} pc1S {u'aswarE': 0.5, u'asjErE': 0.5} pc2S {u'aswarE': 0.5, u'asjErE': 0.5} pc3S {u'aswarE': 0.5, u'asjErE': 0.5} pc1P {u'asjErj\xf4': 0.5, u'aswarj\xf4': 0.5} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P {u'aswarE': 0.5, u'asjErE': 0.5} pP {u'asEj\xe2': 0.5, u'aswaj\xe2': 0.5} ppMS {u'asy': 0.2459546925566343, u'asi': 0.7540453074433657} ppMP {u'asy': 0.2647058823529412, u'asi': 0.7352941176470589} ppFS {u'asi': 0.6610878661087866, u'asy': 0.2928870292887029, u'asit': 0.029288702928870293, u'asiz': 0.016736401673640166} ppFP {u'asi': 0.6610878661087866, u'asy': 0.2928870292887029, u'asit': 0.029288702928870293, u'asiz': 0.016736401673640166} ai1S {u'asi': 1.0} ai2S {u'asi': 1.0} ai3S {u'asi': 1.0} ai1P {u'asim': 1.0} ai2P {u'asit': 1.0} ai3P {u'asir': 1.0} is1S {u'asis': 1.0} is2S {u'asis': 1.0} is3S {u'asi': 1.0} is1P {u'asisj\xf4': 1.0} is2P {u'asisje': 1.0} is3P {u'asis': 1.0}
#
# is3P asis
# inf {u'aswar': 0.2, u'asir': 0.8} pi1S {u'aswa': 0.5, u'asje': 0.5} pi2S {u'aswa': 0.5, u'asje': 0.5} pi3S {u'aswa': 0.5, u'asje': 0.5} pi1P asis pas de classe is-wajô, is-Ejô, -ô, s-zô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pi2P {u'aswaje': 0.5, u'asEje': 0.5} pi3P {u'aswa': 0.5, u'asEj': 0.5} ii1S {u'aswajE': 0.5, u'asEjE': 0.5} ii2S {u'aswajE': 0.5, u'asEjE': 0.5} ii3S {u'aswajE': 0.5, u'asEjE': 0.5} ii1P asis pas de classe is-wajô, is-Ejô, -jô, s-zjô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asizj\xf4': 0.25, u'asisj\xf4': 0.25, u'asEj\xf4': 0.25} ii2P {u'aswaje': 0.5, u'asEje': 0.5} ii3P {u'aswajE': 0.5, u'asEjE': 0.5} fi1S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} fi2S {u'aswara': 0.5, u'asjEra': 0.5} fi3S {u'aswara': 0.5, u'asjEra': 0.5} fi1P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} fi2P asis pas de classe s-re, is-ware, is-jEre 0.33 par forme de sortie
# {u'asware': 0.3333333333333333, u'asjEre': 0.3333333333333333, u'asire': 0.3333333333333333} fi3P {u'aswar\xf4': 0.5, u'asjEr\xf4': 0.5} pI2S {u'aswa': 0.5, u'asje': 0.5} pI1P asis pas de classe is-Ejô, -ô, s-zô, is-wajô 0.25 par forme de sortie
# {u'aswaj\xf4': 0.25, u'asis\xf4': 0.25, u'asiz\xf4': 0.25, u'asEj\xf4': 0.25} pI2P {u'aswaje': 0.5, u'asEje': 0.5} ps1S {u'aswa': 0.5, u'asEj': 0.5} ps2S {u'aswa': 0.5, u'asEj': 0.5} ps3S {u'aswa': 0.5, u'asEj': 0.5} ps1P {u'aswaj\xf4': 0.5, u'asEj\xf4': 0.5} ps2P {u'aswaje': 0.5, u'asEje': 0.5} ps3P {u'aswa': 0.5, u'asEj': 0.5} pc1S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc2S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc3S asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pc1P {u'asjErj\xf4': 0.5, u'aswarj\xf4': 0.5} pc2P {u'aswarje': 0.5, u'asjErje': 0.5} pc3P asis pas de classe s-rE, is-warE, is-jErE 0.33 par forme de sortie
# {u'aswarE': 0.3333333333333333, u'asjErE': 0.3333333333333333, u'asirE': 0.3333333333333333} pP {u'asEj\xe2': 0.5, u'aswaj\xe2': 0.5} ppMS {u'asy': 0.24516129032258063, u'asi': 0.7548387096774194} ppMP {u'asy': 0.26373626373626374, u'asi': 0.7362637362637363} ppFS asis pas de classe is-y, s-t, s-z, s- 0.25 par forme de sortie
# {u'asi': 0.25, u'asy': 0.25, u'asit': 0.25, u'asiz': 0.25} ppFP asis pas de classe is-y, s-t, s-z, s- 0.25 par forme de sortie
# {u'asi': 0.25, u'asy': 0.25, u'asit': 0.25, u'asiz': 0.25} ai1S {u'asi': 1.0} ai2S {u'asi': 1.0} ai3S {u'asi': 1.0} ai1P {u'asim': 1.0} ai2P {u'asit': 1.0} ai3P {u'asir': 1.0} is1S {u'asis': 1.0} is2S {u'asis': 1.0} is3S {u'asi': 1.0} is1P {u'asisj\xf4': 1.0} is2P {u'asisje': 1.0} is3P {u'asis': 1.0}
#
# CPU times: user 2.38 s, sys: 247 ms, total: 2.63 s
# Wall time: 2.65 s

# %%
verbes[verbes["lexeme"]==u"balayer"]
# Out:
#               ortho      phono  ext cs  ms  vs   lexeme       freq  \
# 34659        balaie       balE  NaN  V  1S  pi  balayer  483000000
# 34660        balaie       balE  NaN  V  1S  ps  balayer       4960
# 34661        balaie       balE  NaN  V  2S  pI  balayer  483000000
# 34662        balaie       balE  NaN  V  3S  pi  balayer  483000000
# 34663        balaie       balE  NaN  V  3S  ps  balayer       4960
# 34664      balaient       balE   t"  V  3P  pi  balayer  121000000
# 34665      balaient       balE   t"  V  3P  ps  balayer       4960
# 34666      balaiera     balEra  NaN  V  3S  fi  balayer   52000000
# 34667     balaierai     balErE  NaN  V  1S  fi  balayer   28000000
# 34668  balaieraient     balErE   t"  V  3P  pc  balayer    7000000
# 34669    balaierais     balErE   z"  V  1S  pc  balayer       4960
# 34670    balaierais     balErE   z"  V  2S  pc  balayer       4960
# 34671    balaierait     balErE   t"  V  3S  pc  balayer   22000000
# 34672     balaieras     balEra   z"  V  2S  fi  balayer    2000000
# 34673     balaierez     balEre   z"  V  2P  fi  balayer    7000000
# 34674    balaieriez    balErje   z"  V  2P  pc  balayer       4960
# 34675   balaierions    balErjô   z"  V  1P  pc  balayer       4960
# 34676    balaierons     balErô   z"  V  1P  fi  balayer       4960
# 34677    balaieront     balErô   t"  V  3P  fi  balayer       4960
# 34678       balaies       balE  NaN  V  2S  pi  balayer   38000000
# 34679       balaies       balE  NaN  V  2S  ps  balayer       4960
# 34758        balaya     balEja  NaN  V  3S  ai  balayer  252000000
# 34761       balayai     balEjE  NaN  V  1S  ai  balayer    7000000
# 34762    balayaient     balEjE   t"  V  3P  ii  balayer  229000000
# 34763      balayais     balEjE   z"  V  1S  ii  balayer   25000000
# 34764      balayais     balEjE   z"  V  2S  ii  balayer   25000000
# 34765      balayait     balEjE   t"  V  3S  ii  balayer  535000000
# 34766      balayant     balEjâ   t"  V      pP  balayer  354000000
# 34767       balayas     balEja   z"  V  2S  ai  balayer       4960
# 34763  5.158969e-07  ii1S
# 34764  5.158969e-07  ii2S
# 34765  1.104019e-05  ii3S
# 34766  7.305100e-06    pP
# 34767  1.023539e-10  ai2S
# 34768  1.023539e-10  is1S
# ...             ...   ...
# 34781  1.650870e-07  fi3S
# 34782  2.476305e-07  fi1S
# 34783  1.444511e-07  pc3P
# 34784  1.023539e-10  pc1S
# 34785  1.023539e-10  pc2S
# 34786  2.269946e-07  pc3S
# 34787  1.023539e-10  fi2S
# 34788  1.650870e-07  fi2P
# 34789  1.023539e-10  pc2P
# 34790  1.023539e-10  pc1P
# 34791  2.063588e-08  fi1P
# 34792  6.190763e-08  fi3P
# 34793  1.023539e-10  pi2S
# 34794  1.023539e-10  ps2S
# 34803  1.382604e-06  pI2P
# 34804  1.382604e-06  pi2P
# 34805  1.023539e-10  ii2P
# 34806  1.023539e-10  ps2P
# 34807  1.023539e-10  ii1P
# 34808  1.023539e-10  ps1P
# 34809  2.476305e-07  pI1P
# 34810  1.023539e-10  pi1P
# 34812  1.023539e-10  ai1P
# 34813  2.889023e-07  is3S
# 34814  1.023539e-10  ai2P
# 34815  8.460709e-07  ai3P
# 34816  1.023539e-10  ppMS
# 34817  1.023539e-10  ppFS
# 34818  1.023539e-10  ppFP
# 34819  1.023539e-10  ppMP
#
# [72 rows x 10 columns]

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 333819

# %%
#paradigmes[paradigmes["lexeme"]==u"cuire"].stack().value_counts(dropna=True).sum()
paradigmes[paradigmes["lexeme"]==u"dépendre"].stack()
# Out:
#       case
# 2039  lexeme     dépendre
#       ai1P        dEpâdim
#       ai1S         dEpâdi
#       ai2P        dEpâdit
#       ai2S         dEpâdi
#       ai3P        dEpâdir
#       ai3S         dEpâdi
#       fi1P        dEpâdrô
#       fi1S        dEpâdrE
#       fi2P        dEpâdre
#       fi2S        dEpâdra
#       fi3P        dEpâdrô
#       fi3S        dEpâdra
#       ii1P        dEpâdjô
#       ii1S         dEpâdE
#       ii2P        dEpâdje
#       ii2S         dEpâdE
#       ii3P         dEpâdE
#       ii3S         dEpâdE
#       inf          dEpâdr
#       is1P      dEpâdisjô
#       is1S        dEpâdis
#       is2P      dEpâdisje
#       is2S        dEpâdis
#       is3P        dEpâdis
#       is3S         dEpâdi
#       pI1P         dEpâdô
#       pI2P         dEpâde
#       pI2S           dEpâ
#       pP           dEpâdâ
#       pc1P       dEpâdriô
#       pc1S        dEpâdrE
#       pc2P       dEpâdrie
#       pc2S        dEpâdrE
#       pc3P        dEpâdrE
#       pc3S        dEpâdrE
#       pi1P         dEpâdô
#       pi1S           dEpâ
#       pi2P         dEpâde
#       pi2S           dEpâ
#       pi3P          dEpâd
#       pi3S           dEpâ
#       ppFP         dEpâdy
#       ppFS         dEpâdy
#       ppMP         dEpâdy
#       ppMS         dEpâdy
#       ps1P        dEpâdjô
#       ps1S          dEpâd
#       ps2P        dEpâdje
#       ps2S          dEpâd
#       ps3P          dEpâd
#       ps3S          dEpâd
# dtype: object

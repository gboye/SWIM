# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import re
import csv
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
debug=0

# %% [markdown]
# #Préparation du lexique

# %% [markdown]
# ###Lecture des lexiques

# %%
nomLexique="/Users/gilles/Copy/Python/phonemisation/bdlexique-PDM.txt"
with codecs.open(nomLexique, 'r',encoding='utf8') as infile:
    bdlexique=infile.readlines()
for ligne in bdlexique[:5]:
    (ortho,phono,ext,cs,ms,vs,lexeme,L23,lemmeFrantext,lemmeFilms,formeFrantext,formeFilms)=ligne.strip().split(";")
    print ortho,cs,ms,vs,lexeme,lemmeFrantext,lemmeFilms,formeFrantext,formeFilms
# Out:
# a N Mj  a 8136 5865 8136 5865
# à p   à 1219040 1920905 1219040 1920905
# abaca N MS  abaca 1 0 1 0
# abacas N MP  abaca *** *** *** ***
# abacule N MS  abacule *** *** *** ***

# %%
nomLexiqueOrg="/Users/gilles/Copy/Python/phonemisation/Lexique380-UTF8.txt"
verbes={}
vlemmes={}
noms={}
nlemmes={}
adjectifs={}
alemmes={}
with codecs.open(nomLexiqueOrg, 'r',encoding='utf8') as infile:
    lexiqueorg=infile.readlines()
for ligne in lexiqueorg[1:]:
    morceaux=ligne.strip().split("\t")
    (ortho,phon,lemme,cgram,genre,nombre,freqlemfilms2,freqlemlivres,freqfilms2,freqlivres,infover)=morceaux[:11]
    freqlemfilms2=str(int(100*float(freqlemfilms2)))
    freqlemlivres=str(int(100*float(freqlemlivres)))
    freqfilms2=str(int(100*float(freqfilms2)))
    freqlivres=str(int(100*float(freqlivres)))
    if cgram=="NOM":
        vs=genre.upper()+nombre.upper()
        nom=";".join([ortho,lemme,vs])
        noms[nom]=(freqlemfilms2,freqlemlivres,freqfilms2,freqlivres)
        if not lemme in nlemmes:
            nlemmes[lemme]=(freqlemfilms2,freqlemlivres)
#        print nom, noms[nom]
    elif cgram=="ADJ":
        vs=genre.upper()+nombre.upper()
        adjectif=";".join([ortho,lemme,vs])
        adjectifs[adjectif]=(freqlemfilms2,freqlemlivres,freqfilms2,freqlivres)
        if not lemme in alemmes:
            alemmes[lemme]=(freqlemfilms2,freqlemlivres)
#        print adjectif, adjectifs[adjectif]
    elif cgram=="VER":
#        print ortho,lemme,genre,nombre,infover
        if infover=="ind:pre:2p;inf;":
            infover="inf;"
        tams=infover.rstrip(";").split(";")
        for tam in tams:
            morceaux=tam.split(":")
#            print morceaux
            if len(morceaux)==3:
                if morceaux[0]=="imp":
                    mode="I"
                else:
                    mode=morceaux[0][0]
                if morceaux[1]=="pas":
                    temps="a"
                else:
                    temps=morceaux[1][0]
                infotam=temps+mode+morceaux[2].upper()
            elif len(morceaux)==2:
                if morceaux[1]=="pre":
                    infotam=morceaux[0][0]+"P"
                elif morceaux[1]=="pas":
                    infotam="pp"+genre.upper()+nombre.upper()
            elif len(morceaux)==1:
                infotam=morceaux[0]
            verbe=";".join([ortho,lemme,infotam])
 #           print verbe
            verbes[verbe]=(freqlemfilms2,freqlemlivres,freqfilms2,freqlivres)
            if not lemme in vlemmes:
                vlemmes[lemme]=(freqlemfilms2,freqlemlivres)
#            print verbe, verbes[verbe]

# %%
resync=[]
for ligne in bdlexique[:]:
    nouvelleLigne=ligne.strip()
    try :
        (ortho,phono,ext,cs,ms,vs,lexeme,L23,lemmeFrantext,lemmeFilms,formeFrantext,formeFilms)=ligne.strip().split(";")
    except ValueError:
        print ligne
#    print ortho, lexeme, lemmeFrantext,lemmeFilms,formeFrantext,formeFilms
    if lexeme[-1] in "1234":
        lexeme=lexeme[:-1]
    if lexeme in [u"XXX"]: 
        debug=1
    else:
        debug=0
    if cs in ["V","K"]:
        if cs=="K": vs="pp"
        verbe=";".join([ortho,lexeme,vs+ms])
        if verbe in verbes:
            if lemmeFrantext!=verbes[verbe][0] and lemmeFilms!=verbes[verbe][1] and formeFrantext!=verbes[verbe][2] and formeFilms!=verbes[verbe][3]:
                if debug: print "different"
                if debug: print verbe, verbes[verbe]
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,verbes[verbe][0],verbes[verbe][1],verbes[verbe][2],verbes[verbe][3]])
        elif lexeme in vlemmes:
            if debug: print vlemmes[lexeme]
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,vlemmes[lexeme][0],vlemmes[lexeme][1],"***","***"])
        else:
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,"***","***","***","***"])
    elif cs in ["G","H","I","J"]:
        adjectif=";".join([ortho,lexeme,ms])
        if adjectif in adjectifs:
#            print adjectifs[adjectif]
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,adjectifs[adjectif][0],adjectifs[adjectif][1],adjectifs[adjectif][2],adjectifs[adjectif][3]])
        elif lexeme in alemmes:
#            print alemmes[lexeme]
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,alemmes[lexeme][0],alemmes[lexeme][1],formeFrantext,formeFilms])
    elif cs in ["N"]:
        nom=";".join([ortho,lexeme,ms])
        if nom in noms:
#            print noms[nom]
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,noms[nom][0],noms[nom][1],noms[nom][2],noms[nom][3]])
        elif lexeme in nlemmes:
#            print nlemmes[lexeme]
            nouvelleLigne=";".join([ortho,phono,ext,cs,ms,vs,lexeme,L23,nlemmes[lexeme][0],nlemmes[lexeme][1],formeFrantext,formeFilms])
    if debug: print [ortho, nouvelleLigne]
    resync.append(nouvelleLigne)
# Out:
# [u'd\xe9pendre', u'd\xe9pendre;d\xe8p\xe2dr;@;V;;inf;d\xe9pendre;L23;6033;3649;246;284']
# [u'd\xe9pends', u'd\xe9pends;d\xe8p\xe2;z";V;1S;pi;d\xe9pendre;L23;6033;3649;118;20']
# [u'd\xe9pends', u'd\xe9pends;d\xe8p\xe2;z";V;2S;pi;d\xe9pendre;L23;6033;3649;118;20']
# [u'd\xe9pend', u'd\xe9pend;d\xe8p\xe2;t";V;3S;pi;d\xe9pendre;L23;6033;3649;4830;1520']
# [u'd\xe9pendons', u'd\xe9pendons;d\xe8p\xe2d\xf4;z";V;1P;pi;d\xe9pendre;L23;6033;3649;43;20']
# [u'd\xe9pendez', u'd\xe9pendez;d\xe8p\xe2de;z";V;2P;pi;d\xe9pendre;L23;6033;3649;25;0']
# [u'd\xe9pendent', u'd\xe9pendent;d\xe8p\xe2d;@t";V;3P;pi;d\xe9pendre;L23;6033;3649;264;209']
# [u'd\xe9pendais', u'd\xe9pendais;d\xe8p\xe2d\xe8;z";V;1S;ii;d\xe9pendre;L23;6033;3649;4;34']
# [u'd\xe9pendais', u'd\xe9pendais;d\xe8p\xe2d\xe8;z";V;2S;ii;d\xe9pendre;L23;6033;3649;4;34']
# [u'd\xe9pendait', u'd\xe9pendait;d\xe8p\xe2d\xe8;t";V;3S;ii;d\xe9pendre;L23;6033;3649;187;764']
# [u'd\xe9pendions', u'd\xe9pendions;d\xe8p\xe2dj\xf4;z";V;1P;ii;d\xe9pendre;L23;6033;3649;1;7']
# ('6033', '3649')
# [u'd\xe9pendiez', u'd\xe9pendiez;d\xe8p\xe2dje;z";V;2P;ii;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendaient', u'd\xe9pendaient;d\xe8p\xe2d\xe8;t";V;3P;ii;d\xe9pendre;L23;6033;3649;13;176']
# ('6033', '3649')
# [u'd\xe9pendis', u'd\xe9pendis;d\xe8p\xe2di;z";V;1S;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendis', u'd\xe9pendis;d\xe8p\xe2di;z";V;2S;ai;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendit', u'd\xe9pendit;d\xe8p\xe2di;t";V;3S;ai;d\xe9pendre;L23;6033;3649;0;7']
# ('6033', '3649')
# [u'd\xe9pend\xeemes', u'd\xe9pend\xeemes;d\xe8p\xe2dim;@z";V;1P;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pend\xeetes', u'd\xe9pend\xeetes;d\xe8p\xe2dit;@z";V;2P;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendirent', u'd\xe9pendirent;d\xe8p\xe2dir;@t";V;3P;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendrai', u'd\xe9pendrai;d\xe8p\xe2dr\xe8;;V;1S;fi;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendras', u'd\xe9pendras;d\xe8p\xe2dra;z";V;2S;fi;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendra', u'd\xe9pendra;d\xe8p\xe2dra;;V;3S;fi;d\xe9pendre;L23;6033;3649;204;122']
# ('6033', '3649')
# [u'd\xe9pendrons', u'd\xe9pendrons;d\xe8p\xe2dr\xf4;z";V;1P;fi;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendrez', u'd\xe9pendrez;d\xe8p\xe2dre;z";V;2P;fi;d\xe9pendre;L23;6033;3649;1;14']
# [u'd\xe9pendront', u'd\xe9pendront;d\xe8p\xe2dr\xf4;t";V;3P;fi;d\xe9pendre;L23;6033;3649;7;61']
# [u'd\xe9pends', u'd\xe9pends;d\xe8p\xe2;z";V;2S;pI;d\xe9pendre;L23;6033;3649;118;20']
# [u'd\xe9pendons', u'd\xe9pendons;d\xe8p\xe2d\xf4;z";V;1P;pI;d\xe9pendre;L23;6033;3649;43;20']
# ('6033', '3649')
# [u'd\xe9pendez', u'd\xe9pendez;d\xe8p\xe2de;z";V;2P;pI;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pende', u'd\xe9pende;d\xe8p\xe2d;@;V;1S;ps;d\xe9pendre;L23;6033;3649;17;27']
# ('6033', '3649')
# [u'd\xe9pendes', u'd\xe9pendes;d\xe8p\xe2d;@;V;2S;ps;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pende', u'd\xe9pende;d\xe8p\xe2d;@;V;3S;ps;d\xe9pendre;L23;6033;3649;17;27']
# ('6033', '3649')
# [u'd\xe9pendions', u'd\xe9pendions;d\xe8p\xe2dj\xf4;z";V;1P;ps;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendiez', u'd\xe9pendiez;d\xe8p\xe2dje;z";V;2P;ps;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendent', u'd\xe9pendent;d\xe8p\xe2d;@t";V;3P;ps;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendisse', u'd\xe9pendisse;d\xe8p\xe2dis;@;V;1S;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendisses', u'd\xe9pendisses;d\xe8p\xe2dis;@;V;2S;is;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pend\xeet', u'd\xe9pend\xeet;d\xe8p\xe2di;t";V;3S;is;d\xe9pendre;L23;6033;3649;0;34']
# ('6033', '3649')
# [u'd\xe9pendissions', u'd\xe9pendissions;d\xe8p\xe2disj\xf4;z";V;1P;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendissiez', u'd\xe9pendissiez;d\xe8p\xe2disje;z";V;2P;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendissent', u'd\xe9pendissent;d\xe8p\xe2dis;@t";V;3P;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendrais', u'd\xe9pendrais;d\xe8p\xe2dr\xe8;z";V;1S;pc;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendrais', u'd\xe9pendrais;d\xe8p\xe2dr\xe8;z";V;2S;pc;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendrait', u'd\xe9pendrait;d\xe8p\xe2dr\xe8;t";V;3S;pc;d\xe9pendre;L23;6033;3649;12;142']
# ('6033', '3649')
# [u'd\xe9pendrions', u'd\xe9pendrions;d\xe8p\xe2dri\xf4;z";V;1P;pc;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendriez', u'd\xe9pendriez;d\xe8p\xe2drie;z";V;2P;pc;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendraient', u'd\xe9pendraient;d\xe8p\xe2dr\xe8;t";V;3P;pc;d\xe9pendre;L23;6033;3649;1;34']
# [u'd\xe9pendant', u'd\xe9pendant;d\xe8p\xe2d\xe2;t";V;;pP;d\xe9pendre;L23;6033;3649;47;108']
# ('6033', '3649')
# [u'd\xe9pendu', u'd\xe9pendu;d\xe8p\xe2dy;;K;ij;;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendre', u'd\xe9pendre;d\xe8p\xe2dr;@;V;;inf;d\xe9pendre;L23;6033;3649;246;284']
# [u'd\xe9pends', u'd\xe9pends;d\xe8p\xe2;z";V;1S;pi;d\xe9pendre;L23;6033;3649;118;20']
# [u'd\xe9pends', u'd\xe9pends;d\xe8p\xe2;z";V;2S;pi;d\xe9pendre;L23;6033;3649;118;20']
# [u'd\xe9pend', u'd\xe9pend;d\xe8p\xe2;t";V;3S;pi;d\xe9pendre;L23;6033;3649;4830;1520']
# [u'd\xe9pendons', u'd\xe9pendons;d\xe8p\xe2d\xf4;z";V;1P;pi;d\xe9pendre;L23;6033;3649;43;20']
# [u'd\xe9pendez', u'd\xe9pendez;d\xe8p\xe2de;z";V;2P;pi;d\xe9pendre;L23;6033;3649;25;0']
# [u'd\xe9pendent', u'd\xe9pendent;d\xe8p\xe2d;@t";V;3P;pi;d\xe9pendre;L23;6033;3649;264;209']
# [u'd\xe9pendais', u'd\xe9pendais;d\xe8p\xe2d\xe8;z";V;1S;ii;d\xe9pendre;L23;6033;3649;4;34']
# [u'd\xe9pendais', u'd\xe9pendais;d\xe8p\xe2d\xe8;z";V;2S;ii;d\xe9pendre;L23;6033;3649;4;34']
# [u'd\xe9pendait', u'd\xe9pendait;d\xe8p\xe2d\xe8;t";V;3S;ii;d\xe9pendre;L23;6033;3649;187;764']
# [u'd\xe9pendions', u'd\xe9pendions;d\xe8p\xe2dj\xf4;z";V;1P;ii;d\xe9pendre;L23;6033;3649;1;7']
# ('6033', '3649')
# [u'd\xe9pendiez', u'd\xe9pendiez;d\xe8p\xe2dje;z";V;2P;ii;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendaient', u'd\xe9pendaient;d\xe8p\xe2d\xe8;t";V;3P;ii;d\xe9pendre;L23;6033;3649;13;176']
# ('6033', '3649')
# [u'd\xe9pendis', u'd\xe9pendis;d\xe8p\xe2di;z";V;1S;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendis', u'd\xe9pendis;d\xe8p\xe2di;z";V;2S;ai;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendit', u'd\xe9pendit;d\xe8p\xe2di;t";V;3S;ai;d\xe9pendre;L23;6033;3649;0;7']
# ('6033', '3649')
# [u'd\xe9pend\xeemes', u'd\xe9pend\xeemes;d\xe8p\xe2dim;@z";V;1P;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pend\xeetes', u'd\xe9pend\xeetes;d\xe8p\xe2dit;@z";V;2P;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendirent', u'd\xe9pendirent;d\xe8p\xe2dir;@t";V;3P;ai;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendrai', u'd\xe9pendrai;d\xe8p\xe2dr\xe8;;V;1S;fi;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendras', u'd\xe9pendras;d\xe8p\xe2dra;z";V;2S;fi;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendra', u'd\xe9pendra;d\xe8p\xe2dra;;V;3S;fi;d\xe9pendre;L23;6033;3649;204;122']
# ('6033', '3649')
# [u'd\xe9pendrons', u'd\xe9pendrons;d\xe8p\xe2dr\xf4;z";V;1P;fi;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendrez', u'd\xe9pendrez;d\xe8p\xe2dre;z";V;2P;fi;d\xe9pendre;L23;6033;3649;1;14']
# [u'd\xe9pendront', u'd\xe9pendront;d\xe8p\xe2dr\xf4;t";V;3P;fi;d\xe9pendre;L23;6033;3649;7;61']
# [u'd\xe9pends', u'd\xe9pends;d\xe8p\xe2;z";V;2S;pI;d\xe9pendre;L23;6033;3649;118;20']
# [u'd\xe9pendons', u'd\xe9pendons;d\xe8p\xe2d\xf4;z";V;1P;pI;d\xe9pendre;L23;6033;3649;43;20']
# ('6033', '3649')
# [u'd\xe9pendez', u'd\xe9pendez;d\xe8p\xe2de;z";V;2P;pI;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pende', u'd\xe9pende;d\xe8p\xe2d;@;V;1S;ps;d\xe9pendre;L23;6033;3649;17;27']
# ('6033', '3649')
# [u'd\xe9pendes', u'd\xe9pendes;d\xe8p\xe2d;@;V;2S;ps;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pende', u'd\xe9pende;d\xe8p\xe2d;@;V;3S;ps;d\xe9pendre;L23;6033;3649;17;27']
# ('6033', '3649')
# [u'd\xe9pendions', u'd\xe9pendions;d\xe8p\xe2dj\xf4;z";V;1P;ps;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendiez', u'd\xe9pendiez;d\xe8p\xe2dje;z";V;2P;ps;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendent', u'd\xe9pendent;d\xe8p\xe2d;@t";V;3P;ps;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendisse', u'd\xe9pendisse;d\xe8p\xe2dis;@;V;1S;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendisses', u'd\xe9pendisses;d\xe8p\xe2dis;@;V;2S;is;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pend\xeet', u'd\xe9pend\xeet;d\xe8p\xe2di;t";V;3S;is;d\xe9pendre;L23;6033;3649;0;34']
# ('6033', '3649')
# [u'd\xe9pendissions', u'd\xe9pendissions;d\xe8p\xe2disj\xf4;z";V;1P;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendissiez', u'd\xe9pendissiez;d\xe8p\xe2disje;z";V;2P;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendissent', u'd\xe9pendissent;d\xe8p\xe2dis;@t";V;3P;is;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendrais', u'd\xe9pendrais;d\xe8p\xe2dr\xe8;z";V;1S;pc;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendrais', u'd\xe9pendrais;d\xe8p\xe2dr\xe8;z";V;2S;pc;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendrait', u'd\xe9pendrait;d\xe8p\xe2dr\xe8;t";V;3S;pc;d\xe9pendre;L23;6033;3649;12;142']
# ('6033', '3649')
# [u'd\xe9pendrions', u'd\xe9pendrions;d\xe8p\xe2dri\xf4;z";V;1P;pc;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendriez', u'd\xe9pendriez;d\xe8p\xe2drie;z";V;2P;pc;d\xe9pendre;L23;6033;3649;***;***']
# [u'd\xe9pendraient', u'd\xe9pendraient;d\xe8p\xe2dr\xe8;t";V;3P;pc;d\xe9pendre;L23;6033;3649;1;34']
# [u'd\xe9pendant', u'd\xe9pendant;d\xe8p\xe2d\xe2;t";V;;pP;d\xe9pendre;L23;6033;3649;47;108']
# ('6033', '3649')
# [u'd\xe9pendu', u'd\xe9pendu;d\xe8p\xe2dy;;K;MS;;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendus', u'd\xe9pendus;d\xe8p\xe2dy;z";K;MP;;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendue', u'd\xe9pendue;d\xe8p\xe2dy;;K;FS;;d\xe9pendre;L23;6033;3649;***;***']
# ('6033', '3649')
# [u'd\xe9pendues', u'd\xe9pendues;d\xe8p\xe2dy;z";K;FP;;d\xe9pendre;L23;6033;3649;***;***']

# %%
nomLexiqueResync=nomLexique.split(".")[0]+"-Resync.txt"
resync=sorted([x.rstrip("\n")+"\n" for x in set(resync)])
with codecs.open(nomLexiqueResync, 'w',encoding='utf8') as outfile:
    outfile.writelines(resync)

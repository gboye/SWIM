# %%
from PDM import *
import PDM 
import pickle
import warnings

# %%
PDM.seuilDistribution=0.01
verbose=True

# %%
analyse=Regles()
classification=Classes()

# %%
with open('Regles.pkl', 'rb') as input:
    analyse = pickle.load(input)
with open('Classes.pkl', 'rb') as input:
    classification = pickle.load(input)

# %% [markdown]
# #Définition de la représentation lexicale
#
# - Création des cases
#  - Ajout des formes
# - Création du paradigme
#  - Ajout des cases

# %%
inf=Case("inf")
inf.addForm(FormeCoef("finir",1))
prs1=Case("prs.1")
prs1.addForm(FormeCoef("fini",1))
pst1=Case("pst.1")
pst1.addForm(FormeCoef("fini",1))

# %%
lexical=Paradigme()
lexical.addEntrees(inf,prs1,pst1)
lexical
# Out:
# entrees : {prs.1 : [("fini",1)], inf : [("finir",1)], pst.1 : [("fini",1)]}
# sorties : {}

# %%
def modifierForme(forme,numRegle):
    patron=analyse.regles[numRegle].patron
    mod=analyse.regles[numRegle].mod

    m=re.search(patron,forme)
    if m:
        sortie=m.group(1)+mod+m.group(2)
        return(forme,sortie)
    else:
        return (forme,"")

# %%
def calculerParadigme(lexeme):
    if i<3: 
        verbose = False
    else:
        verbose =True
    verbe=Paradigme()
    verbe.entrees=lexeme.nouveau
    for inCase in verbe.entrees:
        if verbose: print("inCase",inCase,verbe.entrees[inCase])
        for fc in verbe.entrees[inCase]:
            if verbose: print("\tforme classe",fc)
            forme=fc.forme
            for outCase in analyse.pairesCase[inCase]:
                if verbose: print("\t\toutCase",outCase)
                paire=Paire(inCase,outCase)
                formeSorties=FormeClasse(forme)
#                formeSorties=FormesDist(forme)
                for numRegle in analyse.reglesPaire[paire]:
                    (entree,sortie)=modifierForme(forme,numRegle)
                    if sortie!="":
#                        formeSorties.addRule(RegleDist(numRegle,1,sortie,entree),True)
                        formeSorties.addRule(RegleDist(numRegle,1,sortie,entree),force=True)
                if formeSorties in classification.classes[paire]:
                    numClasse=classification.classes[paire].index(formeSorties)
                    for numRegle in formeSorties.reglesDist:
                        formeSorties.reglesDist[numRegle].dist=classification.classes[paire][numClasse].reglesDist[numRegle].dist
                    verbe.addSortie(paire,formeSorties)
                    if verbose: print("\t\t\tformeSorties",paire,formeSorties)
                    for rd in formeSorties.numRulesDist():
                        if rd.dist!=0:
                            verbe.addSupporter(paire,rd)
                else:
                    if verbose: print ("formeSorties",formeSorties.getRules())
                    if verbose: print ("classes", classification.classes[paire])
                    if verbose: print ("pas de classe", paire, formeSorties)
    verbose=True
    if verbose: print("verbes.sorties")
    for nomCase in verbe.sorties:
        if verbose: print("nom Case",nomCase)
        case=Case(nomCase)
        for vecteur in verbe.sorties[nomCase]:
            if verbose: print("\tvecteur",vecteur)
            for fc in verbe.sorties[nomCase][vecteur]:
                if verbose: print("\t\tforme classe",fc)
                for rd in fc.numRulesDist():
                    if verbose: print("\t\t\trègle distribution",rd)
                    if rd.dist!=0:
                        case.addForm(FormeCoef(rd.sortie,rd.dist))
        verbe.nouveau[nomCase]=case
    return verbe

# %%
def etayage(verbe, nb):
    for outCase in verbe.supporters:
        print (outCase)
        for forme in verbe.supporters[outCase]:
            nbCases=len(verbe.supporters[outCase][forme])
            if nbCases>nb:
                print ("\t",forme,nbCases)
                if verbose:
                    for inCase in verbe.supporters[outCase][forme]:
                        print ("\t\t",inCase,verbe.supporters[outCase][forme][inCase].reglesDist)

# %%
verbe=Paradigme()
verbe.nouveau=lexical.entrees
print (verbe)
for i in range(1):
    print ("époque",i)
    verbe=calculerParadigme(verbe)
    print (verbe.nouveau)
# Out:
# entrees : {}
# sorties : {}
# époque 0
# verbes.sorties
# nom Case prs.3
# 	vecteur inf=>prs.3
# 		forme classe finir : [10450 (1 fini)]
# 			règle distribution 10450 (1 fini)
# 	vecteur pst.1=>prs.3
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur prs.1=>prs.3
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# nom Case prs.2
# 	vecteur inf=>prs.2
# 		forme classe finir : [10450 (1 fini)]
# 			règle distribution 10450 (1 fini)
# 	vecteur pst.1=>prs.2
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur prs.1=>prs.2
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# nom Case prs.1
# 	vecteur pst.1=>prs.1
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur inf=>prs.1
# 		forme classe finir : [10450 (1 fini)]
# 			règle distribution 10450 (1 fini)
# nom Case prs.6
# 	vecteur prs.1=>prs.6
# 		forme classe fini : [1669 (0.84 finis), 1623 (0.16 fini)]
# 			règle distribution 1669 (0.84 finis)
# 			règle distribution 1623 (0.16 fini)
# 	vecteur inf=>prs.6
# 		forme classe finir : [8489 (0.88 finis), 10490 (0 fini), 10498 (0.12 fin)]
# 			règle distribution 8489 (0.88 finis)
# 			règle distribution 10490 (0 fini)
# 			règle distribution 10498 (0.12 fin)
# 	vecteur pst.1=>prs.6
# 		forme classe fini : [6877 (0.29 fin), 6878 (0.71 finis)]
# 			règle distribution 6877 (0.29 fin)
# 			règle distribution 6878 (0.71 finis)
# nom Case prs.5
# 	vecteur prs.1=>prs.5
# 		forme classe fini : [1498 (0.8 finisE), 1499 (0.2 finjE), 1494 (0 finiE)]
# 			règle distribution 1498 (0.8 finisE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur pst.1=>prs.5
# 		forme classe fini : [6730 (0.3 finE), 6731 (0.7 finisE)]
# 			règle distribution 6730 (0.3 finE)
# 			règle distribution 6731 (0.7 finisE)
# 	vecteur inf=>prs.5
# 		forme classe finir : [10404 (0 finE), 8319 (1 finisE)]
# 			règle distribution 10404 (0 finE)
# 			règle distribution 8319 (1 finisE)
# nom Case prs.4
# 	vecteur prs.1=>prs.4
# 		forme classe fini : [1545 (0.2 finjô), 1627 (0 finiô), 1631 (0.8 finisô)]
# 			règle distribution 1545 (0.2 finjô)
# 			règle distribution 1627 (0 finiô)
# 			règle distribution 1631 (0.8 finisô)
# 	vecteur pst.1=>prs.4
# 		forme classe fini : [6848 (0.29 finô), 6849 (0.71 finisô)]
# 			règle distribution 6848 (0.29 finô)
# 			règle distribution 6849 (0.71 finisô)
# 	vecteur inf=>prs.4
# 		forme classe finir : [10476 (0 finô), 8460 (1 finisô)]
# 			règle distribution 10476 (0 finô)
# 			règle distribution 8460 (1 finisô)
# nom Case pst.sbj.6
# 	vecteur pst.1=>pst.sbj.6
# 		forme classe fini : [7086 (1 finis)]
# 			règle distribution 7086 (1 finis)
# 	vecteur inf=>pst.sbj.6
# 		forme classe finir : [10725 (1 finis)]
# 			règle distribution 10725 (1 finis)
# 	vecteur prs.1=>pst.sbj.6
# 		forme classe fini : [2049 (0.48 finis), 2050 (0.52 finjas), 2045 (0 finias)]
# 			règle distribution 2049 (0.48 finis)
# 			règle distribution 2050 (0.52 finjas)
# 			règle distribution 2045 (0 finias)
# nom Case pst.sbj.4
# 	vecteur pst.1=>pst.sbj.4
# 		forme classe fini : [7087 (1 finisjô)]
# 			règle distribution 7087 (1 finisjô)
# 	vecteur prs.1=>pst.sbj.4
# 		forme classe fini : [2097 (0.48 finisjô), 2098 (0.52 finjasjô), 2093 (0 finiasjô)]
# 			règle distribution 2097 (0.48 finisjô)
# 			règle distribution 2098 (0.52 finjasjô)
# 			règle distribution 2093 (0 finiasjô)
# 	vecteur inf=>pst.sbj.4
# 		forme classe finir : [10753 (1 finisjô)]
# 			règle distribution 10753 (1 finisjô)
# nom Case pst.sbj.5
# 	vecteur pst.1=>pst.sbj.5
# 		forme classe fini : [7088 (1 finisjE)]
# 			règle distribution 7088 (1 finisjE)
# 	vecteur prs.1=>pst.sbj.5
# 		forme classe fini : [2145 (0.48 finisjE), 2146 (0.52 finjasjE), 2141 (0 finiasjE)]
# 			règle distribution 2145 (0.48 finisjE)
# 			règle distribution 2146 (0.52 finjasjE)
# 			règle distribution 2141 (0 finiasjE)
# 	vecteur inf=>pst.sbj.5
# 		forme classe finir : [10781 (1 finisjE)]
# 			règle distribution 10781 (1 finisjE)
# nom Case pst.sbj.2
# 	vecteur inf=>pst.sbj.2
# 		forme classe finir : [10725 (1 finis)]
# 			règle distribution 10725 (1 finis)
# 	vecteur prs.1=>pst.sbj.2
# 		forme classe fini : [2049 (0.48 finis), 2050 (0.52 finjas), 2045 (0 finias)]
# 			règle distribution 2049 (0.48 finis)
# 			règle distribution 2050 (0.52 finjas)
# 			règle distribution 2045 (0 finias)
# 	vecteur pst.1=>pst.sbj.2
# 		forme classe fini : [7086 (1 finis)]
# 			règle distribution 7086 (1 finis)
# nom Case pst.sbj.3
# 	vecteur inf=>pst.sbj.3
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# 	vecteur prs.1=>pst.sbj.3
# 		forme classe fini : [1880 (0 finia), 1883 (0.52 finja), 1845 (0.48 fini)]
# 			règle distribution 1880 (0 finia)
# 			règle distribution 1883 (0.52 finja)
# 			règle distribution 1845 (0.48 fini)
# 	vecteur pst.1=>pst.sbj.3
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# nom Case pst.sbj.1
# 	vecteur prs.1=>pst.sbj.1
# 		forme classe fini : [2049 (0.48 finis), 2050 (0.52 finjas), 2045 (0 finias)]
# 			règle distribution 2049 (0.48 finis)
# 			règle distribution 2050 (0.52 finjas)
# 			règle distribution 2045 (0 finias)
# 	vecteur inf=>pst.sbj.1
# 		forme classe finir : [10725 (1 finis)]
# 			règle distribution 10725 (1 finis)
# 	vecteur pst.1=>pst.sbj.1
# 		forme classe fini : [7086 (1 finis)]
# 			règle distribution 7086 (1 finis)
# nom Case pst.pcp
# 	vecteur prs.1=>pst.pcp
# 		forme classe fini : [1499 (0.51 finjE), 2254 (0.49 fini), 1494 (0 finiE)]
# 			règle distribution 1499 (0.51 finjE)
# 			règle distribution 2254 (0.49 fini)
# 			règle distribution 1494 (0 finiE)
# 	vecteur inf=>pst.pcp
# 		forme classe finir : [8835 (0.88 fini), 10831 (0.12 finy)]
# 			règle distribution 8835 (0.88 fini)
# 			règle distribution 10831 (0.12 finy)
# 	vecteur pst.1=>pst.pcp
# 		forme classe fini : [7145 (1 fini)]
# 			règle distribution 7145 (1 fini)
# nom Case sbjv.4
# 	vecteur pst.1=>sbjv.4
# 		forme classe fini : [6760 (1 finisjô), 6759 (0 finjô)]
# 			règle distribution 6760 (1 finisjô)
# 			règle distribution 6759 (0 finjô)
# 	vecteur inf=>sbjv.4
# 		forme classe finir : [10416 (0 finijô), 10422 (0.48 finjô), 8351 (0.52 finisjô)]
# 			règle distribution 10416 (0 finijô)
# 			règle distribution 10422 (0.48 finjô)
# 			règle distribution 8351 (0.52 finisjô)
# 	vecteur prs.1=>sbjv.4
# 		forme classe fini : [1544 (0.8 finisjô), 1545 (0.2 finjô), 1539 (0 finijô)]
# 			règle distribution 1544 (0.8 finisjô)
# 			règle distribution 1545 (0.2 finjô)
# 			règle distribution 1539 (0 finijô)
# nom Case sbjv.5
# 	vecteur pst.1=>sbjv.5
# 		forme classe fini : [6787 (0 finjE), 6788 (1 finisjE)]
# 			règle distribution 6787 (0 finjE)
# 			règle distribution 6788 (1 finisjE)
# 	vecteur prs.1=>sbjv.5
# 		forme classe fini : [1584 (0 finijE), 1499 (0.2 finjE), 1589 (0.8 finisjE)]
# 			règle distribution 1584 (0 finijE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1589 (0.8 finisjE)
# 	vecteur inf=>sbjv.5
# 		forme classe finir : [10434 (0 finijE), 8382 (0.52 finisjE), 10439 (0.48 finjE)]
# 			règle distribution 10434 (0 finijE)
# 			règle distribution 8382 (0.52 finisjE)
# 			règle distribution 10439 (0.48 finjE)
# nom Case sbjv.6
# 	vecteur pst.1=>sbjv.6
# 		forme classe fini : [6877 (0.29 fin), 6878 (0.71 finis)]
# 			règle distribution 6877 (0.29 fin)
# 			règle distribution 6878 (0.71 finis)
# 	vecteur inf=>sbjv.6
# 		forme classe finir : [8489 (0.88 finis), 10490 (0 fini), 10498 (0.12 fin)]
# 			règle distribution 8489 (0.88 finis)
# 			règle distribution 10490 (0 fini)
# 			règle distribution 10498 (0.12 fin)
# 	vecteur prs.1=>sbjv.6
# 		forme classe fini : [1669 (0.84 finis), 1623 (0.16 fini)]
# 			règle distribution 1669 (0.84 finis)
# 			règle distribution 1623 (0.16 fini)
# nom Case prs.pcp
# 	vecteur pst.1=>prs.pcp
# 		forme classe fini : [7116 (0.33 finâ), 7117 (0.67 finisâ)]
# 			règle distribution 7116 (0.33 finâ)
# 			règle distribution 7117 (0.67 finisâ)
# 	vecteur inf=>prs.pcp
# 		forme classe finir : [10809 (0 finiâ), 10815 (0.47 finâ), 8807 (0.53 finisâ)]
# 			règle distribution 10809 (0 finiâ)
# 			règle distribution 10815 (0.47 finâ)
# 			règle distribution 8807 (0.53 finisâ)
# 	vecteur prs.1=>prs.pcp
# 		forme classe fini : [2210 (0 finiâ), 2218 (0 finijâ), 2214 (0.8 finisâ), 2215 (0.2 finjâ)]
# 			règle distribution 2210 (0 finiâ)
# 			règle distribution 2218 (0 finijâ)
# 			règle distribution 2214 (0.8 finisâ)
# 			règle distribution 2215 (0.2 finjâ)
# nom Case sbjv.1
# 	vecteur prs.1=>sbjv.1
# 		forme classe fini : [1669 (0.84 finis), 1623 (0.16 fini)]
# 			règle distribution 1669 (0.84 finis)
# 			règle distribution 1623 (0.16 fini)
# 	vecteur inf=>sbjv.1
# 		forme classe finir : [8489 (0.88 finis), 10490 (0 fini), 10498 (0.12 fin)]
# 			règle distribution 8489 (0.88 finis)
# 			règle distribution 10490 (0 fini)
# 			règle distribution 10498 (0.12 fin)
# 	vecteur pst.1=>sbjv.1
# 		forme classe fini : [6877 (0.29 fin), 6878 (0.71 finis)]
# 			règle distribution 6877 (0.29 fin)
# 			règle distribution 6878 (0.71 finis)
# nom Case sbjv.2
# 	vecteur inf=>sbjv.2
# 		forme classe finir : [8489 (0.88 finis), 10490 (0 fini), 10498 (0.12 fin)]
# 			règle distribution 8489 (0.88 finis)
# 			règle distribution 10490 (0 fini)
# 			règle distribution 10498 (0.12 fin)
# 	vecteur prs.1=>sbjv.2
# 		forme classe fini : [1669 (0.84 finis), 1623 (0.16 fini)]
# 			règle distribution 1669 (0.84 finis)
# 			règle distribution 1623 (0.16 fini)
# 	vecteur pst.1=>sbjv.2
# 		forme classe fini : [6877 (0.29 fin), 6878 (0.71 finis)]
# 			règle distribution 6877 (0.29 fin)
# 			règle distribution 6878 (0.71 finis)
# nom Case sbjv.3
# 	vecteur prs.1=>sbjv.3
# 		forme classe fini : [1669 (0.84 finis), 1623 (0.16 fini)]
# 			règle distribution 1669 (0.84 finis)
# 			règle distribution 1623 (0.16 fini)
# 	vecteur inf=>sbjv.3
# 		forme classe finir : [8489 (0.88 finis), 10490 (0 fini), 10498 (0.12 fin)]
# 			règle distribution 8489 (0.88 finis)
# 			règle distribution 10490 (0 fini)
# 			règle distribution 10498 (0.12 fin)
# 	vecteur pst.1=>sbjv.3
# 		forme classe fini : [6877 (0.29 fin), 6878 (0.71 finis)]
# 			règle distribution 6877 (0.29 fin)
# 			règle distribution 6878 (0.71 finis)
# nom Case inf
# 	vecteur prs.1=>inf
# 		forme classe fini : [1499 (0.52 finjE), 2190 (0 finidr), 1494 (0 finiE), 2191 (0.48 finir)]
# 			règle distribution 1499 (0.52 finjE)
# 			règle distribution 2190 (0 finidr)
# 			règle distribution 1494 (0 finiE)
# 			règle distribution 2191 (0.48 finir)
# 	vecteur pst.1=>inf
# 		forme classe fini : [7089 (0 fini), 1999 (1 finir)]
# 			règle distribution 7089 (0 fini)
# 			règle distribution 1999 (1 finir)
# nom Case imp.4
# 	vecteur prs.1=>imp.4
# 		forme classe fini : [1545 (0.2 finjô), 1627 (0 finiô), 1694 (0 finijô), 1631 (0.8 finisô)]
# 			règle distribution 1545 (0.2 finjô)
# 			règle distribution 1627 (0 finiô)
# 			règle distribution 1694 (0 finijô)
# 			règle distribution 1631 (0.8 finisô)
# 	vecteur inf=>imp.4
# 		forme classe finir : [10476 (0 finô), 8460 (1 finisô)]
# 			règle distribution 10476 (0 finô)
# 			règle distribution 8460 (1 finisô)
# 	vecteur pst.1=>imp.4
# 		forme classe fini : [6848 (0.29 finô), 6849 (0.71 finisô)]
# 			règle distribution 6848 (0.29 finô)
# 			règle distribution 6849 (0.71 finisô)
# nom Case fut.6
# 	vecteur inf=>fut.6
# 		forme classe finir : [10563 (1 finirô)]
# 			règle distribution 10563 (1 finirô)
# 	vecteur pst.1=>fut.6
# 		forme classe fini : [6985 (1 finirô)]
# 			règle distribution 6985 (1 finirô)
# 	vecteur prs.1=>fut.6
# 		forme classe fini : [1766 (0.02 finidrô), 1767 (0.98 finirô)]
# 			règle distribution 1766 (0.02 finidrô)
# 			règle distribution 1767 (0.98 finirô)
# nom Case fut.5
# 	vecteur pst.1=>fut.5
# 		forme classe fini : [6917 (1 finirE)]
# 			règle distribution 6917 (1 finirE)
# 	vecteur inf=>fut.5
# 		forme classe finir : [10531 (1 finirE)]
# 			règle distribution 10531 (1 finirE)
# 	vecteur prs.1=>fut.5
# 		forme classe fini : [1712 (0.98 finirE), 1711 (0.02 finidrE)]
# 			règle distribution 1712 (0.98 finirE)
# 			règle distribution 1711 (0.02 finidrE)
# nom Case fut.4
# 	vecteur pst.1=>fut.4
# 		forme classe fini : [6985 (1 finirô)]
# 			règle distribution 6985 (1 finirô)
# 	vecteur inf=>fut.4
# 		forme classe finir : [10563 (1 finirô)]
# 			règle distribution 10563 (1 finirô)
# 	vecteur prs.1=>fut.4
# 		forme classe fini : [1766 (0.02 finidrô), 1767 (0.98 finirô)]
# 			règle distribution 1766 (0.02 finidrô)
# 			règle distribution 1767 (0.98 finirô)
# nom Case fut.3
# 	vecteur prs.1=>fut.3
# 		forme classe fini : [1738 (0.02 finidra), 1739 (0.98 finira)]
# 			règle distribution 1738 (0.02 finidra)
# 			règle distribution 1739 (0.98 finira)
# 	vecteur inf=>fut.3
# 		forme classe finir : [10547 (1 finira)]
# 			règle distribution 10547 (1 finira)
# 	vecteur pst.1=>fut.3
# 		forme classe fini : [6951 (1 finira)]
# 			règle distribution 6951 (1 finira)
# nom Case fut.2
# 	vecteur prs.1=>fut.2
# 		forme classe fini : [1738 (0.02 finidra), 1739 (0.98 finira)]
# 			règle distribution 1738 (0.02 finidra)
# 			règle distribution 1739 (0.98 finira)
# 	vecteur inf=>fut.2
# 		forme classe finir : [10547 (1 finira)]
# 			règle distribution 10547 (1 finira)
# 	vecteur pst.1=>fut.2
# 		forme classe fini : [6951 (1 finira)]
# 			règle distribution 6951 (1 finira)
# nom Case fut.1
# 	vecteur prs.1=>fut.1
# 		forme classe fini : [1712 (0.98 finirE), 1711 (0.02 finidrE)]
# 			règle distribution 1712 (0.98 finirE)
# 			règle distribution 1711 (0.02 finidrE)
# 	vecteur pst.1=>fut.1
# 		forme classe fini : [6917 (1 finirE)]
# 			règle distribution 6917 (1 finirE)
# 	vecteur inf=>fut.1
# 		forme classe finir : [10531 (1 finirE)]
# 			règle distribution 10531 (1 finirE)
# nom Case cond.6
# 	vecteur pst.1=>cond.6
# 		forme classe fini : [6917 (1 finirE)]
# 			règle distribution 6917 (1 finirE)
# 	vecteur prs.1=>cond.6
# 		forme classe fini : [1712 (0.98 finirE), 1711 (0.02 finidrE)]
# 			règle distribution 1712 (0.98 finirE)
# 			règle distribution 1711 (0.02 finidrE)
# 	vecteur inf=>cond.6
# 		forme classe finir : [10531 (1 finirE)]
# 			règle distribution 10531 (1 finirE)
# nom Case cond.5
# 	vecteur pst.1=>cond.5
# 		forme classe fini : [7052 (1 finirjE)]
# 			règle distribution 7052 (1 finirjE)
# 	vecteur inf=>cond.5
# 		forme classe finir : [10597 (1 finirjE)]
# 			règle distribution 10597 (1 finirjE)
# 	vecteur prs.1=>cond.5
# 		forme classe fini : [1819 (0.02 finidrijE), 1820 (0.98 finirjE)]
# 			règle distribution 1819 (0.02 finidrijE)
# 			règle distribution 1820 (0.98 finirjE)
# nom Case cond.4
# 	vecteur pst.1=>cond.4
# 		forme classe fini : [7020 (1 finirjô)]
# 			règle distribution 7020 (1 finirjô)
# 	vecteur prs.1=>cond.4
# 		forme classe fini : [1793 (0.02 finidrijô), 1794 (0.98 finirjô)]
# 			règle distribution 1793 (0.02 finidrijô)
# 			règle distribution 1794 (0.98 finirjô)
# 	vecteur inf=>cond.4
# 		forme classe finir : [10581 (1 finirjô)]
# 			règle distribution 10581 (1 finirjô)
# nom Case cond.3
# 	vecteur inf=>cond.3
# 		forme classe finir : [10531 (1 finirE)]
# 			règle distribution 10531 (1 finirE)
# 	vecteur prs.1=>cond.3
# 		forme classe fini : [1712 (0.98 finirE), 1711 (0.02 finidrE)]
# 			règle distribution 1712 (0.98 finirE)
# 			règle distribution 1711 (0.02 finidrE)
# 	vecteur pst.1=>cond.3
# 		forme classe fini : [6917 (1 finirE)]
# 			règle distribution 6917 (1 finirE)
# nom Case cond.2
# 	vecteur prs.1=>cond.2
# 		forme classe fini : [1712 (0.98 finirE), 1711 (0.02 finidrE)]
# 			règle distribution 1712 (0.98 finirE)
# 			règle distribution 1711 (0.02 finidrE)
# 	vecteur inf=>cond.2
# 		forme classe finir : [10531 (1 finirE)]
# 			règle distribution 10531 (1 finirE)
# 	vecteur pst.1=>cond.2
# 		forme classe fini : [6917 (1 finirE)]
# 			règle distribution 6917 (1 finirE)
# nom Case cond.1
# 	vecteur inf=>cond.1
# 		forme classe finir : [10531 (1 finirE)]
# 			règle distribution 10531 (1 finirE)
# 	vecteur prs.1=>cond.1
# 		forme classe fini : [1712 (0.98 finirE), 1711 (0.02 finidrE)]
# 			règle distribution 1712 (0.98 finirE)
# 			règle distribution 1711 (0.02 finidrE)
# 	vecteur pst.1=>cond.1
# 		forme classe fini : [6917 (1 finirE)]
# 			règle distribution 6917 (1 finirE)
# nom Case ipf.5
# 	vecteur pst.1=>ipf.5
# 		forme classe fini : [6787 (0 finjE), 6788 (1 finisjE)]
# 			règle distribution 6787 (0 finjE)
# 			règle distribution 6788 (1 finisjE)
# 	vecteur inf=>ipf.5
# 		forme classe finir : [10434 (0 finijE), 8382 (0.52 finisjE), 10439 (0.48 finjE)]
# 			règle distribution 10434 (0 finijE)
# 			règle distribution 8382 (0.52 finisjE)
# 			règle distribution 10439 (0.48 finjE)
# 	vecteur prs.1=>ipf.5
# 		forme classe fini : [1584 (0 finijE), 1499 (0.2 finjE), 1589 (0.8 finisjE)]
# 			règle distribution 1584 (0 finijE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1589 (0.8 finisjE)
# nom Case ipf.4
# 	vecteur pst.1=>ipf.4
# 		forme classe fini : [6760 (1 finisjô), 6759 (0 finjô)]
# 			règle distribution 6760 (1 finisjô)
# 			règle distribution 6759 (0 finjô)
# 	vecteur inf=>ipf.4
# 		forme classe finir : [10416 (0 finijô), 10422 (0.48 finjô), 8351 (0.52 finisjô)]
# 			règle distribution 10416 (0 finijô)
# 			règle distribution 10422 (0.48 finjô)
# 			règle distribution 8351 (0.52 finisjô)
# 	vecteur prs.1=>ipf.4
# 		forme classe fini : [1544 (0.8 finisjô), 1545 (0.2 finjô), 1539 (0 finijô)]
# 			règle distribution 1544 (0.8 finisjô)
# 			règle distribution 1545 (0.2 finjô)
# 			règle distribution 1539 (0 finijô)
# nom Case imp.2
# 	vecteur pst.1=>imp.2
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur inf=>imp.2
# 		forme classe finir : [10450 (1 fini)]
# 			règle distribution 10450 (1 fini)
# 	vecteur prs.1=>imp.2
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# nom Case ipf.6
# 	vecteur pst.1=>ipf.6
# 		forme classe fini : [6730 (0.29 finE), 6731 (0.71 finisE)]
# 			règle distribution 6730 (0.29 finE)
# 			règle distribution 6731 (0.71 finisE)
# 	vecteur prs.1=>ipf.6
# 		forme classe fini : [1498 (0.8 finisE), 1499 (0.2 finjE), 1494 (0 finiE)]
# 			règle distribution 1498 (0.8 finisE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur inf=>ipf.6
# 		forme classe finir : [10404 (0.47 finE), 10398 (0 finiE), 8319 (0.53 finisE)]
# 			règle distribution 10404 (0.47 finE)
# 			règle distribution 10398 (0 finiE)
# 			règle distribution 8319 (0.53 finisE)
# nom Case ipf.1
# 	vecteur inf=>ipf.1
# 		forme classe finir : [10404 (0.47 finE), 10398 (0 finiE), 8319 (0.53 finisE)]
# 			règle distribution 10404 (0.47 finE)
# 			règle distribution 10398 (0 finiE)
# 			règle distribution 8319 (0.53 finisE)
# 	vecteur prs.1=>ipf.1
# 		forme classe fini : [1498 (0.8 finisE), 1499 (0.2 finjE), 1494 (0 finiE)]
# 			règle distribution 1498 (0.8 finisE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur pst.1=>ipf.1
# 		forme classe fini : [6730 (0.29 finE), 6731 (0.71 finisE)]
# 			règle distribution 6730 (0.29 finE)
# 			règle distribution 6731 (0.71 finisE)
# nom Case imp.5
# 	vecteur prs.1=>imp.5
# 		forme classe fini : [1697 (0 finijE), 1498 (0.8 finisE), 1499 (0.2 finjE), 1494 (0 finiE)]
# 			règle distribution 1697 (0 finijE)
# 			règle distribution 1498 (0.8 finisE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur inf=>imp.5
# 		forme classe finir : [10404 (0 finE), 8319 (1 finisE)]
# 			règle distribution 10404 (0 finE)
# 			règle distribution 8319 (1 finisE)
# 	vecteur pst.1=>imp.5
# 		forme classe fini : [6730 (0.3 finE), 6731 (0.7 finisE)]
# 			règle distribution 6730 (0.3 finE)
# 			règle distribution 6731 (0.7 finisE)
# nom Case ipf.3
# 	vecteur prs.1=>ipf.3
# 		forme classe fini : [1498 (0.8 finisE), 1499 (0.2 finjE), 1494 (0 finiE)]
# 			règle distribution 1498 (0.8 finisE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur inf=>ipf.3
# 		forme classe finir : [10404 (0.47 finE), 10398 (0 finiE), 8319 (0.53 finisE)]
# 			règle distribution 10404 (0.47 finE)
# 			règle distribution 10398 (0 finiE)
# 			règle distribution 8319 (0.53 finisE)
# 	vecteur pst.1=>ipf.3
# 		forme classe fini : [6730 (0.29 finE), 6731 (0.71 finisE)]
# 			règle distribution 6730 (0.29 finE)
# 			règle distribution 6731 (0.71 finisE)
# nom Case ipf.2
# 	vecteur prs.1=>ipf.2
# 		forme classe fini : [1498 (0.8 finisE), 1499 (0.2 finjE), 1494 (0 finiE)]
# 			règle distribution 1498 (0.8 finisE)
# 			règle distribution 1499 (0.2 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur inf=>ipf.2
# 		forme classe finir : [10404 (0.47 finE), 10398 (0 finiE), 8319 (0.53 finisE)]
# 			règle distribution 10404 (0.47 finE)
# 			règle distribution 10398 (0 finiE)
# 			règle distribution 8319 (0.53 finisE)
# 	vecteur pst.1=>ipf.2
# 		forme classe fini : [6730 (0.29 finE), 6731 (0.71 finisE)]
# 			règle distribution 6730 (0.29 finE)
# 			règle distribution 6731 (0.71 finisE)
# nom Case pst.6
# 	vecteur pst.1=>pst.6
# 		forme classe fini : [7085 (1 finir)]
# 			règle distribution 7085 (1 finir)
# 	vecteur inf=>pst.6
# 		forme classe finir : [8778 (1 finir)]
# 			règle distribution 8778 (1 finir)
# 	vecteur prs.1=>pst.6
# 		forme classe fini : [2000 (0.52 finjEr), 1995 (0 finiEr), 1999 (0.48 finir)]
# 			règle distribution 2000 (0.52 finjEr)
# 			règle distribution 1995 (0 finiEr)
# 			règle distribution 1999 (0.48 finir)
# nom Case pst.5
# 	vecteur pst.1=>pst.5
# 		forme classe fini : [7084 (1 finit)]
# 			règle distribution 7084 (1 finit)
# 	vecteur prs.1=>pst.5
# 		forme classe fini : [1945 (0 finiat), 1949 (0.48 finit), 1950 (0.52 finjat)]
# 			règle distribution 1945 (0 finiat)
# 			règle distribution 1949 (0.48 finit)
# 			règle distribution 1950 (0.52 finjat)
# 	vecteur inf=>pst.5
# 		forme classe finir : [10668 (1 finit)]
# 			règle distribution 10668 (1 finit)
# nom Case pst.4
# 	vecteur pst.1=>pst.4
# 		forme classe fini : [7083 (1 finim)]
# 			règle distribution 7083 (1 finim)
# 	vecteur prs.1=>pst.4
# 		forme classe fini : [1899 (0.48 finim), 1900 (0.52 finjam), 1895 (0 finiam)]
# 			règle distribution 1899 (0.48 finim)
# 			règle distribution 1900 (0.52 finjam)
# 			règle distribution 1895 (0 finiam)
# 	vecteur inf=>pst.4
# 		forme classe finir : [10639 (1 finim)]
# 			règle distribution 10639 (1 finim)
# nom Case pst.3
# 	vecteur inf=>pst.3
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# 	vecteur prs.1=>pst.3
# 		forme classe fini : [1880 (0 finia), 1883 (0.52 finja), 1845 (0.48 fini)]
# 			règle distribution 1880 (0 finia)
# 			règle distribution 1883 (0.52 finja)
# 			règle distribution 1845 (0.48 fini)
# 	vecteur pst.1=>pst.3
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# nom Case pst.2
# 	vecteur inf=>pst.2
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# 	vecteur prs.1=>pst.2
# 		forme classe fini : [1880 (0 finia), 1883 (0.52 finja), 1845 (0.48 fini)]
# 			règle distribution 1880 (0 finia)
# 			règle distribution 1883 (0.52 finja)
# 			règle distribution 1845 (0.48 fini)
# 	vecteur pst.1=>pst.2
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# nom Case pst.1
# 	vecteur prs.1=>pst.1
# 		forme classe fini : [1499 (0.52 finjE), 1845 (0.48 fini), 1494 (0 finiE)]
# 			règle distribution 1499 (0.52 finjE)
# 			règle distribution 1845 (0.48 fini)
# 			règle distribution 1494 (0 finiE)
# 	vecteur inf=>pst.1
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# {'prs.3': [("fini",1)], 'prs.2': [("fini",1)], 'prs.1': [("fini",1)], 'prs.6': [("finis",0.81),("fin",0.14),("fini",0.05)], 'prs.5': [("finisE",0.83),("finE",0.1),("finjE",0.07)], 'prs.4': [("finisô",0.84),("finô",0.1),("finjô",0.07)], 'pst.sbj.6': [("finis",0.83),("finjas",0.17)], 'pst.sbj.4': [("finisjô",0.83),("finjasjô",0.17)], 'pst.sbj.5': [("finisjE",0.83),("finjasjE",0.17)], 'pst.sbj.2': [("finis",0.83),("finjas",0.17)], 'pst.sbj.3': [("fini",0.83),("finja",0.17)], 'pst.sbj.1': [("finis",0.83),("finjas",0.17)], 'sbjv.4': [("finisjô",0.77),("finjô",0.23)], 'pst.pcp': [("fini",0.79),("finjE",0.17),("finy",0.04)], 'sbjv.5': [("finisjE",0.77),("finjE",0.23)], 'sbjv.6': [("finis",0.81),("fin",0.14),("fini",0.05)], 'prs.pcp': [("finisâ",0.67),("finâ",0.27),("finjâ",0.07)], 'sbjv.1': [("finis",0.81),("fin",0.14),("fini",0.05)], 'sbjv.2': [("finis",0.81),("fin",0.14),("fini",0.05)], 'sbjv.3': [("finis",0.81),("fin",0.14),("fini",0.05)], 'inf': [("finir",0.74),("finjE",0.26)], 'imp.4': [("finisô",0.84),("finô",0.1),("finjô",0.07)], 'fut.5': [("finirE",1)], 'fut.4': [("finirô",1)], 'fut.3': [("finira",1)], 'fut.2': [("finira",1)], 'fut.1': [("finirE",1)], 'cond.6': [("finirE",1)], 'cond.5': [("finirjE",1)], 'cond.4': [("finirjô",1)], 'cond.3': [("finirE",1)], 'cond.2': [("finirE",1)], 'cond.1': [("finirE",1)], 'fut.6': [("finirô",1)], 'ipf.5': [("finisjE",0.77),("finjE",0.23)], 'ipf.4': [("finisjô",0.77),("finjô",0.23)], 'imp.2': [("fini",1)], 'ipf.6': [("finisE",0.68),("finE",0.25),("finjE",0.07)], 'ipf.1': [("finisE",0.68),("finE",0.25),("finjE",0.07)], 'imp.5': [("finisE",0.83),("finE",0.1),("finjE",0.07)], 'ipf.3': [("finisE",0.68),("finE",0.25),("finjE",0.07)], 'ipf.2': [("finisE",0.68),("finE",0.25),("finjE",0.07)], 'pst.6': [("finir",0.83),("finjEr",0.17)], 'pst.5': [("finit",0.83),("finjat",0.17)], 'pst.4': [("finim",0.83),("finjam",0.17)], 'pst.3': [("fini",0.83),("finja",0.17)], 'pst.2': [("fini",0.83),("finja",0.17)], 'pst.1': [("fini",0.74),("finjE",0.26)]}
# époque 1
# verbes.sorties
# nom Case prs.3
# 	vecteur ipf.2=>prs.3
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 	vecteur pst.sbj.6=>prs.3
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finjas : [8936 (1 fini), 8931 (0 finj)]
# 			règle distribution 8936 (1 fini)
# 			règle distribution 8931 (0 finj)
# 	vecteur pst.3=>prs.3
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe finja : [7161 (0 finj), 7164 (1 fini)]
# 			règle distribution 7161 (0 finj)
# 			règle distribution 7164 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur pst.pcp=>prs.3
# 		forme classe finjE : [12 (1 fini), 2254 (0 finjE), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 2254 (0 finjE)
# 			règle distribution 7 (0 finj)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 		forme classe finy : [2254 (0 finy), 6815 (1 finE)]
# 			règle distribution 2254 (0 finy)
# 			règle distribution 6815 (1 finE)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 	vecteur sbjv.5=>prs.3
# 		forme classe finisjE : [1041 (0.33 finis), 12 (0.02 finisi), 1046 (0.65 fini)]
# 			règle distribution 1041 (0.33 finis)
# 			règle distribution 12 (0.02 finisi)
# 			règle distribution 1046 (0.65 fini)
# 		forme classe finjE : [1041 (0.93 fin), 12 (0.07 fini)]
# 			règle distribution 1041 (0.93 fin)
# 			règle distribution 12 (0.07 fini)
# 		forme classe finisjE : [1041 (0.33 finis), 12 (0.02 finisi), 1046 (0.65 fini)]
# 			règle distribution 1041 (0.33 finis)
# 			règle distribution 12 (0.02 finisi)
# 			règle distribution 1046 (0.65 fini)
# 		forme classe finisjE : [1041 (0.33 finis), 12 (0.02 finisi), 1046 (0.65 fini)]
# 			règle distribution 1041 (0.33 finis)
# 			règle distribution 12 (0.02 finisi)
# 			règle distribution 1046 (0.65 fini)
# 		forme classe finjE : [1041 (0.93 fin), 12 (0.07 fini)]
# 			règle distribution 1041 (0.93 fin)
# 			règle distribution 12 (0.07 fini)
# 	vecteur prs.6=>prs.3
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 	vecteur prs.pcp=>prs.3
# 		forme classe finâ : [10852 (1 fin)]
# 			règle distribution 10852 (1 fin)
# 		forme classe finisâ : [10856 (0.66 fini), 10852 (0.34 finis)]
# 			règle distribution 10856 (0.66 fini)
# 			règle distribution 10852 (0.34 finis)
# 		forme classe finâ : [10852 (1 fin)]
# 			règle distribution 10852 (1 fin)
# 		forme classe finisâ : [10856 (0.66 fini), 10852 (0.34 finis)]
# 			règle distribution 10856 (0.66 fini)
# 			règle distribution 10852 (0.34 finis)
# 		forme classe finisâ : [10856 (0.66 fini), 10852 (0.34 finis)]
# 			règle distribution 10856 (0.66 fini)
# 			règle distribution 10852 (0.34 finis)
# 		forme classe finjâ : [10857 (1 fini), 10852 (0 finj)]
# 			règle distribution 10857 (1 fini)
# 			règle distribution 10852 (0 finj)
# 	vecteur pst.sbj.5=>prs.3
# 		forme classe finisjE : [9970 (1 fini)]
# 			règle distribution 9970 (1 fini)
# 		forme classe finisjE : [9970 (1 fini)]
# 			règle distribution 9970 (1 fini)
# 		forme classe finjasjE : [9971 (1 fini), 9966 (0 finj)]
# 			règle distribution 9971 (1 fini)
# 			règle distribution 9966 (0 finj)
# 		forme classe finisjE : [9970 (1 fini)]
# 			règle distribution 9970 (1 fini)
# 	vecteur pst.2=>prs.3
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe finja : [7161 (0 finj), 7164 (1 fini)]
# 			règle distribution 7161 (0 finj)
# 			règle distribution 7164 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur pst.1=>prs.3
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur sbjv.3=>prs.3
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 	vecteur pst.sbj.3=>prs.3
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe finja : [7161 (0 finj), 7164 (1 fini)]
# 			règle distribution 7161 (0 finj)
# 			règle distribution 7164 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 		forme classe fini : [1845 (1 fini)]
# 			règle distribution 1845 (1 fini)
# 	vecteur prs.2=>prs.3
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 	vecteur fut.4=>prs.3
# 		forme classe finirô : [4978 (1 fini)]
# 			règle distribution 4978 (1 fini)
# 		forme classe finirô : [4978 (1 fini)]
# 			règle distribution 4978 (1 fini)
# 		forme classe finidrô : [4977 (1 fini)]
# 			règle distribution 4977 (1 fini)
# 		forme classe finirô : [4978 (1 fini)]
# 			règle distribution 4978 (1 fini)
# 	vecteur prs.4=>prs.3
# 		forme classe finjô : [520 (1 fini), 2346 (0 finj)]
# 			règle distribution 520 (1 fini)
# 			règle distribution 2346 (0 finj)
# 		forme classe finisô : [2346 (0.34 finis), 2350 (0.66 fini)]
# 			règle distribution 2346 (0.34 finis)
# 			règle distribution 2350 (0.66 fini)
# 		forme classe finô : [2346 (1 fin)]
# 			règle distribution 2346 (1 fin)
# 		forme classe finisô : [2346 (0.34 finis), 2350 (0.66 fini)]
# 			règle distribution 2346 (0.34 finis)
# 			règle distribution 2350 (0.66 fini)
# 		forme classe finisô : [2346 (0.34 finis), 2350 (0.66 fini)]
# 			règle distribution 2346 (0.34 finis)
# 			règle distribution 2350 (0.66 fini)
# 	vecteur pst.6=>prs.3
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# 		forme classe finjEr : [8410 (1 fini), 8405 (0 finj)]
# 			règle distribution 8410 (1 fini)
# 			règle distribution 8405 (0 finj)
# 		forme classe finir : [8409 (1 fini)]
# 			règle distribution 8409 (1 fini)
# 	vecteur fut.5=>prs.3
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 	vecteur pst.sbj.2=>prs.3
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finjas : [8936 (1 fini), 8931 (0 finj)]
# 			règle distribution 8936 (1 fini)
# 			règle distribution 8931 (0 finj)
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 	vecteur imp.2=>prs.3
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 	vecteur cond.6=>prs.3
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 	vecteur sbjv.1=>prs.3
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 	vecteur sbjv.2=>prs.3
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 	vecteur cond.4=>prs.3
# 		forme classe finirjô : [5610 (1 fini)]
# 			règle distribution 5610 (1 fini)
# 		forme classe finidrijô : [5609 (1 fini)]
# 			règle distribution 5609 (1 fini)
# 		forme classe finirjô : [5610 (1 fini)]
# 			règle distribution 5610 (1 fini)
# 		forme classe finirjô : [5610 (1 fini)]
# 			règle distribution 5610 (1 fini)
# 	vecteur fut.6=>prs.3
# 		forme classe finirô : [4978 (1 fini)]
# 			règle distribution 4978 (1 fini)
# 		forme classe finirô : [4978 (1 fini)]
# 			règle distribution 4978 (1 fini)
# 		forme classe finidrô : [4977 (1 fini)]
# 			règle distribution 4977 (1 fini)
# 		forme classe finirô : [4978 (1 fini)]
# 			règle distribution 4978 (1 fini)
# 	vecteur fut.3=>prs.3
# 		forme classe finidra : [4356 (1 fini)]
# 			règle distribution 4356 (1 fini)
# 		forme classe finira : [4357 (1 fini)]
# 			règle distribution 4357 (1 fini)
# 		forme classe finira : [4357 (1 fini)]
# 			règle distribution 4357 (1 fini)
# 		forme classe finira : [4357 (1 fini)]
# 			règle distribution 4357 (1 fini)
# 	vecteur ipf.3=>prs.3
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 	vecteur prs.1=>prs.3
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 	vecteur ipf.1=>prs.3
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 	vecteur imp.4=>prs.3
# 		forme classe finjô : [520 (1 fini), 2346 (0 finj)]
# 			règle distribution 520 (1 fini)
# 			règle distribution 2346 (0 finj)
# 		forme classe finisô : [2346 (0.34 finis), 2350 (0.66 fini)]
# 			règle distribution 2346 (0.34 finis)
# 			règle distribution 2350 (0.66 fini)
# 		forme classe finisô : [2346 (0.34 finis), 2350 (0.66 fini)]
# 			règle distribution 2346 (0.34 finis)
# 			règle distribution 2350 (0.66 fini)
# 		forme classe finô : [2346 (1 fin)]
# 			règle distribution 2346 (1 fin)
# 		forme classe finisô : [2346 (0.34 finis), 2350 (0.66 fini)]
# 			règle distribution 2346 (0.34 finis)
# 			règle distribution 2350 (0.66 fini)
# 	vecteur sbjv.6=>prs.3
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fin : [1623 (1 fin)]
# 			règle distribution 1623 (1 fin)
# 		forme classe finis : [2891 (0.66 fini), 1623 (0.34 finis)]
# 			règle distribution 2891 (0.66 fini)
# 			règle distribution 1623 (0.34 finis)
# 		forme classe fini : [1623 (1 fini)]
# 			règle distribution 1623 (1 fini)
# 	vecteur pst.4=>prs.3
# 		forme classe finim : [7364 (1 fini)]
# 			règle distribution 7364 (1 fini)
# 		forme classe finim : [7364 (1 fini)]
# 			règle distribution 7364 (1 fini)
# 		forme classe finjam : [7360 (0 finj), 7365 (1 fini)]
# 			règle distribution 7360 (0 finj)
# 			règle distribution 7365 (1 fini)
# 		forme classe finim : [7364 (1 fini)]
# 			règle distribution 7364 (1 fini)
# 	vecteur cond.5=>prs.3
# 		forme classe finirjE : [6224 (1 fini)]
# 			règle distribution 6224 (1 fini)
# 		forme classe finirjE : [6224 (1 fini)]
# 			règle distribution 6224 (1 fini)
# 		forme classe finidrijE : [6223 (1 fini)]
# 			règle distribution 6223 (1 fini)
# 		forme classe finirjE : [6224 (1 fini)]
# 			règle distribution 6224 (1 fini)
# 	vecteur fut.2=>prs.3
# 		forme classe finidra : [4356 (1 fini)]
# 			règle distribution 4356 (1 fini)
# 		forme classe finira : [4357 (1 fini)]
# 			règle distribution 4357 (1 fini)
# 		forme classe finira : [4357 (1 fini)]
# 			règle distribution 4357 (1 fini)
# 		forme classe finira : [4357 (1 fini)]
# 			règle distribution 4357 (1 fini)
# 	vecteur fut.1=>prs.3
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 	vecteur ipf.5=>prs.3
# 		forme classe finisjE : [1041 (0.33 finis), 12 (0.02 finisi), 1046 (0.65 fini)]
# 			règle distribution 1041 (0.33 finis)
# 			règle distribution 12 (0.02 finisi)
# 			règle distribution 1046 (0.65 fini)
# 		forme classe finisjE : [1041 (0.33 finis), 12 (0.02 finisi), 1046 (0.65 fini)]
# 			règle distribution 1041 (0.33 finis)
# 			règle distribution 12 (0.02 finisi)
# 			règle distribution 1046 (0.65 fini)
# 		forme classe finjE : [1041 (0.93 fin), 12 (0.07 fini)]
# 			règle distribution 1041 (0.93 fin)
# 			règle distribution 12 (0.07 fini)
# 		forme classe finjE : [1041 (0.93 fin), 12 (0.07 fini)]
# 			règle distribution 1041 (0.93 fin)
# 			règle distribution 12 (0.07 fini)
# 		forme classe finisjE : [1041 (0.33 finis), 12 (0.02 finisi), 1046 (0.65 fini)]
# 			règle distribution 1041 (0.33 finis)
# 			règle distribution 12 (0.02 finisi)
# 			règle distribution 1046 (0.65 fini)
# 	vecteur sbjv.4=>prs.3
# 		forme classe finisjô : [520 (0.02 finisi), 514 (0.33 finis), 519 (0.65 fini)]
# 			règle distribution 520 (0.02 finisi)
# 			règle distribution 514 (0.33 finis)
# 			règle distribution 519 (0.65 fini)
# 		forme classe finjô : [520 (0.07 fini), 514 (0.93 fin)]
# 			règle distribution 520 (0.07 fini)
# 			règle distribution 514 (0.93 fin)
# 		forme classe finisjô : [520 (0.02 finisi), 514 (0.33 finis), 519 (0.65 fini)]
# 			règle distribution 520 (0.02 finisi)
# 			règle distribution 514 (0.33 finis)
# 			règle distribution 519 (0.65 fini)
# 		forme classe finisjô : [520 (0.02 finisi), 514 (0.33 finis), 519 (0.65 fini)]
# 			règle distribution 520 (0.02 finisi)
# 			règle distribution 514 (0.33 finis)
# 			règle distribution 519 (0.65 fini)
# 		forme classe finjô : [520 (0.07 fini), 514 (0.93 fin)]
# 			règle distribution 520 (0.07 fini)
# 			règle distribution 514 (0.93 fin)
# 	vecteur imp.5=>prs.3
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 	vecteur pst.sbj.1=>prs.3
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finjas : [8936 (1 fini), 8931 (0 finj)]
# 			règle distribution 8936 (1 fini)
# 			règle distribution 8931 (0 finj)
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 		forme classe finis : [8935 (1 fini)]
# 			règle distribution 8935 (1 fini)
# 	vecteur inf=>prs.3
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finir : [10450 (1 fini)]
# 			règle distribution 10450 (1 fini)
# 		forme classe finir : [10450 (1 fini)]
# 			règle distribution 10450 (1 fini)
# 	vecteur cond.3=>prs.3
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 	vecteur cond.1=>prs.3
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 	vecteur pst.5=>prs.3
# 		forme classe finit : [7887 (1 fini)]
# 			règle distribution 7887 (1 fini)
# 		forme classe finit : [7887 (1 fini)]
# 			règle distribution 7887 (1 fini)
# 		forme classe finjat : [7888 (1 fini), 7883 (0 finj)]
# 			règle distribution 7888 (1 fini)
# 			règle distribution 7883 (0 finj)
# 		forme classe finit : [7887 (1 fini)]
# 			règle distribution 7887 (1 fini)
# 	vecteur ipf.6=>prs.3
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 	vecteur prs.5=>prs.3
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finjE : [12 (1 fini), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 7 (0 finj)
# 		forme classe finE : [7 (1 fin)]
# 			règle distribution 7 (1 fin)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 		forme classe finisE : [11 (0.66 fini), 7 (0.34 finis)]
# 			règle distribution 11 (0.66 fini)
# 			règle distribution 7 (0.34 finis)
# 	vecteur cond.2=>prs.3
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 	vecteur ipf.4=>prs.3
# 		forme classe finisjô : [520 (0.02 finisi), 514 (0.33 finis), 519 (0.65 fini)]
# 			règle distribution 520 (0.02 finisi)
# 			règle distribution 514 (0.33 finis)
# 			règle distribution 519 (0.65 fini)
# 		forme classe finjô : [520 (0.07 fini), 514 (0.93 fin)]
# 			règle distribution 520 (0.07 fini)
# 			règle distribution 514 (0.93 fin)
# 		forme classe finisjô : [520 (0.02 finisi), 514 (0.33 finis), 519 (0.65 fini)]
# 			règle distribution 520 (0.02 finisi)
# 			règle distribution 514 (0.33 finis)
# 			règle distribution 519 (0.65 fini)
# 		forme classe finisjô : [520 (0.02 finisi), 514 (0.33 finis), 519 (0.65 fini)]
# 			règle distribution 520 (0.02 finisi)
# 			règle distribution 514 (0.33 finis)
# 			règle distribution 519 (0.65 fini)
# 		forme classe finjô : [520 (0.07 fini), 514 (0.93 fin)]
# 			règle distribution 520 (0.07 fini)
# 			règle distribution 514 (0.93 fin)
# 	vecteur pst.sbj.4=>prs.3
# 		forme classe finisjô : [9453 (1 fini)]
# 			règle distribution 9453 (1 fini)
# 		forme classe finisjô : [9453 (1 fini)]
# 			règle distribution 9453 (1 fini)
# 		forme classe finjasjô : [9449 (0 finj), 9454 (1 fini)]
# 			règle distribution 9449 (0 finj)
# 			règle distribution 9454 (1 fini)
# 		forme classe finisjô : [9453 (1 fini)]
# 			règle distribution 9453 (1 fini)
# nom Case prs.2
# 	vecteur pst.pcp=>prs.2
# 		forme classe finjE : [12 (1 fini), 2254 (0 finjE), 7 (0 finj)]
# 			règle distribution 12 (1 fini)
# 			règle distribution 2254 (0 finjE)
# 			règle distribution 7 (0 finj)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 		forme classe finy : [2254 (0 finy), 6815 (1 finE)]
# 			règle distribution 2254 (0 finy)
# 			règle distribution 6815 (1 finE)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 	vecteur cond.2=>prs.2
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finidrE : [3737 (1 fini)]
# 			règle distribution 3737 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# 			règle distribution 3738 (1 fini)
# 		forme classe finirE : [3738 (1 fini)]
# ...
# 			règle distribution 11111 (0.89 fini)
# 		forme classe finâ : [10837 (0.96 finE), 11110 (0.04 fini)]
# 			règle distribution 10837 (0.96 finE)
# 			règle distribution 11110 (0.04 fini)
# 		forme classe finisâ : [10837 (0.11 finisE), 11110 (0 finisi), 11111 (0.89 fini)]
# 			règle distribution 10837 (0.11 finisE)
# 			règle distribution 11110 (0 finisi)
# 			règle distribution 11111 (0.89 fini)
# 		forme classe finisâ : [10837 (0.11 finisE), 11110 (0 finisi), 11111 (0.89 fini)]
# 			règle distribution 10837 (0.11 finisE)
# 			règle distribution 11110 (0 finisi)
# 			règle distribution 11111 (0.89 fini)
# 		forme classe finjâ : [10837 (1 finjE)]
# 			règle distribution 10837 (1 finjE)
# 	vecteur sbjv.1=>pst.1
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe fini : [1499 (1 finjE), 1494 (0 finiE)]
# 			règle distribution 1499 (1 finjE)
# 			règle distribution 1494 (0 finiE)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe fin : [1494 (0.95 finE), 3063 (0.05 fini)]
# 			règle distribution 1494 (0.95 finE)
# 			règle distribution 3063 (0.05 fini)
# 		forme classe fin : [1494 (0.95 finE), 3063 (0.05 fini)]
# 			règle distribution 1494 (0.95 finE)
# 			règle distribution 3063 (0.05 fini)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 	vecteur sbjv.6=>pst.1
# 		forme classe fin : [1494 (0.95 finE), 3063 (0.05 fini)]
# 			règle distribution 1494 (0.95 finE)
# 			règle distribution 3063 (0.05 fini)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe fin : [1494 (0.95 finE), 3063 (0.05 fini)]
# 			règle distribution 1494 (0.95 finE)
# 			règle distribution 3063 (0.05 fini)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe fini : [1499 (1 finjE), 1494 (0 finiE)]
# 			règle distribution 1499 (1 finjE)
# 			règle distribution 1494 (0 finiE)
# 	vecteur pst.2=>pst.1
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 		forme classe finja : [7154 (1 finjE)]
# 			règle distribution 7154 (1 finjE)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 		forme classe fini : [2254 (1 fini)]
# 			règle distribution 2254 (1 fini)
# 	vecteur ipf.4=>pst.1
# 		forme classe finisjô : [512 (0.02 finisjE), 786 (0 finisi), 787 (0.89 fini), 511 (0.09 finisE)]
# 			règle distribution 512 (0.02 finisjE)
# 			règle distribution 786 (0 finisi)
# 			règle distribution 787 (0.89 fini)
# 			règle distribution 511 (0.09 finisE)
# 		forme classe finjô : [512 (0.06 finjE), 786 (0.04 fini), 511 (0.9 finE)]
# 			règle distribution 512 (0.06 finjE)
# 			règle distribution 786 (0.04 fini)
# 			règle distribution 511 (0.9 finE)
# 		forme classe finisjô : [512 (0.02 finisjE), 786 (0 finisi), 787 (0.89 fini), 511 (0.09 finisE)]
# 			règle distribution 512 (0.02 finisjE)
# 			règle distribution 786 (0 finisi)
# 			règle distribution 787 (0.89 fini)
# 			règle distribution 511 (0.09 finisE)
# 		forme classe finisjô : [512 (0.02 finisjE), 786 (0 finisi), 787 (0.89 fini), 511 (0.09 finisE)]
# 			règle distribution 512 (0.02 finisjE)
# 			règle distribution 786 (0 finisi)
# 			règle distribution 787 (0.89 fini)
# 			règle distribution 511 (0.09 finisE)
# 		forme classe finjô : [512 (0.06 finjE), 786 (0.04 fini), 511 (0.9 finE)]
# 			règle distribution 512 (0.06 finjE)
# 			règle distribution 786 (0.04 fini)
# 			règle distribution 511 (0.9 finE)
# 	vecteur ipf.3=>pst.1
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 		forme classe finjE : [0 (1 finjE)]
# 			règle distribution 0 (1 finjE)
# 		forme classe finE : [0 (0.96 finE), 268 (0.04 fini)]
# 			règle distribution 0 (0.96 finE)
# 			règle distribution 268 (0.04 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 		forme classe finE : [0 (0.96 finE), 268 (0.04 fini)]
# 			règle distribution 0 (0.96 finE)
# 			règle distribution 268 (0.04 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 	vecteur sbjv.3=>pst.1
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe fini : [1499 (1 finjE), 1494 (0 finiE)]
# 			règle distribution 1499 (1 finjE)
# 			règle distribution 1494 (0 finiE)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 		forme classe fin : [1494 (0.95 finE), 3063 (0.05 fini)]
# 			règle distribution 1494 (0.95 finE)
# 			règle distribution 3063 (0.05 fini)
# 		forme classe fin : [1494 (0.95 finE), 3063 (0.05 fini)]
# 			règle distribution 1494 (0.95 finE)
# 			règle distribution 3063 (0.05 fini)
# 		forme classe finis : [3064 (0.89 fini), 1494 (0.11 finisE), 3063 (0 finisi)]
# 			règle distribution 3064 (0.89 fini)
# 			règle distribution 1494 (0.11 finisE)
# 			règle distribution 3063 (0 finisi)
# 	vecteur ipf.1=>pst.1
# 		forme classe finE : [0 (0.96 finE), 268 (0.04 fini)]
# 			règle distribution 0 (0.96 finE)
# 			règle distribution 268 (0.04 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 		forme classe finjE : [0 (1 finjE)]
# 			règle distribution 0 (1 finjE)
# 		forme classe finE : [0 (0.96 finE), 268 (0.04 fini)]
# 			règle distribution 0 (0.96 finE)
# 			règle distribution 268 (0.04 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 	vecteur cond.4=>pst.1
# 		forme classe finirjô : [5507 (0.5 finjE), 5509 (0 finiE), 5726 (0.5 fini)]
# 			règle distribution 5507 (0.5 finjE)
# 			règle distribution 5509 (0 finiE)
# 			règle distribution 5726 (0.5 fini)
# 		forme classe finirjô : [5507 (0.5 finjE), 5509 (0 finiE), 5726 (0.5 fini)]
# 			règle distribution 5507 (0.5 finjE)
# 			règle distribution 5509 (0 finiE)
# 			règle distribution 5726 (0.5 fini)
# 		forme classe finirjô : [5507 (0.5 finjE), 5509 (0 finiE), 5726 (0.5 fini)]
# 			règle distribution 5507 (0.5 finjE)
# 			règle distribution 5509 (0 finiE)
# 			règle distribution 5726 (0.5 fini)
# 	vecteur sbjv.4=>pst.1
# 		forme classe finisjô : [512 (0.02 finisjE), 786 (0 finisi), 787 (0.89 fini), 511 (0.09 finisE)]
# 			règle distribution 512 (0.02 finisjE)
# 			règle distribution 786 (0 finisi)
# 			règle distribution 787 (0.89 fini)
# 			règle distribution 511 (0.09 finisE)
# 		forme classe finjô : [512 (0.06 finjE), 786 (0.04 fini), 511 (0.9 finE)]
# 			règle distribution 512 (0.06 finjE)
# 			règle distribution 786 (0.04 fini)
# 			règle distribution 511 (0.9 finE)
# 		forme classe finisjô : [512 (0.02 finisjE), 786 (0 finisi), 787 (0.89 fini), 511 (0.09 finisE)]
# 			règle distribution 512 (0.02 finisjE)
# 			règle distribution 786 (0 finisi)
# 			règle distribution 787 (0.89 fini)
# 			règle distribution 511 (0.09 finisE)
# 		forme classe finisjô : [512 (0.02 finisjE), 786 (0 finisi), 787 (0.89 fini), 511 (0.09 finisE)]
# 			règle distribution 512 (0.02 finisjE)
# 			règle distribution 786 (0 finisi)
# 			règle distribution 787 (0.89 fini)
# 			règle distribution 511 (0.09 finisE)
# 		forme classe finjô : [512 (0.06 finjE), 786 (0.04 fini), 511 (0.9 finE)]
# 			règle distribution 512 (0.06 finjE)
# 			règle distribution 786 (0.04 fini)
# 			règle distribution 511 (0.9 finE)
# 	vecteur sbjv.5=>pst.1
# 		forme classe finisjE : [1276 (0 finisi), 1277 (0.89 fini), 6 (0.02 finisjE), 1039 (0.09 finisE)]
# 			règle distribution 1276 (0 finisi)
# 			règle distribution 1277 (0.89 fini)
# 			règle distribution 6 (0.02 finisjE)
# 			règle distribution 1039 (0.09 finisE)
# 		forme classe finjE : [1276 (0.04 fini), 6 (0.06 finjE), 1039 (0.9 finE)]
# 			règle distribution 1276 (0.04 fini)
# 			règle distribution 6 (0.06 finjE)
# 			règle distribution 1039 (0.9 finE)
# 		forme classe finisjE : [1276 (0 finisi), 1277 (0.89 fini), 6 (0.02 finisjE), 1039 (0.09 finisE)]
# 			règle distribution 1276 (0 finisi)
# 			règle distribution 1277 (0.89 fini)
# 			règle distribution 6 (0.02 finisjE)
# 			règle distribution 1039 (0.09 finisE)
# 		forme classe finisjE : [1276 (0 finisi), 1277 (0.89 fini), 6 (0.02 finisjE), 1039 (0.09 finisE)]
# 			règle distribution 1276 (0 finisi)
# 			règle distribution 1277 (0.89 fini)
# 			règle distribution 6 (0.02 finisjE)
# 			règle distribution 1039 (0.09 finisE)
# 		forme classe finjE : [1276 (0.04 fini), 6 (0.06 finjE), 1039 (0.9 finE)]
# 			règle distribution 1276 (0.04 fini)
# 			règle distribution 6 (0.06 finjE)
# 			règle distribution 1039 (0.9 finE)
# 	vecteur fut.6=>pst.1
# 		forme classe finirô : [4876 (0.5 finjE), 5092 (0.5 fini), 5094 (0 finiE)]
# 			règle distribution 4876 (0.5 finjE)
# 			règle distribution 5092 (0.5 fini)
# 			règle distribution 5094 (0 finiE)
# 		forme classe finirô : [4876 (0.5 finjE), 5092 (0.5 fini), 5094 (0 finiE)]
# 			règle distribution 4876 (0.5 finjE)
# 			règle distribution 5092 (0.5 fini)
# 			règle distribution 5094 (0 finiE)
# 		forme classe finirô : [4876 (0.5 finjE), 5092 (0.5 fini), 5094 (0 finiE)]
# 			règle distribution 4876 (0.5 finjE)
# 			règle distribution 5092 (0.5 fini)
# 			règle distribution 5094 (0 finiE)
# 	vecteur fut.1=>pst.1
# 		forme classe finirE : [3636 (0.5 finjE), 3852 (0.5 fini), 3854 (0 finiE)]
# 			règle distribution 3636 (0.5 finjE)
# 			règle distribution 3852 (0.5 fini)
# 			règle distribution 3854 (0 finiE)
# 		forme classe finirE : [3636 (0.5 finjE), 3852 (0.5 fini), 3854 (0 finiE)]
# 			règle distribution 3636 (0.5 finjE)
# 			règle distribution 3852 (0.5 fini)
# 			règle distribution 3854 (0 finiE)
# 		forme classe finirE : [3636 (0.5 finjE), 3852 (0.5 fini), 3854 (0 finiE)]
# 			règle distribution 3636 (0.5 finjE)
# 			règle distribution 3852 (0.5 fini)
# 			règle distribution 3854 (0 finiE)
# 	vecteur ipf.6=>pst.1
# 		forme classe finE : [0 (0.96 finE), 268 (0.04 fini)]
# 			règle distribution 0 (0.96 finE)
# 			règle distribution 268 (0.04 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 		forme classe finjE : [0 (1 finjE)]
# 			règle distribution 0 (1 finjE)
# 		forme classe finE : [0 (0.96 finE), 268 (0.04 fini)]
# 			règle distribution 0 (0.96 finE)
# 			règle distribution 268 (0.04 fini)
# 		forme classe finisE : [0 (0.11 finisE), 268 (0 finisi), 269 (0.89 fini)]
# 			règle distribution 0 (0.11 finisE)
# 			règle distribution 268 (0 finisi)
# 			règle distribution 269 (0.89 fini)
# 	vecteur pst.pcp=>pst.1
# 		forme classe finjE : [7145 (1 finjE)]
# 			règle distribution 7145 (1 finjE)
# 		forme classe fini : [7145 (1 fini)]
# 			règle distribution 7145 (1 fini)
# 		forme classe fini : [7145 (1 fini)]
# 			règle distribution 7145 (1 fini)
# 		forme classe finy : [7145 (1 finy)]
# 			règle distribution 7145 (1 finy)
# 		forme classe fini : [7145 (1 fini)]
# 			règle distribution 7145 (1 fini)
# {'prs.3': [("fini",0.76),("fin",0.15),("finis",0.09)], 'prs.2': [("fini",0.76),("fin",0.15),("finis",0.09)], 'prs.1': [("fini",0.76),("fin",0.15),("finis",0.09)], 'prs.6': [("finis",0.57),("fin",0.21),("fini",0.16),("finid",0.06)], 'prs.5': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)], 'prs.4': [("finisô",0.56),("finô",0.21),("finjô",0.17),("finidô",0.06)], 'pst.sbj.6': [("finis",0.56),("finjas",0.26),("finas",0.15),("finisas",0.03)], 'pst.sbj.4': [("finisjô",0.56),("finjasjô",0.26),("finasjô",0.15),("finisasjô",0.03)], 'pst.sbj.5': [("finisjE",0.56),("finjasjE",0.26),("finasjE",0.15),("finisasjE",0.03)], 'pst.sbj.2': [("finis",0.56),("finjas",0.26),("finas",0.15),("finisas",0.03)], 'pst.sbj.3': [("fini",0.56),("finja",0.26),("fina",0.15),("finisa",0.03)], 'pst.sbj.1': [("finis",0.56),("finjas",0.26),("finas",0.15),("finisas",0.03)], 'sbjv.4': [("finisjô",0.6),("finjô",0.34),("finidjô",0.06)], 'pst.pcp': [("fini",0.53),("finjE",0.27),("finE",0.15),("finisE",0.05)], 'sbjv.5': [("finisjE",0.6),("finjE",0.34),("finidjE",0.06)], 'sbjv.6': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)], 'prs.pcp': [("finisâ",0.56),("finâ",0.21),("finjâ",0.17),("finidâ",0.06)], 'sbjv.1': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)], 'sbjv.2': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)], 'sbjv.3': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)], 'inf': [("finir",0.53),("finjE",0.24),("finE",0.15),("finidr",0.06),("finisE",0.02)], 'imp.4': [("finisô",0.56),("finô",0.21),("finjô",0.17),("finidô",0.06)], 'fut.5': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)], 'fut.4': [("finirô",0.78),("fin6rô",0.15),("finidrô",0.05),("finis6rô",0.02)], 'fut.3': [("finira",0.78),("fin6ra",0.15),("finidra",0.05),("finis6ra",0.02)], 'fut.2': [("finira",0.78),("fin6ra",0.15),("finidra",0.05),("finis6ra",0.02)], 'fut.1': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)], 'cond.6': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)], 'cond.5': [("finirjE",0.78),("fin6rjE",0.15),("finidrijE",0.05),("finis6rjE",0.02)], 'cond.4': [("finirjô",0.78),("fin6rjô",0.15),("finidrijô",0.05),("finis6rjô",0.02)], 'cond.3': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)], 'cond.2': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)], 'cond.1': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)], 'fut.6': [("finirô",0.78),("fin6rô",0.15),("finidrô",0.05),("finis6rô",0.02)], 'ipf.5': [("finisjE",0.6),("finjE",0.34),("finidjE",0.06)], 'ipf.4': [("finisjô",0.6),("finjô",0.34),("finidjô",0.06)], 'imp.2': [("fini",0.76),("fin",0.15),("finis",0.09)], 'ipf.6': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)], 'ipf.1': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)], 'imp.5': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)], 'ipf.3': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)], 'ipf.2': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)], 'pst.6': [("finir",0.56),("finjEr",0.26),("finEr",0.15),("finisEr",0.03)], 'pst.5': [("finit",0.56),("finjat",0.26),("finat",0.15),("finisat",0.03)], 'pst.4': [("finim",0.56),("finjam",0.26),("finam",0.15),("finisam",0.03)], 'pst.3': [("fini",0.56),("finja",0.26),("fina",0.15),("finisa",0.03)], 'pst.2': [("fini",0.56),("finja",0.26),("fina",0.15),("finisa",0.03)], 'pst.1': [("fini",0.56),("finjE",0.26),("finE",0.15),("finisE",0.03)]}

# %% [markdown]
# for nomCase in verbe.sorties:
#     case=Case(nomCase)
#     for vecteur in verbe.sorties[nomCase]:
#         for element in verbe.sorties[nomCase][vecteur].numRulesDist():
#             case.addForm(FormeCoef(element.sortie,element.dist))
#     verbe.nouveau[nomCase]=case

# %%
verbe.nouveau
# Out:
# {'prs.3': [("fini",0.76),("fin",0.15),("finis",0.09)],
#  'prs.2': [("fini",0.76),("fin",0.15),("finis",0.09)],
#  'prs.1': [("fini",0.76),("fin",0.15),("finis",0.09)],
#  'prs.6': [("finis",0.57),("fin",0.21),("fini",0.16),("finid",0.06)],
#  'prs.5': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)],
#  'prs.4': [("finisô",0.56),("finô",0.21),("finjô",0.17),("finidô",0.06)],
#  'pst.sbj.6': [("finis",0.56),("finjas",0.26),("finas",0.15),("finisas",0.03)],
#  'pst.sbj.4': [("finisjô",0.56),("finjasjô",0.26),("finasjô",0.15),("finisasjô",0.03)],
#  'pst.sbj.5': [("finisjE",0.56),("finjasjE",0.26),("finasjE",0.15),("finisasjE",0.03)],
#  'pst.sbj.2': [("finis",0.56),("finjas",0.26),("finas",0.15),("finisas",0.03)],
#  'pst.sbj.3': [("fini",0.56),("finja",0.26),("fina",0.15),("finisa",0.03)],
#  'pst.sbj.1': [("finis",0.56),("finjas",0.26),("finas",0.15),("finisas",0.03)],
#  'sbjv.4': [("finisjô",0.6),("finjô",0.34),("finidjô",0.06)],
#  'pst.pcp': [("fini",0.53),("finjE",0.27),("finE",0.15),("finisE",0.05)],
#  'sbjv.5': [("finisjE",0.6),("finjE",0.34),("finidjE",0.06)],
#  'sbjv.6': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)],
#  'prs.pcp': [("finisâ",0.56),("finâ",0.21),("finjâ",0.17),("finidâ",0.06)],
#  'sbjv.1': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)],
#  'sbjv.2': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)],
#  'sbjv.3': [("finis",0.56),("fin",0.21),("fini",0.17),("finid",0.06)],
#  'inf': [("finir",0.53),("finjE",0.24),("finE",0.15),("finidr",0.06),("finisE",0.02)],
#  'imp.4': [("finisô",0.56),("finô",0.21),("finjô",0.17),("finidô",0.06)],
#  'fut.5': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)],
#  'fut.4': [("finirô",0.78),("fin6rô",0.15),("finidrô",0.05),("finis6rô",0.02)],
#  'fut.3': [("finira",0.78),("fin6ra",0.15),("finidra",0.05),("finis6ra",0.02)],
#  'fut.2': [("finira",0.78),("fin6ra",0.15),("finidra",0.05),("finis6ra",0.02)],
#  'fut.1': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)],
#  'cond.6': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)],
#  'cond.5': [("finirjE",0.78),("fin6rjE",0.15),("finidrijE",0.05),("finis6rjE",0.02)],
#  'cond.4': [("finirjô",0.78),("fin6rjô",0.15),("finidrijô",0.05),("finis6rjô",0.02)],
#  'cond.3': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)],
#  'cond.2': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)],
#  'cond.1': [("finirE",0.78),("fin6rE",0.15),("finidrE",0.05),("finis6rE",0.02)],
#  'fut.6': [("finirô",0.78),("fin6rô",0.15),("finidrô",0.05),("finis6rô",0.02)],
#  'ipf.5': [("finisjE",0.6),("finjE",0.34),("finidjE",0.06)],
#  'ipf.4': [("finisjô",0.6),("finjô",0.34),("finidjô",0.06)],
#  'imp.2': [("fini",0.76),("fin",0.15),("finis",0.09)],
#  'ipf.6': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)],
#  'ipf.1': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)],
#  'imp.5': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)],
#  'ipf.3': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)],
#  'ipf.2': [("finisE",0.56),("finE",0.21),("finjE",0.17),("finidE",0.06)],
#  'pst.6': [("finir",0.56),("finjEr",0.26),("finEr",0.15),("finisEr",0.03)],
#  'pst.5': [("finit",0.56),("finjat",0.26),("finat",0.15),("finisat",0.03)],
#  'pst.4': [("finim",0.56),("finjam",0.26),("finam",0.15),("finisam",0.03)],
#  'pst.3': [("fini",0.56),("finja",0.26),("fina",0.15),("finisa",0.03)],
#  'pst.2': [("fini",0.56),("finja",0.26),("fina",0.15),("finisa",0.03)],
#  'pst.1': [("fini",0.56),("finjE",0.26),("finE",0.15),("finisE",0.03)]}

# %%
etayage(verbe,2)

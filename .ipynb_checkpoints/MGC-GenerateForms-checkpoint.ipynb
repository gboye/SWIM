# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
import yaml

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
samplePrefix="MGC-150815-extend-02-X-paradigmes"
sampleFile=samplePrefix+".csv"
goldFile="MGC-150815-total-1508150555-paradigmes.csv"
analysisPrefix="MGC-150815-extend-02-X"
logfile_name=analysisPrefix+samplePrefix+".log"
logfile = codecs.open("2015-Data/"+logfile_name,mode='w',encoding="utf8")

# %% [markdown]
# ###Préparation des cases du paradigme

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# #Préparation du calcul des analogies

# %% [markdown]
# ###Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ###Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ###Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ###Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmes=pd.read_csv("2015-Data/"+sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]

# %%
phonologicalMap=analysisPrefix[-2:]
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="-N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="-S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("-X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %%
GOLD=pd.read_csv("2015-Data/"+goldFile,sep=";",encoding="utf8")
del GOLD[u"Unnamed: 0"]
goldCases=GOLD.columns.tolist()
goldCases.remove(u"lexeme")
for case in goldCases:
    GOLD[case]=GOLD[case].apply(lambda x: recoder(x))
    
paradigmesGOLD=GOLD[paradigmes.columns.values.tolist()]
paradigmesGOLD
# Out:
#              lexeme         ai1P        ai1S         ai2P        ai2S  \
# 0          abaisser       abEsam       abEsE       abEsat       abEsa
# 1        abandonner     abâdOnam     abâdOnE     abâdOnat     abâdOna
# 2        abasourdir    abazurdim    abazurdi    abazurdit    abazurdi
# 3           abattre       abatim       abati       abatit       abati
# 4           abcéder      absEdam      absEdE      absEdat      absEda
# 5          abdiquer      abdikam      abdikE      abdikat      abdika
# 6          abecquer       abEkam       abEkE       abEkat       abEka
# 7           aberrer       abEram       abErE       abErat       abEra
# 8          abhorrer       abOram       abOrE       abOrat       abOra
# 9           abjurer      abZyram      abZyrE      abZyrat      abZyra
# 10          ablater      ablatam      ablatE      ablatat      ablata
# 11          ablatir      ablatim      ablati      ablatit      ablati
# 12         abloquer      ablOkam      ablOkE      ablOkat      ablOka
# 13           abolir       abOlim       abOli       abOlit       abOli
# 14          abonder       abôdam       abôdE       abôdat       abôda
# 15          abonner       abOnam       abOnE       abOnat       abOna
# 16          abonnir       abOnim       abOni       abOnit       abOni
# 17          aborder      abOrdam      abOrdE      abOrdat      abOrda
# 18          aborner      abOrnam      abOrnE      abOrnat      abOrna
# 19         aboucher       abuSam       abuSE       abuSat       abuSa
# 20          abouler       abulam       abulE       abulat       abula
# 21          abouter       abutam       abutE       abutat       abuta
# 22          aboutir       abutim       abuti       abutit       abuti
# 23           aboyer      abwajam      abwajE      abwajat      abwaja
# 24          abraser      abrazam      abrazE      abrazat      abraza
# 25         abreuver      abr6vam      abr6vE      abr6vat      abr6va
# 26        abricoter    abrikOtam    abrikOtE    abrikOtat    abrikOta
# 27          abriter      abritam      abritE      abritat      abrita
# 28          abroger      abrOZam      abrOZE      abrOZat      abrOZa
# 29          abrutir      abrytim      abryti      abrytit      abryti
# ...             ...          ...         ...          ...         ...
# 6531      étreindre      EtrEJim      EtrEJi      EtrEJit      EtrEJi
# 6532       étrenner      EtrEnam      EtrEnE      EtrEnat      EtrEna
# 6533       étriller      Etrijam      EtrijE      Etrijat      Etrija
# 6557      EvOlyEr      EvOlya       EvOlyrô       EvOlyrE       EvOlyre
# 6558       EvOkEr       EvOka       EvOk6rô       EvOk6rE       EvOk6re
# 6559          fyr          fy          s6rô          s6rE          s6re
# 6560         OtEr         Ota         Ot6rô         Ot6rE         Ot6re
#
#         ...            ppFP        ppFS        ppMP        ppMS         ps1P  \
# 0       ...           abEse       abEse       abEse       abEse       abEsjô
# 1       ...         abâdOne     abâdOne     abâdOne     abâdOne     abâdOnjô
# 2       ...        abazurdi    abazurdi    abazurdi    abazurdi  abazurdisjô
# 3       ...           abaty       abaty       abaty       abaty       abatjô
# 4       ...             NaN         NaN         NaN      absEde      absEdjô
# 5       ...          abdike      abdike      abdike      abdike      abdikjô
# 6       ...           abEke       abEke       abEke       abEke       abEkjô
# 7       ...             NaN         NaN         NaN       abEre       abErjô
# 8       ...           abOre       abOre       abOre       abOre       abOrjô
# 9       ...          abZyre      abZyre      abZyre      abZyre      abZyrjô
# 10      ...          ablate      ablate      ablate      ablate      ablatjô
# 11      ...          ablati      ablati      ablati      ablati    ablatisjô
# 12      ...          ablOke      ablOke      ablOke      ablOke      ablOkjô
# 13      ...           abOli       abOli       abOli       abOli     abOlisjô
# 14      ...             NaN         NaN         NaN       abôde       abôdjô
# 15      ...           abOne       abOne       abOne       abOne       abOnjô
# 16      ...           abOni       abOni       abOni       abOni     abOnisjô
# 17      ...          abOrde      abOrde      abOrde      abOrde      abOrdjô
# 18      ...          abOrne      abOrne      abOrne      abOrne      abOrnjô
# 19      ...           abuSe       abuSe       abuSe       abuSe       abuSjô
# 20      ...           abule       abule       abule       abule       abuljô
# 21      ...           abute       abute       abute       abute       abutjô
# 22      ...             NaN         NaN         NaN       abuti     abutisjô
# 23      ...             NaN         NaN         NaN      abwaje       abwajô
# 24      ...          abraze      abraze      abraze      abraze      abrazjô
# 25      ...          abr6ve      abr6ve      abr6ve      abr6ve      abr6vjô
# 26      ...        abrikOte    abrikOte    abrikOte    abrikOte    abrikOtjô
# 27      ...          abrite      abrite      abrite      abrite      abritjô
# 28      ...          abrOZe      abrOZe      abrOZe      abrOZe      abrOZjô
# 29      ...          abryti      abryti      abryti      abryti    abrytisjô
# ...     ...             ...         ...         ...         ...          ...
# 6531    ...           Etrêt       Etrêt        Etrê        Etrê       EtrEJô
# 6532    ...          EtrEne      EtrEne      EtrEne      EtrEne      EtrEnjô
# 6533    ...          Etrije      Etrije      Etrije      Etrije       Etrijô
# 6534    ...          Etripe      Etripe      Etripe      Etripe      Etripjô
# 6535    ...          Etrike      Etrike      Etrike      Etrike      Etrikjô
# 6536    ...          EtrEsi      EtrEsi      EtrEsi      EtrEsi    EtrEsisjô
# 6537    ...      EtrEzijOne  EtrEzijOne  EtrEzijOne  EtrEzijOne  EtrEzijOnjô
# 6538    ...          Etydje      Etydje      Etydje      Etydje      Etydijô
# 6539    ...           Etyve       Etyve       Etyve       Etyve       Etyvjô
# 6540    ...           EtEte       EtEte       EtEte       EtEte       EtEtjô
# 6541    ...          Evakye      Evakye      Evakye      Evakye      Evakyjô
# 6542    ...           Evade       Evade       Evade       Evade       Evadjô
# 6543    ...          Evalye      Evalye      Evalye      Evalye      Evalyjô
# 6544    ...       EvâZElize   EvâZElize   EvâZElize   EvâZElize   EvâZElizjô
# 6545    ...          Evanui      Evanui      Evanui      Evanui    Evanuisjô
# 6546    ...         EvapOre     EvapOre     EvapOre     EvapOre     EvapOrjô
# 6547    ...           Evaze       Evaze       Evaze       Evaze       Evazjô
# 6548    ...           EvEje       EvEje       EvEje       EvEje        EvEjô
# 6549    ...           Evâte       Evâte       Evâte       Evâte       Evâtjô
# 6550    ...             NaN         NaN         NaN     Evâtije      Evâtijô
# 6551    ...          Evâtre      Evâtre      Evâtre      Evâtre      Evâtrjô
# 6552    ...         EvErtye     EvErtye     EvErtye     EvErtye     EvErtyjô
# 6553    ...           Evide       Evide       Evide       Evide       Evidjô
# 6554    ...           Evêse       Evêse       Evêse       Evêse       Evêsjô
# 6555    ...         EvisEre     EvisEre     EvisEre     EvisEre     EvisErjô
# 6556    ...           Evite       Evite       Evite       Evite       Evitjô
# 6557    ...             NaN         NaN         NaN      EvOlye      EvOlyjô
# 6558    ...           EvOke       EvOke       EvOke       EvOke       EvOkjô
# 6559    ...             NaN         NaN         NaN         Ete        swajô
# 6560    ...             Ote         Ote         Ote         Ote         Otjô
#
#            ps1S         ps2P       ps2S       ps3P       ps3S
# 0          abEs       abEsje       abEs       abEs       abEs
# 1        abâdOn     abâdOnje     abâdOn     abâdOn     abâdOn
# 2     abazurdis  abazurdisje  abazurdis  abazurdis  abazurdis
# 3          abat       abatje       abat       abat       abat
# 4         absEd      absEdje      absEd      absEd      absEd
# 5         abdik      abdikje      abdik      abdik      abdik
# 6          abEk       abEkje       abEk       abEk       abEk
# 7          abEr       abErje       abEr       abEr       abEr
# 8          abOr       abOrje       abOr       abOr       abOr
# 9         abZyr      abZyrje      abZyr      abZyr      abZyr
# 10        ablat      ablatje      ablat      ablat      ablat
# 11      ablatis    ablatisje    ablatis    ablatis    ablatis
# 12        ablOk      ablOkje      ablOk      ablOk      ablOk
# 13       abOlis     abOlisje     abOlis     abOlis     abOlis
# 14         abôd       abôdje       abôd       abôd       abôd
# 15         abOn       abOnje       abOn       abOn       abOn
# 16       abOnis     abOnisje     abOnis     abOnis     abOnis
# 17        abOrd      abOrdje      abOrd      abOrd      abOrd
# 18        abOrn      abOrnje      abOrn      abOrn      abOrn
# 19         abuS       abuSje       abuS       abuS       abuS
# 20         abul       abulje       abul       abul       abul
# 21         abut       abutje       abut       abut       abut
# 22       abutis     abutisje     abutis     abutis     abutis
# 23         abwa       abwaje       abwa       abwa       abwa
# 24        abraz      abrazje      abraz      abraz      abraz
# 25        abr9v      abr6vje      abr9v      abr9v      abr9v
# 26      abrikOt    abrikOtje    abrikOt    abrikOt    abrikOt
# 27        abrit      abritje      abrit      abrit      abrit
# 28        abrOZ      abrOZje      abrOZ      abrOZ      abrOZ
# 29      abrytis    abrytisje    abrytis    abrytis    abrytis
# ...         ...          ...        ...        ...        ...
# 6531      EtrEJ       EtrEJe      EtrEJ      EtrEJ      EtrEJ
# 6532      EtrEn      EtrEnje      EtrEn      EtrEn      EtrEn
# 6533      Etrij       Etrije      Etrij      Etrij      Etrij
# 6534      Etrip      Etripje      Etrip      Etrip      Etrip
# 6535      Etrik      Etrikje      Etrik      Etrik      Etrik
# 6536    EtrEsis    EtrEsisje    EtrEsis    EtrEsis    EtrEsis
# 6537  EtrEzijOn  EtrEzijOnje  EtrEzijOn  EtrEzijOn  EtrEzijOn
# 6538      Etydi      Etydije      Etydi      Etydi      Etydi
# 6539       Etyv       Etyvje       Etyv       Etyv       Etyv
# 6540       EtEt       EtEtje       EtEt       EtEt       EtEt
# 6541      Evaky      Evakyje      Evaky      Evaky      Evaky
# 6542       Evad       Evadje       Evad       Evad       Evad
# 6543      Evaly      Evalyje      Evaly      Evaly      Evaly
# 6544   EvâZEliz   EvâZElizje   EvâZEliz   EvâZEliz   EvâZEliz
# 6545    Evanuis    Evanuisje    Evanuis    Evanuis    Evanuis
# 6546     EvapOr     EvapOrje     EvapOr     EvapOr     EvapOr
# 6547       Evaz       Evazje       Evaz       Evaz       Evaz
# 6548       EvEj        EvEje       EvEj       EvEj       EvEj
# 6549       Evât       Evâtje       Evât       Evât       Evât
# 6550     Evâtij      Evâtije     Evâtij     Evâtij     Evâtij
# 6551      Evâtr      Evâtrje      Evâtr      Evâtr      Evâtr
# 6552     EvErty     EvErtyje     EvErty     EvErty     EvErty
# 6553       Evid       Evidje       Evid       Evid       Evid
# 6554       Evês       Evêsje       Evês       Evês       Evês
# 6555     EvisEr     EvisErje     EvisEr     EvisEr     EvisEr
# 6556       Evit       Evitje       Evit       Evit       Evit
# 6557      EvOly      EvOlyje      EvOly      EvOly      EvOly
# 6558       EvOk       EvOkje       EvOk       EvOk       EvOk
# 6559        swa        swaje        swa        swa        swa
# 6560         ot         Otje         ot         ot         ot
#
# [6561 rows x 51 columns]

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 33917

# %%
with open("2015-Data/"+analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ###Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(casesTotales):
    print ("Attention l'analyse ne comprend pas toutes les cases")
# Out:
# Attention l'analyse ne comprend pas toutes les cases

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie))
    return candidats

# %%
def generate(lexeme,genDigraphe=True):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme)
#    print ("génération 2",end=", ")
    generation2=generateParadigms(generation1,genDigraphe)
#    print ("génération 3")
    return generation2

# %%
len(paradigmes.dropna(thresh=11)["lexeme"])
# Out:
# 1078

# %%
# %%time
debug=False
genDigraphe=False
listeTest=[u"manger",u"boire",u"dormir",u"aller",u"neiger"]
listeTest=paradigmes.dropna(thresh=11)["lexeme"].values.tolist()
nbVerbes=len(listeTest)
print (nbVerbes)
digraphe=nx.DiGraph()
graphe=nx.Graph()
for i,element in enumerate(listeTest):
    if (i%10)==0: print (i, dateheure(), int(100*float(i)/nbVerbes), end=", ")
    generate(element,genDigraphe)
# Out:
# 1078
# 0 1508200459 0, 10 1508200500 0, 20 1508200501 1, 30 1508200502 2, 40 1508200503 3, 50 1508200511 4, 60 1508200512 5, 70 1508200513 6, 80 1508200514 7, 90 1508200515 8, 100 1508200516 9, 110 1508200516 10, 120 1508200517 11, 130 1508200518 12, 140 1508200519 12, 150 1508200520 13, 160 1508200520 14, 170 1508200521 15, 180 1508200522 16, 190 1508200523 17, 200 1508200524 18, 210 1508200525 19, 220 1508200525 20, 230 1508200526 21, 240 1508200527 22, 250 1508200528 23, 260 1508200529 24, 270 1508200530 25, 280 1508200531 25, 290 1508200531 26, 300 1508200532 27, 310 1508200533 28, 320 1508200534 29, 330 1508200535 30, 340 1508200541 31, 350 1508200542 32, 360 1508200542 33, 370 1508200545 34, 380 1508200545 35, 390 1508200546 36, 400 1508200603 37, 410 1508200604 38, 420 1508200605 38, 430 1508200606 39, 440 1508200606 40, 450 1508200646 41, 460 1508200647 42, 470 1508200647 43, 480 1508200652 44, 490 1508200653 45, 500 1508200654 46, 510 1508200655 47, 520 1508200941 48, 530 1508200942 49, 540 1508200943 50, 550 1508200943 51, 560 1508200945 51, 570 1508200946 52, 580 1508200947 53, 590 1508200949 54, 600 1508200950 55, 610 1508200951 56, 620 1508200952 57, 630 1508200954 58, 640 1508200955 59, 650 1508200956 60, 660 1508200958 61, 670 1508200959 62, 680 1508201001 63, 690 1508201002 64, 700 1508201003 64, 710 1508201005 65, 720 1508201006 66, 730 1508201007 67, 740 1508201009 68, 750 1508201010 69, 760 1508201011 70, 770 1508201012 71, 780 1508201013 72, 790 1508201015 73, 800 1508201016 74, 810 1508201017 75, 820 1508201018 76, 830 1508201020 76, 840 1508201021 77, 850 1508201022 78, 860 1508201023 79, 870 1508201040 80, 880 1508201041 81, 890 1508201042 82, 900 1508201044 83, 910 1508201045 84, 920 1508201046 85, 930 1508201047 86, 940 1508201049 87, 950 1508201050 88, 960 1508201051 89, 970 1508201052 89, 980 1508201053 90, 990 1508201054 91, 1000 1508201055 92, 1010 1508201056 93, 1020 1508201057 94, 1030 1508201058 95, 1040 1508201059 96, 1050 1508201101 97, 1060 1508201102 98, 1070 1508201103 99, CPU times: user 1h 48min 29s, sys: 58.5 s, total: 1h 49min 28s
# Wall time: 6h 4min 17s

# %%
# %%time
versionStamp=dateheure()
if genDigraphe: 
    nx.write_dot(digraphe,u"2015-Data/digraphe-%s.dot"%versionStamp)
nx.write_dot(graphe,u"2015-Data/graphe-%s.dot"%versionStamp)
# Out:
# CPU times: user 2min 20s, sys: 10.8 s, total: 2min 31s
# Wall time: 2min 35s

# %%
#graphe=nx.Graph()
#graphe=nx.read_dot(u"graphe-1508180522.dot")

# %%
# %%time
cliques=list(nx.algorithms.clique.find_cliques(graphe))
# Out:
# CPU times: user 37 s, sys: 1.93 s, total: 39 s
# Wall time: 41.3 s

# %%
print (len(cliques))
# Out:
# 253196

# %%
longueurCliques={}
for clique in cliques:
    longueur=len(clique)
    if not longueur in longueurCliques:
        longueurCliques[longueur]=1
    else:
        longueurCliques[longueur]+=1
longueurCliques
# Out:
# {2: 484,
#  3: 2232,
#  4: 3561,
#  5: 3810,
#  6: 5282,
#  7: 7693,
#  8: 10572,
#  9: 14189,
#  10: 14048,
#  11: 13364,
#  12: 14499,
#  13: 13605,
#  14: 13573,
#  15: 12175,
#  16: 10753,
#  17: 10097,
#  18: 9871,
#  19: 11353,
#  20: 11807,
#  21: 11864,
#  22: 10073,
#  23: 9589,
#  24: 8051,
#  25: 7087,
#  26: 5508,
#  27: 3531,
#  28: 2330,
#  29: 1507,
#  30: 1588,
#  31: 1439,
#  32: 944,
#  33: 769,
#  34: 1080,
#  35: 1172,
#  36: 842,
#  37: 725,
#  38: 744,
#  39: 612,
#  40: 448,
#  41: 249,
#  42: 64,
#  43: 5,
#  44: 1,
#  45: 4,
#  46: 2}

# %% [markdown]
# ###Faire la liste des cases lexicalisées de l'échantillon

# %%
nbFormesLexicales={}
casesLexicales={element:paradigmes[paradigmes["lexeme"]==element].columns[paradigmes[paradigmes["lexeme"]==element].notnull().iloc[0]].tolist() for element in listeTest}
for element in casesLexicales:
    casesLexicales[element].remove("lexeme")
    nbFormesLexicales[element]=len(casesLexicales[element])

# %% [markdown]
# ##Comparer la sortie des cliques avec le paradigme de départ

# %%
# %%time
seuilClique=1
#paradigmesCLIQUES=pd.DataFrame(columns=paradigmes.columns.values.tolist())
paradigmesListe=[]
for n,clique in enumerate(sorted(cliques,key=lambda x: len(x),reverse=True)):
#    if seuilClique==0:
#        seuilClique=len(clique)-15
    if len(clique)>seuilClique:
        paradigmeClique={}
        sampleOK=True
#        print (n, len(clique))
        point=clique[0].split("-")
        lPoint=len(point)
#        print (point,"-".join(point[0:len(point)-2]))
        if lPoint==3:
            lexeme=point[0]
        else:
            lexeme="-".join(point[0:len(point)-2])
        paradigmeClique["lexeme"]=lexeme
        if n%100==0: print (n,end=", ")
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].notnull().columns.tolist()
#        casesLexeme=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
#        casesLexeme.remove("lexeme")
        casesLexeme=casesLexicales[lexeme]
        if casesLexeme and len(casesLexeme)<=len(clique):
            for element in casesLexeme:
#                print (lexeme,element, paradigmes[paradigmes["lexeme"]==lexeme][element])
                pointCase=u"%s-%s-%s"% (lexeme,paradigmes[paradigmes["lexeme"]==lexeme][element].iloc[0],element)
                if debug: print (pointCase, clique)
                if not pointCase in clique:
                    sampleOK=False
                    break
        else:
            sampleOK=False
        if sampleOK:
            for element in clique:
                (lexeme,forme,taminfo)=element.split("-")
                paradigmeClique[taminfo]=forme
                if taminfo in paradigmes.columns:
                    if not paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].isnull().item():
                        if paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item()!=forme:
                            sampleOK=False
                            print (paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item(),forme,taminfo,end=", ")
            paradigmesListe.append(paradigmeClique)
        else:
            if debug:
                print ()
                print (lexeme,clique)
                print ()
    else:
        break
paradigmesCLIQUES=pd.DataFrame(paradigmesListe,columns=GOLD.columns.values.tolist())
print (seuilClique)
# Out:
# 0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700, 10800, 10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800, 11900, 12000, 12100, 12200, 12300, 12400, 12500, 12600, 12700, 12800, 12900, 13000, 13100, 13200, 13300, 13400, 13500, 13600, 13700, 13800, 13900, 14000, 14100, 14200, 14300, 14400, 14500, 14600, 14700, 14800, 14900, 15000, 15100, 15200, 15300, 15400, 15500, 15600, 15700, 15800, 15900, 16000, 16100, 16200, 16300, 16400, 16500, 16600, 16700, 16800, 16900, 17000, 17100, 17200, 17300, 17400, 17500, 17600, 17700, 17800, 17900, 18000, 18100, 18200, 18300, 18400, 18500, 18600, 18700, 18800, 18900, 19000, 19100, 19200, 19300, 19400, 19500, 19600, 19700, 19800, 19900, 20000, 20100, 20200, 20300, 20400, 20500, 20600, 20700, 20800, 20900, 21000, 21100, 21200, 21300, 21400, 21500, 21600, 21700, 21800, 21900, 22000, 22100, 22200, 22300, 22400, 22500, 22600, 22700, 22800, 22900, 23000, 23100, 23200, 23300, 23400, 23500, 23600, 23700, 23800, 23900, 24000, 24100, 24200, 24300, 24400, 24500, 24600, 24700, 24800, 24900, 25000, 25100, 25200, 25300, 25400, 25500,
# 4         trouver    truvam     truvE  NaN    NaN     truvEr     truva
# 5            voir       vim        vi  NaN     vi        NaN        vi
# 6          devoir       NaN        dy  NaN    NaN        dyr        dy
# 7          sonner       NaN      sOnE  NaN    NaN      sOnEr      sOna
# 8        mépriser  mEprizam   mEprizE  NaN    NaN   mEprizEr   mEpriza
# 9        mépriser  mEprizam   mEprizE  NaN    NaN   mEprizEr   mEpriza
# 10        pousser     pusam      pusE  NaN    NaN      pusEr      pusa
# 11        pousser     pusam      pusE  NaN    NaN      pusEr      pusa
# 12     soupçonner       NaN   supsOnE  NaN    NaN   supsOnEr   supsOna
# 13      autoriser  OtOrizam   OtOrizE  NaN    NaN   OtOrizEr   OtOriza
# 14      autoriser  OtOrizam   OtOrizE  NaN    NaN   OtOrizEr   OtOriza
# 15     téléphoner       NaN  tElEfOnE  NaN    NaN  tElEfOnEr  tElEfOna
# 16      repousser   r6pusam    r6pusE  NaN    NaN    r6pusEr    r6pusa
# 17      repousser   r6pusam    r6pusE  NaN    NaN    r6pusEr    r6pusa
# 18        activer   aktivam    aktivE  NaN    NaN    aktivEr    aktiva
# 19    emprisonner       NaN  âprizOnE  NaN    NaN  âprizOnEr  âprizOna
# 20        refuser   r6fyzam    r6fyzE  NaN    NaN    r6fyzEr    r6fyza
# 21         partir    partim     parti  NaN  parti     partir     parti
# 22       assommer       NaN     asOmE  NaN    NaN     asOmEr     asOma
# 23        dériver   dErivam    dErivE  NaN    NaN    dErivEr    dEriva
# 24        dériver   dErivam    dErivE  NaN    NaN    dErivEr    dEriva
# 25      approuver   apruvam    apruvE  NaN    NaN    apruvEr    apruva
# 26      approuver   apruvam    apruvE  NaN    NaN    apruvEr    apruva
# 27      maîtriser  mEtrizam   mEtrizE  NaN    NaN   mEtrizEr   mEtriza
# 28      maîtriser  mEtrizam   mEtrizE  NaN    NaN   mEtrizEr   mEtriza
# 29       diffuser   difyzam    difyzE  NaN    NaN    difyzEr    difyza
# ...           ...       ...       ...  ...    ...        ...       ...
# 3774     conclure       NaN       NaN  NaN    NaN        NaN     kôkly
# 3775       planer       NaN       NaN  NaN  plana        NaN     plana
# 3776     cueillir       NaN      k6ji  NaN    NaN        NaN      k6ji
# 3777        durer     dyram       NaN  NaN    NaN        NaN      dyra
# 3778       manier       NaN       NaN  NaN    NaN        NaN     manja
# 3779    attendrir       NaN       NaN  NaN    NaN    atâdrir    atâdri
# 3780      éblouir       NaN       NaN  NaN    NaN     Ebluir     Eblui
# 3781       relire       NaN       NaN  NaN    NaN        NaN      r6ly
# 3782     déjeuner       NaN    dEZ6nE  NaN    NaN    dEZ6nEr       NaN
# 3783       relier       NaN       NaN  NaN    NaN        NaN     r6lja
# 3784    engueuler       NaN       NaN  NaN    NaN        NaN     âg6la
# 3785       gravir       NaN       NaN  NaN    NaN     gravir     gravi
# 3786   recueillir       NaN    r6k6ji  NaN    NaN        NaN    r6k6ji
# 3787       envier       NaN       NaN  NaN    NaN        NaN       NaN
# 3788      revivre       NaN       NaN  NaN    NaN        NaN       NaN
# 3789      feindre       NaN       NaN  NaN    NaN        NaN       NaN
# 3790      gueuler       NaN       NaN  NaN    NaN        NaN      g6la
# 3791     humilier       NaN       NaN  NaN    NaN        NaN    ymilja
# 3792       renier       NaN     r6njE  NaN    NaN        NaN       NaN
# 3793      envahir       NaN       NaN  NaN    NaN      âvair      âvai
# 3794         lier       NaN       NaN  NaN    NaN        NaN       lja
# 3795        épier       NaN       NaN  NaN    NaN        NaN       NaN
# 3796    distraire       NaN       NaN  NaN    NaN        NaN       NaN
# 3797    étreindre       NaN       NaN  NaN    NaN        NaN    EtrEJi
# 3798    entrevoir       NaN    âtr6vi  NaN    NaN        NaN    âtr6vi
# 3799   convaincre       NaN       NaN  NaN    NaN        NaN       NaN
# 3800        chier       NaN       NaN  NaN    NaN        NaN       NaN
# 3801    dissoudre       NaN       NaN  NaN    NaN        NaN       NaN
# 3802     accourir       NaN       NaN  NaN    NaN     akuryr       NaN
# 3803     associer       NaN       NaN  NaN    NaN        NaN       NaN
#
#             fi1P        fi1S        fi2P   ...         ppFP      ppFS  \
# 0            Orô         OrE         Ore   ...            y         y
# 1           s6rô        s6rE        s6re   ...          NaN       NaN
# 2           f6rô        f6rE        f6re   ...          fEt       fEt
# 3           dirô        dirE        dire   ...          dit       dit
# 4        truv6rô     truv6rE     truv6re   ...        truve     truve
# 5           vErô        vErE        vEre   ...           vy        vy
# 6          d6vrô       d6vrE       d6vre   ...           dy        dy
# 7         sOn6rô      sOn6rE      sOn6re   ...         sOne      sOne
# 8      mEpriz6rô   mEpriz6rE   mEpriz6re   ...      mEprize   mEprize
# 9      mEpriz6rô   mEpriz6rE   mEpriz6re   ...      mEprize   mEprize
# 10        pus6rô      pus6rE      pus6re   ...         puse      puse
# 11        pus6rô      pus6rE      pus6re   ...         puse      puse
# 12     supsOn6rô   supsOn6rE   supsOn6re   ...      supsOne   supsOne
# 13     OtOriz6rô   OtOriz6rE   OtOriz6re   ...      OtOrize   OtOrize
# 14     OtOriz6rô   OtOriz6rE   OtOriz6re   ...      OtOrize   OtOrize
# 15    tElEfOn6rô  tElEfOn6rE  tElEfOn6re   ...     tElEfOne  tElEfOne
# 16      r6pus6rô    r6pus6rE    r6pus6re   ...       r6puse    r6puse
# 17      r6pus6rô    r6pus6rE    r6pus6re   ...       r6puse    r6puse
# 18      aktiv6rô    aktiv6rE    aktiv6re   ...       aktive    aktive
# 19    âprizOn6rô  âprizOn6rE  âprizOn6re   ...     âprizOne  âprizOne
# 20      r6fyz6rô    r6fyz6rE    r6fyz6re   ...       r6fyze    r6fyze
# 21       partirô     partirE     partire   ...        parti     parti
# 22       asOm6rô     asOm6rE     asOm6re   ...        asOme     asOme
# 23      dEriv6rô    dEriv6rE    dEriv6re   ...       dErive    dErive
# 24      dEriv6rô    dEriv6rE    dEriv6re   ...       dErive    dErive
# 25      apruv6rô    apruv6rE    apruv6re   ...       apruve    apruve
# 26      apruv6rô    apruv6rE    apruv6re   ...       apruve    apruve
# 27     mEtriz6rô   mEtriz6rE   mEtriz6re   ...      mEtrize   mEtrize
# 28     mEtriz6rô   mEtriz6rE   mEtriz6re   ...      mEtrize   mEtrize
# 29      difyz6rô    difyz6rE    difyz6re   ...       difyze    difyze
# ...          ...         ...         ...   ...          ...       ...
# 3774     kôklyrô         NaN         NaN   ...          NaN     kôkly
# 3775         NaN         NaN         NaN   ...          NaN       NaN
# 3776         NaN         NaN         NaN   ...         k6ji      k6ji
# 3777         NaN         NaN         NaN   ...          NaN       NaN
# 3778         NaN         NaN         NaN   ...          NaN     manje
# 3779         NaN         NaN         NaN   ...       atâdri    atâdri
# 3780         NaN         NaN         NaN   ...        Eblui     Eblui
# 3781         NaN         NaN         NaN   ...          NaN       NaN
# 3782         NaN         NaN         NaN   ...          NaN       NaN
# 3783         NaN         NaN         NaN   ...        r6lje     r6lje
# 3784         NaN         NaN         NaN   ...          NaN     âg6le
# 3785         NaN         NaN         NaN   ...          NaN       NaN
# 3786         NaN         NaN         NaN   ...       r6k6ji    r6k6ji
# 3787         NaN         NaN         NaN   ...          NaN      âvje
# 3788         NaN     r6vivrE         NaN   ...          NaN       NaN
# 3789         NaN         NaN         NaN   ...          NaN       NaN
# 3790         NaN         NaN         NaN   ...          NaN       NaN
# 3791         NaN         NaN         NaN   ...          NaN    ymilje
# 3792         NaN      r6nirE         NaN   ...          NaN     r6nje
# 3793         NaN         NaN         NaN   ...         âvai      âvai
# 3794         NaN         NaN         NaN   ...          NaN       lje
# 3795         NaN         NaN         NaN   ...         Epje      Epje
# 3796         NaN         NaN         NaN   ...          NaN   distrEt
# 3797         NaN         NaN         NaN   ...          NaN       NaN
# 3798         NaN         NaN         NaN   ...          NaN       NaN
# 3799         NaN         NaN         NaN   ...          NaN    kôvêky
# 3800         NaN         NaN         NaN   ...          NaN       NaN
# 3801         NaN         NaN         NaN   ...          NaN       NaN
# 3802         NaN         NaN         NaN   ...          NaN     akury
# 3803         NaN         NaN         NaN   ...       asOsje       NaN
#
#           ppMP      ppMS       ps1P     ps1S       ps2P     ps2S     ps3P  \
# 0            y         y        Ejô        E        Eje        E        E
# 1          NaN       NaN      swajô      swa      swaje      swa      swa
# 2           fE        fE      fasjô      fas      fasje      fas      fas
# 3           di        di        NaN      diz      dizje      diz      diz
# 4        truve     truve     truvjô     truv        NaN     truv     truv
# 5           vy        vy        NaN      vwa      vwaje      vwa      vwa
# 6           dy        dy        NaN     dwav      d6vje     dwav     dwav
# 7         sOne      sOne      sOnjô      sOn      sOnje      sOn      sOn
# 8      mEprize   mEprize   mEprizjô   mEpriz        NaN   mEpriz   mEpriz
# 9      mEprize   mEprize        NaN   mEpriz        NaN   mEpriz   mEpriz
# 10        puse      puse      pusjô      pus        NaN      pus      pus
# 11        puse      puse      pusjô      pus      pusje      pus      pus
# 12     supsOne   supsOne   supsOnjô   supsOn   supsOnje   supsOn   supsOn
# 13     OtOrize   OtOrize        NaN   OtOriz        NaN   OtOriz   OtOriz
# 14     OtOrize   OtOrize   OtOrizjô   OtOriz        NaN   OtOriz   OtOriz
# 15    tElEfOne  tElEfOne  tElEfOnjô  tElEfOn  tElEfOnje  tElEfOn  tElEfOn
# 16      r6puse    r6puse    r6pusjô    r6pus    r6pusje    r6pus    r6pus
# 17      r6puse    r6puse    r6pusjô    r6pus        NaN    r6pus    r6pus
# 18      aktive    aktive        NaN    aktiv        NaN    aktiv    aktiv
# 19    âprizOne  âprizOne  âprizOnjô  âprizOn  âprizOnje  âprizOn  âprizOn
# 20      r6fyze    r6fyze    r6fyzjô    r6fyz        NaN    r6fyz    r6fyz
# 21       parti     parti        NaN     part     partje     part      NaN
# 22       asOme     asOme     asOmjô     asOm     asOmje     asOm     asOm
# 23      dErive    dErive    dErivjô    dEriv        NaN    dEriv    dEriv
# 24      dErive    dErive        NaN    dEriv        NaN    dEriv    dEriv
# 25      apruve    apruve    apruvjô    apruv    apruvje    apruv    apruv
# 26      apruve    apruve    apruvjô    apruv        NaN    apruv    apruv
# 27     mEtrize   mEtrize        NaN   mEtriz        NaN   mEtriz   mEtriz
# 28     mEtrize   mEtrize   mEtrizjô   mEtriz        NaN   mEtriz   mEtriz
# 29      difyze    difyze    difyzjô    difyz        NaN    difyz    difyz
# ...        ...       ...        ...      ...        ...      ...      ...
# 3774     kôkly     kôkly        NaN    kôkly        NaN      NaN      NaN
# 3775       NaN       NaN        NaN      NaN        NaN      NaN      NaN
# 3776      k6ji      k6ji        NaN      NaN        NaN      NaN      NaN
# 3777       NaN       NaN        NaN      NaN        NaN      NaN      NaN
# 3778     manje     manje        NaN      NaN        NaN      NaN      NaN
# 3779    atâdri    atâdri        NaN      NaN        NaN      NaN      NaN
# 3780     Eblui     Eblui        NaN      NaN        NaN      NaN      NaN
# 3781       NaN      r6ly        NaN    r6liz        NaN      NaN      NaN
# 3782       NaN       NaN        NaN      NaN        NaN      NaN      NaN
# 3783     r6lje     r6lje        NaN      NaN        NaN      NaN      NaN
# 3784     âg6le     âg6le        NaN      NaN        NaN      NaN      NaN
# 3785     gravi     gravi        NaN      NaN        NaN      NaN      NaN
# 3786       NaN    r6k6ji        NaN      NaN        NaN      NaN      NaN
# 3787       NaN      âvje        NaN      NaN        NaN      NaN      NaN
# 3788       NaN       NaN        NaN      NaN        NaN      NaN      NaN
# 3789       NaN        fê        NaN      fEJ        NaN      NaN      NaN
# 3790       NaN      g6le        NaN      NaN        NaN      NaN      NaN
# 3791    ymilje    ymilje        NaN      NaN        NaN      NaN      NaN
# 3792       NaN     r6nje        NaN      NaN        NaN      NaN      NaN
# 3793       NaN      âvai        NaN      NaN        NaN      NaN      NaN
# 3794       lje       lje        NaN      NaN        NaN      NaN      NaN
# 3795      Epje      Epje        NaN      NaN        NaN      NaN      NaN
# 3796    distrE    distrE        NaN      NaN        NaN      NaN   distrE
# 3797      Etrê      Etrê        NaN      NaN        NaN      NaN    EtrEJ
# 3798       NaN    âtr6vy        NaN      NaN        NaN      NaN      NaN
# 3799    kôvêky    kôvêky        NaN    kôvêk        NaN    kôvêk      NaN
# 3800       NaN       Sje        NaN       Si        NaN      NaN      NaN
# 3801       NaN       NaN        NaN      NaN        NaN      NaN      NaN
# 3802     akury     akury        NaN      NaN        NaN      NaN      NaN
# 3803    asOsje    asOsje        NaN      NaN        NaN      NaN      NaN
#
#          ps3S
# 0           E
# 1         swa
# 2         fas
# 3         diz
# 4        truv
# 5         vwa
# 6        dwav
# 7         sOn
# 8      mEpriz
# 9      mEpriz
# 10        pus
# 11        pus
# 12     supsOn
# 13     OtOriz
# 14     OtOriz
# 15    tElEfOn
# 16      r6pus
# 17      r6pus
# 18      aktiv
# 19    âprizOn
# 20      r6fyz
# 21       part
# 22       asOm
# 23      dEriv
# 24      dEriv
# 25      apruv
# 26      apruv
# 27     mEtriz
# 28     mEtriz
# 29      difyz
# ...       ...
# 3774    kôkly
# 3775     plan
# 3776      NaN
# 3777      NaN
# 3778      NaN
# 3779      NaN
# 3780   Ebluis
# 3781      NaN
# 3782    dEZ9n
# 3783      NaN
# 3784      NaN
# 3785      NaN
# 3786      NaN
# 3787      NaN
# 3788    r6viv
# 3789      NaN
# 3790      NaN
# 3791      NaN
# 3792      NaN
# 3793      NaN
# 3794      NaN
# 3795      Epi
# 3796      NaN
# 3797      NaN
# 3798      NaN
# 3799    kôvêk
# 3800      NaN
# 3801   disOlv
# 3802      NaN
# 3803      NaN
#
# [3804 rows x 52 columns]

# %%
def compareGOLD(row):
#    if row["lexeme"]=="dodo": 
#        debug=True
#    else:
#        debug=False
    print (row["lexeme"],end=" : ")
    lexeme=row["lexeme"]
    if not lexeme in conjugaisons:
        conjugaisons[lexeme]={"diff":[],"miss":[],"over":[],"overmiss":[],"ok":[]}
    identiques=[]
    differents=[]
    missing=[]
    over=[]
    for case in analyseCases:
        if debug:    
            print (lexeme,case)
            print (GOLD[GOLD["lexeme"]==lexeme][case].item())
            print ((GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]))
        if not case in row:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("absence",case)
        elif case in row[row.isnull()] and not GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            missing.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print ("CLIQUES +NaN",case)
        elif not case in row[row.isnull()] and GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]:
            if debug: print ("not case")
            over.append(u"%s : %s ≠ Ø" % (case,row[case]))
            lexical=False
            if debug: print ("GOLD -NaN",case)            
        elif (row[case]==GOLD[GOLD["lexeme"]==lexeme][case].item()):
            if debug: print ("egal")
            identiques.append(u"%s : %s" % (case,row[case]))
            if debug: print ("valeurs id")
        elif (case in row[row.isnull()]) and (GOLD[GOLD["lexeme"]==lexeme][case].isnull().iloc[0]):
            if debug: print ("NaNs")
            identiques.append(u"%s : %s" % (case,u"ØØØ"))
            if debug: print ("deux NaN")
        else:
            if debug: print ("else")
            differents.append(u"%s : %s ≠ %s" % (case, row[case],GOLD[GOLD["lexeme"]==lexeme][case].item()))
            lexical=False
            if debug: print (u"différence",case)
    if differents:
        conjugaisons[lexeme]["diff"].append(differents)
        if debug: print ("DIFF",len(differents),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: print (", ".join(differents))
    if missing and over:
        conjugaisons[lexeme]["overmiss"].append(over+missing)
        if debug: print ("OVERMISS", len(over), len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
            print (", ".join(over))
    elif missing:
        conjugaisons[lexeme]["miss"].append(missing)
        if debug: print ("MISS", len(missing),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(missing))
    elif over:
        conjugaisons[lexeme]["over"].append(over)
        if debug: print ("OVER", len(over),"=>", len(identiques), len(identiques)-nombreElements[lexeme], end=saut)
        if debug1: 
            print (", ".join(over))
    if identiques:
        conjugaisons[lexeme]["ok"].append(identiques)
        if debug: print ("OK", len(identiques), len(identiques)-nombreElements[lexeme],end=saut)
        if debug1: print (", ".join(identiques))
#    print ()
    return lexical

# %%
# %%time
debug=False
debug1=False
saut="\n"
conjugaisons={}
print (", ".join(sampleCases))
paradigmesCLIQUES.apply(compareGOLD,axis=1)
# Out:
# ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P, fi2S, fi3P, fi3S, ii1P, ii1S, ii2P, ii2S, ii3P, ii3S, inf, is1P, is1S, is2S, is3P, is3S, pI1P, pI2P, pI2S, pP, pc1P, pc1S, pc2P, pc2S, pc3P, pc3S, pi1P, pi1S, pi2P, pi2S, pi3P, pi3S, ppFP, ppFS, ppMP, ppMS, ps1P, ps1S, ps2P, ps2S, ps3P, ps3S
# avoir : être : faire : dire : trouver : voir : devoir : sonner : mépriser : mépriser : pousser : pousser : soupçonner : autoriser : autoriser : téléphoner : repousser : repousser : activer : emprisonner : refuser : partir : assommer : dériver : dériver : approuver : approuver : maîtriser : maîtriser : diffuser : buter : déconner : pardonner : couronner : briser : briser : ordonner : donner : prouver : prouver : impressionner : mériter : passionner : passer : empoisonner : hériter : abuser : irriter : épouser : épouser : cultiver : abriter : scruter : arriver : arriver : disputer : étonner : précipiter : venir : baisser : résonner : mentionner : éprouver : éprouver : imprimer : imprimer : adresser : adresser : exprimer : exprimer : exciter : hésiter : entasser : déchirer : assurer : intéresser : intéresser : attirer : étirer : préoccuper : préoccuper : progresser : progresser : progresser : progresser : agacer : inviter : inviter : ricaner : figurer : réclamer : exécuter : exécuter : classer : virer : dégoûter : dégoûter : dépasser : dépasser : redresser : redresser : occuper : occuper : casser : dîner : activer : imaginer : dessiner : dessiner : solliciter : supprimer : supprimer : débiter : débiter : débiter : balader : éclater : fasciner : fasciner : abîmer : abîmer : deviner : deviner : féliciter : réciter : aspirer : guider : guider : buter : aller : décider : chasser : participer : couper : couper : coûter : coûter : suicider : suicider : désirer : échapper : inspirer : rassurer : repasser : repasser : repasser : respirer : prouver : dissiper : mériter : surpasser : surpasser : assumer : assumer : parler : déguiser : déguiser : masser : dresser : dresser : susciter : soupirer : agiter : agiter : ramasser : accuser : laisser : hériter : hériter : irriter : épater : découper : découper : résumer : résumer : abaisser : abaisser : abaisser : abaisser : excuser : éviter : éviter : cultiver : placer : inciter : abriter : abriter : exprimer : exprimer : sucer : sucer : sucer : retirer : savoir : scruter : écouter : écouter : bouder : cesser : procurer : aimer : refléter : flatter : imprimer : imprimer : habiter : habiter : habiter : graisser : graisser : graisser : graisser : endurer : profiter : profiter : profiter : ajouter : ajouter : mesurer : précipiter : lasser : jurer : escalader : méditer : méditer : torturer : presser : presser : menacer : compléter : déplacer : exclamer : piétiner : piétiner : citer : méditer : méditer : irriter : consumer : consumer : visiter : rajouter : rajouter : goûter : goûter : nommer : ressusciter : estimer : estimer : estimer : estimer : tousser : tousser : tousser : obstiner : obstiner : remplacer : cuisiner : cuisiner : proclamer : entourer : adresser : pratiquer : enfoncer : enfoncer : exciter : hésiter : hésiter : hésiter : rouler : entasser : entasser : envisager : sécher : assurer : intéresser : fatiguer : attirer : admirer : affronter : affronter : embrasser : embrasser : débarquer : étirer : rattraper : remonter : préoccuper : progresser : progresser : agacer : torturer : ricaner : chasser : raccrocher : défiler : défiler : exécuter : accrocher : dévisager : répéter : répéter : répéter : répéter : arracher : virer : embarquer : évoquer : dégoûter : enquêter : enquêter : brûler : redresser : occuper : exiger : casser : cesser : corriger : dîner : reprocher : fabriquer : ruiner : dessiner : provoquer : débarrasser : débarrasser : débarrasser : écrouler : taper : rattacher : refuser : solliciter : solliciter : solliciter : rester : détacher : garder : rallumer : rallumer : discuter : regretter : regretter : regretter : dépêcher : tracer : tracer : tracer : tracer : tracer : tracer : fasciner : devenir : piquer : frapper : froncer : froncer : manifester : diriger : féliciter : féliciter : féliciter : réciter : réciter : réciter : surmonter : aspirer : rédiger : diffuser : craquer : terminer : terminer : prévenir : blesser : guider : organiser : organiser : organiser : buter : lutter : lutt ...
# Wall time: 31min 27s

# %%
with codecs.open("2015-Data/"+samplePrefix+".yaml", 'w', encoding='utf8') as outfile:
    outfile.write(yaml.dump(conjugaisons, default_flow_style=True, encoding='utf8'))

# %%
yaml.safe_dump(conjugaisons, file("2015-Data/"+samplePrefix+".yaml",'w'), encoding='utf-8', allow_unicode=True)

# %%
pb=[i for i in conjugaisons if conjugaisons[i]["diff"]]
for element in pb:
    print (element)
    print ("DIFF",conjugaisons[element]["diff"])
    print ("MISS",conjugaisons[element]["miss"],end="\n\n")
# Out:
# sortir
# DIFF [[u'pP : sOrt\xe2 \u2260 sOrt\xe2,sOrtis\xe2', u'ii3S : sOrtE \u2260 sOrtE,sOrtisE', u'ps3S : sOrt \u2260 sOrt,sOrtis', u'ii3P : sOrtE \u2260 sOrtE,sOrtisE', u'pi3P : sOrt \u2260 sOrt,sOrtis', u'pi3S : sOr \u2260 sOr,sOrti']]
2P : \xd8 \u2260 \xe2sEJe', u'ii2S : \xd8 \u2260 \xe2sEJE', u'is1S : \xd8 \u2260 \xe2sEJas', u'fi3P : \xd8 \u2260 \xe2sEJ6r\xf4', u'ai3P : \xd8 \u2260 \xe2sEJEr', u'fi1P : \xd8 \u2260 \xe2sEJ6r\xf4', u'pI1P : \xd8 \u2260 \xe2sEJ\xf4'], [u'ii1P : \xd8 \u2260 \xe2sEJ\xf4', u'pP : \xd8 \u2260 \xe2sEJ\xe2', u'pc1P : \xd8 \u2260 \xe2sEJ6rj\xf4', u'ppMP : \xd8 \u2260 \xe2sEJe', u'is3P : \xd8 \u2260 \xe2sEJas', u'is3S : \xd8 \u2260 \xe2sEJa', u'ai1P : \xd8 \u2260 \xe2sEJam', u'ii3P : \xd8 \u2260 \xe2sEJE', u'ai1S : \xd8 \u2260 \xe2sEJE', u'ppFS : \xd8 \u2260 \xe2sEJe', u'ppFP : \xd8 \u2260 \xe2sEJe', u'ps1P : \xd8 \u2260 \xe2sEJ\xf4', u'ps3P : \xd8 \u2260 \xe2sEJ', u'fi2P : \xd8 \u2260 \xe2sEJ6re', u'ps2P : \xd8 \u2260 \xe2sEJe', u'ai2P : \xd8 \u2260 \xe2sEJat', u'ai2S : \xd8 \u2260 \xe2sEJa', u'pc2P : \xd8 \u2260 \xe2sEJ6rje', u'ii2P : \xd8 \u2260 \xe2sEJe', u'ii2S : \xd8 \u2260 \xe2sEJE', u'is1S : \xd8 \u2260 \xe2sEJas', u'fi3P : \xd8 \u2260 \xe2sEJ6r\xf4', u'pI1P : \xd8 \u2260 \xe2sEJ\xf4'], [u'ii1P : \xd8 \u2260 \xe2sEJ\xf4', u'pP : \xd8 \u2260 \xe2sEJ\xe2', u'pc1P : \xd8 \u2260 \xe2sEJ6rj\xf4', u'is3P : \xd8 \u2260 \xe2sEJas', u'is3S : \xd8 \u2260 \xe2sEJa', u'ai1P : \xd8 \u2260 \xe2sEJam', u'ii3P : \xd8 \u2260 \xe2sEJE', u'ai1S : \xd8 \u2260 \xe2sEJE', u'pp ...

# %%
good=[i for i in conjugaisons if not conjugaisons[i]["diff"]]
for lexeme in good:
    print (lexeme)
    for ident in conjugaisons[lexeme]:
        for element in conjugaisons[lexeme][ident]:
            print (ident)
            print (", ".join(element))
    print ()
# Out:
# reprendre
# miss
# ii1P : Ø ≠ r6pr6njô, pc1P : Ø ≠ r6prâdriô, ii1S : Ø ≠ r6pr6nE, ppMP : Ø ≠ r6pri, is3P : Ø ≠ r6pris, is3S : Ø ≠ r6pri, ai1P : Ø ≠ r6prim, ppFS : Ø ≠ r6priz, ppFP : Ø ≠ r6priz, ps1P : Ø ≠ r6pr6njô, ps3P : Ø ≠ r6prEn, fi2P : Ø ≠ r6prâdre, fi2S : Ø ≠ r6prâdra, pI2P : Ø ≠ r6pr6ne, ps2P : Ø ≠ r6pr6nje, ps2S : Ø ≠ r6prEn, ai2P : Ø ≠ r6prit, pc2P : Ø ≠ r6prâdrie, pc2S : Ø ≠ r6prâdrE, ii2P : Ø ≠ r6pr6nje, ppMS : Ø ≠ r6pri, pc3P : Ø ≠ r6prâdrE, is1S : Ø ≠ r6pris, pc1S : Ø ≠ r6prâdrE, fi3P : Ø ≠ r6prâdrô, ai3P : Ø ≠ r6prir, fi1P : Ø ≠ r6prâdrô
# ok
# pP : r6pr6nâ, ai3S : r6pri, ii3S : r6pr6nE, ps3S : r6prEn, inf : r6prâdr, ii3P : r6pr6nE, pi2S : r6prâ, ai1S : r6pri, pi2P : r6pr6ne, ps1S : r6prEn, pI2S : r6prâ, ai2S : r6pri, pi1S : r6prâ, pi1P : r6pr6nô, ii2S : r6pr6nE, pi3P : r6prEn, pi3S : r6prâ, pc3S : r6prâdrE, fi3S : r6prâdra, fi1S : r6prâdrE, pI1P : r6pr6nô
#
# surprendre
# miss
# pc1P : Ø ≠ syrprâdriô, ppMP : Ø ≠ syrpri, is3P : Ø ≠ syrpris, is3S : Ø ≠ syrpri, ai1P : Ø ≠ syrprim, ppFP : Ø ≠ syrpriz, ps1P : Ø ≠ syrpr6njô, ps3P : Ø ≠ syrprEn, ps2P : Ø ≠ syrpr6nje, ai2P : Ø ≠ syrprit, pc2P : Ø ≠ syrprâdrie, pi1P : Ø ≠ syrpr6nô, ppMS : Ø ≠ syrpri, is1S : Ø ≠ syrpris, ai3P : Ø ≠ syrprir, fi1P : Ø ≠ syrprâdrô, fi1S : Ø ≠ syrprâdrE
# ok
# ii1P : syrpr6njô, pP : syrpr6nâ, ii1S : syrpr6nE, ai3S : syrpri, ii3S : syrpr6nE, ps3S : syrprEn, inf : syrprâdr, ii3P : syrpr6nE, pi2S : syrprâ, ai1S : syrpri, pi2P : syrpr6ne, ppFS : syrpriz, ps1S : syrprEn, pI2S : syrprâ, fi2P : syrprâdre, fi2S : syrprâdra, pI2P : syrpr6ne, ps2S : syrprEn, ai2S : syrpri, pc2S : syrprâdrE, ii2P : syrpr6nje, pi1S : syrprâ, ii2S : syrpr6nE, pi3P : syrprEn, pi3S : syrprâ, pc3S : syrprâdrE, pc3P : syrprâdrE, pc1S : syrprâdrE, fi3S : syrprâdra, fi3P : syrprâdrô, pI1P : syrpr6nô
#
# rentrer
# miss
# ii1P : Ø ≠ râtrjô, pc1P : Ø ≠ râtr6rjô, is3P : Ø ≠ râtras, is3S : Ø ≠ râtra, ai1P : Ø ≠ râtram, ps1P : Ø ≠ râtrjô, ps3P : Ø ≠ râtr, fi2P : Ø ≠ râtr6re, fi2S : Ø ≠ râtr6ra, ps2P : Ø ≠ râtrje, ai2P : Ø ≠ râtrat, ai2S : Ø ≠ râtra, pc2P : Ø ≠ râtr6rje, pc2S : Ø ≠ râtr6rE, ii2P : Ø ≠ râtrje, pc3P : Ø ≠ râtr6rE, is1S : Ø ≠ râtras, pc1S : Ø ≠ râtr6rE, fi3P : Ø ≠ râtr6rô, fi1P : Ø ≠ râtr6rô
# ok
# pP : râtrâ, ii1S : râtrE, ai3S : râtra, ppMP : râtre, ii3S : râtrE, ps3S : râtr, inf : râtre, ii3P : râtrE, pi2S : râtr, ai1S : râtrE, pi2P : râtre, ppFS : râtre, ppFP : râtre, ps1S : râtr, pI2S : râtr, pI2P : râtre, ps2S : râtr, pi1S : râtr, pi1P : râtrô, ii2S : râtrE, pi3P : râtr, pi3S : râtr, ppMS : râtre, pc3S : râtr6rE, fi3S : râtr6ra, ai3P : râtrEr, fi1S : râtr6rE, pI1P : râtrô
#
# proposer
# miss
# ii1P : Ø ≠ prOpOzjô, pP : Ø ≠ prOpOzâ, ppMP : Ø ≠ prOpOze, is3P : Ø ≠ prOpOzas, is3S : Ø ≠ prOpOza, ai1P : Ø ≠ prOpOzam, ii3P : Ø ≠ prOpOzE, ai1S : Ø ≠ prOpOzE, pi2P : Ø ≠ prOpOze, ppFS : Ø ≠ prOpOze, ppFP : Ø ≠ prOpOze, ps1P : Ø ≠ prOpOzjô, ps3P : Ø ≠ prOpoz, ps1S : Ø ≠ prOpoz, fi2P : Ø ≠ prOpOz6re, fi2S : Ø ≠ prOpOz6ra, pI2P : Ø ≠ prOpOze, ps2P : Ø ≠ prOpOzje, ps2S : Ø ≠ prOpoz, ai2P : Ø ≠ prOpOzat, ai2S : Ø ≠ prOpOza, pc2P : Ø ≠ prOpOz6rje, pc2S : Ø ≠ prOpOz6rE, ii2P : Ø ≠ prOpOzje, pi1P : Ø ≠ prOpOzô, ii2S : Ø ≠ prOpOzE, pc3P : Ø ≠ prOpOz6rE, is1S : Ø ≠ prOpOzas, fi3S : Ø ≠ prOpOz6ra, fi3P : Ø ≠ prOpOz6rô, ai3P : Ø ≠ prOpOzEr, fi1P : Ø ≠ prOpOz6rô, pI1P : Ø ≠ prOpOzô
# ok
# pc1P : prOpOz6rjô, ii1S : prOpOzE, ai3S : prOpOza, ii3S : prOpOzE, ps3S : prOpoz, inf : prOpOze, pi2S : prOpoz, pI2S : prOpoz, pi1S : prOpoz, pi3P : prOpoz, pi3S : prOpoz, ppMS : prOpOze, pc3S : prOpOz6rE, pc1S : prOpOz6rE, fi1S : prOpOz6rE
#
# projeter
# miss
# pc1P : Ø ≠ prOZEt6rjô, is3P : Ø ≠ prOZ6tas, is3S : Ø ≠ prOZ6ta, ai1P : Ø ≠ prOZ6tam, ii3P : Ø ≠ prOZ6tE, pi2S : Ø ≠ prOZEt, ppFP : Ø ≠ prOZ6te, ps1P : Ø ≠ prOZ6tjô, ps3P : Ø ≠ prOZEt, ps1S : Ø ≠ prOZEt, fi2P : Ø ≠ prOZEt6re, fi2S : Ø ≠ prOZEt6ra, ps2P : Ø ≠ prOZ6tje, ai2P : Ø ≠ prOZ6tat, ai2S : Ø ≠ prOZ6ta, pc2P : Ø ≠ prOZEt6rje, pc2S : Ø ≠ prOZEt6rE, ii2P : Ø ≠ prOZ6tje, ii2S : Ø ≠ prOZ6tE, pi3P : Ø ≠ prOZEt, pc3S : Ø ≠ prOZEt6rE, pc3P : Ø ≠ prOZEt6rE, is1S : Ø ≠ prOZ6tas, pc1S : Ø ≠ prOZEt6rE, fi3S : Ø ≠ prOZEt6ra, fi3P : Ø ≠ prOZEt6rô, fi1P : Ø ≠ prOZEt6rô, fi1S : Ø ≠ prOZEt6rE
# miss
# ii1P : Ø ≠ prOZ6tjô, pP : Ø ≠ prOZ6tâ, pc1P : Ø ≠ prOZEt6rjô, is3P : Ø ≠ prOZ6tas, is3S : Ø ≠ prOZ6ta, ai1P : Ø ≠ prOZ6tam, ii3P : Ø ≠ prOZ6tE, ai1S : Ø ≠ prOZ6tE, ppFP : Ø ≠ prOZ6te, ps1P : Ø ≠ prOZ6tjô, ps3P : Ø ≠ prOZEt, ps1S : Ø ≠ prOZEt, fi2P : Ø ≠ prOZEt6re, fi2S : Ø ≠ prOZEt6ra, pI2P : Ø ≠ prOZ6te, ps2P : Ø ≠ prOZ6tje, ai2P : Ø ≠ prOZ6tat, ai2S : Ø ≠ prOZ6ta, pc2P : Ø ≠ prOZEt6rje, pc2S : Ø ≠ prOZEt6rE, ii2P : Ø ≠ prOZ6tje, pi1P : Ø ≠ prOZ6tô, ii2S : Ø ≠ prOZ6tE, pc3P : Ø ≠ prOZEt6rE, is1S : Ø ≠ prOZ6tas, pc1S : Ø ≠ prOZEt6rE, fi3P : Ø ≠ prOZEt6rô, ai3P : Ø ≠ prOZ6tEr, fi1P : Ø ≠ prOZEt6rô, fi1S : Ø ≠ prOZEt6rE, pI1P : Ø ≠ prOZ6tô
# ok
# ii1P : prOZ6tjô, pP : prOZ6tâ, ii1S : prOZ6tE, ai3S : prOZ6ta, ppMP : prOZ6te, ii3S : prOZ6tE, ps3S : prOZEt, inf : prOZ6te, ai1S : prOZ6tE, pi2P : prOZ6te, ppFS : prOZ6te, pI2S : prOZEt, pI2P : prOZ6te, ps2S : prOZEt, pi1S : prOZEt, pi1P : prOZ6tô, pi3S : prOZEt, ppMS : prOZ6te, ai3P : prOZ6tEr, pI1P : prOZ6tô
# ok
# ii1S : prOZ6tE, ai3S : prOZ6ta, ppMP : prOZ6te, ii3S : prOZ6tE, ps3S : prOZEt, inf : prOZ6te, pi2S : prOZEt, pi2P : prOZ6te, ppFS : prOZ6te, pI2S : prOZEt, ps2S : prOZEt, pi1S : prOZEt, pi3P : prOZEt, pi3S : prOZEt, ppMS : prOZ6te, pc3S : prOZEt6rE, fi3S : prOZEt6ra
#
# aider
# miss
# ii1P : Ø ≠ Edjô, pc1P : Ø ≠ Ed6rjô, ii1S : Ø ≠ EdE, ai3S : Ø ≠ Eda, is3P : Ø ≠ Edas, is3S : Ø ≠ Eda, ai1P : Ø ≠ Edam, ii3P : Ø ≠ EdE, ai1S : Ø ≠ EdE, ppFP : Ø ≠ Ede, ps1P : Ø ≠ Edjô, fi2P : Ø ≠ Ed6re, fi2S : Ø ≠ Ed6ra, ai2P : Ø ≠ Edat, ai2S : Ø ≠ Eda, pc2P : Ø ≠ Ed6rje, pc2S : Ø ≠ Ed6rE, ii2P : Ø ≠ Edje, ii2S : Ø ≠ EdE, pc3S : Ø ≠ Ed6rE, pc3P : Ø ≠ Ed6rE, is1S : Ø ≠ Edas, pc1S : Ø ≠ Ed6rE, ai3P : Ø ≠ EdEr, fi1P : Ø ≠ Ed6rô, fi1S : Ø ≠ Ed6rE, pI1P : Ø ≠ Edô
# ok
# pP : Edâ, ppMP : Ede, ii3S : EdE, ps3S : Ed, inf : Ede, pi2S : Ed, pi2P : Ede, ppFS : Ede, ps3P : Ed, ps1S : Ed, pI2S : Ed, pI2P : Ede, ps2P : Edje, ps2S : Ed, pi1S : Ed, pi1P : Edô, pi3P : Ed, pi3S : Ed, ppMS : Ede, fi3S : Ed6ra, fi3P : Ed6rô
#
# causer
# miss
# ii1P : Ø ≠ kOzjô, pP : Ø ≠ kOzâ, pc1P : Ø ≠ kOz6rjô, ii1S : Ø ≠ kOzE, ai3S : Ø ≠ kOza, ppMP : Ø ≠ kOze, is3P : Ø ≠ kOzas, is3S : Ø ≠ kOza, ai1P : Ø ≠ kOzam, ps3S : Ø ≠ koz, ai1S : Ø ≠ kOzE, pi2P : Ø ≠ kOze, ppFP : Ø ≠ kOze, ps1P : Ø ≠ kOzjô, ps3P : Ø ≠ koz, ps1S : Ø ≠ koz, fi2P : Ø ≠ kOz6re, fi2S : Ø ≠ kOz6ra, pI2P : Ø ≠ kOze, ps2P : Ø ≠ kOzje, ai2P : Ø ≠ kOzat, ai2S : Ø ≠ kOza, pc2P : Ø ≠ kOz6rje, pc2S : Ø ≠ kOz6rE, ii2P : Ø ≠ kOzje, pi1P : Ø ≠ kOzô, ii2S : Ø ≠ kOzE, pi3P : Ø ≠ koz, pc3S : Ø ≠ kOz6rE, pc3P : Ø ≠ kOz6rE, is1S : Ø ≠ kOzas, pc1S : Ø ≠ kOz6rE, fi3S : Ø ≠ kOz6ra, fi3P : Ø ≠ kOz6rô, ai3P : Ø ≠ kOzEr, fi1P : Ø ≠ kOz6rô, fi1S : Ø ≠ kOz6rE, pI1P : Ø ≠ kOzô
# ok
# ii3S : kOzE, inf : kOze, ii3P : kOzE, pi2S : koz, ppFS : kOze, pI2S : koz, ps2S : koz, pi1S : koz, pi3S : koz, ppMS : kOze
#
# enfoncer
# miss
# pc1P : Ø ≠ âfôs6rjô, is3P : Ø ≠ âfôsas, is3S : Ø ≠ âfôsa, ai1P : Ø ≠ âfôsam, ai1S : Ø ≠ âfôsE, ppFP : Ø ≠ âfôse, ps1P : Ø ≠ âfôsjô, ps1S : Ø ≠ âfôs, fi2P : Ø ≠ âfôs6re, fi2S : Ø ≠ âfôs6ra, ps2P : Ø ≠ âfôsje, ai2P : Ø ≠ âfôsat, ai2S : Ø ≠ âfôsa, pc2P : Ø ≠ âfôs6rje, ii2P : Ø ≠ âfôsje, is1S : Ø ≠ âfôsas, fi3P : Ø ≠ âfôs6rô, fi1P : Ø ≠ âfôs6rô
# miss
# pc1P : Ø ≠ vOt6rjô, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ps1P : Ø ≠ vOtjô, pI2S : Ø ≠ vOt, fi2S : Ø ≠ vOt6ra, ps2P : Ø ≠ vOtje, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, ii2P : Ø ≠ vOtje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas
# miss
# pc1P : Ø ≠ vOt6rjô, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ps1P : Ø ≠ vOtjô, fi2P : Ø ≠ vOt6re, fi2S : Ø ≠ vOt6ra, ps2P : Ø ≠ vOtje, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, ii2P : Ø ≠ vOtje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas
# miss
# pc1P : Ø ≠ vOt6rjô, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ps1P : Ø ≠ vOtjô, ps1S : Ø ≠ vOt, pI2S : Ø ≠ vOt, ps2P : Ø ≠ vOtje, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, ii2P : Ø ≠ vOtje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas
# miss
# pc1P : Ø ≠ vOt6rjô, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ps1P : Ø ≠ vOtjô, ps1S : Ø ≠ vOt, fi2P : Ø ≠ vOt6re, ps2P : Ø ≠ vOtje, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, ii2P : Ø ≠ vOtje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas
# miss
# pc1P : Ø ≠ vOt6rjô, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ps1P : Ø ≠ vOtjô, fi2P : Ø ≠ vOt6re, fi2S : Ø ≠ vOt6ra, ps2P : Ø ≠ vOtje, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, pc3P : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas, fi3P : Ø ≠ vOt6rô
# miss
# pc1P : Ø ≠ vOt6rjô, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ai1S : Ø ≠ vOtE, fi2P : Ø ≠ vOt6re, fi2S : Ø ≠ vOt6ra, ps2P : Ø ≠ vOtje, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, pc3P : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas, pc1S : Ø ≠ vOt6rE, fi3P : Ø ≠ vOt6rô, ai3P : Ø ≠ vOtEr
# miss
# pc1P : Ø ≠ vOt6rjô, ppMP : Ø ≠ vOte, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ai1S : Ø ≠ vOtE, ppFP : Ø ≠ vOte, fi2P : Ø ≠ vOt6re, fi2S : Ø ≠ vOt6ra, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, pc2S : Ø ≠ vOt6rE, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, pc3P : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas, pc1S : Ø ≠ vOt6rE, fi3P : Ø ≠ vOt6rô, ai3P : Ø ≠ vOtEr, fi1P : Ø ≠ vOt6rô, fi1S : Ø ≠ vOt6rE
# miss
# pc1P : Ø ≠ vOt6rjô, ppMP : Ø ≠ vOte, is3P : Ø ≠ vOtas, is3S : Ø ≠ vOta, ai1P : Ø ≠ vOtam, ps3S : Ø ≠ vOt, ai1S : Ø ≠ vOtE, ppFP : Ø ≠ vOte, ps1P : Ø ≠ vOtjô, fi2P : Ø ≠ vOt6re, fi2S : Ø ≠ vOt6ra, ps2S : Ø ≠ vOt, ai2P : Ø ≠ vOtat, ai2S : Ø ≠ vOta, pc2P : Ø ≠ vOt6rje, pc2S : Ø ≠ vOt6rE, ii2P : Ø ≠ vOtje, ii2S : Ø ≠ vOtE, pi3S : Ø ≠ vOt, pc3S : Ø ≠ vOt6rE, pc3P : Ø ≠ vOt6rE, is1S : Ø ≠ vOtas, pc1S : Ø ≠ vOt6rE, ai3P : Ø ≠ vOtEr, fi1P : Ø ≠ vOt6rô, fi1S : Ø ≠ vOt6rE
# ok
# ii1P : vOtjô, pP : vOtâ, ii1S : vOtE, ai3S : vOta, ppMP : vOte, ii3S : vOtE, inf : vOte, ii3P : vOtE, pi2S : vOt, ai1S : vOtE, pi2P : vOte, ppFS : vOte, ppFP : vOte, ps3P : vOt, ps1S : vOt, fi2P : vOt6re, pI2P : vOte, pc2S : vOt6rE, pi1S : vOt, pi1P : vOtô, pi3P : vOt, ppMS : vOte, pc3P : vOt6rE, pc1S : vOt6rE, fi3S : vOt6ra, fi3P : vOt6rô, ai3P : vOtEr, fi1P : vOt6rô, fi1S : vOt6rE, pI1P : vOtô
# pc1P : Ø ≠ dOn6rjô, is3P : Ø ≠ dOnas, is3S : Ø ≠ dOna, ai1P : Ø ≠ dOnam, ai1S : Ø ≠ dOnE, fi2S : Ø ≠ dOn6ra, ai2P : Ø ≠ dOnat, ai2S : Ø ≠ dOna, pc2P : Ø ≠ dOn6rje, ii2S : Ø ≠ dOnE, is1S : Ø ≠ dOnas, fi3P : Ø ≠ dOn6rô, ai3P : Ø ≠ dOnEr, pI1P : Ø ≠ dOnô
# ok
# ii1P : dOnjô, pP : dOnâ, ii1S : dOnE, ai3S : dOna, ppMP : dOne, ii3S : dOnE, ps3S : dOn, inf : dOne, ii3P : dOnE, pi2S : dOn, pi2P : dOne, ppFS : dOne, ppFP : dOne, ps1P : dOnjô, ps3P : dOn, ps1S : dOn, pI2S : dOn, fi2P : dOn6re, pI2P : dOne, ps2P : dOnje, ps2S : dOn, pc2S : dOn6rE, ii2P : dOnje, pi1S : dOn, pi1P : dOnô, pi3P : dOn, pi3S : dOn, ppMS : dOne, pc3S : dOn6rE, pc3P : dOn6rE, pc1S : dOn6rE, fi3S : dOn6ra, fi1P : dOn6rô, fi1S : dOn6rE
#
# retomber
# miss
# ii1P : Ø ≠ r6tôbjô, pc1P : Ø ≠ r6tôb6rjô, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, fi2S : Ø ≠ r6tôb6ra, ps2P : Ø ≠ r6tôbje, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, pc3P : Ø ≠ r6tôb6rE, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô, fi1S : Ø ≠ r6tôb6rE
# miss
# pc1P : Ø ≠ r6tôb6rjô, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ai1S : Ø ≠ r6tôbE, ppFP : Ø ≠ r6tôbe, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, fi2S : Ø ≠ r6tôb6ra, ps2P : Ø ≠ r6tôbje, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô, fi1S : Ø ≠ r6tôb6rE
# miss
# ii1P : Ø ≠ r6tôbjô, pc1P : Ø ≠ r6tôb6rjô, ppMP : Ø ≠ r6tôbe, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, ps2P : Ø ≠ r6tôbje, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, pc3P : Ø ≠ r6tôb6rE, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô, fi1S : Ø ≠ r6tôb6rE
# miss
# ii1P : Ø ≠ r6tôbjô, pc1P : Ø ≠ r6tôb6rjô, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, fi2S : Ø ≠ r6tôb6ra, ps2P : Ø ≠ r6tôbje, ps2S : Ø ≠ r6tôb, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, pc3P : Ø ≠ r6tôb6rE, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô
# miss
# pc1P : Ø ≠ r6tôb6rjô, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ai1S : Ø ≠ r6tôbE, ppFP : Ø ≠ r6tôbe, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, fi2S : Ø ≠ r6tôb6ra, ps2P : Ø ≠ r6tôbje, ps2S : Ø ≠ r6tôb, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô
# miss
# ii1P : Ø ≠ r6tôbjô, pc1P : Ø ≠ r6tôb6rjô, ppMP : Ø ≠ r6tôbe, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, ps2P : Ø ≠ r6tôbje, ps2S : Ø ≠ r6tôb, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, pc3P : Ø ≠ r6tôb6rE, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô
# miss
# ii1P : Ø ≠ r6tôbjô, pc1P : Ø ≠ r6tôb6rjô, ppMP : Ø ≠ r6tôbe, is3P : Ø ≠ r6tôbas, is3S : Ø ≠ r6tôba, ai1P : Ø ≠ r6tôbam, ai1S : Ø ≠ r6tôbE, ppFP : Ø ≠ r6tôbe, ps1P : Ø ≠ r6tôbjô, ps1S : Ø ≠ r6tôb, fi2P : Ø ≠ r6tôb6re, ps2P : Ø ≠ r6tôbje, ai2P : Ø ≠ r6tôbat, ai2S : Ø ≠ r6tôba, pc2P : Ø ≠ r6tôb6rje, ii2P : Ø ≠ r6tôbje, is1S : Ø ≠ r6tôbas, fi3P : Ø ≠ r6tôb6rô, fi1P : Ø ≠ r6tôb6rô, fi1S : Ø ≠ r6tôb6rE
# pP : r6tôbâ, ii1S : r6tôbE, ai3S : r6tôba, ii3S : r6tôbE, ps3S : r6tôb, inf : r6tôbe, ii3P : r6tôbE, pi2S : r6tôb, pi2P : r6tôbe, ppFS : r6tôbe, ps3P : r6tôb, pI2S : r6tôb, fi2S : r6tôb6ra, pI2P : r6tôbe, pc2S : r6tôb6rE, pi1S : r6tôb, pi1P : r6tôbô, ii2S : r6tôbE, pi3P : r6tôb, pi3S : r6tôb, ppMS : r6tôbe, pc3S : r6tôb6rE, pc3P : r6tôb6rE, pc1S : r6tôb6rE, fi3S : r6tôb6ra, ai3P : r6tôbEr, fi1S : r6tôb6rE, pI1P : r6tôbô
#
# revenir
# miss
# ii1P : Ø ≠ r6v6njô, pc1P : Ø ≠ r6vjêdriô, is3P : Ø ≠ r6vês, is3S : Ø ≠ r6vê, ai1P : Ø ≠ r6vêm, ppFP : Ø ≠ r6v6ny, ps1P : Ø ≠ r6v6njô, fi2P : Ø ≠ r6vjêdre, ps2P : Ø ≠ r6v6nje, ps2S : Ø ≠ r6vjEn, ai2P : Ø ≠ r6vêt, ai2S : Ø ≠ r6vê, pc2S : Ø ≠ r6vjêdrE, ii2P : Ø ≠ r6v6nje, is1S : Ø ≠ r6vês, fi3P : Ø ≠ r6vjêdrô, ai3P : Ø ≠ r6vêr
# ok
# pP : r6v6nâ, ii1S : r6v6nE, ai3S : r6vê, ppMP : r6v6ny, ii3S : r6v6nE, ps3S : r6vjEn, inf : r6v6nir, ii3P : r6v6nE, pi2S : r6vjê, ai1S : r6vê, pi2P : r6v6ne, ppFS : r6v6ny, ps3P : r6vjEn, ps1S : r6vjEn, pI2S : r6vjê, fi2S : r6vjêdra, pI2P : r6v6ne, pc2P : r6vjêdrie, pi1S : r6vjê, pi1P : r6v6nô, ii2S : r6v6nE, pi3P : r6vjEn, pi3S : r6vjê, ppMS : r6v6ny, pc3S : r6vjêdrE, pc3P : r6vjêdrE, pc1S : r6vjêdrE, fi3S : r6vjêdra, fi1P : r6vjêdrô, fi1S : r6vjêdrE, pI1P : r6v6nô
#
# couler
# miss
# pP : Ø ≠ kulâ, pc1P : Ø ≠ kul6rjô, ii1S : Ø ≠ kulE, is3P : Ø ≠ kulas, is3S : Ø ≠ kula, ai1P : Ø ≠ kulam, ai1S : Ø ≠ kulE, ps1P : Ø ≠ kuljô, ps3P : Ø ≠ kul, ps1S : Ø ≠ kul, fi2P : Ø ≠ kul6re, fi2S : Ø ≠ kul6ra, ps2P : Ø ≠ kulje, ps2S : Ø ≠ kul, ai2P : Ø ≠ kulat, ai2S : Ø ≠ kula, pc2P : Ø ≠ kul6rje, pc2S : Ø ≠ kul6rE, ii2S : Ø ≠ kulE, pc3S : Ø ≠ kul6rE, pc3P : Ø ≠ kul6rE, is1S : Ø ≠ kulas, pc1S : Ø ≠ kul6rE, fi3P : Ø ≠ kul6rô, fi1P : Ø ≠ kul6rô, fi1S : Ø ≠ kul6rE
# miss
# ii1P : Ø ≠ kuljô, pP : Ø ≠ kulâ, pc1P : Ø ≠ kul6rjô, ii1S : Ø ≠ kulE, is3P : Ø ≠ kulas, is3S : Ø ≠ kula, ai1P : Ø ≠ kulam, ai1S : Ø ≠ kulE, ps1P : Ø ≠ kuljô, ps3P : Ø ≠ kul, ps1S : Ø ≠ kul, fi2P : Ø ≠ kul6re, fi2S : Ø ≠ kul6ra, ps2P : Ø ≠ kulje, ps2S : Ø ≠ kul, ai2P : Ø ≠ kulat, ai2S : Ø ≠ kula, pc2P : Ø ≠ kul6rje, pc2S : Ø ≠ kul6rE, ii2P : Ø ≠ kulje, ii2S : Ø ≠ kulE, pc3P : Ø ≠ kul6rE, is1S : Ø ≠ kulas, pc1S : Ø ≠ kul6rE, fi3P : Ø ≠ kul6rô, fi1P : Ø ≠ kul6rô, fi1S : Ø ≠ kul6rE
# ok
# ii1P : kuljô, ai3S : kula, ppMP : kule, ii3S : kulE, ps3S : kul, inf : kule, ii3P : kulE, pi2S : kul, pi2P : kule, ppFS : kule, ppFP : kule, pI2S : kul, pI2P : kule, ii2P : kulje, pi1S : kul, pi1P : kulô, pi3P : kul, pi3S : kul, ppMS : kule, fi3S : kul6ra, ai3P : kulEr, pI1P : kulô
# ok
# ai3S : kula, ppMP : kule, ii3S : kulE, ps3S : kul, inf : kule, ii3P : kulE, pi2S : kul, pi2P : kule, ppFS : kule, ppFP : kule, pI2S : kul, pI2P : kule, pi1S : kul, pi1P : kulô, pi3P : kul, pi3S : kul, ppMS : kule, pc3S : kul6rE, fi3S : kul6ra, ai3P : kulEr, pI1P : kulô
#
# battre
# miss
# ii1P : Ø ≠ batjô, pP : Ø ≠ batâ, pc1P : Ø ≠ batriô, ai3S : Ø ≠ bati, is3P : Ø ≠ batis, is3S : Ø ≠ bati, ai1P : Ø ≠ batim, ps3S : Ø ≠ bat, ai1S : Ø ≠ bati, pi2P : Ø ≠ bate, ppFP : Ø ≠ baty, ps1P : Ø ≠ batjô, ps3P : Ø ≠ bat, fi2P : Ø ≠ batre, fi2S : Ø ≠ batra, ps2P : Ø ≠ batje, ps2S : Ø ≠ bat, ai2P : Ø ≠ batit, ai2S : Ø ≠ bati, pc2P : Ø ≠ batrie, pc2S : Ø ≠ batrE, ii2S : Ø ≠ batE, is1S : Ø ≠ batis, pc1S : Ø ≠ batrE, fi3S : Ø ≠ batra, fi3P : Ø ≠ batrô, ai3P : Ø ≠ batir, fi1S : Ø ≠ batrE, pI1P : Ø ≠ batô
# ok
# ii1S : batE, ppMP : baty, ii3S : batE, inf : batr, ii3P : batE, pi2S : ba, ppFS : baty, ps1S : bat, pI2S : ba, pI2P : bate, ii2P : batje, pi1S : ba, pi1P : batô, pi3P : bat, pi3S : ba, ppMS : baty, pc3S : batrE, pc3P : batrE, fi1P : batrô
#
# ôter
# miss
# ii1P : Ø ≠ Otjô, pP : Ø ≠ Otâ, pc1P : Ø ≠ Ot6rjô, ii1S : Ø ≠ OtE, ppMP : Ø ≠ Ote, is3P : Ø ≠ Otas, is3S : Ø ≠ Ota, ai1P : Ø ≠ Otam, ps3S : Ø ≠ ot, inf : Ø ≠ Ote, pi2S : Ø ≠ ot, ai1S : Ø ≠ OtE, pi2P : Ø ≠ Ote, ppFS : Ø ≠ Ote, ppFP : Ø ≠ Ote, ps1P : Ø ≠ Otjô, ps3P : Ø ≠ ot, ps1S : Ø ≠ ot, fi2S : Ø ≠ Ot6ra, pI2P : Ø ≠ Ote, ps2P : Ø ≠ Otje, ps2S : Ø ≠ ot, ai2P : Ø ≠ Otat, ai2S : Ø ≠ Ota, pc2P : Ø ≠ Ot6rje, pc2S : Ø ≠ Ot6rE, ii2P : Ø ≠ Otje, pi1P : Ø ≠ Otô, ii2S : Ø ≠ OtE, pc3P : Ø ≠ Ot6rE, is1S : Ø ≠ Otas, pc1S : Ø ≠ Ot6rE, fi3S : Ø ≠ Ot6ra, fi3P : Ø ≠ Ot6rô, ai3P : Ø ≠ OtEr, fi1P : Ø ≠ Ot6rô, fi1S : Ø ≠ Ot6rE, pI1P : Ø ≠ Otô
# ok
# ai3S : Ota, ii3S : OtE, ii3P : OtE, pI2S : ot, fi2P : Ot6re, pi1S : ot, pi3P : ot, pi3S : ot, ppMS : Ote, pc3S : Ot6rE
#
# continuer
# miss
# ii1P : Ø ≠ kôtinyjô, pc1P : Ø ≠ kôtinyrjô, ppMP : Ø ≠ kôtinye, is3P : Ø ≠ kôtinyas, ai1P : Ø ≠ kôtinyam, ppFS : Ø ≠ kôtinye, ppFP : Ø ≠ kôtinye, ps1P : Ø ≠ kôtinyjô, ps3P : Ø ≠ kôtiny, ps1S : Ø ≠ kôtiny, fi2P : Ø ≠ kôtinyre, fi2S : Ø ≠ kôtinyra, ps2P : Ø ≠ kôtinyje, ai2P : Ø ≠ kôtinyat, ai2S : Ø ≠ kôtinya, pc2P : Ø ≠ kôtinyrje, ii2P : Ø ≠ kôtinyje, pi1P : Ø ≠ kôtinyô, is1S : Ø ≠ kôtinyas, pc1S : Ø ≠ kôtinyrE, fi3P : Ø ≠ kôtinyrô, pI1P : Ø ≠ kôtinyô
# ok
# pP : kôtinyâ, ii1S : kôtinyE, ai3S : kôtinya, is3S : kôtinya, ii3S : kôtinyE, ps3S : kôtiny, inf : kôtinye, ii3P : kôtinyE, pi2S : kôtiny, ai1S : kôtinyE, pi2P : kôtinye, pI2S : kôtiny, pI2P : kôtinye, ps2S : kôtiny, pc2S : kôtinyrE, pi1S : kôtiny, ii2S : kôtinyE, pi3P : kôtiny, pi3S : kôtiny, ppMS : kôtinye, pc3S : kôtinyrE, pc3P : kôtinyrE, fi3S : kôtinyra, ai3P : kôtinyEr, fi1P : kôtinyrô, fi1S : kôtinyrE
#
# traîner
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, ai3P : Ø ≠ trEnEr, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, ii2S : Ø ≠ trEnE, pc3S : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, ii2S : Ø ≠ trEnE, pc3S : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps3P : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps3P : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pc2S : Ø ≠ trEn6rE, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pc2S : Ø ≠ trEn6rE, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ps3P : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, ai3P : Ø ≠ trEnEr, fi1P : Ø ≠ trEn6rô
# miss
# ii1P : Ø ≠ trEnjô, pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ppFP : Ø ≠ trEne, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, ii2S : Ø ≠ trEnE, pc3S : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, pI1P : Ø ≠ trEnô
# miss
# ii1P : Ø ≠ trEnjô, pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ppFP : Ø ≠ trEne, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, ii2S : Ø ≠ trEnE, pc3S : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, pI1P : Ø ≠ trEnô
# miss
# ii1P : Ø ≠ trEnjô, pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ppFP : Ø ≠ trEne, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, pI1P : Ø ≠ trEnô
# miss
# ii1P : Ø ≠ trEnjô, pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ppFP : Ø ≠ trEne, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, pI1P : Ø ≠ trEnô
# miss
# ii1P : Ø ≠ trEnjô, pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ai1S : Ø ≠ trEnE, ppFP : Ø ≠ trEne, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pc2S : Ø ≠ trEn6rE, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, ii2S : Ø ≠ trEnE, pc3S : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2S : Ø ≠ trEn6ra, ps2P : Ø ≠ trEnje, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pc2S : Ø ≠ trEn6rE, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, ii2S : Ø ≠ trEnE, pc3S : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, fi1P : Ø ≠ trEn6rô, pI1P : Ø ≠ trEnô
# miss
# pc1P : Ø ≠ trEn6rjô, ppMP : Ø ≠ trEne, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pc2S : Ø ≠ trEn6rE, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, ai3P : Ø ≠ trEnEr, fi1P : Ø ≠ trEn6rô
# miss
# pc1P : Ø ≠ trEn6rjô, is3P : Ø ≠ trEnas, is3S : Ø ≠ trEna, ai1P : Ø ≠ trEnam, ps1P : Ø ≠ trEnjô, ps3P : Ø ≠ trEn, ps1S : Ø ≠ trEn, fi2P : Ø ≠ trEn6re, fi2S : Ø ≠ trEn6ra, ai2P : Ø ≠ trEnat, ai2S : Ø ≠ trEna, pc2P : Ø ≠ trEn6rje, pc2S : Ø ≠ trEn6rE, ii2P : Ø ≠ trEnje, pi1P : Ø ≠ trEnô, pc3S : Ø ≠ trEn6rE, pc3P : Ø ≠ trEn6rE, is1S : Ø ≠ trEnas, fi3P : Ø ≠ trEn6rô, ai3P : Ø ≠ trEnEr, fi1P : Ø ≠ trEn6rô
# ok
# ii1P : trEnjô, pP : trEnâ, ii1S : trEnE, ai3S : trEna, ppMP : trEne, ii3S : trEnE, ps3S : trEn, inf : trEne, ii3P : trEnE, pi2S : trEn, pi2P : trEne, ppFS : trEne, ppFP : trEne, ps1P : trEnjô, pI2S : trEn, pI2P : trEne, ps2S : trEn, pc2S : trEn6rE, ii2P : trEnje, pi1S : trEn, ii2S : trEnE, pi3P : trEn, pi3S : trEn, ppMS : trEne, pc1S : trEn6rE, fi3S : trEn6ra, ai3P : trEnEr, fi1P : trEn6rô, fi1S : trEn6rE
# ok
# ii1P : trEnjô, pP : trEnâ, ii1S : trEnE, ai3S : trEna, ppMP : trEne, ii3S : trEnE, ps3S : trEn, inf : trEne, ii3P : trEnE, pi2S : trEn, pi2P : trEne, ppFS : trEne, ppFP : trEne, ps1P : trEnjô, pI2S : trEn, pI2P : trEne, ps2S : trEn, pc2S : trEn6rE, ii2P : trEnje, pi1S : trEn, ii2S : trEnE, pi3P : trEn, pi3S : trEn, ppMS : trEne, pc1S : trEn6rE, fi3S : trEn6ra, ai3P : trEnEr, fi1S : trEn6rE, pI1P : trEnô
# ok
# ii1P : trEnjô, pP : trEnâ, ii1S : trEnE, ai3S : trEna, ppMP : trEne, ii3S : trEnE, ps3S : trEn, inf : trEne, ii3P : trEnE, pi2S : trEn, pi2P : trEne, ppFS : trEne, ppFP : trEne, ps1P : trEnjô, pI2S : trEn, pI2P : trEne, ps2P : trEnje, ps2S : trEn, pc2S : trEn6rE, ii2P : trEnje, pi1S : trEn, ii2S : trEnE, pi3P : trEn, pi3S : trEn, ppMS : trEne, pc1S : trEn6rE, fi3S : trEn6ra, fi1S : trEn6rE, pI1P : trEnô
# ok
# ii1P : trEnjô, pP : trEnâ, ii1S : trEnE, ai3S : trEna, ppMP : trEne, ii3S : trEnE, ps3S : trEn, inf : trEne, ii3P : trEnE, pi2S : trEn, pi2P : trEne, ppFS : trEne, ppFP : trEne, pI2S : trEn, fi2P : trEn6re, pI2P : trEne, ps2S : trEn, pc2S : trEn6rE, pi1S : trEn, pi3P : trEn, pi3S : trEn, ppMS : trEne, pc3P : trEn6rE, pc1S : trEn6rE, fi3S : trEn6ra, ai3P : trEnEr, fi1P : trEn6rô, fi1S : trEn6rE
# ok
# ii1P : Ø ≠ gôfljô, pc1P : Ø ≠ gôfl6rjô, is3P : Ø ≠ gôflas, is3S : Ø ≠ gôfla, ai1P : Ø ≠ gôflam, ai1S : Ø ≠ gôflE, ps1P : Ø ≠ gôfljô, ps3P : Ø ≠ gôfl, ps1S : Ø ≠ gôfl, fi2P : Ø ≠ gôfl6re, fi2S : Ø ≠ gôfl6ra, ps2P : Ø ≠ gôflje, ps2S : Ø ≠ gôfl, ai2P : Ø ≠ gôflat, ai2S : Ø ≠ gôfla, pc2P : Ø ≠ gôfl6rje, pc2S : Ø ≠ gôfl6rE, ii2P : Ø ≠ gôflje, pc3P : Ø ≠ gôfl6rE, is1S : Ø ≠ gôflas, pc1S : Ø ≠ gôfl6rE, fi3P : Ø ≠ gôfl6rô, fi1P : Ø ≠ gôfl6rô, fi1S : Ø ≠ gôfl6rE
# ok
# pP : gôflâ, ii1S : gôflE, ai3S : gôfla, ppMP : gôfle, ii3S : gôflE, ps3S : gôfl, inf : gôfle, ii3P : gôflE, pi2S : gôfl, pi2P : gôfle, ppFS : gôfle, ppFP : gôfle, pI2S : gôfl, pI2P : gôfle, pi1S : gôfl, pi1P : gôflô, ii2S : gôflE, pi3P : gôfl, pi3S : gôfl, ppMS : gôfle, pc3S : gôfl6rE, fi3S : gôfl6ra, ai3P : gôflEr, pI1P : gôflô
#
# céder
# miss
# ii1P : Ø ≠ sEdjô, pc1P : Ø ≠ sEd6rjô, is3P : Ø ≠ sEdas, is3S : Ø ≠ sEda, ai1P : Ø ≠ sEdam, ps1P : Ø ≠ sEdjô, ps3P : Ø ≠ sEd, fi2P : Ø ≠ sEd6re, fi2S : Ø ≠ sEd6ra, ps2P : Ø ≠ sEdje, ai2P : Ø ≠ sEdat, ai2S : Ø ≠ sEda, pc2P : Ø ≠ sEd6rje, pc2S : Ø ≠ sEd6rE, ii2P : Ø ≠ sEdje, pi3P : Ø ≠ sEd, is1S : Ø ≠ sEdas, pc1S : Ø ≠ sEd6rE, fi1S : Ø ≠ sEd6rE
# miss
# ii1P : Ø ≠ sEdjô, pc1P : Ø ≠ sEd6rjô, is3P : Ø ≠ sEdas, is3S : Ø ≠ sEda, ai1P : Ø ≠ sEdam, ps1P : Ø ≠ sEdjô, ps3P : Ø ≠ sEd, ps1S : Ø ≠ sEd, fi2P : Ø ≠ sEd6re, ps2P : Ø ≠ sEdje, ai2P : Ø ≠ sEdat, ai2S : Ø ≠ sEda, pc2P : Ø ≠ sEd6rje, pc2S : Ø ≠ sEd6rE, ii2P : Ø ≠ sEdje, pi3P : Ø ≠ sEd, is1S : Ø ≠ sEdas, pc1S : Ø ≠ sEd6rE, fi1S : Ø ≠ sEd6rE
# miss
# ii1P : Ø ≠ sEdjô, pc1P : Ø ≠ sEd6rjô, is3P : Ø ≠ sEdas, is3S : Ø ≠ sEda, ai1P : Ø ≠ sEdam, ps3P : Ø ≠ sEd, fi2P : Ø ≠ sEd6re, fi2S : Ø ≠ sEd6ra, ps2P : Ø ≠ sEdje, ai2P : Ø ≠ sEdat, ai2S : Ø ≠ sEda, pc2P : Ø ≠ sEd6rje, pc2S : Ø ≠ sEd6rE, ii2P : Ø ≠ sEdje, pi3P : Ø ≠ sEd, pc3P : Ø ≠ sEd6rE, is1S : Ø ≠ sEdas, pc1S : Ø ≠ sEd6rE, fi1P : Ø ≠ sEd6rô, fi1S : Ø ≠ sEd6rE
# miss
# ii1P : Ø ≠ sEdjô, pc1P : Ø ≠ sEd6rjô, is3P : Ø ≠ sEdas, is3S : Ø ≠ sEda, ai1P : Ø ≠ sEdam, ps3P : Ø ≠ sEd, ps1S : Ø ≠ sEd, fi2P : Ø ≠ sEd6re, ps2P : Ø ≠ sEdje, ai2P : Ø ≠ sEdat, ai2S : Ø ≠ sEda, pc2P : Ø ≠ sEd6rje, pc2S : Ø ≠ sEd6rE, pi3P : Ø ≠ sEd, pc3P : Ø ≠ sEd6rE, is1S : Ø ≠ sEdas, pc1S : Ø ≠ sEd6rE, fi3P : Ø ≠ sEd6rô, fi1P : Ø ≠ sEd6rô, fi1S : Ø ≠ sEd6rE
# miss
# ii1P : Ø ≠ sEdjô, pc1P : Ø ≠ sEd6rjô, is3P : Ø ≠ sEdas, is3S : Ø ≠ sEda, ai1P : Ø ≠ sEdam, ps3P : Ø ≠ sEd, ps1S : Ø ≠ sEd, fi2P : Ø ≠ sEd6re, ps2P : Ø ≠ sEdje, ai2P : Ø ≠ sEdat, ai2S : Ø ≠ sEda, pc2P : Ø ≠ sEd6rje, pc2S : Ø ≠ sEd6rE, ii2P : Ø ≠ sEdje, pi3P : Ø ≠ sEd, pc3P : Ø ≠ sEd6rE, is1S : Ø ≠ sEdas, pc1S : Ø ≠ sEd6rE, fi1P : Ø ≠ sEd6rô, fi1S : Ø ≠ sEd6rE
# ok
# pP : sEdâ, ii1S : sEdE, ai3S : sEda, ppMP : sEde, ii3S : sEdE, ps3S : sEd, inf : sEde, ii3P : sEdE, pi2S : sEd, ai1S : sEdE, pi2P : sEde, ppFS : sEde, ppFP : sEde, ps1S : sEd, pI2S : sEd, pI2P : sEde, ps2S : sEd, pi1S : sEd, pi1P : sEdô, ii2S : sEdE, pi3S : sEd, ppMS : sEde, pc3S : sEd6rE, pc3P : sEd6rE, fi3S : sEd6ra, fi3P : sEd6rô, ai3P : sEdEr, fi1P : sEd6rô, pI1P : sEdô
# ok
# pP : sEdâ, ii1S : sEdE, ai3S : sEda, ppMP : sEde, ii3S : sEdE, ps3S : sEd, inf : sEde, ii3P : sEdE, pi2S : sEd, ai1S : sEdE, pi2P : sEde, ppFS : sEde, ppFP : sEde, pI2S : sEd, fi2S : sEd6ra, pI2P : sEde, ps2S : sEd, pi1S : sEd, pi1P : sEdô, ii2S : sEdE, pi3S : sEd, ppMS : sEde, pc3S : sEd6rE, pc3P : sEd6rE, fi3S : sEd6ra, fi3P : sEd6rô, ai3P : sEdEr, fi1P : sEd6rô, pI1P : sEdô
# ok
# pP : sEdâ, ii1S : sEdE, ai3S : sEda, ppMP : sEde, ii3S : sEdE, ps3S : sEd, inf : sEde, ii3P : sEdE, pi2S : sEd, ai1S : sEdE, pi2P : sEde, ppFS : sEde, ppFP : sEde, ps1P : sEdjô, ps1S : sEd, pI2S : sEd, pI2P : sEde, ps2S : sEd, pi1S : sEd, pi1P : sEdô, ii2S : sEdE, pi3S : sEd, ppMS : sEde, pc3S : sEd6rE, fi3S : sEd6ra, fi3P : sEd6rô, ai3P : sEdEr, pI1P : sEdô
# ok
# pP : sEdâ, ii1S : sEdE, ai3S : sEda, ppMP : sEde, ii3S : sEdE, ps3S : sEd, inf : sEde, ii3P : sEdE, pi2S : sEd, ai1S : sEdE, pi2P : sEde, ppFS : sEde, ppFP : sEde, ps1P : sEdjô, pI2S : sEd, fi2S : sEd6ra, pI2P : sEde, ps2S : sEd, ii2P : sEdje, pi1S : sEd, pi1P : sEdô, ii2S : sEdE, pi3S : sEd, ppMS : sEde, pc3S : sEd6rE, fi3S : sEd6ra, ai3P : sEdEr, pI1P : sEdô
# ok
# pP : sEdâ, ii1S : sEdE, ai3S : sEda, ppMP : sEde, ii3S : sEdE, ps3S : sEd, inf : sEde, ii3P : sEdE, pi2S : sEd, ai1S : sEdE, pi2P : sEde, ppFS : sEde, ppFP : sEde, ps1P : sEdjô, pI2S : sEd, fi2S : sEd6ra, pI2P : sEde, ps2S : sEd, pi1S : sEd, pi1P : sEdô, ii2S : sEdE, pi3S : sEd, ppMS : sEde, pc3S : sEd6rE, fi3S : sEd6ra, fi3P : sEd6rô, ai3P : sEdEr, pI1P : sEdô
#
# utiliser
# miss
# pc1P : Ø ≠ ytiliz6rjô, ai3S : Ø ≠ ytiliza, is3P : Ø ≠ ytilizas, is3S : Ø ≠ ytiliza, ai1P : Ø ≠ ytilizam, ii3P : Ø ≠ ytilizE, pi2S : Ø ≠ ytiliz, ps1P : Ø ≠ ytilizjô, fi2P : Ø ≠ ytiliz6re, fi2S : Ø ≠ ytiliz6ra, ps2P : Ø ≠ ytilizje, ai2P : Ø ≠ ytilizat, ai2S : Ø ≠ ytiliza, pc2P : Ø ≠ ytiliz6rje, pc2S : Ø ≠ ytiliz6rE, ii2S : Ø ≠ ytilizE, pc3S : Ø ≠ ytiliz6rE, pc3P : Ø ≠ ytiliz6rE, is1S : Ø ≠ ytilizas, pc1S : Ø ≠ ytiliz6rE, fi3S : Ø ≠ ytiliz6ra, fi3P : Ø ≠ ytiliz6rô, fi1P : Ø ≠ ytiliz6rô, fi1S : Ø ≠ ytiliz6rE
# ok
# ii1P : ytilizjô, pP : ytilizâ, ii1S : ytilizE, ppMP : ytilize, ii3S : ytilizE, ps3S : ytiliz, inf : ytilize, ai1S : ytilizE, pi2P : ytilize, ppFS : ytilize, ppFP : ytilize, ps3P : ytiliz, ps1S : ytiliz, pI2S : ytiliz, pI2P : ytilize, ps2S : ytiliz, ii2P : ytilizje, pi1S : ytiliz, pi1P : ytilizô, pi3P : ytiliz, pi3S : ytiliz, ppMS : ytilize, ai3P : ytilizEr, pI1P : ytilizô

# %%
paradigmes[paradigmes["lexeme"]==u"éprouver"].stack()

# %%
GOLD[GOLD["lexeme"]==u"éprouver"]

# %%
paradigmesCLIQUES[paradigmesCLIQUES["lexeme"]==u"éprouver"].stack()

# %%
paradigmesGOLD

# %%
paradigmesGOLD.loc[paradigmesGOLD["lexeme"]=="boire"]["inf"]

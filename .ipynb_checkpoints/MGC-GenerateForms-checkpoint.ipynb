# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
samplePrefix="MGC-150812-3000-1508140124-paradigmes"
sampleFile=samplePrefix+".csv"
goldFile="MGC-150815-total-1508150555-paradigmes.csv"
analysisPrefix="MGC-150805-total"
logfile_name=analysisPrefix+samplePrefix+".log"
logfile = codecs.open(logfile_name,mode='w',encoding="utf8")

# %% [markdown]
# ###Préparation des cases du paradigme

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# #Préparation du calcul des analogies

# %% [markdown]
# ###Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ###Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ###Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ###Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print (minLongueur, maxLongueur, file=logfile)
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print (phonemes, file=logfile)
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print (forme1,forme2,patron, file=logfile)
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print (patron12,patron21, file=logfile)
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print ("patron1", patron, file=logfile)
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print ("patron2", patron, file=logfile)
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmes=pd.read_csv(sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]

# %%
GOLD=pd.read_csv(goldFile,sep=";",encoding="utf8")
del GOLD[u"Unnamed: 0"]
paradigmesGOLD=GOLD[paradigmes.columns.values.tolist()]

# %% [markdown]
# - listeCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
listeCases=paradigmes.columns.values.tolist()
listeCases.remove(u"lexeme")

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 4000

# %%
with open(analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in casesTotales}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=casesTotales):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    for forme in listeCases:
        if not pd.isnull(paradigmes[paradigmes["lexeme"]==lexeme][forme].iloc[0]):
            depart=paradigmes[paradigmes["lexeme"]==lexeme][forme].iloc[0]
            if debug: print (forme,depart, file=logfile)
            if depart!="nan":
                for case in casesTotales:
                    if debug: print (case, file=logfile)
                    if not isinstance(resultatsLecture[(forme, case)],str):
                        if "," in depart:
                            departs=depart.split(",")
                            coef=1.0/len(departs)
                            for element in departs:
                                candidats.ajouterFormes(case,resultatsLecture[(forme, case)].sortirForme(element),coef)
                        else:
                            candidats.ajouterFormes(case,resultatsLecture[(forme, case)].sortirForme(depart))
                    else: print ("str", resultatsLecture[(forme, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    digraphe.add_node(pointName)
    graphe.add_node(pointName)
    return pointName

def ajouterFleche(depart,sortie,coef):
    digraphe.add_edge(depart,sortie,weight=float(coef))
    if digraphe.has_edge(sortie,depart):
        coefGraphe=float(digraphe.edge[sortie][depart]["weight"]+coef)/2
        graphe.add_edge(depart,sortie,weight=coefGraphe)

# %%
def generateParadigms(generation1):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    for caseDepart in casesTotales:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in casesTotales:
                    distributionSortie=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortie:
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie))
    return candidats

# %%
def generate(lexeme):
    print ("génération 1",end=", ")
    generation1=generateForms(lexeme)
    print ("génération 2",end=", ")
    generation2=generateParadigms(generation1)
    print ("génération 3")
    return generation2

# %%
len(paradigmes.dropna(thresh=3)["lexeme"])
# Out:
# 501

# %%
# %%time
debug=True
listeTest=[u"manger",u"boire",u"dormir",u"aller",u"avoir"]
listeTest=paradigmes.dropna(thresh=3)["lexeme"].values.tolist()
digraphe=nx.DiGraph()
graphe=nx.Graph()
for i,element in enumerate(listeTest):
    print (i,end=", ")
    generate(element)
# Out:
# 0, génération 1, génération 2, génération 3
# 1, génération 1, génération 2, génération 3
# 2, génération 1, génération 2, génération 3
# 3, génération 1, génération 2, génération 3
# 4, génération 1, génération 2, génération 3
# 5, génération 1, génération 2, génération 3
# 6, génération 1, génération 2, génération 3
# 7, génération 1, génération 2, génération 3
# 8, génération 1, génération 2, génération 3
# 9, génération 1, génération 2, génération 3
# 10, génération 1, génération 2, génération 3
# 11, génération 1, génération 2, génération 3
# 12, génération 1, génération 2, génération 3
# 13, génération 1, génération 2, génération 3
# 14, génération 1, génération 2, génération 3
# 15, génération 1, génération 2, génération 3
# 16, génération 1, génération 2, génération 3
# 17, génération 1, génération 2, génération 3
# 18, génération 1, génération 2, génération 3
# 19, génération 1, génération 2, génération 3
# 20, génération 1, génération 2, génération 3
# 21, génération 1, génération 2, génération 3
# 22, génération 1, génération 2, génération 3
# 23, génération 1, génération 2, génération 3
# 24, génération 1, génération 2, génération 3
# 25, génération 1, génération 2, génération 3
# 26, génération 1, génération 2, génération 3
# 27, génération 1, génération 2, génération 3
# 28, génération 1, génération 2, génération 3
# 29, génération 1, génération 2, génération 3
# 30, génération 1, génération 2, génération 3
# 31, génération 1, génération 2, génération 3
# 32, génération 1, génération 2, génération 3
# 33, génération 1, génération 2, génération 3
# 34, génération 1, génération 2, génération 3
# 35, génération 1, génération 2, génération 3
# 36, génération 1, génération 2, génération 3
# 37, génération 1, génération 2, génération 3
# 38, génération 1, génération 2, génération 3
# 39, génération 1, génération 2, génération 3
# 40, génération 1, génération 2, génération 3
# 41, génération 1, génération 2, génération 3
# 42, génération 1, génération 2, génération 3
# 43, génération 1, génération 2, génération 3
# 44, génération 1, génération 2, génération 3
# 45, génération 1, génération 2, génération 3
# 46, génération 1, génération 2, génération 3
# 47, génération 1, génération 2, génération 3
# 48, génération 1, génération 2, génération 3
# 49, génération 1, génération 2, génération 3
# 50, génération 1, génération 2, génération 3
# 51, génération 1, génération 2, génération 3
# 52, génération 1, génération 2, génération 3
# 53, génération 1, génération 2, génération 3
# 54, génération 1, génération 2, génération 3
# 55, génération 1, génération 2, génération 3
# 56, génération 1, génération 2, génération 3
# 57, génération 1, génération 2, génération 3
# 58, génération 1, génération 2, génération 3
# 59, génération 1, génération 2, génération 3
# 60, génération 1, génération 2, génération 3
# 61, génération 1, génération 2, génération 3
# 62, génération 1, génération 2, génération 3
# 63, génération 1, génération 2, génération 3
# 64, génération 1, génération 2, génération 3
# 65, génération 1, génération 2, génération 3
# 66, génération 1, génération 2, génération 3
# 67, génération 1, génération 2, génération 3
# 68, génération 1, génération 2, génération 3
# 69, génération 1, génération 2, génération 3
# 70, génération 1, génération 2, génération 3
# 71, génération 1, génération 2, génération 3
# 72, génération 1, génération 2, génération 3
# 73, génération 1, génération 2, génération 3
# 74, génération 1, génération 2, génération 3
# 75, génération 1, génération 2, génération 3
# 76, génération 1, génération 2, génération 3
# 77, génération 1, génération 2, génération 3
# 78, génération 1, génération 2, génération 3
# 79, génération 1, génération 2, génération 3
# 80, génération 1, génération 2, génération 3
# 81, génération 1, génération 2, génération 3
# 82, génération 1, génération 2, génération 3
# 83, génération 1, génération 2, génération 3
# 84, génération 1, génération 2, génération 3
# 85, génération 1, génération 2, génération 3
# 86, génération 1, génération 2, génération 3
# 87, génération 1, génération 2, génération 3
# 88, génération 1, génération 2, génération 3
# 89, génération 1, génération 2, génération 3
# 90, génération 1, génération 2, génération 3
# 91, génération 1, génération 2, génération 3
# 92, génération 1, génération 2, génération 3
# 93, génération 1, génération 2, génération 3
# 94, génération 1, génération 2, génération 3
# 95, génération 1, génération 2, génération 3
# 96, génération 1, génération 2, génération 3
# 97, génération 1, génération 2, génération 3
# 98, génération 1, génération 2, génération 3
# 99, génération 1, génération 2, génération 3
# 100, génération 1, génération 2, génération 3
# 101, génération 1, génération 2, génération 3
# 102, génération 1, génération 2, génération 3
# 103, génération 1, génération 2, génération 3
# 104, génération 1, génération 2, génération 3
# 105, génération 1, génération 2, génération 3
# 106, génération 1, génération 2, génération 3
# 107, génération 1, génération 2, génération 3
# 108, génération 1, génération 2, génération 3
# 109, génération 1, génération 2, génération 3
# 110, génération 1, génération 2, génération 3
# 111, génération 1, génération 2, génération 3
# 112, génération 1, génération 2, génération 3
# 113, génération 1, génération 2, génération 3
# 114, génération 1, génération 2, génération 3
# 115, génération 1, génération 2, génération 3
# 116, génération 1, génération 2, génération 3
# 117, génération 1, génération 2, génération 3
# 118, génération 1, génération 2, génération 3
# 119, génération 1, génération 2, génération 3
# 120, génération 1, génération 2, génération 3
# 121, génération 1, génération 2, génération 3
# 122, génération 1, génération 2, génération 3
# 123, génération 1, génération 2, génération 3
# 124, génération 1, génération 2, génération 3
# 125, génération 1, génération 2, génération 3
# 126, génération 1, génération 2, génération 3
# 127, génération 1, génération 2, génération 3
# 128, génération 1, génération 2, génération 3
# 129, génération 1, génération 2, génération 3
# 130, génération 1, génération 2, génération 3
# 131, génération 1, génération 2, génération 3
# 132, génération 1, génération 2, génération 3
# 133, génération 1, génération 2, génération 3
# 134, génération 1, génération 2, génération 3
# 135, génération 1, génération 2, génération 3
# 136, génération 1, génération 2, génération 3
# 137, génération 1, génération 2, génération 3
# 138, génération 1, génération 2, génération 3
# 139, génération 1, génération 2, génération 3
# 140, génération 1, génération 2, génération 3
# 141, génération 1, génération 2, génération 3
# 142, génération 1, génération 2, génération 3
# 143, génération 1, génération 2, génération 3
# 144, génération 1, génération 2, génération 3
# 145, génération 1, génération 2, génération 3
# 146, génération 1, génération 2, génération 3
# 147, génération 1, génération 2, génération 3
# 148, génération 1, génération 2, génération 3
# 149, génération 1, génération 2, génération 3
# 150, génération 1, génération 2, génération 3
# 151, génération 1, génération 2, génération 3
# 152, génération 1, génération 2, génération 3
# 153, génération 1, génération 2, génération 3
# 154, génération 1, génération 2, génération 3
# 155, génération 1, génération 2, génération 3
# 156, génération 1, génération 2, génération 3
# 157, génération 1, génération 2, génération 3
# 158, génération 1, génération 2, génération 3
# 159, génération 1, génération 2, génération 3
# 160, génération 1, génération 2, génération 3
# 161, génération 1, génération 2, génération 3
# 162, génération 1, génération 2, génération 3
# 163, génération 1, génération 2, génération 3
# 164, génération 1, génération 2, génération 3
# 165, génération 1, génération 2, génération 3
# 166, génération 1, génération 2, génération 3
# 167, génération 1, génération 2, génération 3
# 168, génération 1, génération 2, génération 3
# 169, génération 1, génération 2, génération 3
# 170, génération 1, génération 2, génération 3
# 171, génération 1, génération 2, génération 3
# 172, génération 1, génération 2, génération 3
# 173, génération 1, génération 2, génération 3
# 174, génération 1, génération 2, génération 3
# 175, génération 1, génération 2, génération 3
# 176, génération 1, génération 2, génération 3
# 177, génération 1, génération 2, génération 3
# 178, génération 1, génération 2, génération 3
# 179, génération 1, génération 2, génération 3
# 180, génération 1, génération 2, génération 3
# 181, génération 1, génération 2, génération 3
# 182, génération 1, génération 2, génération 3
# 427, génération 1, génération 2, génération 3
# 428, génération 1, génération 2, génération 3
# 429, génération 1, génération 2, génération 3
# 430, génération 1, génération 2, génération 3
# 431, génération 1, génération 2, génération 3
# 432, génération 1, génération 2, génération 3
# 433, génération 1, génération 2, génération 3
# 434, génération 1, génération 2, génération 3
# 435, génération 1, génération 2, génération 3
# 436, génération 1, génération 2, génération 3
# 437, génération 1, génération 2, génération 3
# 438, génération 1, génération 2, génération 3
# 439, génération 1, génération 2, génération 3
# 440, génération 1, génération 2, génération 3
# 441, génération 1, génération 2, génération 3
# 442, génération 1, génération 2, génération 3
# 443, génération 1, génération 2, génération 3
# 444, génération 1, génération 2, génération 3
# 445, génération 1, génération 2, génération 3
# 446, génération 1, génération 2, génération 3
# 447, génération 1, génération 2, génération 3
# 448, génération 1, génération 2, génération 3
# 449, génération 1, génération 2, génération 3
# 450, génération 1, génération 2, génération 3
# 451, génération 1, génération 2, génération 3
# 452, génération 1, génération 2, génération 3
# 453, génération 1, génération 2, génération 3
# 454, génération 1, génération 2, génération 3
# 455, génération 1, génération 2, génération 3
# 456, génération 1, génération 2, génération 3
# 457, génération 1, génération 2, génération 3
# 458, génération 1, génération 2, génération 3
# 459, génération 1, génération 2, génération 3
# 460, génération 1, génération 2, génération 3
# 461, génération 1, génération 2, génération 3
# 462, génération 1, génération 2, génération 3
# 463, génération 1, génération 2, génération 3
# 464, génération 1, génération 2, génération 3
# 465, génération 1, génération 2, génération 3
# 466, génération 1, génération 2, génération 3
# 467, génération 1, génération 2, génération 3
# 468, génération 1, génération 2, génération 3
# 469, génération 1, génération 2, génération 3
# 470, génération 1, génération 2, génération 3
# 471, génération 1, génération 2, génération 3
# 472, génération 1, génération 2, génération 3
# 473, génération 1, génération 2, génération 3
# 474, génération 1, génération 2, génération 3
# 475, génération 1, génération 2, génération 3
# 476, génération 1, génération 2, génération 3
# 477, génération 1, génération 2, génération 3
# 478, génération 1, génération 2, génération 3
# 479, génération 1, génération 2, génération 3
# 480, génération 1, génération 2, génération 3
# 481, génération 1, génération 2, génération 3
# 482, génération 1, génération 2, génération 3
# 483, génération 1, génération 2, génération 3
# 484, génération 1, génération 2, génération 3
# 485, génération 1, génération 2, génération 3
# 486, génération 1, génération 2, génération 3
# 487, génération 1, génération 2, génération 3
# 488, génération 1, génération 2, génération 3
# 489, génération 1, génération 2, génération 3
# 490, génération 1, génération 2, génération 3
# 491, génération 1, génération 2, génération 3
# 492, génération 1, génération 2, génération 3
# 493, génération 1, génération 2, génération 3
# 494, génération 1, génération 2, génération 3
# 495, génération 1, génération 2, génération 3
# 496, génération 1, génération 2, génération 3
# 497, génération 1, génération 2, génération 3
# 498, génération 1, génération 2, génération 3
# 499, génération 1, génération 2, génération 3
# 500, génération 1, génération 2, génération 3
# CPU times: user 41min 49s, sys: 55.5 s, total: 42min 45s
# Wall time: 43min 53s

# %%
#nx.write_dot(digraphe,u"digraphe.dot")
#nx.write_dot(graphe,u"graphe.dot")

# %%
cliques=list(nx.algorithms.clique.find_cliques(graphe))

# %%
for element in listeTest:
    print (element,paradigmes[paradigmes["lexeme"]==element].stack().value_counts(dropna=True).sum()-1)
for element in listeTest:
    print (paradigmes[paradigmes["lexeme"]==element].stack())
# Out:
# abandonner 4
# abattre 3
# accepter 2
# accompagner 2
# accomplir 2
# accorder 2
# accrocher 2
# acheter 6
# achever 2
# admettre 4
# admirer 2
# adopter 2
# adorer 3
# adoucir 2
# adresser 3
# agacer 2
# agir 4
# agiter 2
# aider 11
# aimer 22
# ajouter 5
# aller 23
# allonger 3
# allumer 2
# amener 5
# amuser 6
# annoncer 3
# anéantir 2
# apercevoir 6
# apparaître 3
# appartenir 2
# appeler 13
# applaudir 2
# apporter 7
# apprendre 6
# approcher 6
# approuver 2
# apprécier 2
# arranger 8
# arriver 14
# arrêter 15
# asseoir 12
# assurer 3
# attaquer 5
# atteindre 3
# attendre 16
# attirer 2
# attraper 2
# avancer 4
# avertir 3
# avoir 25
# avouer 2
# baigner 3
# baiser 3
# baptiser 3
# basculer 2
# battre 3
# boire 4
# bosser 3
# bouffer 2
# bouger 5
# bousculer 3
# briser 2
# brûler 6
# bâtir 2
# bénir 2
# cacher 8
# calmer 7
# caresser 2
# casser 6
# causer 4
# cesser 4
# changer 6
# chanter 4
# charger 4
# chasser 3
# chercher 12
# chier 2
# choisir 5
# chuchoter 4
# claquer 3
# cogner 2
# coincer 2
# coller 2
# commander 5
# commencer 12
# comprendre 13
# compter 7
# concerner 4
# conclure 2
# condamner 3
# conduire 5
# confirmer 3
# confondre 5
# connaître 14
# considérer 6
# consoler 2
# constater 3
# construire 4
# consulter 2
# continuer 9
# contrôler 4
# convaincre 3
# coucher 8
# couler 5
# couper 3
# courir 2
# couvrir 2
# coûter 4
# craindre 6
# craquer 2
# crier 7
# croire 12
# créer 2
# cueillir 3
# céder 3
# célébrer 2
# danser 7
# dater 2
# demander 12
# demeurer 2
# descendre 9
# devenir 12
# deviner 2
# devoir 23
# dicter 2
# dire 24
# diriger 3
# disparaître 6
# disposer 2
# dissimuler 2
# distinguer 2
# donner 16
# dormir 8
# douter 4
# durer 3
# débarrasser 2
# déborder 2
# décider 5
# découvrir 4
# défiler 3
# dégager 6
# déjeuner 2
# démarrer 2
# dénoncer 3
# dépendre 2
# dépenser 2
# déplacer 4
# déposer 2
# dépêcher 2
# déranger 3
# désigner 3
# désirer 5
# désoler 2
# détacher 2
# détendre 2
# détester 5
# détruire 2
# dîner 3
# emballer 3
# embaucher 2
# embrasser 6
# embêter 3
# emmener 6
# emmerder 2
# employer 2
# emporter 5
# empêcher 4
# endormir 2
# enfermer 4
# enfoncer 4
# engager 2
# enlever 3
# ennuyer 6
# entendre 9
# enterrer 3
# entraîner 3
# entrer 8
# envahir 3
# envoyer 10
# espérer 6
# essayer 11
# estimer 2
# exalter 2
# examiner 3
# excuser 7
# exercer 3
# exister 4
# expliquer 7
# exposer 3
# faillir 2
# faire 25
# falloir 5
# fatiguer 3
# fermer 7
# ficher 5
# figurer 2
# filer 2
# finir 12
# fixer 2
# flairer 2
# forcer 2
# songer 3
# sonner 3
# sortir 13
# souffler 2
# souffrir 3
# souhaiter 3
# soulever 5
# soupirer 2
# sourire 6
# souvenir 7
# sucer 3
# suffire 3
# suivre 6
# supporter 3
# supposer 4
# surgir 4
# surprendre 3
# surveiller 4
# sécher 4
# séparer 2
# taire 7
# taper 3
# tendre 2
# tenir 12
# tirer 11
# tomber 8
# toucher 7
# tourner 9
# traduire 2
# traiter 5
# transformer 3
# transporter 2
# travailler 8
# traverser 2
# traîner 2
# trembler 3
# triompher 3
# tromper 5
# trouver 21
# tuer 11
# tâter 3
# téléphoner 4
# unir 2
# utiliser 7
# vaincre 2
# valoir 2
# veiller 2
# vendre 3
# venir 22
# verser 2
# vieillir 2
# visiter 4
# vivre 7
# voir 22
# voler 5
# vomir 2
# voter 3
# vouloir 17
# vérifier 4
# écarter 5
# échanger 2
# échapper 4
# éclairer 3
# éclater 4
# écouter 9
# écraser 2
# écrire 5
# élancer 2
# élever 3
# éloigner 5
# émerveiller 2
# énerver 2
# épargner 3
# épouser 5
# éprouver 3
# éteindre 3
# étendre 3
# étonner 5
# étouffer 2
# éviter 3
# évoquer 2
# être 32
# ôter 2
# 1  lexeme    abandonner
#    fi1P       abâdOn6rô
#    inf          abâdOne
#    pI2S          abâdOn
#    ppMS         abâdOne
# dtype: object
# 2  lexeme    abattre
#    inf         abatr
#    pi1S          aba
#    ppMS        abaty
# dtype: object
# 6  lexeme    accepter
#    pP         aksEptâ
#    pi3S        aksEpt
# dtype: object
# 8  lexeme    accompagner
#    pI2S           akôpaJ
#    ps1S           akôpaJ
# dtype: object
# 9  lexeme    accomplir
#    inf         akôplir
#    ppFS         akôpli
# dtype: object
# 10  lexeme    accorder
#     pI2S         akOrd
#     ps3S         akOrd
# dtype: object
# 11  lexeme    accrocher
#     pi2P         akrOSe
#     ppFS         akrOSe
# dtype: object
# 15  lexeme    acheter
#     inf         aS6te
#     pI2P        aS6te
#     pI2S         aSEt
#     pi1S         aSEt
#     pi3S         aSEt
#     ppFP        aS6te
# dtype: object
# 16  lexeme    achever
#     inf         aS6ve
#     pi3S         aSEv
# dtype: object
# 19  lexeme    admettre
#     inf         admEtr
#     pI2S          admE
#     pP          admEtâ
#     pi3S          admE
# dtype: object
# 20  lexeme    admirer
#     ii3S       admirE
#     pi3S        admir
# dtype: object
# 21  lexeme    adopter
#     ii3S       adOptE
#     ppMS       adOpte
# dtype: object
# 22  lexeme    adorer
#     ii2S       adOrE
#     pI2S        adOr
#     pi3S        adOr
# dtype: object
# 23  lexeme    adoucir
#     ii3S      adusisE
#     inf        adusir
# dtype: object
# 24  lexeme    adresser
#     ii3S        adrEsE
#     inf         adrEse
#     ps3S         adrEs
# dtype: object
# 30  lexeme    agacer
#     inf        agase
#     ppMS       agase
# dtype: object
# 33  lexeme     agir
#     ai3S        aZi
#     pc3S      aZirE
#     pi2S        aZi
#     pi3S        aZi
# dtype: object
# 34  lexeme     agiter
#     fi3P      aZit6rô
#     inf         aZite
# dtype: object
# 35  lexeme    aider
#     fi1S      Ed6rE
#     ii3P        EdE
#     inf         Ede
#     pI2P        Ede
#     pI2S         Ed
#     pi1S         Ed
#     pi2P        Ede
#     pi3S         Ed
#     ppMS        Ede
#     ps1S         Ed
#     ps3S         Ed
# dtype: object
# 36  lexeme     aimer
#     fi1S       Em6rE
#     fi3P       Em6rô
#     ii1S         EmE
#     ii2P        Emje
#     ii2S         EmE
#     ii3S         EmE
#     inf          Eme
#     pI2P         Eme
#     pI2S          Em
#     pc1P      Em6rjô
#     pc1S       Em6rE
#     pc2S       Em6rE
#     pi1P         Emô
#     pi1S          Em
#     pi2S          Em
#     pi3P          Em
#     pi3S          Em
#     ppFS         Eme
#     ppMS         Eme
#     ps1S          Em
#     ps2S          Em
#     ps3S          Em
# dtype: object
# 37  lexeme    ajouter
#     ii3S        aZutE
#     pI2S         aZut
#     pc2S      aZut6rE
#     ppMS        aZute
#     ps3S         aZut
# dtype: object
# 39  lexeme    aller
#     ai3S        ala
#     fi2P        ire
#     fi3S        ira
#     ii1S        alE
#     ii2P       alje
#     ii2S        alE
#     ii3S        alE
#     inf         ale
#     pI1P        alô
#     pI2P        ale
#     pI2S         va
#     pc1P       irjô
#     pc3S        irE
#     pi1P        alô
#     pi1S         vE
#     pi2P        ale
#     pi2S         va
#     pi3P         vô
#     pi3S         va
#     ppFS        ale
#     ppMS        ale
#     ps1S         aj
#     ps3S         aj
# dtype: object
# 41  lexeme    allonger
#     inf          alôZe
#     ppFS         alôZe
#     ppMS         alôZe
# dtype: object
# 42  lexeme    allumer
#     pi1S         alym
#     pi2P        alyme
# dtype: object
# 45  lexeme    amener
#     pI2S        amEn
#     ppMS       am6ne
#     ps1S        amEn
#     ps2S        amEn
#     ps3S        amEn
# dtype: object
# 46  lexeme    amuser
#     ii2P      amyzje
#     inf        amyze
#     pi2S        amyz
#     pi3P        amyz
#     pi3S        amyz
#     ps3S        amyz
# dtype: object
# 48  lexeme    annoncer
#     ii2S         anôsE
#     ii3S         anôsE
#     ppMS         anôse
# dtype: object
# 50  lexeme    anéantir
#     ppMP        anEâti
#     ppMS        anEâti
# dtype: object
# 52  lexeme    apercevoir
#     ii3S        apErs6vE
#     inf       apErs6vwar
#     pc2S       apErs6vrE
#     pi1S         apErswa
#     pi2S         apErswa
#     ppMP          apErsy
# dtype: object
# 54  lexeme    apparaître
#     inf          aparEtr
#     ppFS           apary
#     ppMP           apary
# dtype: object
# 56  lexeme    appartenir
#     ii3S        apart6nE
#     pi3S         apartjê
# dtype: object
# 57  lexeme    appeler
#     ai3S        ap6la
#     ii2S        ap6lE
#     ii3S        ap6lE
#     inf         ap6le
#     pI2P        ap6le
#     pI2S         apEl
#     pi1S         apEl
#     pi2P        ap6le
#     pi2S         apEl
#     pi3S         apEl
#     ppMS        ap6le
#     ps1S         apEl
#     ps3S         apEl
# dtype: object
# 58  lexeme    applaudir
#     ai3S         aplOdi
#     fi1S       aplOdirE
# dtype: object
# 60  lexeme    apporter
#     ii3S        apOrtE
#     inf         apOrte
#     pI2P        apOrte
#     pi1S         apOrt
#     pi3S         apOrt
#     ppMP        apOrte
#     ps3S         apOrt
# dtype: object
# 61  lexeme    apprendre
#     ai1S           apri
#     ai2S           apri
#     ii3S         apr6nE
#     inf          aprâdr
#     pi2P         apr6ne
#     pi3S           aprâ
# dtype: object
# 63  lexeme    approcher
#     ii3S         aprOSE
#     inf          aprOSe
#     pI2P         aprOSe
#     pi2P         aprOSe
#     pi3S          aprOS
#     ps2S          aprOS
# dtype: object
# 64  lexeme    approuver
#     inf          apruve
#     pi1S          apruv
# dtype: object
# 65  lexeme    apprécier
#     pI2S         aprEsi
#     pi1S         aprEsi
# dtype: object
# 68  lexeme    arranger
#     fi3P       arâZ6rô
#     ii3S         arâZE
#     inf          arâZe
#     pI2S          arâZ
#     pc3S       arâZ6rE
#     pi1S          arâZ
#     pi3S          arâZ
#     ppMS         arâZe
# dtype: object
# 69  lexeme    arriver
#     ai3S        ariva
#     fi3S      ariv6ra
#     ii1S        arivE
#     ii3P        arivE
#     ii3S        arivE
#     inf         arive
#     pI2S         ariv
#     pi1S         ariv
#     pi3P         ariv
#     pi3S         ariv
#     ppFS        arive
#     ppMS        arive
#     ps1S         ariv
#     ps3S         ariv
# dtype: object
# 70  lexeme    arrêter
#     ai3S        arEta
#     fi3S      arEt6ra
#     ii2S        arEtE
#     ii3S        arEtE
#     inf         arEte
#     pI2P        arEte
#     pI2S         arEt
#     pi1S         arEt
#     pi2P        arEte
#     pi2S         arEt
#     pi3S         arEt
#     ppMP        arEte
#     ppMS        arEte
#     ps1S         arEt
#     ps3S         arEt
# dtype: object
# 73  lexeme      asseoir
#     ai1S            asi
#     ai2S            asi
#     ai3S            asi
#     ii3S          asEjE
#     inf           aswar
#     pI2P          asEje
#     pI2S           asje
#     pi1S           asje
#     pi2P          asEje
#     pi3S      asje,aswa
#     ppFP           asiz
#     ppFS           asiz
# dtype: object
# 77  lexeme    assurer
#     inf         asyre
#     pi3S         asyr
#     ps3S         asyr
# dtype: object
# 78  lexeme    attaquer
#     pI2S          atak
#     pi1S          atak
#     pi3S          atak
#     ps3P          atak
#     ps3S          atak
# dtype: object
# 79  lexeme    atteindre
#     pI1P          atEJô
#     pi3S            atê
#     ppMS            atê
# dtype: object
# 80  lexeme    attendre
#     ai3S         atâdi
#     fi1S        atâdrE
#     ii1P        atâdjô
#     ii1S         atâdE
#     ii2S         atâdE
#     ii3S         atâdE
#     inf          atâdr
#     pI2P         atâde
#     pI2S           atâ
#     pi1P         atâdô
#     pi1S           atâ
#     pi2P         atâde
#     pi2S           atâ
#     pi3P          atâd
#     pi3S           atâ
#     ppMS         atâdy
# dtype: object
# 81  lexeme    attirer
#     ii3S        atirE
#     inf         atire
# dtype: object
# 82  lexeme    attraper
#     inf         atrape
#     ps3S         atrap
# dtype: object
# 86  lexeme    avancer
#     ai3S        avâsa
#     pI2S         avâs
#     pP          avâsâ
#     pi3S         avâs
# dtype: object
# 87  lexeme    avertir
#     inf       avErtir
#     pi1S       avErti
#     pi2S       avErti
# dtype: object
# 89  lexeme    avoir
#     ai3S          y
#     fi1P        Orô
#     fi1S        OrE
#     fi2P        Ore
#     fi2S        Ora
#     fi3P        Orô
#     fi3S        Ora
#     ii1P       avjô
#     ii1S        avE
#     ii2S        avE
#     ii3P        avE
#     ii3S        avE
#     inf       avwar
#     pI2P        Eje
#     pI2S          E
#     pc1S        OrE
#     pi1P        avô
#     pi1S          E
#     pi2P        ave
#     pi2S          a
#     pi3P          ô
#     pi3S          a
#     ppMP          y
#     ppMS          y
#     ps2P        Eje
# dtype: object
# 90  lexeme    avouer
#     inf         avue
#     pI2P        avue
# dtype: object
# 93  lexeme    baigner
#     ii3P         bEJE
#     pI2S          bEJ
#     pi3S          bEJ
# dtype: object
# 94  lexeme    baiser
#     inf         bEze
#     pI2S         bEz
#     ps2S         bEz
# dtype: object
# 99  lexeme    baptiser
#     inf         batize
#     ppMP        batize
#     ps3S         batiz
# dtype: object
# 101  lexeme    basculer
#      inf        baskyle
#      pi1S        baskyl
# dtype: object
# 102  lexeme    battre
#      inf         batr
#      pi3S          ba
#      ppFS        baty
# dtype: object
# 108  lexeme    boire
#      inf        bwar
#      pc2S      bwarE
#      pi1P       byvô
#      ppMS         by
# dtype: object
# 109  lexeme    bosser
#      pI2S         bOs
#      pi1S         bOs
#      pi2S         bOs
# dtype: object
# 111  lexeme    bouffer
#      inf          bufe
#      ppMS         bufe
# dtype: object
# 112  lexeme    bouger
#      ii3S        buZE
#      pI2S         buZ
#      pi1S         buZ
#      pi3S         buZ
#      ppMS        buZe
# dtype: object
# 116  lexeme    bousculer
#      inf         buskyle
#      pP          buskylâ
#      ppMS        buskyle
# dtype: object
# 121  lexeme    briser
#      ii3S       brizE
#      ppMP       brize
# dtype: object
# 123  lexeme    brûler
#      pI2P       bryle
#      pI2S        bryl
#      pi1S        bryl
#      pi3S        bryl
#      ppMS       bryle
#      ps3S        bryl
# dtype: object
# 125  lexeme    bâtir
#      inf       batir
#      ppFS       bati
# dtype: object
# 126  lexeme    bénir
#      ppMS       bEni
#      ps1S      bEnis
# dtype: object
# 130  lexeme    cacher
#      ii1S        kaSE
#      inf         kaSe
#      pI2S         kaS
#      pi1S         kaS
#      pi2P        kaSe
#      ps1S         kaS
#      ps2S         kaS
#      ps3S         kaS
# dtype: object
# 133  lexeme     calmer
#      fi3S      kalm6ra
#      inf         kalme
#      pI2P        kalme
#      pi2P        kalme
#      pi3S         kalm
#      ps1S         kalm
#      ps3S         kalm
# dtype: object
# 135  lexeme    caresser
#      inf         karEse
#      ps3S         karEs
# dtype: object
# 136  lexeme    casser
#      pI2S         kas
#      pi1S         kas
#      pi3S         kas
#      ppMS        kase
#      ps1S         kas
#      ps3S         kas
# dtype: object
# 137  lexeme    causer
#      ii3S        kOzE
#      pP          kOzâ
#      pi1S         koz
#      ppFS        kOze
# dtype: object
# 139  lexeme    cesser
#      pI2P        sEse
#      pi1S         sEs
#      pi2P        sEse
#      ppMS        sEse
# dtype: object
# 140  lexeme    changer
#      inf          SâZe
#      pI2S          SâZ
#      pi2P         SâZe
#      pi3S          SâZ
#      ppMS         SâZe
#      ps1S          SâZ
# dtype: object
# 141  lexeme    chanter
#      ii3P         SâtE
#      inf          Sâte
#      pI2S          Sât
#      pi3S          Sât
# dtype: object
# 143  lexeme    charger
#      pi1S         SarZ
#      ppMS        SarZe
#      ps1S         SarZ
#      ps3S         SarZ
# dtype: object
# 145  lexeme    chasser
#      ai3S         Sasa
#      pI2S          Sas
#      pi3S          Sas
# dtype: object
# 148  lexeme    chercher
#      ii1S         SErSE
#      inf          SErSe
#      pI2P         SErSe
#      pI2S          SErS
#      pc1P      SErS6rjô
#      pc1S       SErS6rE
#      pi1S          SErS
#      pi2P         SErSe
#      pi2S          SErS
#      ppFS         SErSe
#      ps1S          SErS
#      ps3S          SErS
# dtype: object
# 149  lexeme    chier
#      inf         Sje
#      pi1S         Si
# dtype: object
# 151  lexeme    choisir
#      inf        Swazir
#      pI2P      Swazise
#      pI2S        Swazi
#      pi2S        Swazi
#      ppMS        Swazi
# dtype: object
# 152  lexeme    chuchoter
#      ai3S         SySOta
#      pI2S          SySOt
#      pP           SySOtâ
#      pi3S          SySOt
# dtype: object
# 154  lexeme    claquer
#      ai3P       klakEr
#      pi1S         klak
#      pi3S         klak
# dtype: object
# 156  lexeme    cogner
#      inf         kOJe
#      pi3S         kOJ
# dtype: object
# 157  lexeme    coincer
#      pI2P        kwêse
#      ppFS        kwêse
# dtype: object
# 159  lexeme    coller
#      ii3S        kOlE
#      ppMS        kOle
# dtype: object
# 162  lexeme    commander
#      inf          kOmâde
#      pI2S          kOmâd
#      pi1S          kOmâd
#      pi3S          kOmâd
#      ps3S          kOmâd
# dtype: object
# 163  lexeme    commencer
#      ai3S         kOmâsa
#      ii3S         kOmâsE
#      inf          kOmâse
#      pI2S          kOmâs
#      pi1S          kOmâs
#      pi2P         kOmâse
#      pi2S          kOmâs
#      pi3P          kOmâs
#      pi3S          kOmâs
#      ppMS         kOmâse
#      ps2S          kOmâs
#      ps3S          kOmâs
# dtype: object
# 168  lexeme    comprendre
#      ai1S           kôpri
#      ai2S           kôpri
#      ai3S           kôpri
#      ii1S         kôpr6nE
#      ii2S         kôpr6nE
#      inf          kôprâdr
#      pI2P         kôpr6ne
#      pI2S           kôprâ
#      pi1S           kôprâ
#      pi2P         kôpr6ne
#      pi2S           kôprâ
#      pi3S           kôprâ
#      ppFP          kôpriz
# dtype: object
# 169  lexeme    compter
#      pI2P         kôte
#      pI2S          kôt
#      pi1S          kôt
#      pi2P         kôte
#      pi3P          kôt
#      pi3S          kôt
#      ps2S          kôt
# dtype: object
# 170  lexeme    concerner
#      ii3S        kôsErnE
#      pI2S         kôsErn
#      pi1S         kôsErn
#      pi3S         kôsErn
# dtype: object
# 172  lexeme    conclure
#      ai3S         kôkly
#      ppMP         kôkly
# dtype: object
# 173  lexeme    condamner
#      ai3S         kôdana
#      ii3S         kôdanE
#      ppFP         kôdane
# dtype: object
# 174  lexeme    conduire
#      ii3S       kôdHizE
#      pi1S         kôdHi
#      pi3P        kôdHiz
#      pi3S         kôdHi
#      ppMS         kôdHi
# dtype: object
# 176  lexeme    confirmer
#      inf         kôfirme
#      pI2S         kôfirm
#      pi3S         kôfirm
# dtype: object
# 177  lexeme    confondre
#      ii2S         kôfôdE
#      ii3P         kôfôdE
#      ii3S         kôfôdE
#      pc3S        kôfôdrE
#      ps1S          kôfôd
# dtype: object
# 179  lexeme    connaître
#      ii2P        kOnEsje
#      ii2S         kOnEsE
#      ii3S         kOnEsE
#      inf          kOnEtr
#      pI1P         kOnEsô
#      pI2P         kOnEse
#      pI2S           kOnE
#      pi1S           kOnE
#      pi2P         kOnEse
#      pi2S           kOnE
#      pi3P          kOnEs
#      pi3S           kOnE
#      ppMS           kOny
#      ps2P        kOnEsje
# dtype: object
# 182  lexeme    considérer
#      inf         kôsidEre
#      pI2P        kôsidEre
#      pI2S         kôsidEr
#      pi3S         kôsidEr
#      ppFP        kôsidEre
#      ppMS        kôsidEre
# dtype: object
# 184  lexeme    consoler
#      pI2S         kôsOl
#      pc3S      kôsOl6rE
# dtype: object
# 186  lexeme    constater
#      pI2S         kôstat
#      pP          kôstatâ
#      pi1S         kôstat
# dtype: object
# 188  lexeme    construire
#      inf         kôstrHir
#      pi3P        kôstrHiz
#      pi3S         kôstrHi
#      ppMS         kôstrHi
# dtype: object
# 189  lexeme    consulter
#      pI2P        kôsylte
#      ppMS        kôsylte
# dtype: object
# 194  lexeme    continuer
#      fi3S       kôtinyra
#      ii3S        kôtinyE
#      inf         kôtinye
#      pI2S         kôtiny
#      pi1P        kôtinyô
#      pi2P        kôtinye
#      ppMS        kôtinye
#      ps2S         kôtiny
#      ps3S         kôtiny
# dtype: object
# 197  lexeme    contrôler
#      ii3S        kôtrOlE
#      inf         kôtrOle
#      ppMP        kôtrOle
#      ps3S         kôtrol
# dtype: object
# 198  lexeme    convaincre
#      inf           kôvêkr
#      pi2S            kôvê
#      ppMS          kôvêky
# dtype: object
# 205  lexeme    coucher
#      ii1S         kuSE
#      ii2S         kuSE
#      ii3S         kuSE
#      inf          kuSe
#      pI2S          kuS
#      pi1S          kuS
#      pi3S          kuS
#      ps3S          kuS
# dtype: object
# 207  lexeme    couler
#      ii3S        kulE
#      pI2S         kul
#      pi1S         kul
#      ppMS        kule
#      ps3S         kul
# dtype: object
# 208  lexeme    couper
#      ii3S        kupE
#      ppMS        kupe
#      ps1S         kup
# dtype: object
# 209  lexeme    courir
#      pi2S         kur
#      pi3P         kur
# dtype: object
# 211  lexeme    couvrir
#      fi3S      kuvrira
#      ii3S        kuvrE
# dtype: object
# 213  lexeme    coûter
#      pI2S         kut
#      pi1S         kut
#      pi3P         kut
#      pi3S         kut
# dtype: object
# 215  lexeme    craindre
#      pI2S           krê
#      pc2P       krêdrie
#      pi1S           krê
#      pi2S           krê
#      pi3S           krê
#      ppMS           krê
# dtype: object
# 217  lexeme    craquer
#      pi1S         krak
#      ppMS        krake
# dtype: object
# 220  lexeme    crier
#      ai3S       krja
#      inf        krie
#      pI2S        kri
#      pP         kriâ
#      pi1S        kri
#      pi2S        kri
#      ps2S        kri
# dtype: object
# 221  lexeme    croire
#      ii1S      krwajE
#      ii2S      krwajE
#      ii3S      krwajE
#      inf        krwar
#      pI2P      krwaje
#      pI2S        krwa
#      pc3S      krwarE
#      pi1S        krwa
#      pi2P      krwaje
#      pi2S        krwa
#      pi3S        krwa
#      ppMS         kry
# dtype: object
# 223  lexeme    créer
#      pI2S        kre
#      ppFP       krEe
# dtype: object
# 224  lexeme    cueillir
#      inf          k6jir
#      pi3S           k9j
#      ppMS          k6ji
# dtype: object
# 225  lexeme    céder
#      inf        sEde
#      pi1S        sEd
#      ppMS       sEde
# dtype: object
# 226  lexeme    célébrer
#      pI1P       sElEbrô
#      pI2S        sElEbr
# dtype: object
# 228  lexeme    danser
#      ii2S        dâsE
#      inf         dâse
#      pI2S         dâs
#      pi1S         dâs
#      ppMS        dâse
#      ps2S         dâs
#      ps3S         dâs
# dtype: object
# 229  lexeme    dater
#      pi1S        dat
#      pi3P        dat
# dtype: object
# 230  lexeme    demander
#      ai1S        d6mâdE
#      ai3P       d6mâdEr
#      ii2S        d6mâdE
#      inf         d6mâde
#      pI2S         d6mâd
#      pi1S         d6mâd
#      pi2P        d6mâde
#      pi3S         d6mâd
#      ppMP        d6mâde
#      ppMS        d6mâde
#      ps1S         d6mâd
#      ps3S         d6mâd
# dtype: object
# 231  lexeme    demeurer
#      ii3S        d6m6rE
#      pI2S         d6m9r
# dtype: object
# 232  lexeme    descendre
#      ai3S         dEsâdi
#      inf          dEsâdr
#      pI1P         dEsâdô
#      pI2S           dEsâ
#      pi1S           dEsâ
#      pi2S           dEsâ
#      pi3P          dEsâd
#      pi3S           dEsâ
#      ppMP         dEsâdy
# dtype: object
# 233  lexeme     devenir
#      ai3S          d6vê
#      fi2S      d6vjêdra
#      fi3S      d6vjêdra
#      ii1S        d6v6nE
#      ii3S        d6v6nE
#      inf        d6v6nir
#      pi2S         d6vjê
#      pi3S         d6vjê
#      ppFP        d6v6ny
#      ppFS        d6v6ny
#      ppMS        d6v6ny
#      ps1S        d6vjEn
# dtype: object
# 234  lexeme    deviner
#      ii3S       d6vinE
#      pI2S        d6vin
# dtype: object
# 235  lexeme    devoir
#      ai3S          dy
#      fi2P       d6vre
#      fi3P       d6vrô
#      fi3S       d6vra
#      ii1S        d6vE
#      ii3S        d6vE
#      pI1P        d6vô
#      pI2P        d6ve
#      pI2S         dwa
#      pP          d6vâ
#      pc1S       d6vrE
#      pc2P      d6vrie
#      pc2S       d6vrE
#      pc3S       d6vrE
#      pi1P        d6vô
#      pi1S         dwa
#      pi2P        d6ve
#      pi2S         dwa
#      pi3P        dwav
#      pi3S         dwa
#      ppMS          dy
#      ps3P        dwav
#      ps3S        dwav
# dtype: object
# 236  lexeme    dicter
#      pI2S        dikt
#      pi1S        dikt
# dtype: object
# 238  lexeme    dire
#      ai1S        di
#      ai3S        di
#      fi1S      dirE
#      fi3S      dira
#      ii1S      dizE
#      ii2S      dizE
#      ii3S      dizE
#      inf        dir
#      pI1P      dizô
#      pI2P       dit
#      pI2S        di
#      pc2S      dirE
#      pc3S      dirE
#      pi1P      dizô
#      pi1S        di
#      pi2P       dit
#      pi2S        di
#      pi3P       diz
#      pi3S        di
#      ppFP       dit
#      ppMS        di
#      ps1S       diz
#      ps3P       diz
#      ps3S       diz
# dtype: object
# 239  lexeme    diriger
#      ii1S       diriZE
#      pi1S        diriZ
#      pi3S        diriZ
# dtype: object
# 243  lexeme    disparaître
#      ai3S          dispary
#      inf         disparEtr
#      pi3P         disparEs
#      ppFS          dispary
#      ppMS          dispary
#      ps1S         disparEs
# dtype: object
# 244  lexeme    disposer
#      ii3S       dispOzE
#      pi3S        dispoz
# dtype: object
# 246  lexeme    dissimuler
#      ii2S        disimylE
#      pi1S         disimyl
# dtype: object
# 249  lexeme    distinguer
#      inf          distêge
#      ppMS         distêge
# dtype: object
# 253  lexeme    donner
#      ai3S        dOna
#      fi3P      dOn6rô
#      ii3P        dOnE
#      ii3S        dOnE
#      inf         dOne
#      pI2P        dOne
#      pI2S         dOn
#      pi1S         dOn
#      pi2S         dOn
#      pi3S         dOn
#      ppFP        dOne
#      ppFS        dOne
#      ppMS        dOne
#      ps1S         dOn
#      ps3P         dOn
#      ps3S         dOn
# dtype: object
# 254  lexeme    dormir
#      ai3S       dOrmi
#      ii3P       dOrmE
#      inf       dOrmir
#      pI2P       dOrme
#      pi1S         dOr
#      pi2S         dOr
#      pi3S         dOr
#      ps3P        dOrm
# dtype: object
# 257  lexeme    douter
#      pI2P        dute
#      pI2S         dut
#      pi1S         dut
#      pi3S         dut
# dtype: object
# 260  lexeme    durer
#      ii3S       dyrE
#      pi1S        dyr
#      pi3S        dyr
# dtype: object
# 263  lexeme    débarrasser
#      inf          dEbarase
#      pI2S          dEbaras
# dtype: object
# 264  lexeme    déborder
#      pP         dEbOrdâ
#      ppMS       dEbOrde
# dtype: object
# 270  lexeme    décider
#      inf        dEside
#      pi1S        dEsid
#      pi2S        dEsid
#      ppMS       dEside
#      ps3S        dEsid
# dtype: object
# 283  lexeme    découvrir
#      ii3S        dEkuvrE
#      inf        dEkuvrir
#      pI2S         dEkuvr
#      pP          dEkuvrâ
# dtype: object
# 289  lexeme    défiler
#      ii3S       dEfilE
#      inf        dEfile
#      pi1S        dEfil
# dtype: object
# 291  lexeme    dégager
#      pI2P       dEgaZe
#      pI2S        dEgaZ
#      pi1S        dEgaZ
#      pi2P       dEgaZe
#      pi3S        dEgaZ
#      ps3S        dEgaZ
# dtype: object
# 297  lexeme    déjeuner
#      inf         dEZ6ne
#      pi1S         dEZ9n
# dtype: object
# 299  lexeme    démarrer
#      inf         dEmare
#      pi2P        dEmare
# dtype: object
# 301  lexeme    dénoncer
#      inf         dEnôse
#      pi3P         dEnôs
#      pi3S         dEnôs
# dtype: object
# 304  lexeme    dépendre
#      ii3S        dEpâdE
#      pi2S          dEpâ
# dtype: object
# 305  lexeme    dépenser
#      inf         dEpâse
#      ppMS        dEpâse
# dtype: object
# 306  lexeme    déplacer
#      ii3S       dEplasE
#      pI2S        dEplas
#      ppFS       dEplase
#      ps3S        dEplas
# dtype: object
# 309  lexeme    déposer
#      ai3S       dEpOza
#      pI2S        dEpoz
# dtype: object
# 310  lexeme    dépêcher
#      pI2S         dEpES
#      pi1S         dEpES
# dtype: object
# 312  lexeme    déranger
#      inf         dErâZe
#      pI2S         dErâZ
#      pi3S         dErâZ
# dtype: object
# 317  lexeme    désigner
#      pP          dEziJâ
#      pi1S         dEziJ
#      ppMS        dEziJe
# dtype: object
# 318  lexeme     désirer
#      ii3S        dEzirE
#      pc3S      dEzir6rE
#      pi1S         dEzir
#      pi2S         dEzir
#      pi3P         dEzir
# dtype: object
# 319  lexeme    désoler
#      ppFS       dEzOle
#      ppMS       dEzOle
# dtype: object
# 320  lexeme    détacher
#      ii3S        dEtaSE
#      pi1S         dEtaS
# dtype: object
# 321  lexeme    détendre
#      pI2P        dEtâde
#      ppMS        dEtâdy
# dtype: object
# 322  lexeme    détester
#      pI2S        dEtEst
#      pi1S        dEtEst
#      ps1S        dEtEst
#      ps2S        dEtEst
#      ps3S        dEtEst
# dtype: object
# 324  lexeme    détruire
#      inf        dEtrHir
#      ppFS       dEtrHit
# dtype: object
# 330  lexeme    dîner
#      ai3S       dina
#      inf        dine
#      pi1S        din
# dtype: object
# 332  lexeme    emballer
#      inf          âbale
#      pi2S          âbal
#      pi3S          âbal
# dtype: object
# 334  lexeme    embaucher
#      ppFS          âbOSe
#      ppMS          âbOSe
# dtype: object
# 335  lexeme    embrasser
#      ai3S         âbrasa
#      ii1S         âbrasE
#      inf          âbrase
#      pi1S          âbras
#      ps1S          âbras
#      ps3S          âbras
# dtype: object
# 336  lexeme    embêter
#      inf         âbEte
#      pI2S         âbEt
#      pi3S         âbEt
# dtype: object
# 337  lexeme    emmener
#      inf         âm6ne
#      pI2P        âm6ne
#      pi1S         âmEn
#      ppFS        âm6ne
#      ppMS        âm6ne
#      ps3S         âmEn
# dtype: object
# 338  lexeme    emmerder
#      pi1S         âmErd
#      pi3S         âmErd
# dtype: object
# 340  lexeme    employer
#      pP         âplwajâ
#      pi1S         âplwa
# dtype: object
# 341  lexeme    emporter
#      pP          âpOrtâ
#      pi1S         âpOrt
#      pi3P         âpOrt
#      ppFS        âpOrte
#      ps3S         âpOrt
# dtype: object
# 344  lexeme    empêcher
#      pI2S          âpES
#      pP           âpESâ
#      pi3S          âpES
#      ppMS         âpESe
# dtype: object
# 348  lexeme    endormir
#      inf        âdOrmir
#      ppMP        âdOrmi
# dtype: object
# 350  lexeme    enfermer
#      ii3S        âfErmE
#      pi3P         âfErm
#      pi3S         âfErm
#      ppMS        âfErme
# dtype: object
# 352  lexeme    enfoncer
#      ii1S         âfôsE
#      inf          âfôse
#      pI2S          âfôs
#      ppMS         âfôse
# dtype: object
# 356  lexeme    engager
#      pI1P        âgaZô
#      ppMS        âgaZe
# dtype: object
# 359  lexeme    enlever
#      inf         âl6ve
#      pi1S         âlEv
#      ps3S         âlEv
# dtype: object
# 360  lexeme    ennuyer
#      ii3P        ânHiE
#      pI2S         ânHi
#      pP          ânHiâ
#      pi1S         ânHi
#      ppMS        ânHie
#      ps1S         ânHi
# dtype: object
# 366  lexeme    entendre
#      inf          âtâdr
#      pI2P         âtâde
#      pI2S           âtâ
#      pi1S           âtâ
#      pi2P         âtâde
#      pi2S           âtâ
#      pi3S           âtâ
#      ppMP         âtâdy
#      ppMS         âtâdy
# dtype: object
# 367  lexeme    enterrer
#      pI2S          âtEr
#      pi3P          âtEr
#      ps3S          âtEr
# dtype: object
# 370  lexeme    entraîner
#      inf          âtrEne
#      ppMS         âtrEne
#      ps3S          âtrEn
# dtype: object
# 372  lexeme    entrer
#      inf         âtre
#      pI2S         âtr
#      pi1P        âtrô
#      pi1S         âtr
#      pi2P        âtre
#      pi3S         âtr
#      ppMP        âtre
#      ps3S         âtr
# dtype: object
# 375  lexeme    envahir
#      ii3S       âvaisE
#      ppFS         âvai
#      ppMS         âvai
# dtype: object
# 380  lexeme    envoyer
#      inf        âvwaje
#      pI1P       âvwajô
#      pI2P       âvwaje
#      pI2S         âvwa
#      pi1S         âvwa
#      pi3S         âvwa
#      ppMP       âvwaje
#      ppMS       âvwaje
#      ps1S         âvwa
#      ps3S         âvwa
# dtype: object
# 381  lexeme    espérer
#      ii2S       EspErE
#      pI2S        EspEr
#      pP         EspErâ
#      pi1S        EspEr
#      pi3S        EspEr
#      ps1S        EspEr
# dtype: object
# 383  lexeme     essayer
#      fi1S         EsErE
#      ii2P         EsEje
#      inf          EsEje
#      pI2S      EsE,EsEj
#      pP           EsEjâ
#      pc2S       EsEj6rE
#      pi1S      EsE,EsEj
#      pi2P         EsEje
#      pi3S           EsE
#      ppMS         EsEje
#      ps3S           EsE
# dtype: object
# 384  lexeme    estimer
#      pI2S        Estim
#      pi1S        Estim
# dtype: object
# 386  lexeme    exalter
#      ai3S      Egzalta
#      pi1S       Egzalt
# dtype: object
# 387  lexeme    examiner
#      ai3S      Egzamina
#      pP        Egzaminâ
#      pi1P      Egzaminô
# dtype: object
# 390  lexeme    excuser
#      pI2P      Ekskyze
#      pI2S       Ekskyz
#      pi1S       Ekskyz
#      pi2P      Ekskyze
#      pi3S       Ekskyz
#      ppMS      Ekskyze
#      ps3S       Ekskyz
# dtype: object
# 391  lexeme    exercer
#      ii3S      EgzErsE
#      pI2P      EgzErse
#      ppMS      EgzErse
# dtype: object
# 393  lexeme    exister
#      ii3S      EgzistE
#      pI2S       Egzist
#      pi3S       Egzist
#      ps3S       Egzist
# dtype: object
# 395  lexeme    expliquer
#      fi3S      Esplik6ra
#      inf         Esplike
#      pI2S         Esplik
#      pi1S         Esplik
#      pi3S         Esplik
#      ps1S         Esplik
#      ps3S         Esplik
# dtype: object
# 397  lexeme    exposer
#      inf       EkspOze
#      pi2P      EkspOze
#      pi3S       Ekspoz
# dtype: object
# 401  lexeme    faillir
#      ai3S         faji
#      fi1S       fajirE
# dtype: object
# 402  lexeme    faire
#      ai2S         fi
#      ai3S         fi
#      fi1S       f6rE
#      fi3P       f6rô
#      fi3S       f6ra
#      ii1S       f6zE
#      ii2S       f6zE
#      ii3P       f6zE
#      ii3S       f6zE
#      inf         fEr
#      pI2P        fEt
#      pI2S         fE
#      pc1S       f6rE
#      pc2S       f6rE
#      pc3S       f6rE
#      pi1S         fE
#      pi2P        fEt
#      pi2S         fE
#      pi3P         fô
#      pi3S         fE
#      ppFP        fEt
#      ppFS        fEt
#      ppMS         fE
#      ps1S        fas
#      ps3S        fas
# dtype: object
# 403  lexeme    falloir
#      fi3S        fOdra
#      ii3S         falE
#      inf        falwar
#      pc3S        fOdrE
#      pi3S           fo
# dtype: object
# 406  lexeme    fatiguer
#      pI2S         fatig
#      ppFP        fatige
#      ppMS        fatige
# dtype: object
# 410  lexeme    fermer
#      inf        fErme
#      pP         fErmâ
#      pi1S        fErm
#      pi2P       fErme
#      pi3S        fErm
#      ppFS       fErme
#      ps3S        fErm
# dtype: object
# 413  lexeme    ficher
#      ii2S        fiSE
#      pi1S         fiS
#      pi3S         fiS
#      ps1S         fiS
#      ps3S         fiS
# dtype: object
# 415  lexeme    figurer
#      pI2S        figyr
#      ppMP       figyre
# dtype: object
# 416  lexeme    filer
#      inf        file
#      pI1P       filô
# dtype: object
# 417  lexeme     finir
#      ai3S        fini
#      fi1S      finirE
#      fi3S      finira
#      inf        finir
#      pc3S      finirE
#      pi1S        fini
#      pi3S        fini
#      ppFS        fini
#      ppMP        fini
#      ppMS        fini
#      ps1S       finis
#      ps3S       finis
# dtype: object
# 418  lexeme    fixer
#      ai3S      fiksa
#      ps1S       fiks
# dtype: object
# 419  lexeme    flairer
#      pi1S         flEr
#      ppMS        flEre
# dtype: object
# 426  lexeme    forcer
#      pi1S        fOrs
#      pi3S        fOrs
# dtype: object
# 427  lexeme    former
#      pi3P        fOrm
#      ppMS       fOrme
# dtype: object
# 433  lexeme    fourrer
#      pP           furâ
#      pi1S          fur
# dtype: object
# 434  lexeme    foutre
#      inf         futr
#      pI2P        fute
#      pi1S          fu
#      pi2S          fu
#      pi3P         fut
#      ppMS        futy
# dtype: object
# 435  lexeme    franchir
#      ai3S         frâSi
#      inf         frâSir
#      pi3S         frâSi
# dtype: object
# 436  lexeme    frapper
#      fi3S      frap6ra
#      pI1P        frapô
#      pI2S         frap
#      pP          frapâ
#      pi1S         frap
#      ppMS        frape
#      ps1S         frap
# dtype: object
# 438  lexeme    froisser
#      pi2S         frwas
#      ppFP        frwase
# dtype: object
# 439  lexeme    frotter
#      pi1S         frOt
#      pi3S         frOt
#      ps1S         frOt
# dtype: object
# 440  lexeme    frémir
#      ai3P      frEmir
#      inf       frEmir
# dtype: object
# 442  lexeme     fuir
#      ai3S        fHi
#      inf        fHir
#      is1S       fHis
#      pP        fHijâ
#      ppMP        fHi
#      ppMS        fHi
# dtype: object
# 443  lexeme    fumer
#      inf        fyme
#      pI2S        fym
# dtype: object
# 445  lexeme    féliciter
#      ai3S       fElisita
#      inf        fElisite
#      pI2S        fElisit
# dtype: object
# 446  lexeme    gagner
#      inf         gaJe
#      pI2S         gaJ
#      pi1S         gaJ
#      pi2S         gaJ
# dtype: object
# 448  lexeme    garder
#      inf        garde
#      pI2P       garde
#      pI2S        gard
#      pP         gardâ
#      pi1S        gard
#      pi2P       garde
#      ppMS       garde
#      ps1S        gard
#      ps2S        gard
#      ps3S        gard
# dtype: object
# 453  lexeme    glisser
#      ii3S        glisE
#      pI2S         glis
#      pi3S         glis
# dtype: object
# 455  lexeme    gonfler
#      pI2S         gôfl
#      ppFP        gôfle
# dtype: object
# 457  lexeme    grandir
#      pi2S        grâdi
#      pi3S        grâdi
#      ppMS        grâdi
# dtype: object
# 462  lexeme    guetter
#      pI2S          gEt
#      pi1S          gEt
#      pi3S          gEt
# dtype: object
# 463  lexeme    gueuler
#      ii3S         g6lE
#      pi1S          g9l
# dtype: object
# 464  lexeme    guider
#      pI2S         gid
#      ppMS        gide
# dtype: object
# 465  lexeme    guérir
#      fi3S      gErira
#      inf        gErir
#      ppMS        gEri
# dtype: object
# 466  lexeme    gâcher
#      inf         gaSe
#      ppMS        gaSe
# dtype: object
# 469  lexeme    gêner
#      pI2S        ZEn
#      pi1S        ZEn
#      ppMS       ZEne
# dtype: object
# 470  lexeme    habiller
#      ii1S         abijE
#      pI2P         abije
#      pi3S          abij
# dtype: object
# 471  lexeme    habiter
#      ii3P        abitE
#      pI2P        abite
#      pI2S         abit
#      pi1S         abit
#      ps3S         abit
# dtype: object
# 476  lexeme    haïr
#      pI2S         E
#      pi2S         E
# dtype: object
# 483  lexeme    hésiter
#      inf         Ezite
#      pi1S         Ezit
#      pi2P        Ezite
#      pi3S         Ezit
# dtype: object
# 485  lexeme    ignorer
#      ii2S        iJOrE
#      ii3P        iJOrE
#      inf         iJOre
#      pI2S         iJOr
#      pi1S         iJOr
#      pi3S         iJOr
# dtype: object
# 488  lexeme    imaginer
#      ii1S       imaZinE
#      inf        imaZine
#      pI2S        imaZin
#      pi1S        imaZin
#      pi3S        imaZin
#      ps1S        imaZin
#      ps2S        imaZin
#      ps3S        imaZin
# dtype: object
# 492  lexeme    importer
#      pI2S         êpOrt
#      pi1S         êpOrt
#      pi3S         êpOrt
# dtype: object
# 493  lexeme    imposer
#      ai3S        êpOza
#      pI2S         êpoz
# dtype: object
# 494  lexeme    impressionner
#      inf           êprEsjOne
#      pi1S           êprEsjOn
# dtype: object
# 500  lexeme    inonder
#      ii3S        inôdE
#      pi1S         inôd
# dtype: object
# 501  lexeme    inquiéter
#      pI2P         êkjEte
#      pI2S          êkjEt
#      pi1S          êkjEt
#      pi3S          êkjEt
#      ps1S          êkjEt
#      ps3S          êkjEt
# dtype: object
# 503  lexeme    insister
#      inf         êsiste
#      pi1S         êsist
#      pi3S         êsist
# dtype: object
# 505  lexeme    inspirer
#      pi1S         êspir
#      ppMS        êspire
# dtype: object
# 506  lexeme    installer
#      ii3S         êstalE
#      pi3S          êstal
#      ppFS         êstale
#      ppMP         êstale
#      ppMS         êstale
# dtype: object
# 508  lexeme    interdire
#      pP         êtErdizâ
#      ppFS        êtErdit
#      ppMS         êtErdi
# dtype: object
# 510  lexeme    interroger
#      inf          êtErOZe
#      pI2S          êtErOZ
#      pi3S          êtErOZ
#      ps3S          êtErOZ
# dtype: object
# 512  lexeme    intriguer
#      inf          êtrige
#      pI2S          êtrig
# dtype: object
# 514  lexeme    intéresser
#      ai3P        êtErEsEr
#      ii3S         êtErEsE
#      pI2S          êtErEs
#      pi1S          êtErEs
#      pi3S          êtErEs
#      ps1S          êtErEs
#      ps3S          êtErEs
# dtype: object
# 515  lexeme    inventer
#      pI2S          êvât
#      pi1S          êvât
#      ppMS         êvâte
# dtype: object
# 517  lexeme    inviter
#      ai3S        êvita
#      pI2S         êvit
#      pi1S         êvit
#      ps1S         êvit
# dtype: object
# 521  lexeme    jeter
#      ai3S       Z6ta
#      inf        Z6te
#      pI2S        ZEt
#      pP         Z6tâ
#      pi3S        ZEt
#      ppFS       Z6te
#      ps1S        ZEt
#      ps3P        ZEt
#      ps3S        ZEt
# dtype: object
# 523  lexeme    jouer
#      ii1S        ZuE
#      ii3S        ZuE
#      inf         Zue
#      pI2S         Zu
#      pi1P        Zuô
#      pi1S         Zu
#      pi2S         Zu
#      pi3S         Zu
#      ppMS        Zue
#      ps2S         Zu
#      ps3S         Zu
# dtype: object
# 526  lexeme     jurer
#      pc2S      Zyr6rE
#      pi1S         Zyr
#      pi3S         Zyr
#      ps1S         Zyr
# dtype: object
# 527  lexeme    laisser
#      ai3S         lEsa
#      fi1S       lEs6rE
#      fi3S       lEs6ra
#      inf          lEse
#      pI1P         lEsô
#      pI2P         lEse
#      pI2S          lEs
#      pi1S          lEs
#      pi2P         lEse
#      pi2S          lEs
#      pi3P          lEs
#      pi3S          lEs
#      ppMS         lEse
#      ps1S          lEs
#      ps2S          lEs
#      ps3S          lEs
# dtype: object
# 528  lexeme    lancer
#      ii3S        lâsE
#      inf         lâse
#      pI1P        lâsô
#      pi1S         lâs
#      pi3S         lâs
# dtype: object
# 529  lexeme    languir
#      ii2S       lâgisE
#      pi2S         lâgi
# dtype: object
# 531  lexeme    laver
#      pI2S        lav
#      pi2P       lave
#      pi2S        lav
#      ps3S        lav
# dtype: object
# 532  lexeme    lever
#      ai3P      l6vEr
#      ii3P       l6vE
#      ii3S       l6vE
#      inf        l6ve
#      pI2S        lEv
#      pP         l6vâ
#      pi1S        lEv
#      pi3S        lEv
#      ppFS       l6ve
#      ps1S        lEv
# dtype: object
# 533  lexeme    libérer
#      pI1P       libErô
#      ppFS       libEre
#      ppMS       libEre
# dtype: object
# 536  lexeme    ligoter
#      pi1S        ligOt
#      pi3S        ligOt
# dtype: object
# 537  lexeme    lire
#      inf        lir
#      pI2S        li
#      pi1S        li
#      pi3S        li
#      ppMS        ly
# dtype: object
# 538  lexeme    livrer
#      inf        livre
#      pI2S        livr
#      pi1S        livr
#      ppMP       livre
#      ps3S        livr
# dtype: object
# 545  lexeme    lâcher
#      ii3P        laSE
#      inf         laSe
#      pI2P        laSe
#      pI2S         laS
#      pi1S         laS
#      pi2P        laSe
#      pi3S         laS
#      ps3S         laS
# dtype: object
# 546  lexeme    maintenir
#      pP           mêt6nâ
#      pi3S          mêtjê
# dtype: object
# 547  lexeme    malaxer
#      pi1S       malaks
#      pi3S       malaks
# dtype: object
# 549  lexeme    manger
#      fi1S      mâZ6rE
#      inf         mâZe
#      pI2P        mâZe
#      pI2S         mâZ
#      pi3P         mâZ
#      ppMS        mâZe
# dtype: object
# 550  lexeme    manquer
#      ii3P         mâkE
#      inf          mâke
#      pi1S          mâk
#      pi3P          mâk
#      pi3S          mâk
# dtype: object
# 551  lexeme    marcher
#      ii1S        marSE
#      ii3S        marSE
#      inf         marSe
#      pI2P        marSe
#      pI2S         marS
#      pc3S      marS6rE
#      pi3P         marS
#      pi3S         marS
#      ps3S         marS
# dtype: object
# 552  lexeme    marier
#      inf        marje
#      ppFS       marje
#      ppMP       marje
#      ppMS       marje
#      ps3S        mari
# dtype: object
# 553  lexeme    marquer
#      inf         marke
#      ppMS        marke
# dtype: object
# 558  lexeme    menacer
#      pI2S        m6nas
#      pi1S        m6nas
#      ppFP       m6nase
# dtype: object
# 559  lexeme    mener
#      pi3S        mEn
#      ppMS       m6ne
# dtype: object
# 562  lexeme    mettre
#      ai1S          mi
#      ai2S          mi
#      ai3S          mi
#      ii3P        mEtE
#      inf         mEtr
#      pI2P        mEte
#      pI2S          mE
#      pc3S       mEtrE
#      pi1S          mE
#      pi2P        mEte
#      pi2S          mE
#      pi3S          mE
#      ps1S         mEt
#      ps3P         mEt
#      ps3S         mEt
# dtype: object
# 565  lexeme    monter
#      ii3S        môtE
#      inf         môte
#      pI2S         môt
#      pi1S         môt
#      pi3S         môt
#      ppFP        môte
#      ps3S         môt
# dtype: object
# 566  lexeme    montrer
#      ai3S        môtra
#      inf         môtre
#      pI1P        môtrô
#      pI2S         môtr
#      pi1S         môtr
#      pi2P        môtre
#      pi3P         môtr
#      pi3S         môtr
#      ppMS        môtre
#      ps3S         môtr
# dtype: object
# 567  lexeme    moquer
#      pI2S         mOk
#      pi2S         mOk
# dtype: object
# 571  lexeme    mourir
#      inf        murir
#      pi1S         m9r
#      ppFS        mOrt
#      ppMS         mOr
#      ps1S         m9r
# dtype: object
# 574  lexeme    mélanger
#      inf         mElâZe
#      pI2S         mElâZ
# dtype: object
# 577  lexeme    mériter
#      ii3S       mEritE
#      pI2S        mErit
#      pi1S        mErit
#      pi3P        mErit
#      ps1S        mErit
# dtype: object
# 578  lexeme    mêler
#      pi3S        mEl
#      ps1S        mEl
# dtype: object
# 581  lexeme    nettoyer
#      inf        nEtwaje
#      pi3S         nEtwa
#      ps3S         nEtwa
# dtype: object
# 584  lexeme     noter
#      fi3S      nOt6ra
#      pi3S         nOt
# dtype: object
# 587  lexeme    obliger
#      pI2S        ObliZ
#      pi1S        ObliZ
#      ppMP       ObliZe
# dtype: object
# 589  lexeme    observer
#      ai3S       ObsErva
#      ii1S       ObsErvE
#      pI2S        ObsErv
#      pi1S        ObsErv
#      ppMP       ObsErve
#      ps3S        ObsErv
# dtype: object
# 591  lexeme    occuper
#      ai3S        Okypa
#      fi1S      Okyp6rE
#      fi3P      Okyp6rô
#      inf         Okype
#      pI2S         Okyp
#      pi1S         Okyp
#      pi3S         Okyp
#      ppMP        Okype
#      ps1S         Okyp
#      ps3S         Okyp
# dtype: object
# 593  lexeme    offrir
#      inf        Ofrir
#      pI2S         Ofr
#      pi1S         Ofr
#      ppMS        OfEr
#      ps1S         Ofr
#      ps3S         Ofr
# dtype: object
# 596  lexeme    organiser
#      inf        Organize
#      ppMS       Organize
# dtype: object
# 597  lexeme     oser
#      ai3S        Oza
#      fi2P      Oz6re
#      inf         Oze
#      pi2S         oz
#      pi3S         oz
#      ppMS        Oze
# dtype: object
# 598  lexeme    oublier
#      fi2P       ublire
#      ii3S        ubliE
#      inf         ublie
#      pI2P        ublie
#      pI2S         ubli
#      pc2S       ublirE
#      pi1S         ubli
#      pi3S         ubli
#      ppFP        ublie
#      ppMS        ublie
#      ps1S         ubli
#      ps2S         ubli
#      ps3S         ubli
# dtype: object
# 599  lexeme    ouvrir
#      ai3S        uvri
#      inf        uvrir
#      pI2S         uvr
#      pi1S         uvr
#      pi3S         uvr
#      ppFS       uvErt
#      ps3S         uvr
# dtype: object
# 601  lexeme    paraître
#      fi3S       parEtra
#      ii3P        parEsE
#      pi3S          parE
# dtype: object
# 602  lexeme    pardonner
#      fi1S      pardOn6rE
#      inf         pardOne
#      pi1S         pardOn
#      pi3S         pardOn
# dtype: object
# 603  lexeme    parfaire
#      pi3S         parfE
#      ppFS        parfEt
#      ppMS         parfE
# dtype: object
# 605  lexeme     parler
#      ai3S        parla
#      fi2P      parl6re
#      ii3P        parlE
#      ii3S        parlE
#      inf         parle
#      pI1P        parlô
#      pI2P        parle
#      pI2S         parl
#      pc3S      parl6rE
#      pi1S         parl
#      pi2P        parle
#      pi2S         parl
#      pi3S         parl
#      ppMS        parle
#      ps1S         parl
#      ps3S         parl
# dtype: object
# 606  lexeme     partager
#      fi1S      partaZ6rE
#      inf         partaZe
# dtype: object
# 607  lexeme     partir
#      ai1S        parti
# ...
#      ppMS        rEysi
# dtype: object
# 819  lexeme    réveiller
#      ai3P        rEvEjEr
#      fi3S       rEvEj6ra
#      ii3P         rEvEjE
#      inf          rEvEje
#      pI2S          rEvEj
#      pi1P         rEvEjô
#      pi1S          rEvEj
#      pi2S          rEvEj
#      pi3S          rEvEj
#      ppMS         rEvEje
#      ps1S          rEvEj
# dtype: object
# 820  lexeme    révolter
#      inf        rEvOlte
#      ppMP       rEvOlte
# dtype: object
# 822  lexeme    rêver
#      pP         rEvâ
#      ppMS       rEve
# dtype: object
# 826  lexeme    saigner
#      pI2P         sEJe
#      pI2S          sEJ
# dtype: object
# 827  lexeme    saisir
#      ii3S      sEzisE
#      inf        sEzir
# dtype: object
# 829  lexeme    salir
#      inf       salir
#      pi3S       sali
# dtype: object
# 831  lexeme    saurer
#      ii2P       sOrje
#      ii2S        sOrE
# dtype: object
# 832  lexeme    sauter
#      ii3P        sOtE
#      inf         sOte
#      pI2S         sot
#      pP          sOtâ
#      pi1S         sot
#      pi2P        sOte
#      ppMS        sOte
# dtype: object
# 833  lexeme    sauver
#      fi1S      sOv6rE
#      inf         sOve
#      pc2S      sOv6rE
#      pi1S         sov
#      pi3S         sov
#      ppMS        sOve
# dtype: object
# 834  lexeme    savoir
#      ai3S          sy
#      fi2S        sOra
#      fi3S        sOra
#      ii1P       savjô
#      ii1S        savE
#      ii2P       savje
#      ii2S        savE
#      ii3S        savE
#      inf       savwar
#      pI2S         saS
#      pi1S          sE
#      pi2P        save
#      pi2S          sE
#      pi3P         sav
#      pi3S          sE
#      ppMS          sy
#      ps1S         saS
#      ps3S         saS
# dtype: object
# 837  lexeme    secouer
#      ai3S        s6kua
#      pI2S         s6ku
#      ppFS        s6kue
# dtype: object
# 838  lexeme    sembler
#      ii3P        sâblE
#      ii3S        sâblE
#      pI2S         sâbl
#      pP          sâblâ
#      pc3S      sâbl6rE
#      pi1S         sâbl
#      pi2P        sâble
#      pi3P         sâbl
#      pi3S         sâbl
#      ps3S         sâbl
# dtype: object
# 839  lexeme    sentir
#      ai1S        sâti
#      ai3S        sâti
#      ii1S        sâtE
#      ii2S        sâtE
#      ii3P        sâtE
#      ii3S        sâtE
#      inf        sâtir
#      pI2S          sâ
#      pi1S          sâ
#      pi2P        sâte
#      pi2S          sâ
#      pi3S          sâ
#      ppFS        sâti
#      ppMP        sâti
#      ppMS        sâti
# dtype: object
# 840  lexeme    serrer
#      ii3S        sErE
#      pi1S         sEr
#      pi3P         sEr
#      ppFS        sEre
#      ppMP        sEre
# dtype: object
# 841  lexeme    servir
#      inf       sErvir
#      pI2P       sErve
#      pI2S         sEr
#      pi1S         sEr
#      pi2P       sErve
#      ppMS       sErvi
# dtype: object
# 842  lexeme    siffler
#      inf         sifle
#      pi1S         sifl
# dtype: object
# 844  lexeme    signer
#      fi1S      siJ6rE
#      pi3S         siJ
#      ppFS        siJe
#      ppMS        siJe
# dtype: object
# 845  lexeme    signifier
#      ii3P        siJifjE
#      ii3S        siJifjE
#      pi1S         siJifi
# dtype: object
# 849  lexeme    songer
#      pP          sôZâ
#      pi1S         sôZ
#      ps3S         sôZ
# dtype: object
# 850  lexeme    sonner
#      inf         sOne
#      pi3S         sOn
#      ppMS        sOne
# dtype: object
# 851  lexeme     sortir
#      ai1S        sOrti
#      ai3S        sOrti
#      fi1S      sOrtirE
#      ii2S        sOrtE
#      ii3S        sOrtE
#      inf        sOrtir
#      pI2S          sOr
#      pi1S          sOr
#      pi2S          sOr
#      pi3P         sOrt
#      ppFS        sOrti
#      ppMP        sOrti
#      ps1S         sOrt
# dtype: object
# 853  lexeme    souffler
#      ai3S         sufla
#      ii1S         suflE
# dtype: object
# 854  lexeme    souffrir
#      ii3S         sufrE
#      inf         sufrir
#      pc2S       sufrirE
# dtype: object
# 855  lexeme    souhaiter
#      pP            suEtâ
#      pi3S           suEt
#      ps1S           suEt
# dtype: object
# 856  lexeme    soulever
#      inf         sul6ve
#      pI1P        sul6vô
#      pi1S         sulEv
#      pi3S         sulEv
#      ppMS        sul6ve
# dtype: object
# 858  lexeme    soupirer
#      ai3S        supira
#      pi1S         supir
# dtype: object
# 859  lexeme    sourire
#      ai3S         suri
#      ii3S        surjE
#      pI2S         suri
#      pi1S         suri
#      pi3S         suri
#      ps3S         suri
# dtype: object
# 860  lexeme    souvenir
#      pI2P        suv6ne
#      pI2S         suvjê
#      pP          suv6nâ
#      pi1S         suvjê
#      pi2P        suv6ne
#      pi2S         suvjê
#      ps2S        suvjEn
# dtype: object
# 862  lexeme    sucer
#      inf        syse
#      pi3S        sys
#      ps2S        sys
# dtype: object
# 863  lexeme    suffire
#      ai3S         syfi
#      fi3S       syfira
#      pi3S         syfi
# dtype: object
# 865  lexeme    suivre
#      ai3S       sHivi
#      inf        sHivr
#      pI2P       sHive
#      pI2S         sHi
#      pi1S         sHi
#      pi3S         sHi
# dtype: object
# 867  lexeme    supporter
#      fi3S      sypOrt6ra
#      inf         sypOrte
#      pi1S         sypOrt
# dtype: object
# 868  lexeme    supposer
#      pI2S         sypoz
#      pP          sypOzâ
#      pi1S         sypoz
#      pi3S         sypoz
# dtype: object
# 869  lexeme     surgir
#      ai3S        syrZi
#      inf        syrZir
#      pP        syrZisâ
#      ppMS        syrZi
# dtype: object
# 872  lexeme    surprendre
#      ai1S          syrpri
#      pc3S       syrprâdrE
#      ppFS         syrpriz
# dtype: object
# 874  lexeme    surveiller
#      inf          syrvEje
#      pI2S          syrvEj
#      pi3S          syrvEj
#      ps3S          syrvEj
# dtype: object
# 879  lexeme    sécher
#      pI2S         sES
#      pi1S         sES
#      ppFP        sESe
#      ps3S         sES
# dtype: object
# 881  lexeme    séparer
#      inf        sEpare
#      ppFS       sEpare
# dtype: object
# 883  lexeme    taire
#      ai3P        tyr
#      ii3S       tEzE
#      pI2S         tE
#      pi1S         tE
#      pi2P       tEze
#      pi2S         tE
#      ps1S        tEz
# dtype: object
# 884  lexeme    taper
#      pI2P       tape
#      pi1S        tap
#      pi2S        tap
# dtype: object
# 889  lexeme    tendre
#      ii3S        tâdE
#      inf         tâdr
# dtype: object
# 890  lexeme     tenir
#      ii2S        t6nE
#      inf        t6nir
#      pI2P        t6ne
#      pI2S         tjê
#      pP          t6nâ
#      pc1S      tjêdrE
#      pi1S         tjê
#      pi2P        t6ne
#      pi2S         tjê
#      pi3S         tjê
#      ppFP        t6ny
#      ppMS        t6ny
# dtype: object
# 896  lexeme    tirer
#      ai3S       tira
#      ii3S       tirE
#      inf        tire
#      pI2S        tir
#      pi1P       tirô
#      pi1S        tir
#      pi3S        tir
#      ppMP       tire
#      ppMS       tire
#      ps1S        tir
#      ps3S        tir
# dtype: object
# 898  lexeme    tomber
#      ai3S        tôba
#      ii1S        tôbE
#      ii3P        tôbE
#      inf         tôbe
#      is3S        tôba
#      pI2S         tôb
#      pi1S         tôb
#      ppFS        tôbe
# dtype: object
# 900  lexeme    toucher
#      inf          tuSe
#      pI2P         tuSe
#      pI2S          tuS
#      pi3S          tuS
#      ppMS         tuSe
#      ps1S          tuS
#      ps3S          tuS
# dtype: object
# 901  lexeme    tourner
#      ai3S        turna
#      ii3S        turnE
#      inf         turne
#      pI2P        turne
#      pI2S         turn
#      pi1S         turn
#      pi3S         turn
#      ps3P         turn
#      ps3S         turn
# dtype: object
# 903  lexeme    traduire
#      ii1S      tradHizE
#      inf        tradHir
# dtype: object
# 905  lexeme    traiter
#      inf         trEte
#      pI2S         trEt
#      ppFS        trEte
#      ppMS        trEte
#      ps3S         trEt
# dtype: object
# 907  lexeme    transformer
#      pi3P         trâsfOrm
#      ppMS        trâsfOrme
#      ps3S         trâsfOrm
# dtype: object
# 910  lexeme    transporter
#      ii3S        trâspOrtE
#      ppMS        trâspOrte
# dtype: object
# 911  lexeme    travailler
#      fi1S       travaj6rE
#      ii1S         travajE
#      ii3S         travajE
#      pI2P         travaje
#      pI2S          travaj
#      pi1S          travaj
#      pi3S          travaj
#      ps3S          travaj
# dtype: object
# 912  lexeme    traverser
#      inf        travErse
#      pi3P        travErs
# dtype: object
# 913  lexeme    traîner
#      ii3S        trEnE
#      pI2S         trEn
# dtype: object
# 914  lexeme    trembler
#      ii1S        trâblE
#      inf         trâble
#      pI2P        trâble
# dtype: object
# 918  lexeme    triompher
#      ai3S         triôfa
#      ii3S         triôfE
#      pi1S          triôf
# dtype: object
# 921  lexeme    tromper
#      inf         trôpe
#      pI2P        trôpe
#      pi3S         trôp
#      ppMP        trôpe
#      ps1S         trôp
# dtype: object
# 923  lexeme    trouver
#      ai1S        truvE
#      ai3S        truva
#      fi1S      truv6rE
#      ii1S        truvE
#      ii2S        truvE
#      ii3S        truvE
#      inf         truve
#      pI1P        truvô
#      pI2P        truve
#      pI2S         truv
#      pP          truvâ
#      pc1S      truv6rE
#      pi1P        truvô
#      pi1S         truv
#      pi2P        truve
#      pi2S         truv
#      pi3S         truv
#      ppMS        truve
#      ps1S         truv
#      ps2S         truv
#      ps3S         truv
# dtype: object
# 926  lexeme    tuer
#      fi1S      tyrE
#      inf        tye
#      pI2P       tye
#      pI2S        ty
#      pc1S      tyrE
#      pi1S        ty
#      pi3S        ty
#      ppMP       tye
#      ppMS       tye
#      ps1S        ty
#      ps3S        ty
# dtype: object
# 927  lexeme    tâter
#      inf        tate
#      pi1S        tat
#      pi3S        tat
# dtype: object
# 928  lexeme    téléphoner
#      ai3S        tElEfOna
#      inf         tElEfOne
#      pI2S         tElEfOn
#      pi3S         tElEfOn
# dtype: object
# 929  lexeme    unir
#      inf       ynir
#      pi1S       yni
# dtype: object
# 931  lexeme    utiliser
#      ii1S       ytilizE
#      ii3S       ytilizE
#      inf        ytilize
#      pI2S        ytiliz
#      ppMP       ytilize
#      ppMS       ytilize
#      ps3S        ytiliz
# dtype: object
# 933  lexeme    vaincre
#      inf          vêkr
#      ppMS         vêky
# dtype: object
# 935  lexeme    valoir
#      pi3S          vo
#      ps1S         vaj
# dtype: object
# 937  lexeme    veiller
#      ii3S         vEjE
#      pI2P         vEje
# dtype: object
# 938  lexeme    vendre
#      inf         vâdr
#      pI2S          vâ
#      pi2S          vâ
# dtype: object
# 940  lexeme     venir
#      fi1S      vjêdrE
#      fi3P      vjêdrô
#      ii1S        v6nE
#      ii2P       v6nje
#      ii3P        v6nE
#      ii3S        v6nE
#      inf        v6nir
#      pI1P        v6nô
#      pI2P        v6ne
#      pI2S         vjê
#      pc3S      vjêdrE
#      pi1P        v6nô
#      pi1S         vjê
#      pi2P        v6ne
#      pi2S         vjê
#      pi3P        vjEn
#      pi3S         vjê
#      ppFS        v6ny
#      ppMP        v6ny
#      ppMS        v6ny
#      ps1S        vjEn
#      ps3P        vjEn
# dtype: object
# 942  lexeme    verser
#      pI2S        vErs
#      pi3S        vErs
# dtype: object
# 946  lexeme    vieillir
#      ai3S         vjEji
#      pP         vjEjisâ
# dtype: object
# 948  lexeme    visiter
#      ai3S       vizita
#      inf        vizite
#      pI2S        vizit
#      pP         vizitâ
# dtype: object
# 950  lexeme    vivre
#      ii2S       vivE
#      inf        vivr
#      pi1S         vi
#      pi2P       vive
#      pi3S         vi
#      ps1S        viv
#      ps3P        viv
# dtype: object
# 951  lexeme     voir
#      ai2S         vi
#      ai3S         vi
#      fi2P       vEre
#      fi2S       vEra
#      ii1S      vwajE
#      ii2P      vwaje
#      ii3P      vwajE
#      ii3S      vwajE
#      inf        vwar
#      pI1P      vwajô
#      pI2P      vwaje
#      pI2S        vwa
#      pi1S        vwa
#      pi2P      vwaje
#      pi2S        vwa
#      pi3S        vwa
#      ppFP         vy
#      ppFS         vy
#      ppMP         vy
#      ppMS         vy
#      ps3P        vwa
#      ps3S        vwa
# dtype: object
# 952  lexeme    voler
#      inf        vOle
#      pi1S        vOl
#      pi3P        vOl
#      ppMS       vOle
#      ps3S        vOl
# dtype: object
# 953  lexeme     vomir
#      ii3S      vOmisE
#      inf        vOmir
# dtype: object
# 954  lexeme    voter
#      inf        vOte
#      pi1S        vOt
#      ppMS       vOte
# dtype: object
# 955  lexeme    vouloir
#      ai3S         vuly
#      fi3P        vudrô
#      ii1S         vulE
#      ii2P        vulje
#      ii2S         vulE
#      ii3S         vulE
#      inf        vulwar
#      pI2P         vule
#      pc1S        vudrE
#      pc2S        vudrE
#      pi1S           v2
#      pi2P         vule
#      pi2S           v2
#      pi3P          v9l
#      pi3S           v2
#      ppMS         vuly
#      ps1P        vuljô
# dtype: object
# 957  lexeme    vérifier
#      inf        vErifje
#      pc2S      vErifirE
#      pi1S        vErifi
#      ps3S        vErifi
# dtype: object
# 961  lexeme    écarter
#      inf        Ekarte
#      pI2S        Ekart
#      pP         Ekartâ
#      pi3P        Ekart
#      pi3S        Ekart
# dtype: object
# 962  lexeme    échanger
#      ai3P        ESâZEr
#      pc3S       ESâZ6rE
# dtype: object
# 963  lexeme    échapper
#      ai3S         ESapa
#      pI2S          ESap
#      pi1S          ESap
#      ps3S          ESap
# dtype: object
# 965  lexeme    éclairer
#      ai3S        EklEra
#      inf         EklEre
#      pi3S         EklEr
# dtype: object
# 966  lexeme    éclater
#      ai3S       Eklata
#      pP         Eklatâ
#      pi1S        Eklat
#      pi3S        Eklat
# dtype: object
# 967  lexeme    écouter
#      ii2S        EkutE
#      pI2P        Ekute
#      pI2S         Ekut
#      pi1S         Ekut
#      pi3S         Ekut
#      ppMS        Ekute
#      ps1S         Ekut
#      ps2S         Ekut
#      ps3S         Ekut
# dtype: object
# 968  lexeme    écraser
#      pi2P       Ekraze
#      ps3S        Ekraz
# dtype: object
# 969  lexeme    écrire
#      ii2S      EkrivE
#      inf        Ekrir
#      pi1S        Ekri
#      pi3S        Ekri
#      ppMS        Ekri
# dtype: object
# 973  lexeme    élancer
#      ai3S        Elâsa
#      pi3S         Elâs
# dtype: object
# 974  lexeme    élever
#      inf        El6ve
#      pi3P        ElEv
#      pi3S        ElEv
# dtype: object
# 976  lexeme    éloigner
#      ai3S        ElwaJa
#      ii3P        ElwaJE
#      inf         ElwaJe
#      pI2S         ElwaJ
#      pi1S         ElwaJ
# dtype: object
# 981  lexeme    émerveiller
#      ppFP         EmErvEje
#      ppMS         EmErvEje
# dtype: object
# 983  lexeme    énerver
#      pi1S        EnErv
#      pi2S        EnErv
# dtype: object
# 984  lexeme    épargner
#      pi1S         EparJ
#      pi2P        EparJe
#      pi3S         EparJ
# dtype: object
# 988  lexeme    épouser
#      ii3P        EpuzE
#      pI2S         Epuz
#      pi1S         Epuz
#      ppFS        Epuze
#      ppMS        Epuze
# dtype: object
# 989  lexeme    éprouver
#      inf         Epruve
#      pI2S         Epruv
#      ppMS        Epruve
# dtype: object
# 994  lexeme    éteindre
#      pc3S        EtêdrE
#      pi2S           Etê
#      ps1S          EtEJ
# dtype: object
# 995  lexeme    étendre
#      ai3S        Etâdi
#      ii3S        EtâdE
#      ppMP        Etâdy
# dtype: object
# 996  lexeme    étonner
#      ai3S        EtOna
#      ii3S        EtOnE
#      pc3S      EtOn6rE
#      pi3S         EtOn
#      ps1S         EtOn
# dtype: object
# 997  lexeme    étouffer
#      pi3S          Etuf
#      ppMP         Etufe
# dtype: object
# 1002  lexeme    éviter
#       ii3S       EvitE
#       inf        Evite
#       pP         Evitâ
# dtype: object
# 1003  lexeme    évoquer
#       pP          EvOkâ
#       ppMS        EvOke
# dtype: object
# 1004  lexeme     être
#       ai3S         fy
#       fi1P       s6rô
#       fi1S       s6rE
#       fi2P       s6re
#       fi2S       s6ra
#       fi3P       s6rô
#       fi3S       s6ra
#       ii1P       Etjô
#       ii1S        EtE
#       ii2S        EtE
#       ii3P        EtE
#       ii3S        EtE
#       inf         Etr
#       is1S        fys
#       is3P        fys
#       is3S         fy
#       pI2P      swaje
#       pI2S        swa
#       pc1S       s6rE
#       pc2S       s6rE
#       pc3P       s6rE
#       pc3S       s6rE
#       pi1P        sOm
#       pi1S        sHi
#       pi2P         Et
#       pi2S          E
#       pi3P         sô
#       pi3S          E
#       ps1S        swa
#       ps2S        swa
#       ps3P        swa
#       ps3S        swa
# dtype: object
# 1005  lexeme    ôter
#       pi1S        ot
#       ppMS       Ote
# dtype: object

# %% [markdown]
# ##Comparer la sortie des cliques avec le tableau de conjugaison normal

# %%
seuilClique=40
#paradigmesCLIQUES=pd.DataFrame(columns=paradigmes.columns.values.tolist())
paradigmesListe=[]
for n,clique in enumerate(sorted(cliques,key=lambda x: len(x),reverse=True)):
    if len(clique)>seuilClique:
        paradigmeClique={}
        sampleOK=True
#        print (n, len(clique))
        lexeme=clique[0].split("-")[0]
        paradigmeClique["lexeme"]=lexeme
        for element in clique:
            (lexeme,forme,taminfo)=element.split("-")
            paradigmeClique[taminfo]=forme
            if taminfo in paradigmes.columns:
                if not paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].isnull().item():
                    if paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item()!=forme:
                        sampleOK=False
                        print (paradigmes[(paradigmes["lexeme"]==lexeme)][taminfo].item(),forme,end=", ")
    if sampleOK:
        paradigmesListe.append(paradigmeClique)
    else:
        print ()
paradigmesCLIQUES=pd.DataFrame(paradigmesListe)
# Out:
# asje aswa, asEje aswaje, asEje aswaje, asEjE aswajE, asje aswa, asje,aswa asje, asje,aswa aswa,
# r6sOr r6sOrti,
# tE tEj, tE tEj, tEz tEj, tEz tE, tyr tEjEr, tEzE tEjE, tEze tEje, tE tEj,
# r6kOnEtra r6kOnEra, r6kOnEse r6kOnEje, r6kOnE r6kOnEj, r6kOny r6kOnEje, r6kOnEtra r6kOnEj6ra,
# parEtra parEra, parEsE parEjE, parEtra parEj6ra, parE parEj,
# kOnEsje kOnEje, kOnEtr kOnEje, kOnEse kOnEje, kOnEs kOnE, kOnE kOnEj, kOnEsE kOnEjE, kOnEsje kOnEje, kOny kOnEje, kOnE kOnEj, kOnEsE kOnEjE, kOnEs kOnEj, kOnEsô kOnEjô, kOnE kOnEj, kOnE kOnEj, kOnEse kOnEje,
# EsErE EsEj6rE, EsE EsEj, EsE,EsEj EsEj, EsE EsEj, EsE,EsEj EsEj, EsEj6rE EsErE, EsE,EsEj EsE, EsE,EsEj EsE,
# pE,pEj pE, pE,pEj pE, pEj pE, pE,pEj pE, pE,pEj pEj, pE,pEj pEj, pE pEj, pE,pEj pEj,
# admE admEj, admEtr admEje, admE admEj, admEtâ admEjâ,
# plE plEj, plEzE plEjE,
# plE plEj, plEzE plEjE,
# mE mEj, mEtE mEjE, mEt mE, mEte mEje, mEtrE mErE, mE mEj, mi mEja, mi mEjE, mEte mEje, mi mEja, mEt mEj, mEt mEj, mEtr mEje, mEt mEj, mE mEj, mEtrE mEj6rE, mE mEj, mEt mE, mEt mE,
# pErmEtrô pErmEj6rô, pErmE pErmEj, pErmEtrE pErmEj6rE, pErmE pErmEj, pErmEtrô pErmErô, pErmEtr pErmEje, pErmEte pErmEje, pErmEte pErmEje, pErmEtrE pErmErE,
# r6mEt r6mE, r6mEt r6mE, r6mEtr r6mEje, r6mE r6mEj, r6mEt r6mEj, r6mEtô r6mEjô, r6mEt r6mEj, r6mE r6mEj, r6mi r6mEja,
# prOmE prOmEj, prOmEtE prOmEjE, prOmE prOmEj, prOmi prOmEja, prOmi prOmEjE,
# rEvEj rEvE, rEvEj rEvE, rEvEj rEvE, rEvEj rEvE, rEvEj rEvE,
# syrvEj syrvE, syrvEj syrvE, syrvEj syrvE,
# sOrt sOrtis, sOrtE sOrtisE,
# sOra sEj6ra, sy sEja, sy sEje, savE sEjE, sOra sEra, savE sEjE, savjô sEjô, sE sEj, sE sEj, sE sEj, save sEje, savwar sEje, savE sEjE, savje sEje, sOra sEra, sOra sEj6ra,
# ram6ne ramEne, ram6ne ramEne,
# êkjEte êkj6te,
# r6mEtr r6mir, r6miz r6mi, r6mE r6mi, r6mEt r6mis, r6mEtô r6misô, r6mE r6mi, r6mEt r6mis,
# Etâdy Etâde, Etâdi Etâda,
# atê atEJe, atê atEJ,
# Etâdy Etâdi, EtâdE EtâdisE,
# âplwa âplwaj,
# vâdr vâtir,
# r6sâ r6sâti, r6sâ r6sâti,
# dEsâ dEsâdi, dEsâdô dEsâdisô, dEsâdy dEsâdi, dEsâ dEsâdi, dEsâdr dEsâdir, dEsâ dEsâdi, dEsâd dEsâdis, dEsâ dEsâdi,
# trEnE tr6nE,
# kôstrHiz kôstrHi, kôstrHi kôstrHie, kôstrHir kôstrHie,
# âtrô âtrdô, âtr âtrd, âtre âtrdr, âtre âtrde, âtre âtrdy,
# kôstrHi kôstrHize, kôstrHi kôstrHiz, kôstrHir kôstrHize,
# vOl vol, vOl vol, vOl vol,
# vOt vot,
# sOn son,
# grâdi grâdje,
# lâgisE lâgjE,
# d6vjEn d6vEn, d6v6ny d6v6ne, d6vjêdra d6vEn6ra, d6vjê d6vEn, d6vê d6v6na, d6v6ny d6v6ne, d6v6ny d6v6ne, d6v6nir d6v6ne, d6vjêdra d6vEn6ra, d6vjê d6vEn,
# dEkuvrir dEkuvre,
# âl6ve âlEve,
# ô av, Eje avje, Orô av6rô, OrE av6rE, Eje ave, Orô av6rô, y ava, y ave, y ave, E av, Ore av6re, avwar ave, OrE av6rE, Ora av6ra, E av, a av, a av, Ora av6ra,
# partE partjE, parti partja, parti partja, par parti, parti partje, partir partje, parte partje, par parti, parte partje, part parti, parti partjE, part parti, par parti, partô partjô, par parti, partâ partjâ, parti partje,
# uvrir uvre, uvErt uvre, uvri uvra,
# frâSir frâSje, frâSi frâSja,
# vOmir vOmise,
# s6kue s6kuzy, s6kua s6kuzi,
# syrZi syrZise, syrZir syrZise, syrZi syrZisa,
# êtErdizâ êtErdisâ, êtErdit êtErdi,
# pErd pEr, pErdâ pErâ, pErdy pEre, pErdr pEre,
# Swazi Swazje, Swazir Swazje, Swazise Swazje,
# dEtrHit dEtrHi,
# prEte pr6te,
# tElEfOn tElEfon, tElEfOn tElEfon,
# rEpôdy rEpôde, rEpô rEpôd, rEpôdi rEpôda, rEpôdr rEpôde, rEpô rEpôd, rEpô rEpôd, rEpôdi rEpôdE,
# m6ne mEne,
# nOt not,
# trEte tr6te, trEte tr6te, trEte tr6te,
# dOrmir dOrme, dOr dOrm, dOr dOrm, dOrmi dOrma, dOr dOrm,
# trôpe trôpy, trôp trô, trôpe trôpr,
# p6zE pEzE,
# vjêdrô vEn6rô, vjê vEn, vjEn vEn, vjê vEn, vjêdrE vEn6rE, vjEn vEn, v6nir v6ne, v6ny v6ne, v6ny v6ne, v6ny v6ne, vjêdrE vEn6rE, vjEn vEn, vjê vEn, vjê vEn,
# sufrE sufrisE,
# sEr sErv, sErvir sErve, sErvi sErve, sEr sErv,
# r6drEsa r6dr6sa,
# dOn don, dOn don, dOn don, dOn don, dOn don, dOn don, dOn don,
# EsE,EsEj EsEi, EsE,EsEj EsEi, EsErE EsEirE, EsEj6rE EsEirE, EsEje EsEije, EsE EsEi, EsE EsEi,
# rEkôfOrte rEkôfOrti,
# rEkôfOrte rEkôfOrty,
# pOrte pOrti, pOrte pOrtir,
# pOrte pOrty, pOrte pOrtr,
# tôba tôbi, tôba tôbi, tôbe tôbr, tôbe tôby,
# sâti sâty, sâti sâty, sâti sâty, sâtir sâtr,
# trEte trEtr, trEte trEty, trEte trEty,
# asje aswa, asEje aswaje, asEje aswaje, asje aswa, asEjE aswajE, asje,aswa aswa, aswar aswaje, asi aswaja, asi aswaja, asi aswajE,
# âfErme âfErmi,
# abatr abat6vwar,
# Ezite Ezitr,
# nEtwaje nEt6vwar, nEtwa nEtwav,
# EsEje EsEe, EsEje EsEe, EsEje EsEe, EsE,EsEj Ese, EsE Ese, EsEj6rE EsErE, EsE Ese, EsE,EsEj Ese,
# rEvEj rEvEi, rEvEj rEvEi, rEvEj rEvEi, rEvEj6ra rEvEira, rEvEj rEvEi,
# EvOke EvOky,
# fOrme fOrmi,
# trEte trEty, trEte trEty, trEte trEtir,
# atrape atrapir,
# rêse rêsir,
# ElEv El9v,
# êvita êviti,
# sOrtir sOrtr, sOrtirE sOrtrE, sOrti sOrty, sOrti sOrty,
# dOrmE dOrmisE, dOrme dOrmise, dOrm dOrmis,
# bati baty,
# r6lEv r6l9v, r6lEv r6l9v,
# r6lEv r6l9v, r6lEv r6l9v,
# dEbOrde dEbOrdy,
# kOJ koJ,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE, asje,aswa asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asE, asje asEj, asje asE, asje,aswa asE,
# rjâ risâ, rjE risE,
# vjEjisâ vjEjâ,
# prie prje,
# rEvEjEr rEvEjir,
# adOr ador, adOr ador,
# âlEv âl9v,
# lEv l9v, lEv l9v, lEv l9v, lEv l9v,
# sulEv sul9v, sulEv sul9v,
# âplwa âplwaj,
# ublie ublize, ublie ubly, ubliE ublizE, ublie ublir, ublie ubly,
# kriâ krjâ, krie krje,
# kriâ krjâ, krja kri,
# ElEv El9v, ElEv El9v,
# aSEt aS9t, aSEt aS9t, aSEt aS9t,
# ZEt Z9t, ZEt Z9t, ZEt Z9t, ZEt Z9t, ZEt Z9t,
# salir salie,
# r6lEv r6l9v,
# iJOr iJor, iJOr iJor, iJOr iJor,
# sOrti sOrdy, sOrtE sOrdE, sOrt sOrd, sOrti sOrdi, sOrtirE sOrdrE, sOrtir sOrdr, sOrti sOrdi, sOrti sOrdy,
# r6gardEr r6gardir, r6garde r6gardi, r6gard6ra r6gardira, r6garde r6gardir,
# garde gardir, garde gardi,
# dizE disE, dizE disE, diz dis, diz dis, dizô disô, dizE disE, dizô disô, diz dis, diz dis, dit di,
# pl9r plEr,
# r6kOmâse r6kOmâsir,
# avâsa avâsi,
# rapOrt rapOr,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asE, asje asEj, asje asE, asje,aswa asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asiz asEje, asiz asEje, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE, asje,aswa asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asiz asEje, asiz asEje, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE, asje,aswa asE,
# pâdy pâdi,
# âpOrte âpOrty,
# apOrte apOrtir, apOrt apOr, apOrt apOr, apOrte apOrti,
# apOrte apOrty, apOrte apOrtir,
# apOrte apOrty,
# dâse dâsi, dâse dâsir,
# prEzâte prEzâty,
# prEzâte prEzâty,
# pErdr pErdir, pErdy pErdi,
# rjâ risâ, rjE risE,
# Etâdy Etâdi,
# kOmâde kOmâdir,
# dEtâdy dEtâdi,
# prie prje,
# pâsa pâsi, pâse pâsir, pâse pâsi,
# râdrE râdirE, râdr râdir, râdy râdi, râdy râdi,
# trâspOrte trâspOrty,
# trâspOrte trâspOrty,
# âtâdr âtâdir, âtâdy âtâdi, âtâdy âtâdi,
# trâspOrte trâspOrti,
# êtErdit êtErdi, êtErdizâ êtErdâ,
# rEkôfOrte rEkôfOrti,
# travErse travErsir,
# sOr sOrti, sOrtir sOrtje, sOrtE sOrtjE, sOrti sOrtja, sOrt sOrti, sOrti sOrtjE, sOr sOrti, sOrtE sOrtjE, sOrti sOrtje, sOr sOrti, sOrti sOrtje,
# rEkôfOrte rEkôfOrty,
# rEkôfOrte rEkôfOrty,
# pOrte pOrti, pOrte pOrtir, pOrt pOr, pOrt pOr, pOrt pOr,
# pOrte pOrty, pOrte pOrtir,
# pOrte pOrty,
# dEbOrde dEbOrdi,
# sâti sâty, sâti sâty, sâti sâty,
# sâti sâty, sâti sâty,
# falwar fajir, falE fajE, fOdra fajira, fOdrE fajirE,
# krie krje, kriâ krjâ,
# sOrti sOrty, sOrti sOrty,
# sOrti sOrty,
# dEsâdr dEsâdir, dEsâdy dEsâdi,
# tâdr tâdir,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdir, d6mâde d6mâdi, d6mâde d6mâdi,
# atâdrE atâdirE, atâdy atâdi, atâdr atâdir,
# travaj6rE travarE, travaj trava,
# kOmâse kOmâsir, kOmâse kOmâsi, kOmâsa kOmâsi,
# mEn m2n,
# r6gardEr r6gardir, r6garde r6gardi, r6gard6ra r6gardira, r6garde r6gardir,
# r6gardEr r6gardir, r6garde r6gardi, r6gard6ra r6gardira, r6garde r6gardir,
# garde gardir, garde gardi,
# garde gardir, garde gardi,
# frap6ra frapra,
# frap6ra frapra,
# rakôta rakôti, rakôte rakôty, rakôt6ra rakôtra,
# kupe kupy,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asE, asje asEj, asje asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asE, asje asEj, asje asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asiz asEje, asiz asEje, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE, asje,aswa asE,
# pâdy pâdi,
# pâdy pâdi,
# âmEn âm2n, âmEn âm2n,
# âmEn âm9n, âmEn âm9n,
# pErdr pErdir, pErdy pErdi,
# pErdy pErdi, pErdr pErdir,
# Etâdy Etâdi,
# Etâdy Etâdi,
# ESapa ESapi,
# aZut6rE aZutrE, aZute aZuty,
# r6truve r6truvy,
# kOmâde kOmâdir,
# kOmâde kOmâdir,
# dEtâdy dEtâdi,
# dEtâdy dEtâdi,
# râdrE râdirE, râdr râdir, râdy râdi, râdy râdi,
# râdrE râdirE, râdr râdir, râdy râdi, râdy râdi,
# mEn m9n,
# âtâdy âtâdi, âtâdy âtâdi, âtâdr âtâdir,
# âtâdr âtâdir, âtâdy âtâdi, âtâdy âtâdi,
# êtErdit êtErdi, êtErdizâ êtErdâ,
# êtErdit êtErdi, êtErdizâ êtErdâ,
# Z6tâ ZEtâ, Z6ta ZEti, Z6te ZEty,
# SySOta SySOti,
# prEvwar prEvEtr,
# kite kity, kite kity,
# EsE,EsEj EsEi, EsE,EsEj EsEi, EsErE EsEirE, EsEj6rE EsEirE, EsEje EsEije,
# EsE,EsEj EsEi, EsE,EsEj EsEi, EsErE EsEirE, EsEj6rE EsEirE, EsEje EsEije,
# truv6rE truvrE, truva truvi, truvE truvi, truv6rE truvrE, truve truvy,
# ramEn ram9n, ramEn ram9n, ramEn ram9n,
# dEsâdr dEsâdir, dEsâdy dEsâdi,
# dEsâdr dEsâdir, dEsâdy dEsâdi,
# atrape atrapr,
# tâdr tâdir,
# tâdr tâdir,
# ramEn ram2n, ramEn ram2n, ramEn ram2n,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdir, d6mâde d6mâdi, d6mâde d6mâdi,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdir, d6mâde d6mâdi, d6mâde d6mâdi,
# atâdrE atâdirE, atâdy atâdi, atâdr atâdir,
# atâdrE atâdirE, atâdy atâdi, atâdr atâdir,
# travaj6rE travarE, travaj trava,
# travaj6rE travarE,
# amEn am9n, amEn am9n, amEn am9n, amEn am9n,
# amEn am2n, amEn am2n, amEn am2n, amEn am2n,
# Okypa Okypi, Okyp6rE OkyprE, Okyp6rô Okyprô, Okype Okypy,
# Ekute Ekuty,
# dEbOrde dEbOrdi,
# dEbOrde dEbOrdi,
# vizita viziti, vizite vizitir,
# vOmisE vOmE,
# adusisE adusE,
# koz kOz,
# prOmiz prOmi, prOmEtE prOmE,
# môte môtir, môte môti,
# vulwar vule, vudrE vul6rE, vudrE vul6rE, vuly vule, vuly vula, v9l vul, vudrô vul6rô,
# poz pOz, poz pOz, poz pOz,
# êpoz êpOz,
# rakôta rakôti, rakôt6ra rakôtira, rakôte rakôtir, rakôte rakôti,
# rakôta rakôti, rakôt6ra rakôtra, rakôte rakôtr,
# dEpoz dEpOz,
# ânHiE ânHizE, ânHiâ ânHizâ, ânHie ânHi, ânHi ânHiz,
# faji fajja,
# pwête pwêtr,
# kupe kupi,
# atâdr atâdir, atâdrE atâdirE,
# atâdrE atâdirE,
# atâdrE atâdirE,
# êvita êviti,
# kite kitir, kite kiti, kite kiti,
# sOte sOtir, sOte sOti,
# sHivr sHivir,
# ariva arivi, ariv6ra arivra, arive arivr,
# travaj6rE travajirE,
# pErdr pErdir,
# rjâ risâ, rjE risE,
# ESapa ESapi,
# ESapa ESapi,
# aZute aZuti, aZut6rE aZutirE,
# aZut6rE aZutrE,
# r6truve r6truvr,
# pusa pusi,
# dEnôse dEnôsir,
# fajirE faj6rE,
# sufrE sufrjE, sufrir sufrje,
# pusa pusi,
# rêse rêsr,
# anôse anôsi,
# Ekute Ekuti,
# râdrE râdirE,
# râdrE râdirE,
# râdrE râdirE, râdr râdir,
# âfôse âfôsir, âfôse âfôsi,
# âtâdr âtâdir,
# Ekspoz EkspOz,
# kwêse kwêsi,
# r6poz r6pOz, r6poz r6pOz,
# Z6tâ ZEtâ, Z6ta ZEti, Z6te ZEtr,
# SySOta SySOti,
# SySOta SySOti,
# prEvwar prEvEtr,
# travaj6rE travajirE,
# sErve sErvize, sErve sErvize,
# sOrti sOrte, sOr sOrt, sOrti sOrta, sOrti sOrte, sOr sOrt, sOr sOrt, sOrti sOrtE, sOrtir sOrte, sOrtirE sOrt6rE,
# âfôse âfôsr,
# rEpâdr rEpâdir,
# r6vwar r6vir, r6vwa r6viz,
# Ezite Ezitir,
# truv6rE truvrE, truva truvi, truvE truvi, truv6rE truvrE, truve truvr,
# dEbOrde dEbOrdy,
# dEbOrde dEbOrdy,
# tâdr tâdir,
# Sâte Sâtr,
# syse sysir,
# syse sysr,
# sOr sOrti, sOr sOrti, sOr sOrti, sOrt sOrtiz, sOrtE sOrtizE, sOrti sOrtit, sOrtE sOrtizE,
# kriâ krjâ, krie krir, krja kri,
# kuvrE kuvrjE,
# trôpe trôpir, trôpe trôpi,
# dEsâdr dEsâdir,
# livre livrir,
# pwête pwêtir,
# Sâte Sâtir,
# Evite Evitir,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdy, d6mâde d6mâdy,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdy, d6mâde d6mâdy,
# prOpoz prOpOz, prOpoz prOpOz,
# r6môta r6môti,
# Okypa Okypi, Okyp6rE OkyprE, Okyp6rô Okyprô, Okype Okypr,
# Okypa Okypi, Okype Okypir, Okyp6rE OkypirE, Okype Okypi, Okyp6rô Okypirô,
# tôbe tôbir, tôbe tôbi, tôba tôbi, tôba tôbi,
# futr futir, futy futi,
# dEbOrde dEbOrdy,
# kite kitr,
# koz kOz,
# poz pOz, poz pOz,
# êpoz êpOz,
# apOrtE apOrtisE, apOrte apOrtir, apOrt apOrti, apOrte apOrti, apOrt apOrtis,
# rEkôfOrt rEkôfOrtis, rEkôfOrte rEkôfOrti,
# dEpoz dEpOz,
# rapOrt rapOrtis,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE, asje,aswa asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj, asiz asEje, asiz asEje,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj, asje asE, asje asE,
# atâdr atâdir, atâdrE atâdirE,
# atâdr atâdir, atâdrE atâdirE,
# âpOrt âpOrtis, âpOrt âpOrtis, âpOrte âpOrti, âpOrtâ âpOrtisâ,
# ariva arivi, ariv6ra arivra, arive arivy,
# pErdr pErdir,
# pErdr pErdir,
# arEta arEti, arEte arEti, arEte arEtir, arEt6ra arEtira, arEte arEti,
# kOmâde kOmâdir,
# sufrE sufrjE,
# tyr tEzEr, tE tEz, tE tEz, tE tEz,
# rir rje,
# râdrE râdirE, râdr râdir,
# râdrE râdirE, râdr râdir,
# trâspOrte trâspOrti, trâspOrtE trâspOrtisE,
# rEpEte rEpEtir, rEpEt rEpE, rEpEte rEpEty,
# rEpEte rEpEtir, rEpEte rEpEti,
# âtâdr âtâdir,
# âtâdr âtâdir,
# r6poz r6pOz, r6poz r6pOz,
# âplwa âplwaj,
# uvr uvri, uvr uvri, uvr uvri, uvr uvri,
# âpOrt âpOr,
# rEpâdr rEpâdir,
# rEpâdr rEpâdir,
# pOrte pOrti, pOrt pOrtis, pOrtE pOrtisE, pOrt pOrti, pOrte pOrtir,
# plEzât plEzâ,
# tâdr tâdir,
# tâdr tâdir,
# kuvrE kuvrjE,
# dEsâdr dEsâdir,
# dEsâdr dEsâdir,
# fHis fHizis, fHi fHizi,
# sOrti sOrmi, sOrti sOrmi, sOrt sOrm, sOrtE sOrmE, sOrtir sOrmir, sOrtirE sOrmirE,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdy, d6mâde d6mâdy,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdir, d6mâde d6mâdy,
# prOpoz prOpOz, prOpoz prOpOz,
# prEzâte prEzâti, prEzât prEzâ, prEzât prEzâ,
# Ekri Ekriv, Ekri Ekriv,
# tE tEz, tE tEz, tE tEz, tEze t6ze, tEzE t6zE,
# EsErE EsEj6rE, EsE EsEj,
# dEbOrde dEbOrdy,
# dEbOrde dEbOrdy,
# kOnE kOnEs, kOnEsE kOn6sE, kOnEsje kOn6sje, kOnEsô kOn6sô, kOny kOn6se, kOnEsje kOn6sje, kOnE kOnEs, kOnE kOnEs, kOnEsE kOn6sE, kOnEse kOn6se, kOnEtr kOn6se, kOnEse kOn6se, kOnE kOnEs,
# râpli râply,
# pE,pEj pEj, pE pEj,
# vizita viziti,
# vizita viziti, vizite vizitir,
# rEpôdr rEpôdir, rEpôdy rEpôdi,
# rEve rEvi,
# rakôta rakôti, rakôte rakôty, rakôt6ra rakôtira,
# frap6ra frapira, frape frapi, frapâ frapisâ,
# karEse kar6se,
# karEse kar6se,
# pl9r plEr,
# nEtwaje nEt6vwar,
# r6kOmâse r6kOmâsir,
# akOrd akOr,
# dEside dEsidir, dEside dEsidi,
# avâsa avâsi,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asEj,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asE, asje asEj, asje asE,
# asi asEjE, asi asEja, aswar asEje, asi asEja, asje,aswa asEj, asje asEj, asje asE, asje asEj, asje asE,
# êvita êviti,
# êvita êviti,
# kite kity, kite kity,
# dâse dâsr,
# dâse dâsi, dâse dâsir,
# sOte sOty,
# sOte sOty, sOte sOtir,
# dispary dispar6sa, disparEtr dispar6se, dispary dispar6se,
# pErdy pErdi, pErdr pErdir, pErdâ pErdisâ,
# aZut6rE aZutirE, aZute aZuty,
# kOmâde kOmâdir,
# kOmâde kOmâdir,
# pâsa pâsi, pâse pâsr,
# pâsa pâsi, pâse pâsir, pâse pâsi,
# Ekute Ekuty,
# akOrd akOrdis,
# dOne dOnir, dOne dOni, dOne dOni, dOna dOni, dOn6rô dOnirô,
# kôsidEre kôsidErdy, kôsidEre kôsidErdy, kôsidEre kôsidErdr, kôsidEre kôsidErde,
# disparEtr dispar6se, dispary dispar6se, dispary dispar6sa,
# kôfôdrE kôfôdirE,
# êtErdit êtErdi, êtErdizâ êtErdâ, êtErdizâ êtErdisâ,
# Z6tâ ZEtâ, Z6ta ZEti, Z6te ZEty,
# SySOta SySOti,
# môte môty,
# prEvwar prEvEtr,
# atrape atrapir, atrap atrapis,
# EtOna EtOni, EtOn6rE EtOnirE,
# Ezite Ezitir,
# dEbOrde dEbOrdi, dEbOrdâ dEbOrdisâ,
# Evite Evitir,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdir, d6mâde d6mâdy,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdy, d6mâde d6mâdy,
# d6mâdE d6mâdi, d6mâdEr d6mâdir, d6mâde d6mâdir, d6mâde d6mâdy,
# kôsidEre kôsid6re, kôsidEre kôsid6re, kôsidEre kôsid6re, kôsidEre kôsid6re,
# kOmâse kOmâsir, kOmâse kOmâsi,
# r6môta r6môti,
# futr futir,

# %%
paradigmesCLIQUES.dropna(thresh=52)
# Out:
#           ai1P      ai1S       ai2P      ai2S       ai3P      ai3S  \
# 0    EmErvEjam  EmErvEjE  EmErvEjat  EmErvEja  EmErvEjEr  EmErvEja
# 1        vEjam      vEjE      vEjat      vEja      vEjEr      vEja
# 2        fiSam      fiSE      fiSat      fiSa      fiSEr      fiSa
# 3         Ozam       OzE       Ozat       Oza       OzEr       Oza
# 4       rEysim     rEysi     rEysit     rEysi     rEysir     rEysi
# 5       âfôsam     âfôsE     âfôsat     âfôsa     âfôsEr     âfôsa
# 6        m6lam      m6lE      m6lat      m6la      m6lEr      m6la
# 7     r6fErmam   r6fErmE   r6fErmat   r6fErma   r6fErmEr   r6fErma
# 8      sypOzam    sypOzE    sypOzat    sypOza    sypOzEr    sypOza
# 9      âmErdam    âmErdE    âmErdat    âmErda    âmErdEr    âmErda
# 10         bym        by        byt        by        byr        by
# 11      asyram     asyrE     asyrat     asyra     asyrEr     asyra
# 12       lEsam      lEsE      lEsat      lEsa      lEsEr      lEsa
# 13        pyam       pyE       pyat       pya       pyEr       pya
# 14     fatigam    fatigE    fatigat    fatiga    fatigEr    fatiga
# 15     r6môtam    r6môtE    r6môtat    r6môta    r6môtEr    r6môta
# 16       tôbam      tôbE      tôbat      tôba      tôbEr      tôba
# 17     figyram    figyrE    figyrat    figyra    figyrEr    figyra
# 18       Sasam      SasE      Sasat      Sasa      SasEr      Sasa
# 19    Egzistam   EgzistE   Egzistat   Egzista   EgzistEr   Egzista
# 20     dEfilam    dEfilE    dEfilat    dEfila    dEfilEr    dEfila
# 21       Ofrim      Ofri      Ofrit      Ofri      Ofrir      Ofri
# 22      râplim     râpli     râplit     râpli     râplir     râpli
# 23       vOmim      vOmi      vOmit      vOmi      vOmir      vOmi
# 24       mâZam      mâZE      mâZat      mâZa      mâZEr      mâZa
# 25     r6pOzam    r6pOzE    r6pOzat    r6pOza    r6pOzEr    r6pOza
# 26      turnam     turnE     turnat     turna     turnEr     turna
# 27       vEkym      vEky      vEkyt      vEky      vEkyr      vEky
# 28      adusim     adusi     adusit     adusi     adusir     adusi
# 29      flEram     flErE     flErat     flEra     flErEr     flEra
# ..         ...       ...        ...       ...        ...       ...
# 469   partaZam   partaZE   partaZat   partaZa   partaZEr   partaZa
# 470   r6ZwaJim   r6ZwaJi   r6ZwaJit   r6ZwaJi   r6ZwaJir   r6ZwaJi
# 471      lavam      lavE      lavat      lava      lavEr      lava
# 472     arâZam     arâZE     arâZat     arâZa     arâZEr     arâZa
# 473      kulam      kulE      kulat      kula      kulEr      kula
# 474     ESapam     ESapE     ESapat     ESapa     ESapEr     ESapa
# 475     prEtam     prEtE     prEtat     prEta     prEtEr     prEta
# 476      lâgim      lâgi      lâgit      lâgi      lâgir      lâgi
# 477    rEpEtam    rEpEtE    rEpEtat    rEpEta    rEpEtEr    rEpEta
# 478   sypOrtam   sypOrtE   sypOrtat   sypOrta   sypOrtEr   sypOrta
# 479     iJOram     iJOrE     iJOrat     iJOra     iJOrEr     iJOra
# 480   prEfEram   prEfErE   prEfErat   prEfEra   prEfErEr   prEfEra
# 481    d6m6ram    d6m6rE    d6m6rat    d6m6ra    d6m6rEr    d6m6ra
# 482     Epuzam     EpuzE     Epuzat     Epuza     EpuzEr     Epuza
# 483    diriZam    diriZE    diriZat    diriZa    diriZEr    diriZa
# 484    rEzOlym    rEzOly    rEzOlyt    rEzOly    rEzOlyr    rEzOly
# 485      admim      admi      admit      admi      admir      admi
# 486   rapOrtam   rapOrtE   rapOrtat   rapOrta   rapOrtEr   rapOrta
# 487      vêkim      vêki      vêkit      vêki      vêkir      vêki
# 488     pruvam     pruvE     pruvat     pruva     pruvEr     pruva
# 489   prOnôsam   prOnôsE   prOnôsat   prOnôsa   prOnôsEr   prOnôsa
# 490     kôklym     kôkly     kôklyt     kôkly     kôklyr     kôkly
# 491        sym        sy        syt        sy        syr        sy
# 492     rEstam     rEstE     rEstat     rEsta     rEstEr     rEsta
# 493     El6vam     El6vE     El6vat     El6va     El6vEr     El6va
# 494      sOvam      sOvE      sOvat      sOva      sOvEr      sOva
# 495      k6jim      k6ji      k6jit      k6ji      k6jir      k6ji
# 496     plâtam     plâtE     plâtat     plâta     plâtEr     plâta
# 497     ap6lam     ap6lE     ap6lat     ap6la     ap6lEr     ap6la
# 498    pOs6dam    pOs6dE    pOs6dat    pOs6da    pOs6dEr    pOs6da
#
#            fi1P        fi1S        fi2P        fi2S   ...         ppFP  \
# 0    EmErvEj6rô  EmErvEj6rE  EmErvEj6re  EmErvEj6ra   ...     EmErvEje
# 1        vEj6rô      vEj6rE      vEj6re      vEj6ra   ...         vEje
# 2        fiS6rô      fiS6rE      fiS6re      fiS6ra   ...         fiSe
# 3         Oz6rô       Oz6rE       Oz6re       Oz6ra   ...          Oze
# 4       rEysirô     rEysirE     rEysire     rEysira   ...        rEysi
# 5       âfôs6rô     âfôs6rE     âfôs6re     âfôs6ra   ...        âfôse
# 6        mEl6rô      mEl6rE      mEl6re      mEl6ra   ...         m6le
# 7     r6fErm6rô   r6fErm6rE   r6fErm6re   r6fErm6ra   ...      r6fErme
# 8      sypOz6rô    sypOz6rE    sypOz6re    sypOz6ra   ...       sypOze
# 9      âmErd6rô    âmErd6rE    âmErd6re    âmErd6ra   ...       âmErde
# 10        bwarô       bwarE       bware       bwara   ...           by
# 11      asyr6rô     asyr6rE     asyr6re     asyr6ra   ...        asyre
# 12       lEs6rô      lEs6rE      lEs6re      lEs6ra   ...         lEse
# 13         pyrô        pyrE        pyre        pyra   ...          pye
# 14     fatig6rô    fatig6rE    fatig6re    fatig6ra   ...       fatige
# 15     r6môt6rô    r6môt6rE    r6môt6re    r6môt6ra   ...       r6môte
# 16       tôb6rô      tôb6rE      tôb6re      tôb6ra   ...         tôbe
# 17     figyr6rô    figyr6rE    figyr6re    figyr6ra   ...       figyre
# 18       Sas6rô      Sas6rE      Sas6re      Sas6ra   ...         Sase
# 19    Egzist6rô   Egzist6rE   Egzist6re   Egzist6ra   ...      Egziste
# 20     dEfil6rô    dEfil6rE    dEfil6re    dEfil6ra   ...       dEfile
# 21       Ofrirô      OfrirE      Ofrire      Ofrira   ...        OfErt
# 22      râplirô     râplirE     râplire     râplira   ...        râpli
# 23       vOmirô      vOmirE      vOmire      vOmira   ...         vOmi
# 24       mâZ6rô      mâZ6rE      mâZ6re      mâZ6ra   ...         mâZe
# 25     r6pOz6rô    r6pOz6rE    r6pOz6re    r6pOz6ra   ...       r6pOze
# 26      turn6rô     turn6rE     turn6re     turn6ra   ...        turne
# 27        vivrô       vivrE       vivre       vivra   ...         vEky
# 28      adusirô     adusirE     adusire     adusira   ...        adusi
# 29      flEr6rô     flEr6rE     flEr6re     flEr6ra   ...        flEre
# ..          ...         ...         ...         ...   ...          ...
# 469   partaZ6rô   partaZ6rE   partaZ6re   partaZ6ra   ...      partaZe
# 470    r6Zwêdrô    r6ZwêdrE    r6Zwêdre    r6Zwêdra   ...       r6Zwêt
# 471      lav6rô      lav6rE      lav6re      lav6ra   ...         lave
# 472     arâZ6rô     arâZ6rE     arâZ6re     arâZ6ra   ...        arâZe
# 473      kul6rô      kul6rE      kul6re      kul6ra   ...         kule
# 474     ESap6rô     ESap6rE     ESap6re     ESap6ra   ...        ESape
# 475     prEt6rô     prEt6rE     prEt6re     prEt6ra   ...        prEte
# 476      lâgirô      lâgirE      lâgire      lâgira   ...         lâgi
# 477    rEpEt6rô    rEpEt6rE    rEpEt6re    rEpEt6ra   ...       rEpEte
# 478   sypOrt6rô   sypOrt6rE   sypOrt6re   sypOrt6ra   ...      sypOrte
# 479     iJOr6rô     iJOr6rE     iJOr6re     iJOr6ra   ...        iJOre
# 480   prEfEr6rô   prEfEr6rE   prEfEr6re   prEfEr6ra   ...      prEfEre
# 481    d6m6r6rô    d6m6r6rE    d6m6r6re    d6m6r6ra   ...       d6m6re
# 482     Epuz6rô     Epuz6rE     Epuz6re     Epuz6ra   ...        Epuze
# 483    diriZ6rô    diriZ6rE    diriZ6re    diriZ6ra   ...       diriZe
# 484     rEzudrô     rEzudrE     rEzudre     rEzudra   ...       rEzOly
# 485     admEtrô     admEtrE     admEtre     admEtra   ...        admiz
# 486   rapOrt6rô   rapOrt6rE   rapOrt6re   rapOrt6ra   ...      rapOrte
# 487       vêkrô       vêkrE       vêkre       vêkra   ...         vêky
# 488     pruv6rô     pruv6rE     pruv6re     pruv6ra   ...        pruve
# 489   prOnôs6rô   prOnôs6rE   prOnôs6re   prOnôs6ra   ...      prOnôse
# 490     kôklyrô     kôklyrE     kôklyre     kôklyra   ...        kôkly
# 491        sOrô        sOrE        sOre        sOra   ...           sy
# 492     rEst6rô     rEst6rE     rEst6re     rEst6ra   ...        rEste
# 493     ElEv6rô     ElEv6rE     ElEv6re     ElEv6ra   ...        El6ve
# 494      sOv6rô      sOv6rE      sOv6re      sOv6ra   ...         sOve
# 495      k6j6rô      k6j6rE      k6j6re      k6j6ra   ...         k6ji
# 496     plât6rô     plât6rE     plât6re     plât6ra   ...        plâte
# 497     apEl6rô     apEl6rE     apEl6re     apEl6ra   ...        ap6le
# 498    pOsEd6rô    pOsEd6rE    pOsEd6re    pOsEd6ra   ...       pOs6de
#
#          ppFS      ppMP      ppMS      ps1P     ps1S      ps2P     ps2S  \
# 0    EmErvEje  EmErvEje  EmErvEje  EmErvEjô  EmErvEj  EmErvEje  EmErvEj
# 1        vEje      vEje      vEje      vEjô       vE      vEje      vEj
# 2        fiSe      fiSy      fiSy     fiSjô      fiS     fiSje      fiS
# 3         Oze       Oze       Oze      Ozjô       oz      Ozje       oz
# 4       rEysi     rEysi     rEysi  rEysisjô   rEysis  rEysisje   rEysis
# 5       âfôse     âfôse     âfôse    âfôsjô     âfôs    âfôsje     âfôs
# 6        m6le      m6le      m6le     m6ljô      mEl     m6lje      mEl
# 7     r6fErme   r6fErme   r6fErme  r6fErmjô   r6fErm  r6fErmje   r6fErm
# 8      sypOze    sypOze    sypOze   sypOzjô    sypoz   sypOzje    sypoz
# 9      âmErde    âmErde    âmErde   âmErdjô    âmErd   âmErdje    âmErd
# 10         by        by        by     byvjô     bwav     byvje     bwav
# 11      asyre     asyre     asyre    asyrjô     asyr    asyrje     asyr
# 12       lEse      lEse      lEse     lEsjô      lEs     lEsje      lEs
# 13        pye       pye       pye      pyjô       py      pyje       py
# 14     fatige    fatige    fatige   fatigjô    fatig   fatigje    fatig
# 15     r6môte    r6môte    r6môte   r6môtjô    r6môt   r6môtje    r6môt
# 16       tôbe      tôbe      tôbe     tôbjô      tôb     tôbje      tôb
# 17     figyre    figyre    figyre   figyrjô    figyr   figyrje    figyr
# 18       Sase      Sase      Sase     Sasjô      Sas     Sasje      Sas
# 19    Egziste   Egziste   Egziste  Egzistjô   Egzist  Egzistje   Egzist
# 20     dEfile    dEfile    dEfile   dEfiljô    dEfil   dEfilje    dEfil
# 21      OfErt      OfEr      OfEr     Ofriô      Ofr     Ofrie      Ofr
# 22      râpli     râpli     râpli  râplisjô   râplis  râplisje   râplis
# 23       vOmi      vOmi      vOmi   vOmisjô    vOmis   vOmisje    vOmis
# 24       mâZe      mâZe      mâZe     mâZjô      mâZ     mâZje      mâZ
# 25     r6pOze    r6pOze    r6pOze   r6pOzjô    r6poz   r6pOzje    r6poz
# 26      turne     turne     turne    turnjô     turn    turnje     turn
# 27       vEky      vEky      vEky     vivjô      viv     vivje      viv
# 28      adusi     adusi     adusi  adusisjô   adusis  adusisje   adusis
# 29      flEre     flEre     flEre    flErjô     flEr    flErje     flEr
# ..        ...       ...       ...       ...      ...       ...      ...
# 469   partaZe   partaZe   partaZe  partaZjô   partaZ  partaZje   partaZ
# 470    r6Zwêt     r6Zwê     r6Zwê   r6ZwaJô   r6ZwaJ   r6ZwaJe   r6ZwaJ
# 471      lave      lave      lave     lavjô      lav     lavje      lav
# 472     arâZe     arâZe     arâZe    arâZjô     arâZ    arâZje     arâZ
# 473      kule      kule      kule     kuljô      kul     kulje      kul
# 474     ESape     ESape     ESape    ESapjô     ESap    ESapje     ESap
# 475     prEte     prEte     prEte    prEtjô     prEt    prEtje     prEt
# 476      lâgi      lâgi      lâgi   lâgisjô    lâgis   lâgisje    lâgis
# 477    rEpEte    rEpEte    rEpEte   rEpEtjô    rEpEt   rEpEtje    rEpEt
# 478   sypOrte   sypOrte   sypOrte  sypOrtjô   sypOrt  sypOrtje   sypOrt
# 479     iJOre     iJOre     iJOre    iJOrjô     iJOr    iJOrje     iJOr
# 480   prEfEre   prEfEre   prEfEre  prEfErjô   prEfEr  prEfErje   prEfEr
# 481    d6m6re    d6m6re    d6m6re   d6m6rjô    d6m9r   d6m6rje    d6m9r
# 482     Epuze     Epuze     Epuze    Epuzjô     Epuz    Epuzje     Epuz
# 483    diriZe    diriZe    diriZe   diriZjô    diriZ   diriZje    diriZ
# 484    rEzOly    rEzOly    rEzOly  rEzOlvjô   rEzOlv  rEzOlvje   rEzOlv
# 485     admiz      admi      admi   admEtjô    admEt   admEtje    admEt
# 486   rapOrte   rapOrte   rapOrte  rapOrtjô   rapOrt  rapOrtje   rapOrt
# 487      vêky      vêky      vêky     vêkjô      vêk     vêkje      vêk
# 488     pruve     pruve     pruve    pruvjô     pruv    pruvje     pruv
# 489   prOnôse   prOnôse   prOnôse  prOnôsjô   prOnôs  prOnôsje   prOnôs
# 490     kôkly     kôkly     kôkly   kôklyjô    kôkly   kôklyje    kôkly
# 491        sy        sy        sy     saSjô      saS     saSje      saS
# 492     rEste     rEste     rEste    rEstjô     rEst    rEstje     rEst
# 493     El6ve     El6ve     El6ve    El6vjô     ElEv    El6vje     ElEv
# 494      sOve      sOve      sOve     sOvjô      sov     sOvje      sov
# 495      k6ji      k6ji      k6ji      k6jô      k9j      k6je      k9j
# 496     plâte     plâte     plâte    plâtjô     plât    plâtje     plât
# 497     ap6le     ap6le     ap6le    ap6ljô     apEl    ap6lje     apEl
# 498    pOs6de    pOs6de    pOs6de   pOs6djô    pOsEd   pOs6dje    pOsEd
#
#         ps3P     ps3S
# 0    EmErvEj  EmErvEj
# 1         vE       vE
# 2        fiS      fiS
# 3         oz       oz
# 4     rEysis   rEysis
# 5       âfôs     âfôs
# 6        mEl      mEl
# 7     r6fErm   r6fErm
# 8      sypoz    sypoz
# 9      âmErd    âmErd
# 10      bwav     bwav
# 11      asyr     asyr
# 12       lEs      lEs
# 13        py       py
# 14     fatig    fatig
# 15     r6môt    r6môt
# 16       tôb      tôb
# 17     figyr    figyr
# 18       Sas      Sas
# 19    Egzist   Egzist
# 20     dEfil    dEfil
# 21       Ofr      Ofr
# 22    râplis   râplis
# 23     vOmis    vOmis
# 24       mâZ      mâZ
# 25     r6poz    r6poz
# 26      turn     turn
# 27       viv      viv
# 28    adusis   adusis
# 29      flEr     flEr
# ..       ...      ...
# 469   partaZ   partaZ
# 470   r6ZwaJ   r6ZwaJ
# 471      lav      lav
# 472     arâZ     arâZ
# 473      kul      kul
# 474     ESap     ESap
# 475     prEt     prEt
# 476    lâgis    lâgis
# 477    rEpEt    rEpEt
# 478   sypOrt   sypOrt
# 479     iJOr     iJOr
# 480   prEfEr   prEfEr
# 481    d6m9r    d6m9r
# 482     Epuz     Epuz
# 483    diriZ    diriZ
# 484   rEzOlv   rEzOlv
# 485    admEt    admEt
# 486   rapOrt   rapOrt
# 487      vêk      vêk
# 488     pruv     pruv
# 489   prOnôs   prOnôs
# 490    kôkly    kôkly
# 491      saS      saS
# 492     rEst     rEst
# 493     ElEv     ElEv
# 494      sov      sov
# 495      k9j      k9j
# 496     plât     plât
# 497     apEl     apEl
# 498    pOsEd    pOsEd
#
# [499 rows x 52 columns]

# %%
def compareGOLD(row):
    ligne=[]
    lexical=True
    for case in casesTotales:
#        print (case, row)
        if not case in row:
            ligne.append(u"%s : Ø ≠ %s" % (case,GOLD[GOLD["lexeme"]==row["lexeme"]][case].item()))
            lexical=False
        elif row[case]==GOLD[GOLD["lexeme"]==row["lexeme"]][case].item():
            ligne.append(u"%s : %s" % (case,row[case]))
        else:
            ligne.append(u"%s : %s ≠ %s" % (case, row[case],GOLD[GOLD["lexeme"]==row["lexeme"]][case].item()))
            lexical=False
    if lexical:
        print (row["lexeme"], "OK")
    else:
        print (row["lexeme"], "DIFF")
        print (", ".join(ligne))
    print ()

# %%
paradigmes
# Out:
#            lexeme ai1S ai2S ai3P    ai3S       fi1P  fi1S  fi2P  fi2S  fi3P  \
# 0        abaisser  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 1      abandonner  NaN  NaN  NaN     NaN  abâdòn6rô   NaN   NaN   NaN   NaN
# 2         abattre  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 3         aboutir  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 4         abriter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 5         abréger  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 6        accepter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 7      accommoder  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 8     accompagner  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 9       accomplir  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 10       accorder  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 11      accrocher  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 12     accueillir  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 13      accumuler  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 14        accuser  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 15        acheter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 16        achever  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 17        adapter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 18      adjoindre  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 19       admettre  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 20        admirer  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 21        adopter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 22         adorer  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 23        adoucir  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 24       adresser  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 25      affaisser  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 26       affecter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 27       affirmer  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 28       affliger  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 29      affronter  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# ...           ...  ...  ...  ...     ...        ...   ...   ...   ...   ...
# 976      éloigner  NaN  NaN  NaN  èlwaJa        NaN   NaN   NaN   NaN   NaN
# 977       émacier  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 978      émailler  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 979     émanciper  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 980       émerger  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 981   émerveiller  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 982      émouvoir  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 983       énerver  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 984      épargner  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
# 985        épater  NaN  NaN  NaN     NaN        NaN   NaN   NaN   NaN   NaN
#
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10    akOrd
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24    adrEs
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ...     ...
# 976     NaN
# 977     NaN
# 978     NaN
# 979     NaN
# 980     NaN
# 981     NaN
# 982     NaN
# 983     NaN
# 984     NaN
# 985     NaN
# 986     NaN
# 987     NaN
# 988     NaN
# 989     NaN
# 990     NaN
# 991     NaN
# 992     NaN
# 993     NaN
# 994     NaN
# 995     NaN
# 996     NaN
# 997     NaN
# 998     NaN
# 999     NaN
# 1000    NaN
# 1001    NaN
# 1002    NaN
# 1003    NaN
# 1004    swa
# 1005    NaN
#
# [1006 rows x 47 columns]

# %%
paradigmesCLIQUES.apply(compareGOLD,axis=1)
# Out:
# boire OK
#
# avoir OK
#
# avoir DIFF
# inf : ave ≠ avwar, pi1S : av ≠ E, pi2S : av ≠ a, pi3S : av ≠ a, pi1P : avô, pi2P : ave, pi3P : av ≠ ô, ii1S : avE, ii2S : avE, ii3S : avE, ii1P : avjô, ii2P : avje, ii3P : avE, fi1S : av6rE ≠ OrE, fi2S : av6ra ≠ Ora, fi3S : av6ra ≠ Ora, fi1P : av6rô ≠ Orô, fi2P : av6re ≠ Ore, fi3P : av6rô ≠ Orô, pI2S : av ≠ E, pI1P : avô ≠ Ejô, pI2P : ave ≠ Eje, ps1S : av ≠ E, ps2S : av ≠ E, ps3S : av ≠ E, ps1P : avjô ≠ Ejô, ps2P : avje ≠ Eje, ps3P : av ≠ E, pc1S : av6rE ≠ OrE, pc2S : av6rE ≠ OrE, pc3S : av6rE ≠ OrE, pc1P : av6rjô ≠ Orjô, pc2P : av6rje ≠ Orje, pc3P : av6rE ≠ OrE, pP : avâ ≠ Ejâ, ppMS : ave ≠ y, ppMP : ave ≠ y, ppFS : ave ≠ y, ppFP : ave ≠ y, ai1S : avE ≠ y, ai2S : ava ≠ y, ai3S : ava ≠ y, ai1P : avam ≠ ym, ai2P : avat ≠ yt, ai3P : avEr ≠ yr, is1S : avas ≠ ys, is2S : avas ≠ ys, is3S : ava ≠ y, is1P : avasjô ≠ ysjô, is2P : avasje ≠ ysje, is3P : avas ≠ ys
#
# aller DIFF
# inf : ale, pi1S : al ≠ vE, pi2S : al ≠ va, pi3S : al ≠ va, pi1P : alô, pi2P : ale, pi3P : al ≠ vô, ii1S : alE, ii2S : alE, ii3S : alE, ii1P : aljô, ii2P : alje, ii3P : alE, fi1S : al6rE ≠ irE, fi2S : al6ra ≠ ira, fi3S : al6ra ≠ ira, fi1P : al6rô ≠ irô, fi2P : al6re ≠ ire, fi3P : al6rô ≠ irô, pI2S : al ≠ va, pI1P : alô, pI2P : ale, ps1S : al ≠ aj, ps2S : al ≠ aj, ps3S : al ≠ aj, ps1P : aljô, ps2P : alje, ps3P : al ≠ aj, pc1S : al6rE ≠ irE, pc2S : al6rE ≠ irE, pc3S : al6rE ≠ irE, pc1P : al6rjô ≠ irjô, pc2P : al6rje ≠ irje, pc3P : al6rE ≠ irE, pP : alâ, ppMS : ale, ppMP : ale, ppFS : ale, ppFP : ale, ai1S : alE, ai2S : ala, ai3S : ala, ai1P : alam, ai2P : alat, ai3P : alEr, is1S : alas, is2S : alas, is3S : ala, is1P : alasjô, is2P : alasje, is3P : alas
#
# aller OK
#
# manger OK
#
# aller DIFF
# inf : aje ≠ ale, pi1S : aj ≠ vE, pi2S : aj ≠ va, pi3S : aj ≠ va, pi1P : ajô ≠ alô, pi2P : aje ≠ ale, pi3P : aj ≠ vô, ii1S : ajE ≠ alE, ii2S : ajE ≠ alE, ii3S : ajE ≠ alE, ii1P : ajô ≠ aljô, ii2P : aje ≠ alje, ii3P : ajE ≠ alE, fi1S : aj6rE ≠ irE, fi2S : aj6ra ≠ ira, fi3S : aj6ra ≠ ira, fi1P : aj6rô ≠ irô, fi2P : aj6re ≠ ire, fi3P : aj6rô ≠ irô, pI2S : aj ≠ va, pI1P : ajô ≠ alô, pI2P : aje ≠ ale, ps1S : aj, ps2S : aj, ps3S : aj, ps1P : ajô ≠ aljô, ps2P : aje ≠ alje, ps3P : aj, pc1S : aj6rE ≠ irE, pc2S : aj6rE ≠ irE, pc3S : aj6rE ≠ irE, pc1P : aj6rjô ≠ irjô, pc2P : aj6rje ≠ irje, pc3P : aj6rE ≠ irE, pP : ajâ ≠ alâ, ppMS : aje ≠ ale, ppMP : aje ≠ ale, ppFS : aje ≠ ale, ppFP : aje ≠ ale, ai1S : ajE ≠ alE, ai2S : aja ≠ ala, ai3S : aja ≠ ala, ai1P : ajam ≠ alam, ai2P : ajat ≠ alat, ai3P : ajEr ≠ alEr, is1S : ajas ≠ alas, is2S : ajas ≠ alas, is3S : aja ≠ ala, is1P : ajasjô ≠ alasjô, is2P : ajasje ≠ alasje, is3P : ajas ≠ alas
#
# dormir DIFF
# inf : dOrme ≠ dOrmir, pi1S : dOrm ≠ dOr, pi2S : dOrm ≠ dOr, pi3S : dOrm ≠ dOr, pi1P : dOrmô, pi2P : dOrme, pi3P : dOrm, ii1S : dOrmE, ii2S : dOrmE, ii3S : dOrmE, ii1P : dOrmjô, ii2P : dOrmje, ii3P : dOrmE, fi1S : dOrm6rE ≠ dOrmirE, fi2S : dOrm6ra ≠ dOrmira, fi3S : dOrm6ra ≠ dOrmira, fi1P : dOrm6rô ≠ dOrmirô, fi2P : dOrm6re ≠ dOrmire, fi3P : dOrm6rô ≠ dOrmirô, pI2S : dOrm ≠ dOr, pI1P : dOrmô, pI2P : dOrme, ps1S : dOrm, ps2S : dOrm, ps3S : dOrm, ps1P : dOrmjô, ps2P : dOrmje, ps3P : dOrm, pc1S : dOrm6rE ≠ dOrmirE, pc2S : dOrm6rE ≠ dOrmirE, pc3S : dOrm6rE ≠ dOrmirE, pc1P : dOrm6rjô ≠ dOrmirjô, pc2P : dOrm6rje ≠ dOrmirje, pc3P : dOrm6rE ≠ dOrmirE, pP : dOrmâ, ppMS : dOrme ≠ dOrmi, ppMP : dOrme ≠ nan, ppFS : dOrme ≠ nan, ppFP : dOrme ≠ nan, ai1S : dOrmE ≠ dOrmi, ai2S : dOrma ≠ dOrmi, ai3S : dOrma ≠ dOrmi, ai1P : dOrmam ≠ dOrmim, ai2P : dOrmat ≠ dOrmit, ai3P : dOrmEr ≠ dOrmir, is1S : dOrmas ≠ dOrmis, is2S : dOrmas ≠ dOrmis, is3S : dOrma ≠ dOrmi, is1P : dOrmasjô ≠ dOrmisjô, is2P : dOrmasje ≠ dOrmisje, is3P : dOrmas ≠ dOrmis
irjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
#
# dormir DIFF
# inf : dOrmEtr ≠ dOrmir, pi1S : nan ≠ dOr, pi2S : nan ≠ dOr, pi3S : nan ≠ dOr, pi1P : dOrmEtô ≠ dOrmô, pi2P : dOrmEte ≠ dOrme, pi3P : dOrmEt ≠ dOrm, ii1S : dOrmEtE ≠ dOrmE, ii2S : dOrmEtE ≠ dOrmE, ii3S : dOrmEtE ≠ dOrmE, ii1P : dOrmEtjô ≠ dOrmjô, ii2P : dOrmEtje ≠ dOrmje, ii3P : dOrmEtE ≠ dOrmE, fi1S : dOrmEtrE ≠ dOrmirE, fi2S : dOrmEtra ≠ dOrmira, fi3S : dOrmEtra ≠ dOrmira, fi1P : dOrmEtrô ≠ dOrmirô, fi2P : dOrmEtre ≠ dOrmire, fi3P : dOrmEtrô ≠ dOrmirô, pI2S : nan ≠ dOr, pI1P : dOrmEtô ≠ dOrmô, pI2P : dOrmEte ≠ dOrme, ps1S : dOrmEt ≠ dOrm, ps2S : dOrmEt ≠ dOrm, ps3S : dOrmEt ≠ dOrm, ps1P : dOrmEtjô ≠ dOrmjô, ps2P : dOrmEtje ≠ dOrmje, ps3P : dOrmEt ≠ dOrm, pc1S : dOrmEtrE ≠ dOrmirE, pc2S : dOrmEtrE ≠ dOrmirE, pc3S : dOrmEtrE ≠ dOrmirE, pc1P : dOrmEtriô ≠ dOrmirjô, pc2P : dOrmEtrie ≠ dOrmirje, pc3P : dOrmEtrE ≠ dOrmirE, pP : dOrmEtâ ≠ dOrmâ, ppMS : dOrmi, ppMP : dOrmi ≠ nan, ppFS : dOrmiz ≠ nan, ppFP : dOrmiz ≠ nan, ai1S : dOrmi, ai2S : dOrmi, ai3S : dOrmi, ai1P : dOrmim, ai2P : dOrmit, ai3P : dOrmir, is1S : dOrmis, is2S : dOrmis, is3S : dOrmi, is1P : dOrmisjô, is2P : dOrmisje, is3P : dOrmis
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-8b4bb0147b34> in <module>()
# ----> 1 paradigmesCLIQUES.apply(compareGOLD,axis=1)
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    3716                     if reduce is None:
#    3717                         reduce = True
# -> 3718                     return self._apply_standard(f, axis, reduce=reduce)
#    3719             else:
#    3720                 return self._apply_broadcast(f, axis)
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    3768                 labels = self._get_agg_axis(axis)
#    3769                 result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 3770                                     labels=labels)
#    3771                 return Series(result, index=labels)
#    3772             except Exception:
#
# pandas/src/reduce.pyx in pandas.lib.reduce (pandas/lib.c:41385)()
#
# pandas/src/reduce.pyx in pandas.lib.Reducer.get_result (pandas/lib.c:31188)()
#
# <ipython-input-29-d82c2a0bb47a> in compareGOLD(row)
#      10             ligne.append(u"%s : %s" % (case,row[case]))
#      11         else:
# ---> 12             ligne.append(u"%s : %s ≠ %s" % (case, row[case],GOLD[GOLD["lexeme"]==row["lexeme"]][case].item()))
#      13             lexical=False
#      14     if lexical:
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1789         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1790             # either boolean or fancy integer index
# -> 1791             return self._getitem_array(key)
#    1792         elif isinstance(key, DataFrame):
#    1793             return self._getitem_frame(key)
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    1831             key = check_bool_indexer(self.index, key)
#    1832             indexer = key.nonzero()[0]
# -> 1833             return self.take(indexer, axis=0, convert=False)
#    1834         else:
#    1835             indexer = self.ix._convert_to_indexer(key, axis=1)
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in take(self, indices, axis, convert, is_copy)
#    1356         new_data = self._data.take(indices,
#    1357                                    axis=self._get_block_manager_axis(axis),
# -> 1358                                    convert=True, verify=True)
#    1359         result = self._constructor(new_data).__finalize__(self)
#    1360
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in take(self, indexer, axis, verify, convert)
#    3273         new_labels = self.axes[axis].take(indexer)
#    3274         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 3275                                     axis=axis, allow_dups=True)
#    3276
#    3277     def merge(self, other, lsuffix='', rsuffix=''):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3164         new_axes = list(self.axes)
#    3165         new_axes[axis] = new_axis
# -> 3166         return self.__class__(new_blocks, new_axes)
#    3167
#    3168     def _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple=None):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2180         self._consolidate_check()
#    2181
# -> 2182         self._rebuild_blknos_and_blklocs()
#    2183
#    2184     def make_empty(self, axes=None):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _rebuild_blknos_and_blklocs(self)
#    2268             rl = blk.mgr_locs
#    2269             new_blknos[rl.indexer] = blkno
# -> 2270             new_blklocs[rl.indexer] = np.arange(len(rl))
#    2271
#    2272         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
paradigmesGOLD
# Out:
#              lexeme        ai1S        ai2S         ai3P        ai3S  \
# 0          abaisser       abEsE       abEsa       abEsEr       abEsa
# 1        abandonner     abâdOnE     abâdOna     abâdOnEr     abâdOna
# 2        abasourdir    abazurdi    abazurdi    abazurdir    abazurdi
# 3           abattre       abati       abati       abatir       abati
# 4           abcéder      absEdE      absEda      absEdEr      absEda
# 5          abdiquer      abdikE      abdika      abdikEr      abdika
# 6          abecquer       abEkE       abEka       abEkEr       abEka
# 7           aberrer       abErE       abEra       abErEr       abEra
# 8          abhorrer       abOrE       abOra       abOrEr       abOra
# 9           abjurer      abZyrE      abZyra      abZyrEr      abZyra
# 10          ablater      ablatE      ablata      ablatEr      ablata
# 11          ablatir      ablati      ablati      ablatir      ablati
# 12         abloquer      ablOkE      ablOka      ablOkEr      ablOka
# 13           abolir       abOli       abOli       abOlir       abOli
# 14          abonder       abôdE       abôda       abôdEr       abôda
# 15          abonner       abOnE       abOna       abOnEr       abOna
# 16          abonnir       abOni       abOni       abOnir       abOni
# 17          aborder      abOrdE      abOrda      abOrdEr      abOrda
# 18          aborner      abOrnE      abOrna      abOrnEr      abOrna
# 19         aboucher       abuSE       abuSa       abuSEr       abuSa
# 20          abouler       abulE       abula       abulEr       abula
# 21          abouter       abutE       abuta       abutEr       abuta
# 22          aboutir       abuti       abuti       abutir       abuti
# 23           aboyer      abwajE      abwaja      abwajEr      abwaja
# 24          abraser      abrazE      abraza      abrazEr      abraza
# 25         abreuver      abr6vE      abr6va      abr6vEr      abr6va
# 26        abricoter    abrikOtE    abrikOta    abrikOtEr    abrikOta
# 27          abriter      abritE      abrita      abritEr      abrita
# 28          abroger      abrOZE      abrOZa      abrOZEr      abrOZa
# 29          abrutir      abryti      abryti      abrytir      abryti
# ...             ...         ...         ...          ...         ...
# 6531      étreindre      EtrEJi      EtrEJi      EtrEJir      EtrEJi
# 6532       étrenner      EtrEnE      EtrEna      EtrEnEr      EtrEna
# 6533       étriller      EtrijE      Etrija      EtrijEr      Etrija
# 6534        étriper      EtripE      Etripa      EtripEr      Etripa
# 6535       étriquer      EtrikE      Etrika      EtrikEr      Etrika
# 6536        étrécir      EtrEsi      EtrEsi      EtrEsir      EtrEsi
# 6537  étrésillonner  EtrEzijOnE  EtrEzijOna  EtrEzijOnEr  EtrEzijOna
# 6538        étudier      EtydjE      Etydja      EtydjEr      Etydja
# 6539         étuver       EtyvE       Etyva       EtyvEr       Etyva
# 6540         étêter       EtEtE       EtEta       EtEtEr       EtEta
# 6541        évacuer      EvakyE      Evakya      EvakyEr      Evakya
# 6542         évader       EvadE       Evada       EvadEr       Evada
# 6543        évaluer      EvalyE      Evalya      EvalyEr      Evalya
# 6544    évangéliser   EvâZElizE   EvâZEliza   EvâZElizEr   EvâZEliza
# 6545       évanouir      Evanui      Evanui      Evanuir      Evanui
# 6546       évaporer     EvapOrE     EvapOra     EvapOrEr     EvapOra
# 6547         évaser       EvazE       Evaza       EvazEr       Evaza
# 5       ...          abdike      abdike      abdike      abdike      abdikjô
# 6       ...           abEke       abEke       abEke       abEke       abEkjô
# 7       ...             NaN         NaN         NaN       abEre       abErjô
# 8       ...           abOre       abOre       abOre       abOre       abOrjô
# 9       ...          abZyre      abZyre      abZyre      abZyre      abZyrjô
# 10      ...          ablate      ablate      ablate      ablate      ablatjô
# 11      ...          ablati      ablati      ablati      ablati    ablatisjô
# 12      ...          ablOke      ablOke      ablOke      ablOke      ablOkjô
# 13      ...           abOli       abOli       abOli       abOli     abOlisjô
# 14      ...             NaN         NaN         NaN       abôde       abôdjô
# 15      ...           abOne       abOne       abOne       abOne       abOnjô
# 16      ...           abOni       abOni       abOni       abOni     abOnisjô
# 17      ...          abOrde      abOrde      abOrde      abOrde      abOrdjô
# 18      ...          abOrne      abOrne      abOrne      abOrne      abOrnjô
# 19      ...           abuSe       abuSe       abuSe       abuSe       abuSjô
# 20      ...           abule       abule       abule       abule       abuljô
# 21      ...           abute       abute       abute       abute       abutjô
# 22      ...             NaN         NaN         NaN       abuti     abutisjô
# 23      ...             NaN         NaN         NaN      abwaje       abwajô
# 24      ...          abraze      abraze      abraze      abraze      abrazjô
# 25      ...          abr6ve      abr6ve      abr6ve      abr6ve      abr6vjô
# 26      ...        abrikOte    abrikOte    abrikOte    abrikOte    abrikOtjô
# 27      ...          abrite      abrite      abrite      abrite      abritjô
# 28      ...          abrOZe      abrOZe      abrOZe      abrOZe      abrOZjô
# 29      ...          abryti      abryti      abryti      abryti    abrytisjô
# ...     ...             ...         ...         ...         ...          ...
# 6531    ...           Etrêt       Etrêt        Etrê        Etrê       EtrEJô
# 6532    ...          EtrEne      EtrEne      EtrEne      EtrEne      EtrEnjô
# 6533    ...          Etrije      Etrije      Etrije      Etrije       Etrijô
# 6534    ...          Etripe      Etripe      Etripe      Etripe      Etripjô
# 6535    ...          Etrike      Etrike      Etrike      Etrike      Etrikjô
# 6536    ...          EtrEsi      EtrEsi      EtrEsi      EtrEsi    EtrEsisjô
# 6537    ...      EtrEzijOne  EtrEzijOne  EtrEzijOne  EtrEzijOne  EtrEzijOnjô
# 6538    ...          Etydje      Etydje      Etydje      Etydje      Etydijô
# 6539    ...           Etyve       Etyve       Etyve       Etyve       Etyvjô
# 6540    ...           EtEte       EtEte       EtEte       EtEte       EtEtjô
# 6541    ...          Evakye      Evakye      Evakye      Evakye      Evakyjô
# 6542    ...           Evade       Evade       Evade       Evade       Evadjô
# 6543    ...          Evalye      Evalye      Evalye      Evalye      Evalyjô
# 6544    ...       EvâZElize   EvâZElize   EvâZElize   EvâZElize   EvâZElizjô
# 6545    ...          Evanui      Evanui      Evanui      Evanui    Evanuisjô
# 6546    ...         EvapOre     EvapOre     EvapOre     EvapOre     EvapOrjô
# 6547    ...           Evaze       Evaze       Evaze       Evaze       Evazjô
# 6548    ...           EvEje       EvEje       EvEje       EvEje        EvEjô
# 6549    ...           Evâte       Evâte       Evâte       Evâte       Evâtjô
# 6550    ...             NaN         NaN         NaN     Evâtije      Evâtijô
# 6551    ...          Evâtre      Evâtre      Evâtre      Evâtre      Evâtrjô
# 6552    ...         EvErtye     EvErtye     EvErtye     EvErtye     EvErtyjô
# 6553    ...           Evide       Evide       Evide       Evide       Evidjô
# 6554    ...           Evêse       Evêse       Evêse       Evêse       Evêsjô
# 6555    ...         EvisEre     EvisEre     EvisEre     EvisEre     EvisErjô
# 6556    ...           Evite       Evite       Evite       Evite       Evitjô
# 6557    ...             NaN         NaN         NaN      EvOlye      EvOlyjô
# 6558    ...           EvOke       EvOke       EvOke       EvOke       EvOkjô
# 6559    ...             NaN         NaN         NaN         Ete        swajô
# 6560    ...             Ote         Ote         Ote         Ote         Otjô
#
#            ps1S         ps2P       ps2S       ps3P       ps3S
# 0          abEs       abEsje       abEs       abEs       abEs
# 1        abâdOn     abâdOnje     abâdOn     abâdOn     abâdOn
# 2     abazurdis  abazurdisje  abazurdis  abazurdis  abazurdis
# 3          abat       abatje       abat       abat       abat
# 4         absEd      absEdje      absEd      absEd      absEd
# 5         abdik      abdikje      abdik      abdik      abdik
# 6          abEk       abEkje       abEk       abEk       abEk
# 7          abEr       abErje       abEr       abEr       abEr
# 8          abOr       abOrje       abOr       abOr       abOr
# 9         abZyr      abZyrje      abZyr      abZyr      abZyr
# 10        ablat      ablatje      ablat      ablat      ablat
# 11      ablatis    ablatisje    ablatis    ablatis    ablatis
# 12        ablOk      ablOkje      ablOk      ablOk      ablOk
# 13       abOlis     abOlisje     abOlis     abOlis     abOlis
# 14         abôd       abôdje       abôd       abôd       abôd
# 15         abOn       abOnje       abOn       abOn       abOn
# 16       abOnis     abOnisje     abOnis     abOnis     abOnis
# 17        abOrd      abOrdje      abOrd      abOrd      abOrd
# 18        abOrn      abOrnje      abOrn      abOrn      abOrn
# 19         abuS       abuSje       abuS       abuS       abuS
# 20         abul       abulje       abul       abul       abul
# 21         abut       abutje       abut       abut       abut
# 22       abutis     abutisje     abutis     abutis     abutis
# 23         abwa       abwaje       abwa       abwa       abwa
# 24        abraz      abrazje      abraz      abraz      abraz
# 25        abr9v      abr6vje      abr9v      abr9v      abr9v
# 26      abrikOt    abrikOtje    abrikOt    abrikOt    abrikOt
# 27        abrit      abritje      abrit      abrit      abrit
# 28        abrOZ      abrOZje      abrOZ      abrOZ      abrOZ
# 29      abrytis    abrytisje    abrytis    abrytis    abrytis
# ...         ...          ...        ...        ...        ...
# 6531      EtrEJ       EtrEJe      EtrEJ      EtrEJ      EtrEJ
# 6532      EtrEn      EtrEnje      EtrEn      EtrEn      EtrEn
# 6533      Etrij       Etrije      Etrij      Etrij      Etrij
# 6534      Etrip      Etripje      Etrip      Etrip      Etrip
# 6535      Etrik      Etrikje      Etrik      Etrik      Etrik
# 6536    EtrEsis    EtrEsisje    EtrEsis    EtrEsis    EtrEsis
# 6537  EtrEzijOn  EtrEzijOnje  EtrEzijOn  EtrEzijOn  EtrEzijOn
# 6538      Etydi      Etydije      Etydi      Etydi      Etydi
# 6539       Etyv       Etyvje       Etyv       Etyv       Etyv
# 6540       EtEt       EtEtje       EtEt       EtEt       EtEt
# 6541      Evaky      Evakyje      Evaky      Evaky      Evaky
# 6542       Evad       Evadje       Evad       Evad       Evad
# 6543      Evaly      Evalyje      Evaly      Evaly      Evaly
# 6544   EvâZEliz   EvâZElizje   EvâZEliz   EvâZEliz   EvâZEliz
# 6545    Evanuis    Evanuisje    Evanuis    Evanuis    Evanuis
# 6546     EvapOr     EvapOrje     EvapOr     EvapOr     EvapOr
# 6547       Evaz       Evazje       Evaz       Evaz       Evaz
# 6548       EvEj        EvEje       EvEj       EvEj       EvEj
# 6549       Evât       Evâtje       Evât       Evât       Evât
# 6550     Evâtij      Evâtije     Evâtij     Evâtij     Evâtij
# 6551      Evâtr      Evâtrje      Evâtr      Evâtr      Evâtr
# 6552     EvErty     EvErtyje     EvErty     EvErty     EvErty
# 6553       Evid       Evidje       Evid       Evid       Evid
# 6554       Evês       Evêsje       Evês       Evês       Evês
# 6555     EvisEr     EvisErje     EvisEr     EvisEr     EvisEr
# 6556       Evit       Evitje       Evit       Evit       Evit
# 6557      EvOly      EvOlyje      EvOly      EvOly      EvOly
# 6558       EvOk       EvOkje       EvOk       EvOk       EvOk
# 6559        swa        swaje        swa        swa        swa
# 6560         ot         Otje         ot         ot         ot
#
# [6561 rows x 47 columns]

# %%
paradigmesGOLD.loc[paradigmesGOLD["lexeme"]=="boire"]["inf"]
# Out:
# 627    bwar
# Name: inf, dtype: object

# %% [markdown]
# ##Faire un tableau XML pour la sortie des cliques

# %% [markdown]
# class tableauParadigme:
#     '''
#     Gestion des tableaux de flexion
#     '''
#
#     def __init__(self):
#         self.paradigme={}
#         self.lexeme=""
#
#     def ajouterElement(self,element):
#         (lexeme,forme,taminfo)=element.split("-")
#         if self.lexeme=="":
#             self.lexeme=lexeme
#         if self.lexeme==lexeme:
#             if len(taminfo)==4:
#                 (tense,mode,pers,num)=taminfo
#             elif taminfo=="inf":
#                 (tense,mode,pers,num)=("",taminfo,"","")
#
#             elif taminfo=="pP":
#                 (tense,mode,pers,num)=("p","part","","")
#             else:
#                 print("erreur case",element,file=logfile)
#             if not mode in self.paradigme:
#                 self.paradigme[mode]={}
#             if not tense in self.paradigme[mode]:
#                 self.paradigme[mode][tense]={}
#             if not pers+num in self.paradigme[mode][tense]:
#                 self.paradigme[mode][tense][pers+num]=[]
#             self.paradigme[mode][tense][pers+num].append(forme)

# %% [markdown]
# seuilClique=25
#
# for n,clique in enumerate(sorted(cliques,key=lambda x: len(x),reverse=True)):
#     if len(clique)>seuilClique:
#         print (n, len(clique))
#         tabParadigme=tableauParadigme()
#         for element in clique:
#             tabParadigme.ajouterElement(element)
#         for mode in ["i","s","c","I"]:
#             for tense in tabParadigme.paradigme[mode]:
#                 if mode=="I":
#                     for pers in ["2S", "1P", "2P"]:
#                         print ("-".join(tabParadigme.paradigme[mode][tense][pers]), end=", ")
#                 else:
#                     for pers in [str(i+1)+"S" for i in range(3)]+[str(i+1)+"P" for i in range(3)]:
#                         print ("-".join(tabParadigme.paradigme[mode][tense][pers]), end=", ")
#                 print()

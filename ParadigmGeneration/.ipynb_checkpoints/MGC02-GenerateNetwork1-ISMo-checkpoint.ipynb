# %% [markdown]
# # Génération des réseaux de formes à partir des règles
# - Gén-1 : génération des formes à partir de l'échantillon lexical
# - Gén-2 : génération du réseau orienté à partir de Gén-1
# - Filt-1 : extraction du sous-réseau symétrique
# - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
# - Filt-3 : extraction des cliques maximales

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
import yaml

# %%
from ipywidgets import FloatProgress
from IPython.display import display, HTML

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %% [markdown]
# # Choix de l'échantillon et des règles
# - *sampleFile* est le nom de l'échantillon de départ
# - *analysisPrefix* est une partie du nom des règles

# %%
filePrefix="/Users/gilles/Box Sync/2015-Data/MGC-170330"
filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/MGC-170330"
sampleNumber="19-100Ko"
sampleType="N"
casesType="-Morphomes"
paperPrefix="-ISMo"
genFormeVotes=True
genCliques=True
listeFormesOutput=["FS","FP"]
genDigraphe=True
genGraphe=True
samplePrefix=filePrefix+"-%s-%s"%(sampleNumber,sampleType)+casesType
sampleFile=samplePrefix+"-paradigmes.csv"
analysisPrefix=samplePrefix
logfile_name=analysisPrefix+"-network.log"
logfile = codecs.open(logfile_name,mode='w',encoding="utf8")

# %% [markdown]
# ### Préparation des cases du paradigme

# %% [raw]
# casesPrincipales= [
#         'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
#         'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P',
#         'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
#         'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
#         'ps2P', 'ps3P',
#         'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
#         'ppMS', 'ppMP', 'ppFS', 'ppFP'
#             ]
# casesSecondaires= [
#        'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
#             ]
# casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print ("le numéro de forme n'est pas dans [1,2]",n,file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print (forme, file=logfile) 
            print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %% [raw]
# def OLDrapports(paradigme):
#     (case1,case2,lexeme)= paradigme.columns.values.tolist()
#     patrons=pairePatrons(case1,case2)
#     if len(paradigme)>0:
# #        for index, row in paradigme.iterrows():
# #            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
#         paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
#         (regles1,regles2)=patrons.calculerGM()
#     return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmes=pd.read_csv(sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
paradigmes=paradigmes.dropna(axis=1,how='all')

# %%
phonologicalMap=sampleType
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [raw]
# GOLD=pd.read_csv("2015-Data/"+goldFile,sep=";",encoding="utf8")
# del GOLD[u"Unnamed: 0"]
# goldCases=GOLD.columns.tolist()
# goldCases.remove(u"lexeme")
# for case in goldCases:
#     GOLD[case]=GOLD[case].apply(lambda x: recoder(x))
#
# paradigmesGOLD=GOLD[paradigmes.columns.values.tolist()]
# #paradigmesGOLD

# %%
goldCases=paradigmes.columns.tolist()
goldCases.remove("lexeme")
#goldCases

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")
#sampleCases

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 17249

# %%
with open(analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ### Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(goldCases):
    print ("Attention l'analyse ne comprend pas toutes les cases")
    print (sorted(analyseCases))
    print (sorted(goldCases))

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %%
def generate(lexeme,genDigraphe=True):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
len(paradigmes.dropna(thresh=1)["lexeme"])
# Out:
# 3108

# %%
#paradigmes
#analyseCases
lexeme=u"découper"
paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
# Out:
# [u'lexeme',
#  u'ii1S',
#  u'inf',
#  u'pP',
#  u'pi1S',
#  u'pi2S',
#  u'pi3P',
#  u'ppFP',
#  u'ppMP']

# %%
paradigmes.dropna(thresh=1).count().sum()-paradigmes.dropna(thresh=1)["lexeme"].count()
# Out:
# 14141

# %% [markdown]
# #### Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    if len(clique)>1:
        for (depart,arrivee) in it.combinations_with_replacement(clique,2):
            score+=graph[depart][arrivee]["weight"]
    return score

# %%
def splitArrivee(arrivee):
    arriveeMorceaux=arrivee.split("-")
    lexeme="-".join(arriveeMorceaux[:-2])
    formeArrivee=arriveeMorceaux[-2]
    caseArrivee=arriveeMorceaux[-1]
    return (lexeme,formeArrivee,caseArrivee)
    
# trouver tous les liens vers FS-* et FP-*
# regrouper par forme 
# calculer les proportions
# renvoyer les proportions par forme
# avec le nombre de forme à l'appui
def formeScore(forme,graph):
    scores={}
    scoresNormes={}
    for depart in graph.edge:
        for arrivee in graph.edge[depart]:
            (lexeme, formeArrivee, caseArrivee)=splitArrivee(arrivee)
            if caseArrivee==forme:
#                print (depart, formeArrivee, graph.edge[depart][arrivee])
                if not formeArrivee in scores:
                    scores[formeArrivee]=0
                scores[formeArrivee]+=graph.edge[depart][arrivee]["weight"]
    totalArrivee=0
    for formeArrivee in scores:
        totalArrivee+=scores[formeArrivee]
    for formeArrivee in scores:
        scoresNormes[formeArrivee]=scores[formeArrivee]/totalArrivee
    return (scores,scoresNormes)

# %% [markdown]
# ## Génération des formes

# %%
#%%time
debug=False
listeTest=paradigmes.dropna(thresh=1)["lexeme"].values.tolist()
listeTest=[u"abaisser",u"aboutir",u"abuser",u"accoucher",u"acquiescer",u"acquérir",u"adapter",
           u"administrer",u"affaiblir",u"agenouiller",u"alléger",u"amasser",u"amorcer",u"amplifier",
           u"amputer",u"angoisser",u"appareiller",u"assaillir",u"assombrir",u"attiser",u"attrister",
           u"baser",u"bluffer",u"blâmer",u"botter",u"bousculer",u"branler",u"cambrer",u"chagriner",
           u"chanceler",u"charmer",u"chevaucher",u"choper",u"cligner",u"collaborer",u"compenser",
           u"compléter",u"concevoir",u"confiner",u"consister",u"contester",u"coopérer",u"copier",
           u"corriger",u"courber",u"couronner",u"crisper",u"croquer",u"cultiver",u"dicter",u"diffuser",
           u"digérer",u"diviser",u"doucher",u"draguer",u"droguer",u"débiter",u"déboucher",u"débuter",
           u"déchiffrer",u"déconner",u"décorer",u"dégonfler",u"délaisser",u"délier",u"délirer",
           u"démolir",u"démontrer",u"démêler",u"dépouiller",u"déraper",u"déserter",u"désespérer",
           u"déshonorer",u"détecter",u"déterminer",u"dévaler",u"développer",u"dévoiler",u"effleurer",
           u"effriter",u"embaumer",u"embraser",u"empoisonner",u"emprisonner",u"encadrer",u"encaisser",
           u"encombrer",u"enflammer",u"engraisser",u"engueuler",u"entraver",u"exploiter",u"extraire",
           u"faciliter",u"faucher",u"feuilleter",u"financer",u"flairer",u"fouetter",u"fouler",
           u"fracasser",u"frayer",u"freiner",u"garnir",u"gaspiller",u"glorifier",u"grommeler",u"grouper",
           u"gémir",u"haver",u"hisser",u"hérisser",u"illustrer",u"improviser",u"inaugurer",u"incruster",
           u"infiltrer",u"influencer",u"injecter",u"inspecter",u"intercepter",u"intimider",u"intituler",
           u"investir",u"joncher",u"lisser",u"lorgner",u"louper",u"marteler",u"maudire",u"maîtriser",
           u"mijoter",u"minauder",u"mouler",u"muer",u"méditer",u"mélanger",u"nager",u"naviguer",
           u"obliquer",u"obséder",u"offenser",u"orienter",u"parfaire",u"passionner",u"patauger",u"pavoiser",
           u"percuter",u"photographier",u"picoler",u"piger",u"piloter",u"piéger",u"plisser",u"pressentir",
           u"priser",u"prodiguer",u"profiler",u"progresser",u"provenir",u"préserver",u"présumer",u"puiser",
           u"quadriller",u"racler",u"rajuster",u"rallier",u"rallumer",u"ramer",u"ravaler",u"rebondir",
           u"rebrousser",u"reconstituer",u"refiler",u"relancer",u"relater",u"relayer",u"remporter",
           u"remémorer",u"rendormir",u"reparaître",u"repeindre",u"reproduire",u"restituer",u"retapisser",
           u"retentir",u"revendre",u"revivre",u"rhabiller",u"rincer",u"ronfler",u"ruer",u"ruminer",
           u"répliquer",u"répugner",u"résulter",u"scandaliser",u"scruter",u"simplifier",u"superposer",
           u"surmonter",u"survenir",u"séduire",u"tacher",u"tamponner",u"tapir",u"tapoter",u"terrasser",
           u"tolérer",u"tortiller",u"transmettre",u"tricher",u"trier",u"trimballer",u"trimer",u"trotter",
           u"trouer",u"trébucher",u"vaincre",u"vouer",u"vêtir",u"ébaucher",u"éblouir",u"éclaircir",
           u"écouler",u"égaler",u"égorger",u"éliminer",u"émerger",u"émerveiller",u"émettre",u"émouvoir",
           "épaissir",u"éponger",u"évaluer"]
listeTest=[u"corriger",u"résulter",u"émerger",u"injecter","concevoir","collaborer",u"coopérer",u"méditer"]
listeTest=[u"coopérer"]
nbVerbes=len(listeTest)
print (nbVerbes)
globDigraphe=nx.DiGraph()
globGraphe=nx.Graph()
cliques=[]
cliquesScores={}
cliquesListes={}
numClique=0
formesScores={}
formesScoresNormes={}
progressBar = FloatProgress(min=0, max=nbVerbes)
display(progressBar)
for i,element in enumerate(listeTest):
    cliquesScores[element]={}
    cliquesListes[element]={}
#    if (i%100)==0: print (i, dateheure()[-4:], int(100*float(i)/nbVerbes), end=", ")
    progressBar.value=i
    #print (element)
    result=generate(element,genDigraphe)
    (generation,lexDigraphe,lexGraphe,lexCliques)= result
#    print (generation,lexDigraphe,lexGraphe,lexCliques)
    if genFormeVotes:
        formesScores[element]={}
        formesScoresNormes[element]={}
        for formeOutput in listeFormesOutput:
            (formesScores[element][formeOutput],formesScoresNormes[element][formeOutput])=formeScore(formeOutput,lexDigraphe)
    if genDigraphe:
        globDigraphe=nx.union(globDigraphe,lexDigraphe)
    if genGraphe:
        globGraphe=nx.union(globGraphe,lexGraphe)
    cliques.extend(lexCliques)
    for clique in lexCliques:
        cliquesScores[element][numClique]=cliqueScore(clique,lexGraphe)
        cliquesListes[element][numClique]=clique
        numClique+=1
# Out:
# 1

# %%
globDigraphe.edges()
# Out:
# [(u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr-ps1S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEris-pi3P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErise-pi2P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErisE-ii1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErj\xe2-pP'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-pI2S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-ps1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-ppFP'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEris\xe2-pP'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEriz-ppFP'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErje-pi2P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEris-ps1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErise-pI2P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEris\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEris-ai2P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErjE-ii1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-pi2S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-ppMP'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-pi1S'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpEri-pi3P'),
#  (u'coop\xe9rer-kOOpEri-ai2S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr-pi3P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEri-ppFP'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEri-ppMP'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEris-ai2P'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErim-ai1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr9rj\xf4-pc1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEras-ai2P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEram-ai1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr9re-fi2P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEry-ppFP'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEry-ai2S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErre-fi2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr\xe2-pP', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ii1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpErr\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpErre-fi2P'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpErr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErre-fi2P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi3P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEry-ppFP'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEry-ai2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErre-fi2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErE-ii1S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEre-ppFP', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pI1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEre-inf', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEris-ai2P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEri-ppFP'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEriz-ppFP'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEri-ppMP'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpErir-ai3P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErr-inf'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErr\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErre-fi2P'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErr\xf4-fi1P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpEret-ppFP'),
#  (u'coop\xe9rer-kOOpEre-ppMP', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr9ra-fi2S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr9r\xf4-fi1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpErj\xf4-ps1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwaj\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEry-ai1S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwaj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwa-pI2S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEravj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErys-ai2P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErware-fi2P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEtra-fi2S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwaje-ii2P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErE-pi1S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwaj\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErav\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwa-pi2S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErOrje-pc2P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEry-ppFP'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEryr-inf'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEry-ai2S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEsE-ii1S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEtr-inf'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEryv\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwar-inf'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEryr-ai3P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEs\xe2-pP'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErOr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErE-pi2S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEsj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEs-ps1S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEse-pi2P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErym-ai1P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErOr\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEs-pi3P'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpEravwar-inf'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErwa-pi1S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErE-pI2S'),
#  (u'coop\xe9rer-kOOpEry-ppMP', u'coop\xe9rer-kOOpErEtrE-fi1S'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErje-ps2P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr\xf4-pi1P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErje-pi2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErijE-ai1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErije-pi2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErise-pi2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErij\xe2-pP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErj\xe2-pP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErije-ii2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErij\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-pI2S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-ps1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEris-pi3P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErje-ppFP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErij\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-ppFP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEris\xe2-pP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErja-ai2S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEriv\xe2-pP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErje-inf'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErire-fi2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-pi2S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri\xe2-pP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErirj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErise-pI2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErir\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-pi1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErje-ppMP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErirje-pc2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErive-pi2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErije-pI2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErjE-ii1S'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEriv\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-ppMP'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpEri-pi3P'),
#  (u'coop\xe9rer-kOOpErirE-fi1S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErv-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErvi-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdr\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErd\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErt-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErti-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErde-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtir-inf'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtje-ii2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErti-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErt\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdre-fi2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErt-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErde-pi2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErv-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdy-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErd-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtira-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErd-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErti-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdi-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErd\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErtirE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErve-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdir-ai3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErti-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdr-inf'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErvE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErvi-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErdy-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErv\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErd\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr-pI2S', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr9rE-fi1S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErv-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErvi-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdr\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErt\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErd\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErti-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErvi-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErde-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdrE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtir-inf'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtje-ii2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErti-ai1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErt\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdre-fi2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErt-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErde-pi2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErv-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdy-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErd-pi3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtira-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErd-ps1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErti-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErv\xe2-pP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdi-ai2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErd\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErtirE-fi1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErve-pI2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdir-ai3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErti-ppMP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdr-inf'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErvE-ii1S'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErdy-ppFP'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErv\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErd\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEr-pi2S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEry-ppFP'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEry-ai2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErra-fi2S'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErj\xf4-ps1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEre-pI2P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEris-ai2P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEri-ppFP'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEriz-ppFP'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEri-ppMP'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpEri-ai1S', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpErEs-ai2P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr9r\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpEr9r\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErEr-ai3P', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEris-pi3P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErise-pi2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEry-ai1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErisE-ii1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErj\xe2-pP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErije-ii2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErit-ppFP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-pI2S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-ps1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErij\xf4-ii1P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-ppFP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEris\xe2-pP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEry-ppFP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErje-pi2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErire-fi2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEry-ai2S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErir\xf4-fi3P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri\xe2-pP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEris-ps1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErise-pI2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErir\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErjE-ii1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-pi2S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-ppMP'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-pi1S'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEre-pi2P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpEri-pi3P'),
#  (u'coop\xe9rer-kOOpErir-inf', u'coop\xe9rer-kOOpErE-ii1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErje-ii2P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEry-ppMP'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr-pi3P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr-ps1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErE-ai1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr9ra-fi2S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr-pi1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEri-ai2S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErim-ai1P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr\xf4-pi1P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErir-ai3P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr-pI2S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEre-ppFP'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr9rE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr\xf4-pI1P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEra-ai2S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEram-ai1P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEre-inf'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr-pi2S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErirE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr\xe2-pP'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr9re-fi2P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErr\xf4-fi1P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEre-ppMP'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErje-ps2P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEre-pI2P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEri-ai1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErira-fi2S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr9rj\xf4-pc1P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErrE-fi1S'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErEr-ai3P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpEr9rje-pc2P'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErir-inf'),
#  (u'coop\xe9rer-kOOpEre-pi2P', u'coop\xe9rer-kOOpErj\xf4-ii1P'),
#  ...]

# %%
if genFormeVotes:
    fScores=(formesScores,formesScoresNormes)
    with open(analysisPrefix+paperPrefix+'-Scores.pkl', 'wb') as output:
        pickle.dump(fScores, output, pickle.HIGHEST_PROTOCOL)

# %%
# %%time
versionStamp=dateheure()
if genDigraphe and len(listeTest)==1: 
    nx.readwrite.write_gexf(globDigraphe,analysisPrefix+paperPrefix+u"-digraphe-%s.gexf"%versionStamp)
if genGraphe and len(listeTest)==1:
    nx.readwrite.write_gexf(globGraphe,analysisPrefix+paperPrefix+u"-graphe-%s.gexf"%versionStamp)
# Out:
# CPU times: user 62.7 ms, sys: 3.63 ms, total: 66.3 ms
# Wall time: 1.41 s

# %%
print (len(cliques))
# Out:
# 183

# %%
if genCliques:
    infoCliques={"cliques":cliques, "cliquesScores":cliquesScores, "cliquesListes":cliquesListes}
    with open(analysisPrefix+paperPrefix+'-Network.pkl', 'wb') as output:
        pickle.dump(infoCliques, output, pickle.HIGHEST_PROTOCOL)

# %%
lexemeMaxCliques={}
for lexeme in cliquesListes:
    maxLen=max([len(c) for c in cliquesListes[lexeme].values()])
    maxCliques=[c for c in cliquesListes[lexeme].values() if len(c)==maxLen]
    lexemeMaxCliques[lexeme]=(maxLen,maxCliques)

# %%
def dictCliqueForms(clique):
    result={}
    for element in clique:
        lexeme,forme,case=splitArrivee(element)
        result[case]=forme
    return result

def dictPdRowForms(row):
    result={}
    for case in sampleCases:
        print (case,row[case].values[0])
    return result

def tableZero(case):
    if case in sampleCases:
        return u"Ø"
    else:
        return u"="

def makeTable(dictForms,title=""):
    tabular=[]
    labelTenseCode={"pi":"Present","ii":"Imperfective","ai":"Simple Past","fi":"Future",
                    "ps":"Subjunctive Pres.","is":"Subjunctive Imp.","pc":"Conditional","pI":"Imperative",
                    "inf":"Infinitive",
                    "ppMS":"Past Part. MS","ppMP":"Past Part. MP",
                    "ppFS":"Past Part. FS","ppMP":"Past Part. FP"
                   }
    def makeLine6(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            case=tenseCode+person
            if (case in dictForms) and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"

    def makeLine3(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            if person in ["2S","1P","2P"]:
                case=tenseCode+person
                if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                    line.append(r"<td>%s</td>"%(dictForms[case]))
                else:
                    line.append(r"<td>%s</td>"%(tableZero(case)))
            else:
                line.append(r"<td>%s</td>"%(u"---"))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
    def makeLineNF():
        line=[]
        line.append(r"<th>%s</th>"%"NF")
        for case in ["inf","pP","ppMS","ppMP","ppFS","ppFP"]:
            if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
        
    top=[
        r"<table>",
        r"<caption style='caption-side:bottom;text-align:center'>",
        "Verbe : %s"%title,
        r"</caption>",
#        r"<tr><th/><th>1S</th><th>2S</th><th>3S</th><th>1P</th><th>2P</th><th>3P</th></tr>"
        r"<tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>"
        ]
    bottom=[
        r"</table>"
        ]
    tabular.append("\n".join(top))
    for tenseCode in ["pi","ii","fi","pc", "ps","ai", "is"]:
        tabular.append(makeLine6(tenseCode))
    tabular.append(makeLine3("pI"))
    tabular.append(makeLineNF())
    tabular.append("\n".join(bottom))
    return "\n".join(tabular)    

def diffParadigme(lexeme):
    outLen=lexemeMaxCliques[lexeme][0]
    inLen=paradigmes[paradigmes["lexeme"]==lexeme].notnull().sum(axis=1).values[0]-1
    if outLen>inLen:
        print (lexemeMaxCliques[lexeme][1])
        print (paradigmes[paradigmes["lexeme"]=="grandir"].values)
    return outLen-inLen

# %%
for lexeme in lexemeMaxCliques:
    for clique in lexemeMaxCliques[lexeme][1]:
        display(HTML(makeTable(dictCliqueForms(clique),title=lexeme)))
lexeme=u"coopérer"
# Out:
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : méditer
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>mEdit</td><td>mEdit</td><td>=</td><td>mEditô</td><td>mEdite</td><td>mEdit</td></tr>
# <tr><th>Imperfective</th><td>mEditE</td><td>=</td><td>=</td><td>mEditjô</td><td>mEditje</td><td>=</td></tr>
# <tr><th>Future</th><td>mEdit9rE</td><td>mEdit9ra</td><td>=</td><td>Ø</td><td>mEdit9re</td><td>mEdit9rô</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>mEdit</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>mEditE</td><td>mEdita</td><td>=</td><td>Ø</td><td>Ø</td><td>mEditEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>mEdit</td><td>---</td><td>mEditô</td><td>mEdite</td><td>---</td></tr>
# <tr><th>NF</th><td>mEdite</td><td>mEditâ</td><td>=</td><td>mEdite</td><td>=</td><td>mEdite</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : méditer
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>mEdit</td><td>mEdit</td><td>=</td><td>mEditô</td><td>mEdite</td><td>mEdit</td></tr>
# <tr><th>Imperfective</th><td>mEditE</td><td>=</td><td>=</td><td>mEditjô</td><td>mEditje</td><td>=</td></tr>
# <tr><th>Future</th><td>mEdit9rE</td><td>mEdit9ra</td><td>=</td><td>Ø</td><td>mEdit9re</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>mEdit</td><td>=</td><td>=</td><td>Ø</td><td>mEditje</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>mEditE</td><td>mEdita</td><td>=</td><td>Ø</td><td>Ø</td><td>mEditEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>mEdit</td><td>---</td><td>mEditô</td><td>mEdite</td><td>---</td></tr>
# <tr><th>NF</th><td>mEdite</td><td>mEditâ</td><td>=</td><td>mEdite</td><td>=</td><td>mEdite</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : méditer
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>mEdit</td><td>mEdit</td><td>=</td><td>mEditô</td><td>mEdite</td><td>mEdit</td></tr>
# <tr><th>Imperfective</th><td>mEditE</td><td>=</td><td>=</td><td>mEditjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>mEdit9rE</td><td>mEdit9ra</td><td>=</td><td>mEdit9rô</td><td>mEdit9re</td><td>mEdit9rô</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>mEdit</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>mEditE</td><td>mEdita</td><td>=</td><td>Ø</td><td>Ø</td><td>mEditEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>mEdit</td><td>---</td><td>mEditô</td><td>mEdite</td><td>---</td></tr>
# <tr><th>NF</th><td>mEdite</td><td>mEditâ</td><td>=</td><td>mEdite</td><td>=</td><td>mEdite</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : méditer
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>mEdit</td><td>mEdit</td><td>=</td><td>mEditô</td><td>mEdite</td><td>mEdit</td></tr>
# <tr><th>Imperfective</th><td>mEditE</td><td>=</td><td>=</td><td>mEditjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>mEdit9rE</td><td>mEdit9ra</td><td>=</td><td>mEdit9rô</td><td>mEdit9re</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>mEdit</td><td>=</td><td>=</td><td>Ø</td><td>mEditje</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>mEditE</td><td>mEdita</td><td>=</td><td>Ø</td><td>Ø</td><td>mEditEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>mEdit</td><td>---</td><td>mEditô</td><td>mEdite</td><td>---</td></tr>
# <tr><th>NF</th><td>mEdite</td><td>mEditâ</td><td>=</td><td>mEdite</td><td>=</td><td>mEdite</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : résulter
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>rEzylt</td><td>rEzylt</td><td>=</td><td>Ø</td><td>rEzylte</td><td>Ø</td></tr>
# <tr><th>Imperfective</th><td>rEzyltE</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>rEzylt9rE</td><td>rEzylt9ra</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>rEzylt</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>Ø</td><td>rEzylta</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>rEzylt</td><td>---</td><td>Ø</td><td>rEzylte</td><td>---</td></tr>
# <tr><th>NF</th><td>rEzylte</td><td>Ø</td><td>=</td><td>rEzylte</td><td>=</td><td>rEzylte</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : émerger
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>EmErZ</td><td>EmErZ</td><td>=</td><td>EmErZô</td><td>EmErZe</td><td>EmErZ</td></tr>
# <tr><th>Imperfective</th><td>EmErZE</td><td>=</td><td>=</td><td>EmErZjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>EmErZ9rE</td><td>EmErZ9ra</td><td>=</td><td>EmErZ9rô</td><td>EmErZ9re</td><td>EmErZ9rô</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>EmErZ</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>EmErZE</td><td>EmErZa</td><td>=</td><td>EmErZam</td><td>Ø</td><td>EmErZEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>EmErZ</td><td>---</td><td>EmErZô</td><td>EmErZe</td><td>---</td></tr>
# <tr><th>NF</th><td>EmErZe</td><td>EmErZâ</td><td>=</td><td>EmErZe</td><td>=</td><td>EmErZe</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : injecter
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>êZEkt</td><td>êZEkt</td><td>=</td><td>êZEktô</td><td>êZEkte</td><td>êZEkt</td></tr>
# <tr><th>Imperfective</th><td>êZEktE</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>êZEkt9rE</td><td>êZEkt9ra</td><td>=</td><td>Ø</td><td>êZEkt9re</td><td>êZEkt9rô</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>êZEkt</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>êZEktE</td><td>êZEkta</td><td>=</td><td>Ø</td><td>Ø</td><td>êZEktEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>êZEkt</td><td>---</td><td>êZEktô</td><td>êZEkte</td><td>---</td></tr>
# <tr><th>NF</th><td>êZEkte</td><td>êZEktâ</td><td>=</td><td>êZEkte</td><td>=</td><td>êZEkte</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : concevoir
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>kôswa</td><td>kôswa</td><td>=</td><td>Ø</td><td>kôs9ve</td><td>Ø</td></tr>
# <tr><th>Imperfective</th><td>kôs9vE</td><td>=</td><td>=</td><td>kôs9vjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>Ø</td><td>kôs9vra</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>kôswav</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>kôsy</td><td>kôsy</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>kôswa</td><td>---</td><td>Ø</td><td>kôs9ve</td><td>---</td></tr>
# <tr><th>NF</th><td>kôs9vwar</td><td>kôs9vâ</td><td>=</td><td>kôsy</td><td>=</td><td>kôsy</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : concevoir
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>kôswa</td><td>kôswa</td><td>=</td><td>Ø</td><td>kôs9ve</td><td>Ø</td></tr>
# <tr><th>Imperfective</th><td>kôs9vE</td><td>=</td><td>=</td><td>kôs9vjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>Ø</td><td>Ø</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>kôswav</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>kôsy</td><td>kôsy</td><td>=</td><td>Ø</td><td>Ø</td><td>kôsyr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>kôswa</td><td>---</td><td>Ø</td><td>kôs9ve</td><td>---</td></tr>
# <tr><th>NF</th><td>kôs9vwar</td><td>kôs9vâ</td><td>=</td><td>kôsy</td><td>=</td><td>kôsy</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : collaborer
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>kOlabOr</td><td>kOlabOr</td><td>=</td><td>kOlabOrô</td><td>kOlabOre</td><td>kOlabOr</td></tr>
# <tr><th>Imperfective</th><td>kOlabOrE</td><td>=</td><td>=</td><td>kOlabOrjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>kOlabOr9rE</td><td>kOlabOr9ra</td><td>=</td><td>kOlabOr9rô</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>kOlabOr</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>kOlabOrE</td><td>kOlabOra</td><td>=</td><td>kOlabOram</td><td>Ø</td><td>kOlabOrEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>kOlabOr</td><td>---</td><td>kOlabOrô</td><td>kOlabOre</td><td>---</td></tr>
# <tr><th>NF</th><td>kOlabOre</td><td>kOlabOrâ</td><td>=</td><td>kOlabOre</td><td>=</td><td>kOlabOre</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : corriger
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>kOriZ</td><td>kOriZ</td><td>=</td><td>kOriZô</td><td>kOriZe</td><td>kOriZ</td></tr>
# <tr><th>Imperfective</th><td>kOriZE</td><td>=</td><td>=</td><td>kOriZjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>kOriZ9rE</td><td>kOriZ9ra</td><td>=</td><td>kOriZ9rô</td><td>kOriZ9re</td><td>kOriZ9rô</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>kOriZ</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>kOriZE</td><td>kOriZa</td><td>=</td><td>kOriZam</td><td>Ø</td><td>kOriZEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>kOriZ</td><td>---</td><td>kOriZô</td><td>kOriZe</td><td>---</td></tr>
# <tr><th>NF</th><td>kOriZe</td><td>kOriZâ</td><td>=</td><td>kOriZe</td><td>=</td><td>kOriZe</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : corriger
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>kOriZ</td><td>kOriZ</td><td>=</td><td>kOriZô</td><td>kOriZe</td><td>kOriZ</td></tr>
# <tr><th>Imperfective</th><td>kOriZE</td><td>=</td><td>=</td><td>Ø</td><td>kOriZje</td><td>=</td></tr>
# <tr><th>Future</th><td>kOriZ9rE</td><td>kOriZ9ra</td><td>=</td><td>kOriZ9rô</td><td>kOriZ9re</td><td>kOriZ9rô</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>kOriZ9rje</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>kOriZ</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>kOriZE</td><td>kOriZa</td><td>=</td><td>Ø</td><td>Ø</td><td>kOriZEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>kOriZ</td><td>---</td><td>kOriZô</td><td>kOriZe</td><td>---</td></tr>
# <tr><th>NF</th><td>kOriZe</td><td>kOriZâ</td><td>=</td><td>kOriZe</td><td>=</td><td>kOriZe</td></tr>
# </table>
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : coopérer
# </caption>
# <tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>
# <tr><th>Present</th><td>kOOpEr</td><td>kOOpEr</td><td>=</td><td>kOOpErô</td><td>kOOpEre</td><td>kOOpEr</td></tr>
# <tr><th>Imperfective</th><td>kOOpErE</td><td>=</td><td>=</td><td>kOOpErjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>Future</th><td>kOOpEr9rE</td><td>kOOpEr9ra</td><td>=</td><td>kOOpEr9rô</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>Conditional</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Subjunctive Pres.</th><td>kOOpEr</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>Simple Past</th><td>kOOpErE</td><td>kOOpEra</td><td>=</td><td>kOOpEram</td><td>Ø</td><td>kOOpErEr</td></tr>
# <tr><th>Subjunctive Imp.</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>Imperative</th><td>---</td><td>kOOpEr</td><td>---</td><td>kOOpErô</td><td>kOOpEre</td><td>---</td></tr>
# <tr><th>NF</th><td>kOOpEre</td><td>kOOpErâ</td><td>=</td><td>kOOpEre</td><td>=</td><td>kOOpEre</td></tr>
# </table>

# %%
print (paradigmes[paradigmes["lexeme"]==lexeme].to_latex(na_rep=""))
# Out:
# \begin{tabular}{llllllllllllllllllllllllllllllll}
# \toprule
# {} &    lexeme & ai1P & ai1S & ai2P & ai2S & ai3P & fi1P & fi1S & fi2P & fi2S & fi3P &      ii1P & ii1S & ii2P &      inf & pI1P & pI2P & pI2S & pP & pc1P & pc2P & pi1P & pi1S &     pi2P & pi2S &    pi3P & ppFP & ppMP & ps1P & ps1S & ps2P \\
# \midrule
# 665 &  coopérer &      &      &      &      &      &      &      &      &      &      &  kOOpErjô &      &      &  kOOpEre &      &      &      &    &      &      &      &      &  kOOpEre &      &  kOOpEr &      &      &      &      &      \\
# \bottomrule
# \end{tabular}

# %%
cliquesBrutes={}
for l in cliquesListes[u"coopérer"].values():
    longueur=len(l)
    if longueur>1:
        if not longueur in cliquesBrutes:
            cliquesBrutes[longueur]=0
        cliquesBrutes[longueur]+=1
cliquesBrutes
# Out:
# {4: 1, 7: 2, 8: 5, 9: 5, 10: 4, 18: 4, 19: 6, 20: 4, 21: 3, 22: 1}

# %%
cliquesFideles={}
fidelites=[v+"-"+k for k,v in dictParadigmes[u"coopérer"].iteritems() if isinstance(v,unicode)]
for l in cliquesListes[u"coopérer"].values():
    longueur=len(l)
    if longueur>1:
        fidele=True
        for fidelite in fidelites:
            lFidele=False
            for element in l:
                if fidelite in element:
                    lFidele=True
            if not lFidele:
                fidele=False
                break
        if fidele:
            if not longueur in cliquesFideles:
                cliquesFideles[longueur]=[]
            cliquesFideles[longueur].append(l)
cliquesFideles
# Out:
# {19: [[u'coop\xe9rer-kOOpEre-pi2P',
#    u'coop\xe9rer-kOOpErE-ii1S',
#    u'coop\xe9rer-kOOpEr-ps1S',
#    u'coop\xe9rer-kOOpEre-pI2P',
#    u'coop\xe9rer-kOOpEr-pi3P',
#    u'coop\xe9rer-kOOpEr\xe2-pP',
#    u'coop\xe9rer-kOOpEr\xf4-pi1P',
#    u'coop\xe9rer-kOOpEr\xf4-pI1P',
#    u'coop\xe9rer-kOOpEre-inf',
#    u'coop\xe9rer-kOOpEr9ra-fi2S',
#    u'coop\xe9rer-kOOpEr9rE-fi1S',
#    u'coop\xe9rer-kOOpEre-ppFP',
#    u'coop\xe9rer-kOOpEre-ppMP',
#    u'coop\xe9rer-kOOpEra-ai2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi1P',
#    u'coop\xe9rer-kOOpEr9rje-pc2P',
#    u'coop\xe9rer-kOOpErj\xf4-ii1P',
#    u'coop\xe9rer-kOOpEr-pi2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi3P'],
#   [u'coop\xe9rer-kOOpEre-pi2P',
#    u'coop\xe9rer-kOOpErE-ii1S',
#    u'coop\xe9rer-kOOpEr-ps1S',
#    u'coop\xe9rer-kOOpEre-pI2P',
#    u'coop\xe9rer-kOOpEr-pi3P',
#    u'coop\xe9rer-kOOpEr\xe2-pP',
#    u'coop\xe9rer-kOOpEr\xf4-pi1P',
#    u'coop\xe9rer-kOOpEr\xf4-pI1P',
#    u'coop\xe9rer-kOOpEre-inf',
#    u'coop\xe9rer-kOOpEr9ra-fi2S',
#    u'coop\xe9rer-kOOpEr9rE-fi1S',
#    u'coop\xe9rer-kOOpEre-ppFP',
#    u'coop\xe9rer-kOOpEre-ppMP',
#    u'coop\xe9rer-kOOpEra-ai2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi1P',
#    u'coop\xe9rer-kOOpEr9rje-pc2P',
#    u'coop\xe9rer-kOOpErj\xf4-ii1P',
#    u'coop\xe9rer-kOOpEr9re-fi2P',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi3P']],
#  20: [[u'coop\xe9rer-kOOpEre-pi2P',
#    u'coop\xe9rer-kOOpErE-ii1S',
#    u'coop\xe9rer-kOOpEr-ps1S',
#    u'coop\xe9rer-kOOpEre-pI2P',
#    u'coop\xe9rer-kOOpEr-pi3P',
#    u'coop\xe9rer-kOOpEr\xe2-pP',
#    u'coop\xe9rer-kOOpEr\xf4-pi1P',
#    u'coop\xe9rer-kOOpEr\xf4-pI1P',
#    u'coop\xe9rer-kOOpEre-inf',
#    u'coop\xe9rer-kOOpEr9ra-fi2S',
#    u'coop\xe9rer-kOOpEr9rE-fi1S',
#    u'coop\xe9rer-kOOpEre-ppFP',
#    u'coop\xe9rer-kOOpEre-ppMP',
#    u'coop\xe9rer-kOOpEra-ai2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi1P',
#    u'coop\xe9rer-kOOpEr9rje-pc2P',
#    u'coop\xe9rer-kOOpErj\xf4-ii1P',
#    u'coop\xe9rer-kOOpEr-pi2S',
#    u'coop\xe9rer-kOOpEr-pi1S',
#    u'coop\xe9rer-kOOpEr-pI2S']],
#  21: [[u'coop\xe9rer-kOOpEre-pi2P',
#    u'coop\xe9rer-kOOpErE-ii1S',
#    u'coop\xe9rer-kOOpEr-ps1S',
#    u'coop\xe9rer-kOOpEre-pI2P',
#    u'coop\xe9rer-kOOpEr-pi3P',
#    u'coop\xe9rer-kOOpEr\xe2-pP',
#    u'coop\xe9rer-kOOpEr\xf4-pi1P',
#    u'coop\xe9rer-kOOpEr\xf4-pI1P',
#    u'coop\xe9rer-kOOpEre-inf',
#    u'coop\xe9rer-kOOpEr9ra-fi2S',
#    u'coop\xe9rer-kOOpEr9rE-fi1S',
#    u'coop\xe9rer-kOOpEre-ppFP',
#    u'coop\xe9rer-kOOpEre-ppMP',
#    u'coop\xe9rer-kOOpEra-ai2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi1P',
#    u'coop\xe9rer-kOOpErEr-ai3P',
#    u'coop\xe9rer-kOOpErE-ai1S',
#    u'coop\xe9rer-kOOpErj\xf4-ii1P',
#    u'coop\xe9rer-kOOpEram-ai1P',
#    u'coop\xe9rer-kOOpEr-pi2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi3P'],
#   [u'coop\xe9rer-kOOpEre-pi2P',
#    u'coop\xe9rer-kOOpErE-ii1S',
#    u'coop\xe9rer-kOOpEr-ps1S',
#    u'coop\xe9rer-kOOpEre-pI2P',
#    u'coop\xe9rer-kOOpEr-pi3P',
#    u'coop\xe9rer-kOOpEr\xe2-pP',
#    u'coop\xe9rer-kOOpEr\xf4-pi1P',
#    u'coop\xe9rer-kOOpEr\xf4-pI1P',
#    u'coop\xe9rer-kOOpEre-inf',
#    u'coop\xe9rer-kOOpEr9ra-fi2S',
#    u'coop\xe9rer-kOOpEr9rE-fi1S',
#    u'coop\xe9rer-kOOpEre-ppFP',
#    u'coop\xe9rer-kOOpEre-ppMP',
#    u'coop\xe9rer-kOOpEra-ai2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi1P',
#    u'coop\xe9rer-kOOpErEr-ai3P',
#    u'coop\xe9rer-kOOpErE-ai1S',
#    u'coop\xe9rer-kOOpErj\xf4-ii1P',
#    u'coop\xe9rer-kOOpEram-ai1P',
#    u'coop\xe9rer-kOOpEr9re-fi2P',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi3P']],
#  22: [[u'coop\xe9rer-kOOpEre-pi2P',
#    u'coop\xe9rer-kOOpErE-ii1S',
#    u'coop\xe9rer-kOOpEr-ps1S',
#    u'coop\xe9rer-kOOpEre-pI2P',
#    u'coop\xe9rer-kOOpEr-pi3P',
#    u'coop\xe9rer-kOOpEr\xe2-pP',
#    u'coop\xe9rer-kOOpEr\xf4-pi1P',
#    u'coop\xe9rer-kOOpEr\xf4-pI1P',
#    u'coop\xe9rer-kOOpEre-inf',
#    u'coop\xe9rer-kOOpEr9ra-fi2S',
#    u'coop\xe9rer-kOOpEr9rE-fi1S',
#    u'coop\xe9rer-kOOpEre-ppFP',
#    u'coop\xe9rer-kOOpEre-ppMP',
#    u'coop\xe9rer-kOOpEra-ai2S',
#    u'coop\xe9rer-kOOpEr9r\xf4-fi1P',
#    u'coop\xe9rer-kOOpErEr-ai3P',
#    u'coop\xe9rer-kOOpErE-ai1S',
#    u'coop\xe9rer-kOOpErj\xf4-ii1P',
#    u'coop\xe9rer-kOOpEram-ai1P',
#    u'coop\xe9rer-kOOpEr-pi2S',
#    u'coop\xe9rer-kOOpEr-pi1S',
#    u'coop\xe9rer-kOOpEr-pI2S']]}

# %%
[v+"-"+k for k,v in dictParadigmes[u"coopérer"].iteritems() if isinstance(v,unicode)]
#type(dictParadigmes[u"coopérer"]["ii1P"])
#cliquesListes[u"coopérer"].values()
# Out:
# [u'kOOpErj\xf4-ii1P', u'kOOpEre-inf', u'kOOpEre-pi2P', u'kOOpEr-pi3P']

# %%
dictParadigmes=paradigmes.set_index("lexeme").to_dict(orient="index")

# %%
HTML(makeTable(dictParadigmes[lexeme],title=lexeme))
# Out:
# <table>
# <caption style='caption-side:bottom;text-align:center'>
# Verbe : coopérer
# </caption>
# <tr><th/><th>1S</th><th>2S</th><th>3S</th><th>1P</th><th>2P</th><th>3P</th></tr>
# <tr><th>pi</th><td>Ø</td><td>Ø</td><td>=</td><td>Ø</td><td>kOOpEre</td><td>kOOpEr</td></tr>
# <tr><th>ii</th><td>Ø</td><td>=</td><td>=</td><td>kOOpErjô</td><td>Ø</td><td>=</td></tr>
# <tr><th>fi</th><td>Ø</td><td>Ø</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>pc</th><td>=</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>ps</th><td>Ø</td><td>=</td><td>=</td><td>Ø</td><td>Ø</td><td>=</td></tr>
# <tr><th>ai</th><td>Ø</td><td>Ø</td><td>=</td><td>Ø</td><td>Ø</td><td>Ø</td></tr>
# <tr><th>is</th><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td><td>=</td></tr>
# <tr><th>pI</th><td>---</td><td>Ø</td><td>---</td><td>Ø</td><td>Ø</td><td>---</td></tr>
# <tr><th>NF</th><td>kOOpEre</td><td>Ø</td><td>=</td><td>Ø</td><td>=</td><td>Ø</td></tr>
# </table>

# %%
print (paradigmes.columns)
len(sampleCases)
# Out:
# Index([u'lexeme', u'ai1P', u'ai1S', u'ai2P', u'ai2S', u'ai3P', u'fi1P',
#        u'fi1S', u'fi2P', u'fi2S', u'fi3P', u'ii1P', u'ii1S', u'ii2P', u'inf',
#        u'pI1P', u'pI2P', u'pI2S', u'pP', u'pc1P', u'pc2P', u'pi1P', u'pi1S',
#        u'pi2P', u'pi2S', u'pi3P', u'ppFP', u'ppMP', u'ps1P', u'ps1S', u'ps2P'],
#       dtype='object')
# 30

# %% [raw]
# print ('",u"'.join(paradigmes[paradigmes.isnull().sum(axis=1)==26]["lexeme"].tolist()))

# %%
tirage='/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/MGC-170330-100Ko-19-Tirage.pkl'
with open(tirage, 'rb') as input:
    sampleTirage = pickle.load(input)

# %%
sampleTirage[(sampleTirage["lexeme"]==u"coopérer") & (sampleTirage["tir1"]!=0)]
# Out:
#             ortho     phono    lexeme         freq  case           freqcum  \
# 85780   coopèrent    kOOpEr  coopérer   56000000.0  pi3P  5948343031202941
# 85815    coopérer   kOOpEre  coopérer  659000000.0   inf  5949102045491941
# 85829    coopérez   kOOpEre  coopérer   63000000.0  pi2P  5949285049388941
# 85832  coopérions  kOOpErjô  coopérer    6000000.0  ii1P  5949310050687941
#
#        tir1
# 85780     1
# 85815     2
# 85829     1
# 85832     1

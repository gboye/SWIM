# %% [markdown]
# # Génération des réseaux de formes à partir des règles
# - Swim1 basé sur l'échantillon initial
#  - Gén-1 : génération des formes d'après les contextes phonologiques
#  - Gén-2 : génération du réseau d'après les contextes phonologiques
#  - Filt-1 : extraction du sous-réseau symétrique
#  - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
#  - Filt-3 : extraction des cliques maximales & fidèles
# - Swim2 basé sur le réseau calculé par Swim1
#  - Exp : génération d'un nouvel échantillon basé sur Swim1
#  - Gén-1 : génération des formes sans contexte phonologique
#  - Gén-2 : génération du réseau sans contexte phonologique
#  - Filt-1 : extraction du sous-réseau symétrique
#  - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
#  - Filt-3 : extraction des cliques maximales & fidèles
# - Évaluation

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs,operator,datetime,os,glob
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

# %%
# %matplotlib inline

# %%
import yaml

# %%
from ipywidgets import FloatProgress
from IPython.display import display, HTML

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %% [markdown]
# # Choix de l'échantillon et des règles
# - *sampleFile* est le nom de l'échantillon de départ
# - *analysisPrefix* est une partie du nom des règles

# %%
sampleFiles=glob.glob(filePrefix+"*.pkl")
def prefixEchantillon(numero):
    candidats=[]
    matchFile=ur"^.*/Longitudinal(-%s-T\d+-F\d+)%s\.pkl"%(numero,sampleType+casesType)
    for sample in sampleFiles:
        m=re.match(matchFile,sample)
        if m:
#            print (sample)
#            print (m.group(1))
            candidats.append(m.group(1))
    if len(candidats)==1:
        return candidats[0]
    else:
        print ("PB pas de nom unique correspondant",len(candidats))

# %%
goldPrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/"
goldFile="MGC-171229-Verbes3.pkl"
filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal"
sampleNumero="02"
sampleType="-X"
casesType="-Morphomes"
sampleType=""
casesType=""
sampleNumber=prefixEchantillon(sampleNumero)
print (sampleNumber)
paperPrefix="-ISMo"
genFormeVotes=True
genCliques=True
listeFormesOutput=["FS","FP"]
genDigraphe=False
genGraphe=False
plotDistributionCliques=False
if casesType:
    samplePrefix=filePrefix+"%s-%s"%(sampleNumber,sampleType.strip("-"))+casesType
    tirageFile=samplePrefix+".pkl"
elif sampleType:
    samplePrefix=filePrefix+"%s-%s"%(sampleNumber,sampleType.strip("-"))
    tirageFile=filePrefix+sampleNumber+".pkl"
else:
    samplePrefix=filePrefix+"%s-X"%(sampleNumber)
    tirageFile=filePrefix+sampleNumber+".pkl"
sampleFile=samplePrefix+"-paradigmes.csv"
analysisPrefix=samplePrefix
if debug: 
    logfile_name=analysisPrefix+"-network.log"
    logfile = codecs.open(logfile_name,mode='w',encoding="utf8")
# Out:
# -02-T30000-F7497

# %%
#tirage=filePrefix+'-'+sampleNumber+'-Tirage-'+sampleType+'-170503-1907'+casesType+'.pkl'
#tirage=filePrefix+sampleNumber+casesType+'.pkl'
with open(tirageFile, 'rb') as input:
    sampleTirage = pickle.load(input)

# %%
if not "morphome" in sampleTirage.columns.tolist():
    sampleTirage["morphome"]=sampleTirage["case"]
morphomeCases=sampleTirage[["case","morphome"]].drop_duplicates().to_dict()
casesMC=morphomeCases["case"]
morphomesMC=morphomeCases["morphome"]
dictMorphomeCases={}
for element in casesMC:
    dictMorphomeCases[casesMC[element]]=morphomesMC[element].split("/")
dictMorphomeCases
# Out:
# {u'ai1P': [u'ai1P'],
#  u'ai1S': [u'ai1S'],
#  u'ai2P': [u'ai2P'],
#  u'ai2S': [u'ai2S'],
#  u'ai3P': [u'ai3P'],
#  u'ai3S': [u'ai3S'],
#  u'fi1P': [u'fi1P'],
#  u'fi1S': [u'fi1S'],
#  u'fi2P': [u'fi2P'],
#  u'fi2S': [u'fi2S'],
#  u'fi3P': [u'fi3P'],
#  u'fi3S': [u'fi3S'],
#  u'ii1P': [u'ii1P'],
#  u'ii1S': [u'ii1S'],
#  u'ii2P': [u'ii2P'],
#  u'ii2S': [u'ii2S'],
#  u'ii3P': [u'ii3P'],
#  u'ii3S': [u'ii3S'],
#  u'inf': [u'inf'],
#  u'is1S': [u'is1S'],
#  u'is2P': [u'is2P'],
#  u'is3P': [u'is3P'],
#  u'is3S': [u'is3S'],
#  u'pI1P': [u'pI1P'],
#  u'pI2P': [u'pI2P'],
#  u'pI2S': [u'pI2S'],
#  u'pP': [u'pP'],
#  u'pc1P': [u'pc1P'],
#  u'pc1S': [u'pc1S'],
#  u'pc2P': [u'pc2P'],
#  u'pc2S': [u'pc2S'],
#  u'pc3P': [u'pc3P'],
#  u'pc3S': [u'pc3S'],
#  u'pi1P': [u'pi1P'],
#  u'pi1S': [u'pi1S'],
#  u'pi2P': [u'pi2P'],
#  u'pi2S': [u'pi2S'],
#  u'pi3P': [u'pi3P'],
#  u'pi3S': [u'pi3S'],
#  u'ppFP': [u'ppFP'],
#  u'ppFS': [u'ppFS'],
#  u'ppMP': [u'ppMP'],
#  u'ppMS': [u'ppMS'],
#  u'ps1P': [u'ps1P'],
#  u'ps2P': [u'ps2P'],
#  u'ps2S': [u'ps2S'],
#  u'ps3P': [u'ps3P'],
#  u'ps3S': [u'ps3S']}

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            if debug: print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
        self.classeCF={}
        self.nbClasseCF={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeFormeCF=[]
        regleFormeCF=""
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            filterF1=".*"+patron.split("-")[0]+"$"
            if re.match(filterF1,forme1):
                classeFormeCF.append(patron)
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleFormeCF=patron
            filterF1=self.patrons[patron]
            if re.match(filterF1,forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseFormeCF=", ".join(classeFormeCF)
        if not idClasseFormeCF in self.classeCF:
            self.classeCF[idClasseFormeCF]={}
            self.nbClasseCF[idClasseFormeCF]=0
        if not regleFormeCF in self.classeCF[idClasseFormeCF]:
            self.classeCF[idClasseFormeCF][regleFormeCF]=0
        self.nbClasseCF[idClasseFormeCF]+=1
        self.classeCF[idClasseFormeCF][regleFormeCF]+=1
        
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme,contextFree=True):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if contextFree:
                filterF1=".*"+patron.split("-")[0]+"$"
            else:
                filterF1=self.patrons[patron]
            if re.match(filterF1,forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if contextFree:
                nbClasse=self.nbClasseCF
                classe=self.classeCF
            else:
                nbClasse=self.nbClasse
                classe=self.classe
            if idClasseForme in nbClasse:
                nTotal=nbClasse[idClasseForme]
                for patron in classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            if debug:
                print (forme, file=logfile) 
                print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# # Lecture de l'échantillon

# %%
paradigmes=pd.read_csv(sampleFile,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
paradigmes=paradigmes.dropna(axis=1,how='all')

# %%
phonologicalMap=sampleType.strip("-")
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# ### Vérification de la phonotactique des glides du français
# - si *prononciation* est *None* renvoyer *None*
# - ajout de diérèses dans les séquences mal-formées
# - vérification des séquences consonne+glide à la finale

# %%
dierese={"j":"ij", "w":"uw","H":"yH","i":"ij","u":"uw","y":"yH"}

# %%
def checkFrench(prononciation):
    if prononciation:
        result=recoder(prononciation)
        m=re.match(ur"^.*([^ieèEaOouy926êôâ])[jwH]$",result)
        if m:
            print ("pb avec un glide final", prononciation)
        m=re.match(ur"(.*[ptkbdgfsSvzZ][rl])([jwH])(.*)",result)
        if m:
            n=re.search(ur"[ptkbdgfsSvzZ][rl](wa|Hi|wê)",result)
            if not n:
                glide=m.group(2)
                result=m.group(1)+dierese[glide]+m.group(3)
        m=re.match(ur"(.*)([iuy])([ieEaOouy].*)",result)
        if m:
            glide=m.group(2)
            result=m.group(1)+dierese[glide]+m.group(3)
        result=result.replace("Jj","J")
    else:
        result=prononciation
    return result

# %%
goldCases=paradigmes.columns.tolist()
goldCases.remove("lexeme")
#goldCases

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")
#sampleCases

# %% [markdown]
# ## Préparation des données initiales et de référence

# %%
listeTest=paradigmes.dropna(thresh=1)["lexeme"].values.tolist()
#listeTest=[u"asseoir",u"balayer",u"manger"]
nbVerbes=len(listeTest)
#print (nbVerbes)

# %% [markdown]
# ### Préparation des formes initiales

# %%
initialForms=pd.melt(paradigmes[paradigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()

initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)

initialForms.set_index(["lexeme-case"],inplace=True)

initialFormsIndex=initialForms.index.tolist()

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 9534

# %%
len(paradigmes.dropna(thresh=1)["lexeme"])
# Out:
# 2043

# %% [markdown]
# ### Préparation des formes de référence

# %%
#with open(goldPrefix+"/"+goldFile,"rb") as input:
with open(goldPrefix+goldFile,"rb") as input:
    lexiqueGold=pickle.load(input)

'''Rectifications phonologiques'''
lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

'''Mise en liste des formes de références'''
goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
goldTestForms.set_index(["lexeme-case"],inplace=True)

'''Extraction des formes de références pertinentes'''
goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #paradigmes
# #analyseCases
# lexeme=u"découper"
# paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()

# %% [markdown]
# # Lecture des règles

# %%
with open(analysisPrefix+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ### Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(goldCases):
    print ("Attention l'analyse ne comprend pas toutes les cases")
    print (sorted(analyseCases))
    print (sorted(goldCases))

# %% [markdown]
# # Préparations pour la génération des formes

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme,contextFree=False):
    candidats=paradigmeDistribution(lexeme)
    casesSamples=paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[paradigmes["lexeme"]==lexeme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element,contextFree),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart,contextFree))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True,contextFree=False):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart,contextFree)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %% [markdown]
# # Génération d'un jeu de cliques

# %%
def generate(lexeme,genDigraphe=True,contextFree=False):
#    print (lexeme,end=", ")
    generation1=generateForms(lexeme,contextFree)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe,contextFree)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
paradigmes.dropna(thresh=1).count().sum()-paradigmes.dropna(thresh=1)["lexeme"].count()
# Out:
# 7491

# %% [markdown]
# #### Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    if len(clique)>1:
        for (depart,arrivee) in it.combinations_with_replacement(clique,2):
            score+=graph[depart][arrivee]["weight"]
    return score

# %%
def splitArrivee(arrivee):
    arriveeMorceaux=arrivee.split("-")
    if len(arriveeMorceaux)<3:
        print (arrivee,arriveeMorceaux)
    lexeme="-".join(arriveeMorceaux[:-2])
    formeArrivee=arriveeMorceaux[-2]
    caseArrivee=arriveeMorceaux[-1]
    return (lexeme,formeArrivee,caseArrivee)
    
# trouver tous les liens vers FS-* et FP-*
# regrouper par forme 
# calculer les proportions
# renvoyer les proportions par forme
# avec le nombre de forme à l'appui
def formeScore(forme,graph):
    scores={}
    scoresNormes={}
    for depart in graph.edge:
        for arrivee in graph.edge[depart]:
            (lexeme, formeArrivee, caseArrivee)=splitArrivee(arrivee)
            if caseArrivee==forme:
#                print (depart, formeArrivee, graph.edge[depart][arrivee])
                if not formeArrivee in scores:
                    scores[formeArrivee]=0
                scores[formeArrivee]+=graph.edge[depart][arrivee]["weight"]
    totalArrivee=0
    for formeArrivee in scores:
        totalArrivee+=scores[formeArrivee]
    for formeArrivee in scores:
        scoresNormes[formeArrivee]=scores[formeArrivee]/totalArrivee
    return (scores,scoresNormes)

# %% [markdown]
# ## Préparations pour SWIM

# %%
def generateAnalysis(globDigraphe,globGraphe,contextFree=False):
    numClique=0
    progressBar = FloatProgress(min=0, max=nbVerbes-1)
    display(progressBar)
    for i,element in enumerate(listeTest):
        cliquesScores[element]={}
        cliquesListes[element]={}
    #    if (i%100)==0: print (i, dateheure()[-4:], int(100*float(i)/nbVerbes), end=", ")
        progressBar.value=i
        #print (element)
        result=generate(element,genDigraphe,contextFree)
        (generation,lexDigraphe,lexGraphe,lexCliques)= result
    #    print (generation,lexDigraphe,lexGraphe,lexCliques)
        if genFormeVotes:
            formesScores[element]={}
            formesScoresNormes[element]={}
            for formeOutput in listeFormesOutput:
                (formesScores[element][formeOutput],formesScoresNormes[element][formeOutput])=formeScore(formeOutput,lexDigraphe)
        if genDigraphe:
            globDigraphe=nx.union(globDigraphe,lexDigraphe)
        if genGraphe:
            globGraphe=nx.union(globGraphe,lexGraphe)
        cliques.extend(lexCliques)
        for clique in lexCliques:
            cliquesScores[element][numClique]=cliqueScore(clique,lexGraphe)
            cliquesListes[element][numClique]=clique
            numClique+=1
    return globDigraphe,globGraphe,numClique

# %%
def dictCliqueForms(clique):
    result={}
    for element in clique:
        lexeme,forme,case=splitArrivee(element)
        for c in dictMorphomeCases[case]:
            result[c]=forme
    return result

def dictPdRowForms(row):
    result={}
    for case in sampleCases:
        print (case,row[case].values[0])
    return result

def tableZero(case):
    if case in sampleCases:
        return u"Ø"
    else:
        return u"="

def makeTable(dictForms,title=""):
    tabular=[]
    labelTenseCode={"pi":"Present","ii":"Imperfective","ai":"Simple Past","fi":"Future",
                    "ps":"Subjunctive Pres.","is":"Subjunctive Imp.","pc":"Conditional","pI":"Imperative",
                    "inf":"Infinitive",
                    "ppMS":"Past Part. MS","ppMP":"Past Part. MP",
                    "ppFS":"Past Part. FS","ppMP":"Past Part. FP"
                   }
    def makeLine6(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            case=tenseCode+person
            if (case in dictForms) and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"

    def makeLine3(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            if person in ["2S","1P","2P"]:
                case=tenseCode+person
                if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                    line.append(r"<td>%s</td>"%(dictForms[case]))
                else:
                    line.append(r"<td>%s</td>"%(tableZero(case)))
            else:
                line.append(r"<td>%s</td>"%(u"---"))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
    def makeLineNF():
        line=[]
        line.append(r"<th>%s</th>"%"NF")
        for case in ["inf","pP","ppMS","ppMP","ppFS","ppFP"]:
            if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
        
    top=[
        r"<table>",
        r"<caption style='caption-side:bottom;text-align:center'>",
        "Verbe : %s"%title,
        r"</caption>",
#        r"<tr><th/><th>1S</th><th>2S</th><th>3S</th><th>1P</th><th>2P</th><th>3P</th></tr>"
        r"<tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>"
        ]
    bottom=[
        r"</table>"
        ]
    tabular.append("\n".join(top))
    for tenseCode in ["pi","ii","fi","pc", "ps","ai", "is"]:
        tabular.append(makeLine6(tenseCode))
    tabular.append(makeLine3("pI"))
    tabular.append(makeLineNF())
    tabular.append("\n".join(bottom))
    return "\n".join(tabular)    

def diffParadigme(lexeme):
    outLen=lexemeMaxCliques[lexeme][0]
    inLen=paradigmes[paradigmes["lexeme"]==lexeme].notnull().sum(axis=1).values[0]-1
    if outLen>inLen:
        print (lexemeMaxCliques[lexeme][1])
        print (paradigmes[paradigmes["lexeme"]=="grandir"].values)
    return outLen-inLen

# %%
def checkFidelite(fidelite,clique):
    lFidele=False
    for element in clique:
        if fidelite in element:
            lFidele=True
    return lFidele

def generateCliques(contextFree=False):
    
    def bruteCliques(lexeme,maxCliqueSize=51):
        cliquesBrutes={n+1:0 for n in range(maxCliqueSize)}
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                if not longueur in cliquesBrutes:
                    cliquesBrutes[longueur]=0
                cliquesBrutes[longueur]+=1
        return cliquesBrutes
    
    globDigraphe=nx.DiGraph()
    globGraphe=nx.Graph()

    globDigraphe,globGraphe,numClique=generateAnalysis(globDigraphe,globGraphe,contextFree)
    print 

    lexemeMaxCliques={}
    lexemeParadigmes={}
    progressBarCliques = FloatProgress(min=0, max=len(cliquesListes)-1)
    display(progressBarCliques)
    for lexeme in cliquesListes:
        progressBarCliques.value+=1
        maxLen=max([len(c) for c in cliquesListes[lexeme].values()])
        lexemeMaxCliques[lexeme]=bruteCliques(lexeme,maxLen)
        print (lexeme,"Nombre de cliques",sum([v for k,v in lexemeMaxCliques[lexeme].iteritems()]))
        maxNbCliques=max([v for k,v in lexemeMaxCliques[lexeme].iteritems()])
        if plotDistributionCliques:
            ax=pd.DataFrame.from_dict(lexemeMaxCliques[lexeme],orient="index").plot(kind="bar",legend=False,grid=True,figsize=(10,3))
            ax.set(xlim=(0,maxLen+.5),ylim=(0,maxNbCliques+10))
            ax.set_xlabel("Clique Size in Cells",fontsize=16)
            ax.set_ylabel("Number of Cliques",fontsize=16)

        dictParadigmes=paradigmes.set_index("lexeme").to_dict(orient="index")

        cliquesFideles={}
        fidelites=[v+"-"+k for k,v in dictParadigmes[lexeme].iteritems() if isinstance(v,unicode)]
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                fidele=True
                for fidelite in fidelites:
                    if "," in fidelite:
                        fideliteForme,fideliteCase=fidelite.split("-")
                        fideliteFormes=fideliteForme.split(",")
                        fideliteItems=[fideliteF+"-"+fideliteCase for fideliteF in fideliteFormes]
#                        print (fideliteItems)
                        lFidele=True
                        for f in fideliteItems:
                            lFidele=lFidele & checkFidelite(f,l)
                    else:
                        lFidele=checkFidelite(fidelite,l)
                    if not lFidele:
                        fidele=False
                        break
                if fidele:
                    if not longueur in cliquesFideles:
                        cliquesFideles[longueur]=[]
                    cliquesFideles[longueur].append(l)
#                else:
#                    if lexeme==u"bégayer": print ()
#        print ([(k,len(v)) for k,v in cliquesFideles.iteritems()])
        if cliquesFideles:
            maxCliquesCard=max([k for k,v in cliquesFideles.iteritems()])
    #        print (maxCliquesCard)
    #        print (cliquesScores[lexeme])
    #        print (cliquesListes[lexeme])
            lexemeParadigmes[lexeme]=[]
            maxScoreCliques=max([clique for cliqueNumber, clique in cliquesScores[lexeme].items()])
            maxCardScoreNums=[numC for numC, c in cliquesListes[lexeme].items() if c in cliquesFideles[maxCliquesCard]]
            maxCardScore=max([scoreC for numC, scoreC in cliquesScores[lexeme].items() if numC in maxCardScoreNums])
    #        print ("max score among all cliques:",maxScoreCliques)
            print ("max score among faithfull cliques of %d forms:"%maxCliquesCard,maxCardScore)
            for c in cliquesFideles[maxCliquesCard]:
                cNumber=[cliqueNumber for cliqueNumber, clique in cliquesListes[lexeme].items() if clique == c]
                if len(cNumber)!=1:
                    print ("TOO MANY SCORES PROBLEM WITH CLIQUE", cNumber)
    #            print ("Liste n°",cNumber[0],cliquesScores[lexeme][cNumber[0]])
    #            print (sorted(cliquesScores[lexeme].items(), key=operator.itemgetter(1)))
    #            display(HTML(makeTable(dictCliqueForms(c),title=c[0].split("-")[0])))
    #            print (cliquesScores[lexeme][cNumber[0]], maxCardScore)
                if cliquesScores[lexeme][cNumber[0]]==maxCardScore:
                    lexemeParadigmes[lexeme].append(c)
        else:
            lexemeParadigmes[lexeme]=[[lexeme+"-"+f for f in fidelites]]
            print (u"no new faithfull clique, the previous one contained %d forms"%len(lexemeParadigmes[lexeme]))
    return lexemeParadigmes

# %%
def cutNodeName(nodeName):
    items=nodeName.split("-")
    nbItems=len(items)
    if nbItems>3:
        items=["-".join(items[0:nbItems-2]),items[-2],items[-1]]
    return items

def filledOutClique(cliques):
    if cliques:
        result=[]
        for clique in cliques:
#            print (clique)
            fullClique=[]
            for element in clique:
                if debug: print ("element",element)
                lexeme,forme,case=splitArrivee(element)
                for c in dictMorphomeCases[case]:
                    fullClique.append("-".join([lexeme,forme,c]))
            result.append(fullClique)
        return result
    else:
        return cliques

# %%
def extendParadigmes(contextParadigmes,extendMorphomes=False):
    lexemesParadigmeListe=[]
    for lexeme in contextParadigmes:
        if extendMorphomes:
            lexParadigmes=filledOutClique(contextParadigmes[lexeme])
        else:
            lexParadigmes=contextParadigmes[lexeme]
        if len(lexParadigmes)!=1:
            print ("LEXEME WITH A NON UNIQUE PARADIGM PB",len(lexParadigmes),lexeme)
            if debug: print (lexParadigmes)
        lexParadigme=lexParadigmes[0]
        for lexForme in lexParadigme:
            lexemesParadigmeListe.append(cutNodeName(lexForme))
    newForms=pd.DataFrame(lexemesParadigmeListe)
    newForms.columns=["lexeme","form","case"]
#    newParadigmes=newForms.pivot(index="lexeme", columns="case", values="form")
    newParadigmes=pd.pivot_table(newForms, values='form', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
    for i in newParadigmes.itertuples():
#        print (i[0],i[1])
        lexeme=i[1]
        lexemeIndexes=paradigmes.lexeme[paradigmes.lexeme==lexeme].index.tolist()
        if lexemeIndexes:
            lexemeIndex=lexemeIndexes[0]
        else:
            print (i,lexeme,lexemeIndexes)
        newParadigmes.loc[newParadigmes.lexeme==lexeme,"index"]=int(lexemeIndex)
    newParadigmes.set_index("index",inplace=True)   
    return paradigmes.combine_first(newParadigmes)

# %%
def countSplits(dfForms):
    dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
    return dfForms["split"].str.len().sum()

def calculerResultats(contextParadigmes,extension="-Swim2"):
    
    '''Préparer le paradigme des prédictions'''
    brutParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=False)
    finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
    finalParadigmes.to_csv(path_or_buf=analysisPrefix+"-paradigmes%s.csv"%extension,encoding="utf8",sep=";")
    finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
    finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
    finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
    finalTestForms.set_index(["lexeme-case"],inplace=True)
    
    '''Soustraire les formes initiales'''
    finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
    finalFormsIndex=finalForms.index.tolist()
    
    '''Calculer les sur/sous-générations'''
    underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
    overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]
    
    '''Réduire les prédictions et la référence aux cases communes'''
    predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
    actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]
    
    '''Créer un tableau pour les comparaisons'''
    compareForms=predictedForms.copy()
    compareForms.loc[:,"right"]=actualForms.loc[:,"value"]
    
    '''Séparer les cases identiques des cases différentes'''
    sameForms=compareForms[compareForms["value"]==compareForms["right"]]
    diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

    
    '''Sauvegarder les comparatifs'''
    overGeneration.to_csv(path_or_buf=analysisPrefix+"-overGeneration%s.csv"%extension,encoding="utf8")
    underGeneration.to_csv(path_or_buf=analysisPrefix+"-underGeneration%s.csv"%extension,encoding="utf8")
    sameForms.to_csv(path_or_buf=analysisPrefix+"-sameForms%s.csv"%extension,encoding="utf8")
    diffForms.to_csv(path_or_buf=analysisPrefix+"-diffForms%s.csv"%extension,encoding="utf8")
    
    
    '''Transformer les surabondances en liste'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")

    '''Transformer les surabondances en set()'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
    
    '''Calculer le nombre de formes (y compris surabondances)'''
    nbValues=diffForms["split-value"].str.len().sum()
    nbRights=diffForms["split-right"].str.len().sum()

    '''Calculer les identités et les inclusions'''
    nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
    nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
    nbWrongForms=(nbValues-nbIdenticalSets-nbIncludedSets)
    underBonus=(nbRights-nbIdenticalSets-nbIncludedSets)

    UG=countSplits(underGeneration)+underBonus
    OG=countSplits(overGeneration)
    TP=countSplits(sameForms)+nbIdenticalSets+nbIncludedSets
    FP=nbWrongForms
    resultCharacteristics=(UG,OG,TP,FP)
    recall=float(TP)/(UG+TP+FP)
    precision=float(TP)/(OG+TP+FP)
    fMeasure=2*recall*precision/(recall+precision)
    resultMeasures=(precision,recall,fMeasure)
    print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
    print ("recall", recall, "precision", precision)
    print (fMeasure)
    return (brutParadigmes,finalParadigmes,resultCharacteristics,resultMeasures)

# %% [markdown]
# # SWIM1

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim1ContextParadigmes=generateCliques()
# Out:
# 2017-12-30 14:24:38.010752
# escamoter Nombre de cliques 31
# max score among faithfull cliques of 19 forms: 180.877906541
# assembler Nombre de cliques 28
# max score among faithfull cliques of 12 forms: 78.0
# projeter Nombre de cliques 26
# max score among faithfull cliques of 17 forms: 148.944831413
# aider Nombre de cliques 26
# max score among faithfull cliques of 16 forms: 134.997881623
# pratiquer Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 227.164734253
# ranimer Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 229.388582698
# offenser Nombre de cliques 31
# max score among faithfull cliques of 19 forms: 184.264563385
# voter Nombre de cliques 174
# max score among faithfull cliques of 20 forms: 187.599353703
# surprendre Nombre de cliques 127
# max score among faithfull cliques of 16 forms: 127.598220057
# devenir Nombre de cliques 154
# max score among faithfull cliques of 15 forms: 105.7280656
# remâcher Nombre de cliques 19
# max score among faithfull cliques of 19 forms: 189.68915543
# débouler Nombre de cliques 39
# max score among faithfull cliques of 16 forms: 134.473901099
# engueuler Nombre de cliques 50
# max score among faithfull cliques of 2 forms: 2.375
# dénuer Nombre de cliques 8
# max score among faithfull cliques of 8 forms: 35.8
# déverser Nombre de cliques 67
# max score among faithfull cliques of 21 forms: 220.845792663
# voir Nombre de cliques 75
# max score among faithfull cliques of 32 forms: 501.041414373
# adhérer Nombre de cliques 135
# max score among faithfull cliques of 17 forms: 150.146364219
# persister Nombre de cliques 17
# max score among faithfull cliques of 19 forms: 189.643483078
# commenter Nombre de cliques 38
# max score among faithfull cliques of 19 forms: 182.578724233
# rapprocher Nombre de cliques 31
# max score among faithfull cliques of 21 forms: 229.02617911
# rutiler Nombre de cliques 21
# max score among faithfull cliques of 18 forms: 165.597880776
# sangler Nombre de cliques 27
# max score among faithfull cliques of 12 forms: 78.0
# perpétuer Nombre de cliques 13
# max score among faithfull cliques of 8 forms: 34.9
# chauffer Nombre de cliques 177
# max score among faithfull cliques of 5 forms: 12.4147048416
# dépayser Nombre de cliques 41
# max score among faithfull cliques of 22 forms: 247.34785761
# pencher Nombre de cliques 36
# max score among faithfull cliques of 15 forms: 118.639671393
# agrandir Nombre de cliques 46
# max score among faithfull cliques of 13 forms: 85.4512820513
# retransmettre Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 82.0889289454
# moucharder Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 225.97101365
# remplacer Nombre de cliques 29
# max score among faithfull cliques of 18 forms: 169.385660017
# risquer Nombre de cliques 21
# max score among faithfull cliques of 17 forms: 152.95268899
# enquiquiner Nombre de cliques 16
# max score among faithfull cliques of 21 forms: 229.145186297
# coter Nombre de cliques 54
# max score among faithfull cliques of 18 forms: 168.150473961
# reprocher Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 224.048176639
# supplier Nombre de cliques 57
# max score among faithfull cliques of 8 forms: 31.2042464691
# grossir Nombre de cliques 95
# max score among faithfull cliques of 18 forms: 163.126202148
# revivre Nombre de cliques 46
# max score among faithfull cliques of 9 forms: 36.5234537239
# tanguer Nombre de cliques 27
# max score among faithfull cliques of 18 forms: 165.317423661
# susciter Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 249.205261653
# terroriser Nombre de cliques 17
# max score among faithfull cliques of 26 forms: 343.809893947
# figer Nombre de cliques 22
# max score among faithfull cliques of 21 forms: 230.055450975
# indiquer Nombre de cliques 30
# max score among faithfull cliques of 21 forms: 228.092800657
# repérer Nombre de cliques 135
# max score among faithfull cliques of 17 forms: 149.905524482
# désosser Nombre de cliques 85
# max score among faithfull cliques of 20 forms: 206.766887076
# visualiser Nombre de cliques 42
# max score among faithfull cliques of 20 forms: 209.084441475
# changer Nombre de cliques 30
# max score among faithfull cliques of 16 forms: 134.696703559
# appeler Nombre de cliques 73
# max score among faithfull cliques of 22 forms: 238.436103512
# prêcher Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 230.681319415
# dégager Nombre de cliques 29
# max score among faithfull cliques of 16 forms: 134.215182159
# unir Nombre de cliques 73
# max score among faithfull cliques of 4 forms: 10.0
# acharner Nombre de cliques 38
# max score among faithfull cliques of 20 forms: 204.481306574
# ménager Nombre de cliques 31
# max score among faithfull cliques of 19 forms: 189.108115675
# invoquer Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 224.042188313
# barbouiller Nombre de cliques 19
# max score among faithfull cliques of 15 forms: 119.090325511
# priver Nombre de cliques 83
# max score among faithfull cliques of 22 forms: 246.221185988
# encadrer Nombre de cliques 29
# max score among faithfull cliques of 14 forms: 101.678216821
# métamorphoser Nombre de cliques 72
# max score among faithfull cliques of 19 forms: 186.812546412
# exploser Nombre de cliques 99
# max score among faithfull cliques of 5 forms: 12.7631578947
# rugir Nombre de cliques 10
# max score among faithfull cliques of 7 forms: 27.9128029505
# menacer Nombre de cliques 34
# max score among faithfull cliques of 22 forms: 245.886621928
# redevenir Nombre de cliques 66
# max score among faithfull cliques of 22 forms: 227.17639022
# avaler Nombre de cliques 26
# max score among faithfull cliques of 17 forms: 150.678983545
# aligner Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 230.648373984
# gicler Nombre de cliques 18
# max score among faithfull cliques of 12 forms: 78.0
# mirer Nombre de cliques 33
# max score among faithfull cliques of 18 forms: 164.870388992
# sortir Nombre de cliques 136
# max score among faithfull cliques of 21 forms: 172.025926552
# berner Nombre de cliques 97
# max score among faithfull cliques of 20 forms: 205.806226393
# estimer Nombre de cliques 26
# max score among faithfull cliques of 24 forms: 291.085086877
# précipiter Nombre de cliques 44
# max score among faithfull cliques of 22 forms: 240.13290173
# orner Nombre de cliques 31
# max score among faithfull cliques of 20 forms: 205.325984318
# déclencher Nombre de cliques 24
# max score among faithfull cliques of 6 forms: 21.0
# dérider Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 317.766134253
# débattre Nombre de cliques 6
# max score among faithfull cliques of 8 forms: 35.2303921569
# divorcer Nombre de cliques 22
# max score among faithfull cliques of 20 forms: 203.205888454
# dénombrer Nombre de cliques 39
# max score among faithfull cliques of 15 forms: 109.790762267
# prôner Nombre de cliques 46
# max score among faithfull cliques of 24 forms: 284.701366688
# falloir Nombre de cliques 48
# max score among faithfull cliques of 7 forms: 23.4523952141
# relire Nombre de cliques 13
# max score among faithfull cliques of 8 forms: 33.3529761905
# citer Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 265.952370392
# enliser Nombre de cliques 60
# max score among faithfull cliques of 21 forms: 227.894373781
# réchauffer Nombre de cliques 169
# max score among faithfull cliques of 6 forms: 18.5819590297
# tondre Nombre de cliques 13
# max score among faithfull cliques of 10 forms: 49.8317454773
# polir Nombre de cliques 18
# max score among faithfull cliques of 6 forms: 19.0716817187
# prostituer Nombre de cliques 6
# max score among faithfull cliques of 7 forms: 28.0
# cotiser Nombre de cliques 99
# max score among faithfull cliques of 20 forms: 207.006569648
# destiner Nombre de cliques 17
# max score among faithfull cliques of 24 forms: 297.120186297
# mépriser Nombre de cliques 31
# max score among faithfull cliques of 26 forms: 332.862078275
# douter Nombre de cliques 57
# max score among faithfull cliques of 10 forms: 51.7544715443
# rassurer Nombre de cliques 32
# max score among faithfull cliques of 21 forms: 224.644789419
# épouvanter Nombre de cliques 76
# max score among faithfull cliques of 17 forms: 116.143769987
# suggérer Nombre de cliques 83
# max score among faithfull cliques of 17 forms: 139.220467837
# prévenir Nombre de cliques 137
# max score among faithfull cliques of 22 forms: 228.57524292
# vibrer Nombre de cliques 22
# max score among faithfull cliques of 15 forms: 117.639843094
# chiner Nombre de cliques 12
# max score among faithfull cliques of 21 forms: 228.78912569
# déménager Nombre de cliques 25
# max score among faithfull cliques of 19 forms: 189.68915543
# combler Nombre de cliques 28
# max score among faithfull cliques of 12 forms: 78.0
# plier Nombre de cliques 41
# max score among faithfull cliques of 8 forms: 28.0664930476
# exagérer Nombre de cliques 76
# max score among faithfull cliques of 17 forms: 136.886125629
# affubler Nombre de cliques 23
# max score among faithfull cliques of 12 forms: 78.0
# sillonner Nombre de cliques 30
# max score among faithfull cliques of 21 forms: 227.192120079
# défiler Nombre de cliques 24
# max score among faithfull cliques of 18 forms: 168.061548846
# anoblir Nombre de cliques 13
# max score among faithfull cliques of 6 forms: 21.0
# bouillir Nombre de cliques 28
# max score among faithfull cliques of 2 forms: 3.0
# amorcer Nombre de cliques 27
# max score among faithfull cliques of 20 forms: 203.541053289
# surnommer Nombre de cliques 33
# max score among faithfull cliques of 21 forms: 230.709135724
# réduire Nombre de cliques 67
# max score among faithfull cliques of 7 forms: 24.3726667983
# boire Nombre de cliques 163
# max score among faithfull cliques of 14 forms: 92.0577012856
# refléter Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 280.501280005
# ériger Nombre de cliques 25
# max score among faithfull cliques of 21 forms: 227.82763973
# cingler Nombre de cliques 27
# max score among faithfull cliques of 12 forms: 78.0
# rader Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 265.591141377
# obséder Nombre de cliques 146
# max score among faithfull cliques of 20 forms: 199.447788473
# émaner Nombre de cliques 25
# max score among faithfull cliques of 21 forms: 230.228526314
# subsister Nombre de cliques 14
# max score among faithfull cliques of 19 forms: 189.684578969
# concevoir Nombre de cliques 102
# max score among faithfull cliques of 11 forms: 42.9918906647
# pulluler Nombre de cliques 16
# max score among faithfull cliques of 18 forms: 168.94047619
# confirmer Nombre de cliques 32
# max score among faithfull cliques of 16 forms: 134.48519854
# borner Nombre de cliques 31
# max score among faithfull cliques of 19 forms: 186.479487066
# reparler Nombre de cliques 3
# max score among faithfull cliques of 18 forms: 171.0
# croquer Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 223.226823991
# mettre Nombre de cliques 85
# max score among faithfull cliques of 24 forms: 261.956982996
# incendier Nombre de cliques 14
# max score among faithfull cliques of 11 forms: 65.5875
# vivre Nombre de cliques 178
# max score among faithfull cliques of 17 forms: 134.508447813
# surgir Nombre de cliques 79
# max score among faithfull cliques of 6 forms: 17.8508219955
# glacer Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 274.59364717
# lessiver Nombre de cliques 58
# max score among faithfull cliques of 22 forms: 245.085083448
# affecter Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 119.789887188
# chérir Nombre de cliques 35
# max score among faithfull cliques of 6 forms: 18.8076923077
# ajuster Nombre de cliques 15
# max score among faithfull cliques of 19 forms: 189.616085818
# exaucer Nombre de cliques 97
# max score among faithfull cliques of 20 forms: 206.723787075
# agneler Nombre de cliques 19
# max score among faithfull cliques of 16 forms: 134.59696046
# choir Nombre de cliques 10
# max score among faithfull cliques of 2 forms: 3.0
# couronner Nombre de cliques 38
# max score among faithfull cliques of 24 forms: 277.311783357
# piocher Nombre de cliques 18
# max score among faithfull cliques of 19 forms: 184.291348411
# écrire Nombre de cliques 125
# max score among faithfull cliques of 18 forms: 147.771983447
# stabiliser Nombre de cliques 60
# max score among faithfull cliques of 21 forms: 227.894373781
# diminuer Nombre de cliques 4
# max score among faithfull cliques of 8 forms: 35.8
# rayonner Nombre de cliques 31
# max score among faithfull cliques of 21 forms: 224.611315324
# créer Nombre de cliques 19
# max score among faithfull cliques of 6 forms: 20.4583333333
# désobéir Nombre de cliques 6
# max score among faithfull cliques of 6 forms: 21.0
# palpiter Nombre de cliques 42
# max score among faithfull cliques of 22 forms: 226.666834734
# redresser Nombre de cliques 46
# max score among faithfull cliques of 24 forms: 266.463373617
# reconstituer Nombre de cliques 15
# max score among faithfull cliques of 8 forms: 34.9
# réécrire Nombre de cliques 53
# max score among faithfull cliques of 9 forms: 39.1394978106
# retourner Nombre de cliques 35
# max score among faithfull cliques of 17 forms: 151.202764969
# apposer Nombre de cliques 87
# max score among faithfull cliques of 19 forms: 186.709806686
# insister Nombre de cliques 17
# max score among faithfull cliques of 17 forms: 152.647592667
# assurer Nombre de cliques 39
# max score among faithfull cliques of 21 forms: 224.4573531
# emprisonner Nombre de cliques 25
# max score among faithfull cliques of 24 forms: 295.569147354
# disputer Nombre de cliques 44
# max score among faithfull cliques of 22 forms: 232.976578472
# droguer Nombre de cliques 29
# max score among faithfull cliques of 21 forms: 225.288130701
# enlever Nombre de cliques 131
# max score among faithfull cliques of 7 forms: 24.6188105379
# sauver Nombre de cliques 205
# max score among faithfull cliques of 10 forms: 51.6779385206
# entraîner Nombre de cliques 214
# max score among faithfull cliques of 20 forms: 202.38712738
# cantonner Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 271.569147354
# clapoter Nombre de cliques 200
# max score among faithfull cliques of 19 forms: 164.389377754
# redéfinir Nombre de cliques 128
# max score among faithfull cliques of 16 forms: 130.90758317
# enfuir Nombre de cliques 40
# max score among faithfull cliques of 4 forms: 8.62980769231
# attribuer Nombre de cliques 4
# max score among faithfull cliques of 7 forms: 28.0
# salir Nombre de cliques 15
# max score among faithfull cliques of 5 forms: 13.2073903895
# étaler Nombre de cliques 21
# max score among faithfull cliques of 16 forms: 134.916773644
# rejouer Nombre de cliques 3
# max score among faithfull cliques of 10 forms: 55.0
# embrouiller Nombre de cliques 25
# max score among faithfull cliques of 15 forms: 116.908814722
# rabâcher Nombre de cliques 20
# max score among faithfull cliques of 19 forms: 189.609368196
# croître Nombre de cliques 14
# max score among faithfull cliques of 3 forms: 5.57575757576
# enfanter Nombre de cliques 80
# max score among faithfull cliques of 17 forms: 116.143769987
# promener Nombre de cliques 145
# max score among faithfull cliques of 10 forms: 50.1654255886
# construire Nombre de cliques 67
# max score among faithfull cliques of 7 forms: 22.2819408718
# entrevoir Nombre de cliques 60
# max score among faithfull cliques of 6 forms: 16.7196153846
# concéder Nombre de cliques 144
# max score among faithfull cliques of 20 forms: 200.022910706
# enrichir Nombre de cliques 47
# max score among faithfull cliques of 16 forms: 134.211961236
# carrer Nombre de cliques 34
# max score among faithfull cliques of 18 forms: 166.003100953
# dévider Nombre de cliques 42
# max score among faithfull cliques of 23 forms: 258.459148298
# tapisser Nombre de cliques 45
# max score among faithfull cliques of 21 forms: 195.570288169
# momifier Nombre de cliques 16
# max score among faithfull cliques of 12 forms: 77.65813778
# ravir Nombre de cliques 33
# max score among faithfull cliques of 7 forms: 20.1832399627
# grignoter Nombre de cliques 32
# max score among faithfull cliques of 19 forms: 184.534113809
# ennuyer Nombre de cliques 49
# max score among faithfull cliques of 6 forms: 16.8030323228
# injecter Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 119.789887188
# économiser Nombre de cliques 25
# max score among faithfull cliques of 22 forms: 248.689367446
# chanter Nombre de cliques 46
# max score among faithfull cliques of 17 forms: 143.400334398
# cerner Nombre de cliques 56
# max score among faithfull cliques of 20 forms: 206.4528599
# délester Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 299.434578969
# exulter Nombre de cliques 1
# max score among faithfull cliques of 2 forms: 3.0
# confier Nombre de cliques 58
# max score among faithfull cliques of 8 forms: 31.2754937564
# prendre Nombre de cliques 111
# max score among faithfull cliques of 28 forms: 384.360115008
# tirer Nombre de cliques 43
# max score among faithfull cliques of 17 forms: 147.485163879
# ancrer Nombre de cliques 22
# max score among faithfull cliques of 15 forms: 118.813603048
# effectuer Nombre de cliques 5
# max score among faithfull cliques of 8 forms: 35.8
# classer Nombre de cliques 25
# max score among faithfull cliques of 20 forms: 207.779959507
# téléphoner Nombre de cliques 51
# max score among faithfull cliques of 23 forms: 263.267104939
# repenser Nombre de cliques 41
# max score among faithfull cliques of 19 forms: 180.132286431
# enchanter Nombre de cliques 26
# max score among faithfull cliques of 18 forms: 165.291685038
# spécialiser Nombre de cliques 60
# max score among faithfull cliques of 21 forms: 227.894373781
# préciser Nombre de cliques 89
# max score among faithfull cliques of 21 forms: 223.087107482
# caler Nombre de cliques 17
# max score among faithfull cliques of 17 forms: 151.855596465
# arrimer Nombre de cliques 21
# max score among faithfull cliques of 24 forms: 297.456433383
# absorber Nombre de cliques 56
# max score among faithfull cliques of 18 forms: 167.019426039
# découler Nombre de cliques 35
# max score among faithfull cliques of 16 forms: 133.774942829
# coincer Nombre de cliques 26
# max score among faithfull cliques of 17 forms: 149.180443901
# latter Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 273.062715297
# forcer Nombre de cliques 52
# max score among faithfull cliques of 17 forms: 144.478640337
# rétrécir Nombre de cliques 35
# max score among faithfull cliques of 9 forms: 34.2258567488
# retapisser Nombre de cliques 67
# max score among faithfull cliques of 21 forms: 227.594227343
# végéter Nombre de cliques 78
# max score among faithfull cliques of 19 forms: 181.776166422
# incurver Nombre de cliques 58
# max score among faithfull cliques of 16 forms: 133.618098347
# manifester Nombre de cliques 13
# max score among faithfull cliques of 11 forms: 65.75
# revêtir Nombre de cliques 99
# max score among faithfull cliques of 3 forms: 5.125
# ausculter Nombre de cliques 5
# max score among faithfull cliques of 8 forms: 36.0
# réchapper Nombre de cliques 21
# max score among faithfull cliques of 22 forms: 246.438118283
# confondre Nombre de cliques 186
# max score among faithfull cliques of 8 forms: 27.5389212497
# vérifier Nombre de cliques 70
# max score among faithfull cliques of 8 forms: 31.9570535487
# réviser Nombre de cliques 153
# max score among faithfull cliques of 19 forms: 187.873168479
# plaindre Nombre de cliques 35
# max score among faithfull cliques of 7 forms: 26.1227140745
# exclure Nombre de cliques 15
# max score among faithfull cliques of 3 forms: 5.06666666667
# advenir Nombre de cliques 16
# max score among faithfull cliques of 14 forms: 98.770552159
# purger Nombre de cliques 22
# max score among faithfull cliques of 17 forms: 152.761106649
# licencier Nombre de cliques 23
# max score among faithfull cliques of 12 forms: 77.8859081684
# dessiner Nombre de cliques 29
# max score among faithfull cliques of 24 forms: 293.911371105
# relever Nombre de cliques 79
# max score among faithfull cliques of 11 forms: 64.5020431713
# tapoter Nombre de cliques 200
# max score among faithfull cliques of 19 forms: 164.389377754
# jalonner Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 275.648373984
# réparer Nombre de cliques 72
# max score among faithfull cliques of 17 forms: 142.425154533
# consumer Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 274.379647964
# photographier Nombre de cliques 12
# max score among faithfull cliques of 12 forms: 76.28313778
# froncer Nombre de cliques 41
# max score among faithfull cliques of 19 forms: 187.492667849
# ruisseler Nombre de cliques 28
# max score among faithfull cliques of 15 forms: 117.246428571
# isoler Nombre de cliques 12
# max score among faithfull cliques of 15 forms: 117.197766794
# aspirer Nombre de cliques 33
# max score among faithfull cliques of 21 forms: 225.976255254
# contacter Nombre de cliques 24
# max score among faithfull cliques of 13 forms: 90.6948529412
# écouler Nombre de cliques 27
# max score among faithfull cliques of 16 forms: 134.97098108
# entasser Nombre de cliques 4
# max score among faithfull cliques of 20 forms: 204.650787377
# mentionner Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 230.026813956
# recharger Nombre de cliques 22
# max score among faithfull cliques of 20 forms: 209.06493933
# deviner Nombre de cliques 29
# max score among faithfull cliques of 19 forms: 185.126229078
# maudire Nombre de cliques 19
# max score among faithfull cliques of 13 forms: 87.4054487179
# astiquer Nombre de cliques 24
# max score among faithfull cliques of 21 forms: 229.61100653
# enrouer Nombre de cliques 1
# max score among faithfull cliques of 7 forms: 27.9526889904
# avouer Nombre de cliques 14
# max score among faithfull cliques of 5 forms: 13.625
# infliger Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 230.516148792
# débrancher Nombre de cliques 26
# max score among faithfull cliques of 18 forms: 169.983499755
# pétrir Nombre de cliques 31
# max score among faithfull cliques of 10 forms: 46.5375539296
# essuyer Nombre de cliques 19
# max score among faithfull cliques of 15 forms: 110.356759206
# tâcher Nombre de cliques 33
# max score among faithfull cliques of 19 forms: 189.152051123
# traverser Nombre de cliques 79
# max score among faithfull cliques of 21 forms: 218.161946663
# alourdir Nombre de cliques 25
# max score among faithfull cliques of 13 forms: 89.7387820513
# entretenir Nombre de cliques 68
# max score among faithfull cliques of 14 forms: 91.4055169822
# reposer Nombre de cliques 211
# max score among faithfull cliques of 9 forms: 40.0166596059
# griller Nombre de cliques 32
# max score among faithfull cliques of 13 forms: 86.467643218
# fleurir Nombre de cliques 28
# max score among faithfull cliques of 9 forms: 41.1967638205
# scandaliser Nombre de cliques 60
# max score among faithfull cliques of 21 forms: 227.894373781
# conspuer Nombre de cliques 3
# max score among faithfull cliques of 7 forms: 28.0
# revaloir Nombre de cliques 2
# max score among faithfull cliques of 8 forms: 36.0
# juguler Nombre de cliques 16
# max score among faithfull cliques of 17 forms: 151.855596465
# équiper Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 226.892100879
# observer Nombre de cliques 208
# max score among faithfull cliques of 17 forms: 139.875667306
# pressentir Nombre de cliques 51
# max score among faithfull cliques of 12 forms: 37.9989092705
# haïr Nombre de cliques 48
# max score among faithfull cliques of 7 forms: 19.2307692308
# sevrer Nombre de cliques 83
# max score among faithfull cliques of 15 forms: 116.575948836
# renouveler Nombre de cliques 75
# max score among faithfull cliques of 10 forms: 42.1694255733
# désigner Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 228.777996187
# traquer Nombre de cliques 24
# max score among faithfull cliques of 19 forms: 189.196462718
# débiner Nombre de cliques 19
# max score among faithfull cliques of 24 forms: 297.437493989
# siffloter Nombre de cliques 22
# max score among faithfull cliques of 22 forms: 237.885931991
# entreposer Nombre de cliques 38
# max score among faithfull cliques of 19 forms: 186.812546412
# introduire Nombre de cliques 32
# max score among faithfull cliques of 9 forms: 42.3064102564
# foncer Nombre de cliques 35
# max score among faithfull cliques of 19 forms: 186.89146242
# soûler Nombre de cliques 23
# max score among faithfull cliques of 17 forms: 152.154761905
# enlacer Nombre de cliques 17
# max score among faithfull cliques of 20 forms: 209.15840433
# galber Nombre de cliques 2
# max score among faithfull cliques of 5 forms: 14.9897260274
# souvenir Nombre de cliques 150
# max score among faithfull cliques of 13 forms: 82.3886744287
# gésir Nombre de cliques 28
# max score among faithfull cliques of 22 forms: 228.334639503
# programmer Nombre de cliques 17
# max score among faithfull cliques of 22 forms: 250.202225289
# adapter Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 119.872078969
# abandonner Nombre de cliques 36
# max score among faithfull cliques of 25 forms: 312.682979602
# sympathiser Nombre de cliques 132
# max score among faithfull cliques of 20 forms: 206.601845358
# incinérer Nombre de cliques 67
# max score among faithfull cliques of 16 forms: 134.670957896
# civiliser Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 227.894373781
# écourter Nombre de cliques 31
# max score among faithfull cliques of 18 forms: 167.305224045
# demander Nombre de cliques 56
# max score among faithfull cliques of 18 forms: 165.797804697
# déserter Nombre de cliques 146
# max score among faithfull cliques of 18 forms: 163.027787222
# bronzer Nombre de cliques 38
# max score among faithfull cliques of 19 forms: 187.921296529
# banaliser Nombre de cliques 39
# max score among faithfull cliques of 21 forms: 227.894373781
# parier Nombre de cliques 61
# max score among faithfull cliques of 8 forms: 21.6996897567
# pactiser Nombre de cliques 122
# max score among faithfull cliques of 20 forms: 206.601845358
# engoncer Nombre de cliques 8
# max score among faithfull cliques of 18 forms: 168.348007295
# dévêtir Nombre de cliques 19
# max score among faithfull cliques of 15 forms: 107.625
# mortifier Nombre de cliques 15
# max score among faithfull cliques of 12 forms: 77.5245761362
# abstenir Nombre de cliques 5
# max score among faithfull cliques of 11 forms: 60.7485819609
# maintenir Nombre de cliques 140
# max score among faithfull cliques of 10 forms: 49.2996509309
# exaspérer Nombre de cliques 127
# max score among faithfull cliques of 17 forms: 140.145868071
# retrouver Nombre de cliques 51
# max score among faithfull cliques of 22 forms: 242.413649595
# parler Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 276.0
# captiver Nombre de cliques 72
# max score among faithfull cliques of 22 forms: 246.421509351
# gausser Nombre de cliques 87
# max score among faithfull cliques of 17 forms: 141.872807362
# bagarrer Nombre de cliques 28
# max score among faithfull cliques of 18 forms: 165.905498213
# penser Nombre de cliques 52
# max score among faithfull cliques of 17 forms: 146.66050353
# tutoyer Nombre de cliques 29
# max score among faithfull cliques of 4 forms: 7.96458333333
# patienter Nombre de cliques 21
# max score among faithfull cliques of 18 forms: 164.888071048
# suivre Nombre de cliques 182
# max score among faithfull cliques of 17 forms: 114.355205891
# haranguer Nombre de cliques 24
# max score among faithfull cliques of 18 forms: 169.946462718
# regretter Nombre de cliques 90
# max score among faithfull cliques of 14 forms: 87.7105346644
# halluciner Nombre de cliques 22
# max score among faithfull cliques of 24 forms: 292.797779537
# horrifier Nombre de cliques 4
# max score among faithfull cliques of 11 forms: 65.7054487897
# évoquer Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 226.189610637
# immatriculer Nombre de cliques 6
# max score among faithfull cliques of 16 forms: 135.002465349
# taper Nombre de cliques 40
# max score among faithfull cliques of 24 forms: 283.140691443
# paraître Nombre de cliques 176
# max score among faithfull cliques of 10 forms: 49.1165504535
# empêcher Nombre de cliques 36
# max score among faithfull cliques of 16 forms: 135.660533112
# mentir Nombre de cliques 76
# max score among faithfull cliques of 7 forms: 18.0089027445
# éprendre Nombre de cliques 22
# max score among faithfull cliques of 19 forms: 172.810051713
# servir Nombre de cliques 414
# max score among faithfull cliques of 16 forms: 91.0080679372
# aboyer Nombre de cliques 10
# max score among faithfull cliques of 8 forms: 34.8333333333
# démentir Nombre de cliques 52
# max score among faithfull cliques of 19 forms: 172.099824821
# couper Nombre de cliques 40
# max score among faithfull cliques of 21 forms: 225.491745432
# réfugier Nombre de cliques 9
# max score among faithfull cliques of 2 forms: 3.0
# électrocuter Nombre de cliques 19
# max score among faithfull cliques of 21 forms: 228.119652043
# relancer Nombre de cliques 40
# max score among faithfull cliques of 18 forms: 168.816286053
# enorgueillir Nombre de cliques 77
# max score among faithfull cliques of 4 forms: 6.23717948718
# réserver Nombre de cliques 158
# max score among faithfull cliques of 18 forms: 161.878953998
# faner Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 227.091114178
# élargir Nombre de cliques 18
# max score among faithfull cliques of 7 forms: 27.8846153846
# hésiter Nombre de cliques 49
# max score among faithfull cliques of 22 forms: 232.881597097
# dessécher Nombre de cliques 28
# max score among faithfull cliques of 21 forms: 228.913441842
# intituler Nombre de cliques 7
# max score among faithfull cliques of 16 forms: 134.974992822
# peindre Nombre de cliques 44
# max score among faithfull cliques of 7 forms: 25.5493506494
# traiter Nombre de cliques 89
# max score among faithfull cliques of 23 forms: 232.938532242
# clouer Nombre de cliques 10
# max score among faithfull cliques of 2 forms: 3.0
# anesthésier Nombre de cliques 32
# max score among faithfull cliques of 7 forms: 27.9897260274
# éblouir Nombre de cliques 47
# max score among faithfull cliques of 3 forms: 5.85416666667
# voyager Nombre de cliques 24
# max score among faithfull cliques of 19 forms: 189.233499755
# débusquer Nombre de cliques 21
# max score among faithfull cliques of 17 forms: 152.95268899
# biler Nombre de cliques 18
# max score among faithfull cliques of 18 forms: 169.712739322
# marcher Nombre de cliques 32
# max score among faithfull cliques of 14 forms: 104.242489253
# caparaçonner Nombre de cliques 33
# max score among faithfull cliques of 23 forms: 271.569147354
# marchander Nombre de cliques 38
# max score among faithfull cliques of 18 forms: 153.512159528
# interpréter Nombre de cliques 65
# max score among faithfull cliques of 23 forms: 236.325503184
# raccommoder Nombre de cliques 53
# max score among faithfull cliques of 20 forms: 206.116836642
# apprivoiser Nombre de cliques 24
# max score among faithfull cliques of 21 forms: 221.147347871
# crécher Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 230.681319415
# négocier Nombre de cliques 18
# max score among faithfull cliques of 12 forms: 77.9526889904
# dépasser Nombre de cliques 42
# max score among faithfull cliques of 24 forms: 289.774369627
# emplir Nombre de cliques 42
# max score among faithfull cliques of 5 forms: 13.1575
# chasser Nombre de cliques 37
# max score among faithfull cliques of 22 forms: 238.515334064
# tasser Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 310.094123996
# paralyser Nombre de cliques 59
# max score among faithfull cliques of 21 forms: 227.668346384
# pécher Nombre de cliques 28
# max score among faithfull cliques of 21 forms: 229.829423578
# contenir Nombre de cliques 82
# max score among faithfull cliques of 15 forms: 103.622289859
# élever Nombre de cliques 146
# max score among faithfull cliques of 11 forms: 60.0809216967
# apaiser Nombre de cliques 202
# max score among faithfull cliques of 18 forms: 150.18573323
# asseoir Nombre de cliques 85
# max score among faithfull cliques of 20 forms: 160.203577678
# habituer Nombre de cliques 14
# max score among faithfull cliques of 6 forms: 20.8974928124
# proposer Nombre de cliques 143
# max score among faithfull cliques of 13 forms: 84.3151397829
# verser Nombre de cliques 48
# max score among faithfull cliques of 22 forms: 245.172693249
# unifier Nombre de cliques 15
# max score among faithfull cliques of 12 forms: 77.5245761362
# garnir Nombre de cliques 7
# max score among faithfull cliques of 7 forms: 26.516392372
# progresser Nombre de cliques 38
# max score among faithfull cliques of 24 forms: 274.713231454
# déconner Nombre de cliques 31
# max score among faithfull cliques of 21 forms: 229.568109503
# fréquenter Nombre de cliques 35
# max score among faithfull cliques of 18 forms: 157.352274033
# transformer Nombre de cliques 27
# max score among faithfull cliques of 18 forms: 167.629487066
# biffer Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 270.223697877
# embaumer Nombre de cliques 39
# max score among faithfull cliques of 23 forms: 274.625806993
# subventionner Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 230.026813956
# râler Nombre de cliques 15
# max score among faithfull cliques of 18 forms: 169.855596465
# contribuer Nombre de cliques 13
# max score among faithfull cliques of 5 forms: 15.0
# pallier Nombre de cliques 9
# max score among faithfull cliques of 6 forms: 21.0
# détacher Nombre de cliques 36
# max score among faithfull cliques of 13 forms: 88.8844632238
# regarder Nombre de cliques 41
# max score among faithfull cliques of 21 forms: 219.825225571
# trôner Nombre de cliques 69
# max score among faithfull cliques of 2 forms: 2.42307692308
# déjeuner Nombre de cliques 38
# max score among faithfull cliques of 16 forms: 131.953755514
# saccager Nombre de cliques 11
# max score among faithfull cliques of 19 forms: 189.233499755
# rouvrir Nombre de cliques 48
# max score among faithfull cliques of 3 forms: 5.73076923077
# parlementer Nombre de cliques 38
# max score among faithfull cliques of 19 forms: 182.578724233
# prévaloir Nombre de cliques 5
# max score among faithfull cliques of 9 forms: 42.1702380952
# aérer Nombre de cliques 86
# max score among faithfull cliques of 17 forms: 151.60932355
# poser Nombre de cliques 197
# max score among faithfull cliques of 16 forms: 126.957270524
# dîner Nombre de cliques 26
# max score among faithfull cliques of 24 forms: 290.296187653
# rouler Nombre de cliques 26
# max score among faithfull cliques of 16 forms: 132.572942338
# développer Nombre de cliques 25
# max score among faithfull cliques of 23 forms: 267.276944244
# fournir Nombre de cliques 110
# max score among faithfull cliques of 4 forms: 7.63492063492
# relâcher Nombre de cliques 22
# max score among faithfull cliques of 19 forms: 189.766148792
# palper Nombre de cliques 7
# max score among faithfull cliques of 4 forms: 10.0
# bâtir Nombre de cliques 50
# max score among faithfull cliques of 7 forms: 23.7472298535
# briser Nombre de cliques 29
# max score among faithfull cliques of 26 forms: 340.320023946
# flatter Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 268.277001011
# assassiner Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 296.76412569
# régir Nombre de cliques 21
# max score among faithfull cliques of 8 forms: 33.4561688312
# honorer Nombre de cliques 76
# max score among faithfull cliques of 17 forms: 136.511119867
# fourrer Nombre de cliques 66
# max score among faithfull cliques of 18 forms: 169.607437697
# fléchir Nombre de cliques 8
# max score among faithfull cliques of 6 forms: 20.9897260274
# viser Nombre de cliques 172
# max score among faithfull cliques of 17 forms: 139.992657229
# démultiplier Nombre de cliques 17
# max score among faithfull cliques of 12 forms: 76.1493433974
# intégrer Nombre de cliques 27
# max score among faithfull cliques of 14 forms: 104.119355657
# imposer Nombre de cliques 171
# max score among faithfull cliques of 11 forms: 61.3376905542
# cirer Nombre de cliques 28
# max score among faithfull cliques of 21 forms: 226.968653167
# détester Nombre de cliques 12
# max score among faithfull cliques of 24 forms: 299.391770749
# déboucler Nombre de cliques 7
# max score among faithfull cliques of 11 forms: 66.0
# maîtriser Nombre de cliques 19
# max score among faithfull cliques of 26 forms: 343.474729111
# démerder Nombre de cliques 306
# max score among faithfull cliques of 17 forms: 150.886127327
# déguerpir Nombre de cliques 35
# max score among faithfull cliques of 10 forms: 43.6546499296
# descendre Nombre de cliques 155
# max score among faithfull cliques of 15 forms: 91.9994162098
# coller Nombre de cliques 38
# max score among faithfull cliques of 16 forms: 127.902471333
# dandiner Nombre de cliques 14
# max score among faithfull cliques of 24 forms: 291.561196101
# délivrer Nombre de cliques 56
# max score among faithfull cliques of 13 forms: 89.2035283617
# cultiver Nombre de cliques 72
# max score among faithfull cliques of 22 forms: 246.165049265
# patauger Nombre de cliques 38
# max score among faithfull cliques of 20 forms: 203.8052373
# triompher Nombre de cliques 25
# max score among faithfull cliques of 16 forms: 135.395462846
# convoquer Nombre de cliques 21
# max score among faithfull cliques of 10 forms: 54.920212766
# ensemencer Nombre de cliques 27
# max score among faithfull cliques of 19 forms: 187.906397739
# renaître Nombre de cliques 19
# max score among faithfull cliques of 11 forms: 62.1396099497
# illustrer Nombre de cliques 20
# max score among faithfull cliques of 14 forms: 103.184777735
# paniquer Nombre de cliques 21
# max score among faithfull cliques of 7 forms: 27.7908928172
# saurer Nombre de cliques 27
# max score among faithfull cliques of 5 forms: 15.0
# réquisitionner Nombre de cliques 32
# max score among faithfull cliques of 21 forms: 227.31906464
# rattraper Nombre de cliques 39
# max score among faithfull cliques of 24 forms: 287.126781451
# effleurer Nombre de cliques 73
# max score among faithfull cliques of 17 forms: 152.601062974
# véhiculer Nombre de cliques 16
# max score among faithfull cliques of 17 forms: 151.855596465
# mutiler Nombre de cliques 21
# max score among faithfull cliques of 18 forms: 169.828123937
# déposer Nombre de cliques 172
# max score among faithfull cliques of 11 forms: 61.7366884783
# entuber Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 272.017653141
# balancer Nombre de cliques 43
# max score among faithfull cliques of 18 forms: 169.455435771
# lier Nombre de cliques 21
# max score among faithfull cliques of 6 forms: 17.0587840654
# ronfler Nombre de cliques 11
# max score among faithfull cliques of 15 forms: 120.0
# compartimenter Nombre de cliques 33
# max score among faithfull cliques of 19 forms: 180.139699842
# reconduire Nombre de cliques 13
# max score among faithfull cliques of 13 forms: 86.0607748606
# réfléchir Nombre de cliques 68
# max score among faithfull cliques of 9 forms: 42.8982729076
# effacer Nombre de cliques 42
# max score among faithfull cliques of 24 forms: 284.847778961
# carguer Nombre de cliques 13
# max score among faithfull cliques of 20 forms: 209.243655717
# mériter Nombre de cliques 19
# max score among faithfull cliques of 24 forms: 289.920499333
# pelotonner Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 271.569147354
# exister Nombre de cliques 19
# max score among faithfull cliques of 19 forms: 188.783376022
# inspecter Nombre de cliques 20
# max score among faithfull cliques of 15 forms: 119.872078969
# décorer Nombre de cliques 65
# max score among faithfull cliques of 16 forms: 131.300086365
# connaître Nombre de cliques 123
# max score among faithfull cliques of 25 forms: 307.020027815
# oeuvrer Nombre de cliques 73
# max score among faithfull cliques of 15 forms: 113.34285167
# grimper Nombre de cliques 63
# max score among faithfull cliques of 17 forms: 148.577093765
# griffer Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 318.027296107
# abreuver Nombre de cliques 136
# max score among faithfull cliques of 21 forms: 216.901552282
# occuper Nombre de cliques 35
# max score among faithfull cliques of 21 forms: 225.458034526
# bousculer Nombre de cliques 17
# max score among faithfull cliques of 17 forms: 150.419426252
# diviser Nombre de cliques 115
# max score among faithfull cliques of 19 forms: 187.962736446
# humilier Nombre de cliques 8
# max score among faithfull cliques of 5 forms: 14.9589041096
# racornir Nombre de cliques 1
# max score among faithfull cliques of 4 forms: 8.97083333333
# impressionner Nombre de cliques 32
# max score among faithfull cliques of 21 forms: 230.026813956
# tamponner Nombre de cliques 42
# max score among faithfull cliques of 23 forms: 269.342469776
# sculpter Nombre de cliques 6
# max score among faithfull cliques of 5 forms: 14.9589041096
# emporter Nombre de cliques 80
# max score among faithfull cliques of 17 forms: 139.340122671
# soucier Nombre de cliques 59
# max score among faithfull cliques of 6 forms: 17.2520833333
# rappeler Nombre de cliques 96
# max score among faithfull cliques of 13 forms: 80.0598505023
# ruiner Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 228.430886413
# attacher Nombre de cliques 30
# max score among faithfull cliques of 19 forms: 188.465082202
# cravacher Nombre de cliques 28
# max score among faithfull cliques of 19 forms: 189.609368196
# repartir Nombre de cliques 110
# max score among faithfull cliques of 13 forms: 56.2870220736
# creuser Nombre de cliques 94
# max score among faithfull cliques of 4 forms: 9.325
# retravailler Nombre de cliques 16
# max score among faithfull cliques of 15 forms: 111.034651139
# conserver Nombre de cliques 190
# max score among faithfull cliques of 16 forms: 127.932842844
# démasquer Nombre de cliques 17
# max score among faithfull cliques of 20 forms: 209.70268899
# peupler Nombre de cliques 12
# max score among faithfull cliques of 12 forms: 77.9897260274
# décider Nombre de cliques 36
# max score among faithfull cliques of 24 forms: 286.374598509
# éclore Nombre de cliques 0
# no new faithfull clique, the previous one contained 1 forms
# trimballer Nombre de cliques 17
# max score among faithfull cliques of 18 forms: 169.712739322
# tarder Nombre de cliques 53
# max score among faithfull cliques of 18 forms: 166.810175504
# rompre Nombre de cliques 70
# max score among faithfull cliques of 6 forms: 17.1282407407
# aventurer Nombre de cliques 25
# max score among faithfull cliques of 20 forms: 206.576860329
# pâlir Nombre de cliques 10
# max score among faithfull cliques of 6 forms: 21.0
# entonner Nombre de cliques 34
# max score among faithfull cliques of 23 forms: 271.569147354
# molester Nombre de cliques 10
# max score among faithfull cliques of 24 forms: 299.434578969
# dépeigner Nombre de cliques 39
# max score among faithfull cliques of 20 forms: 209.034198141
# attraper Nombre de cliques 44
# max score among faithfull cliques of 24 forms: 283.007500574
# protester Nombre de cliques 10
# max score among faithfull cliques of 24 forms: 299.434578969
# dinguer Nombre de cliques 27
# max score among faithfull cliques of 18 forms: 169.696462718
# extirper Nombre de cliques 26
# max score among faithfull cliques of 18 forms: 168.598273588
# siéger Nombre de cliques 22
# max score among faithfull cliques of 19 forms: 185.529811384
# rehausser Nombre de cliques 96
# max score among faithfull cliques of 21 forms: 210.197013074
# ritualiser Nombre de cliques 29
# max score among faithfull cliques of 21 forms: 227.894373781
# lotir Nombre de cliques 4
# max score among faithfull cliques of 6 forms: 19.380015083
# répliquer Nombre de cliques 11
# max score among faithfull cliques of 21 forms: 230.479111755
# séparer Nombre de cliques 83
# max score among faithfull cliques of 15 forms: 108.471614146
# transporter Nombre de cliques 66
# max score among faithfull cliques of 18 forms: 147.815955052
# incruster Nombre de cliques 16
# max score among faithfull cliques of 18 forms: 170.684578969
# guérir Nombre de cliques 66
# max score among faithfull cliques of 7 forms: 23.3272962454
# décimer Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 297.13912569
# céder Nombre de cliques 144
# max score among faithfull cliques of 13 forms: 82.7751265938
# gourer Nombre de cliques 55
# max score among faithfull cliques of 17 forms: 143.79012915
# malmener Nombre de cliques 96
# max score among faithfull cliques of 16 forms: 134.551905666
# sniffer Nombre de cliques 25
# max score among faithfull cliques of 21 forms: 229.348649678
# frire Nombre de cliques 8
# max score among faithfull cliques of 7 forms: 27.775862069
# redouter Nombre de cliques 43
# max score among faithfull cliques of 22 forms: 241.921243342
# doter Nombre de cliques 87
# max score among faithfull cliques of 20 forms: 194.813083586
# boitiller Nombre de cliques 14
# max score among faithfull cliques of 15 forms: 115.539273271
# rentrer Nombre de cliques 42
# max score among faithfull cliques of 18 forms: 161.545286366
# manager Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 119.989726027
# primer Nombre de cliques 25
# max score among faithfull cliques of 24 forms: 291.736736413
# enfoncer Nombre de cliques 47
# max score among faithfull cliques of 18 forms: 168.200678153
# polluer Nombre de cliques 5
# max score among faithfull cliques of 7 forms: 28.0
# dérober Nombre de cliques 94
# max score among faithfull cliques of 23 forms: 252.224111223
# recroqueviller Nombre de cliques 38
# max score among faithfull cliques of 12 forms: 64.0194075097
# donner Nombre de cliques 37
# max score among faithfull cliques of 26 forms: 341.980484136
# redonner Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 315.744679269
# gerber Nombre de cliques 42
# max score among faithfull cliques of 22 forms: 245.829433427
# écailler Nombre de cliques 1
# max score among faithfull cliques of 10 forms: 54.0053424564
# référer Nombre de cliques 138
# max score among faithfull cliques of 17 forms: 144.584836817
# tortiller Nombre de cliques 15
# max score among faithfull cliques of 14 forms: 100.684807781
# truquer Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 229.73661731
# brandir Nombre de cliques 101
# max score among faithfull cliques of 19 forms: 181.922913466
# imaginer Nombre de cliques 36
# max score among faithfull cliques of 16 forms: 133.045518287
# couler Nombre de cliques 33
# max score among faithfull cliques of 16 forms: 134.173622246
# alléger Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 228.280376434
# fatiguer Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 229.869722193
# chanceler Nombre de cliques 22
# max score among faithfull cliques of 15 forms: 118.579761905
# battre Nombre de cliques 176
# max score among faithfull cliques of 14 forms: 74.9819368758
# bénéficier Nombre de cliques 15
# max score among faithfull cliques of 12 forms: 77.9526889904
# frissonner Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 267.115792198
# avoyer Nombre de cliques 44
# max score among faithfull cliques of 11 forms: 55.7387170233
# pomper Nombre de cliques 33
# max score among faithfull cliques of 18 forms: 168.504576248
# entrouvrir Nombre de cliques 13
# max score among faithfull cliques of 8 forms: 33.9515493592
# bluffer Nombre de cliques 21
# max score among faithfull cliques of 22 forms: 251.590222512
# coucher Nombre de cliques 24
# max score among faithfull cliques of 16 forms: 135.230275351
# emmerder Nombre de cliques 311
# max score among faithfull cliques of 17 forms: 150.839894451
# mousser Nombre de cliques 22
# max score among faithfull cliques of 20 forms: 199.700173566
# distraire Nombre de cliques 47
# max score among faithfull cliques of 8 forms: 28.5048076923
# régler Nombre de cliques 31
# max score among faithfull cliques of 11 forms: 66.0
# calculer Nombre de cliques 23
# max score among faithfull cliques of 17 forms: 147.245886503
# naître Nombre de cliques 25
# max score among faithfull cliques of 5 forms: 14.5769230769
# consentir Nombre de cliques 114
# max score among faithfull cliques of 14 forms: 68.8088511407
# racheter Nombre de cliques 135
# max score among faithfull cliques of 10 forms: 42.0358104032
# magner Nombre de cliques 17
# max score among faithfull cliques of 19 forms: 189.821380622
# affermir Nombre de cliques 57
# max score among faithfull cliques of 18 forms: 153.654761905
# lever Nombre de cliques 115
# max score among faithfull cliques of 10 forms: 49.348816133
# attendre Nombre de cliques 128
# max score among faithfull cliques of 24 forms: 264.573955141
# accepter Nombre de cliques 27
# max score among faithfull cliques of 14 forms: 104.296736503
# hospitaliser Nombre de cliques 59
# max score among faithfull cliques of 21 forms: 227.668346384
# excommunier Nombre de cliques 13
# max score among faithfull cliques of 12 forms: 77.531855657
# arracher Nombre de cliques 35
# max score among faithfull cliques of 19 forms: 188.569979915
# ...
# dégauchir Nombre de cliques 11
# max score among faithfull cliques of 7 forms: 27.7846153846
# canoniser Nombre de cliques 25
# max score among faithfull cliques of 22 forms: 248.786399409
# retenir Nombre de cliques 92
# max score among faithfull cliques of 11 forms: 57.6859159091
# entamer Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 249.971922259
# délayer Nombre de cliques 12
# max score among faithfull cliques of 14 forms: 95.7208446666
# hérisser Nombre de cliques 45
# max score among faithfull cliques of 22 forms: 249.005784485
# traduire Nombre de cliques 32
# max score among faithfull cliques of 13 forms: 82.1718576895
# sceller Nombre de cliques 9
# max score among faithfull cliques of 17 forms: 149.434681259
# confronter Nombre de cliques 69
# max score among faithfull cliques of 17 forms: 149.796100416
# lorgner Nombre de cliques 27
# max score among faithfull cliques of 18 forms: 168.675102024
# claironner Nombre de cliques 33
# max score among faithfull cliques of 24 forms: 296.729861639
# pédaler Nombre de cliques 16
# max score among faithfull cliques of 18 forms: 168.244790604
# examiner Nombre de cliques 28
# max score among faithfull cliques of 21 forms: 230.505987298
# respecter Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 118.038745635
# répugner Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 225.985540045
# démanger Nombre de cliques 29
# max score among faithfull cliques of 17 forms: 151.12034809
# démolir Nombre de cliques 15
# max score among faithfull cliques of 5 forms: 13.2073903895
# accabler Nombre de cliques 29
# max score among faithfull cliques of 12 forms: 78.0
# goûter Nombre de cliques 35
# max score among faithfull cliques of 21 forms: 225.301198354
# broyer Nombre de cliques 6
# max score among faithfull cliques of 13 forms: 86.4421266234
# ouïr Nombre de cliques 8
# max score among faithfull cliques of 8 forms: 35.7846153846
# marteler Nombre de cliques 23
# max score among faithfull cliques of 14 forms: 103.579761905
# évaluer Nombre de cliques 5
# max score among faithfull cliques of 7 forms: 28.0
# froisser Nombre de cliques 16
# max score among faithfull cliques of 21 forms: 224.924902251
# inhumer Nombre de cliques 22
# max score among faithfull cliques of 21 forms: 230.709135724
# préparer Nombre de cliques 82
# max score among faithfull cliques of 17 forms: 138.252961985
# modérer Nombre de cliques 131
# max score among faithfull cliques of 17 forms: 150.146364219
# sauter Nombre de cliques 138
# max score among faithfull cliques of 11 forms: 58.6249586031
# baver Nombre de cliques 61
# max score among faithfull cliques of 14 forms: 99.8414446266
# déborder Nombre de cliques 101
# max score among faithfull cliques of 18 forms: 154.561997327
# tatouer Nombre de cliques 6
# max score among faithfull cliques of 7 forms: 28.0
# distancier Nombre de cliques 16
# max score among faithfull cliques of 12 forms: 77.9526889904
# remonter Nombre de cliques 51
# max score among faithfull cliques of 18 forms: 168.569015946
# bander Nombre de cliques 160
# max score among faithfull cliques of 11 forms: 60.3717948718
# refiler Nombre de cliques 24
# max score among faithfull cliques of 18 forms: 169.712739322
# barboter Nombre de cliques 140
# max score among faithfull cliques of 21 forms: 195.93903806
# débrouiller Nombre de cliques 3
# max score among faithfull cliques of 11 forms: 66.0
# picoler Nombre de cliques 25
# max score among faithfull cliques of 16 forms: 133.463616515
# crier Nombre de cliques 77
# max score among faithfull cliques of 11 forms: 57.2727089596
# caserner Nombre de cliques 74
# max score among faithfull cliques of 20 forms: 205.963500939
# voleter Nombre de cliques 17
# max score among faithfull cliques of 22 forms: 240.283945456
# enserrer Nombre de cliques 111
# max score among faithfull cliques of 17 forms: 149.896364219
# amalgamer Nombre de cliques 7
# max score among faithfull cliques of 21 forms: 228.876272321
# contredire Nombre de cliques 57
# max score among faithfull cliques of 13 forms: 88.5721153846
# dévisser Nombre de cliques 153
# max score among faithfull cliques of 20 forms: 204.826419406
# inscrire Nombre de cliques 85
# max score among faithfull cliques of 6 forms: 18.2142831803
# agréer Nombre de cliques 1
# max score among faithfull cliques of 4 forms: 10.0
# danser Nombre de cliques 51
# max score among faithfull cliques of 19 forms: 180.766513198
# impliquer Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 229.658511836
# tarer Nombre de cliques 44
# max score among faithfull cliques of 17 forms: 147.225842692
# témoigner Nombre de cliques 22
# max score among faithfull cliques of 19 forms: 189.57430006
# rêver Nombre de cliques 106
# max score among faithfull cliques of 20 forms: 193.463622539
# ravager Nombre de cliques 36
# max score among faithfull cliques of 19 forms: 188.737808563
# râper Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 268.342377482
# durer Nombre de cliques 42
# max score among faithfull cliques of 20 forms: 202.978887883
# deviser Nombre de cliques 109
# max score among faithfull cliques of 19 forms: 175.544606266
# représenter Nombre de cliques 98
# max score among faithfull cliques of 17 forms: 130.068375654
# étouffer Nombre de cliques 35
# max score among faithfull cliques of 12 forms: 77.5241817047
# vexer Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 119.817284448
# accoler Nombre de cliques 32
# max score among faithfull cliques of 16 forms: 129.338521108
# esquisser Nombre de cliques 28
# max score among faithfull cliques of 20 forms: 206.892098567
# oser Nombre de cliques 57
# max score among faithfull cliques of 9 forms: 42.6142857143
# élimer Nombre de cliques 7
# max score among faithfull cliques of 23 forms: 275.330192166
# dépendre Nombre de cliques 108
# max score among faithfull cliques of 10 forms: 47.0651688016
# raffiner Nombre de cliques 22
# max score among faithfull cliques of 24 forms: 296.76412569
# angoisser Nombre de cliques 15
# max score among faithfull cliques of 21 forms: 225.486094484
# accentuer Nombre de cliques 1
# max score among faithfull cliques of 6 forms: 21.0
# infiltrer Nombre de cliques 24
# max score among faithfull cliques of 15 forms: 117.639843094
# recommander Nombre de cliques 50
# max score among faithfull cliques of 17 forms: 147.560220204
# becter Nombre de cliques 21
# max score among faithfull cliques of 15 forms: 119.707695407
# crouler Nombre de cliques 23
# max score among faithfull cliques of 18 forms: 164.639791505
# tremper Nombre de cliques 33
# max score among faithfull cliques of 18 forms: 166.092144378
# négliger Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 230.290121394
# manigancer Nombre de cliques 36
# max score among faithfull cliques of 18 forms: 165.634130857
# vaincre Nombre de cliques 8
# max score among faithfull cliques of 2 forms: 3.0
# joncher Nombre de cliques 20
# max score among faithfull cliques of 17 forms: 151.421079867
# arborer Nombre de cliques 75
# max score among faithfull cliques of 19 forms: 162.637109862
# puer Nombre de cliques 21
# max score among faithfull cliques of 5 forms: 15.0
# miauler Nombre de cliques 15
# max score among faithfull cliques of 17 forms: 146.714069681
# miner Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 230.505987298
# philosopher Nombre de cliques 91
# max score among faithfull cliques of 21 forms: 227.686750038
# merder Nombre de cliques 306
# max score among faithfull cliques of 17 forms: 150.886127327
# contester Nombre de cliques 10
# max score among faithfull cliques of 24 forms: 299.434578969
# bosser Nombre de cliques 261
# max score among faithfull cliques of 18 forms: 156.822819555
# déplier Nombre de cliques 37
# max score among faithfull cliques of 12 forms: 72.1639299017
# objecter Nombre de cliques 25
# max score among faithfull cliques of 15 forms: 116.705412302
# décompresser Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 289.793294425
# écoeurer Nombre de cliques 106
# max score among faithfull cliques of 4 forms: 9.125
# investir Nombre de cliques 20
# max score among faithfull cliques of 10 forms: 53.3554487179
# analyser Nombre de cliques 62
# max score among faithfull cliques of 21 forms: 227.894373781
# faufiler Nombre de cliques 21
# max score among faithfull cliques of 18 forms: 169.712739322
# persuader Nombre de cliques 29
# max score among faithfull cliques of 21 forms: 215.895351582
# éviter Nombre de cliques 47
# max score among faithfull cliques of 22 forms: 239.183655023
# langer Nombre de cliques 23
# max score among faithfull cliques of 18 forms: 170.516148792
# ébahir Nombre de cliques 4
# max score among faithfull cliques of 6 forms: 21.0
# brailler Nombre de cliques 30
# max score among faithfull cliques of 12 forms: 71.8784527341
# fondre Nombre de cliques 25
# max score among faithfull cliques of 10 forms: 48.1583926629
# baigner Nombre de cliques 50
# max score among faithfull cliques of 20 forms: 208.373461213
# ressurgir Nombre de cliques 45
# max score among faithfull cliques of 19 forms: 182.40517722
# survivre Nombre de cliques 205
# max score among faithfull cliques of 7 forms: 23.5481575964
# ouvrir Nombre de cliques 109
# max score among faithfull cliques of 15 forms: 106.447387888
# renverser Nombre de cliques 72
# max score among faithfull cliques of 21 forms: 219.553483587
# dorer Nombre de cliques 56
# max score among faithfull cliques of 17 forms: 150.923154341
# bouger Nombre de cliques 28
# max score among faithfull cliques of 21 forms: 230.106093471
# localiser Nombre de cliques 61
# max score among faithfull cliques of 21 forms: 227.781360082
# nommer Nombre de cliques 35
# max score among faithfull cliques of 21 forms: 229.923210461
# jauger Nombre de cliques 24
# max score among faithfull cliques of 19 forms: 181.382404495
# approuver Nombre de cliques 42
# max score among faithfull cliques of 24 forms: 283.878081465
# enfermer Nombre de cliques 48
# max score among faithfull cliques of 22 forms: 246.352548858
# chuchoter Nombre de cliques 130
# max score among faithfull cliques of 18 forms: 164.53758954
# achever Nombre de cliques 150
# max score among faithfull cliques of 9 forms: 34.4994290458
# déboîter Nombre de cliques 18
# max score among faithfull cliques of 21 forms: 223.373422434
# prononcer Nombre de cliques 37
# max score among faithfull cliques of 18 forms: 168.836027105
# jubiler Nombre de cliques 20
# max score among faithfull cliques of 18 forms: 169.712739322
# boiter Nombre de cliques 20
# max score among faithfull cliques of 21 forms: 223.373422434
# offrir Nombre de cliques 90
# max score among faithfull cliques of 11 forms: 54.162085456
# dissiper Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 265.878234031
# freiner Nombre de cliques 236
# max score among faithfull cliques of 20 forms: 186.244295904
# promettre Nombre de cliques 163
# max score among faithfull cliques of 10 forms: 43.1438761228
# perfectionner Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 230.026813956
# embrasser Nombre de cliques 23
# max score among faithfull cliques of 24 forms: 291.621575404
# suffire Nombre de cliques 129
# max score among faithfull cliques of 7 forms: 19.9694895788
# endiguer Nombre de cliques 24
# max score among faithfull cliques of 21 forms: 229.792386541
# répercuter Nombre de cliques 22
# max score among faithfull cliques of 21 forms: 228.34567944
# précéder Nombre de cliques 154
# max score among faithfull cliques of 20 forms: 186.866245825
# répertorier Nombre de cliques 27
# max score among faithfull cliques of 9 forms: 43.0266160185
# piller Nombre de cliques 23
# max score among faithfull cliques of 15 forms: 112.020693167
# baiser Nombre de cliques 252
# max score among faithfull cliques of 15 forms: 107.632708486
# placer Nombre de cliques 30
# max score among faithfull cliques of 22 forms: 250.724225285
# résumer Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 298.379647964
# cercler Nombre de cliques 26
# max score among faithfull cliques of 12 forms: 78.0
# marier Nombre de cliques 56
# max score among faithfull cliques of 9 forms: 38.5879827494
# évoluer Nombre de cliques 5
# max score among faithfull cliques of 7 forms: 28.0
# allonger Nombre de cliques 34
# max score among faithfull cliques of 18 forms: 170.283750046
# puiser Nombre de cliques 126
# max score among faithfull cliques of 7 forms: 25.2459677419
# faillir Nombre de cliques 22
# max score among faithfull cliques of 6 forms: 20.7231710768
# compenser Nombre de cliques 53
# max score among faithfull cliques of 17 forms: 143.808122611
# signer Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 229.635694815
# pétrifier Nombre de cliques 17
# max score among faithfull cliques of 12 forms: 75.2039720457
# faciliter Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 298.590222512
# jouir Nombre de cliques 16
# max score among faithfull cliques of 8 forms: 35.7846153846
# chercher Nombre de cliques 38
# max score among faithfull cliques of 19 forms: 189.345952456
# repentir Nombre de cliques 24
# max score among faithfull cliques of 9 forms: 43.7400075415
# nuire Nombre de cliques 13
# max score among faithfull cliques of 13 forms: 85.5607748606
# bégayer Nombre de cliques 24
# max score among faithfull cliques of 14 forms: 81.2331992623
# dédicacer Nombre de cliques 22
# max score among faithfull cliques of 22 forms: 234.810060168
# coiffer Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 224.230424496
# chialer Nombre de cliques 12
# max score among faithfull cliques of 17 forms: 152.160454764
# saigner Nombre de cliques 54
# max score among faithfull cliques of 20 forms: 203.27711673
# plaquer Nombre de cliques 27
# max score among faithfull cliques of 19 forms: 188.610111866
# monter Nombre de cliques 51
# max score among faithfull cliques of 19 forms: 186.084671751
# broder Nombre de cliques 91
# max score among faithfull cliques of 21 forms: 215.015994426
# participer Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 261.55435317
# préserver Nombre de cliques 138
# max score among faithfull cliques of 19 forms: 182.619268592
# rebeller Nombre de cliques 72
# max score among faithfull cliques of 15 forms: 118.127465349
# radoter Nombre de cliques 109
# max score among faithfull cliques of 21 forms: 223.230432316
# importuner Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 274.004647964
# annuler Nombre de cliques 18
# max score among faithfull cliques of 16 forms: 135.357159165
# conspirer Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 212.376395784
# comparer Nombre de cliques 63
# max score among faithfull cliques of 17 forms: 139.758626811
# atterrir Nombre de cliques 63
# max score among faithfull cliques of 7 forms: 25.3222341954
# renseigner Nombre de cliques 49
# max score among faithfull cliques of 20 forms: 209.034198141
# envisager Nombre de cliques 27
# max score among faithfull cliques of 19 forms: 188.737808563
# dresser Nombre de cliques 46
# max score among faithfull cliques of 24 forms: 282.371650056
# blasphémer Nombre de cliques 41
# max score among faithfull cliques of 22 forms: 230.18578169
# éteindre Nombre de cliques 57
# max score among faithfull cliques of 8 forms: 34.1041666667
# apprécier Nombre de cliques 80
# max score among faithfull cliques of 6 forms: 18.5364583333
# raidir Nombre de cliques 38
# max score among faithfull cliques of 13 forms: 74.8228695324
# dénicher Nombre de cliques 24
# max score among faithfull cliques of 19 forms: 189.620662279
# dérouiller Nombre de cliques 18
# max score among faithfull cliques of 15 forms: 119.090325511
# aviser Nombre de cliques 162
# max score among faithfull cliques of 19 forms: 172.152002892
# décrire Nombre de cliques 109
# max score among faithfull cliques of 6 forms: 15.49
# saisir Nombre de cliques 176
# max score among faithfull cliques of 6 forms: 14.6160470513
# augmenter Nombre de cliques 39
# max score among faithfull cliques of 19 forms: 182.510231082
# bouleverser Nombre de cliques 64
# max score among faithfull cliques of 21 forms: 223.556426126
# piger Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 229.980108509
# évanouir Nombre de cliques 13
# max score among faithfull cliques of 5 forms: 14.7013718144
# CPU times: user 34min 14s, sys: 1min 49s, total: 36min 3s
# Wall time: 34min 29s

# %%
newParadigmes,paradigmesSwim1,characteristicsSwim1,measuresSwim1=calculerResultats(swim1ContextParadigmes,"-Swim1")
# Out:
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 escamoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 commenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 sangler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enquiquiner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 coter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 grossir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ménager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 priver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 métamorphoser
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 esquisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gicler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chiner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déménager
# LEXEME WITH A NON UNIQUE PARADIGM PB 6 combler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 surnommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 cingler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 borner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lessiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 piocher
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 redresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 apposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 clamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cantonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 clapoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 attribuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rejouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rabâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chantonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 enrichir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tapisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 adopter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 délester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 téléphoner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mijoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 retapisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 purger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tapoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 consumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 conspuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 revaloir
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 équiper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 traquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 siffloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entreposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 introduire
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déserter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 alerter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 buter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 captiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décomposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 démentir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 couper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 électrocuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hésiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 voyager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 caparaçonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 insister
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 garnir
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 progresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 transformer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 biffer
# LEXEME WITH A NON UNIQUE PARADIGM PB 7 déjeuner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 saccager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 parlementer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 développer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 relâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 briser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cultiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 triompher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ensemencer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 illustrer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 effleurer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entuber
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ronfler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 compartimenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 effacer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mériter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 pelotonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décorer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 griffer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tamponner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 affirmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 attacher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cravacher
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 trembler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 molester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 protester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rehausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 malmener
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 redouter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 doter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enfoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 polluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 brandir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 frissonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 bluffer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 boucler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 excommunier
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 arracher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 soupçonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 frotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 pâtisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 sommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enthousiasmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 draguer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 parsemer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 accompagner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dompter
# LEXEME WITH A NON UNIQUE PARADIGM PB 8 jongler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 défoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 claquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 aimanter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 acclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 ajourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 piloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entrechoquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 recommencer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 embêter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 délaisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 klaxonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 préoccuper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rajouter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 discontinuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 redoubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 aboutir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déboucler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 confesser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 égoutter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 rebondir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 égaliser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 aménager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déformer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 disperser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gigoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 essouffler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 amadouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 héberger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 encourager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fraiser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 flipper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 désintéresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 engraisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 motiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 informer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dérouter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 proclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 former
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 bourrer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mincir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 coupler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 feindre
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 flotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 déchaîner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cuire
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 agrafer
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 meubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 défrayer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 accoutumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 reboutonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 consolider
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 haleter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 expérimenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 alimenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 allouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 plisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 épingler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 transpercer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 dégainer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 retracer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ruer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 envoûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cogner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 blesser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 disposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 assumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 léser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 goder
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 ingurgiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inonder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 arranger
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 cogiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 gêner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 façonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 discerner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 habiliter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 consommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 souder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hanter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dénigrer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 abriter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 égorger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rechercher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déconcerter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 louper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 enfler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 choquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 liter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 séjourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 désarmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 exclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décourager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 goutter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 présager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 horrifier
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 interposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 armer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 recruter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 grelotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 hisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 détonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 craquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 engluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 écoper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déboutonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 transposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 outrager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 baguer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mécher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 accoucher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renifler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 affleurer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chiffonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 braquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 nager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 camoufler
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 partager
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 agresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 diffuser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décorner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tripoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ligoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 muscler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cracher
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 racler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hériter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 languir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 recoucher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 énoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 sursauter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 réclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 assister
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cocher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inclure
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cuber
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 blâmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 choper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 adresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fuser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 noyauter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 réaffirmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 remâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 acharner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 désactiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 écosser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 infuser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cramponner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enflammer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 remporter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 huer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 conformer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 activer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gifler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 agripper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 écorcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 vouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chahuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renfermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 remanger
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 caresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 exercer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tâtonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 poster
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 mugir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 planer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 charmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 savourer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 noircir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rechigner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 grouper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 joncher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 accouder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rengorger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 sangloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 réapparaître
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 éluder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 coûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tituber
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rallier
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dégotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 discuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 siffler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 pallier
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 empester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 noter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 boutonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 friser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dégoûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 terrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 échanger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 submerger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 réagir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 envelopper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 évacuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 resplendir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lutter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 labourer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 louer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 charcuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 peloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 émerger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dénoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 échafauder
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 féliciter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tracer
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 encercler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 nommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 embarrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 atténuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 indisposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 souffler
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 contourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 visiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 amocher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 border
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 agiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 découper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 embrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déchausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tarir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gober
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 irriter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 empresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cacher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 débarrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 quitter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inviter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 troubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 immerger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 juger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 refermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dévaster
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hérisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lorgner
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 démanger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 affubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 accabler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 goûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ouïr
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 plaquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 évaluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déborder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tatouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 voleter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dévisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 importuner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ravager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 amincir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 contester
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 décompresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 éviter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 détourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 ressurgir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 jauger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enfermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chuchoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 cercler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 évoluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 faciliter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 jouir
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 broder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 envisager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 blasphémer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dénicher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 augmenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 bouleverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 escamoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 commenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 sangler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enquiquiner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 coter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 grossir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ménager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 priver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 métamorphoser
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 esquisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gicler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chiner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déménager
# LEXEME WITH A NON UNIQUE PARADIGM PB 6 combler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 surnommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 cingler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 borner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lessiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 piocher
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 redresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 apposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 clamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cantonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 clapoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 attribuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rejouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rabâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chantonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 enrichir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tapisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 adopter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 délester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 téléphoner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mijoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 retapisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 purger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tapoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 consumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 conspuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 revaloir
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 équiper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 traquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 siffloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entreposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 introduire
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déserter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 alerter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 buter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 captiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décomposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 démentir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 couper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 électrocuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hésiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 voyager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 caparaçonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 insister
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 garnir
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 progresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 transformer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 biffer
# LEXEME WITH A NON UNIQUE PARADIGM PB 7 déjeuner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 saccager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 parlementer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 développer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 relâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 briser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cultiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 triompher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ensemencer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 illustrer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 effleurer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entuber
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ronfler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 compartimenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 effacer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mériter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 pelotonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décorer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 griffer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tamponner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 affirmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 attacher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cravacher
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 trembler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 molester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 protester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rehausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 malmener
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 redouter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 doter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enfoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 polluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 brandir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 frissonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 bluffer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 boucler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 excommunier
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 arracher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 soupçonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 frotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 pâtisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 sommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enthousiasmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 draguer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 parsemer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 accompagner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dompter
# LEXEME WITH A NON UNIQUE PARADIGM PB 8 jongler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 défoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 claquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 aimanter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 acclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 ajourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 piloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 entrechoquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 recommencer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 embêter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 délaisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 klaxonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 préoccuper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rajouter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 discontinuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 redoubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 aboutir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déboucler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 confesser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 égoutter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 rebondir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 égaliser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 aménager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déformer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 disperser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gigoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 essouffler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 amadouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 héberger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 encourager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fraiser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 flipper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 désintéresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 engraisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 motiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 informer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dérouter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 proclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 former
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 bourrer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mincir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 coupler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 feindre
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 flotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 déchaîner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cuire
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 agrafer
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 meubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 défrayer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 accoutumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 reboutonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 consolider
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 haleter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 expérimenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 alimenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 allouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 plisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 épingler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 transpercer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 dégainer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 retracer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ruer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 envoûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cogner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 blesser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 disposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 assumer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 léser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 goder
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 ingurgiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inonder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 arranger
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 cogiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 gêner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 façonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 discerner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 habiliter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 consommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 souder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hanter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dénigrer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 abriter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 égorger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rechercher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déconcerter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 louper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 enfler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 choquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 liter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 séjourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 désarmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 exclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décourager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 goutter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 présager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 horrifier
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 interposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 armer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 recruter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 grelotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 hisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 détonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 craquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 engluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 écoper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déboutonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 transposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 outrager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 baguer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mécher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 accoucher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renifler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 affleurer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chiffonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 braquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 nager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 camoufler
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 partager
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 agresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 diffuser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 décorner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tripoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ligoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 muscler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cracher
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 racler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hériter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 languir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 recoucher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 énoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 sursauter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 réclamer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 assister
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renoncer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cocher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inclure
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cuber
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 blâmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 choper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 adresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 fuser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 noyauter
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 réaffirmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 remâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 acharner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 désactiver
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 écosser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 infuser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cramponner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enflammer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 remporter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 huer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 conformer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 activer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gifler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 agripper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 écorcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 vouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chahuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renfermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 remanger
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 caresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 exercer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tâtonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 poster
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 mugir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 planer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 charmer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 savourer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 noircir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rechigner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 grouper
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 joncher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 accouder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rengorger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 sangloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 réapparaître
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 éluder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 coûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tituber
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 rallier
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dégotter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 discuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 siffler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 pallier
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 empester
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 noter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 boutonner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 friser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dégoûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 terrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 échanger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 submerger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 réagir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 envelopper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 évacuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 resplendir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lutter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 labourer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 louer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 charcuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 peloter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 émerger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dénoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 échafauder
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 féliciter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tracer
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 encercler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 nommer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 embarrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 atténuer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 indisposer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 souffler
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 contourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 visiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 amocher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 border
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 agiter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 découper
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 embrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déchausser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tarir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 gober
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 irriter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 empresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 cacher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 débarrasser
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 quitter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 inviter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chuter
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 troubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 immerger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 juger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 mâcher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 refermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dévaster
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 hérisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 lorgner
# LEXEME WITH A NON UNIQUE PARADIGM PB 4 démanger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 affubler
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 accabler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 goûter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ouïr
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 plaquer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 évaluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 déborder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 tatouer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 voleter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dévisser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 importuner
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 ravager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 amincir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 contester
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 décompresser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 éviter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 détourner
# LEXEME WITH A NON UNIQUE PARADIGM PB 5 ressurgir
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 renverser
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 jauger
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 enfermer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 chuchoter
# LEXEME WITH A NON UNIQUE PARADIGM PB 10 cercler
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 évoluer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 faciliter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 jouir
# LEXEME WITH A NON UNIQUE PARADIGM PB 3 broder
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 envisager
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 blasphémer
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 dénicher
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 augmenter
# LEXEME WITH A NON UNIQUE PARADIGM PB 2 bouleverser
# UG 71150 OG 401 TP 24618 FP 682
# recall 0.255241057543 precision 0.957861561807
# 0.403074882727

# %% [markdown]
# # SWIM2

# %% [markdown]
# ## Préparation des paradigmes

# %%
paradigmesOriginaux=paradigmes.copy()
paradigmesSample=paradigmesOriginaux[paradigmesOriginaux["lexeme"].isin(listeTest)]

# %%
paradigmes=newParadigmes.copy()
paradigmesColumns=paradigmes.columns.tolist()
for c in sampleCases:
    if not c in paradigmesColumns:
        print (c)
        paradigmes[c]=np.NaN

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim2ContextParadigmes=generateCliques(contextFree=True)
# Out:
# 2017-12-30 14:59:23.659073
# escamoter Nombre de cliques 1703
# no new faithfull clique, the previous one contained 1 forms
# assembler Nombre de cliques 1887
# max score among faithfull cliques of 26 forms: 209.483153338
# projeter Nombre de cliques 2496
# no new faithfull clique, the previous one contained 1 forms
# aider Nombre de cliques 2154
# max score among faithfull cliques of 22 forms: 132.720127302
# pratiquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# ranimer Nombre de cliques 2065
# max score among faithfull cliques of 30 forms: 279.15910309
# offenser Nombre de cliques 2034
# no new faithfull clique, the previous one contained 1 forms
# voter Nombre de cliques 2157
# no new faithfull clique, the previous one contained 1 forms
# surprendre Nombre de cliques 2589
# max score among faithfull cliques of 28 forms: 107.567211916
# devenir Nombre de cliques 2760
# max score among faithfull cliques of 26 forms: 167.854559061
# remâcher Nombre de cliques 1843
# no new faithfull clique, the previous one contained 1 forms
# débouler Nombre de cliques 2257
# no new faithfull clique, the previous one contained 1 forms
# engueuler Nombre de cliques 605
# max score among faithfull cliques of 9 forms: 28.1803859015
# dénuer Nombre de cliques 2112
# max score among faithfull cliques of 16 forms: 57.4441524952
# déverser Nombre de cliques 2340
# no new faithfull clique, the previous one contained 1 forms
# voir Nombre de cliques 3790
# max score among faithfull cliques of 32 forms: 205.351598892
# adhérer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# persister Nombre de cliques 2040
# max score among faithfull cliques of 30 forms: 265.126689134
# commenter Nombre de cliques 1615
# max score among faithfull cliques of 30 forms: 281.918001734
# rapprocher Nombre de cliques 1939
# max score among faithfull cliques of 28 forms: 241.310299895
# rutiler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# sangler Nombre de cliques 1892
# max score among faithfull cliques of 26 forms: 209.66430884
# perpétuer Nombre de cliques 2110
# max score among faithfull cliques of 16 forms: 57.4441524952
# chauffer Nombre de cliques 2351
# max score among faithfull cliques of 14 forms: 53.3923203047
# dépayser Nombre de cliques 2671
# no new faithfull clique, the previous one contained 1 forms
# pencher Nombre de cliques 1798
# max score among faithfull cliques of 25 forms: 209.340135509
# agrandir Nombre de cliques 1627
# max score among faithfull cliques of 32 forms: 164.903898112
# retransmettre Nombre de cliques 1589
# max score among faithfull cliques of 24 forms: 88.6390208325
# moucharder Nombre de cliques 2244
# max score among faithfull cliques of 29 forms: 256.371592217
# remplacer Nombre de cliques 2292
# max score among faithfull cliques of 26 forms: 181.772669232
# risquer Nombre de cliques 1974
# max score among faithfull cliques of 30 forms: 285.001659837
# enquiquiner Nombre de cliques 1991
# max score among faithfull cliques of 30 forms: 293.024090425
# coter Nombre de cliques 1445
# no new faithfull clique, the previous one contained 1 forms
# reprocher Nombre de cliques 1940
# max score among faithfull cliques of 28 forms: 243.658478811
# supplier Nombre de cliques 2266
# max score among faithfull cliques of 12 forms: 47.1886974269
# grossir Nombre de cliques 2392
# max score among faithfull cliques of 25 forms: 165.38149554
# revivre Nombre de cliques 1907
# max score among faithfull cliques of 17 forms: 71.4101744274
# tanguer Nombre de cliques 1800
# max score among faithfull cliques of 30 forms: 302.671032846
# susciter Nombre de cliques 2113
# max score among faithfull cliques of 30 forms: 270.74562103
# terroriser Nombre de cliques 2714
# no new faithfull clique, the previous one contained 1 forms
# figer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# indiquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# repérer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# désosser Nombre de cliques 1615
# no new faithfull clique, the previous one contained 1 forms
# visualiser Nombre de cliques 2633
# no new faithfull clique, the previous one contained 1 forms
# changer Nombre de cliques 1988
# max score among faithfull cliques of 30 forms: 278.837222148
# appeler Nombre de cliques 2726
# max score among faithfull cliques of 23 forms: 140.612690987
# prêcher Nombre de cliques 2074
# no new faithfull clique, the previous one contained 1 forms
# dégager Nombre de cliques 1640
# max score among faithfull cliques of 30 forms: 292.243478319
# unir Nombre de cliques 725
# max score among faithfull cliques of 11 forms: 27.91408447
# acharner Nombre de cliques 1990
# max score among faithfull cliques of 30 forms: 286.769676645
# ménager Nombre de cliques 1983
# max score among faithfull cliques of 30 forms: 287.28180896
# invoquer Nombre de cliques 2006
# max score among faithfull cliques of 29 forms: 259.12597684
# barbouiller Nombre de cliques 2992
# no new faithfull clique, the previous one contained 1 forms
# priver Nombre de cliques 2472
# max score among faithfull cliques of 26 forms: 197.678041106
# encadrer Nombre de cliques 1794
# max score among faithfull cliques of 29 forms: 265.48503441
# métamorphoser Nombre de cliques 2184
# no new faithfull clique, the previous one contained 1 forms
# exploser Nombre de cliques 2357
# max score among faithfull cliques of 17 forms: 87.700239804
# rugir Nombre de cliques 715
# max score among faithfull cliques of 19 forms: 67.5977749524
# menacer Nombre de cliques 2371
# max score among faithfull cliques of 26 forms: 181.071692711
# redevenir Nombre de cliques 3295
# max score among faithfull cliques of 29 forms: 220.99741177
# avaler Nombre de cliques 1719
# no new faithfull clique, the previous one contained 1 forms
# aligner Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# gicler Nombre de cliques 2046
# max score among faithfull cliques of 26 forms: 201.743981863
# mirer Nombre de cliques 1955
# max score among faithfull cliques of 29 forms: 266.849804749
# sortir Nombre de cliques 2602
# max score among faithfull cliques of 21 forms: 56.2950185388
# berner Nombre de cliques 2039
# max score among faithfull cliques of 30 forms: 284.871843088
# estimer Nombre de cliques 2075
# max score among faithfull cliques of 30 forms: 286.48847588
# précipiter Nombre de cliques 2112
# max score among faithfull cliques of 30 forms: 271.638145611
# orner Nombre de cliques 1914
# max score among faithfull cliques of 30 forms: 288.34784663
# déclencher Nombre de cliques 1399
# max score among faithfull cliques of 25 forms: 191.597229442
# dérider Nombre de cliques 2215
# no new faithfull clique, the previous one contained 1 forms
# débattre Nombre de cliques 1136
# max score among faithfull cliques of 28 forms: 133.476500492
# divorcer Nombre de cliques 2471
# no new faithfull clique, the previous one contained 1 forms
# dénombrer Nombre de cliques 2028
# max score among faithfull cliques of 29 forms: 252.826715573
# prôner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 248.789818368
# falloir Nombre de cliques 1768
# max score among faithfull cliques of 9 forms: 16.3129876692
# relire Nombre de cliques 1686
# no new faithfull clique, the previous one contained 1 forms
# citer Nombre de cliques 2113
# max score among faithfull cliques of 30 forms: 270.74562103
# enliser Nombre de cliques 2542
# no new faithfull clique, the previous one contained 1 forms
# réchauffer Nombre de cliques 1635
# max score among faithfull cliques of 16 forms: 75.0917045886
# tondre Nombre de cliques 2163
# max score among faithfull cliques of 15 forms: 32.5523896399
# polir Nombre de cliques 1628
# max score among faithfull cliques of 29 forms: 115.259174119
# prostituer Nombre de cliques 1305
# max score among faithfull cliques of 17 forms: 111.512549284
# cotiser Nombre de cliques 2672
# no new faithfull clique, the previous one contained 1 forms
# destiner Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.828611355
# mépriser Nombre de cliques 2714
# no new faithfull clique, the previous one contained 1 forms
# douter Nombre de cliques 1692
# max score among faithfull cliques of 30 forms: 262.965804009
# rassurer Nombre de cliques 2084
# max score among faithfull cliques of 29 forms: 269.100984359
# épouvanter Nombre de cliques 1625
# max score among faithfull cliques of 30 forms: 277.605599489
# suggérer Nombre de cliques 2244
# no new faithfull clique, the previous one contained 1 forms
# prévenir Nombre de cliques 3293
# max score among faithfull cliques of 29 forms: 220.99741177
# vibrer Nombre de cliques 2028
# max score among faithfull cliques of 29 forms: 252.826715573
# chiner Nombre de cliques 1991
# max score among faithfull cliques of 30 forms: 293.024090425
# déménager Nombre de cliques 1983
# max score among faithfull cliques of 30 forms: 287.28180896
# combler Nombre de cliques 1828
# max score among faithfull cliques of 26 forms: 215.704071087
# plier Nombre de cliques 2266
# max score among faithfull cliques of 12 forms: 47.1886974269
# exagérer Nombre de cliques 2244
# no new faithfull clique, the previous one contained 1 forms
# affubler Nombre de cliques 1887
# max score among faithfull cliques of 26 forms: 209.483153338
# sillonner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# défiler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# anoblir Nombre de cliques 634
# max score among faithfull cliques of 17 forms: 47.4688459871
# bouillir Nombre de cliques 1369
# max score among faithfull cliques of 4 forms: 3.49287362423
# amorcer Nombre de cliques 2471
# no new faithfull clique, the previous one contained 1 forms
# surnommer Nombre de cliques 2078
# max score among faithfull cliques of 29 forms: 239.410675285
# réduire Nombre de cliques 1651
# max score among faithfull cliques of 17 forms: 61.755968621
# boire Nombre de cliques 3286
# max score among faithfull cliques of 14 forms: 39.9742207169
# refléter Nombre de cliques 1976
# no new faithfull clique, the previous one contained 1 forms
# ériger Nombre de cliques 2002
# max score among faithfull cliques of 30 forms: 290.789975916
# cingler Nombre de cliques 1892
# max score among faithfull cliques of 26 forms: 209.66430884
# rader Nombre de cliques 2194
# no new faithfull clique, the previous one contained 1 forms
# obséder Nombre de cliques 2364
# no new faithfull clique, the previous one contained 1 forms
# émaner Nombre de cliques 2042
# max score among faithfull cliques of 30 forms: 282.595283763
# subsister Nombre de cliques 2040
# max score among faithfull cliques of 30 forms: 265.126689134
# concevoir Nombre de cliques 3221
# max score among faithfull cliques of 28 forms: 131.516459847
# pulluler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# confirmer Nombre de cliques 1550
# max score among faithfull cliques of 30 forms: 302.918163296
# borner Nombre de cliques 1923
# max score among faithfull cliques of 30 forms: 284.078694107
# reparler Nombre de cliques 2120
# max score among faithfull cliques of 26 forms: 214.389203214
# croquer Nombre de cliques 2006
# max score among faithfull cliques of 29 forms: 259.12597684
# mettre Nombre de cliques 2428
# max score among faithfull cliques of 24 forms: 82.0121852594
# incendier Nombre de cliques 2980
# max score among faithfull cliques of 18 forms: 80.2123950406
# vivre Nombre de cliques 2675
# max score among faithfull cliques of 17 forms: 71.7479517212
# surgir Nombre de cliques 1986
# max score among faithfull cliques of 12 forms: 24.8937065998
# glacer Nombre de cliques 2339
# max score among faithfull cliques of 26 forms: 186.847957399
# lessiver Nombre de cliques 2522
# no new faithfull clique, the previous one contained 1 forms
# affecter Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 280.227784933
# chérir Nombre de cliques 1967
# max score among faithfull cliques of 13 forms: 32.716232889
# ajuster Nombre de cliques 2040
# max score among faithfull cliques of 30 forms: 265.126689134
# exaucer Nombre de cliques 1586
# no new faithfull clique, the previous one contained 1 forms
# agneler Nombre de cliques 1646
# no new faithfull clique, the previous one contained 1 forms
# choir Nombre de cliques 441
# max score among faithfull cliques of 28 forms: 98.8572579585
# couronner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 248.789818368
# piocher Nombre de cliques 1915
# max score among faithfull cliques of 28 forms: 241.665464811
# écrire Nombre de cliques 2785
# max score among faithfull cliques of 18 forms: 45.3994086611
# stabiliser Nombre de cliques 2542
# no new faithfull clique, the previous one contained 1 forms
# diminuer Nombre de cliques 2112
# max score among faithfull cliques of 16 forms: 57.4441524952
# rayonner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# créer Nombre de cliques 1362
# max score among faithfull cliques of 6 forms: 17.7115603928
# désobéir Nombre de cliques 508
# max score among faithfull cliques of 16 forms: 44.5922865169
# palpiter Nombre de cliques 2112
# max score among faithfull cliques of 30 forms: 271.638145611
# redresser Nombre de cliques 2586
# no new faithfull clique, the previous one contained 1 forms
# reconstituer Nombre de cliques 2110
# max score among faithfull cliques of 16 forms: 57.4441524952
# réécrire Nombre de cliques 2147
# max score among faithfull cliques of 18 forms: 35.8099246709
# retourner Nombre de cliques 1748
# max score among faithfull cliques of 29 forms: 284.487535638
# apposer Nombre de cliques 2175
# no new faithfull clique, the previous one contained 1 forms
# insister Nombre de cliques 1939
# max score among faithfull cliques of 30 forms: 277.987909114
# assurer Nombre de cliques 2084
# max score among faithfull cliques of 29 forms: 269.100984359
# emprisonner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 248.789818368
# disputer Nombre de cliques 2068
# max score among faithfull cliques of 30 forms: 277.069074149
# droguer Nombre de cliques 2006
# max score among faithfull cliques of 29 forms: 259.12597684
# enlever Nombre de cliques 2645
# max score among faithfull cliques of 16 forms: 51.4433517874
# sauver Nombre de cliques 2134
# max score among faithfull cliques of 19 forms: 107.670874538
# entraîner Nombre de cliques 2218
# no new faithfull clique, the previous one contained 1 forms
# cantonner Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 249.846501565
# clapoter Nombre de cliques 1742
# max score among faithfull cliques of 26 forms: 222.036864087
# redéfinir Nombre de cliques 2327
# no new faithfull clique, the previous one contained 1 forms
# enfuir Nombre de cliques 1769
# max score among faithfull cliques of 27 forms: 100.114099826
# attribuer Nombre de cliques 1304
# max score among faithfull cliques of 17 forms: 111.512549284
# salir Nombre de cliques 755
# max score among faithfull cliques of 16 forms: 59.3116631437
# étaler Nombre de cliques 1724
# no new faithfull clique, the previous one contained 1 forms
# rejouer Nombre de cliques 787
# max score among faithfull cliques of 32 forms: 314.07828141
# embrouiller Nombre de cliques 2992
# no new faithfull clique, the previous one contained 1 forms
# rabâcher Nombre de cliques 1847
# no new faithfull clique, the previous one contained 1 forms
# croître Nombre de cliques 736
# max score among faithfull cliques of 29 forms: 113.730605044
# enfanter Nombre de cliques 1625
# max score among faithfull cliques of 30 forms: 277.605599489
# promener Nombre de cliques 1759
# max score among faithfull cliques of 11 forms: 33.0624710659
# construire Nombre de cliques 2131
# max score among faithfull cliques of 29 forms: 173.989245908
# entrevoir Nombre de cliques 1134
# max score among faithfull cliques of 31 forms: 103.074857837
# concéder Nombre de cliques 2377
# no new faithfull clique, the previous one contained 1 forms
# enrichir Nombre de cliques 2376
# max score among faithfull cliques of 25 forms: 162.224541904
# carrer Nombre de cliques 2012
# max score among faithfull cliques of 29 forms: 272.992135071
# dévider Nombre de cliques 2166
# no new faithfull clique, the previous one contained 1 forms
# tapisser Nombre de cliques 2435
# max score among faithfull cliques of 25 forms: 165.733991764
# momifier Nombre de cliques 1969
# no new faithfull clique, the previous one contained 1 forms
# ravir Nombre de cliques 1602
# no new faithfull clique, the previous one contained 1 forms
# grignoter Nombre de cliques 2165
# no new faithfull clique, the previous one contained 1 forms
# ennuyer Nombre de cliques 2445
# max score among faithfull cliques of 10 forms: 20.6025310429
# injecter Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 280.227784933
# économiser Nombre de cliques 2668
# no new faithfull clique, the previous one contained 1 forms
# chanter Nombre de cliques 1580
# no new faithfull clique, the previous one contained 1 forms
# cerner Nombre de cliques 2043
# max score among faithfull cliques of 30 forms: 281.003685114
# délester Nombre de cliques 2090
# max score among faithfull cliques of 30 forms: 275.611160659
# exulter Nombre de cliques 51
# max score among faithfull cliques of 30 forms: 346.990499397
# confier Nombre de cliques 2900
# no new faithfull clique, the previous one contained 1 forms
# prendre Nombre de cliques 3550
# max score among faithfull cliques of 28 forms: 125.591268919
# tirer Nombre de cliques 2124
# max score among faithfull cliques of 29 forms: 255.971544847
# ancrer Nombre de cliques 2037
# max score among faithfull cliques of 29 forms: 262.434238663
# effectuer Nombre de cliques 2110
# max score among faithfull cliques of 16 forms: 57.4441524952
# classer Nombre de cliques 2357
# max score among faithfull cliques of 26 forms: 178.020965006
# téléphoner Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 249.846501565
# repenser Nombre de cliques 2034
# no new faithfull clique, the previous one contained 1 forms
# enchanter Nombre de cliques 1607
# max score among faithfull cliques of 30 forms: 277.91857959
# spécialiser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# préciser Nombre de cliques 2658
# no new faithfull clique, the previous one contained 1 forms
# caler Nombre de cliques 2236
# no new faithfull clique, the previous one contained 1 forms
# arrimer Nombre de cliques 2084
# max score among faithfull cliques of 30 forms: 285.393995375
# absorber Nombre de cliques 1909
# max score among faithfull cliques of 30 forms: 289.07338651
# découler Nombre de cliques 2259
# no new faithfull clique, the previous one contained 1 forms
# coincer Nombre de cliques 2284
# max score among faithfull cliques of 25 forms: 183.990900384
# latter Nombre de cliques 2055
# max score among faithfull cliques of 30 forms: 277.301237669
# forcer Nombre de cliques 2422
# max score among faithfull cliques of 25 forms: 177.235441199
# rétrécir Nombre de cliques 1322
# no new faithfull clique, the previous one contained 1 forms
# retapisser Nombre de cliques 2449
# no new faithfull clique, the previous one contained 1 forms
# végéter Nombre de cliques 2135
# no new faithfull clique, the previous one contained 1 forms
# incurver Nombre de cliques 2488
# no new faithfull clique, the previous one contained 1 forms
# manifester Nombre de cliques 1020
# max score among faithfull cliques of 30 forms: 277.849260396
# revêtir Nombre de cliques 1023
# max score among faithfull cliques of 5 forms: 4.76885685342
# ausculter Nombre de cliques 1533
# max score among faithfull cliques of 30 forms: 265.005439085
# réchapper Nombre de cliques 2050
# max score among faithfull cliques of 30 forms: 279.215934819
# confondre Nombre de cliques 1629
# max score among faithfull cliques of 15 forms: 44.7682830904
# vérifier Nombre de cliques 2995
# max score among faithfull cliques of 9 forms: 11.5411663708
# réviser Nombre de cliques 2586
# no new faithfull clique, the previous one contained 1 forms
# plaindre Nombre de cliques 3491
# max score among faithfull cliques of 8 forms: 15.8362086865
# exclure Nombre de cliques 870
# max score among faithfull cliques of 7 forms: 9.12557858799
# advenir Nombre de cliques 2514
# max score among faithfull cliques of 29 forms: 227.88268944
# purger Nombre de cliques 1974
# max score among faithfull cliques of 30 forms: 285.001659837
# licencier Nombre de cliques 2005
# no new faithfull clique, the previous one contained 1 forms
# dessiner Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.828611355
# relever Nombre de cliques 2716
# no new faithfull clique, the previous one contained 1 forms
# tapoter Nombre de cliques 1719
# max score among faithfull cliques of 26 forms: 220.893662203
# jalonner Nombre de cliques 2007
# no new faithfull clique, the previous one contained 1 forms
# réparer Nombre de cliques 1904
# max score among faithfull cliques of 29 forms: 277.231007693
# consumer Nombre de cliques 2072
# max score among faithfull cliques of 30 forms: 286.81203054
# photographier Nombre de cliques 1969
# no new faithfull clique, the previous one contained 1 forms
# froncer Nombre de cliques 2354
# no new faithfull clique, the previous one contained 1 forms
# ruisseler Nombre de cliques 1615
# no new faithfull clique, the previous one contained 1 forms
# isoler Nombre de cliques 1694
# max score among faithfull cliques of 26 forms: 206.892266706
# aspirer Nombre de cliques 2084
# max score among faithfull cliques of 29 forms: 269.100984359
# contacter Nombre de cliques 1773
# max score among faithfull cliques of 29 forms: 261.01316947
# écouler Nombre de cliques 2259
# no new faithfull clique, the previous one contained 1 forms
# entasser Nombre de cliques 2300
# max score among faithfull cliques of 26 forms: 195.153404646
# mentionner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# recharger Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 290.997367353
# deviner Nombre de cliques 2002
# max score among faithfull cliques of 30 forms: 285.26110217
# maudire Nombre de cliques 1720
# max score among faithfull cliques of 32 forms: 164.903898112
# astiquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# enrouer Nombre de cliques 1461
# max score among faithfull cliques of 23 forms: 182.161413329
# avouer Nombre de cliques 2171
# max score among faithfull cliques of 10 forms: 29.2143465348
# infliger Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# débrancher Nombre de cliques 1944
# max score among faithfull cliques of 28 forms: 264.742942499
# pétrir Nombre de cliques 1804
# max score among faithfull cliques of 26 forms: 110.968145238
# essuyer Nombre de cliques 2927
# no new faithfull clique, the previous one contained 1 forms
# tâcher Nombre de cliques 1848
# no new faithfull clique, the previous one contained 1 forms
# traverser Nombre de cliques 2369
# no new faithfull clique, the previous one contained 1 forms
# alourdir Nombre de cliques 1668
# max score among faithfull cliques of 32 forms: 164.903898112
# entretenir Nombre de cliques 2794
# max score among faithfull cliques of 29 forms: 198.315209012
# reposer Nombre de cliques 2903
# max score among faithfull cliques of 17 forms: 86.9698454162
# griller Nombre de cliques 3094
# no new faithfull clique, the previous one contained 1 forms
# fleurir Nombre de cliques 2115
# no new faithfull clique, the previous one contained 1 forms
# scandaliser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# conspuer Nombre de cliques 1180
# max score among faithfull cliques of 17 forms: 119.579746188
# revaloir Nombre de cliques 823
# max score among faithfull cliques of 13 forms: 72.6903797714
# juguler Nombre de cliques 2113
# max score among faithfull cliques of 26 forms: 211.902906031
# équiper Nombre de cliques 2012
# max score among faithfull cliques of 30 forms: 284.048616978
# observer Nombre de cliques 2440
# max score among faithfull cliques of 27 forms: 222.348143022
# pressentir Nombre de cliques 1905
# max score among faithfull cliques of 18 forms: 41.6823403584
# haïr Nombre de cliques 2350
# max score among faithfull cliques of 7 forms: 7.88078738919
# sevrer Nombre de cliques 1219
# max score among faithfull cliques of 28 forms: 261.037061263
# renouveler Nombre de cliques 1999
# max score among faithfull cliques of 23 forms: 139.725596839
# désigner Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# traquer Nombre de cliques 1989
# max score among faithfull cliques of 30 forms: 287.338672332
# débiner Nombre de cliques 2050
# max score among faithfull cliques of 30 forms: 288.935927761
# siffloter Nombre de cliques 2103
# no new faithfull clique, the previous one contained 1 forms
# entreposer Nombre de cliques 2175
# no new faithfull clique, the previous one contained 1 forms
# introduire Nombre de cliques 1789
# max score among faithfull cliques of 27 forms: 118.68019071
# foncer Nombre de cliques 2224
# no new faithfull clique, the previous one contained 1 forms
# soûler Nombre de cliques 2257
# no new faithfull clique, the previous one contained 1 forms
# enlacer Nombre de cliques 2300
# max score among faithfull cliques of 26 forms: 195.153404646
# galber Nombre de cliques 485
# max score among faithfull cliques of 30 forms: 334.250827536
# souvenir Nombre de cliques 2626
# max score among faithfull cliques of 26 forms: 140.899721868
# gésir Nombre de cliques 2681
# no new faithfull clique, the previous one contained 1 forms
# programmer Nombre de cliques 2075
# max score among faithfull cliques of 30 forms: 278.857105489
# adapter Nombre de cliques 1984
# max score among faithfull cliques of 30 forms: 280.227784933
# abandonner Nombre de cliques 2047
# max score among faithfull cliques of 29 forms: 246.765676571
# sympathiser Nombre de cliques 2657
# no new faithfull clique, the previous one contained 1 forms
# incinérer Nombre de cliques 1732
# no new faithfull clique, the previous one contained 1 forms
# civiliser Nombre de cliques 2542
# no new faithfull clique, the previous one contained 1 forms
# écourter Nombre de cliques 1998
# max score among faithfull cliques of 30 forms: 266.832217836
# demander Nombre de cliques 1480
# max score among faithfull cliques of 28 forms: 235.893396563
# déserter Nombre de cliques 2077
# max score among faithfull cliques of 30 forms: 280.024236316
# bronzer Nombre de cliques 2567
# no new faithfull clique, the previous one contained 1 forms
# banaliser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# parier Nombre de cliques 2931
# max score among faithfull cliques of 13 forms: 42.4751265968
# pactiser Nombre de cliques 2657
# no new faithfull clique, the previous one contained 1 forms
# engoncer Nombre de cliques 2152
# no new faithfull clique, the previous one contained 1 forms
# dévêtir Nombre de cliques 1372
# max score among faithfull cliques of 33 forms: 299.419527527
# mortifier Nombre de cliques 1969
# no new faithfull clique, the previous one contained 1 forms
# abstenir Nombre de cliques 2521
# max score among faithfull cliques of 29 forms: 203.692439237
# maintenir Nombre de cliques 2169
# max score among faithfull cliques of 26 forms: 169.276214765
# exaspérer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# retrouver Nombre de cliques 2514
# no new faithfull clique, the previous one contained 1 forms
# parler Nombre de cliques 2121
# max score among faithfull cliques of 25 forms: 209.982558266
# captiver Nombre de cliques 2551
# no new faithfull clique, the previous one contained 1 forms
# gausser Nombre de cliques 1562
# no new faithfull clique, the previous one contained 1 forms
# bagarrer Nombre de cliques 2012
# max score among faithfull cliques of 29 forms: 272.992135071
# penser Nombre de cliques 2237
# max score among faithfull cliques of 22 forms: 163.826279364
# tutoyer Nombre de cliques 1788
# max score among faithfull cliques of 18 forms: 72.582817498
# patienter Nombre de cliques 1581
# no new faithfull clique, the previous one contained 1 forms
# suivre Nombre de cliques 2716
# max score among faithfull cliques of 17 forms: 44.5343659825
# haranguer Nombre de cliques 1800
# max score among faithfull cliques of 30 forms: 302.671032846
# regretter Nombre de cliques 1798
# no new faithfull clique, the previous one contained 1 forms
# halluciner Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.828611355
# horrifier Nombre de cliques 1870
# no new faithfull clique, the previous one contained 1 forms
# évoquer Nombre de cliques 2006
# max score among faithfull cliques of 29 forms: 259.12597684
# immatriculer Nombre de cliques 1585
# max score among faithfull cliques of 25 forms: 224.148263198
# taper Nombre de cliques 2061
# max score among faithfull cliques of 30 forms: 282.308626822
# paraître Nombre de cliques 2012
# max score among faithfull cliques of 12 forms: 21.0968904645
# empêcher Nombre de cliques 1950
# no new faithfull clique, the previous one contained 1 forms
# mentir Nombre de cliques 1443
# max score among faithfull cliques of 18 forms: 41.9051831651
# éprendre Nombre de cliques 2732
# max score among faithfull cliques of 28 forms: 119.283677777
# servir Nombre de cliques 2729
# max score among faithfull cliques of 16 forms: 38.5259582234
# aboyer Nombre de cliques 1522
# max score among faithfull cliques of 19 forms: 71.3562261271
# démentir Nombre de cliques 1820
# max score among faithfull cliques of 30 forms: 276.846906657
# couper Nombre de cliques 2328
# no new faithfull clique, the previous one contained 1 forms
# réfugier Nombre de cliques 642
# max score among faithfull cliques of 8 forms: 13.3553096432
# électrocuter Nombre de cliques 2037
# max score among faithfull cliques of 30 forms: 279.922960196
# relancer Nombre de cliques 2234
# max score among faithfull cliques of 24 forms: 183.642037892
# enorgueillir Nombre de cliques 1490
# max score among faithfull cliques of 11 forms: 31.2043390052
# réserver Nombre de cliques 2321
# no new faithfull clique, the previous one contained 1 forms
# faner Nombre de cliques 2043
# max score among faithfull cliques of 30 forms: 278.855189871
# élargir Nombre de cliques 623
# max score among faithfull cliques of 29 forms: 175.285568315
# hésiter Nombre de cliques 2113
# max score among faithfull cliques of 30 forms: 270.728850919
# dessécher Nombre de cliques 2074
# no new faithfull clique, the previous one contained 1 forms
# intituler Nombre de cliques 1585
# max score among faithfull cliques of 25 forms: 224.148263198
# peindre Nombre de cliques 2397
# max score among faithfull cliques of 8 forms: 16.6680726622
# traiter Nombre de cliques 2177
# no new faithfull clique, the previous one contained 1 forms
# clouer Nombre de cliques 935
# max score among faithfull cliques of 12 forms: 33.7735626558
# anesthésier Nombre de cliques 1859
# max score among faithfull cliques of 18 forms: 122.535477063
# éblouir Nombre de cliques 1215
# max score among faithfull cliques of 15 forms: 36.2133178917
# voyager Nombre de cliques 1984
# max score among faithfull cliques of 30 forms: 291.102449854
# débusquer Nombre de cliques 1974
# max score among faithfull cliques of 30 forms: 285.001659837
# biler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# marcher Nombre de cliques 1856
# max score among faithfull cliques of 25 forms: 207.136972778
# caparaçonner Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 249.846501565
# marchander Nombre de cliques 1265
# no new faithfull clique, the previous one contained 1 forms
# interpréter Nombre de cliques 2168
# no new faithfull clique, the previous one contained 1 forms
# raccommoder Nombre de cliques 2247
# no new faithfull clique, the previous one contained 1 forms
# apprivoiser Nombre de cliques 2721
# no new faithfull clique, the previous one contained 1 forms
# crécher Nombre de cliques 2074
# no new faithfull clique, the previous one contained 1 forms
# négocier Nombre de cliques 2003
# no new faithfull clique, the previous one contained 1 forms
# dépasser Nombre de cliques 2437
# max score among faithfull cliques of 26 forms: 184.246210835
# emplir Nombre de cliques 1691
# max score among faithfull cliques of 14 forms: 29.0804757671
# chasser Nombre de cliques 2367
# max score among faithfull cliques of 26 forms: 181.071692711
# tasser Nombre de cliques 2385
# max score among faithfull cliques of 26 forms: 183.003710132
# paralyser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# pécher Nombre de cliques 2074
# no new faithfull clique, the previous one contained 1 forms
# contenir Nombre de cliques 3095
# max score among faithfull cliques of 29 forms: 194.361138599
# élever Nombre de cliques 2762
# max score among faithfull cliques of 16 forms: 60.0353779152
# apaiser Nombre de cliques 2848
# no new faithfull clique, the previous one contained 1 forms
# asseoir Nombre de cliques 4879
# max score among faithfull cliques of 20 forms: 46.9411755197
# habituer Nombre de cliques 1223
# max score among faithfull cliques of 10 forms: 33.5927501886
# proposer Nombre de cliques 2384
# max score among faithfull cliques of 18 forms: 102.246735454
# verser Nombre de cliques 2345
# no new faithfull clique, the previous one contained 1 forms
# unifier Nombre de cliques 1969
# no new faithfull clique, the previous one contained 1 forms
# garnir Nombre de cliques 910
# max score among faithfull cliques of 19 forms: 80.6049032167
# progresser Nombre de cliques 2569
# no new faithfull clique, the previous one contained 1 forms
# déconner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# fréquenter Nombre de cliques 1607
# max score among faithfull cliques of 30 forms: 277.91857959
# transformer Nombre de cliques 1848
# max score among faithfull cliques of 30 forms: 291.764891995
# biffer Nombre de cliques 1949
# max score among faithfull cliques of 30 forms: 291.984097909
# embaumer Nombre de cliques 2708
# no new faithfull clique, the previous one contained 1 forms
# subventionner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# râler Nombre de cliques 2240
# no new faithfull clique, the previous one contained 1 forms
# contribuer Nombre de cliques 1346
# max score among faithfull cliques of 16 forms: 64.2456563536
# pallier Nombre de cliques 1689
# max score among faithfull cliques of 18 forms: 115.845966908
# détacher Nombre de cliques 1353
# no new faithfull clique, the previous one contained 1 forms
# regarder Nombre de cliques 2244
# max score among faithfull cliques of 29 forms: 256.371592217
# trôner Nombre de cliques 1284
# max score among faithfull cliques of 16 forms: 60.0439844233
# déjeuner Nombre de cliques 1793
# no new faithfull clique, the previous one contained 1 forms
# saccager Nombre de cliques 1990
# max score among faithfull cliques of 30 forms: 293.709792819
# rouvrir Nombre de cliques 771
# max score among faithfull cliques of 27 forms: 127.28412837
# parlementer Nombre de cliques 1820
# max score among faithfull cliques of 30 forms: 276.846906657
# prévaloir Nombre de cliques 920
# max score among faithfull cliques of 16 forms: 61.1230930278
# aérer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# poser Nombre de cliques 3239
# max score among faithfull cliques of 16 forms: 74.6075726726
# dîner Nombre de cliques 2050
# max score among faithfull cliques of 30 forms: 288.935927761
# rouler Nombre de cliques 1735
# no new faithfull clique, the previous one contained 1 forms
# développer Nombre de cliques 2020
# no new faithfull clique, the previous one contained 1 forms
# fournir Nombre de cliques 1597
# max score among faithfull cliques of 12 forms: 26.5637715641
# relâcher Nombre de cliques 1846
# no new faithfull clique, the previous one contained 1 forms
# palper Nombre de cliques 1324
# max score among faithfull cliques of 30 forms: 280.002037145
# bâtir Nombre de cliques 1470
# no new faithfull clique, the previous one contained 1 forms
# briser Nombre de cliques 2714
# no new faithfull clique, the previous one contained 1 forms
# flatter Nombre de cliques 2055
# max score among faithfull cliques of 30 forms: 277.301237669
# assassiner Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.828611355
# régir Nombre de cliques 2188
# max score among faithfull cliques of 16 forms: 46.1364055379
# honorer Nombre de cliques 1935
# max score among faithfull cliques of 29 forms: 257.564069905
# fourrer Nombre de cliques 2374
# max score among faithfull cliques of 29 forms: 263.775180679
# fléchir Nombre de cliques 701
# max score among faithfull cliques of 18 forms: 63.2276370646
# viser Nombre de cliques 1771
# no new faithfull clique, the previous one contained 1 forms
# démultiplier Nombre de cliques 2570
# no new faithfull clique, the previous one contained 1 forms
# intégrer Nombre de cliques 1969
# max score among faithfull cliques of 29 forms: 265.138422408
# imposer Nombre de cliques 1948
# no new faithfull clique, the previous one contained 1 forms
# cirer Nombre de cliques 2084
# max score among faithfull cliques of 29 forms: 269.100984359
# détester Nombre de cliques 2090
# max score among faithfull cliques of 30 forms: 275.611160659
# déboucler Nombre de cliques 1593
# max score among faithfull cliques of 26 forms: 219.790634254
# maîtriser Nombre de cliques 2714
# no new faithfull clique, the previous one contained 1 forms
# démerder Nombre de cliques 2163
# no new faithfull clique, the previous one contained 1 forms
# déguerpir Nombre de cliques 892
# max score among faithfull cliques of 19 forms: 98.2558974591
# descendre Nombre de cliques 1593
# max score among faithfull cliques of 22 forms: 86.8397116347
# coller Nombre de cliques 1809
# max score among faithfull cliques of 26 forms: 203.161014339
# dandiner Nombre de cliques 2050
# max score among faithfull cliques of 30 forms: 288.935927761
# délivrer Nombre de cliques 1136
# max score among faithfull cliques of 29 forms: 278.869668865
# cultiver Nombre de cliques 2552
# no new faithfull clique, the previous one contained 1 forms
# patauger Nombre de cliques 1845
# max score among faithfull cliques of 29 forms: 263.208802183
# triompher Nombre de cliques 1606
# max score among faithfull cliques of 30 forms: 297.365442212
# convoquer Nombre de cliques 1519
# max score among faithfull cliques of 26 forms: 212.564690444
# ensemencer Nombre de cliques 2246
# no new faithfull clique, the previous one contained 1 forms
# renaître Nombre de cliques 879
# no new faithfull clique, the previous one contained 1 forms
# illustrer Nombre de cliques 1969
# max score among faithfull cliques of 29 forms: 265.138422408
# paniquer Nombre de cliques 530
# max score among faithfull cliques of 25 forms: 244.589451953
# saurer Nombre de cliques 776
# max score among faithfull cliques of 22 forms: 181.734749197
# réquisitionner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# rattraper Nombre de cliques 2061
# max score among faithfull cliques of 30 forms: 282.308626822
# effleurer Nombre de cliques 2329
# no new faithfull clique, the previous one contained 1 forms
# véhiculer Nombre de cliques 2113
# max score among faithfull cliques of 26 forms: 211.902906031
# mutiler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# déposer Nombre de cliques 2164
# max score among faithfull cliques of 18 forms: 103.214782885
# entuber Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.450888583
# balancer Nombre de cliques 2234
# max score among faithfull cliques of 24 forms: 183.642037892
# lier Nombre de cliques 1963
# max score among faithfull cliques of 13 forms: 43.7268594771
# ronfler Nombre de cliques 2088
# max score among faithfull cliques of 26 forms: 207.374476694
# compartimenter Nombre de cliques 1615
# max score among faithfull cliques of 30 forms: 281.918001734
# reconduire Nombre de cliques 2803
# max score among faithfull cliques of 27 forms: 133.593386787
# réfléchir Nombre de cliques 2739
# max score among faithfull cliques of 11 forms: 18.0132754503
# effacer Nombre de cliques 2426
# max score among faithfull cliques of 26 forms: 184.246210835
# carguer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 290.997367353
# mériter Nombre de cliques 2121
# max score among faithfull cliques of 30 forms: 274.210703501
# pelotonner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 246.13157732
# exister Nombre de cliques 2040
# max score among faithfull cliques of 30 forms: 265.126689134
# inspecter Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 280.227784933
# décorer Nombre de cliques 1329
# max score among faithfull cliques of 29 forms: 262.708654686
# connaître Nombre de cliques 2773
# max score among faithfull cliques of 25 forms: 100.891976199
# oeuvrer Nombre de cliques 1219
# max score among faithfull cliques of 28 forms: 261.037061263
# grimper Nombre de cliques 1889
# max score among faithfull cliques of 30 forms: 295.362101693
# griffer Nombre de cliques 2036
# max score among faithfull cliques of 30 forms: 284.526086915
# abreuver Nombre de cliques 2595
# no new faithfull clique, the previous one contained 1 forms
# occuper Nombre de cliques 1988
# max score among faithfull cliques of 30 forms: 291.582134952
# bousculer Nombre de cliques 2113
# max score among faithfull cliques of 26 forms: 211.902906031
# diviser Nombre de cliques 2586
# no new faithfull clique, the previous one contained 1 forms
# humilier Nombre de cliques 1617
# max score among faithfull cliques of 18 forms: 123.731478653
# racornir Nombre de cliques 171
# max score among faithfull cliques of 19 forms: 88.3952438682
# impressionner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# tamponner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 246.13157732
# sculpter Nombre de cliques 74
# max score among faithfull cliques of 30 forms: 343.736469191
# emporter Nombre de cliques 1601
# max score among faithfull cliques of 29 forms: 271.52001937
# soucier Nombre de cliques 2627
# max score among faithfull cliques of 13 forms: 44.0584498032
# rappeler Nombre de cliques 2291
# max score among faithfull cliques of 20 forms: 110.688240631
# ruiner Nombre de cliques 2022
# max score among faithfull cliques of 30 forms: 285.002426447
# attacher Nombre de cliques 1849
# no new faithfull clique, the previous one contained 1 forms
# cravacher Nombre de cliques 1843
# no new faithfull clique, the previous one contained 1 forms
# repartir Nombre de cliques 2174
# max score among faithfull cliques of 22 forms: 63.5487035321
# creuser Nombre de cliques 1128
# max score among faithfull cliques of 4 forms: 6.77996863892
# retravailler Nombre de cliques 2813
# no new faithfull clique, the previous one contained 1 forms
# conserver Nombre de cliques 2015
# no new faithfull clique, the previous one contained 1 forms
# démasquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 290.997367353
# peupler Nombre de cliques 1618
# no new faithfull clique, the previous one contained 1 forms
# décider Nombre de cliques 2198
# no new faithfull clique, the previous one contained 1 forms
# éclore Nombre de cliques 129
# max score among faithfull cliques of 17 forms: 99.9583482654
# trimballer Nombre de cliques 2238
# no new faithfull clique, the previous one contained 1 forms
# tarder Nombre de cliques 2125
# max score among faithfull cliques of 29 forms: 265.140432945
# rompre Nombre de cliques 1581
# max score among faithfull cliques of 7 forms: 7.30196582634
# aventurer Nombre de cliques 2079
# max score among faithfull cliques of 29 forms: 271.742242947
# pâlir Nombre de cliques 641
# max score among faithfull cliques of 17 forms: 45.0282147863
# entonner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 246.13157732
# molester Nombre de cliques 2095
# max score among faithfull cliques of 30 forms: 273.260736918
# dépeigner Nombre de cliques 3586
# no new faithfull clique, the previous one contained 1 forms
# attraper Nombre de cliques 2061
# max score among faithfull cliques of 30 forms: 282.308626822
# protester Nombre de cliques 2095
# max score among faithfull cliques of 30 forms: 273.260736918
# dinguer Nombre de cliques 1800
# max score among faithfull cliques of 30 forms: 302.671032846
# extirper Nombre de cliques 2009
# max score among faithfull cliques of 30 forms: 275.37378499
# siéger Nombre de cliques 1941
# no new faithfull clique, the previous one contained 1 forms
# rehausser Nombre de cliques 2479
# no new faithfull clique, the previous one contained 1 forms
# ritualiser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# lotir Nombre de cliques 813
# max score among faithfull cliques of 19 forms: 66.8236129015
# répliquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# séparer Nombre de cliques 1592
# max score among faithfull cliques of 28 forms: 260.585514895
# transporter Nombre de cliques 2007
# max score among faithfull cliques of 30 forms: 266.545995276
# incruster Nombre de cliques 2028
# max score among faithfull cliques of 30 forms: 269.387070308
# guérir Nombre de cliques 2072
# max score among faithfull cliques of 13 forms: 33.4355622947
# décimer Nombre de cliques 2075
# max score among faithfull cliques of 30 forms: 286.48847588
# céder Nombre de cliques 1856
# no new faithfull clique, the previous one contained 1 forms
# gourer Nombre de cliques 2359
# max score among faithfull cliques of 29 forms: 253.553842184
# malmener Nombre de cliques 1831
# no new faithfull clique, the previous one contained 1 forms
# sniffer Nombre de cliques 1939
# max score among faithfull cliques of 30 forms: 285.043284924
# frire Nombre de cliques 858
# no new faithfull clique, the previous one contained 1 forms
# redouter Nombre de cliques 2349
# max score among faithfull cliques of 30 forms: 277.98092159
# doter Nombre de cliques 2129
# no new faithfull clique, the previous one contained 1 forms
# boitiller Nombre de cliques 2942
# no new faithfull clique, the previous one contained 1 forms
# rentrer Nombre de cliques 2151
# max score among faithfull cliques of 20 forms: 117.611534979
# manager Nombre de cliques 1956
# max score among faithfull cliques of 30 forms: 288.921469874
# primer Nombre de cliques 2084
# max score among faithfull cliques of 30 forms: 285.393995375
# enfoncer Nombre de cliques 1937
# no new faithfull clique, the previous one contained 1 forms
# polluer Nombre de cliques 1179
# max score among faithfull cliques of 17 forms: 119.579746188
# dérober Nombre de cliques 1933
# max score among faithfull cliques of 29 forms: 252.110553594
# recroqueviller Nombre de cliques 2867
# no new faithfull clique, the previous one contained 1 forms
# donner Nombre de cliques 2048
# max score among faithfull cliques of 29 forms: 246.14940766
# redonner Nombre de cliques 2047
# max score among faithfull cliques of 29 forms: 246.765676571
# gerber Nombre de cliques 1996
# max score among faithfull cliques of 30 forms: 286.480200792
# écailler Nombre de cliques 1795
# max score among faithfull cliques of 18 forms: 122.302274873
# référer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# tortiller Nombre de cliques 2874
# no new faithfull clique, the previous one contained 1 forms
# truquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# brandir Nombre de cliques 2208
# no new faithfull clique, the previous one contained 1 forms
# imaginer Nombre de cliques 1717
# max score among faithfull cliques of 30 forms: 294.635799892
# couler Nombre de cliques 2259
# no new faithfull clique, the previous one contained 1 forms
# alléger Nombre de cliques 1960
# no new faithfull clique, the previous one contained 1 forms
# fatiguer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# chanceler Nombre de cliques 1615
# no new faithfull clique, the previous one contained 1 forms
# battre Nombre de cliques 2413
# max score among faithfull cliques of 16 forms: 37.8194183098
# bénéficier Nombre de cliques 2005
# no new faithfull clique, the previous one contained 1 forms
# frissonner Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 249.846501565
# avoyer Nombre de cliques 1923
# max score among faithfull cliques of 15 forms: 53.5093413341
# pomper Nombre de cliques 1562
# max score among faithfull cliques of 30 forms: 294.089736037
# entrouvrir Nombre de cliques 1624
# max score among faithfull cliques of 15 forms: 41.9471605303
# bluffer Nombre de cliques 2886
# no new faithfull clique, the previous one contained 1 forms
# coucher Nombre de cliques 2446
# max score among faithfull cliques of 28 forms: 250.172180696
# emmerder Nombre de cliques 2163
# no new faithfull clique, the previous one contained 1 forms
# mousser Nombre de cliques 2451
# ...
# no new faithfull clique, the previous one contained 1 forms
# hérisser Nombre de cliques 2440
# no new faithfull clique, the previous one contained 1 forms
# traduire Nombre de cliques 2803
# max score among faithfull cliques of 27 forms: 133.593386787
# sceller Nombre de cliques 1332
# max score among faithfull cliques of 23 forms: 190.093843201
# confronter Nombre de cliques 1920
# max score among faithfull cliques of 30 forms: 288.001528053
# lorgner Nombre de cliques 1984
# max score among faithfull cliques of 30 forms: 287.317345725
# claironner Nombre de cliques 2043
# max score among faithfull cliques of 29 forms: 248.789818368
# pédaler Nombre de cliques 2238
# no new faithfull clique, the previous one contained 1 forms
# examiner Nombre de cliques 2031
# max score among faithfull cliques of 30 forms: 282.839359483
# respecter Nombre de cliques 1791
# max score among faithfull cliques of 29 forms: 265.308931128
# répugner Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# démanger Nombre de cliques 1642
# max score among faithfull cliques of 30 forms: 299.090063602
# démolir Nombre de cliques 767
# max score among faithfull cliques of 17 forms: 61.2783993166
# accabler Nombre de cliques 1892
# max score among faithfull cliques of 26 forms: 209.66430884
# goûter Nombre de cliques 2346
# no new faithfull clique, the previous one contained 1 forms
# broyer Nombre de cliques 2821
# max score among faithfull cliques of 27 forms: 138.03613004
# ouïr Nombre de cliques 1530
# max score among faithfull cliques of 29 forms: 142.239191229
# marteler Nombre de cliques 1125
# max score among faithfull cliques of 18 forms: 140.66935208
# évaluer Nombre de cliques 1180
# max score among faithfull cliques of 17 forms: 119.579746188
# froisser Nombre de cliques 2373
# max score among faithfull cliques of 26 forms: 183.064605194
# inhumer Nombre de cliques 2062
# max score among faithfull cliques of 30 forms: 279.15910309
# préparer Nombre de cliques 1904
# max score among faithfull cliques of 29 forms: 277.231007693
# modérer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# sauter Nombre de cliques 2056
# max score among faithfull cliques of 17 forms: 89.5520928445
# baver Nombre de cliques 1830
# no new faithfull clique, the previous one contained 1 forms
# déborder Nombre de cliques 1808
# no new faithfull clique, the previous one contained 1 forms
# tatouer Nombre de cliques 1469
# max score among faithfull cliques of 23 forms: 179.370202282
# distancier Nombre de cliques 2005
# no new faithfull clique, the previous one contained 1 forms
# remonter Nombre de cliques 1537
# max score among faithfull cliques of 26 forms: 232.484482682
# bander Nombre de cliques 1622
# max score among faithfull cliques of 29 forms: 250.535013373
# refiler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# barboter Nombre de cliques 2129
# no new faithfull clique, the previous one contained 1 forms
# débrouiller Nombre de cliques 1392
# no new faithfull clique, the previous one contained 1 forms
# picoler Nombre de cliques 1962
# max score among faithfull cliques of 26 forms: 200.065991815
# crier Nombre de cliques 2785
# max score among faithfull cliques of 11 forms: 23.7608630198
# caserner Nombre de cliques 2024
# max score among faithfull cliques of 30 forms: 278.121731199
# voleter Nombre de cliques 3141
# no new faithfull clique, the previous one contained 1 forms
# enserrer Nombre de cliques 1737
# no new faithfull clique, the previous one contained 1 forms
# amalgamer Nombre de cliques 2072
# max score among faithfull cliques of 30 forms: 278.007522797
# contredire Nombre de cliques 1896
# no new faithfull clique, the previous one contained 1 forms
# dévisser Nombre de cliques 2366
# no new faithfull clique, the previous one contained 1 forms
# inscrire Nombre de cliques 2023
# max score among faithfull cliques of 15 forms: 25.4861084548
# agréer Nombre de cliques 261
# max score among faithfull cliques of 24 forms: 195.687765911
# danser Nombre de cliques 2197
# no new faithfull clique, the previous one contained 1 forms
# impliquer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# tarer Nombre de cliques 1913
# max score among faithfull cliques of 29 forms: 276.222649773
# témoigner Nombre de cliques 2315
# no new faithfull clique, the previous one contained 1 forms
# rêver Nombre de cliques 2841
# no new faithfull clique, the previous one contained 1 forms
# ravager Nombre de cliques 1983
# max score among faithfull cliques of 30 forms: 287.28180896
# râper Nombre de cliques 2020
# max score among faithfull cliques of 30 forms: 285.106570268
# durer Nombre de cliques 2084
# max score among faithfull cliques of 29 forms: 268.826917156
# deviser Nombre de cliques 2635
# no new faithfull clique, the previous one contained 1 forms
# représenter Nombre de cliques 1625
# max score among faithfull cliques of 30 forms: 277.605599489
# étouffer Nombre de cliques 1821
# no new faithfull clique, the previous one contained 1 forms
# vexer Nombre de cliques 2373
# max score among faithfull cliques of 24 forms: 172.216594794
# accoler Nombre de cliques 1962
# max score among faithfull cliques of 26 forms: 200.065991815
# esquisser Nombre de cliques 2399
# no new faithfull clique, the previous one contained 1 forms
# oser Nombre de cliques 2458
# max score among faithfull cliques of 17 forms: 84.8309111515
# élimer Nombre de cliques 2038
# max score among faithfull cliques of 30 forms: 291.259499558
# dépendre Nombre de cliques 986
# max score among faithfull cliques of 22 forms: 95.487081584
# raffiner Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.828611355
# angoisser Nombre de cliques 2373
# max score among faithfull cliques of 26 forms: 183.064605194
# accentuer Nombre de cliques 1415
# max score among faithfull cliques of 30 forms: 242.021244401
# infiltrer Nombre de cliques 2028
# max score among faithfull cliques of 29 forms: 252.826715573
# recommander Nombre de cliques 1559
# max score among faithfull cliques of 29 forms: 266.174332689
# becter Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 280.227784933
# crouler Nombre de cliques 2271
# no new faithfull clique, the previous one contained 1 forms
# tremper Nombre de cliques 1606
# max score among faithfull cliques of 30 forms: 291.138827922
# négliger Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# manigancer Nombre de cliques 2066
# no new faithfull clique, the previous one contained 1 forms
# vaincre Nombre de cliques 539
# max score among faithfull cliques of 13 forms: 34.9048951966
# joncher Nombre de cliques 1786
# max score among faithfull cliques of 28 forms: 261.139231168
# arborer Nombre de cliques 1830
# max score among faithfull cliques of 29 forms: 259.427183583
# puer Nombre de cliques 1713
# max score among faithfull cliques of 16 forms: 36.0976455881
# miauler Nombre de cliques 1466
# max score among faithfull cliques of 25 forms: 210.634105184
# miner Nombre de cliques 2031
# max score among faithfull cliques of 30 forms: 282.839359483
# philosopher Nombre de cliques 1679
# no new faithfull clique, the previous one contained 1 forms
# merder Nombre de cliques 2163
# no new faithfull clique, the previous one contained 1 forms
# contester Nombre de cliques 2090
# max score among faithfull cliques of 30 forms: 275.611160659
# bosser Nombre de cliques 2388
# no new faithfull clique, the previous one contained 1 forms
# déplier Nombre de cliques 2570
# no new faithfull clique, the previous one contained 1 forms
# objecter Nombre de cliques 1791
# max score among faithfull cliques of 29 forms: 265.308931128
# décompresser Nombre de cliques 2307
# no new faithfull clique, the previous one contained 1 forms
# écoeurer Nombre de cliques 1480
# max score among faithfull cliques of 11 forms: 34.2920994904
# investir Nombre de cliques 2047
# no new faithfull clique, the previous one contained 1 forms
# analyser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# faufiler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# persuader Nombre de cliques 2214
# no new faithfull clique, the previous one contained 1 forms
# éviter Nombre de cliques 2087
# max score among faithfull cliques of 30 forms: 278.778712705
# langer Nombre de cliques 1800
# max score among faithfull cliques of 30 forms: 302.671032846
# ébahir Nombre de cliques 610
# max score among faithfull cliques of 19 forms: 67.0798035858
# brailler Nombre de cliques 2449
# no new faithfull clique, the previous one contained 1 forms
# fondre Nombre de cliques 2163
# max score among faithfull cliques of 15 forms: 32.5523896399
# baigner Nombre de cliques 3586
# no new faithfull clique, the previous one contained 1 forms
# ressurgir Nombre de cliques 2429
# max score among faithfull cliques of 25 forms: 165.574018384
# survivre Nombre de cliques 2183
# max score among faithfull cliques of 11 forms: 26.0795126788
# ouvrir Nombre de cliques 2230
# max score among faithfull cliques of 15 forms: 41.3973326387
# renverser Nombre de cliques 2303
# no new faithfull clique, the previous one contained 1 forms
# dorer Nombre de cliques 1354
# max score among faithfull cliques of 29 forms: 264.462476514
# bouger Nombre de cliques 2382
# max score among faithfull cliques of 30 forms: 280.622276478
# localiser Nombre de cliques 2543
# no new faithfull clique, the previous one contained 1 forms
# nommer Nombre de cliques 2078
# max score among faithfull cliques of 29 forms: 239.410675285
# jauger Nombre de cliques 1981
# max score among faithfull cliques of 29 forms: 256.820911316
# approuver Nombre de cliques 2532
# no new faithfull clique, the previous one contained 1 forms
# enfermer Nombre de cliques 2066
# max score among faithfull cliques of 30 forms: 280.051084223
# chuchoter Nombre de cliques 1854
# no new faithfull clique, the previous one contained 1 forms
# achever Nombre de cliques 2363
# max score among faithfull cliques of 18 forms: 81.8658571697
# déboîter Nombre de cliques 2078
# max score among faithfull cliques of 29 forms: 256.289071781
# prononcer Nombre de cliques 2377
# max score among faithfull cliques of 25 forms: 181.878987114
# jubiler Nombre de cliques 2115
# max score among faithfull cliques of 26 forms: 212.517387178
# boiter Nombre de cliques 2078
# max score among faithfull cliques of 29 forms: 256.289071781
# offrir Nombre de cliques 1844
# max score among faithfull cliques of 16 forms: 57.6836463776
# dissiper Nombre de cliques 2050
# max score among faithfull cliques of 30 forms: 279.242466791
# freiner Nombre de cliques 2218
# no new faithfull clique, the previous one contained 1 forms
# promettre Nombre de cliques 1819
# max score among faithfull cliques of 24 forms: 69.1360837809
# perfectionner Nombre de cliques 1988
# no new faithfull clique, the previous one contained 1 forms
# embrasser Nombre de cliques 2355
# max score among faithfull cliques of 26 forms: 182.433123568
# suffire Nombre de cliques 2025
# max score among faithfull cliques of 29 forms: 150.023198932
# endiguer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# répercuter Nombre de cliques 2019
# max score among faithfull cliques of 30 forms: 282.77671012
# précéder Nombre de cliques 2381
# no new faithfull clique, the previous one contained 1 forms
# répertorier Nombre de cliques 1862
# max score among faithfull cliques of 18 forms: 119.969623014
# piller Nombre de cliques 2930
# no new faithfull clique, the previous one contained 1 forms
# baiser Nombre de cliques 2580
# no new faithfull clique, the previous one contained 1 forms
# placer Nombre de cliques 2230
# no new faithfull clique, the previous one contained 1 forms
# résumer Nombre de cliques 2081
# max score among faithfull cliques of 30 forms: 285.393995375
# cercler Nombre de cliques 1927
# max score among faithfull cliques of 26 forms: 210.224359568
# marier Nombre de cliques 2779
# max score among faithfull cliques of 13 forms: 46.2871403661
# évoluer Nombre de cliques 1304
# max score among faithfull cliques of 17 forms: 111.512549284
# allonger Nombre de cliques 1800
# max score among faithfull cliques of 30 forms: 302.671032846
# puiser Nombre de cliques 1906
# no new faithfull clique, the previous one contained 1 forms
# faillir Nombre de cliques 1071
# max score among faithfull cliques of 15 forms: 52.6811215744
# compenser Nombre de cliques 2435
# max score among faithfull cliques of 25 forms: 174.791185335
# signer Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# pétrifier Nombre de cliques 1969
# no new faithfull clique, the previous one contained 1 forms
# faciliter Nombre de cliques 2104
# max score among faithfull cliques of 30 forms: 280.493169446
# jouir Nombre de cliques 1794
# max score among faithfull cliques of 28 forms: 132.612629565
# chercher Nombre de cliques 2032
# max score among faithfull cliques of 22 forms: 171.444283992
# repentir Nombre de cliques 1203
# max score among faithfull cliques of 28 forms: 150.416720193
# nuire Nombre de cliques 2803
# max score among faithfull cliques of 27 forms: 133.593386787
# bégayer Nombre de cliques 2400
# no new faithfull clique, the previous one contained 1 forms
# dédicacer Nombre de cliques 2367
# max score among faithfull cliques of 26 forms: 181.071692711
# coiffer Nombre de cliques 2032
# max score among faithfull cliques of 29 forms: 266.162632511
# chialer Nombre de cliques 2236
# no new faithfull clique, the previous one contained 1 forms
# saigner Nombre de cliques 3588
# no new faithfull clique, the previous one contained 1 forms
# plaquer Nombre de cliques 1989
# max score among faithfull cliques of 30 forms: 287.338672332
# monter Nombre de cliques 1759
# max score among faithfull cliques of 26 forms: 225.221901949
# broder Nombre de cliques 2174
# no new faithfull clique, the previous one contained 1 forms
# participer Nombre de cliques 2050
# max score among faithfull cliques of 30 forms: 279.242466791
# préserver Nombre de cliques 1977
# no new faithfull clique, the previous one contained 1 forms
# rebeller Nombre de cliques 847
# max score among faithfull cliques of 23 forms: 200.149071369
# radoter Nombre de cliques 2183
# no new faithfull clique, the previous one contained 1 forms
# importuner Nombre de cliques 2041
# max score among faithfull cliques of 30 forms: 290.450888583
# annuler Nombre de cliques 1585
# max score among faithfull cliques of 25 forms: 224.148263198
# conspirer Nombre de cliques 2084
# max score among faithfull cliques of 29 forms: 269.100984359
# comparer Nombre de cliques 1904
# max score among faithfull cliques of 29 forms: 277.231007693
# atterrir Nombre de cliques 1948
# max score among faithfull cliques of 26 forms: 92.9022909109
# renseigner Nombre de cliques 3586
# no new faithfull clique, the previous one contained 1 forms
# envisager Nombre de cliques 1988
# max score among faithfull cliques of 30 forms: 283.518031438
# dresser Nombre de cliques 2645
# no new faithfull clique, the previous one contained 1 forms
# blasphémer Nombre de cliques 2196
# no new faithfull clique, the previous one contained 1 forms
# éteindre Nombre de cliques 2099
# max score among faithfull cliques of 9 forms: 17.5358164882
# apprécier Nombre de cliques 2745
# max score among faithfull cliques of 10 forms: 21.5397447818
# raidir Nombre de cliques 2118
# max score among faithfull cliques of 32 forms: 166.270128877
# dénicher Nombre de cliques 2127
# max score among faithfull cliques of 28 forms: 251.808346872
# dérouiller Nombre de cliques 2992
# no new faithfull clique, the previous one contained 1 forms
# aviser Nombre de cliques 2478
# no new faithfull clique, the previous one contained 1 forms
# décrire Nombre de cliques 2056
# max score among faithfull cliques of 14 forms: 36.5891809082
# saisir Nombre de cliques 1883
# no new faithfull clique, the previous one contained 1 forms
# augmenter Nombre de cliques 1820
# max score among faithfull cliques of 30 forms: 276.846906657
# bouleverser Nombre de cliques 2303
# no new faithfull clique, the previous one contained 1 forms
# piger Nombre de cliques 2003
# max score among faithfull cliques of 30 forms: 294.246746249
# évanouir Nombre de cliques 1587
# max score among faithfull cliques of 17 forms: 63.3225519371
# CPU times: user 39min 57s, sys: 3min 45s, total: 43min 43s
# Wall time: 40min 39s

# %%
newParadigmes,paradigmesSwim2,characteristicsSwim2,measuresSwim2=calculerResultats(swim2ContextParadigmes,"-Swim2")
# Out:
# UG 59180 OG 690 TP 36588 FP 2012
# recall 0.374186950297 precision 0.931229320438
# 0.533858612388

# %%
nomFichierResultats=filePrefix+"-X-Resultats.yaml"
if os.path.isfile(nomFichierResultats):
    with open(nomFichierResultats, 'r') as stream:
            resultats=yaml.load(stream)
else:
    resultats={}

if casesType:
    sampleExt=casesType
else:
    sampleExt=sampleType
sampleId=sampleNumber.strip("-")+sampleExt
resultats[sampleId]={}
resultats[sampleId]["type"]="X"
resultats[sampleId]["results"]={}
resultats[sampleId]["results"]["Swim1"]={}
resultats[sampleId]["results"]["Swim1"]["UG"]=characteristicsSwim1[0]
resultats[sampleId]["results"]["Swim1"]["OG"]=characteristicsSwim1[1]
resultats[sampleId]["results"]["Swim1"]["TP"]=characteristicsSwim1[2]
resultats[sampleId]["results"]["Swim1"]["FP"]=characteristicsSwim1[3]
resultats[sampleId]["results"]["Swim1"]["Precision"]=measuresSwim1[0]
resultats[sampleId]["results"]["Swim1"]["Recall"]=measuresSwim1[1]
resultats[sampleId]["results"]["Swim1"]["F-Measure"]=measuresSwim1[2]
resultats[sampleId]["results"]["Swim2"]={}
resultats[sampleId]["results"]["Swim2"]["UG"]=characteristicsSwim2[0]
resultats[sampleId]["results"]["Swim2"]["OG"]=characteristicsSwim2[1]
resultats[sampleId]["results"]["Swim2"]["TP"]=characteristicsSwim2[2]
resultats[sampleId]["results"]["Swim2"]["FP"]=characteristicsSwim2[3]
resultats[sampleId]["results"]["Swim2"]["Precision"]=measuresSwim2[0]
resultats[sampleId]["results"]["Swim2"]["Recall"]=measuresSwim2[1]
resultats[sampleId]["results"]["Swim2"]["F-Measure"]=measuresSwim2[2]

yaml.safe_dump(resultats, file(nomFichierResultats, 'w'), encoding='utf-8', allow_unicode=True)

# %%
import cellbell
# %ding

# %%
print ("Swim1",characteristicsSwim1,measuresSwim1)
print ("Swim2",characteristicsSwim2,measuresSwim2)
# Out:
# Swim1 (71150, 401, 24618, 682) (0.9578615618069336, 0.25524105754276827, 0.40307488272711645)
# Swim2 (59180, 690, 36588, 2012) (0.9312293204377704, 0.37418695029658416, 0.533858612387831)

# %% [markdown]
# # Fin du traitement

# %% [markdown]
# # Calcul des distances

# %% [markdown]
# ### Préparation des fichiers de référence
# La comparaison se fait sur les lexèmes de *listeTest*
# - initialForms : les formes initiales
# - finalForms : les formes initiales plus les formes prédites
# - goldForms : les formes de référence

# %% [markdown]
# #### Formes initiales

# %% [raw]
# initialForms=pd.melt(paradigmesSample[paradigmesSample["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
# initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
#
# initialForms.set_index(["lexeme-case"],inplace=True)
#
# initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# #### Formes avec prédictions

# %% [raw]
# finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
# finalParadigmes.to_csv(path_or_buf=analysisPrefix+"-paradigmes-Swim2.csv",encoding="utf8",sep=";")
# finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
# finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
# finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
# finalTestForms.set_index(["lexeme-case"],inplace=True)

# %% [markdown]
# #### Formes de référence
# - recoder les représentations phonologiques en fonction de l'échantillon

# %% [raw]
# with open(goldPrefix+"/"+goldFile,"rb") as input:
#     lexiqueGold=pickle.load(input)
#
# lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
#
# completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
#
# goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# #goldTestForms
#
# goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
# goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
#
# goldTestForms.set_index(["lexeme-case"],inplace=True)

# %% [raw]
# #goldFormsIndex=goldForms.index.tolist()

# %% [markdown]
# ### Soustraction des formes initiales

# %% [raw]
# finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
# finalFormsIndex=finalForms.index.tolist()
# #initialForms.loc[~initialForms.index.isin(finalFormsIndex)]

# %% [raw]
# #finalForms[finalForms.index.str.contains("asseoir")]

# %% [raw]
# #goldTestForms[goldTestForms.index.str.contains("asseoir")]

# %% [raw]
# goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
# goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #goldForms[goldForms.index.str.contains("asseoir")]

# %% [raw]
# print (finalFormsIndex)
# goldForms[~goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# ### Évaluation des formes

# %% [markdown]
# #### Problèmes de génération
# - sous-génération : formes de références sans prédiction
# - sur-génération : formes prédites absentes de la référence

# %% [raw]
# underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
# overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]

# %% [markdown]
# #### Formes comparables
# - *predictedForms* => formes prédites présentes dans la référence
# - *actualForms* => formes de référence présentes dans les prédictions

# %% [raw]
# predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
# actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# #### Préparation de la comparaison
# - *compareForms* => tableau avec les formes à comparer

# %% [raw]
# compareForms=predictedForms.copy()
# compareForms.loc[:,"right"]=actualForms.loc[:,"value"]

# %% [markdown]
# #### Comparaison des formes
# - *sameForms* => formes identiques dans les prédictions et la référence
# - *diffForms* => formes différentes dans les prédictions et la référence

# %% [raw]
# sameForms=compareForms[compareForms["value"]==compareForms["right"]]
# diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

# %% [markdown]
# #### Décompte du nombre de formes
# À cause du traitement de la surabondance, le décompte des lignes ne tient pas compte du nombre de formes. Il faut compter les formes dans chaque ligne pour obtenir le nombre total.

# %% [raw]
# def countSplits(dfForms):
#     dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
#     return dfForms["split"].str.len().sum()

# %% [markdown]
# #### Évaluation des différences
# Certaines différences ne sont qu'apparentes à cause du traitement de la surabondance sous forme de chaine concaténée. Il faut transformer les surabondances en set() pour pouvoir faire une comparaison pertinente.

# %% [raw]
# def evaluateDiffForms(diffForms):
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
#
#     nbValues=diffForms["split-value"].str.len().sum()
#     nbRights=diffForms["split-right"].str.len().sum()
# #    print (nbValues,nbRights)
#
#     nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
#     nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
#
#     return (nbIdenticalSets,nbIncludedSets,(nbValues-nbIdenticalSets-nbIncludedSets),(nbRights-nbIdenticalSets-nbIncludedSets))

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus=evaluateDiffForms(diffForms)
# #evaluateDiffForms(diffForms)

# %% [markdown]
# #### Calcul des grandeurs de mesure

# %% [raw]
# UG=countSplits(underGeneration)+underBonus
# OG=countSplits(overGeneration)
# TP=countSplits(sameForms)+identicalBonus+partialBonus
# FP=wrongBonus
# recall=float(TP)/(UG+TP+FP)
# precision=float(TP)/(OG+TP+FP)
# print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
# print ("recall", recall, "precision", precision)
#
# fMeasure=2*recall*precision/(recall+precision)
# fMeasure

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus

# %% [raw]
# countSplits(underGeneration),countSplits(overGeneration),countSplits(sameForms)

# %% [markdown]
# ### Sauvegarde des résultats pour analyse ultérieure

# %% [raw]
# overGeneration.to_csv(path_or_buf=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration.to_csv(path_or_buf=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# sameForms.to_csv(path_or_buf=analysisPrefix+"-sameForms.csv",encoding="utf8")
# diffForms.to_csv(path_or_buf=analysisPrefix+"-diffForms.csv",encoding="utf8")

# %% [markdown]
# ## Analyse des sur-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# overGeneration.loc[:,"case"]=overGeneration.index.str.rsplit("-").str[-1]

# %% [raw]
# casesOverGeneration=overGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# casesOverGeneration.plot(kind="bar",figsize=(20,5))

# %% [raw]
# casesOverGeneration[:3].sum()/casesOverGeneration.sum()

# %% [markdown]
# Le facteur principal de **surgénération** est la production de **participes passés** (ppMP 662, ppFS 661, ppFP 661) pour les verbes qui n'ont qu'une seule forme de participe passé invariable (ppMS) : **54.78%** (1984/3622).

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# overGeneration.loc[:,"verbe"]=overGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesOverGeneration=overGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
# verbesOverGeneration[:54].plot(kind="bar",figsize=(20,5))

# %% [markdown]
# Le facteur principal de **surgénération** tient aux **verbes vestiges** et aux **météorologiques**.

# %% [markdown]
# ## Analyse des sous-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# underGeneration.loc[:,"case"]=underGeneration.index.str.rsplit("-",1).str[-1]

# %% [raw]
# casesUnderGeneration=underGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# ax=casesUnderGeneration[:9].plot(kind="bar",figsize=(20,5))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Verbs missing the form",fontsize=16)
# print ("Total sous-générations :",casesUnderGeneration.sum().values[0])

# %% [raw]
# def ratioAnalyses(df,chaine):
#     return df[df.index.str.contains(chaine)].sum().values[0],df.sum().values[0],(df[df.index.str.contains(chaine)].sum()/df.sum()).values[0]

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"is")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"ai")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"2P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"1P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"pi")

# %% [markdown]
# Le facteur principal de **sous-génération** est lié à la fréquence des TAM et de certaines personnes :
# - TAM :
#  - imparfait du subjonctif 45.98% (7875/17126)
#  - passé simple 12.70% (2176/17126)
# - Personnes :
#  - 2PL 46.11% (7897/17126)
#  - 1PL 32.98% (5649/17126)

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# underGeneration.loc[:,"verbe"]=underGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesUnderGeneration=underGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
#
# ax=verbesUnderGeneration[:50].plot(kind="bar",figsize=(40,5))
# ax.set_xlabel("Verbes",fontsize=16)
# ax.set_ylabel("Number of Missing Forms",fontsize=16)

# %% [markdown]
# # Fin de l'analyse des résultats

# %% [raw]
# overGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# goodForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-goodForms.csv",encoding="utf8")
# wrongForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-wrongForms.csv",encoding="utf8")

# %% [raw]
# len(overGeneration), len(underGeneration), len(goodForms), len(wrongForms)

# %% [raw]
# wrongForms["rightChecked"]=wrongForms["right"].apply(checkFrench)
# wrongForms["valueChecked"]=wrongForms["value"].apply(checkFrench)

# %% [raw]
# wrongForms[wrongForms["valueChecked"]!=wrongForms["rightChecked"]]

# %% [raw]
# goodForms[goodForms["value"].str.contains(",")]

# %% [raw]
# set(overGeneration["lexeme-case"].str.rsplit("-").str[0].tolist())

# %% [raw]
# underGeneration["case"]=underGeneration["lexeme-case"].str.rsplit("-").str[-1]

# %% [raw]
# underGeneration.groupby("case").count()["value"].sort_values(ascending=False)

# %% [raw]
# finalParadigmes=extendParadigmes(savedContextParadigmes,extendMorphomes=True)

# %% [raw]
# test["ppMS"]

# %% [raw]
# def repairContextParadigmes(contextParadigmes):
#     repaired={}
#     for sCP in contextParadigmes.keys():
#     #    noLexeme=False
#         repaired[sCP]=[]
#         for numClique,clique in enumerate(contextParadigmes[sCP]):
#             repaired[sCP].append(clique)
#     #        noLexemeElements=[]
#     #        withLexemeElements=[]
#             for numElement,element in enumerate(clique):
#                 if not len(element.split("-"))>2 or not element.startswith(sCP):
#                     print (sCP+"-"+element)
#                     repaired[sCP][numClique][numElement]=sCP+"-"+element
#     #                noLexemeElements.append(element)
#     #            else:
#     #                withLexemeElements.append(element)
#     #        if noLexemeElements:
#     #            print (sCP)
#     #            print (noLexemeElements)
#     #            print (withLexemeElements)
#     #            print ()
#     #        noLexeme=False
#     return repaired

# %% [raw]
# repairContextParadigmes(contextParadigmes)[u"féminiser"]

# %% [markdown]
# ### Test de la sauvegarde de l'analyse brute

# %% [raw]
# with open(analysisPrefix+"-analyseParadigmes.pkl","rb") as input:
#     savedAnalyseParadigmes = pickle.load(input)

# %% [raw]
# savedContextParadigmes=savedAnalyseParadigmes[0]
# savedCliques=savedAnalyseParadigmes[1]
# savedCliquesScores=savedAnalyseParadigmes[2]
# savedCliquesListes=savedAnalyseParadigmes[3]
# #savedFormesScores=savedAnalyseParadigmes[4]
# #savedFormesScoresNormes=savedAnalyseParadigmes[5]

# %% [raw]
# generateForms(u"crépir",contextFree=True).formes

# %% [raw]
# if genFormeVotes:
#     fScores=(formesScores,formesScoresNormes)
#     with open(analysisPrefix+paperPrefix+'-Scores.pkl', 'wb') as output:
#         pickle.dump(fScores, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# %%time
# versionStamp=dateheure()
# if genDigraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globDigraphe,analysisPrefix+paperPrefix+u"-digraphe-%s.gexf"%versionStamp)
# if genGraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globGraphe,analysisPrefix+paperPrefix+u"-graphe-%s.gexf"%versionStamp)

# %% [raw]
# print (len(cliques))

# %% [raw]
# if genCliques:
#     infoCliques={"cliques":cliques, "cliquesScores":cliquesScores, "cliquesListes":cliquesListes}
#     with open(analysisPrefix+paperPrefix+'-Network.pkl', 'wb') as output:
#         pickle.dump(infoCliques, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# print (paradigmes[paradigmes["lexeme"]==lexeme].to_latex(na_rep=""))

# %% [raw]
# HTML(makeTable(dictParadigmes[lexeme],title=lexeme))

# %% [raw]
# print (len(sampleCases),sampleCases,paradigmes["lexeme"].count())
# nbCoformes=paradigmes.notnull().sum(axis=1)-1
# distNbCoformes=nbCoformes.groupby(by=nbCoformes).count()
# ax=distNbCoformes.plot(kind="bar",legend=False,grid=True,figsize=(10,3))
# ax.set(xlim=(-0.5,32),ylim=(0,600))
# ax.set_xlabel("Number of Co-Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["lexeme"]==u"être") & (sampleTirage["tir1"]!=0)]

# %% [raw]
# freqCasesSampleTirage=sampleTirage[sampleTirage["tir1"]!=0].groupby("case")[["lexeme"]].count().sort_values("lexeme",ascending=False)
# ax=freqCasesSampleTirage.plot(kind="bar",legend=False,grid=True,figsize=(10,5))
# ax.set(xlim=(-0.5,32.5),ylim=(0,5000))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# coFormes=paradigmes.copy()
# coFormes["nbCoformes"]=coFormes.notnull().sum(axis=1)-1
# singletonLexemes=coFormes[coFormes["nbCoformes"]==1]["lexeme"].tolist()
# print (coFormes["nbCoformes"].sum(),len(singletonLexemes))

# %% [raw]
# freqCaseSingleton=sampleTirage[(sampleTirage["tir1"]!=0) & (sampleTirage["lexeme"].isin(singletonLexemes))][["case","morphome"]].groupby("case").count()
# ax=freqCaseSingleton.sort_values("morphome",ascending=False).plot(kind="bar",legend=False,grid=True,figsize=(8,3))
# ax.set(xlim=(-0.25,17),ylim=(0,200))
# ax.set_xlabel("Isolated Form",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["tir1"]!=0)]["tir1"].sum()

# %% [raw]
# recoder("degrosirje")

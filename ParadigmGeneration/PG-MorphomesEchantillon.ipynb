# %% [markdown]
# # Script pour trouver un paradigme morphomique

# %%
# -*- coding: utf8 -*-
import pandas as pd
import pickle, glob,re
import itertools as it
import networkx as nx

# %%
debug=False
noDiff=True
nbFormesPrint=False
regroupeTirages=True

# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dierese={"j":"ij", "w":"uw","H":"yH","i":"ij","u":"uw","y":"yH"}
correctionsGlides={}
correctionsHiatus={}
preGlideFinal=set()

# %%
def checkFrench(prononciation):
    result=prononciation
    m=re.match(ur"^.*([^ieEaOouy926êôâ])[jwH]$",prononciation)
    if m:
        print "pb avec un glide final"
    m=re.match(ur"(.*[ptkbdgfsSvzZ][rl])([jwH])(.*)",prononciation)
    if m:
        n=re.search(ur"[ptkbdgfsSvzZ][rl](wa|Hi|wê)",prononciation)
        if not n:
            glide=m.group(2)
            result=m.group(1)+dierese[glide]+m.group(3)
    m=re.match(ur"(.*)([iuy])([ieEaOouy].*)",prononciation)
    if m:
        glide=m.group(2)
        result=m.group(1)+dierese[glide]+m.group(3)
    return result

# %%
print checkFrench(u"trwe")
# Out:
# truwe

# %%
def lireLexique(nomLexique):
    with open(nomLexique, 'rb') as input:
        lexique=pickle.load(input)
    return lexique

# %%
nomFichierMorphomes="/Users/gilles/Github/BoSchal17-Morphology/PG-Morphomes.tex"
listeTirages=glob.glob("/Users/gilles/Box Sync/2015-Data/*-Tirage.pkl")
listeVHF=[u"être","avoir","faire","dire","pouvoir","aller","voir","savoir","vouloir","venir"]

# %%
coulMF=["orange","brown","yellow","lime",
          "green","teal","lightgray","pink","cyan","magenta"]
coulMT=["blue","darkgray","purple","red","olive","violet"]
couleurCase={
    "pi2S":"orange","pi3S":"orange",
    "ii1S":"brown","ii2S":"brown","ii3S":"brown","ii3P":"brown",
    "fi1S":"yellow","fi2P":"yellow",
    "pc1S":"yellow","pc2S":"yellow","pc3S":"yellow","pc3P":"yellow",
    "fi2S":"lime","fi3S":"lime",
    "fi1P":"green","fi3P":"green",
    "ps1S":"teal","ps2S":"teal","ps3S":"teal","ps3P":"teal",
    "ai2S":"lightgray","ai3S":"lightgray","is3S":"lightgray",
    "is1S":"pink","is2S":"pink","is3P":"pink",
    "ppMS":"cyan","ppMP":"cyan",
    "ppFS":"magenta","ppFP":"magenta"
            }
listLimites=[2,8,32,128,512]
listLimCoul=["red","pink","orange","green","teal","white"]

# %%
def tiragesNom(nom):
    result=[tirage for tirage in listeTirages if nom in tirage]
    return result

# %%
def nbFormesEchantillons(nom):
    print nom
    for tirage in tiragesNom(nom):
        sample=lireLexique(tirage)
        print sample[sample["tir1"]>0]["tir1"].count(),
        print sample[sample["tir1"]>0]["tir1"].sum(),
        print tirage

# %%
listeTirages200=tiragesNom("200Mo")
listeTirages20=tiragesNom("20Mo")
#len(listeTirages200)
listeTirages1=tiragesNom("1Mo")
listeTirages50k=tiragesNom("50Ko")
listeTirages100k=tiragesNom("100Ko")

# %% [markdown]
# tailleLexique=[]
# nomLexique0=listeTirages200.pop(0)
# nomLexique0=listeTirages1.pop(0)
# lexique=lireLexique(nomLexique0)
# taille=lexique[lexique["tir1"]>0]["tir1"].count()
# print taille, lexique[lexique["tir1"]>0]["tir1"].sum()
# tailleLexique.append(taille)

# %%
def findFormNumbers(paradigme):
    dictNumbers={}
    cases=[c for c in paradigmes.columns.tolist() if c!="lexeme"]
    for case in cases:
        dictNumbers[case]=paradigme[case].count()
    return dictNumbers

# %%
def reduceTrad(el,traductions):
    if traductions[el]==el:
        return el
    else:
        return reduceTrad(traductions[el],traductions)
    
def defParadigme(paradigmes):
    syncretisms=[]
    cases=[c for c in paradigmes.columns.tolist() if c!="lexeme"]
    for (c1,c2) in it.combinations(cases, 2):
        c1Val=paradigmes[c1].notnull()
        c2Val=paradigmes[c2].notnull()
        c1Sur=paradigmes[c1].str.contains(",")
        c2Sur=paradigmes[c2].str.contains(",")
        l1=len(paradigmes[paradigmes[c1].notnull()])
        l2=len(paradigmes[paradigmes[c2].notnull()])
        paire=paradigmes[c1Val & c2Val & (paradigmes[c1]!=paradigmes[c2])][[c1,c2]]
        lenDiff=len(paire[~paire[c1].str.contains(",") & ~paire[c2].str.contains(",")])
        if lenDiff>0:
            if debug:
                print u"%s ≠ %s"%(c1,c2)
                print "différence",lenDiff
                if lenDiff<12:
                    print paire
        else:
            surAbondant=paire[paire[c1].str.contains(",") | paire[c2].str.contains(",")]
#            print "--------------------------------"
            if len(surAbondant)==0:
#                print u"%s = %s"%(c1,c2) 
                syncretisms.append(u"%s = %s"%(c1,c2))
            else:
                compatible=True
                for index,row in surAbondant.iterrows():
                    if "," in row[c1]:
                        if "," in row[c2]:
                            if row[c1]!=row[c2]:
                                compatible=False
                        else:
                            if not row[c2] in row[c1].split(","):
                                compatible=False
                    else:
                        if not row[c1] in row[c2].split(","):
                            compatible=False
                if compatible:
#                    print u"%s = %s"%(c1,c2)
                    syncretisms.append(u"%s = %s"%(c1,c2))
                else:
                    print u"%s ≠ %s"%(c1,c2)
                    print surAbondant

    reductionParadigme={c:c for c in cases}
    for syncretism in syncretisms:
        c1,c2=syncretism.split(" = ")
        removeC=max(c1,c2)
        keyC=min(c1,c2)
        if removeC in reductionParadigme:
            if keyC in reductionParadigme:
                key=min(reductionParadigme[keyC],reductionParadigme[removeC])
            else:
                key=min(keyC,reductionParadigme[removeC])
        else:
            if keyC in reductionParadigme:
                key=reductionParadigme[keyC]
            else:
                key=keyC
        reductionParadigme[removeC]=key
        reductionParadigme[keyC]=key

    for el in reductionParadigme:
        reductionParadigme[el]=reduceTrad(el,reductionParadigme)

    paradigmeReduit = {}
    for k, v in reductionParadigme.iteritems():
        paradigmeReduit[v] = paradigmeReduit.get(v, [])
        paradigmeReduit[v].append(k)
    print "syncrétismes",len(paradigmeReduit), sorted(paradigmeReduit.keys())
    print paradigmeReduit

# %%
def findClique(cliques,remElement="node"):
    pNodes=set()

    sCliques=sorted(cliques, key=len, reverse=True)

    cliqueFound=sorted(sCliques[0])
    pNodes=pNodes|set(sCliques[0])

    if remElement=="clique":
        removeCliques=[]
        for clique in sCliques:
            sClique=set(clique)
            if set.intersection(pNodes,sClique):
                removeCliques.append(clique)
        for clique in removeCliques:
            sCliques.remove(clique)
    elif remElement=="node":
        newCliques=[]
        for clique in sCliques:
            sClique=set(clique)
            diffClique=list(sClique-set.intersection(pNodes,sClique))
            if diffClique:
                newCliques.append(diffClique)               
#            print "sortie",newCliques
        sCliques=sorted(newCliques,key=len,reverse=True)
    else:
        print "remElement non prévu"
    return (cliqueFound,sCliques)

# %%
def findPartition(syncretismes):
    g=nx.Graph()
    for node in list(lexique[lexique["tir1"]>0]["case"].unique()):
        g.add_node(node)
    for syncretisme in syncretismes:
        c1,c2=syncretisme.split(" = ")
        g.add_edge(c1,c2)
    cliques.extend(list(nx.find_cliques(g)))
    sCliques=sorted(cliques, key=len, reverse=True)
    foundCliques=[]
    while sCliques:
        foundClique,sCliques=findClique(sCliques)
        foundCliques.append(foundClique)
    foundNodes=set(n for l in foundCliques for n in l )
    missingNodes=[[n] for n in g.nodes() if not n in foundNodes]
    partition=foundCliques+missingNodes
    dictPartition={l[0]:l for l in partition}
    return dictPartition

# %%
def drawPartition(dictPartition):
    g=nx.DiGraph()
    g.add_node("paradigme",color="red")
    for numMorphome,morphome in enumerate(dictPartition):
        g.add_node("M%02d"%numMorphome,color="blue")
        g.add_edge("paradigme","M%02d"%numMorphome)
        for case in dictPartition[morphome]:
            g.add_edge("M%02d"%numMorphome,case)
    graphs.append(g)

# %%
def findColours(dictPartition,debug=False):
    def assignColour(listMorphome,morphColour):
        for m in listMorphome:
            if not m in dictColours:
                dictColours[m]=morphColour
            else:
                print "conflit sur %s entre %s et %s"%(m,dictColours[m],morphColour)

    dictColours={}
    iCoul=0
    for morphome in dictPartition:
        listMorphome=dictPartition[morphome]
        lenMorphome=len(listMorphome)
        if lenMorphome>1:
            if debug: print lenMorphome,listMorphome,
            if morphome in couleurCase:
                if debug: print couleurCase[morphome]
                morphColour=couleurCase[morphome]
            else:
                noCoul=True
                for el in listMorphome:
                    if el in couleurCase:
                        if debug: print couleurCase[el]
                        morphColour=couleurCase[el]
                        noCoul=False
                        break
                if noCoul:
                    if debug: print "autre",coulMT[iCoul]
                    morphColour=coulMT[iCoul]
                    iCoul+=1
        else:
            morphColour="white"
        assignColour(listMorphome,morphColour)
    return dictColours

# %%
def makeTabular(dictColours,title="",coulLim=False):
    tabular=[]
    def makeLine6(tenseCode):
        line=[]
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            case=tenseCode+person
            if case in dictColours:
                line.append(r"\cellcolor{%s}%s"%(dictColours[case],case))
            else:
                line.append(r"\cellcolor{%s}%s"%("black",case))
        return r" & ".join(line)+r"\\"

    def makeLine3(tenseCode):
        line=[]
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            if person in ["2S","1P","2P"]:
                case=tenseCode+person
                line.append(r"\cellcolor{%s}%s"%(dictColours[case],case))
            else:
                line.append(r"---")
        return r" & ".join(line)+r"\\"
    
    def makeLineNF():
        line=[]
        for case in ["inf","pP","ppMS","ppMP","ppFS","ppFP"]:
            line.append(r"\cellcolor{%s}%s"%(dictColours[case],case))
        return r" & ".join(line)+r"\\"
    
    def makeLineCoulLim():
        line=[]
        for numLimite,limite in enumerate(listLimites):
            line.append(r"\cellcolor{%s}%s"%(listLimCoul[numLimite],"$<$"+str(limite)))
        return r"\hline\hline "+r" & ".join(line)+r"\\"
        
    top=[
        r"\begin{center}",
        r"\begin{tabular}{cccccc}",
        r"\hline"
        ]
    bottom=[
        r"\hline",
        r"\end{tabular}\\",
        title,
        r"\end{center}",
        r"\bigskip",
        r""
        ]
    tabular.append("\n".join(top))
    for tenseCode in ["pi","ii","fi","pc", "ps","ai", "is"]:
        tabular.append(makeLine6(tenseCode))
    tabular.append(makeLine3("pI"))
    tabular.append(makeLineNF())
    if coulLim:
        tabular.append(makeLineCoulLim())
    tabular.append("\n".join(bottom))
    return "\n".join(tabular)

# %%
def caseEgalite(c1,c2,debug=False):
    c1Val=paradigmes[c1].notnull()
    c2Val=paradigmes[c2].notnull()
    c1Sur=paradigmes[c1].str.contains(",")
    c2Sur=paradigmes[c2].str.contains(",")
    l1=len(paradigmes[paradigmes[c1].notnull()])
    l2=len(paradigmes[paradigmes[c2].notnull()])
    egalPaire=paradigmes[c1Val & c2Val & (paradigmes[c1]==paradigmes[c2])][[c1,c2]]
    diffPaire=paradigmes[c1Val & c2Val & (paradigmes[c1]!=paradigmes[c2])][[c1,c2]]
    lenDiff=len(diffPaire[~diffPaire[c1].str.contains(",") & ~diffPaire[c2].str.contains(",")])
    if lenDiff>0:
        return False
        if debug:
            print u"%s ≠ %s"%(c1,c2)
            print "différence",lenDiff
            if lenDiff<12:
                print diffPaire
    else:
        surAbondant=diffPaire[diffPaire[c1].str.contains(",") | diffPaire[c2].str.contains(",")]
        if len(surAbondant)==0:
            if len(egalPaire)>0 or noDiff:
                if debug: print u"%s = %s"%(c1,c2), len(egalPaire)
                return True
        else:
            compatible=True
            egalCount=0
            for index,row in surAbondant.iterrows():
                if "," in row[c1]:
                    if "," in row[c2]:
                        setC1=set(row[c1].split(","))
                        setC2=set(row[c2].split(","))
                        print setC1&setC2
                        if not setC1&setC2:
                            compatible=False
                            break
                        else:
                            egalCount+=1
                    else:
                        if not row[c2] in row[c1].split(","):
                            compatible=False
                            break
                        else:
                            egalCount+=1
                else:
                    if not row[c1] in row[c2].split(","):
                        compatible=False
                        break
                    else:
                        egalCount+=1
            if compatible:
                if debug: print u"%s = %s"%(c1,c2), len(egalPaire), egalCount
                return True
            else:
                if debug: print u"%s ≠ %s"%(c1,c2)
                if debug: print surAbondant
                return False

# %%
def defParadigme(paradigmes,debug=False):
    syncretisms=[]

    cases=[c for c in paradigmes.columns.tolist() if c!="lexeme"]
    if debug: print "%d cases :"%len(cases),", ".join(cases)
    for (c1,c2) in it.combinations(cases, 2):
        if caseEgalite(c1,c2):
            syncretisms.append(u"%s = %s"%(c1,c2))
    dictPartition=findPartition(syncretisms)
    itemizeLines.append("%d morphomes"%len(dictPartition))
    for key in sorted(dictPartition):
        if debug: print "%s: %s," % (key, dictPartition[key]),
    if debug: print
    drawPartition(dictPartition)
    return(dictPartition)

# %% [raw]
# def pivotLexique(lexique,debug=False):
#     paradigmes=pd.pivot_table(lexique[lexique["tir1"]>0], values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
#     return defParadigme(paradigmes,debug)

# %%
def makeItemize(itemizeLines):
    lines=[]
    lines.append(r"\begin{itemize}")
    for line in itemizeLines:
        lines.append(r"\item "+line)
    lines.append(r"\end{itemize}")
    return "\n".join(lines)

# %%
def findNumberColour(dictNumbers):
    result={}
    for case in dictNumbers:
        if dictNumbers[case]<listLimites[0]:
            result[case]=listLimCoul[0]
        elif dictNumbers[case]<listLimites[1]:
            result[case]=listLimCoul[1]
        elif dictNumbers[case]<listLimites[2]:
            result[case]=listLimCoul[2]
        elif dictNumbers[case]<listLimites[3]:
            result[case]=listLimCoul[3]
        elif dictNumbers[case]<listLimites[4]:
            result[case]=listLimCoul[4]
        else:
            result[case]=listLimCoul[5]
    return result

# %%
def regroupeLexique(dictPartition,lexique):
    lexiqueRegroupe=lexique.copy()
    for p in dictPartition:
        lCases=dictPartition[p]
        lexiqueRegroupe.loc[lexiqueRegroupe["case"].isin(lCases),"morphome"]="/".join(lCases)
        lexiqueRegroupe.loc[lexiqueRegroupe["case"].isin(lCases),"case"]=p
    return lexiqueRegroupe.groupby(["lexeme","phono","case","morphome"]).agg({"freq":np.sum, "tir1":np.sum}).reset_index()

# %%
graphs=[]
latexLines=[]
for nomLexique in sorted(listeTirages100k):
    lexique=lireLexique(nomLexique)
    lexique["phono"]=lexique["phono"].apply(checkFrench)
    lexique1=lexique[lexique["tir1"]>0]
    taille=lexique1["tir1"].count()
    itemizeLines=[]
    latexLines.append(nomLexique.split("/")[-1])
    itemizeLines.append("%d formes"%taille)
    itemizeLines.append("%d tirages"%lexique1["tir1"].sum())
    paradigmes=pd.pivot_table(lexique1, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
    dictNumbers=findFormNumbers(paradigmes)
    dictFormNumbers=findNumberColour(dictNumbers)

    syncretisms=[]
    cliques=[]

    dictPartition=defParadigme(paradigmes)
    if regroupeTirages:
        lexiqueRegroupe=regroupeLexique(dictPartition,lexique1)
        nomLexiqueRegroupe=nomLexique.replace(".pkl","-Morphomes.pkl")
        if nomLexique==nomLexiqueRegroupe:
            print u"pb avec le nom du fichier pour les tirages regroupés"
        else:
            with open(nomLexiqueRegroupe,"wb") as output:
                pickle.dump(lexiqueRegroupe, output, pickle.HIGHEST_PROTOCOL)
    dictColours=findColours(dictPartition)
    latexLines.append(makeItemize(itemizeLines))
    latexLines.append(makeTabular(dictColours,title="Morphomes"))
    if nbFormesPrint:
        latexLines.append(makeTabular(dictFormNumbers,title="Nombre de formes",coulLim=True))
if noDiff:
    nomFichierMorphomes=nomFichierMorphomes.replace(".tex","-NoDiff.tex")
else:
    nomFichierMorphomes=nomFichierMorphomes.replace(".tex","-Diff.tex")
with open(nomFichierMorphomes,"w") as output:
    output.write("\n".join(latexLines))

# %% [raw]
# try:
#     import pygraphviz
#     from networkx.drawing.nx_agraph import write_dot
#     print("using package pygraphviz")
# except ImportError:
#     try:
#         import pydotplus
#         from networkx.drawing.nx_pydot import write_dot
#         print("using package pydotplus")
#     except ImportError:
#         print()
#         print("Both pygraphviz and pydotplus were not found ")
#         print("see http://networkx.github.io/documentation"
#               "/latest/reference/drawing.html for info")
#         print()
#         raise

# %% [raw]
# G=graphs[0]
# #pos =
# #nx.draw(G,pos=nx.layout.fruchterman_reingold_layout(G,scale=20))
# for numG,G in enumerate(graphs):
#     write_dot(G,"test%02d.dot"%numG)

# %%
pdLexiqueRegroupe=regroupeLexique(dictPartition,lexique1)
pdLexiqueRegroupe
pdParadigmeRegroupe=pd.pivot_table(pdLexiqueRegroupe, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x))
pdParadigmeRegroupe.to_dict(orient="index")
# Out:
# {u'escamoter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'EskamOt6rE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'EskamOte',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'assembler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'as\xe2bla',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'as\xe2ble',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': u'as\xe2bl',
#   u'ppFP': u'as\xe2ble',
#   u'ppMP': u'as\xe2ble',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'ensanglanter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'\xe2s\xe2gl\xe2tE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'\xe2s\xe2gl\xe2te',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'projeter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'prOZ6ta',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'prOZ6tE',
#   u'ii2P': None,
#   u'inf': u'prOZ6te',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'prOZEt',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'prOZ6te',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'forger': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'fOrZE',
#   u'ii2P': None,
#   u'inf': u'fOrZe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'fOrZ',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'fOrZ',
#   u'pi3P': None,
#   u'ppFP': u'fOrZe',
#   u'ppMP': u'fOrZe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'aider': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'Eda',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'Ed6rE',
#   u'fi2P': None,
#   u'fi2S': u'Ed6ra',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'EdE',
#   u'ii2P': u'Edje',
#   u'inf': u'Ede',
#   u'pI1P': None,
#   u'pI2P': u'Ede',
#   u'pI2S': u'Ed',
#   u'pP': u'Ed\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'Ed',
#   u'pi2P': u'Ede',
#   u'pi2S': u'Ed',
#   u'pi3P': u'Ed',
#   u'ppFP': u'Ede',
#   u'ppMP': u'Ede',
#   u'ps1P': None,
#   u'ps1S': u'Ed',
#   u'ps2P': u'Edje'},
#  u'limiter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'limite',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'limit',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'limit',
#   u'pi3P': None,
#   u'ppFP': u'limite',
#   u'ppMP': u'limite',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'pratiquer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'pratikE',
#   u'ii2P': None,
#   u'inf': u'pratike',
#   u'pI1P': None,
#   u'pI2P': u'pratike',
#   u'pI2S': u'pratik',
#   u'pP': u'pratik\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'pratik',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': u'pratik',
#   u'ppFP': u'pratike',
#   u'ppMP': u'pratike',
#   u'ps1P': None,
#   u'ps1S': u'pratik',
#   u'ps2P': None},
#  u'\xe9purer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'Epyre',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9lier': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'dEljE',
#   u'ii2P': None,
#   u'inf': u'dElje',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'dElje',
#   u'ppMP': u'dElje',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'r\xe9installer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'rE\xeastale',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': u'rE\xeastal\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'cabrioler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'kabrijOlE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'caner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'kane',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'voter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'vOte',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': u'vOt\xf4',
#   u'pi1S': u'vOt',
#   u'pi2P': None,
#   u'pi2S': u'vOt',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'vOte',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'surprendre': {u'ai1P': None,
#   u'ai1S': u'syrpri',
#   u'ai2P': None,
#   u'ai2S': u'syrpri',
#   u'ai3P': u'syrprir',
#   u'fi1P': None,
#   u'fi1S': u'syrpr\xe2drE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'syrpr6nE',
#   u'ii2P': None,
#   u'inf': u'syrpr\xe2dr',
#   u'pI1P': None,
#   u'pI2P': u'syrpr6ne',
#   u'pI2S': None,
#   u'pP': u'syrpr6n\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'syrpr\xe2',
#   u'pi3P': u'syrprEn',
#   u'ppFP': u'syrpriz',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': u'syrprEn',
#   u'ps2P': None},
#  u'devenir': {u'ai1P': None,
#   u'ai1S': u'd6v\xea',
#   u'ai2P': None,
#   u'ai2S': u'd6v\xea',
#   u'ai3P': u'd6v\xear',
#   u'fi1P': u'd6vj\xeadr\xf4',
#   u'fi1S': u'd6vj\xeadrE',
#   u'fi2P': u'd6vj\xeadre',
#   u'fi2S': u'd6vj\xeadra',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'd6v6nE',
#   u'ii2P': None,
#   u'inf': u'd6v6nir',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'd6vj\xea',
#   u'pP': u'd6v6n\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'd6vj\xea',
#   u'pi2P': None,
#   u'pi2S': u'd6vj\xea',
#   u'pi3P': u'd6vjEn',
#   u'ppFP': u'd6v6ny',
#   u'ppMP': u'd6v6ny',
#   u'ps1P': None,
#   u'ps1S': u'd6vjEn',
#   u'ps2P': None},
#  u'klaxonner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'klaksOn',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'klaksOne',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'divertir': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'divErtir',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'divErti',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'b\xe9er': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'be',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'admonester': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'admOnEstE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'admOnEst',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'verser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'vErsa',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'vErsE',
#   u'ii2P': None,
#   u'inf': u'vErse',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'vErs',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'vErs',
#   u'pi2P': None,
#   u'pi2S': u'vErs',
#   u'pi3P': u'vErs',
#   u'ppFP': None,
#   u'ppMP': u'vErse',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'rem\xe2cher': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'r6maSa',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9bouler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': u'dEbulje',
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'r\xe9crier': {u'ai1P': None,
#   u'ai1S': u'rEkrijE',
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'engueuler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'\xe2g6lE',
#   u'ii2P': None,
#   u'inf': u'\xe2g6le',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'\xe2g9l',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'\xe2g6le',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9nuer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'dEnyHe',
#   u'ppMP': u'dEnyHe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'abrutir': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'abrytisE',
#   u'ii2P': None,
#   u'inf': u'abrytir',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'abryti',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9verser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'dEvErsE',
#   u'ii2P': None,
#   u'inf': u'dEvErse',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'dEvErs',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9poss\xe9der': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'dEpOsEde',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'dEpOsEde',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'superposer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'sypErpOzE',
#   u'ii2P': None,
#   u'inf': u'sypErpOze',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'sypErpoz',
#   u'pi3P': None,
#   u'ppFP': u'sypErpOze',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'effeuiller': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'Ef6jE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'rebattre': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'r6batr',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': u'r6bate',
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9boiser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'dEbwaze',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'voir': {u'ai1P': u'vim',
#   u'ai1S': u'vi',
#   u'ai2P': None,
#   u'ai2S': u'vi',
#   u'ai3P': None,
#   u'fi1P': u'vEr\xf4',
#   u'fi1S': u'vErE',
#   u'fi2P': u'vEre',
#   u'fi2S': u'vEra',
#   u'fi3P': u'vEr\xf4',
#   u'ii1P': u'vwaj\xf4',
#   u'ii1S': u'vwajE',
#   u'ii2P': u'vwaje',
#   u'inf': u'vwar',
#   u'pI1P': u'vwaj\xf4',
#   u'pI2P': u'vwaje',
#   u'pI2S': u'vwa',
#   u'pP': u'vwaj\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': u'vwaj\xf4',
#   u'pi1S': u'vwa',
#   u'pi2P': u'vwaje',
#   u'pi2S': u'vwa',
#   u'pi3P': u'vwa',
#   u'ppFP': u'vy',
#   u'ppMP': u'vy',
#   u'ps1P': None,
#   u'ps1S': u'vwa',
#   u'ps2P': None},
#  u'adh\xe9rer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'adEr',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'persister': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'pErsista',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'pErsistE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': u'pErsiste',
#   u'pI2S': u'pErsist',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'pErsist',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'pr\xe9occuper': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'prEOkypE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'prEOkype',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'commenter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'kOm\xe2ta',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'kOm\xe2tE',
#   u'ii2P': None,
#   u'inf': u'kOm\xe2te',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'kOm\xe2t',
#   u'pP': u'kOm\xe2t\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'kOm\xe2te',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'scintiller': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u's\xeatijE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u's\xeatij',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'rapprocher': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'raprOSa',
#   u'ai3P': u'raprOSEr',
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'raprOSE',
#   u'ii2P': None,
#   u'inf': u'raprOSe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'raprOS',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'raprOS',
#   u'pi2P': None,
#   u'pi2S': u'raprOS',
#   u'pi3P': u'raprOS',
#   u'ppFP': u'raprOSe',
#   u'ppMP': u'raprOSe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'r\xe9g\xe9n\xe9rer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'rEZEnEre',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'\xe9peurer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'Ep6re',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'rutiler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'rytile',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'rytil',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'perp\xe9tuer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'pErpEty',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'pErpEtyHe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'chauffer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'SOfE',
#   u'ii2P': None,
#   u'inf': u'SOfe',
#   u'pI1P': None,
#   u'pI2P': u'SOfe',
#   u'pI2S': u'Sof',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'Sof',
#   u'pi2P': u'SOfe',
#   u'pi2S': u'Sof',
#   u'pi3P': None,
#   u'ppFP': u'SOfe',
#   u'ppMP': u'SOfe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'rouer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'ru',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9payser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'dEpEizE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'dEpEiz',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'dEpEize',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'pencher': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'p\xe2Sa',
#   u'ai3P': u'p\xe2SEr',
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'p\xe2SE',
#   u'ii2P': None,
#   u'inf': u'p\xe2Se',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'p\xe2S',
#   u'pP': u'p\xe2S\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'p\xe2S',
#   u'pi2P': u'p\xe2Se',
#   u'pi2S': u'p\xe2S',
#   u'pi3P': u'p\xe2S',
#   u'ppFP': u'p\xe2Se',
#   u'ppMP': u'p\xe2Se',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'poivrer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'pwavr',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'pwavr',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'exceller': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'EksElE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': u'EksEl',
#   u'ps2P': None},
#  u'agrandir': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'agr\xe2di',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'agr\xe2dirE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'agr\xe2disE',
#   u'ii2P': None,
#   u'inf': u'agr\xe2dir',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'agr\xe2di',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': u'agr\xe2dis',
#   u'ppFP': None,
#   u'ppMP': u'agr\xe2di',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'ranimer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'ranimE',
#   u'ii2P': None,
#   u'inf': u'ranime',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'ranime',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'moucharder': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'muSarde',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'muSard',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'muSarde',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'incarner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'\xeakarne',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'\xeakarn',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'\xeakarn',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'mailler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': u'maj\xf4',
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'remplacer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'r\xe2plasa',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'r\xe2plas6rE',
#   u'fi2P': None,
#   u'fi2S': u'r\xe2plas6ra',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'r\xe2plasE',
#   u'ii2P': None,
#   u'inf': u'r\xe2plase',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'r\xe2plas',
#   u'pP': u'r\xe2plas\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'r\xe2plase',
#   u'ppMP': u'r\xe2plase',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'risquer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'risk6rE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'riskE',
#   u'ii2P': None,
#   u'inf': u'riske',
#   u'pI1P': None,
#   u'pI2P': u'riske',
#   u'pI2S': u'risk',
#   u'pP': u'risk\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'risk',
#   u'pi2P': u'riske',
#   u'pi2S': u'risk',
#   u'pi3P': u'risk',
#   u'ppFP': None,
#   u'ppMP': u'riske',
#   u'ps1P': None,
#   u'ps1S': u'risk',
#   u'ps2P': None},
#  u'muer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'myHE',
#   u'ii2P': None,
#   u'inf': u'myHe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'myHe',
#   u'ppMP': u'myHe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'\xe9toiler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'Etwal',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'coter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'kOte',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'biner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'bine',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'reprocher': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'r6prOSa',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': u'r6prOSj\xf4',
#   u'ii1S': u'r6prOSE',
#   u'ii2P': None,
#   u'inf': u'r6prOSe',
#   u'pI1P': None,
#   u'pI2P': u'r6prOSe',
#   u'pI2S': u'r6prOS',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': u'r6prOS\xf4',
#   u'pi1S': u'r6prOS',
#   u'pi2P': u'r6prOSe',
#   u'pi2S': u'r6prOS',
#   u'pi3P': u'r6prOS',
#   u'ppFP': u'r6prOSe',
#   u'ppMP': u'r6prOSe',
#   u'ps1P': None,
#   u'ps1S': u'r6prOS',
#   u'ps2P': None},
#  u'supplier': {u'ai1P': None,
#   u'ai1S': u'syplijE',
#   u'ai2P': None,
#   u'ai2S': u'syplija',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': u'syplira',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'syplijE',
#   u'ii2P': None,
#   u'inf': u'syplije',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'sypli',
#   u'pP': u'sypli\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'sypli',
#   u'pi2P': None,
#   u'pi2S': u'sypli',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'syplije',
#   u'ps1P': None,
#   u'ps1S': u'sypli',
#   u'ps2P': None},
#  u'acagnarder': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'akaJardE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'offenser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'Of\xe2se',
#   u'pI1P': None,
#   u'pI2P': u'Of\xe2se',
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'Of\xe2s',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'Of\xe2se',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'fusionner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'fyzjOne',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'confisquer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'k\xf4fiska',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'k\xf4fiske',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'k\xf4fisk',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'k\xf4fiske',
#   u'ppMP': u'k\xf4fiske',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'reporter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'r6pOrte',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'r6pOrt',
#   u'pi2P': u'r6pOrte',
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'sacquer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'sak',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'diss\xe9miner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'disEminE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'disEmine',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'susurrer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'sysyre',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'revivre': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'r6vivE',
#   u'ii2P': None,
#   u'inf': u'r6vivr',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'r6vi',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': u'r6viv',
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'\xe9reinter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'Er\xeate',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'fissurer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'fisyrE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'fisyr',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'fisyre',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'susciter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'sysita',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'sysitE',
#   u'ii2P': None,
#   u'inf': u'sysite',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'sysit',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'sysite',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'intimider': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'\xeatimidE',
#   u'ii2P': None,
#   u'inf': u'\xeatimide',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'\xeatimid',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'\xeatimide',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9vouer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'dEvuwe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'dEvuwe',
#   u'ppMP': u'dEvuwe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'stresser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'strEse',
#   u'ppMP': u'strEse',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'figer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'fiZa',
#   u'ai3P': u'fiZEr',
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'fiZE',
#   u'ii2P': None,
#   u'inf': u'fiZe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'fiZe',
#   u'ppMP': u'fiZe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'expliciter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'Esplisite',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'indiquer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'\xeadika',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': u'\xeadik6ra',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'\xeadikE',
#   u'ii2P': None,
#   u'inf': u'\xeadike',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': u'\xeadik\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'\xeadik',
#   u'pi2P': None,
#   u'pi2S': u'\xeadik',
#   u'pi3P': None,
#   u'ppFP': u'\xeadike',
#   u'ppMP': u'\xeadike',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'boudiner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': u'budin',
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'rep\xe9rer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'r6pEra',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'r6pEre',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'r6pEr',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'r6pEr',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': u'r6pEr',
#   u'ppFP': u'r6pEre',
#   u'ppMP': u'r6pEre',
#   u'ps1P': None,
#   u'ps1S': u'r6pEr',
#   u'ps2P': None},
#  u'sourdre': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'surdr',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'r\xe9futer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'rEfyta',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'rEfyt',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'changer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'S\xe2Za',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'S\xe2Z6rE',
#   u'fi2P': None,
#   u'fi2S': u'S\xe2Z6ra',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'S\xe2ZE',
#   u'ii2P': u'S\xe2Zje',
#   u'inf': u'S\xe2Ze',
#   u'pI1P': u'S\xe2Z\xf4',
#   u'pI2P': u'S\xe2Ze',
#   u'pI2S': u'S\xe2Z',
#   u'pP': u'S\xe2Z\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'S\xe2Z',
#   u'pi2P': u'S\xe2Ze',
#   u'pi2S': u'S\xe2Z',
#   u'pi3P': u'S\xe2Z',
#   u'ppFP': u'S\xe2Ze',
#   u'ppMP': u'S\xe2Ze',
#   u'ps1P': None,
#   u'ps1S': u'S\xe2Z',
#   u'ps2P': None},
#  u'\xe9pingler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'Ep\xeagl',
#   u'pi3P': None,
#   u'ppFP': u'Ep\xeagle',
#   u'ppMP': u'Ep\xeagle',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'appeler': {u'ai1P': None,
#   u'ai1S': u'ap6lE',
#   u'ai2P': None,
#   u'ai2S': u'ap6la',
#   u'ai3P': None,
#   u'fi1P': u'apEl6r\xf4',
#   u'fi1S': u'apEl6rE',
#   u'fi2P': None,
#   u'fi2S': u'apEl6ra',
#   u'fi3P': None,
#   u'ii1P': u'ap6lj\xf4',
#   u'ii1S': u'ap6lE',
#   u'ii2P': None,
#   u'inf': u'ap6le',
#   u'pI1P': u'ap6l\xf4',
#   u'pI2P': u'ap6le',
#   u'pI2S': u'apEl',
#   u'pP': u'ap6l\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': u'ap6l\xf4',
#   u'pi1S': u'apEl',
#   u'pi2P': u'ap6le',
# ...
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'k\xf4fEksjOne',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'piloter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'pilOtE',
#   u'ii2P': None,
#   u'inf': u'pilOte',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'pilOt',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'pilOte',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'ch\xe2trer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'SatrE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'graisser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'grEse',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'bavarder': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': u'bavardj\xf4',
#   u'ii1S': u'bavardE',
#   u'ii2P': None,
#   u'inf': u'bavarde',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': u'bavard\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': u'bavard\xf4',
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'enr\xf4ler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': u'\xe2rOle',
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'pr\xe9lever': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'prEl6vE',
#   u'ii2P': None,
#   u'inf': u'prEl6ve',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'prElEv',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'prEl6ve',
#   u'ppMP': u'prEl6ve',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'noyer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': u'nwajEr',
#   u'fi1P': None,
#   u'fi1S': u'nwarE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'nwajE',
#   u'ii2P': None,
#   u'inf': u'nwaje',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'nwaje',
#   u'ppMP': u'nwaje',
#   u'ps1P': None,
#   u'ps1S': u'nwa',
#   u'ps2P': None},
#  u'grogner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'grOJa',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': u'grOJ\xf4',
#   u'ii1S': u'grOJE',
#   u'ii2P': None,
#   u'inf': u'grOJe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': u'grOJ\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'grOJ',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'ombrager': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'\xf4braZe',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'confluer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'k\xf4flyHe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'obstruer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'ObstryHE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': u'ObstryHe',
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'v\xe9hiculer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'vEikyle',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'vEikyl',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'entrechoquer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'\xe2tr6SOke',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9consigner': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'dEk\xf4siJe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'entortiller': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'\xe2tOrtije',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'taire': {u'ai1P': None,
#   u'ai1S': u'ty',
#   u'ai2P': None,
#   u'ai2S': u'ty',
#   u'ai3P': u'tyr',
#   u'fi1P': None,
#   u'fi1S': u'tErE',
#   u'fi2P': u'tEre',
#   u'fi2S': u'tEra',
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'tEzE',
#   u'ii2P': None,
#   u'inf': u'tEr',
#   u'pI1P': u'tEz\xf4',
#   u'pI2P': u'tEze',
#   u'pI2S': u'tE',
#   u'pP': u'tEz\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'tE',
#   u'pi2P': u'tEze',
#   u'pi2S': u'tE',
#   u'pi3P': u'tEz',
#   u'ppFP': None,
#   u'ppMP': u'ty',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'revaloriser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'r6valOrizE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9couvrir': {u'ai1P': None,
#   u'ai1S': u'dEkuvri',
#   u'ai2P': u'dEkuvris',
#   u'ai2S': u'dEkuvri',
#   u'ai3P': u'dEkuvrir',
#   u'fi1P': None,
#   u'fi1S': u'dEkuvrirE',
#   u'fi2P': None,
#   u'fi2S': u'dEkuvrira',
#   u'fi3P': u'dEkuvrir\xf4',
#   u'ii1P': u'dEkuvri\xf4',
#   u'ii1S': u'dEkuvrE',
#   u'ii2P': None,
#   u'inf': u'dEkuvrir',
#   u'pI1P': None,
#   u'pI2P': u'dEkuvre',
#   u'pI2S': u'dEkuvr',
#   u'pP': u'dEkuvr\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': u'dEkuvr\xf4',
#   u'pi1S': u'dEkuvr',
#   u'pi2P': None,
#   u'pi2S': u'dEkuvr',
#   u'pi3P': u'dEkuvr',
#   u'ppFP': None,
#   u'ppMP': u'dEkuvEr',
#   u'ps1P': None,
#   u'ps1S': u'dEkuvr',
#   u'ps2P': None},
#  u'zigzaguer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': u'zigzag\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': u'zigzag',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'p\xe9ter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'pEtE',
#   u'ii2P': None,
#   u'inf': u'pEte',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'pEt',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'pEt',
#   u'pi2P': None,
#   u'pi2S': u'pEt',
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'pEte',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9crocher': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': u'dEkrOS6r\xf4',
#   u'ii1P': None,
#   u'ii1S': u'dEkrOSE',
#   u'ii2P': None,
#   u'inf': u'dEkrOSe',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'dEkrOS',
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'dEkrOS',
#   u'pi2P': None,
#   u'pi2S': u'dEkrOS',
#   u'pi3P': None,
#   u'ppFP': u'dEkrOSe',
#   u'ppMP': u'dEkrOSe',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'expier': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'Ekspje',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'hausser': {u'ai1P': None,
#   u'ai1S': u'OsE',
#   u'ai2P': None,
#   u'ai2S': u'Osa',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'OsE',
#   u'ii2P': None,
#   u'inf': u'Ose',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': u'Os\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'os',
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': u'Ose',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'maltraiter': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'maltrEte',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'd\xe9primer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'dEprim6rE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'dEprime',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'dEprim',
#   u'pi2P': None,
#   u'pi2S': u'dEprim',
#   u'pi3P': None,
#   u'ppFP': u'dEprime',
#   u'ppMP': u'dEprime',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'muser': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': u'myzE',
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'surestimer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': None,
#   u'pI1P': None,
#   u'pI2P': u'syrEstime',
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'bricoler': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': None,
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': None,
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': None,
#   u'ii1P': None,
#   u'ii1S': None,
#   u'ii2P': None,
#   u'inf': u'brikOle',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': None,
#   u'pP': None,
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': None,
#   u'pi2P': None,
#   u'pi2S': None,
#   u'pi3P': None,
#   u'ppFP': None,
#   u'ppMP': None,
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  u'allumer': {u'ai1P': None,
#   u'ai1S': None,
#   u'ai2P': None,
#   u'ai2S': u'alyma',
#   u'ai3P': None,
#   u'fi1P': None,
#   u'fi1S': u'alym6rE',
#   u'fi2P': None,
#   u'fi2S': None,
#   u'fi3P': u'alym6r\xf4',
#   u'ii1P': u'alymj\xf4',
#   u'ii1S': u'alymE',
#   u'ii2P': None,
#   u'inf': u'alyme',
#   u'pI1P': None,
#   u'pI2P': None,
#   u'pI2S': u'alym',
#   u'pP': u'alym\xe2',
#   u'pc1P': None,
#   u'pc2P': None,
#   u'pi1P': None,
#   u'pi1S': u'alym',
#   u'pi2P': u'alyme',
#   u'pi2S': u'alym',
#   u'pi3P': None,
#   u'ppFP': u'alyme',
#   u'ppMP': u'alyme',
#   u'ps1P': None,
#   u'ps1S': None,
#   u'ps2P': None},
#  ...}

# %%
pdLexiqueRegroupe[pdLexiqueRegroupe["lexeme"]==u"abaisser"][["phono","case"]]
# Out:
#    phono  case
# 0  abEsE  ii1S
# 1  abEsa  ai2S
# 2  abEse   inf
# 3  abEse  pI2P

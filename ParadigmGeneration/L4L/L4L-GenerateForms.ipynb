# %% [markdown]
# # Génération des réseaux de formes à partir des règles
# - Gén-1 : génération des formes d'après les contextes phonologiques

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs,operator,datetime,os,glob
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

def ding():
    os.system('afplay /System/Library/Sounds/Submarine.aiff')

# %%
# %matplotlib inline

# %%
import yaml

# %%
from ipywidgets import FloatProgress
from IPython.display import display, HTML

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ### Préparation des matrices de traits

# %%
repConfig="/Users/gilles/Github/SWIM/ParadigmGeneration/L4L/"
features.add_config(repConfig+'bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %% [markdown]
# # Choix de l'échantillon et des règles
# - *sampleFile* est le nom de l'échantillon de départ
# - *rulesFile* est le nom du fichier de règles
# - *goldFile* est le nom du lexique Gold de référence

# %%
repFiles="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/L4L/IMM21/"
tirageFile="IMM21-00.pkl"
rulesFile="IMM21-00-X-Regles.pkl"
sampleFile="IMM21-00-X-paradigmes.csv"
fTirage=repFiles+tirageFile
fRules=repFiles+rulesFile
fSample=repFiles+sampleFile
fInitial=fSample

# %%
sampleType="-X"
casesType=""
# casesType="-Morphomes"
listeFormesOutput=["FS","FP"]

# %%
with open(fTirage, 'rb') as input:
    sampleTirage = pickle.load(input)
sampleTirage.head()
# Out:
#      ortho  phono   lexeme  freq  case  freqcum  tir1
# 0  gauchir  gOSir  gauchir     1   inf        1     1
# 1  gauchir   gOSi  gauchir     1  pi3S        1     1
# 2  gauchir   gOSi  gauchir     1  ppFS        1     1
# 3  gauchir   gOSi  gauchir     1  ppFP        1     1
# 4  gauchir   gOSi  gauchir     1  ppMP        1     1

# %%
if not "morphome" in sampleTirage.columns.tolist():
    sampleTirage["morphome"]=sampleTirage["case"]
morphomeCases=sampleTirage[["case","morphome"]].drop_duplicates().to_dict()
# morphomeCases

# %%
casesMC=morphomeCases["case"]
morphomesMC=morphomeCases["morphome"]
dictMorphomeCases={}
for element in casesMC:
    dictMorphomeCases[casesMC[element]]=morphomesMC[element].split("/")
dictMorphomeCases
# Out:
# {'inf': ['inf'],
#  'pi3S': ['pi3S'],
#  'ppFS': ['ppFS'],
#  'ppFP': ['ppFP'],
#  'ppMP': ['ppMP'],
#  'ppMS': ['ppMS'],
#  'pP': ['pP'],
#  'ps3P': ['ps3P'],
#  'ii3P': ['ii3P'],
#  'pi1S': ['pi1S'],
#  'pi3P': ['pi3P'],
#  'fi2S': ['fi2S'],
#  'ai3S': ['ai3S'],
#  'pi2P': ['pi2P'],
#  'pi2S': ['pi2S'],
#  'fi1P': ['fi1P'],
#  'pI1P': ['pI1P'],
#  'pi1P': ['pi1P'],
#  'pI2S': ['pI2S'],
#  'pI2P': ['pI2P'],
#  'pc3P': ['pc3P'],
#  'fi1S': ['fi1S'],
#  'ai2S': ['ai2S'],
#  'ps2S': ['ps2S'],
#  'ai1S': ['ai1S'],
#  'ai3P': ['ai3P'],
#  'ps1S': ['ps1S'],
#  'ps3S': ['ps3S'],
#  'pc2S': ['pc2S'],
#  'pc2P': ['pc2P'],
#  'ii3S': ['ii3S'],
#  'ai2P': ['ai2P'],
#  'ii1S': ['ii1S'],
#  'ii1P': ['ii1P'],
#  'fi2P': ['fi2P'],
#  'ps2P': ['ps2P'],
#  'pc1S': ['pc1S'],
#  'pc1P': ['pc1P'],
#  'ai1P': ['ai1P'],
#  'pc3S': ['pc3S'],
#  'is3S': ['is3S'],
#  'ii2S': ['ii2S'],
#  'ii2P': ['ii2P'],
#  'is3P': ['is3P'],
#  'is1S': ['is1S'],
#  'fi3P': ['fi3P'],
#  'fi3S': ['fi3S'],
#  'ps1P': ['ps1P'],
#  'is1P': ['is1P'],
#  'is2S': ['is2S'],
#  'is2P': ['is2P']}

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            if debug: print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
        self.classeCF={}
        self.nbClasseCF={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeFormeCF=[]
        regleFormeCF=""
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            filterF1=".*"+patron.split("-")[0]+"$"
            if re.match(filterF1,forme1):
                classeFormeCF.append(patron)
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleFormeCF=patron
            filterF1=self.patrons[patron]
            if re.match(filterF1,forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseFormeCF=", ".join(classeFormeCF)
        if not idClasseFormeCF in self.classeCF:
            self.classeCF[idClasseFormeCF]={}
            self.nbClasseCF[idClasseFormeCF]=0
        if not regleFormeCF in self.classeCF[idClasseFormeCF]:
            self.classeCF[idClasseFormeCF][regleFormeCF]=0
        self.nbClasseCF[idClasseFormeCF]+=1
        self.classeCF[idClasseFormeCF][regleFormeCF]+=1
        
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme,contextFree=True):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if contextFree:
                filterF1=".*"+patron.split("-")[0]+"$"
            else:
                filterF1=self.patrons[patron]
            if re.match(filterF1,forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if contextFree:
                nbClasse=self.nbClasseCF
                classe=self.classeCF
            else:
                nbClasse=self.nbClasse
                classe=self.classe
            if idClasseForme in nbClasse:
                nTotal=nbClasse[idClasseForme]
                for patron in classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            if debug:
                print (forme, file=logfile) 
                print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# # Lecture de l'échantillon

# %%
phonologicalMap=sampleType.strip("-")
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("X")
bdlexiqueIn = u"èò"+neutralisations[0]
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = u"EO"+neutralisations[1]
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# ### Vérification de la phonotactique des glides du français
# - si *prononciation* est *None* renvoyer *None*
# - ajout de diérèses dans les séquences mal-formées
# - vérification des séquences consonne+glide à la finale

# %%
dierese={"j":"ij", "w":"uw","H":"yH","i":"ij","u":"uw","y":"yH"}

# %%
def checkFrench(prononciation):
    if prononciation:
        result=recoder(prononciation)
        m=re.match(r"^.*([^ieèEaOouy926êôâ])[jwH]$",result)
        if m:
            print ("pb avec un glide final", prononciation)
        m=re.match(r"(.*[ptkbdgfsSvzZ][rl])([jwH])(.*)",result)
        if m:
            n=re.search(r"[ptkbdgfsSvzZ][rl](wa|Hi|wê)",result)
            if not n:
                glide=m.group(2)
                result=m.group(1)+dierese[glide]+m.group(3)
        m=re.match(r"(.*)([iuy])([ieEaOouy].*)",result)
        if m:
            glide=m.group(2)
            result=m.group(1)+dierese[glide]+m.group(3)
        result=result.replace("Jj","J")
    else:
        result=prononciation
    return result

# %%
paradigmes=pd.read_csv(fSample,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
paradigmes=paradigmes.dropna(axis=1,how='all')

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")
#sampleCases

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 110056

# %%
len(paradigmes.dropna(thresh=1)["lexeme"])
# Out:
# 6433

# %% [markdown]
# ## Préparation des données initiales et de référence

# %%
listeTest=paradigmes.dropna(thresh=1)["lexeme"].values.tolist()
#listeTest=[u"asseoir",u"balayer",u"manger"]
nbVerbes=len(listeTest)
print (nbVerbes)
# Out:
# 6433

# %% [markdown]
# ### Préparation des formes initiales

# %%
initialParadigmes=pd.read_csv(fInitial,sep=";",encoding="utf8")
del initialParadigmes[u"Unnamed: 0"]
initialParadigmes=initialParadigmes.dropna(axis=1,how='all')

# %%
initialForms=pd.melt(initialParadigmes[paradigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()

initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)

initialForms.set_index(["lexeme-case"],inplace=True)

initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# # Lecture des règles

# %%
with open(fRules, 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ### Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
print (", ".join(analyseCases))
# Out:
# pi3P, ps1P, ppFP, is1P, ai1S, pc3P, pI1P, ii3S, ps3P, fi1P, pP, ai3P, ai3S, pi1P, fi3S, fi1S, ai2P, pc2P, fi2S, ii2P, pI2S, ai2S, fi2P, ps3S, ii1P, pi2P, pI2P, ppFS, pi2S, pc3S, ii2S, ps2S, is2S, ii3P, is2P, is3S, pc1P, ai1P, inf, is1S, ps1S, ppMS, pc2S, is3P, ii1S, ppMP, pi1S, pi3S, ps2P, fi3P, pc1S

# %% [markdown]
# # Préparations pour la génération des formes

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme,contextFree=False):
    # pb avec l'encodage des noms de lexèmes
    candidats=paradigmeDistribution(lexeme)
    bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
    casesSamples=paradigmes[bLexParadigme].columns[paradigmes[bLexParadigme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[bLexParadigme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element,contextFree),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart,contextFree))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        # modif pour networkx v2
        # coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        coefGraphe=float(digraphe.adj[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True,contextFree=False):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart,contextFree)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %% [markdown]
# # Génération d'un jeu de cliques

# %%
def generate(lexeme,genDigraphe=True,contextFree=False):
    # print (lexeme,end=", ")
    generation1=generateForms(lexeme,contextFree)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe,contextFree)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
paradigmes.dropna(thresh=1).count().sum()-paradigmes.dropna(thresh=1)["lexeme"].count()
# Out:
# 40185

# %% [markdown]
# #### Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    if len(clique)>1:
        for (depart,arrivee) in it.combinations_with_replacement(clique,2):
            score+=graph[depart][arrivee]["weight"]
    return score

# %%
def splitArrivee(arrivee):
    arriveeMorceaux=arrivee.split("-")
    if len(arriveeMorceaux)<3:
        print (arrivee,arriveeMorceaux)
    lexeme="-".join(arriveeMorceaux[:-2])
    formeArrivee=arriveeMorceaux[-2]
    caseArrivee=arriveeMorceaux[-1]
    return (lexeme,formeArrivee,caseArrivee)
    
# trouver tous les liens vers FS-* et FP-*
# regrouper par forme 
# calculer les proportions
# renvoyer les proportions par forme
# avec le nombre de forme à l'appui
def formeScore(forme,graph):
    scores={}
    scoresNormes={}
    # modif pour networkx v2
    # for depart in graph.edge edge=>adj:
    for depart in graph.adj:
        for arrivee in graph.adj[depart]:
            (lexeme, formeArrivee, caseArrivee)=splitArrivee(arrivee)
            if caseArrivee==forme:
#                print (depart, formeArrivee, graph.edge[depart][arrivee])
                if not formeArrivee in scores:
                    scores[formeArrivee]=0
                scores[formeArrivee]+=graph.adj[depart][arrivee]["weight"]
    totalArrivee=0
    for formeArrivee in scores:
        totalArrivee+=scores[formeArrivee]
    for formeArrivee in scores:
        scoresNormes[formeArrivee]=scores[formeArrivee]/totalArrivee
    return (scores,scoresNormes)

# %% [markdown]
# ## Préparations pour SWIM

# %%
def generateAnalysis(globDigraphe,globGraphe,contextFree=False):
    numClique=0
    progressBar = FloatProgress(min=0, max=nbVerbes-1,description="Generation (%d verbs)"%nbVerbes)
    display(progressBar)
    for i,element in enumerate(listeTest):
        cliquesScores[element]={}
        cliquesListes[element]={}
        if (i%100)==0: print (i, dateheure()[-4:], int(100*float(i)/nbVerbes), end=", ")
        progressBar.value=i
        #print (element)
        result=generate(element,genDigraphe,contextFree)
        (generation,lexDigraphe,lexGraphe,lexCliques)= result
    #    print (generation,lexDigraphe,lexGraphe,lexCliques)
        if genFormeVotes:
            formesScores[element]={}
            formesScoresNormes[element]={}
            for formeOutput in listeFormesOutput:
                (formesScores[element][formeOutput],formesScoresNormes[element][formeOutput])=formeScore(formeOutput,lexDigraphe)
        if genDigraphe:
            globDigraphe=nx.union(globDigraphe,lexDigraphe)
        if genGraphe:
            globGraphe=nx.union(globGraphe,lexGraphe)
        cliques.extend(lexCliques)
        for clique in lexCliques:
            cliquesScores[element][numClique]=cliqueScore(clique,lexGraphe)
            cliquesListes[element][numClique]=clique
            numClique+=1
    return globDigraphe,globGraphe,numClique

# %%
def dictCliqueForms(clique):
    result={}
    for element in clique:
        lexeme,forme,case=splitArrivee(element)
        for c in dictMorphomeCases[case]:
            result[c]=forme
    return result

def dictPdRowForms(row):
    result={}
    for case in sampleCases:
        print (case,row[case].values[0])
    return result

def tableZero(case):
    if case in sampleCases:
        return u"Ø"
    else:
        return u"="

def makeTable(dictForms,title=""):
    tabular=[]
    labelTenseCode={"pi":"Present","ii":"Imperfective","ai":"Simple Past","fi":"Future",
                    "ps":"Subjunctive Pres.","is":"Subjunctive Imp.","pc":"Conditional","pI":"Imperative",
                    "inf":"Infinitive",
                    "ppMS":"Past Part. MS","ppMP":"Past Part. MP",
                    "ppFS":"Past Part. FS","ppMP":"Past Part. FP"
                   }
    def makeLine6(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            case=tenseCode+person
            if (case in dictForms) and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"

    def makeLine3(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            if person in ["2S","1P","2P"]:
                case=tenseCode+person
                if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                    line.append(r"<td>%s</td>"%(dictForms[case]))
                else:
                    line.append(r"<td>%s</td>"%(tableZero(case)))
            else:
                line.append(r"<td>%s</td>"%(u"---"))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
    def makeLineNF():
        line=[]
        line.append(r"<th>%s</th>"%"NF")
        for case in ["inf","pP","ppMS","ppMP","ppFS","ppFP"]:
            if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
        
    top=[
        r"<table>",
        r"<caption style='caption-side:bottom;text-align:center'>",
        "Verbe : %s"%title,
        r"</caption>",
#        r"<tr><th/><th>1S</th><th>2S</th><th>3S</th><th>1P</th><th>2P</th><th>3P</th></tr>"
        r"<tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>"
        ]
    bottom=[
        r"</table>"
        ]
    tabular.append("\n".join(top))
    for tenseCode in ["pi","ii","fi","pc", "ps","ai", "is"]:
        tabular.append(makeLine6(tenseCode))
    tabular.append(makeLine3("pI"))
    tabular.append(makeLineNF())
    tabular.append("\n".join(bottom))
    return "\n".join(tabular)    

def diffParadigme(lexeme):
    outLen=lexemeMaxCliques[lexeme][0]
    bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
    inLen=paradigmes[bLexParadigme].notnull().sum(axis=1).values[0]-1
    if outLen>inLen:
        print (lexemeMaxCliques[lexeme][1])
        print (paradigmes[paradigmes["lexeme"]=="grandir"].values)
    return outLen-inLen

# %%
def checkFidelite(fidelite,clique):
    lFidele=False
    for element in clique:
        if fidelite in element:
            lFidele=True
    return lFidele

def generateCliques(contextFree=False):
    
    def bruteCliques(lexeme,maxCliqueSize=51):
        cliquesBrutes={n+1:0 for n in range(maxCliqueSize)}
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                if not longueur in cliquesBrutes:
                    cliquesBrutes[longueur]=0
                cliquesBrutes[longueur]+=1
        return cliquesBrutes
    
    globDigraphe=nx.DiGraph()
    globGraphe=nx.Graph()

    globDigraphe,globGraphe,numClique=generateAnalysis(globDigraphe,globGraphe,contextFree)
    print 

    lexemeMaxCliques={}
    lexemeParadigmes={}
    progressBarCliques = FloatProgress(min=0, max=len(cliquesListes)-1,description="Analysis (%d verbes)"%len(cliquesListes))
    display(progressBarCliques)
    for lexeme in cliquesListes:
        progressBarCliques.value+=1
        maxLen=max([len(c) for c in cliquesListes[lexeme].values()])
        lexemeMaxCliques[lexeme]=bruteCliques(lexeme,maxLen)
        print (lexeme,"Nombre de cliques",sum([v for k,v in lexemeMaxCliques[lexeme].iteritems()]))
        maxNbCliques=max([v for k,v in lexemeMaxCliques[lexeme].iteritems()])
        if plotDistributionCliques:
            ax=pd.DataFrame.from_dict(lexemeMaxCliques[lexeme],orient="index").plot(kind="bar",legend=False,grid=True,figsize=(10,3))
            ax.set(xlim=(0,maxLen+.5),ylim=(0,maxNbCliques+10))
            ax.set_xlabel("Clique Size in Cells",fontsize=16)
            ax.set_ylabel("Number of Cliques",fontsize=16)

        dictParadigmes=paradigmes.set_index("lexeme").to_dict(orient="index")

        cliquesFideles={}
        fidelites=[v+"-"+k for k,v in dictParadigmes[lexeme].iteritems() if isinstance(v,unicode)]
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                fidele=True
                for fidelite in fidelites:
                    if "," in fidelite:
                        fideliteForme,fideliteCase=fidelite.split("-")
                        fideliteFormes=fideliteForme.split(",")
                        fideliteItems=[fideliteF+"-"+fideliteCase for fideliteF in fideliteFormes]
#                        print (fideliteItems)
                        lFidele=True
                        for f in fideliteItems:
                            lFidele=lFidele & checkFidelite(f,l)
                    else:
                        lFidele=checkFidelite(fidelite,l)
                    if not lFidele:
                        fidele=False
                        break
                if fidele:
                    if not longueur in cliquesFideles:
                        cliquesFideles[longueur]=[]
                    cliquesFideles[longueur].append(l)
#                else:
#                    if lexeme==u"bégayer": print ()
#        print ([(k,len(v)) for k,v in cliquesFideles.iteritems()])
        if cliquesFideles:
            maxCliquesCard=max([k for k,v in cliquesFideles.iteritems()])
    #        print (maxCliquesCard)
    #        print (cliquesScores[lexeme])
    #        print (cliquesListes[lexeme])
            lexemeParadigmes[lexeme]=[]
            maxScoreCliques=max([clique for cliqueNumber, clique in cliquesScores[lexeme].items()])
            maxCardScoreNums=[numC for numC, c in cliquesListes[lexeme].items() if c in cliquesFideles[maxCliquesCard]]
            maxCardScore=max([scoreC for numC, scoreC in cliquesScores[lexeme].items() if numC in maxCardScoreNums])
    #        print ("max score among all cliques:",maxScoreCliques)
            print ("max score among faithfull cliques of %d forms:"%maxCliquesCard,maxCardScore)
            for c in cliquesFideles[maxCliquesCard]:
                cNumber=[cliqueNumber for cliqueNumber, clique in cliquesListes[lexeme].items() if clique == c]
                if len(cNumber)!=1:
                    print ("TOO MANY SCORES PROBLEM WITH CLIQUE", cNumber)
    #            print ("Liste n°",cNumber[0],cliquesScores[lexeme][cNumber[0]])
    #            print (sorted(cliquesScores[lexeme].items(), key=operator.itemgetter(1)))
    #            display(HTML(makeTable(dictCliqueForms(c),title=c[0].split("-")[0])))
    #            print (cliquesScores[lexeme][cNumber[0]], maxCardScore)
                if cliquesScores[lexeme][cNumber[0]]==maxCardScore:
                    lexemeParadigmes[lexeme].append(c)
        else:
            lexemeParadigmes[lexeme]=[[lexeme+"-"+f for f in fidelites]]
            print (u"no new faithfull clique, the previous one contained %d forms"%len(lexemeParadigmes[lexeme][0]))
    return lexemeParadigmes

# %%
def cutNodeName(nodeName):
    items=nodeName.split("-")
    nbItems=len(items)
    if nbItems>3:
        items=["-".join(items[0:nbItems-2]),items[-2],items[-1]]
    return items

def filledOutClique(cliques):
    if cliques:
        result=[]
        for clique in cliques:
#            print (clique)
            fullClique=[]
            for element in clique:
                if debug: print ("element",element)
                lexeme,forme,case=splitArrivee(element)
                for c in dictMorphomeCases[case]:
                    fullClique.append("-".join([lexeme,forme,c]))
            result.append(fullClique)
        return result
    else:
        return cliques

# %%
def extendParadigmes(contextParadigmes,extendMorphomes=False):
    lexemesParadigmeListe=[]
    for lexeme in contextParadigmes:
        if extendMorphomes:
            lexParadigmes=filledOutClique(contextParadigmes[lexeme])
        else:
            lexParadigmes=contextParadigmes[lexeme]
        if len(lexParadigmes)!=1:
            if debug:
                print ("LEXEME WITH A NON UNIQUE PARADIGM PB",len(lexParadigmes),lexeme)
                print (lexParadigmes)
        lexParadigme=lexParadigmes[0]
        for lexForme in lexParadigme:
            lexemesParadigmeListe.append(cutNodeName(lexForme))
    newForms=pd.DataFrame(lexemesParadigmeListe)
    newForms.columns=["lexeme","form","case"]
#    newParadigmes=newForms.pivot(index="lexeme", columns="case", values="form")
    newParadigmes=pd.pivot_table(newForms, values='form', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
    for i in newParadigmes.itertuples():
#        print (i[0],i[1])
        lexeme=i[1]
        bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
        lexemeIndexes=paradigmes.lexeme[bLexParadigme].index.tolist()
        if lexemeIndexes:
            lexemeIndex=lexemeIndexes[0]
        else:
            print (i,lexeme,lexemeIndexes)
        bLexNewParadigme=newParadigmes["lexeme"].str.contains("^"+lexeme+"$")
        newParadigmes.loc[bLexNewParadigme,"index"]=int(lexemeIndex)
    newParadigmes.set_index("index",inplace=True)   
    return paradigmes.combine_first(newParadigmes)

# %%
def countSplits(dfForms):
    dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
    return dfForms["split"].str.len().sum()

def calculerResultats(contextParadigmes,extension="-Swim2"):
    
    '''Préparer le paradigme des prédictions'''
    brutParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=False)
    finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
    finalParadigmes.to_csv(fSample.replace(".csv","")+"%s.csv"%extension,encoding="utf8",sep=";")
    finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
    finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
    finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
    print (finalTestForms.columns)
    # finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["case"]
    # finalTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
    finalTestForms.set_index(["lexeme-case"],inplace=True)
    
    '''Soustraire les formes initiales'''
    finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
    finalFormsIndex=finalForms.index.tolist()
    
    '''Calculer les sur/sous-générations'''
    underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
    overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]
    
    '''Réduire les prédictions et la référence aux cases communes'''
    predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
    actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]
    
    '''Créer un tableau pour les comparaisons'''
    compareForms=predictedForms.copy()
    compareForms.loc[:,"right"]=actualForms.loc[:,"value"]
    
    '''Séparer les cases identiques des cases différentes'''
    sameForms=compareForms[compareForms["value"]==compareForms["right"]]
    diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

    
    '''Sauvegarder les comparatifs'''
    overGeneration.to_csv(fSample.replace(".csv","")+"-overGeneration%s.csv"%extension,encoding="utf8")
    underGeneration.to_csv(fSample.replace(".csv","")+"-underGeneration%s.csv"%extension,encoding="utf8")
    sameForms.to_csv(fSample.replace(".csv","")+"-sameForms%s.csv"%extension,encoding="utf8")
    diffForms.to_csv(fSample.replace(".csv","")+"-diffForms%s.csv"%extension,encoding="utf8")
    
    
    '''Transformer les surabondances en liste'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")

    '''Transformer les surabondances en set()'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
    
    '''Calculer le nombre de formes (y compris surabondances)'''
    nbValues=diffForms["split-value"].str.len().sum()
    nbRights=diffForms["split-right"].str.len().sum()

    '''Calculer les identités et les inclusions'''
    nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
    nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
    nbWrongForms=(nbValues-nbIdenticalSets-nbIncludedSets)
    underBonus=(nbRights-nbIdenticalSets-nbIncludedSets)

    UG=countSplits(underGeneration)+underBonus
    OG=countSplits(overGeneration)
    TP=countSplits(sameForms)+nbIdenticalSets+nbIncludedSets
    FP=nbWrongForms
    resultCharacteristics=(UG,OG,TP,FP)
    recall=float(TP)/(UG+TP+FP)
    precision=float(TP)/(OG+TP+FP)
    fMeasure=2*recall*precision/(recall+precision)
    resultMeasures=(precision,recall,fMeasure)
    print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
    print ("recall", recall, "precision", precision)
    print (fMeasure)
    return (brutParadigmes,finalParadigmes,resultCharacteristics,resultMeasures)

# %% [markdown]
# # SWIM1

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim1ContextParadigmes=generateCliques()
# Out:
# 2023-11-14 11:52:42.574242
# FloatProgress(value=0.0, description=u'Generation (6368 verbs)', max=6367.0)
# 0 1052 0, 100 1055 1, 200 1058 3, 300 1101 4, 400 1104 6, 500 1107 7, 600 1110 9, 700 1113 10, 800 1115 12, 900 1118 14, 1000 1121 15, 1100 1124 17, 1200 1127 18, 1300 1130 20, 1400 1133 21, 1500 1135 23, 1600 1138 25, 1700 1140 26, 1800 1143 28, 1900 1145 29, 2000 1148 31, 2100 1150 32, 2200 1153 34, 2300 1155 36, 2400 1158 37, 2500 1200 39, 2600 1203 40, 2700 1206 42, 2800 1208 43, 2900 1211 45, 3000 1214 47, 3100 1216 48, 3200 1219 50, 3300 1221 51, 3400 1224 53, 3500 1226 54, 3600 1229 56, 3700 1231 58, 3800 1234 59, 3900 1237 61, 4000 1239 62, 4100 1242 64, 4200 1244 65, 4300 1247 67, 4400 1250 69, 4500 1253 70, 4600 1255 72, 4700 1258 73, 4800 1300 75, 4900 1303 76, 5000 1306 78, 5100 1308 80, 5200 1311 81, 5300 1314 83, 5400 1317 84, 5500 1319 86, 5600 1322 87, 5700 1324 89, 5800 1327 91, 5900 1330 92, 6000 1332 94, 6100 1335 95, 6200 1337 97, 6300 1340 98,
# FloatProgress(value=0.0, description=u'Analysis (6368 verbes)', max=6367.0)
# gauchir Nombre de cliques 41
# max score among faithfull cliques of 7 forms: 22.9876498417
# dénazifier Nombre de cliques 22
# max score among faithfull cliques of 18 forms: 149.339914958
# réinstaller Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 272.109751563
# caner Nombre de cliques 20
# max score among faithfull cliques of 23 forms: 271.80320857
# tancer Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 268.715077147
# devenir Nombre de cliques 29
# max score among faithfull cliques of 5 forms: 15.0
# orthographier Nombre de cliques 51
# max score among faithfull cliques of 19 forms: 145.866458697
# affectionner Nombre de cliques 34
# max score among faithfull cliques of 23 forms: 260.28454417
# verser Nombre de cliques 52
# max score among faithfull cliques of 22 forms: 242.46165592
# dégommer Nombre de cliques 33
# max score among faithfull cliques of 22 forms: 232.604845032
# déverser Nombre de cliques 69
# max score among faithfull cliques of 22 forms: 239.425004279
# superposer Nombre de cliques 53
# max score among faithfull cliques of 23 forms: 244.874132033
# spiritualiser Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 266.618758694
# empoissonner Nombre de cliques 40
# max score among faithfull cliques of 23 forms: 251.392179307
# persister Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 224.547946351
# déganter Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 271.246237146
# judaïser Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 273.282926828
# commenter Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 263.237447342
# douiller Nombre de cliques 23
# max score among faithfull cliques of 20 forms: 203.85642531
# concasser Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 268.036673687
# entrégorger Nombre de cliques 2
# max score among faithfull cliques of 23 forms: 271.972411973
# bossuer Nombre de cliques 20
# max score among faithfull cliques of 7 forms: 24.39875926
# fritter Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 261.009688474
# maquereauter Nombre de cliques 144
# max score among faithfull cliques of 11 forms: 38.9930389593
# boursicoter Nombre de cliques 36
# max score among faithfull cliques of 22 forms: 235.811363031
# aposter Nombre de cliques 6
# max score among faithfull cliques of 21 forms: 228.218641186
# chauffer Nombre de cliques 62
# max score among faithfull cliques of 23 forms: 250.811739548
# poiler Nombre de cliques 7
# max score among faithfull cliques of 23 forms: 272.466077112
# dépayser Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 260.472856748
# pencher Nombre de cliques 42
# max score among faithfull cliques of 23 forms: 267.430740918
# poivrer Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 225.298951884
# évider Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 286.148052159
# foisonner Nombre de cliques 39
# max score among faithfull cliques of 22 forms: 227.163402711
# préluder Nombre de cliques 2
# max score among faithfull cliques of 22 forms: 251.088293926
# moucharder Nombre de cliques 34
# max score among faithfull cliques of 23 forms: 271.583281193
# muer Nombre de cliques 44
# max score among faithfull cliques of 13 forms: 86.9286489876
# revouloir Nombre de cliques 3
# max score among faithfull cliques of 4 forms: 9.875
# enquiquiner Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 271.29631782
# effaroucher Nombre de cliques 25
# max score among faithfull cliques of 22 forms: 247.13091681
# dévaloriser Nombre de cliques 27
# max score among faithfull cliques of 24 forms: 288.208493429
# grossir Nombre de cliques 188
# max score among faithfull cliques of 17 forms: 97.2831498724
# contre-braquer Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 271.776943892
# offenser Nombre de cliques 46
# max score among faithfull cliques of 20 forms: 196.67800149
# fusionner Nombre de cliques 54
# max score among faithfull cliques of 23 forms: 244.701565477
# confisquer Nombre de cliques 41
# max score among faithfull cliques of 21 forms: 225.553883329
# reporter Nombre de cliques 45
# max score among faithfull cliques of 23 forms: 263.834953417
# susurrer Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 267.148787051
# parisianiser Nombre de cliques 1
# max score among faithfull cliques of 25 forms: 321.284895418
# désincruster Nombre de cliques 19
# max score among faithfull cliques of 21 forms: 220.941780519
# éreinter Nombre de cliques 54
# max score among faithfull cliques of 20 forms: 197.477185336
# fissurer Nombre de cliques 35
# max score among faithfull cliques of 22 forms: 241.912643172
# bambocher Nombre de cliques 40
# max score among faithfull cliques of 23 forms: 265.698969409
# biquer Nombre de cliques 15
# max score among faithfull cliques of 24 forms: 287.595350991
# rassortir Nombre de cliques 3
# max score among faithfull cliques of 12 forms: 66.0426299541
# ragoter Nombre de cliques 25
# max score among faithfull cliques of 22 forms: 236.379479487
# déboulonner Nombre de cliques 13
# max score among faithfull cliques of 22 forms: 244.330944318
# aniser Nombre de cliques 2
# max score among faithfull cliques of 24 forms: 296.733662364
# endenter Nombre de cliques 31
# max score among faithfull cliques of 23 forms: 257.696818687
# emplir Nombre de cliques 185
# max score among faithfull cliques of 10 forms: 42.6808507192
# remeubler Nombre de cliques 10
# max score among faithfull cliques of 20 forms: 209.053786571
# prêcher Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 291.493998859
# coqueter Nombre de cliques 48
# max score among faithfull cliques of 12 forms: 62.2257166129
# unir Nombre de cliques 107
# max score among faithfull cliques of 7 forms: 23.5372908036
# agencer Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 262.432866142
# jambonner Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 253.882416106
# exploser Nombre de cliques 25
# max score among faithfull cliques of 17 forms: 145.029562066
# transvider Nombre de cliques 6
# max score among faithfull cliques of 24 forms: 293.207645083
# rugir Nombre de cliques 197
# max score among faithfull cliques of 17 forms: 121.188461857
# menacer Nombre de cliques 39
# max score among faithfull cliques of 22 forms: 239.432076747
# décompiler Nombre de cliques 3
# max score among faithfull cliques of 23 forms: 273.663034124
# fustiger Nombre de cliques 40
# max score among faithfull cliques of 24 forms: 289.632028082
# bâter Nombre de cliques 60
# max score among faithfull cliques of 23 forms: 257.463896014
# ronger Nombre de cliques 53
# max score among faithfull cliques of 23 forms: 264.853194991
# ébouriffer Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 288.000621571
# convoler Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 241.163512517
# sortir Nombre de cliques 83
# max score among faithfull cliques of 4 forms: 5.33555805057
# mémoriser Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 283.870400303
# précipiter Nombre de cliques 38
# max score among faithfull cliques of 24 forms: 283.371350535
# orner Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 268.061873026
# cajoler Nombre de cliques 26
# max score among faithfull cliques of 22 forms: 241.477666665
# déclencher Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 269.974158808
# dérider Nombre de cliques 31
# max score among faithfull cliques of 25 forms: 309.582413832
# prôner Nombre de cliques 97
# max score among faithfull cliques of 12 forms: 48.7666317973
# embuer Nombre de cliques 35
# max score among faithfull cliques of 13 forms: 87.7150867945
# ratisser Nombre de cliques 135
# max score among faithfull cliques of 13 forms: 61.4755598726
# nitrater Nombre de cliques 57
# max score among faithfull cliques of 23 forms: 252.195768145
# sous-exploiter Nombre de cliques 40
# max score among faithfull cliques of 23 forms: 267.923614832
# bigarrer Nombre de cliques 2
# max score among faithfull cliques of 24 forms: 294.470119549
# swinguer Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 272.633618054
# canarder Nombre de cliques 37
# max score among faithfull cliques of 23 forms: 270.17511418
# avarier Nombre de cliques 89
# max score among faithfull cliques of 15 forms: 91.9200089512
# prostituer Nombre de cliques 27
# max score among faithfull cliques of 18 forms: 161.042082863
# biaiser Nombre de cliques 90
# max score among faithfull cliques of 21 forms: 196.443134703
# destiner Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 268.962601344
# mépriser Nombre de cliques 35
# max score among faithfull cliques of 21 forms: 218.063704524
# appendre Nombre de cliques 19
# max score among faithfull cliques of 8 forms: 29.2011853157
# préformater Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 270.248667242
# ardre Nombre de cliques 0
# no new faithfull clique, the previous one contained 1 forms
# vibrer Nombre de cliques 34
# max score among faithfull cliques of 11 forms: 64.8770551067
# attitrer Nombre de cliques 15
# max score among faithfull cliques of 20 forms: 199.239095758
# consacrer Nombre de cliques 56
# max score among faithfull cliques of 15 forms: 112.360037082
# combler Nombre de cliques 27
# max score among faithfull cliques of 20 forms: 207.591738369
# émasculer Nombre de cliques 10
# max score among faithfull cliques of 22 forms: 251.582585406
# naufrager Nombre de cliques 31
# max score among faithfull cliques of 23 forms: 268.604592957
# typer Nombre de cliques 8
# max score among faithfull cliques of 24 forms: 294.265962775
# sentir Nombre de cliques 67
# max score among faithfull cliques of 9 forms: 24.4954607901
# expectorer Nombre de cliques 25
# max score among faithfull cliques of 23 forms: 260.34270912
# accéder Nombre de cliques 108
# max score among faithfull cliques of 23 forms: 239.465498318
# tarauder Nombre de cliques 133
# max score among faithfull cliques of 11 forms: 42.7390164309
# entrapercevoir Nombre de cliques 74
# max score among faithfull cliques of 5 forms: 13.5955555556
# défiler Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 272.36907566
# pigmenter Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 265.484839317
# substituer Nombre de cliques 25
# max score among faithfull cliques of 19 forms: 181.708368108
# efféminer Nombre de cliques 7
# max score among faithfull cliques of 23 forms: 274.625518242
# boire Nombre de cliques 46
# max score among faithfull cliques of 5 forms: 12.8690740741
# sous-tendre Nombre de cliques 54
# max score among faithfull cliques of 4 forms: 7.92527867597
# profaner Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 266.964226469
# repriser Nombre de cliques 38
# max score among faithfull cliques of 24 forms: 285.610358507
# maturer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 271.944029345
# bâcher Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 270.589508433
# plafonner Nombre de cliques 47
# max score among faithfull cliques of 23 forms: 243.676655824
# collectionner Nombre de cliques 40
# max score among faithfull cliques of 23 forms: 254.041064096
# bosseler Nombre de cliques 29
# max score among faithfull cliques of 18 forms: 142.955408951
# incendier Nombre de cliques 81
# max score among faithfull cliques of 17 forms: 103.396981756
# réfracter Nombre de cliques 11
# max score among faithfull cliques of 22 forms: 250.366274271
# surgir Nombre de cliques 207
# max score among faithfull cliques of 14 forms: 80.7445143575
# vadrouiller Nombre de cliques 27
# max score among faithfull cliques of 20 forms: 201.371362658
# éloigner Nombre de cliques 83
# max score among faithfull cliques of 16 forms: 132.51613841
# braiser Nombre de cliques 51
# max score among faithfull cliques of 24 forms: 259.8197185
# froufrouter Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 244.78736986
# violacer Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 271.930565727
# ensacher Nombre de cliques 55
# max score among faithfull cliques of 23 forms: 265.375162273
# rapprendre Nombre de cliques 5
# max score among faithfull cliques of 6 forms: 20.68
# vouloir Nombre de cliques 28
# max score among faithfull cliques of 8 forms: 32.5977033514
# aliter Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 273.977475338
# boucaner Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 273.470293387
# piocher Nombre de cliques 55
# max score among faithfull cliques of 23 forms: 261.717078002
# couturer Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 271.989111312
# acheminer Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 273.121490618
# stabiliser Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 264.421040594
# opacifier Nombre de cliques 32
# max score among faithfull cliques of 18 forms: 146.054199255
# blinder Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 272.331992916
# parasiter Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 281.954042036
# désendetter Nombre de cliques 23
# max score among faithfull cliques of 24 forms: 259.061322641
# autodéterminer Nombre de cliques 3
# max score among faithfull cliques of 23 forms: 273.815801643
# retuber Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 270.997897166
# gercer Nombre de cliques 41
# max score among faithfull cliques of 23 forms: 264.650280102
# inaugurer Nombre de cliques 31
# max score among faithfull cliques of 22 forms: 245.789442635
# blablater Nombre de cliques 28
# max score among faithfull cliques of 22 forms: 249.047968534
# rembobiner Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 270.112812385
# ratiociner Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 273.492786946
# roquer Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 245.048043007
# biser Nombre de cliques 33
# max score among faithfull cliques of 24 forms: 285.275452861
# valoir Nombre de cliques 49
# max score among faithfull cliques of 7 forms: 24.9752747253
# assurer Nombre de cliques 27
# max score among faithfull cliques of 23 forms: 263.409978492
# emprisonner Nombre de cliques 49
# max score among faithfull cliques of 23 forms: 253.815689813
# réattribuer Nombre de cliques 30
# max score among faithfull cliques of 16 forms: 125.431108223
# materner Nombre de cliques 47
# max score among faithfull cliques of 23 forms: 266.606836765
# décarboniser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 296.483662364
# réciproquer Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 266.965092337
# glycériner Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 273.429150583
# carotter Nombre de cliques 61
# max score among faithfull cliques of 23 forms: 251.504375759
# maximaliser Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 270.238275708
# redéfinir Nombre de cliques 157
# max score among faithfull cliques of 13 forms: 67.6455792618
# apitoyer Nombre de cliques 71
# max score among faithfull cliques of 16 forms: 115.632618643
# gambiller Nombre de cliques 18
# max score among faithfull cliques of 20 forms: 194.05190362
# rejouer Nombre de cliques 40
# max score among faithfull cliques of 13 forms: 86.4456232734
# embrouiller Nombre de cliques 39
# max score among faithfull cliques of 20 forms: 190.364721202
# lister Nombre de cliques 39
# max score among faithfull cliques of 21 forms: 223.050483854
# détracter Nombre de cliques 9
# max score among faithfull cliques of 22 forms: 250.649953225
# octroyer Nombre de cliques 64
# max score among faithfull cliques of 14 forms: 81.0887847512
# entrevoir Nombre de cliques 109
# max score among faithfull cliques of 10 forms: 50.529994135
# regreffer Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 259.51299155
# préremplir Nombre de cliques 3
# max score among faithfull cliques of 7 forms: 26.3455136471
# bitter Nombre de cliques 8
# max score among faithfull cliques of 24 forms: 293.743436222
# motoriser Nombre de cliques 7
# max score among faithfull cliques of 24 forms: 294.2685397
# rectifier Nombre de cliques 73
# max score among faithfull cliques of 20 forms: 137.126493705
# dissimiler Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 272.911202622
# exulter Nombre de cliques 25
# max score among faithfull cliques of 18 forms: 169.361423438
# baliser Nombre de cliques 26
# max score among faithfull cliques of 22 forms: 245.729246367
# tirer Nombre de cliques 22
# max score among faithfull cliques of 19 forms: 185.805594452
# prouter Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 270.809748769
# ardoiser Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 271.069409474
# cacarder Nombre de cliques 14
# max score among faithfull cliques of 23 forms: 271.396320717
# mitrer Nombre de cliques 10
# max score among faithfull cliques of 19 forms: 188.056239787
# palanquer Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 274.467678204
# chamarrer Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 272.867071698
# arrimer Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 270.027061296
# absorber Nombre de cliques 79
# max score among faithfull cliques of 23 forms: 257.333769402
# overclocker Nombre de cliques 10
# max score among faithfull cliques of 22 forms: 250.23210622
# désensorceler Nombre de cliques 52
# max score among faithfull cliques of 10 forms: 44.5726085334
# décentrer Nombre de cliques 26
# max score among faithfull cliques of 19 forms: 184.4505118
# coulisser Nombre de cliques 104
# max score among faithfull cliques of 12 forms: 56.3249567601
# nuer Nombre de cliques 39
# max score among faithfull cliques of 12 forms: 75.3215725755
# enjamber Nombre de cliques 36
# max score among faithfull cliques of 23 forms: 264.329646149
# fauter Nombre de cliques 113
# max score among faithfull cliques of 11 forms: 38.0802199311
# briffer Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 292.735225777
# bafouer Nombre de cliques 43
# max score among faithfull cliques of 8 forms: 33.3602632239
# discréditer Nombre de cliques 33
# max score among faithfull cliques of 24 forms: 284.169360366
# singer Nombre de cliques 48
# max score among faithfull cliques of 23 forms: 267.550040498
# provisionner Nombre de cliques 31
# max score among faithfull cliques of 22 forms: 235.871975376
# purger Nombre de cliques 45
# max score among faithfull cliques of 23 forms: 266.422288598
# calquer Nombre de cliques 20
# max score among faithfull cliques of 18 forms: 170.236715389
# dessiner Nombre de cliques 22
# max score among faithfull cliques of 23 forms: 271.41932673
# relever Nombre de cliques 175
# max score among faithfull cliques of 9 forms: 36.1077114383
# tapoter Nombre de cliques 70
# max score among faithfull cliques of 23 forms: 247.965898126
# réparer Nombre de cliques 37
# max score among faithfull cliques of 21 forms: 219.870629251
# froncer Nombre de cliques 39
# max score among faithfull cliques of 23 forms: 266.057953429
# essorer Nombre de cliques 58
# max score among faithfull cliques of 22 forms: 233.940194319
# ruisseler Nombre de cliques 73
# max score among faithfull cliques of 10 forms: 44.0949497098
# écouler Nombre de cliques 15
# max score among faithfull cliques of 22 forms: 249.230079873
# dégoûter Nombre de cliques 38
# max score among faithfull cliques of 23 forms: 265.411507758
# replâtrer Nombre de cliques 14
# max score among faithfull cliques of 20 forms: 201.09152139
# décrypter Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 224.749685642
# caper Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 271.178674926
# toucher Nombre de cliques 22
# max score among faithfull cliques of 18 forms: 165.548772765
# écarquiller Nombre de cliques 51
# max score among faithfull cliques of 20 forms: 186.544553968
# poireauter Nombre de cliques 60
# max score among faithfull cliques of 22 forms: 223.710752949
# tournailler Nombre de cliques 6
# max score among faithfull cliques of 20 forms: 204.072843008
# ravaler Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 271.278226266
# annihiler Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 271.808568469
# environner Nombre de cliques 35
# max score among faithfull cliques of 23 forms: 258.411019763
# repolariser Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 289.957306728
# essaimer Nombre de cliques 30
# max score among faithfull cliques of 22 forms: 246.918259255
# effriter Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 291.342726199
# étoffer Nombre de cliques 46
# max score among faithfull cliques of 22 forms: 229.87146984
# rameuter Nombre de cliques 127
# max score among faithfull cliques of 13 forms: 86.5466395691
# reposer Nombre de cliques 41
# max score among faithfull cliques of 23 forms: 241.31804023
# badigeonner Nombre de cliques 52
# max score among faithfull cliques of 22 forms: 229.842315344
# fleurir Nombre de cliques 185
# max score among faithfull cliques of 14 forms: 74.2047711074
# faisander Nombre de cliques 51
# max score among faithfull cliques of 23 forms: 253.032520576
# ensuquer Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 272.318102983
# drayer Nombre de cliques 46
# max score among faithfull cliques of 18 forms: 126.729506019
# mâchurer Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 271.855796182
# outiller Nombre de cliques 25
# max score among faithfull cliques of 20 forms: 188.558281501
# lapider Nombre de cliques 26
# max score among faithfull cliques of 24 forms: 285.215399074
# embouter Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 270.391777921
# haïr Nombre de cliques 19
# max score among faithfull cliques of 6 forms: 20.6428571429
# clarifier Nombre de cliques 85
# max score among faithfull cliques of 21 forms: 139.143888956
# désigner Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 224.687187953
# dépêtrer Nombre de cliques 33
# max score among faithfull cliques of 20 forms: 200.949358615
# reprogrammer Nombre de cliques 30
# max score among faithfull cliques of 23 forms: 269.197212167
# débiner Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 269.680385889
# pressurer Nombre de cliques 29
# max score among faithfull cliques of 23 forms: 267.864149216
# entreposer Nombre de cliques 63
# max score among faithfull cliques of 23 forms: 239.594558187
# embrever Nombre de cliques 25
# max score among faithfull cliques of 16 forms: 133.430404992
# débouder Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 270.422909397
# moissonner Nombre de cliques 48
# max score among faithfull cliques of 22 forms: 229.897876302
# souvenir Nombre de cliques 22
# max score among faithfull cliques of 5 forms: 15.0
# euphoriser Nombre de cliques 13
# max score among faithfull cliques of 24 forms: 285.310708483
# cafter Nombre de cliques 25
# max score among faithfull cliques of 21 forms: 226.825535142
# nébuliser Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 268.02802363
# étourdir Nombre de cliques 243
# max score among faithfull cliques of 16 forms: 92.5316614799
# adapter Nombre de cliques 31
# max score among faithfull cliques of 21 forms: 226.853335758
# remouler Nombre de cliques 10
# max score among faithfull cliques of 22 forms: 251.576254656
# incinérer Nombre de cliques 23
# max score among faithfull cliques of 24 forms: 286.320676337
# fouiner Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 270.603852153
# percuter Nombre de cliques 36
# max score among faithfull cliques of 23 forms: 262.655508664
# écourter Nombre de cliques 37
# max score among faithfull cliques of 23 forms: 262.811211138
# révulser Nombre de cliques 19
# max score among faithfull cliques of 18 forms: 170.107718815
# patenter Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 265.903594061
# demander Nombre de cliques 31
# max score among faithfull cliques of 13 forms: 88.8996362274
# surproduire Nombre de cliques 144
# max score among faithfull cliques of 8 forms: 28.5051289611
# avaliser Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 248.529380879
# pactiser Nombre de cliques 48
# max score among faithfull cliques of 24 forms: 272.015649569
# menuiser Nombre de cliques 34
# max score among faithfull cliques of 19 forms: 180.018069367
# mortifier Nombre de cliques 62
# max score among faithfull cliques of 20 forms: 163.092232847
# perler Nombre de cliques 14
# max score among faithfull cliques of 23 forms: 271.605740897
# exaspérer Nombre de cliques 29
# max score among faithfull cliques of 24 forms: 281.97140203
# ganter Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 271.251704475
# potasser Nombre de cliques 43
# max score among faithfull cliques of 23 forms: 248.455532576
# récliner Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 274.756149914
# traficoter Nombre de cliques 58
# max score among faithfull cliques of 22 forms: 229.875145466
# parler Nombre de cliques 7
# max score among faithfull cliques of 7 forms: 27.9875
# défouler Nombre de cliques 18
# max score among faithfull cliques of 22 forms: 247.409487546
# penser Nombre de cliques 27
# max score among faithfull cliques of 13 forms: 88.9384695281
# tutoyer Nombre de cliques 71
# max score among faithfull cliques of 16 forms: 115.571702688
# suivre Nombre de cliques 58
# max score among faithfull cliques of 5 forms: 8.77757815525
# haranguer Nombre de cliques 53
# max score among faithfull cliques of 23 forms: 268.097629323
# contreficher Nombre de cliques 36
# max score among faithfull cliques of 24 forms: 290.632921315
# batifoler Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 241.451486191
# claboter Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 259.228166654
# criminaliser Nombre de cliques 16
# max score among faithfull cliques of 22 forms: 249.501098541
# panoramiquer Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 297.663030457
# empêcher Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 289.653980162
# tortorer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 267.490284659
# récriminer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 274.223219392
# déverdir Nombre de cliques 41
# max score among faithfull cliques of 15 forms: 61.8300940732
# aboyer Nombre de cliques 62
# max score among faithfull cliques of 16 forms: 111.561671049
# vendanger Nombre de cliques 29
# max score among faithfull cliques of 23 forms: 269.741106476
# truster Nombre de cliques 13
# max score among faithfull cliques of 21 forms: 228.317181444
# rebrûler Nombre de cliques 4
# max score among faithfull cliques of 22 forms: 251.744535955
# élargir Nombre de cliques 128
# max score among faithfull cliques of 9 forms: 37.8204939664
# recadrer Nombre de cliques 23
# max score among faithfull cliques of 20 forms: 203.284732997
# toaster Nombre de cliques 17
# max score among faithfull cliques of 21 forms: 228.082611652
# voiturer Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 271.50530394
# rouir Nombre de cliques 4
# max score among faithfull cliques of 5 forms: 14.4049305449
# étatiser Nombre de cliques 5
# max score among faithfull cliques of 25 forms: 318.24014727
# intituler Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 249.821054013
# peindre Nombre de cliques 104
# max score among faithfull cliques of 7 forms: 25.2519351491
# ragaillardir Nombre de cliques 133
# max score among faithfull cliques of 13 forms: 75.8206617603
# voyager Nombre de cliques 33
# max score among faithfull cliques of 23 forms: 268.752250873
# palpiter Nombre de cliques 28
# max score among faithfull cliques of 24 forms: 279.977000646
# encrer Nombre de cliques 20
# max score among faithfull cliques of 21 forms: 224.554097646
# cloquer Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 272.094221355
# bistrer Nombre de cliques 13
# max score among faithfull cliques of 19 forms: 187.826194691
# bedonner Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 254.857973342
# négocier Nombre de cliques 92
# max score among faithfull cliques of 15 forms: 75.2151538415
# dépasser Nombre de cliques 52
# max score among faithfull cliques of 23 forms: 254.169976779
# dérégler Nombre de cliques 14
# max score among faithfull cliques of 21 forms: 229.878485692
# rescinder Nombre de cliques 33
# max score among faithfull cliques of 20 forms: 194.089803765
# chancir Nombre de cliques 5
# max score among faithfull cliques of 15 forms: 97.6970634128
# apurer Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 271.773377949
# tiédir Nombre de cliques 105
# max score among faithfull cliques of 15 forms: 86.732808041
# contremander Nombre de cliques 15
# max score among faithfull cliques of 22 forms: 248.434881219
# solidariser Nombre de cliques 20
# max score among faithfull cliques of 25 forms: 312.832919722
# mordorer Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 267.411250631
# renouveler Nombre de cliques 65
# max score among faithfull cliques of 10 forms: 42.3745220956
# déconner Nombre de cliques 52
# max score among faithfull cliques of 23 forms: 257.976237567
# fréquenter Nombre de cliques 30
# max score among faithfull cliques of 23 forms: 266.325519603
# rabouter Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 270.255769679
# dialoguer Nombre de cliques 37
# max score among faithfull cliques of 22 forms: 246.877888269
# embaumer Nombre de cliques 35
# max score among faithfull cliques of 23 forms: 260.777438936
# râler Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 273.145656195
# exorciser Nombre de cliques 56
# max score among faithfull cliques of 24 forms: 266.375866402
# suriner Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 270.798049768
# contribuer Nombre de cliques 39
# max score among faithfull cliques of 13 forms: 85.3977549775
# rustiquer Nombre de cliques 4
# max score among faithfull cliques of 24 forms: 296.194401235
# coproduire Nombre de cliques 203
# max score among faithfull cliques of 6 forms: 16.1499238852
# présumer Nombre de cliques 29
# max score among faithfull cliques of 23 forms: 269.300916794
# recoloniser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 296.733662364
# revisser Nombre de cliques 157
# max score among faithfull cliques of 14 forms: 74.8640790086
# détacher Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 290.461605043
# trôner Nombre de cliques 76
# max score among faithfull cliques of 10 forms: 30.5241737532
# défléchir Nombre de cliques 57
# max score among faithfull cliques of 12 forms: 59.4444518761
# pister Nombre de cliques 27
# max score among faithfull cliques of 21 forms: 224.693660069
# ballaster Nombre de cliques 7
# max score among faithfull cliques of 21 forms: 228.63220202
# parlementer Nombre de cliques 25
# max score among faithfull cliques of 23 forms: 262.931706755
# trépider Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 282.52858358
# rebondir Nombre de cliques 193
# max score among faithfull cliques of 17 forms: 103.994690188
# poser Nombre de cliques 43
# max score among faithfull cliques of 19 forms: 177.01958914
# dîner Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 272.19200306
# styliser Nombre de cliques 9
# max score among faithfull cliques of 22 forms: 246.820764044
# fournir Nombre de cliques 110
# max score among faithfull cliques of 6 forms: 20.4669312169
# préfigurer Nombre de cliques 26
# max score among faithfull cliques of 22 forms: 242.711762443
# briser Nombre de cliques 30
# max score among faithfull cliques of 24 forms: 285.987178149
# chevaucher Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 265.612069338
# loucher Nombre de cliques 33
# max score among faithfull cliques of 23 forms: 271.795168958
# filouter Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 273.759844184
# tictaquer Nombre de cliques 7
# max score among faithfull cliques of 23 forms: 271.801679284
# fourrer Nombre de cliques 42
# max score among faithfull cliques of 22 forms: 243.844135183
# proroger Nombre de cliques 43
# max score among faithfull cliques of 23 forms: 262.2984668
# soutirer Nombre de cliques 38
# max score among faithfull cliques of 24 forms: 289.59449208
# détester Nombre de cliques 20
# max score among faithfull cliques of 11 forms: 64.7919099471
# tordre Nombre de cliques 100
# max score among faithfull cliques of 12 forms: 38.6979131151
# léguer Nombre de cliques 22
# max score among faithfull cliques of 23 forms: 271.428344394
# rescolariser Nombre de cliques 3
# max score among faithfull cliques of 24 forms: 294.380792204
# descendre Nombre de cliques 76
# max score among faithfull cliques of 12 forms: 45.789791136
# coller Nombre de cliques 18
# max score among faithfull cliques of 22 forms: 238.859511387
# retravailler Nombre de cliques 57
# max score among faithfull cliques of 20 forms: 168.921739374
# délivrer Nombre de cliques 50
# max score among faithfull cliques of 20 forms: 202.330840203
# patauger Nombre de cliques 66
# max score among faithfull cliques of 23 forms: 256.326339448
# moraliser Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 272.559241679
# morfler Nombre de cliques 25
# max score among faithfull cliques of 20 forms: 205.950378618
# rapprovisionner Nombre de cliques 18
# max score among faithfull cliques of 22 forms: 244.313397172
# encocher Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 268.517231778
# automatiser Nombre de cliques 16
# max score among faithfull cliques of 24 forms: 292.486497982
# disqualifier Nombre de cliques 66
# max score among faithfull cliques of 18 forms: 114.198136139
# iodler Nombre de cliques 6
# max score among faithfull cliques of 20 forms: 209.066286571
# démunir Nombre de cliques 90
# max score among faithfull cliques of 15 forms: 78.4457253813
# béatifier Nombre de cliques 43
# max score among faithfull cliques of 18 forms: 127.708114072
# pilonner Nombre de cliques 15
# max score among faithfull cliques of 22 forms: 243.5612906
# mutiler Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 269.894067526
# reconduire Nombre de cliques 182
# max score among faithfull cliques of 14 forms: 73.1533149515
# ensiler Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 274.125488336
# récuser Nombre de cliques 39
# max score among faithfull cliques of 22 forms: 241.437122214
# câbler Nombre de cliques 29
# max score among faithfull cliques of 20 forms: 207.094013286
# spolier Nombre de cliques 68
# max score among faithfull cliques of 14 forms: 77.4809736487
# roupiller Nombre de cliques 40
# max score among faithfull cliques of 20 forms: 193.530788036
# affûter Nombre de cliques 35
# max score among faithfull cliques of 22 forms: 238.871945564
# japoniser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 296.483662364
# éparpiller Nombre de cliques 65
# max score among faithfull cliques of 20 forms: 177.450830904
# modéliser Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 263.13768796
# improuver Nombre de cliques 14
# max score among faithfull cliques of 23 forms: 270.671972762
# smasher Nombre de cliques 11
# max score among faithfull cliques of 21 forms: 227.42449074
# escarmoucher Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 272.745713858
# décroûter Nombre de cliques 4
# max score among faithfull cliques of 22 forms: 241.064869729
# conjuguer Nombre de cliques 21
# max score among faithfull cliques of 22 forms: 245.615781287
# angéliser Nombre de cliques 122
# max score among faithfull cliques of 17 forms: 147.755013296
# creuser Nombre de cliques 155
# max score among faithfull cliques of 5 forms: 13.925
# centrifuger Nombre de cliques 31
# max score among faithfull cliques of 23 forms: 270.13260386
# démasquer Nombre de cliques 36
# max score among faithfull cliques of 21 forms: 227.049011041
# rasseoir Nombre de cliques 144
# max score among faithfull cliques of 11 forms: 57.1039522309
# quintupler Nombre de cliques 17
# max score among faithfull cliques of 20 forms: 207.809490723
# tarder Nombre de cliques 34
# max score among faithfull cliques of 23 forms: 268.666800279
# dealer Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 271.193643119
# réensemencer Nombre de cliques 3
# max score among faithfull cliques of 23 forms: 272.715180746
# suinter Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 263.149778042
# coéditer Nombre de cliques 6
# max score among faithfull cliques of 24 forms: 294.170966913
# protester Nombre de cliques 43
# max score among faithfull cliques of 21 forms: 222.773011432
# aiguer Nombre de cliques 18
# max score among faithfull cliques of 17 forms: 152.162758667
# baiser Nombre de cliques 78
# max score among faithfull cliques of 22 forms: 224.078662036
# déphaser Nombre de cliques 6
# max score among faithfull cliques of 24 forms: 292.88703442
# épaissir Nombre de cliques 208
# max score among faithfull cliques of 17 forms: 99.25553842
# siéger Nombre de cliques 53
# max score among faithfull cliques of 23 forms: 265.698093445
# différer Nombre de cliques 68
# max score among faithfull cliques of 25 forms: 304.836161981
# transporter Nombre de cliques 48
# max score among faithfull cliques of 21 forms: 219.570198722
# mirer Nombre de cliques 32
# max score among faithfull cliques of 24 forms: 290.412943328
# paralléliser Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 269.568044207
# remparer Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 270.945404236
# gourer Nombre de cliques 27
# max score among faithfull cliques of 22 forms: 240.082856717
# psalmodier Nombre de cliques 76
# max score among faithfull cliques of 17 forms: 111.093795011
# malmener Nombre de cliques 78
# max score among faithfull cliques of 9 forms: 33.1782023228
# sniffer Nombre de cliques 27
# max score among faithfull cliques of 24 forms: 290.97130467
# frire Nombre de cliques 79
# max score among faithfull cliques of 12 forms: 46.6016360923
# cravater Nombre de cliques 49
# max score among faithfull cliques of 23 forms: 256.191579004
# doter Nombre de cliques 53
# max score among faithfull cliques of 23 forms: 247.538340732
# retéléphoner Nombre de cliques 31
# max score among faithfull cliques of 23 forms: 248.624576205
# transcoder Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 266.252406547
# polluer Nombre de cliques 37
# max score among faithfull cliques of 9 forms: 39.5936065267
# baller Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 273.914978211
# perquisitionner Nombre de cliques 41
# max score among faithfull cliques of 22 forms: 228.877852124
# décoder Nombre de cliques 62
# max score among faithfull cliques of 23 forms: 249.906680748
# calomnier Nombre de cliques 80
# max score among faithfull cliques of 10 forms: 39.6486440096
# truquer Nombre de cliques 42
# max score among faithfull cliques of 23 forms: 267.565451572
# caviarder Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 273.23792828
# jardiner Nombre de cliques 25
# max score among faithfull cliques of 23 forms: 269.284222742
# fatiguer Nombre de cliques 36
# max score among faithfull cliques of 24 forms: 288.345469232
# chalouper Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 274.081457803
# élucubrer Nombre de cliques 11
# max score among faithfull cliques of 20 forms: 208.088698902
# avoyer Nombre de cliques 46
# max score among faithfull cliques of 14 forms: 85.5806934578
# bluffer Nombre de cliques 158
# max score among faithfull cliques of 6 forms: 18.7114457945
# emmerder Nombre de cliques 83
# max score among faithfull cliques of 23 forms: 256.622667578
# enluminer Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 274.257463099
# échauffer Nombre de cliques 61
# max score among faithfull cliques of 23 forms: 254.045640438
# zozoter Nombre de cliques 80
# max score among faithfull cliques of 23 forms: 244.494401259
# distraire Nombre de cliques 143
# max score among faithfull cliques of 11 forms: 51.9808719214
# rasséréner Nombre de cliques 45
# max score among faithfull cliques of 21 forms: 204.232591998
# thermoformer Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 272.765494005
# chapeauter Nombre de cliques 57
# max score among faithfull cliques of 22 forms: 226.549433475
# fricoter Nombre de cliques 46
# max score among faithfull cliques of 23 forms: 251.222167953
# surpayer Nombre de cliques 79
# max score among faithfull cliques of 20 forms: 170.114968043
# prévoir Nombre de cliques 53
# max score among faithfull cliques of 7 forms: 28.0
# soupçonner Nombre de cliques 52
# max score among faithfull cliques of 23 forms: 250.40118495
# idiotiser Nombre de cliques 25
# max score among faithfull cliques of 24 forms: 246.86570897
# besogner Nombre de cliques 33
# max score among faithfull cliques of 20 forms: 202.49183148
# phosphater Nombre de cliques 55
# max score among faithfull cliques of 23 forms: 254.352892193
# pulvériser Nombre de cliques 35
# max score among faithfull cliques of 24 forms: 283.774227879
# nieller Nombre de cliques 8
# max score among faithfull cliques of 22 forms: 251.340971108
# axer Nombre de cliques 16
# max score among faithfull cliques of 22 forms: 248.581114769
# rocher Nombre de cliques 27
# max score among faithfull cliques of 22 forms: 241.598091309
# tabuler Nombre de cliques 5
# max score among faithfull cliques of 22 forms: 251.234462695
# syndiquer Nombre de cliques 19
# max score among faithfull cliques of 24 forms: 291.421433028
# calandrer Nombre de cliques 16
# max score among faithfull cliques of 21 forms: 218.453377239
# volter Nombre de cliques 25
# max score among faithfull cliques of 18 forms: 167.605143631
# ahurir Nombre de cliques 49
# max score among faithfull cliques of 7 forms: 24.7416613767
# décolleter Nombre de cliques 118
# max score among faithfull cliques of 16 forms: 134.903808639
# moirer Nombre de cliques 15
# max score among faithfull cliques of 23 forms: 264.334836833
# affoler Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 236.832794474
# renoncer Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 271.143281394
# flûter Nombre de cliques 14
# max score among faithfull cliques of 23 forms: 273.774627803
# imiter Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 290.846990212
# fayoter Nombre de cliques 56
# max score among faithfull cliques of 23 forms: 245.85032072
# fomenter Nombre de cliques 42
# max score among faithfull cliques of 23 forms: 264.259304791
# dérougir Nombre de cliques 112
# max score among faithfull cliques of 17 forms: 112.142251582
# désaffectionner Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 249.13928823
# poursuivre Nombre de cliques 57
# max score among faithfull cliques of 6 forms: 14.8241628826
# vitrifier Nombre de cliques 44
# max score among faithfull cliques of 20 forms: 161.522813533
# impacter Nombre de cliques 18
# max score among faithfull cliques of 22 forms: 248.469762625
# jongler Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 228.679673055
# serpenter Nombre de cliques 32
# max score among faithfull cliques of 22 forms: 237.633583824
# réconcilier Nombre de cliques 67
# max score among faithfull cliques of 12 forms: 49.7168886348
# tiser Nombre de cliques 25
# max score among faithfull cliques of 24 forms: 288.115936961
# gifler Nombre de cliques 42
# max score among faithfull cliques of 20 forms: 204.184808869
# inverser Nombre de cliques 83
# max score among faithfull cliques of 23 forms: 258.706295732
# empreindre Nombre de cliques 83
# max score among faithfull cliques of 5 forms: 13.8298
# interloquer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 272.864223857
# endetter Nombre de cliques 58
# max score among faithfull cliques of 24 forms: 261.545922784
# prodiguer Nombre de cliques 39
# max score among faithfull cliques of 24 forms: 291.004436599
# opposer Nombre de cliques 26
# max score among faithfull cliques of 23 forms: 253.81700155
# défoncer Nombre de cliques 39
# max score among faithfull cliques of 23 forms: 262.927561656
# limoger Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 264.813216877
# feutrer Nombre de cliques 25
# max score among faithfull cliques of 19 forms: 185.222610677
# consoler Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 239.324285957
# scratcher Nombre de cliques 16
# max score among faithfull cliques of 21 forms: 227.197856245
# flaquer Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 273.8037223
# soutenir Nombre de cliques 18
# max score among faithfull cliques of 5 forms: 15.0
# ambrer Nombre de cliques 18
# max score among faithfull cliques of 21 forms: 227.658256826
# réalimenter Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 268.35300586
# sanctifier Nombre de cliques 69
# max score among faithfull cliques of 20 forms: 125.99627054
# inciter Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 281.527203853
# déchiqueter Nombre de cliques 13
# max score among faithfull cliques of 22 forms: 250.198677237
# grognonner Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 271.599730893
# nettoyer Nombre de cliques 72
# max score among faithfull cliques of 12 forms: 68.6329566273
# repartager Nombre de cliques 4
# max score among faithfull cliques of 24 forms: 295.478880057
# maugréer Nombre de cliques 34
# max score among faithfull cliques of 7 forms: 21.1519563492
# épousseter Nombre de cliques 207
# max score among faithfull cliques of 12 forms: 61.5279338789
# encarter Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 273.299322566
# coordonner Nombre de cliques 115
# max score among faithfull cliques of 9 forms: 25.2165305924
# fleurdeliser Nombre de cliques 89
# max score among faithfull cliques of 17 forms: 150.602985112
# loufer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 273.906937391
# admirer Nombre de cliques 13
# max score among faithfull cliques of 11 forms: 65.5830144833
# déviriliser Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 263.615012288
# décloisonner Nombre de cliques 4
# max score among faithfull cliques of 23 forms: 264.937559633
# déduire Nombre de cliques 189
# max score among faithfull cliques of 12 forms: 49.2756620803
# reconfigurer Nombre de cliques 36
# max score among faithfull cliques of 22 forms: 240.34178155
# décanter Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 264.168878094
# explorer Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 267.626267872
# octupler Nombre de cliques 10
# max score among faithfull cliques of 20 forms: 207.809490723
# ristourner Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 273.245547826
# convaincre Nombre de cliques 63
# max score among faithfull cliques of 7 forms: 19.869992469
# adonner Nombre de cliques 52
# max score among faithfull cliques of 23 forms: 253.642281746
# distendre Nombre de cliques 63
# max score among faithfull cliques of 8 forms: 21.4789558561
# jurer Nombre de cliques 26
# max score among faithfull cliques of 23 forms: 267.708297109
# ralentir Nombre de cliques 111
# max score among faithfull cliques of 14 forms: 75.7106542216
# maquiller Nombre de cliques 65
# max score among faithfull cliques of 20 forms: 179.71681892
# ...
# disputailler Nombre de cliques 14
# max score among faithfull cliques of 20 forms: 196.151888615
# dégrader Nombre de cliques 68
# max score among faithfull cliques of 23 forms: 263.773300731
# foudroyer Nombre de cliques 63
# max score among faithfull cliques of 16 forms: 110.808541011
# dévirginiser Nombre de cliques 2
# max score among faithfull cliques of 24 forms: 296.528744331
# asphyxier Nombre de cliques 102
# max score among faithfull cliques of 9 forms: 31.5259455492
# africaniser Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 321.284895418
# englober Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 263.300789349
# escarper Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 273.319494199
# câliner Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 272.788198966
# permanenter Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 271.523874053
# enclore Nombre de cliques 8
# max score among faithfull cliques of 3 forms: 6.0
# oraliser Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 267.838275708
# infléchir Nombre de cliques 88
# max score among faithfull cliques of 12 forms: 58.6146710163
# assécher Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 288.87648121
# propager Nombre de cliques 51
# max score among faithfull cliques of 23 forms: 265.057540446
# veiller Nombre de cliques 47
# max score among faithfull cliques of 21 forms: 203.518188158
# caracoler Nombre de cliques 19
# max score among faithfull cliques of 22 forms: 244.276508071
# parachever Nombre de cliques 106
# max score among faithfull cliques of 10 forms: 37.5087552838
# élaguer Nombre de cliques 11
# max score among faithfull cliques of 22 forms: 249.786446365
# chuter Nombre de cliques 44
# max score among faithfull cliques of 23 forms: 263.794602074
# départir Nombre de cliques 77
# max score among faithfull cliques of 5 forms: 9.37065783941
# tressaillir Nombre de cliques 101
# max score among faithfull cliques of 12 forms: 49.206873438
# juger Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 267.435604896
# connoter Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 266.097599191
# désapprendre Nombre de cliques 94
# max score among faithfull cliques of 7 forms: 25.744047619
# voltiger Nombre de cliques 16
# max score among faithfull cliques of 24 forms: 291.50580411
# dynamiser Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 290.248399892
# délabrer Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 219.920004219
# pomponner Nombre de cliques 44
# max score among faithfull cliques of 22 forms: 233.887675197
# désexualiser Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 267.884709746
# prélaver Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 274.043349837
# raisonner Nombre de cliques 76
# max score among faithfull cliques of 23 forms: 244.986123049
# insurger Nombre de cliques 30
# max score among faithfull cliques of 23 forms: 267.831052091
# graveler Nombre de cliques 30
# max score among faithfull cliques of 16 forms: 104.519077453
# réengager Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 268.190506331
# spammer Nombre de cliques 22
# max score among faithfull cliques of 23 forms: 271.804854397
# louper Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 251.000359956
# corser Nombre de cliques 46
# max score among faithfull cliques of 23 forms: 260.504347206
# anodiser Nombre de cliques 7
# max score among faithfull cliques of 24 forms: 284.708796752
# thésauriser Nombre de cliques 32
# max score among faithfull cliques of 24 forms: 285.962467212
# rebaisser Nombre de cliques 14
# max score among faithfull cliques of 24 forms: 280.68884046
# friponner Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 262.266762134
# obscurcir Nombre de cliques 247
# max score among faithfull cliques of 16 forms: 92.017674556
# lorgner Nombre de cliques 30
# max score among faithfull cliques of 15 forms: 116.011067059
# claironner Nombre de cliques 41
# max score among faithfull cliques of 22 forms: 228.899207168
# pédaler Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 268.695400619
# terroriser Nombre de cliques 27
# max score among faithfull cliques of 24 forms: 287.848526699
# désengourdir Nombre de cliques 1
# max score among faithfull cliques of 10 forms: 49.1986650588
# accabler Nombre de cliques 33
# max score among faithfull cliques of 20 forms: 205.308898132
# insupporter Nombre de cliques 44
# max score among faithfull cliques of 23 forms: 264.02634781
# ennoblir Nombre de cliques 75
# max score among faithfull cliques of 14 forms: 92.823248193
# goûter Nombre de cliques 27
# max score among faithfull cliques of 23 forms: 268.335975959
# pitonner Nombre de cliques 22
# max score among faithfull cliques of 23 forms: 262.494447221
# départager Nombre de cliques 29
# max score among faithfull cliques of 24 forms: 290.149042021
# désaliniser Nombre de cliques 2
# max score among faithfull cliques of 24 forms: 296.778744331
# repiquer Nombre de cliques 20
# max score among faithfull cliques of 24 forms: 289.650274548
# froisser Nombre de cliques 62
# max score among faithfull cliques of 23 forms: 252.558533394
# subvenir Nombre de cliques 145
# max score among faithfull cliques of 12 forms: 69.3095668201
# merdoyer Nombre de cliques 71
# max score among faithfull cliques of 16 forms: 119.496566379
# resituer Nombre de cliques 31
# max score among faithfull cliques of 15 forms: 111.980734432
# inhumer Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 250.031837932
# rogner Nombre de cliques 43
# max score among faithfull cliques of 20 forms: 199.114529705
# préparer Nombre de cliques 34
# max score among faithfull cliques of 21 forms: 221.315846972
# modérer Nombre de cliques 42
# max score among faithfull cliques of 24 forms: 278.283252311
# sauter Nombre de cliques 48
# max score among faithfull cliques of 23 forms: 255.987800368
# resurgir Nombre de cliques 242
# max score among faithfull cliques of 14 forms: 80.762877215
# ratonner Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 260.855521916
# dévaluer Nombre de cliques 33
# max score among faithfull cliques of 14 forms: 102.460793286
# brumer Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 273.472355373
# gruger Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 246.541505346
# décapoter Nombre de cliques 36
# max score among faithfull cliques of 23 forms: 261.394505276
# émacier Nombre de cliques 32
# max score among faithfull cliques of 18 forms: 140.816260811
# ébaucher Nombre de cliques 45
# max score among faithfull cliques of 23 forms: 259.975607699
# remonter Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 261.723442968
# bander Nombre de cliques 52
# max score among faithfull cliques of 23 forms: 259.9774094
# réhabiliter Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 272.401468395
# catéchiser Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 318.910150668
# gargouiller Nombre de cliques 31
# max score among faithfull cliques of 20 forms: 200.412571901
# parapher Nombre de cliques 51
# max score among faithfull cliques of 24 forms: 286.54348572
# appauvrir Nombre de cliques 275
# max score among faithfull cliques of 14 forms: 71.3799892954
# crier Nombre de cliques 94
# max score among faithfull cliques of 12 forms: 61.3539127297
# ragoûter Nombre de cliques 12
# max score among faithfull cliques of 23 forms: 270.937479966
# riveter Nombre de cliques 208
# max score among faithfull cliques of 13 forms: 78.315176488
# rouvrir Nombre de cliques 186
# max score among faithfull cliques of 7 forms: 16.4265268281
# amalgamer Nombre de cliques 17
# max score among faithfull cliques of 15 forms: 118.969665821
# contredire Nombre de cliques 172
# max score among faithfull cliques of 10 forms: 31.849734851
# trouilloter Nombre de cliques 68
# max score among faithfull cliques of 17 forms: 149.29952496
# camer Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 270.899251402
# chorégraphier Nombre de cliques 105
# max score among faithfull cliques of 18 forms: 111.640665472
# recenser Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 262.435787745
# prosodier Nombre de cliques 16
# max score among faithfull cliques of 14 forms: 103.472123977
# caillasser Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 257.239730391
# ravager Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 267.417946641
# râper Nombre de cliques 54
# max score among faithfull cliques of 23 forms: 260.401594896
# fagoter Nombre de cliques 81
# max score among faithfull cliques of 11 forms: 49.4806806179
# représenter Nombre de cliques 81
# max score among faithfull cliques of 19 forms: 174.770611652
# électrolyser Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 268.363506616
# accentuer Nombre de cliques 42
# max score among faithfull cliques of 13 forms: 87.881073655
# déterrer Nombre de cliques 44
# max score among faithfull cliques of 24 forms: 282.929802175
# boumer Nombre de cliques 18
# max score among faithfull cliques of 21 forms: 224.75751635
# crouler Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 249.827382743
# espacer Nombre de cliques 63
# max score among faithfull cliques of 22 forms: 233.377801831
# indemniser Nombre de cliques 26
# max score among faithfull cliques of 24 forms: 290.258961578
# quémander Nombre de cliques 47
# max score among faithfull cliques of 23 forms: 263.335807087
# joncher Nombre de cliques 20
# max score among faithfull cliques of 23 forms: 268.727923289
# miauler Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 238.548128282
# miner Nombre de cliques 13
# max score among faithfull cliques of 13 forms: 90.0501679323
# piétiner Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 269.53595986
# ratiboiser Nombre de cliques 47
# max score among faithfull cliques of 23 forms: 264.861562084
# remplier Nombre de cliques 73
# max score among faithfull cliques of 4 forms: 7.57374551971
# décompresser Nombre de cliques 89
# max score among faithfull cliques of 24 forms: 259.20472379
# bouturer Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 271.989111312
# investir Nombre de cliques 133
# max score among faithfull cliques of 8 forms: 24.9925965653
# trachéotomiser Nombre de cliques 6
# max score among faithfull cliques of 24 forms: 294.640714759
# analyser Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 228.063050068
# agrainer Nombre de cliques 16
# max score among faithfull cliques of 22 forms: 250.706895038
# vaquer Nombre de cliques 46
# max score among faithfull cliques of 23 forms: 264.373472555
# cyanoser Nombre de cliques 26
# max score among faithfull cliques of 20 forms: 204.034807224
# linger Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 274.212195748
# pieuter Nombre de cliques 101
# max score among faithfull cliques of 8 forms: 33.6110100661
# ébahir Nombre de cliques 68
# max score among faithfull cliques of 9 forms: 41.7267111373
# urger Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 264.484511048
# rencaisser Nombre de cliques 7
# max score among faithfull cliques of 24 forms: 291.399275496
# dérouiller Nombre de cliques 30
# max score among faithfull cliques of 20 forms: 197.427237115
# sursignifier Nombre de cliques 6
# max score among faithfull cliques of 19 forms: 158.847141885
# ressurgir Nombre de cliques 236
# max score among faithfull cliques of 15 forms: 87.4648261131
# halener Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 204.933487931
# numériser Nombre de cliques 38
# max score among faithfull cliques of 24 forms: 281.938226024
# ingénier Nombre de cliques 77
# max score among faithfull cliques of 14 forms: 87.1460209959
# délustrer Nombre de cliques 6
# max score among faithfull cliques of 20 forms: 207.141249385
# approuver Nombre de cliques 33
# max score among faithfull cliques of 23 forms: 264.434294352
# défroquer Nombre de cliques 21
# max score among faithfull cliques of 22 forms: 241.215804082
# chuchoter Nombre de cliques 57
# max score among faithfull cliques of 23 forms: 251.536242368
# missionner Nombre de cliques 25
# max score among faithfull cliques of 23 forms: 262.407273581
# volatiliser Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 264.340472618
# frauder Nombre de cliques 136
# max score among faithfull cliques of 12 forms: 47.3862502731
# déminer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 274.196284681
# recontacter Nombre de cliques 27
# max score among faithfull cliques of 22 forms: 248.188285073
# reboucler Nombre de cliques 16
# max score among faithfull cliques of 20 forms: 209.158240594
# fourgonner Nombre de cliques 20
# max score among faithfull cliques of 23 forms: 257.593075626
# mailer Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 271.011731772
# refouler Nombre de cliques 19
# max score among faithfull cliques of 22 forms: 246.658686661
# déconseiller Nombre de cliques 89
# max score among faithfull cliques of 20 forms: 168.31967169
# répercuter Nombre de cliques 26
# max score among faithfull cliques of 23 forms: 266.130182726
# précéder Nombre de cliques 201
# max score among faithfull cliques of 19 forms: 156.542390094
# fourrager Nombre de cliques 33
# max score among faithfull cliques of 23 forms: 265.999305616
# marier Nombre de cliques 81
# max score among faithfull cliques of 13 forms: 78.6897141475
# faillir Nombre de cliques 89
# max score among faithfull cliques of 10 forms: 55.0
# interchanger Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 271.982253128
# chigner Nombre de cliques 20
# max score among faithfull cliques of 21 forms: 228.004466009
# épointer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 270.820722315
# repentir Nombre de cliques 136
# max score among faithfull cliques of 12 forms: 44.0025805314
# autolimiter Nombre de cliques 4
# max score among faithfull cliques of 24 forms: 296.420030878
# jumeler Nombre de cliques 56
# max score among faithfull cliques of 12 forms: 65.9049725476
# dédicacer Nombre de cliques 44
# max score among faithfull cliques of 24 forms: 279.545540425
# poudroyer Nombre de cliques 39
# max score among faithfull cliques of 18 forms: 147.357929998
# paginer Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 271.277036042
# plaquer Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 271.724708758
# réépouser Nombre de cliques 14
# max score among faithfull cliques of 23 forms: 269.882797532
# démilitariser Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 318.662750189
# démarier Nombre de cliques 77
# max score among faithfull cliques of 18 forms: 128.975341699
# importuner Nombre de cliques 32
# max score among faithfull cliques of 22 forms: 247.139571661
# pérorer Nombre de cliques 58
# max score among faithfull cliques of 23 forms: 251.913978539
# conspirer Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 290.976023138
# atterrir Nombre de cliques 203
# max score among faithfull cliques of 9 forms: 36.0708267942
# raidir Nombre de cliques 215
# max score among faithfull cliques of 15 forms: 76.2801901942
# aviser Nombre de cliques 57
# max score among faithfull cliques of 24 forms: 278.584219589
# tranquilliser Nombre de cliques 28
# max score among faithfull cliques of 23 forms: 264.418977792
# décrire Nombre de cliques 198
# max score among faithfull cliques of 10 forms: 37.9739817135
# branlocher Nombre de cliques 4
# max score among faithfull cliques of 23 forms: 272.897037611
# militer Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 271.118389919
# piger Nombre de cliques 43
# max score among faithfull cliques of 24 forms: 291.08581098
# évanouir Nombre de cliques 58
# max score among faithfull cliques of 12 forms: 72.6805616086
# tonner Nombre de cliques 56
# max score among faithfull cliques of 23 forms: 258.679826787
# CPU times: user 3h 2min 10s, sys: 1min 31s, total: 3h 3min 41s
# Wall time: 3h 3min 23s

# %%
newParadigmes,paradigmesSwim1,characteristicsSwim1,measuresSwim1=calculerResultats(swim1ContextParadigmes,"-Swim1")
# %ding
# Out:
# Index([u'value', u'lexeme-case'], dtype='object')
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# UG 92254 OG 36870 TP 146615 FP 19328
# recall 0.567841609314 precision 0.722907308703
# 0.636059955316

# %% [markdown]
# # SWIM2

# %% [markdown]
# ## Préparation des paradigmes

# %%
paradigmesOriginaux=paradigmes.copy()
paradigmesSample=paradigmesOriginaux[paradigmesOriginaux["lexeme"].isin(listeTest)]

# %%
paradigmes=newParadigmes.copy()
paradigmesColumns=paradigmes.columns.tolist()
for c in sampleCases:
    if not c in paradigmesColumns:
        print (c)
        paradigmes[c]=np.NaN

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim2ContextParadigmes=generateCliques(contextFree=True)
# Out:
# 2023-11-14 14:58:21.994624
# FloatProgress(value=0.0, description=u'Generation (6368 verbs)', max=6367.0)
# 0 1358 0, 100 1359 1, 200 1400 3, 300 1402 4, 400 1403 6, 500 1404 7, 600 1406 9, 700 1407 10, 800 1409 12, 900 1410 14, 1000 1411 15, 1100 1413 17, 1200 1414 18, 1300 1415 20, 1400 1416 21, 1500 1418 23, 1600 1419 25, 1700 1420 26, 1800 1422 28, 1900 1423 29, 2000 1424 31, 2100 1426 32, 2200 1427 34, 2300 1428 36, 2400 1430 37, 2500 1431 39, 2600 1432 40, 2700 1434 42, 2800 1435 43, 2900 1436 45, 3000 1437 47, 3100 1439 48, 3200 1440 50, 3300 1441 51, 3400 1443 53, 3500 1444 54, 3600 1445 56, 3700 1446 58, 3800 1447 59, 3900 1449 61, 4000 1450 62, 4100 1452 64, 4200 1453 65, 4300 1454 67, 4400 1456 69, 4500 1457 70, 4600 1458 72, 4700 1500 73, 4800 1501 75, 4900 1502 76, 5000 1504 78, 5100 1505 80, 5200 1506 81, 5300 1507 83, 5400 1508 84, 5500 1510 86, 5600 1511 87, 5700 1512 89, 5800 1513 91, 5900 1515 92, 6000 1516 94, 6100 1517 95, 6200 1519 97, 6300 1520 98,
# FloatProgress(value=0.0, description=u'Analysis (6368 verbes)', max=6367.0)
# gauchir Nombre de cliques 822
# max score among faithfull cliques of 22 forms: 98.9843659981
# dénazifier Nombre de cliques 1497
# max score among faithfull cliques of 22 forms: 95.3937123309
# réinstaller Nombre de cliques 1234
# max score among faithfull cliques of 27 forms: 242.94044586
# caner Nombre de cliques 1125
# max score among faithfull cliques of 27 forms: 244.985269368
# tancer Nombre de cliques 1430
# max score among faithfull cliques of 27 forms: 211.605379725
# devenir Nombre de cliques 293
# max score among faithfull cliques of 9 forms: 30.8977366206
# orthographier Nombre de cliques 1526
# max score among faithfull cliques of 22 forms: 91.1249945286
# affectionner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# verser Nombre de cliques 1386
# max score among faithfull cliques of 27 forms: 209.945736907
# dégommer Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.193649128
# déverser Nombre de cliques 1413
# max score among faithfull cliques of 27 forms: 212.79703063
# superposer Nombre de cliques 1479
# no new faithfull clique, the previous one contained 23 forms
# spiritualiser Nombre de cliques 1478
# max score among faithfull cliques of 26 forms: 214.009585398
# empoissonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# persister Nombre de cliques 1183
# max score among faithfull cliques of 27 forms: 244.250393198
# déganter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# judaïser Nombre de cliques 1480
# max score among faithfull cliques of 26 forms: 214.009585398
# commenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# douiller Nombre de cliques 1681
# max score among faithfull cliques of 24 forms: 152.045300338
# concasser Nombre de cliques 1438
# max score among faithfull cliques of 26 forms: 194.16493846
# entrégorger Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# bossuer Nombre de cliques 1087
# max score among faithfull cliques of 20 forms: 102.071007103
# fritter Nombre de cliques 1199
# max score among faithfull cliques of 27 forms: 242.800867761
# maquereauter Nombre de cliques 1798
# max score among faithfull cliques of 19 forms: 80.2038927518
# boursicoter Nombre de cliques 1244
# max score among faithfull cliques of 26 forms: 219.812502338
# aposter Nombre de cliques 1175
# max score among faithfull cliques of 27 forms: 248.34763843
# chauffer Nombre de cliques 1236
# max score among faithfull cliques of 27 forms: 240.169525284
# poiler Nombre de cliques 1238
# max score among faithfull cliques of 27 forms: 241.429024844
# dépayser Nombre de cliques 1473
# max score among faithfull cliques of 26 forms: 213.515066021
# pencher Nombre de cliques 1155
# max score among faithfull cliques of 27 forms: 248.679309212
# poivrer Nombre de cliques 1071
# max score among faithfull cliques of 27 forms: 244.098123259
# évider Nombre de cliques 1254
# max score among faithfull cliques of 27 forms: 242.013896103
# foisonner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# préluder Nombre de cliques 1204
# max score among faithfull cliques of 27 forms: 242.417703622
# moucharder Nombre de cliques 1227
# max score among faithfull cliques of 27 forms: 241.822026311
# muer Nombre de cliques 1698
# max score among faithfull cliques of 20 forms: 117.00809547
# revouloir Nombre de cliques 438
# max score among faithfull cliques of 8 forms: 14.8055178332
# enquiquiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# effaroucher Nombre de cliques 1157
# max score among faithfull cliques of 27 forms: 245.209265485
# dévaloriser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# grossir Nombre de cliques 1700
# max score among faithfull cliques of 22 forms: 88.1762816634
# contre-braquer Nombre de cliques 1366
# max score among faithfull cliques of 27 forms: 245.218179717
# offenser Nombre de cliques 1385
# no new faithfull clique, the previous one contained 20 forms
# fusionner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# confisquer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 244.763386411
# reporter Nombre de cliques 1191
# max score among faithfull cliques of 27 forms: 248.413041514
# susurrer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# parisianiser Nombre de cliques 1498
# no new faithfull clique, the previous one contained 25 forms
# désincruster Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 248.34763843
# éreinter Nombre de cliques 1142
# max score among faithfull cliques of 27 forms: 251.015215865
# fissurer Nombre de cliques 1090
# max score among faithfull cliques of 27 forms: 244.050145164
# bambocher Nombre de cliques 1262
# max score among faithfull cliques of 27 forms: 239.877542637
# biquer Nombre de cliques 1148
# max score among faithfull cliques of 27 forms: 245.134793499
# rassortir Nombre de cliques 1232
# max score among faithfull cliques of 22 forms: 90.7273548104
# ragoter Nombre de cliques 1244
# max score among faithfull cliques of 26 forms: 219.812502338
# déboulonner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# aniser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# endenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# emplir Nombre de cliques 1328
# max score among faithfull cliques of 21 forms: 80.0225996133
# remeubler Nombre de cliques 1137
# max score among faithfull cliques of 27 forms: 248.166005743
# prêcher Nombre de cliques 1209
# max score among faithfull cliques of 27 forms: 224.806006039
# coqueter Nombre de cliques 1060
# max score among faithfull cliques of 20 forms: 132.977662665
# unir Nombre de cliques 1115
# max score among faithfull cliques of 12 forms: 30.5933334964
# agencer Nombre de cliques 1420
# max score among faithfull cliques of 27 forms: 208.749290373
# jambonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# exploser Nombre de cliques 1407
# max score among faithfull cliques of 26 forms: 202.738679275
# transvider Nombre de cliques 1259
# max score among faithfull cliques of 27 forms: 246.257962607
# rugir Nombre de cliques 1496
# max score among faithfull cliques of 22 forms: 87.2355634039
# menacer Nombre de cliques 1435
# max score among faithfull cliques of 26 forms: 196.043774835
# décompiler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# fustiger Nombre de cliques 1148
# max score among faithfull cliques of 27 forms: 245.134793499
# bâter Nombre de cliques 1185
# max score among faithfull cliques of 27 forms: 244.458092136
# ronger Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# ébouriffer Nombre de cliques 1148
# max score among faithfull cliques of 27 forms: 245.134793499
# convoler Nombre de cliques 1234
# max score among faithfull cliques of 26 forms: 218.202588348
# sortir Nombre de cliques 692
# max score among faithfull cliques of 10 forms: 16.6085743718
# mémoriser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# précipiter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# orner Nombre de cliques 1124
# max score among faithfull cliques of 27 forms: 245.012991625
# cajoler Nombre de cliques 1234
# max score among faithfull cliques of 26 forms: 218.202588348
# déclencher Nombre de cliques 1155
# max score among faithfull cliques of 27 forms: 248.679309212
# dérider Nombre de cliques 1260
# max score among faithfull cliques of 27 forms: 243.290734702
# prôner Nombre de cliques 1812
# max score among faithfull cliques of 19 forms: 67.6032944952
# embuer Nombre de cliques 1726
# max score among faithfull cliques of 20 forms: 115.031300676
# ratisser Nombre de cliques 1212
# no new faithfull clique, the previous one contained 13 forms
# nitrater Nombre de cliques 1185
# max score among faithfull cliques of 27 forms: 244.458092136
# sous-exploiter Nombre de cliques 1201
# max score among faithfull cliques of 27 forms: 242.957105912
# bigarrer Nombre de cliques 1112
# max score among faithfull cliques of 27 forms: 243.913935161
# swinguer Nombre de cliques 1124
# max score among faithfull cliques of 27 forms: 245.012991625
# canarder Nombre de cliques 1237
# max score among faithfull cliques of 27 forms: 246.066638818
# avarier Nombre de cliques 1242
# max score among faithfull cliques of 22 forms: 104.186100654
# prostituer Nombre de cliques 1890
# max score among faithfull cliques of 20 forms: 116.257540092
# biaiser Nombre de cliques 1872
# no new faithfull clique, the previous one contained 21 forms
# destiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# mépriser Nombre de cliques 1453
# no new faithfull clique, the previous one contained 21 forms
# appendre Nombre de cliques 851
# max score among faithfull cliques of 17 forms: 36.2053013356
# préformater Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 244.704948972
# ardre Nombre de cliques 121
# max score among faithfull cliques of 16 forms: 48.0373054018
# vibrer Nombre de cliques 684
# max score among faithfull cliques of 27 forms: 248.689950161
# attitrer Nombre de cliques 1102
# max score among faithfull cliques of 24 forms: 181.898514557
# consacrer Nombre de cliques 1072
# max score among faithfull cliques of 23 forms: 144.804131565
# combler Nombre de cliques 1113
# max score among faithfull cliques of 27 forms: 246.168500092
# émasculer Nombre de cliques 1143
# max score among faithfull cliques of 27 forms: 245.709663656
# naufrager Nombre de cliques 1125
# max score among faithfull cliques of 27 forms: 244.985269368
# typer Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.841621843
# sentir Nombre de cliques 912
# max score among faithfull cliques of 17 forms: 42.134724683
# expectorer Nombre de cliques 1241
# max score among faithfull cliques of 27 forms: 238.872042762
# accéder Nombre de cliques 1231
# max score among faithfull cliques of 27 forms: 223.082340467
# tarauder Nombre de cliques 1500
# max score among faithfull cliques of 17 forms: 85.9396801493
# entrapercevoir Nombre de cliques 925
# max score among faithfull cliques of 5 forms: 5.83102732199
# défiler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# pigmenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# substituer Nombre de cliques 1896
# max score among faithfull cliques of 20 forms: 118.185779873
# efféminer Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# boire Nombre de cliques 787
# max score among faithfull cliques of 9 forms: 24.8769288948
# sous-tendre Nombre de cliques 449
# max score among faithfull cliques of 18 forms: 57.8430556695
# profaner Nombre de cliques 1125
# max score among faithfull cliques of 27 forms: 244.985269368
# repriser Nombre de cliques 1499
# no new faithfull clique, the previous one contained 24 forms
# maturer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# bâcher Nombre de cliques 1165
# max score among faithfull cliques of 26 forms: 228.406446811
# plafonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# collectionner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# bosseler Nombre de cliques 1632
# max score among faithfull cliques of 21 forms: 116.112768753
# incendier Nombre de cliques 1390
# max score among faithfull cliques of 21 forms: 96.807451812
# réfracter Nombre de cliques 1179
# max score among faithfull cliques of 27 forms: 245.60098806
# surgir Nombre de cliques 1472
# max score among faithfull cliques of 22 forms: 86.9951639915
# vadrouiller Nombre de cliques 1681
# max score among faithfull cliques of 24 forms: 152.045300338
# éloigner Nombre de cliques 1150
# no new faithfull clique, the previous one contained 16 forms
# braiser Nombre de cliques 1827
# no new faithfull clique, the previous one contained 24 forms
# froufrouter Nombre de cliques 1179
# max score among faithfull cliques of 27 forms: 244.895840861
# violacer Nombre de cliques 1447
# max score among faithfull cliques of 26 forms: 194.16493846
# ensacher Nombre de cliques 1165
# max score among faithfull cliques of 26 forms: 228.406446811
# rapprendre Nombre de cliques 648
# max score among faithfull cliques of 17 forms: 42.5524706865
# vouloir Nombre de cliques 839
# max score among faithfull cliques of 8 forms: 11.2373628136
# aliter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.406936488
# boucaner Nombre de cliques 1125
# max score among faithfull cliques of 27 forms: 244.985269368
# piocher Nombre de cliques 1245
# max score among faithfull cliques of 27 forms: 238.124535934
# couturer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# acheminer Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# stabiliser Nombre de cliques 1476
# max score among faithfull cliques of 26 forms: 214.009585398
# opacifier Nombre de cliques 1497
# max score among faithfull cliques of 22 forms: 95.3937123309
# blinder Nombre de cliques 1296
# max score among faithfull cliques of 27 forms: 246.066638818
# parasiter Nombre de cliques 1201
# max score among faithfull cliques of 27 forms: 244.615772608
# désendetter Nombre de cliques 1424
# no new faithfull clique, the previous one contained 24 forms
# autodéterminer Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# retuber Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# gercer Nombre de cliques 1432
# max score among faithfull cliques of 27 forms: 211.605379725
# inaugurer Nombre de cliques 1095
# max score among faithfull cliques of 27 forms: 247.476484061
# blablater Nombre de cliques 1160
# max score among faithfull cliques of 27 forms: 245.140363738
# rembobiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# ratiociner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# roquer Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# biser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# valoir Nombre de cliques 1157
# max score among faithfull cliques of 7 forms: 9.0764677195
# assurer Nombre de cliques 1106
# max score among faithfull cliques of 27 forms: 247.408506914
# emprisonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# réattribuer Nombre de cliques 1866
# max score among faithfull cliques of 20 forms: 116.449362641
# materner Nombre de cliques 1124
# max score among faithfull cliques of 27 forms: 245.012991625
# décarboniser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# réciproquer Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# glycériner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# carotter Nombre de cliques 1250
# max score among faithfull cliques of 26 forms: 221.093693811
# maximaliser Nombre de cliques 1478
# max score among faithfull cliques of 26 forms: 214.009585398
# redéfinir Nombre de cliques 1219
# max score among faithfull cliques of 22 forms: 92.3396971059
# apitoyer Nombre de cliques 1625
# no new faithfull clique, the previous one contained 16 forms
# gambiller Nombre de cliques 1631
# max score among faithfull cliques of 25 forms: 161.999499211
# rejouer Nombre de cliques 1562
# max score among faithfull cliques of 18 forms: 90.5501557702
# embrouiller Nombre de cliques 1915
# max score among faithfull cliques of 21 forms: 98.4355313676
# lister Nombre de cliques 1183
# max score among faithfull cliques of 27 forms: 244.250393198
# détracter Nombre de cliques 1179
# max score among faithfull cliques of 27 forms: 245.60098806
# octroyer Nombre de cliques 1633
# max score among faithfull cliques of 20 forms: 62.9676673034
# entrevoir Nombre de cliques 1998
# max score among faithfull cliques of 10 forms: 8.08563007374
# regreffer Nombre de cliques 1177
# max score among faithfull cliques of 27 forms: 223.253574462
# préremplir Nombre de cliques 954
# max score among faithfull cliques of 22 forms: 81.5220313315
# bitter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# motoriser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# rectifier Nombre de cliques 1520
# max score among faithfull cliques of 22 forms: 89.745516734
# dissimiler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# exulter Nombre de cliques 1122
# max score among faithfull cliques of 27 forms: 242.980014978
# baliser Nombre de cliques 1444
# max score among faithfull cliques of 26 forms: 213.823851392
# tirer Nombre de cliques 992
# max score among faithfull cliques of 27 forms: 251.329585077
# prouter Nombre de cliques 1212
# max score among faithfull cliques of 27 forms: 247.828779152
# ardoiser Nombre de cliques 1488
# max score among faithfull cliques of 26 forms: 215.58989929
# cacarder Nombre de cliques 1237
# max score among faithfull cliques of 27 forms: 246.066638818
# mitrer Nombre de cliques 1013
# max score among faithfull cliques of 27 forms: 245.669032791
# palanquer Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# chamarrer Nombre de cliques 1107
# max score among faithfull cliques of 27 forms: 243.645345743
# arrimer Nombre de cliques 1133
# max score among faithfull cliques of 27 forms: 244.991430947
# absorber Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# overclocker Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# désensorceler Nombre de cliques 1198
# max score among faithfull cliques of 19 forms: 76.6308082316
# décentrer Nombre de cliques 1013
# max score among faithfull cliques of 27 forms: 245.669032791
# coulisser Nombre de cliques 1033
# no new faithfull clique, the previous one contained 12 forms
# nuer Nombre de cliques 1514
# max score among faithfull cliques of 20 forms: 120.82728777
# enjamber Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# fauter Nombre de cliques 1683
# max score among faithfull cliques of 19 forms: 79.9930873539
# briffer Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# bafouer Nombre de cliques 1380
# max score among faithfull cliques of 20 forms: 108.186645542
# discréditer Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# singer Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# provisionner Nombre de cliques 1215
# max score among faithfull cliques of 27 forms: 241.563029169
# purger Nombre de cliques 1124
# max score among faithfull cliques of 27 forms: 245.012991625
# calquer Nombre de cliques 1060
# max score among faithfull cliques of 27 forms: 243.584112306
# dessiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# relever Nombre de cliques 1184
# max score among faithfull cliques of 17 forms: 68.6053929959
# tapoter Nombre de cliques 1261
# max score among faithfull cliques of 27 forms: 237.940308081
# réparer Nombre de cliques 1073
# max score among faithfull cliques of 27 forms: 239.103889653
# froncer Nombre de cliques 1440
# max score among faithfull cliques of 27 forms: 211.605379725
# essorer Nombre de cliques 1188
# max score among faithfull cliques of 26 forms: 216.744123956
# ruisseler Nombre de cliques 1201
# max score among faithfull cliques of 21 forms: 115.091197991
# écouler Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 247.222661801
# dégoûter Nombre de cliques 1212
# max score among faithfull cliques of 27 forms: 247.828779152
# replâtrer Nombre de cliques 1066
# max score among faithfull cliques of 27 forms: 245.307236786
# décrypter Nombre de cliques 1183
# max score among faithfull cliques of 27 forms: 244.250393198
# caper Nombre de cliques 1191
# max score among faithfull cliques of 27 forms: 244.276798345
# toucher Nombre de cliques 1039
# max score among faithfull cliques of 27 forms: 252.098425464
# écarquiller Nombre de cliques 1564
# max score among faithfull cliques of 24 forms: 150.825149459
# poireauter Nombre de cliques 1244
# max score among faithfull cliques of 26 forms: 219.812502338
# tournailler Nombre de cliques 1568
# max score among faithfull cliques of 25 forms: 157.117759319
# ravaler Nombre de cliques 1234
# max score among faithfull cliques of 27 forms: 242.94044586
# annihiler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# environner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# repolariser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# essaimer Nombre de cliques 1379
# no new faithfull clique, the previous one contained 22 forms
# effriter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# étoffer Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# rameuter Nombre de cliques 2478
# max score among faithfull cliques of 17 forms: 92.3912088351
# reposer Nombre de cliques 1486
# max score among faithfull cliques of 26 forms: 211.713739931
# badigeonner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# fleurir Nombre de cliques 1700
# max score among faithfull cliques of 20 forms: 73.2829848099
# faisander Nombre de cliques 1218
# max score among faithfull cliques of 27 forms: 246.066638818
# ensuquer Nombre de cliques 1151
# max score among faithfull cliques of 27 forms: 248.674574715
# drayer Nombre de cliques 1734
# max score among faithfull cliques of 23 forms: 132.863053891
# mâchurer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# outiller Nombre de cliques 1633
# max score among faithfull cliques of 25 forms: 161.999499211
# lapider Nombre de cliques 1254
# max score among faithfull cliques of 27 forms: 242.013896103
# embouter Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 248.078061513
# haïr Nombre de cliques 721
# max score among faithfull cliques of 22 forms: 93.6947361488
# clarifier Nombre de cliques 1533
# max score among faithfull cliques of 22 forms: 86.2150052651
# désigner Nombre de cliques 1095
# max score among faithfull cliques of 27 forms: 245.364243634
# dépêtrer Nombre de cliques 1102
# max score among faithfull cliques of 24 forms: 181.898514557
# reprogrammer Nombre de cliques 1132
# max score among faithfull cliques of 27 forms: 244.969493376
# débiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# pressurer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# entreposer Nombre de cliques 1503
# no new faithfull clique, the previous one contained 23 forms
# embrever Nombre de cliques 1060
# no new faithfull clique, the previous one contained 16 forms
# débouder Nombre de cliques 1483
# max score among faithfull cliques of 27 forms: 243.452164616
# moissonner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# souvenir Nombre de cliques 262
# max score among faithfull cliques of 11 forms: 46.6637442427
# euphoriser Nombre de cliques 1499
# no new faithfull clique, the previous one contained 24 forms
# cafter Nombre de cliques 1159
# max score among faithfull cliques of 27 forms: 242.360309265
# nébuliser Nombre de cliques 1476
# max score among faithfull cliques of 26 forms: 214.009585398
# étourdir Nombre de cliques 1560
# max score among faithfull cliques of 22 forms: 89.1841472439
# adapter Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 248.34763843
# remouler Nombre de cliques 1154
# max score among faithfull cliques of 27 forms: 245.362885183
# incinérer Nombre de cliques 1375
# max score among faithfull cliques of 27 forms: 217.530021493
# fouiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# percuter Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 246.548460358
# écourter Nombre de cliques 1181
# max score among faithfull cliques of 27 forms: 244.485814393
# révulser Nombre de cliques 1365
# max score among faithfull cliques of 27 forms: 205.721970151
# patenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# demander Nombre de cliques 954
# max score among faithfull cliques of 27 forms: 243.284221563
# surproduire Nombre de cliques 1240
# max score among faithfull cliques of 16 forms: 30.9715544275
# avaliser Nombre de cliques 1444
# max score among faithfull cliques of 26 forms: 213.823851392
# pactiser Nombre de cliques 1492
# no new faithfull clique, the previous one contained 24 forms
# menuiser Nombre de cliques 1380
# max score among faithfull cliques of 26 forms: 214.154552799
# mortifier Nombre de cliques 1520
# max score among faithfull cliques of 22 forms: 89.745516734
# perler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.008273846
# exaspérer Nombre de cliques 1380
# max score among faithfull cliques of 27 forms: 222.685237896
# ganter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# potasser Nombre de cliques 1437
# max score among faithfull cliques of 26 forms: 191.358000743
# récliner Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# traficoter Nombre de cliques 1244
# max score among faithfull cliques of 26 forms: 219.812502338
# parler Nombre de cliques 520
# max score among faithfull cliques of 27 forms: 247.963390966
# défouler Nombre de cliques 1154
# max score among faithfull cliques of 27 forms: 245.362885183
# penser Nombre de cliques 1056
# max score among faithfull cliques of 25 forms: 188.968042695
# tutoyer Nombre de cliques 1740
# max score among faithfull cliques of 20 forms: 66.6076904607
# suivre Nombre de cliques 891
# max score among faithfull cliques of 9 forms: 19.1255875889
# haranguer Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# contreficher Nombre de cliques 1173
# max score among faithfull cliques of 27 forms: 248.812625491
# batifoler Nombre de cliques 1259
# max score among faithfull cliques of 27 forms: 236.844350736
# claboter Nombre de cliques 1278
# max score among faithfull cliques of 27 forms: 239.686521711
# criminaliser Nombre de cliques 1444
# max score among faithfull cliques of 26 forms: 213.823851392
# panoramiquer Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# empêcher Nombre de cliques 1209
# max score among faithfull cliques of 27 forms: 224.806006039
# tortorer Nombre de cliques 1241
# max score among faithfull cliques of 27 forms: 238.872042762
# récriminer Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# déverdir Nombre de cliques 1529
# max score among faithfull cliques of 22 forms: 87.4813907346
# aboyer Nombre de cliques 1733
# max score among faithfull cliques of 20 forms: 66.0897457691
# vendanger Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# truster Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 248.34763843
# rebrûler Nombre de cliques 1143
# max score among faithfull cliques of 27 forms: 245.709663656
# élargir Nombre de cliques 1002
# max score among faithfull cliques of 21 forms: 77.5253455163
# recadrer Nombre de cliques 1018
# max score among faithfull cliques of 27 forms: 244.381373788
# toaster Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 248.34763843
# voiturer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# rouir Nombre de cliques 665
# max score among faithfull cliques of 21 forms: 95.1444557293
# étatiser Nombre de cliques 1498
# no new faithfull clique, the previous one contained 25 forms
# intituler Nombre de cliques 1143
# max score among faithfull cliques of 27 forms: 245.709663656
# peindre Nombre de cliques 807
# max score among faithfull cliques of 13 forms: 35.0956720677
# ragaillardir Nombre de cliques 1377
# max score among faithfull cliques of 22 forms: 93.4914884471
# voyager Nombre de cliques 1135
# max score among faithfull cliques of 27 forms: 245.218179717
# palpiter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# encrer Nombre de cliques 1091
# max score among faithfull cliques of 27 forms: 244.544542657
# cloquer Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# bistrer Nombre de cliques 1042
# max score among faithfull cliques of 27 forms: 243.473090088
# bedonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# négocier Nombre de cliques 1512
# max score among faithfull cliques of 20 forms: 67.8379933074
# dépasser Nombre de cliques 1431
# max score among faithfull cliques of 26 forms: 195.011772588
# dérégler Nombre de cliques 1138
# max score among faithfull cliques of 27 forms: 245.378461898
# rescinder Nombre de cliques 1271
# max score among faithfull cliques of 27 forms: 240.936447928
# chancir Nombre de cliques 1677
# max score among faithfull cliques of 22 forms: 86.8097011209
# apurer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# tiédir Nombre de cliques 1506
# max score among faithfull cliques of 21 forms: 86.8788961636
# contremander Nombre de cliques 1218
# max score among faithfull cliques of 27 forms: 244.880746672
# solidariser Nombre de cliques 1505
# no new faithfull clique, the previous one contained 25 forms
# mordorer Nombre de cliques 1241
# max score among faithfull cliques of 27 forms: 238.872042762
# renouveler Nombre de cliques 1096
# max score among faithfull cliques of 18 forms: 61.9888249203
# déconner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# fréquenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# rabouter Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 248.078061513
# dialoguer Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# embaumer Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.396687788
# râler Nombre de cliques 1234
# max score among faithfull cliques of 27 forms: 242.94044586
# exorciser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# suriner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# contribuer Nombre de cliques 1700
# max score among faithfull cliques of 19 forms: 101.589991709
# rustiquer Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# coproduire Nombre de cliques 960
# max score among faithfull cliques of 15 forms: 34.3275025097
# présumer Nombre de cliques 1141
# max score among faithfull cliques of 27 forms: 248.894685693
# recoloniser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# revisser Nombre de cliques 1141
# max score among faithfull cliques of 25 forms: 195.222192376
# détacher Nombre de cliques 1166
# max score among faithfull cliques of 26 forms: 229.537558084
# trôner Nombre de cliques 1795
# max score among faithfull cliques of 19 forms: 68.8368626057
# défléchir Nombre de cliques 1361
# max score among faithfull cliques of 21 forms: 83.9900052475
# pister Nombre de cliques 1183
# max score among faithfull cliques of 27 forms: 244.250393198
# ballaster Nombre de cliques 1176
# max score among faithfull cliques of 27 forms: 248.34763843
# parlementer Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# trépider Nombre de cliques 1254
# max score among faithfull cliques of 27 forms: 242.013896103
# rebondir Nombre de cliques 1581
# max score among faithfull cliques of 22 forms: 86.787557814
# poser Nombre de cliques 1372
# no new faithfull clique, the previous one contained 19 forms
# dîner Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# styliser Nombre de cliques 1442
# max score among faithfull cliques of 26 forms: 213.823851392
# fournir Nombre de cliques 814
# max score among faithfull cliques of 15 forms: 42.8293747038
# préfigurer Nombre de cliques 1090
# max score among faithfull cliques of 27 forms: 244.050145164
# briser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# chevaucher Nombre de cliques 1245
# max score among faithfull cliques of 27 forms: 238.124535934
# loucher Nombre de cliques 1173
# max score among faithfull cliques of 27 forms: 248.344084448
# filouter Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 248.078061513
# tictaquer Nombre de cliques 1366
# max score among faithfull cliques of 27 forms: 245.218179717
# fourrer Nombre de cliques 1108
# max score among faithfull cliques of 27 forms: 247.572762094
# proroger Nombre de cliques 1236
# max score among faithfull cliques of 27 forms: 240.169525284
# soutirer Nombre de cliques 1120
# max score among faithfull cliques of 27 forms: 243.504020993
# détester Nombre de cliques 952
# max score among faithfull cliques of 27 forms: 237.623535032
# tordre Nombre de cliques 908
# max score among faithfull cliques of 18 forms: 51.3344106607
# léguer Nombre de cliques 1166
# max score among faithfull cliques of 27 forms: 224.945850658
# rescolariser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# descendre Nombre de cliques 933
# no new faithfull clique, the previous one contained 12 forms
# coller Nombre de cliques 1234
# max score among faithfull cliques of 26 forms: 218.202588348
# retravailler Nombre de cliques 1502
# max score among faithfull cliques of 23 forms: 104.056869818
# délivrer Nombre de cliques 1101
# max score among faithfull cliques of 27 forms: 248.486494101
# patauger Nombre de cliques 1194
# max score among faithfull cliques of 26 forms: 219.574747051
# moraliser Nombre de cliques 1478
# max score among faithfull cliques of 26 forms: 214.009585398
# morfler Nombre de cliques 1138
# max score among faithfull cliques of 27 forms: 247.118086482
# rapprovisionner Nombre de cliques 1215
# max score among faithfull cliques of 27 forms: 241.563029169
# encocher Nombre de cliques 1262
# max score among faithfull cliques of 27 forms: 239.877542637
# automatiser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# disqualifier Nombre de cliques 1515
# max score among faithfull cliques of 22 forms: 89.0440032544
# iodler Nombre de cliques 1113
# max score among faithfull cliques of 27 forms: 246.168500092
# démunir Nombre de cliques 1474
# max score among faithfull cliques of 22 forms: 87.2771277701
# béatifier Nombre de cliques 1497
# max score among faithfull cliques of 22 forms: 95.3937123309
# pilonner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# mutiler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# reconduire Nombre de cliques 1328
# max score among faithfull cliques of 16 forms: 34.8499085839
# ensiler Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# récuser Nombre de cliques 1453
# no new faithfull clique, the previous one contained 22 forms
# câbler Nombre de cliques 1137
# max score among faithfull cliques of 27 forms: 248.166005743
# spolier Nombre de cliques 1487
# max score among faithfull cliques of 22 forms: 96.0338755241
# roupiller Nombre de cliques 1607
# max score among faithfull cliques of 24 forms: 149.26142224
# affûter Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 245.168588522
# japoniser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# éparpiller Nombre de cliques 1684
# max score among faithfull cliques of 20 forms: 83.5088445983
# modéliser Nombre de cliques 1461
# max score among faithfull cliques of 26 forms: 214.009585398
# improuver Nombre de cliques 1763
# no new faithfull clique, the previous one contained 23 forms
# smasher Nombre de cliques 1139
# max score among faithfull cliques of 27 forms: 248.619371207
# escarmoucher Nombre de cliques 1163
# max score among faithfull cliques of 27 forms: 246.518045784
# décroûter Nombre de cliques 1179
# max score among faithfull cliques of 27 forms: 244.895840861
# conjuguer Nombre de cliques 1118
# max score among faithfull cliques of 27 forms: 245.803712912
# angéliser Nombre de cliques 1220
# max score among faithfull cliques of 26 forms: 215.030143842
# creuser Nombre de cliques 1458
# max score among faithfull cliques of 9 forms: 16.9951278743
# centrifuger Nombre de cliques 1151
# max score among faithfull cliques of 27 forms: 248.674574715
# démasquer Nombre de cliques 1116
# max score among faithfull cliques of 27 forms: 248.862501851
# rasseoir Nombre de cliques 1953
# max score among faithfull cliques of 11 forms: 11.5842075265
# quintupler Nombre de cliques 1205
# max score among faithfull cliques of 24 forms: 183.432327623
# tarder Nombre de cliques 1227
# max score among faithfull cliques of 27 forms: 241.822026311
# dealer Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.002489159
# réensemencer Nombre de cliques 1430
# max score among faithfull cliques of 27 forms: 211.605379725
# suinter Nombre de cliques 1194
# max score among faithfull cliques of 27 forms: 248.413041514
# coéditer Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# protester Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 244.250393198
# aiguer Nombre de cliques 1028
# max score among faithfull cliques of 27 forms: 227.936723308
# baiser Nombre de cliques 1818
# no new faithfull clique, the previous one contained 22 forms
# déphaser Nombre de cliques 1489
# max score among faithfull cliques of 26 forms: 218.195854695
# épaissir Nombre de cliques 1644
# max score among faithfull cliques of 21 forms: 83.9536008958
# siéger Nombre de cliques 1246
# no new faithfull clique, the previous one contained 23 forms
# différer Nombre de cliques 1381
# max score among faithfull cliques of 27 forms: 219.253257527
# transporter Nombre de cliques 1137
# max score among faithfull cliques of 27 forms: 242.392312354
# mirer Nombre de cliques 1120
# max score among faithfull cliques of 27 forms: 243.504020993
# paralléliser Nombre de cliques 1461
# max score among faithfull cliques of 26 forms: 214.009585398
# remparer Nombre de cliques 1107
# max score among faithfull cliques of 27 forms: 243.645345743
# gourer Nombre de cliques 1139
# max score among faithfull cliques of 27 forms: 245.423720857
# psalmodier Nombre de cliques 1709
# max score among faithfull cliques of 21 forms: 80.1288376543
# malmener Nombre de cliques 1529
# max score among faithfull cliques of 14 forms: 34.8031166415
# sniffer Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# frire Nombre de cliques 1153
# max score among faithfull cliques of 22 forms: 91.5484733761
# cravater Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 244.704948972
# doter Nombre de cliques 1278
# max score among faithfull cliques of 27 forms: 239.686521711
# retéléphoner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# transcoder Nombre de cliques 1379
# max score among faithfull cliques of 27 forms: 236.418720025
# polluer Nombre de cliques 1415
# max score among faithfull cliques of 20 forms: 105.678915944
# baller Nombre de cliques 1234
# max score among faithfull cliques of 27 forms: 242.94044586
# perquisitionner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# décoder Nombre de cliques 1351
# max score among faithfull cliques of 26 forms: 217.56521522
# calomnier Nombre de cliques 1120
# max score among faithfull cliques of 22 forms: 77.7696813401
# truquer Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# caviarder Nombre de cliques 1237
# max score among faithfull cliques of 27 forms: 246.066638818
# jardiner Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# fatiguer Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# chalouper Nombre de cliques 1185
# max score among faithfull cliques of 27 forms: 248.374629528
# élucubrer Nombre de cliques 1018
# max score among faithfull cliques of 27 forms: 244.381373788
# avoyer Nombre de cliques 1458
# max score among faithfull cliques of 20 forms: 72.0837789734
# bluffer Nombre de cliques 1836
# max score among faithfull cliques of 17 forms: 74.795431615
# emmerder Nombre de cliques 1238
# max score among faithfull cliques of 27 forms: 246.066638818
# enluminer Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# échauffer Nombre de cliques 1236
# max score among faithfull cliques of 27 forms: 240.169525284
# zozoter Nombre de cliques 1261
# max score among faithfull cliques of 27 forms: 237.940308081
# distraire Nombre de cliques 1222
# max score among faithfull cliques of 13 forms: 36.4124412193
# rasséréner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 227.850117518
# thermoformer Nombre de cliques 1131
# max score among faithfull cliques of 27 forms: 244.997215633
# chapeauter Nombre de cliques 1244
# max score among faithfull cliques of 26 forms: 219.812502338
# fricoter Nombre de cliques 1278
# max score among faithfull cliques of 27 forms: 239.686521711
# surpayer Nombre de cliques 1716
# no new faithfull clique, the previous one contained 20 forms
# prévoir Nombre de cliques 958
# max score among faithfull cliques of 7 forms: 11.5505663998
# soupçonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# idiotiser Nombre de cliques 1492
# no new faithfull clique, the previous one contained 24 forms
# besogner Nombre de cliques 1139
# max score among faithfull cliques of 24 forms: 178.979884844
# phosphater Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 244.704948972
# pulvériser Nombre de cliques 1517
# no new faithfull clique, the previous one contained 24 forms
# nieller Nombre de cliques 1240
# no new faithfull clique, the previous one contained 22 forms
# axer Nombre de cliques 1430
# max score among faithfull cliques of 27 forms: 205.348945769
# rocher Nombre de cliques 1209
# max score among faithfull cliques of 26 forms: 217.91720957
# tabuler Nombre de cliques 1143
# max score among faithfull cliques of 27 forms: 245.709663656
# syndiquer Nombre de cliques 1148
# max score among faithfull cliques of 27 forms: 245.134793499
# calandrer Nombre de cliques 1071
# max score among faithfull cliques of 27 forms: 244.098123259
# volter Nombre de cliques 1119
# max score among faithfull cliques of 27 forms: 242.980014978
# ahurir Nombre de cliques 855
# max score among faithfull cliques of 22 forms: 94.8846812376
# décolleter Nombre de cliques 1084
# no new faithfull clique, the previous one contained 16 forms
# moirer Nombre de cliques 1111
# max score among faithfull cliques of 27 forms: 241.897502683
# affoler Nombre de cliques 1259
# max score among faithfull cliques of 27 forms: 236.844350736
# renoncer Nombre de cliques 1440
# max score among faithfull cliques of 27 forms: 211.605379725
# flûter Nombre de cliques 1188
# max score among faithfull cliques of 27 forms: 248.413041514
# imiter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# fayoter Nombre de cliques 1261
# max score among faithfull cliques of 27 forms: 237.940308081
# fomenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# dérougir Nombre de cliques 1502
# max score among faithfull cliques of 21 forms: 85.4997514491
# désaffectionner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# poursuivre Nombre de cliques 928
# max score among faithfull cliques of 9 forms: 19.8193773308
# vitrifier Nombre de cliques 1520
# max score among faithfull cliques of 22 forms: 89.745516734
# impacter Nombre de cliques 1179
# max score among faithfull cliques of 27 forms: 245.60098806
# jongler Nombre de cliques 1138
# max score among faithfull cliques of 27 forms: 245.378461898
# serpenter Nombre de cliques 1177
# max score among faithfull cliques of 27 forms: 248.731848197
# réconcilier Nombre de cliques 1095
# max score among faithfull cliques of 22 forms: 82.5176248367
# tiser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# gifler Nombre de cliques 1205
# max score among faithfull cliques of 24 forms: 183.432327623
# inverser Nombre de cliques 1432
# max score among faithfull cliques of 27 forms: 211.605379725
# empreindre Nombre de cliques 516
# max score among faithfull cliques of 14 forms: 48.4374119014
# interloquer Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# endetter Nombre de cliques 1419
# no new faithfull clique, the previous one contained 24 forms
# prodiguer Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# opposer Nombre de cliques 1486
# max score among faithfull cliques of 26 forms: 211.713739931
# défoncer Nombre de cliques 1440
# max score among faithfull cliques of 27 forms: 211.605379725
# limoger Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# feutrer Nombre de cliques 1013
# max score among faithfull cliques of 27 forms: 245.669032791
# consoler Nombre de cliques 1259
# max score among faithfull cliques of 27 forms: 236.844350736
# scratcher Nombre de cliques 1139
# max score among faithfull cliques of 27 forms: 248.619371207
# flaquer Nombre de cliques 1366
# max score among faithfull cliques of 27 forms: 245.218179717
# soutenir Nombre de cliques 262
# max score among faithfull cliques of 11 forms: 46.6637442427
# ambrer Nombre de cliques 1071
# max score among faithfull cliques of 27 forms: 244.098123259
# réalimenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# sanctifier Nombre de cliques 1520
# max score among faithfull cliques of 22 forms: 89.745516734
# inciter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# déchiqueter Nombre de cliques 1184
# max score among faithfull cliques of 27 forms: 241.774149006
# grognonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# nettoyer Nombre de cliques 1380
# max score among faithfull cliques of 18 forms: 51.8014336768
# repartager Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 246.258534002
# maugréer Nombre de cliques 750
# max score among faithfull cliques of 25 forms: 197.94176091
# épousseter Nombre de cliques 1478
# max score among faithfull cliques of 20 forms: 106.864116464
# encarter Nombre de cliques 1191
# max score among faithfull cliques of 27 forms: 248.413041514
# coordonner Nombre de cliques 1526
# max score among faithfull cliques of 19 forms: 81.9564105044
# fleurdeliser Nombre de cliques 1026
# no new faithfull clique, the previous one contained 17 forms
# loufer Nombre de cliques 1152
# max score among faithfull cliques of 27 forms: 248.575134996
# admirer Nombre de cliques 731
# max score among faithfull cliques of 27 forms: 242.596157732
# déviriliser Nombre de cliques 1476
# max score among faithfull cliques of 26 forms: 214.009585398
# décloisonner Nombre de cliques 1219
# ...
# no new faithfull clique, the previous one contained 24 forms
# asphyxier Nombre de cliques 1429
# max score among faithfull cliques of 21 forms: 85.7959283689
# africaniser Nombre de cliques 1498
# no new faithfull clique, the previous one contained 25 forms
# englober Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# escarper Nombre de cliques 1186
# max score among faithfull cliques of 27 forms: 248.709701159
# câliner Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# permanenter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.413041514
# enclore Nombre de cliques 448
# max score among faithfull cliques of 3 forms: 3.45887654478
# oraliser Nombre de cliques 1478
# max score among faithfull cliques of 26 forms: 214.009585398
# infléchir Nombre de cliques 1361
# max score among faithfull cliques of 21 forms: 83.9900052475
# assécher Nombre de cliques 1209
# max score among faithfull cliques of 27 forms: 224.806006039
# propager Nombre de cliques 1135
# max score among faithfull cliques of 27 forms: 245.218179717
# veiller Nombre de cliques 1812
# no new faithfull clique, the previous one contained 21 forms
# caracoler Nombre de cliques 1234
# max score among faithfull cliques of 26 forms: 218.202588348
# parachever Nombre de cliques 1561
# no new faithfull clique, the previous one contained 10 forms
# élaguer Nombre de cliques 1100
# max score among faithfull cliques of 27 forms: 245.687122845
# chuter Nombre de cliques 1188
# max score among faithfull cliques of 27 forms: 248.413041514
# départir Nombre de cliques 806
# max score among faithfull cliques of 14 forms: 35.8698662661
# tressaillir Nombre de cliques 1544
# max score among faithfull cliques of 14 forms: 29.3794228169
# juger Nombre de cliques 1151
# max score among faithfull cliques of 27 forms: 248.674574715
# connoter Nombre de cliques 1261
# max score among faithfull cliques of 27 forms: 237.940308081
# désapprendre Nombre de cliques 1187
# max score among faithfull cliques of 7 forms: 8.70349335465
# voltiger Nombre de cliques 1153
# max score among faithfull cliques of 27 forms: 249.038634561
# dynamiser Nombre de cliques 1502
# no new faithfull clique, the previous one contained 24 forms
# délabrer Nombre de cliques 1071
# max score among faithfull cliques of 27 forms: 244.098123259
# pomponner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# désexualiser Nombre de cliques 1478
# max score among faithfull cliques of 26 forms: 214.009585398
# prélaver Nombre de cliques 1652
# no new faithfull clique, the previous one contained 23 forms
# raisonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# insurger Nombre de cliques 1124
# max score among faithfull cliques of 27 forms: 245.012991625
# graveler Nombre de cliques 1621
# max score among faithfull cliques of 21 forms: 118.518472351
# réengager Nombre de cliques 1135
# max score among faithfull cliques of 27 forms: 245.218179717
# spammer Nombre de cliques 1132
# max score among faithfull cliques of 27 forms: 244.969493376
# louper Nombre de cliques 1150
# max score among faithfull cliques of 27 forms: 245.159354198
# corser Nombre de cliques 1422
# max score among faithfull cliques of 27 forms: 208.749290373
# anodiser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# thésauriser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# rebaisser Nombre de cliques 1550
# no new faithfull clique, the previous one contained 24 forms
# friponner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# obscurcir Nombre de cliques 1679
# max score among faithfull cliques of 22 forms: 89.3367915195
# lorgner Nombre de cliques 723
# max score among faithfull cliques of 25 forms: 215.347090452
# claironner Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# pédaler Nombre de cliques 1234
# max score among faithfull cliques of 27 forms: 242.94044586
# terroriser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 24 forms
# désengourdir Nombre de cliques 1159
# max score among faithfull cliques of 22 forms: 93.1498141914
# accabler Nombre de cliques 1205
# max score among faithfull cliques of 24 forms: 183.432327623
# insupporter Nombre de cliques 1191
# max score among faithfull cliques of 27 forms: 248.413041514
# ennoblir Nombre de cliques 1342
# max score among faithfull cliques of 22 forms: 94.5297134514
# goûter Nombre de cliques 1195
# max score among faithfull cliques of 27 forms: 248.078061513
# pitonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# départager Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 246.258534002
# désaliniser Nombre de cliques 1497
# no new faithfull clique, the previous one contained 24 forms
# repiquer Nombre de cliques 1148
# max score among faithfull cliques of 27 forms: 245.134793499
# froisser Nombre de cliques 1496
# no new faithfull clique, the previous one contained 23 forms
# subvenir Nombre de cliques 1786
# max score among faithfull cliques of 12 forms: 29.655283497
# merdoyer Nombre de cliques 1642
# no new faithfull clique, the previous one contained 16 forms
# resituer Nombre de cliques 1781
# max score among faithfull cliques of 20 forms: 120.210680794
# inhumer Nombre de cliques 1106
# max score among faithfull cliques of 27 forms: 245.699376027
# rogner Nombre de cliques 1139
# max score among faithfull cliques of 26 forms: 217.743232022
# préparer Nombre de cliques 1073
# max score among faithfull cliques of 27 forms: 239.103889653
# modérer Nombre de cliques 1380
# max score among faithfull cliques of 27 forms: 222.685237896
# sauter Nombre de cliques 1261
# max score among faithfull cliques of 27 forms: 237.940308081
# resurgir Nombre de cliques 1349
# max score among faithfull cliques of 22 forms: 91.7820639281
# ratonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# dévaluer Nombre de cliques 1828
# max score among faithfull cliques of 20 forms: 117.274278398
# brumer Nombre de cliques 1141
# max score among faithfull cliques of 27 forms: 248.894685693
# gruger Nombre de cliques 1118
# max score among faithfull cliques of 27 forms: 245.803712912
# décapoter Nombre de cliques 1278
# max score among faithfull cliques of 27 forms: 239.686521711
# émacier Nombre de cliques 1697
# max score among faithfull cliques of 21 forms: 86.1286801883
# ébaucher Nombre de cliques 1262
# max score among faithfull cliques of 27 forms: 239.877542637
# remonter Nombre de cliques 1194
# max score among faithfull cliques of 27 forms: 248.413041514
# bander Nombre de cliques 1218
# max score among faithfull cliques of 27 forms: 246.066638818
# réhabiliter Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.406936488
# catéchiser Nombre de cliques 1483
# no new faithfull clique, the previous one contained 25 forms
# gargouiller Nombre de cliques 1681
# max score among faithfull cliques of 24 forms: 152.045300338
# parapher Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 246.258534002
# appauvrir Nombre de cliques 1380
# max score among faithfull cliques of 22 forms: 88.1028084416
# crier Nombre de cliques 1020
# max score among faithfull cliques of 16 forms: 52.4947724659
# ragoûter Nombre de cliques 1212
# max score among faithfull cliques of 27 forms: 247.828779152
# riveter Nombre de cliques 1226
# max score among faithfull cliques of 20 forms: 121.541786883
# rouvrir Nombre de cliques 844
# max score among faithfull cliques of 15 forms: 29.6828698242
# amalgamer Nombre de cliques 815
# max score among faithfull cliques of 27 forms: 255.82917783
# contredire Nombre de cliques 1099
# max score among faithfull cliques of 15 forms: 37.585800157
# trouilloter Nombre de cliques 1353
# no new faithfull clique, the previous one contained 17 forms
# camer Nombre de cliques 1132
# max score among faithfull cliques of 27 forms: 244.969493376
# chorégraphier Nombre de cliques 1526
# max score among faithfull cliques of 22 forms: 92.1460744283
# recenser Nombre de cliques 1430
# max score among faithfull cliques of 27 forms: 211.605379725
# prosodier Nombre de cliques 1004
# max score among faithfull cliques of 21 forms: 107.882917324
# caillasser Nombre de cliques 1442
# max score among faithfull cliques of 26 forms: 194.16493846
# ravager Nombre de cliques 1135
# max score among faithfull cliques of 27 forms: 245.218179717
# râper Nombre de cliques 1177
# max score among faithfull cliques of 27 forms: 244.78298426
# fagoter Nombre de cliques 1297
# max score among faithfull cliques of 17 forms: 96.1466416207
# représenter Nombre de cliques 1000
# max score among faithfull cliques of 27 forms: 247.292851848
# électrolyser Nombre de cliques 1476
# max score among faithfull cliques of 26 forms: 214.009585398
# accentuer Nombre de cliques 1622
# max score among faithfull cliques of 20 forms: 119.918516593
# déterrer Nombre de cliques 1259
# max score among faithfull cliques of 27 forms: 222.362273969
# boumer Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 243.164588176
# crouler Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 247.222661801
# espacer Nombre de cliques 1422
# max score among faithfull cliques of 26 forms: 193.10924904
# indemniser Nombre de cliques 1492
# no new faithfull clique, the previous one contained 24 forms
# quémander Nombre de cliques 1218
# max score among faithfull cliques of 27 forms: 246.066638818
# joncher Nombre de cliques 1155
# max score among faithfull cliques of 27 forms: 248.679309212
# miauler Nombre de cliques 1259
# max score among faithfull cliques of 27 forms: 236.844350736
# miner Nombre de cliques 856
# max score among faithfull cliques of 27 forms: 241.581859615
# piétiner Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# ratiboiser Nombre de cliques 1488
# max score among faithfull cliques of 26 forms: 215.58989929
# remplier Nombre de cliques 988
# max score among faithfull cliques of 9 forms: 9.49583953945
# décompresser Nombre de cliques 1500
# no new faithfull clique, the previous one contained 24 forms
# bouturer Nombre de cliques 1123
# max score among faithfull cliques of 27 forms: 247.153166664
# investir Nombre de cliques 1055
# max score among faithfull cliques of 22 forms: 82.1970429599
# trachéotomiser Nombre de cliques 1507
# no new faithfull clique, the previous one contained 24 forms
# analyser Nombre de cliques 1441
# no new faithfull clique, the previous one contained 21 forms
# agrainer Nombre de cliques 1371
# no new faithfull clique, the previous one contained 22 forms
# vaquer Nombre de cliques 1366
# max score among faithfull cliques of 27 forms: 245.218179717
# cyanoser Nombre de cliques 1778
# no new faithfull clique, the previous one contained 20 forms
# linger Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# pieuter Nombre de cliques 1728
# max score among faithfull cliques of 17 forms: 83.1408063828
# ébahir Nombre de cliques 1079
# max score among faithfull cliques of 22 forms: 85.6139694381
# urger Nombre de cliques 1124
# max score among faithfull cliques of 27 forms: 245.012991625
# rencaisser Nombre de cliques 1550
# no new faithfull clique, the previous one contained 24 forms
# dérouiller Nombre de cliques 1705
# max score among faithfull cliques of 25 forms: 164.764291616
# sursignifier Nombre de cliques 1520
# max score among faithfull cliques of 22 forms: 93.6840303329
# ressurgir Nombre de cliques 1494
# max score among faithfull cliques of 22 forms: 88.8859659638
# halener Nombre de cliques 1199
# max score among faithfull cliques of 27 forms: 224.800095893
# numériser Nombre de cliques 1512
# no new faithfull clique, the previous one contained 24 forms
# ingénier Nombre de cliques 1441
# max score among faithfull cliques of 22 forms: 100.343385865
# délustrer Nombre de cliques 1071
# max score among faithfull cliques of 27 forms: 241.122559812
# approuver Nombre de cliques 1763
# no new faithfull clique, the previous one contained 23 forms
# défroquer Nombre de cliques 1183
# max score among faithfull cliques of 26 forms: 218.208791691
# chuchoter Nombre de cliques 1278
# max score among faithfull cliques of 27 forms: 239.686521711
# missionner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# volatiliser Nombre de cliques 1476
# max score among faithfull cliques of 26 forms: 214.009585398
# frauder Nombre de cliques 1890
# max score among faithfull cliques of 19 forms: 74.643241857
# déminer Nombre de cliques 1126
# max score among faithfull cliques of 27 forms: 245.007206939
# recontacter Nombre de cliques 1184
# max score among faithfull cliques of 27 forms: 241.774149006
# reboucler Nombre de cliques 1133
# max score among faithfull cliques of 27 forms: 246.634128647
# fourgonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# mailer Nombre de cliques 1168
# max score among faithfull cliques of 27 forms: 245.008273846
# refouler Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 247.222661801
# déconseiller Nombre de cliques 1750
# no new faithfull clique, the previous one contained 20 forms
# répercuter Nombre de cliques 1178
# max score among faithfull cliques of 27 forms: 246.548460358
# précéder Nombre de cliques 1146
# max score among faithfull cliques of 27 forms: 214.19308633
# fourrager Nombre de cliques 1135
# max score among faithfull cliques of 27 forms: 245.218179717
# marier Nombre de cliques 1240
# no new faithfull clique, the previous one contained 13 forms
# faillir Nombre de cliques 1072
# max score among faithfull cliques of 20 forms: 76.3758659996
# interchanger Nombre de cliques 1134
# max score among faithfull cliques of 27 forms: 248.91046304
# chigner Nombre de cliques 1095
# max score among faithfull cliques of 27 forms: 245.364243634
# épointer Nombre de cliques 1194
# max score among faithfull cliques of 27 forms: 248.413041514
# repentir Nombre de cliques 907
# max score among faithfull cliques of 12 forms: 24.4445422076
# autolimiter Nombre de cliques 1206
# max score among faithfull cliques of 27 forms: 248.548926458
# jumeler Nombre de cliques 865
# max score among faithfull cliques of 21 forms: 144.285524062
# dédicacer Nombre de cliques 1443
# max score among faithfull cliques of 26 forms: 192.703226012
# poudroyer Nombre de cliques 1834
# no new faithfull clique, the previous one contained 18 forms
# paginer Nombre de cliques 1136
# max score among faithfull cliques of 27 forms: 248.904358015
# plaquer Nombre de cliques 1366
# max score among faithfull cliques of 27 forms: 245.218179717
# réépouser Nombre de cliques 1504
# no new faithfull clique, the previous one contained 23 forms
# démilitariser Nombre de cliques 1505
# no new faithfull clique, the previous one contained 25 forms
# démarier Nombre de cliques 1462
# max score among faithfull cliques of 22 forms: 96.3573962373
# importuner Nombre de cliques 1099
# max score among faithfull cliques of 27 forms: 245.715347629
# pérorer Nombre de cliques 1199
# max score among faithfull cliques of 26 forms: 218.139343689
# conspirer Nombre de cliques 1125
# max score among faithfull cliques of 27 forms: 247.569298957
# atterrir Nombre de cliques 1118
# max score among faithfull cliques of 20 forms: 79.4242014173
# raidir Nombre de cliques 1511
# max score among faithfull cliques of 21 forms: 83.5000749813
# aviser Nombre de cliques 1493
# no new faithfull clique, the previous one contained 24 forms
# tranquilliser Nombre de cliques 1476
# max score among faithfull cliques of 26 forms: 214.009585398
# décrire Nombre de cliques 1273
# max score among faithfull cliques of 10 forms: 16.0758042682
# branlocher Nombre de cliques 1245
# max score among faithfull cliques of 27 forms: 238.124535934
# militer Nombre de cliques 1189
# max score among faithfull cliques of 27 forms: 248.406936488
# piger Nombre de cliques 1148
# max score among faithfull cliques of 27 forms: 245.134793499
# évanouir Nombre de cliques 1463
# max score among faithfull cliques of 21 forms: 78.0220457326
# tonner Nombre de cliques 1219
# max score among faithfull cliques of 27 forms: 238.411833134
# CPU times: user 1h 38min 49s, sys: 3min 17s, total: 1h 42min 7s
# Wall time: 1h 44min 8s

# %%
newParadigmes,paradigmesSwim2,characteristicsSwim2,measuresSwim2=calculerResultats(swim2ContextParadigmes,"-Swim2")
# Out:
# Index([u'value', u'lexeme-case'], dtype='object')
# UG 64244 OG 40633 TP 174625 FP 24680
# recall 0.662590258358 precision 0.727792179646
# 0.693662398433

# %%
nomFichierResultats=filePrefix+"-X-Resultats.yaml"
if os.path.isfile(nomFichierResultats):
    with open(nomFichierResultats, 'r') as stream:
            resultats=yaml.load(stream)
else:
    resultats={}

if casesType:
    sampleExt=casesType
else:
    sampleExt=sampleType
sampleId=sampleNumber.strip("-")+sampleExt
resultats[sampleId]={}
resultats[sampleId]["Swim1"]={}
resultats[sampleId]["Swim1"]["UG"]=characteristicsSwim1[0]
resultats[sampleId]["Swim1"]["OG"]=characteristicsSwim1[1]
resultats[sampleId]["Swim1"]["TP"]=characteristicsSwim1[2]
resultats[sampleId]["Swim1"]["FP"]=characteristicsSwim1[3]
resultats[sampleId]["Swim1"]["Precision"]=measuresSwim1[0]
resultats[sampleId]["Swim1"]["Recall"]=measuresSwim1[1]
resultats[sampleId]["Swim1"]["F-Measure"]=measuresSwim1[2]
resultats[sampleId]["Swim2"]={}
resultats[sampleId]["Swim2"]["UG"]=characteristicsSwim2[0]
resultats[sampleId]["Swim2"]["OG"]=characteristicsSwim2[1]
resultats[sampleId]["Swim2"]["TP"]=characteristicsSwim2[2]
resultats[sampleId]["Swim2"]["FP"]=characteristicsSwim2[3]
resultats[sampleId]["Swim2"]["Precision"]=measuresSwim2[0]
resultats[sampleId]["Swim2"]["Recall"]=measuresSwim2[1]
resultats[sampleId]["Swim2"]["F-Measure"]=measuresSwim2[2]

yaml.safe_dump(resultats, file(nomFichierResultats, 'w'), encoding='utf-8', allow_unicode=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-86ec22b4798d> in <module>()
# ----> 1 nomFichierResultats=filePrefix+"-X-Resultats.yaml"
#       2 if os.path.isfile(nomFichierResultats):
#       3     with open(nomFichierResultats, 'r') as stream:
#       4             resultats=yaml.load(stream)
#       5 else:
#
# NameError: name 'filePrefix' is not defined

# %%
# %ding
# %ding

# %%
print ("Sample",sampleNumber.strip("-"))
print ("Swim1",characteristicsSwim1,measuresSwim1)
print ("Swim2",characteristicsSwim2,measuresSwim2)

# %% [markdown]
# # Fin du traitement

# %%
paradigmesSwim2.columns.tolist()[25:]

# %%
paradigmesSwim2.pc1S

# %% [markdown]
# # Calcul des distances

# %% [markdown]
# ### Préparation des fichiers de référence
# La comparaison se fait sur les lexèmes de *listeTest*
# - initialForms : les formes initiales
# - finalForms : les formes initiales plus les formes prédites
# - goldForms : les formes de référence

# %% [markdown]
# #### Formes initiales

# %% [raw]
# initialForms=pd.melt(paradigmesSample[paradigmesSample["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
# initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
#
# initialForms.set_index(["lexeme-case"],inplace=True)
#
# initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# #### Formes avec prédictions

# %% [raw]
# finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
# finalParadigmes.to_csv(path_or_buf=analysisPrefix+"-paradigmes-Swim2.csv",encoding="utf8",sep=";")
# finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
# finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
# finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
# finalTestForms.set_index(["lexeme-case"],inplace=True)

# %% [markdown]
# #### Formes de référence
# - recoder les représentations phonologiques en fonction de l'échantillon

# %% [raw]
# with open(goldPrefix+"/"+goldFile,"rb") as input:
#     lexiqueGold=pickle.load(input)
#
# lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
#
# completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
#
# goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# #goldTestForms
#
# goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
# goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
#
# goldTestForms.set_index(["lexeme-case"],inplace=True)

# %% [raw]
# #goldFormsIndex=goldForms.index.tolist()

# %% [markdown]
# ### Soustraction des formes initiales

# %% [raw]
# finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
# finalFormsIndex=finalForms.index.tolist()
# #initialForms.loc[~initialForms.index.isin(finalFormsIndex)]

# %% [raw]
# #finalForms[finalForms.index.str.contains("asseoir")]

# %% [raw]
# #goldTestForms[goldTestForms.index.str.contains("asseoir")]

# %% [raw]
# goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
# goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #goldForms[goldForms.index.str.contains("asseoir")]

# %% [raw]
# print (finalFormsIndex)
# goldForms[~goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# ### Évaluation des formes

# %% [markdown]
# #### Problèmes de génération
# - sous-génération : formes de références sans prédiction
# - sur-génération : formes prédites absentes de la référence

# %% [raw]
# underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
# overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]

# %% [markdown]
# #### Formes comparables
# - *predictedForms* => formes prédites présentes dans la référence
# - *actualForms* => formes de référence présentes dans les prédictions

# %% [raw]
# predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
# actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# #### Préparation de la comparaison
# - *compareForms* => tableau avec les formes à comparer

# %% [raw]
# compareForms=predictedForms.copy()
# compareForms.loc[:,"right"]=actualForms.loc[:,"value"]

# %% [markdown]
# #### Comparaison des formes
# - *sameForms* => formes identiques dans les prédictions et la référence
# - *diffForms* => formes différentes dans les prédictions et la référence

# %% [raw]
# sameForms=compareForms[compareForms["value"]==compareForms["right"]]
# diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

# %% [markdown]
# #### Décompte du nombre de formes
# À cause du traitement de la surabondance, le décompte des lignes ne tient pas compte du nombre de formes. Il faut compter les formes dans chaque ligne pour obtenir le nombre total.

# %% [raw]
# def countSplits(dfForms):
#     dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
#     return dfForms["split"].str.len().sum()

# %% [markdown]
# #### Évaluation des différences
# Certaines différences ne sont qu'apparentes à cause du traitement de la surabondance sous forme de chaine concaténée. Il faut transformer les surabondances en set() pour pouvoir faire une comparaison pertinente.

# %% [raw]
# def evaluateDiffForms(diffForms):
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
#
#     nbValues=diffForms["split-value"].str.len().sum()
#     nbRights=diffForms["split-right"].str.len().sum()
# #    print (nbValues,nbRights)
#
#     nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
#     nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
#
#     return (nbIdenticalSets,nbIncludedSets,(nbValues-nbIdenticalSets-nbIncludedSets),(nbRights-nbIdenticalSets-nbIncludedSets))

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus=evaluateDiffForms(diffForms)
# #evaluateDiffForms(diffForms)

# %% [markdown]
# #### Calcul des grandeurs de mesure

# %% [raw]
# UG=countSplits(underGeneration)+underBonus
# OG=countSplits(overGeneration)
# TP=countSplits(sameForms)+identicalBonus+partialBonus
# FP=wrongBonus
# recall=float(TP)/(UG+TP+FP)
# precision=float(TP)/(OG+TP+FP)
# print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
# print ("recall", recall, "precision", precision)
#
# fMeasure=2*recall*precision/(recall+precision)
# fMeasure

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus

# %% [raw]
# countSplits(underGeneration),countSplits(overGeneration),countSplits(sameForms)

# %% [markdown]
# ### Sauvegarde des résultats pour analyse ultérieure

# %% [raw]
# overGeneration.to_csv(path_or_buf=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration.to_csv(path_or_buf=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# sameForms.to_csv(path_or_buf=analysisPrefix+"-sameForms.csv",encoding="utf8")
# diffForms.to_csv(path_or_buf=analysisPrefix+"-diffForms.csv",encoding="utf8")

# %% [markdown]
# ## Analyse des sur-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# overGeneration.loc[:,"case"]=overGeneration.index.str.rsplit("-").str[-1]

# %% [raw]
# casesOverGeneration=overGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# casesOverGeneration.plot(kind="bar",figsize=(20,5))

# %% [raw]
# casesOverGeneration[:3].sum()/casesOverGeneration.sum()

# %% [markdown]
# Le facteur principal de **surgénération** est la production de **participes passés** (ppMP 662, ppFS 661, ppFP 661) pour les verbes qui n'ont qu'une seule forme de participe passé invariable (ppMS) : **54.78%** (1984/3622).

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# overGeneration.loc[:,"verbe"]=overGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesOverGeneration=overGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
# verbesOverGeneration[:54].plot(kind="bar",figsize=(20,5))

# %% [markdown]
# Le facteur principal de **surgénération** tient aux **verbes vestiges** et aux **météorologiques**.

# %% [markdown]
# ## Analyse des sous-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# underGeneration.loc[:,"case"]=underGeneration.index.str.rsplit("-",1).str[-1]

# %% [raw]
# casesUnderGeneration=underGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# ax=casesUnderGeneration[:9].plot(kind="bar",figsize=(20,5))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Verbs missing the form",fontsize=16)
# print ("Total sous-générations :",casesUnderGeneration.sum().values[0])

# %% [raw]
# def ratioAnalyses(df,chaine):
#     return df[df.index.str.contains(chaine)].sum().values[0],df.sum().values[0],(df[df.index.str.contains(chaine)].sum()/df.sum()).values[0]

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"is")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"ai")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"2P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"1P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"pi")

# %% [markdown]
# Le facteur principal de **sous-génération** est lié à la fréquence des TAM et de certaines personnes :
# - TAM :
#  - imparfait du subjonctif 45.98% (7875/17126)
#  - passé simple 12.70% (2176/17126)
# - Personnes :
#  - 2PL 46.11% (7897/17126)
#  - 1PL 32.98% (5649/17126)

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# underGeneration.loc[:,"verbe"]=underGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesUnderGeneration=underGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
#
# ax=verbesUnderGeneration[:50].plot(kind="bar",figsize=(40,5))
# ax.set_xlabel("Verbes",fontsize=16)
# ax.set_ylabel("Number of Missing Forms",fontsize=16)

# %% [markdown]
# # Fin de l'analyse des résultats

# %% [raw]
# overGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# goodForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-goodForms.csv",encoding="utf8")
# wrongForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-wrongForms.csv",encoding="utf8")

# %% [raw]
# len(overGeneration), len(underGeneration), len(goodForms), len(wrongForms)

# %% [raw]
# wrongForms["rightChecked"]=wrongForms["right"].apply(checkFrench)
# wrongForms["valueChecked"]=wrongForms["value"].apply(checkFrench)

# %% [raw]
# wrongForms[wrongForms["valueChecked"]!=wrongForms["rightChecked"]]

# %% [raw]
# goodForms[goodForms["value"].str.contains(",")]

# %% [raw]
# set(overGeneration["lexeme-case"].str.rsplit("-").str[0].tolist())

# %% [raw]
# underGeneration["case"]=underGeneration["lexeme-case"].str.rsplit("-").str[-1]

# %% [raw]
# underGeneration.groupby("case").count()["value"].sort_values(ascending=False)

# %% [raw]
# finalParadigmes=extendParadigmes(savedContextParadigmes,extendMorphomes=True)

# %% [raw]
# test["ppMS"]

# %% [raw]
# def repairContextParadigmes(contextParadigmes):
#     repaired={}
#     for sCP in contextParadigmes.keys():
#     #    noLexeme=False
#         repaired[sCP]=[]
#         for numClique,clique in enumerate(contextParadigmes[sCP]):
#             repaired[sCP].append(clique)
#     #        noLexemeElements=[]
#     #        withLexemeElements=[]
#             for numElement,element in enumerate(clique):
#                 if not len(element.split("-"))>2 or not element.startswith(sCP):
#                     print (sCP+"-"+element)
#                     repaired[sCP][numClique][numElement]=sCP+"-"+element
#     #                noLexemeElements.append(element)
#     #            else:
#     #                withLexemeElements.append(element)
#     #        if noLexemeElements:
#     #            print (sCP)
#     #            print (noLexemeElements)
#     #            print (withLexemeElements)
#     #            print ()
#     #        noLexeme=False
#     return repaired

# %% [raw]
# repairContextParadigmes(contextParadigmes)[u"féminiser"]

# %% [markdown]
# ### Test de la sauvegarde de l'analyse brute

# %% [markdown]
# ## with open(analysisPrefix+"-analyseParadigmes.pkl","rb") as input:
#     savedAnalyseParadigmes = pickle.load(input)

# %% [raw]
# savedContextParadigmes=savedAnalyseParadigmes[0]
# savedCliques=savedAnalyseParadigmes[1]
# savedCliquesScores=savedAnalyseParadigmes[2]
# savedCliquesListes=savedAnalyseParadigmes[3]
# #savedFormesScores=savedAnalyseParadigmes[4]
# #savedFormesScoresNormes=savedAnalyseParadigmes[5]

# %% [raw]
# generateForms(u"crépir",contextFree=True).formes

# %% [raw]
# if genFormeVotes:
#     fScores=(formesScores,formesScoresNormes)
#     with open(analysisPrefix+paperPrefix+'-Scores.pkl', 'wb') as output:
#         pickle.dump(fScores, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# %%time
# versionStamp=dateheure()
# if genDigraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globDigraphe,analysisPrefix+paperPrefix+u"-digraphe-%s.gexf"%versionStamp)
# if genGraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globGraphe,analysisPrefix+paperPrefix+u"-graphe-%s.gexf"%versionStamp)

# %% [raw]
# print (len(cliques))

# %% [raw]
# if genCliques:
#     infoCliques={"cliques":cliques, "cliquesScores":cliquesScores, "cliquesListes":cliquesListes}
#     with open(analysisPrefix+paperPrefix+'-Network.pkl', 'wb') as output:
#         pickle.dump(infoCliques, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# print (paradigmes[paradigmes["lexeme"]==lexeme].to_latex(na_rep=""))

# %% [raw]
# HTML(makeTable(dictParadigmes[lexeme],title=lexeme))

# %% [raw]
# print (len(sampleCases),sampleCases,paradigmes["lexeme"].count())
# nbCoformes=paradigmes.notnull().sum(axis=1)-1
# distNbCoformes=nbCoformes.groupby(by=nbCoformes).count()
# ax=distNbCoformes.plot(kind="bar",legend=False,grid=True,figsize=(10,3))
# ax.set(xlim=(-0.5,32),ylim=(0,600))
# ax.set_xlabel("Number of Co-Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["lexeme"]==u"être") & (sampleTirage["tir1"]!=0)]

# %% [raw]
# freqCasesSampleTirage=sampleTirage[sampleTirage["tir1"]!=0].groupby("case")[["lexeme"]].count().sort_values("lexeme",ascending=False)
# ax=freqCasesSampleTirage.plot(kind="bar",legend=False,grid=True,figsize=(10,5))
# ax.set(xlim=(-0.5,32.5),ylim=(0,5000))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# coFormes=paradigmes.copy()
# coFormes["nbCoformes"]=coFormes.notnull().sum(axis=1)-1
# singletonLexemes=coFormes[coFormes["nbCoformes"]==1]["lexeme"].tolist()
# print (coFormes["nbCoformes"].sum(),len(singletonLexemes))

# %% [raw]
# freqCaseSingleton=sampleTirage[(sampleTirage["tir1"]!=0) & (sampleTirage["lexeme"].isin(singletonLexemes))][["case","morphome"]].groupby("case").count()
# ax=freqCaseSingleton.sort_values("morphome",ascending=False).plot(kind="bar",legend=False,grid=True,figsize=(8,3))
# ax.set(xlim=(-0.25,17),ylim=(0,200))
# ax.set_xlabel("Isolated Form",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["tir1"]!=0)]["tir1"].sum()

# %% [raw]
# recoder("degrosirje")

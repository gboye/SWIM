# %%
import pandas as pd
import numpy as np

# %%
repL4L="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/L4L/"
fL4L=repL4L+"L4L-paradigmes.csv"
fL4LHead=repL4L+"L4L-paradigmes-head.csv"
fL4LTail=repL4L+"L4L-paradigmes-tail.csv"
fHead=repL4L+"L4L_verbesMED+.csv"
fTail=repL4L+"L4L_verbesMED-.csv"

# %%
dfTotal=pd.read_csv(fL4L,sep=";")
dfTotal.head()
# Out:
#    0       lexeme     pP      pI1P ps1S ps1P  ps3P ps3S pc2S pc2P  ...  \
# 0  1      gauchir    NaN       NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 1  2       évider  Evidâ       NaN  NaN  NaN  Evid  NaN  NaN  NaN  ...
# 2  3  réinstaller    NaN  rEêstalô  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 3  4        caner    NaN      kanô  NaN  NaN   NaN  NaN  NaN  NaN  ...
# 4  5       tancer    NaN       NaN  NaN  NaN   NaN  NaN  NaN  NaN  ...
#
#        ppMP     pi2S      ppMS is3P is1P is1S        fi1S        fi1P fi3P  \
# 0      gOSi      NaN      gOSi  NaN  NaN  NaN         NaN         NaN  NaN
# 1     Evide     Evid     Evide  NaN  NaN  NaN         NaN     Evid6rô  NaN
# 2  rEêstale  rEêstal  rEêstale  NaN  NaN  NaN  rEêstal6rE  rEêstal6rô  NaN
# 3      kane      kan      kane  NaN  NaN  NaN         NaN         NaN  NaN
# 4      tâse      NaN       NaN  NaN  NaN  NaN         NaN         NaN  NaN
#
#   fi3S
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 53 columns]

# %%
# %store -r mapCols

# %%
if mapCols:
    colsMap={v:k for k,v in mapCols.iteritems()}
    maps=True
else:
    maps=False
colsMap
# Out:
# {'0': '0',
#  'ai1P': 'pst.1pl',
#  'ai1S': 'pst.1sg',
#  'ai2P': 'pst.2pl',
#  'ai2S': 'pst.2sg',
#  'ai3P': 'pst.3pl',
#  'ai3S': 'pst.3sg',
#  'fi1P': 'fut.1pl',
#  'fi1S': 'fut.1sg',
#  'fi2P': 'fut.2pl',
#  'fi2S': 'fut.2sg',
#  'fi3P': 'fut.3pl',
#  'fi3S': 'fut.3sg',
#  'ii1P': 'ipfv.1pl',
#  'ii1S': 'ipfv.1sg',
#  'ii2P': 'ipfv.2pl',
#  'ii2S': 'ipfv.2sg',
#  'ii3P': 'ipfv.3pl',
#  'ii3S': 'ipfv.3sg',
#  'inf': 'inf',
#  'is1P': 'pst.sbjv.1pl',
#  'is1S': 'pst.sbjv.1sg',
#  'is2P': 'pst.sbjv.2pl',
#  'is2S': 'pst.sbjv.2sg',
#  'is3P': 'pst.sbjv.3pl',
#  'is3S': 'pst.sbjv.3sg',
#  'lexeme': 'lexeme',
#  'pI1P': 'imp.1pl',
#  'pI2P': 'imp.2pl',
#  'pI2S': 'imp.2sg',
#  'pP': 'prs.ptcp',
#  'pc1P': 'cond.1pl',
#  'pc1S': 'cond.1sg',
#  'pc2P': 'cond.2pl',
#  'pc2S': 'cond.2sg',
#  'pc3P': 'cond.3pl',
#  'pc3S': 'cond.3sg',
#  'pi1P': 'prs.1pl',
#  'pi1S': 'prs.1sg',
#  'pi2P': 'prs.2pl',
#  'pi2S': 'prs.2sg',
#  'pi3P': 'prs.3pl',
#  'pi3S': 'prs.3sg',
# ...

# %%
cols=dfTotal.columns.tolist()
print cols
print len(cols)-2
# Out:
# ['0', 'lexeme', 'pP', 'pI1P', 'ps1S', 'ps1P', 'ps3P', 'ps3S', 'pc2S', 'pc2P', 'ii3P', 'inf', 'ii3S', 'ai2P', 'ai2S', 'is2P', 'pi1P', 'pi1S', 'pi3P', 'ii1S', 'ii1P', 'is2S', 'pi3S', 'fi2S', 'fi2P', 'pI2S', 'pI2P', 'ps2S', 'ps2P', 'ppFS', 'ppFP', 'pc1S', 'pc1P', 'ai1P', 'pc3P', 'pc3S', 'ai1S', 'is3S', 'ii2S', 'ai3S', 'ai3P', 'ii2P', 'pi2P', 'ppMP', 'pi2S', 'ppMS', 'is3P', 'is1P', 'is1S', 'fi1S', 'fi1P', 'fi3P', 'fi3S']
# 51

# %%
def copierL4L(row):
    lexeme=row.lexeme
    result=row
    for c in cols:
        if maps: cc=colsMap[c]
        else: cc=c
        # if row[cc]=="ABS":
        #     l4lForm=dfTotal[dfTotal.lexeme==lexeme][c].values[0]
        #     if l4lForm=="#DEF#":
        #         print lexeme,c,cc,"ABS-DEF"
        #         result[cc]=np.nan
        #     else:
        #         result[cc]=dfTotal[dfTotal.lexeme==lexeme][c].values[0]
        # elif row[cc]=="#DEF#":
        #     print lexeme,c,cc,"DEF"
        #     result[cc]=np.nan
        # else:
        if row[cc]==row[cc]:
            l4lForm=dfTotal[dfTotal.lexeme==lexeme][c].values[0]
            result[cc]=l4lForm
    return result

# %% [markdown]
# ### Traitement Head

# %%
dfHead=pd.read_csv(fHead,sep=";")
dfHead.head()
# Out:
#    0       lexeme prs.ptcp imp.1pl sbjv.1sg sbjv.1pl sbjv.3pl sbjv.3sg  \
# 0  1      gauchir      NaN     NaN      NaN      NaN      NaN      NaN
# 1  2       évider   Evidɑ̃     NaN      NaN      NaN      NaN      NaN
# 2  3  réinstaller      NaN     NaN      NaN      NaN      NaN      NaN
# 3  4        caner      NaN     NaN      NaN      NaN      NaN      NaN
# 4  5       tancer      NaN     NaN      NaN      NaN      NaN      NaN
#
#   cond.2sg cond.2pl  ... pst.ptcp.m.pl prs.2sg pst.ptcp.m.sg pst.sbjv.3pl  \
# 0      NaN      NaN  ...           NaN     NaN           NaN          NaN
# 1      NaN      NaN  ...           NaN     NaN         Evide          NaN
# 2      NaN      NaN  ...           NaN     NaN     ʁEɛ̃stale          NaN
# 3      NaN      NaN  ...           NaN     NaN           ABS          NaN
# 4      NaN      NaN  ...           NaN     NaN           NaN          NaN
#
#   pst.sbjv.1pl pst.sbjv.1sg fut.1sg fut.1pl fut.3pl fut.3sg
# ...

# %%
dfHeadL4L=dfHead.apply(copierL4L,axis=1)
dfHeadL4L.head()
# Out:
#    0       lexeme prs.ptcp imp.1pl sbjv.1sg sbjv.1pl sbjv.3pl sbjv.3sg  \
# 0  1      gauchir      NaN     NaN      NaN      NaN      NaN      NaN
# 1  2       évider    Evidâ     NaN      NaN      NaN      NaN      NaN
# 2  3  réinstaller      NaN     NaN      NaN      NaN      NaN      NaN
# 3  4        caner      NaN     NaN      NaN      NaN      NaN      NaN
# 4  5       tancer      NaN     NaN      NaN      NaN      NaN      NaN
#
#   cond.2sg cond.2pl  ... pst.ptcp.m.pl prs.2sg pst.ptcp.m.sg pst.sbjv.3pl  \
# 0      NaN      NaN  ...           NaN     NaN           NaN          NaN
# 1      NaN      NaN  ...           NaN     NaN         Evide          NaN
# 2      NaN      NaN  ...           NaN     NaN      rEêstale          NaN
# 3      NaN      NaN  ...           NaN     NaN          kane          NaN
# 4      NaN      NaN  ...           NaN     NaN           NaN          NaN
#
#   pst.sbjv.1pl pst.sbjv.1sg fut.1sg fut.1pl fut.3pl fut.3sg
# ...

# %%
newCols=[mapCols[c] for c in dfHeadL4L.columns]
newCols
# Out:
# ['0',
#  'lexeme',
#  'pP',
#  'pI1P',
#  'ps1S',
#  'ps1P',
#  'ps3P',
#  'ps3S',
#  'pc2S',
#  'pc2P',
#  'ii3P',
#  'inf',
#  'ii3S',
#  'ai2P',
#  'ai2S',
#  'is2P',
#  'pi1P',
#  'pi1S',
#  'pi3P',
#  'ii1S',
#  'ii1P',
#  'is2S',
#  'pi3S',
#  'fi2S',
#  'fi2P',
#  'pI2S',
#  'pI2P',
#  'ps2S',
#  'ps2P',
#  'ppFS',
#  'ppFP',
#  'pc1S',
#  'pc1P',
#  'ai1P',
#  'pc3P',
#  'pc3S',
#  'ai1S',
#  'is3S',
#  'ii2S',
#  'ai3S',
#  'ai3P',
#  'ii2P',
#  'pi2P',
#  'ppMP',
#  'pi2S',
#  'ppMS',
#  'is3P',
#  'is1P',
#  'is1S',
#  'fi1S',
#  'fi1P',
#  'fi3P',
#  'fi3S']

# %%
dfHeadL4L.columns=newCols
dfHeadL4L.head()
# Out:
#    0       lexeme     pP pI1P ps1S ps1P ps3P ps3S pc2S pc2P  ... ppMP pi2S  \
# 0  1      gauchir    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 1  2       évider  Evidâ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 2  3  réinstaller    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 3  4        caner    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
# 4  5       tancer    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN
#
#        ppMS is3P is1P is1S fi1S fi1P fi3P fi3S
# 0       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     Evide  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  rEêstale  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      kane  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 53 columns]

# %%
dfHeadL4L.to_csv(fL4LHead,encoding="utf8",sep=";",index=None)

# %% [markdown]
# ### Traitement Tail

# %%
dfTail=pd.read_csv(fTail,sep=";")
dfTail.head()
# Out:
#    0       lexeme prs.ptcp     imp.1pl sbjv.1sg sbjv.1pl sbjv.3pl sbjv.3sg  \
# 0  1      gauchir      NaN         NaN      NaN      NaN      NaN      NaN
# 1  2       évider      NaN         NaN      NaN      NaN     Evid      NaN
# 2  3  réinstaller      NaN  ʁEɛ̃stalɔ̃      NaN      NaN      NaN      NaN
# 3  4        caner      NaN         ABS      NaN      NaN      NaN      NaN
# 4  5       tancer      NaN         NaN      NaN      NaN      NaN      NaN
#
#   cond.2sg cond.2pl  ... pst.ptcp.m.pl   prs.2sg pst.ptcp.m.sg pst.sbjv.3pl  \
# 0      NaN      NaN  ...          gOʃi       NaN          gOʃi          NaN
# 1      NaN      NaN  ...         Evide      Evid           NaN          NaN
# 2      NaN      NaN  ...     ʁEɛ̃stale  ʁEɛ̃stal           NaN          NaN
# 3      NaN      NaN  ...           ABS       ABS           NaN          NaN
# 4      NaN      NaN  ...         tɑ̃se       NaN           NaN          NaN
#
# ...

# %%
dfTailL4L=dfTail.apply(copierL4L,axis=1)

# %%
newCols=[mapCols[c] for c in dfTailL4L.columns]
newCols
dfTailL4L.columns=newCols

# %%
dfTailL4L.to_csv(fL4LTail,encoding="utf8",sep=";",index=None)

# %% [markdown]
# # Fin

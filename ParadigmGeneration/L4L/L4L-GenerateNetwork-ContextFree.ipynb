# %% [markdown]
# # Génération des réseaux de formes à partir des règles
# - Swim1 basé sur l'échantillon initial
#  - Gén-1 : génération des formes d'après les contextes phonologiques
#  - Gén-2 : génération du réseau d'après les contextes phonologiques
#  - Filt-1 : extraction du sous-réseau symétrique
#  - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
#  - Filt-3 : extraction des cliques maximales & fidèles
# - Swim2 basé sur le réseau calculé par Swim1
#  - Exp : génération d'un nouvel échantillon basé sur Swim1
#  - Gén-1 : génération des formes sans contexte phonologique
#  - Gén-2 : génération du réseau sans contexte phonologique
#  - Filt-1 : extraction du sous-réseau symétrique
#  - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
#  - Filt-3 : extraction des cliques maximales & fidèles
# - Évaluation

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs,operator,datetime,os,glob
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

def ding():
    os.system('afplay /System/Library/Sounds/Submarine.aiff')

# %%
# %matplotlib inline

# %%
import yaml

# %%
from ipywidgets import FloatProgress
from IPython.display import display, HTML

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %% [markdown]
# # Choix de l'échantillon et des règles
# - *sampleFile* est le nom de l'échantillon de départ
# - *rulesFile* est le nom du fichier de règles
# - *goldFile* est le nom du lexique Gold de référence

# %%
repFiles="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/L4L/IMM21/"
sampleFile="IMM21-00-X-Morphomes.csv"
tirageFile="IMM21-00.pkl"
tirageFile="IMM21-00-X-Morphomes.pkl"
rulesFile="IMM21-00-X-Morphomes-Regles.pkl"
repGold="/Volumes/BroadExt/ownCloud/Recherche/Boye/HDR/Data/Samples/"
goldFile="MGC-171229-Verbes3.pkl"
fSample=repFiles+sampleFile
fInitial=fSample
fTirage=repFiles+tirageFile
fRules=repFiles+rulesFile
fGold=repGold+goldFile

# %%
sampleType="-X"
casesType="-Morphomes"
listeFormesOutput=["FS","FP"]

# %%
genDigraphe=False
genGraphe=False
genFormeVotes=True
genCliques=True
plotDistributionCliques=False

# %%
with open(fTirage, 'rb') as input:
    sampleTirage = pickle.load(input)
sampleTirage.head()
# Out:
#      lexeme    phono  case                  morphome  freq  tir1
# 0  abaisser     abEs  pI2S                      pI2S     1     1
# 1  abaisser     abEs  pi1S                      pi1S     1     1
# 2  abaisser     abEs  pi2S                 pi2S/pi3S     2     2
# 3  abaisser     abEs  pi3P                      pi3P     1     1
# 4  abaisser  abEs6rE  fi1S  fi1S/pc1S/pc2S/pc3P/pc3S     4     4

# %%
if not "morphome" in sampleTirage.columns.tolist():
    sampleTirage["morphome"]=sampleTirage["case"]
morphomeCases=sampleTirage[["case","morphome"]].drop_duplicates().to_dict()
# morphomeCases

# %%
casesMC=morphomeCases["case"]
morphomesMC=morphomeCases["morphome"]
dictMorphomeCases={}
for element in casesMC:
    dictMorphomeCases[casesMC[element]]=morphomesMC[element].split("/")
dictMorphomeCases
# Out:
# {u'ai1P': [u'ai1P'],
#  u'ai1S': [u'ai1S'],
#  u'ai2P': [u'ai2P'],
#  u'ai2S': [u'ai2S', u'ai3S', u'is3S'],
#  u'ai3P': [u'ai3P'],
#  u'fi1P': [u'fi1P', u'fi3P'],
#  u'fi1S': [u'fi1S', u'pc1S', u'pc2S', u'pc3P', u'pc3S'],
#  u'fi2P': [u'fi2P'],
#  u'fi2S': [u'fi2S', u'fi3S'],
#  u'ii1P': [u'ii1P'],
#  u'ii1S': [u'ii1S', u'ii2S', u'ii3P', u'ii3S'],
#  u'ii2P': [u'ii2P'],
#  u'inf': [u'inf'],
#  u'is1P': [u'is1P', u'ppFP', u'ppFS'],
#  u'is1S': [u'is1S', u'is2S', u'is3P'],
#  u'is2P': [u'is2P'],
#  u'pI1P': [u'pI1P'],
#  u'pI2P': [u'pI2P'],
#  u'pI2S': [u'pI2S'],
#  u'pP': [u'pP'],
#  u'pc1P': [u'pc1P'],
#  u'pc2P': [u'pc2P'],
#  u'pi1P': [u'pi1P'],
#  u'pi1S': [u'pi1S'],
#  u'pi2P': [u'pi2P'],
#  u'pi2S': [u'pi2S', u'pi3S'],
#  u'pi3P': [u'pi3P'],
#  u'ppMP': [u'ppMP', u'ppMS'],
#  u'ps1P': [u'ps1P'],
#  u'ps1S': [u'ps1S', u'ps2S', u'ps3P', u'ps3S'],
#  u'ps2P': [u'ps2P']}

# %% [markdown]
# ### Choix original

# %% [raw]
# filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/LongitudinalesRnd/Longitudinal"
# filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/lexique3/Longitudinal-Lexique3"
# filePrefix="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/L4L/IMM21/"
# sampleFiles=glob.glob(filePrefix+"*.pkl")
# def prefixEchantillon(numero,sampleType="",casesType=""):
#     candidats=[]
# #    matchFile=ur"^.*/Longitudinal(-%s-T\d+-F\d+)%s\.pkl"%(numero,sampleType+casesType)
#     matchFile=ur"^.*/Longitudinal-Lexique3(-%s-T\d+-F\d+)%s\.pkl"%(numero,sampleType+casesType)
#     print (matchFile)
#     for sample in sampleFiles:
#         m=re.match(matchFile,sample)
#         if m:
# #            print (sample)
# #            print (m.group(1))
#             candidats.append(m.group(1))
#     if len(candidats)==1:
#         return candidats[0]
#     else:
#         print ("PB pas de nom unique correspondant",len(candidats),numero,sampleType,casesType)

# %% [raw]
# goldPrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/"
# goldFile="MGC-171229-Verbes3.pkl"

# %% [raw]
# sampleNumero="00"
# sampleType="-X"
# casesType="-Morphomes"
# #sampleType=""
# casesType=""
# print (sampleNumero,sampleType,casesType)
# if casesType:
#     sampleNumber=prefixEchantillon(sampleNumero,sampleType,casesType)
# else:
#     sampleNumber=prefixEchantillon(sampleNumero)
# print (sampleNumber)
# paperPrefix="-ISMo"
# paperPrefix="IMM21"
# genFormeVotes=True
# genCliques=True
# listeFormesOutput=["FS","FP"]
# genDigraphe=False
# genGraphe=False
# plotDistributionCliques=False
# samplePrefix=filePrefix+"%s-X"%(sampleNumber)
#     tirageFile=filePrefix+sampleNumber+".pkl"
# sampleFile=samplePrefix+"-paradigmes.csv"
# initialFile=filePrefix+prefixEchantillon(sampleNumero)+sampleType+"-paradigmes.csv"
# print (initialFile)
# analysisPrefix=samplePrefix
# if debug:
#     logfile_name=analysisPrefix+"-network.log"
#     logfile = codecs.open(logfile_name,mode='w',encoding="utf8")

# %% [raw]
# #tirage=filePrefix+'-'+sampleNumber+'-Tirage-'+sampleType+'-170503-1907'+casesType+'.pkl'
# #tirage=filePrefix+sampleNumber+casesType+'.pkl'
# with open(tirageFile, 'rb') as input:
#     sampleTirage = pickle.load(input)

# %% [raw]
# if not "morphome" in sampleTirage.columns.tolist():
#     sampleTirage["morphome"]=sampleTirage["case"]
# morphomeCases=sampleTirage[["case","morphome"]].drop_duplicates().to_dict()
# morphomeCases

# %% [raw]
# casesMC=morphomeCases["case"]
# morphomesMC=morphomeCases["morphome"]
# dictMorphomeCases={}
# for element in casesMC:
#     dictMorphomeCases[casesMC[element]]=morphomesMC[element].split("/")
# dictMorphomeCases

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            if debug: print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
        self.classeCF={}
        self.nbClasseCF={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeFormeCF=[]
        regleFormeCF=""
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            filterF1=".*"+patron.split("-")[0]+"$"
            if re.match(filterF1,forme1):
                classeFormeCF.append(patron)
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleFormeCF=patron
            filterF1=self.patrons[patron]
            if re.match(filterF1,forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseFormeCF=", ".join(classeFormeCF)
        if not idClasseFormeCF in self.classeCF:
            self.classeCF[idClasseFormeCF]={}
            self.nbClasseCF[idClasseFormeCF]=0
        if not regleFormeCF in self.classeCF[idClasseFormeCF]:
            self.classeCF[idClasseFormeCF][regleFormeCF]=0
        self.nbClasseCF[idClasseFormeCF]+=1
        self.classeCF[idClasseFormeCF][regleFormeCF]+=1
        
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme,contextFree=True):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if contextFree:
                filterF1=".*"+patron.split("-")[0]+"$"
            else:
                filterF1=self.patrons[patron]
            if re.match(filterF1,forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if contextFree:
                nbClasse=self.nbClasseCF
                classe=self.classeCF
            else:
                nbClasse=self.nbClasse
                classe=self.classe
            if idClasseForme in nbClasse:
                nTotal=nbClasse[idClasseForme]
                for patron in classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            if debug:
                print (forme, file=logfile) 
                print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# # Lecture de l'échantillon

# %%
phonologicalMap=sampleType.strip("-")
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# ### Vérification de la phonotactique des glides du français
# - si *prononciation* est *None* renvoyer *None*
# - ajout de diérèses dans les séquences mal-formées
# - vérification des séquences consonne+glide à la finale

# %%
dierese={"j":"ij", "w":"uw","H":"yH","i":"ij","u":"uw","y":"yH"}

# %%
def checkFrench(prononciation):
    if prononciation:
        result=recoder(prononciation)
        m=re.match(ur"^.*([^ieèEaOouy926êôâ])[jwH]$",result)
        if m:
            print ("pb avec un glide final", prononciation)
        m=re.match(ur"(.*[ptkbdgfsSvzZ][rl])([jwH])(.*)",result)
        if m:
            n=re.search(ur"[ptkbdgfsSvzZ][rl](wa|Hi|wê)",result)
            if not n:
                glide=m.group(2)
                result=m.group(1)+dierese[glide]+m.group(3)
        m=re.match(ur"(.*)([iuy])([ieEaOouy].*)",result)
        if m:
            glide=m.group(2)
            result=m.group(1)+dierese[glide]+m.group(3)
        result=result.replace("Jj","J")
    else:
        result=prononciation
    return result

# %%
paradigmes=pd.read_csv(fSample,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
paradigmes=paradigmes.dropna(axis=1,how='all')

# %%
goldCases=paradigmes.columns.tolist()
goldCases.remove("lexeme")
#goldCases

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")
#sampleCases

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 43497

# %%
len(paradigmes.dropna(thresh=1)["lexeme"])
# Out:
# 4803

# %% [markdown]
# ## Préparation des données initiales et de référence

# %%
listeTest=paradigmes.dropna(thresh=1)["lexeme"].values.tolist()
#listeTest=[u"asseoir",u"balayer",u"manger"]
nbVerbes=len(listeTest)
print (nbVerbes)
# Out:
# 4803

# %% [markdown]
# ### Préparation des formes initiales

# %%
initialParadigmes=pd.read_csv(fInitial,sep=";",encoding="utf8")
del initialParadigmes[u"Unnamed: 0"]
initialParadigmes=initialParadigmes.dropna(axis=1,how='all')

# %%
initialForms=pd.melt(initialParadigmes[paradigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()

initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)

initialForms.set_index(["lexeme-case"],inplace=True)

initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# ### Préparation des formes de référence

# %%
#with open(goldPrefix+"/"+goldFile,"rb") as input:

# with open(goldPrefix+goldFile,"rb") as input:
#     lexiqueGold=pickle.load(input)
lexiqueGold=pd.read_pickle(path=fGold)

'''Rectifications phonologiques'''
lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

'''Mise en liste des formes de références'''
goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
goldTestForms.set_index(["lexeme-case"],inplace=True)

'''Extraction des formes de références pertinentes'''
goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #paradigmes
# #analyseCases
# lexeme=u"découper"
# paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()

# %% [markdown]
# # Lecture des règles

# %%
with open(fRules, 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ### Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(goldCases):
    print ("Attention l'analyse ne comprend pas toutes les cases")
    print (sorted(analyseCases))
    print (sorted(goldCases))

# %% [markdown]
# # Préparations pour la génération des formes

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme,contextFree=False):
    # pb avec l'encodage des noms de lexèmes
    candidats=paradigmeDistribution(lexeme)
    bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
    casesSamples=paradigmes[bLexParadigme].columns[paradigmes[bLexParadigme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[bLexParadigme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element,contextFree),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart,contextFree))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        # modif pour networkx v2
        # coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        coefGraphe=float(digraphe.adj[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True,contextFree=False):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart,contextFree)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %% [markdown]
# # Génération d'un jeu de cliques

# %%
def generate(lexeme,genDigraphe=True,contextFree=False):
    # print (lexeme,end=", ")
    generation1=generateForms(lexeme,contextFree)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe,contextFree)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
paradigmes.dropna(thresh=1).count().sum()-paradigmes.dropna(thresh=1)["lexeme"].count()
# Out:
# 38694

# %% [markdown]
# #### Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    if len(clique)>1:
        for (depart,arrivee) in it.combinations_with_replacement(clique,2):
            score+=graph[depart][arrivee]["weight"]
    return score

# %%
def splitArrivee(arrivee):
    arriveeMorceaux=arrivee.split("-")
    if len(arriveeMorceaux)<3:
        print (arrivee,arriveeMorceaux)
    lexeme="-".join(arriveeMorceaux[:-2])
    formeArrivee=arriveeMorceaux[-2]
    caseArrivee=arriveeMorceaux[-1]
    return (lexeme,formeArrivee,caseArrivee)
    
# trouver tous les liens vers FS-* et FP-*
# regrouper par forme 
# calculer les proportions
# renvoyer les proportions par forme
# avec le nombre de forme à l'appui
def formeScore(forme,graph):
    scores={}
    scoresNormes={}
    # modif pour networkx v2
    # for depart in graph.edge edge=>adj:
    for depart in graph.adj:
        for arrivee in graph.adj[depart]:
            (lexeme, formeArrivee, caseArrivee)=splitArrivee(arrivee)
            if caseArrivee==forme:
#                print (depart, formeArrivee, graph.edge[depart][arrivee])
                if not formeArrivee in scores:
                    scores[formeArrivee]=0
                scores[formeArrivee]+=graph.adj[depart][arrivee]["weight"]
    totalArrivee=0
    for formeArrivee in scores:
        totalArrivee+=scores[formeArrivee]
    for formeArrivee in scores:
        scoresNormes[formeArrivee]=scores[formeArrivee]/totalArrivee
    return (scores,scoresNormes)

# %% [markdown]
# ## Préparations pour SWIM

# %%
def generateAnalysis(globDigraphe,globGraphe,contextFree=False):
    numClique=0
    progressBar = FloatProgress(min=0, max=nbVerbes-1,description="Generation (%d verbs)"%nbVerbes)
    display(progressBar)
    for i,element in enumerate(listeTest):
        cliquesScores[element]={}
        cliquesListes[element]={}
        if (i%100)==0: print (i, dateheure()[-4:], int(100*float(i)/nbVerbes), end=", ")
        progressBar.value=i
        #print (element)
        result=generate(element,genDigraphe,contextFree)
        (generation,lexDigraphe,lexGraphe,lexCliques)= result
    #    print (generation,lexDigraphe,lexGraphe,lexCliques)
        if genFormeVotes:
            formesScores[element]={}
            formesScoresNormes[element]={}
            for formeOutput in listeFormesOutput:
                (formesScores[element][formeOutput],formesScoresNormes[element][formeOutput])=formeScore(formeOutput,lexDigraphe)
        if genDigraphe:
            globDigraphe=nx.union(globDigraphe,lexDigraphe)
        if genGraphe:
            globGraphe=nx.union(globGraphe,lexGraphe)
        cliques.extend(lexCliques)
        for clique in lexCliques:
            cliquesScores[element][numClique]=cliqueScore(clique,lexGraphe)
            cliquesListes[element][numClique]=clique
            numClique+=1
    return globDigraphe,globGraphe,numClique

# %%
def dictCliqueForms(clique):
    result={}
    for element in clique:
        lexeme,forme,case=splitArrivee(element)
        for c in dictMorphomeCases[case]:
            result[c]=forme
    return result

def dictPdRowForms(row):
    result={}
    for case in sampleCases:
        print (case,row[case].values[0])
    return result

def tableZero(case):
    if case in sampleCases:
        return u"Ø"
    else:
        return u"="

def makeTable(dictForms,title=""):
    tabular=[]
    labelTenseCode={"pi":"Present","ii":"Imperfective","ai":"Simple Past","fi":"Future",
                    "ps":"Subjunctive Pres.","is":"Subjunctive Imp.","pc":"Conditional","pI":"Imperative",
                    "inf":"Infinitive",
                    "ppMS":"Past Part. MS","ppMP":"Past Part. MP",
                    "ppFS":"Past Part. FS","ppMP":"Past Part. FP"
                   }
    def makeLine6(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            case=tenseCode+person
            if (case in dictForms) and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"

    def makeLine3(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            if person in ["2S","1P","2P"]:
                case=tenseCode+person
                if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                    line.append(r"<td>%s</td>"%(dictForms[case]))
                else:
                    line.append(r"<td>%s</td>"%(tableZero(case)))
            else:
                line.append(r"<td>%s</td>"%(u"---"))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
    def makeLineNF():
        line=[]
        line.append(r"<th>%s</th>"%"NF")
        for case in ["inf","pP","ppMS","ppMP","ppFS","ppFP"]:
            if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
        
    top=[
        r"<table>",
        r"<caption style='caption-side:bottom;text-align:center'>",
        "Verbe : %s"%title,
        r"</caption>",
#        r"<tr><th/><th>1S</th><th>2S</th><th>3S</th><th>1P</th><th>2P</th><th>3P</th></tr>"
        r"<tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>"
        ]
    bottom=[
        r"</table>"
        ]
    tabular.append("\n".join(top))
    for tenseCode in ["pi","ii","fi","pc", "ps","ai", "is"]:
        tabular.append(makeLine6(tenseCode))
    tabular.append(makeLine3("pI"))
    tabular.append(makeLineNF())
    tabular.append("\n".join(bottom))
    return "\n".join(tabular)    

def diffParadigme(lexeme):
    outLen=lexemeMaxCliques[lexeme][0]
    bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
    inLen=paradigmes[bLexParadigme].notnull().sum(axis=1).values[0]-1
    if outLen>inLen:
        print (lexemeMaxCliques[lexeme][1])
        print (paradigmes[paradigmes["lexeme"]=="grandir"].values)
    return outLen-inLen

# %%
def checkFidelite(fidelite,clique):
    lFidele=False
    for element in clique:
        if fidelite in element:
            lFidele=True
    return lFidele

def generateCliques(contextFree=False):
    
    def bruteCliques(lexeme,maxCliqueSize=51):
        cliquesBrutes={n+1:0 for n in range(maxCliqueSize)}
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                if not longueur in cliquesBrutes:
                    cliquesBrutes[longueur]=0
                cliquesBrutes[longueur]+=1
        return cliquesBrutes
    
    globDigraphe=nx.DiGraph()
    globGraphe=nx.Graph()

    globDigraphe,globGraphe,numClique=generateAnalysis(globDigraphe,globGraphe,contextFree)
    print 

    lexemeMaxCliques={}
    lexemeParadigmes={}
    progressBarCliques = FloatProgress(min=0, max=len(cliquesListes)-1,description="Analysis (%d verbes)"%len(cliquesListes))
    display(progressBarCliques)
    for lexeme in cliquesListes:
        progressBarCliques.value+=1
        maxLen=max([len(c) for c in cliquesListes[lexeme].values()])
        lexemeMaxCliques[lexeme]=bruteCliques(lexeme,maxLen)
        print (lexeme,"Nombre de cliques",sum([v for k,v in lexemeMaxCliques[lexeme].iteritems()]))
        maxNbCliques=max([v for k,v in lexemeMaxCliques[lexeme].iteritems()])
        if plotDistributionCliques:
            ax=pd.DataFrame.from_dict(lexemeMaxCliques[lexeme],orient="index").plot(kind="bar",legend=False,grid=True,figsize=(10,3))
            ax.set(xlim=(0,maxLen+.5),ylim=(0,maxNbCliques+10))
            ax.set_xlabel("Clique Size in Cells",fontsize=16)
            ax.set_ylabel("Number of Cliques",fontsize=16)

        dictParadigmes=paradigmes.set_index("lexeme").to_dict(orient="index")

        cliquesFideles={}
        fidelites=[v+"-"+k for k,v in dictParadigmes[lexeme].iteritems() if isinstance(v,unicode)]
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                fidele=True
                for fidelite in fidelites:
                    if "," in fidelite:
                        fideliteForme,fideliteCase=fidelite.split("-")
                        fideliteFormes=fideliteForme.split(",")
                        fideliteItems=[fideliteF+"-"+fideliteCase for fideliteF in fideliteFormes]
#                        print (fideliteItems)
                        lFidele=True
                        for f in fideliteItems:
                            lFidele=lFidele & checkFidelite(f,l)
                    else:
                        lFidele=checkFidelite(fidelite,l)
                    if not lFidele:
                        fidele=False
                        break
                if fidele:
                    if not longueur in cliquesFideles:
                        cliquesFideles[longueur]=[]
                    cliquesFideles[longueur].append(l)
#                else:
#                    if lexeme==u"bégayer": print ()
#        print ([(k,len(v)) for k,v in cliquesFideles.iteritems()])
        if cliquesFideles:
            maxCliquesCard=max([k for k,v in cliquesFideles.iteritems()])
    #        print (maxCliquesCard)
    #        print (cliquesScores[lexeme])
    #        print (cliquesListes[lexeme])
            lexemeParadigmes[lexeme]=[]
            maxScoreCliques=max([clique for cliqueNumber, clique in cliquesScores[lexeme].items()])
            maxCardScoreNums=[numC for numC, c in cliquesListes[lexeme].items() if c in cliquesFideles[maxCliquesCard]]
            maxCardScore=max([scoreC for numC, scoreC in cliquesScores[lexeme].items() if numC in maxCardScoreNums])
    #        print ("max score among all cliques:",maxScoreCliques)
            print ("max score among faithfull cliques of %d forms:"%maxCliquesCard,maxCardScore)
            for c in cliquesFideles[maxCliquesCard]:
                cNumber=[cliqueNumber for cliqueNumber, clique in cliquesListes[lexeme].items() if clique == c]
                if len(cNumber)!=1:
                    print ("TOO MANY SCORES PROBLEM WITH CLIQUE", cNumber)
    #            print ("Liste n°",cNumber[0],cliquesScores[lexeme][cNumber[0]])
    #            print (sorted(cliquesScores[lexeme].items(), key=operator.itemgetter(1)))
    #            display(HTML(makeTable(dictCliqueForms(c),title=c[0].split("-")[0])))
    #            print (cliquesScores[lexeme][cNumber[0]], maxCardScore)
                if cliquesScores[lexeme][cNumber[0]]==maxCardScore:
                    lexemeParadigmes[lexeme].append(c)
        else:
            lexemeParadigmes[lexeme]=[[lexeme+"-"+f for f in fidelites]]
            print (u"no new faithfull clique, the previous one contained %d forms"%len(lexemeParadigmes[lexeme][0]))
    return lexemeParadigmes

# %%
def cutNodeName(nodeName):
    items=nodeName.split("-")
    nbItems=len(items)
    if nbItems>3:
        items=["-".join(items[0:nbItems-2]),items[-2],items[-1]]
    return items

def filledOutClique(cliques):
    if cliques:
        result=[]
        for clique in cliques:
#            print (clique)
            fullClique=[]
            for element in clique:
                if debug: print ("element",element)
                lexeme,forme,case=splitArrivee(element)
                for c in dictMorphomeCases[case]:
                    fullClique.append("-".join([lexeme,forme,c]))
            result.append(fullClique)
        return result
    else:
        return cliques

# %%
def extendParadigmes(contextParadigmes,extendMorphomes=False):
    lexemesParadigmeListe=[]
    for lexeme in contextParadigmes:
        if extendMorphomes:
            lexParadigmes=filledOutClique(contextParadigmes[lexeme])
        else:
            lexParadigmes=contextParadigmes[lexeme]
        if len(lexParadigmes)!=1:
            if debug:
                print ("LEXEME WITH A NON UNIQUE PARADIGM PB",len(lexParadigmes),lexeme)
                print (lexParadigmes)
        lexParadigme=lexParadigmes[0]
        for lexForme in lexParadigme:
            lexemesParadigmeListe.append(cutNodeName(lexForme))
    newForms=pd.DataFrame(lexemesParadigmeListe)
    newForms.columns=["lexeme","form","case"]
#    newParadigmes=newForms.pivot(index="lexeme", columns="case", values="form")
    newParadigmes=pd.pivot_table(newForms, values='form', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
    for i in newParadigmes.itertuples():
#        print (i[0],i[1])
        lexeme=i[1]
        bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
        lexemeIndexes=paradigmes.lexeme[bLexParadigme].index.tolist()
        if lexemeIndexes:
            lexemeIndex=lexemeIndexes[0]
        else:
            print (i,lexeme,lexemeIndexes)
        bLexNewParadigme=newParadigmes["lexeme"].str.contains("^"+lexeme+"$")
        newParadigmes.loc[bLexNewParadigme,"index"]=int(lexemeIndex)
    newParadigmes.set_index("index",inplace=True)   
    return paradigmes.combine_first(newParadigmes)

# %%
def countSplits(dfForms):
    dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
    return dfForms["split"].str.len().sum()

def calculerResultats(contextParadigmes,extension="-Swim2"):
    
    '''Préparer le paradigme des prédictions'''
    brutParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=False)
    finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
    finalParadigmes.to_csv(fSample.replace(".csv","")+"%s.csv"%extension,encoding="utf8",sep=";")
    finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
    finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
    finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
    print (finalTestForms.columns)
    # finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["case"]
    # finalTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
    finalTestForms.set_index(["lexeme-case"],inplace=True)
    
    '''Soustraire les formes initiales'''
    finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
    finalFormsIndex=finalForms.index.tolist()
    
    '''Calculer les sur/sous-générations'''
    underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
    overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]
    
    '''Réduire les prédictions et la référence aux cases communes'''
    predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
    actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]
    
    '''Créer un tableau pour les comparaisons'''
    compareForms=predictedForms.copy()
    compareForms.loc[:,"right"]=actualForms.loc[:,"value"]
    
    '''Séparer les cases identiques des cases différentes'''
    sameForms=compareForms[compareForms["value"]==compareForms["right"]]
    diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

    
    '''Sauvegarder les comparatifs'''
    overGeneration.to_csv(fSample.replace(".csv","")+"-overGeneration%s.csv"%extension,encoding="utf8")
    underGeneration.to_csv(fSample.replace(".csv","")+"-underGeneration%s.csv"%extension,encoding="utf8")
    sameForms.to_csv(fSample.replace(".csv","")+"-sameForms%s.csv"%extension,encoding="utf8")
    diffForms.to_csv(fSample.replace(".csv","")+"-diffForms%s.csv"%extension,encoding="utf8")
    
    
    '''Transformer les surabondances en liste'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")

    '''Transformer les surabondances en set()'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
    
    '''Calculer le nombre de formes (y compris surabondances)'''
    nbValues=diffForms["split-value"].str.len().sum()
    nbRights=diffForms["split-right"].str.len().sum()

    '''Calculer les identités et les inclusions'''
    nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
    nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
    nbWrongForms=(nbValues-nbIdenticalSets-nbIncludedSets)
    underBonus=(nbRights-nbIdenticalSets-nbIncludedSets)

    UG=countSplits(underGeneration)+underBonus
    OG=countSplits(overGeneration)
    TP=countSplits(sameForms)+nbIdenticalSets+nbIncludedSets
    FP=nbWrongForms
    resultCharacteristics=(UG,OG,TP,FP)
    recall=float(TP)/(UG+TP+FP)
    precision=float(TP)/(OG+TP+FP)
    fMeasure=2*recall*precision/(recall+precision)
    resultMeasures=(precision,recall,fMeasure)
    print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
    print ("recall", recall, "precision", precision)
    print (fMeasure)
    return (brutParadigmes,finalParadigmes,resultCharacteristics,resultMeasures)

# %% [markdown]
# # SWIM1

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim1ContextParadigmes=generateCliques()
# Out:
# 2023-11-03 12:02:14.446640
# FloatProgress(value=0.0, description=u'Generation (4803 verbs)', max=4802.0)
# 0 1102 0, 100 1105 2, 200 1108 4, 300 1112 6, 400 1115 8, 500 1118 10, 600 1120 12, 700 1123 14, 800 1125 16, 900 1129 18, 1000 1132 20, 1100 1135 22, 1200 1138 24, 1300 1141 27, 1400 1143 29, 1500 1146 31, 1600 1149 33, 1700 1152 35, 1800 1154 37, 1900 1158 39, 2000 1201 41, 2100 1204 43, 2200 1207 45, 2300 1210 47, 2400 1212 49, 2500 1216 52, 2600 1218 54, 2700 1221 56, 2800 1224 58, 2900 1227 60, 3000 1230 62, 3100 1233 64, 3200 1236 66, 3300 1239 68, 3400 1242 70, 3500 1246 72, 3600 1249 74, 3700 1252 77, 3800 1255 79, 3900 1258 81, 4000 1301 83, 4100 1304 85, 4200 1307 87, 4300 1310 89, 4400 1313 91, 4500 1316 93, 4600 1319 95, 4700 1322 97, 4800 1325 99,
# FloatProgress(value=0.0, description=u'Analysis (4803 verbes)', max=4802.0)
# escamoter Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 307.383611761
# enquérir Nombre de cliques 78
# max score among faithfull cliques of 10 forms: 40.1204884866
# réfugier Nombre de cliques 71
# max score among faithfull cliques of 14 forms: 78.9501100026
# assembler Nombre de cliques 21
# max score among faithfull cliques of 23 forms: 265.111293273
# décrédibiliser Nombre de cliques 4
# max score among faithfull cliques of 24 forms: 281.504095881
# ensanglanter Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 317.834492425
# projeter Nombre de cliques 77
# max score among faithfull cliques of 22 forms: 156.250083364
# conceptualiser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 281.504095881
# forger Nombre de cliques 15
# max score among faithfull cliques of 25 forms: 310.042785916
# réglementer Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 326.945282472
# aider Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 313.07204463
# limiter Nombre de cliques 24
# max score among faithfull cliques of 26 forms: 318.022707562
# pratiquer Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 308.591444364
# épurer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 307.351145209
# délier Nombre de cliques 58
# max score among faithfull cliques of 17 forms: 96.9613324808
# fenêtrer Nombre de cliques 11
# max score among faithfull cliques of 23 forms: 242.02483461
# réinstaller Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 271.884329701
# offenser Nombre de cliques 22
# max score among faithfull cliques of 26 forms: 302.767254742
# élever Nombre de cliques 53
# max score among faithfull cliques of 23 forms: 188.759799645
# caner Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 308.25648189
# sonder Nombre de cliques 17
# max score among faithfull cliques of 24 forms: 251.835800652
# hennir Nombre de cliques 46
# max score among faithfull cliques of 23 forms: 213.18041122
# devenir Nombre de cliques 94
# max score among faithfull cliques of 26 forms: 300.836034534
# interner Nombre de cliques 9
# max score among faithfull cliques of 26 forms: 323.685059053
# criser Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 328.797431183
# présenter Nombre de cliques 28
# max score among faithfull cliques of 25 forms: 269.550194077
# orthographier Nombre de cliques 11
# max score among faithfull cliques of 22 forms: 177.280503487
# mouvementer Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 325.617408631
# divertir Nombre de cliques 137
# max score among faithfull cliques of 20 forms: 113.740852206
# béer Nombre de cliques 11
# max score among faithfull cliques of 10 forms: 54.9738426514
# admonester Nombre de cliques 1
# max score among faithfull cliques of 26 forms: 346.067460274
# folâtrer Nombre de cliques 14
# max score among faithfull cliques of 23 forms: 257.072355611
# remâcher Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 318.758061073
# débouler Nombre de cliques 14
# max score among faithfull cliques of 24 forms: 290.221170194
# chaperonner Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 302.220321147
# remodeler Nombre de cliques 17
# max score among faithfull cliques of 22 forms: 211.612420712
# épandre Nombre de cliques 1
# max score among faithfull cliques of 26 forms: 282.054293459
# humaniser Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 313.489472381
# dénuer Nombre de cliques 7
# max score among faithfull cliques of 23 forms: 270.46834457
# abrutir Nombre de cliques 93
# max score among faithfull cliques of 24 forms: 178.917128112
# déverser Nombre de cliques 20
# max score among faithfull cliques of 26 forms: 303.941605478
# époumoner Nombre de cliques 1
# max score among faithfull cliques of 25 forms: 318.031612823
# épingler Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 247.334271589
# déposséder Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 276.237619273
# superposer Nombre de cliques 28
# max score among faithfull cliques of 25 forms: 269.16470008
# effeuiller Nombre de cliques 23
# max score among faithfull cliques of 16 forms: 129.274898364
# désinhiber Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 313.623932561
# enrailler Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 190.574569577
# déboiser Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 304.273721476
# empoissonner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 306.137992999
# instiguer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.502798522
# punaiser Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 313.456349837
# médicaliser Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 281.401613499
# voir Nombre de cliques 100
# max score among faithfull cliques of 24 forms: 248.001363916
# américaniser Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 313.356982205
# adhérer Nombre de cliques 31
# max score among faithfull cliques of 26 forms: 299.68175972
# persister Nombre de cliques 12
# max score among faithfull cliques of 26 forms: 343.641508653
# préoccuper Nombre de cliques 26
# max score among faithfull cliques of 25 forms: 296.274193738
# commenter Nombre de cliques 28
# max score among faithfull cliques of 26 forms: 307.293419074
# douiller Nombre de cliques 9
# max score among faithfull cliques of 22 forms: 240.011355158
# fluidifier Nombre de cliques 40
# max score among faithfull cliques of 20 forms: 128.811164477
# obnubiler Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 290.458005152
# chouchouter Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 298.742642176
# targuer Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 314.220059573
# concasser Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 324.783631847
# rapprocher Nombre de cliques 20
# max score among faithfull cliques of 25 forms: 309.334051408
# indicer Nombre de cliques 36
# max score among faithfull cliques of 21 forms: 145.335917783
# régénérer Nombre de cliques 33
# max score among faithfull cliques of 26 forms: 309.089449064
# iriser Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 331.409779551
# débrayer Nombre de cliques 87
# max score among faithfull cliques of 19 forms: 108.057045223
# fritter Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 332.294009613
# maquereauter Nombre de cliques 9
# max score among faithfull cliques of 19 forms: 179.682041401
# boursicoter Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 306.541553424
# perpétuer Nombre de cliques 28
# max score among faithfull cliques of 20 forms: 192.194691705
# chauffer Nombre de cliques 51
# max score among faithfull cliques of 25 forms: 280.354219922
# discipliner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 317.909956416
# rouer Nombre de cliques 19
# max score among faithfull cliques of 16 forms: 126.639282708
# poiler Nombre de cliques 2
# max score among faithfull cliques of 23 forms: 273.556255563
# regarnir Nombre de cliques 9
# max score among faithfull cliques of 22 forms: 144.502552814
# positionner Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 300.424917569
# dépayser Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 332.645275516
# pencher Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 308.325335394
# basaner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 295.857906633
# courailler Nombre de cliques 6
# max score among faithfull cliques of 23 forms: 210.598703902
# évider Nombre de cliques 18
# max score among faithfull cliques of 26 forms: 315.300413921
# cranter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 295.142028999
# revoler Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 285.770946677
# exceller Nombre de cliques 16
# max score among faithfull cliques of 24 forms: 229.606926828
# télécommander Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 330.837095911
# agrandir Nombre de cliques 137
# max score among faithfull cliques of 22 forms: 150.404621013
# réveiller Nombre de cliques 81
# max score among faithfull cliques of 24 forms: 188.065537211
# catalyser Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 281.408550236
# relativiser Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 249.110516677
# ranimer Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 316.034939307
# moucharder Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 298.176710943
# incarner Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 293.987155636
# financer Nombre de cliques 35
# max score among faithfull cliques of 25 forms: 283.159363824
# saurer Nombre de cliques 36
# max score among faithfull cliques of 25 forms: 286.452258096
# incuber Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 309.129146746
# remplacer Nombre de cliques 29
# max score among faithfull cliques of 25 forms: 310.118157291
# risquer Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 319.850527789
# muer Nombre de cliques 31
# max score among faithfull cliques of 14 forms: 99.7408846276
# étoiler Nombre de cliques 15
# max score among faithfull cliques of 21 forms: 223.920881497
# enquiquiner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 309.135152707
# coter Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 297.145038376
# biner Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 315.87653541
# reprocher Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 309.59000049
# dévaloriser Nombre de cliques 25
# max score among faithfull cliques of 26 forms: 318.499574212
# supplier Nombre de cliques 56
# max score among faithfull cliques of 21 forms: 107.898996377
# grossir Nombre de cliques 155
# max score among faithfull cliques of 24 forms: 175.297923272
# causer Nombre de cliques 74
# max score among faithfull cliques of 22 forms: 149.760209501
# exciser Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 249.977284297
# référencer Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 323.824327935
# sélectionner Nombre de cliques 34
# max score among faithfull cliques of 13 forms: 51.2869709841
# dépiter Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 329.521236468
# confisquer Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 322.349258437
# réséquer Nombre de cliques 5
# max score among faithfull cliques of 26 forms: 342.698344167
# carrosser Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 309.720740811
# reporter Nombre de cliques 23
# max score among faithfull cliques of 25 forms: 272.604727055
# sacquer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.702166154
# émuler Nombre de cliques 1
# max score among faithfull cliques of 24 forms: 296.295442946
# disséminer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 313.68290404
# cadrer Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 262.250084999
# tancer Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 304.158134777
# accidenter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 296.263229713
# répugner Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 262.279833166
# revivre Nombre de cliques 153
# max score among faithfull cliques of 18 forms: 96.7190805163
# tanguer Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 308.304722792
# reclassifier Nombre de cliques 39
# max score among faithfull cliques of 22 forms: 108.59073908
# fissurer Nombre de cliques 20
# max score among faithfull cliques of 25 forms: 301.124387306
# réer Nombre de cliques 44
# max score among faithfull cliques of 11 forms: 43.6102509466
# susciter Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 296.194267487
# facturer Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 300.869177077
# dévouer Nombre de cliques 30
# max score among faithfull cliques of 18 forms: 149.81365757
# terroriser Nombre de cliques 26
# max score among faithfull cliques of 26 forms: 313.937107649
# stresser Nombre de cliques 84
# max score among faithfull cliques of 25 forms: 213.204001836
# figer Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 311.052383527
# expliciter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 309.480174367
# rencarder Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 300.422247757
# indiquer Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 311.112207217
# boudiner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 311.066890505
# ouiller Nombre de cliques 8
# max score among faithfull cliques of 22 forms: 237.61521167
# ragoter Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 306.541553424
# occire Nombre de cliques 16
# max score among faithfull cliques of 21 forms: 163.492265376
# déboulonner Nombre de cliques 1
# max score among faithfull cliques of 25 forms: 320.955392913
# réfuter Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 295.343874243
# pouffer Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 294.495933741
# désosser Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 302.629165761
# empapaouter Nombre de cliques 1
# max score among faithfull cliques of 25 forms: 312.854549034
# refrapper Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 325.736598117
# gaminer Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 319.617149136
# visualiser Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 261.708692159
# changer Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 308.070687411
# saboter Nombre de cliques 35
# max score among faithfull cliques of 25 forms: 281.858818361
# langer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 322.259688504
# appeler Nombre de cliques 47
# max score among faithfull cliques of 23 forms: 201.901994314
# prêcher Nombre de cliques 18
# max score among faithfull cliques of 26 forms: 334.343036367
# fourrager Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 316.697029282
# contresigner Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 269.516227182
# placarder Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 304.711197745
# séquestrer Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 261.959062306
# butiner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 307.449807031
# raccorder Nombre de cliques 27
# max score among faithfull cliques of 25 forms: 282.847542536
# dégager Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 307.624311439
# avantager Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 310.389672158
# gondoler Nombre de cliques 6
# max score among faithfull cliques of 24 forms: 290.066698428
# ménager Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 311.208407178
# courtiser Nombre de cliques 59
# max score among faithfull cliques of 23 forms: 217.549402347
# graduer Nombre de cliques 7
# max score among faithfull cliques of 19 forms: 184.645213906
# surarmer Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 311.183409149
# speeder Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 334.377153413
# agencer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 304.707330765
# priver Nombre de cliques 59
# max score among faithfull cliques of 23 forms: 222.712798803
# canaliser Nombre de cliques 21
# max score among faithfull cliques of 24 forms: 262.790688583
# encadrer Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 258.172193694
# cliqueter Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 319.819924159
# repousser Nombre de cliques 33
# max score among faithfull cliques of 25 forms: 296.424149292
# affectionner Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 298.510549103
# incommoder Nombre de cliques 23
# max score among faithfull cliques of 25 forms: 303.227373428
# réhydrater Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 320.060138959
# réopérer Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 302.606863919
# formaliser Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 273.874777936
# exploser Nombre de cliques 27
# max score among faithfull cliques of 25 forms: 306.039853132
# réactualiser Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 281.408550236
# officialiser Nombre de cliques 17
# max score among faithfull cliques of 24 forms: 272.054008289
# rugir Nombre de cliques 117
# max score among faithfull cliques of 23 forms: 201.96807196
# écailler Nombre de cliques 30
# max score among faithfull cliques of 22 forms: 155.434805015
# menacer Nombre de cliques 49
# max score among faithfull cliques of 25 forms: 282.908050828
# essorer Nombre de cliques 20
# max score among faithfull cliques of 25 forms: 267.023239248
# redevenir Nombre de cliques 113
# max score among faithfull cliques of 25 forms: 273.240198318
# défraîchir Nombre de cliques 3
# max score among faithfull cliques of 23 forms: 236.928227042
# envier Nombre de cliques 149
# max score among faithfull cliques of 17 forms: 96.665154621
# aiguer Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 323.048751867
# aligner Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 272.770611856
# gicler Nombre de cliques 16
# max score among faithfull cliques of 22 forms: 249.435336661
# débriefer Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 323.286103716
# bâter Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 242.099628004
# mémoriser Nombre de cliques 29
# max score among faithfull cliques of 26 forms: 311.535193154
# éroder Nombre de cliques 19
# max score among faithfull cliques of 24 forms: 256.032050087
# ronger Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 309.41580991
# baronner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 300.157892171
# munir Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 216.019338535
# convoler Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 285.770946677
# sortir Nombre de cliques 84
# max score among faithfull cliques of 26 forms: 131.035587854
# berner Nombre de cliques 11
# max score among faithfull cliques of 26 forms: 321.265332951
# ressouder Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 302.780076968
# carmer Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 311.670040165
# précipiter Nombre de cliques 29
# max score among faithfull cliques of 26 forms: 313.212189751
# raréfier Nombre de cliques 127
# max score among faithfull cliques of 21 forms: 144.913328019
# orner Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 296.963388432
# sous-payer Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 181.318205473
# cajoler Nombre de cliques 14
# max score among faithfull cliques of 24 forms: 287.769222438
# déclencher Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 320.577623792
# dérider Nombre de cliques 15
# max score among faithfull cliques of 26 forms: 324.291752013
# réinventer Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 296.539950392
# entrecouper Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 308.182752737
# débattre Nombre de cliques 74
# max score among faithfull cliques of 23 forms: 144.314385786
# divorcer Nombre de cliques 28
# max score among faithfull cliques of 25 forms: 282.538402055
# dégonfler Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 248.489890762
# gérer Nombre de cliques 121
# max score among faithfull cliques of 24 forms: 257.58030092
# prôner Nombre de cliques 39
# max score among faithfull cliques of 14 forms: 64.634809541
# falloir Nombre de cliques 61
# max score among faithfull cliques of 7 forms: 17.9374598733
# ensuivre Nombre de cliques 69
# max score among faithfull cliques of 21 forms: 122.480906577
# pétrir Nombre de cliques 108
# max score among faithfull cliques of 15 forms: 73.7207400593
# satiner Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 315.87653541
# magasiner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 313.192365489
# embuer Nombre de cliques 39
# max score among faithfull cliques of 16 forms: 124.654502402
# ratisser Nombre de cliques 68
# max score among faithfull cliques of 18 forms: 110.504560104
# plucher Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 321.944222028
# trouver Nombre de cliques 52
# max score among faithfull cliques of 23 forms: 245.525066441
# valoriser Nombre de cliques 25
# max score among faithfull cliques of 26 forms: 319.785414476
# nitrater Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 321.250560681
# spitter Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 332.310534666
# sauvegarder Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 293.297944907
# militer Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 316.384840959
# compléter Nombre de cliques 21
# max score among faithfull cliques of 26 forms: 275.054584964
# conforter Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 286.574652238
# redéposer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 290.147023601
# reformater Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 325.441446006
# blêmir Nombre de cliques 18
# max score among faithfull cliques of 13 forms: 52.4331084721
# replonger Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 320.033905846
# citer Nombre de cliques 28
# max score among faithfull cliques of 25 forms: 288.750434911
# enliser Nombre de cliques 15
# max score among faithfull cliques of 24 forms: 273.759299575
# swinguer Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 323.059798977
# redire Nombre de cliques 143
# max score among faithfull cliques of 11 forms: 39.4048991032
# réchauffer Nombre de cliques 52
# max score among faithfull cliques of 25 forms: 275.569916402
# bruisser Nombre de cliques 84
# max score among faithfull cliques of 19 forms: 125.439896365
# taguer Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 310.394176662
# décuver Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 307.95737213
# décaféiner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 305.659510749
# nantir Nombre de cliques 22
# max score among faithfull cliques of 22 forms: 112.990982719
# tondre Nombre de cliques 48
# max score among faithfull cliques of 24 forms: 168.474082765
# témoigner Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 263.893321036
# canarder Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 286.989706534
# avarier Nombre de cliques 12
# max score among faithfull cliques of 21 forms: 164.50211833
# polir Nombre de cliques 43
# max score among faithfull cliques of 23 forms: 190.601250844
# proscrire Nombre de cliques 124
# max score among faithfull cliques of 19 forms: 110.693715129
# prostituer Nombre de cliques 26
# max score among faithfull cliques of 20 forms: 196.017601103
# cotiser Nombre de cliques 41
# max score among faithfull cliques of 23 forms: 230.180583192
# repêcher Nombre de cliques 11
# max score among faithfull cliques of 26 forms: 339.621467939
# biaiser Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 249.779580368
# truffer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 300.305715569
# destiner Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 307.48170827
# mépriser Nombre de cliques 37
# max score among faithfull cliques of 26 forms: 311.210556804
# mouvoir Nombre de cliques 59
# max score among faithfull cliques of 8 forms: 28.428057595
# appendre Nombre de cliques 1
# max score among faithfull cliques of 26 forms: 282.054293459
# rassurer Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 299.022110701
# mourir Nombre de cliques 98
# max score among faithfull cliques of 24 forms: 240.055166524
# suggérer Nombre de cliques 118
# max score among faithfull cliques of 25 forms: 285.218302986
# prévenir Nombre de cliques 107
# max score among faithfull cliques of 25 forms: 273.671550118
# nipper Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 313.625861245
# attitrer Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 264.589456845
# chiner Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 315.87653541
# réincarner Nombre de cliques 10
# max score among faithfull cliques of 25 forms: 304.732309731
# prédestiner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 308.662068053
# consacrer Nombre de cliques 37
# max score among faithfull cliques of 21 forms: 219.254303554
# composter Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 317.89017642
# combler Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 263.791253019
# migrer Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 265.615706769
# naufrager Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.498294017
# escher Nombre de cliques 1
# max score among faithfull cliques of 24 forms: 298.383515528
# carapater Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 320.623570836
# exécrer Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 258.99979635
# bourgeonner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 294.130975521
# dribler Nombre de cliques 9
# max score among faithfull cliques of 22 forms: 250.326042809
# assener Nombre de cliques 23
# max score among faithfull cliques of 24 forms: 227.344532729
# rejaillir Nombre de cliques 137
# max score among faithfull cliques of 17 forms: 89.1904677266
# roupiller Nombre de cliques 75
# max score among faithfull cliques of 22 forms: 180.411155434
# doigter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 303.266916844
# tituber Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 298.838054027
# exagérer Nombre de cliques 117
# max score among faithfull cliques of 25 forms: 277.237064926
# accéder Nombre de cliques 56
# max score among faithfull cliques of 26 forms: 249.128013829
# tarauder Nombre de cliques 10
# max score among faithfull cliques of 24 forms: 263.327717281
# rentraire Nombre de cliques 47
# max score among faithfull cliques of 16 forms: 88.7321861339
# entrapercevoir Nombre de cliques 16
# max score among faithfull cliques of 23 forms: 116.635083978
# défiler Nombre de cliques 17
# max score among faithfull cliques of 24 forms: 289.683835151
# découcher Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 310.492076893
# farfouiller Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 231.486472388
# enter Nombre de cliques 7
# max score among faithfull cliques of 24 forms: 295.743164926
# anoblir Nombre de cliques 34
# max score among faithfull cliques of 22 forms: 169.021762466
# sécréter Nombre de cliques 34
# max score among faithfull cliques of 26 forms: 258.373280342
# bouillir Nombre de cliques 105
# max score among faithfull cliques of 9 forms: 20.3709261946
# amorcer Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 283.558954273
# chaparder Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 304.271971798
# réverbérer Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 328.606863919
# nier Nombre de cliques 41
# max score among faithfull cliques of 18 forms: 107.935993826
# flancher Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 320.920064988
# substituer Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 217.695900519
# maquer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 318.719932842
# clapper Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 319.627724647
# efféminer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 305.98759655
# boire Nombre de cliques 118
# max score among faithfull cliques of 24 forms: 245.871313724
# simplifier Nombre de cliques 115
# max score among faithfull cliques of 19 forms: 127.241468424
# sous-tendre Nombre de cliques 5
# max score among faithfull cliques of 26 forms: 226.666264018
# infester Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 344.507441632
# dégorger Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.882773438
# refléter Nombre de cliques 17
# max score among faithfull cliques of 26 forms: 280.415699675
# coexister Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 344.493218728
# natter Nombre de cliques 5
# max score among faithfull cliques of 25 forms: 305.909436465
# cingler Nombre de cliques 15
# max score among faithfull cliques of 22 forms: 247.748051643
# plaisanter Nombre de cliques 26
# max score among faithfull cliques of 25 forms: 262.465731972
# resalir Nombre de cliques 8
# max score among faithfull cliques of 23 forms: 189.331674013
# participer Nombre de cliques 28
# max score among faithfull cliques of 25 forms: 294.144641543
# galérer Nombre de cliques 18
# max score among faithfull cliques of 26 forms: 322.610079756
# obséder Nombre de cliques 36
# max score among faithfull cliques of 26 forms: 256.858551437
# repriser Nombre de cliques 16
# max score among faithfull cliques of 26 forms: 299.633512595
# embarrasser Nombre de cliques 38
# max score among faithfull cliques of 26 forms: 290.690192519
# rétamer Nombre de cliques 5
# max score among faithfull cliques of 25 forms: 310.753638157
# réadapter Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 320.324259301
# bâcher Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.730784193
# plafonner Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 301.55820452
# raciner Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 315.87653541
# concevoir Nombre de cliques 154
# max score among faithfull cliques of 19 forms: 131.917871209
# pulluler Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 297.572208784
# collectionner Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 298.365750868
# vocaliser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 281.504095881
# ioniser Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 313.456349837
# peindre Nombre de cliques 56
# max score among faithfull cliques of 17 forms: 111.809240941
# borner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 295.291593207
# transcrire Nombre de cliques 163
# max score among faithfull cliques of 19 forms: 103.983228193
# dactylographier Nombre de cliques 5
# max score among faithfull cliques of 22 forms: 189.917978212
# croquer Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 307.350114246
# capitonner Nombre de cliques 11
# max score among faithfull cliques of 17 forms: 143.330315538
# entretuer Nombre de cliques 41
# max score among faithfull cliques of 12 forms: 57.3560709547
# incendier Nombre de cliques 115
# max score among faithfull cliques of 14 forms: 73.7576986805
# réfracter Nombre de cliques 5
# max score among faithfull cliques of 25 forms: 320.31944983
# surgir Nombre de cliques 115
# max score among faithfull cliques of 23 forms: 201.225376469
# exhaler Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 271.422102087
# resquiller Nombre de cliques 69
# max score among faithfull cliques of 22 forms: 169.409609174
# presser Nombre de cliques 91
# max score among faithfull cliques of 25 forms: 208.963265498
# supporter Nombre de cliques 23
# max score among faithfull cliques of 25 forms: 280.443499464
# compulser Nombre de cliques 6
# max score among faithfull cliques of 21 forms: 224.274705016
# braiser Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 295.718239156
# ruser Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 306.662494763
# affecter Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 316.201271505
# chérir Nombre de cliques 247
# max score among faithfull cliques of 21 forms: 136.551832423
# regrouper Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 298.340275232
# recalibrer Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 264.645511273
# maximiser Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 335.368778977
# ajuster Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 316.468035063
# réfrigérer Nombre de cliques 25
# max score among faithfull cliques of 24 forms: 270.492615922
# glaiser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 283.231043759
# nicher Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 312.591142609
# exaucer Nombre de cliques 64
# max score among faithfull cliques of 14 forms: 58.311069297
# plastiquer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.735288698
# doler Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 294.745630014
# vouloir Nombre de cliques 84
# max score among faithfull cliques of 22 forms: 216.070155153
# rouler Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 266.938009672
# grognasser Nombre de cliques 4
# max score among faithfull cliques of 26 forms: 331.944480694
# choir Nombre de cliques 24
# max score among faithfull cliques of 5 forms: 11.1033620543
# halluciner Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 306.957768914
# tricoter Nombre de cliques 30
# max score among faithfull cliques of 25 forms: 287.402677941
# couronner Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 298.108088132
# exclamer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 320.867146954
# classifier Nombre de cliques 49
# max score among faithfull cliques of 20 forms: 141.565781136
# notifier Nombre de cliques 50
# max score among faithfull cliques of 20 forms: 145.25911613
# collectiviser Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 249.14720614
# moitir Nombre de cliques 15
# max score among faithfull cliques of 24 forms: 181.979196186
# décomprimer Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 316.447940356
# piocher Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 309.712911611
# vivoter Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 299.734511712
# couturer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 295.284396635
# acheminer Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 312.015168166
# stabiliser Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 265.656854346
# diminuer Nombre de cliques 26
# max score among faithfull cliques of 18 forms: 161.012830916
# mandater Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 300.930840189
# blinder Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 317.227437109
# accroire Nombre de cliques 2
# max score among faithfull cliques of 15 forms: 108.862461692
# électrifier Nombre de cliques 50
# max score among faithfull cliques of 20 forms: 144.507359493
# parasiter Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 298.035703569
# scintiller Nombre de cliques 52
# max score among faithfull cliques of 22 forms: 167.098121593
# créer Nombre de cliques 100
# max score among faithfull cliques of 19 forms: 131.57752388
# désobéir Nombre de cliques 100
# max score among faithfull cliques of 22 forms: 219.773459771
# débusquer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 322.464665554
# lifter Nombre de cliques 5
# max score among faithfull cliques of 26 forms: 335.920911432
# députer Nombre de cliques 5
# max score among faithfull cliques of 25 forms: 309.022469986
# imbriquer Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 312.301795811
# stocker Nombre de cliques 15
# max score among faithfull cliques of 25 forms: 309.339863446
# conjecturer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 303.736682473
# putréfier Nombre de cliques 82
# max score among faithfull cliques of 21 forms: 148.270741733
# benner Nombre de cliques 6
# max score among faithfull cliques of 22 forms: 218.46842002
# gercer Nombre de cliques 6
# max score among faithfull cliques of 26 forms: 325.280788214
# palpiter Nombre de cliques 13
# max score among faithfull cliques of 26 forms: 315.050050988
# réécouter Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 300.675862258
# inaugurer Nombre de cliques 25
# max score among faithfull cliques of 25 forms: 298.751651829
# désinstaller Nombre de cliques 2
# max score among faithfull cliques of 23 forms: 273.267503511
# formater Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 325.441446006
# blablater Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 319.266402761
# rembobiner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 308.985837279
# réécrire Nombre de cliques 215
# max score among faithfull cliques of 18 forms: 96.6835599666
# débourser Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 299.668365522
# retourner Nombre de cliques 15
# max score among faithfull cliques of 25 forms: 295.303316817
# redresser Nombre de cliques 85
# max score among faithfull cliques of 25 forms: 215.1262149
# martyriser Nombre de cliques 26
# max score among faithfull cliques of 26 forms: 313.40765281
# ressasser Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 272.419444748
# stagner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 320.080495826
# stupéfier Nombre de cliques 87
# max score among faithfull cliques of 19 forms: 140.858504333
# certifier Nombre de cliques 89
# max score among faithfull cliques of 19 forms: 132.389989638
# désappointer Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 301.80528217
# enneiger Nombre de cliques 5
# max score among faithfull cliques of 26 forms: 344.547379778
# tartiner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 312.990748467
# apposer Nombre de cliques 28
# max score among faithfull cliques of 25 forms: 272.986343605
# insister Nombre de cliques 18
# max score among faithfull cliques of 26 forms: 342.082343308
# assurer Nombre de cliques 31
# max score among faithfull cliques of 25 forms: 297.2819252
# emprisonner Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 295.565548625
# disputer Nombre de cliques 31
# max score among faithfull cliques of 25 forms: 291.770249902
# grincer Nombre de cliques 15
# max score among faithfull cliques of 26 forms: 297.998991204
# formuler Nombre de cliques 15
# max score among faithfull cliques of 24 forms: 292.180695467
# normer Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 310.978742332
# materner Nombre de cliques 10
# max score among faithfull cliques of 26 forms: 326.846627002
# enlever Nombre de cliques 51
# max score among faithfull cliques of 24 forms: 205.548009402
# rayer Nombre de cliques 70
# max score among faithfull cliques of 14 forms: 75.0280119165
# biseauter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 303.934252246
# ambler Nombre de cliques 4
# max score among faithfull cliques of 22 forms: 250.485765031
# virer Nombre de cliques 38
# max score among faithfull cliques of 25 forms: 298.600449096
# houspiller Nombre de cliques 84
# max score among faithfull cliques of 22 forms: 169.009609174
# tracer Nombre de cliques 49
# max score among faithfull cliques of 26 forms: 285.622350415
# prolonger Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 320.277119988
# restreindre Nombre de cliques 39
# max score among faithfull cliques of 16 forms: 108.854278808
# vamper Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 325.291322868
# impulser Nombre de cliques 3
# max score among faithfull cliques of 21 forms: 227.025342852
# carotter Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 300.541442429
# ozoner Nombre de cliques 13
# max score among faithfull cliques of 18 forms: 164.128189369
# découpler Nombre de cliques 3
# max score among faithfull cliques of 22 forms: 250.902431698
# éborgner Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 269.781858359
# mutiner Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 309.135152707
# pourfendre Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 243.910437709
# simuler Nombre de cliques 16
# max score among faithfull cliques of 24 forms: 292.352430021
# cantonner Nombre de cliques 15
# max score among faithfull cliques of 25 forms: 297.897156952
# mâchouiller Nombre de cliques 23
# max score among faithfull cliques of 22 forms: 235.032836263
# vernir Nombre de cliques 28
# max score among faithfull cliques of 22 forms: 167.395853193
# paralyser Nombre de cliques 25
# max score among faithfull cliques of 24 forms: 266.101319632
# clapoter Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 299.734511712
# morceler Nombre de cliques 19
# max score among faithfull cliques of 21 forms: 196.705911896
# survirer Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 302.358313521
# désister Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 345.118611024
# user Nombre de cliques 23
# max score among faithfull cliques of 24 forms: 293.388673946
# enfuir Nombre de cliques 76
# max score among faithfull cliques of 22 forms: 147.813764841
# tonifier Nombre de cliques 46
# max score among faithfull cliques of 20 forms: 128.743842508
# piller Nombre de cliques 101
# max score among faithfull cliques of 22 forms: 166.667747121
# apitoyer Nombre de cliques 48
# max score among faithfull cliques of 21 forms: 136.923711831
# sangler Nombre de cliques 15
# max score among faithfull cliques of 22 forms: 248.483316692
# emboîter Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 293.318994248
# attribuer Nombre de cliques 47
# max score among faithfull cliques of 19 forms: 175.666756294
# gambiller Nombre de cliques 20
# max score among faithfull cliques of 22 forms: 177.485889943
# discourir Nombre de cliques 23
# max score among faithfull cliques of 21 forms: 129.837046559
# retransformer Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 309.796175639
# décharner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 304.266676537
# pouponner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 299.851694364
# rejouer Nombre de cliques 20
# max score among faithfull cliques of 20 forms: 197.665542138
# chopper Nombre de cliques 26
# max score among faithfull cliques of 25 forms: 295.467192917
# enrager Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 311.966511439
# corréler Nombre de cliques 1
# max score among faithfull cliques of 24 forms: 265.600296107
# calibrer Nombre de cliques 17
# max score among faithfull cliques of 23 forms: 260.762501239
# suralimenter Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 325.624900307
# rabâcher Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 309.248461525
# croître Nombre de cliques 71
# max score among faithfull cliques of 9 forms: 23.9414022712
# enfanter Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 286.887827148
# ramollir Nombre de cliques 44
# max score among faithfull cliques of 23 forms: 199.715874903
# désaffecter Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 316.95265362
# zigouiller Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 238.137706617
# empoter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 303.934252246
# bavasser Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 322.230997934
# promener Nombre de cliques 59
# max score among faithfull cliques of 22 forms: 169.52173145
# construire Nombre de cliques 109
# max score among faithfull cliques of 23 forms: 160.238300896
# octroyer Nombre de cliques 36
# max score among faithfull cliques of 18 forms: 115.878565806
# subordonner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 304.546867458
# bidouiller Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 236.719191098
# venger Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 309.301640828
# coasser Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 282.942414568
# concéder Nombre de cliques 37
# max score among faithfull cliques of 25 forms: 246.353844999
# enrichir Nombre de cliques 124
# max score among faithfull cliques of 23 forms: 206.636542645
# carrer Nombre de cliques 53
# max score among faithfull cliques of 24 forms: 245.191857672
# galvauder Nombre de cliques 24
# max score among faithfull cliques of 14 forms: 57.938457268
# accrocher Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 307.444448697
# bitter Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 332.310534666
# motoriser Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 328.789939507
# mijoter Nombre de cliques 30
# max score among faithfull cliques of 25 forms: 290.502477066
# rééquilibrer Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 256.886150473
# momifier Nombre de cliques 53
# max score among faithfull cliques of 20 forms: 141.471329187
# renter Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 285.060966771
# poiroter Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 305.68402804
# ravir Nombre de cliques 205
# max score among faithfull cliques of 21 forms: 130.477022221
# grignoter Nombre de cliques 25
# max score among faithfull cliques of 25 forms: 302.519315676
# ennuyer Nombre de cliques 77
# max score among faithfull cliques of 18 forms: 88.494915549
# injecter Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 315.735855673
# crailler Nombre de cliques 16
# max score among faithfull cliques of 22 forms: 196.634367094
# économiser Nombre de cliques 29
# max score among faithfull cliques of 26 forms: 322.95288313
# idolâtrer Nombre de cliques 19
# max score among faithfull cliques of 23 forms: 261.019691566
# chanter Nombre de cliques 31
# max score among faithfull cliques of 25 forms: 283.984816769
# cerner Nombre de cliques 10
# max score among faithfull cliques of 26 forms: 318.465225771
# délester Nombre de cliques 6
# max score among faithfull cliques of 26 forms: 344.366340552
# exulter Nombre de cliques 3
# max score among faithfull cliques of 21 forms: 226.867374517
# baliser Nombre de cliques 10
# max score among faithfull cliques of 24 forms: 281.469935087
# confier Nombre de cliques 139
# max score among faithfull cliques of 19 forms: 135.051170831
# reprogrammer Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 301.608355083
# démordre Nombre de cliques 30
# max score among faithfull cliques of 18 forms: 89.4822411232
# ankyloser Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 312.203889816
# tirer Nombre de cliques 31
# max score among faithfull cliques of 25 forms: 297.930057509
# télégraphier Nombre de cliques 81
# ...
# max score among faithfull cliques of 19 forms: 155.534158629
# décélérer Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 320.663247084
# goudronner Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 305.612478008
# procrastiner Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 315.87653541
# stériliser Nombre de cliques 15
# max score among faithfull cliques of 24 forms: 271.90472609
# convoiter Nombre de cliques 27
# max score among faithfull cliques of 25 forms: 283.806441775
# trébucher Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 308.791190904
# emménager Nombre de cliques 20
# max score among faithfull cliques of 25 forms: 312.276123049
# rincer Nombre de cliques 19
# max score among faithfull cliques of 26 forms: 300.378770505
# analyser Nombre de cliques 34
# max score among faithfull cliques of 24 forms: 256.832713482
# émaner Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 300.785848718
# antidater Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 300.884763476
# vaquer Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 304.431581903
# serrer Nombre de cliques 123
# max score among faithfull cliques of 24 forms: 258.86265907
# cyanoser Nombre de cliques 21
# max score among faithfull cliques of 21 forms: 218.837263468
# festoyer Nombre de cliques 34
# max score among faithfull cliques of 21 forms: 157.087842636
# faufiler Nombre de cliques 18
# max score among faithfull cliques of 24 forms: 290.524382423
# persuader Nombre de cliques 47
# max score among faithfull cliques of 25 forms: 289.466871858
# décompter Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 303.647993893
# restituer Nombre de cliques 28
# max score among faithfull cliques of 20 forms: 195.32189841
# détourner Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 298.46760085
# cuiter Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 299.538758549
# prétexter Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 344.124688314
# javelliser Nombre de cliques 18
# max score among faithfull cliques of 23 forms: 235.649040451
# crasser Nombre de cliques 4
# max score among faithfull cliques of 26 forms: 322.64005122
# ébahir Nombre de cliques 7
# max score among faithfull cliques of 21 forms: 216.476441086
# gainer Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 239.139223971
# brailler Nombre de cliques 51
# max score among faithfull cliques of 22 forms: 161.553442139
# urger Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 318.480679201
# repeindre Nombre de cliques 21
# max score among faithfull cliques of 17 forms: 132.504098592
# tergiverser Nombre de cliques 17
# max score among faithfull cliques of 26 forms: 310.945441305
# fondre Nombre de cliques 49
# max score among faithfull cliques of 24 forms: 206.665784457
# dérouiller Nombre de cliques 22
# max score among faithfull cliques of 22 forms: 234.190027404
# ressurgir Nombre de cliques 86
# max score among faithfull cliques of 23 forms: 204.355387043
# influencer Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 292.970424069
# ouvrir Nombre de cliques 165
# max score among faithfull cliques of 24 forms: 191.752797965
# déambuler Nombre de cliques 12
# max score among faithfull cliques of 24 forms: 291.257595041
# renverser Nombre de cliques 24
# max score among faithfull cliques of 26 forms: 305.36446264
# dorer Nombre de cliques 38
# max score among faithfull cliques of 20 forms: 164.335603734
# assermenter Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 326.502657858
# raquer Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 313.201743406
# requinquer Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 314.921130456
# bouger Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 308.233682979
# localiser Nombre de cliques 29
# max score among faithfull cliques of 24 forms: 260.073868739
# déglutir Nombre de cliques 41
# max score among faithfull cliques of 23 forms: 155.576602095
# lésiner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 308.994225835
# endurcir Nombre de cliques 127
# max score among faithfull cliques of 23 forms: 160.4004195
# externaliser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 281.504095881
# végéter Nombre de cliques 6
# max score among faithfull cliques of 26 forms: 269.063824128
# jauger Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 309.461958005
# approuver Nombre de cliques 50
# max score among faithfull cliques of 25 forms: 287.248890394
# généraliser Nombre de cliques 10
# max score among faithfull cliques of 24 forms: 281.463102928
# enfermer Nombre de cliques 10
# max score among faithfull cliques of 26 forms: 319.097949997
# défroquer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.385131847
# chuchoter Nombre de cliques 40
# max score among faithfull cliques of 25 forms: 285.52014642
# diluer Nombre de cliques 28
# max score among faithfull cliques of 17 forms: 140.414952452
# brider Nombre de cliques 19
# max score among faithfull cliques of 26 forms: 328.792864861
# mander Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 331.798144829
# incorporer Nombre de cliques 40
# max score among faithfull cliques of 25 forms: 285.270469603
# déboîter Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 303.006745594
# frauder Nombre de cliques 53
# max score among faithfull cliques of 14 forms: 56.7046569767
# déminer Nombre de cliques 2
# max score among faithfull cliques of 25 forms: 318.551934053
# surnager Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 318.658061073
# succomber Nombre de cliques 22
# max score among faithfull cliques of 25 forms: 297.643470901
# jubiler Nombre de cliques 12
# max score among faithfull cliques of 24 forms: 291.563971248
# rapatrier Nombre de cliques 135
# max score among faithfull cliques of 19 forms: 84.9653004206
# surprendre Nombre de cliques 89
# max score among faithfull cliques of 21 forms: 196.84991747
# laper Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 319.13500101
# boiter Nombre de cliques 29
# max score among faithfull cliques of 25 forms: 283.131775202
# reloger Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 321.08962377
# offrir Nombre de cliques 152
# max score among faithfull cliques of 23 forms: 177.378195257
# dissiper Nombre de cliques 23
# max score among faithfull cliques of 25 forms: 298.412670207
# caractériser Nombre de cliques 28
# max score among faithfull cliques of 26 forms: 312.004321908
# freiner Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 222.398150332
# poisser Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 250.830115814
# promettre Nombre de cliques 76
# max score among faithfull cliques of 24 forms: 167.145656272
# culpabiliser Nombre de cliques 24
# max score among faithfull cliques of 24 forms: 260.295274487
# déconseiller Nombre de cliques 48
# max score among faithfull cliques of 24 forms: 214.847435888
# climatiser Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 249.961015041
# suppléer Nombre de cliques 9
# max score among faithfull cliques of 11 forms: 61.4064532886
# médiatiser Nombre de cliques 13
# max score among faithfull cliques of 23 forms: 249.99380935
# embrasser Nombre de cliques 51
# max score among faithfull cliques of 26 forms: 290.092992351
# rationaliser Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 281.440398784
# suffire Nombre de cliques 161
# max score among faithfull cliques of 15 forms: 43.2707511469
# endiguer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.630479227
# damner Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 303.013520961
# réinstaurer Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 300.290247918
# précéder Nombre de cliques 45
# max score among faithfull cliques of 26 forms: 256.759530137
# défouler Nombre de cliques 17
# max score among faithfull cliques of 24 forms: 291.373147953
# exhausser Nombre de cliques 9
# max score among faithfull cliques of 25 forms: 303.61619318
# schtroumpfer Nombre de cliques 1
# max score among faithfull cliques of 25 forms: 310.793958501
# baiser Nombre de cliques 147
# max score among faithfull cliques of 23 forms: 180.990690097
# glousser Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 317.19703978
# placer Nombre de cliques 30
# max score among faithfull cliques of 25 forms: 310.592747149
# résumer Nombre de cliques 13
# max score among faithfull cliques of 25 forms: 308.603582617
# chroniquer Nombre de cliques 3
# max score among faithfull cliques of 25 forms: 318.762565577
# marier Nombre de cliques 124
# max score among faithfull cliques of 23 forms: 162.646770285
# tutoyer Nombre de cliques 43
# max score among faithfull cliques of 21 forms: 136.633908167
# allonger Nombre de cliques 15
# max score among faithfull cliques of 25 forms: 319.851736613
# puiser Nombre de cliques 69
# max score among faithfull cliques of 17 forms: 117.169356097
# faillir Nombre de cliques 110
# max score among faithfull cliques of 7 forms: 23.014118088
# compenser Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 300.724764711
# signer Nombre de cliques 24
# max score among faithfull cliques of 22 forms: 243.311973916
# pistonner Nombre de cliques 8
# max score among faithfull cliques of 25 forms: 300.023941658
# patienter Nombre de cliques 19
# max score among faithfull cliques of 26 forms: 295.212728484
# évertuer Nombre de cliques 33
# max score among faithfull cliques of 15 forms: 105.909596868
# minuter Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 303.799388554
# éplucher Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 319.749064595
# intellectualiser Nombre de cliques 5
# max score among faithfull cliques of 24 forms: 281.504095881
# interchanger Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 316.463397357
# espionner Nombre de cliques 18
# max score among faithfull cliques of 25 forms: 299.268337633
# faciliter Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 313.868677459
# détériorer Nombre de cliques 64
# max score among faithfull cliques of 8 forms: 20.356685009
# jouir Nombre de cliques 112
# max score among faithfull cliques of 20 forms: 164.627621224
# transfuser Nombre de cliques 23
# max score among faithfull cliques of 25 forms: 298.444523599
# chercher Nombre de cliques 21
# max score among faithfull cliques of 26 forms: 334.356005545
# repentir Nombre de cliques 84
# max score among faithfull cliques of 22 forms: 79.7103897534
# nuire Nombre de cliques 101
# max score among faithfull cliques of 17 forms: 87.1517246171
# désolidariser Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 331.409779551
# jumeler Nombre de cliques 26
# max score among faithfull cliques of 21 forms: 176.490162224
# bégayer Nombre de cliques 73
# max score among faithfull cliques of 19 forms: 115.931971331
# dédicacer Nombre de cliques 29
# max score among faithfull cliques of 26 forms: 318.823241373
# coiffer Nombre de cliques 54
# max score among faithfull cliques of 25 forms: 271.366684736
# lober Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 319.502803766
# dessouler Nombre de cliques 9
# max score among faithfull cliques of 24 forms: 289.43984013
# subodorer Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 118.227769674
# réfréner Nombre de cliques 21
# max score among faithfull cliques of 24 forms: 237.001791041
# moyenner Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 335.075224548
# saigner Nombre de cliques 31
# max score among faithfull cliques of 22 forms: 206.265498139
# plaquer Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 319.705165381
# réquisitionner Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 300.38098939
# fourguer Nombre de cliques 15
# max score among faithfull cliques of 25 forms: 313.230963522
# broder Nombre de cliques 48
# max score among faithfull cliques of 14 forms: 61.4338752716
# douter Nombre de cliques 32
# max score among faithfull cliques of 25 forms: 291.101546973
# préserver Nombre de cliques 64
# max score among faithfull cliques of 26 forms: 293.109985051
# rebeller Nombre de cliques 30
# max score among faithfull cliques of 23 forms: 213.514250654
# radoter Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 283.172545512
# mordiller Nombre de cliques 58
# max score among faithfull cliques of 22 forms: 177.835129992
# arrêter Nombre de cliques 50
# max score among faithfull cliques of 26 forms: 241.14592816
# annuler Nombre de cliques 16
# max score among faithfull cliques of 24 forms: 295.163153255
# craqueler Nombre de cliques 18
# max score among faithfull cliques of 22 forms: 193.381153439
# conspirer Nombre de cliques 33
# max score among faithfull cliques of 25 forms: 297.305303287
# comparer Nombre de cliques 73
# max score among faithfull cliques of 24 forms: 255.051869272
# atterrir Nombre de cliques 240
# max score among faithfull cliques of 22 forms: 146.061249545
# renseigner Nombre de cliques 30
# max score among faithfull cliques of 22 forms: 204.719123933
# envisager Nombre de cliques 21
# max score among faithfull cliques of 25 forms: 308.761850379
# occuper Nombre de cliques 27
# max score among faithfull cliques of 25 forms: 296.718608771
# marbrer Nombre de cliques 9
# max score among faithfull cliques of 23 forms: 264.540386313
# dresser Nombre de cliques 94
# max score among faithfull cliques of 25 forms: 211.663482491
# disculper Nombre de cliques 16
# max score among faithfull cliques of 21 forms: 224.681376389
# encastrer Nombre de cliques 20
# max score among faithfull cliques of 23 forms: 260.137460396
# rapetisser Nombre de cliques 58
# max score among faithfull cliques of 20 forms: 133.174636396
# blasphémer Nombre de cliques 16
# max score among faithfull cliques of 25 forms: 251.095458327
# éteindre Nombre de cliques 44
# max score among faithfull cliques of 22 forms: 198.127474168
# apprécier Nombre de cliques 155
# max score among faithfull cliques of 22 forms: 135.587771037
# raidir Nombre de cliques 123
# max score among faithfull cliques of 23 forms: 158.930838524
# dénicher Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 313.425145508
# baigner Nombre de cliques 29
# max score among faithfull cliques of 22 forms: 206.660707949
# aviser Nombre de cliques 89
# max score among faithfull cliques of 23 forms: 226.920398763
# éclaircir Nombre de cliques 138
# max score among faithfull cliques of 24 forms: 172.904282353
# pérenniser Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 313.698577371
# décrire Nombre de cliques 229
# max score among faithfull cliques of 17 forms: 90.1103697571
# démettre Nombre de cliques 31
# max score among faithfull cliques of 23 forms: 161.390703698
# rééquiper Nombre de cliques 3
# max score among faithfull cliques of 26 forms: 336.704662639
# entailler Nombre de cliques 38
# max score among faithfull cliques of 23 forms: 192.051694382
# réinviter Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 329.512203091
# augmenter Nombre de cliques 28
# max score among faithfull cliques of 26 forms: 305.309471121
# bouleverser Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 312.600396394
# délurer Nombre de cliques 4
# max score among faithfull cliques of 25 forms: 317.574850472
# déverrouiller Nombre de cliques 27
# max score among faithfull cliques of 22 forms: 234.663121337
# piger Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 308.757881764
# évanouir Nombre de cliques 155
# max score among faithfull cliques of 19 forms: 149.693852393
# tonner Nombre de cliques 12
# max score among faithfull cliques of 25 forms: 293.593313854
# répertorier Nombre de cliques 110
# max score among faithfull cliques of 17 forms: 94.9894464555
# trifouiller Nombre de cliques 14
# max score among faithfull cliques of 22 forms: 236.719191098
# CPU times: user 2h 30min 44s, sys: 1min 6s, total: 2h 31min 51s
# Wall time: 2h 31min 30s

# %%
newParadigmes,paradigmesSwim1,characteristicsSwim1,measuresSwim1=calculerResultats(swim1ContextParadigmes,"-Swim1")
# %ding
# Out:
# Index([u'value', u'lexeme-case'], dtype='object')
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# UG 59842 OG 16668 TP 125485 FP 12745
# recall 0.633532250899 precision 0.810113752276
# 0.711023599739
# UsageError: Line magic function `%ding` not found.

# %% [markdown]
# # SWIM2

# %% [markdown]
# ## Préparation des paradigmes

# %%
paradigmesOriginaux=paradigmes.copy()
paradigmesSample=paradigmesOriginaux[paradigmesOriginaux["lexeme"].isin(listeTest)]

# %%
paradigmes=newParadigmes.copy()
paradigmesColumns=paradigmes.columns.tolist()
for c in sampleCases:
    if not c in paradigmesColumns:
        print (c)
        paradigmes[c]=np.NaN

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim2ContextParadigmes=generateCliques(contextFree=True)
# Out:
# 2023-11-03 14:39:13.877329
# FloatProgress(value=0.0, description=u'Generation (4803 verbs)', max=4802.0)
# 0 1339 0, 100 1341 2, 200 1343 4, 300 1345 6, 400 1347 8, 500 1349 10, 600 1351 12, 700 1353 14, 800 1355 16, 900 1356 18, 1000 1359 20, 1100 1400 22, 1200 1403 24, 1300 1405 27, 1400 1407 29, 1500 1408 31, 1600 1410 33, 1700 1412 35, 1800 1414 37, 1900 1416 39, 2000 1418 41, 2100 1420 43, 2200 1422 45, 2300 1424 47, 2400 1426 49, 2500 1428 52, 2600 1430 54, 2700 1432 56, 2800 1434 58, 2900 1436 60, 3000 1438 62, 3100 1440 64, 3200 1442 66, 3300 1444 68, 3400 1446 70, 3500 1448 72, 3600 1450 74, 3700 1452 77, 3800 1454 79, 3900 1456 81, 4000 1458 83, 4100 1500 85, 4200 1501 87, 4300 1503 89, 4400 1505 91, 4500 1507 93, 4600 1510 95, 4700 1511 97, 4800 1514 99,
# FloatProgress(value=0.0, description=u'Analysis (4803 verbes)', max=4802.0)
# escamoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# enquérir Nombre de cliques 1341
# max score among faithfull cliques of 15 forms: 19.5269254416
# réfugier Nombre de cliques 1236
# max score among faithfull cliques of 23 forms: 76.5526228244
# assembler Nombre de cliques 1383
# max score among faithfull cliques of 25 forms: 172.78941292
# décrédibiliser Nombre de cliques 1247
# max score among faithfull cliques of 26 forms: 201.386693894
# ensanglanter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# projeter Nombre de cliques 1928
# max score among faithfull cliques of 26 forms: 156.526024987
# conceptualiser Nombre de cliques 1259
# max score among faithfull cliques of 26 forms: 204.445678528
# forger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# réglementer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# aider Nombre de cliques 1094
# max score among faithfull cliques of 26 forms: 184.304882614
# limiter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# pratiquer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 221.827379816
# épurer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# délier Nombre de cliques 1597
# max score among faithfull cliques of 21 forms: 69.6939918847
# fenêtrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# réinstaller Nombre de cliques 1388
# no new faithfull clique, the previous one contained 23 forms
# offenser Nombre de cliques 1373
# max score among faithfull cliques of 26 forms: 186.395794474
# élever Nombre de cliques 2245
# no new faithfull clique, the previous one contained 23 forms
# caner Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# sonder Nombre de cliques 1059
# max score among faithfull cliques of 26 forms: 213.474076875
# hennir Nombre de cliques 1518
# max score among faithfull cliques of 25 forms: 92.2980185474
# devenir Nombre de cliques 2523
# max score among faithfull cliques of 26 forms: 152.396458561
# interner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.346028758
# criser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# présenter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# orthographier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 58.7386186945
# mouvementer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# divertir Nombre de cliques 1502
# max score among faithfull cliques of 23 forms: 82.7277107
# béer Nombre de cliques 353
# max score among faithfull cliques of 19 forms: 103.927545459
# admonester Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 219.42997753
# folâtrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# remâcher Nombre de cliques 1030
# no new faithfull clique, the previous one contained 25 forms
# débouler Nombre de cliques 1412
# no new faithfull clique, the previous one contained 24 forms
# chaperonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# remodeler Nombre de cliques 1841
# max score among faithfull cliques of 26 forms: 151.26714733
# épandre Nombre de cliques 1560
# max score among faithfull cliques of 27 forms: 99.7773604268
# humaniser Nombre de cliques 1262
# max score among faithfull cliques of 26 forms: 203.041234764
# dénuer Nombre de cliques 1382
# max score among faithfull cliques of 25 forms: 167.811215861
# abrutir Nombre de cliques 1567
# no new faithfull clique, the previous one contained 24 forms
# déverser Nombre de cliques 1360
# no new faithfull clique, the previous one contained 26 forms
# époumoner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# épingler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# déposséder Nombre de cliques 1103
# max score among faithfull cliques of 26 forms: 190.828341078
# superposer Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 198.852729312
# effeuiller Nombre de cliques 1920
# no new faithfull clique, the previous one contained 16 forms
# désinhiber Nombre de cliques 948
# max score among faithfull cliques of 26 forms: 223.62872973
# enrailler Nombre de cliques 1367
# max score among faithfull cliques of 25 forms: 95.0889219599
# déboiser Nombre de cliques 1431
# max score among faithfull cliques of 26 forms: 202.601760556
# empoissonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# instiguer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# punaiser Nombre de cliques 1546
# no new faithfull clique, the previous one contained 25 forms
# médicaliser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# voir Nombre de cliques 2366
# max score among faithfull cliques of 24 forms: 63.9082301789
# américaniser Nombre de cliques 1262
# max score among faithfull cliques of 26 forms: 203.041234764
# adhérer Nombre de cliques 1215
# no new faithfull clique, the previous one contained 26 forms
# persister Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 219.42997753
# préoccuper Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.750957529
# commenter Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# douiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# fluidifier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 63.0480793935
# obnubiler Nombre de cliques 1182
# max score among faithfull cliques of 26 forms: 218.253409314
# chouchouter Nombre de cliques 1135
# max score among faithfull cliques of 26 forms: 217.275720461
# targuer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# concasser Nombre de cliques 1385
# max score among faithfull cliques of 26 forms: 185.651032844
# rapprocher Nombre de cliques 1012
# max score among faithfull cliques of 26 forms: 210.845850483
# indicer Nombre de cliques 1309
# max score among faithfull cliques of 26 forms: 190.17289404
# régénérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 26 forms
# iriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# débrayer Nombre de cliques 1513
# max score among faithfull cliques of 27 forms: 78.7059462887
# fritter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# maquereauter Nombre de cliques 1010
# no new faithfull clique, the previous one contained 19 forms
# boursicoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# perpétuer Nombre de cliques 1347
# max score among faithfull cliques of 24 forms: 152.075769715
# chauffer Nombre de cliques 1011
# max score among faithfull cliques of 26 forms: 212.579284996
# discipliner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# rouer Nombre de cliques 1296
# max score among faithfull cliques of 22 forms: 138.001213856
# poiler Nombre de cliques 1380
# no new faithfull clique, the previous one contained 23 forms
# regarnir Nombre de cliques 1462
# max score among faithfull cliques of 25 forms: 92.0580782361
# positionner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# dépayser Nombre de cliques 1284
# max score among faithfull cliques of 26 forms: 200.281734015
# pencher Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 221.282873499
# basaner Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# courailler Nombre de cliques 1367
# max score among faithfull cliques of 25 forms: 95.0889219599
# évider Nombre de cliques 1071
# max score among faithfull cliques of 26 forms: 213.107017167
# cranter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# revoler Nombre de cliques 1387
# max score among faithfull cliques of 26 forms: 211.357875498
# exceller Nombre de cliques 1340
# max score among faithfull cliques of 26 forms: 195.440944761
# télécommander Nombre de cliques 1073
# max score among faithfull cliques of 26 forms: 213.107017167
# agrandir Nombre de cliques 1575
# max score among faithfull cliques of 25 forms: 91.7150786999
# réveiller Nombre de cliques 1674
# no new faithfull clique, the previous one contained 24 forms
# catalyser Nombre de cliques 1252
# max score among faithfull cliques of 26 forms: 201.386693894
# relativiser Nombre de cliques 1254
# max score among faithfull cliques of 26 forms: 202.481695482
# ranimer Nombre de cliques 974
# max score among faithfull cliques of 26 forms: 219.714252679
# moucharder Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 212.475558127
# incarner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# financer Nombre de cliques 1366
# max score among faithfull cliques of 26 forms: 184.48223079
# saurer Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 209.76657173
# incuber Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# remplacer Nombre de cliques 1378
# max score among faithfull cliques of 26 forms: 183.730285239
# risquer Nombre de cliques 923
# max score among faithfull cliques of 26 forms: 221.827379816
# muer Nombre de cliques 803
# max score among faithfull cliques of 25 forms: 182.291380072
# étoiler Nombre de cliques 1328
# no new faithfull clique, the previous one contained 21 forms
# enquiquiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# coter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# biner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# reprocher Nombre de cliques 1012
# max score among faithfull cliques of 26 forms: 210.845850483
# dévaloriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# supplier Nombre de cliques 1264
# max score among faithfull cliques of 24 forms: 62.8927063709
# grossir Nombre de cliques 1846
# max score among faithfull cliques of 25 forms: 91.7671044637
# causer Nombre de cliques 1817
# max score among faithfull cliques of 23 forms: 113.161299406
# exciser Nombre de cliques 1245
# no new faithfull clique, the previous one contained 23 forms
# référencer Nombre de cliques 1373
# max score among faithfull cliques of 26 forms: 186.395794474
# sélectionner Nombre de cliques 1045
# max score among faithfull cliques of 22 forms: 97.1963415247
# dépiter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# confisquer Nombre de cliques 923
# max score among faithfull cliques of 26 forms: 221.827379816
# réséquer Nombre de cliques 1100
# max score among faithfull cliques of 26 forms: 195.400442458
# carrosser Nombre de cliques 1508
# no new faithfull clique, the previous one contained 25 forms
# reporter Nombre de cliques 926
# max score among faithfull cliques of 26 forms: 218.113081301
# sacquer Nombre de cliques 1044
# max score among faithfull cliques of 26 forms: 221.827379816
# émuler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# disséminer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# cadrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# tancer Nombre de cliques 1373
# max score among faithfull cliques of 26 forms: 188.882611114
# accidenter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# répugner Nombre de cliques 885
# max score among faithfull cliques of 26 forms: 223.187635926
# revivre Nombre de cliques 1903
# max score among faithfull cliques of 24 forms: 85.3751445448
# tanguer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# reclassifier Nombre de cliques 1446
# max score among faithfull cliques of 25 forms: 94.3328459897
# fissurer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# réer Nombre de cliques 669
# max score among faithfull cliques of 19 forms: 81.6115440416
# susciter Nombre de cliques 952
# max score among faithfull cliques of 26 forms: 220.740277658
# facturer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# dévouer Nombre de cliques 1390
# max score among faithfull cliques of 22 forms: 134.104044348
# terroriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# stresser Nombre de cliques 1389
# no new faithfull clique, the previous one contained 25 forms
# figer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# expliciter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 220.740277658
# rencarder Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 212.475558127
# indiquer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 221.827379816
# boudiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# ouiller Nombre de cliques 1646
# max score among faithfull cliques of 24 forms: 132.162244245
# ragoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# occire Nombre de cliques 1753
# max score among faithfull cliques of 25 forms: 91.7878938828
# déboulonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# réfuter Nombre de cliques 943
# max score among faithfull cliques of 26 forms: 218.113081301
# pouffer Nombre de cliques 1127
# max score among faithfull cliques of 26 forms: 218.910687211
# désosser Nombre de cliques 1508
# max score among faithfull cliques of 26 forms: 169.540615503
# empapaouter Nombre de cliques 1135
# max score among faithfull cliques of 26 forms: 217.275720461
# refrapper Nombre de cliques 934
# max score among faithfull cliques of 26 forms: 219.515517586
# gaminer Nombre de cliques 946
# max score among faithfull cliques of 26 forms: 220.698319988
# visualiser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# changer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# saboter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# langer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# appeler Nombre de cliques 1867
# max score among faithfull cliques of 26 forms: 144.102150498
# prêcher Nombre de cliques 1064
# max score among faithfull cliques of 26 forms: 194.663759915
# fourrager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# contresigner Nombre de cliques 885
# max score among faithfull cliques of 26 forms: 223.187635926
# placarder Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 212.475558127
# séquestrer Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 222.143965227
# butiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# raccorder Nombre de cliques 1061
# max score among faithfull cliques of 26 forms: 212.475558127
# dégager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# avantager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# gondoler Nombre de cliques 1387
# max score among faithfull cliques of 26 forms: 211.357875498
# ménager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# courtiser Nombre de cliques 1255
# no new faithfull clique, the previous one contained 23 forms
# graduer Nombre de cliques 1344
# max score among faithfull cliques of 25 forms: 172.89824191
# surarmer Nombre de cliques 972
# max score among faithfull cliques of 26 forms: 218.090160673
# speeder Nombre de cliques 1071
# max score among faithfull cliques of 26 forms: 213.107017167
# agencer Nombre de cliques 1373
# max score among faithfull cliques of 26 forms: 188.882611114
# priver Nombre de cliques 1554
# max score among faithfull cliques of 26 forms: 191.468623475
# canaliser Nombre de cliques 1259
# max score among faithfull cliques of 26 forms: 204.445678528
# encadrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# cliqueter Nombre de cliques 914
# max score among faithfull cliques of 26 forms: 218.113081301
# repousser Nombre de cliques 1443
# max score among faithfull cliques of 26 forms: 195.557214046
# affectionner Nombre de cliques 998
# max score among faithfull cliques of 26 forms: 211.006341151
# incommoder Nombre de cliques 1080
# no new faithfull clique, the previous one contained 25 forms
# réhydrater Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 219.42997753
# réopérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 25 forms
# formaliser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# exploser Nombre de cliques 1395
# no new faithfull clique, the previous one contained 25 forms
# réactualiser Nombre de cliques 1259
# max score among faithfull cliques of 26 forms: 204.445678528
# officialiser Nombre de cliques 1252
# max score among faithfull cliques of 26 forms: 201.386693894
# rugir Nombre de cliques 1462
# max score among faithfull cliques of 25 forms: 92.4491986004
# écailler Nombre de cliques 1355
# max score among faithfull cliques of 25 forms: 101.531325719
# menacer Nombre de cliques 1378
# max score among faithfull cliques of 26 forms: 183.730285239
# essorer Nombre de cliques 1062
# max score among faithfull cliques of 26 forms: 211.338556656
# redevenir Nombre de cliques 2522
# max score among faithfull cliques of 26 forms: 149.541220661
# défraîchir Nombre de cliques 1517
# max score among faithfull cliques of 25 forms: 92.2980185474
# envier Nombre de cliques 1711
# max score among faithfull cliques of 21 forms: 63.7457443114
# aiguer Nombre de cliques 1046
# max score among faithfull cliques of 26 forms: 194.053594086
# aligner Nombre de cliques 889
# max score among faithfull cliques of 26 forms: 225.336266067
# gicler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# débriefer Nombre de cliques 968
# max score among faithfull cliques of 26 forms: 222.7486319
# bâter Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 219.42997753
# mémoriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# éroder Nombre de cliques 1080
# no new faithfull clique, the previous one contained 24 forms
# ronger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# baronner Nombre de cliques 998
# max score among faithfull cliques of 26 forms: 211.006341151
# munir Nombre de cliques 1462
# max score among faithfull cliques of 25 forms: 92.4491986004
# convoler Nombre de cliques 1387
# max score among faithfull cliques of 26 forms: 211.357875498
# sortir Nombre de cliques 1039
# max score among faithfull cliques of 27 forms: 74.0718008749
# berner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.346028758
# ressouder Nombre de cliques 1270
# max score among faithfull cliques of 26 forms: 209.214964185
# carmer Nombre de cliques 972
# max score among faithfull cliques of 26 forms: 218.090160673
# précipiter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# raréfier Nombre de cliques 1361
# max score among faithfull cliques of 23 forms: 57.589428683
# orner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# sous-payer Nombre de cliques 1662
# max score among faithfull cliques of 23 forms: 87.6807360647
# cajoler Nombre de cliques 1387
# max score among faithfull cliques of 26 forms: 211.357875498
# déclencher Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 221.282873499
# dérider Nombre de cliques 1071
# max score among faithfull cliques of 26 forms: 213.107017167
# réinventer Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# entrecouper Nombre de cliques 1110
# max score among faithfull cliques of 26 forms: 217.419165725
# débattre Nombre de cliques 1375
# max score among faithfull cliques of 24 forms: 73.3588047624
# divorcer Nombre de cliques 1353
# max score among faithfull cliques of 26 forms: 184.48223079
# dégonfler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# gérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 24 forms
# prôner Nombre de cliques 988
# max score among faithfull cliques of 22 forms: 105.894343657
# falloir Nombre de cliques 1399
# max score among faithfull cliques of 21 forms: 74.6675712883
# ensuivre Nombre de cliques 1858
# max score among faithfull cliques of 24 forms: 88.3077478169
# pétrir Nombre de cliques 1390
# max score among faithfull cliques of 25 forms: 92.0598737461
# satiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# magasiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 224.994732473
# embuer Nombre de cliques 1310
# max score among faithfull cliques of 25 forms: 171.022335456
# ratisser Nombre de cliques 1223
# no new faithfull clique, the previous one contained 18 forms
# plucher Nombre de cliques 965
# max score among faithfull cliques of 26 forms: 221.282873499
# trouver Nombre de cliques 1669
# max score among faithfull cliques of 25 forms: 182.251039883
# valoriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# nitrater Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 219.42997753
# spitter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# sauvegarder Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 212.475558127
# militer Nombre de cliques 943
# max score among faithfull cliques of 26 forms: 218.113081301
# compléter Nombre de cliques 1556
# no new faithfull clique, the previous one contained 26 forms
# conforter Nombre de cliques 926
# max score among faithfull cliques of 26 forms: 218.113081301
# redéposer Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 198.852729312
# reformater Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 219.42997753
# blêmir Nombre de cliques 968
# no new faithfull clique, the previous one contained 13 forms
# replonger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# citer Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 220.740277658
# enliser Nombre de cliques 1247
# max score among faithfull cliques of 26 forms: 201.386693894
# swinguer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# redire Nombre de cliques 1527
# max score among faithfull cliques of 25 forms: 77.3024214292
# réchauffer Nombre de cliques 1011
# max score among faithfull cliques of 26 forms: 212.579284996
# bruisser Nombre de cliques 1295
# max score among faithfull cliques of 25 forms: 172.470151909
# taguer Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# décuver Nombre de cliques 1653
# no new faithfull clique, the previous one contained 25 forms
# décaféiner Nombre de cliques 946
# max score among faithfull cliques of 26 forms: 220.698319988
# nantir Nombre de cliques 1139
# max score among faithfull cliques of 27 forms: 74.8144602269
# tondre Nombre de cliques 1491
# max score among faithfull cliques of 27 forms: 95.5532991237
# témoigner Nombre de cliques 1337
# no new faithfull clique, the previous one contained 23 forms
# canarder Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 212.475558127
# avarier Nombre de cliques 1380
# max score among faithfull cliques of 23 forms: 64.2432102582
# polir Nombre de cliques 1876
# max score among faithfull cliques of 25 forms: 92.4491986004
# proscrire Nombre de cliques 1857
# max score among faithfull cliques of 23 forms: 51.8959081742
# prostituer Nombre de cliques 1338
# max score among faithfull cliques of 24 forms: 152.075769715
# cotiser Nombre de cliques 1260
# max score among faithfull cliques of 26 forms: 202.481695482
# repêcher Nombre de cliques 1064
# max score among faithfull cliques of 26 forms: 194.663759915
# biaiser Nombre de cliques 1558
# no new faithfull clique, the previous one contained 23 forms
# truffer Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 223.017992743
# destiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# mépriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# mouvoir Nombre de cliques 1405
# max score among faithfull cliques of 10 forms: 10.9616049108
# appendre Nombre de cliques 1560
# max score among faithfull cliques of 27 forms: 99.7773604268
# rassurer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# mourir Nombre de cliques 1867
# max score among faithfull cliques of 24 forms: 62.7546009407
# suggérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 25 forms
# prévenir Nombre de cliques 2522
# max score among faithfull cliques of 26 forms: 149.541220661
# nipper Nombre de cliques 932
# max score among faithfull cliques of 26 forms: 220.724086728
# attitrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# chiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# réincarner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# prédestiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# consacrer Nombre de cliques 1019
# max score among faithfull cliques of 26 forms: 188.243438949
# composter Nombre de cliques 929
# max score among faithfull cliques of 26 forms: 218.113081301
# combler Nombre de cliques 1383
# max score among faithfull cliques of 25 forms: 172.78941292
# migrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# naufrager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# escher Nombre de cliques 1064
# max score among faithfull cliques of 26 forms: 196.645928747
# carapater Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 219.42997753
# exécrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# bourgeonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# dribler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# assener Nombre de cliques 1058
# no new faithfull clique, the previous one contained 24 forms
# rejaillir Nombre de cliques 1532
# max score among faithfull cliques of 25 forms: 92.7577740043
# roupiller Nombre de cliques 1396
# max score among faithfull cliques of 22 forms: 93.2831063195
# doigter Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 211.160497629
# tituber Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# exagérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 25 forms
# accéder Nombre de cliques 1096
# max score among faithfull cliques of 26 forms: 186.85375597
# tarauder Nombre de cliques 1078
# no new faithfull clique, the previous one contained 24 forms
# rentraire Nombre de cliques 1438
# max score among faithfull cliques of 17 forms: 34.6663754136
# entrapercevoir Nombre de cliques 2370
# max score among faithfull cliques of 25 forms: 103.547313135
# défiler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# découcher Nombre de cliques 1051
# max score among faithfull cliques of 26 forms: 218.714839904
# farfouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# enter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 219.423106591
# anoblir Nombre de cliques 1681
# max score among faithfull cliques of 25 forms: 89.9343057988
# sécréter Nombre de cliques 1556
# no new faithfull clique, the previous one contained 26 forms
# bouillir Nombre de cliques 1667
# max score among faithfull cliques of 9 forms: 7.21156693087
# amorcer Nombre de cliques 1353
# max score among faithfull cliques of 26 forms: 184.48223079
# chaparder Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 212.475558127
# réverbérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 26 forms
# nier Nombre de cliques 1300
# max score among faithfull cliques of 23 forms: 68.5595747074
# flancher Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 221.282873499
# substituer Nombre de cliques 1361
# max score among faithfull cliques of 25 forms: 172.458626407
# maquer Nombre de cliques 1044
# max score among faithfull cliques of 26 forms: 221.827379816
# clapper Nombre de cliques 927
# max score among faithfull cliques of 26 forms: 219.750957529
# efféminer Nombre de cliques 946
# max score among faithfull cliques of 26 forms: 220.698319988
# boire Nombre de cliques 2428
# max score among faithfull cliques of 24 forms: 73.048346947
# simplifier Nombre de cliques 1350
# max score among faithfull cliques of 23 forms: 67.5201443689
# sous-tendre Nombre de cliques 1562
# max score among faithfull cliques of 27 forms: 99.7773604268
# infester Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 219.42997753
# dégorger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# refléter Nombre de cliques 1556
# no new faithfull clique, the previous one contained 26 forms
# coexister Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 219.42997753
# natter Nombre de cliques 927
# max score among faithfull cliques of 26 forms: 220.740277658
# cingler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# plaisanter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# resalir Nombre de cliques 1856
# max score among faithfull cliques of 25 forms: 91.7101001827
# participer Nombre de cliques 932
# max score among faithfull cliques of 26 forms: 220.724086728
# galérer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 26 forms
# obséder Nombre de cliques 1096
# max score among faithfull cliques of 26 forms: 186.85375597
# repriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# embarrasser Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 185.651032844
# rétamer Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 219.714252679
# réadapter Nombre de cliques 914
# max score among faithfull cliques of 26 forms: 218.113081301
# bâcher Nombre de cliques 1030
# no new faithfull clique, the previous one contained 25 forms
# plafonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# raciner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# concevoir Nombre de cliques 2459
# max score among faithfull cliques of 25 forms: 88.198943658
# pulluler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# collectionner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# vocaliser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# ioniser Nombre de cliques 1262
# max score among faithfull cliques of 26 forms: 203.041234764
# peindre Nombre de cliques 1799
# max score among faithfull cliques of 24 forms: 94.8214959894
# borner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# transcrire Nombre de cliques 1857
# max score among faithfull cliques of 23 forms: 51.8959081742
# dactylographier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 58.7386186945
# croquer Nombre de cliques 997
# max score among faithfull cliques of 26 forms: 211.44602099
# capitonner Nombre de cliques 776
# no new faithfull clique, the previous one contained 17 forms
# entretuer Nombre de cliques 1118
# max score among faithfull cliques of 13 forms: 19.6681984098
# incendier Nombre de cliques 1256
# max score among faithfull cliques of 23 forms: 70.0493275442
# réfracter Nombre de cliques 914
# max score among faithfull cliques of 26 forms: 218.113081301
# surgir Nombre de cliques 1462
# max score among faithfull cliques of 25 forms: 92.4491986004
# exhaler Nombre de cliques 1385
# no new faithfull clique, the previous one contained 23 forms
# resquiller Nombre de cliques 1395
# max score among faithfull cliques of 22 forms: 93.2831063195
# presser Nombre de cliques 1389
# no new faithfull clique, the previous one contained 25 forms
# supporter Nombre de cliques 926
# max score among faithfull cliques of 26 forms: 218.113081301
# compulser Nombre de cliques 1327
# max score among faithfull cliques of 26 forms: 177.071170845
# braiser Nombre de cliques 1526
# no new faithfull clique, the previous one contained 26 forms
# ruser Nombre de cliques 1370
# max score among faithfull cliques of 26 forms: 209.570586777
# affecter Nombre de cliques 934
# max score among faithfull cliques of 26 forms: 218.113081301
# chérir Nombre de cliques 1599
# max score among faithfull cliques of 24 forms: 88.6699501506
# regrouper Nombre de cliques 1110
# max score among faithfull cliques of 26 forms: 217.419165725
# recalibrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# maximiser Nombre de cliques 1279
# max score among faithfull cliques of 26 forms: 200.281734015
# ajuster Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 217.161543888
# réfrigérer Nombre de cliques 1214
# max score among faithfull cliques of 25 forms: 181.955162917
# glaiser Nombre de cliques 1546
# no new faithfull clique, the previous one contained 24 forms
# nicher Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 221.282873499
# exaucer Nombre de cliques 1860
# max score among faithfull cliques of 20 forms: 68.626427244
# plastiquer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 223.791908671
# doler Nombre de cliques 1385
# max score among faithfull cliques of 26 forms: 207.6605889
# vouloir Nombre de cliques 3730
# max score among faithfull cliques of 22 forms: 47.5365757751
# rouler Nombre de cliques 1408
# no new faithfull clique, the previous one contained 23 forms
# grognasser Nombre de cliques 1394
# max score among faithfull cliques of 26 forms: 185.651032844
# choir Nombre de cliques 867
# max score among faithfull cliques of 25 forms: 52.242869099
# halluciner Nombre de cliques 939
# max score among faithfull cliques of 26 forms: 223.017992743
# tricoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# couronner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# exclamer Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 219.714252679
# classifier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 63.0480793935
# notifier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 63.0480793935
# collectiviser Nombre de cliques 1254
# max score among faithfull cliques of 26 forms: 202.481695482
# moitir Nombre de cliques 1564
# no new faithfull clique, the previous one contained 24 forms
# décomprimer Nombre de cliques 974
# max score among faithfull cliques of 26 forms: 219.714252679
# piocher Nombre de cliques 1012
# max score among faithfull cliques of 26 forms: 210.845850483
# vivoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# couturer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# acheminer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# stabiliser Nombre de cliques 1247
# max score among faithfull cliques of 26 forms: 201.386693894
# diminuer Nombre de cliques 1312
# max score among faithfull cliques of 24 forms: 151.58971743
# mandater Nombre de cliques 927
# max score among faithfull cliques of 26 forms: 220.740277658
# blinder Nombre de cliques 1142
# max score among faithfull cliques of 26 forms: 212.475558127
# accroire Nombre de cliques 1271
# max score among faithfull cliques of 25 forms: 81.0398056923
# électrifier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 63.0480793935
# parasiter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 220.740277658
# scintiller Nombre de cliques 1411
# max score among faithfull cliques of 22 forms: 93.2831063195
# créer Nombre de cliques 1105
# max score among faithfull cliques of 19 forms: 66.5757632147
# désobéir Nombre de cliques 1569
# max score among faithfull cliques of 25 forms: 98.5116870624
# débusquer Nombre de cliques 940
# max score among faithfull cliques of 26 forms: 220.852567787
# lifter Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 219.42997753
# députer Nombre de cliques 943
# max score among faithfull cliques of 26 forms: 218.113081301
# imbriquer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 221.827379816
# stocker Nombre de cliques 995
# max score among faithfull cliques of 26 forms: 209.873782829
# conjecturer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# putréfier Nombre de cliques 1361
# max score among faithfull cliques of 23 forms: 58.93772251
# benner Nombre de cliques 1057
# no new faithfull clique, the previous one contained 22 forms
# gercer Nombre de cliques 1360
# no new faithfull clique, the previous one contained 26 forms
# palpiter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# réécouter Nombre de cliques 1135
# max score among faithfull cliques of 26 forms: 217.275720461
# inaugurer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# désinstaller Nombre de cliques 1388
# no new faithfull clique, the previous one contained 23 forms
# formater Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 219.42997753
# blablater Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 218.113081301
# rembobiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# réécrire Nombre de cliques 1829
# max score among faithfull cliques of 21 forms: 50.9417124865
# débourser Nombre de cliques 1369
# max score among faithfull cliques of 26 forms: 184.48223079
# retourner Nombre de cliques 946
# max score among faithfull cliques of 26 forms: 220.698319988
# redresser Nombre de cliques 1389
# no new faithfull clique, the previous one contained 25 forms
# martyriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# ressasser Nombre de cliques 1394
# max score among faithfull cliques of 26 forms: 183.730285239
# stagner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# stupéfier Nombre de cliques 1316
# max score among faithfull cliques of 23 forms: 72.0515432535
# certifier Nombre de cliques 1313
# max score among faithfull cliques of 23 forms: 71.9101631652
# désappointer Nombre de cliques 953
# max score among faithfull cliques of 26 forms: 218.113081301
# enneiger Nombre de cliques 1048
# max score among faithfull cliques of 26 forms: 196.478571881
# tartiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# apposer Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 198.852729312
# insister Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 219.42997753
# assurer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# emprisonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# disputer Nombre de cliques 943
# max score among faithfull cliques of 26 forms: 218.113081301
# grincer Nombre de cliques 1356
# max score among faithfull cliques of 26 forms: 186.395794474
# formuler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# normer Nombre de cliques 968
# max score among faithfull cliques of 26 forms: 218.090160673
# materner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.346028758
# enlever Nombre de cliques 2247
# no new faithfull clique, the previous one contained 24 forms
# rayer Nombre de cliques 1266
# max score among faithfull cliques of 27 forms: 82.5162784527
# biseauter Nombre de cliques 986
# no new faithfull clique, the previous one contained 25 forms
# ambler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# virer Nombre de cliques 990
# max score among faithfull cliques of 26 forms: 220.885896482
# houspiller Nombre de cliques 1395
# max score among faithfull cliques of 22 forms: 93.2831063195
# tracer Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 185.651032844
# prolonger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# restreindre Nombre de cliques 1542
# max score among faithfull cliques of 24 forms: 95.9025389292
# vamper Nombre de cliques 932
# max score among faithfull cliques of 26 forms: 219.515517586
# impulser Nombre de cliques 1327
# max score among faithfull cliques of 26 forms: 177.071170845
# carotter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# ozoner Nombre de cliques 799
# no new faithfull clique, the previous one contained 18 forms
# découpler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# éborgner Nombre de cliques 885
# max score among faithfull cliques of 26 forms: 223.187635926
# mutiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# pourfendre Nombre de cliques 1560
# max score among faithfull cliques of 27 forms: 99.7773604268
# simuler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# cantonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# mâchouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# vernir Nombre de cliques 1462
# max score among faithfull cliques of 25 forms: 92.0580782361
# paralyser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# clapoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# morceler Nombre de cliques 1842
# max score among faithfull cliques of 26 forms: 158.358795788
# survirer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 223.976560859
# désister Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 219.42997753
# user Nombre de cliques 1370
# max score among faithfull cliques of 26 forms: 211.731516606
# enfuir Nombre de cliques 1502
# max score among faithfull cliques of 24 forms: 57.0489417838
# tonifier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 63.0480793935
# piller Nombre de cliques 1395
# max score among faithfull cliques of 22 forms: 93.2831063195
# apitoyer Nombre de cliques 1432
# max score among faithfull cliques of 22 forms: 77.463877938
# sangler Nombre de cliques 1107
# max score among faithfull cliques of 26 forms: 222.254246059
# emboîter Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 211.160497629
# attribuer Nombre de cliques 1339
# max score among faithfull cliques of 24 forms: 154.44178569
# gambiller Nombre de cliques 1395
# max score among faithfull cliques of 22 forms: 93.2831063195
# discourir Nombre de cliques 1400
# max score among faithfull cliques of 25 forms: 91.1573886196
# retransformer Nombre de cliques 970
# max score among faithfull cliques of 26 forms: 219.714252679
# décharner Nombre de cliques 939
# max score among faithfull cliques of 26 forms: 221.393416201
# pouponner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# rejouer Nombre de cliques 1389
# max score among faithfull cliques of 22 forms: 138.00410718
# chopper Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 209.46980449
# enrager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# corréler Nombre de cliques 1340
# max score among faithfull cliques of 26 forms: 195.440944761
# calibrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# suralimenter Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# rabâcher Nombre de cliques 1030
# no new faithfull clique, the previous one contained 25 forms
# croître Nombre de cliques 1190
# max score among faithfull cliques of 9 forms: 13.6815219203
# enfanter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# ramollir Nombre de cliques 1876
# max score among faithfull cliques of 25 forms: 92.4491986004
# désaffecter Nombre de cliques 934
# max score among faithfull cliques of 26 forms: 218.113081301
# zigouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# empoter Nombre de cliques 986
# no new faithfull clique, the previous one contained 25 forms
# bavasser Nombre de cliques 1395
# max score among faithfull cliques of 26 forms: 185.651032844
# promener Nombre de cliques 1737
# max score among faithfull cliques of 26 forms: 102.025376201
# construire Nombre de cliques 1795
# max score among faithfull cliques of 24 forms: 68.9284976941
# octroyer Nombre de cliques 1360
# max score among faithfull cliques of 22 forms: 75.2952235737
# subordonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# bidouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# venger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# coasser Nombre de cliques 1372
# max score among faithfull cliques of 26 forms: 183.730285239
# concéder Nombre de cliques 1103
# max score among faithfull cliques of 26 forms: 190.828341078
# enrichir Nombre de cliques 1467
# max score among faithfull cliques of 25 forms: 92.4491986004
# carrer Nombre de cliques 984
# max score among faithfull cliques of 26 forms: 223.684343404
# galvauder Nombre de cliques 1283
# max score among faithfull cliques of 22 forms: 92.0530173934
# accrocher Nombre de cliques 1012
# max score among faithfull cliques of 26 forms: 210.845850483
# bitter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# motoriser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# mijoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# rééquilibrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# momifier Nombre de cliques 1351
# max score among faithfull cliques of 23 forms: 63.0480793935
# renter Nombre de cliques 918
# max score among faithfull cliques of 26 forms: 218.113081301
# poiroter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# ravir Nombre de cliques 2074
# max score among faithfull cliques of 24 forms: 87.2517720697
# grignoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# ennuyer Nombre de cliques 1304
# max score among faithfull cliques of 24 forms: 59.0380893219
# injecter Nombre de cliques 934
# max score among faithfull cliques of 26 forms: 218.113081301
# crailler Nombre de cliques 1363
# max score among faithfull cliques of 25 forms: 94.7428726699
# économiser Nombre de cliques 1279
# max score among faithfull cliques of 26 forms: 200.281734015
# idolâtrer Nombre de cliques 935
# ...
# stériliser Nombre de cliques 1247
# max score among faithfull cliques of 26 forms: 201.386693894
# convoiter Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 211.160497629
# trébucher Nombre de cliques 965
# max score among faithfull cliques of 26 forms: 221.282873499
# emménager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# rincer Nombre de cliques 1356
# max score among faithfull cliques of 26 forms: 186.395794474
# analyser Nombre de cliques 1259
# max score among faithfull cliques of 26 forms: 204.445678528
# émaner Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# antidater Nombre de cliques 927
# max score among faithfull cliques of 26 forms: 220.740277658
# vaquer Nombre de cliques 1045
# max score among faithfull cliques of 26 forms: 221.827379816
# serrer Nombre de cliques 1214
# no new faithfull clique, the previous one contained 24 forms
# cyanoser Nombre de cliques 1107
# no new faithfull clique, the previous one contained 21 forms
# festoyer Nombre de cliques 1432
# max score among faithfull cliques of 22 forms: 77.463877938
# faufiler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# persuader Nombre de cliques 1062
# max score among faithfull cliques of 26 forms: 212.475558127
# décompter Nombre de cliques 914
# max score among faithfull cliques of 26 forms: 218.113081301
# restituer Nombre de cliques 1338
# max score among faithfull cliques of 24 forms: 152.075769715
# détourner Nombre de cliques 939
# max score among faithfull cliques of 26 forms: 221.393416201
# cuiter Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 218.113081301
# prétexter Nombre de cliques 921
# max score among faithfull cliques of 26 forms: 219.42997753
# javelliser Nombre de cliques 1255
# max score among faithfull cliques of 26 forms: 203.900948653
# crasser Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 185.651032844
# ébahir Nombre de cliques 1491
# max score among faithfull cliques of 25 forms: 91.6921558644
# gainer Nombre de cliques 1056
# no new faithfull clique, the previous one contained 23 forms
# brailler Nombre de cliques 1363
# max score among faithfull cliques of 25 forms: 94.7428726699
# urger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# repeindre Nombre de cliques 1542
# max score among faithfull cliques of 24 forms: 96.8890100646
# tergiverser Nombre de cliques 1360
# no new faithfull clique, the previous one contained 26 forms
# fondre Nombre de cliques 1491
# max score among faithfull cliques of 27 forms: 95.5532991237
# dérouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# ressurgir Nombre de cliques 1462
# max score among faithfull cliques of 25 forms: 92.4491986004
# influencer Nombre de cliques 1366
# max score among faithfull cliques of 26 forms: 184.48223079
# ouvrir Nombre de cliques 1166
# max score among faithfull cliques of 26 forms: 82.4970283009
# déambuler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# renverser Nombre de cliques 1360
# no new faithfull clique, the previous one contained 26 forms
# dorer Nombre de cliques 1045
# max score among faithfull cliques of 26 forms: 211.21292346
# assermenter Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# raquer Nombre de cliques 1044
# max score among faithfull cliques of 26 forms: 221.827379816
# requinquer Nombre de cliques 923
# max score among faithfull cliques of 26 forms: 221.827379816
# bouger Nombre de cliques 1088
# max score among faithfull cliques of 26 forms: 218.910687211
# localiser Nombre de cliques 1252
# max score among faithfull cliques of 26 forms: 201.386693894
# déglutir Nombre de cliques 1567
# no new faithfull clique, the previous one contained 23 forms
# lésiner Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# endurcir Nombre de cliques 1797
# max score among faithfull cliques of 25 forms: 92.4491986004
# externaliser Nombre de cliques 1252
# max score among faithfull cliques of 26 forms: 201.386693894
# végéter Nombre de cliques 1556
# no new faithfull clique, the previous one contained 26 forms
# jauger Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# approuver Nombre de cliques 1664
# no new faithfull clique, the previous one contained 25 forms
# généraliser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# enfermer Nombre de cliques 974
# max score among faithfull cliques of 26 forms: 220.091827676
# défroquer Nombre de cliques 997
# max score among faithfull cliques of 26 forms: 211.44602099
# chuchoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# diluer Nombre de cliques 1319
# max score among faithfull cliques of 24 forms: 154.205496915
# brider Nombre de cliques 1071
# max score among faithfull cliques of 26 forms: 213.107017167
# mander Nombre de cliques 1073
# max score among faithfull cliques of 26 forms: 213.107017167
# incorporer Nombre de cliques 1062
# max score among faithfull cliques of 26 forms: 211.338556656
# déboîter Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 211.160497629
# frauder Nombre de cliques 1221
# max score among faithfull cliques of 22 forms: 104.329361401
# déminer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 224.994732473
# surnager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# succomber Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# jubiler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# rapatrier Nombre de cliques 1146
# max score among faithfull cliques of 24 forms: 64.4414222366
# surprendre Nombre de cliques 1820
# max score among faithfull cliques of 26 forms: 58.2635663852
# laper Nombre de cliques 927
# max score among faithfull cliques of 26 forms: 219.750957529
# boiter Nombre de cliques 975
# max score among faithfull cliques of 26 forms: 211.160497629
# reloger Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# offrir Nombre de cliques 1166
# max score among faithfull cliques of 26 forms: 82.2173599844
# dissiper Nombre de cliques 932
# max score among faithfull cliques of 26 forms: 220.724086728
# caractériser Nombre de cliques 1265
# max score among faithfull cliques of 26 forms: 200.281734015
# freiner Nombre de cliques 1058
# no new faithfull clique, the previous one contained 24 forms
# poisser Nombre de cliques 1445
# no new faithfull clique, the previous one contained 25 forms
# promettre Nombre de cliques 1905
# max score among faithfull cliques of 25 forms: 74.659806065
# culpabiliser Nombre de cliques 1254
# max score among faithfull cliques of 26 forms: 204.445678528
# déconseiller Nombre de cliques 1644
# no new faithfull clique, the previous one contained 24 forms
# climatiser Nombre de cliques 1260
# max score among faithfull cliques of 26 forms: 202.481695482
# suppléer Nombre de cliques 506
# max score among faithfull cliques of 19 forms: 85.2788573952
# médiatiser Nombre de cliques 1260
# max score among faithfull cliques of 26 forms: 202.481695482
# embrasser Nombre de cliques 1388
# max score among faithfull cliques of 26 forms: 185.651032844
# rationaliser Nombre de cliques 1252
# max score among faithfull cliques of 26 forms: 201.386693894
# suffire Nombre de cliques 1334
# max score among faithfull cliques of 25 forms: 71.9653811269
# endiguer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 224.994732473
# damner Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# réinstaurer Nombre de cliques 1062
# max score among faithfull cliques of 26 forms: 211.338556656
# précéder Nombre de cliques 1096
# max score among faithfull cliques of 26 forms: 186.85375597
# défouler Nombre de cliques 1412
# no new faithfull clique, the previous one contained 24 forms
# exhausser Nombre de cliques 1508
# max score among faithfull cliques of 26 forms: 169.540615503
# schtroumpfer Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 223.017992743
# baiser Nombre de cliques 1530
# no new faithfull clique, the previous one contained 23 forms
# glousser Nombre de cliques 1443
# max score among faithfull cliques of 26 forms: 195.557214046
# placer Nombre de cliques 1378
# max score among faithfull cliques of 26 forms: 183.730285239
# résumer Nombre de cliques 974
# max score among faithfull cliques of 26 forms: 219.714252679
# chroniquer Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 221.827379816
# marier Nombre de cliques 1281
# max score among faithfull cliques of 23 forms: 62.263478956
# tutoyer Nombre de cliques 1432
# max score among faithfull cliques of 22 forms: 77.463877938
# allonger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# puiser Nombre de cliques 974
# max score among faithfull cliques of 26 forms: 204.744835511
# faillir Nombre de cliques 689
# max score among faithfull cliques of 25 forms: 84.7475181551
# compenser Nombre de cliques 1373
# max score among faithfull cliques of 26 forms: 186.395794474
# signer Nombre de cliques 883
# max score among faithfull cliques of 25 forms: 183.418602948
# pistonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# patienter Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# évertuer Nombre de cliques 1268
# max score among faithfull cliques of 24 forms: 149.402356719
# minuter Nombre de cliques 943
# max score among faithfull cliques of 26 forms: 218.113081301
# éplucher Nombre de cliques 965
# max score among faithfull cliques of 26 forms: 221.282873499
# intellectualiser Nombre de cliques 1254
# no new faithfull clique, the previous one contained 24 forms
# interchanger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# espionner Nombre de cliques 998
# max score among faithfull cliques of 26 forms: 211.006341151
# faciliter Nombre de cliques 943
# max score among faithfull cliques of 26 forms: 218.113081301
# détériorer Nombre de cliques 609
# max score among faithfull cliques of 21 forms: 93.6242544916
# jouir Nombre de cliques 1502
# max score among faithfull cliques of 25 forms: 96.1318912178
# transfuser Nombre de cliques 1369
# max score among faithfull cliques of 26 forms: 209.570586777
# chercher Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 220.624088182
# repentir Nombre de cliques 1116
# max score among faithfull cliques of 27 forms: 76.1870154277
# nuire Nombre de cliques 1474
# max score among faithfull cliques of 25 forms: 83.0300898862
# désolidariser Nombre de cliques 1263
# max score among faithfull cliques of 26 forms: 200.281734015
# jumeler Nombre de cliques 1814
# max score among faithfull cliques of 26 forms: 154.377431817
# bégayer Nombre de cliques 1524
# max score among faithfull cliques of 24 forms: 65.8622691978
# dédicacer Nombre de cliques 1385
# max score among faithfull cliques of 26 forms: 185.651032844
# coiffer Nombre de cliques 1002
# max score among faithfull cliques of 26 forms: 216.031612379
# lober Nombre de cliques 998
# max score among faithfull cliques of 26 forms: 211.006341151
# dessouler Nombre de cliques 1412
# no new faithfull clique, the previous one contained 24 forms
# subodorer Nombre de cliques 1060
# max score among faithfull cliques of 26 forms: 208.634027536
# réfréner Nombre de cliques 1058
# no new faithfull clique, the previous one contained 24 forms
# moyenner Nombre de cliques 1120
# no new faithfull clique, the previous one contained 26 forms
# saigner Nombre de cliques 1227
# max score among faithfull cliques of 22 forms: 113.225446207
# plaquer Nombre de cliques 1044
# max score among faithfull cliques of 26 forms: 221.827379816
# réquisitionner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# fourguer Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# broder Nombre de cliques 1221
# max score among faithfull cliques of 22 forms: 104.329361401
# douter Nombre de cliques 1135
# max score among faithfull cliques of 26 forms: 217.275720461
# préserver Nombre de cliques 1589
# no new faithfull clique, the previous one contained 26 forms
# rebeller Nombre de cliques 1340
# max score among faithfull cliques of 26 forms: 197.072908608
# radoter Nombre de cliques 988
# max score among faithfull cliques of 26 forms: 207.902212309
# mordiller Nombre de cliques 1405
# max score among faithfull cliques of 22 forms: 93.2831063195
# arrêter Nombre de cliques 1556
# no new faithfull clique, the previous one contained 26 forms
# annuler Nombre de cliques 1184
# max score among faithfull cliques of 26 forms: 221.964291612
# craqueler Nombre de cliques 1853
# max score among faithfull cliques of 26 forms: 152.125179304
# conspirer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 223.976560859
# comparer Nombre de cliques 984
# max score among faithfull cliques of 26 forms: 223.684343404
# atterrir Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 86.7086075965
# renseigner Nombre de cliques 1227
# max score among faithfull cliques of 22 forms: 113.225446207
# envisager Nombre de cliques 942
# max score among faithfull cliques of 26 forms: 223.017992743
# occuper Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.750957529
# marbrer Nombre de cliques 935
# max score among faithfull cliques of 26 forms: 221.784932038
# dresser Nombre de cliques 1409
# no new faithfull clique, the previous one contained 25 forms
# disculper Nombre de cliques 894
# max score among faithfull cliques of 26 forms: 222.037189976
# encastrer Nombre de cliques 928
# max score among faithfull cliques of 26 forms: 222.143965227
# rapetisser Nombre de cliques 1296
# max score among faithfull cliques of 26 forms: 187.586241667
# blasphémer Nombre de cliques 1028
# max score among faithfull cliques of 26 forms: 194.055256958
# éteindre Nombre de cliques 1821
# max score among faithfull cliques of 24 forms: 99.5723894448
# apprécier Nombre de cliques 1647
# max score among faithfull cliques of 22 forms: 55.4604934564
# raidir Nombre de cliques 1541
# max score among faithfull cliques of 25 forms: 89.7578931743
# dénicher Nombre de cliques 961
# max score among faithfull cliques of 26 forms: 222.220349757
# baigner Nombre de cliques 1227
# max score among faithfull cliques of 25 forms: 158.35465817
# aviser Nombre de cliques 1249
# no new faithfull clique, the previous one contained 23 forms
# éclaircir Nombre de cliques 1797
# max score among faithfull cliques of 25 forms: 91.7671044637
# pérenniser Nombre de cliques 1258
# no new faithfull clique, the previous one contained 25 forms
# décrire Nombre de cliques 1838
# max score among faithfull cliques of 23 forms: 47.9122236907
# démettre Nombre de cliques 1924
# max score among faithfull cliques of 25 forms: 76.3489312481
# rééquiper Nombre de cliques 932
# max score among faithfull cliques of 26 forms: 219.515517586
# entailler Nombre de cliques 1379
# max score among faithfull cliques of 25 forms: 101.326513039
# réinviter Nombre de cliques 950
# max score among faithfull cliques of 26 forms: 219.42997753
# augmenter Nombre de cliques 925
# max score among faithfull cliques of 26 forms: 219.42997753
# bouleverser Nombre de cliques 1360
# no new faithfull clique, the previous one contained 26 forms
# délurer Nombre de cliques 983
# max score among faithfull cliques of 26 forms: 222.014455443
# déverrouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# piger Nombre de cliques 941
# max score among faithfull cliques of 26 forms: 223.017992743
# évanouir Nombre de cliques 1767
# max score among faithfull cliques of 25 forms: 90.8416412251
# tonner Nombre de cliques 1000
# max score among faithfull cliques of 26 forms: 212.579284996
# répertorier Nombre de cliques 1363
# max score among faithfull cliques of 23 forms: 67.2822138631
# trifouiller Nombre de cliques 1648
# max score among faithfull cliques of 24 forms: 131.994547819
# CPU times: user 1h 43min 17s, sys: 1min 16s, total: 1h 44min 34s
# Wall time: 1h 44min 18s

# %%
newParadigmes,paradigmesSwim2,characteristicsSwim2,measuresSwim2=calculerResultats(swim2ContextParadigmes,"-Swim2")
# Out:
# Index([u'value', u'lexeme-case'], dtype='object')
# UG 52099 OG 17756 TP 133228 FP 15005
# recall 0.665036040173 precision 0.802631499678
# 0.727383906465

# %%
nomFichierResultats=filePrefix+"-X-Resultats.yaml"
if os.path.isfile(nomFichierResultats):
    with open(nomFichierResultats, 'r') as stream:
            resultats=yaml.load(stream)
else:
    resultats={}

if casesType:
    sampleExt=casesType
else:
    sampleExt=sampleType
sampleId=sampleNumber.strip("-")+sampleExt
resultats[sampleId]={}
resultats[sampleId]["Swim1"]={}
resultats[sampleId]["Swim1"]["UG"]=characteristicsSwim1[0]
resultats[sampleId]["Swim1"]["OG"]=characteristicsSwim1[1]
resultats[sampleId]["Swim1"]["TP"]=characteristicsSwim1[2]
resultats[sampleId]["Swim1"]["FP"]=characteristicsSwim1[3]
resultats[sampleId]["Swim1"]["Precision"]=measuresSwim1[0]
resultats[sampleId]["Swim1"]["Recall"]=measuresSwim1[1]
resultats[sampleId]["Swim1"]["F-Measure"]=measuresSwim1[2]
resultats[sampleId]["Swim2"]={}
resultats[sampleId]["Swim2"]["UG"]=characteristicsSwim2[0]
resultats[sampleId]["Swim2"]["OG"]=characteristicsSwim2[1]
resultats[sampleId]["Swim2"]["TP"]=characteristicsSwim2[2]
resultats[sampleId]["Swim2"]["FP"]=characteristicsSwim2[3]
resultats[sampleId]["Swim2"]["Precision"]=measuresSwim2[0]
resultats[sampleId]["Swim2"]["Recall"]=measuresSwim2[1]
resultats[sampleId]["Swim2"]["F-Measure"]=measuresSwim2[2]

yaml.safe_dump(resultats, file(nomFichierResultats, 'w'), encoding='utf-8', allow_unicode=True)

# %%
# %ding
# %ding

# %%
print ("Sample",sampleNumber.strip("-"))
print ("Swim1",characteristicsSwim1,measuresSwim1)
print ("Swim2",characteristicsSwim2,measuresSwim2)

# %% [markdown]
# # Fin du traitement

# %%
paradigmesSwim2.columns.tolist()[25:]

# %%
paradigmesSwim2.pc1S

# %% [markdown]
# # Calcul des distances

# %% [markdown]
# ### Préparation des fichiers de référence
# La comparaison se fait sur les lexèmes de *listeTest*
# - initialForms : les formes initiales
# - finalForms : les formes initiales plus les formes prédites
# - goldForms : les formes de référence

# %% [markdown]
# #### Formes initiales

# %% [raw]
# initialForms=pd.melt(paradigmesSample[paradigmesSample["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
# initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
#
# initialForms.set_index(["lexeme-case"],inplace=True)
#
# initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# #### Formes avec prédictions

# %% [raw]
# finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
# finalParadigmes.to_csv(path_or_buf=analysisPrefix+"-paradigmes-Swim2.csv",encoding="utf8",sep=";")
# finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
# finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
# finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
# finalTestForms.set_index(["lexeme-case"],inplace=True)

# %% [markdown]
# #### Formes de référence
# - recoder les représentations phonologiques en fonction de l'échantillon

# %% [raw]
# with open(goldPrefix+"/"+goldFile,"rb") as input:
#     lexiqueGold=pickle.load(input)
#
# lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
#
# completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
#
# goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# #goldTestForms
#
# goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
# goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
#
# goldTestForms.set_index(["lexeme-case"],inplace=True)

# %% [raw]
# #goldFormsIndex=goldForms.index.tolist()

# %% [markdown]
# ### Soustraction des formes initiales

# %% [raw]
# finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
# finalFormsIndex=finalForms.index.tolist()
# #initialForms.loc[~initialForms.index.isin(finalFormsIndex)]

# %% [raw]
# #finalForms[finalForms.index.str.contains("asseoir")]

# %% [raw]
# #goldTestForms[goldTestForms.index.str.contains("asseoir")]

# %% [raw]
# goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
# goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #goldForms[goldForms.index.str.contains("asseoir")]

# %% [raw]
# print (finalFormsIndex)
# goldForms[~goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# ### Évaluation des formes

# %% [markdown]
# #### Problèmes de génération
# - sous-génération : formes de références sans prédiction
# - sur-génération : formes prédites absentes de la référence

# %% [raw]
# underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
# overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]

# %% [markdown]
# #### Formes comparables
# - *predictedForms* => formes prédites présentes dans la référence
# - *actualForms* => formes de référence présentes dans les prédictions

# %% [raw]
# predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
# actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# #### Préparation de la comparaison
# - *compareForms* => tableau avec les formes à comparer

# %% [raw]
# compareForms=predictedForms.copy()
# compareForms.loc[:,"right"]=actualForms.loc[:,"value"]

# %% [markdown]
# #### Comparaison des formes
# - *sameForms* => formes identiques dans les prédictions et la référence
# - *diffForms* => formes différentes dans les prédictions et la référence

# %% [raw]
# sameForms=compareForms[compareForms["value"]==compareForms["right"]]
# diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

# %% [markdown]
# #### Décompte du nombre de formes
# À cause du traitement de la surabondance, le décompte des lignes ne tient pas compte du nombre de formes. Il faut compter les formes dans chaque ligne pour obtenir le nombre total.

# %% [raw]
# def countSplits(dfForms):
#     dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
#     return dfForms["split"].str.len().sum()

# %% [markdown]
# #### Évaluation des différences
# Certaines différences ne sont qu'apparentes à cause du traitement de la surabondance sous forme de chaine concaténée. Il faut transformer les surabondances en set() pour pouvoir faire une comparaison pertinente.

# %% [raw]
# def evaluateDiffForms(diffForms):
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
#
#     nbValues=diffForms["split-value"].str.len().sum()
#     nbRights=diffForms["split-right"].str.len().sum()
# #    print (nbValues,nbRights)
#
#     nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
#     nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
#
#     return (nbIdenticalSets,nbIncludedSets,(nbValues-nbIdenticalSets-nbIncludedSets),(nbRights-nbIdenticalSets-nbIncludedSets))

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus=evaluateDiffForms(diffForms)
# #evaluateDiffForms(diffForms)

# %% [markdown]
# #### Calcul des grandeurs de mesure

# %% [raw]
# UG=countSplits(underGeneration)+underBonus
# OG=countSplits(overGeneration)
# TP=countSplits(sameForms)+identicalBonus+partialBonus
# FP=wrongBonus
# recall=float(TP)/(UG+TP+FP)
# precision=float(TP)/(OG+TP+FP)
# print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
# print ("recall", recall, "precision", precision)
#
# fMeasure=2*recall*precision/(recall+precision)
# fMeasure

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus

# %% [raw]
# countSplits(underGeneration),countSplits(overGeneration),countSplits(sameForms)

# %% [markdown]
# ### Sauvegarde des résultats pour analyse ultérieure

# %% [raw]
# overGeneration.to_csv(path_or_buf=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration.to_csv(path_or_buf=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# sameForms.to_csv(path_or_buf=analysisPrefix+"-sameForms.csv",encoding="utf8")
# diffForms.to_csv(path_or_buf=analysisPrefix+"-diffForms.csv",encoding="utf8")

# %% [markdown]
# ## Analyse des sur-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# overGeneration.loc[:,"case"]=overGeneration.index.str.rsplit("-").str[-1]

# %% [raw]
# casesOverGeneration=overGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# casesOverGeneration.plot(kind="bar",figsize=(20,5))

# %% [raw]
# casesOverGeneration[:3].sum()/casesOverGeneration.sum()

# %% [markdown]
# Le facteur principal de **surgénération** est la production de **participes passés** (ppMP 662, ppFS 661, ppFP 661) pour les verbes qui n'ont qu'une seule forme de participe passé invariable (ppMS) : **54.78%** (1984/3622).

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# overGeneration.loc[:,"verbe"]=overGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesOverGeneration=overGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
# verbesOverGeneration[:54].plot(kind="bar",figsize=(20,5))

# %% [markdown]
# Le facteur principal de **surgénération** tient aux **verbes vestiges** et aux **météorologiques**.

# %% [markdown]
# ## Analyse des sous-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# underGeneration.loc[:,"case"]=underGeneration.index.str.rsplit("-",1).str[-1]

# %% [raw]
# casesUnderGeneration=underGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# ax=casesUnderGeneration[:9].plot(kind="bar",figsize=(20,5))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Verbs missing the form",fontsize=16)
# print ("Total sous-générations :",casesUnderGeneration.sum().values[0])

# %% [raw]
# def ratioAnalyses(df,chaine):
#     return df[df.index.str.contains(chaine)].sum().values[0],df.sum().values[0],(df[df.index.str.contains(chaine)].sum()/df.sum()).values[0]

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"is")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"ai")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"2P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"1P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"pi")

# %% [markdown]
# Le facteur principal de **sous-génération** est lié à la fréquence des TAM et de certaines personnes :
# - TAM :
#  - imparfait du subjonctif 45.98% (7875/17126)
#  - passé simple 12.70% (2176/17126)
# - Personnes :
#  - 2PL 46.11% (7897/17126)
#  - 1PL 32.98% (5649/17126)

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# underGeneration.loc[:,"verbe"]=underGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesUnderGeneration=underGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
#
# ax=verbesUnderGeneration[:50].plot(kind="bar",figsize=(40,5))
# ax.set_xlabel("Verbes",fontsize=16)
# ax.set_ylabel("Number of Missing Forms",fontsize=16)

# %% [markdown]
# # Fin de l'analyse des résultats

# %% [raw]
# overGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# goodForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-goodForms.csv",encoding="utf8")
# wrongForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-wrongForms.csv",encoding="utf8")

# %% [raw]
# len(overGeneration), len(underGeneration), len(goodForms), len(wrongForms)

# %% [raw]
# wrongForms["rightChecked"]=wrongForms["right"].apply(checkFrench)
# wrongForms["valueChecked"]=wrongForms["value"].apply(checkFrench)

# %% [raw]
# wrongForms[wrongForms["valueChecked"]!=wrongForms["rightChecked"]]

# %% [raw]
# goodForms[goodForms["value"].str.contains(",")]

# %% [raw]
# set(overGeneration["lexeme-case"].str.rsplit("-").str[0].tolist())

# %% [raw]
# underGeneration["case"]=underGeneration["lexeme-case"].str.rsplit("-").str[-1]

# %% [raw]
# underGeneration.groupby("case").count()["value"].sort_values(ascending=False)

# %% [raw]
# finalParadigmes=extendParadigmes(savedContextParadigmes,extendMorphomes=True)

# %% [raw]
# test["ppMS"]

# %% [raw]
# def repairContextParadigmes(contextParadigmes):
#     repaired={}
#     for sCP in contextParadigmes.keys():
#     #    noLexeme=False
#         repaired[sCP]=[]
#         for numClique,clique in enumerate(contextParadigmes[sCP]):
#             repaired[sCP].append(clique)
#     #        noLexemeElements=[]
#     #        withLexemeElements=[]
#             for numElement,element in enumerate(clique):
#                 if not len(element.split("-"))>2 or not element.startswith(sCP):
#                     print (sCP+"-"+element)
#                     repaired[sCP][numClique][numElement]=sCP+"-"+element
#     #                noLexemeElements.append(element)
#     #            else:
#     #                withLexemeElements.append(element)
#     #        if noLexemeElements:
#     #            print (sCP)
#     #            print (noLexemeElements)
#     #            print (withLexemeElements)
#     #            print ()
#     #        noLexeme=False
#     return repaired

# %% [raw]
# repairContextParadigmes(contextParadigmes)[u"féminiser"]

# %% [markdown]
# ### Test de la sauvegarde de l'analyse brute

# %% [markdown]
# ## with open(analysisPrefix+"-analyseParadigmes.pkl","rb") as input:
#     savedAnalyseParadigmes = pickle.load(input)

# %% [raw]
# savedContextParadigmes=savedAnalyseParadigmes[0]
# savedCliques=savedAnalyseParadigmes[1]
# savedCliquesScores=savedAnalyseParadigmes[2]
# savedCliquesListes=savedAnalyseParadigmes[3]
# #savedFormesScores=savedAnalyseParadigmes[4]
# #savedFormesScoresNormes=savedAnalyseParadigmes[5]

# %% [raw]
# generateForms(u"crépir",contextFree=True).formes

# %% [raw]
# if genFormeVotes:
#     fScores=(formesScores,formesScoresNormes)
#     with open(analysisPrefix+paperPrefix+'-Scores.pkl', 'wb') as output:
#         pickle.dump(fScores, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# %%time
# versionStamp=dateheure()
# if genDigraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globDigraphe,analysisPrefix+paperPrefix+u"-digraphe-%s.gexf"%versionStamp)
# if genGraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globGraphe,analysisPrefix+paperPrefix+u"-graphe-%s.gexf"%versionStamp)

# %% [raw]
# print (len(cliques))

# %% [raw]
# if genCliques:
#     infoCliques={"cliques":cliques, "cliquesScores":cliquesScores, "cliquesListes":cliquesListes}
#     with open(analysisPrefix+paperPrefix+'-Network.pkl', 'wb') as output:
#         pickle.dump(infoCliques, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# print (paradigmes[paradigmes["lexeme"]==lexeme].to_latex(na_rep=""))

# %% [raw]
# HTML(makeTable(dictParadigmes[lexeme],title=lexeme))

# %% [raw]
# print (len(sampleCases),sampleCases,paradigmes["lexeme"].count())
# nbCoformes=paradigmes.notnull().sum(axis=1)-1
# distNbCoformes=nbCoformes.groupby(by=nbCoformes).count()
# ax=distNbCoformes.plot(kind="bar",legend=False,grid=True,figsize=(10,3))
# ax.set(xlim=(-0.5,32),ylim=(0,600))
# ax.set_xlabel("Number of Co-Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["lexeme"]==u"être") & (sampleTirage["tir1"]!=0)]

# %% [raw]
# freqCasesSampleTirage=sampleTirage[sampleTirage["tir1"]!=0].groupby("case")[["lexeme"]].count().sort_values("lexeme",ascending=False)
# ax=freqCasesSampleTirage.plot(kind="bar",legend=False,grid=True,figsize=(10,5))
# ax.set(xlim=(-0.5,32.5),ylim=(0,5000))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# coFormes=paradigmes.copy()
# coFormes["nbCoformes"]=coFormes.notnull().sum(axis=1)-1
# singletonLexemes=coFormes[coFormes["nbCoformes"]==1]["lexeme"].tolist()
# print (coFormes["nbCoformes"].sum(),len(singletonLexemes))

# %% [raw]
# freqCaseSingleton=sampleTirage[(sampleTirage["tir1"]!=0) & (sampleTirage["lexeme"].isin(singletonLexemes))][["case","morphome"]].groupby("case").count()
# ax=freqCaseSingleton.sort_values("morphome",ascending=False).plot(kind="bar",legend=False,grid=True,figsize=(8,3))
# ax.set(xlim=(-0.25,17),ylim=(0,200))
# ax.set_xlabel("Isolated Form",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["tir1"]!=0)]["tir1"].sum()

# %% [raw]
# recoder("degrosirje")

# %% [markdown]
# # Génération des réseaux de formes à partir des règles
# - Swim1 basé sur l'échantillon initial
#  - Gén-1 : génération des formes d'après les contextes phonologiques
#  - Gén-2 : génération du réseau d'après les contextes phonologiques
#  - Filt-1 : extraction du sous-réseau symétrique
#  - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
#  - Filt-3 : extraction des cliques maximales & fidèles
# - Swim2 basé sur le réseau calculé par Swim1
#  - Exp : génération d'un nouvel échantillon basé sur Swim1
#  - Gén-1 : génération des formes sans contexte phonologique
#  - Gén-2 : génération du réseau sans contexte phonologique
#  - Filt-1 : extraction du sous-réseau symétrique
#  - Filt-2 : génération du réseau non-orienté correspondant à Filt-1
#  - Filt-3 : extraction des cliques maximales & fidèles
# - Évaluation

# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs,operator,datetime,os,glob
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
import networkx as nx
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False
from __future__ import print_function

def ding():
    os.system('afplay /System/Library/Sounds/Submarine.aiff')

# %%
# %matplotlib inline

# %%
import yaml

# %%
from ipywidgets import FloatProgress
from IPython.display import display, HTML

# %%
import datetime
def dateheure():
    return datetime.datetime.utcnow().strftime('%y%m%d%H%M')

# %%
saut="\n"

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %% [markdown]
# # Choix de l'échantillon et des règles
# - *sampleFile* est le nom de l'échantillon de départ
# - *rulesFile* est le nom du fichier de règles
# - *goldFile* est le nom du lexique Gold de référence

# %%
repFiles="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/L4L/IMM21/"
# sampleFile="IMM21-00-X-paradigmes.csv"
sampleFile="IMM21-01-X-Morphomes.csv"
# tirageFile="IMM21-00.pkl"
tirageFile="IMM21-01-X-Morphomes.pkl"
# rulesFile="IMM21-00-X-Regles.pkl"
rulesFile="IMM21-01-X-Morphomes-Regles.pkl"
repGold="/Volumes/BroadExt/ownCloud/Recherche/Boye/HDR/Data/Samples/"
goldFile="MGC-171229-Verbes3.pkl"
fSample=repFiles+sampleFile
fInitial=fSample
fTirage=repFiles+tirageFile
fRules=repFiles+rulesFile
fGold=repGold+goldFile

# %%
sampleType="-X"
casesType=""
casesType="-Morphomes"
listeFormesOutput=["FS","FP"]

# %%
genDigraphe=False
genGraphe=False
genFormeVotes=True
genCliques=True
plotDistributionCliques=False

# %%
with open(fTirage, 'rb') as input:
    sampleTirage = pickle.load(input)
sampleTirage.head()
# Out:
#     lexeme  phono  case   morphome  freq  tir1
# 0  gauchir  gOSir   inf        inf     1     1
# 1  gauchir   gOSi  ppMS  ppMP/ppMS     1     1
# 2  gauchir   gOSi  ppFS  ppFS/ppFP     1     1
# 3  gauchir   gOSi  pi3S  pi2S/pi3S     1     1
# 4   évider  Evidâ    pP         pP     1     1

# %%
if not "morphome" in sampleTirage.columns.tolist():
    sampleTirage["morphome"]=sampleTirage["case"]
morphomeCases=sampleTirage[["case","morphome"]].drop_duplicates().to_dict()
# morphomeCases

# %%
casesMC=morphomeCases["case"]
morphomesMC=morphomeCases["morphome"]
dictMorphomeCases={}
for element in casesMC:
    dictMorphomeCases[casesMC[element]]=morphomesMC[element].split("/")
dictMorphomeCases
# Out:
# {u'ai1P': [u'ai1P'],
#  u'ai1S': [u'ai1S'],
#  u'ai2P': [u'ai2P'],
#  u'ai3P': [u'ai3P'],
#  u'ai3S': ['ai3S', 'ai2S', 'is3S'],
#  u'fi2P': [u'fi2P'],
#  u'fi3P': ['fi3P', 'fi1P'],
#  u'fi3S': ['fi2S', 'fi3S'],
#  u'ii1P': [u'ii1P'],
#  u'ii2P': [u'ii2P'],
#  u'ii3S': ['ii1S', 'ii3S', 'ii2S', 'ii3P'],
#  u'inf': [u'inf'],
#  u'is1P': [u'is1P'],
#  u'is2P': [u'is2P'],
#  u'is3P': ['is3P', 'is2S', 'is1S'],
#  u'pI1P': [u'pI1P'],
#  u'pI2P': [u'pI2P'],
#  u'pI2S': [u'pI2S'],
#  u'pP': [u'pP'],
#  u'pc1P': [u'pc1P'],
#  u'pc2P': [u'pc2P'],
#  u'pc3S': ['pc2S', 'pc3S', 'pc3P', 'pc1S', 'fi1S'],
#  u'pi1P': [u'pi1P'],
#  u'pi1S': [u'pi1S'],
#  u'pi2P': [u'pi2P'],
#  u'pi3P': [u'pi3P'],
#  u'pi3S': ['pi2S', 'pi3S'],
#  u'ppFS': ['ppFS', 'ppFP'],
#  u'ppMS': ['ppMP', 'ppMS'],
#  u'ps1P': [u'ps1P'],
#  u'ps2P': [u'ps2P'],
#  u'ps3S': ['ps3S', 'ps3P', 'ps2S', 'ps1S']}

# %% [markdown]
# ### Choix original

# %% [raw]
# filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/LongitudinalesRnd/Longitudinal"
# filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/lexique3/Longitudinal-Lexique3"
# filePrefix="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/L4L/IMM21/"
# sampleFiles=glob.glob(filePrefix+"*.pkl")
# def prefixEchantillon(numero,sampleType="",casesType=""):
#     candidats=[]
# #    matchFile=ur"^.*/Longitudinal(-%s-T\d+-F\d+)%s\.pkl"%(numero,sampleType+casesType)
#     matchFile=ur"^.*/Longitudinal-Lexique3(-%s-T\d+-F\d+)%s\.pkl"%(numero,sampleType+casesType)
#     print (matchFile)
#     for sample in sampleFiles:
#         m=re.match(matchFile,sample)
#         if m:
# #            print (sample)
# #            print (m.group(1))
#             candidats.append(m.group(1))
#     if len(candidats)==1:
#         return candidats[0]
#     else:
#         print ("PB pas de nom unique correspondant",len(candidats),numero,sampleType,casesType)

# %% [raw]
# goldPrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/"
# goldFile="MGC-171229-Verbes3.pkl"

# %% [raw]
# sampleNumero="00"
# sampleType="-X"
# casesType="-Morphomes"
# #sampleType=""
# casesType=""
# print (sampleNumero,sampleType,casesType)
# if casesType:
#     sampleNumber=prefixEchantillon(sampleNumero,sampleType,casesType)
# else:
#     sampleNumber=prefixEchantillon(sampleNumero)
# print (sampleNumber)
# paperPrefix="-ISMo"
# paperPrefix="IMM21"
# genFormeVotes=True
# genCliques=True
# listeFormesOutput=["FS","FP"]
# genDigraphe=False
# genGraphe=False
# plotDistributionCliques=False
# samplePrefix=filePrefix+"%s-X"%(sampleNumber)
#     tirageFile=filePrefix+sampleNumber+".pkl"
# sampleFile=samplePrefix+"-paradigmes.csv"
# initialFile=filePrefix+prefixEchantillon(sampleNumero)+sampleType+"-paradigmes.csv"
# print (initialFile)
# analysisPrefix=samplePrefix
# if debug:
#     logfile_name=analysisPrefix+"-network.log"
#     logfile = codecs.open(logfile_name,mode='w',encoding="utf8")

# %% [raw]
# #tirage=filePrefix+'-'+sampleNumber+'-Tirage-'+sampleType+'-170503-1907'+casesType+'.pkl'
# #tirage=filePrefix+sampleNumber+casesType+'.pkl'
# with open(tirageFile, 'rb') as input:
#     sampleTirage = pickle.load(input)

# %% [raw]
# if not "morphome" in sampleTirage.columns.tolist():
#     sampleTirage["morphome"]=sampleTirage["case"]
# morphomeCases=sampleTirage[["case","morphome"]].drop_duplicates().to_dict()
# morphomeCases

# %% [raw]
# casesMC=morphomeCases["case"]
# morphomesMC=morphomeCases["morphome"]
# dictMorphomeCases={}
# for element in casesMC:
#     dictMorphomeCases[casesMC[element]]=morphomesMC[element].split("/")
# dictMorphomeCases

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            if debug: print ("le numéro de forme n'est pas dans [1,2]",n, file=logfile)

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
        self.classeCF={}
        self.nbClasseCF={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeFormeCF=[]
        regleFormeCF=""
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            filterF1=".*"+patron.split("-")[0]+"$"
            if re.match(filterF1,forme1):
                classeFormeCF.append(patron)
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleFormeCF=patron
            filterF1=self.patrons[patron]
            if re.match(filterF1,forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseFormeCF=", ".join(classeFormeCF)
        if not idClasseFormeCF in self.classeCF:
            self.classeCF[idClasseFormeCF]={}
            self.nbClasseCF[idClasseFormeCF]=0
        if not regleFormeCF in self.classeCF[idClasseFormeCF]:
            self.classeCF[idClasseFormeCF][regleFormeCF]=0
        self.nbClasseCF[idClasseFormeCF]+=1
        self.classeCF[idClasseFormeCF][regleFormeCF]+=1
        
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme,contextFree=True):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if contextFree:
                filterF1=".*"+patron.split("-")[0]+"$"
            else:
                filterF1=self.patrons[patron]
            if re.match(filterF1,forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if contextFree:
                nbClasse=self.nbClasseCF
                classe=self.classeCF
            else:
                nbClasse=self.nbClasse
                classe=self.classe
            if idClasseForme in nbClasse:
                nTotal=nbClasse[idClasseForme]
                for patron in classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(classe[idClasseForme][patron])/nTotal
            else:
                if debug:
                    print (forme, file=logfile)
                    print ("pas de classe",idClasseForme, file=logfile)
                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            if debug:
                print (forme, file=logfile) 
                print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# # Lecture de l'échantillon

# %%
phonologicalMap=sampleType.strip("-")
if debug: print(phonologicalMap)
neutralisationsNORD=(u"6û",u"9ê")
neutralisationsSUD=(u"e2o",u"E9O")
if phonologicalMap=="N":
    neutralisations=neutralisationsNORD
elif phonologicalMap=="S":
    neutralisations=neutralisationsSUD
else:
    neutralisations=(u"",u"")
    phonologicalMap=("X")
bdlexiqueIn = unicode(u"èò"+neutralisations[0])
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO"+neutralisations[1])
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    else:
        result=chaine
    return result

# %% [markdown]
# ### Vérification de la phonotactique des glides du français
# - si *prononciation* est *None* renvoyer *None*
# - ajout de diérèses dans les séquences mal-formées
# - vérification des séquences consonne+glide à la finale

# %%
dierese={"j":"ij", "w":"uw","H":"yH","i":"ij","u":"uw","y":"yH"}

# %%
def checkFrench(prononciation):
    if prononciation:
        result=recoder(prononciation)
        m=re.match(ur"^.*([^ieèEaOouy926êôâ])[jwH]$",result)
        if m:
            print ("pb avec un glide final", prononciation)
        m=re.match(ur"(.*[ptkbdgfsSvzZ][rl])([jwH])(.*)",result)
        if m:
            n=re.search(ur"[ptkbdgfsSvzZ][rl](wa|Hi|wê)",result)
            if not n:
                glide=m.group(2)
                result=m.group(1)+dierese[glide]+m.group(3)
        m=re.match(ur"(.*)([iuy])([ieEaOouy].*)",result)
        if m:
            glide=m.group(2)
            result=m.group(1)+dierese[glide]+m.group(3)
        result=result.replace("Jj","J")
    else:
        result=prononciation
    return result

# %%
paradigmes=pd.read_csv(fSample,sep=";",encoding="utf8")
del paradigmes[u"Unnamed: 0"]
paradigmes=paradigmes.dropna(axis=1,how='all')

# %%
goldCases=paradigmes.columns.tolist()
goldCases.remove("lexeme")
#goldCases

# %% [markdown]
# - sampleCases pour la liste des cases effectivement représentées dans le corpus de départ

# %%
sampleCases=paradigmes.columns.values.tolist()
sampleCases.remove(u"lexeme")
#sampleCases

# %%
paradigmes.stack().value_counts(dropna=True).sum()
# Out:
# 80820

# %%
len(paradigmes.dropna(thresh=1)["lexeme"])
# Out:
# 6433

# %% [markdown]
# ## Préparation des données initiales et de référence

# %%
listeTest=paradigmes.dropna(thresh=1)["lexeme"].values.tolist()
#listeTest=[u"asseoir",u"balayer",u"manger"]
nbVerbes=len(listeTest)
print (nbVerbes)
# Out:
# 6433

# %% [markdown]
# ### Préparation des formes initiales

# %%
initialParadigmes=pd.read_csv(fInitial,sep=";",encoding="utf8")
del initialParadigmes[u"Unnamed: 0"]
initialParadigmes=initialParadigmes.dropna(axis=1,how='all')

# %%
initialForms=pd.melt(initialParadigmes[paradigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()

initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)

initialForms.set_index(["lexeme-case"],inplace=True)

initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# ### Préparation des formes de référence

# %%
#with open(goldPrefix+"/"+goldFile,"rb") as input:

# with open(goldPrefix+goldFile,"rb") as input:
#     lexiqueGold=pickle.load(input)
lexiqueGold=pd.read_pickle(path=fGold)

'''Rectifications phonologiques'''
lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

'''Mise en liste des formes de références'''
goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
goldTestForms.set_index(["lexeme-case"],inplace=True)

'''Extraction des formes de références pertinentes'''
goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #paradigmes
# #analyseCases
# lexeme=u"découper"
# paradigmes[paradigmes["lexeme"]==lexeme].columns[paradigmes[paradigmes["lexeme"]==lexeme].notnull().iloc[0]].tolist()

# %% [markdown]
# # Lecture des règles

# %%
with open(fRules, 'rb') as input:
    resultatsLecture = pickle.load(input)

# %% [markdown]
# ### Comparer les cases analysées avec l'ensemble de toutes les cases

# %%
analyseCases=list(set([case for (case,autre) in resultatsLecture.keys()]))
if sorted(analyseCases)!=sorted(goldCases):
    print ("Attention l'analyse ne comprend pas toutes les cases")
    print (sorted(analyseCases))
    print (sorted(goldCases))

# %% [markdown]
# # Préparations pour la génération des formes

# %%
class paradigmeDistribution:
    '''
    Gestion des distributions dans les cases du paradigme
    '''

    def __init__(self,lexeme):
        self.lexeme=lexeme
        self.formes={i:{} for i in analyseCases}

    def ajouterFormes(self,case,formes,coef=1.0):
        for forme in formes:
            if not forme in self.formes[case]:
                self.formes[case][forme]=0
            self.formes[case][forme]+=formes[forme]*coef
            
    def normaliserDistributions(self,caseListe=analyseCases):
        normalesDistributions={i:{} for i in caseListe}
        for case in caseListe:
            total=0
            for element in self.formes[case]:
                total+=self.formes[case][element]
            for element in self.formes[case]:
                normalesDistributions[case][element]=float(self.formes[case][element])/total
        return normalesDistributions

# %%
def generateForms(lexeme,contextFree=False):
    # pb avec l'encodage des noms de lexèmes
    candidats=paradigmeDistribution(lexeme)
    bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
    casesSamples=paradigmes[bLexParadigme].columns[paradigmes[bLexParadigme].notnull().iloc[0]].tolist()
    casesSamples.remove("lexeme")
    for caseDepart in casesSamples:
        formeDepart=paradigmes[bLexParadigme][caseDepart].iloc[0]
        if debug: print (caseDepart,formeDepart, file=logfile)
#        if formeDepart!="nan":
        for case in analyseCases:
            if debug: print (case, file=logfile)
            if not isinstance(resultatsLecture[(caseDepart, case)],str):
                if "," in formeDepart:
                    formesDepart=formeDepart.split(",")
                    coef=1.0/len(formesDepart)
                    for element in formesDepart:
                        candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(element,contextFree),coef)
                else:
                    candidats.ajouterFormes(case,resultatsLecture[(caseDepart, case)].sortirForme(formeDepart,contextFree))
            else: 
                if debug: print ("str", resultatsLecture[(caseDepart, case)], file=logfile)
    return candidats

# %%
def ajouterPoint(lexeme,forme,case,digraphe,graphe):
    pointName="%s-%s-%s"%(lexeme,forme,case)
#    if not pointName in digraphe.nodes():
    tam=case[:2]
    if tam=="in": tam="inf"
    digraphe.add_node(pointName, tam='"%s"'%tam)
    graphe.add_node(pointName, tam='"%s"'%tam)
    return pointName

def ajouterFleche(pointDepart,pointSortie,coef,digraphe,graphe):
    digraphe.add_edge(pointDepart,pointSortie,weight=float(coef))
    if digraphe.has_edge(pointSortie,pointDepart):
        # modif pour networkx v2
        # coefGraphe=float(digraphe.edge[pointSortie][pointDepart]["weight"]+coef)/2
        coefGraphe=float(digraphe.adj[pointSortie][pointDepart]["weight"]+coef)/2
        graphe.add_edge(pointDepart,pointSortie,weight=coefGraphe)

# %%
def generateParadigms(generation1,genDigraphe=True,contextFree=False):
    lexeme=generation1.lexeme
    distributionInitiale=generation1.normaliserDistributions()
    candidats=paradigmeDistribution(lexeme)
    digraphe=nx.DiGraph()
    graphe=nx.Graph()    
    for caseDepart in analyseCases:
        for formeDepart in distributionInitiale[caseDepart]:
            if formeDepart:
                pointDepart=ajouterPoint(lexeme,formeDepart,caseDepart,digraphe,graphe)
                coefDepart=distributionInitiale[caseDepart][formeDepart]
                if debug: print (caseDepart,formeDepart, file=logfile)
                for caseSortie in analyseCases:
                    distributionSortieBrute=resultatsLecture[(caseDepart, caseSortie)].sortirForme(formeDepart,contextFree)
                    if distributionSortieBrute:
                        if not genDigraphe:
#                            print ("brute",distributionSortieBrute)
                            distributionSortie={f:distributionSortieBrute[f] for f in distributionSortieBrute if f in distributionInitiale[caseSortie]}
                        else:
                            distributionSortie=distributionSortieBrute
#                        print ("filtre",distributionSortie)
#                        print (distributionInitiale[caseSortie])
                        if debug: print (caseSortie,distributionSortie,distributionInitiale[caseDepart], file=logfile)
                        candidats.ajouterFormes(caseSortie,distributionSortie,distributionInitiale[caseDepart][formeDepart])
                        for formeSortie in distributionSortie:
                            pointSortie=ajouterPoint(lexeme,formeSortie,caseSortie,digraphe,graphe)
                            coefSortie=distributionSortie[formeSortie]
                            ajouterFleche(pointDepart,pointSortie,float(coefDepart*coefSortie),digraphe,graphe)
    return (candidats,digraphe,graphe)

# %% [markdown]
# # Génération d'un jeu de cliques

# %%
def generate(lexeme,genDigraphe=True,contextFree=False):
    # print (lexeme,end=", ")
    generation1=generateForms(lexeme,contextFree)
#    print ("génération 2",end=", ")
    (generation2,lexDigraphe,lexGraphe)=generateParadigms(generation1,genDigraphe,contextFree)
    lexCliques=list(nx.algorithms.clique.find_cliques(lexGraphe))
#    print (lexCliques)
#    print ("génération 3")
    return (generation2,lexDigraphe,lexGraphe,lexCliques)

# %%
paradigmes.dropna(thresh=1).count().sum()-paradigmes.dropna(thresh=1)["lexeme"].count()
# Out:
# 74387

# %% [markdown]
# #### Calculer le score de la clique

# %%
def cliqueScore(clique,graph):
    score=0
    if len(clique)>1:
        for (depart,arrivee) in it.combinations_with_replacement(clique,2):
            score+=graph[depart][arrivee]["weight"]
    return score

# %%
def splitArrivee(arrivee):
    arriveeMorceaux=arrivee.split("-")
    if len(arriveeMorceaux)<3:
        print (arrivee,arriveeMorceaux)
    lexeme="-".join(arriveeMorceaux[:-2])
    formeArrivee=arriveeMorceaux[-2]
    caseArrivee=arriveeMorceaux[-1]
    return (lexeme,formeArrivee,caseArrivee)
    
# trouver tous les liens vers FS-* et FP-*
# regrouper par forme 
# calculer les proportions
# renvoyer les proportions par forme
# avec le nombre de forme à l'appui
def formeScore(forme,graph):
    scores={}
    scoresNormes={}
    # modif pour networkx v2
    # for depart in graph.edge edge=>adj:
    for depart in graph.adj:
        for arrivee in graph.adj[depart]:
            (lexeme, formeArrivee, caseArrivee)=splitArrivee(arrivee)
            if caseArrivee==forme:
#                print (depart, formeArrivee, graph.edge[depart][arrivee])
                if not formeArrivee in scores:
                    scores[formeArrivee]=0
                scores[formeArrivee]+=graph.adj[depart][arrivee]["weight"]
    totalArrivee=0
    for formeArrivee in scores:
        totalArrivee+=scores[formeArrivee]
    for formeArrivee in scores:
        scoresNormes[formeArrivee]=scores[formeArrivee]/totalArrivee
    return (scores,scoresNormes)

# %% [markdown]
# ## Préparations pour SWIM

# %%
def generateAnalysis(globDigraphe,globGraphe,contextFree=False):
    numClique=0
    progressBar = FloatProgress(min=0, max=nbVerbes-1,description="Generation (%d verbs)"%nbVerbes)
    display(progressBar)
    for i,element in enumerate(listeTest):
        cliquesScores[element]={}
        cliquesListes[element]={}
        if (i%100)==0: print (i, dateheure()[-4:], int(100*float(i)/nbVerbes), end=", ")
        progressBar.value=i
        #print (element)
        result=generate(element,genDigraphe,contextFree)
        (generation,lexDigraphe,lexGraphe,lexCliques)= result
    #    print (generation,lexDigraphe,lexGraphe,lexCliques)
        if genFormeVotes:
            formesScores[element]={}
            formesScoresNormes[element]={}
            for formeOutput in listeFormesOutput:
                (formesScores[element][formeOutput],formesScoresNormes[element][formeOutput])=formeScore(formeOutput,lexDigraphe)
        if genDigraphe:
            globDigraphe=nx.union(globDigraphe,lexDigraphe)
        if genGraphe:
            globGraphe=nx.union(globGraphe,lexGraphe)
        cliques.extend(lexCliques)
        for clique in lexCliques:
            cliquesScores[element][numClique]=cliqueScore(clique,lexGraphe)
            cliquesListes[element][numClique]=clique
            numClique+=1
    return globDigraphe,globGraphe,numClique

# %%
def dictCliqueForms(clique):
    result={}
    for element in clique:
        lexeme,forme,case=splitArrivee(element)
        for c in dictMorphomeCases[case]:
            result[c]=forme
    return result

def dictPdRowForms(row):
    result={}
    for case in sampleCases:
        print (case,row[case].values[0])
    return result

def tableZero(case):
    if case in sampleCases:
        return u"Ø"
    else:
        return u"="

def makeTable(dictForms,title=""):
    tabular=[]
    labelTenseCode={"pi":"Present","ii":"Imperfective","ai":"Simple Past","fi":"Future",
                    "ps":"Subjunctive Pres.","is":"Subjunctive Imp.","pc":"Conditional","pI":"Imperative",
                    "inf":"Infinitive",
                    "ppMS":"Past Part. MS","ppMP":"Past Part. MP",
                    "ppFS":"Past Part. FS","ppMP":"Past Part. FP"
                   }
    def makeLine6(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            case=tenseCode+person
            if (case in dictForms) and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"

    def makeLine3(tenseCode):
        line=[]
        line.append(r"<th>%s</th>"%labelTenseCode[tenseCode])
        for person in [per+nb for nb in ["S","P"] for per in ["1","2","3"]]:
            if person in ["2S","1P","2P"]:
                case=tenseCode+person
                if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                    line.append(r"<td>%s</td>"%(dictForms[case]))
                else:
                    line.append(r"<td>%s</td>"%(tableZero(case)))
            else:
                line.append(r"<td>%s</td>"%(u"---"))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
    def makeLineNF():
        line=[]
        line.append(r"<th>%s</th>"%"NF")
        for case in ["inf","pP","ppMS","ppMP","ppFS","ppFP"]:
            if case in dictForms and (not (type(dictForms[case]) == float and np.isnan(dictForms[case]))):
                line.append(r"<td>%s</td>"%(dictForms[case]))
            else:
                line.append(r"<td>%s</td>"%(tableZero(case)))
        return r"<tr>"+r"".join(line)+r"</tr>"
    
        
    top=[
        r"<table>",
        r"<caption style='caption-side:bottom;text-align:center'>",
        "Verbe : %s"%title,
        r"</caption>",
#        r"<tr><th/><th>1S</th><th>2S</th><th>3S</th><th>1P</th><th>2P</th><th>3P</th></tr>"
        r"<tr><th/><th>1SG</th><th>2SG</th><th>3SG</th><th>1PL</th><th>2PL</th><th>3PL</th></tr>"
        ]
    bottom=[
        r"</table>"
        ]
    tabular.append("\n".join(top))
    for tenseCode in ["pi","ii","fi","pc", "ps","ai", "is"]:
        tabular.append(makeLine6(tenseCode))
    tabular.append(makeLine3("pI"))
    tabular.append(makeLineNF())
    tabular.append("\n".join(bottom))
    return "\n".join(tabular)    

def diffParadigme(lexeme):
    outLen=lexemeMaxCliques[lexeme][0]
    bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
    inLen=paradigmes[bLexParadigme].notnull().sum(axis=1).values[0]-1
    if outLen>inLen:
        print (lexemeMaxCliques[lexeme][1])
        print (paradigmes[paradigmes["lexeme"]=="grandir"].values)
    return outLen-inLen

# %%
def checkFidelite(fidelite,clique):
    lFidele=False
    for element in clique:
        if fidelite in element:
            lFidele=True
    return lFidele

def generateCliques(contextFree=False):
    
    def bruteCliques(lexeme,maxCliqueSize=51):
        cliquesBrutes={n+1:0 for n in range(maxCliqueSize)}
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                if not longueur in cliquesBrutes:
                    cliquesBrutes[longueur]=0
                cliquesBrutes[longueur]+=1
        return cliquesBrutes
    
    globDigraphe=nx.DiGraph()
    globGraphe=nx.Graph()

    globDigraphe,globGraphe,numClique=generateAnalysis(globDigraphe,globGraphe,contextFree)
    print 

    lexemeMaxCliques={}
    lexemeParadigmes={}
    progressBarCliques = FloatProgress(min=0, max=len(cliquesListes)-1,description="Analysis (%d verbes)"%len(cliquesListes))
    display(progressBarCliques)
    for lexeme in cliquesListes:
        progressBarCliques.value+=1
        maxLen=max([len(c) for c in cliquesListes[lexeme].values()])
        lexemeMaxCliques[lexeme]=bruteCliques(lexeme,maxLen)
        print (lexeme,"Nombre de cliques",sum([v for k,v in lexemeMaxCliques[lexeme].iteritems()]))
        maxNbCliques=max([v for k,v in lexemeMaxCliques[lexeme].iteritems()])
        if plotDistributionCliques:
            ax=pd.DataFrame.from_dict(lexemeMaxCliques[lexeme],orient="index").plot(kind="bar",legend=False,grid=True,figsize=(10,3))
            ax.set(xlim=(0,maxLen+.5),ylim=(0,maxNbCliques+10))
            ax.set_xlabel("Clique Size in Cells",fontsize=16)
            ax.set_ylabel("Number of Cliques",fontsize=16)

        dictParadigmes=paradigmes.set_index("lexeme").to_dict(orient="index")

        cliquesFideles={}
        fidelites=[v+"-"+k for k,v in dictParadigmes[lexeme].iteritems() if isinstance(v,unicode)]
        for l in cliquesListes[lexeme].values():
            longueur=len(l)
            if longueur>1:
                fidele=True
                for fidelite in fidelites:
                    if "," in fidelite:
                        fideliteForme,fideliteCase=fidelite.split("-")
                        fideliteFormes=fideliteForme.split(",")
                        fideliteItems=[fideliteF+"-"+fideliteCase for fideliteF in fideliteFormes]
#                        print (fideliteItems)
                        lFidele=True
                        for f in fideliteItems:
                            lFidele=lFidele & checkFidelite(f,l)
                    else:
                        lFidele=checkFidelite(fidelite,l)
                    if not lFidele:
                        fidele=False
                        break
                if fidele:
                    if not longueur in cliquesFideles:
                        cliquesFideles[longueur]=[]
                    cliquesFideles[longueur].append(l)
#                else:
#                    if lexeme==u"bégayer": print ()
#        print ([(k,len(v)) for k,v in cliquesFideles.iteritems()])
        if cliquesFideles:
            maxCliquesCard=max([k for k,v in cliquesFideles.iteritems()])
    #        print (maxCliquesCard)
    #        print (cliquesScores[lexeme])
    #        print (cliquesListes[lexeme])
            lexemeParadigmes[lexeme]=[]
            maxScoreCliques=max([clique for cliqueNumber, clique in cliquesScores[lexeme].items()])
            maxCardScoreNums=[numC for numC, c in cliquesListes[lexeme].items() if c in cliquesFideles[maxCliquesCard]]
            maxCardScore=max([scoreC for numC, scoreC in cliquesScores[lexeme].items() if numC in maxCardScoreNums])
    #        print ("max score among all cliques:",maxScoreCliques)
            print ("max score among faithfull cliques of %d forms:"%maxCliquesCard,maxCardScore)
            for c in cliquesFideles[maxCliquesCard]:
                cNumber=[cliqueNumber for cliqueNumber, clique in cliquesListes[lexeme].items() if clique == c]
                if len(cNumber)!=1:
                    print ("TOO MANY SCORES PROBLEM WITH CLIQUE", cNumber)
    #            print ("Liste n°",cNumber[0],cliquesScores[lexeme][cNumber[0]])
    #            print (sorted(cliquesScores[lexeme].items(), key=operator.itemgetter(1)))
    #            display(HTML(makeTable(dictCliqueForms(c),title=c[0].split("-")[0])))
    #            print (cliquesScores[lexeme][cNumber[0]], maxCardScore)
                if cliquesScores[lexeme][cNumber[0]]==maxCardScore:
                    lexemeParadigmes[lexeme].append(c)
        else:
            lexemeParadigmes[lexeme]=[[lexeme+"-"+f for f in fidelites]]
            print (u"no new faithfull clique, the previous one contained %d forms"%len(lexemeParadigmes[lexeme][0]))
    return lexemeParadigmes

# %%
def cutNodeName(nodeName):
    items=nodeName.split("-")
    nbItems=len(items)
    if nbItems>3:
        items=["-".join(items[0:nbItems-2]),items[-2],items[-1]]
    return items

def filledOutClique(cliques):
    if cliques:
        result=[]
        for clique in cliques:
#            print (clique)
            fullClique=[]
            for element in clique:
                if debug: print ("element",element)
                lexeme,forme,case=splitArrivee(element)
                for c in dictMorphomeCases[case]:
                    fullClique.append("-".join([lexeme,forme,c]))
            result.append(fullClique)
        return result
    else:
        return cliques

# %%
def extendParadigmes(contextParadigmes,extendMorphomes=False):
    lexemesParadigmeListe=[]
    for lexeme in contextParadigmes:
        if extendMorphomes:
            lexParadigmes=filledOutClique(contextParadigmes[lexeme])
        else:
            lexParadigmes=contextParadigmes[lexeme]
        if len(lexParadigmes)!=1:
            if debug:
                print ("LEXEME WITH A NON UNIQUE PARADIGM PB",len(lexParadigmes),lexeme)
                print (lexParadigmes)
        lexParadigme=lexParadigmes[0]
        for lexForme in lexParadigme:
            lexemesParadigmeListe.append(cutNodeName(lexForme))
    newForms=pd.DataFrame(lexemesParadigmeListe)
    newForms.columns=["lexeme","form","case"]
#    newParadigmes=newForms.pivot(index="lexeme", columns="case", values="form")
    newParadigmes=pd.pivot_table(newForms, values='form', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
    for i in newParadigmes.itertuples():
#        print (i[0],i[1])
        lexeme=i[1]
        bLexParadigme=paradigmes["lexeme"].str.contains("^"+lexeme+"$")
        lexemeIndexes=paradigmes.lexeme[bLexParadigme].index.tolist()
        if lexemeIndexes:
            lexemeIndex=lexemeIndexes[0]
        else:
            print (i,lexeme,lexemeIndexes)
        bLexNewParadigme=newParadigmes["lexeme"].str.contains("^"+lexeme+"$")
        newParadigmes.loc[bLexNewParadigme,"index"]=int(lexemeIndex)
    newParadigmes.set_index("index",inplace=True)   
    return paradigmes.combine_first(newParadigmes)

# %%
def countSplits(dfForms):
    dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
    return dfForms["split"].str.len().sum()

def calculerResultats(contextParadigmes,extension="-Swim2"):
    
    '''Préparer le paradigme des prédictions'''
    brutParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=False)
    finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
    finalParadigmes.to_csv(fSample.replace(".csv","")+"%s.csv"%extension,encoding="utf8",sep=";")
    finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
    finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
    finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
    print (finalTestForms.columns)
    # finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["case"]
    # finalTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
    finalTestForms.set_index(["lexeme-case"],inplace=True)
    
    '''Soustraire les formes initiales'''
    finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
    finalFormsIndex=finalForms.index.tolist()
    
    '''Calculer les sur/sous-générations'''
    underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
    overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]
    
    '''Réduire les prédictions et la référence aux cases communes'''
    predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
    actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]
    
    '''Créer un tableau pour les comparaisons'''
    compareForms=predictedForms.copy()
    compareForms.loc[:,"right"]=actualForms.loc[:,"value"]
    
    '''Séparer les cases identiques des cases différentes'''
    sameForms=compareForms[compareForms["value"]==compareForms["right"]]
    diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

    
    '''Sauvegarder les comparatifs'''
    overGeneration.to_csv(fSample.replace(".csv","")+"-overGeneration%s.csv"%extension,encoding="utf8")
    underGeneration.to_csv(fSample.replace(".csv","")+"-underGeneration%s.csv"%extension,encoding="utf8")
    sameForms.to_csv(fSample.replace(".csv","")+"-sameForms%s.csv"%extension,encoding="utf8")
    diffForms.to_csv(fSample.replace(".csv","")+"-diffForms%s.csv"%extension,encoding="utf8")
    
    
    '''Transformer les surabondances en liste'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")

    '''Transformer les surabondances en set()'''
    diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
    diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
    
    '''Calculer le nombre de formes (y compris surabondances)'''
    nbValues=diffForms["split-value"].str.len().sum()
    nbRights=diffForms["split-right"].str.len().sum()

    '''Calculer les identités et les inclusions'''
    nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
    nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
    nbWrongForms=(nbValues-nbIdenticalSets-nbIncludedSets)
    underBonus=(nbRights-nbIdenticalSets-nbIncludedSets)

    UG=countSplits(underGeneration)+underBonus
    OG=countSplits(overGeneration)
    TP=countSplits(sameForms)+nbIdenticalSets+nbIncludedSets
    FP=nbWrongForms
    resultCharacteristics=(UG,OG,TP,FP)
    recall=float(TP)/(UG+TP+FP)
    precision=float(TP)/(OG+TP+FP)
    fMeasure=2*recall*precision/(recall+precision)
    resultMeasures=(precision,recall,fMeasure)
    print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
    print ("recall", recall, "precision", precision)
    print (fMeasure)
    return (brutParadigmes,finalParadigmes,resultCharacteristics,resultMeasures)

# %% [markdown]
# # SWIM1

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim1ContextParadigmes=generateCliques()
# Out:
# 2023-11-08 02:59:03.803549
# FloatProgress(value=0.0, description=u'Generation (6433 verbs)', max=6432.0)
# 0 0159 0, 100 0205 1, 200 0210 3, 300 0216 4, 400 0222 6, 500 0227 7, 600 0232 9, 700 0237 10, 800 0242 12, 900 0246 13, 1000 0251 15, 1100 0256 17, 1200 0302 18, 1300 0307 20, 1400 0312 21, 1500 0317 23, 1600 0322 24, 1700 0327 26, 1800 0332 27, 1900 0337 29, 2000 0342 31, 2100 0346 32, 2200 0350 34, 2300 0355 35, 2400 0400 37, 2500 0405 38, 2600 0410 40, 2700 0416 41, 2800 0421 43, 2900 0427 45, 3000 0431 46, 3100 0436 48, 3200 0441 49, 3300 0446 51, 3400 0452 52, 3500 0457 54, 3600 0502 55, 3700 0507 57, 3800 0512 59, 3900 0517 60, 4000 0522 62, 4100 0527 63, 4200 0532 65, 4300 0538 66, 4400 0543 68, 4500 0549 69, 4600 0554 71, 4700 0559 73, 4800 0604 74, 4900 0609 76, 5000 0615 77, 5100 0621 79, 5200 0625 80, 5300 0631 82, 5400 0637 83, 5500 0642 85, 5600 0648 87, 5700 0652 88, 5800 0657 90, 5900 0702 91, 6000 0708 93, 6100 0713 94, 6200 0718 96, 6300 0723 97, 6400 0728 99,
# FloatProgress(value=0.0, description=u'Analysis (6433 verbes)', max=6432.0)
# gauchir Nombre de cliques 63
# max score among faithfull cliques of 26 forms: 264.383147017
# dénazifier Nombre de cliques 17
# max score among faithfull cliques of 25 forms: 249.368762454
# réinstaller Nombre de cliques 24
# max score among faithfull cliques of 28 forms: 392.449667622
# caner Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 408.10654017
# tancer Nombre de cliques 27
# max score among faithfull cliques of 30 forms: 431.572958664
# devenir Nombre de cliques 110
# max score among faithfull cliques of 29 forms: 370.254736122
# volanter Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 425.593681209
# orthographier Nombre de cliques 124
# max score among faithfull cliques of 24 forms: 200.938553066
# affectionner Nombre de cliques 16
# max score among faithfull cliques of 29 forms: 400.066038395
# verser Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 387.645739863
# dégommer Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 399.847561952
# déverser Nombre de cliques 39
# max score among faithfull cliques of 29 forms: 388.326763777
# superposer Nombre de cliques 71
# max score among faithfull cliques of 29 forms: 364.62603831
# spiritualiser Nombre de cliques 11
# max score among faithfull cliques of 29 forms: 384.918022441
# empoissonner Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 392.142204376
# persister Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 419.361090803
# déganter Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 410.360500707
# judaïser Nombre de cliques 4
# max score among faithfull cliques of 28 forms: 391.667241639
# commenter Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 381.76947313
# douiller Nombre de cliques 27
# max score among faithfull cliques of 25 forms: 292.977332964
# concasser Nombre de cliques 12
# max score among faithfull cliques of 29 forms: 399.017019166
# entrégorger Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 420.882407753
# bossuer Nombre de cliques 24
# max score among faithfull cliques of 23 forms: 250.796955399
# fritter Nombre de cliques 19
# max score among faithfull cliques of 26 forms: 311.819358178
# maquereauter Nombre de cliques 134
# max score among faithfull cliques of 19 forms: 97.705242712
# boursicoter Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 388.997932597
# aposter Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 411.584178518
# chauffer Nombre de cliques 96
# max score among faithfull cliques of 28 forms: 347.036278242
# poiler Nombre de cliques 17
# max score among faithfull cliques of 28 forms: 395.811771274
# dépayser Nombre de cliques 25
# max score among faithfull cliques of 28 forms: 381.929584938
# pencher Nombre de cliques 47
# max score among faithfull cliques of 30 forms: 435.282834774
# poivrer Nombre de cliques 25
# max score among faithfull cliques of 26 forms: 315.090634954
# évider Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 398.259554004
# foisonner Nombre de cliques 25
# max score among faithfull cliques of 29 forms: 384.867929912
# préluder Nombre de cliques 5
# max score among faithfull cliques of 29 forms: 424.262781239
# moucharder Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 398.787100872
# muer Nombre de cliques 27
# max score among faithfull cliques of 24 forms: 276.710883336
# revouloir Nombre de cliques 7
# max score among faithfull cliques of 13 forms: 72.8120838531
# enquiquiner Nombre de cliques 16
# max score among faithfull cliques of 29 forms: 413.007839491
# effaroucher Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 408.136424353
# dévaloriser Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 392.016708025
# grossir Nombre de cliques 270
# max score among faithfull cliques of 26 forms: 206.117071238
# contre-braquer Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 420.992623885
# offenser Nombre de cliques 39
# max score among faithfull cliques of 29 forms: 385.692640667
# fusionner Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 395.199316581
# confisquer Nombre de cliques 24
# max score among faithfull cliques of 29 forms: 424.573550186
# reporter Nombre de cliques 31
# max score among faithfull cliques of 29 forms: 380.050605351
# susurrer Nombre de cliques 25
# max score among faithfull cliques of 29 forms: 407.375294505
# parisianiser Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 417.800428816
# désincruster Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 426.702141001
# éreinter Nombre de cliques 25
# max score among faithfull cliques of 29 forms: 376.711201239
# fissurer Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 402.625200136
# bambocher Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 401.646709385
# biquer Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 410.207569469
# rassortir Nombre de cliques 14
# max score among faithfull cliques of 28 forms: 155.627924437
# ragoter Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 395.719975916
# déboulonner Nombre de cliques 9
# max score among faithfull cliques of 29 forms: 413.52003803
# aniser Nombre de cliques 5
# max score among faithfull cliques of 29 forms: 417.776756303
# endenter Nombre de cliques 12
# max score among faithfull cliques of 28 forms: 351.307731004
# emplir Nombre de cliques 45
# max score among faithfull cliques of 19 forms: 128.54408339
# remeubler Nombre de cliques 12
# max score among faithfull cliques of 26 forms: 335.998602771
# prêcher Nombre de cliques 51
# max score among faithfull cliques of 29 forms: 405.347563127
# coqueter Nombre de cliques 7
# max score among faithfull cliques of 27 forms: 238.503096828
# unir Nombre de cliques 96
# max score among faithfull cliques of 26 forms: 271.159925922
# agencer Nombre de cliques 25
# max score among faithfull cliques of 29 forms: 392.30143216
# jambonner Nombre de cliques 10
# max score among faithfull cliques of 30 forms: 423.924676043
# exploser Nombre de cliques 49
# max score among faithfull cliques of 28 forms: 366.40599475
# transvider Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 416.495524053
# rugir Nombre de cliques 172
# max score among faithfull cliques of 25 forms: 219.229314562
# menacer Nombre de cliques 98
# max score among faithfull cliques of 29 forms: 368.938593026
# décompiler Nombre de cliques 9
# max score among faithfull cliques of 28 forms: 390.042844468
# fustiger Nombre de cliques 28
# max score among faithfull cliques of 29 forms: 407.521204073
# bâter Nombre de cliques 25
# max score among faithfull cliques of 29 forms: 378.433356779
# ronger Nombre de cliques 34
# max score among faithfull cliques of 29 forms: 405.714338208
# ébouriffer Nombre de cliques 38
# max score among faithfull cliques of 28 forms: 366.158078456
# convoler Nombre de cliques 32
# max score among faithfull cliques of 28 forms: 377.927907156
# sortir Nombre de cliques 166
# max score among faithfull cliques of 29 forms: 133.964203298
# mémoriser Nombre de cliques 52
# max score among faithfull cliques of 29 forms: 391.04640948
# précipiter Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 393.884325465
# orner Nombre de cliques 13
# max score among faithfull cliques of 29 forms: 404.303869577
# cajoler Nombre de cliques 29
# max score among faithfull cliques of 28 forms: 382.412459317
# déclencher Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 424.221299445
# dérider Nombre de cliques 24
# max score among faithfull cliques of 29 forms: 399.960457083
# prôner Nombre de cliques 82
# max score among faithfull cliques of 18 forms: 92.6642210371
# embuer Nombre de cliques 41
# max score among faithfull cliques of 24 forms: 269.07995822
# ratisser Nombre de cliques 78
# max score among faithfull cliques of 24 forms: 185.325403937
# nitrater Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 365.789252839
# sous-exploiter Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 398.345600721
# bigarrer Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 412.101571887
# swinguer Nombre de cliques 11
# max score among faithfull cliques of 27 forms: 372.331534404
# canarder Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 398.721872087
# avarier Nombre de cliques 173
# max score among faithfull cliques of 26 forms: 206.651446831
# prostituer Nombre de cliques 30
# max score among faithfull cliques of 27 forms: 349.209811328
# biaiser Nombre de cliques 57
# max score among faithfull cliques of 27 forms: 321.963748185
# destiner Nombre de cliques 30
# max score among faithfull cliques of 28 forms: 382.060559986
# mépriser Nombre de cliques 59
# max score among faithfull cliques of 29 forms: 386.732266629
# appendre Nombre de cliques 7
# max score among faithfull cliques of 28 forms: 272.852923821
# préformater Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 403.677524832
# ardre Nombre de cliques 3
# max score among faithfull cliques of 9 forms: 35.8800451847
# vibrer Nombre de cliques 31
# max score among faithfull cliques of 19 forms: 183.632751849
# attitrer Nombre de cliques 15
# max score among faithfull cliques of 26 forms: 322.878967829
# consacrer Nombre de cliques 61
# max score among faithfull cliques of 26 forms: 332.002565351
# combler Nombre de cliques 32
# max score among faithfull cliques of 26 forms: 333.984935146
# émasculer Nombre de cliques 17
# max score among faithfull cliques of 28 forms: 396.369097099
# naufrager Nombre de cliques 34
# max score among faithfull cliques of 29 forms: 407.407417508
# typer Nombre de cliques 13
# max score among faithfull cliques of 29 forms: 411.941060183
# sentir Nombre de cliques 178
# max score among faithfull cliques of 27 forms: 108.727134985
# expectorer Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 384.089775634
# accéder Nombre de cliques 57
# max score among faithfull cliques of 28 forms: 301.549912353
# tarauder Nombre de cliques 106
# max score among faithfull cliques of 20 forms: 101.009655328
# entrapercevoir Nombre de cliques 88
# max score among faithfull cliques of 28 forms: 247.015259722
# défiler Nombre de cliques 34
# max score among faithfull cliques of 28 forms: 392.776032326
# pigmenter Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 398.339857774
# substituer Nombre de cliques 28
# max score among faithfull cliques of 27 forms: 348.989561204
# efféminer Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 411.406706461
# boire Nombre de cliques 178
# max score among faithfull cliques of 26 forms: 263.883520005
# sous-tendre Nombre de cliques 49
# max score among faithfull cliques of 27 forms: 195.962903552
# profaner Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 405.322275021
# repriser Nombre de cliques 48
# max score among faithfull cliques of 29 forms: 387.867779491
# maturer Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 419.728204841
# bâcher Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 415.968991045
# plafonner Nombre de cliques 27
# max score among faithfull cliques of 29 forms: 391.502111526
# collectionner Nombre de cliques 36
# max score among faithfull cliques of 29 forms: 396.083627496
# bosseler Nombre de cliques 19
# max score among faithfull cliques of 27 forms: 291.63826946
# incendier Nombre de cliques 217
# max score among faithfull cliques of 23 forms: 186.140791468
# réfracter Nombre de cliques 9
# max score among faithfull cliques of 27 forms: 368.739704734
# surgir Nombre de cliques 213
# max score among faithfull cliques of 26 forms: 248.977137487
# vadrouiller Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 289.090961826
# éloigner Nombre de cliques 39
# max score among faithfull cliques of 26 forms: 305.638181411
# braiser Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 319.762516485
# froufrouter Nombre de cliques 15
# max score among faithfull cliques of 29 forms: 400.326504056
# violacer Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 413.311773113
# ensacher Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 404.134973337
# rapprendre Nombre de cliques 3
# max score among faithfull cliques of 28 forms: 381.005771001
# vouloir Nombre de cliques 112
# max score among faithfull cliques of 28 forms: 319.361184063
# grognasser Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 403.937042774
# aliter Nombre de cliques 13
# max score among faithfull cliques of 29 forms: 419.790149717
# boucaner Nombre de cliques 10
# max score among faithfull cliques of 29 forms: 414.047354323
# piocher Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 402.359129275
# couturer Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 414.724888724
# acheminer Nombre de cliques 33
# max score among faithfull cliques of 29 forms: 414.369748985
# stabiliser Nombre de cliques 29
# max score among faithfull cliques of 29 forms: 389.037674609
# opacifier Nombre de cliques 105
# max score among faithfull cliques of 25 forms: 242.270823887
# blinder Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 421.009340668
# parasiter Nombre de cliques 28
# max score among faithfull cliques of 29 forms: 393.007505782
# désendetter Nombre de cliques 9
# max score among faithfull cliques of 29 forms: 352.537745829
# autodéterminer Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 401.839029114
# retuber Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 417.301193587
# gercer Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 403.378440815
# inaugurer Nombre de cliques 57
# max score among faithfull cliques of 29 forms: 402.163453398
# blablater Nombre de cliques 23
# max score among faithfull cliques of 29 forms: 418.122132099
# rembobiner Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 411.235498645
# ratiociner Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 423.387037877
# roquer Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 405.901092651
# biser Nombre de cliques 77
# max score among faithfull cliques of 25 forms: 268.215786055
# valoir Nombre de cliques 111
# max score among faithfull cliques of 24 forms: 197.324492683
# assurer Nombre de cliques 49
# max score among faithfull cliques of 29 forms: 403.135772487
# emprisonner Nombre de cliques 46
# max score among faithfull cliques of 29 forms: 390.086242109
# réattribuer Nombre de cliques 37
# max score among faithfull cliques of 24 forms: 257.379187991
# materner Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 402.370122774
# décarboniser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 417.397922254
# réciproquer Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 414.52007102
# glycériner Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 411.968761163
# carotter Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 381.194415788
# maximaliser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 407.654378006
# épeurer Nombre de cliques 54
# max score among faithfull cliques of 21 forms: 188.862252687
# redéfinir Nombre de cliques 112
# max score among faithfull cliques of 26 forms: 256.728309913
# apitoyer Nombre de cliques 82
# max score among faithfull cliques of 25 forms: 205.201700829
# gambiller Nombre de cliques 184
# max score among faithfull cliques of 25 forms: 262.725684428
# rejouer Nombre de cliques 26
# max score among faithfull cliques of 25 forms: 293.287176208
# embrouiller Nombre de cliques 45
# max score among faithfull cliques of 25 forms: 284.104841666
# lister Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 418.993100385
# détracter Nombre de cliques 4
# max score among faithfull cliques of 27 forms: 370.824421518
# octroyer Nombre de cliques 57
# max score among faithfull cliques of 24 forms: 194.812369455
# entrevoir Nombre de cliques 186
# max score among faithfull cliques of 17 forms: 66.26296174
# regreffer Nombre de cliques 8
# max score among faithfull cliques of 28 forms: 339.669489537
# préremplir Nombre de cliques 15
# max score among faithfull cliques of 24 forms: 189.424140292
# bitter Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 412.325054866
# motoriser Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 408.61744749
# rectifier Nombre de cliques 229
# max score among faithfull cliques of 25 forms: 194.901242361
# dissimiler Nombre de cliques 13
# max score among faithfull cliques of 28 forms: 392.676294039
# dépurer Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 417.735982467
# exulter Nombre de cliques 26
# max score among faithfull cliques of 25 forms: 315.691913051
# baliser Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 383.26286944
# tirer Nombre de cliques 50
# max score among faithfull cliques of 29 forms: 403.004264021
# prouter Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 411.400245581
# ardoiser Nombre de cliques 9
# max score among faithfull cliques of 28 forms: 381.512286341
# cacarder Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 407.23886936
# mitrer Nombre de cliques 9
# max score among faithfull cliques of 26 forms: 326.608958058
# palanquer Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 429.630468966
# chamarrer Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 404.928916503
# arrimer Nombre de cliques 16
# max score among faithfull cliques of 29 forms: 416.591059192
# absorber Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 386.678339485
# overclocker Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 426.164048604
# désensorceler Nombre de cliques 23
# max score among faithfull cliques of 27 forms: 273.295664177
# décentrer Nombre de cliques 15
# max score among faithfull cliques of 27 forms: 358.140510578
# coulisser Nombre de cliques 16
# max score among faithfull cliques of 26 forms: 206.407413857
# nuer Nombre de cliques 19
# max score among faithfull cliques of 27 forms: 351.261562233
# enjamber Nombre de cliques 29
# max score among faithfull cliques of 29 forms: 392.095506905
# fauter Nombre de cliques 135
# max score among faithfull cliques of 15 forms: 63.6408431465
# briffer Nombre de cliques 37
# max score among faithfull cliques of 28 forms: 361.120130058
# bafouer Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 243.67342684
# discréditer Nombre de cliques 36
# max score among faithfull cliques of 28 forms: 367.589924424
# singer Nombre de cliques 48
# max score among faithfull cliques of 29 forms: 401.565141331
# provisionner Nombre de cliques 9
# max score among faithfull cliques of 29 forms: 403.479304266
# purger Nombre de cliques 55
# max score among faithfull cliques of 29 forms: 414.010762031
# calquer Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 321.047965892
# dessiner Nombre de cliques 33
# max score among faithfull cliques of 29 forms: 410.773258586
# relever Nombre de cliques 104
# max score among faithfull cliques of 26 forms: 233.604825234
# tapoter Nombre de cliques 69
# max score among faithfull cliques of 29 forms: 377.270128234
# réparer Nombre de cliques 57
# max score among faithfull cliques of 29 forms: 381.845571145
# froncer Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 398.430010063
# essorer Nombre de cliques 53
# max score among faithfull cliques of 29 forms: 377.394012814
# ruisseler Nombre de cliques 32
# max score among faithfull cliques of 27 forms: 279.821309259
# écouler Nombre de cliques 27
# max score among faithfull cliques of 28 forms: 392.180947578
# dégoûter Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 400.516702827
# replâtrer Nombre de cliques 12
# max score among faithfull cliques of 26 forms: 330.074165984
# décrypter Nombre de cliques 21
# max score among faithfull cliques of 27 forms: 366.358715129
# caper Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 400.434369438
# toucher Nombre de cliques 31
# max score among faithfull cliques of 29 forms: 409.19914529
# écarquiller Nombre de cliques 134
# max score among faithfull cliques of 25 forms: 239.125531914
# poireauter Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 376.930729998
# tournailler Nombre de cliques 14
# max score among faithfull cliques of 24 forms: 242.624093723
# ravaler Nombre de cliques 32
# max score among faithfull cliques of 28 forms: 379.861338806
# annihiler Nombre de cliques 29
# max score among faithfull cliques of 28 forms: 393.829988558
# environner Nombre de cliques 23
# max score among faithfull cliques of 29 forms: 390.380948441
# repolariser Nombre de cliques 33
# max score among faithfull cliques of 29 forms: 386.067462491
# essaimer Nombre de cliques 21
# max score among faithfull cliques of 28 forms: 391.374916347
# effriter Nombre de cliques 22
# max score among faithfull cliques of 29 forms: 399.569718272
# étoffer Nombre de cliques 87
# max score among faithfull cliques of 28 forms: 351.65801777
# rameuter Nombre de cliques 184
# max score among faithfull cliques of 16 forms: 119.164036113
# reposer Nombre de cliques 86
# max score among faithfull cliques of 29 forms: 359.243074115
# badigeonner Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 389.858251452
# fleurir Nombre de cliques 178
# max score among faithfull cliques of 25 forms: 210.24751844
# faisander Nombre de cliques 21
# max score among faithfull cliques of 28 forms: 353.883849887
# ensuquer Nombre de cliques 5
# max score among faithfull cliques of 29 forms: 422.86375971
# drayer Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 205.691264568
# mâchurer Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 406.015454986
# outiller Nombre de cliques 73
# max score among faithfull cliques of 25 forms: 219.417659252
# lapider Nombre de cliques 31
# max score among faithfull cliques of 28 forms: 374.808454919
# embouter Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 415.860273342
# haïr Nombre de cliques 71
# max score among faithfull cliques of 25 forms: 285.931609489
# clarifier Nombre de cliques 224
# max score among faithfull cliques of 25 forms: 188.212067606
# désigner Nombre de cliques 34
# max score among faithfull cliques of 26 forms: 338.914178092
# dépêtrer Nombre de cliques 20
# max score among faithfull cliques of 26 forms: 329.263213004
# reprogrammer Nombre de cliques 27
# max score among faithfull cliques of 29 forms: 405.798048633
# débiner Nombre de cliques 22
# max score among faithfull cliques of 28 forms: 384.589374264
# pressurer Nombre de cliques 23
# max score among faithfull cliques of 29 forms: 406.565832726
# entreposer Nombre de cliques 78
# max score among faithfull cliques of 29 forms: 361.867303327
# embrever Nombre de cliques 19
# max score among faithfull cliques of 26 forms: 261.291247534
# débouder Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 417.201855838
# moissonner Nombre de cliques 31
# max score among faithfull cliques of 29 forms: 390.151598809
# souvenir Nombre de cliques 134
# max score among faithfull cliques of 27 forms: 314.266028628
# euphoriser Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 400.188449419
# cafter Nombre de cliques 22
# max score among faithfull cliques of 29 forms: 404.187605806
# nébuliser Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 401.001342974
# étourdir Nombre de cliques 258
# max score among faithfull cliques of 26 forms: 217.680770383
# adapter Nombre de cliques 33
# max score among faithfull cliques of 27 forms: 364.828370219
# remouler Nombre de cliques 8
# max score among faithfull cliques of 28 forms: 370.022065454
# incinérer Nombre de cliques 54
# max score among faithfull cliques of 29 forms: 387.183726643
# fouiner Nombre de cliques 26
# max score among faithfull cliques of 28 forms: 385.266563932
# percuter Nombre de cliques 44
# max score among faithfull cliques of 29 forms: 398.796197802
# écourter Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 408.223379813
# révulser Nombre de cliques 19
# max score among faithfull cliques of 25 forms: 314.81412039
# patenter Nombre de cliques 15
# max score among faithfull cliques of 28 forms: 362.107215286
# demander Nombre de cliques 44
# max score among faithfull cliques of 29 forms: 392.306811624
# surproduire Nombre de cliques 46
# max score among faithfull cliques of 26 forms: 199.464563602
# avaliser Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 397.392428958
# pactiser Nombre de cliques 92
# max score among faithfull cliques of 26 forms: 286.868619714
# menuiser Nombre de cliques 12
# max score among faithfull cliques of 26 forms: 316.972404539
# mortifier Nombre de cliques 213
# max score among faithfull cliques of 25 forms: 220.669252496
# perler Nombre de cliques 20
# max score among faithfull cliques of 28 forms: 394.643032846
# exaspérer Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 385.16362968
# ganter Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 411.038243858
# potasser Nombre de cliques 84
# max score among faithfull cliques of 29 forms: 361.475636338
# récliner Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 427.432705816
# traficoter Nombre de cliques 59
# max score among faithfull cliques of 29 forms: 381.621749143
# parler Nombre de cliques 28
# max score among faithfull cliques of 28 forms: 393.833688448
# défouler Nombre de cliques 32
# max score among faithfull cliques of 28 forms: 387.402435689
# penser Nombre de cliques 46
# max score among faithfull cliques of 30 forms: 415.613462387
# tutoyer Nombre de cliques 79
# max score among faithfull cliques of 25 forms: 203.09216672
# suivre Nombre de cliques 114
# max score among faithfull cliques of 27 forms: 159.092422277
# haranguer Nombre de cliques 50
# max score among faithfull cliques of 29 forms: 406.243795269
# contreficher Nombre de cliques 24
# max score among faithfull cliques of 29 forms: 404.514532703
# batifoler Nombre de cliques 33
# max score among faithfull cliques of 28 forms: 380.883751123
# claboter Nombre de cliques 14
# max score among faithfull cliques of 30 forms: 420.803662949
# criminaliser Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 381.406690262
# panoramiquer Nombre de cliques 12
# max score among faithfull cliques of 29 forms: 415.84729759
# empêcher Nombre de cliques 51
# max score among faithfull cliques of 29 forms: 405.193495892
# tortorer Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 409.253163549
# récriminer Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 414.812591139
# déverdir Nombre de cliques 102
# max score among faithfull cliques of 25 forms: 156.802650513
# aboyer Nombre de cliques 61
# max score among faithfull cliques of 24 forms: 190.494182186
# vendanger Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 408.23859543
# truster Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 424.283233705
# rebrûler Nombre de cliques 6
# max score among faithfull cliques of 28 forms: 399.388841672
# élargir Nombre de cliques 214
# max score among faithfull cliques of 25 forms: 221.106334471
# recadrer Nombre de cliques 17
# max score among faithfull cliques of 26 forms: 328.045594296
# toaster Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 425.240176307
# voiturer Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 410.444062462
# rouir Nombre de cliques 5
# max score among faithfull cliques of 23 forms: 232.312121318
# étatiser Nombre de cliques 8
# max score among faithfull cliques of 27 forms: 343.495236823
# intituler Nombre de cliques 25
# max score among faithfull cliques of 28 forms: 394.034896652
# peindre Nombre de cliques 44
# max score among faithfull cliques of 22 forms: 180.931087333
# ragaillardir Nombre de cliques 156
# max score among faithfull cliques of 26 forms: 221.044699968
# voyager Nombre de cliques 53
# max score among faithfull cliques of 29 forms: 409.487184846
# palpiter Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 397.249394777
# encrer Nombre de cliques 20
# max score among faithfull cliques of 26 forms: 336.144756634
# cloquer Nombre de cliques 9
# max score among faithfull cliques of 29 forms: 422.797596859
# bistrer Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 318.562819664
# bedonner Nombre de cliques 21
# max score among faithfull cliques of 30 forms: 422.59422764
# négocier Nombre de cliques 241
# max score among faithfull cliques of 25 forms: 184.60536848
# dépasser Nombre de cliques 99
# max score among faithfull cliques of 28 forms: 344.314911937
# dérégler Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 336.284853529
# virguler Nombre de cliques 5
# max score among faithfull cliques of 28 forms: 399.5576111
# rescinder Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 370.590891074
# chancir Nombre de cliques 7
# max score among faithfull cliques of 25 forms: 217.605258187
# apurer Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 417.743069081
# tiédir Nombre de cliques 128
# max score among faithfull cliques of 26 forms: 215.517370957
# contremander Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 400.716009605
# solidariser Nombre de cliques 25
# max score among faithfull cliques of 29 forms: 389.659704137
# mordorer Nombre de cliques 8
# max score among faithfull cliques of 28 forms: 354.114368886
# renouveler Nombre de cliques 70
# max score among faithfull cliques of 27 forms: 265.640058989
# déconner Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 390.549474596
# fréquenter Nombre de cliques 35
# max score among faithfull cliques of 29 forms: 389.073066211
# rabouter Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 408.936031788
# dialoguer Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 419.914423337
# embaumer Nombre de cliques 40
# max score among faithfull cliques of 29 forms: 398.729068097
# râler Nombre de cliques 31
# max score among faithfull cliques of 28 forms: 388.667574765
# exorciser Nombre de cliques 79
# max score among faithfull cliques of 27 forms: 308.23475514
# suriner Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 411.311321402
# contribuer Nombre de cliques 51
# max score among faithfull cliques of 24 forms: 265.387815037
# rustiquer Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 422.961560136
# coproduire Nombre de cliques 76
# max score among faithfull cliques of 26 forms: 190.594049663
# présumer Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 413.405029661
# recoloniser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 417.397922254
# revisser Nombre de cliques 44
# max score among faithfull cliques of 23 forms: 177.720683329
# détacher Nombre de cliques 47
# max score among faithfull cliques of 29 forms: 403.619527979
# trôner Nombre de cliques 64
# max score among faithfull cliques of 20 forms: 100.201549496
# défléchir Nombre de cliques 108
# max score among faithfull cliques of 25 forms: 214.674088246
# pister Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 418.486519696
# éradiquer Nombre de cliques 28
# max score among faithfull cliques of 29 forms: 411.031773359
# ballaster Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 426.804417903
# parlementer Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 383.479551399
# trépider Nombre de cliques 18
# max score among faithfull cliques of 28 forms: 369.109836539
# rebondir Nombre de cliques 268
# max score among faithfull cliques of 25 forms: 188.444634635
# poser Nombre de cliques 85
# max score among faithfull cliques of 30 forms: 386.340480306
# dîner Nombre de cliques 33
# max score among faithfull cliques of 29 forms: 411.939050314
# styliser Nombre de cliques 12
# max score among faithfull cliques of 29 forms: 400.050709516
# fournir Nombre de cliques 111
# max score among faithfull cliques of 26 forms: 249.453702695
# préfigurer Nombre de cliques 27
# max score among faithfull cliques of 29 forms: 399.506579505
# briser Nombre de cliques 60
# max score among faithfull cliques of 29 forms: 389.23848263
# chevaucher Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 400.291745868
# loucher Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 423.9497123
# filouter Nombre de cliques 15
# max score among faithfull cliques of 29 forms: 416.979188454
# tictaquer Nombre de cliques 5
# max score among faithfull cliques of 29 forms: 420.9274236
# fourrer Nombre de cliques 64
# max score among faithfull cliques of 26 forms: 321.938216696
# proroger Nombre de cliques 27
# max score among faithfull cliques of 29 forms: 409.188924126
# soutirer Nombre de cliques 45
# max score among faithfull cliques of 29 forms: 405.701220385
# détester Nombre de cliques 30
# max score among faithfull cliques of 27 forms: 363.558906727
# tordre Nombre de cliques 71
# max score among faithfull cliques of 23 forms: 114.504587476
# léguer Nombre de cliques 22
# max score among faithfull cliques of 29 forms: 424.736004929
# rescolariser Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 399.825843092
# descendre Nombre de cliques 78
# max score among faithfull cliques of 28 forms: 212.201298632
# coller Nombre de cliques 39
# max score among faithfull cliques of 28 forms: 378.556777096
# retravailler Nombre de cliques 60
# max score among faithfull cliques of 26 forms: 235.890758556
# délivrer Nombre de cliques 113
# max score among faithfull cliques of 26 forms: 311.304558042
# patauger Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 394.177537233
# moraliser Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 401.469170338
# morfler Nombre de cliques 38
# max score among faithfull cliques of 25 forms: 316.462325455
# rapprovisionner Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 416.52436075
# encocher Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 412.243826748
# automatiser Nombre de cliques 33
# max score among faithfull cliques of 27 forms: 327.311947949
# disqualifier Nombre de cliques 220
# max score among faithfull cliques of 25 forms: 202.117668622
# iodler Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 341.291744678
# démunir Nombre de cliques 71
# max score among faithfull cliques of 26 forms: 262.573373716
# béatifier Nombre de cliques 88
# max score among faithfull cliques of 25 forms: 224.951630955
# pilonner Nombre de cliques 12
# max score among faithfull cliques of 29 forms: 414.345752119
# mutiler Nombre de cliques 28
# max score among faithfull cliques of 28 forms: 394.172537973
# brasiller Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 275.396484277
# reconduire Nombre de cliques 133
# max score among faithfull cliques of 26 forms: 186.824423171
# ensiler Nombre de cliques 4
# max score among faithfull cliques of 28 forms: 400.541172996
# récuser Nombre de cliques 58
# max score among faithfull cliques of 29 forms: 391.110129837
# câbler Nombre de cliques 33
# max score among faithfull cliques of 26 forms: 333.258346303
# spolier Nombre de cliques 54
# max score among faithfull cliques of 24 forms: 209.010369239
# roupiller Nombre de cliques 157
# max score among faithfull cliques of 25 forms: 241.583151308
# affûter Nombre de cliques 23
# max score among faithfull cliques of 29 forms: 396.543027639
# japoniser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 417.397922254
# éparpiller Nombre de cliques 210
# max score among faithfull cliques of 25 forms: 231.434851487
# modéliser Nombre de cliques 13
# max score among faithfull cliques of 29 forms: 394.558933082
# improuver Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 401.805377622
# smasher Nombre de cliques 8
# max score among faithfull cliques of 27 forms: 371.605198396
# escarmoucher Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 413.052989161
# décroûter Nombre de cliques 13
# max score among faithfull cliques of 29 forms: 382.071488021
# conjuguer Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 410.471748818
# angéliser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 407.495713547
# creuser Nombre de cliques 193
# max score among faithfull cliques of 25 forms: 282.379256105
# centrifuger Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 414.512647274
# démasquer Nombre de cliques 23
# max score among faithfull cliques of 29 forms: 424.899637143
# rasseoir Nombre de cliques 216
# max score among faithfull cliques of 15 forms: 90.828436325
# quintupler Nombre de cliques 14
# max score among faithfull cliques of 26 forms: 336.883957822
# tarder Nombre de cliques 44
# max score among faithfull cliques of 29 forms: 399.520827281
# dealer Nombre de cliques 29
# max score among faithfull cliques of 28 forms: 393.696066512
# somatiser Nombre de cliques 60
# max score among faithfull cliques of 27 forms: 318.508433882
# suinter Nombre de cliques 21
# max score among faithfull cliques of 28 forms: 364.612297878
# coéditer Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 415.041322218
# protester Nombre de cliques 30
# max score among faithfull cliques of 30 forms: 446.771982655
# aiguer Nombre de cliques 3
# max score among faithfull cliques of 28 forms: 401.374950155
# baiser Nombre de cliques 117
# max score among faithfull cliques of 28 forms: 287.197852445
# déphaser Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 409.127594083
# épaissir Nombre de cliques 302
# max score among faithfull cliques of 25 forms: 188.261518904
# siéger Nombre de cliques 52
# max score among faithfull cliques of 29 forms: 407.440838702
# retraire Nombre de cliques 38
# max score among faithfull cliques of 20 forms: 130.55860589
# différer Nombre de cliques 109
# max score among faithfull cliques of 29 forms: 376.309016688
# transporter Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 382.875285304
# mirer Nombre de cliques 78
# max score among faithfull cliques of 29 forms: 400.644255012
# paralléliser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 407.813042466
# remparer Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 403.469409329
# gourer Nombre de cliques 35
# max score among faithfull cliques of 25 forms: 296.681392018
# psalmodier Nombre de cliques 229
# max score among faithfull cliques of 25 forms: 212.771236128
# malmener Nombre de cliques 67
# max score among faithfull cliques of 27 forms: 254.347923705
# sniffer Nombre de cliques 57
# max score among faithfull cliques of 28 forms: 361.054367861
# frire Nombre de cliques 103
# max score among faithfull cliques of 19 forms: 112.651583436
# cravater Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 392.171437459
# doter Nombre de cliques 55
# max score among faithfull cliques of 30 forms: 413.129870423
# retéléphoner Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 392.956303748
# morguer Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 420.896201512
# transcoder Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 404.049655549
# polluer Nombre de cliques 24
# max score among faithfull cliques of 25 forms: 288.321857114
# baller Nombre de cliques 18
# max score among faithfull cliques of 28 forms: 393.149213203
# perquisitionner Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 400.737281905
# claver Nombre de cliques 9
# max score among faithfull cliques of 26 forms: 339.13233728
# calomnier Nombre de cliques 50
# max score among faithfull cliques of 21 forms: 155.654334742
# truquer Nombre de cliques 26
# max score among faithfull cliques of 29 forms: 409.597417375
# caviarder Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 411.877591301
# jardiner Nombre de cliques 30
# max score among faithfull cliques of 28 forms: 382.243559626
# fatiguer Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 409.10859477
# chalouper Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 425.294678735
# élucubrer Nombre de cliques 5
# max score among faithfull cliques of 26 forms: 338.904207247
# avoyer Nombre de cliques 61
# max score among faithfull cliques of 22 forms: 138.814195939
# bluffer Nombre de cliques 106
# max score among faithfull cliques of 18 forms: 155.744472862
# emmerder Nombre de cliques 48
# max score among faithfull cliques of 28 forms: 336.07736598
# enluminer Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 406.228516614
# échauffer Nombre de cliques 84
# max score among faithfull cliques of 28 forms: 358.21763921
# zozoter Nombre de cliques 56
# max score among faithfull cliques of 29 forms: 375.487776252
# distraire Nombre de cliques 96
# max score among faithfull cliques of 21 forms: 126.584507017
# rasséréner Nombre de cliques 19
# max score among faithfull cliques of 28 forms: 325.374985182
# thermoformer Nombre de cliques 3
# max score among faithfull cliques of 28 forms: 392.68554288
# chapeauter Nombre de cliques 49
# max score among faithfull cliques of 29 forms: 382.055910529
# fricoter Nombre de cliques 59
# max score among faithfull cliques of 29 forms: 380.165519179
# surpayer Nombre de cliques 54
# max score among faithfull cliques of 22 forms: 179.125529323
# prévoir Nombre de cliques 187
# max score among faithfull cliques of 23 forms: 135.988109955
# soupçonner Nombre de cliques 46
# max score among faithfull cliques of 29 forms: 388.868018022
# idiotiser Nombre de cliques 23
# max score among faithfull cliques of 27 forms: 270.8661574
# besogner Nombre de cliques 22
# max score among faithfull cliques of 27 forms: 357.233675656
# phosphater Nombre de cliques 11
# max score among faithfull cliques of 29 forms: 368.600810368
# cimenter Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 388.663666348
# nieller Nombre de cliques 32
# max score among faithfull cliques of 23 forms: 267.963957533
# axer Nombre de cliques 30
# max score among faithfull cliques of 27 forms: 363.907912103
# rocher Nombre de cliques 28
# max score among faithfull cliques of 29 forms: 406.133677403
# tabuler Nombre de cliques 9
# max score among faithfull cliques of 28 forms: 385.184422352
# syndiquer Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 406.66908391
# calandrer Nombre de cliques 13
# max score among faithfull cliques of 26 forms: 321.915345256
# volter Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 318.527624655
# ahurir Nombre de cliques 119
# max score among faithfull cliques of 26 forms: 227.579298304
# décolleter Nombre de cliques 18
# max score among faithfull cliques of 27 forms: 310.838712808
# moirer Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 387.2185857
# affoler Nombre de cliques 38
# max score among faithfull cliques of 28 forms: 378.618360719
# renoncer Nombre de cliques 59
# max score among faithfull cliques of 29 forms: 399.096007323
# flûter Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 422.481540267
# imiter Nombre de cliques 39
# max score among faithfull cliques of 29 forms: 396.730134449
# fayoter Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 385.599804605
# fomenter Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 383.666710459
# dérougir Nombre de cliques 133
# max score among faithfull cliques of 25 forms: 227.009055198
# désaffectionner Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 382.242485511
# poursuivre Nombre de cliques 103
# max score among faithfull cliques of 28 forms: 175.505540839
# vitrifier Nombre de cliques 94
# max score among faithfull cliques of 25 forms: 219.468429724
# impacter Nombre de cliques 14
# max score among faithfull cliques of 27 forms: 367.284786732
# jongler Nombre de cliques 25
# max score among faithfull cliques of 26 forms: 336.042179438
# serpenter Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 384.376225989
# réconcilier Nombre de cliques 69
# max score among faithfull cliques of 23 forms: 163.280686728
# tiser Nombre de cliques 29
# max score among faithfull cliques of 27 forms: 328.194916734
# gifler Nombre de cliques 47
# max score among faithfull cliques of 26 forms: 333.113219219
# inverser Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 384.141275581
# empreindre Nombre de cliques 23
# max score among faithfull cliques of 23 forms: 195.870881474
# interloquer Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 425.178078702
# endetter Nombre de cliques 44
# max score among faithfull cliques of 29 forms: 323.480162822
# prodiguer Nombre de cliques 31
# max score among faithfull cliques of 29 forms: 408.18393829
# opposer Nombre de cliques 86
# max score among faithfull cliques of 29 forms: 357.7169689
# défoncer Nombre de cliques 51
# max score among faithfull cliques of 29 forms: 394.906582452
# éperdre Nombre de cliques 28
# max score among faithfull cliques of 27 forms: 196.160805063
# limoger Nombre de cliques 10
# max score among faithfull cliques of 29 forms: 412.939064523
# feutrer Nombre de cliques 15
# max score among faithfull cliques of 26 forms: 331.390521147
# consoler Nombre de cliques 36
# max score among faithfull cliques of 28 forms: 379.03299113
# scratcher Nombre de cliques 8
# max score among faithfull cliques of 27 forms: 373.08178553
# flaquer Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 425.130230569
# soutenir Nombre de cliques 141
# max score among faithfull cliques of 26 forms: 290.516240603
# ambrer Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 328.460765655
# réalimenter Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 398.193850487
# sanctifier Nombre de cliques 228
# max score among faithfull cliques of 25 forms: 193.974516617
# inciter Nombre de cliques 33
# max score among faithfull cliques of 29 forms: 395.497563152
# déchiqueter Nombre de cliques 19
# max score among faithfull cliques of 27 forms: 366.412433677
# grognonner Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 421.162820621
# nettoyer Nombre de cliques 72
# max score among faithfull cliques of 25 forms: 213.974282068
# repartager Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 420.958830125
# maugréer Nombre de cliques 48
# max score among faithfull cliques of 20 forms: 144.572549297
# épousseter Nombre de cliques 66
# max score among faithfull cliques of 28 forms: 259.248246792
# encarter Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 408.468750255
# coordonner Nombre de cliques 91
# max score among faithfull cliques of 21 forms: 126.048464247
# fleurdeliser Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 395.442627128
# loufer Nombre de cliques 9
# max score among faithfull cliques of 28 forms: 387.106139917
# admirer Nombre de cliques 82
# max score among faithfull cliques of 27 forms: 350.906511336
# déviriliser Nombre de cliques 16
# max score among faithfull cliques of 29 forms: 392.443919476
# décloisonner Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 391.37017006
# déduire Nombre de cliques 133
# max score among faithfull cliques of 26 forms: 188.548657705
# ...
# dégrader Nombre de cliques 36
# max score among faithfull cliques of 29 forms: 390.429632667
# foudroyer Nombre de cliques 52
# max score among faithfull cliques of 24 forms: 195.045297695
# dévirginiser Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 417.800428816
# asphyxier Nombre de cliques 131
# max score among faithfull cliques of 23 forms: 176.340352974
# africaniser Nombre de cliques 5
# max score among faithfull cliques of 29 forms: 417.599175535
# englober Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 412.082011509
# escarper Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 409.733649634
# sigler Nombre de cliques 5
# max score among faithfull cliques of 26 forms: 340.478817978
# permanenter Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 407.838287502
# enclore Nombre de cliques 17
# max score among faithfull cliques of 6 forms: 18.0227396453
# oraliser Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 407.495713547
# infléchir Nombre de cliques 131
# max score among faithfull cliques of 25 forms: 229.921775015
# assécher Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 405.479878399
# propager Nombre de cliques 49
# max score among faithfull cliques of 29 forms: 406.602804103
# veiller Nombre de cliques 89
# max score among faithfull cliques of 26 forms: 223.738163714
# caracoler Nombre de cliques 25
# max score among faithfull cliques of 28 forms: 382.828310257
# parachever Nombre de cliques 104
# max score among faithfull cliques of 27 forms: 241.519404065
# élaguer Nombre de cliques 10
# max score among faithfull cliques of 29 forms: 427.378046079
# chuter Nombre de cliques 42
# max score among faithfull cliques of 29 forms: 399.353990253
# départir Nombre de cliques 81
# max score among faithfull cliques of 28 forms: 141.710302227
# tressaillir Nombre de cliques 127
# max score among faithfull cliques of 18 forms: 75.2907558943
# juger Nombre de cliques 34
# max score among faithfull cliques of 29 forms: 411.28144499
# connoter Nombre de cliques 44
# max score among faithfull cliques of 29 forms: 385.53808717
# désapprendre Nombre de cliques 39
# max score among faithfull cliques of 28 forms: 359.502317619
# voltiger Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 409.409167585
# dynamiser Nombre de cliques 31
# max score among faithfull cliques of 29 forms: 403.616259912
# délabrer Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 327.061170733
# pomponner Nombre de cliques 32
# max score among faithfull cliques of 29 forms: 394.710298494
# désexualiser Nombre de cliques 9
# max score among faithfull cliques of 29 forms: 404.622509397
# prélaver Nombre de cliques 7
# max score among faithfull cliques of 26 forms: 339.13233728
# raisonner Nombre de cliques 45
# max score among faithfull cliques of 29 forms: 388.269895402
# insurger Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 417.587708256
# graveler Nombre de cliques 23
# max score among faithfull cliques of 27 forms: 261.167776616
# réengager Nombre de cliques 35
# max score among faithfull cliques of 29 forms: 412.547113203
# spammer Nombre de cliques 14
# max score among faithfull cliques of 28 forms: 382.597047007
# louper Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 417.535371015
# corser Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 390.553676643
# anodiser Nombre de cliques 14
# max score among faithfull cliques of 25 forms: 288.878555088
# thésauriser Nombre de cliques 40
# max score among faithfull cliques of 29 forms: 378.398219656
# rebaisser Nombre de cliques 25
# max score among faithfull cliques of 27 forms: 325.939904884
# friponner Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 404.946075977
# obscurcir Nombre de cliques 236
# max score among faithfull cliques of 25 forms: 198.257992182
# lorgner Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 336.671875164
# claironner Nombre de cliques 23
# max score among faithfull cliques of 29 forms: 395.765658934
# pédaler Nombre de cliques 26
# max score among faithfull cliques of 28 forms: 392.509351156
# terroriser Nombre de cliques 55
# max score among faithfull cliques of 29 forms: 393.127004281
# désengourdir Nombre de cliques 23
# max score among faithfull cliques of 26 forms: 234.384855219
# accabler Nombre de cliques 42
# max score among faithfull cliques of 26 forms: 331.537762899
# insupporter Nombre de cliques 15
# max score among faithfull cliques of 29 forms: 385.644746373
# ennoblir Nombre de cliques 31
# max score among faithfull cliques of 25 forms: 232.866284483
# goûter Nombre de cliques 44
# max score among faithfull cliques of 29 forms: 399.703907859
# pitonner Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 405.332439613
# départager Nombre de cliques 35
# max score among faithfull cliques of 29 forms: 406.482319111
# préconcevoir Nombre de cliques 17
# max score among faithfull cliques of 28 forms: 150.424862341
# désaliniser Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 417.800428816
# repiquer Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 412.260146155
# froisser Nombre de cliques 85
# max score among faithfull cliques of 28 forms: 340.586097767
# subvenir Nombre de cliques 129
# max score among faithfull cliques of 27 forms: 311.531291861
# merdoyer Nombre de cliques 51
# max score among faithfull cliques of 25 forms: 231.574452954
# resituer Nombre de cliques 20
# max score among faithfull cliques of 27 forms: 351.681937966
# inhumer Nombre de cliques 34
# max score among faithfull cliques of 29 forms: 417.822290578
# rogner Nombre de cliques 25
# max score among faithfull cliques of 27 forms: 353.459085123
# préparer Nombre de cliques 57
# max score among faithfull cliques of 29 forms: 383.965707542
# modérer Nombre de cliques 85
# max score among faithfull cliques of 29 forms: 381.292765667
# sauter Nombre de cliques 67
# max score among faithfull cliques of 29 forms: 377.682809587
# resurgir Nombre de cliques 205
# max score among faithfull cliques of 26 forms: 242.685886772
# ratonner Nombre de cliques 11
# max score among faithfull cliques of 29 forms: 394.350533807
# dévaluer Nombre de cliques 25
# max score among faithfull cliques of 25 forms: 291.94829192
# brumer Nombre de cliques 4
# max score among faithfull cliques of 29 forms: 424.98188614
# gruger Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 410.257571557
# décapoter Nombre de cliques 35
# max score among faithfull cliques of 29 forms: 395.177835136
# émacier Nombre de cliques 90
# max score among faithfull cliques of 25 forms: 228.612279068
# ébaucher Nombre de cliques 33
# max score among faithfull cliques of 29 forms: 399.793851007
# remonter Nombre de cliques 49
# max score among faithfull cliques of 29 forms: 396.369542267
# bander Nombre de cliques 43
# max score among faithfull cliques of 29 forms: 370.719379831
# réhabiliter Nombre de cliques 20
# max score among faithfull cliques of 29 forms: 419.503460626
# catéchiser Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 410.500349306
# gargouiller Nombre de cliques 30
# max score among faithfull cliques of 25 forms: 290.641700543
# parapher Nombre de cliques 43
# max score among faithfull cliques of 28 forms: 357.899129489
# appauvrir Nombre de cliques 234
# max score among faithfull cliques of 17 forms: 81.182926016
# crier Nombre de cliques 155
# max score among faithfull cliques of 25 forms: 141.665904821
# ragoûter Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 417.959270497
# riveter Nombre de cliques 40
# max score among faithfull cliques of 28 forms: 280.594109245
# rouvrir Nombre de cliques 224
# max score among faithfull cliques of 25 forms: 167.020368655
# amalgamer Nombre de cliques 14
# max score among faithfull cliques of 29 forms: 414.358830878
# contredire Nombre de cliques 263
# max score among faithfull cliques of 23 forms: 100.156918273
# trouilloter Nombre de cliques 25
# max score among faithfull cliques of 20 forms: 201.92870979
# camer Nombre de cliques 19
# max score among faithfull cliques of 29 forms: 412.114055685
# chorégraphier Nombre de cliques 269
# max score among faithfull cliques of 24 forms: 176.49091897
# recenser Nombre de cliques 28
# max score among faithfull cliques of 29 forms: 389.279753536
# prosodier Nombre de cliques 10
# max score among faithfull cliques of 23 forms: 224.736084186
# caillasser Nombre de cliques 51
# max score among faithfull cliques of 28 forms: 352.816403798
# ravager Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 407.529837183
# râper Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 396.405570274
# fagoter Nombre de cliques 163
# max score among faithfull cliques of 19 forms: 115.74917393
# représenter Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 380.419205267
# électrolyser Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 401.670423618
# accentuer Nombre de cliques 27
# max score among faithfull cliques of 27 forms: 351.645383927
# déterrer Nombre de cliques 104
# max score among faithfull cliques of 29 forms: 381.853093426
# boumer Nombre de cliques 17
# max score among faithfull cliques of 29 forms: 414.769321525
# crouler Nombre de cliques 31
# max score among faithfull cliques of 28 forms: 390.136170638
# espacer Nombre de cliques 93
# max score among faithfull cliques of 28 forms: 343.194614166
# indemniser Nombre de cliques 40
# max score among faithfull cliques of 29 forms: 401.638122206
# quémander Nombre de cliques 38
# max score among faithfull cliques of 29 forms: 389.54911614
# joncher Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 416.058997523
# miauler Nombre de cliques 33
# max score among faithfull cliques of 28 forms: 376.987471723
# miner Nombre de cliques 34
# max score among faithfull cliques of 27 forms: 362.285136701
# piétiner Nombre de cliques 33
# max score among faithfull cliques of 28 forms: 382.828573034
# ratiboiser Nombre de cliques 25
# max score among faithfull cliques of 28 forms: 371.933450176
# remplier Nombre de cliques 68
# max score among faithfull cliques of 7 forms: 18.7596018315
# décompresser Nombre de cliques 77
# max score among faithfull cliques of 29 forms: 301.201958503
# bouturer Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 419.728204841
# investir Nombre de cliques 161
# max score among faithfull cliques of 24 forms: 183.300221547
# trachéotomiser Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 413.95107389
# analyser Nombre de cliques 47
# max score among faithfull cliques of 29 forms: 378.458148467
# agrainer Nombre de cliques 4
# max score among faithfull cliques of 28 forms: 395.680663289
# vaquer Nombre de cliques 51
# max score among faithfull cliques of 29 forms: 403.235646101
# cyanoser Nombre de cliques 37
# max score among faithfull cliques of 19 forms: 153.687405299
# linger Nombre de cliques 2
# max score among faithfull cliques of 29 forms: 429.353761821
# pieuter Nombre de cliques 75
# max score among faithfull cliques of 11 forms: 60.6167394271
# ébahir Nombre de cliques 59
# max score among faithfull cliques of 26 forms: 308.241421436
# urger Nombre de cliques 30
# max score among faithfull cliques of 29 forms: 418.524189462
# rencaisser Nombre de cliques 3
# max score among faithfull cliques of 28 forms: 379.483256799
# dérouiller Nombre de cliques 32
# max score among faithfull cliques of 25 forms: 291.94337267
# sursignifier Nombre de cliques 11
# max score among faithfull cliques of 25 forms: 240.275704815
# ressurgir Nombre de cliques 205
# max score among faithfull cliques of 26 forms: 247.837054817
# halener Nombre de cliques 6
# max score among faithfull cliques of 29 forms: 310.118303979
# numériser Nombre de cliques 46
# max score among faithfull cliques of 29 forms: 390.354545407
# ingénier Nombre de cliques 56
# max score among faithfull cliques of 23 forms: 189.234602566
# délustrer Nombre de cliques 6
# max score among faithfull cliques of 25 forms: 318.550536199
# approuver Nombre de cliques 82
# max score among faithfull cliques of 29 forms: 378.694784668
# défroquer Nombre de cliques 29
# max score among faithfull cliques of 29 forms: 406.326514575
# chuchoter Nombre de cliques 68
# max score among faithfull cliques of 29 forms: 382.254119548
# missionner Nombre de cliques 9
# max score among faithfull cliques of 29 forms: 405.796764587
# volatiliser Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 395.17969073
# frauder Nombre de cliques 138
# max score among faithfull cliques of 19 forms: 101.784085628
# déminer Nombre de cliques 22
# max score among faithfull cliques of 29 forms: 414.873159395
# recontacter Nombre de cliques 32
# max score among faithfull cliques of 27 forms: 364.228765089
# reboucler Nombre de cliques 8
# max score among faithfull cliques of 26 forms: 339.065034815
# fourgonner Nombre de cliques 11
# max score among faithfull cliques of 29 forms: 403.484024659
# mailer Nombre de cliques 18
# max score among faithfull cliques of 28 forms: 394.710023811
# refouler Nombre de cliques 31
# max score among faithfull cliques of 28 forms: 387.556144791
# déconseiller Nombre de cliques 76
# max score among faithfull cliques of 25 forms: 226.034071891
# répercuter Nombre de cliques 37
# max score among faithfull cliques of 29 forms: 396.642170388
# précéder Nombre de cliques 53
# max score among faithfull cliques of 28 forms: 306.007638691
# fourrager Nombre de cliques 34
# max score among faithfull cliques of 29 forms: 409.098416986
# marier Nombre de cliques 264
# max score among faithfull cliques of 27 forms: 207.893414753
# faillir Nombre de cliques 78
# max score among faithfull cliques of 15 forms: 77.7620091427
# interchanger Nombre de cliques 18
# max score among faithfull cliques of 29 forms: 417.675363049
# chigner Nombre de cliques 15
# max score among faithfull cliques of 26 forms: 341.511237738
# épointer Nombre de cliques 8
# max score among faithfull cliques of 28 forms: 382.110577265
# repentir Nombre de cliques 181
# max score among faithfull cliques of 25 forms: 104.962823069
# autolimiter Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 416.624734032
# jumeler Nombre de cliques 29
# max score among faithfull cliques of 27 forms: 282.408470561
# dédicacer Nombre de cliques 96
# max score among faithfull cliques of 29 forms: 369.08204761
# poudroyer Nombre de cliques 35
# max score among faithfull cliques of 25 forms: 250.647028684
# paginer Nombre de cliques 15
# max score among faithfull cliques of 29 forms: 411.12844451
# plaquer Nombre de cliques 21
# max score among faithfull cliques of 29 forms: 424.864336802
# réépouser Nombre de cliques 7
# max score among faithfull cliques of 29 forms: 398.705310768
# démilitariser Nombre de cliques 8
# max score among faithfull cliques of 29 forms: 409.626418605
# démarier Nombre de cliques 157
# max score among faithfull cliques of 26 forms: 201.999550173
# importuner Nombre de cliques 34
# max score among faithfull cliques of 29 forms: 411.28734326
# pérorer Nombre de cliques 67
# max score among faithfull cliques of 29 forms: 372.862051681
# conspirer Nombre de cliques 58
# max score among faithfull cliques of 29 forms: 397.90501424
# atterrir Nombre de cliques 249
# max score among faithfull cliques of 25 forms: 192.059061912
# raidir Nombre de cliques 230
# max score among faithfull cliques of 26 forms: 207.964924533
# aviser Nombre de cliques 113
# max score among faithfull cliques of 26 forms: 282.047048206
# tranquilliser Nombre de cliques 28
# max score among faithfull cliques of 29 forms: 390.361647927
# décrire Nombre de cliques 277
# max score among faithfull cliques of 25 forms: 155.823968236
# branlocher Nombre de cliques 3
# max score among faithfull cliques of 29 forms: 424.497029315
# militer Nombre de cliques 22
# max score among faithfull cliques of 29 forms: 420.628872385
# piger Nombre de cliques 29
# max score among faithfull cliques of 29 forms: 408.033436235
# évanouir Nombre de cliques 99
# max score among faithfull cliques of 23 forms: 203.728704065
# tonner Nombre de cliques 46
# max score among faithfull cliques of 29 forms: 389.07532787
# CPU times: user 5h 43min 42s, sys: 2min 1s, total: 5h 45min 44s
# Wall time: 5h 45min 29s

# %%
newParadigmes,paradigmesSwim1,characteristicsSwim1,measuresSwim1=calculerResultats(swim1ContextParadigmes,"-Swim1")
# %ding
# Out:
# Index([u'value', u'lexeme-case'], dtype='object')
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/gilles/opt/anaconda3/envs/python2/lib/python2.7/site-packages/pandas/core/indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# UG 54169 OG 41392 TP 152870 FP 22053
# recall 0.667286504985 precision 0.706700876037
# 0.686428367763

# %% [markdown]
# # SWIM2

# %% [markdown]
# ## Préparation des paradigmes

# %%
paradigmesOriginaux=paradigmes.copy()
paradigmesSample=paradigmesOriginaux[paradigmesOriginaux["lexeme"].isin(listeTest)]

# %%
paradigmes=newParadigmes.copy()
paradigmesColumns=paradigmes.columns.tolist()
for c in sampleCases:
    if not c in paradigmesColumns:
        print (c)
        paradigmes[c]=np.NaN

# %%
cliques=[]
cliquesScores={}
cliquesListes={}

formesScores={}
formesScoresNormes={}

print (datetime.datetime.now())
# %time swim2ContextParadigmes=generateCliques(contextFree=True)
# Out:
# 2023-11-08 08:46:35.236266
# FloatProgress(value=0.0, description=u'Generation (6433 verbs)', max=6432.0)
# 0 0746 0, 100 0749 1, 200 0753 3, 300 0756 4, 400 0759 6, 500 0803 7, 600 0806 9, 700 0809 10, 800 0812 12, 900 0815 13, 1000 0819 15, 1100 0822 17, 1200 0825 18, 1300 0828 20, 1400 0832 21, 1500 0835 23, 1600 0838 24, 1700 0841 26, 1800 0845 27, 1900 0848 29, 2000 0851 31, 2100 0855 32, 2200 0858 34, 2300 0901 35, 2400 0905 37, 2500 0908 38, 2600 0911 40, 2700 0914 41, 2800 0918 43, 2900 0921 45, 3000 0924 46, 3100 0927 48, 3200 0930 49, 3300 0934 51, 3400 0937 52, 3500 0940 54, 3600 0944 55, 3700 0947 57, 3800 0950 59, 3900 0953 60, 4000 0957 62, 4100 1000 63, 4200 1003 65, 4300 1006 66, 4400 1010 68, 4500 1013 69, 4600 1016 71, 4700 1020 73, 4800 1023 74, 4900 1026 76, 5000 1030 77, 5100 1033 79, 5200 1037 80, 5300 1040 82, 5400 1043 83, 5500 1047 85, 5600 1050 87, 5700 1053 88, 5800 1057 90, 5900 1100 91, 6000 1103 93, 6100 1107 94, 6200 1110 96, 6300 1113 97, 6400 1117 99,
# FloatProgress(value=0.0, description=u'Analysis (6433 verbes)', max=6432.0)
# gauchir Nombre de cliques 2430
# max score among faithfull cliques of 28 forms: 105.184297662
# dénazifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# réinstaller Nombre de cliques 2801
# max score among faithfull cliques of 28 forms: 221.952315248
# caner Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# tancer Nombre de cliques 2516
# max score among faithfull cliques of 30 forms: 231.124371268
# devenir Nombre de cliques 4382
# max score among faithfull cliques of 31 forms: 215.557005852
# volanter Nombre de cliques 1864
# max score among faithfull cliques of 31 forms: 302.393405516
# orthographier Nombre de cliques 2250
# max score among faithfull cliques of 28 forms: 98.4799434097
# affectionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# verser Nombre de cliques 2484
# max score among faithfull cliques of 30 forms: 229.336750492
# dégommer Nombre de cliques 2213
# max score among faithfull cliques of 31 forms: 287.483998096
# déverser Nombre de cliques 2484
# max score among faithfull cliques of 30 forms: 229.336750492
# superposer Nombre de cliques 3048
# no new faithfull clique, the previous one contained 29 forms
# spiritualiser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# empoissonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# persister Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# déganter Nombre de cliques 1870
# max score among faithfull cliques of 31 forms: 302.393405516
# judaïser Nombre de cliques 2529
# max score among faithfull cliques of 30 forms: 249.375672776
# commenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# douiller Nombre de cliques 2949
# max score among faithfull cliques of 25 forms: 126.616805489
# concasser Nombre de cliques 2470
# no new faithfull clique, the previous one contained 29 forms
# entrégorger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# bossuer Nombre de cliques 2237
# max score among faithfull cliques of 29 forms: 220.119807315
# fritter Nombre de cliques 1848
# max score among faithfull cliques of 31 forms: 294.060698827
# maquereauter Nombre de cliques 3137
# max score among faithfull cliques of 26 forms: 129.402239851
# boursicoter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# aposter Nombre de cliques 1857
# max score among faithfull cliques of 31 forms: 302.393405516
# chauffer Nombre de cliques 2250
# max score among faithfull cliques of 31 forms: 289.850610843
# poiler Nombre de cliques 2743
# max score among faithfull cliques of 28 forms: 217.933046479
# dépayser Nombre de cliques 2577
# max score among faithfull cliques of 30 forms: 248.939772011
# pencher Nombre de cliques 2086
# max score among faithfull cliques of 31 forms: 293.150505438
# poivrer Nombre de cliques 1963
# max score among faithfull cliques of 31 forms: 305.401329997
# évider Nombre de cliques 2126
# max score among faithfull cliques of 31 forms: 293.915530152
# foisonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# préluder Nombre de cliques 2040
# max score among faithfull cliques of 31 forms: 293.647941321
# moucharder Nombre de cliques 1982
# max score among faithfull cliques of 31 forms: 284.207310932
# muer Nombre de cliques 2169
# max score among faithfull cliques of 29 forms: 215.017612902
# revouloir Nombre de cliques 2033
# no new faithfull clique, the previous one contained 13 forms
# enquiquiner Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# effaroucher Nombre de cliques 2216
# max score among faithfull cliques of 31 forms: 302.089647449
# dévaloriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# grossir Nombre de cliques 2727
# max score among faithfull cliques of 28 forms: 105.184297662
# contre-braquer Nombre de cliques 2235
# max score among faithfull cliques of 29 forms: 260.052559238
# offenser Nombre de cliques 2463
# max score among faithfull cliques of 30 forms: 229.724815524
# fusionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# confisquer Nombre de cliques 1906
# max score among faithfull cliques of 31 forms: 303.791138772
# reporter Nombre de cliques 1805
# max score among faithfull cliques of 31 forms: 293.041907862
# susurrer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# parisianiser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# désincruster Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# éreinter Nombre de cliques 1909
# max score among faithfull cliques of 31 forms: 301.900138084
# fissurer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# bambocher Nombre de cliques 2255
# max score among faithfull cliques of 31 forms: 289.186933116
# biquer Nombre de cliques 2091
# max score among faithfull cliques of 31 forms: 304.062781369
# rassortir Nombre de cliques 1811
# max score among faithfull cliques of 30 forms: 79.6940588423
# ragoter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# déboulonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# aniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# endenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 301.480445466
# emplir Nombre de cliques 2801
# max score among faithfull cliques of 28 forms: 105.435889563
# remeubler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# prêcher Nombre de cliques 2684
# max score among faithfull cliques of 30 forms: 252.252246193
# coqueter Nombre de cliques 3454
# max score among faithfull cliques of 29 forms: 173.858900697
# unir Nombre de cliques 2236
# max score among faithfull cliques of 28 forms: 102.237806955
# agencer Nombre de cliques 2516
# max score among faithfull cliques of 30 forms: 229.79251755
# jambonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 293.552918316
# exploser Nombre de cliques 2961
# max score among faithfull cliques of 30 forms: 247.390792491
# transvider Nombre de cliques 2124
# max score among faithfull cliques of 31 forms: 294.412260396
# rugir Nombre de cliques 2248
# max score among faithfull cliques of 28 forms: 108.59379276
# menacer Nombre de cliques 2474
# no new faithfull clique, the previous one contained 29 forms
# décompiler Nombre de cliques 2806
# max score among faithfull cliques of 30 forms: 271.636290025
# fustiger Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# bâter Nombre de cliques 1849
# max score among faithfull cliques of 29 forms: 255.507179783
# ronger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# ébouriffer Nombre de cliques 2160
# max score among faithfull cliques of 31 forms: 304.281140426
# convoler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# sortir Nombre de cliques 1841
# max score among faithfull cliques of 30 forms: 79.9094956639
# mémoriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# précipiter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# orner Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# cajoler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# déclencher Nombre de cliques 2086
# max score among faithfull cliques of 31 forms: 303.542021207
# dérider Nombre de cliques 2126
# max score among faithfull cliques of 31 forms: 293.915530152
# prôner Nombre de cliques 3051
# max score among faithfull cliques of 26 forms: 123.785040039
# embuer Nombre de cliques 2169
# max score among faithfull cliques of 29 forms: 215.017612902
# ratisser Nombre de cliques 2265
# max score among faithfull cliques of 30 forms: 222.522821663
# nitrater Nombre de cliques 1896
# max score among faithfull cliques of 29 forms: 258.691356751
# sous-exploiter Nombre de cliques 2403
# max score among faithfull cliques of 29 forms: 255.923092423
# bigarrer Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 260.690374194
# swinguer Nombre de cliques 1786
# max score among faithfull cliques of 31 forms: 291.489891864
# canarder Nombre de cliques 1982
# max score among faithfull cliques of 31 forms: 284.207310932
# avarier Nombre de cliques 2386
# max score among faithfull cliques of 28 forms: 102.950082045
# prostituer Nombre de cliques 2221
# max score among faithfull cliques of 29 forms: 217.588572414
# biaiser Nombre de cliques 3058
# no new faithfull clique, the previous one contained 27 forms
# destiner Nombre de cliques 2029
# max score among faithfull cliques of 31 forms: 304.014479339
# mépriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# appendre Nombre de cliques 2509
# max score among faithfull cliques of 30 forms: 99.431390953
# préformater Nombre de cliques 1896
# max score among faithfull cliques of 29 forms: 258.691356751
# ardre Nombre de cliques 1153
# max score among faithfull cliques of 28 forms: 105.326413438
# vibrer Nombre de cliques 1769
# max score among faithfull cliques of 31 forms: 310.055431201
# attitrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# consacrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# combler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# émasculer Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 271.362878943
# naufrager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# typer Nombre de cliques 2085
# max score among faithfull cliques of 31 forms: 300.949438462
# sentir Nombre de cliques 1973
# max score among faithfull cliques of 29 forms: 75.8086192188
# expectorer Nombre de cliques 2303
# max score among faithfull cliques of 31 forms: 290.586262655
# accéder Nombre de cliques 2604
# max score among faithfull cliques of 30 forms: 243.225017855
# tarauder Nombre de cliques 3492
# max score among faithfull cliques of 26 forms: 135.478214314
# entrapercevoir Nombre de cliques 4381
# max score among faithfull cliques of 30 forms: 125.613134021
# défiler Nombre de cliques 2807
# max score among faithfull cliques of 30 forms: 271.137777565
# pigmenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# substituer Nombre de cliques 2221
# max score among faithfull cliques of 29 forms: 217.588572414
# efféminer Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 304.882126565
# boire Nombre de cliques 4052
# max score among faithfull cliques of 26 forms: 65.8146946719
# sous-tendre Nombre de cliques 2509
# max score among faithfull cliques of 30 forms: 100.314773009
# profaner Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# repriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# maturer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# bâcher Nombre de cliques 1970
# no new faithfull clique, the previous one contained 29 forms
# plafonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# collectionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# bosseler Nombre de cliques 4546
# max score among faithfull cliques of 29 forms: 170.687919915
# incendier Nombre de cliques 2131
# max score among faithfull cliques of 28 forms: 104.071177363
# réfracter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# surgir Nombre de cliques 2252
# max score among faithfull cliques of 28 forms: 107.417020152
# vadrouiller Nombre de cliques 2949
# max score among faithfull cliques of 25 forms: 126.616805489
# éloigner Nombre de cliques 2623
# max score among faithfull cliques of 27 forms: 181.765263274
# braiser Nombre de cliques 3013
# no new faithfull clique, the previous one contained 29 forms
# froufrouter Nombre de cliques 1991
# max score among faithfull cliques of 31 forms: 290.448481539
# violacer Nombre de cliques 2510
# no new faithfull clique, the previous one contained 29 forms
# ensacher Nombre de cliques 2017
# no new faithfull clique, the previous one contained 29 forms
# rapprendre Nombre de cliques 3332
# max score among faithfull cliques of 31 forms: 87.1967398834
# vouloir Nombre de cliques 6792
# max score among faithfull cliques of 28 forms: 52.6431875082
# grognasser Nombre de cliques 2509
# no new faithfull clique, the previous one contained 29 forms
# aliter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# boucaner Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# piocher Nombre de cliques 2255
# max score among faithfull cliques of 31 forms: 289.186933116
# couturer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# acheminer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# stabiliser Nombre de cliques 2605
# no new faithfull clique, the previous one contained 29 forms
# opacifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# blinder Nombre de cliques 2234
# max score among faithfull cliques of 31 forms: 294.140885478
# parasiter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# désendetter Nombre de cliques 2793
# no new faithfull clique, the previous one contained 29 forms
# autodéterminer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# retuber Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# gercer Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 229.408806691
# inaugurer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# blablater Nombre de cliques 1896
# max score among faithfull cliques of 29 forms: 258.691356751
# rembobiner Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# ratiociner Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# roquer Nombre de cliques 2205
# max score among faithfull cliques of 31 forms: 289.95823938
# biser Nombre de cliques 2480
# no new faithfull clique, the previous one contained 25 forms
# valoir Nombre de cliques 4162
# max score among faithfull cliques of 24 forms: 72.858688308
# assurer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# emprisonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# réattribuer Nombre de cliques 2180
# max score among faithfull cliques of 29 forms: 215.017612902
# materner Nombre de cliques 1860
# max score among faithfull cliques of 31 forms: 306.015382391
# décarboniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# réciproquer Nombre de cliques 2205
# max score among faithfull cliques of 31 forms: 289.95823938
# glycériner Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 304.882126565
# carotter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# maximaliser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# épeurer Nombre de cliques 2700
# no new faithfull clique, the previous one contained 21 forms
# redéfinir Nombre de cliques 2435
# max score among faithfull cliques of 28 forms: 107.53556904
# apitoyer Nombre de cliques 3112
# max score among faithfull cliques of 26 forms: 106.91652014
# gambiller Nombre de cliques 2606
# max score among faithfull cliques of 26 forms: 115.430413332
# rejouer Nombre de cliques 2031
# max score among faithfull cliques of 29 forms: 191.707853416
# embrouiller Nombre de cliques 2949
# max score among faithfull cliques of 25 forms: 126.616805489
# lister Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# détracter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# octroyer Nombre de cliques 3095
# max score among faithfull cliques of 26 forms: 103.724459131
# entrevoir Nombre de cliques 4023
# max score among faithfull cliques of 28 forms: 52.746752752
# regreffer Nombre de cliques 2560
# max score among faithfull cliques of 30 forms: 250.368321717
# préremplir Nombre de cliques 2854
# max score among faithfull cliques of 28 forms: 107.321419093
# bitter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# motoriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# rectifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# dissimiler Nombre de cliques 2806
# max score among faithfull cliques of 30 forms: 271.636290025
# dépurer Nombre de cliques 2008
# max score among faithfull cliques of 31 forms: 304.444202448
# exulter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 296.694710139
# baliser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# tirer Nombre de cliques 2195
# max score among faithfull cliques of 31 forms: 304.715845046
# prouter Nombre de cliques 1991
# max score among faithfull cliques of 31 forms: 290.448481539
# ardoiser Nombre de cliques 2974
# no new faithfull clique, the previous one contained 28 forms
# cacarder Nombre de cliques 1982
# max score among faithfull cliques of 31 forms: 284.207310932
# mitrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# palanquer Nombre de cliques 1908
# max score among faithfull cliques of 31 forms: 303.791138772
# chamarrer Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 260.690374194
# arrimer Nombre de cliques 2147
# max score among faithfull cliques of 31 forms: 301.943671317
# absorber Nombre de cliques 1829
# max score among faithfull cliques of 31 forms: 295.326877229
# overclocker Nombre de cliques 2205
# max score among faithfull cliques of 31 forms: 289.95823938
# désensorceler Nombre de cliques 4546
# max score among faithfull cliques of 29 forms: 170.687919915
# décentrer Nombre de cliques 2269
# max score among faithfull cliques of 28 forms: 200.22944903
# coulisser Nombre de cliques 2267
# max score among faithfull cliques of 30 forms: 223.133656543
# nuer Nombre de cliques 2218
# max score among faithfull cliques of 29 forms: 217.588572414
# enjamber Nombre de cliques 1829
# max score among faithfull cliques of 31 forms: 295.326877229
# fauter Nombre de cliques 2721
# max score among faithfull cliques of 26 forms: 109.441168185
# briffer Nombre de cliques 2160
# max score among faithfull cliques of 31 forms: 304.281140426
# bafouer Nombre de cliques 2065
# max score among faithfull cliques of 29 forms: 196.350368338
# discréditer Nombre de cliques 1971
# max score among faithfull cliques of 31 forms: 291.61250127
# singer Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# provisionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# purger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# calquer Nombre de cliques 1814
# max score among faithfull cliques of 31 forms: 298.124795445
# dessiner Nombre de cliques 2083
# max score among faithfull cliques of 31 forms: 304.385073045
# relever Nombre de cliques 4153
# max score among faithfull cliques of 27 forms: 121.036933202
# tapoter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# réparer Nombre de cliques 2036
# max score among faithfull cliques of 29 forms: 260.211115382
# froncer Nombre de cliques 2454
# max score among faithfull cliques of 30 forms: 229.724815524
# essorer Nombre de cliques 2305
# max score among faithfull cliques of 31 forms: 290.131710088
# ruisseler Nombre de cliques 4546
# max score among faithfull cliques of 29 forms: 170.687919915
# écouler Nombre de cliques 2829
# no new faithfull clique, the previous one contained 28 forms
# dégoûter Nombre de cliques 1991
# max score among faithfull cliques of 31 forms: 289.955161783
# replâtrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# décrypter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# caper Nombre de cliques 1928
# max score among faithfull cliques of 29 forms: 257.01775335
# toucher Nombre de cliques 2216
# max score among faithfull cliques of 31 forms: 302.089647449
# écarquiller Nombre de cliques 2623
# max score among faithfull cliques of 26 forms: 115.430413332
# poireauter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# tournailler Nombre de cliques 2708
# max score among faithfull cliques of 26 forms: 107.137337291
# ravaler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 221.952315248
# annihiler Nombre de cliques 2806
# max score among faithfull cliques of 30 forms: 271.636290025
# environner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# repolariser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# essaimer Nombre de cliques 3071
# no new faithfull clique, the previous one contained 28 forms
# effriter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# étoffer Nombre de cliques 2252
# max score among faithfull cliques of 31 forms: 289.382056399
# rameuter Nombre de cliques 3973
# max score among faithfull cliques of 26 forms: 172.222243485
# reposer Nombre de cliques 2996
# max score among faithfull cliques of 30 forms: 248.828439668
# badigeonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# fleurir Nombre de cliques 3315
# no new faithfull clique, the previous one contained 25 forms
# faisander Nombre de cliques 2004
# max score among faithfull cliques of 31 forms: 293.923714998
# ensuquer Nombre de cliques 1906
# max score among faithfull cliques of 31 forms: 303.791138772
# drayer Nombre de cliques 2299
# no new faithfull clique, the previous one contained 25 forms
# mâchurer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# outiller Nombre de cliques 2622
# max score among faithfull cliques of 26 forms: 115.430413332
# lapider Nombre de cliques 2037
# max score among faithfull cliques of 31 forms: 295.319014992
# embouter Nombre de cliques 2043
# max score among faithfull cliques of 31 forms: 299.787442442
# haïr Nombre de cliques 2319
# max score among faithfull cliques of 28 forms: 105.42927679
# clarifier Nombre de cliques 2461
# max score among faithfull cliques of 28 forms: 100.98231058
# désigner Nombre de cliques 1952
# max score among faithfull cliques of 28 forms: 222.711079245
# dépêtrer Nombre de cliques 2227
# max score among faithfull cliques of 28 forms: 199.760671887
# reprogrammer Nombre de cliques 1968
# max score among faithfull cliques of 29 forms: 257.987644262
# débiner Nombre de cliques 2031
# max score among faithfull cliques of 31 forms: 303.51227895
# pressurer Nombre de cliques 1988
# max score among faithfull cliques of 31 forms: 303.950935016
# entreposer Nombre de cliques 3048
# no new faithfull clique, the previous one contained 29 forms
# embrever Nombre de cliques 4192
# no new faithfull clique, the previous one contained 26 forms
# débouder Nombre de cliques 2383
# max score among faithfull cliques of 31 forms: 293.752226458
# moissonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# souvenir Nombre de cliques 4336
# max score among faithfull cliques of 31 forms: 209.235878114
# euphoriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# cafter Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# nébuliser Nombre de cliques 2605
# no new faithfull clique, the previous one contained 29 forms
# étourdir Nombre de cliques 2341
# max score among faithfull cliques of 28 forms: 106.535126249
# adapter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# remouler Nombre de cliques 2827
# no new faithfull clique, the previous one contained 28 forms
# incinérer Nombre de cliques 2959
# max score among faithfull cliques of 30 forms: 246.940075579
# fouiner Nombre de cliques 2029
# max score among faithfull cliques of 31 forms: 304.014479339
# percuter Nombre de cliques 1880
# max score among faithfull cliques of 31 forms: 302.393405516
# écourter Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# révulser Nombre de cliques 2409
# max score among faithfull cliques of 30 forms: 223.997128949
# patenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 301.480445466
# demander Nombre de cliques 1952
# max score among faithfull cliques of 31 forms: 284.207310932
# surproduire Nombre de cliques 3161
# max score among faithfull cliques of 27 forms: 73.22622871
# avaliser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# pactiser Nombre de cliques 2561
# no new faithfull clique, the previous one contained 26 forms
# menuiser Nombre de cliques 2590
# no new faithfull clique, the previous one contained 26 forms
# mortifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# perler Nombre de cliques 2574
# max score among faithfull cliques of 30 forms: 270.910697223
# exaspérer Nombre de cliques 2959
# max score among faithfull cliques of 30 forms: 246.940075579
# ganter Nombre de cliques 1864
# max score among faithfull cliques of 31 forms: 302.393405516
# potasser Nombre de cliques 2545
# no new faithfull clique, the previous one contained 29 forms
# récliner Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# traficoter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# parler Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 271.362878943
# défouler Nombre de cliques 2829
# no new faithfull clique, the previous one contained 28 forms
# penser Nombre de cliques 2516
# max score among faithfull cliques of 30 forms: 231.124371268
# tutoyer Nombre de cliques 3112
# max score among faithfull cliques of 26 forms: 106.91652014
# suivre Nombre de cliques 2946
# max score among faithfull cliques of 28 forms: 95.5726961
# haranguer Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# contreficher Nombre de cliques 2146
# max score among faithfull cliques of 31 forms: 303.765284362
# batifoler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# claboter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 291.487577114
# criminaliser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# panoramiquer Nombre de cliques 2091
# max score among faithfull cliques of 31 forms: 304.062781369
# empêcher Nombre de cliques 2684
# max score among faithfull cliques of 30 forms: 252.252246193
# tortorer Nombre de cliques 2303
# max score among faithfull cliques of 31 forms: 290.586262655
# récriminer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# déverdir Nombre de cliques 2340
# max score among faithfull cliques of 28 forms: 107.386028755
# aboyer Nombre de cliques 3075
# max score among faithfull cliques of 26 forms: 103.724459131
# vendanger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# truster Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# rebrûler Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 271.362878943
# élargir Nombre de cliques 2225
# max score among faithfull cliques of 28 forms: 106.27176137
# recadrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# toaster Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# voiturer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# rouir Nombre de cliques 2380
# max score among faithfull cliques of 28 forms: 108.084954005
# étatiser Nombre de cliques 2529
# max score among faithfull cliques of 30 forms: 250.825991006
# intituler Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 271.362878943
# peindre Nombre de cliques 3640
# max score among faithfull cliques of 26 forms: 92.6276557505
# ragaillardir Nombre de cliques 2314
# max score among faithfull cliques of 28 forms: 104.070578742
# voyager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# palpiter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# encrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# cloquer Nombre de cliques 2205
# max score among faithfull cliques of 31 forms: 289.95823938
# bistrer Nombre de cliques 1900
# max score among faithfull cliques of 31 forms: 304.457730564
# bedonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 293.552918316
# négocier Nombre de cliques 2630
# max score among faithfull cliques of 27 forms: 90.2399997676
# dépasser Nombre de cliques 2395
# no new faithfull clique, the previous one contained 28 forms
# dérégler Nombre de cliques 2837
# max score among faithfull cliques of 28 forms: 198.365092877
# virguler Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 271.362878943
# rescinder Nombre de cliques 2234
# max score among faithfull cliques of 31 forms: 294.140885478
# chancir Nombre de cliques 2647
# max score among faithfull cliques of 28 forms: 104.174115974
# apurer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# tiédir Nombre de cliques 2687
# max score among faithfull cliques of 28 forms: 105.498515155
# contremander Nombre de cliques 1952
# max score among faithfull cliques of 31 forms: 284.207310932
# solidariser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# mordorer Nombre de cliques 2297
# max score among faithfull cliques of 31 forms: 287.853049707
# renouveler Nombre de cliques 4546
# max score among faithfull cliques of 29 forms: 170.687919915
# déconner Nombre de cliques 2151
# max score among faithfull cliques of 31 forms: 290.282535232
# fréquenter Nombre de cliques 1816
# max score among faithfull cliques of 31 forms: 292.548588106
# rabouter Nombre de cliques 2043
# max score among faithfull cliques of 31 forms: 299.787442442
# dialoguer Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# embaumer Nombre de cliques 2209
# max score among faithfull cliques of 31 forms: 287.938550662
# râler Nombre de cliques 2798
# max score among faithfull cliques of 28 forms: 221.952315248
# exorciser Nombre de cliques 2529
# max score among faithfull cliques of 30 forms: 250.825991006
# suriner Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# contribuer Nombre de cliques 2180
# max score among faithfull cliques of 29 forms: 215.017612902
# rustiquer Nombre de cliques 2091
# max score among faithfull cliques of 31 forms: 304.062781369
# coproduire Nombre de cliques 3161
# max score among faithfull cliques of 27 forms: 73.22622871
# présumer Nombre de cliques 1942
# max score among faithfull cliques of 31 forms: 301.178761288
# recoloniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# revisser Nombre de cliques 2346
# max score among faithfull cliques of 30 forms: 222.878233872
# détacher Nombre de cliques 2020
# no new faithfull clique, the previous one contained 29 forms
# trôner Nombre de cliques 3089
# max score among faithfull cliques of 26 forms: 137.055336487
# défléchir Nombre de cliques 2681
# max score among faithfull cliques of 28 forms: 105.78160011
# pister Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# éradiquer Nombre de cliques 2091
# max score among faithfull cliques of 31 forms: 304.062781369
# ballaster Nombre de cliques 1855
# max score among faithfull cliques of 31 forms: 302.393405516
# parlementer Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# trépider Nombre de cliques 2039
# max score among faithfull cliques of 31 forms: 282.615608162
# rebondir Nombre de cliques 2314
# max score among faithfull cliques of 28 forms: 105.181368688
# poser Nombre de cliques 3048
# no new faithfull clique, the previous one contained 30 forms
# dîner Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# styliser Nombre de cliques 2605
# no new faithfull clique, the previous one contained 29 forms
# fournir Nombre de cliques 2252
# max score among faithfull cliques of 28 forms: 107.417020152
# préfigurer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# briser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# chevaucher Nombre de cliques 2255
# max score among faithfull cliques of 31 forms: 289.186933116
# loucher Nombre de cliques 2216
# max score among faithfull cliques of 31 forms: 302.089647449
# filouter Nombre de cliques 2043
# max score among faithfull cliques of 31 forms: 299.787442442
# tictaquer Nombre de cliques 2235
# max score among faithfull cliques of 29 forms: 260.052559238
# fourrer Nombre de cliques 2063
# max score among faithfull cliques of 31 forms: 296.91022216
# proroger Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# soutirer Nombre de cliques 2195
# max score among faithfull cliques of 31 forms: 304.715845046
# détester Nombre de cliques 1789
# max score among faithfull cliques of 31 forms: 288.677064374
# tordre Nombre de cliques 2394
# max score among faithfull cliques of 26 forms: 74.3977925728
# léguer Nombre de cliques 2533
# max score among faithfull cliques of 30 forms: 251.548338294
# rescolariser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# descendre Nombre de cliques 2551
# max score among faithfull cliques of 30 forms: 99.2717643729
# coller Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# retravailler Nombre de cliques 2583
# no new faithfull clique, the previous one contained 26 forms
# délivrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# patauger Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# moraliser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# morfler Nombre de cliques 2519
# max score among faithfull cliques of 30 forms: 281.239743965
# rapprovisionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# encocher Nombre de cliques 2255
# max score among faithfull cliques of 31 forms: 289.186933116
# automatiser Nombre de cliques 2529
# max score among faithfull cliques of 30 forms: 250.825991006
# disqualifier Nombre de cliques 2461
# max score among faithfull cliques of 28 forms: 100.98231058
# iodler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# démunir Nombre de cliques 2237
# max score among faithfull cliques of 28 forms: 102.237806955
# béatifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# pilonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# mutiler Nombre de cliques 2806
# max score among faithfull cliques of 30 forms: 271.636290025
# brasiller Nombre de cliques 2687
# max score among faithfull cliques of 26 forms: 115.430413332
# reconduire Nombre de cliques 3152
# max score among faithfull cliques of 27 forms: 73.22622871
# ensiler Nombre de cliques 2806
# max score among faithfull cliques of 30 forms: 271.636290025
# récuser Nombre de cliques 2811
# no new faithfull clique, the previous one contained 29 forms
# câbler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# spolier Nombre de cliques 3190
# max score among faithfull cliques of 27 forms: 107.507392263
# roupiller Nombre de cliques 2619
# max score among faithfull cliques of 26 forms: 115.430413332
# affûter Nombre de cliques 1880
# max score among faithfull cliques of 31 forms: 302.393405516
# japoniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# éparpiller Nombre de cliques 2617
# max score among faithfull cliques of 26 forms: 115.430413332
# modéliser Nombre de cliques 2602
# no new faithfull clique, the previous one contained 29 forms
# improuver Nombre de cliques 3387
# max score among faithfull cliques of 29 forms: 220.285179596
# smasher Nombre de cliques 1999
# max score among faithfull cliques of 31 forms: 301.342803254
# escarmoucher Nombre de cliques 2216
# max score among faithfull cliques of 31 forms: 302.089647449
# décroûter Nombre de cliques 1991
# max score among faithfull cliques of 31 forms: 290.448481539
# conjuguer Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# angéliser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# creuser Nombre de cliques 5202
# max score among faithfull cliques of 26 forms: 168.077584127
# centrifuger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# démasquer Nombre de cliques 1906
# max score among faithfull cliques of 31 forms: 303.791138772
# rasseoir Nombre de cliques 3530
# max score among faithfull cliques of 17 forms: 22.0348212451
# quintupler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# tarder Nombre de cliques 1982
# max score among faithfull cliques of 31 forms: 284.207310932
# dealer Nombre de cliques 2806
# max score among faithfull cliques of 30 forms: 271.636290025
# somatiser Nombre de cliques 2529
# max score among faithfull cliques of 30 forms: 250.825991006
# suinter Nombre de cliques 1826
# max score among faithfull cliques of 31 forms: 291.835722457
# coéditer Nombre de cliques 2045
# max score among faithfull cliques of 31 forms: 302.665048113
# protester Nombre de cliques 1885
# max score among faithfull cliques of 31 forms: 304.603565048
# aiguer Nombre de cliques 2527
# max score among faithfull cliques of 30 forms: 248.770352354
# baiser Nombre de cliques 2966
# no new faithfull clique, the previous one contained 28 forms
# déphaser Nombre de cliques 2905
# no new faithfull clique, the previous one contained 29 forms
# épaissir Nombre de cliques 2768
# max score among faithfull cliques of 28 forms: 105.332473504
# siéger Nombre de cliques 2519
# max score among faithfull cliques of 30 forms: 249.357416798
# retraire Nombre de cliques 2303
# max score among faithfull cliques of 21 forms: 53.5254694827
# différer Nombre de cliques 2959
# max score among faithfull cliques of 30 forms: 246.940075579
# transporter Nombre de cliques 1805
# max score among faithfull cliques of 31 forms: 293.041907862
# mirer Nombre de cliques 2195
# max score among faithfull cliques of 31 forms: 304.715845046
# paralléliser Nombre de cliques 2602
# no new faithfull clique, the previous one contained 29 forms
# remparer Nombre de cliques 2034
# max score among faithfull cliques of 29 forms: 260.690374194
# gourer Nombre de cliques 2001
# max score among faithfull cliques of 31 forms: 291.372012874
# psalmodier Nombre de cliques 2450
# max score among faithfull cliques of 28 forms: 97.6092186429
# malmener Nombre de cliques 3471
# max score among faithfull cliques of 27 forms: 94.4575405503
# sniffer Nombre de cliques 2160
# max score among faithfull cliques of 31 forms: 304.281140426
# frire Nombre de cliques 2268
# max score among faithfull cliques of 28 forms: 105.809559473
# cravater Nombre de cliques 1906
# max score among faithfull cliques of 29 forms: 258.691356751
# doter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 291.487577114
# retéléphoner Nombre de cliques 2151
# max score among faithfull cliques of 31 forms: 290.282535232
# morguer Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# transcoder Nombre de cliques 2484
# max score among faithfull cliques of 31 forms: 279.437536039
# polluer Nombre de cliques 2289
# max score among faithfull cliques of 29 forms: 218.035742393
# baller Nombre de cliques 2798
# max score among faithfull cliques of 28 forms: 221.952315248
# perquisitionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# claver Nombre de cliques 2859
# no new faithfull clique, the previous one contained 26 forms
# calomnier Nombre de cliques 2238
# max score among faithfull cliques of 28 forms: 105.577577956
# truquer Nombre de cliques 1906
# max score among faithfull cliques of 31 forms: 303.791138772
# caviarder Nombre de cliques 1982
# max score among faithfull cliques of 31 forms: 284.207310932
# jardiner Nombre de cliques 2029
# max score among faithfull cliques of 31 forms: 304.014479339
# fatiguer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# chalouper Nombre de cliques 2071
# max score among faithfull cliques of 31 forms: 297.639015503
# élucubrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# avoyer Nombre de cliques 3071
# max score among faithfull cliques of 26 forms: 103.417886385
# bluffer Nombre de cliques 4359
# max score among faithfull cliques of 26 forms: 171.27864061
# emmerder Nombre de cliques 1977
# max score among faithfull cliques of 31 forms: 295.378169421
# enluminer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# échauffer Nombre de cliques 2252
# max score among faithfull cliques of 31 forms: 289.382056399
# zozoter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# distraire Nombre de cliques 2335
# max score among faithfull cliques of 21 forms: 53.261288063
# rasséréner Nombre de cliques 2557
# no new faithfull clique, the previous one contained 28 forms
# thermoformer Nombre de cliques 1882
# max score among faithfull cliques of 31 forms: 300.753569757
# chapeauter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# fricoter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# surpayer Nombre de cliques 3117
# max score among faithfull cliques of 27 forms: 102.875974131
# prévoir Nombre de cliques 4199
# max score among faithfull cliques of 23 forms: 59.2642294079
# soupçonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# idiotiser Nombre de cliques 2569
# no new faithfull clique, the previous one contained 27 forms
# besogner Nombre de cliques 2128
# max score among faithfull cliques of 31 forms: 291.696433405
# phosphater Nombre de cliques 1896
# max score among faithfull cliques of 29 forms: 258.691356751
# cimenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# nieller Nombre de cliques 2614
# max score among faithfull cliques of 30 forms: 244.548652083
# axer Nombre de cliques 2398
# max score among faithfull cliques of 30 forms: 224.761915212
# rocher Nombre de cliques 2255
# max score among faithfull cliques of 31 forms: 289.186933116
# tabuler Nombre de cliques 2537
# max score among faithfull cliques of 30 forms: 271.362878943
# syndiquer Nombre de cliques 2091
# max score among faithfull cliques of 31 forms: 304.062781369
# calandrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# volter Nombre de cliques 1761
# max score among faithfull cliques of 31 forms: 296.694710139
# ahurir Nombre de cliques 2328
# max score among faithfull cliques of 28 forms: 104.161205122
# décolleter Nombre de cliques 3500
# max score among faithfull cliques of 29 forms: 179.469027014
# moirer Nombre de cliques 2162
# max score among faithfull cliques of 29 forms: 257.922208459
# affoler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# renoncer Nombre de cliques 2454
# max score among faithfull cliques of 30 forms: 229.724815524
# flûter Nombre de cliques 1880
# max score among faithfull cliques of 31 forms: 302.393405516
# imiter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# fayoter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# fomenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# dérougir Nombre de cliques 2277
# max score among faithfull cliques of 28 forms: 106.222286217
# désaffectionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# poursuivre Nombre de cliques 2975
# max score among faithfull cliques of 28 forms: 94.5250413902
# vitrifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# impacter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# jongler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# serpenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# réconcilier Nombre de cliques 3090
# max score among faithfull cliques of 27 forms: 97.24499158
# tiser Nombre de cliques 2569
# no new faithfull clique, the previous one contained 27 forms
# gifler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# inverser Nombre de cliques 2484
# max score among faithfull cliques of 30 forms: 229.336750492
# empreindre Nombre de cliques 3640
# max score among faithfull cliques of 26 forms: 98.8480655639
# interloquer Nombre de cliques 2205
# max score among faithfull cliques of 31 forms: 289.95823938
# endetter Nombre de cliques 2741
# no new faithfull clique, the previous one contained 29 forms
# prodiguer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# opposer Nombre de cliques 3048
# no new faithfull clique, the previous one contained 29 forms
# défoncer Nombre de cliques 2456
# max score among faithfull cliques of 30 forms: 229.267615883
# éperdre Nombre de cliques 2387
# max score among faithfull cliques of 29 forms: 95.5569449833
# limoger Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# feutrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# consoler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# scratcher Nombre de cliques 1991
# max score among faithfull cliques of 31 forms: 288.330718553
# flaquer Nombre de cliques 2235
# max score among faithfull cliques of 29 forms: 260.052559238
# soutenir Nombre de cliques 4279
# max score among faithfull cliques of 31 forms: 209.702699553
# ambrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# réalimenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# sanctifier Nombre de cliques 2522
# max score among faithfull cliques of 28 forms: 103.425605038
# inciter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# déchiqueter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# grognonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# nettoyer Nombre de cliques 3107
# ...
# africaniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# englober Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# escarper Nombre de cliques 1845
# max score among faithfull cliques of 31 forms: 291.451142616
# sigler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# permanenter Nombre de cliques 1812
# max score among faithfull cliques of 31 forms: 293.041907862
# enclore Nombre de cliques 2098
# max score among faithfull cliques of 10 forms: 17.9392784254
# oraliser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# infléchir Nombre de cliques 2681
# max score among faithfull cliques of 28 forms: 105.78160011
# assécher Nombre de cliques 2684
# max score among faithfull cliques of 30 forms: 252.252246193
# propager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# veiller Nombre de cliques 3506
# max score among faithfull cliques of 26 forms: 87.5293058188
# caracoler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# parachever Nombre de cliques 4237
# no new faithfull clique, the previous one contained 27 forms
# élaguer Nombre de cliques 1913
# max score among faithfull cliques of 29 forms: 260.370605229
# chuter Nombre de cliques 1880
# max score among faithfull cliques of 31 forms: 302.393405516
# départir Nombre de cliques 1823
# max score among faithfull cliques of 30 forms: 79.5680969748
# tressaillir Nombre de cliques 2385
# max score among faithfull cliques of 22 forms: 55.2718272952
# juger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# connoter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# désapprendre Nombre de cliques 3332
# max score among faithfull cliques of 31 forms: 87.1967398834
# voltiger Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# dynamiser Nombre de cliques 2622
# no new faithfull clique, the previous one contained 29 forms
# délabrer Nombre de cliques 2167
# max score among faithfull cliques of 28 forms: 200.204808669
# pomponner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# désexualiser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# prélaver Nombre de cliques 2874
# no new faithfull clique, the previous one contained 26 forms
# raisonner Nombre de cliques 2151
# max score among faithfull cliques of 31 forms: 290.282535232
# insurger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# graveler Nombre de cliques 4546
# max score among faithfull cliques of 29 forms: 170.687919915
# réengager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# spammer Nombre de cliques 1916
# max score among faithfull cliques of 29 forms: 257.336356726
# louper Nombre de cliques 2071
# max score among faithfull cliques of 31 forms: 297.639015503
# corser Nombre de cliques 2504
# max score among faithfull cliques of 30 forms: 229.79251755
# anodiser Nombre de cliques 2521
# max score among faithfull cliques of 30 forms: 253.244006698
# thésauriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# rebaisser Nombre de cliques 2542
# no new faithfull clique, the previous one contained 27 forms
# friponner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# obscurcir Nombre de cliques 2647
# max score among faithfull cliques of 28 forms: 106.148470527
# lorgner Nombre de cliques 1759
# max score among faithfull cliques of 28 forms: 222.973373329
# claironner Nombre de cliques 2151
# max score among faithfull cliques of 31 forms: 290.282535232
# pédaler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 221.472943249
# terroriser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# désengourdir Nombre de cliques 2341
# max score among faithfull cliques of 28 forms: 106.535126249
# accabler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# insupporter Nombre de cliques 1805
# max score among faithfull cliques of 31 forms: 293.041907862
# ennoblir Nombre de cliques 2858
# max score among faithfull cliques of 28 forms: 106.27176137
# goûter Nombre de cliques 1991
# max score among faithfull cliques of 31 forms: 290.448481539
# pitonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# départager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# préconcevoir Nombre de cliques 4344
# max score among faithfull cliques of 30 forms: 125.613134021
# désaliniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# repiquer Nombre de cliques 2091
# max score among faithfull cliques of 31 forms: 304.062781369
# froisser Nombre de cliques 2452
# no new faithfull clique, the previous one contained 28 forms
# subvenir Nombre de cliques 4336
# max score among faithfull cliques of 31 forms: 209.235878114
# merdoyer Nombre de cliques 3392
# no new faithfull clique, the previous one contained 25 forms
# resituer Nombre de cliques 2221
# max score among faithfull cliques of 29 forms: 217.588572414
# inhumer Nombre de cliques 1940
# max score among faithfull cliques of 31 forms: 301.67202872
# rogner Nombre de cliques 2128
# max score among faithfull cliques of 31 forms: 291.696433405
# préparer Nombre de cliques 2036
# max score among faithfull cliques of 29 forms: 260.211115382
# modérer Nombre de cliques 2957
# max score among faithfull cliques of 30 forms: 246.940075579
# sauter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# resurgir Nombre de cliques 2252
# max score among faithfull cliques of 28 forms: 107.417020152
# ratonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# dévaluer Nombre de cliques 2273
# max score among faithfull cliques of 29 forms: 218.035742393
# brumer Nombre de cliques 1940
# max score among faithfull cliques of 31 forms: 301.67202872
# gruger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# décapoter Nombre de cliques 2127
# max score among faithfull cliques of 31 forms: 288.645032253
# émacier Nombre de cliques 2650
# max score among faithfull cliques of 27 forms: 93.0188099007
# ébaucher Nombre de cliques 2257
# max score among faithfull cliques of 31 forms: 288.730569363
# remonter Nombre de cliques 1803
# max score among faithfull cliques of 31 forms: 293.041907862
# bander Nombre de cliques 2004
# max score among faithfull cliques of 31 forms: 284.895448915
# réhabiliter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# catéchiser Nombre de cliques 2613
# no new faithfull clique, the previous one contained 29 forms
# gargouiller Nombre de cliques 2949
# max score among faithfull cliques of 25 forms: 126.616805489
# parapher Nombre de cliques 1998
# max score among faithfull cliques of 29 forms: 260.486312433
# appauvrir Nombre de cliques 2160
# max score among faithfull cliques of 28 forms: 113.445003804
# crier Nombre de cliques 1972
# max score among faithfull cliques of 26 forms: 64.5891200294
# ragoûter Nombre de cliques 2043
# max score among faithfull cliques of 31 forms: 299.787442442
# riveter Nombre de cliques 3443
# max score among faithfull cliques of 29 forms: 176.199255159
# rouvrir Nombre de cliques 1857
# max score among faithfull cliques of 27 forms: 75.201626411
# amalgamer Nombre de cliques 1968
# max score among faithfull cliques of 29 forms: 257.987644262
# contredire Nombre de cliques 3195
# max score among faithfull cliques of 26 forms: 67.185257465
# trouilloter Nombre de cliques 1840
# no new faithfull clique, the previous one contained 20 forms
# camer Nombre de cliques 1968
# max score among faithfull cliques of 29 forms: 257.987644262
# chorégraphier Nombre de cliques 2313
# max score among faithfull cliques of 28 forms: 101.871956461
# recenser Nombre de cliques 2516
# max score among faithfull cliques of 30 forms: 229.79251755
# prosodier Nombre de cliques 2275
# max score among faithfull cliques of 28 forms: 104.071177363
# caillasser Nombre de cliques 2423
# no new faithfull clique, the previous one contained 28 forms
# ravager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# râper Nombre de cliques 1928
# max score among faithfull cliques of 29 forms: 257.01775335
# fagoter Nombre de cliques 3137
# max score among faithfull cliques of 26 forms: 129.402239851
# représenter Nombre de cliques 1816
# max score among faithfull cliques of 31 forms: 292.548588106
# électrolyser Nombre de cliques 2610
# no new faithfull clique, the previous one contained 29 forms
# accentuer Nombre de cliques 2215
# max score among faithfull cliques of 29 forms: 217.588572414
# déterrer Nombre de cliques 2959
# max score among faithfull cliques of 30 forms: 246.494463218
# boumer Nombre de cliques 2032
# max score among faithfull cliques of 31 forms: 299.157536074
# crouler Nombre de cliques 2827
# no new faithfull clique, the previous one contained 28 forms
# espacer Nombre de cliques 2384
# no new faithfull clique, the previous one contained 28 forms
# indemniser Nombre de cliques 2616
# no new faithfull clique, the previous one contained 29 forms
# quémander Nombre de cliques 1954
# max score among faithfull cliques of 31 forms: 283.714314452
# joncher Nombre de cliques 2086
# max score among faithfull cliques of 31 forms: 303.542021207
# miauler Nombre de cliques 3266
# max score among faithfull cliques of 30 forms: 256.745963717
# miner Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 291.773359227
# piétiner Nombre de cliques 2031
# max score among faithfull cliques of 31 forms: 303.51227895
# ratiboiser Nombre de cliques 2917
# max score among faithfull cliques of 28 forms: 229.208608414
# remplier Nombre de cliques 1562
# max score among faithfull cliques of 10 forms: 16.3101460953
# décompresser Nombre de cliques 2908
# no new faithfull clique, the previous one contained 29 forms
# bouturer Nombre de cliques 1986
# max score among faithfull cliques of 31 forms: 304.444202448
# investir Nombre de cliques 2284
# max score among faithfull cliques of 28 forms: 102.363519174
# trachéotomiser Nombre de cliques 2622
# no new faithfull clique, the previous one contained 29 forms
# analyser Nombre de cliques 2612
# no new faithfull clique, the previous one contained 29 forms
# agrainer Nombre de cliques 3082
# no new faithfull clique, the previous one contained 28 forms
# vaquer Nombre de cliques 2237
# max score among faithfull cliques of 29 forms: 260.052559238
# cyanoser Nombre de cliques 2803
# no new faithfull clique, the previous one contained 19 forms
# linger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# pieuter Nombre de cliques 3087
# max score among faithfull cliques of 26 forms: 156.311567104
# ébahir Nombre de cliques 2351
# max score among faithfull cliques of 28 forms: 104.137677845
# urger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# rencaisser Nombre de cliques 2623
# no new faithfull clique, the previous one contained 28 forms
# dérouiller Nombre de cliques 2990
# max score among faithfull cliques of 25 forms: 126.795954062
# sursignifier Nombre de cliques 2461
# max score among faithfull cliques of 28 forms: 100.98231058
# ressurgir Nombre de cliques 2252
# max score among faithfull cliques of 28 forms: 107.417020152
# halener Nombre de cliques 2557
# no new faithfull clique, the previous one contained 29 forms
# numériser Nombre de cliques 2633
# no new faithfull clique, the previous one contained 29 forms
# ingénier Nombre de cliques 2636
# no new faithfull clique, the previous one contained 23 forms
# délustrer Nombre de cliques 1900
# max score among faithfull cliques of 31 forms: 304.457730564
# approuver Nombre de cliques 3387
# max score among faithfull cliques of 29 forms: 220.285179596
# défroquer Nombre de cliques 2205
# max score among faithfull cliques of 31 forms: 289.95823938
# chuchoter Nombre de cliques 2075
# max score among faithfull cliques of 31 forms: 278.403161735
# missionner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# volatiliser Nombre de cliques 2605
# no new faithfull clique, the previous one contained 29 forms
# frauder Nombre de cliques 3451
# max score among faithfull cliques of 26 forms: 126.562781423
# déminer Nombre de cliques 2083
# max score among faithfull cliques of 31 forms: 304.385073045
# recontacter Nombre de cliques 1759
# max score among faithfull cliques of 31 forms: 289.127421866
# reboucler Nombre de cliques 2800
# max score among faithfull cliques of 28 forms: 198.809229659
# fourgonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# mailer Nombre de cliques 2575
# max score among faithfull cliques of 30 forms: 270.910697223
# refouler Nombre de cliques 2827
# no new faithfull clique, the previous one contained 28 forms
# déconseiller Nombre de cliques 3444
# max score among faithfull cliques of 27 forms: 101.007144726
# répercuter Nombre de cliques 1880
# max score among faithfull cliques of 31 forms: 302.393405516
# précéder Nombre de cliques 2606
# max score among faithfull cliques of 30 forms: 242.776712931
# fourrager Nombre de cliques 1911
# max score among faithfull cliques of 29 forms: 260.849864041
# marier Nombre de cliques 2386
# max score among faithfull cliques of 28 forms: 101.577481629
# faillir Nombre de cliques 2125
# max score among faithfull cliques of 21 forms: 50.4654261299
# interchanger Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# chigner Nombre de cliques 2037
# max score among faithfull cliques of 31 forms: 305.84407918
# épointer Nombre de cliques 1913
# max score among faithfull cliques of 31 forms: 303.274639289
# repentir Nombre de cliques 1945
# max score among faithfull cliques of 26 forms: 60.8851434826
# autolimiter Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# jumeler Nombre de cliques 4546
# max score among faithfull cliques of 29 forms: 170.687919915
# dédicacer Nombre de cliques 2470
# no new faithfull clique, the previous one contained 29 forms
# poudroyer Nombre de cliques 3452
# no new faithfull clique, the previous one contained 25 forms
# paginer Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# plaquer Nombre de cliques 2235
# max score among faithfull cliques of 29 forms: 260.052559238
# réépouser Nombre de cliques 2969
# no new faithfull clique, the previous one contained 29 forms
# démilitariser Nombre de cliques 2618
# no new faithfull clique, the previous one contained 29 forms
# démarier Nombre de cliques 2387
# max score among faithfull cliques of 28 forms: 102.950082045
# importuner Nombre de cliques 1881
# max score among faithfull cliques of 31 forms: 304.610483968
# pérorer Nombre de cliques 2305
# max score among faithfull cliques of 31 forms: 290.131710088
# conspirer Nombre de cliques 2195
# max score among faithfull cliques of 31 forms: 304.715845046
# atterrir Nombre de cliques 3058
# max score among faithfull cliques of 28 forms: 104.59866163
# raidir Nombre de cliques 2691
# max score among faithfull cliques of 28 forms: 105.498515155
# aviser Nombre de cliques 2533
# max score among faithfull cliques of 30 forms: 251.605736919
# tranquilliser Nombre de cliques 2605
# no new faithfull clique, the previous one contained 29 forms
# décrire Nombre de cliques 3118
# max score among faithfull cliques of 26 forms: 61.9644492703
# branlocher Nombre de cliques 2255
# max score among faithfull cliques of 31 forms: 289.186933116
# militer Nombre de cliques 2059
# max score among faithfull cliques of 31 forms: 302.665048113
# piger Nombre de cliques 2081
# max score among faithfull cliques of 31 forms: 304.882126565
# évanouir Nombre de cliques 2447
# max score among faithfull cliques of 28 forms: 107.796245849
# tonner Nombre de cliques 2149
# max score among faithfull cliques of 31 forms: 290.737087798
# CPU times: user 3h 47min 19s, sys: 1min 55s, total: 3h 49min 15s
# Wall time: 3h 48min 44s

# %%
newParadigmes,paradigmesSwim2,characteristicsSwim2,measuresSwim2=calculerResultats(swim2ContextParadigmes,"-Swim2")
# Out:
# Index([u'value', u'lexeme-case'], dtype='object')
# UG 42401 OG 43849 TP 164638 FP 24437
# recall 0.711253002471 precision 0.706831412821
# 0.709035314384

# %%
nomFichierResultats=filePrefix+"-X-Resultats.yaml"
if os.path.isfile(nomFichierResultats):
    with open(nomFichierResultats, 'r') as stream:
            resultats=yaml.load(stream)
else:
    resultats={}

if casesType:
    sampleExt=casesType
else:
    sampleExt=sampleType
sampleId=sampleNumber.strip("-")+sampleExt
resultats[sampleId]={}
resultats[sampleId]["Swim1"]={}
resultats[sampleId]["Swim1"]["UG"]=characteristicsSwim1[0]
resultats[sampleId]["Swim1"]["OG"]=characteristicsSwim1[1]
resultats[sampleId]["Swim1"]["TP"]=characteristicsSwim1[2]
resultats[sampleId]["Swim1"]["FP"]=characteristicsSwim1[3]
resultats[sampleId]["Swim1"]["Precision"]=measuresSwim1[0]
resultats[sampleId]["Swim1"]["Recall"]=measuresSwim1[1]
resultats[sampleId]["Swim1"]["F-Measure"]=measuresSwim1[2]
resultats[sampleId]["Swim2"]={}
resultats[sampleId]["Swim2"]["UG"]=characteristicsSwim2[0]
resultats[sampleId]["Swim2"]["OG"]=characteristicsSwim2[1]
resultats[sampleId]["Swim2"]["TP"]=characteristicsSwim2[2]
resultats[sampleId]["Swim2"]["FP"]=characteristicsSwim2[3]
resultats[sampleId]["Swim2"]["Precision"]=measuresSwim2[0]
resultats[sampleId]["Swim2"]["Recall"]=measuresSwim2[1]
resultats[sampleId]["Swim2"]["F-Measure"]=measuresSwim2[2]

yaml.safe_dump(resultats, file(nomFichierResultats, 'w'), encoding='utf-8', allow_unicode=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-86ec22b4798d> in <module>()
# ----> 1 nomFichierResultats=filePrefix+"-X-Resultats.yaml"
#       2 if os.path.isfile(nomFichierResultats):
#       3     with open(nomFichierResultats, 'r') as stream:
#       4             resultats=yaml.load(stream)
#       5 else:
#
# NameError: name 'filePrefix' is not defined

# %%
# %ding
# %ding

# %%
print ("Sample",sampleNumber.strip("-"))
print ("Swim1",characteristicsSwim1,measuresSwim1)
print ("Swim2",characteristicsSwim2,measuresSwim2)

# %% [markdown]
# # Fin du traitement

# %%
paradigmesSwim2.columns.tolist()[25:]

# %%
paradigmesSwim2.pc1S

# %% [markdown]
# # Calcul des distances

# %% [markdown]
# ### Préparation des fichiers de référence
# La comparaison se fait sur les lexèmes de *listeTest*
# - initialForms : les formes initiales
# - finalForms : les formes initiales plus les formes prédites
# - goldForms : les formes de référence

# %% [markdown]
# #### Formes initiales

# %% [raw]
# initialForms=pd.melt(paradigmesSample[paradigmesSample["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# initialForms["lexeme-case"]=initialForms["lexeme"]+"-"+initialForms["variable"]
# initialForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
#
# initialForms.set_index(["lexeme-case"],inplace=True)
#
# initialFormsIndex=initialForms.index.tolist()

# %% [markdown]
# #### Formes avec prédictions

# %% [raw]
# finalParadigmes=extendParadigmes(contextParadigmes,extendMorphomes=True)
# finalParadigmes.to_csv(path_or_buf=analysisPrefix+"-paradigmes-Swim2.csv",encoding="utf8",sep=";")
# finalTestForms=pd.melt(finalParadigmes[finalParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
# finalTestForms["lexeme-case"]=finalTestForms["lexeme"]+"-"+finalTestForms["variable"]
# finalTestForms.drop(labels=["lexeme","variable"],axis=1,inplace=True)
# finalTestForms.set_index(["lexeme-case"],inplace=True)

# %% [markdown]
# #### Formes de référence
# - recoder les représentations phonologiques en fonction de l'échantillon

# %% [raw]
# with open(goldPrefix+"/"+goldFile,"rb") as input:
#     lexiqueGold=pickle.load(input)
#
# lexiqueGold["phono"]=lexiqueGold["phono"].apply(lambda x: checkFrench(x))
#
# completeParadigmes=pd.pivot_table(lexiqueGold, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()
#
# goldTestForms=pd.melt(completeParadigmes[completeParadigmes["lexeme"].isin(listeTest)],id_vars=["lexeme"]).dropna()
#
# #goldTestForms
#
# goldTestForms["lexeme-case"]=goldTestForms["lexeme"]+"-"+goldTestForms["case"]
# goldTestForms.drop(labels=["lexeme","case"],axis=1,inplace=True)
#
# goldTestForms.set_index(["lexeme-case"],inplace=True)

# %% [raw]
# #goldFormsIndex=goldForms.index.tolist()

# %% [markdown]
# ### Soustraction des formes initiales

# %% [raw]
# finalForms=finalTestForms.loc[~finalTestForms.index.isin(initialFormsIndex)]
# finalFormsIndex=finalForms.index.tolist()
# #initialForms.loc[~initialForms.index.isin(finalFormsIndex)]

# %% [raw]
# #finalForms[finalForms.index.str.contains("asseoir")]

# %% [raw]
# #goldTestForms[goldTestForms.index.str.contains("asseoir")]

# %% [raw]
# goldForms=goldTestForms.loc[~goldTestForms.index.isin(initialFormsIndex)]
# goldFormsIndex=goldForms.index.tolist()

# %% [raw]
# #goldForms[goldForms.index.str.contains("asseoir")]

# %% [raw]
# print (finalFormsIndex)
# goldForms[~goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# ### Évaluation des formes

# %% [markdown]
# #### Problèmes de génération
# - sous-génération : formes de références sans prédiction
# - sur-génération : formes prédites absentes de la référence

# %% [raw]
# underGeneration=goldForms.loc[~goldForms.index.isin(finalFormsIndex)]
# overGeneration=finalForms.loc[~finalForms.index.isin(goldFormsIndex)]

# %% [markdown]
# #### Formes comparables
# - *predictedForms* => formes prédites présentes dans la référence
# - *actualForms* => formes de référence présentes dans les prédictions

# %% [raw]
# predictedForms=finalForms.loc[finalForms.index.isin(goldFormsIndex)]
# actualForms=goldForms.loc[goldForms.index.isin(finalFormsIndex)]

# %% [markdown]
# #### Préparation de la comparaison
# - *compareForms* => tableau avec les formes à comparer

# %% [raw]
# compareForms=predictedForms.copy()
# compareForms.loc[:,"right"]=actualForms.loc[:,"value"]

# %% [markdown]
# #### Comparaison des formes
# - *sameForms* => formes identiques dans les prédictions et la référence
# - *diffForms* => formes différentes dans les prédictions et la référence

# %% [raw]
# sameForms=compareForms[compareForms["value"]==compareForms["right"]]
# diffForms=compareForms[compareForms["value"]!=compareForms["right"]]

# %% [markdown]
# #### Décompte du nombre de formes
# À cause du traitement de la surabondance, le décompte des lignes ne tient pas compte du nombre de formes. Il faut compter les formes dans chaque ligne pour obtenir le nombre total.

# %% [raw]
# def countSplits(dfForms):
#     dfForms.loc[:,"split"]=dfForms.loc[:,"value"].str.split(",")
#     return dfForms["split"].str.len().sum()

# %% [markdown]
# #### Évaluation des différences
# Certaines différences ne sont qu'apparentes à cause du traitement de la surabondance sous forme de chaine concaténée. Il faut transformer les surabondances en set() pour pouvoir faire une comparaison pertinente.

# %% [raw]
# def evaluateDiffForms(diffForms):
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"value"].str.split(",")
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"right"].str.split(",")
#
#     diffForms.loc[:,"split-value"]=diffForms.loc[:,"split-value"].apply(set)
#     diffForms.loc[:,"split-right"]=diffForms.loc[:,"split-right"].apply(set)
#
#     nbValues=diffForms["split-value"].str.len().sum()
#     nbRights=diffForms["split-right"].str.len().sum()
# #    print (nbValues,nbRights)
#
#     nbIdenticalSets=diffForms[diffForms["split-value"]==diffForms["split-right"]]["split-value"].str.len().sum()
#     nbIncludedSets=diffForms[diffForms["split-value"]<diffForms["split-right"]]["split-value"].str.len().sum()
#
#     return (nbIdenticalSets,nbIncludedSets,(nbValues-nbIdenticalSets-nbIncludedSets),(nbRights-nbIdenticalSets-nbIncludedSets))

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus=evaluateDiffForms(diffForms)
# #evaluateDiffForms(diffForms)

# %% [markdown]
# #### Calcul des grandeurs de mesure

# %% [raw]
# UG=countSplits(underGeneration)+underBonus
# OG=countSplits(overGeneration)
# TP=countSplits(sameForms)+identicalBonus+partialBonus
# FP=wrongBonus
# recall=float(TP)/(UG+TP+FP)
# precision=float(TP)/(OG+TP+FP)
# print ("UG",UG ,"OG",OG,"TP",TP,"FP",FP)
# print ("recall", recall, "precision", precision)
#
# fMeasure=2*recall*precision/(recall+precision)
# fMeasure

# %% [raw]
# identicalBonus,partialBonus,wrongBonus,underBonus

# %% [raw]
# countSplits(underGeneration),countSplits(overGeneration),countSplits(sameForms)

# %% [markdown]
# ### Sauvegarde des résultats pour analyse ultérieure

# %% [raw]
# overGeneration.to_csv(path_or_buf=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration.to_csv(path_or_buf=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# sameForms.to_csv(path_or_buf=analysisPrefix+"-sameForms.csv",encoding="utf8")
# diffForms.to_csv(path_or_buf=analysisPrefix+"-diffForms.csv",encoding="utf8")

# %% [markdown]
# ## Analyse des sur-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# overGeneration.loc[:,"case"]=overGeneration.index.str.rsplit("-").str[-1]

# %% [raw]
# casesOverGeneration=overGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# casesOverGeneration.plot(kind="bar",figsize=(20,5))

# %% [raw]
# casesOverGeneration[:3].sum()/casesOverGeneration.sum()

# %% [markdown]
# Le facteur principal de **surgénération** est la production de **participes passés** (ppMP 662, ppFS 661, ppFP 661) pour les verbes qui n'ont qu'une seule forme de participe passé invariable (ppMS) : **54.78%** (1984/3622).

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# overGeneration.loc[:,"verbe"]=overGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesOverGeneration=overGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
# verbesOverGeneration[:54].plot(kind="bar",figsize=(20,5))

# %% [markdown]
# Le facteur principal de **surgénération** tient aux **verbes vestiges** et aux **météorologiques**.

# %% [markdown]
# ## Analyse des sous-générations

# %% [markdown]
# ### Analyse par cases

# %% [raw]
# underGeneration.loc[:,"case"]=underGeneration.index.str.rsplit("-",1).str[-1]

# %% [raw]
# casesUnderGeneration=underGeneration.groupby(by="case").count()[["value"]].sort_values("value",ascending=False)
# ax=casesUnderGeneration[:9].plot(kind="bar",figsize=(20,5))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Verbs missing the form",fontsize=16)
# print ("Total sous-générations :",casesUnderGeneration.sum().values[0])

# %% [raw]
# def ratioAnalyses(df,chaine):
#     return df[df.index.str.contains(chaine)].sum().values[0],df.sum().values[0],(df[df.index.str.contains(chaine)].sum()/df.sum()).values[0]

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"is")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"ai")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"2P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"1P")

# %% [raw]
# ratioAnalyses(casesUnderGeneration,"pi")

# %% [markdown]
# Le facteur principal de **sous-génération** est lié à la fréquence des TAM et de certaines personnes :
# - TAM :
#  - imparfait du subjonctif 45.98% (7875/17126)
#  - passé simple 12.70% (2176/17126)
# - Personnes :
#  - 2PL 46.11% (7897/17126)
#  - 1PL 32.98% (5649/17126)

# %% [markdown]
# ### Analyse par verbes

# %% [raw]
# underGeneration.loc[:,"verbe"]=underGeneration.index.str.rsplit("-",1).str[0]

# %% [raw]
# verbesUnderGeneration=underGeneration.groupby(by="verbe").count()[["value"]].sort_values("value",ascending=False)
#
# ax=verbesUnderGeneration[:50].plot(kind="bar",figsize=(40,5))
# ax.set_xlabel("Verbes",fontsize=16)
# ax.set_ylabel("Number of Missing Forms",fontsize=16)

# %% [markdown]
# # Fin de l'analyse des résultats

# %% [raw]
# overGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-overGeneration.csv",encoding="utf8")
# underGeneration=pd.read_csv(filepath_or_buffer=analysisPrefix+"-underGeneration.csv",encoding="utf8")
# goodForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-goodForms.csv",encoding="utf8")
# wrongForms=pd.read_csv(filepath_or_buffer=analysisPrefix+"-wrongForms.csv",encoding="utf8")

# %% [raw]
# len(overGeneration), len(underGeneration), len(goodForms), len(wrongForms)

# %% [raw]
# wrongForms["rightChecked"]=wrongForms["right"].apply(checkFrench)
# wrongForms["valueChecked"]=wrongForms["value"].apply(checkFrench)

# %% [raw]
# wrongForms[wrongForms["valueChecked"]!=wrongForms["rightChecked"]]

# %% [raw]
# goodForms[goodForms["value"].str.contains(",")]

# %% [raw]
# set(overGeneration["lexeme-case"].str.rsplit("-").str[0].tolist())

# %% [raw]
# underGeneration["case"]=underGeneration["lexeme-case"].str.rsplit("-").str[-1]

# %% [raw]
# underGeneration.groupby("case").count()["value"].sort_values(ascending=False)

# %% [raw]
# finalParadigmes=extendParadigmes(savedContextParadigmes,extendMorphomes=True)

# %% [raw]
# test["ppMS"]

# %% [raw]
# def repairContextParadigmes(contextParadigmes):
#     repaired={}
#     for sCP in contextParadigmes.keys():
#     #    noLexeme=False
#         repaired[sCP]=[]
#         for numClique,clique in enumerate(contextParadigmes[sCP]):
#             repaired[sCP].append(clique)
#     #        noLexemeElements=[]
#     #        withLexemeElements=[]
#             for numElement,element in enumerate(clique):
#                 if not len(element.split("-"))>2 or not element.startswith(sCP):
#                     print (sCP+"-"+element)
#                     repaired[sCP][numClique][numElement]=sCP+"-"+element
#     #                noLexemeElements.append(element)
#     #            else:
#     #                withLexemeElements.append(element)
#     #        if noLexemeElements:
#     #            print (sCP)
#     #            print (noLexemeElements)
#     #            print (withLexemeElements)
#     #            print ()
#     #        noLexeme=False
#     return repaired

# %% [raw]
# repairContextParadigmes(contextParadigmes)[u"féminiser"]

# %% [markdown]
# ### Test de la sauvegarde de l'analyse brute

# %% [markdown]
# ## with open(analysisPrefix+"-analyseParadigmes.pkl","rb") as input:
#     savedAnalyseParadigmes = pickle.load(input)

# %% [raw]
# savedContextParadigmes=savedAnalyseParadigmes[0]
# savedCliques=savedAnalyseParadigmes[1]
# savedCliquesScores=savedAnalyseParadigmes[2]
# savedCliquesListes=savedAnalyseParadigmes[3]
# #savedFormesScores=savedAnalyseParadigmes[4]
# #savedFormesScoresNormes=savedAnalyseParadigmes[5]

# %% [raw]
# generateForms(u"crépir",contextFree=True).formes

# %% [raw]
# if genFormeVotes:
#     fScores=(formesScores,formesScoresNormes)
#     with open(analysisPrefix+paperPrefix+'-Scores.pkl', 'wb') as output:
#         pickle.dump(fScores, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# %%time
# versionStamp=dateheure()
# if genDigraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globDigraphe,analysisPrefix+paperPrefix+u"-digraphe-%s.gexf"%versionStamp)
# if genGraphe and len(listeTest)==1:
#     nx.readwrite.write_gexf(globGraphe,analysisPrefix+paperPrefix+u"-graphe-%s.gexf"%versionStamp)

# %% [raw]
# print (len(cliques))

# %% [raw]
# if genCliques:
#     infoCliques={"cliques":cliques, "cliquesScores":cliquesScores, "cliquesListes":cliquesListes}
#     with open(analysisPrefix+paperPrefix+'-Network.pkl', 'wb') as output:
#         pickle.dump(infoCliques, output, pickle.HIGHEST_PROTOCOL)

# %% [raw]
# print (paradigmes[paradigmes["lexeme"]==lexeme].to_latex(na_rep=""))

# %% [raw]
# HTML(makeTable(dictParadigmes[lexeme],title=lexeme))

# %% [raw]
# print (len(sampleCases),sampleCases,paradigmes["lexeme"].count())
# nbCoformes=paradigmes.notnull().sum(axis=1)-1
# distNbCoformes=nbCoformes.groupby(by=nbCoformes).count()
# ax=distNbCoformes.plot(kind="bar",legend=False,grid=True,figsize=(10,3))
# ax.set(xlim=(-0.5,32),ylim=(0,600))
# ax.set_xlabel("Number of Co-Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["lexeme"]==u"être") & (sampleTirage["tir1"]!=0)]

# %% [raw]
# freqCasesSampleTirage=sampleTirage[sampleTirage["tir1"]!=0].groupby("case")[["lexeme"]].count().sort_values("lexeme",ascending=False)
# ax=freqCasesSampleTirage.plot(kind="bar",legend=False,grid=True,figsize=(10,5))
# ax.set(xlim=(-0.5,32.5),ylim=(0,5000))
# ax.set_xlabel("Forms",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# coFormes=paradigmes.copy()
# coFormes["nbCoformes"]=coFormes.notnull().sum(axis=1)-1
# singletonLexemes=coFormes[coFormes["nbCoformes"]==1]["lexeme"].tolist()
# print (coFormes["nbCoformes"].sum(),len(singletonLexemes))

# %% [raw]
# freqCaseSingleton=sampleTirage[(sampleTirage["tir1"]!=0) & (sampleTirage["lexeme"].isin(singletonLexemes))][["case","morphome"]].groupby("case").count()
# ax=freqCaseSingleton.sort_values("morphome",ascending=False).plot(kind="bar",legend=False,grid=True,figsize=(8,3))
# ax.set(xlim=(-0.25,17),ylim=(0,200))
# ax.set_xlabel("Isolated Form",fontsize=16)
# ax.set_ylabel("Number of Lexemes",fontsize=16)

# %% [raw]
# sampleTirage[(sampleTirage["tir1"]!=0)]["tir1"].sum()

# %% [raw]
# recoder("degrosirje")

# %%
for i in range(10,13):
    for caseType in ["-X","-X-Morphomes"]: #["-X","-X-Morphomes"]
        for etapeSwim in ["-Swim1","-Swim2"]:
            cli="./EvaluationParadigmes-Recalcul.py %02d -X %s %s"%(i,caseType,etapeSwim)
            print cli
            # %run $cli
# Out:
# ./EvaluationParadigmes-Recalcul.py 10 -X -X -Swim1
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-10-T110000-F15616-X-paradigmes-Swim1.csv
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:284: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 134608 formes à prédire à partir de 15616 formes de 3102 lexèmes
# Sous-générations :
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:545: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#  76571 Sur-générations : 1049
# Formes identiques 56646
# Formes potentiellement différentes 1290
# UG : 77860 OG : 1049 TP : 56747 FP : 1189
# recall : 0.421575400982 precision : 0.962058150377
# fMeasure : 0.586253564197
# 2018-01-03 11:29:00.731867
# 2018-01-03 11:29:37.389982
# ./EvaluationParadigmes-Recalcul.py 10 -X -X -Swim2
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-10-T110000-F15616-X-paradigmes-Swim2.csv
# 134608 formes à prédire à partir de 15616 formes de 3102 lexèmes
# Sous-générations : 57969 Sur-générations : 1434
# Formes identiques 73836
# Formes potentiellement différentes 2683
# UG : 60648 OG : 1434 TP : 73959 FP : 2560
# recall : 0.549443936794 precision : 0.94876399882
# fMeasure : 0.695888219797
# 2018-01-03 11:29:37.394454
# 2018-01-03 11:30:17.927572
# ./EvaluationParadigmes-Recalcul.py 10 -X -X-Morphomes -Swim1
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-10-T110000-F15616-X-Morphomes-paradigmes-Swim1.csv
# 134608 formes à prédire à partir de 15616 formes de 3102 lexèmes
# Sous-générations : 53517 Sur-générations : 1271
# Formes identiques 76283
# Formes potentiellement différentes 4594
# UG : 58112 OG : 1271 TP : 76495 FP : 4382
# recall : 0.568283967401 precision : 0.931185177971
# fMeasure : 0.70581993495
# 2018-01-03 11:30:17.942833
# 2018-01-03 11:31:03.819427
# ./EvaluationParadigmes-Recalcul.py 10 -X -X-Morphomes -Swim2
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-10-T110000-F15616-X-Morphomes-paradigmes-Swim2.csv
# 134608 formes à prédire à partir de 15616 formes de 3102 lexèmes
# Sous-générations : 39340 Sur-générations : 1660
# Formes identiques 89032
# Formes potentiellement différentes 6033
# UG : 45326 OG : 1660 TP : 89281 FP : 5784
# recall : 0.66327159806 precision : 0.923039545102
# fMeasure : 0.771886293293
# 2018-01-03 11:31:03.836838
# 2018-01-03 11:31:43.371739
# ./EvaluationParadigmes-Recalcul.py 11 -X -X -Swim1
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-11-T120000-F16280-X-paradigmes-Swim1.csv
# 136874 formes à prédire à partir de 16280 formes de 3162 lexèmes
# Sous-générations : 77310 Sur-générations : 1086
# Formes identiques 58145
# Formes potentiellement différentes 1303
# UG : 78613 OG : 1086 TP : 58260 FP : 1188
# recall : 0.425650055161 precision : 0.962434334424
# fMeasure : 0.590252625287
# 2018-01-03 11:31:43.388998
# 2018-01-03 11:32:22.203809
# ./EvaluationParadigmes-Recalcul.py 11 -X -X -Swim2
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-11-T120000-F16280-X-paradigmes-Swim2.csv
# 136874 formes à prédire à partir de 16280 formes de 3162 lexèmes
# Sous-générations : 57198 Sur-générations : 1473
# Formes identiques 76887
# Formes potentiellement différentes 2652
# UG : 59846 OG : 1473 TP : 77027 FP : 2512
# recall : 0.562762560914 precision : 0.950809756579
# fMeasure : 0.707042706015
# 2018-01-03 11:32:22.422285
# 2018-01-03 11:33:08.181449
# ./EvaluationParadigmes-Recalcul.py 11 -X -X-Morphomes -Swim1
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-11-T120000-F16280-X-Morphomes-paradigmes-Swim1.csv
# 136874 formes à prédire à partir de 16280 formes de 3162 lexèmes
# Sous-générations : 48065 Sur-générations : 1325
# Formes identiques 81039
# Formes potentiellement différentes 7517
# UG : 55566 OG : 1325 TP : 81307 FP : 7249
# recall : 0.594032424218 precision : 0.904607202857
# fMeasure : 0.717138396677
# 2018-01-03 11:33:08.278873
# 2018-01-03 11:33:51.518655
# ./EvaluationParadigmes-Recalcul.py 11 -X -X-Morphomes -Swim2
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-11-T120000-F16280-X-Morphomes-paradigmes-Swim2.csv
# 136874 formes à prédire à partir de 16280 formes de 3162 lexèmes
# Sous-générations : 33298 Sur-générations : 1694
# Formes identiques 94448
# Formes potentiellement différentes 8881
# UG : 42120 OG : 1694 TP : 94753 FP : 8576
# recall : 0.692269476084 precision : 0.902211896442
# fMeasure : 0.7834193207
# 2018-01-03 11:33:51.540433
# 2018-01-03 11:34:35.732938
# ./EvaluationParadigmes-Recalcul.py 12 -X -X -Swim1
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-12-T130000-F16948-X-paradigmes-Swim1.csv
# 138867 formes à prédire à partir de 16948 formes de 3217 lexèmes
# Sous-générations : 75898 Sur-générations : 1129
# Formes identiques 61498
# Formes potentiellement différentes 1349
# UG : 77247 OG : 1129 TP : 61619 FP : 1228
# recall : 0.443729926692 precision : 0.963158059272
# fMeasure : 0.607556620424
# 2018-01-03 11:34:35.751728
# 2018-01-03 11:35:18.783179
# ./EvaluationParadigmes-Recalcul.py 12 -X -X -Swim2
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-12-T130000-F16948-X-paradigmes-Swim2.csv
# 138867 formes à prédire à partir de 16948 formes de 3217 lexèmes
# Sous-générations : 57190 Sur-générations : 1524
# Formes identiques 78766
# Formes potentiellement différentes 2770
# UG : 59956 OG : 1524 TP : 78910 FP : 2626
# recall : 0.568245646883 precision : 0.950036118469
# fMeasure : 0.711137946883
# 2018-01-03 11:35:18.801827
# 2018-01-03 11:36:05.004155
# ./EvaluationParadigmes-Recalcul.py 12 -X -X-Morphomes -Swim1
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-12-T130000-F16948-X-Morphomes-paradigmes-Swim1.csv
# 138867 formes à prédire à partir de 16948 formes de 3217 lexèmes
# Sous-générations : 46127 Sur-générations : 1426
# Formes identiques 84553
# Formes potentiellement différentes 7928
# UG : 54039 OG : 1426 TP : 84827 FP : 7654
# recall : 0.610855068915 precision : 0.903308592544
# fMeasure : 0.728838825809
# 2018-01-03 11:36:05.021261
# 2018-01-03 11:36:49.341022
# ./EvaluationParadigmes-Recalcul.py 12 -X -X-Morphomes -Swim2
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-12-T130000-F16948-X-Morphomes-paradigmes-Swim2.csv
# 138867 formes à prédire à partir de 16948 formes de 3217 lexèmes
# Sous-générations : 32988 Sur-générations : 1796
# Formes identiques 96370
# Formes potentiellement différentes 9252
# UG : 42200 OG : 1796 TP : 96666 FP : 8956
# recall : 0.696109918915 precision : 0.899905043847
# fMeasure : 0.784996183268
# 2018-01-03 11:36:49.359563
# 2018-01-03 11:37:37.359806

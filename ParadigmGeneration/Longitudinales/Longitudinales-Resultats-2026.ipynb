# %% [markdown]
# # Exploitation des résultats des longitudinales

# %% [markdown]
# ## Préparation des données

# %%
import yaml,operator
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.transforms as transforms
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import itertools as it
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# #### Ouvrir le fichier résultats

# %%
filePrefix="/Users/gilles/pCloud Drive/FOD/GB/2015-Data/Longitudinales/"
with open(filePrefix+"Longitudinal-X-Resultats-Recalcul.yaml", 'r') as stream:
    longitudinal=yaml.safe_load(stream)

# %% [markdown]
# #### Découper les résultats en fonction des étapes et des types de paradigmes
# - étapes :
#  - Swim1 avec les contextes phonologiques
#  - Swim2 avec les formes de Swim1 mais sans les contextes phonologiques
# - types de paradigmes :
#  - paradigme morphosyntaxique avec les colonnes standards correspondant aux propriétés morphosyntaxiques
#  - paradigme morphomique issu du regroupement des colonnes compatibles avec réextension aux cases standards à la fin

# %%
msp1Dict={}
msp2Dict={}
omp1Dict={}
omp2Dict={}
for k in longitudinal:
    if "Morphomes" in k:
        kSimple=k.strip("-X-Morphomes")
        omp1Dict[kSimple]=longitudinal[k]["Swim1"]
        omp2Dict[kSimple]=longitudinal[k]["Swim2"]
    else:
        kSimple=k.strip("-X")
        msp1Dict[kSimple]=longitudinal[k]["Swim1"]
        msp2Dict[kSimple]=longitudinal[k]["Swim2"]

# %% [markdown]
# #### Création des DF pour chaque combinaison
# - orient="index" pour transformer les clés en index,colonnes

# %%
msp1=pd.DataFrame.from_dict(msp1Dict,orient="index")
msp2=pd.DataFrame.from_dict(msp2Dict,orient="index")
omp1=pd.DataFrame.from_dict(omp1Dict,orient="index")
omp2=pd.DataFrame.from_dict(omp2Dict,orient="index")

# %% [markdown]
# #### Mise en forme des colonnes avant fusion
# - suppression des colonnes redondantes (*colonnesUniques*)
# - suffixation des autres colonnes pour les distinguer
#  - type de paradigme :
#    - S pour morphosyntaxique
#    - M pour morphomique
#  - étape de SWIM
#    - 1 pour Swim1
#    - 2 pour Swim2

# %%
colonnesUniques=["nbGoldForms","nbInitialForms","nbLexemes"]
for colonne in colonnesUniques:
    del msp2[colonne]
    del omp1[colonne]
    del omp2[colonne]
msp1.columns=[c+"-S1" if not c in colonnesUniques else c for c in msp1.columns]
msp2.columns=[c+"-S2" for c in msp2.columns]
omp1.columns=[c+"-M1" for c in omp1.columns]
omp2.columns=[c+"-M2" for c in omp2.columns]

# %%
msp1[["TP-S1","UG-S1","nbGoldForms"]]
# Out:
#                        TP-S1  UG-S1  nbGoldForms
# 00-T10000-F3663         8505  45354        53859
# 01-T20000-F5816        16950  59685        76635
# 02-T30000-F7497        24618  65064        89682
# 03-T40000-F8900        31318  68324        99642
# 04-T50000-F10082       36322  72396       108718
# 05-T60000-F11252       41305  73543       114848
# 06-T70000-F12207       44658  74765       119424
# 07-T80000-F13155       48145  75984       124130
# 08-T90000-F14038       50839  76879       127719
# 09-T100000-F14858      53821  77431       131253
# 10-T110000-F15616      56747  77860       134608
# 100-T11000000-F65816  139793  58702       198495
# 101-T12000000-F66324  140167  58180       198347
# 102-T13000000-F66785  139864  58231       198095
# 103-T14000000-F67196  139908  58230       198138
# 104-T15000000-F67525  139853  58207       198060
# 105-T16000000-F67823  139811  58308       198119
# 106-T17000000-F68097  140060  58089       198149
# 107-T18000000-F68321  140234  57892       198126
# 108-T19000000-F68546  141109  57088       198197
# 109-T20000000-F68760  141137  57145       198282
# 11-T120000-F16280      58260  78613       136874
# 110-T21000000-F68931  141286  57077       198363
# 111-T22000000-F69080  141298  57018       198316
# 112-T23000000-F69221  141220  57006       198226
# 113-T24000000-F69370  141552  56576       198128
# 114-T25000000-F69523  141496  56582       198078
# 115-T26000000-F69676  141519  56506       198025
# 116-T27000000-F69795  141745  56488       198233
# 117-T28000000-F69897  142446  55787       198233
# ...                      ...    ...          ...
# 70-T2600000-F52078    129301  66464       195766
# 71-T2700000-F52583    129878  66234       196113
# 72-T2800000-F53043    130036  66275       196312
# 73-T2900000-F53450    130119  66357       196477
# 74-T3000000-F53894    130309  66380       196690
# 75-T3100000-F54304    130544  66059       196604
# 76-T3200000-F54672    130625  66014       196640
# 77-T3300000-F54985    130714  65967       196682
# 78-T3400000-F55311    130906  65905       196812
# 79-T3500000-F55659    131097  65774       196872
# 80-T3600000-F55975    131620  65494       197115
# 81-T3700000-F56255    131692  65541       197234
# 82-T3800000-F56572    131788  65383       197172
# 83-T3900000-F56880    131886  65403       197290
# 84-T4000000-F57148    132476  65004       197481
# 85-T4100000-F57407    132571  65004       197576
# 86-T4200000-F57666    132638  65077       197716
# 87-T4300000-F57900    132759  65074       197834
# 88-T4400000-F58139    132927  64915       197843
# 89-T4500000-F58356    133056  64872       197929
# 90-T4600000-F58581    133118  64805       197924
# 91-T4700000-F58794    133256  64808       198065
# 92-T4800000-F58999    133617  64293       197911
# 93-T4900000-F59191    133672  64301       197974
# 94-T5000000-F59398    133844  64173       198018
# 95-T6000000-F61082    135696  62503       198200
# 96-T7000000-F62451    136501  62043       198545
# 97-T8000000-F63534    137183  60983       198166
# 98-T9000000-F64430    138869  59640       198509
# 99-T10000000-F65173   139622  58911       198533
#
# [130 rows x 3 columns]

# %% [markdown]
# #### Fusion des DF

# %%
df=pd.merge(msp1,msp2, left_index=True, right_index=True)
df=pd.merge(df,omp1, left_index=True, right_index=True)
df=pd.merge(df,omp2, left_index=True, right_index=True)

# %% [markdown]
# #### Ajout des colonnes *forms* et *tokens*

# %%
df["forms"]=df.index.str.split("-").str[-1].str.strip("F").astype(int)
df["tokens"]=df.index.str.split("-").str[1].str.strip("T").astype(int)
df["M-tokens"]=df["tokens"].astype(float)/1000000
df["numero"]=df.index.str.split("-").str[0].astype(int)
df.sort_values(by="numero")[["tokens","M-tokens","forms","nbInitialForms","nbGoldForms","nbLexemes"]]
# Out:
#                           tokens  M-tokens  forms  nbInitialForms  \
# 00-T10000-F3663            10000      0.01   3663            3663
# 01-T20000-F5816            20000      0.02   5816            5816
# 02-T30000-F7497            30000      0.03   7497            7497
# 03-T40000-F8900            40000      0.04   8900            8900
# 04-T50000-F10082           50000      0.05  10082           10082
# 05-T60000-F11252           60000      0.06  11252           11252
# 06-T70000-F12207           70000      0.07  12207           12207
# 07-T80000-F13155           80000      0.08  13155           13155
# 09-T100000-F14858           131253       3016
# 10-T110000-F15616           134608       3102
# 11-T120000-F16280           136874       3162
# 12-T130000-F16948           138867       3217
# 13-T140000-F17587           140684       3268
# 14-T150000-F18240           143304       3335
# 15-T160000-F18824           145228       3386
# 16-T170000-F19369           146475       3423
# 17-T180000-F19921           148297       3472
# 18-T190000-F20415           149401       3506
# 19-T200000-F20877           151131       3551
# 20-T210000-F21393           152463       3589
# 21-T220000-F21883           153812       3627
# 22-T230000-F22343           155291       3667
# 23-T240000-F22786           163866       3702
# 24-T250000-F23208           165138       3736
# 25-T260000-F23683           166135       3765
# 26-T270000-F24099           167499       3800
# 27-T280000-F24478           168085       3820
# 28-T290000-F24873           168960       3845
# 29-T300000-F25250           169943       3872
# ...                            ...        ...
# 100-T11000000-F65816        198495       5255
# 101-T12000000-F66324        198347       5263
# 102-T13000000-F66785        198095       5268
# 103-T14000000-F67196        198138       5277
# 104-T15000000-F67525        198060       5282
# 105-T16000000-F67823        198119       5289
# 106-T17000000-F68097        198149       5295
# 107-T18000000-F68321        198126       5299
# 108-T19000000-F68546        198197       5305
# 109-T20000000-F68760        198282       5311
# 110-T21000000-F68931        198363       5316
# 111-T22000000-F69080        198316       5318
# 112-T23000000-F69221        198226       5319
# 113-T24000000-F69370        198128       5320
# 114-T25000000-F69523        198078       5322
# 115-T26000000-F69676        198025       5324
# 116-T27000000-F69795        198233       5330
# 117-T28000000-F69897        198233       5332
# 118-T29000000-F70013        198219       5334
# 119-T30000000-F70110        198272       5337
# 120-T40000000-F70904        197883       5345
# 121-T50000000-F71435        197858       5355
# 122-T60000000-F71811        197834       5362
# 123-T70000000-F72058        197944       5369
# 124-T80000000-F72279        197976       5375
# 125-T90000000-F72474        197982       5379
# 126-T100000000-F72598       198008       5382
# 127-T110000000-F72720       197886       5382
# 128-T120000000-F72811       197795       5382
# 129-T130000000-F72864       197790       5383
#
# [130 rows x 6 columns]

# %%
echantillons=[n for n in range(130) if not n in sorted(df["numero"].tolist())]
for k, g in it.groupby(enumerate(echantillons), lambda (i,x):i-x):
       print " ".join([str(n) for n in map(operator.itemgetter(1), g)])

#" ".join([str(n) for n in range(130) if not n in sorted(df["numero"].tolist())])

# %%
df.sort_values(by="numero")[["FP-S1","TP-S1","UG-S1","OG-S1","FP-M1","TP-M1","UG-M1","OG-M1"]]
# Out:
#                        FP-S1   TP-S1  UG-S1  OG-S1  FP-M1   TP-M1  UG-M1  \
# 00-T10000-F3663          495    8505  45354    123   5175   15215  38644
# 01-T20000-F5816          716   16950  59685    262   7630   32171  44464
# 02-T30000-F7497          682   24618  65064    401   3968   38573  51109
# 03-T40000-F8900          903   31318  68324    518   3103   45777  53865
# 04-T50000-F10082        1090   36322  72396    562   5583   52620  56098
# 05-T60000-F11252        1023   41305  73543    699   3773   55985  58863
# 06-T70000-F12207        1043   44658  74765    743   3834   61910  57513
# 07-T80000-F13155        1044   48145  75984    813   8628   66838  57291
# 08-T90000-F14038        1244   50839  76879    912   4307   68105  59613
# 09-T100000-F14858       1177   53821  77431    949   4348   72980  58272
# 127-T110000000-F72720    804  143625  54261   3113    890  158353  39533
# 128-T120000000-F72811    804  143560  54235   3113    889  158261  39534
# 129-T130000000-F72864    804  143565  54225   3116    889  158249  39541
#
#                        OG-M1
# 00-T10000-F3663          186
# 01-T20000-F5816          482
# 02-T30000-F7497          575
# 03-T40000-F8900          690
# 04-T50000-F10082         813
# 05-T60000-F11252         874
# 06-T70000-F12207         923
# 07-T80000-F13155        1076
# 08-T90000-F14038        1139
# 09-T100000-F14858       1200
# 10-T110000-F15616       1271
# 11-T120000-F16280       1325
# 12-T130000-F16948       1426
# 13-T140000-F17587       1463
# 14-T150000-F18240       1482
# 15-T160000-F18824       1485
# 16-T170000-F19369       1526
# 17-T180000-F19921       1549
# 18-T190000-F20415       1596
# 19-T200000-F20877       1632
# 20-T210000-F21393       1650
# 21-T220000-F21883       1657
# 22-T230000-F22343       1683
# 23-T240000-F22786       1676
# 24-T250000-F23208       1722
# 25-T260000-F23683       1738
# 26-T270000-F24099       1709
# 27-T280000-F24478       1757
# 28-T290000-F24873       1784
# 29-T300000-F25250       1800
# ...                      ...
# 100-T11000000-F65816    3126
# 101-T12000000-F66324    3163
# 102-T13000000-F66785    3198
# 103-T14000000-F67196    3204
# 104-T15000000-F67525    3211
# 105-T16000000-F67823    3211
# 106-T17000000-F68097    3209
# 107-T18000000-F68321    3212
# 108-T19000000-F68546    3229
# 109-T20000000-F68760    3233
# 110-T21000000-F68931    3229
# 111-T22000000-F69080    3229
# 112-T23000000-F69221    3229
# 113-T24000000-F69370    3228
# 114-T25000000-F69523    3228
# 115-T26000000-F69676    3230
# 116-T27000000-F69795    3230
# 117-T28000000-F69897    3234
# 118-T29000000-F70013    3234
# 119-T30000000-F70110    3237
# 120-T40000000-F70904    3243
# 121-T50000000-F71435    3249
# 122-T60000000-F71811    3249
# 123-T70000000-F72058    3249
# 124-T80000000-F72279    3288
# 125-T90000000-F72474    3292
# 126-T100000000-F72598   3292
# 127-T110000000-F72720   3295
# 128-T120000000-F72811   3295
# 129-T130000000-F72864   3300
#
# [130 rows x 8 columns]

# %% [markdown]
# #### Fonction pour les graphes

# %%
sns.set(style="ticks")
sns.set_style("whitegrid")
sns.set_palette("husl")
sns.set_context("paper")
# sns.set_context("notebook")

# %%
def reFormatTicks(x,pos):
    text="0"
    if x!=0:
        magnitude=int(np.log10(x))
        value=float(x)/(10**magnitude)
        value=("%.1f"%value).strip("0").strip(".")
        if value=="1":
            text="$\mathdefault{10^{%d}}$"%(magnitude)
        else:
            text="$\mathdefault{%s\\ 10^{%d}}$"%(value,magnitude)
    return text

# %%
def reFormatTicks(x,pos):
    text="0"
    if x!=0:
        magnitude=int(np.log10(x))
        x=round(float(x)/(10**magnitude),1)*10**magnitude
        if magnitude>=9:
            unit="G"
            value=("%.1f"%(float(x)/1e9)).strip("0").strip(".")
        elif magnitude>=6:
            unit="M"
            value=("%.1f"%(float(x)/1e6)).strip("0").strip(".")
        elif magnitude>=3:
            unit="k"
            value=("%.1f"%(float(x)/1e3)).strip("0").strip(".")
        else:
            unit=""
            value=("%.1f"%float(x)).strip("0").strip(".")
        text="%s%s"%(value,unit)
    return text

# %%
reFormatTicks(12500,(32,10))
# Out:
# '13k'

# %%
def addLine(h,ax):
    ax.axhline(h,ls="dotted",lw=.25)
    trans = transforms.blended_transform_factory(
        ax.get_yticklabels()[0].get_transform(), ax.transData)
    ax.text(0,h, "{:.1%}".format(h), color="black", transform=trans, 
            ha="right", va="center")
    return

# %%
def makeGraph(x,colonnes,xlabel="Nombre de tokens verbaux",ylabel="Score",size=(8,5),hlines=[],fontsize=16):
    scale=x
    (largeur,hauteur)=size
    if scale=="M-tokens":
        size=(25,3)
    elif not "tokens" in scale:
        largeur*=2
        size=(largeur,hauteur)
    ax=df.set_index(scale).sort_values(by="numero")[colonnes].plot(figsize=size,marker=".")
    ax.set_xlabel(xlabel,fontsize=fontsize)
    ax.set_ylabel(ylabel,fontsize=fontsize)
    if "M-tokens"==scale:
        ax.xaxis.set_ticks(np.linspace(2,130,num=55))
#        ax.xaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
    elif "tokens"==scale:
        ax.set_xscale("log")
        ax.set_xticks(np.logspace(4,8.5, num=10))
#        ax.set_xticks(np.logspace(6.3,8.11, num=4))
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
    if ylabel=="Score":
        ax.set_yscale("linear")
        ax.yaxis.set_ticks(np.linspace(0,1,num=11))
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
    elif ylabel=="Number of Forms":
        ax.set_yscale("log")
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
    for h in hlines:
        addLine(h,ax)
    ax.tick_params(axis='both', which='major', labelsize=fontsize)
    return ax
        
'''Plotting values on the graph'''
#    for colonne in colonnes:
#        for (a,b) in zip(df.sort_values(by="numero")[scale],df.sort_values(by="numero")[colonne])[-10:]:
#            plt.text(a,b,"%0.3f"%b)
# Out:
# 'Plotting values on the graph'

# %% [markdown]
# ## Graphes et Commentaires

# %% [markdown]
# ### Étapes

# %%
ax=makeGraph("tokens",["Precision-S1","Recall-S1","F-Measure-S1"],hlines=[])

# %%
df.sort_values(by="numero").ix[[0,-1]][["nbLexemes","nbGoldForms","Precision-S1","Recall-S1","F-Measure-S1","TP-S1"]]
# Out:
# /opt/anaconda3/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                        nbLexemes  nbGoldForms  Precision-S1  Recall-S1  \
# 00-T10000-F3663             1289        53859      0.932259   0.157912
# 129-T130000000-F72864       5383       197790      0.973421   0.725846
#
#                        F-Measure-S1   TP-S1
# 00-T10000-F3663            0.270077    8505
# 129-T130000000-F72864      0.831598  143565

# %% [markdown]
# #### SWIM1 : Précision plutôt que Rappel
# Avec SWIM1, on obtient tout de suite une très bonne précision mais un faible rappel. Dès le premier échantillon avec 10.000 tokens, on a une précision de 93,23% à partir des 3663 formes connues pour 1289 lexèmes mais un rappel de 15,79% sur les 53859 formes à produire, c'est à dire 8505 nouvelles formes.
#
# La précision évolue peu avec le nombre de tokens. Elle passe de 93,23% pour 10.000 tokens à 96,32% pour 130,000 tokens. En revanche, le rappel augmente avec la taille de l'échantillon de 15,79% à 44,37% pour les mêmes échantillons. Avec une précision constante et un rappel croissant, la F-mesure suit l'évolution du rappel et la performance globale est directement liée à la faiblesse du rappel : 27,01% pour 10.000 tokens, 60,76% pour 130.000 tokens.
#
# SWIM1 optimise la précision au détriment du rappel en utilisant les contextes phonologiques précis pour conditionner les transformations entre formes.

# %%
palette = sns.color_palette()
ax=makeGraph("tokens",["Precision-S1","Recall-S1","Precision-S2","Recall-S2"])
pSwim1 = mlines.Line2D([], [], color=palette[0], marker='.', label=u'Précision 1 tour')
rSwim1 = mlines.Line2D([], [], color=palette[1], marker='.', label='Rappel 1 tour')
pSwim2 = mlines.Line2D([], [], color=palette[2], marker='.', label=u'Précision 2 tours')
rSwim2 = mlines.Line2D([], [], color=palette[3], marker='.', label='Rappel 2 tours')
ax.legend(handles=[pSwim1, rSwim1, pSwim2, rSwim2],fontsize=12)
plt.xlim(10000,150000000)
plt.savefig(filePrefix+"Comparaison-1Tour-2Tour.png",dpi=300,bbox_inches="tight")

# %%
df["DeltaF-S1S2"]=df["F-Measure-S2"]-df["F-Measure-S1"]
df["DeltaR-S1S2"]=df["Recall-S2"]-df["Recall-S1"]
print "Delta R %2.2f%%"%(df["DeltaR-S1S2"].mean()*100)
# Out:
# Delta R 11.05%

# %%
df.sort_values(by="numero").ix[[0,-1]][["Precision-S1","Recall-S1","F-Measure-S1","Precision-S2","Recall-S2","F-Measure-S2","TP-S1","TP-S2"]]
# Out:
# /opt/anaconda3/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                        Precision-S1  Recall-S1  F-Measure-S1  Precision-S2  \
# 00-T10000-F3663            0.932259   0.157912      0.270077      0.891946
# 129-T130000000-F72864      0.973421   0.725846      0.831598      0.968940
#
#                        Recall-S2  F-Measure-S2   TP-S1   TP-S2
# 00-T10000-F3663         0.287064      0.434340    8505   15461
# 129-T130000000-F72864   0.819374      0.887903  143565  162064

# %% [markdown]
# #### SWIM2 : Rappel plutôt que Précision
# L'étape SWIM2 consiste à appliquer une nouvelle série de transformations comme dans l'étape précédente mais sans tenir compte des contextes phonologiques. Gràce à la précision des résultats obtenus à l'étape précédente et malgré un rappel relativement faible, les nouvelles formes ajoutées par SWIM1 sont assez fiables pour servir de nouvelles formes initiales pour cette deuxième étape.
#
# Le fait d'inclure ces nouvelles formes dans les paradigmes initiaux impose de nouvelles contraintes de fidélité sur les cliques qui compensent en partie la perte d'information sur les contextes phonologiques. La précision baisse un peu mais la perte s'atténue avec la taille de l'échantillon, 89,19% contre 93,23% à 10.000 tokens mais 95% contre 96,32% à 130.000 tokens.
#
# En revanche, le rappel augmente de 13,29% sur l'ensemble des échantillons. Il passe de 15,79% à 28,71% à 10.000 tokens et de 44,37% à 56,82% à 130.000 tokens
#
# SWIM2 capitalise sur la précision des résultats de SWIM1 pour trouver de nouvelles formes à inclure dans les paradigmes sans tenir compte des propriétés phonologiques des contextes. La différence de précision entre les deux étapes est restreinte et c'est le rappel qui conditionne la variation de la F-mesure +12,69% en moyenne.

# %%
makeGraph("tokens",["F-Measure-S1","F-Measure-S2"])
print "Delta F %2.2f%%"%(df["DeltaF-S1S2"].mean()*100)
# Out:
# Delta F 7.88%

# %%
df.sort_values(by="numero").ix[[0,9,54,99,10]][["Precision-M1","Recall-M1","F-Measure-M1","Precision-M2","Recall-M2","F-Measure-M2","TP-M1","TP-M1"]]
# Out:
# /opt/anaconda3/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                      Precision-M1  Recall-M1  F-Measure-M1  Precision-M2  \
# 00-T10000-F3663          0.739454   0.282497      0.408813      0.713659
# 09-T100000-F14858        0.929350   0.556030      0.695777      0.921693
# 54-T1000000-F39898       0.974189   0.706696      0.819158      0.965635
# 99-T10000000-F65173      0.973912   0.783371      0.868311      0.967598
# 10-T110000-F15616        0.931185   0.568284      0.705820      0.923040
#
#                      Recall-M2  F-Measure-M2   TP-M1   TP-M1
# 00-T10000-F3663       0.419763      0.528607   15215   15215
# 09-T100000-F14858     0.659838      0.769087   72980   72980
# 54-T1000000-F39898    0.805785      0.878498  134138  134138
# 99-T10000000-F65173   0.886241      0.925134  155525  155525
# 10-T110000-F15616     0.663272      0.771886   76495   76495

# %%
makeGraph("tokens",["DeltaF-S1S2"])

# %% [markdown]
# ### Types de paradigmes

# %%
palette = sns.color_palette()
ax=makeGraph("tokens",["Precision-S1","Recall-S1","Precision-M1","Recall-M1"])
pSwim1 = mlines.Line2D([], [], color=palette[0], marker='.', label=u'Précision paradigme morphosyntaxique')
rSwim1 = mlines.Line2D([], [], color=palette[1], marker='.', label='Rappel Paradigme morphosyntaxique')
pSwim2 = mlines.Line2D([], [], color=palette[2], marker='.', label=u'Précision paradigme morphomique')
rSwim2 = mlines.Line2D([], [], color=palette[3], marker='.', label='Rappel Paradigme morphomique')
ax.legend(handles=[pSwim1, rSwim1, pSwim2, rSwim2],fontsize=12)
plt.xlim(10000,150000000)
plt.savefig(filePrefix+"Comparaison-Morphosyntaxique-Morphomique.png",dpi=300,bbox_inches="tight")

# %%
df["DeltaP-S1M1"]=df["Precision-M1"]-df["Precision-S1"]
df["DeltaR-S1M1"]=df["Recall-M1"]-df["Recall-S1"]
df["DeltaF-S1M1"]=df["F-Measure-M1"]-df["F-Measure-S1"]
print "Delta P %2.2f%%"%(df["DeltaP-S1M1"].mean()*100)
print "Delta R %2.2f%%"%(df["DeltaR-S1M1"].mean()*100)
print "Delta F %2.2f%%"%(df["DeltaF-S1M1"].mean()*100)
# Out:
# Delta P -1.44%
# Delta R 11.56%
# Delta F 8.23%

# %% [markdown]
# En passant d'un paradigme morphosyntaxique classique à un paradigme morphomique, il se produit deux effets.
#
# D'un côté, le regroupement des cases morphosyntaxiques compatibles en une case morphomique permet d'obtenir beaucoup plus de co-formes pour chaque paire de cases et de fait une meilleure couverture des transformations entre formes et des contextes phonologiques plus précis.
#
# D'un autre côté, les regroupements morphomiques constituent par eux-mêmes des prédictions sur les formes puisque les cases regroupées sont considérées comme syncrétiques, toutes les formes qui se trouvent associées à une même case morphomique sont par hypothèse identiques.
#
# Au départ, les deux effets s'opposent. Avec peu de formes dans les paradigmes, les regroupements permettent d'obtenir des meilleurs résultats à l'intérieur de SWIM mais certains regroupements de cases syncrétiques sont des erreurs liées au petit nombre de co-formes dans l'échantillon brut. Ces erreurs au niveau de l'abstraction du paradigme morphomique se répercutent sur la précision quand les formes générées sont redistribuées à mauvais escient dans les cases morphosyntaxiques en sortie.

# %%
makeGraph("tokens",["DeltaP-S1M1","DeltaR-S1M1","DeltaF-S1M1"])

# %%
makeGraph("tokens",["Precision-M1","Precision-M2","Recall-M1","Recall-M2"])

# %%
makeGraph("tokens",["Precision-S1","Precision-S2","Precision-M1","Precision-M2"])

# %%
makeGraph("tokens",["Recall-S1","Recall-S2","Recall-M1","Recall-M2"])

# %%
palette = sns.color_palette()
ax=makeGraph("tokens",["Precision-S1","Recall-S1","Precision-M2","Recall-M2"],size=(8,5),hlines=[],fontsize=12)
pSwim1 = mlines.Line2D([], [], color=palette[0], marker='.', label=u'Swim$_{1}$ Précision')
rSwim1 = mlines.Line2D([], [], color=palette[1], marker='.', label='Swim$_{1}$ Rappel')
pSwim2 = mlines.Line2D([], [], color=palette[2], marker='.', label=u'Swim$_{2}$ Précision')
rSwim2 = mlines.Line2D([], [], color=palette[3], marker='.', label='Swim$_{2}$ Rappel')
ax.legend(handles=[pSwim1, rSwim1, pSwim2, rSwim2],fontsize=12)
plt.xlim(10000,150000000)
plt.savefig(filePrefix+"Comparaison-Swim1-Swim2.png",dpi=300,bbox_inches="tight")

# %%
makeGraph("tokens",["F-Measure-S1","F-Measure-S2","F-Measure-M1","F-Measure-M2"])

# %%
makeGraph("tokens",["nbGoldForms","TP-S1","TP-M2","FP-S1","FP-M2"],ylabel="Number of Forms")

# %%
makeGraph("tokens",["nbGoldForms","forms","TP-S1","TP-M2"],ylabel="Number of Forms")

# %%
makeGraph("nbLexemes",["nbGoldForms","forms","TP-S1","TP-M2"],ylabel="Number of Forms")

# %%
makeGraph("forms",["Precision-S1","Precision-S2","Precision-M1","Precision-M2"])

# %%
makeGraph("forms",["Recall-S1","Recall-S2","Recall-M1","Recall-M2"])

# %%
makeGraph("forms",["F-Measure-S1","F-Measure-S2","F-Measure-M1","F-Measure-M2"])

# %%
makeGraph("tokens",["forms","nbGoldForms"],ylabel="Number of Forms")

# %%
makeGraph("tokens",["nbLexemes"],ylabel="Number of Lexemes")

# %% [markdown]
# # Qu'est-ce qu'il se passe si on mélange les profils de fréquences entre lexèmes ?
#
# - faire une substitution des lexèmes et des formes dans les échantillons et voir ce qui se produit dans les généralisations
#  - quelles irrégularités pourraient survivre à une inversion des fréquences ?

# %% [markdown]
# # Graphe nbFormes(tokens)

# %%
sns.reset_orig()
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_context("paper")
sns.set_palette("husl")

# %%
#makeGraph("tokens",["forms"],ylabel="Number of Forms",hlines=[75000,360000])
ax=df.set_index("tokens").sort_values(by="numero")[:]["forms"].plot(figsize=(6,3),marker=".",linewidth=3)
ax.set_xlabel("Sample size in tokens")#,fontsize=16)
ax.set_ylabel("Number of Cell-Forms")#,fontsize=16)
plt.xticks([100000,50000000,100000000,130000000])
plt.yticks([25000,50000,70000,75000])
plt.xticks(list(plt.xticks()[0]) + [29000000])
ax.xaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
ax.set_xlim(0,130000000)
ax.set_ylim(0,87500)
#addLine(75000,ax)
ax.axhline(75000,linestyle=":",linewidth=3,label="75k")
ax.axvline(29000000,linestyle=":",linewidth=3,c="green")
handles, labels = ax.get_legend_handles_labels()
legend1=ax.legend([handles[0]], ["Cell-forms in the sample"], loc=1,ncol=2)
ax.legend(handles[1:],["75,000 cell-forms"],loc=2)
ax.add_artist(legend1)
plt.grid()
plt.savefig("NbForms.png",dpi=300, bbox_inches="tight")
plt.show()

# %%
#makeGraph("tokens",["forms"],ylabel="Number of Forms",hlines=[75000,360000])
df["forms-prop"]=df["forms"]/328103
df["25%"]=.25
df[df["forms"]>=70000][["forms","forms-prop"]]
# Out:
#                        forms  forms-prop
# 118-T29000000-F70013   70013    0.213387
# 119-T30000000-F70110   70110    0.213683
# 120-T40000000-F70904   70904    0.216103
# 121-T50000000-F71435   71435    0.217721
# 122-T60000000-F71811   71811    0.218867
# 123-T70000000-F72058   72058    0.219620
# 124-T80000000-F72279   72279    0.220294
# 125-T90000000-F72474   72474    0.220888
# 126-T100000000-F72598  72598    0.221266
# 127-T110000000-F72720  72720    0.221638
# 128-T120000000-F72811  72811    0.221915
# 129-T130000000-F72864  72864    0.222077

# %%
ax=df.set_index("tokens").sort_values(by="numero")[["forms-prop"]].plot(figsize=(8,4),marker=".")
ax.set_xlabel("Sample size in tokens")#,fontsize=16)
ax.set_ylabel("Percentage of complete lexicon")#,fontsize=16)
ax.set_ylim(0,.28)
plt.xticks([100000,23000000,50000000,100000000])
ax.xaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
vals = ax.get_yticks()
ax.set_yticklabels(['{:3.2f}%'.format(x*100) for x in vals])
#ax.yaxis.set_major_formatter(ticker.FuncFormatter(reFormatTicks))
#addLine(75000,ax)
ax.axhline(.23,linestyle="--",label="23% of the complete lexicon")
handles, labels = ax.get_legend_handles_labels()
labels=["Cell-forms in the sample", "23% of the complete lexicon"]
ax.legend(handles, labels)
plt.grid()

# %%
msp1
# Out:
#                       FP-S1  nbGoldForms  F-Measure-S1  nbInitialForms  OG-S1  \
# 00-T10000-F3663         495        53859      0.270077            3663    123
# 01-T20000-F5816         716        76635      0.358491            5816    262
# 02-T30000-F7497         682        89682      0.426718            7497    401
# 03-T40000-F8900         903        99642      0.473149            8900    518
# 04-T50000-F10082       1090       108718      0.495214           10082    562
# 05-T60000-F11252       1023       114848      0.523262           11252    699
# 06-T70000-F12207       1043       119424      0.538480           12207    743
# 07-T80000-F13155       1044       124130      0.552974           13155    813
# 08-T90000-F14038       1244       127719      0.562649           14038    912
# 09-T100000-F14858      1177       131253      0.575014           14858    949
# 10-T110000-F15616      1189       134608      0.586254           15616   1049
# 100-T11000000-F65816    923       198495      0.817257           65816   2892
# 101-T12000000-F66324    938       198347      0.818752           66324   2940
# 102-T13000000-F66785    958       198095      0.818186           66785   2971
# 103-T14000000-F67196    925       198138      0.818290           67196   2981
# 104-T15000000-F67525    902       198060      0.818318           67525   2991
# 105-T16000000-F67823    887       198119      0.818063           67823   2993
# 106-T17000000-F68097    902       198149      0.818815           68097   2993
# 107-T18000000-F68321    904       198126      0.819459           68321   2996
# 108-T19000000-F68546    912       198197      0.822249           68546   3009
# 109-T20000000-F68760    911       198282      0.822139           68760   3011

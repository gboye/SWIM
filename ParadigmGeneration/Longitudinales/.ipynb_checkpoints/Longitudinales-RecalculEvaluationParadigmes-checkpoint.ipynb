# %% [markdown]
# #### Garbage Collection
# Les variables des scripts invoqués remontent dans le script principal. %xdel permet de désallouer une variable.

# %%
def trashDataFrames():
    # %xdel actualForms
    # %xdel compareForms
    # %xdel completeParadigmes
    # %xdel diffForms
    # %xdel finalForms
    # %xdel goldForms
    # %xdel goldTestForms
    # %xdel initialForms
    # %xdel initialParadigmes
    # %xdel lexiqueGold
    # %xdel overGeneration
    # %xdel predictedForms
    # %xdel predictedParadigmes
    # %xdel sameForms
    # %xdel underGeneration
    return

# %% [markdown]
# #### Mesurer la mémoire utilisée

# %%
def memory_usage_psutil():
    # return the memory usage in MB
    import psutil
    process = psutil.Process(os.getpid())
    mem = process.memory_info()[0] / float(2 ** 20)
    return mem

# %%
for i in range(13,14):
    for caseType in ["-X","-X-Morphomes"]: #["-X","-X-Morphomes"]
        for etapeSwim in ["-Swim1","-Swim2"]:
            cli="./EvaluationParadigmes-Recalcul.py %02d -X %s %s"%(i,caseType,etapeSwim)
            print cli
            print memory_usage_psutil()
            # %run $cli
            print memory_usage_psutil()
            trashDataFrames()
            print memory_usage_psutil()
            # %whos
# Out:
# ./EvaluationParadigmes-Recalcul.py 13 -X -X -Swim1
# 47.015625
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-13-T140000-F17587-X-paradigmes-Swim1.csv
# 140684 formes à prédire à partir de 17587 formes de 3268 lexèmes
# Sous-générations : 76051 Sur-générations : 1121
# Formes identiques 63233
# Formes potentiellement différentes 1282
# UG : 77323 OG : 1121 TP : 63360 FP : 1155
# recall : 0.450374245644 precision : 0.965323907612
# fMeasure : 0.614194524014
# 2018-01-03 23:08:01.388645
# 2018-01-03 23:08:42.809888
# 481.80078125
# 478.6875
# Variable                   Type        Data/Info
# ------------------------------------------------
# FP                         int         1155
# OG                         int         1121
# TP                         int         63360
# UG                         int         77323
# analysisPrefix             str         /Volumes/gilles/Transfert<...>dinal-13-T140000-F17587-X
# arguments                  list        n=5
# bdlexiqueIn                unicode     èò
# bdlexiqueNum               list        n=2
# caseType                   str         -X
# casesType                  str         -X
# char                       unicode     ò
# checkFrench                function    <function checkFrench at 0x1237258c0>
# cli                        str         ./EvaluationParadigmes-Re<...>calcul.py 13 -X -X -Swim1
# countSplits                function    <function countSplits at 0x106365d70>
# dataFrames                 list        n=15
# datetime                   module      <module 'datetime' from '<...>lib-dynload/datetime.so'>
# debut                      datetime    2018-01-03 23:08:01.388645
# dierese                    dict        n=6
# etape                      str         Swim1
# etapeSwim                  str         -Swim1
# fMeasure                   float       0.614194524014
# filePrefix                 str         /Volumes/gilles/Transfert<...>2015-Data/Longitudinales/
# fin                        datetime    2018-01-03 23:08:42.809888
# finalFormsIndex            list        n=65624
# glob                       module      <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# goldFormsIndex             list        n=140238
# i                          int         13
# initialFile                str         /Volumes/gilles/Transfert<...>0-F17587-X-paradigmes.csv
# initialFormsIndex          list        n=17568
# initialParadigmesColumns   list        n=50
# input                      file        <closed file '/Volumes/gi<...>mode 'rb' at 0x11fea9420>
# listeLexemes               list        n=3268
# memory_usage_psutil        function    <function memory_usage_psutil at 0x123725398>
# nbGoldForms                int         140684
# nbIdenticalSets            int         11
# nbIncludedSets             int         116
# nbInitialForms             int         17587
# nbLexemes                  int         3268
# nbRights                   int         1399
# nbValues                   int         1282
# nbWrongForms               int         1155
# neutralisations            tuple       n=2
# neutralisationsNORD        tuple       n=2
# neutralisationsSUD         tuple       n=2
# neutralise                 dict        n=2
# neutreOut                  unicode     EO
# nomFichierResultats        str         /Volumes/gilles/Transfert<...>X-Resultats-Recalcul.yaml
# numeroEchantillon          str         13
# os                         module      <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# pd                         module      <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# phonologicalMap            str         X
# pickle                     module      <module 'pickle' from '/U<...>ib/python2.7/pickle.pyc'>
# precision                  float       0.965323907612
# predictedFormsIndex        list        n=83192
# predictionsFile            str         /Volumes/gilles/Transfert<...>87-X-paradigmes-Swim1.csv
# prefixEchantillon          function    <function prefixEchantillon at 0x123725488>
# process                    Process     psutil.Process(pid=36285, name='python2.7')
# psutil                     module      <module 'psutil' from '/U<...>ges/psutil/__init__.pyc'>
# re                         module      <module 're' from '/Users<...>da/lib/python2.7/re.pyc'>
# recall                     float       0.450374245644
# recoder                    function    <function recoder at 0x123725848>
# referenceFile              str         /Volumes/gilles/Transfert<...>ta/MGC-171229-Verbes3.pkl
# resultCharacteristics      tuple       n=4
# resultMeasures             tuple       n=3
# resultats                  dict        n=28
# sampleExt                  str         -X
# sampleFiles                list        n=386
# sampleId                   str         13-T140000-F17587-X
# samplePrefix               str         Longitudinal-13-T140000-F17587
# sampleType                 str         -X
# stream                     file        <closed file '/Volumes/gi<...> mode 'r' at 0x11fea9390>
# sys                        module      <module 'sys' (built-in)>
# trashDataFrames            function    <function trashDataFrames at 0x112e9c938>
# underBonus                 int         1272
# yaml                       module      <module 'yaml' from '/Use<...>kages/yaml/__init__.pyc'>
# ./EvaluationParadigmes-Recalcul.py 13 -X -X -Swim2
# 478.69921875
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-13-T140000-F17587-X-paradigmes-Swim2.csv
# 140684 formes à prédire à partir de 17587 formes de 3268 lexèmes
# Sous-générations : 57597 Sur-générations : 1526
# Formes identiques 80336
# Formes potentiellement différentes 2617
# UG : 60192 OG : 1526 TP : 80491 FP : 2462
# recall : 0.572144466638 precision : 0.952793001811
# fMeasure : 0.714960783791
# 2018-01-03 23:08:42.891882
# 2018-01-03 23:09:25.646482
# 495.16796875
# 490.890625
# Variable                   Type        Data/Info
# ------------------------------------------------
# FP                         int         2462
# OG                         int         1526
# TP                         int         80491
# UG                         int         60192
# analysisPrefix             str         /Volumes/gilles/Transfert<...>dinal-13-T140000-F17587-X
# arguments                  list        n=5
# bdlexiqueIn                unicode     èò
# bdlexiqueNum               list        n=2
# caseType                   str         -X
# casesType                  str         -X
# char                       unicode     ò
# checkFrench                function    <function checkFrench at 0x10dc308c0>
# cli                        str         ./EvaluationParadigmes-Re<...>calcul.py 13 -X -X -Swim2
# countSplits                function    <function countSplits at 0x106365c08>
# dataFrames                 list        n=15
# datetime                   module      <module 'datetime' from '<...>lib-dynload/datetime.so'>
# debut                      datetime    2018-01-03 23:08:42.891882
# dierese                    dict        n=6
# etape                      str         Swim2
# etapeSwim                  str         -Swim2
# fMeasure                   float       0.714960783791
# filePrefix                 str         /Volumes/gilles/Transfert<...>2015-Data/Longitudinales/
# fin                        datetime    2018-01-03 23:09:25.646482
# finalFormsIndex            list        n=84449
# glob                       module      <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# goldFormsIndex             list        n=140238
# i                          int         13
# initialFile                str         /Volumes/gilles/Transfert<...>0-F17587-X-paradigmes.csv
# initialFormsIndex          list        n=17568
# initialParadigmesColumns   list        n=50
# input                      file        <closed file '/Volumes/gi<...>mode 'rb' at 0x10631f4b0>
# listeLexemes               list        n=3268
# memory_usage_psutil        function    <function memory_usage_psutil at 0x123725398>
# nbGoldForms                int         140684
# nbIdenticalSets            int         19
# nbIncludedSets             int         136
# nbInitialForms             int         17587
# nbLexemes                  int         3268
# nbRights                   int         2750
# nbValues                   int         2617
# nbWrongForms               int         2462
# neutralisations            tuple       n=2
# neutralisationsNORD        tuple       n=2
# neutralisationsSUD         tuple       n=2
# neutralise                 dict        n=2
# neutreOut                  unicode     EO
# nomFichierResultats        str         /Volumes/gilles/Transfert<...>X-Resultats-Recalcul.yaml
# numeroEchantillon          str         13
# os                         module      <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# pd                         module      <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# phonologicalMap            str         X
# pickle                     module      <module 'pickle' from '/U<...>ib/python2.7/pickle.pyc'>
# precision                  float       0.952793001811
# predictedFormsIndex        list        n=102017
# predictionsFile            str         /Volumes/gilles/Transfert<...>87-X-paradigmes-Swim2.csv
# prefixEchantillon          function    <function prefixEchantillon at 0x112e9ca28>
# process                    Process     psutil.Process(pid=36285, name='python2.7')
# psutil                     module      <module 'psutil' from '/U<...>ges/psutil/__init__.pyc'>
# re                         module      <module 're' from '/Users<...>da/lib/python2.7/re.pyc'>
# recall                     float       0.572144466638
# recoder                    function    <function recoder at 0x106365de8>
# referenceFile              str         /Volumes/gilles/Transfert<...>ta/MGC-171229-Verbes3.pkl
# resultCharacteristics      tuple       n=4
# resultMeasures             tuple       n=3
# resultats                  dict        n=28
# sampleExt                  str         -X
# sampleFiles                list        n=386
# sampleId                   str         13-T140000-F17587-X
# samplePrefix               str         Longitudinal-13-T140000-F17587
# sampleType                 str         -X
# stream                     file        <closed file '/Volumes/gi<...> mode 'r' at 0x10631f660>
# sys                        module      <module 'sys' (built-in)>
# trashDataFrames            function    <function trashDataFrames at 0x112e9c938>
# underBonus                 int         2595
# yaml                       module      <module 'yaml' from '/Use<...>kages/yaml/__init__.pyc'>
# ./EvaluationParadigmes-Recalcul.py 13 -X -X-Morphomes -Swim1
# 490.890625
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-13-T140000-F17587-X-Morphomes-paradigmes-Swim1.csv
# 140684 formes à prédire à partir de 17587 formes de 3268 lexèmes
# Sous-générations : 45905 Sur-générations : 1463
# Formes identiques 86560
# Formes potentiellement différentes 7978
# UG : 53838 OG : 1463 TP : 86845 FP : 7693
# recall : 0.617309838431 precision : 0.904625993479
# fMeasure : 0.733847661861
# 2018-01-03 23:09:25.705657
# 2018-01-03 23:10:11.802785
# 501.7109375
# 499.9921875
# Variable                   Type        Data/Info
# ------------------------------------------------
# FP                         int         7693
# OG                         int         1463
# TP                         int         86845
# UG                         int         53838
# analysisPrefix             str         /Volumes/gilles/Transfert<...>140000-F17587-X-Morphomes
# arguments                  list        n=5
# bdlexiqueIn                unicode     èò
# bdlexiqueNum               list        n=2
# caseType                   str         -X-Morphomes
# casesType                  str         -X-Morphomes
# char                       unicode     ò
# checkFrench                function    <function checkFrench at 0x106365d70>
# cli                        str         ./EvaluationParadigmes-Re<...>13 -X -X-Morphomes -Swim1
# countSplits                function    <function countSplits at 0x111de1a28>
# dataFrames                 list        n=15
# datetime                   module      <module 'datetime' from '<...>lib-dynload/datetime.so'>
# debut                      datetime    2018-01-03 23:09:25.705657
# dierese                    dict        n=6
# etape                      str         Swim1
# etapeSwim                  str         -Swim1
# fMeasure                   float       0.733847661861
# filePrefix                 str         /Volumes/gilles/Transfert<...>2015-Data/Longitudinales/
# fin                        datetime    2018-01-03 23:10:11.802785
# finalFormsIndex            list        n=95955
# glob                       module      <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# goldFormsIndex             list        n=140238
# i                          int         13
# initialFile                str         /Volumes/gilles/Transfert<...>0-F17587-X-paradigmes.csv
# initialFormsIndex          list        n=17568
# initialParadigmesColumns   list        n=50
# input                      file        <closed file '/Volumes/gi<...>mode 'rb' at 0x11fea9390>
# listeLexemes               list        n=3268
# memory_usage_psutil        function    <function memory_usage_psutil at 0x123725398>
# nbGoldForms                int         140684
# nbIdenticalSets            int         39
# nbIncludedSets             int         246
# nbInitialForms             int         17587
# nbLexemes                  int         3268
# nbRights                   int         8218
# nbValues                   int         7978
# nbWrongForms               int         7693
# neutralisations            tuple       n=2
# neutralisationsNORD        tuple       n=2
# neutralisationsSUD         tuple       n=2
# neutralise                 dict        n=2
# neutreOut                  unicode     EO
# nomFichierResultats        str         /Volumes/gilles/Transfert<...>X-Resultats-Recalcul.yaml
# numeroEchantillon          str         13
# os                         module      <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# pd                         module      <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# phonologicalMap            str         X
# pickle                     module      <module 'pickle' from '/U<...>ib/python2.7/pickle.pyc'>
# precision                  float       0.904625993479
# predictedFormsIndex        list        n=113523
# predictionsFile            str         /Volumes/gilles/Transfert<...>omes-paradigmes-Swim1.csv
# prefixEchantillon          function    <function prefixEchantillon at 0x10c258f50>
# process                    Process     psutil.Process(pid=36285, name='python2.7')
# psutil                     module      <module 'psutil' from '/U<...>ges/psutil/__init__.pyc'>
# re                         module      <module 're' from '/Users<...>da/lib/python2.7/re.pyc'>
# recall                     float       0.617309838431
# recoder                    function    <function recoder at 0x111de1578>
# referenceFile              str         /Volumes/gilles/Transfert<...>ta/MGC-171229-Verbes3.pkl
# resultCharacteristics      tuple       n=4
# resultMeasures             tuple       n=3
# resultats                  dict        n=28
# sampleExt                  str         -X-Morphomes
# sampleFiles                list        n=386
# sampleId                   str         13-T140000-F17587-X-Morphomes
# samplePrefix               str         Longitudinal-13-T140000-F17587
# sampleType                 str         -X
# stream                     file        <closed file '/Volumes/gi<...> mode 'r' at 0x11fea9420>
# sys                        module      <module 'sys' (built-in)>
# trashDataFrames            function    <function trashDataFrames at 0x112e9c938>
# underBonus                 int         7933
# yaml                       module      <module 'yaml' from '/Use<...>kages/yaml/__init__.pyc'>
# ./EvaluationParadigmes-Recalcul.py 13 -X -X-Morphomes -Swim2
# 499.9921875
# Nom du fichier prédictions /Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/Longitudinal-13-T140000-F17587-X-Morphomes-paradigmes-Swim2.csv
# 140684 formes à prédire à partir de 17587 formes de 3268 lexèmes
# Sous-générations : 32789 Sur-générations : 1836
# Formes identiques 98364
# Formes potentiellement différentes 9304
# UG : 42030 OG : 1836 TP : 98653 FP : 9015
# recall : 0.701243220574 precision : 0.900907729398
# fMeasure : 0.788634101692
# 2018-01-03 23:10:11.902486
# 2018-01-03 23:10:53.244658
# 514.83984375
# 511.79296875
# Variable                   Type        Data/Info
# ------------------------------------------------
# FP                         int         9015
# OG                         int         1836
# TP                         int         98653
# UG                         int         42030
# analysisPrefix             str         /Volumes/gilles/Transfert<...>140000-F17587-X-Morphomes
# arguments                  list        n=5
# bdlexiqueIn                unicode     èò
# bdlexiqueNum               list        n=2
# caseType                   str         -X-Morphomes
# casesType                  str         -X-Morphomes
# char                       unicode     ò
# checkFrench                function    <function checkFrench at 0x10d478b90>
# cli                        str         ./EvaluationParadigmes-Re<...>13 -X -X-Morphomes -Swim2
# countSplits                function    <function countSplits at 0x10d478c80>
# dataFrames                 list        n=15
# datetime                   module      <module 'datetime' from '<...>lib-dynload/datetime.so'>
# debut                      datetime    2018-01-03 23:10:11.902486
# dierese                    dict        n=6
# etape                      str         Swim2
# etapeSwim                  str         -Swim2
# fMeasure                   float       0.788634101692
# filePrefix                 str         /Volumes/gilles/Transfert<...>2015-Data/Longitudinales/
# fin                        datetime    2018-01-03 23:10:53.244658
# finalFormsIndex            list        n=109394
# glob                       module      <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# goldFormsIndex             list        n=140238
# i                          int         13
# initialFile                str         /Volumes/gilles/Transfert<...>0-F17587-X-paradigmes.csv
# initialFormsIndex          list        n=17568
# initialParadigmesColumns   list        n=50
# input                      file        <closed file '/Volumes/gi<...>mode 'rb' at 0x10631f660>
# listeLexemes               list        n=3268
# memory_usage_psutil        function    <function memory_usage_psutil at 0x123725398>
# nbGoldForms                int         140684
# nbIdenticalSets            int         35
# nbIncludedSets             int         254
# nbInitialForms             int         17587
# nbLexemes                  int         3268
# nbRights                   int         9530
# nbValues                   int         9304
# nbWrongForms               int         9015
# neutralisations            tuple       n=2
# neutralisationsNORD        tuple       n=2
# neutralisationsSUD         tuple       n=2
# neutralise                 dict        n=2
# neutreOut                  unicode     EO
# nomFichierResultats        str         /Volumes/gilles/Transfert<...>X-Resultats-Recalcul.yaml
# numeroEchantillon          str         13
# os                         module      <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# pd                         module      <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# phonologicalMap            str         X
# pickle                     module      <module 'pickle' from '/U<...>ib/python2.7/pickle.pyc'>
# precision                  float       0.900907729398
# predictedFormsIndex        list        n=126962
# predictionsFile            str         /Volumes/gilles/Transfert<...>omes-paradigmes-Swim2.csv
# prefixEchantillon          function    <function prefixEchantillon at 0x112e9ca28>
# process                    Process     psutil.Process(pid=36285, name='python2.7')
# psutil                     module      <module 'psutil' from '/U<...>ges/psutil/__init__.pyc'>
# re                         module      <module 're' from '/Users<...>da/lib/python2.7/re.pyc'>
# recall                     float       0.701243220574
# recoder                    function    <function recoder at 0x102f0f398>
# referenceFile              str         /Volumes/gilles/Transfert<...>ta/MGC-171229-Verbes3.pkl
# resultCharacteristics      tuple       n=4
# resultMeasures             tuple       n=3
# resultats                  dict        n=28
# sampleExt                  str         -X-Morphomes
# sampleFiles                list        n=386
# sampleId                   str         13-T140000-F17587-X-Morphomes
# samplePrefix               str         Longitudinal-13-T140000-F17587
# sampleType                 str         -X
# stream                     file        <closed file '/Volumes/gi<...> mode 'r' at 0x10631f4b0>
# sys                        module      <module 'sys' (built-in)>
# trashDataFrames            function    <function trashDataFrames at 0x112e9c938>
# underBonus                 int         9241
# yaml                       module      <module 'yaml' from '/Use<...>kages/yaml/__init__.pyc'>

# %%
memory_usage_psutil()
# Out:
# 46.921875

# %%
# Out:
# pmem(rss=48693248L, vms=5092360192L, pfaults=2475033, pageins=381)

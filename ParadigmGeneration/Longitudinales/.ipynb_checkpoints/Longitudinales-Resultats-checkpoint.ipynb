# %%
import yaml
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
filePrefix="/Volumes/gilles/Transfert/Copies-iMac-GB/2015-Data/Longitudinales/"
with open(filePrefix+"Longitudinal-X-Resultats-Recalcul.yaml", 'r') as stream:
    longitudinal=yaml.load(stream)

# %%
msp1Dict={}
msp2Dict={}
omp1Dict={}
omp2Dict={}
for k in longitudinal:
    if "Morphomes" in k:
        kSimple=k.strip("-Morphomes")
        omp1Dict[kSimple]=longitudinal[k]["Swim1"]
        omp2Dict[kSimple]=longitudinal[k]["Swim2"]
    else:
        kSimple=k.strip("-X")
        msp1Dict[kSimple]=longitudinal[k]["Swim1"]
        msp2Dict[kSimple]=longitudinal[k]["Swim2"]

# %%
msp1=pd.DataFrame.from_dict(msp1Dict,orient="index")
msp2=pd.DataFrame.from_dict(msp2Dict,orient="index")
omp1=pd.DataFrame.from_dict(omp1Dict,orient="index")
omp2=pd.DataFrame.from_dict(omp2Dict,orient="index")

# %%
del msp2[u"nbGoldForms"]
del omp1[u"nbGoldForms"]
del omp2[u"nbGoldForms"]
msp1.columns=[c+"-S1" if c!="nbGoldForms" else c for c in msp1.columns]
msp2.columns=[c+"-S2" for c in msp2.columns]
omp1.columns=[c+"-M1" for c in omp1.columns]
omp2.columns=[c+"-M2" for c in omp2.columns]

# %%
msp1[["TP-S1","UG-S1","nbGoldForms"]]
# Out:
#                    TP-S1  UG-S1  nbGoldForms
# 00-T10000-F3663     8505  45354        53859
# 01-T20000-F5816    16950  59685        76635
# 02-T30000-F7497    24618  65064        89682
# 03-T40000-F8900    31318  68324        99642
# 04-T50000-F10082   36322  72396       108718
# 05-T60000-F11252   41305  73543       114848
# 06-T70000-F12207   44658  74765       119424
# 07-T80000-F13155   48145  75984       124130
# 08-T90000-F14038   50839  76879       127719
# 09-T100000-F14858  53821  77431       131253

# %%
df=pd.merge(msp1,msp2, left_index=True, right_index=True)
df=pd.merge(df,omp1, left_index=True, right_index=True)
df=pd.merge(df,omp2, left_index=True, right_index=True)

# %%
df.index
# Out:
# Index([], dtype='object')

# %%
#.str[-1].str.strip("F").astype(int)
df["tokens"]=df.index.str.split("-").str[1].str.strip("T").astype(int)
df[["tokens","forms"]]
# Out:
# ----------------------------------------------------------------
# AttributeError                 Traceback (most recent call last)
# <ipython-input-31-09ab88508cdd> in <module>()
# ----> 1 df["forms"]=df.index.str.split("-").str[-1].str.strip("F").astype(int)
#       2 df["tokens"]=df.index.str.split("-").str[1].str.strip("T").astype(int)
#       3 df[["tokens","forms"]]
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/base.pyc in __get__(self, instance, owner)
#     231             # this ensures that Series.str.<method> is well defined
#     232             return self.accessor_cls
# --> 233         return self.construct_accessor(instance)
#     234
#     235     def __set__(self, instance, value):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/strings.pyc in _make_str_accessor(self)
#    1813                            "(i.e. inferred_type is 'string', 'unicode' or "
#    1814                            "'mixed')")
# -> 1815                 raise AttributeError(message)
#    1816             if self.nlevels > 1:
#    1817                 message = ("Can only use .str accessor with Index, not "
#
# AttributeError: Can only use .str accessor with string values (i.e. inferred_type is 'string', 'unicode' or 'mixed')

# %%
df[["FP-S1","TP-S1","UG-S1","OG-S1","FP-M1","TP-M1","UG-M1","OG-M1"]]
# Out:
#                    FP-S1  TP-S1  UG-S1  OG-S1  FP-M1  TP-M1  UG-M1  OG-M1
# 00-T10000-F3663      495   8505  53031    123   5175  15215  46321    186
# 01-T20000-F5816      716  16950  66704    262   7630  32171  51483    482
# 02-T30000-F7497      682  24618  71150    401   3961  39240  57195    563
# 03-T40000-F8900      903  31318  75125    518   3089  46855  60660    623
# 04-T50000-F10082    1090  36322  77240    562   4960  54525  60326    733
# 05-T60000-F11252    1023  41305  78687    699   3753  57484  63993    784
# 06-T70000-F12207    1043  44658  80135    743   3826  63597  62882    829
# 07-T80000-F13155    1044  48145  81586    813   7821  69467  62093    968
# 08-T90000-F14038    1244  50839  82663    912   4300  70096  65397   1022
# 09-T100000-F14858   1177  53821  83391    949   4341  75171  64232   1077

# %%
df.set_index("forms")[["Precision-S1","Precision-S2","Recall-S1","Recall-S2"]].plot(figsize=(20,10))

# %%
df.set_index("forms")[["Precision-M1","Precision-M2","Recall-M1","Recall-M2"]].plot(figsize=(20,10))

# %%
df.set_index("forms")[["Precision-S1","Precision-S2","Precision-M1","Precision-M2"]].plot(figsize=(20,10))

# %%
df.set_index("forms")[["Recall-S1","Recall-S2","Recall-M1","Recall-M2"]].plot(figsize=(20,10))

# %%
df.set_index("forms")[["Precision-S1","Precision-M2","Recall-S1","Recall-M2"]].plot(figsize=(20,10))

# %%
df.set_index("forms")[["F-Measure-S1","F-Measure-S2","F-Measure-M1","F-Measure-M2"]].plot(figsize=(20,10))

# %% [markdown]
# # Test Notifications

# %%
import requests
from datetime import datetime, timezone, timedelta

# %% [raw]
# message="Tâche terminée"
# params={"user":"10217754","pass":"dSzBYyPrv7Fy10","msg":message}
# urlBase="https://smsapi.free-mobile.fr/sendmsg"
# r=requests.get(urlBase,params=params)

# %%
tz = timezone(timedelta(seconds=7200))

# %%
today=datetime.now(tz)
print(today)
# Out:
# 2025-05-18 09:25:18.807178+02:00

# %%
sThen="2025-05-17 21:00:05-07:00"
then=datetime.strptime(sThen,"%Y-%m-%d %H:%M:%S%z")
print(then)
print(then.astimezone(tz))
# Out:
# 2025-05-17 21:00:05-07:00
# 2025-05-18 06:00:05+02:00

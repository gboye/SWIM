# %% [markdown]
# ## Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle,yaml
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False

# %% [markdown]
# ### Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')

# %%
rep="/Users/gilles/ownCloud/Recherche/Boye/HDR/Data/Longitudinales/"
sample="Longitudinal-55-T1100000-F41134-X-"
fPMS="paradigmes.csv"
fPMO="Morphomes-paradigmes.csv"
fRulesPMS="Regles.pkl"
fRulesPMO="Morphomes-Regles.pkl"

# %% [markdown]
# ### Préparation des cases du paradigme

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %% [markdown]
# # Préparation du calcul des analogies

# %% [markdown]
# ### Calcul de la différence entre deux formes

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

# %% [markdown]
# ### Accumulation des paires appartenant à un patron

# %%
def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %% [markdown]
# ### Transformation d'un patron en RegExp

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %% [markdown]
# ### Substitution de sortie
# ???

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print minLongueur, maxLongueur
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print phonemes
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print forme1,forme2,patron
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print patron12,patron21
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print "patron1", patron
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print "patron2", patron
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# # Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print "le numéro de forme n'est pas dans [1,2]",n

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme,contextFree=False):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if contextFree:
                filterF1=".*"+patron.split("-")[0]+"$"
            else:
                filterF1=self.patrons[patron]
            if re.match(filterF1,forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if contextFree:
                nbClasse=self.nbClasseCF
                classe=self.classeCF
            else:
                nbClasse=self.nbClasse
                classe=self.classe
            if idClasseForme in nbClasse:
                nTotal=nbClasse[idClasseForme]
                for patron in classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(classe[idClasseForme][patron])/nTotal
            else:
#                if debug: 
#                    print (forme, file=logfile)
#                    print ("pas de classe",idClasseForme, file=logfile)
#                    print ("%.2f par forme de sortie" % (float(1)/len(classeForme)), file=logfile)
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
#        else:
#            if debug:
#                print (forme, file=logfile) 
#                print ("pas de patron", file=logfile)
        return sortieForme

# %% [markdown]
# ## Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ### Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %%
paradigmesPMS=pd.read_csv(rep+sample+fPMS,sep=";",encoding="utf8")
del paradigmesPMS[u"Unnamed: 0"]

# %%
with open(rep+sample+fRulesPMS, 'rb') as input:
    rulesPMS = pickle.load(input)
with open(rep+sample+fRulesPMO, 'rb') as input:
    rulesPMO = pickle.load(input)

# %%
def generateForms(lexeme,paradigmes):
    for forme in listeCases:
        if not pd.isnull(paradigmes[paradigmes["lexeme"]==lexeme][forme].iloc[0]):
            depart=paradigmes[paradigmes["lexeme"]==lexeme][forme].iloc[0]
            print forme,depart
            if depart!="nan":
                for case in listeCases:
                    print case,
                    if not isinstance(resultatsLecture[(forme, case)],str):
                        print resultatsLecture[(forme, case)].sortirForme(depart),
                print
                print

# %%
#generateForms(u"lever",paradigmes)

# %%
def showPatterns(listePaires,rules=rulesPMS):
    for resultat in listePaires:
        print "paire :",resultat
        for element in rules[resultat].patrons:
            print "\t"+element, rules[resultat].patrons[element]
        print

# %%
listePaires=[("inf","ppMP")]
showPatterns(listePaires,rules=rulesPMS)
# Out:
# paire : ('inf', 'ppMP')
# 	Etr-i ^(.*)mEtr$
# 	dr-zy ^kudr$
# 	rir-Er ^(.*)uvrir$
# 	- ^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOoêûâô][ptkbdgfsSvzZmnJjlrwHE96Oêûô])e$
# 	u.ir-O. ^murir$
# 	ivr-Eky ^vivr$
# 	war-i ^aswar$
# 	r-y ^(.*[ptbdfsvzrE96O][jrwHiyEe926auOoêûâô][ptkbdg])r$
# 	avwar-y ^(.*)avwar$
# 	6vwar-y ^(.*[tdsz])6vwar$
# 	Etr-y ^(.*)kOnEtr$
# 	dr- ^(.*[ptkbdgjwH])êdr$
# 	âdr-i ^(.*)prâdr$
# 	Etr-e ^nEtr$
# 	war-y ^(.*[fsSvzZlr])war$
# 	r- ^(.*[ptkbdgfsSvzZmnJjlrwH][iEe])r$
# 	Erir-i ^(.*[E96aOêûâô])kErir$
# 	r-i ^(.*)sHivr$
# 	uvwar-y ^Emuvwar$
# 	ir-y ^(.*[ptbdfsvzmnlr])ir$

# %%
#paradigmes[paradigmes["lexeme"]==u"cuire"].stack().value_counts(dropna=True).sum()
#paradigmes[paradigmes["lexeme"]==u"dépendre"].stack()

# %%
"""
A dictionary difference calculator
Originally posted as:
http://stackoverflow.com/questions/1165352/fast-comparison-between-two-python-dictionary/1165552#1165552
"""


class DictDiffer(object):
    # TODO: on changed() avoid returning duplicate keys.
    # TODO:
    """
        Compares two dictionaries, traversing nested dictionaries,
        and provides four simple methods to access the differences between them:
            changed(), removed(), added(), unchanged()
         All four methods return a tuple of tuples of keys.
         When a given key is a nested one, it returns a tuple containing
         all the keys in the path to that key. For instance, given the sample above,
         the second "b" dict bellow contains the new "y" key under "x" and this in turn under "c",
         so it returns on tuple: ('c', ('x', 'y'))
    """

    def __init__(self, current_dict, past_dict):
        self._added,self._removed,self._changed,self._unchanged = self.diff_dicts(current_dict, past_dict)

        for key in (self._changed + self._unchanged):
#            print key, current_dict[key], past_dict[key]
            if isinstance(current_dict[key], dict) and isinstance(past_dict[key], dict):
                self._extend( key, self.__class__(current_dict[key], past_dict[key]) )

    def diff_dicts(self, current_dict, past_dict):
        """
        This is the original functionality for simple (not nested) dicts:
            Compares current_dict and past_dict and returns
            (added, removed, changed, unchanged) keys
        """
        set_current, set_past = set(current_dict.keys()), set(past_dict.keys())
        intersect = set_current.intersection(set_past)
        added = list(set_current - intersect)
        removed = list(set_past - intersect)
        changed = list(o for o in intersect if past_dict[o] != current_dict[o])
        unchanged = list(o for o in intersect if past_dict[o] == current_dict[o])
        return added, removed, changed, unchanged

    def _extend(self, parent, diff):
        """
            Adds the given differences to the appropriate members.
            Used with nested dicts.
        """
        self._added += [tuple([parent, o]) for o in diff._added]
        self._removed += [tuple([parent, o]) for o in diff._removed]
        self._changed += [tuple([parent, o]) for o in diff._changed]
        self._unchanged += [tuple([parent, o]) for o in diff._unchanged]

    def added(self):
        return tuple(self._added)
    def removed(self):
        return tuple(self._removed)
    def changed(self):
        return tuple(self._changed)
    def unchanged(self):
        return tuple(self._unchanged)

# %%
def showDifference(listePaires,rules1=rulesPMS,rules2=rulesPMO):
    for resultat in listePaires:
        print "paire :",resultat
    #    print resultatsLecture[resultat].patrons
    #    for element in resultatsLecture[resultat].patrons:
    #        print "\t"+element, resultatsLecture[resultat].patrons[element]
    #    print
        test=DictDiffer(rules1[resultat].patrons,rules2[resultat].patrons)
        if test.added(): print "added",test.added()
        if test.removed():
            print "missing"
            for element in test.removed():
                print "\t"+element,rules2[resultat].patrons[element]
            print "classe"
            print "\t"+element,rules2[resultat].classe
        if test.changed():
            print "overspecified"
            for element in test.changed():
                print "\t"+element,rules2[resultat].patrons[element]
                print "\t"+element,rules1[resultat].patrons[element]
                print
        if test.unchanged():
            print "optimal"
            print "\t"+element,rules2[resultat].patrons[element]

# %%
listePaires=[("inf","ppMP"),("pi1S","pi2S"),("pi2S","pi1P"),("pi2S","inf")]
showDifference(listePaires)
# Out:
# paire : ('inf', 'ppMP')
# missing
# 	udr-Oly ^rEzudr$
# 	Er-y ^dEplEr$
# 	Or-o ^klOr$
# 	r-e ^Etr$
# classe
# 	r-e {u'Etr-i': {u'Etr-i': 8}, u'Etr-e': {u'Etr-e': 1}, u'Etr-y': {u'Etr-y': 2}, u'war-i, war-y': {u'war-i': 1}, '-': {'-': 877}, u'6vwar-y, war-y': {u'6vwar-y': 7}, u'dr-': {u'dr-': 2}, u'\xe2dr-i, r-y': {u'\xe2dr-i': 7}, u'Etr-i, Etr-y': {u'Etr-i': 1}, u'Or-o': {u'Or-o': 1}, u'ir-y, r-, u.ir-O.': {u'u.ir-O.': 1}, u'ir-y, r-': {u'r-': 62, u'ir-y': 23}, u'ir-y, r-, Erir-i': {u'Erir-i': 2}, u'Etr-y, r-y': {u'Etr-y': 4}, u'r-y': {u'r-y': 31}, u'r-e': {u'r-e': 1}, u'ir-y, r-, rir-Er': {u'rir-Er': 6}, u'r-i': {u'r-i': 2}, u'dr-, r-y': {u'dr-': 5}, u'dr-zy': {u'dr-zy': 1}, u'ivr-Eky': {u'ivr-Eky': 2}, u'Er-y, r-': {u'Er-y': 1}, u'war-y': {u'war-y': 11}, u'uvwar-y, war-y': {u'uvwar-y': 2}, u'r-': {u'r-': 43}, u'r-y, udr-Oly': {u'udr-Oly': 1}, u'avwar-y, war-y': {u'avwar-y': 2}}
# overspecified
# 	rir-Er ^(.*[uOo][fv])rir$
# 	rir-Er ^(.*)uvrir$
#
# 	ivr-Eky ^(.*)vivr$
# 	ivr-Eky ^vivr$
#
# 	Etr-y ^(.*[pk][E96aO][mnr])Etr$
# 	Etr-y ^(.*)kOnEtr$
#
# 	6vwar-y ^(.*[tdszl])6vwar$
# 	6vwar-y ^(.*[tdsz])6vwar$
#
# 	dr- ^(.*[ptkbdgfsSvzZjlrwH])êdr$
# 	dr- ^(.*[ptkbdgjwH])êdr$
#
# 	war-y ^(.*[ptkbdgfsSvzZlr])war$
# 	war-y ^(.*[fsSvzZlr])war$
#
# 	r- ^(.*[ptkbdgfsSvzZmnJjlrwHE96aOêûâô][iyEe92])r$
# 	r- ^(.*[ptkbdgfsSvzZmnJjlrwH][iEe])r$
#
# 	uvwar-y ^(.*[pbm])uvwar$
# 	uvwar-y ^Emuvwar$
#
# optimal
# 	uvwar-y ^(.*[pbm])uvwar$
# paire : ('pi1S', 'pi2S')
# overspecified
# 	-j ^(.*[ptfs])E$
# 	-j ^pE$
#
# optimal
# 	-j ^(.*[ptfs])E$
# paire : ('pi2S', 'pi1P')
# overspecified
# 	ê-EJô ^([kgjE6a][ptbdfsvzr])ê$
# 	ê-EJô ^krê$
#
# 	E.-6.ô ^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])$
# 	E.-6.ô ^(.*[ptbdmnl])E([bdvzmnl])$
#
# 	o.-O.ô ^(.*[fsSvzZjriEe6][fsSvzZjrwHiyEe926uOo])poz$
# 	o.-O.ô ^(.*[fsvzr][y92uOo])poz$
#
# 	i-jô ^(.*[mrE6ê][jriEe6a][fsvzr])i$
# 	i-jô ^(.*[mr])E([fs])i$
#
# 	-sô ^(.*[jrwHiyEe926auOoêûâô][tdsSzZn][iEe])$
# 	-sô ^(.*[iyEe926auOo][dzZn][iEe])$
#
# optimal
# 	-sô ^(.*[jrwHiyEe926auOoêûâô][tdsSzZn][iEe])$
# paire : ('pi2S', 'inf')
# missing
# 	2-6vwar ^pl2$
# 	e-Ee ^kre$
# 	2.-6.e ^kr2z$
# 	9.-6.ir ^(.*)k9j$
# 	9..-6..e ^av9gl$
# 	-kr ^vê$
# 	-jir ^bu$
# classe
# 	-jir {u'-dr, j\xea-6nir': {u'j\xea-6nir': 17}, u'-dr, -tr, -we': {u'-tr': 1, u'-dr': 1, u'-we': 4}, u'-dr, -kr': {u'-kr': 1}, u'E.-6.e, -e': {u'-e': 41, u'E.-6.e': 24}, u'-dr, -je, -vr, -tr, -r': {u'-je': 3, u'-vr': 2, u'-r': 17}, u'-e, 2.-6.e': {u'2.-6.e': 1}, u'-e, 9.-6.e': {u'9.-6.e': 3}, u'-dr, -e, -tir': {u'-e': 40, u'-dr': 3, u'-tir': 2}, u'-dr, -je, -tr, -r': {u'-tr': 7, u'-je': 7, u'-r': 17}, u'-dr, -e': {u'-e': 50, u'-dr': 1}, u'-dr, -je, -vr, -tr, -r, i-je': {u'i-je': 1, u'-vr': 2}, u'-e': {u'-e': 561}, u'-dr, -tr, -we, -jir': {u'-jir': 1}, u'-dr, -e, -ir': {u'-e': 3, u'-ir': 2}, u'-e, o.-O.e': {u'o.-O.e': 25}, u'-tr, -r, i-je': {u'i-je': 1, u'-r': 5}, u'-He, -dr, -tr, -r': {u'-He': 9, u'-r': 3}, u'-dr, -e, -vir, -tir': {u'-e': 1, u'-vir': 1}, u'-He, -tr, -r': {u'-He': 3}, u'-dr, -je, -tr, -r, wa-6vwar': {u'-je': 2, u'wa-6vwar': 5, u'-r': 1}, u'-tr, -r': {u'-tr': 11, u'-r': 2}, u'-dr, -tr, o-alwar': {u'o-alwar': 2}, u'-dr, -tr, -r': {u'-r': 1}, u'-dr, -je, -tr, -r, e-Ee': {u'e-Ee': 1}, u'2-6vwar, -dr, -tr, -r': {u'2-6vwar': 1}, u'-tr, -r, 2-uvwar': {u'2-uvwar': 1}, u'-dr, -je, -tr, -r, E-avwar': {u'E-avwar': 1}, u'-dr, -e, -tir, -ir': {u'-e': 1, u'-ir': 5}, u'-e, -tir': {u'-e': 11, u'-tir': 2}, u'-dr, -je, -tr, -r, i-je': {u'i-je': 24, u'-r': 46, u'-je': 9}, u'-dr': {u'-dr': 12}, u'-dr, -tir': {u'-dr': 20, u'-tir': 3}, u'-dr, -tr, -r, 2-uvwar': {u'2-uvwar': 1}, u'-dr, -pr': {u'-pr': 1}, u'-dr, -e, -tir, -mir': {u'-e': 1, u'-mir': 2}, u'je-war, -dr, -je, -tr, -r': {u'je-war': 1}, u'-dr, -je, -tr, -r, va-ale': {u'va-ale': 1}, u'-tir': {u'-tir': 1}, u'-dr, -e, 9.-6.ir': {u'9.-6.ir': 3}, u'-dr, -e, 9.-u.ir, -tir, 9.-6.e': {u'9.-u.ir': 1}, u'-vwar, -tr': {u'-vwar': 1}, u'-e, 9..-6..e': {u'9..-6..e': 1}, u'-tr, -we': {u'-we': 1}, u'-dr, -e, -tir, 9.-6.e': {u'9.-6.e': 2}, u'-tr, E-air': {u'-tr': 1, u'E-air': 1}, u'-dr, 2-ulwar, -tr, -r': {u'2-ulwar': 1}}
# overspecified
# 	-He ^(.*[ptbdmnl])y$
# 	-He ^(.*[tdn])y$
#
# 	-vr ^(.*[vjH])i$
# 	-vr ^(.*)vi$
#
# 	-r ^(.*[ptkbdgfsSvzZmnJjlrwHE96aOêûâô][iyEe92a])$
# 	-r ^(.*[ptkbdgfsSvzZmnJjlrwHE96aOêûâô][iEea])$
#
# 	2-uvwar ^(.*[pbm])2$
# 	2-uvwar ^p2$
#
# 	o.-O.e ^(.*)o([ptkbdgfsSvzZlr])$
# 	o.-O.e ^(.*)o([ptbdfsvzl])$
#
# 	-dr ^(.*[ptkbdgfsSvzZjlrwHiyEe926uOo][jrwHiyEe926auOoêûâô])$
# 	-dr ^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOoêûâô])$
#
# 	i-je ^(.*[ptkbdgfsSvzZmnJlr])i$
# 	i-je ^(.*[ptkbdgfsSvzZmnJr])i$
#
# 	o-alwar ^([fv])o$
# 	o-alwar ^vo$
#
# 	-we ^(.*[ptkbdgfsSvzZmnJlr])u$
# 	-we ^Zu$
#
# 	9.-6.e ^(.*[bdgvzZmnJlr])9([mnlr])$
# 	9.-6.e ^(.*[pbE6][bdgvzZmnJlr])9([mnr])$
#
# 	-ir ^(.*[kgw6uOo][fvjrwHiyEe926uOo])r$
# 	-ir ^(.*[kgwu][vjrwHiyEe926uOo])r$
#
# optimal
# 	-ir ^(.*[kgw6uOo][fvjrwHiyEe926uOo])r$

# %%
cases=set([case for (case,autre) in rulesPMO.keys()])
systemes=[r+"-"+c for r in ["PMS","PMO"] for c in ["AC","SC"]]

# %%
def printSortie(paire,forme,rules,context=False):
    sorties=rules[paire].sortirForme(forme,contextFree=context)
    return [s+" : %2.2f"%sorties[s] for s in sorties]

# %%
paire=("fi2S","fi1P")
forme1=u"abâdOn6ra"

# %%
def printAlternatives(paire,forme1,lRules=systemes):
    if "PMS-AC" in lRules:
        print "PMS avec contexte\n\t",
        print "\n\t".join(printSortie(paire,forme1,rulesPMS,context=False))
    if "PMS-SC" in lRules:
        print "PMS sans contexte\n\t",
        print "\n\t".join(printSortie(paire,forme1,rulesPMS,context=True))
    if "PMO-AC" in lRules:
        print "PMO avec contexte\n\t",
        print "\n\t".join(printSortie(paire,forme1,rulesPMO,context=False))
    if "PMO-SC" in lRules:
        print "PMO sans contexte\n\t",
        print "\n\t".join(printSortie(paire,forme1,rulesPMO,context=True))

# %%
case1="ii1P"
forme1=u"mOrdjô"
paires=[(case1,c) for c in cases]
print forme1
for paire in paires:
    print paire
    printAlternatives(paire,forme1,lRules=["PMS-AC"])
# Out:
# mOrdjô
# ('ii1P', u'ii1P')
# PMS avec contexte
# 	mOrdjô : 1.00
# ('ii1P', u'pP')
# PMS avec contexte
# 	mOrdâ : 1.00
# ('ii1P', u'is1S')
# PMS avec contexte
#
# ('ii1P', u'ii1S')
# PMS avec contexte
# 	mOrdE : 1.00
# ('ii1P', u'ppMP')
# PMS avec contexte
# 	mOrdi : 0.33
# 	mOrdy : 0.33
# 	mOrde : 0.33
# ('ii1P', u'ai1P')
# PMS avec contexte
# 	mOrdim : 0.34
# 	mOrdam : 0.66
# ('ii1P', u'ai1S')
# PMS avec contexte
# 	mOrdi : 0.18
# 	mOrdE : 0.82
# ('ii1P', u'pc1S')
# PMS avec contexte
# 	mOrdirE : 0.24
# 	mOrd6rE : 0.52
# 	mOrdrE : 0.24
# ('ii1P', u'pi2S')
# PMS avec contexte
# 	mOr : 0.91
# 	mOrd : 0.09
# ('ii1P', u'inf')
# PMS avec contexte
# 	mOrdr : 0.14
# 	mOrde : 0.80
# 	mOrdir : 0.07
# ('ii1P', u'pi2P')
# PMS avec contexte
# 	mOrde : 1.00
# ('ii1P', u'ppFP')
# PMS avec contexte
# 	mOrdi : 0.29
# 	mOrde : 0.71
# ('ii1P', u'ps1P')
# PMS avec contexte
#
# ('ii1P', u'is2P')
# PMS avec contexte
#
# ('ii1P', u'ps1S')
# PMS avec contexte
# 	mOrd : 1.00
# ('ii1P', u'pI2S')
# PMS avec contexte
# 	mOrd : 1.00
# ('ii1P', u'fi2P')
# PMS avec contexte
# 	mOrdire : 0.22
# 	mOrd6re : 0.48
# 	mOrdre : 0.30
# ('ii1P', u'fi2S')
# PMS avec contexte
# 	mOrd6ra : 0.44
# 	mOrdra : 0.25
# 	mOrdira : 0.31
# ('ii1P', u'pI2P')
# PMS avec contexte
# 	mOrde : 1.00
# ('ii1P', u'ps2P')
# PMS avec contexte
# 	mOrdje : 1.00
# ('ii1P', u'ai2P')
# PMS avec contexte
#
# ('ii1P', u'ai2S')
# PMS avec contexte
# 	mOrda : 1.00
# ('ii1P', u'pc2P')
# PMS avec contexte
# 	mOrdirje : 0.33
# 	mOrd6rje : 0.67
# ('ii1P', u'ii2P')
# PMS avec contexte
# 	mOrdje : 1.00
# ('ii1P', u'pi1S')
# PMS avec contexte
# 	mOr : 0.77
# 	mOrd : 0.23
# ('ii1P', u'pi1P')
# PMS avec contexte
# 	mOrdô : 1.00
# ('ii1P', u'pi3P')
# PMS avec contexte
# 	mOrd : 1.00
# ('ii1P', u'pc1P')
# PMS avec contexte
# 	mOrd6rjô : 1.00
# ('ii1P', u'is1P')
# PMS avec contexte
#
# ('ii1P', u'ai3P')
# PMS avec contexte
# 	mOrdir : 0.18
# 	mOrdEr : 0.82
# ('ii1P', u'fi1P')
# PMS avec contexte
# 	mOrdirô : 0.26
# 	mOrdrô : 0.21
# 	mOrd6rô : 0.53
# ('ii1P', u'fi1S')
# PMS avec contexte
# 	mOrdirE : 0.21
# 	mOrd6rE : 0.58
# 	mOrdrE : 0.21
# ('ii1P', u'pI1P')
# PMS avec contexte
# 	mOrdô : 1.00

# %%
def sousPaires(liste):
    for i in range(0, len(liste)-1):
        yield(liste[i],liste[i+1])

# %%
listePaires=list(sousPaires(list(cases)))
print listePaires+[(u'pI1P',u'ii1P')]
# Out:
# [(u'ii1P', u'pP'), (u'pP', u'is1S'), (u'is1S', u'ii1S'), (u'ii1S', u'ppMP'), (u'ppMP', u'ai1P'), (u'ai1P', u'ai1S'), (u'ai1S', u'pc1S'), (u'pc1S', u'pi2S'), (u'pi2S', u'inf'), (u'inf', u'pi2P'), (u'pi2P', u'ppFP'), (u'ppFP', u'ps1P'), (u'ps1P', u'is2P'), (u'is2P', u'ps1S'), (u'ps1S', u'pI2S'), (u'pI2S', u'fi2P'), (u'fi2P', u'fi2S'), (u'fi2S', u'pI2P'), (u'pI2P', u'ps2P'), (u'ps2P', u'ai2P'), (u'ai2P', u'ai2S'), (u'ai2S', u'pc2P'), (u'pc2P', u'ii2P'), (u'ii2P', u'pi1S'), (u'pi1S', u'pi1P'), (u'pi1P', u'pi3P'), (u'pi3P', u'pc1P'), (u'pc1P', u'is1P'), (u'is1P', u'ai3P'), (u'ai3P', u'fi1P'), (u'fi1P', u'fi1S'), (u'fi1S', u'pI1P'), (u'pI1P', u'ii1P')]

# %%
transformations={}
for paire in listePaires:
    transformations[paire]=rulesPMS[paire].patrons

# %%
transformations
# Out:
# {(u'ai1P',
#   u'ai1S'): {u'am-E': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwH])am$', u'm-': u'^(.*[iyEe92\xea\xfb])m$'},
#  (u'ai1S', u'pc1S'): {u'-rE': u'^(.*[ptbdfsvzmnrE6a\xea\xe2])i$',
#   u'6.E-E.6rE': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])E$',
#   u'E-6rE': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])E$',
#   u'E-rE': u'^krEE$',
#   u'EJi-\xeadrE': u'^(.*[pt])EJi$',
#   u'Eky-ivrE': u'^syrvEky$',
#   u'H.-r.': u'^(.*[tdn])yHE$',
#   u'aJi-\xeadrE': u'^(.*)ZwaJi$',
#   u'al.-ir.': u'^alE$',
#   u'fy-s6rE': u'^fy$',
#   u'i-6rE': u'^(.*)fi$',
#   u'i-ErE': u'^vi$',
#   u'i-EtrE': u'^(.*)mi$',
#   u'i-jErE': u'^asi$',
#   u'i-rE': u'^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvz])i$',
#   u'i-\xe2drE': u'^(.*)pri$',
#   u'j.-r.': u'^(.*[ptkbdgfsSvzZjlrwH][iEe])jE$',
#   u'jE-irE': u'^(.*[ptbdfsvzmnr])jE$',
#   u'ly-drE': u'^vuly$',
#   u'vi-rE': u'^(.*)Ekrivi$',
#   u'w.-r.': u'^ZuwE$',
#   u'wajE-ErE': u'^\xe2vwajE$',
#   u'y-6vrE': u'^(.*[tdsz])y$',
#   u'y-ErE': u'^ply$',
#   u'y-EtrE': u'^(.*[pk][E96aO][mnr])y$',
#   u'y-OrE': u'^(.*)y$',
#   u'y-irE': u'^(.*)ly$',
#   u'y-rE': u'^([pkbgmJ])ury$',
#   u'y-warE': u'^(.*[bvr])y$',
#   u'zi-rE': u'^([td][rE6][ptbdEa][bdvzr])Hizi$',
#   u'\xea-j\xeadrE': u'^(.*[ptbdfsvz])\xea$'},
#  (u'ai2P', u'ai2S'): {u't-': u'^(.*[fs][iyEe92a])t$'},
#  (u'ai2S', u'pc2P'): {u'-rje': u'^([ptfs][E96aO])rti$',
#   u'a-6rje': u'^(.*[ptbdmn][E96aO\xea\xfb\xe2\xf4][tdsSzZn])a$',
#   u'fy-s6rje': u'^fy$',
#   u'i-6rje': u'^fi$',
#   u'i-Erje': u'^vi$',
#   u'i-\xe2drije': u'^(.*)pri$',
#   u'y-6vrije': u'^r6sy$',
#   u'y-Erje': u'^ply$',
#   u'y-Etrije': u'^kOny$',
#   u'y-urje': u'^py$',
#   u'y-warje': u'^kry$',
#   u'\xea-j\xeadrije': u'^v\xea$'},
#  (u'ai3P',
#   u'fi1P'): {u'-\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])ir$', u'6.E.-E.6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])Er$', u'E.-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])Er$', u'EJir-\xeadr\xf4': u'^([Ea])tEJir$', u'Ekyr-ivr\xf4': u'^vEkyr$', u'HEr-r\xf4': u'^(.*[tdnl])yHEr$', u'aJir-\xeadr\xf4': u'^r6ZwaJir$', u'alEr-ir\xf4': u'^alEr$', u'fy.-s6.\xf4': u'^fyr$', u'i.-6.\xf4': u'^(.*[fvj])ir$', u'i.-E.\xf4': u'^r6vir$', u'ir-Etr\xf4': u'^mir$', u'ir-r\xf4': u'^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvz])ir$', u'ir-\xe2dr\xf4': u'^(.*)prir$', u'jEr-ir\xf4': u'^(.*[mrE6\xea][jriEe6a][fsvzr])jEr$', u'jEr-r\xf4': u'^(.*[ptbdfsvzlr][iEe])jEr$', u'lyr-dr\xf4': u'^vulyr$', u'wEr-r\xf4': u'^ZuwEr$', u'wajEr-Er\xf4': u'^\xe2vwajEr$', u'y.-O.\xf4': u'^(.*)yr$', u'y.-u.\xf4': u'^pyr$', u'yr-6vr\xf4': u'^(.*[tdsz])yr$', u'yr-Etr\xf4': u'^(.*[pk][E96aO][mnr])yr$', u'yr-r\xf4': u'^muryr$', u'yr-war\xf4': u'^(.*[bvr])yr$', u'zir-r\xf4': u'^(.*[kgjrE6][ptbdmnE96O\xea\xfb\xf4][bdvzr])Hizir$', u'\xear-j\xeadr\xf4': u'^(.*[ptbdfsvz])\xear$'},
#  (u'fi1P', u'fi1S'): {u'j6r\xf4-rE': u'^(.*[ptfs])Ej6r\xf4$',
#   u'r\xf4-j6rE': u'^(.*[ptfs])Er\xf4$',
#   u'\xf4-E': u'^(.*[ptkbdgfsSvzZjrwHiyEe926auOo])r\xf4$'},
#  (u'fi1S', u'pI1P'): {u'6rE-waj\xf4': u'^s6rE$',
#   u'6rE-\xf4': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])6rE$',
#   u'E.6rE-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])6rE$',
#   u'ErE-waj\xf4': u'^vErE$',
#   u'OrE-Ej\xf4': u'^OrE$',
#   u'OrE-aS\xf4': u'^sOrE$',
#   u'drE-l\xf4': u'^vudrE$',
#   u'irE-al\xf4': u'^irE$',
#   u'irE-j\xf4': u'^r6mErsirE$',
#   u'irE-\xf4': u'^(.*[fsvzrE96aO][fvrE6a\xea\xe2][ptbdfsvzr])irE$',
#   u'jErE-Ej\xf4': u'^asjErE$',
#   u'j\xeadrE-6n\xf4': u'^(.*[ptbdfsvz])j\xeadrE$',
#   u'rE-j\xf4': u'^(.*[ptkbdgfsSvzZjrwH][Ea])rE$',
#   u'rE-s\xf4': u'^(.*[iEea][dzZn])irE$',
#   u'rE-z\xf4': u'^([ptbdfsvz][iEe6])rE$',
#   u'rE-\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZjrwHiyEe926uOo])rE$',
#   u'trE-s\xf4': u'^(.*[pk][E96aO][mnr])EtrE$',
#   u'warE-Ej\xf4': u'^aswarE$',
#   u'warE-yv\xf4': u'^bwarE$',
#   u'\xe2drE-6n\xf4': u'^(.*)pr\xe2drE$'},
#  (u'fi2P', u'fi2S'): {u'e-a': u'^(.*[ptkbdgfsSvzZjrwHiyEe926auOo])re$',
#   u'j6re-ra': u'^pEj6re$',
#   u're-j6ra': u'^pEre$'},
#  (u'fi2S', u'pI2P'): {u'6ra-Et': u'^f6ra$',
#   u'6ra-e': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])6ra$',
#   u'6ra-waje': u'^s6ra$',
#   u'E.6ra-6.e': u'^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])6ra$',
#   u'Era-waje': u'^(.*)vEra$',
#   u'Ora-Eje': u'^Ora$',
#   u'Ora-aSe': u'^sOra$',
#   u'dra-le': u'^vudra$',
#   u'ira-ale': u'^ira$',
#   u'ira-e': u'^(.*[fsSvzZjrwHiyEe926auOo][fvrE6a\xea\xe2][ptbdfsvzmnr])ira$',
#   u'ira-je': u'^(.*[fsvzr])ira$',
#   u'j\xeadra-6ne': u'^(.*[ptbdfsvz])j\xeadra$',
#   u'ra-He': u'^(.*[tdnl])yra$',
#   u'ra-e': u'^(.*[ptkbdgfsSvzZmnJjrwHE96O\xea\xfb\xf4][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvzr])ra$',
#   u'ra-je': u'^(.*[ptkbdgfsSvzZjlrwH][iEea])ra$',
#   u'ra-se': u'^(.*[bjHiyEe92a][ptkbdgfsSvzZmnJjrE6\xea])ira$',
#   u'ra-t': u'^dira$',
#   u'ra-ve': u'^Ekrira$',
#   u'ra-we': u'^(.*[fsSvzZ])ura$',
#   u'ra-ze': u'^(.*[jlH])ira$',
#   u'tra-se': u'^(.*)kOnEtra$',
#   u'udra-6je': u'^vudra$',
#   u'wara-yve': u'^bwara$',
#   u'\xe2dra-6ne': u'^(.*)pr\xe2dra$',
#   u'\xeadra-EJe': u'^(.*[ptbdfsvzr])\xeadra$'},
#  (u'ii1P', u'pP'): {u'avj\xf4-Ej\xe2': u'^avj\xf4$',
#   u'ij\xf4-j\xe2': u'^(.*[fsvzr])ij\xf4$',
#   u'ij\xf4-\xe2': u'^(.*[fsSvzZjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZ][lr])ij\xf4$',
#   u'i\xf4-\xe2': u'^(.*[uOo][fv])ri\xf4$',
#   u'j\xf4-\xe2': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4])j\xf4$',
#   u'vj\xf4-S\xe2': u'^savj\xf4$',
#   u'\xf4-\xe2': u'^(.*[ptkbdgfsSvzZjlrwH][iEea][Jj])\xf4$'},
#  (u'ii1S', u'ppMP'): {u'6nE-i': u'^(.*)pr6nE$',
#   u'6vE-y': u'^(.*[tdsz])6vE$',
#   u'6zE-E': u'^(.*)f6zE$',
#   u'E-e': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHE96O\xea\xfb\xf4])E$',
#   u'E-i': u'^(.*[ptkbdgfsSvzZjrwHE96aO][jriEe6a\xea\xe2][ptbdfsvzmnj])E$',
#   u'E-y': u'^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvzmnlr])E$',
#   u'EJE-\xea': u'^(.*[ptbdfsvzr])EJE$',
#   u'EjE-i': u'^(.*)asEjE$',
#   u'ErE-i': u'^akErE$',
#   u'EsE-y': u'^(.*[pk][E96aO][mnr])EsE$',
#   u'EtE-i': u'^(.*)mEtE$',
#   u'EzE-y': u'^tEzE$',
#   u'HE-': u'^([kgjE6][fsvzrE96O\xea\xfb\xf4])klyHE$',
#   u'aJE-\xea': u'^r6ZwaJE$',
#   u'avE-y': u'^(.*)avE$',
#   u'ivE-Eky': u'^vivE$',
#   u'izE-y': u'^(.*)lizE$',
#   u'jE-': u'^(.*[ptfs][jrwH][iEe])jE$',
#   u'rE-Er': u'^(.*[uOo][fv])rE$',
#   u'sE-': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])isE$',
#   u'u.E-O.': u'^murE$',
#   u'uvE-y': u'^EmuvE$',
#   u'vE-': u'^(.*[bvr][iy])vE$',
#   u'vE-y': u'^rEzOlvE$',
#   u'wajE-y': u'^(.*[vr])wajE$',
#   u'zE-': u'^(.*[bdjH])izE$'},
#  (u'ii2P', u'pi1S'): {u'6.je-9.': u'^(.*[pbE6][mnl])6rje$',
#   u'6.je-E.': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])je$',
#   u'6nje-j\xea': u'^(.*[ptbdfsvz])6nje$',
#   u'6nje-\xe2': u'^(.*)pr6nje$',
#   u'6vje-wa': u'^(.*[tdsz])6vje$',
#   u'6zje-E': u'^f6zje$',
#   u'EJe-\xea': u'^krEJe$',
#   u'Eje-je': u'^asEje$',
#   u'Eje-wa': u'^asEje$',
#   u'Etje-sHi': u'^Etje$',
#   u'O.je-o.': u'^(.*)O([ptbdfsvzl])je$',
#   u'aisje-E': u'^aisje$',
#   u'alje-o': u'^valje$',
#   u'alje-vE': u'^alje$',
#   u'avje-E': u'^(.*)avje$',
#   u'dje-': u'^(.*[ptbdfsvzrE6][r6O\xe2\xf4])dje$',
#   u'e-': u'^(.*[ptkbdgfsSvzZ][iyEe92a][Jj])e$',
#   u'ije-': u'^(.*[iyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZ][lr])ije$',
#   u'je-': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4])je$',
#   u'mje-': u'^(.*)dOrmje$',
#   u'sje-': u'^(.*[bgvjrwHiyEe926auOo][ptkbdgfsSvzZmnJjrE6a\xea\xe2][iEe])sje$',
#   u'tje-': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][rE6a\xea\xe2])tje$',
#   u'u.je-9.': u'^murje$',
#   u'ulje-2': u'^vulje$',
#   u'uvje-2': u'^puvje$',
#   u'vje-': u'^(.*[vjrwH])ivje$',
#   u'yvje-wa': u'^byvje$',
#   u'zje-': u'^(.*[ptkbdgfsSvzZjlrwH][iyEe926uOo])zje$'},
#  (u'inf',
#   u'pi2P'): {'-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHE96O\xea\xfb\xf4])e$', u'ir-e': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][fvjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjr])ir$', u'ir-je': u'^(.*)rir$', u'r-': u'^Etr$', u'r-He': u'^k\xf4klyr$', u'r-e': u'^(.*[ptkbdgfsSvzZmnJjrwHE96O\xea\xfb\xf4][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZ])r$', u'r-je': u'^(.*[fsvzr][wH][iEea])r$', u'r-se': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])ir$', u'r-t': u'^(.*[ptbdfsvz][iEe])r$', u'r-ve': u'^(.*[fsvzE])krir$', u'r-ze': u'^(.*[ptbdfsvzjlH][iEe])r$', u'tr-se': u'^(.*[pk][E96aO][mnr])Etr$', u'udr-Olve': u'^rEzudr$', u'war-Eje': u'^aswar$', u'war-e': u'^(.*[iyEe926auOo][vzl])war$', u'war-yve': u'^bwar$', u'wir-Oje': u'^wir$', u'\xe2dr-6ne': u'^(.*)pr\xe2dr$', u'\xeadr-EJe': u'^(.*[ptbdfsvzlr])\xeadr$', u'\xeadr-aJe': u'^(.*)Zw\xeadr$'},
#  (u'is1P', u'ai3P'): {u'sj\xf4-r': u'^(.*[iy])sj\xf4$'},
#  (u'is1S',
#   u'ii1S'): {u'as-E': u'^(.*[tdsz][iyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])as$', u'fys-EtE': u'^fys$', u'is-6zE': u'^fis$', u'is-E': u'^(.*[ptbdfsvzrE6][jriEe6a\xea\xe2][ptbdfsvz])is$', u'ys-6vE': u'^dys$', u'ys-E': u'^vulys$', u'ys-EzE': u'^plys$', u'ys-avE': u'^ys$', u'ys-uvE': u'^pys$', u'\xeas-6nE': u'^v\xeas$'},
#  (u'is2P', u'ps1S'): {u'fysje-swa': u'^fysje$',
#   u'i.je-a.': u'^fisje$',
#   u'ysje-wav': u'^dysje$'},
#  (u'pI2P', u'ps2P'): {'-': u'^(.*[Ea])je$',
#   u'6je-ulje': u'^v6je$',
#   u'Et-asje': u'^fEt$',
#   u'e-ije': u'^r\xe2tre$',
#   u'e-je': u'^(.*[jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])e$',
#   u't-zje': u'^dit$'},
#  (u'pI2S',
#   u'fi2P'): {u'-6re': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])$', u'-dre': u'^(.*[ptkbdgfsSvzZjrwHE96O][rE96aO\xea\xfb\xe2\xf4])$', u'-ire': u'^(.*[uOo][fv])r$', u'-j6re': u'^pE$', u'-mire': u'^dOr$', u'-re': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][jrwHiyEe926auOo])$', u'-tire': u'^(.*[fsvzrE96aO][r6\xe2])$', u'-tre': u'^(.*[bdmn][Ea])$', u'-vire': u'^sEr$', u'-vre': u'^sHi$', u'9.-6.6re': u'^pl9r$', u'9.-u.re': u'^m9r$', u'9j-udre': u'^v9j$', u'E-6re': u'^fE$', u'E-Ore': u'^E$', u'E-aire': u'^E$', u'aS-Ore': u'^saS$', u'j-re': u'^EsEj$', u'o.-O.6re': u'^(.*)o([ptbdfsvz])$', u'va-ire': u'^va$', u'wa-6re': u'^swa$', u'wa-6vre': u'^(.*[tdsz])wa$', u'wa-Ere': u'^(.*)vwa$'},
#  (u'pP', u'is1S'): {u'6n\xe2-\xeas': u'^v6n\xe2$',
#   u'6v\xe2-ys': u'^d6v\xe2$',
#   u'6z\xe2-is': u'^f6z\xe2$',
#   u'Ej\xe2-ys': u'^Ej\xe2$',
#   u'Es\xe2-akis': u'^nEs\xe2$',
#   u'Et\xe2-fys': u'^Et\xe2$',
#   u'Ez\xe2-ys': u'^plEz\xe2$',
#   u'uv\xe2-ys': u'^puv\xe2$',
#   u'\xe2-as': u'^(.*[ptbdfsvz][iyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])\xe2$',
#   u'\xe2-is': u'^(.*[ptbdfsvzrE6][jriEe6a\xea\xe2][ptbdfsvz])\xe2$',
#   u'\xe2-ys': u'^vul\xe2$'},
#  (u'pc1P', u'is1P'): {u'6r..-is..': u'^f6rj\xf4$',
#   u'Or..-ys..': u'^Orj\xf4$',
#   u's6r..-fys..': u'^s6rj\xf4$'},
#  (u'pc1S', u'pi2S'): {u'6.6rE-9.': u'^(.*[bdgmnJl])6([lr])6rE$',
#   u'6rE-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])6rE$',
#   u'6rE-E': u'^(.*)f6rE$',
#   u'6vrE-wa': u'^(.*[tdsz])6vrE$',
#   u'ErE-e': u'^asjErE$',
#   u'ErE-wa': u'^(.*)vErE$',
#   u'O.6rE-o.': u'^(.*)O([ptbdfsvzl])6rE$',
#   u'OdrE-o': u'^vOdrE$',
#   u'OrE-E': u'^sOrE$',
#   u'OrE-a': u'^OrE$',
#   u'airE-E': u'^airE$',
#   u'drE-': u'^(.*[ptkbdgfsSvzZjlrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4])drE$',
#   u'irE-': u'^(.*[uOo][fv])rirE$',
#   u'irE-va': u'^irE$',
#   u'j6rE-': u'^(.*[ptfs])Ej6rE$',
#   u'jErE-wa': u'^asjErE$',
#   u'mirE-': u'^(.*)dOrmirE$',
#   u'prE-': u'^\xeatEr\xf4prE$',
#   u'rE-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][jrwHiyEe926auOo])rE$',
#   u'rE-j': u'^(.*[ptfs])ErE$',
#   u's6rE-E': u'^s6rE$',
#   u'tirE-': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][r6\xe2])tirE$',
#   u'trE-': u'^(.*[ptbdfsvzmnr][iyEe926auOo])trE$',
#   u'u.rE-9.': u'^murrE$',
#   u'udrE-2': u'^vudrE$',
#   u'urE-2': u'^purE$',
#   u'virE-': u'^sErvirE$',
#   u'vrE-': u'^(.*[vjH])ivrE$'},
#  (u'pc2P', u'ii2P'): {u'6rje-e': u'^(.*[bgv])a([Jj])6rje$',
#   u'6rje-ije': u'^r\xe2tr6rje$',
#   u'6rje-je': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])6rje$',
#   u'E.6rje-6.je': u'^(.*)a([pbm])E([nl])6rje$',
#   u'Er..-wa..': u'^vErje$',
#   u'Or..-av..': u'^(.*)Orje$',
#   u'drije-lje': u'^vudrije$',
#   u'ir..-al..': u'^irje$',
#   u'irje-je': u'^(.*[fsvzrE96aO][r6\xe2])tirje$',
#   u'j\xeadrije-6nje': u'^(.*[ptbdfsvz])j\xeadrije$',
#   u'r..-s..': u'^(.*[iEea][dzZn])irje$',
#   u'r..-v..': u'^(.*[pbfvr][iyu])rje$',
#   u'r..-z..': u'^(.*[ptbdfsvzl][iEe6])rje$',
#   u'rije-je': u'^(.*[ptbdfsvzrE6][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvz])rije$',
#   u'rje-je': u'^(.*[ptkbdgfsSvzZjrwHiyEe926uOo][jrwHiyEe926auOo])rje$',
#   u's6rje-Etje': u'^s6rje$',
#   u'trije-sje': u'^(.*)kOnEtrije$',
#   u'warje-yvje': u'^bwarje$',
#   u'\xe2drije-6nje': u'^(.*)pr\xe2drije$',
#   u'\xeadrije-EJe': u'^kr\xeadrije$'},
#  (u'pi1P', u'pi3P'): {u'6.\xf4-2.': u'^kr6z\xf4$',
#   u'6.\xf4-9.': u'^(.*[ptkbdgfsSvzZmnJlr])6([mnJjr])\xf4$',
#   u'6.\xf4-E.': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])\xf4$',
#   u'6n\xf4-jEn': u'^(.*[ptbdfsvz])6n\xf4$',
#   u'6v\xf4-wav': u'^(.*[tdsz])6v\xf4$',
#   u'6z\xf4-\xf4': u'^(.*)f6z\xf4$',
#   u'Ej\xf4-wa': u'^asEj\xf4$',
#   u'Er\xf4-jEr': u'^k\xf4kEr\xf4$',
#   u'E\xf4-e': u'^krE\xf4$',
#   u'O.\xf4-o.': u'^(.*)O([ptkbdgfsSvzZlr])\xf4$',
#   u'Om-\xf4': u'^sOm$',
#   u'al\xf4-v\xf4': u'^al\xf4$',
#   u'av\xf4-\xf4': u'^av\xf4$',
#   u'j\xf4-': u'^(.*[ptkbdgfsSvzZjrwH][iEea])j\xf4$',
#   u'j\xf4-i': u'^(.*[ptbdfsvzlr])j\xf4$',
#   u'u.\xf4-9.': u'^([pbfv])u([vzl])\xf4$',
#   u'waj\xf4-Ej': u'^aswaj\xf4$',
#   u'yv\xf4-wav': u'^byv\xf4$',
#   u'\xf4-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4])\xf4$'},
#  (u'pi1S', u'pi1P'): {u'-d\xf4': u'^(.*[ptbdfsvzrE6][r6O\xe2\xf4])$',
#   u'-j\xf4': u'^(.*[ptkbdgfsSvzZjrwH][iEea])$',
#   u'-m\xf4': u'^(.*)dOr$',
#   u'-p\xf4': u'^\xeatEr\xf4$',
#   u'-s\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96O\xea\xfb\xf4][iEe])$',
#   u'-t\xf4': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][jrwHiyEe926auOo\xea\xfb\xe2\xf4])$',
#   u'-v\xf4': u'^(.*[vjrwHE96O][jriEe6])$',
#   u'-z\xf4': u'^(.*[ptbdfsvzjlH][iEe])$',
#   u'-\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4])$',
#   u'2-ul\xf4': u'^v2$',
#   u'2-uv\xf4': u'^p2$',
#   u'2.-6.\xf4': u'^kr2z$',
#   u'9.-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])9([mnJjr])$',
#   u'E-6z\xf4': u'^(.*)fE$',
#   u'E-ais\xf4': u'^E$',
#   u'E-av\xf4': u'^(.*)E$',
#   u'E.-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])$',
#   u'Hi-Om': u'^sHi$',
#   u'e-E\xf4': u'^kre$',
#   u'i-j\xf4': u'^(.*[ptbdfsvzmnlr])i$',
#   u'jEr-Er\xf4': u'^k\xf4kjEr$',
#   u'je-Ej\xf4': u'^asje$',
#   u'je-waj\xf4': u'^asje$',
#   u'j\xea-6n\xf4': u'^(.*[ptbdfsvz])j\xea$',
#   u'o-al\xf4': u'^vo$',
#   u'o.-O.\xf4': u'^(.*)o([ptkbdgfsSvzZlr])$',
#   u'vE-al\xf4': u'^vE$',
#   u'wa-6v\xf4': u'^(.*[tdsz])wa$',
#   u'wa-Ej\xf4': u'^aswa$',
#   u'wa-yv\xf4': u'^bwa$',
#   u'\xe2-6n\xf4': u'^(.*)pr\xe2$',
#   u'\xea-EJ\xf4': u'^([pkbgjE6a][ptbdfsvzlr])\xea$',
#   u'\xea-aJ\xf4': u'^(.*)Zw\xea$'},
#  (u'pi2P',
#   u'ppFP'): {'-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4][ptbdEe])$', u'6ne-iz': u'^(.*)pr6ne$', u'6ve-y': u'^(.*[tdsz])6ve$', u'EJe-\xeat': u'^(.*[ptbdfsvzr])EJe$', u'Eje-iz': u'^asEje$', u'Ese-y': u'^(.*[pk][E96aO][mnr])Ese$', u'Ete-iz': u'^(.*)mEte$', u'He-': u'^k\xf4klyHe$', u'ave-y': u'^ave$', u'e-i': u'^(.*[ptkbdgfsSvzZjrwHE96aO][jriEe6a\xea\xe2][ptbdfsvzj])e$', u'e-y': u'^(.*[ptkbdgfsSvzZjrE6][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvzmnlr])e$', u'ive-Eky': u'^vive$', u'ize-y': u'^lize$', u'je-': u'^\xe2fHije$', u're-Ert': u'^(.*[uOo][fv])re$', u'se-': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])ise$', u'u.e-O.t': u'^mure$', u've-t': u'^(.*[fsvzE])krive$', u'waje-iz': u'^aswaje$', u'waje-y': u'^(.*)vwaje$', u'ze-t': u'^(.*[ptkbdgfsSvzZjrE6][ptbdmnE96aO\xea\xfb\xe2\xf4][bdvzr][bdjH])ize$'},
#  (u'pi2S', u'inf'): {u'-He': u'^(.*[ptbdfsvzmnlr])y$',
#   u'-dr': u'^(.*[ptkbdgfsSvzZjlrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4])$',
#   u'-e': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])$',
#   u'-ir': u'^(.*[kgw6uOo][fvjrwHiyEe926uOo])r$',
#   u'-je': u'^(.*[ptkbdgfsSvzZjlrwH][iEea])$',
#   u'-jir': u'^bu$',
#   u'-kr': u'^v\xea$',
#   u'-mir': u'^(.*)dOr$',
#   u'-pr': u'^(.*)r\xf4$',
#   u'-r': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4][iyEe92a])$',
#   u'-tir': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][r6\xe2])$',
#   u'-tr': u'^(.*[iyEe926auOo])$',
#   u'-vir': u'^(.*)sEr$',
#   u'-vr': u'^(.*[vjH])i$',
#   u'-vwar': u'^a$',
#   u'-we': u'^(.*[ptkbdgfsSvzZlr])u$',
#   u'2-ulwar': u'^v2$',
#   u'2-uvwar': u'^p2$',
#   u'2.-6.e': u'^(.*[Zr])2([dzn])$',
#   u'9.-6.e': u'^(.*[bdgvzZmnJlr])9([ptbdfsvzmnlr])$',
#   u'9.-6.ir': u'^(.*)k9j$',
#   u'9.-u.ir': u'^m9r$',
#   u'9..-6..e': u'^av9gl$',
#   u'E-air': u'^E$',
#   u'E-avwar': u'^sE$',
#   u'E.-6.e': u'^(.*[ptkbdgfsSvzZmnJjlr])E([ptbdfsvzmnl])$',
#   u'a-ir': u'^wa$',
#   u'e-Ee': u'^agre$',
#   u'i-je': u'^(.*[ptkbdgfsSvzZmnJlr])i$',
#   u'je-war': u'^asje$',
#   u'j\xea-6nir': u'^(.*[ptbdfsvz])j\xea$',
#   u'o-alwar': u'^vo$',
#   u'o.-O.e': u'^(.*)o([ptkbdgfsSvzZlr])$',
#   u'va-ale': u'^va$',
#   u'wa-6vwar': u'^(.*[tdsz])wa$'},
#  (u'pi3P',
#   u'pc1P'): {u'-6rj\xf4': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])$', u'-irj\xf4': u'^([ptfs][iyEe926auOo][fvr][ptbdfsvzr])$', u'-ri\xf4': u'^(.*[ptbdfsvzmnE\xea][jriEe6a\xea\xe2][ptbdfsvz])$', u'-rj\xf4': u'^(.*[ptkbdgjwHiyEe926uOo][jrwHiyEe926uOo])$', u'9.-6.6rj\xf4': u'^dEZ9n$', u'9.-u.rj\xf4': u'^m9r$', u'9l-udri\xf4': u'^v9l$', u'9v-urj\xf4': u'^p9v$', u'En-\xe2dri\xf4': u'^(.*)prEn$', u'En-\xeadri\xf4': u'^([bdvzr])6vjEn$', u'av-Orj\xf4': u'^sav$', u'j-rj\xf4': u'^pEj$', u'o.-O.6rj\xf4': u'^(.*[pk])oz$', u's-rj\xf4': u'^finis$', u's-tri\xf4': u'^kOnEs$', u'v-rj\xf4': u'^bwav$', u'v\xf4-irj\xf4': u'^v\xf4$', u'wa-Erj\xf4': u'^(.*)vwa$', u'wav-6vri\xf4': u'^dwav$', u'z-rj\xf4': u'^([td][iEe])z$', u'\xf4-6rj\xf4': u'^([fs])\xf4$', u'\xf4-Orj\xf4': u'^\xf4$'},
#  (u'ppFP', u'ps1P'): {u'Et-asj\xf4': u'^fEt$',
#   u'e-j\xf4': u'^(.*[ptkbdgfsSvzZjrE6][kgjwHiyEe926auOo][ptbdfsvz])e$',
#   u'i-j\xf4': u'^s\xe2ti$',
#   u'y-j\xf4': u'^vuly$'},
#  (u'ppMP', u'ai1P'): {u'-m': u'^(.*[iy])$',
#   u'6ny-\xeam': u'^(.*[ptkbdgjE6a][r6O\xf4])v6ny$',
#   u'E-im': u'^fE$',
#   u'Er-rim': u'^(.*)uvEr$',
#   u'e-am': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwH])e$',
#   u'y-im': u'^(.*[ptbdfsvz])y$',
#   u'\xea-EJim': u'^at\xea$',
#   u'\xea-aJim': u'^r6Zw\xea$'},
#  (u'ps1P', u'is2P'): {u'a..\xf4-i..e': u'^fasj\xf4$',
#   u'swa.\xf4-fys.e': u'^swaj\xf4$'},
#  (u'ps1S', u'pI2S'): {'-': u'^(.*[fsSvzZjrE6a])$',
#   u'En-\xe2': u'^aprEn$',
#   u'En-\xea': u'^(.*)vjEn$',
#   u'aj-va': u'^aj$',
#   u'as-E': u'^fas$',
#   u'd-': u'^r\xe2d$',
#   u'm-': u'^dOrm$',
#   u's-': u'^([pkf][iyEe926uOo])n([iEe])s$',
#   u'v-': u'^(.*[tdsz])wav$'},
#  (u'ps2P', u'ai2P'): {u'asje-it': u'^fasje$',
#   u'swaje-fyt': u'^swaje$',
#   u'zje-t': u'^dizje$'}}

# %%
with open(rep+sample+'Transformations.yaml', 'w') as output:
    yaml.dump(transformations, output, default_flow_style=False,allow_unicode=True)

# %%
with open(rep+sample+'Transformations.yaml', 'r') as input:
    tranformations2=yaml.load(input)

# %%
tranformations2
# Out:
# {(u'ai1P',
#   u'ai1S'): {u'am-E': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwH])am$', u'm-': u'^(.*[iyEe92\xea\xfb])m$'},
#  (u'ai1S', u'pc1S'): {u'-rE': u'^(.*[ptbdfsvzmnrE6a\xea\xe2])i$',
#   u'6.E-E.6rE': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])E$',
#   u'E-6rE': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])E$',
#   u'E-rE': u'^krEE$',
#   u'EJi-\xeadrE': u'^(.*[pt])EJi$',
#   u'Eky-ivrE': u'^syrvEky$',
#   u'H.-r.': u'^(.*[tdn])yHE$',
#   u'aJi-\xeadrE': u'^(.*)ZwaJi$',
#   u'al.-ir.': u'^alE$',
#   u'fy-s6rE': u'^fy$',
#   u'i-6rE': u'^(.*)fi$',
#   u'i-ErE': u'^vi$',
#   u'i-EtrE': u'^(.*)mi$',
#   u'i-jErE': u'^asi$',
#   u'i-rE': u'^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvz])i$',
#   u'i-\xe2drE': u'^(.*)pri$',
#   u'j.-r.': u'^(.*[ptkbdgfsSvzZjlrwH][iEe])jE$',
#   u'jE-irE': u'^(.*[ptbdfsvzmnr])jE$',
#   u'ly-drE': u'^vuly$',
#   u'vi-rE': u'^(.*)Ekrivi$',
#   u'w.-r.': u'^ZuwE$',
#   u'wajE-ErE': u'^\xe2vwajE$',
#   u'y-6vrE': u'^(.*[tdsz])y$',
#   u'y-ErE': u'^ply$',
#   u'y-EtrE': u'^(.*[pk][E96aO][mnr])y$',
#   u'y-OrE': u'^(.*)y$',
#   u'y-irE': u'^(.*)ly$',
#   u'y-rE': u'^([pkbgmJ])ury$',
#   u'y-warE': u'^(.*[bvr])y$',
#   u'zi-rE': u'^([td][rE6][ptbdEa][bdvzr])Hizi$',
#   u'\xea-j\xeadrE': u'^(.*[ptbdfsvz])\xea$'},
#  (u'ai2P', u'ai2S'): {u't-': u'^(.*[fs][iyEe92a])t$'},
#  (u'ai2S', u'pc2P'): {u'-rje': u'^([ptfs][E96aO])rti$',
#   u'a-6rje': u'^(.*[ptbdmn][E96aO\xea\xfb\xe2\xf4][tdsSzZn])a$',
#   u'fy-s6rje': u'^fy$',
#   u'i-6rje': u'^fi$',
#   u'i-Erje': u'^vi$',
#   u'i-\xe2drije': u'^(.*)pri$',
#   u'y-6vrije': u'^r6sy$',
#   u'y-Erje': u'^ply$',
#   u'y-Etrije': u'^kOny$',
#   u'y-urje': u'^py$',
#   u'y-warje': u'^kry$',
#   u'\xea-j\xeadrije': u'^v\xea$'},
#  (u'ai3P',
#   u'fi1P'): {u'-\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])ir$', u'6.E.-E.6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])Er$', u'E.-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])Er$', u'EJir-\xeadr\xf4': u'^([Ea])tEJir$', u'Ekyr-ivr\xf4': u'^vEkyr$', u'HEr-r\xf4': u'^(.*[tdnl])yHEr$', u'aJir-\xeadr\xf4': u'^r6ZwaJir$', u'alEr-ir\xf4': u'^alEr$', u'fy.-s6.\xf4': u'^fyr$', u'i.-6.\xf4': u'^(.*[fvj])ir$', u'i.-E.\xf4': u'^r6vir$', u'ir-Etr\xf4': u'^mir$', u'ir-r\xf4': u'^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvz])ir$', u'ir-\xe2dr\xf4': u'^(.*)prir$', u'jEr-ir\xf4': u'^(.*[mrE6\xea][jriEe6a][fsvzr])jEr$', u'jEr-r\xf4': u'^(.*[ptbdfsvzlr][iEe])jEr$', u'lyr-dr\xf4': u'^vulyr$', u'wEr-r\xf4': u'^ZuwEr$', u'wajEr-Er\xf4': u'^\xe2vwajEr$', u'y.-O.\xf4': u'^(.*)yr$', u'y.-u.\xf4': u'^pyr$', u'yr-6vr\xf4': u'^(.*[tdsz])yr$', u'yr-Etr\xf4': u'^(.*[pk][E96aO][mnr])yr$', u'yr-r\xf4': u'^muryr$', u'yr-war\xf4': u'^(.*[bvr])yr$', u'zir-r\xf4': u'^(.*[kgjrE6][ptbdmnE96O\xea\xfb\xf4][bdvzr])Hizir$', u'\xear-j\xeadr\xf4': u'^(.*[ptbdfsvz])\xear$'},
#  (u'fi1P', u'fi1S'): {u'j6r\xf4-rE': u'^(.*[ptfs])Ej6r\xf4$',
#   u'r\xf4-j6rE': u'^(.*[ptfs])Er\xf4$',
#   u'\xf4-E': u'^(.*[ptkbdgfsSvzZjrwHiyEe926auOo])r\xf4$'},
#  (u'fi1S', u'pI1P'): {u'6rE-waj\xf4': u'^s6rE$',
#   u'6rE-\xf4': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])6rE$',
#   u'E.6rE-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])6rE$',
#   u'ErE-waj\xf4': u'^vErE$',
#   u'OrE-Ej\xf4': u'^OrE$',
#   u'OrE-aS\xf4': u'^sOrE$',
#   u'drE-l\xf4': u'^vudrE$',
#   u'irE-al\xf4': u'^irE$',
#   u'irE-j\xf4': u'^r6mErsirE$',
#   u'irE-\xf4': u'^(.*[fsvzrE96aO][fvrE6a\xea\xe2][ptbdfsvzr])irE$',
#   u'jErE-Ej\xf4': u'^asjErE$',
#   u'j\xeadrE-6n\xf4': u'^(.*[ptbdfsvz])j\xeadrE$',
#   u'rE-j\xf4': u'^(.*[ptkbdgfsSvzZjrwH][Ea])rE$',
#   u'rE-s\xf4': u'^(.*[iEea][dzZn])irE$',
#   u'rE-z\xf4': u'^([ptbdfsvz][iEe6])rE$',
#   u'rE-\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZjrwHiyEe926uOo])rE$',
#   u'trE-s\xf4': u'^(.*[pk][E96aO][mnr])EtrE$',
#   u'warE-Ej\xf4': u'^aswarE$',
#   u'warE-yv\xf4': u'^bwarE$',
#   u'\xe2drE-6n\xf4': u'^(.*)pr\xe2drE$'},
#  (u'fi2P', u'fi2S'): {u'e-a': u'^(.*[ptkbdgfsSvzZjrwHiyEe926auOo])re$',
#   u'j6re-ra': u'^pEj6re$',
#   u're-j6ra': u'^pEre$'},
#  (u'fi2S', u'pI2P'): {u'6ra-Et': u'^f6ra$',
#   u'6ra-e': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])6ra$',
#   u'6ra-waje': u'^s6ra$',
#   u'E.6ra-6.e': u'^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])6ra$',
#   u'Era-waje': u'^(.*)vEra$',
#   u'Ora-Eje': u'^Ora$',
#   u'Ora-aSe': u'^sOra$',
#   u'dra-le': u'^vudra$',
#   u'ira-ale': u'^ira$',
#   u'ira-e': u'^(.*[fsSvzZjrwHiyEe926auOo][fvrE6a\xea\xe2][ptbdfsvzmnr])ira$',
#   u'ira-je': u'^(.*[fsvzr])ira$',
#   u'j\xeadra-6ne': u'^(.*[ptbdfsvz])j\xeadra$',
#   u'ra-He': u'^(.*[tdnl])yra$',
#   u'ra-e': u'^(.*[ptkbdgfsSvzZmnJjrwHE96O\xea\xfb\xf4][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvzr])ra$',
#   u'ra-je': u'^(.*[ptkbdgfsSvzZjlrwH][iEea])ra$',
#   u'ra-se': u'^(.*[bjHiyEe92a][ptkbdgfsSvzZmnJjrE6\xea])ira$',
#   u'ra-t': u'^dira$',
#   u'ra-ve': u'^Ekrira$',
#   u'ra-we': u'^(.*[fsSvzZ])ura$',
#   u'ra-ze': u'^(.*[jlH])ira$',
#   u'tra-se': u'^(.*)kOnEtra$',
#   u'udra-6je': u'^vudra$',
#   u'wara-yve': u'^bwara$',
#   u'\xe2dra-6ne': u'^(.*)pr\xe2dra$',
#   u'\xeadra-EJe': u'^(.*[ptbdfsvzr])\xeadra$'},
#  (u'ii1P', u'pP'): {u'avj\xf4-Ej\xe2': u'^avj\xf4$',
#   u'ij\xf4-j\xe2': u'^(.*[fsvzr])ij\xf4$',
#   u'ij\xf4-\xe2': u'^(.*[fsSvzZjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZ][lr])ij\xf4$',
#   u'i\xf4-\xe2': u'^(.*[uOo][fv])ri\xf4$',
#   u'j\xf4-\xe2': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4])j\xf4$',
#   u'vj\xf4-S\xe2': u'^savj\xf4$',
#   u'\xf4-\xe2': u'^(.*[ptkbdgfsSvzZjlrwH][iEea][Jj])\xf4$'},
#  (u'ii1S', u'ppMP'): {u'6nE-i': u'^(.*)pr6nE$',
#   u'6vE-y': u'^(.*[tdsz])6vE$',
#   u'6zE-E': u'^(.*)f6zE$',
#   u'E-e': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHE96O\xea\xfb\xf4])E$',
#   u'E-i': u'^(.*[ptkbdgfsSvzZjrwHE96aO][jriEe6a\xea\xe2][ptbdfsvzmnj])E$',
#   u'E-y': u'^(.*[ptkbdgfsSvzZjrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvzmnlr])E$',
#   u'EJE-\xea': u'^(.*[ptbdfsvzr])EJE$',
#   u'EjE-i': u'^(.*)asEjE$',
#   u'ErE-i': u'^akErE$',
#   u'EsE-y': u'^(.*[pk][E96aO][mnr])EsE$',
#   u'EtE-i': u'^(.*)mEtE$',
#   u'EzE-y': u'^tEzE$',
#   u'HE-': u'^([kgjE6][fsvzrE96O\xea\xfb\xf4])klyHE$',
#   u'aJE-\xea': u'^r6ZwaJE$',
#   u'avE-y': u'^(.*)avE$',
#   u'ivE-Eky': u'^vivE$',
#   u'izE-y': u'^(.*)lizE$',
#   u'jE-': u'^(.*[ptfs][jrwH][iEe])jE$',
#   u'rE-Er': u'^(.*[uOo][fv])rE$',
#   u'sE-': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])isE$',
#   u'u.E-O.': u'^murE$',
#   u'uvE-y': u'^EmuvE$',
#   u'vE-': u'^(.*[bvr][iy])vE$',
#   u'vE-y': u'^rEzOlvE$',
#   u'wajE-y': u'^(.*[vr])wajE$',
#   u'zE-': u'^(.*[bdjH])izE$'},
#  (u'ii2P', u'pi1S'): {u'6.je-9.': u'^(.*[pbE6][mnl])6rje$',
#   u'6.je-E.': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])je$',
#   u'6nje-j\xea': u'^(.*[ptbdfsvz])6nje$',
#   u'6nje-\xe2': u'^(.*)pr6nje$',
#   u'6vje-wa': u'^(.*[tdsz])6vje$',
#   u'6zje-E': u'^f6zje$',
#   u'EJe-\xea': u'^krEJe$',
#   u'Eje-je': u'^asEje$',
#   u'Eje-wa': u'^asEje$',
#   u'Etje-sHi': u'^Etje$',
#   u'O.je-o.': u'^(.*)O([ptbdfsvzl])je$',
#   u'aisje-E': u'^aisje$',
#   u'alje-o': u'^valje$',
#   u'alje-vE': u'^alje$',
#   u'avje-E': u'^(.*)avje$',
#   u'dje-': u'^(.*[ptbdfsvzrE6][r6O\xe2\xf4])dje$',
#   u'e-': u'^(.*[ptkbdgfsSvzZ][iyEe92a][Jj])e$',
#   u'ije-': u'^(.*[iyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZ][lr])ije$',
#   u'je-': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4])je$',
#   u'mje-': u'^(.*)dOrmje$',
#   u'sje-': u'^(.*[bgvjrwHiyEe926auOo][ptkbdgfsSvzZmnJjrE6a\xea\xe2][iEe])sje$',
#   u'tje-': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][rE6a\xea\xe2])tje$',
#   u'u.je-9.': u'^murje$',
#   u'ulje-2': u'^vulje$',
#   u'uvje-2': u'^puvje$',
#   u'vje-': u'^(.*[vjrwH])ivje$',
#   u'yvje-wa': u'^byvje$',
#   u'zje-': u'^(.*[ptkbdgfsSvzZjlrwH][iyEe926uOo])zje$'},
#  (u'inf',
#   u'pi2P'): {'-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHE96O\xea\xfb\xf4])e$', u'ir-e': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][fvjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjr])ir$', u'ir-je': u'^(.*)rir$', u'r-': u'^Etr$', u'r-He': u'^k\xf4klyr$', u'r-e': u'^(.*[ptkbdgfsSvzZmnJjrwHE96O\xea\xfb\xf4][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZ])r$', u'r-je': u'^(.*[fsvzr][wH][iEea])r$', u'r-se': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])ir$', u'r-t': u'^(.*[ptbdfsvz][iEe])r$', u'r-ve': u'^(.*[fsvzE])krir$', u'r-ze': u'^(.*[ptbdfsvzjlH][iEe])r$', u'tr-se': u'^(.*[pk][E96aO][mnr])Etr$', u'udr-Olve': u'^rEzudr$', u'war-Eje': u'^aswar$', u'war-e': u'^(.*[iyEe926auOo][vzl])war$', u'war-yve': u'^bwar$', u'wir-Oje': u'^wir$', u'\xe2dr-6ne': u'^(.*)pr\xe2dr$', u'\xeadr-EJe': u'^(.*[ptbdfsvzlr])\xeadr$', u'\xeadr-aJe': u'^(.*)Zw\xeadr$'},
#  (u'is1P', u'ai3P'): {u'sj\xf4-r': u'^(.*[iy])sj\xf4$'},
#  (u'is1S',
#   u'ii1S'): {u'as-E': u'^(.*[tdsz][iyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])as$', u'fys-EtE': u'^fys$', u'is-6zE': u'^fis$', u'is-E': u'^(.*[ptbdfsvzrE6][jriEe6a\xea\xe2][ptbdfsvz])is$', u'ys-6vE': u'^dys$', u'ys-E': u'^vulys$', u'ys-EzE': u'^plys$', u'ys-avE': u'^ys$', u'ys-uvE': u'^pys$', u'\xeas-6nE': u'^v\xeas$'},
#  (u'is2P', u'ps1S'): {u'fysje-swa': u'^fysje$',
#   u'i.je-a.': u'^fisje$',
#   u'ysje-wav': u'^dysje$'},
#  (u'pI2P', u'ps2P'): {'-': u'^(.*[Ea])je$',
#   u'6je-ulje': u'^v6je$',
#   u'Et-asje': u'^fEt$',
#   u'e-ije': u'^r\xe2tre$',
#   u'e-je': u'^(.*[jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])e$',
#   u't-zje': u'^dit$'},
#  (u'pI2S',
#   u'fi2P'): {u'-6re': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])$', u'-dre': u'^(.*[ptkbdgfsSvzZjrwHE96O][rE96aO\xea\xfb\xe2\xf4])$', u'-ire': u'^(.*[uOo][fv])r$', u'-j6re': u'^pE$', u'-mire': u'^dOr$', u'-re': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][jrwHiyEe926auOo])$', u'-tire': u'^(.*[fsvzrE96aO][r6\xe2])$', u'-tre': u'^(.*[bdmn][Ea])$', u'-vire': u'^sEr$', u'-vre': u'^sHi$', u'9.-6.6re': u'^pl9r$', u'9.-u.re': u'^m9r$', u'9j-udre': u'^v9j$', u'E-6re': u'^fE$', u'E-Ore': u'^E$', u'E-aire': u'^E$', u'aS-Ore': u'^saS$', u'j-re': u'^EsEj$', u'o.-O.6re': u'^(.*)o([ptbdfsvz])$', u'va-ire': u'^va$', u'wa-6re': u'^swa$', u'wa-6vre': u'^(.*[tdsz])wa$', u'wa-Ere': u'^(.*)vwa$'},
#  (u'pP', u'is1S'): {u'6n\xe2-\xeas': u'^v6n\xe2$',
#   u'6v\xe2-ys': u'^d6v\xe2$',
#   u'6z\xe2-is': u'^f6z\xe2$',
#   u'Ej\xe2-ys': u'^Ej\xe2$',
#   u'Es\xe2-akis': u'^nEs\xe2$',
#   u'Et\xe2-fys': u'^Et\xe2$',
#   u'Ez\xe2-ys': u'^plEz\xe2$',
#   u'uv\xe2-ys': u'^puv\xe2$',
#   u'\xe2-as': u'^(.*[ptbdfsvz][iyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])\xe2$',
#   u'\xe2-is': u'^(.*[ptbdfsvzrE6][jriEe6a\xea\xe2][ptbdfsvz])\xe2$',
#   u'\xe2-ys': u'^vul\xe2$'},
#  (u'pc1P', u'is1P'): {u'6r..-is..': u'^f6rj\xf4$',
#   u'Or..-ys..': u'^Orj\xf4$',
#   u's6r..-fys..': u'^s6rj\xf4$'},
#  (u'pc1S', u'pi2S'): {u'6.6rE-9.': u'^(.*[bdgmnJl])6([lr])6rE$',
#   u'6rE-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])6rE$',
#   u'6rE-E': u'^(.*)f6rE$',
#   u'6vrE-wa': u'^(.*[tdsz])6vrE$',
#   u'ErE-e': u'^asjErE$',
#   u'ErE-wa': u'^(.*)vErE$',
#   u'O.6rE-o.': u'^(.*)O([ptbdfsvzl])6rE$',
#   u'OdrE-o': u'^vOdrE$',
#   u'OrE-E': u'^sOrE$',
#   u'OrE-a': u'^OrE$',
#   u'airE-E': u'^airE$',
#   u'drE-': u'^(.*[ptkbdgfsSvzZjlrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4])drE$',
#   u'irE-': u'^(.*[uOo][fv])rirE$',
#   u'irE-va': u'^irE$',
#   u'j6rE-': u'^(.*[ptfs])Ej6rE$',
#   u'jErE-wa': u'^asjErE$',
#   u'mirE-': u'^(.*)dOrmirE$',
#   u'prE-': u'^\xeatEr\xf4prE$',
#   u'rE-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][jrwHiyEe926auOo])rE$',
#   u'rE-j': u'^(.*[ptfs])ErE$',
#   u's6rE-E': u'^s6rE$',
#   u'tirE-': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][r6\xe2])tirE$',
#   u'trE-': u'^(.*[ptbdfsvzmnr][iyEe926auOo])trE$',
#   u'u.rE-9.': u'^murrE$',
#   u'udrE-2': u'^vudrE$',
#   u'urE-2': u'^purE$',
#   u'virE-': u'^sErvirE$',
#   u'vrE-': u'^(.*[vjH])ivrE$'},
#  (u'pc2P', u'ii2P'): {u'6rje-e': u'^(.*[bgv])a([Jj])6rje$',
#   u'6rje-ije': u'^r\xe2tr6rje$',
#   u'6rje-je': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])6rje$',
#   u'E.6rje-6.je': u'^(.*)a([pbm])E([nl])6rje$',
#   u'Er..-wa..': u'^vErje$',
#   u'Or..-av..': u'^(.*)Orje$',
#   u'drije-lje': u'^vudrije$',
#   u'ir..-al..': u'^irje$',
#   u'irje-je': u'^(.*[fsvzrE96aO][r6\xe2])tirje$',
#   u'j\xeadrije-6nje': u'^(.*[ptbdfsvz])j\xeadrije$',
#   u'r..-s..': u'^(.*[iEea][dzZn])irje$',
#   u'r..-v..': u'^(.*[pbfvr][iyu])rje$',
#   u'r..-z..': u'^(.*[ptbdfsvzl][iEe6])rje$',
#   u'rije-je': u'^(.*[ptbdfsvzrE6][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvz])rije$',
#   u'rje-je': u'^(.*[ptkbdgfsSvzZjrwHiyEe926uOo][jrwHiyEe926auOo])rje$',
#   u's6rje-Etje': u'^s6rje$',
#   u'trije-sje': u'^(.*)kOnEtrije$',
#   u'warje-yvje': u'^bwarje$',
#   u'\xe2drije-6nje': u'^(.*)pr\xe2drije$',
#   u'\xeadrije-EJe': u'^kr\xeadrije$'},
#  (u'pi1P', u'pi3P'): {u'6.\xf4-2.': u'^kr6z\xf4$',
#   u'6.\xf4-9.': u'^(.*[ptkbdgfsSvzZmnJlr])6([mnJjr])\xf4$',
#   u'6.\xf4-E.': u'^(.*[ptkbdgfsSvzZmnJlr])6([ptbdfsvzmnl])\xf4$',
#   u'6n\xf4-jEn': u'^(.*[ptbdfsvz])6n\xf4$',
#   u'6v\xf4-wav': u'^(.*[tdsz])6v\xf4$',
#   u'6z\xf4-\xf4': u'^(.*)f6z\xf4$',
#   u'Ej\xf4-wa': u'^asEj\xf4$',
#   u'Er\xf4-jEr': u'^k\xf4kEr\xf4$',
#   u'E\xf4-e': u'^krE\xf4$',
#   u'O.\xf4-o.': u'^(.*)O([ptkbdgfsSvzZlr])\xf4$',
#   u'Om-\xf4': u'^sOm$',
#   u'al\xf4-v\xf4': u'^al\xf4$',
#   u'av\xf4-\xf4': u'^av\xf4$',
#   u'j\xf4-': u'^(.*[ptkbdgfsSvzZjrwH][iEea])j\xf4$',
#   u'j\xf4-i': u'^(.*[ptbdfsvzlr])j\xf4$',
#   u'u.\xf4-9.': u'^([pbfv])u([vzl])\xf4$',
#   u'waj\xf4-Ej': u'^aswaj\xf4$',
#   u'yv\xf4-wav': u'^byv\xf4$',
#   u'\xf4-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4])\xf4$'},
#  (u'pi1S', u'pi1P'): {u'-d\xf4': u'^(.*[ptbdfsvzrE6][r6O\xe2\xf4])$',
#   u'-j\xf4': u'^(.*[ptkbdgfsSvzZjrwH][iEea])$',
#   u'-m\xf4': u'^(.*)dOr$',
#   u'-p\xf4': u'^\xeatEr\xf4$',
#   u'-s\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96O\xea\xfb\xf4][iEe])$',
#   u'-t\xf4': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][jrwHiyEe926auOo\xea\xfb\xe2\xf4])$',
#   u'-v\xf4': u'^(.*[vjrwHE96O][jriEe6])$',
#   u'-z\xf4': u'^(.*[ptbdfsvzjlH][iEe])$',
#   u'-\xf4': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4])$',
#   u'2-ul\xf4': u'^v2$',
#   u'2-uv\xf4': u'^p2$',
#   u'2.-6.\xf4': u'^kr2z$',
#   u'9.-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])9([mnJjr])$',
#   u'E-6z\xf4': u'^(.*)fE$',
#   u'E-ais\xf4': u'^E$',
#   u'E-av\xf4': u'^(.*)E$',
#   u'E.-6.\xf4': u'^(.*[ptkbdgfsSvzZmnJlr])E([ptbdfsvzmnl])$',
#   u'Hi-Om': u'^sHi$',
#   u'e-E\xf4': u'^kre$',
#   u'i-j\xf4': u'^(.*[ptbdfsvzmnlr])i$',
#   u'jEr-Er\xf4': u'^k\xf4kjEr$',
#   u'je-Ej\xf4': u'^asje$',
#   u'je-waj\xf4': u'^asje$',
#   u'j\xea-6n\xf4': u'^(.*[ptbdfsvz])j\xea$',
#   u'o-al\xf4': u'^vo$',
#   u'o.-O.\xf4': u'^(.*)o([ptkbdgfsSvzZlr])$',
#   u'vE-al\xf4': u'^vE$',
#   u'wa-6v\xf4': u'^(.*[tdsz])wa$',
#   u'wa-Ej\xf4': u'^aswa$',
#   u'wa-yv\xf4': u'^bwa$',
#   u'\xe2-6n\xf4': u'^(.*)pr\xe2$',
#   u'\xea-EJ\xf4': u'^([pkbgjE6a][ptbdfsvzlr])\xea$',
#   u'\xea-aJ\xf4': u'^(.*)Zw\xea$'},
#  (u'pi2P',
#   u'ppFP'): {'-': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwHiyEe926uOo\xea\xfb\xf4][ptbdEe])$', u'6ne-iz': u'^(.*)pr6ne$', u'6ve-y': u'^(.*[tdsz])6ve$', u'EJe-\xeat': u'^(.*[ptbdfsvzr])EJe$', u'Eje-iz': u'^asEje$', u'Ese-y': u'^(.*[pk][E96aO][mnr])Ese$', u'Ete-iz': u'^(.*)mEte$', u'He-': u'^k\xf4klyHe$', u'ave-y': u'^ave$', u'e-i': u'^(.*[ptkbdgfsSvzZjrwHE96aO][jriEe6a\xea\xe2][ptbdfsvzj])e$', u'e-y': u'^(.*[ptkbdgfsSvzZjrE6][jrwHiyEe926auOo\xea\xfb\xe2\xf4][ptbdfsvzmnlr])e$', u'ive-Eky': u'^vive$', u'ize-y': u'^lize$', u'je-': u'^\xe2fHije$', u're-Ert': u'^(.*[uOo][fv])re$', u'se-': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4])ise$', u'u.e-O.t': u'^mure$', u've-t': u'^(.*[fsvzE])krive$', u'waje-iz': u'^aswaje$', u'waje-y': u'^(.*)vwaje$', u'ze-t': u'^(.*[ptkbdgfsSvzZjrE6][ptbdmnE96aO\xea\xfb\xe2\xf4][bdvzr][bdjH])ize$'},
#  (u'pi2S', u'inf'): {u'-He': u'^(.*[ptbdfsvzmnlr])y$',
#   u'-dr': u'^(.*[ptkbdgfsSvzZjlrwHE96O][jrwHiyEe926auOo\xea\xfb\xe2\xf4])$',
#   u'-e': u'^(.*[ptkbdgfsSvzZmnJjlrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlr])$',
#   u'-ir': u'^(.*[kgw6uOo][fvjrwHiyEe926uOo])r$',
#   u'-je': u'^(.*[ptkbdgfsSvzZjlrwH][iEea])$',
#   u'-jir': u'^bu$',
#   u'-kr': u'^v\xea$',
#   u'-mir': u'^(.*)dOr$',
#   u'-pr': u'^(.*)r\xf4$',
#   u'-r': u'^(.*[ptkbdgfsSvzZmnJjlrwHE96aO\xea\xfb\xe2\xf4][iyEe92a])$',
#   u'-tir': u'^(.*[ptbdfsvzmnrE96aO\xea\xfb\xe2\xf4][r6\xe2])$',
#   u'-tr': u'^(.*[iyEe926auOo])$',
#   u'-vir': u'^(.*)sEr$',
#   u'-vr': u'^(.*[vjH])i$',
#   u'-vwar': u'^a$',
#   u'-we': u'^(.*[ptkbdgfsSvzZlr])u$',
#   u'2-ulwar': u'^v2$',
#   u'2-uvwar': u'^p2$',
#   u'2.-6.e': u'^(.*[Zr])2([dzn])$',
#   u'9.-6.e': u'^(.*[bdgvzZmnJlr])9([ptbdfsvzmnlr])$',
#   u'9.-6.ir': u'^(.*)k9j$',
#   u'9.-u.ir': u'^m9r$',
#   u'9..-6..e': u'^av9gl$',
#   u'E-air': u'^E$',
#   u'E-avwar': u'^sE$',
#   u'E.-6.e': u'^(.*[ptkbdgfsSvzZmnJjlr])E([ptbdfsvzmnl])$',
#   u'a-ir': u'^wa$',
#   u'e-Ee': u'^agre$',
#   u'i-je': u'^(.*[ptkbdgfsSvzZmnJlr])i$',
#   u'je-war': u'^asje$',
#   u'j\xea-6nir': u'^(.*[ptbdfsvz])j\xea$',
#   u'o-alwar': u'^vo$',
#   u'o.-O.e': u'^(.*)o([ptkbdgfsSvzZlr])$',
#   u'va-ale': u'^va$',
#   u'wa-6vwar': u'^(.*[tdsz])wa$'},
#  (u'pi3P',
#   u'pc1P'): {u'-6rj\xf4': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJlr])$', u'-irj\xf4': u'^([ptfs][iyEe926auOo][fvr][ptbdfsvzr])$', u'-ri\xf4': u'^(.*[ptbdfsvzmnE\xea][jriEe6a\xea\xe2][ptbdfsvz])$', u'-rj\xf4': u'^(.*[ptkbdgjwHiyEe926uOo][jrwHiyEe926uOo])$', u'9.-6.6rj\xf4': u'^dEZ9n$', u'9.-u.rj\xf4': u'^m9r$', u'9l-udri\xf4': u'^v9l$', u'9v-urj\xf4': u'^p9v$', u'En-\xe2dri\xf4': u'^(.*)prEn$', u'En-\xeadri\xf4': u'^([bdvzr])6vjEn$', u'av-Orj\xf4': u'^sav$', u'j-rj\xf4': u'^pEj$', u'o.-O.6rj\xf4': u'^(.*[pk])oz$', u's-rj\xf4': u'^finis$', u's-tri\xf4': u'^kOnEs$', u'v-rj\xf4': u'^bwav$', u'v\xf4-irj\xf4': u'^v\xf4$', u'wa-Erj\xf4': u'^(.*)vwa$', u'wav-6vri\xf4': u'^dwav$', u'z-rj\xf4': u'^([td][iEe])z$', u'\xf4-6rj\xf4': u'^([fs])\xf4$', u'\xf4-Orj\xf4': u'^\xf4$'},
#  (u'ppFP', u'ps1P'): {u'Et-asj\xf4': u'^fEt$',
#   u'e-j\xf4': u'^(.*[ptkbdgfsSvzZjrE6][kgjwHiyEe926auOo][ptbdfsvz])e$',
#   u'i-j\xf4': u'^s\xe2ti$',
#   u'y-j\xf4': u'^vuly$'},
#  (u'ppMP', u'ai1P'): {u'-m': u'^(.*[iy])$',
#   u'6ny-\xeam': u'^(.*[ptkbdgjE6a][r6O\xf4])v6ny$',
#   u'E-im': u'^fE$',
#   u'Er-rim': u'^(.*)uvEr$',
#   u'e-am': u'^(.*[ptkbdgfsSvzZmnJjrwHiyEe926auOo\xea\xfb\xe2\xf4][ptkbdgfsSvzZmnJjlrwH])e$',
#   u'y-im': u'^(.*[ptbdfsvz])y$',
#   u'\xea-EJim': u'^at\xea$',
#   u'\xea-aJim': u'^r6Zw\xea$'},
#  (u'ps1P', u'is2P'): {u'a..\xf4-i..e': u'^fasj\xf4$',
#   u'swa.\xf4-fys.e': u'^swaj\xf4$'},
#  (u'ps1S', u'pI2S'): {'-': u'^(.*[fsSvzZjrE6a])$',
#   u'En-\xe2': u'^aprEn$',
#   u'En-\xea': u'^(.*)vjEn$',
#   u'aj-va': u'^aj$',
#   u'as-E': u'^fas$',
#   u'd-': u'^r\xe2d$',
#   u'm-': u'^dOrm$',
#   u's-': u'^([pkf][iyEe926uOo])n([iEe])s$',
#   u'v-': u'^(.*[tdsz])wav$'},
#  (u'ps2P', u'ai2P'): {u'asje-it': u'^fasje$',
#   u'swaje-fyt': u'^swaje$',
#   u'zje-t': u'^dizje$'}}

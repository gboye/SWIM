# %% [markdown]
# typeEchantillon :
# - fixe pour utiliser tailleEchantillon
# - variable pour utiliser nombre,increment,nombreInitial
# - total pour utiliser tout le lexique

# %%
typeEchantillon="fixe"
tailleEchantillon=30000
nombre=1000
increment=250
nombreInitial=20

# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import pickle
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False

# %% [markdown]
# ###Préparation des matrices de traits

# %%
features.add_config('bdlexique.ini')
fs=features.FeatureSystem('phonemes')
#fs.supremum.concept.extent

# %%
bdlexiqueIn = unicode(u"èò")
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO")
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    return result

# %%
filePrefix="MGC-"

# %% [markdown]
# #Préparation du tableau de VERBES

# %% [markdown]
# ###Lecture du lexique

# %%
nomLexique="/Users/gilles/Copy/Python/phonemisation/bdlexique-PDM-Resync.txt"
bdlexique=pd.read_csv(nomLexique,sep=";",names=["ortho","phono","ext","cs","ms","vs","lexeme","L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"],encoding="utf8")

# %% [markdown]
# ###Définition des cases
# - principales pour le paradigme courant
# - secondaires pour les cases rares
# - totales pour le tout

# %%
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP',
        'ppMS', 'ppMP', 'ppFS', 'ppFP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires
listeCases=casesTotales

# %% [markdown]
# ###Création de la colonne de fréquence *freq*
# - fréquence positive : 10.f
# - fréquence nulle : 5
# - fréquence inexistante : 1

# %%
bdlexique["freq"]=bdlexique[bdlexique["formeFrantext"]!="***"]["formeFrantext"].astype(float)*10
bdlexique.loc[bdlexique["formeFrantext"]=="0","freq"]=5
bdlexique.loc[bdlexique["formeFrantext"]=="***","freq"]=1

# %% [markdown]
# ###Elimination des colonnes inutiles
# - indicateur L23
# - fréquences brutes

# %%
inutilesColonnes=["L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"]
for colonne in inutilesColonnes:
    del bdlexique[colonne]

# %% [markdown]
# ###Extraction des formes verbales dans une structure *verbes*

# %%
verbes=bdlexique[bdlexique["cs"].isin(["V","K"])].copy()

# %%
verbes["phono"]=verbes["phono"].apply(lambda x: recoder(x))

# %%
#verbes["phono"]
print recoder(u"tOtòtètE")
# Out:
# tOtOtEtE

# %% [markdown]
# ###Ajout d'une colonne *prob* pour la fréquence relative

# %%
verbes["prob"]=verbes["freq"]/verbes["freq"].sum()

# %% [markdown]
# ###Ajout d'une colonne *case*
# - remplir les *ms* vides pour permettre la concaténation sans erreur
# - remplir les *vs* vides des participes passés par "pp" pour permettre l'identification de la case
# - *case* est la concaténation de *vs* et *ms*

# %%
verbes["ms"]=verbes["ms"].fillna("")
verbes["vs"]=verbes["vs"].fillna("pp")
verbes["case"]=verbes["vs"]+verbes["ms"]

# %% [markdown]
# #Echantillonage

# %% [markdown]
# ##Assembler les échantillons correspondant à une étape n

# %%
def assemblerExtrait(nombre):
    return verbes.ix[np.sort(np.concatenate(tirages[0:nombre]))]

# %% [markdown]
# ###Tirage incrémental des formes disponibles
# - increment : taille de chaque tirage
# - nombre : nombre de tirages
#
# np.random.choice donne une liste d'index de formes tirées dans l'ordre du tirage
#
# on découpe la liste en morceaux de la taille de l'incrément

# %%
if typeEchantillon=="variable":
    tirage=np.random.choice(verbes.index,size=nombre*increment,p=verbes["prob"],replace=False)
    tirages=[tirage[increment*x:increment*(x+1)] for x in range(len(tirage)/increment+(len(tirage)%increment!=0))]
    extrait=assemblerExtrait(nombreInitial)
elif typeEchantillon=="fixe":
    tirage=np.random.choice(verbes.index,size=tailleEchantillon,p=verbes["prob"],replace=False)
    extrait=verbes.ix[np.sort(tirage)]
elif typeEchantillon=="total":
    extrait=verbes

# %%
#extrait=assemblerExtrait(nEchantillons)

# %%
paradigmes=pd.pivot_table(extrait, values='phono', index=['lexeme'], columns=['case'], aggfunc=lambda x: ",".join(x)).reset_index().reindex()

# %%
def diff(mot1,mot2):
    result=[]
    diff1=""
    diff2=""
    same=""
    vide="."
    lmax=max(len(mot1),len(mot2))
    lmin=min(len(mot1),len(mot2))
    for index in range(lmax):
        if index < lmin:
            if mot1[index]!=mot2[index]:
                diff1+=mot1[index]
                diff2+=mot2[index]
                same+=vide
            else:
                same+=mot1[index]
                diff1+=vide
                diff2+=vide
        elif index < len(mot1):
            diff1+=mot1[index]
        elif index < len(mot2):
            diff2+=mot2[index]
    diff1=diff1.lstrip(".")
    diff2=diff2.lstrip(".")
#    return (same,diff1,diff2,diff1+"_"+diff2)
    return (diff1+"-"+diff2)

def rowDiff(row, patrons):
    result=diff(row[0],row[1])
    if not result in patrons:
        patrons[result]=(formesPatron(),formesPatron())
    patrons[result][0].ajouterFormes(row[0])
    patrons[result][1].ajouterFormes(row[1])
    return (result[0],result[1])

# %%
def patron2regexp(morceaux):
    result="^"
    for morceau in morceaux:
        if morceau=="*":
            result+="(.*)"
        elif len(morceau)>1:
            result+="(["+morceau+"])"
        else:
            result+=morceau
    result+="$"
    result=result.replace(")(","")
    return result

# %%
def remplacementSortie(sortie):
    n=1
    nsortie=""
    for lettre in sortie:
        if lettre==".":
            nsortie+="\g<%d>"%n
            n+=1
        else:
            nsortie+=lettre
    return nsortie

# %%
class formesPatron:
    '''
    Accumulateur de formes correspondant à un patron pour calcul de la Généralisation Minimale (cf. MGL)
    '''
    def __init__(self):
        self.formes=[]

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterForme(self,forme):
        self.formes.append(forme)
        
    def calculerGM(self):
        minLongueur=len(min(self.formes, key=len))
        maxLongueur=len(max(self.formes, key=len))
        if debug: print minLongueur, maxLongueur
        positions=[]
        if maxLongueur>minLongueur:
            positions.append("*")
        for i in xrange(minLongueur, 0, -1):
            phonemes=set([x[-i] for x in self.formes])
            if debug: print phonemes
            if "." in phonemes:
                positions.append(".")
            else:
                positions.append("".join(fs.lattice[phonemes].extent))
        return patron2regexp(positions)

class pairePatrons:
    '''
    Accumulateur de triplets (f1,f2,patron) correspondant à une paire pour calcul des Généralisations Minimales (cf. MGL)
    '''
    def __init__(self,case1,case2):
        self.patrons1={}
        self.patrons2={}
        self.case1=case1
        self.case2=case2

#    def __repr__(self):
#        return ','.join(self.calculerGM())
        
    def ajouterFormes(self,forme1,forme2,patron):
#        print forme1,forme2,patron
        patron12=patron
        (pat1,pat2)=patron.split("-")
        patron21=pat2+"-"+pat1
#        print patron12,patron21
        if not patron12 in self.patrons1:
            self.patrons1[patron12]=formesPatron()
        self.patrons1[patron12].ajouterForme(forme1)
        if not patron21 in self.patrons2:
            self.patrons2[patron21]=formesPatron()
        self.patrons2[patron21].ajouterForme(forme2)
        
        
    def calculerGM(self):
        resultat1={}
        for patron in self.patrons1:
            if debug: print "patron1", patron
            resultat1[patron]=self.patrons1[patron].calculerGM()
        resultat2={}
        for patron in self.patrons2:
            if debug: print "patron2", patron
            resultat2[patron]=self.patrons2[patron].calculerGM()
        return (resultat1,resultat2)

# %% [markdown]
# #Classe pour la gestion des patrons, des classes et des transformations

# %%
class paireClasses:
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classes1=classesPaire(case1,case2)
        self.classes2=classesPaire(case2,case1)

    def ajouterPatron(self,n,patron,motif):
        if n==1:
            self.classes1.ajouterPatron(patron,motif)
        elif n==2:
            self.classes2.ajouterPatron(patron,motif)
        else:
            print "le numéro de forme n'est pas dans [1,2]",n

    def ajouterPaire(self,forme1,forme2):
        self.classes1.ajouterPaire(forme1,forme2)
        self.classes2.ajouterPaire(forme2,forme1)
        
    def calculerClasses(self):
        return(self.classes1,self.classes2)

    
class classesPaire:
    '''
    Gestion des patrons, des classes et des transformations
    
    ajouterPatron : ajoute un patron et son motif associé (MGL)
    ajouterPaire : ajoute une paire de formes, calcule la classe de la forme1 et la règle sélectionnée
    sortirForme : cacule les formes de sortie correspondant à la forme1 avec leurs coefficients respectifs
    '''
    def __init__(self,case1,case2):
        self.case1=case1
        self.case2=case2
        self.nom=case1+"-"+case2
        self.classe={}
        self.nbClasse={}
        self.patrons={}
        self.entree={}
        self.sortie={}
    
    def ajouterPatron(self,patron,motif):
        self.patrons[patron]=motif
        (entree,sortie)=patron.split("-")
        self.entree[patron]=entree.replace(u".",u"(.)")
        self.sortie[patron]=remplacementSortie(sortie)
    
    def ajouterPaire(self,forme1,forme2):
        '''
        on calcule la classe de la paire idClasseForme et la règle sélectionnée
        on incrémente le compteur de la classe et celui de la règle sélectionnée à l'intérieur de la classe
        '''
        classeForme=[]
        regleForme=""
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme1):
                classeForme.append(patron)
                '''
                le +"$" permet de forcer l'alignement à droite pour les transformations suffixales
                '''
                if forme2==re.sub(self.entree[patron]+"$",self.sortie[patron],forme1):
                    regleForme=patron
        idClasseForme=", ".join(classeForme)
        if not idClasseForme in self.classe:
            self.classe[idClasseForme]={}
            self.nbClasse[idClasseForme]=0
        if not regleForme in self.classe[idClasseForme]:
            self.classe[idClasseForme][regleForme]=0
        self.nbClasse[idClasseForme]+=1
        self.classe[idClasseForme][regleForme]+=1

    def sortirForme(self,forme):
        classeForme=[]
        sortieForme={}
        for patron in self.patrons:
            if re.match(self.patrons[patron],forme):
                classeForme.append(patron)
        if classeForme:
            idClasseForme=", ".join(classeForme)
            if idClasseForme in self.nbClasse:
                nTotal=self.nbClasse[idClasseForme]
                for patron in self.classe[idClasseForme]:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(self.classe[idClasseForme][patron])/nTotal
            else:
                print forme,
                print "pas de classe",idClasseForme,
                print "%.2f par forme de sortie" % (float(1)/len(classeForme))
                nTotal=len(classeForme)
                for patron in classeForme:
                    sortie=re.sub(self.entree[patron]+"$",self.sortie[patron],forme)
                    sortieForme[sortie]=float(1)/nTotal
        else:
            print forme, 
            print "pas de patron"
        return sortieForme

# %% [markdown]
# ##Appliquer la formule de calcul des différences entre chaines à chaque ligne
#
# >si il y a au moins une ligne
#
# >>on applique la différence à la ligne
#
# >>on calcule les deux patrons par suppression des points initiaux
#
# >>on renvoie le groupement par patrons (1&2)
#
# >sinon
#
# >>on renvoie le paradigme vide d'origine

# %%
def OLDrapports(paradigme):
    (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    if len(paradigme)>0:
#        for index, row in paradigme.iterrows():
#            patrons.ajouterFormes(row[0],row[1],diff(row[0],row[1]))
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
    return patrons.calculerGM()

# %%
def rapports(paradigme):
    if len(paradigme.columns.values.tolist())==2:
        (case1,lexeme)= paradigme.columns.values.tolist()
        case2=case1
    else:
        (case1,case2,lexeme)= paradigme.columns.values.tolist()
    patrons=pairePatrons(case1,case2)
    classes=paireClasses(case1,case2)
    if len(paradigme)>0:
        paradigme.apply(lambda x: patrons.ajouterFormes(x[case1],x[case2],diff(x[case1],x[case2])), axis=1)
        (regles1,regles2)=patrons.calculerGM()
        for regle in regles1:
            classes.ajouterPatron(1,regle,regles1[regle])
        for regle in regles2:
            classes.ajouterPatron(2,regle,regles2[regle])
        paradigme.apply(lambda x: classes.ajouterPaire(x[case1],x[case2]), axis=1)
    (classes1,classes2)=classes.calculerClasses()
    return (classes1,classes2)

# %% [markdown]
# ###Dédoubler les lignes avec des surabondances dans *colonne*
# >identifier une ligne avec surabondance
#
# >>ajouter les lignes correspondant à chaque valeur
#
# >>ajouter le numéro de la ligne initiale dans les lignes à supprimer
#
# >supprimer les lignes avec surabondance
#
# NB : il faut préparer le tableau pour avoir une indexation qui permette l'ajout des valeurs individuelles et la suppression des lignes de surabondances

# %%
def splitCellMates(df,colonne):
    '''
    Calcul d'une dataframe sans surabondance par dédoublement des valeurs
    '''
    test=df.reset_index()
    del test["index"]
    splitIndexes=[]
    for index,ligne in test.iterrows():
        if "," in ligne[colonne]:
            valeurs=set(ligne[colonne].split(","))
            nouvelleLigne=ligne
            for valeur in valeurs:
                nouvelleLigne[colonne]=valeur
                test=test.append(nouvelleLigne,ignore_index=True)
            splitIndexes.append(index)
    if splitIndexes:
        test=test.drop(test.index[splitIndexes])
    return test

# %% [markdown]
# ##Calculer les rapports entre formes pour chaque paire
#
# >on fait la liste des cases de *paradigmes*
#
# >pour chaque paire du tableau principal
#
# >>si la paire fait partie des cases de *paradigmes*
#
# >>>on calcule le rapport
#
# >>sinon
#
# >>>on signale que qu'une des cases n'est pas représentée

# %%
def evaluerEchantillon(paradigmes):
    result={}
    colonnes=paradigmes.columns.values.tolist()
    for paire in it.combinations_with_replacement(listeCases,2):
        if debug: print paire
#        if paire[0]==paire[1]:
#            paireListe=[paire[0]]
#        else:
#            paireListe=list(paire)
        paireListe=list(paire)
        paireListe.append("lexeme")
        if paire[0] in colonnes and paire[1] in colonnes:
            paradigmePaire=paradigmes[paireListe].dropna(thresh=3, axis=0).reindex()
            if paire[0]==paire[1]:
                paireListe[1]="TEMP"
                paradigmePaire.columns=paireListe
            paradigmePaire=splitCellMates(splitCellMates(paradigmePaire,paireListe[0]),paireListe[1])
            result[paire]=rapports(paradigmePaire)
        else:
            result[paire]=("missing pair", paire)
    return result

# %% [markdown]
# ###Boucle de calcul des analogies pour l'échantillon

# %%
# %%time
debug=False
resultats=evaluerEchantillon(paradigmes)
# Out:
# CPU times: user 1min 14s, sys: 245 ms, total: 1min 14s
# Wall time: 1min 14s

# %%
classesFinales={}
for resultat in resultats:
    classesFinales[resultat]=resultats[resultat][0]
    classesFinales[(resultat[1],resultat[0])]=resultats[resultat][1]

# %%
with open(filePrefix+typeEchantillon+'-Regles.pkl', 'wb') as output:
   pickle.dump(classesFinales, output, pickle.HIGHEST_PROTOCOL)

# %%
classesFinales[('pi2S', 'pi3P')].sortirForme("aswa")
# Out:
# {'aswa': 0.5, u'aswav': 0.5}

# %%
with open(filePrefix+typeEchantillon+'-Regles.pkl', 'rb') as input:
    resultatsLecture = pickle.load(input)

# %%
resultatsLecture[('fi1P', 'fi2S')].sortirForme(u"kurrô")
# Out:
# {u'kurra': 1.0}

# %%
paradigmes[paradigmes["lexeme"]=="courir"]
# Out:
# case  lexeme ai1P  ai1S ai2P ai2S ai3P  ai3S   fi1P   fi1S   fi2P ...  ppFS  \
# 806   courir  NaN  kury  NaN  NaN  NaN  kury  kurrô  kurrE  kurre ...   NaN
#
# case ppMP  ppMS ppij ps1P ps1S ps2P ps2S ps3P ps3S
# 806   NaN  kury  NaN  NaN  kur  NaN  kur  kur  NaN
#
# [1 rows x 53 columns]

# %%
# %%time
for forme in listeCases:
    if not pd.isnull(paradigmes[paradigmes["lexeme"]=="manger"][forme].iloc[0]):
        depart=paradigmes[paradigmes["lexeme"]=="manger"][forme].iloc[0]
        print forme,depart
        if depart!="nan":
            for case in listeCases:
                print case,
                if not isinstance(resultatsLecture[(forme, case)],str):
                    print resultatsLecture[(forme, case)].sortirForme(depart),
            print
            print
# Out:
# inf mâZe
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZe pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZe pas de patron
# {} ai2P mâZe pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZe pas de patron
# {} is2S mâZe pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZe pas de patron
# {} is2P mâZe pas de patron
# {} is3P {u'm\xe2Zas': 1.0}
#
# pi1S mâZ
# inf
# {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P {u'm\xe2Zas': 1.0}
#
# pi2S mâZ
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P
# {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P mâZ pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S mâZ pas de patron
# {} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P mâZ pas de patron
# {}
#
# pi3S mâZ
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S
# {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P {u'm\xe2Zas': 1.0}
#
# pi1P mâZô
# inf {u'm\xe2Zir': 0.11038961038961038, u'm\xe2Ze': 0.8896103896103896} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9259259259259259, u'm\xe2ZrE': 0.07407407407407407} fi2S {u'm\xe2Zra': 0.09259259259259259, u'm\xe2Z6ra': 0.9074074074074074} fi3S {u'm\xe2Zra': 0.12195121951219512, u'm\xe2Z6ra': 0.8780487804878049} fi1P {u'm\xe2Z6r\xf4': 0.7794117647058824, u'm\xe2Zr\xf4': 0.22058823529411764} fi2P {u'm\xe2Z6re': 0.819672131147541, u'm\xe2Zre': 0.18032786885245902} fi3P {u'm\xe2Z6r\xf4': 0.7666666666666667, u'm\xe2Zr\xf4': 0.23333333333333334} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S
# {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9016393442622951, u'm\xe2ZrE': 0.09836065573770492} pc2S {u'm\xe2Z6rE': 0.8923076923076924, u'm\xe2ZrE': 0.1076923076923077} pc3S {u'm\xe2Z6rE': 0.8089887640449438, u'm\xe2ZrE': 0.19101123595505617} pc1P mâZô pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2Zi': 0.40476190476190477, u'm\xe2ZE': 0.5952380952380952} ai2S mâZô pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZô pas de patron
# {} ai2P mâZô pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZô pas de patron
# {} is2S mâZô pas de patron
# {} is3S mâZô pas de patron
# {} is1P mâZô pas de patron
# {} is2P mâZô pas de patron
# {} is3P mâZô pas de patron
# {}
#
# pi2P mâZe
# inf {u'm\xe2Zir': 0.09771986970684039, u'm\xe2Ze': 0.9022801302931596} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9541984732824428, u'm\xe2ZrE': 0.04580152671755725} fi2S {u'm\xe2Zra': 0.04411764705882353, u'm\xe2Z6ra': 0.9558823529411765} fi3S {u'm\xe2Zra': 0.11235955056179775, u'm\xe2Z6ra': 0.8876404494382022} fi1P {u'm\xe2Z6r\xf4': 0.8133333333333334, u'm\xe2Zr\xf4': 0.18666666666666668} fi2P {u'm\xe2Z6re': 0.8589743589743589, u'm\xe2Zre': 0.14102564102564102} fi3P {u'm\xe2Z6r\xf4': 0.8108108108108109, u'm\xe2Zr\xf4': 0.1891891891891892} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9382716049382716, u'm\xe2ZrE': 0.06172839506172839} pc2S {u'm\xe2Z6rE': 0.9397590361445783, u'm\xe2ZrE': 0.060240963855421686} pc3S {u'm\xe2Z6rE': 0.8571428571428571, u'm\xe2ZrE': 0.14285714285714285} pc1P mâZe pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 0.75, u'm\xe2ZrE': 0.25} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2Zi': 0.3958333333333333, u'm\xe2ZE': 0.6041666666666666} ai2S {u'm\xe2Zi': 1.0} ai3S {u'm\xe2Za': 1.0} ai1P mâZe pas de patron
# {} ai2P mâZe pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZe pas de patron
# {} is2S mâZe pas de patron
# {} is3S mâZe pas de patron
# {} is1P mâZe pas de patron
# {} is2P mâZe pas de patron
# {} is3P mâZe pas de patron
# {}
#
# pi3P mâZ
# inf {u'm\xe2Zr': 0.075, u'm\xe2Zir': 0.027777777777777776, u'm\xe2Ze': 0.8972222222222223} pi1S {u'm\xe2Z': 1.0} pi2S
# {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9421487603305785, u'm\xe2ZrE': 0.05785123966942149} fi2S {u'm\xe2Zra': 0.06060606060606061, u'm\xe2Z6ra': 0.9393939393939394} fi3S {u'm\xe2Zra': 0.09941520467836257, u'm\xe2Z6ra': 0.9005847953216374} fi1P {u'm\xe2Z6r\xf4': 0.8243243243243243, u'm\xe2Zr\xf4': 0.17567567567567569} fi2P {u'm\xe2Z6re': 0.8450704225352113, u'm\xe2Zre': 0.15492957746478872} fi3P {u'm\xe2Z6r\xf4': 0.8461538461538461, u'm\xe2Zr\xf4': 0.15384615384615385} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9333333333333333, u'm\xe2ZrE': 0.06666666666666667} pc2S {u'm\xe2Z6rE': 0.9305555555555556, u'm\xe2ZrE': 0.06944444444444445} pc3S {u'm\xe2Z6rE': 0.8717948717948718, u'm\xe2ZrE': 0.1282051282051282} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S mâZ pas de patron
# {} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P mâZ pas de patron
# {}
#
# ii1S mâZE
# inf {u'm\xe2Zir': 0.16393442622950818, u'm\xe2Ze': 0.8360655737704918} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.918918918918919, u'm\xe2ZrE': 0.08108108108108109} fi2S {u'm\xe2Zra': 0.06666666666666667, u'm\xe2Z6ra': 0.9333333333333333} fi3S {u'm\xe2Zra': 0.12631578947368421, u'm\xe2Z6ra': 0.8736842105263158} fi1P {u'm\xe2Z6r\xf4': 0.7551020408163265, u'm\xe2Zr\xf4': 0.24489795918367346} fi2P {u'm\xe2Z6re': 0.8181818181818182, u'm\xe2Zre': 0.18181818181818182} fi3P {u'm\xe2Z6r\xf4': 0.8163265306122449, u'm\xe2Zr\xf4': 0.1836734693877551} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9137931034482759, u'm\xe2ZrE': 0.08620689655172414} pc2S {u'm\xe2Z6rE': 0.9056603773584906, u'm\xe2ZrE': 0.09433962264150944} pc3S
# {u'm\xe2Z6rE': 0.8636363636363636, u'm\xe2ZrE': 0.13636363636363635} pc1P mâZE pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2Zi': 0.4444444444444444, u'm\xe2ZE': 0.5555555555555556} ai2S {u'm\xe2Zi': 1.0} ai3S {u'm\xe2Za': 1.0} ai1P mâZE pas de patron
# {} ai2P mâZE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZE pas de patron
# {} is2S mâZE pas de patron
# {} is3S mâZE pas de patron
# {} is1P mâZE pas de patron
# {} is2P mâZE pas de patron
# {} is3P mâZE pas de patron
# {}
#
# ii3S mâZE
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9381443298969072, u'm\xe2ZrE': 0.061855670103092786} fi2S {u'm\xe2Zra': 0.05357142857142857, u'm\xe2Z6ra': 0.9464285714285714} fi3S {u'm\xe2Zra': 0.12318840579710146, u'm\xe2Z6ra': 0.8768115942028986} fi1P {u'm\xe2Z6r\xf4': 0.7846153846153846, u'm\xe2Zr\xf4': 0.2153846153846154} fi2P {u'm\xe2Z6re': 0.8461538461538461, u'm\xe2Zre': 0.15384615384615385} fi3P {u'm\xe2Z6r\xf4': 0.8135593220338984, u'm\xe2Zr\xf4': 0.1864406779661017} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9264705882352942, u'm\xe2ZrE': 0.07352941176470588} pc2S {u'm\xe2Z6rE': 0.9264705882352942, u'm\xe2ZrE': 0.07352941176470588} pc3S {u'm\xe2Z6rE': 0.8181818181818182, u'm\xe2ZrE': 0.18181818181818182} pc1P mâZE pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZE pas de patron
# {} ai2P mâZE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZE pas de patron
# {} is2S mâZE pas de patron
# {} is3S mâZE pas de patron
# {} is1P mâZE pas de patron
# {} is2P mâZE pas de patron
# {} is3P mâZE pas de patron
# {}
#
# ii2P mâZje
# inf {u'm\xe2Ze': 1.0} pi1S
# {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.8983050847457628, u'm\xe2ZrE': 0.1016949152542373} fi2S {u'm\xe2Zra': 0.05555555555555555, u'm\xe2Z6ra': 0.9444444444444444} fi3S {u'm\xe2Zra': 0.11594202898550725, u'm\xe2Z6ra': 0.8840579710144928} fi1P {u'm\xe2Z6r\xf4': 0.75, u'm\xe2Zr\xf4': 0.25} fi2P {u'm\xe2Z6re': 0.85, u'm\xe2Zre': 0.15} fi3P {u'm\xe2Z6r\xf4': 0.8095238095238095, u'm\xe2Zr\xf4': 0.19047619047619047} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.8863636363636364, u'm\xe2ZrE': 0.11363636363636363} pc2S {u'm\xe2Z6rE': 0.9347826086956522, u'm\xe2ZrE': 0.06521739130434782} pc3S {u'm\xe2Z6rE': 0.8333333333333334, u'm\xe2ZrE': 0.16666666666666666} pc1P mâZje pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZje pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZje pas de patron
# {} ai2P mâZje pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZje pas de patron
# {} is2S mâZje pas de patron
# {} is3S mâZje pas de patron
# {} is1P mâZje pas de patron
# {} is2P mâZje pas de patron
# {} is3P mâZje pas de patron
# {}
#
# ii3P mâZE
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9107142857142857, u'm\xe2ZrE': 0.08928571428571429} fi2S {u'm\xe2Zra': 0.0975609756097561, u'm\xe2Z6ra': 0.9024390243902439} fi3S {u'm\xe2Zra': 0.17045454545454544, u'm\xe2Z6ra': 0.8295454545454546} fi1P {u'm\xe2Z6r\xf4': 0.6888888888888889, u'm\xe2Zr\xf4': 0.3111111111111111} fi2P {u'm\xe2Z6re': 0.7777777777777778, u'm\xe2Zre': 0.2222222222222222} fi3P {u'm\xe2Z6r\xf4': 0.8, u'm\xe2Zr\xf4': 0.2} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.92, u'm\xe2ZrE': 0.08} pc2S {u'm\xe2Z6rE': 0.8913043478260869, u'm\xe2ZrE': 0.10869565217391304} pc3S {u'm\xe2Z6rE': 0.7966101694915254, u'm\xe2ZrE': 0.2033898305084746} pc1P mâZE pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZE pas de patron
# {} ai2P mâZE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZE pas de patron
# {} is2S mâZE pas de patron
# {} is3S mâZE pas de patron
# {} is1P mâZE pas de patron
# {} is2P mâZE pas de patron
# {} is3P mâZE pas de patron
# {}
#
# fi1S mâZ6rE
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P
# {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ii1S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii2S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii3S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps2S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps3S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rE pas de patron
# {} ai2P mâZ6rE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6rE pas de patron
# {} is2S mâZ6rE pas de patron
# {} is3S mâZ6rE pas de patron
# {} is1P mâZ6rE pas de patron
# {} is2P mâZ6rE pas de patron
# {} is3P mâZ6rE pas de patron
# {}
#
# fi2S mâZ6ra
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P mâZ6ra pas de classe 6ra-ô, ra-ô 0.50 par forme de sortie
# {u'm\xe2Z6\xf4': 0.5, u'm\xe2Z\xf4': 0.5} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii2S mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii3S mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6ra pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6ra pas de patron
# {} ai2P mâZ6ra pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6ra pas de patron
# {} is2S mâZ6ra pas de patron
# {} is3S mâZ6ra pas de patron
# {} is1P mâZ6ra pas de patron
# {} is2P mâZ6ra pas de patron
# {} is3P mâZ6ra pas de patron
# {}
#
# fi3S mâZ6ra
# inf {u'm\xe2Ze': 1.0} pi1S
# {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii2S mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P mâZ6ra pas de classe 6ra-E, ra-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6ra pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6ra pas de patron
# {} ai2P mâZ6ra pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6ra pas de patron
# {} is2S mâZ6ra pas de patron
# {} is3S mâZ6ra pas de patron
# {} is1P mâZ6ra pas de patron
# {} is2P mâZ6ra pas de patron
# {} is3P mâZ6ra pas de patron
# {}
#
# fi1P mâZ6rô
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rô pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rô pas de patron
# {} ai2P mâZ6rô pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6rô pas de patron
# {} is2S mâZ6rô pas de patron
# {} is3S mâZ6rô pas de patron
# {}
# is1P mâZ6rô pas de patron
# {} is2P mâZ6rô pas de patron
# {} is3P mâZ6rô pas de patron
# {}
#
# fi2P mâZ6re
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P mâZ6re pas de classe re-e, 6re-e 0.50 par forme de sortie
# {u'm\xe2Z6e': 0.5, u'm\xe2Ze': 0.5} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P mâZ6re pas de classe 6re-je, r.-j. 0.50 par forme de sortie
# {u'm\xe2Z6je': 0.5, u'm\xe2Zje': 0.5} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6re pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6re pas de patron
# {} ai2P mâZ6re pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6re pas de patron
# {} is2S mâZ6re pas de patron
# {} is3S mâZ6re pas de patron
# {} is1P mâZ6re pas de patron
# {} is2P mâZ6re pas de patron
# {} is3P mâZ6re pas de patron
# {}
#
# fi3P mâZ6rô
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rô pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rô pas de patron
# {} ai2P mâZ6rô pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6rô pas de patron
# {} is2S mâZ6rô pas de patron
# {} is3S mâZ6rô pas de patron
# {} is1P mâZ6rô pas de patron
# {} is2P mâZ6rô pas de patron
# {} is3P mâZ6rô pas de patron
# {}
#
# pI2S
#  mâZ
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P mâZ pas de patron
# {}
#
# pI1P
#  mâZô
# inf {u'm\xe2Zir': 0.18055555555555555, u'm\xe2Ze': 0.8194444444444444} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9302325581395349, u'm\xe2ZrE': 0.06976744186046512} fi2S {u'm\xe2Zra': 0.057692307692307696, u'm\xe2Z6ra': 0.9423076923076923} fi3S {u'm\xe2Zra': 0.1391304347826087, u'm\xe2Z6ra': 0.8608695652173913} fi1P {u'm\xe2Z6r\xf4': 0.7936507936507936, u'm\xe2Zr\xf4': 0.20634920634920634} fi2P {u'm\xe2Z6re': 0.8253968253968254, u'm\xe2Zre': 0.1746031746031746} fi3P {u'm\xe2Z6r\xf4': 0.8035714285714286, u'm\xe2Zr\xf4': 0.19642857142857142} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9152542372881356, u'm\xe2ZrE': 0.0847457627118644} pc2S {u'm\xe2Z6rE': 0.9166666666666666, u'm\xe2ZrE': 0.08333333333333333} pc3S {u'm\xe2Z6rE': 0.8227848101265823, u'm\xe2ZrE': 0.17721518987341772} pc1P mâZô pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 0.6875, u'm\xe2ZrE': 0.3125} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2Zi': 0.5, u'm\xe2ZE': 0.5} ai2S {u'm\xe2Zi': 1.0} ai3S {u'm\xe2Za': 1.0} ai1P mâZô pas de patron
# {} ai2P mâZô pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZô pas de patron
# {} is2S mâZô pas de patron
# {} is3S mâZô pas de patron
# {} is1P mâZô pas de patron
# {} is2P mâZô pas de patron
# {} is3P mâZô pas de patron
# {}
#
# pI2P mâZe
# inf {u'm\xe2Zir': 0.09811320754716982, u'm\xe2Ze': 0.9018867924528302} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9477611940298507, u'm\xe2ZrE': 0.05223880597014925} fi2S {u'm\xe2Zra': 0.05555555555555555, u'm\xe2Z6ra': 0.9444444444444444} fi3S {u'm\xe2Zra': 0.10526315789473684, u'm\xe2Z6ra': 0.8947368421052632} fi1P {u'm\xe2Z6r\xf4': 0.8133333333333334, u'm\xe2Zr\xf4': 0.18666666666666668} fi2P {u'm\xe2Z6re': 0.8571428571428571, u'm\xe2Zre': 0.14285714285714285} fi3P {u'm\xe2Z6r\xf4': 0.8055555555555556, u'm\xe2Zr\xf4': 0.19444444444444445} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.926829268292683, u'm\xe2ZrE': 0.07317073170731707} pc2S {u'm\xe2Z6rE': 0.925, u'm\xe2ZrE': 0.075} pc3S {u'm\xe2Z6rE': 0.8629032258064516, u'm\xe2ZrE': 0.13709677419354838} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 0.6842105263157895, u'm\xe2ZrE': 0.3157894736842105} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP
# {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2Zi': 0.4, u'm\xe2ZE': 0.6} ai2S {u'm\xe2Zi': 1.0} ai3S {u'm\xe2Za': 1.0} ai1P mâZe pas de patron
# {} ai2P mâZe pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZe pas de patron
# {} is2S mâZe pas de patron
# {} is3S mâZe pas de patron
# {} is1P mâZe pas de patron
# {} is2P mâZe pas de patron
# {} is3P mâZe pas de patron
# {}
#
# ps1S mâZ
# inf {u'm\xe2Zir': 0.028795811518324606, u'm\xe2Ze': 0.9712041884816754} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.958904109589041, u'm\xe2ZrE': 0.0410958904109589} fi2S {u'm\xe2Zra': 0.05555555555555555, u'm\xe2Z6ra': 0.9444444444444444} fi3S {u'm\xe2Zra': 0.08133971291866028, u'm\xe2Z6ra': 0.9186602870813397} fi1P {u'm\xe2Z6r\xf4': 0.8354430379746836, u'm\xe2Zr\xf4': 0.16455696202531644} fi2P {u'm\xe2Z6re': 0.8518518518518519, u'm\xe2Zre': 0.14814814814814814} fi3P {u'm\xe2Z6r\xf4': 0.8157894736842105, u'm\xe2Zr\xf4': 0.18421052631578946} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9431818181818182, u'm\xe2ZrE': 0.056818181818181816} pc2S {u'm\xe2Z6rE': 0.9361702127659575, u'm\xe2ZrE': 0.06382978723404255} pc3S {u'm\xe2Z6rE': 0.8814814814814815, u'm\xe2ZrE': 0.11851851851851852} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 0.8235294117647058, u'm\xe2ZrE': 0.17647058823529413} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P mâZ pas de patron
# {}
#
# ps2S
#  mâZ
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9312977099236641, u'm\xe2ZrE': 0.06870229007633588} fi2S {u'm\xe2Zra': 0.0684931506849315, u'm\xe2Z6ra': 0.9315068493150684} fi3S {u'm\xe2Zra': 0.058394160583941604, u'm\xe2Z6ra': 0.9416058394160584} fi1P {u'm\xe2Z6r\xf4': 0.8461538461538461, u'm\xe2Zr\xf4': 0.15384615384615385} fi2P {u'm\xe2Z6re': 0.8970588235294118, u'm\xe2Zre': 0.10294117647058823} fi3P {u'm\xe2Z6r\xf4': 0.8833333333333333, u'm\xe2Zr\xf4': 0.11666666666666667} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9222222222222223, u'm\xe2ZrE': 0.07777777777777778} pc2S {u'm\xe2Z6rE': 0.9285714285714286, u'm\xe2ZrE': 0.07142857142857142} pc3S {u'm\xe2Z6rE': 0.9278350515463918, u'm\xe2ZrE': 0.07216494845360824} pc1P mâZ pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S mâZ pas de patron
# {} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P mâZ pas de patron
# {}
#
# ps3S mâZ
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9594594594594594, u'm\xe2ZrE': 0.04054054054054054} fi2S {u'm\xe2Zra': 0.056338028169014086, u'm\xe2Z6ra': 0.9436619718309859} fi3S {u'm\xe2Zra': 0.07655502392344497, u'm\xe2Z6ra': 0.9234449760765551} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 0.8641975308641975, u'm\xe2Zre': 0.13580246913580246} fi3P {u'm\xe2Z6r\xf4': 0.8591549295774648, u'm\xe2Zr\xf4': 0.14084507042253522} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9555555555555556, u'm\xe2ZrE': 0.044444444444444446} pc2S {u'm\xe2Z6rE': 0.9438202247191011, u'm\xe2ZrE': 0.056179775280898875} pc3S {u'm\xe2Z6rE': 0.8832116788321168, u'm\xe2ZrE': 0.11678832116788321} pc1P
# {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 0.7647058823529411, u'm\xe2ZrE': 0.23529411764705882} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P {u'm\xe2Zas': 1.0}
#
# ps1P mâZjô
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.7804878048780488, u'm\xe2ZrE': 0.21951219512195122} fi2S {u'm\xe2Zra': 0.21428571428571427, u'm\xe2Z6ra': 0.7857142857142857} fi3S {u'm\xe2Zra': 0.20454545454545456, u'm\xe2Z6ra': 0.7954545454545454} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 0.7666666666666667, u'm\xe2Zre': 0.23333333333333334} fi3P {u'm\xe2Z6r\xf4': 0.7333333333333333, u'm\xe2Zr\xf4': 0.26666666666666666} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.7647058823529411, u'm\xe2ZrE': 0.23529411764705882} pc2S {u'm\xe2Z6rE': 0.7058823529411765, u'm\xe2ZrE': 0.29411764705882354} pc3S {u'm\xe2Z6rE': 0.7777777777777778, u'm\xe2ZrE': 0.2222222222222222} pc1P mâZjô pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZjô pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZjô pas de patron
# {} ai2P mâZjô pas de patron
# {} ai3P mâZjô pas de patron
# {} is1S mâZjô pas de patron
# {} is2S mâZjô pas de patron
# {} is3S mâZjô pas de patron
# {} is1P mâZjô pas de patron
# {} is2P mâZjô pas de patron
# {} is3P mâZjô pas de patron
# {}
#
# ps2P mâZje
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.8405797101449275, u'm\xe2ZrE': 0.15942028985507245} fi2S mâZje pas de classe je-6ra, je-ra 0.50 par forme de sortie
# {u'm\xe2Zra': 0.5, u'm\xe2Z6ra': 0.5} fi3S {u'm\xe2Zra': 0.13513513513513514, u'm\xe2Z6ra': 0.8648648648648649} fi1P {u'm\xe2Z6r\xf4': 0.7894736842105263, u'm\xe2Zr\xf4': 0.21052631578947367} fi2P {u'm\xe2Z6re': 0.8260869565217391, u'm\xe2Zre': 0.17391304347826086} fi3P {u'm\xe2Z6r\xf4': 0.7959183673469388, u'm\xe2Zr\xf4': 0.20408163265306123} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.8214285714285714, u'm\xe2ZrE': 0.17857142857142858} pc2S {u'm\xe2Z6rE': 0.8596491228070176, u'm\xe2ZrE': 0.14035087719298245} pc3S {u'm\xe2Z6rE': 0.847457627118644, u'm\xe2ZrE': 0.15254237288135594} pc1P mâZje pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S
# {u'm\xe2ZE': 1.0} ai2S mâZje pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZje pas de patron
# {} ai2P mâZje pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZje pas de patron
# {} is2S mâZje pas de patron
# {} is3S mâZje pas de patron
# {} is1P mâZje pas de patron
# {} is2P mâZje pas de patron
# {} is3P mâZje pas de patron
# {}
#
# ps3P mâZ
# inf {u'm\xe2Zir': 0.0430622009569378, u'm\xe2Ze': 0.9569377990430622} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9396551724137931, u'm\xe2ZrE': 0.0603448275862069} fi2S {u'm\xe2Zra': 0.06557377049180328, u'm\xe2Z6ra': 0.9344262295081968} fi3S {u'm\xe2Zra': 0.11695906432748537, u'm\xe2Z6ra': 0.8830409356725146} fi1P {u'm\xe2Z6r\xf4': 0.8266666666666667, u'm\xe2Zr\xf4': 0.17333333333333334} fi2P {u'm\xe2Z6re': 0.8285714285714286, u'm\xe2Zre': 0.17142857142857143} fi3P {u'm\xe2Z6r\xf4': 0.8, u'm\xe2Zr\xf4': 0.2} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9315068493150684, u'm\xe2ZrE': 0.0684931506849315} pc2S {u'm\xe2Z6rE': 0.9178082191780822, u'm\xe2ZrE': 0.0821917808219178} pc3S {u'm\xe2Z6rE': 0.8521739130434782, u'm\xe2ZrE': 0.14782608695652175} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ pas de patron
# {} ai2P mâZ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ pas de patron
# {} is2S mâZ pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZ pas de patron
# {} is2P mâZ pas de patron
# {} is3P mâZ pas de patron
# {}
#
# pc1S mâZ6rE
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pi3S mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ii1S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii2S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii3S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P
# mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps2S {u'm\xe2Z': 1.0} ps3S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rE pas de patron
# {} ai2P mâZ6rE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6rE pas de patron
# {} is2S mâZ6rE pas de patron
# {} is3S mâZ6rE pas de patron
# {} is1P mâZ6rE pas de patron
# {} is2P mâZ6rE pas de patron
# {} is3P mâZ6rE pas de patron
# {}
#
# pc2S mâZ6rE
# inf mâZ6rE pas de classe 6rE-e, rE-e 0.50 par forme de sortie
# {u'm\xe2Z6e': 0.5, u'm\xe2Ze': 0.5} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ii1S mâZ6rE pas de classe 6rE-E, rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii2S mâZ6rE pas de classe 6rE-E, rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii3S mâZ6rE pas de classe 6rE-E, rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P mâZ6rE pas de classe 6rE-E, rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps2S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps3S mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rE pas de patron
# {} ai2P mâZ6rE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6rE pas de patron
# {} is2S mâZ6rE pas de patron
# {} is3S mâZ6rE pas de patron
# {} is1P mâZ6rE pas de patron
# {} is2P mâZ6rE pas de patron
# {} is3P mâZ6rE pas de patron
# {}
#
# pc3S
#  mâZ6rE
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ii1S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii2S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii3S mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P mâZ6rE pas de classe rE-E, 6rE-E 0.50 par forme de sortie
# {u'm\xe2Z6E': 0.5, u'm\xe2ZE': 0.5} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps2S {u'm\xe2Z': 1.0} ps3S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rE pas de patron
# {} ai2P mâZ6rE pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZ6rE pas de patron
# {} is2S mâZ6rE pas de patron
# {} is3S mâZ6rE pas de patron
# {} is1P mâZ6rE pas de patron
# {} is2P mâZ6rE pas de patron
# {} is3P mâZ6rE pas de patron
# {}
#
# pc2P mâZ6rje
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZ6rje pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rje pas de patron
# {} ai2P mâZ6rje pas de patron
# {} ai3P mâZ6rje pas de patron
# {} is1S mâZ6rje pas de patron
# {} is2S mâZ6rje pas de patron
# {} is3S mâZ6rje pas de patron
# {} is1P mâZ6rje pas de patron
# {} is2P mâZ6rje pas de patron
# {} is3P mâZ6rje pas de patron
# {}
#
# pc3P mâZ6rE
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S mâZ6rE pas de classe rE-, 6rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S mâZ6rE pas de classe 6rE-, rE- 0.50 par forme de sortie
# {u'm\xe2Z6': 0.5, u'm\xe2Z': 0.5} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S
# {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP mâZ6rE pas de patron
# {} ai1S mâZ6rE pas de patron
# {} ai2S mâZ6rE pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZ6rE pas de patron
# {} ai2P mâZ6rE pas de patron
# {} ai3P mâZ6rE pas de patron
# {} is1S mâZ6rE pas de patron
# {} is2S mâZ6rE pas de patron
# {} is3S mâZ6rE pas de patron
# {} is1P mâZ6rE pas de patron
# {} is2P mâZ6rE pas de patron
# {} is3P mâZ6rE pas de patron
# {}
#
# pP mâZâ
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 0.9259259259259259, u'm\xe2ZrE': 0.07407407407407407} fi2S {u'm\xe2Zra': 0.07317073170731707, u'm\xe2Z6ra': 0.926829268292683} fi3S {u'm\xe2Zra': 0.1391304347826087, u'm\xe2Z6ra': 0.8608695652173913} fi1P {u'm\xe2Z6r\xf4': 0.7407407407407407, u'm\xe2Zr\xf4': 0.25925925925925924} fi2P {u'm\xe2Z6re': 0.8113207547169812, u'm\xe2Zre': 0.18867924528301888} fi3P {u'm\xe2Z6r\xf4': 0.8, u'm\xe2Zr\xf4': 0.2} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 0.9019607843137255, u'm\xe2ZrE': 0.09803921568627451} pc2S mâZâ pas de classe â-6rE, â-rE 0.50 par forme de sortie
# {u'm\xe2Z6rE': 0.5, u'm\xe2ZrE': 0.5} pc3S {u'm\xe2Z6rE': 0.8072289156626506, u'm\xe2ZrE': 0.1927710843373494} pc1P mâZâ pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 0.6470588235294118, u'm\xe2ZrE': 0.35294117647058826} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZâ pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZâ pas de patron
# {} ai2P mâZâ pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZâ pas de patron
# {} is2S mâZâ pas de patron
# {} is3S mâZâ pas de patron
# {} is1P mâZâ pas de patron
# {} is2P mâZâ pas de patron
# {} is3P mâZâ pas de patron
# {}
#
# ppMS mâZe
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P
# {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 0.9771341463414634, u'm\xe2Zet': 0.022865853658536585} ppFP {u'm\xe2Ze': 0.976, u'm\xe2Zet': 0.024} ai1S {u'm\xe2ZE': 1.0} ai2S mâZe pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZe pas de patron
# {} ai2P mâZe pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZe pas de patron
# {} is2S mâZe pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZe pas de patron
# {} is2P mâZe pas de patron
# {} is3P {u'm\xe2Zas': 1.0}
#
# ppMP mâZe
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S
# {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P {u'm\xe2Z6rj\xf4': 1.0} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 0.974937343358396, u'm\xe2Zet': 0.02506265664160401} ppFP {u'm\xe2Ze': 0.9634146341463414, u'm\xe2Zet': 0.036585365853658534} ai1S {u'm\xe2ZE': 1.0} ai2S mâZe pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZe pas de patron
# {} ai2P mâZe pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZe pas de patron
# {} is2S mâZe pas de patron
# {} is3S mâZe pas de patron
# {} is1P mâZe pas de patron
# {} is2P mâZe pas de patron
# {} is3P mâZe pas de patron
# {}
#
# ppFS mâZe
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S
# {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P mâZe pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZe pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P mâZe pas de patron
# {} ai2P mâZe pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S mâZe pas de patron
# {} is2S mâZe pas de patron
# {} is3S mâZe pas de patron
# {} is1P mâZe pas de patron
# {} is2P mâZe pas de patron
# {} is3P mâZe pas de patron
# {}
#
# ai3S mâZa
# inf {u'm\xe2Ze': 1.0} pi1S {u'm\xe2Z': 1.0} pi2S {u'm\xe2Z': 1.0} pi3S {u'm\xe2Z': 1.0} pi1P {u'm\xe2Z\xf4': 1.0} pi2P {u'm\xe2Ze': 1.0} pi3P {u'm\xe2Z': 1.0} ii1S {u'm\xe2ZE': 1.0} ii2S {u'm\xe2ZE': 1.0} ii3S {u'm\xe2ZE': 1.0} ii1P {u'm\xe2Zj\xf4': 1.0} ii2P {u'm\xe2Zje': 1.0} ii3P {u'm\xe2ZE': 1.0} fi1S {u'm\xe2Z6rE': 1.0} fi2S {u'm\xe2Z6ra': 1.0} fi3S {u'm\xe2Z6ra': 1.0} fi1P {u'm\xe2Z6r\xf4': 1.0} fi2P {u'm\xe2Z6re': 1.0} fi3P {u'm\xe2Z6r\xf4': 1.0} pI2S {u'm\xe2Z': 1.0} pI1P {u'm\xe2Z\xf4': 1.0} pI2P {u'm\xe2Ze': 1.0} ps1S {u'm\xe2Z': 1.0} ps2S {u'm\xe2Z': 1.0} ps3S {u'm\xe2Z': 1.0} ps1P
# {u'm\xe2Zj\xf4': 1.0} ps2P {u'm\xe2Zje': 1.0} ps3P {u'm\xe2Z': 1.0} pc1S {u'm\xe2Z6rE': 1.0} pc2S {u'm\xe2Z6rE': 1.0} pc3S {u'm\xe2Z6rE': 1.0} pc1P mâZa pas de patron
# {} pc2P {u'm\xe2Z6rje': 1.0} pc3P {u'm\xe2Z6rE': 1.0} pP {u'm\xe2Z\xe2': 1.0} ppMS {u'm\xe2Ze': 1.0} ppMP {u'm\xe2Ze': 1.0} ppFS {u'm\xe2Ze': 1.0} ppFP {u'm\xe2Ze': 1.0} ai1S {u'm\xe2ZE': 1.0} ai2S mâZa pas de patron
# {} ai3S {u'm\xe2Za': 1.0} ai1P {u'm\xe2Zam': 1.0} ai2P mâZa pas de patron
# {} ai3P {u'm\xe2ZEr': 1.0} is1S {u'm\xe2Zas': 1.0} is2S mâZa pas de patron
# {} is3S {u'm\xe2Za': 1.0} is1P mâZa pas de patron
# {} is2P mâZa pas de patron
# {} is3P {u'm\xe2Zas': 1.0}
#
# CPU times: user 1.19 s, sys: 6.84 ms, total: 1.2 s
# Wall time: 1.2 s

# %%
verbes[verbes["lexeme"]=="abaisser"]
# Out:
#             ortho     phono  ext cs  ms   vs    lexeme  freq          prob  \
# 15       abaisser     abEse   R"  V      inf  abaisser  1090  3.072840e-06
# 16        abaisse      abEs    @  V  1S   pi  abaisser  1280  3.608473e-06
# 17       abaisses      abEs    @  V  2S   pi  abaisser   160  4.510592e-07
# 18        abaisse      abEs    @  V  3S   pi  abaisser  1280  3.608473e-06
# 19      abaissons     abEsô   z"  V  1P   pi  abaisser    20  5.638239e-08
# 20       abaissez     abEse   z"  V  2P   pi  abaisser   530  1.494133e-06
# 21      abaissent      abEs  @t"  V  3P   pi  abaisser    50  1.409560e-07
# 22      abaissais     abEsE   z"  V  1S   ii  abaisser     1  2.819120e-09
# 23      abaissais     abEsE   z"  V  2S   ii  abaisser     1  2.819120e-09
# 24      abaissait     abEsE   t"  V  3S   ii  abaisser    20  5.638239e-08
# 25     abaissions    abEsjô   z"  V  1P   ii  abaisser     1  2.819120e-09
# 26      abaissiez    abEsje   z"  V  2P   ii  abaisser     1  2.819120e-09
# 27    abaissaient     abEsE   t"  V  3P   ii  abaisser     5  1.409560e-08
# 28       abaissai     abEsE  NaN  V  1S   ai  abaisser   100  2.819120e-07
# 29       abaissas     abEsa   z"  V  2S   ai  abaisser     1  2.819120e-09
# 30        abaissa     abEsa  NaN  V  3S   ai  abaisser     5  1.409560e-08
# 31     abaissâmes    abEsam  @z"  V  1P   ai  abaisser     1  2.819120e-09
# 32     abaissâtes    abEsat  @z"  V  2P   ai  abaisser     1  2.819120e-09
# 33    abaissèrent    abEsEr  @t"  V  3P   ai  abaisser     5  1.409560e-08
# 34     abaisserai   abEs6rE  NaN  V  1S   fi  abaisser   100  2.819120e-07
# 35     abaisseras   abEs6ra   z"  V  2S   fi  abaisser     1  2.819120e-09
# 36      abaissera   abEs6ra  NaN  V  3S   fi  abaisser   190  5.356327e-07
# 37    abaisserons   abEs6rô   z"  V  1P   fi  abaisser     1  2.819120e-09
# 38     abaisserez   abEs6re   z"  V  2P   fi  abaisser     1  2.819120e-09
# 39    abaisseront   abEs6rô   t"  V  3P   fi  abaisser     1  2.819120e-09
# 40        abaisse      abEs    @  V  2S   pI  abaisser  1280  3.608473e-06
# 41      abaissons     abEsô   z"  V  1P   pI  abaisser    20  5.638239e-08
# 42       abaissez     abEse   z"  V  2P   pI  abaisser   530  1.494133e-06
# 43        abaisse      abEs    @  V  1S   ps  abaisser  1280  3.608473e-06
# 44       abaisses      abEs    @  V  2S   ps  abaisser   160  4.510592e-07
# 45        abaisse      abEs    @  V  3S   ps  abaisser  1280  3.608473e-06
# 46     abaissions    abEsjô   z"  V  1P   ps  abaisser     1  2.819120e-09
# 47      abaissiez    abEsje   z"  V  2P   ps  abaisser     1  2.819120e-09
# 48      abaissent      abEs  @t"  V  3P   ps  abaisser    50  1.409560e-07
# 49     abaissasse    abEsas    @  V  1S   is  abaisser     1  2.819120e-09
# 50    abaissasses    abEsas    @  V  2S   is  abaisser     1  2.819120e-09
# 51       abaissât     abEsa   t"  V  3S   is  abaisser     1  2.819120e-09
# 52  abaissassions  abEsasjô   z"  V  1P   is  abaisser     1  2.819120e-09
# 53   abaissassiez  abEsasje   z"  V  2P   is  abaisser     1  2.819120e-09
# 54   abaissassent    abEsas  @t"  V  3P   is  abaisser     1  2.819120e-09
# 55    abaisserais   abEs6rE   z"  V  1S   pc  abaisser   130  3.664856e-07
# 56    abaisserais   abEs6rE   z"  V  2S   pc  abaisser   130  3.664856e-07
# 57    abaisserait   abEs6rE   t"  V  3S   pc  abaisser    20  5.638239e-08
# 58   abaisserions  abEs6rjô   z"  V  1P   pc  abaisser     1  2.819120e-09
# 59    abaisseriez  abEs6rje   z"  V  2P   pc  abaisser     1  2.819120e-09
# 60  abaisseraient   abEs6rE   t"  V  3P   pc  abaisser    10  2.819120e-08
# 61      abaissant     abEsâ   t"  V       pP  abaisser    10  2.819120e-08
# 62        abaissé     abEse  NaN  K  MS   pp  abaisser   740  2.086149e-06
# 63       abaissés     abEse   z"  K  MP   pp  abaisser   300  8.457359e-07
# 64       abaissée     abEse  NaN  K  FS   pp  abaisser   170  4.792504e-07
# 65      abaissées     abEse   z"  K  FP   pp  abaisser    10  2.819120e-08
#
#     case
# 15   inf
# 16  pi1S
# 17  pi2S
# 18  pi3S
# 19  pi1P
# 20  pi2P
# 21  pi3P
# 22  ii1S
# 23  ii2S
# 24  ii3S
# 25  ii1P
# 26  ii2P
# 27  ii3P
# 28  ai1S
# 29  ai2S
# 30  ai3S
# 31  ai1P
# 32  ai2P
# 33  ai3P
# 34  fi1S
# 35  fi2S
# 36  fi3S
# 37  fi1P
# 38  fi2P
# 39  fi3P
# 40  pI2S
# 41  pI1P
# 42  pI2P
# 43  ps1S
# 44  ps2S
# 45  ps3S
# 46  ps1P
# 47  ps2P
# 48  ps3P
# 49  is1S
# 50  is2S
# 51  is3S
# 52  is1P
# 53  is2P
# 54  is3P
# 55  pc1S
# 56  pc2S
# 57  pc3S
# 58  pc1P
# 59  pc2P
# 60  pc3P
# 61    pP
# 62  ppMS
# 63  ppMP
# 64  ppFS
# 65  ppFP

# %%
import codecs,re
import pandas as pd
import itertools as it

# %%
trainingDataFile="/Users/gilles/Github/sigmorphon2016/data/german-task2-train"
cat="V"

# %%
with codecs.open(trainingDataFile,"r",encoding="utf8") as input:
    trainingData=input.readlines()

# %%
inflectedPairs=[]
for line in trainingData:
    (attributes1,form1,attributes2,form2)=line.strip().split("\t")
    (pos1,atts1)=attributes1.split(",",1)
    (pos2,atts2)=attributes2.split(",",1)
    inflectedPairs.append([(pos1,atts1,form1),(pos2,atts2,form2)])

# %%
def listAVs(chaine):
    dictAVs={}
    avs=chaine.split(",")
    for av in avs:
        attribute,value=av.split("=")
        m=re.match(ur"{(.+)\/(.+)}",value)
        if m:
            dictAVs[attribute]=set([m.group(1),m.group(2)])
        else:
            dictAVs[attribute]=set([value])
    return dictAVs

# %%
attributes={}
dimensions=set()
inflectedVerbs=[]
for c1,c2 in inflectedPairs:
    if cat in c1[0] and cat in c2[0]:
        inflectedVerbs.append((c1,c2))
        avs=listAVs(c1[1])
        for av in avs:
#            if "gen" in av: print c1, c2
            dimensions.add(av)
            if not av in attributes:
                attributes[av]=set()
            attributes[av]|=avs[av]
        avs=listAVs(c2[1])
        for av in avs:
#            if "gen" in av: print c2, c1
            dimensions.add(av)
            if not av in attributes:
                attributes[av]=set()
            attributes[av]|=avs[av]
repForme=[u"form"]+list(dimensions)

# %%
lstColumns=[a+"1" for a in repForme]+[a+"2" for a in repForme]
pdPaires=pd.DataFrame(columns=lstColumns)
pdFormes=pd.DataFrame(columns=repForme)
pdFormes
# Out:
# Empty DataFrame
# Columns: [form, mood, per, num, tense, aspect, finite]
# Index: []

# %%
num=0
for c1,c2 in inflectedVerbs:
    avs=listAVs(c1[1])
    pdAVs={av:list(avs[av]) for av in avs}
    pdAVs[u"form"]=[c1[2]]
    produitAVs=list(it.product(*pdAVs.values()))
    for produitAV in produitAVs:
        dictLigne={a:[b] for (a,b) in zip(pdAVs.keys(),produitAV)}
        pdLigne=pd.DataFrame.from_dict(dictLigne)
        pdFormes=pd.concat([pdFormes,pdLigne],ignore_index=True)
    avs=listAVs(c2[1])
    pdAVs={av:list(avs[av]) for av in avs}
    pdAVs[u"form"]=[c2[2]]
    produitAVs=list(it.product(*pdAVs.values()))
    for produitAV in produitAVs:
        dictLigne={a:[b] for (a,b) in zip(pdAVs.keys(),produitAV)}
        pdLigne=pd.DataFrame.from_dict(dictLigne)
        pdFormes=pd.concat([pdFormes,pdLigne],ignore_index=True)
pdFormes
# Out:
#       aspect finite            form  mood  num  per tense
# 0        NaN   NFIN   aktualisieren   NaN  NaN  NaN   NaN
# 1        PFV    NaN  aktualisierten  SBJV   PL    3   PST
# 2        PFV    NaN  aktualisierten  COND   PL    3   PST
# 3        NaN   NFIN        bedanken   NaN  NaN  NaN   NaN
# 4        PFV    NaN       bedankten  SBJV   PL    3   PST
# 5        PFV    NaN       bedankten  COND   PL    3   PST
# 6        NaN   NFIN       beerdigen   NaN  NaN  NaN   NaN
# 7        PFV    NaN       beerdigte  SBJV   SG    3   PST
# 8        PFV    NaN       beerdigte  COND   SG    3   PST
# 9        NaN   NFIN        belohnen   NaN  NaN  NaN   NaN
# 10       NaN    NaN        belohnen   OPT   PL    1   PRS
# 11       NaN    NaN        belohnen  SBJV   PL    1   PRS
# 12       NaN   NFIN         berußen   NaN  NaN  NaN   NaN
# 13       PFV    NaN         berußte   IND   SG    1   PST
# 14       NaN   NFIN      beschießen   NaN  NaN  NaN   NaN
# 15       NaN    NaN      beschießet   OPT   PL    2   PRS
# 16       NaN    NaN      beschießet  SBJV   PL    2   PRS
# 17       NaN   NFIN    bewahrheiten   NaN  NaN  NaN   NaN
# 18       NaN    NaN    bewahrheitet   IND   SG    3   PRS
# 19       NaN   NFIN      brillieren   NaN  NaN  NaN   NaN
# 20       NaN    NaN     brillierend   NaN  NaN  NaN   PRS
# 21       NaN   NFIN          brüten   NaN  NaN  NaN   NaN
# 22       NaN    NaN          brüten   IND   PL    3   PRS
# 23       NaN   NFIN          bücken   NaN  NaN  NaN   NaN
# 24       NaN    NaN          bückst   IND   SG    2   PRS
# 25       NaN   NFIN         bürsten   NaN  NaN  NaN   NaN
# 26       PFV    NaN      bürstetest   IND   SG    2   PST
# 27       NaN   NFIN          cremen   NaN  NaN  NaN   NaN
# 28       PFV    NaN        cremtest  SBJV   SG    2   PST
# 29       PFV    NaN        cremtest  COND   SG    2   PST
# ...      ...    ...             ...   ...  ...  ...   ...
# 10629    NaN    NaN      vergraulen   OPT   PL    3   PRS
# 10630    NaN    NaN      vergraulen  SBJV   PL    3   PRS
# 10631    NaN    NaN        verkannt   NaN  NaN  NaN   PST
# 10632    NaN    NaN        verkenne   OPT   SG    3   PRS
# 10633    NaN    NaN        verkenne  SBJV   SG    3   PRS
# 10634    NaN    NaN       vernommen   NaN  NaN  NaN   PST
# 10635    PFV    NaN         vernahm   IND   SG    3   PST
# 10636    NaN    NaN       verpresst   NaN  NaN  NaN   PST
# 10637    PFV    NaN      verpresste   IND   SG    3   PST
# 10638    NaN    NaN      verschickt   NaN  NaN  NaN   PST
# 10639    PFV    NaN   verschicktest   IND   SG    2   PST
# 10640    NaN    NaN    versifiziert   NaN  NaN  NaN   PST
# 10641    PFV    NaN   versifizierte  SBJV   SG    3   PST
# 10642    PFV    NaN   versifizierte  COND   SG    3   PST
# 10643    NaN    NaN      verurteilt   NaN  NaN  NaN   PST
# 10644    PFV    NaN    verurteiltet   IND   PL    2   PST
# 10645    NaN    NaN       verwaltet   NaN  NaN  NaN   PST
# 10646    PFV    NaN     verwalteten  SBJV   PL    3   PST
# 10647    PFV    NaN     verwalteten  COND   PL    3   PST
# 10648    NaN    NaN      zementiert   NaN  NaN  NaN   PST
# 10649    NaN   NFIN     zementieren   NaN  NaN  NaN   NaN
# 10650    NaN    NaN   zentrifugiert   NaN  NaN  NaN   PST
# 10651    NaN    NaN  zentrifugieren   OPT   PL    3   PRS
# 10652    NaN    NaN  zentrifugieren  SBJV   PL    3   PRS
# 10653    NaN    NaN       zerkratzt   NaN  NaN  NaN   PST
# 10654    NaN    NaN        zekratze   OPT   SG    1   PRS
# 10655    NaN    NaN        zekratze  SBJV   SG    1   PRS
# 10656    NaN    NaN     zerquetscht   NaN  NaN  NaN   PST
# 10657    NaN    NaN    zerquetschen   OPT   PL    3   PRS
# 10658    NaN    NaN    zerquetschen  SBJV   PL    3   PRS
#
# [10659 rows x 7 columns]

# %%
listFormes=[]
for c1,c2 in inflectedVerbs:
    avs=listAVs(c1[1])
    pdAVs={av:avs[av] for av in avs}
    produitAVs=list(it.product(*pdAVs.values()))
    for produitAV in produitAVs:
        listFormes.append([c1[2],c1[2],"-".join(produitAV)])
    avs=listAVs(c2[1])
    pdAVs={av:avs[av] for av in avs}
    produitAVs=list(it.product(*pdAVs.values()))
    for produitAV in produitAVs:
        listFormes.append([c1[2],c2[2],"-".join(produitAV)])

# %%
pdLexique=pd.DataFrame(listFormes,columns=[u"clé","forme","case"])
pdLexique
# Out:
#                  clé           forme               case
# 0      aktualisieren   aktualisieren               NFIN
# 1      aktualisieren  aktualisierten  PL-PST-SBJV-PFV-3
# 2      aktualisieren  aktualisierten  PL-PST-COND-PFV-3
# 3           bedanken        bedanken               NFIN
# 4           bedanken       bedankten  PL-PST-SBJV-PFV-3
# 5           bedanken       bedankten  PL-PST-COND-PFV-3
# 6          beerdigen       beerdigen               NFIN
# 7          beerdigen       beerdigte  SG-PST-SBJV-PFV-3
# 8          beerdigen       beerdigte  SG-PST-COND-PFV-3
# 9           belohnen        belohnen               NFIN
# 10          belohnen        belohnen       PL-PRS-OPT-1
# 11          belohnen        belohnen      PL-PRS-SBJV-1
# 12           berußen         berußen               NFIN
# 13           berußen         berußte   SG-PST-IND-PFV-1
# 14        beschießen      beschießen               NFIN
# 15        beschießen      beschießet       PL-PRS-OPT-2
# 16        beschießen      beschießet      PL-PRS-SBJV-2
# 17      bewahrheiten    bewahrheiten               NFIN
# 18      bewahrheiten    bewahrheitet       SG-PRS-IND-3
# 19        brillieren      brillieren               NFIN
# 20        brillieren     brillierend                PRS
# 21            brüten          brüten               NFIN
# 22            brüten          brüten       PL-PRS-IND-3
# 23            bücken          bücken               NFIN
# 24            bücken          bückst       SG-PRS-IND-2
# 25           bürsten         bürsten               NFIN
# 26           bürsten      bürstetest   SG-PST-IND-PFV-2
# 27            cremen          cremen               NFIN
# 28            cremen        cremtest  SG-PST-SBJV-PFV-2
# 29            cremen        cremtest  SG-PST-COND-PFV-2
# ...              ...             ...                ...
# 10629      vergrault      vergraulen       PL-PRS-OPT-3
# 10630      vergrault      vergraulen      PL-PRS-SBJV-3
# 10631       verkannt        verkannt                PST
# 10632       verkannt        verkenne       SG-PRS-OPT-3
# 10633       verkannt        verkenne      SG-PRS-SBJV-3
# 10634      vernommen       vernommen                PST
# 10635      vernommen         vernahm   SG-PST-IND-PFV-3
# 10636      verpresst       verpresst                PST
# 10637      verpresst      verpresste   SG-PST-IND-PFV-3
# 10638     verschickt      verschickt                PST
# 10639     verschickt   verschicktest   SG-PST-IND-PFV-2
# 10640   versifiziert    versifiziert                PST
# 10641   versifiziert   versifizierte  SG-PST-SBJV-PFV-3
# 10642   versifiziert   versifizierte  SG-PST-COND-PFV-3
# 10643     verurteilt      verurteilt                PST
# 10644     verurteilt    verurteiltet   PL-PST-IND-PFV-2
# 10645      verwaltet       verwaltet                PST
# 10646      verwaltet     verwalteten  PL-PST-SBJV-PFV-3
# 10647      verwaltet     verwalteten  PL-PST-COND-PFV-3
# 10648     zementiert      zementiert                PST
# 10649     zementiert     zementieren               NFIN
# 10650  zentrifugiert   zentrifugiert                PST
# 10651  zentrifugiert  zentrifugieren       PL-PRS-OPT-3
# 10652  zentrifugiert  zentrifugieren      PL-PRS-SBJV-3
# 10653      zerkratzt       zerkratzt                PST
# 10654      zerkratzt        zekratze       SG-PRS-OPT-1
# 10655      zerkratzt        zekratze      SG-PRS-SBJV-1
# 10656    zerquetscht     zerquetscht                PST
# 10657    zerquetscht    zerquetschen       PL-PRS-OPT-3
# 10658    zerquetscht    zerquetschen      PL-PRS-SBJV-3
#
# [10659 rows x 3 columns]

# %%
pdParadigmes=pdLexique.pivot_table(columns=['case'],index=u"clé",aggfunc=lambda x:x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-746366ab8d53> in <module>()
# ----> 1 pdParadigmes=pdLexique.pivot_table(columns=['case'],index=u"clé",aggfunc=lambda x:x)
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/tools/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     119
#     120     grouped = data.groupby(keys)
# --> 121     agged = grouped.agg(aggfunc)
#     122
#     123     table = agged
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3585     @Appender(SelectionMixin._agg_doc)
#    3586     def aggregate(self, arg, *args, **kwargs):
# -> 3587         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3588
#    3589     agg = aggregate
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3110             # grouper specific aggregations
#    3111             if self.grouper.nkeys > 1:
# -> 3112                 return self._python_agg_general(arg, *args, **kwargs)
#    3113             else:
#    3114
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _python_agg_general(self, func, *args, **kwargs)
#     762         for name, obj in self._iterate_slices():
#     763             try:
# --> 764                 result, counts = self.grouper.agg_series(obj, f)
#     765                 output[name] = self._try_cast(result, obj)
#     766             except TypeError:
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in agg_series(self, obj, func)
#    1861             return self._aggregate_series_fast(obj, func)
#    1862         except Exception:
# -> 1863             return self._aggregate_series_pure_python(obj, func)
#    1864
#    1865     def _aggregate_series_fast(self, obj, func):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _aggregate_series_pure_python(self, obj, func)
#    1895                 if (isinstance(res, (Series, Index, np.ndarray)) or
#    1896                         isinstance(res, list)):
# -> 1897                     raise ValueError('Function does not reduce')
#    1898                 result = np.empty(ngroups, dtype='O')
#    1899
#
# ValueError: Function does not reduce

# %%
casesPaire=["NFIN","SG-PRS-IND-2"]
pdParadigmes["forme"][casesPaire].dropna()
